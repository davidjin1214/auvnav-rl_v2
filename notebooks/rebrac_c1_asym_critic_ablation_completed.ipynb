# %% [markdown]
# # ReBRAC C1 — Asymmetric Critic Ablation
#
# > 文档锚点：[CLAUDE.md §3 Asymmetric Critic](../CLAUDE.md) · [docs/online_rl_thesis_plan.md](../docs/online_rl_thesis_plan.md) · [notebooks/rebrac_c1_reward_ablation_completed.ipynb](rebrac_c1_reward_ablation_completed.ipynb)
#
# ## 前传 — 已知事实
#
# | run | dataset | reward | critic | seeds | test success | mean_return |
# |---|---|---|---|---:|---:|---:|
# | broad C1 anchor | crosscomp_s0_h4_eff_v2_u10upstream | efficiency_v2 | sym (10-D) | 5 | **0.225 ± 0.005** | −371 ± 0.41 |
# | reward ablation | crosscomp_s0_h4_arr_v2_s_u10upstream | arrival_v2_simple | sym (10-D) | 2 | **0.215 ± 0.015** | −98 ± 4 |
#
# Reward 干预把 dataset mean_R 从 −108 翻到 +205，**actor 摆脱 deterministic-collapse**（termination 从 ~all timeout → 51% timeout / 26% OOB / 21% goal），但 test success 几乎不动（−1pp）。Verdict：**β 主导，C1 是 s0 sensor info 不够**。
#
# ## 假设 — Asymmetric critic 能否打开 s0 actor 的天花板？
#
# CLAUDE.md 主方法论：**actor 受 deployment-realistic s0 约束（10-D obs），critic 拿 hull-integral 流场（privileged_obs, dim=2）做 TD target**。
# deployment 时 actor 仍 s0，但训练时 critic 给出更好的 supervisory signal。
#
# 数据通路（已就绪）：
# - arrival_v2_simple dataset: sanity card `privileged_obs_present: True` ✓
# - `train_offline.py --use-asymmetric-critic` flag
# - `--privileged-actor-update-mode zeros` 默认值：actor improvement 时 zero-pad privileged channels，mimic deployment（与 online line 一致）
#
# ## Verdict 逻辑（事先 commit）
#
# | arrival_v2_simple + asym test success | verdict | 含义 |
# |---:|---|---|
# | **≥ 0.6** | **asym 主导** | privileged critic 解锁 s0 actor — paper headline；CLAUDE.md §3 在 offline 同样有效 |
# | **0.4–0.6** | **asym 部分有效** | privileged signal 帮助但 s0 actor 仍受限；考虑加 seed 或调 actor_update_mode=batch |
# | **≤ 0.4** | **β floor** | s0 actor 物理上不能在 upstream u10 跑通 — C1 重定义为 sensor floor spoke，paper 写「需要 s1+ 才能 deploy」 |
#
# ## 与前两次实验的隔离
#
# | 维度 | broad C1 | reward ablation | **本 notebook** |
# |---|---|---|---|
# | dataset | eff_v2 | arr_v2_s | **arr_v2_s（复用）** |
# | reward | efficiency_v2 | arrival_v2_simple | **arrival_v2_simple** |
# | critic | sym (10-D) | sym (10-D) | **asym (10-D + 2-D priv)** |
# | β1, β2 | 4.0, 2.0 | 4.0, 2.0 | **4.0, 2.0**（anchor 不动） |
# | seeds | 42–46 (5) | 42, 44 (2) | **42, 44 (2)** |
#
# 唯一变量：`--use-asymmetric-critic`。其余完全一致以隔离信号。

# %% [markdown]
# ## 1. 环境 sanity check

# %%
# !lscpu | head -10
print()
# !nvidia-smi
# Out:
# Architecture:                            x86_64
# CPU op-mode(s):                          32-bit, 64-bit
# Address sizes:                           46 bits physical, 48 bits virtual
# Byte Order:                              Little Endian
# CPU(s):                                  12
# On-line CPU(s) list:                     0-11
# Vendor ID:                               GenuineIntel
# Model name:                              Intel(R) Xeon(R) CPU @ 2.20GHz
# CPU family:                              6
# Model:                                   85
#
# Wed May  6 11:16:12 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA L4                      Off |   00000000:00:03.0 Off |                    0 |
# | N/A   39C    P8             13W /   72W |       0MiB /  23034MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
import torch
print(f'PyTorch: {torch.__version__}')
print(f'CUDA available: {torch.cuda.is_available()}')
# Out:
# PyTorch: 2.10.0+cu128
# CUDA available: True

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# %cd /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5

# %% [markdown]
# ## 2. 通用配置
#
# **复用** reward ablation 的 dataset / manifest，仅切换 critic 类型。`CHECKPOINT_ROOT` / `RESULTS_ROOT` 单独命名以避免与 sym critic 结果碰撞。

# %%
import os
from pathlib import Path

# ---- 与 reward ablation 完全一致的 dataset / 任务 / 评估配置 ----
OBJECTIVE = 'arrival_v2_simple'
PROBE_LAYOUT = 's0'
TASK_GEOMETRY = 'upstream'
TARGET_SPEED = 1.5
HISTORY_LENGTH = 4
FLOW_PATH = 'wake_data/wake_v8_U1p00_Re150_D12p00_dx0p60_Ti5pct_1200f_roi.npy'
BENCHMARK_KEY = 'single_u10_upstream_tgt15'
DATASET_EPISODES = 1000
VAL_EPISODES = 40
TEST_EPISODES = 100

# ---- 训练 anchor（保持与 sym critic anchor 完全一致）----
ACTOR_PENALTY_COEF = 4.0
CRITIC_PENALTY_COEF = 2.0
TRAIN_SEEDS = [42, 44]
TRAIN_EPOCHS = 64
BATCH_SIZE = 256
HIDDEN_DIM = 256
NUM_HIDDEN_LAYERS = 3
GAMMA = 0.99
TAU = 0.005
ACTOR_LR = 3e-4
CRITIC_LR = 3e-4
POLICY_NOISE = 0.2
NOISE_CLIP = 0.5
POLICY_FREQ = 2
GRAD_CLIP_NORM = 10.0
NORMALIZER_EPS = 1e-3

# ---- Asymmetric critic 配置（CLAUDE.md §3 默认）----
PRIVILEGED_ACTOR_UPDATE_MODE = 'zeros'  # actor improvement zero-pads priv channels (deployment-realistic)

# ---- 路径 ----
DATASET_NAME = (
    f'crosscomp_{PROBE_LAYOUT}_h{HISTORY_LENGTH}_{OBJECTIVE}'
    f'_re150_u10upstream_fixdone_ep{DATASET_EPISODES}'
)
DATASET_DIR = Path('offline_data') / DATASET_NAME
TRANSITIONS_NPZ = str(DATASET_DIR / 'transitions.npz')
DATASET_DIR_STR = str(DATASET_DIR)

# 单独的 checkpoint / result 树（asym critic 不与 sym 混）
CHECKPOINT_ROOT = Path('checkpoints/offline/rebrac/c1_asym_critic_ablation')
RESULTS_ROOT = Path('results/offline/rebrac/c1_asym_critic_ablation')

# 复用 reward ablation 的 manifests（geometry / probe / target_speed 完全一致）
VAL_MANIFEST_PATH  = Path(f'benchmarks/c1_reward_ablation/val_{VAL_EPISODES}/{BENCHMARK_KEY}.json')
TEST_MANIFEST_PATH = Path(f'benchmarks/c1_reward_ablation/test_{TEST_EPISODES}/{BENCHMARK_KEY}.json')
VAL_MANIFEST_STR  = str(VAL_MANIFEST_PATH)
TEST_MANIFEST_STR = str(TEST_MANIFEST_PATH)

print(f'DATASET_DIR     = {DATASET_DIR}')
print(f'VAL_MANIFEST    = {VAL_MANIFEST_PATH}  (exists={VAL_MANIFEST_PATH.exists()})')
print(f'TEST_MANIFEST   = {TEST_MANIFEST_PATH}  (exists={TEST_MANIFEST_PATH.exists()})')
print(f'CHECKPOINT_ROOT = {CHECKPOINT_ROOT}')
print(f'RESULTS_ROOT    = {RESULTS_ROOT}')
# Out:
# DATASET_DIR     = offline_data/crosscomp_s0_h4_arrival_v2_simple_re150_u10upstream_fixdone_ep1000
# VAL_MANIFEST    = benchmarks/c1_reward_ablation/val_40/single_u10_upstream_tgt15.json  (exists=True)
# TEST_MANIFEST   = benchmarks/c1_reward_ablation/test_100/single_u10_upstream_tgt15.json  (exists=True)
# CHECKPOINT_ROOT = checkpoints/offline/rebrac/c1_asym_critic_ablation
# RESULTS_ROOT    = results/offline/rebrac/c1_asym_critic_ablation

# %% [markdown]
# ## 3. Pre-flight — 验证 dataset 含 `privileged_obs` / `next_privileged_obs`
#
# Asymmetric critic 在 TD target 时取 `privileged_obs` 和 `next_privileged_obs`；这两列必须在 npz 里。reward ablation 的 sanity card 已说 `privileged_obs_present: True`，这里再做一次硬检查 + dim assert (=2)。

# %%
import numpy as np

assert (DATASET_DIR / 'transitions.npz').exists(), f'missing dataset: {DATASET_DIR}'
data = np.load(DATASET_DIR / 'transitions.npz')
print('npz keys:', list(data.keys()))

for key in ('privileged_obs', 'next_privileged_obs'):
    assert key in data.files, f'missing column: {key} (asym critic requires it)'
    arr = data[key]
    assert arr.ndim == 2, f'{key} ndim={arr.ndim} (expect 2)'
    assert arr.shape[1] == 2, f'{key} dim={arr.shape[1]} (expect 2: body-frame [u_eq, v_eq])'
    print(f'  {key:22s} shape={arr.shape}  '
          f'mean=[{arr[:, 0].mean():+.3f}, {arr[:, 1].mean():+.3f}]  '
          f'std=[{arr[:, 0].std():.3f}, {arr[:, 1].std():.3f}]')

print()
print('[OK] dataset is asym-critic ready')
# Out:
# npz keys: ['obs', 'actions', 'next_actions', 'rewards', 'costs', 'next_obs', 'dones', 'terminateds', 'truncateds', 'terminal_reason_codes', 'behavior_policy_codes', 'privileged_obs', 'next_privileged_obs']
#   privileged_obs         shape=(268329, 2)  mean=[-0.961, +0.002]  std=[0.169, 0.262]
#   next_privileged_obs    shape=(268329, 2)  mean=[-0.961, +0.002]  std=[0.169, 0.262]
#
# [OK] dataset is asym-critic ready

# %% [markdown]
# ## 4. 训练 — ReBRAC anchor (β1=4.0, β2=2.0) + asym critic × 2 seeds
#
# 唯一新增 flag：
# - `--use-asymmetric-critic` — critic 用 (s, a, priv_obs) 计算 Q
# - `--privileged-actor-update-mode zeros` — actor 改进时 zero-pad priv 通道（mimic deployment）
#
# 其余超参与 reward ablation 完全一致。预期 ~30 min/seed × 2 = ~1h L4。

# %%
PAIR_TAG = f'actorb_{ACTOR_PENALTY_COEF:.1f}__criticb_{CRITIC_PENALTY_COEF:.1f}'.replace('.', 'p')

def seed_dir(seed: int) -> Path:
    return CHECKPOINT_ROOT / DATASET_NAME / PAIR_TAG / f'seed_{seed}'

for seed in TRAIN_SEEDS:
    save_dir = seed_dir(seed)
    save_dir_str = str(save_dir)
    if (save_dir / 'agent_final.pt').exists():
        print(f'[skip] seed {seed} done: {save_dir}')
        continue
    print(f'\n========== train seed {seed} (asym critic) → {save_dir} ==========')
    # !python -m scripts.train_offline \
        --algo rebrac \
        --offline-data {TRANSITIONS_NPZ} \
        --flow {FLOW_PATH} \
        --manifest {VAL_MANIFEST_STR} \
        --probe-layout {PROBE_LAYOUT} \
        --history-length {HISTORY_LENGTH} \
        --task-geometry {TASK_GEOMETRY} \
        --target-speed {TARGET_SPEED} \
        --objective {OBJECTIVE} \
        --sampling-mode shuffle_no_replacement \
        --num-epochs {TRAIN_EPOCHS} \
        --batch-size {BATCH_SIZE} \
        --hidden-dim {HIDDEN_DIM} \
        --num-hidden-layers {NUM_HIDDEN_LAYERS} \
        --gamma {GAMMA} \
        --tau {TAU} \
        --actor-lr {ACTOR_LR} \
        --critic-lr {CRITIC_LR} \
        --actor-penalty-coef {ACTOR_PENALTY_COEF} \
        --critic-penalty-coef {CRITIC_PENALTY_COEF} \
        --policy-noise {POLICY_NOISE} \
        --noise-clip {NOISE_CLIP} \
        --policy-freq {POLICY_FREQ} \
        --grad-clip-norm {GRAD_CLIP_NORM} \
        --normalizer-eps {NORMALIZER_EPS} \
        --use-asymmetric-critic \
        --privileged-actor-update-mode {PRIVILEGED_ACTOR_UPDATE_MODE} \
        --eval-every 0 \
        --skip-final-eval \
        --seed {seed} \
        --device cuda \
        --save-dir {save_dir_str}
# Out:
# ========== train seed 42 (asym critic) → checkpoints/offline/rebrac/c1_asym_critic_ablation/crosscomp_s0_h4_arrival_v2_simple_re150_u10upstream_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_42 ==========
# [offline] algo=rebrac transitions=268329 obs_dim=40 action_dim=2 protocol=privileged-critic tensor_replay=on eval_workers=1 sampling=shuffle_no_replacement total_steps=67136
# [train] step=1 epoch=1 epoch_step=1 q=-0.557 critic=163.751 actor=5.655 bc=1.164 lambda=1.796 critic_pen=1.244
# [train] step=1000 epoch=1 epoch_step=1000 q=-1.744 critic=132.644 actor=0.690 bc=0.034 lambda=0.317 critic_pen=0.085
# [train] step=2000 epoch=2 epoch_step=951 q=-1.277 critic=2.647 actor=0.364 bc=0.025 lambda=0.206 critic_pen=0.078
# [train] step=3000 epoch=3 epoch_step=902 q=0.929 critic=153.075 actor=-0.053 bc=0.020 lambda=0.145 critic_pen=0.093
# [train] step=4000 epoch=4 epoch_step=853 q=0.462 critic=2.243 actor=0.048 bc=0.027 lambda=0.134 critic_pen=0.087
# [train] step=5000 epoch=5 epoch_step=804 q=3.529 critic=5.258 actor=-0.215 bc=0.030 lambda=0.095 critic_pen=0.088
# [train] step=6000 epoch=6 epoch_step=755 q=5.528 critic=16.547 actor=-0.350 bc=0.015 lambda=0.074 critic_pen=0.090
# [train] step=7000 epoch=7 epoch_step=706 q=10.783 critic=22.853 actor=-0.468 bc=0.024 lambda=0.052 critic_pen=0.092
# [train] step=8000 epoch=8 epoch_step=657 q=13.031 critic=15.742 actor=-0.357 bc=0.059 lambda=0.046 critic_pen=0.079
# [train] step=9000 epoch=9 epoch_step=608 q=15.752 critic=9.950 actor=-0.488 bc=0.035 lambda=0.040 critic_pen=0.091
# [train] step=10000 epoch=10 epoch_step=559 q=23.543 critic=10.754 actor=-0.623 bc=0.024 lambda=0.031 critic_pen=0.083
# [train] step=11000 epoch=11 epoch_step=510 q=29.597 critic=14.972 actor=-0.718 bc=0.014 lambda=0.026 critic_pen=0.077
# [train] step=12000 epoch=12 epoch_step=461 q=26.982 critic=13.342 actor=-0.556 bc=0.044 lambda=0.027 critic_pen=0.083
# [train] step=13000 epoch=13 epoch_step=412 q=29.029 critic=12.311 actor=-0.691 bc=0.016 lambda=0.026 critic_pen=0.071
# [train] step=14000 epoch=14 epoch_step=363 q=43.470 critic=16.625 actor=-0.757 bc=0.018 lambda=0.019 critic_pen=0.069
# [train] step=15000 epoch=15 epoch_step=314 q=29.243 critic=11.664 actor=-0.652 bc=0.024 lambda=0.026 critic_pen=0.079
# [train] step=16000 epoch=16 epoch_step=265 q=42.885 critic=10.828 actor=-0.788 bc=0.007 lambda=0.019 critic_pen=0.082
# [train] step=17000 epoch=17 epoch_step=216 q=34.105 critic=11.650 actor=-0.668 bc=0.025 lambda=0.023 critic_pen=0.089
# [train] step=18000 epoch=18 epoch_step=167 q=41.503 critic=9.071 actor=-0.707 bc=0.024 lambda=0.019 critic_pen=0.090
# [train] step=19000 epoch=19 epoch_step=118 q=48.074 critic=9.875 actor=-0.739 bc=0.022 lambda=0.017 critic_pen=0.064
# [train] step=20000 epoch=20 epoch_step=69 q=53.192 critic=10.705 actor=-0.767 bc=0.021 lambda=0.016 critic_pen=0.075
# [train] step=21000 epoch=21 epoch_step=20 q=48.016 critic=12.300 actor=-0.704 bc=0.032 lambda=0.017 critic_pen=0.074
# [train] step=22000 epoch=21 epoch_step=1020 q=47.574 critic=9.290 actor=-0.796 bc=0.007 lambda=0.017 critic_pen=0.066
# [train] step=23000 epoch=22 epoch_step=971 q=46.665 critic=11.247 actor=-0.770 bc=0.013 lambda=0.018 critic_pen=0.068
# [train] step=24000 epoch=23 epoch_step=922 q=45.343 critic=6.616 actor=-0.731 bc=0.021 lambda=0.018 critic_pen=0.062
# [train] step=25000 epoch=24 epoch_step=873 q=49.396 critic=8.595 actor=-0.789 bc=0.010 lambda=0.017 critic_pen=0.060
# [train] step=26000 epoch=25 epoch_step=824 q=59.086 critic=8.736 actor=-0.781 bc=0.020 lambda=0.015 critic_pen=0.072
# [train] step=27000 epoch=26 epoch_step=775 q=54.772 critic=6.312 actor=-0.771 bc=0.018 lambda=0.015 critic_pen=0.069
# [train] step=28000 epoch=27 epoch_step=726 q=58.260 critic=6.053 actor=-0.735 bc=0.029 lambda=0.015 critic_pen=0.080
# [train] step=29000 epoch=28 epoch_step=677 q=47.973 critic=5.714 actor=-0.746 bc=0.016 lambda=0.017 critic_pen=0.066
# [train] step=30000 epoch=29 epoch_step=628 q=53.586 critic=6.467 actor=-0.797 bc=0.010 lambda=0.016 critic_pen=0.056
# [train] step=31000 epoch=30 epoch_step=579 q=52.243 critic=6.821 actor=-0.796 bc=0.009 lambda=0.016 critic_pen=0.062
# [train] step=32000 epoch=31 epoch_step=530 q=61.541 critic=13.058 actor=-0.816 bc=0.012 lambda=0.014 critic_pen=0.075
# [train] step=33000 epoch=32 epoch_step=481 q=65.366 critic=6.096 actor=-0.845 bc=0.006 lambda=0.013 critic_pen=0.074
# [train] step=34000 epoch=33 epoch_step=432 q=52.264 critic=5.351 actor=-0.772 bc=0.014 lambda=0.016 critic_pen=0.073
# [train] step=35000 epoch=34 epoch_step=383 q=51.167 critic=6.579 actor=-0.712 bc=0.027 lambda=0.016 critic_pen=0.065
# [train] step=36000 epoch=35 epoch_step=334 q=70.622 critic=8.169 actor=-0.825 bc=0.016 lambda=0.013 critic_pen=0.103
# [train] step=37000 epoch=36 epoch_step=285 q=60.290 critic=4.432 actor=-0.774 bc=0.020 lambda=0.014 critic_pen=0.062
# [train] step=38000 epoch=37 epoch_step=236 q=66.696 critic=5.869 actor=-0.782 bc=0.024 lambda=0.013 critic_pen=0.065
# [train] step=39000 epoch=38 epoch_step=187 q=52.019 critic=3.949 actor=-0.722 bc=0.027 lambda=0.016 critic_pen=0.065
# [train] step=40000 epoch=39 epoch_step=138 q=58.176 critic=4.368 actor=-0.762 bc=0.021 lambda=0.015 critic_pen=0.066
# [train] step=41000 epoch=40 epoch_step=89 q=58.258 critic=4.456 actor=-0.800 bc=0.011 lambda=0.014 critic_pen=0.080
# [train] step=42000 epoch=41 epoch_step=40 q=64.324 critic=3.716 actor=-0.776 bc=0.021 lambda=0.013 critic_pen=0.058
# [train] step=43000 epoch=41 epoch_step=1040 q=64.859 critic=4.587 actor=-0.758 bc=0.027 lambda=0.013 critic_pen=0.063
# [train] step=44000 epoch=42 epoch_step=991 q=65.515 critic=5.082 actor=-0.765 bc=0.025 lambda=0.013 critic_pen=0.063
# [train] step=45000 epoch=43 epoch_step=942 q=64.305 critic=4.312 actor=-0.840 bc=0.007 lambda=0.013 critic_pen=0.051
# [train] step=46000 epoch=44 epoch_step=893 q=69.836 critic=8.590 actor=-0.853 bc=0.005 lambda=0.012 critic_pen=0.066
# [train] step=47000 epoch=45 epoch_step=844 q=54.639 critic=3.367 actor=-0.700 bc=0.034 lambda=0.015 critic_pen=0.062
# [train] step=48000 epoch=46 epoch_step=795 q=66.605 critic=6.331 actor=-0.811 bc=0.015 lambda=0.013 critic_pen=0.077
# [train] step=49000 epoch=47 epoch_step=746 q=58.050 critic=3.880 actor=-0.820 bc=0.004 lambda=0.014 critic_pen=0.088
# [train] step=50000 epoch=48 epoch_step=697 q=69.998 critic=4.379 actor=-0.707 bc=0.044 lambda=0.013 critic_pen=0.075
# [train] step=51000 epoch=49 epoch_step=648 q=60.560 critic=4.972 actor=-0.789 bc=0.017 lambda=0.014 critic_pen=0.084
# [train] step=52000 epoch=50 epoch_step=599 q=75.115 critic=5.150 actor=-0.839 bc=0.015 lambda=0.012 critic_pen=0.076
# [train] step=53000 epoch=51 epoch_step=550 q=71.525 critic=5.320 actor=-0.784 bc=0.026 lambda=0.012 critic_pen=0.086
# [train] step=54000 epoch=52 epoch_step=501 q=67.060 critic=4.243 actor=-0.766 bc=0.031 lambda=0.013 critic_pen=0.057
# [train] step=55000 epoch=53 epoch_step=452 q=64.521 critic=3.528 actor=-0.813 bc=0.015 lambda=0.014 critic_pen=0.065
# [train] step=56000 epoch=54 epoch_step=403 q=67.152 critic=4.545 actor=-0.666 bc=0.052 lambda=0.013 critic_pen=0.067
# [train] step=57000 epoch=55 epoch_step=354 q=66.511 critic=5.017 actor=-0.814 bc=0.017 lambda=0.013 critic_pen=0.068
# [train] step=58000 epoch=56 epoch_step=305 q=68.814 critic=3.984 actor=-0.859 bc=0.005 lambda=0.013 critic_pen=0.069
# [train] step=59000 epoch=57 epoch_step=256 q=63.578 critic=6.126 actor=-0.796 bc=0.020 lambda=0.014 critic_pen=0.062
# [train] step=60000 epoch=58 epoch_step=207 q=80.921 critic=5.275 actor=-0.896 bc=0.004 lambda=0.011 critic_pen=0.077
# [train] step=61000 epoch=59 epoch_step=158 q=73.046 critic=5.850 actor=-0.867 bc=0.008 lambda=0.012 critic_pen=0.103
# [train] step=62000 epoch=60 epoch_step=109 q=65.022 critic=4.393 actor=-0.817 bc=0.013 lambda=0.013 critic_pen=0.071
# [train] step=63000 epoch=61 epoch_step=60 q=76.510 critic=4.306 actor=-0.780 bc=0.031 lambda=0.012 critic_pen=0.088
# [train] step=64000 epoch=62 epoch_step=11 q=74.914 critic=6.662 actor=-0.854 bc=0.011 lambda=0.012 critic_pen=0.063
# [train] step=65000 epoch=62 epoch_step=1011 q=63.517 critic=5.365 actor=-0.796 bc=0.022 lambda=0.014 critic_pen=0.062
# [train] step=66000 epoch=63 epoch_step=962 q=62.538 critic=6.363 actor=-0.693 bc=0.043 lambda=0.014 critic_pen=0.064
# [train] step=67000 epoch=64 epoch_step=913 q=66.511 critic=4.904 actor=-0.878 bc=0.004 lambda=0.013 critic_pen=0.061
#
# ========== train seed 44 (asym critic) → checkpoints/offline/rebrac/c1_asym_critic_ablation/crosscomp_s0_h4_arrival_v2_simple_re150_u10upstream_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_44 ==========
# [offline] algo=rebrac transitions=268329 obs_dim=40 action_dim=2 protocol=privileged-critic tensor_replay=on eval_workers=1 sampling=shuffle_no_replacement total_steps=67136
# [train] step=1 epoch=1 epoch_step=1 q=-0.559 critic=162.355 actor=5.450 bc=1.112 lambda=1.789 critic_pen=1.173
# [train] step=1000 epoch=1 epoch_step=1000 q=-2.100 critic=130.166 actor=0.913 bc=0.057 lambda=0.326 critic_pen=0.127
# [train] step=2000 epoch=2 epoch_step=951 q=-2.143 critic=1.100 actor=0.667 bc=0.031 lambda=0.254 critic_pen=0.102
# [train] step=3000 epoch=3 epoch_step=902 q=0.780 critic=243.243 actor=0.084 bc=0.051 lambda=0.152 critic_pen=0.073
# [train] step=4000 epoch=4 epoch_step=853 q=1.667 critic=6.316 actor=-0.101 bc=0.022 lambda=0.114 critic_pen=0.060
# [train] step=5000 epoch=5 epoch_step=804 q=4.552 critic=68.201 actor=-0.177 bc=0.053 lambda=0.085 critic_pen=0.076
# [train] step=6000 epoch=6 epoch_step=755 q=12.733 critic=13.935 actor=-0.340 bc=0.070 lambda=0.049 critic_pen=0.082
# [train] step=7000 epoch=7 epoch_step=706 q=13.091 critic=6.802 actor=-0.507 bc=0.021 lambda=0.045 critic_pen=0.088
# [train] step=8000 epoch=8 epoch_step=657 q=14.455 critic=12.423 actor=-0.416 bc=0.054 lambda=0.044 critic_pen=0.086
# [train] step=9000 epoch=9 epoch_step=608 q=13.125 critic=14.623 actor=-0.455 bc=0.034 lambda=0.045 critic_pen=0.072
# [train] step=10000 epoch=10 epoch_step=559 q=21.265 critic=10.575 actor=-0.626 bc=0.020 lambda=0.033 critic_pen=0.070
# [train] step=11000 epoch=11 epoch_step=510 q=28.814 critic=12.938 actor=-0.664 bc=0.023 lambda=0.026 critic_pen=0.086
# [train] step=12000 epoch=12 epoch_step=461 q=23.522 critic=8.218 actor=-0.560 bc=0.038 lambda=0.030 critic_pen=0.053
# [train] step=13000 epoch=13 epoch_step=412 q=39.432 critic=18.472 actor=-0.735 bc=0.022 lambda=0.021 critic_pen=0.073
# [train] step=14000 epoch=14 epoch_step=363 q=36.375 critic=12.626 actor=-0.666 bc=0.031 lambda=0.022 critic_pen=0.084
# [train] step=15000 epoch=15 epoch_step=314 q=42.429 critic=12.815 actor=-0.655 bc=0.039 lambda=0.019 critic_pen=0.071
# [train] step=16000 epoch=16 epoch_step=265 q=39.097 critic=13.975 actor=-0.641 bc=0.037 lambda=0.020 critic_pen=0.073
# [train] step=17000 epoch=17 epoch_step=216 q=41.930 critic=9.171 actor=-0.737 bc=0.019 lambda=0.019 critic_pen=0.076
# [train] step=18000 epoch=18 epoch_step=167 q=38.418 critic=11.353 actor=-0.629 bc=0.037 lambda=0.020 critic_pen=0.102
# [train] step=19000 epoch=19 epoch_step=118 q=39.474 critic=8.808 actor=-0.714 bc=0.017 lambda=0.020 critic_pen=0.081
# [train] step=20000 epoch=20 epoch_step=69 q=45.284 critic=9.772 actor=-0.641 bc=0.041 lambda=0.018 critic_pen=0.107
# [train] step=21000 epoch=21 epoch_step=20 q=50.136 critic=9.870 actor=-0.735 bc=0.024 lambda=0.017 critic_pen=0.071
# [train] step=22000 epoch=21 epoch_step=1020 q=43.603 critic=12.485 actor=-0.733 bc=0.016 lambda=0.018 critic_pen=0.070
# [train] step=23000 epoch=22 epoch_step=971 q=41.830 critic=8.155 actor=-0.764 bc=0.004 lambda=0.019 critic_pen=0.058
# [train] step=24000 epoch=23 epoch_step=922 q=50.016 critic=9.765 actor=-0.670 bc=0.038 lambda=0.016 critic_pen=0.072
# [train] step=25000 epoch=24 epoch_step=873 q=53.879 critic=9.759 actor=-0.743 bc=0.024 lambda=0.016 critic_pen=0.065
# [train] step=26000 epoch=25 epoch_step=824 q=59.720 critic=8.075 actor=-0.726 bc=0.032 lambda=0.014 critic_pen=0.083
# [train] step=27000 epoch=26 epoch_step=775 q=50.861 critic=7.605 actor=-0.792 bc=0.007 lambda=0.016 critic_pen=0.074
# [train] step=28000 epoch=27 epoch_step=726 q=53.577 critic=6.414 actor=-0.737 bc=0.022 lambda=0.015 critic_pen=0.058
# [train] step=29000 epoch=28 epoch_step=677 q=55.632 critic=8.928 actor=-0.811 bc=0.005 lambda=0.015 critic_pen=0.070
# [train] step=30000 epoch=29 epoch_step=628 q=54.534 critic=5.084 actor=-0.766 bc=0.016 lambda=0.015 critic_pen=0.074
# [train] step=31000 epoch=30 epoch_step=579 q=56.703 critic=5.460 actor=-0.813 bc=0.006 lambda=0.015 critic_pen=0.068
# [train] step=32000 epoch=31 epoch_step=530 q=51.255 critic=5.527 actor=-0.639 bc=0.044 lambda=0.016 critic_pen=0.068
# [train] step=33000 epoch=32 epoch_step=481 q=61.649 critic=8.508 actor=-0.783 bc=0.020 lambda=0.014 critic_pen=0.065
# [train] step=34000 epoch=33 epoch_step=432 q=56.004 critic=6.093 actor=-0.641 bc=0.048 lambda=0.015 critic_pen=0.079
# [train] step=35000 epoch=34 epoch_step=383 q=57.240 critic=3.757 actor=-0.726 bc=0.027 lambda=0.015 critic_pen=0.071
# [train] step=36000 epoch=35 epoch_step=334 q=61.665 critic=6.550 actor=-0.750 bc=0.025 lambda=0.014 critic_pen=0.062
# [train] step=37000 epoch=36 epoch_step=285 q=52.878 critic=5.438 actor=-0.686 bc=0.032 lambda=0.015 critic_pen=0.070
# [train] step=38000 epoch=37 epoch_step=236 q=54.512 critic=4.107 actor=-0.688 bc=0.033 lambda=0.015 critic_pen=0.090
# [train] step=39000 epoch=38 epoch_step=187 q=66.466 critic=5.539 actor=-0.844 bc=0.006 lambda=0.013 critic_pen=0.097
# [train] step=40000 epoch=39 epoch_step=138 q=65.399 critic=5.207 actor=-0.791 bc=0.019 lambda=0.013 critic_pen=0.063
# [train] step=41000 epoch=40 epoch_step=89 q=56.596 critic=3.845 actor=-0.777 bc=0.012 lambda=0.015 critic_pen=0.061
# [train] step=42000 epoch=41 epoch_step=40 q=61.393 critic=3.704 actor=-0.745 bc=0.024 lambda=0.014 critic_pen=0.063
# [train] step=43000 epoch=41 epoch_step=1040 q=45.591 critic=3.685 actor=-0.731 bc=0.012 lambda=0.017 critic_pen=0.066
# [train] step=44000 epoch=42 epoch_step=991 q=61.564 critic=4.194 actor=-0.734 bc=0.029 lambda=0.014 critic_pen=0.063
# [train] step=45000 epoch=43 epoch_step=942 q=59.031 critic=5.707 actor=-0.806 bc=0.011 lambda=0.014 critic_pen=0.085
# [train] step=46000 epoch=44 epoch_step=893 q=63.296 critic=7.385 actor=-0.787 bc=0.017 lambda=0.014 critic_pen=0.073
# [train] step=47000 epoch=45 epoch_step=844 q=65.121 critic=3.506 actor=-0.788 bc=0.021 lambda=0.013 critic_pen=0.069
# [train] step=48000 epoch=46 epoch_step=795 q=61.560 critic=5.184 actor=-0.754 bc=0.024 lambda=0.014 critic_pen=0.069
# [train] step=49000 epoch=47 epoch_step=746 q=54.397 critic=5.101 actor=-0.624 bc=0.047 lambda=0.015 critic_pen=0.053
# [train] step=50000 epoch=48 epoch_step=697 q=56.428 critic=4.450 actor=-0.767 bc=0.017 lambda=0.015 critic_pen=0.059
# [train] step=51000 epoch=49 epoch_step=648 q=69.196 critic=4.731 actor=-0.802 bc=0.020 lambda=0.013 critic_pen=0.071
# [train] step=52000 epoch=50 epoch_step=599 q=66.922 critic=5.026 actor=-0.790 bc=0.022 lambda=0.013 critic_pen=0.054
# [train] step=53000 epoch=51 epoch_step=550 q=74.744 critic=5.720 actor=-0.787 bc=0.025 lambda=0.012 critic_pen=0.076
# [train] step=54000 epoch=52 epoch_step=501 q=63.333 critic=4.421 actor=-0.753 bc=0.028 lambda=0.014 critic_pen=0.069
# [train] step=55000 epoch=53 epoch_step=452 q=64.354 critic=6.245 actor=-0.806 bc=0.017 lambda=0.014 critic_pen=0.066
# [train] step=56000 epoch=54 epoch_step=403 q=68.502 critic=5.075 actor=-0.839 bc=0.009 lambda=0.013 critic_pen=0.061
# [train] step=57000 epoch=55 epoch_step=354 q=59.277 critic=5.804 actor=-0.790 bc=0.014 lambda=0.014 critic_pen=0.067
# [train] step=58000 epoch=56 epoch_step=305 q=67.858 critic=5.146 actor=-0.851 bc=0.008 lambda=0.013 critic_pen=0.061
# [train] step=59000 epoch=57 epoch_step=256 q=69.677 critic=5.046 actor=-0.733 bc=0.039 lambda=0.013 critic_pen=0.055
# [train] step=60000 epoch=58 epoch_step=207 q=60.718 critic=6.070 actor=-0.845 bc=0.004 lambda=0.014 critic_pen=0.064
# [train] step=61000 epoch=59 epoch_step=158 q=68.846 critic=4.397 actor=-0.854 bc=0.006 lambda=0.013 critic_pen=0.057
# [train] step=62000 epoch=60 epoch_step=109 q=64.392 critic=4.020 actor=-0.841 bc=0.008 lambda=0.014 critic_pen=0.062
# [train] step=63000 epoch=61 epoch_step=60 q=66.008 critic=5.700 actor=-0.854 bc=0.009 lambda=0.013 critic_pen=0.059
# [train] step=64000 epoch=62 epoch_step=11 q=61.013 critic=3.018 actor=-0.834 bc=0.008 lambda=0.014 critic_pen=0.063
# [train] step=65000 epoch=62 epoch_step=1011 q=62.392 critic=4.352 actor=-0.757 bc=0.029 lambda=0.014 critic_pen=0.061
# [train] step=66000 epoch=63 epoch_step=962 q=56.479 critic=4.873 actor=-0.758 bc=0.023 lambda=0.015 critic_pen=0.066
# [train] step=67000 epoch=64 epoch_step=913 q=65.358 critic=16.794 actor=-0.823 bc=0.016 lambda=0.014 critic_pen=0.087

# %% [markdown]
# ## 5. Test eval — 100-episode test manifest
#
# evaluate_offline 自动从 `trainer_state.json` 读出 `use_asymmetric_critic=True`，重建 `AsymmetricQNetwork`。**actor 在 eval 时仍只看 s0**（不传 priv_obs），与 deployment 一致。

# %%
import json

TEST_DIR = RESULTS_ROOT / DATASET_NAME / PAIR_TAG / 'test'
TEST_DIR.mkdir(parents=True, exist_ok=True)
EVAL_NUM_WORKERS = 6

for seed in TRAIN_SEEDS:
    out_path = TEST_DIR / f'seed_{seed}.json'
    out_path_str = str(out_path)
    if out_path.exists():
        print(f'[skip] eval done: {out_path}')
        continue
    save_dir = seed_dir(seed)
    save_dir_str = str(save_dir)
    if not (save_dir / 'agent_final.pt').exists():
        print(f'[warn] missing checkpoint: {save_dir}')
        continue
    print(f'\n========== eval seed {seed} (asym) → {out_path} ==========')
    # !python -m scripts.evaluate_offline \
        --checkpoint {save_dir_str} \
        --manifest {TEST_MANIFEST_STR} \
        --episodes {TEST_EPISODES} \
        --num-workers {EVAL_NUM_WORKERS} \
        --worker-device cpu \
        --device cuda \
        --output-json {out_path_str}
# Out:
# ========== eval seed 42 (asym) → results/offline/rebrac/c1_asym_critic_ablation/crosscomp_s0_h4_arrival_v2_simple_re150_u10upstream_fixdone_ep1000/actorb_4p0__criticb_2p0/test/seed_42.json ==========
# reward_objective      : arrival_v2_simple
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.500000
# episodes              : 100
# success_rate          : 21.0%
# avg_return            : -106.85 +/- 164.83
# avg_safety_cost       : 25.971 +/- 38.608
# avg_time_s            : 200.85 +/- 49.92
# avg_time_s_success    : 126.96
# avg_energy            : 126256.24 +/- 31731.18
# avg_path_length_m     : 100.80 +/- 30.73
# avg_progress_ratio    : 0.436 +/- 0.434
# avg_path_efficiency   : 0.364 +/- 0.341
# termination           : {'timeout': 49, 'out_of_bounds': 30, 'goal': 21}
# benchmark_manifest    : benchmarks/c1_reward_ablation/test_100/single_u10_upstream_tgt15.json
#
# ========== eval seed 44 (asym) → results/offline/rebrac/c1_asym_critic_ablation/crosscomp_s0_h4_arrival_v2_simple_re150_u10upstream_fixdone_ep1000/actorb_4p0__criticb_2p0/test/seed_44.json ==========
# reward_objective      : arrival_v2_simple
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.500000
# episodes              : 100
# success_rate          : 18.0%
# avg_return            : -122.88 +/- 160.87
# avg_safety_cost       : 26.319 +/- 38.687
# avg_time_s            : 203.33 +/- 48.88
# avg_time_s_success    : 128.24
# avg_energy            : 126821.20 +/- 30426.46
# avg_path_length_m     : 101.92 +/- 31.81
# avg_progress_ratio    : 0.399 +/- 0.492
# avg_path_efficiency   : 0.352 +/- 0.348
# termination           : {'timeout': 48, 'out_of_bounds': 34, 'goal': 18}
# benchmark_manifest    : benchmarks/c1_reward_ablation/test_100/single_u10_upstream_tgt15.json

# %% [markdown]
# ## 6. 三向对比：eff_v2 + sym  /  arr_v2_s + sym  /  arr_v2_s + asym
#
# 前两行是已知锚点（hard-coded），第三行是本 notebook 输出。
# 也读取 termination 分布（goal / timeout / out_of_bounds），观察 collapse / explore / succeed 状态。

# %%
import json
import pandas as pd

asym_rows = []
for seed in TRAIN_SEEDS:
    p = TEST_DIR / f'seed_{seed}.json'
    if not p.exists():
        print(f'[warn] missing: {p}')
        continue
    d = json.loads(p.read_text(encoding='utf-8'))
    term = d.get('eval_termination_counts', {})
    n = max(int(d.get('eval_episodes', 100)), 1)
    asym_rows.append({
        'seed': seed,
        'success_rate': d['eval_success_rate'],
        'mean_return':  d['eval_return'],
        'safety_cost':  d['eval_safety_cost'],
        'goal_pct':     term.get('goal', 0)         / n,
        'timeout_pct':  term.get('timeout', 0)      / n,
        'oob_pct':      term.get('out_of_bounds', 0) / n,
    })
asym_df = pd.DataFrame(asym_rows)
print('[arrival_v2_simple + ASYM critic — per-seed test]')
print(asym_df.to_string(index=False, float_format=lambda x: f'{x:.4f}'))

# Hard-coded anchors from completed runs
EFF_V2_SYM = {
    'objective': 'efficiency_v2',
    'critic': 'sym (10-D)',
    'success_rate_mean': 0.225, 'success_rate_std': 0.005,
    'mean_return_mean':  -371.0, 'mean_return_std':  0.41,
    'goal_pct': 0.225, 'timeout_pct': 0.775, 'oob_pct': 0.000,
    'n_seeds': 5,
}
ARR_V2_S_SYM = {
    'objective': 'arrival_v2_simple',
    'critic': 'sym (10-D)',
    'success_rate_mean': 0.215, 'success_rate_std': 0.015,
    'mean_return_mean':  -98.23, 'mean_return_std':  4.03,
    'goal_pct': 0.215, 'timeout_pct': 0.525, 'oob_pct': 0.260,
    'n_seeds': 2,
}

if not asym_df.empty:
    asym_summary = {
        'objective': 'arrival_v2_simple',
        'critic': 'asym (10-D + 2-D priv)',
        'success_rate_mean': asym_df['success_rate'].mean(),
        'success_rate_std':  asym_df['success_rate'].std(ddof=0) if len(asym_df) > 1 else 0.0,
        'mean_return_mean':  asym_df['mean_return'].mean(),
        'mean_return_std':   asym_df['mean_return'].std(ddof=0) if len(asym_df) > 1 else 0.0,
        'goal_pct':    asym_df['goal_pct'].mean(),
        'timeout_pct': asym_df['timeout_pct'].mean(),
        'oob_pct':     asym_df['oob_pct'].mean(),
        'n_seeds':     len(asym_df),
    }
    cmp = pd.DataFrame([EFF_V2_SYM, ARR_V2_S_SYM, asym_summary])
    print()
    print('[three-way summary]')
    cols = ['objective', 'critic', 'n_seeds',
            'success_rate_mean', 'success_rate_std',
            'mean_return_mean',  'mean_return_std',
            'goal_pct', 'timeout_pct', 'oob_pct']
    print(cmp[cols].to_string(index=False, float_format=lambda x: f'{x:.4f}'))
# Out:
# [arrival_v2_simple + ASYM critic — per-seed test]
#  seed  success_rate  mean_return  safety_cost  goal_pct  timeout_pct  oob_pct
#    42        0.2100    -106.8508      25.9710    0.2100       0.4900   0.3000
#    44        0.1800    -122.8825      26.3190    0.1800       0.4800   0.3400
#
# [three-way summary]
#         objective                 critic  n_seeds  success_rate_mean  success_rate_std  mean_return_mean  mean_return_std  goal_pct  timeout_pct  oob_pct
#     efficiency_v2             sym (10-D)        5             0.2250            0.0050         -371.0000           0.4100    0.2250       0.7750   0.0000
# arrival_v2_simple             sym (10-D)        2             0.2150            0.0150          -98.2300           4.0300    0.2150       0.5250   0.2600
# arrival_v2_simple asym (10-D + 2-D priv)        2             0.1950            0.0150         -114.8666           8.0158    0.1950       0.4850   0.3200

# %% [markdown]
# ## 7. 自动 verdict — asym critic 能否打开 s0 actor 在 upstream 的天花板？
#
# 事先 commit 的判定规则（§0 回顾）：
#
# | arrival_v2_simple + asym test success | verdict |
# |---:|---|
# | ≥ 0.6 | **asym 主导** — paper headline result |
# | 0.4–0.6 | **asym 部分有效** — 加 seed 或调 actor_update_mode |
# | ≤ 0.4 | **β floor** — s0 actor 物理上限 — C1 重定义为 sensor-floor spoke |

# %%
if asym_df.empty:
    print('[abort] no asym seeds completed; cannot verdict')
else:
    asym_succ = asym_df['success_rate'].mean()
    sym_succ_arr = ARR_V2_S_SYM['success_rate_mean']
    sym_succ_eff = EFF_V2_SYM['success_rate_mean']
    delta_vs_arr_sym = (asym_succ - sym_succ_arr) * 100
    delta_vs_eff_sym = (asym_succ - sym_succ_eff) * 100

    print('=' * 72)
    print(f'C1 asym critic ablation — verdict (n_seeds={len(asym_df)})')
    print('-' * 72)
    print(f'  efficiency_v2 + sym       success = {sym_succ_eff:.4f}  (5-seed)')
    print(f'  arrival_v2_simple + sym   success = {sym_succ_arr:.4f}  (2-seed)')
    print(f'  arrival_v2_simple + ASYM  success = {asym_succ:.4f}  ({len(asym_df)}-seed)')
    print(f'  Δ vs arr_v2_s+sym = {delta_vs_arr_sym:+.2f} pp   '
          f'Δ vs eff_v2+sym = {delta_vs_eff_sym:+.2f} pp')
    print('-' * 72)

    if asym_succ >= 0.60:
        verdict = 'asym 主导：privileged critic 解锁 s0 actor (paper headline)'
        next_step = (
            'Plan: (1) 升 5-seed 严格统计 + bootstrap CI；'
            '(2) 在其他 upstream spokes (e.g. sbs_u15) 复现；'
            '(3) 对比 priv-actor-update-mode zeros vs batch；'
            '(4) paper 主结果章节落地：CLAUDE.md §3 在 offline 同样有效'
        )
    elif asym_succ >= 0.40:
        verdict = 'asym 部分有效：privileged signal 帮但 s0 actor 仍受限'
        next_step = (
            'Plan: (1) 加 seed 收紧 std；(2) 试 --privileged-actor-update-mode batch '
            '(actor 也用 priv_obs 训练但 eval 时仍 s0)；(3) 升 critic_bc_coef 看是否 BC 抑制了 priv signal'
        )
    else:
        verdict = 'β floor：s0 actor 物理上限 — C1 重定义为 sensor-floor spoke'
        next_step = (
            'Plan: (1) C1 redefine：success target 从 90% 降到 ~30%，定位为「s0 deployment floor」；'
            '(2) 加新 spoke C1-s1 (probe_layout=s1) 看 sensor 升级有多大提升；'
            '(3) paper 写「s0 在 upstream 上不可 deploy，需要 s1+」'
        )

    print(f'  verdict   : {verdict}')
    print(f'  next-step : {next_step}')
    print('=' * 72)
# Out:
# ========================================================================
# C1 asym critic ablation — verdict (n_seeds=2)
# ------------------------------------------------------------------------
#   efficiency_v2 + sym       success = 0.2250  (5-seed)
#   arrival_v2_simple + sym   success = 0.2150  (2-seed)
#   arrival_v2_simple + ASYM  success = 0.1950  (2-seed)
#   Δ vs arr_v2_s+sym = -2.00 pp   Δ vs eff_v2+sym = -3.00 pp
# ------------------------------------------------------------------------
#   verdict   : β floor：s0 actor 物理上限 — C1 重定义为 sensor-floor spoke
#   next-step : Plan: (1) C1 redefine：success target 从 90% 降到 ~30%，定位为「s0 deployment floor」；(2) 加新 spoke C1-s1 (probe_layout=s1) 看 sensor 升级有多大提升；(3) paper 写「s0 在 upstream 上不可 deploy，需要 s1+」
# ========================================================================

# %% [markdown]
# ## 8. 报告写入清单
#
# **任何 verdict（必填）**
# - `docs/superpowers/specs/2026-05-04-rebrac-broad-validation-design.md` 新增 §「C1 asym critic ablation」段：anchor 配置 + n_seeds + Δ + termination 分布
# - `docs/superpowers/plans/2026-05-04-rebrac-broad-validation-plan.md` C1 行：本 ablation 结果
# - `docs/rebrac_experiment_report.md`（如果存在）：把 reward + asym 两次 ablation 串成一段叙事
#
# **verdict = asym 主导（≥ 0.6）**
# - 这是 **paper headline result**：CLAUDE.md §3 (Asymmetric Critic with privileged hull-integral flow) 在 offline RL 上同样有效
# - 立即任务：5-seed × bootstrap CI；在 sbs_u15_upstream 等其他 upstream spokes 复现
# - paper 主章节升级：online + offline 双线都用 asym critic 作为方法论亮点
#
# **verdict = asym 部分有效（0.4–0.6）**
# - 需要进一步 ablation：actor_update_mode zeros vs batch；critic_bc_coef sweep
# - spec 加 backlog：「Asym critic on offline — full hyperparameter sweep」
#
# **verdict = β floor（≤ 0.4）**
# - C1 的两条修复路径（reward / asym critic）都验证为无效 → s0 在 upstream 是 fundamental limitation
# - 提议 C1 重定义为「sensor floor spoke」，broad_validation §3 的 success target 分级
# - backlog：「C1-s1 / C1-s2 验证 sensor 升级提升幅度」
