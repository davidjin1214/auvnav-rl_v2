# %% [markdown]
# # ReBRAC Broad Validation — S3.d Parity Extension
#
# **目的**：把 5 个 representative cell 从 2-seed 扩到 5-seed，让报告里所有 axis-level claim 都建立在 5-seed parity 基础上。
#
# | Spoke | Pair | 现状 | 用途 |
# |---|---|---|---|
# | **A1**       | actorb_4p0__criticb_2p0 (anchor) | 2 → 5 | 让 A1 refit_b vs anchor 是 5v5 公平比较 |
# | **A2-td3bc** | alpha_0p25                       | 2 → 5 | **paper claim 关键**：5v5 检验 ReBRAC vs TD3+BC 方向 |
# | **A3**       | actorb_4p0__criticb_2p0 (anchor) | 2 → 5 | 让 A3 refit_b vs anchor 是 5v5；坐实 1-seed refit decision footnote |
# | **B1**       | actorb_4p0__criticb_2p0          | 2 → 5 | sensor envelope claim 是 B 轴整轴 takeaway |
# | **B2**       | actorb_4p0__criticb_2p0          | 2 → 5 | 同上 |
#
# **新跑 seeds**：[43, 45, 46] × 5 cell = 15 runs，估 ~7.5h L4，单 Colab session 完成。
#
# **输出位置**：与现有结果同目录 `results/offline/rebrac/broad_validation/<spoke>/<pair>/test/seed_*.json`，summarize 自动合并。
#
# **驱动机制**：`scripts/run_offline_rebrac_broad.sh` 的 skip-resume — 已有 seed [42, 44] 跳过，只跑 [43, 45, 46]。

# %% [markdown]
# ## 0. GPU sanity

# %%
# !nvidia-smi | head -10
import torch
print(f"torch={torch.__version__} cuda={torch.cuda.is_available()} device={torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'cpu'}")
# Out:
# Wed May  6 16:51:47 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA L4                      Off |   00000000:00:03.0 Off |                    0 |
# | N/A   39C    P8             12W /   72W |       0MiB /  23034MiB |      0%      Default |
# torch=2.10.0+cu128 cuda=True device=NVIDIA L4

# %% [markdown]
# ## 1. Mount Drive + cwd

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# %cd /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5

# %% [markdown]
# ## 2. 通用配置

# %%
import os
import json
from pathlib import Path

# Anchor (Stage C, crosscomp/s0/cross_stream, 5 seeds)
ANCHOR_MEAN, ANCHOR_STD = 0.902, 0.021

RESULTS_ROOT = Path("results/offline/rebrac/broad_validation")
SUMMARIES_DIR = RESULTS_ROOT / "summaries"

# 5 个目标 cell：(spoke_id, pair_tag) — pair_tag 仅供 preflight/打印用，
# 实际 driver 用 spoke_id 通过 registry 查 anchor 默认值
PARITY_CELLS = [
    ("A1",       "actorb_4p0__criticb_2p0"),  # anchor
    ("A2-td3bc", "alpha_0p25"),               # td3bc α=0.25
    ("A3",       "actorb_4p0__criticb_2p0"),  # anchor
    ("B1",       "actorb_4p0__criticb_2p0"),  # anchor (B1 默认即 anchor)
    ("B2",       "actorb_4p0__criticb_2p0"),  # anchor (B2 默认即 anchor)
]

EXISTING_SEEDS = [42, 44]
TARGET_SEEDS   = [42, 43, 44, 45, 46]
NEW_SEEDS      = [s for s in TARGET_SEEDS if s not in EXISTING_SEEDS]
print(f"existing seeds: {EXISTING_SEEDS}  →  new seeds to run: {NEW_SEEDS}")
# Out:
# existing seeds: [42, 44]  →  new seeds to run: [43, 45, 46]

# %% [markdown]
# ## 3. Preflight — 确认 2-seed 已存在 + 打印当前数字
#
# 如果有任何 cell 的 [42, 44] 不存在，**停止**。说明环境路径或 driver 状态有问题，强行跑会浪费 7.5h 并污染结果。

# %%
rows = []
missing = []

for spoke_id, pair in PARITY_CELLS:
    test_dir = RESULTS_ROOT / spoke_id / pair / "test"
    succs = []
    for s in EXISTING_SEEDS:
        path = test_dir / f"seed_{s}.json"
        if not path.exists():
            missing.append(str(path))
            continue
        d = json.loads(path.read_text(encoding="utf-8"))
        succs.append(d["eval_success_rate"])
    if len(succs) == len(EXISTING_SEEDS):
        mean = sum(succs) / len(succs)
        rows.append((spoke_id, pair, succs, mean))

print("=" * 88)
print(f"{'spoke':<10}{'pair':<32}{'seeds':>10}  {'succ@seed':<24}{'mean':>9}")
print("-" * 88)
for spoke_id, pair, succs, mean in rows:
    succ_str = ", ".join(f"{s:.3f}" for s in succs)
    print(f"{spoke_id:<10}{pair:<32}{str(EXISTING_SEEDS):>10}  {succ_str:<24}{mean:>9.4f}")
print("=" * 88)

if missing:
    print(f"\n[FAIL] missing {len(missing)} seed JSON files — DO NOT proceed:")
    for m in missing:
        print(f"  {m}")
    raise RuntimeError("preflight failed: existing P1 seeds missing for parity targets")
else:
    print(f"\n[OK] all 5 cells × {len(EXISTING_SEEDS)} seeds present → safe to extend")
# Out:
# ========================================================================================
# spoke     pair                                 seeds  succ@seed                    mean
# ----------------------------------------------------------------------------------------
# A1        actorb_4p0__criticb_2p0           [42, 44]  0.750, 0.820               0.7850
# A2-td3bc  alpha_0p25                        [42, 44]  0.650, 0.670               0.6600
# A3        actorb_4p0__criticb_2p0           [42, 44]  0.780, 0.730               0.7550
# B1        actorb_4p0__criticb_2p0           [42, 44]  0.920, 0.940               0.9300
# B2        actorb_4p0__criticb_2p0           [42, 44]  0.880, 0.940               0.9100
# ========================================================================================
#
# [OK] all 5 cells × 2 seeds present → safe to extend

# %% [markdown]
# ## 4. 跑 parity extension — 15 runs
#
# 每个 cell 跑 SEEDS=[42 43 44 45 46]；driver skip-resume 会跳过 [42, 44]，只训 [43, 45, 46]。
#
# **重要**：A2-td3bc 走 td3bc 分支（`--alpha 0.25`），ReBRAC penalty 系数被脚本忽略。其余 4 个走 rebrac 分支并自动从 spoke registry 读到 anchor (4.0, 2.0)，无需 env 覆盖。

# %%
# 显式覆盖 SEEDS 也可以，但 PHASE=p2_5seed 默认即 "42 43 44 45 46"，留空即可。
PARITY_SPOKES = [c[0] for c in PARITY_CELLS]

for spoke_id in PARITY_SPOKES:
    os.environ["SPOKE_ID"] = spoke_id
    os.environ["PHASE"]    = "p2_5seed"
    # 不设 ACTOR_PENALTY_COEFS / CRITIC_PENALTY_COEFS / TD3BC_ALPHAS：
    # script 会从 spoke registry 读 anchor 默认值 (rebrac) 或 alpha (td3bc)
    print(f"\n========== S3.d parity: {spoke_id} (5-seed, anchor defaults) ==========")
    # !bash scripts/run_offline_rebrac_broad.sh
# Out:
# ========== S3.d parity: A1 (5-seed, anchor defaults) ==========
# [skip] dataset exists: offline_data/goalseek_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/transitions.npz
# [skip] manifest exists: benchmarks/offline_rebrac_broad/val_40/single_u10_cross_tgt15.json
# [skip] manifest exists: benchmarks/offline_rebrac_broad/test_100/single_u10_cross_tgt15.json
# [skip] trained run exists: checkpoints/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/seed_42
# [skip] validation exists: results/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/validation/seed_42/agent_step_00005544.json
# [skip] validation exists: results/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/validation/seed_42/agent_step_00011088.json
# [skip] validation exists: results/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/validation/seed_42/agent_step_00016632.json
# [skip] validation exists: results/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/validation/seed_42/agent_step_00022176.json
# [skip] validation exists: results/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/validation/seed_42/agent_step_00027720.json
# [skip] validation exists: results/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/validation/seed_42/agent_step_00033264.json
# [skip] validation exists: results/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/validation/seed_42/agent_step_00038808.json
# [skip] validation exists: results/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/validation/seed_42/agent_step_00044352.json
# [skip] validation exists: results/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/validation/seed_42/agent_final.json
# [skip] checkpoint selection exists: results/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/selection/seed_42/selected_checkpoint.json
# [skip] test exists: results/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/test/seed_42.json
#
# [cmd] python -m scripts.train_offline --algo rebrac --offline-data offline_data/goalseek_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/transitions.npz --flow wake_data/wake_v8_U1p00_Re150_D12p00_dx0p60_Ti5pct_1200f_roi.npy --manifest benchmarks/offline_rebrac_broad/val_40/single_u10_cross_tgt15.json --probe-layout s0 --history-length 4 --task-geometry cross_stream --target-speed 1.5 --objective efficiency_v2 --sampling-mode shuffle_no_replacement --num-epochs 64 --total-steps 44352 --batch-size 256 --hidden-dim 256 --num-hidden-layers 3 --actor-lr 3e-4 --critic-lr 3e-4 --gamma 0.99 --tau 0.005 --actor-penalty-coef 4.0 --critic-penalty-coef 2.0 --policy-noise 0.2 --noise-clip 0.5 --policy-freq 2 --grad-clip-norm 10.0 --normalizer-eps 1e-3 --eval-every 0 --checkpoint-every 5544 --skip-final-eval --log-every 1000 --critic-layernorm --no-actor-layernorm --save-dir checkpoints/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/seed_43 --seed 43 --device cuda
# [offline] algo=rebrac transitions=177377 obs_dim=40 action_dim=2 protocol=deployable tensor_replay=on eval_workers=1 sampling=shuffle_no_replacement total_steps=44352
# [train] step=1 epoch=1 epoch_step=1 q=-0.773 critic=88.767 actor=4.924 bc=0.981 lambda=1.294 critic_pen=1.059
# [train] step=1000 epoch=2 epoch_step=307 q=-4.287 critic=29.078 actor=0.840 bc=0.023 lambda=0.175 critic_pen=0.103
# [train] step=2000 epoch=3 epoch_step=614 q=-6.349 critic=1.255 actor=0.844 bc=0.032 lambda=0.113 critic_pen=0.081
# [train] step=3000 epoch=5 epoch_step=228 q=-6.888 critic=15.844 actor=0.728 bc=0.035 lambda=0.085 critic_pen=0.088
# [train] step=4000 epoch=6 epoch_step=535 q=-6.368 critic=8.223 actor=0.543 bc=0.037 lambda=0.062 critic_pen=0.097
# [train] step=5000 epoch=8 epoch_step=149 q=-6.785 critic=2.943 actor=0.449 bc=0.026 lambda=0.051 critic_pen=0.077
# [train] step=6000 epoch=9 epoch_step=456 q=-7.973 critic=3.219 actor=0.377 bc=0.005 lambda=0.045 critic_pen=0.070
# [train] step=7000 epoch=11 epoch_step=70 q=-3.001 critic=5.380 actor=0.169 bc=0.015 lambda=0.036 critic_pen=0.096
# [train] step=8000 epoch=12 epoch_step=377 q=-8.635 critic=2.235 actor=0.361 bc=0.014 lambda=0.035 critic_pen=0.071
# [train] step=9000 epoch=13 epoch_step=684 q=-9.068 critic=3.197 actor=0.377 bc=0.017 lambda=0.034 critic_pen=0.092
# [train] step=10000 epoch=15 epoch_step=298 q=-10.917 critic=4.459 actor=0.427 bc=0.019 lambda=0.032 critic_pen=0.086
# [train] step=11000 epoch=16 epoch_step=605 q=-6.288 critic=3.158 actor=0.254 bc=0.019 lambda=0.028 critic_pen=0.086
# [train] step=12000 epoch=18 epoch_step=219 q=-13.362 critic=3.798 actor=0.481 bc=0.021 lambda=0.030 critic_pen=0.097
# [train] step=13000 epoch=19 epoch_step=526 q=-7.840 critic=2.569 actor=0.296 bc=0.022 lambda=0.027 critic_pen=0.073
# [train] step=14000 epoch=21 epoch_step=140 q=-13.790 critic=3.704 actor=0.454 bc=0.021 lambda=0.027 critic_pen=0.081
# [train] step=15000 epoch=22 epoch_step=447 q=-15.322 critic=4.016 actor=0.550 bc=0.035 lambda=0.027 critic_pen=0.083
# [train] step=16000 epoch=24 epoch_step=61 q=-18.428 critic=2.279 actor=0.565 bc=0.022 lambda=0.026 critic_pen=0.078
# [train] step=17000 epoch=25 epoch_step=368 q=-10.012 critic=1.908 actor=0.272 bc=0.011 lambda=0.023 critic_pen=0.077
# [train] step=18000 epoch=26 epoch_step=675 q=-15.419 critic=6.185 actor=0.404 bc=0.010 lambda=0.024 critic_pen=0.086
# [train] step=19000 epoch=28 epoch_step=289 q=-15.305 critic=1.462 actor=0.356 bc=0.003 lambda=0.023 critic_pen=0.067
# [train] step=20000 epoch=29 epoch_step=596 q=-14.029 critic=2.277 actor=0.349 bc=0.011 lambda=0.022 critic_pen=0.081
# [train] step=21000 epoch=31 epoch_step=210 q=-20.931 critic=3.029 actor=0.582 bc=0.022 lambda=0.024 critic_pen=0.095
# [train] step=22000 epoch=32 epoch_step=517 q=-13.352 critic=2.632 actor=0.321 bc=0.006 lambda=0.022 critic_pen=0.080
# [train] step=23000 epoch=34 epoch_step=131 q=-18.684 critic=2.522 actor=0.439 bc=0.007 lambda=0.022 critic_pen=0.076
# [train] step=24000 epoch=35 epoch_step=438 q=-23.460 critic=3.059 actor=0.490 bc=0.001 lambda=0.021 critic_pen=0.071
# [train] step=25000 epoch=37 epoch_step=52 q=-22.093 critic=2.043 actor=0.508 bc=0.010 lambda=0.021 critic_pen=0.066
# [train] step=26000 epoch=38 epoch_step=359 q=-25.488 critic=1.495 actor=0.569 bc=0.008 lambda=0.021 critic_pen=0.066
# [train] step=27000 epoch=39 epoch_step=666 q=-25.165 critic=1.603 actor=0.626 bc=0.025 lambda=0.021 critic_pen=0.068
# [train] step=28000 epoch=41 epoch_step=280 q=-17.844 critic=2.392 actor=0.398 bc=0.008 lambda=0.020 critic_pen=0.068
# [train] step=29000 epoch=42 epoch_step=587 q=-22.180 critic=2.964 actor=0.435 bc=0.001 lambda=0.019 critic_pen=0.069
# [train] step=30000 epoch=44 epoch_step=201 q=-29.212 critic=2.305 actor=0.594 bc=0.002 lambda=0.020 critic_pen=0.075
# [train] step=31000 epoch=45 epoch_step=508 q=-21.926 critic=1.841 actor=0.502 bc=0.017 lambda=0.020 critic_pen=0.056
# [train] step=32000 epoch=47 epoch_step=122 q=-25.706 critic=3.119 actor=0.518 bc=0.004 lambda=0.020 critic_pen=0.076
# [train] step=33000 epoch=48 epoch_step=429 q=-23.150 critic=2.044 actor=0.469 bc=0.002 lambda=0.020 critic_pen=0.066
# [train] step=34000 epoch=50 epoch_step=43 q=-28.058 critic=3.044 actor=0.643 bc=0.026 lambda=0.019 critic_pen=0.084
# [train] step=35000 epoch=51 epoch_step=350 q=-24.009 critic=2.528 actor=0.512 bc=0.011 lambda=0.019 critic_pen=0.081
# [train] step=36000 epoch=52 epoch_step=657 q=-24.899 critic=2.019 actor=0.456 bc=0.005 lambda=0.017 critic_pen=0.080
# [train] step=37000 epoch=54 epoch_step=271 q=-27.746 critic=8.213 actor=0.550 bc=0.009 lambda=0.019 critic_pen=0.080
# [train] step=38000 epoch=55 epoch_step=578 q=-25.740 critic=2.150 actor=0.462 bc=0.001 lambda=0.018 critic_pen=0.076
# [train] step=39000 epoch=57 epoch_step=192 q=-32.047 critic=2.093 actor=0.617 bc=0.002 lambda=0.019 critic_pen=0.077
# [train] step=40000 epoch=58 epoch_step=499 q=-28.750 critic=1.847 actor=0.567 bc=0.007 lambda=0.019 critic_pen=0.075
# [train] step=41000 epoch=60 epoch_step=113 q=-31.101 critic=1.701 actor=0.578 bc=0.002 lambda=0.018 critic_pen=0.066
# [train] step=42000 epoch=61 epoch_step=420 q=-28.269 critic=10.340 actor=0.622 bc=0.025 lambda=0.019 critic_pen=0.109
# [train] step=43000 epoch=63 epoch_step=34 q=-28.608 critic=1.427 actor=0.563 bc=0.014 lambda=0.018 critic_pen=0.067
# [train] step=44000 epoch=64 epoch_step=341 q=-25.530 critic=2.679 actor=0.525 bc=0.016 lambda=0.018 critic_pen=0.083
#
# [cmd] python -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/seed_43 --agent-file agent_step_00005544.pt --manifest benchmarks/offline_rebrac_broad/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/validation/seed_43/agent_step_00005544.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 50.0%
# avg_return            : -181.50 +/- 172.42
# avg_safety_cost       : 22.200 +/- 16.191
# avg_time_s            : 115.33 +/- 59.07
# avg_time_s_success    : 103.46
# avg_energy            : 74112.43 +/- 42517.51
# avg_path_length_m     : 82.71 +/- 40.20
# avg_progress_ratio    : 0.352 +/- 0.819
# avg_path_efficiency   : 0.339 +/- 0.356
# termination           : {'goal': 20, 'timeout': 3, 'out_of_bounds': 17}
# benchmark_manifest    : benchmarks/offline_rebrac_broad/val_40/single_u10_cross_tgt15.json
#
# [cmd] python -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/seed_43 --agent-file agent_step_00011088.pt --manifest benchmarks/offline_rebrac_broad/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/validation/seed_43/agent_step_00011088.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 62.5%
# avg_return            : -152.54 +/- 172.77
# avg_safety_cost       : 22.666 +/- 33.078
# avg_time_s            : 112.48 +/- 61.37
# avg_time_s_success    : 99.12
# avg_energy            : 70856.83 +/- 40609.10
# avg_path_length_m     : 76.61 +/- 31.04
# avg_progress_ratio    : 0.550 +/- 0.565
# avg_path_efficiency   : 0.412 +/- 0.300
# termination           : {'goal': 25, 'timeout': 6, 'out_of_bounds': 9}
# benchmark_manifest    : benchmarks/offline_rebrac_broad/val_40/single_u10_cross_tgt15.json
#
# [cmd] python -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/seed_43 --agent-file agent_step_00016632.pt --manifest benchmarks/offline_rebrac_broad/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/validation/seed_43/agent_step_00016632.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 70.0%
# avg_return            : -106.91 +/- 109.12
# avg_safety_cost       : 31.225 +/- 51.524
# avg_time_s            : 96.18 +/- 43.02
# avg_time_s_success    : 103.51
# avg_energy            : 60162.45 +/- 28337.25
# avg_path_length_m     : 69.68 +/- 22.02
# avg_progress_ratio    : 0.695 +/- 0.363
# avg_path_efficiency   : 0.460 +/- 0.193
# termination           : {'goal': 28, 'out_of_bounds': 10, 'timeout': 2}
# benchmark_manifest    : benchmarks/offline_rebrac_broad/val_40/single_u10_cross_tgt15.json
#
# [cmd] python -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/seed_43 --agent-file agent_step_00022176.pt --manifest benchmarks/offline_rebrac_broad/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/validation/seed_43/agent_step_00022176.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 75.0%
# avg_return            : -82.12 +/- 34.86
# avg_safety_cost       : 21.378 +/- 13.776
# avg_time_s            : 89.94 +/- 27.46
# avg_time_s_success    : 102.68
# avg_energy            : 55882.63 +/- 17092.10
# avg_path_length_m     : 65.91 +/- 12.44
# avg_progress_ratio    : 0.782 +/- 0.234
# avg_path_efficiency   : 0.510 +/- 0.125
# termination           : {'goal': 30, 'out_of_bounds': 10}
# benchmark_manifest    : benchmarks/offline_rebrac_broad/val_40/single_u10_cross_tgt15.json
#
# [cmd] python -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/seed_43 --agent-file agent_step_00027720.pt --manifest benchmarks/offline_rebrac_broad/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/validation/seed_43/agent_step_00027720.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 75.0%
# avg_return            : -108.98 +/- 124.73
# avg_safety_cost       : 25.142 +/- 17.445
# avg_time_s            : 100.84 +/- 47.04
# avg_time_s_success    : 100.74
# avg_energy            : 63287.83 +/- 31065.99
# avg_path_length_m     : 72.17 +/- 25.72
# avg_progress_ratio    : 0.691 +/- 0.434
# avg_path_efficiency   : 0.468 +/- 0.221
# termination           : {'goal': 30, 'timeout': 3, 'out_of_bounds': 7}
# benchmark_manifest    : benchmarks/offline_rebrac_broad/val_40/single_u10_cross_tgt15.json
#
# [cmd] python -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/seed_43 --agent-file agent_step_00033264.pt --manifest benchmarks/offline_rebrac_broad/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/validation/seed_43/agent_step_00033264.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 47.5%
# avg_return            : -119.10 +/- 75.38
# avg_safety_cost       : 23.700 +/- 12.995
# avg_time_s            : 87.06 +/- 30.12
# avg_time_s_success    : 102.81
# avg_energy            : 53974.02 +/- 18697.09
# avg_path_length_m     : 69.24 +/- 20.57
# avg_progress_ratio    : 0.565 +/- 0.444
# avg_path_efficiency   : 0.397 +/- 0.235
# termination           : {'goal': 19, 'out_of_bounds': 21}
# benchmark_manifest    : benchmarks/offline_rebrac_broad/val_40/single_u10_cross_tgt15.json
#
# [cmd] python -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/seed_43 --agent-file agent_step_00038808.pt --manifest benchmarks/offline_rebrac_broad/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/validation/seed_43/agent_step_00038808.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 32.5%
# avg_return            : -186.46 +/- 167.70
# avg_safety_cost       : 20.869 +/- 13.801
# avg_time_s            : 104.18 +/- 59.75
# avg_time_s_success    : 95.61
# avg_energy            : 66767.86 +/- 41046.99
# avg_path_length_m     : 85.86 +/- 45.14
# avg_progress_ratio    : 0.195 +/- 0.804
# avg_path_efficiency   : 0.254 +/- 0.351
# termination           : {'goal': 13, 'out_of_bounds': 24, 'timeout': 2, 'depth_hold_failure': 1}
# benchmark_manifest    : benchmarks/offline_rebrac_broad/val_40/single_u10_cross_tgt15.json
#
# [cmd] python -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/seed_43 --agent-file agent_step_00044352.pt --manifest benchmarks/offline_rebrac_broad/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/validation/seed_43/agent_step_00044352.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 10.0%
# avg_return            : -262.35 +/- 165.64
# avg_safety_cost       : 25.266 +/- 17.236
# avg_time_s            : 121.55 +/- 63.17
# avg_time_s_success    : 94.65
# avg_energy            : 76720.27 +/- 41869.43
# avg_path_length_m     : 100.18 +/- 46.05
# avg_progress_ratio    : -0.103 +/- 0.864
# avg_path_efficiency   : 0.107 +/- 0.358
# termination           : {'out_of_bounds': 31, 'timeout': 5, 'goal': 4}
# benchmark_manifest    : benchmarks/offline_rebrac_broad/val_40/single_u10_cross_tgt15.json
#
# [cmd] python -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/seed_43 --agent-file agent_final.pt --manifest benchmarks/offline_rebrac_broad/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/validation/seed_43/agent_final.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 10.0%
# avg_return            : -262.35 +/- 165.64
# avg_safety_cost       : 25.266 +/- 17.236
# avg_time_s            : 121.55 +/- 63.17
# avg_time_s_success    : 94.65
# avg_energy            : 76720.27 +/- 41869.43
# avg_path_length_m     : 100.18 +/- 46.05
# avg_progress_ratio    : -0.103 +/- 0.864
# avg_path_efficiency   : 0.107 +/- 0.358
# termination           : {'out_of_bounds': 31, 'timeout': 5, 'goal': 4}
# benchmark_manifest    : benchmarks/offline_rebrac_broad/val_40/single_u10_cross_tgt15.json
#
# [cmd] python - results/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/validation/seed_43 checkpoints/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/seed_43/trainer_state.json results/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/selection/seed_43/selected_checkpoint.json results/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/selection/seed_43/selected_agent_file.txt
# [write] selection: results/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/selection/seed_43/selected_checkpoint.json
# [best] agent=agent_step_00022176.pt success=0.7500
#
# [cmd] python -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/seed_43 --agent-file agent_step_00022176.pt --manifest benchmarks/offline_rebrac_broad/test_100/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 456 --output-json results/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/test/seed_43.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 100
# success_rate          : 72.0%
# avg_return            : -128.51 +/- 138.75
# avg_safety_cost       : 33.302 +/- 54.961
# avg_time_s            : 108.14 +/- 48.14
# avg_time_s_success    : 104.04
# avg_energy            : 67601.66 +/- 31021.81
# avg_path_length_m     : 73.49 +/- 22.53
# avg_progress_ratio    : 0.702 +/- 0.386
# avg_path_efficiency   : 0.456 +/- 0.209
# termination           : {'goal': 72, 'out_of_bounds': 20, 'timeout': 8}
# benchmark_manifest    : benchmarks/offline_rebrac_broad/test_100/single_u10_cross_tgt15.json
# [skip] trained run exists: checkpoints/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/seed_44
# [skip] validation exists: results/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/validation/seed_44/agent_step_00005544.json
# [skip] validation exists: results/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/validation/seed_44/agent_step_00011088.json
# [skip] validation exists: results/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/validation/seed_44/agent_step_00016632.json
# [skip] validation exists: results/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/validation/seed_44/agent_step_00022176.json
# [skip] validation exists: results/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/validation/seed_44/agent_step_00027720.json
# [skip] validation exists: results/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/validation/seed_44/agent_step_00033264.json
# [skip] validation exists: results/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/validation/seed_44/agent_step_00038808.json
# [skip] validation exists: results/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/validation/seed_44/agent_step_00044352.json
# [skip] validation exists: results/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/validation/seed_44/agent_final.json
# [skip] checkpoint selection exists: results/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/selection/seed_44/selected_checkpoint.json
# [skip] test exists: results/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/test/seed_44.json
#
# [cmd] python -m scripts.train_offline --algo rebrac --offline-data offline_data/goalseek_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/transitions.npz --flow wake_data/wake_v8_U1p00_Re150_D12p00_dx0p60_Ti5pct_1200f_roi.npy --manifest benchmarks/offline_rebrac_broad/val_40/single_u10_cross_tgt15.json --probe-layout s0 --history-length 4 --task-geometry cross_stream --target-speed 1.5 --objective efficiency_v2 --sampling-mode shuffle_no_replacement --num-epochs 64 --total-steps 44352 --batch-size 256 --hidden-dim 256 --num-hidden-layers 3 --actor-lr 3e-4 --critic-lr 3e-4 --gamma 0.99 --tau 0.005 --actor-penalty-coef 4.0 --critic-penalty-coef 2.0 --policy-noise 0.2 --noise-clip 0.5 --policy-freq 2 --grad-clip-norm 10.0 --normalizer-eps 1e-3 --eval-every 0 --checkpoint-every 5544 --skip-final-eval --log-every 1000 --critic-layernorm --no-actor-layernorm --save-dir checkpoints/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/seed_45 --seed 45 --device cuda
# [offline] algo=rebrac transitions=177377 obs_dim=40 action_dim=2 protocol=deployable tensor_replay=on eval_workers=1 sampling=shuffle_no_replacement total_steps=44352
# [train] step=1 epoch=1 epoch_step=1 q=-0.741 critic=90.758 actor=4.639 bc=0.910 lambda=1.350 critic_pen=0.933
# [train] step=1000 epoch=2 epoch_step=307 q=-5.155 critic=0.744 actor=0.959 bc=0.029 lambda=0.164 critic_pen=0.097
# [train] step=2000 epoch=3 epoch_step=614 q=-6.582 critic=14.780 actor=0.927 bc=0.046 lambda=0.113 critic_pen=0.101
# [train] step=3000 epoch=5 epoch_step=228 q=-7.171 critic=6.953 actor=0.685 bc=0.024 lambda=0.082 critic_pen=0.082
# [train] step=4000 epoch=6 epoch_step=535 q=-5.907 critic=5.204 actor=0.437 bc=0.017 lambda=0.062 critic_pen=0.096
# [train] step=5000 epoch=8 epoch_step=149 q=-8.379 critic=4.290 actor=0.485 bc=0.010 lambda=0.053 critic_pen=0.082
# [train] step=6000 epoch=9 epoch_step=456 q=-9.849 critic=4.402 actor=0.540 bc=0.018 lambda=0.048 critic_pen=0.097
# [train] step=7000 epoch=11 epoch_step=70 q=-2.964 critic=8.599 actor=0.265 bc=0.040 lambda=0.036 critic_pen=0.098
# [train] step=8000 epoch=12 epoch_step=377 q=-9.820 critic=3.738 actor=0.390 bc=0.008 lambda=0.036 critic_pen=0.084
# [train] step=9000 epoch=13 epoch_step=684 q=-10.208 critic=2.953 actor=0.417 bc=0.020 lambda=0.033 critic_pen=0.074
# [train] step=10000 epoch=15 epoch_step=298 q=-5.547 critic=3.885 actor=0.250 bc=0.023 lambda=0.029 critic_pen=0.071
# [train] step=11000 epoch=16 epoch_step=605 q=-6.015 critic=3.460 actor=0.195 bc=0.007 lambda=0.028 critic_pen=0.066
# [train] step=12000 epoch=18 epoch_step=219 q=-12.887 critic=1.704 actor=0.391 bc=0.007 lambda=0.028 critic_pen=0.071
# [train] step=13000 epoch=19 epoch_step=526 q=-10.854 critic=4.327 actor=0.405 bc=0.029 lambda=0.027 critic_pen=0.089
# [train] step=14000 epoch=21 epoch_step=140 q=-14.870 critic=3.580 actor=0.443 bc=0.011 lambda=0.027 critic_pen=0.089
# [train] step=15000 epoch=22 epoch_step=447 q=-11.298 critic=2.350 actor=0.460 bc=0.045 lambda=0.025 critic_pen=0.075
# [train] step=16000 epoch=24 epoch_step=61 q=-15.648 critic=3.788 actor=0.426 bc=0.013 lambda=0.024 critic_pen=0.087
# [train] step=17000 epoch=25 epoch_step=368 q=-16.275 critic=1.595 actor=0.537 bc=0.038 lambda=0.024 critic_pen=0.080
# [train] step=18000 epoch=26 epoch_step=675 q=-14.700 critic=1.956 actor=0.351 bc=0.002 lambda=0.023 critic_pen=0.077
# [train] step=19000 epoch=28 epoch_step=289 q=-15.465 critic=5.840 actor=0.506 bc=0.037 lambda=0.023 critic_pen=0.084
# [train] step=20000 epoch=29 epoch_step=596 q=-15.415 critic=1.514 actor=0.366 bc=0.005 lambda=0.022 critic_pen=0.077
# [train] step=21000 epoch=31 epoch_step=210 q=-21.610 critic=2.336 actor=0.517 bc=0.008 lambda=0.022 critic_pen=0.060
# [train] step=22000 epoch=32 epoch_step=517 q=-23.181 critic=1.787 actor=0.522 bc=0.001 lambda=0.022 critic_pen=0.070
# [train] step=23000 epoch=34 epoch_step=131 q=-21.480 critic=2.059 actor=0.520 bc=0.011 lambda=0.022 critic_pen=0.081
# [train] step=24000 epoch=35 epoch_step=438 q=-22.744 critic=5.248 actor=0.682 bc=0.044 lambda=0.022 critic_pen=0.079
# [train] step=25000 epoch=37 epoch_step=52 q=-21.695 critic=1.893 actor=0.506 bc=0.014 lambda=0.021 critic_pen=0.069
# [train] step=26000 epoch=38 epoch_step=359 q=-23.009 critic=10.493 actor=0.536 bc=0.016 lambda=0.021 critic_pen=0.073
# [train] step=27000 epoch=39 epoch_step=666 q=-21.465 critic=1.859 actor=0.517 bc=0.014 lambda=0.021 critic_pen=0.076
# [train] step=28000 epoch=41 epoch_step=280 q=-20.832 critic=2.053 actor=0.537 bc=0.025 lambda=0.021 critic_pen=0.066
# [train] step=29000 epoch=42 epoch_step=587 q=-29.605 critic=1.293 actor=0.788 bc=0.045 lambda=0.021 critic_pen=0.061
# [train] step=30000 epoch=44 epoch_step=201 q=-28.696 critic=1.608 actor=0.638 bc=0.013 lambda=0.020 critic_pen=0.071
# [train] step=31000 epoch=45 epoch_step=508 q=-25.254 critic=2.148 actor=0.662 bc=0.039 lambda=0.020 critic_pen=0.072
# [train] step=32000 epoch=47 epoch_step=122 q=-26.885 critic=2.255 actor=0.552 bc=0.007 lambda=0.020 critic_pen=0.108
# [train] step=33000 epoch=48 epoch_step=429 q=-27.999 critic=1.561 actor=0.579 bc=0.002 lambda=0.020 critic_pen=0.068
# [train] step=34000 epoch=50 epoch_step=43 q=-23.570 critic=2.566 actor=0.549 bc=0.020 lambda=0.020 critic_pen=0.070
# [train] step=35000 epoch=51 epoch_step=350 q=-24.414 critic=1.940 actor=0.502 bc=0.008 lambda=0.019 critic_pen=0.070
# [train] step=36000 epoch=52 epoch_step=657 q=-24.369 critic=1.672 actor=0.471 bc=0.003 lambda=0.019 critic_pen=0.072
# [train] step=37000 epoch=54 epoch_step=271 q=-24.891 critic=1.349 actor=0.481 bc=0.003 lambda=0.019 critic_pen=0.077
# [train] step=38000 epoch=55 epoch_step=578 q=-30.296 critic=1.708 actor=0.653 bc=0.018 lambda=0.019 critic_pen=0.078
# [train] step=39000 epoch=57 epoch_step=192 q=-21.569 critic=12.755 actor=0.444 bc=0.012 lambda=0.018 critic_pen=0.072
# [train] step=40000 epoch=58 epoch_step=499 q=-28.117 critic=1.554 actor=0.559 bc=0.015 lambda=0.018 critic_pen=0.078
# [train] step=41000 epoch=60 epoch_step=113 q=-25.413 critic=6.193 actor=0.549 bc=0.022 lambda=0.018 critic_pen=0.085
# [train] step=42000 epoch=61 epoch_step=420 q=-32.834 critic=11.497 actor=0.609 bc=0.004 lambda=0.018 critic_pen=0.070
# [train] step=43000 epoch=63 epoch_step=34 q=-24.887 critic=2.093 actor=0.497 bc=0.010 lambda=0.018 critic_pen=0.078
# [train] step=44000 epoch=64 epoch_step=341 q=-32.964 critic=1.537 actor=0.664 bc=0.018 lambda=0.018 critic_pen=0.066
#
# [cmd] python -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/seed_45 --agent-file agent_step_00005544.pt --manifest benchmarks/offline_rebrac_broad/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/validation/seed_45/agent_step_00005544.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 62.5%
# avg_return            : -179.27 +/- 181.98
# avg_safety_cost       : 27.663 +/- 23.793
# avg_time_s            : 122.47 +/- 60.47
# avg_time_s_success    : 102.92
# avg_energy            : 77436.56 +/- 41311.98
# avg_path_length_m     : 83.25 +/- 35.86
# avg_progress_ratio    : 0.413 +/- 0.771
# avg_path_efficiency   : 0.349 +/- 0.353
# termination           : {'goal': 25, 'timeout': 4, 'out_of_bounds': 11}
# benchmark_manifest    : benchmarks/offline_rebrac_broad/val_40/single_u10_cross_tgt15.json
#
# [cmd] python -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/seed_45 --agent-file agent_step_00011088.pt --manifest benchmarks/offline_rebrac_broad/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/validation/seed_45/agent_step_00011088.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 65.0%
# avg_return            : -129.08 +/- 142.69
# avg_safety_cost       : 31.781 +/- 57.935
# avg_time_s            : 104.17 +/- 52.33
# avg_time_s_success    : 101.07
# avg_energy            : 64135.68 +/- 31705.33
# avg_path_length_m     : 70.98 +/- 21.93
# avg_progress_ratio    : 0.694 +/- 0.334
# avg_path_efficiency   : 0.462 +/- 0.198
# termination           : {'goal': 26, 'timeout': 3, 'out_of_bounds': 11}
# benchmark_manifest    : benchmarks/offline_rebrac_broad/val_40/single_u10_cross_tgt15.json
#
# [cmd] python -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/seed_45 --agent-file agent_step_00016632.pt --manifest benchmarks/offline_rebrac_broad/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/validation/seed_45/agent_step_00016632.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 77.5%
# avg_return            : -95.93 +/- 84.14
# avg_safety_cost       : 29.292 +/- 24.483
# avg_time_s            : 97.41 +/- 35.43
# avg_time_s_success    : 101.83
# avg_energy            : 60413.02 +/- 21849.62
# avg_path_length_m     : 68.45 +/- 15.28
# avg_progress_ratio    : 0.783 +/- 0.260
# avg_path_efficiency   : 0.505 +/- 0.149
# termination           : {'goal': 31, 'out_of_bounds': 8, 'timeout': 1}
# benchmark_manifest    : benchmarks/offline_rebrac_broad/val_40/single_u10_cross_tgt15.json
#
# [cmd] python -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/seed_45 --agent-file agent_step_00022176.pt --manifest benchmarks/offline_rebrac_broad/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/validation/seed_45/agent_step_00022176.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 70.0%
# avg_return            : -113.02 +/- 127.64
# avg_safety_cost       : 22.050 +/- 20.114
# avg_time_s            : 100.10 +/- 46.65
# avg_time_s_success    : 97.38
# avg_energy            : 62093.95 +/- 28829.13
# avg_path_length_m     : 71.31 +/- 25.34
# avg_progress_ratio    : 0.683 +/- 0.445
# avg_path_efficiency   : 0.471 +/- 0.225
# termination           : {'goal': 28, 'out_of_bounds': 10, 'timeout': 2}
# benchmark_manifest    : benchmarks/offline_rebrac_broad/val_40/single_u10_cross_tgt15.json
#
# [cmd] python -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/seed_45 --agent-file agent_step_00027720.pt --manifest benchmarks/offline_rebrac_broad/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/validation/seed_45/agent_step_00027720.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 77.5%
# avg_return            : -83.10 +/- 37.67
# avg_safety_cost       : 24.434 +/- 22.853
# avg_time_s            : 91.60 +/- 28.08
# avg_time_s_success    : 103.43
# avg_energy            : 56753.57 +/- 17372.47
# avg_path_length_m     : 66.44 +/- 13.19
# avg_progress_ratio    : 0.784 +/- 0.245
# avg_path_efficiency   : 0.509 +/- 0.137
# termination           : {'goal': 31, 'out_of_bounds': 9}
# benchmark_manifest    : benchmarks/offline_rebrac_broad/val_40/single_u10_cross_tgt15.json
#
# [cmd] python -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/seed_45 --agent-file agent_step_00033264.pt --manifest benchmarks/offline_rebrac_broad/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/validation/seed_45/agent_step_00033264.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 75.0%
# avg_return            : -99.46 +/- 97.52
# avg_safety_cost       : 22.388 +/- 19.446
# avg_time_s            : 97.39 +/- 42.00
# avg_time_s_success    : 102.58
# avg_energy            : 60292.53 +/- 26139.08
# avg_path_length_m     : 69.11 +/- 19.50
# avg_progress_ratio    : 0.735 +/- 0.320
# avg_path_efficiency   : 0.481 +/- 0.176
# termination           : {'goal': 30, 'out_of_bounds': 8, 'timeout': 2}
# benchmark_manifest    : benchmarks/offline_rebrac_broad/val_40/single_u10_cross_tgt15.json
#
# [cmd] python -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/seed_45 --agent-file agent_step_00038808.pt --manifest benchmarks/offline_rebrac_broad/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/validation/seed_45/agent_step_00038808.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 77.5%
# avg_return            : -80.53 +/- 39.67
# avg_safety_cost       : 25.367 +/- 20.033
# avg_time_s            : 90.47 +/- 26.22
# avg_time_s_success    : 100.90
# avg_energy            : 56360.85 +/- 16345.46
# avg_path_length_m     : 65.82 +/- 12.81
# avg_progress_ratio    : 0.799 +/- 0.220
# avg_path_efficiency   : 0.523 +/- 0.118
# termination           : {'goal': 31, 'out_of_bounds': 9}
# benchmark_manifest    : benchmarks/offline_rebrac_broad/val_40/single_u10_cross_tgt15.json
#
# [cmd] python -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/seed_45 --agent-file agent_step_00044352.pt --manifest benchmarks/offline_rebrac_broad/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/validation/seed_45/agent_step_00044352.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 75.0%
# avg_return            : -90.85 +/- 85.36
# avg_safety_cost       : 29.816 +/- 42.777
# avg_time_s            : 92.75 +/- 35.70
# avg_time_s_success    : 101.61
# avg_energy            : 57751.39 +/- 22343.67
# avg_path_length_m     : 66.84 +/- 16.01
# avg_progress_ratio    : 0.758 +/- 0.294
# avg_path_efficiency   : 0.504 +/- 0.157
# termination           : {'goal': 30, 'timeout': 1, 'out_of_bounds': 9}
# benchmark_manifest    : benchmarks/offline_rebrac_broad/val_40/single_u10_cross_tgt15.json
#
# [cmd] python -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/seed_45 --agent-file agent_final.pt --manifest benchmarks/offline_rebrac_broad/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/validation/seed_45/agent_final.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 75.0%
# avg_return            : -90.85 +/- 85.36
# avg_safety_cost       : 29.816 +/- 42.777
# avg_time_s            : 92.75 +/- 35.70
# avg_time_s_success    : 101.61
# avg_energy            : 57751.39 +/- 22343.67
# avg_path_length_m     : 66.84 +/- 16.01
# avg_progress_ratio    : 0.758 +/- 0.294
# avg_path_efficiency   : 0.504 +/- 0.157
# termination           : {'goal': 30, 'timeout': 1, 'out_of_bounds': 9}
# benchmark_manifest    : benchmarks/offline_rebrac_broad/val_40/single_u10_cross_tgt15.json
#
# [cmd] python - results/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/validation/seed_45 checkpoints/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/seed_45/trainer_state.json results/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/selection/seed_45/selected_checkpoint.json results/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/selection/seed_45/selected_agent_file.txt
# [write] selection: results/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/selection/seed_45/selected_checkpoint.json
# [best] agent=agent_step_00038808.pt success=0.7750
#
# [cmd] python -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/seed_45 --agent-file agent_step_00038808.pt --manifest benchmarks/offline_rebrac_broad/test_100/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 456 --output-json results/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/test/seed_45.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 100
# success_rate          : 69.0%
# avg_return            : -125.50 +/- 132.30
# avg_safety_cost       : 27.712 +/- 35.394
# avg_time_s            : 105.31 +/- 47.37
# avg_time_s_success    : 100.25
# avg_energy            : 65790.04 +/- 29987.34
# avg_path_length_m     : 72.09 +/- 22.04
# avg_progress_ratio    : 0.694 +/- 0.362
# avg_path_efficiency   : 0.458 +/- 0.212
# termination           : {'goal': 69, 'out_of_bounds': 24, 'timeout': 6, 'depth_hold_failure': 1}
# benchmark_manifest    : benchmarks/offline_rebrac_broad/test_100/single_u10_cross_tgt15.json
#
# [cmd] python -m scripts.train_offline --algo rebrac --offline-data offline_data/goalseek_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/transitions.npz --flow wake_data/wake_v8_U1p00_Re150_D12p00_dx0p60_Ti5pct_1200f_roi.npy --manifest benchmarks/offline_rebrac_broad/val_40/single_u10_cross_tgt15.json --probe-layout s0 --history-length 4 --task-geometry cross_stream --target-speed 1.5 --objective efficiency_v2 --sampling-mode shuffle_no_replacement --num-epochs 64 --total-steps 44352 --batch-size 256 --hidden-dim 256 --num-hidden-layers 3 --actor-lr 3e-4 --critic-lr 3e-4 --gamma 0.99 --tau 0.005 --actor-penalty-coef 4.0 --critic-penalty-coef 2.0 --policy-noise 0.2 --noise-clip 0.5 --policy-freq 2 --grad-clip-norm 10.0 --normalizer-eps 1e-3 --eval-every 0 --checkpoint-every 5544 --skip-final-eval --log-every 1000 --critic-layernorm --no-actor-layernorm --save-dir checkpoints/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/seed_46 --seed 46 --device cuda
# [offline] algo=rebrac transitions=177377 obs_dim=40 action_dim=2 protocol=deployable tensor_replay=on eval_workers=1 sampling=shuffle_no_replacement total_steps=44352
# [train] step=1 epoch=1 epoch_step=1 q=-1.057 critic=87.349 actor=4.640 bc=0.910 lambda=0.946 critic_pen=0.984
# [train] step=1000 epoch=2 epoch_step=307 q=-5.091 critic=1.321 actor=1.013 bc=0.038 lambda=0.169 critic_pen=0.124
# [train] step=2000 epoch=3 epoch_step=614 q=-6.157 critic=2.027 actor=0.804 bc=0.036 lambda=0.107 critic_pen=0.089
# [train] step=3000 epoch=5 epoch_step=228 q=-6.719 critic=1.825 actor=0.597 bc=0.013 lambda=0.081 critic_pen=0.075
# [train] step=4000 epoch=6 epoch_step=535 q=-6.691 critic=6.411 actor=0.496 bc=0.016 lambda=0.065 critic_pen=0.088
# [train] step=5000 epoch=8 epoch_step=149 q=-7.654 critic=2.728 actor=0.519 bc=0.034 lambda=0.050 critic_pen=0.074
# [train] step=6000 epoch=9 epoch_step=456 q=-9.320 critic=2.782 actor=0.477 bc=0.012 lambda=0.046 critic_pen=0.076
# [train] step=7000 epoch=11 epoch_step=70 q=-9.178 critic=2.881 actor=0.401 bc=0.007 lambda=0.041 critic_pen=0.074
# [train] step=8000 epoch=12 epoch_step=377 q=-9.035 critic=2.916 actor=0.457 bc=0.032 lambda=0.036 critic_pen=0.094
# [train] step=9000 epoch=13 epoch_step=684 q=-11.702 critic=1.926 actor=0.468 bc=0.016 lambda=0.035 critic_pen=0.085
# [train] step=10000 epoch=15 epoch_step=298 q=-9.238 critic=2.776 actor=0.299 bc=0.004 lambda=0.031 critic_pen=0.074
# [train] step=11000 epoch=16 epoch_step=605 q=-12.920 critic=2.137 actor=0.452 bc=0.017 lambda=0.030 critic_pen=0.076
# [train] step=12000 epoch=18 epoch_step=219 q=-17.650 critic=1.486 actor=0.570 bc=0.010 lambda=0.030 critic_pen=0.078
# [train] step=13000 epoch=19 epoch_step=526 q=-15.536 critic=1.397 actor=0.497 bc=0.017 lambda=0.028 critic_pen=0.072
# [train] step=14000 epoch=21 epoch_step=140 q=-16.277 critic=2.528 actor=0.469 bc=0.008 lambda=0.027 critic_pen=0.061
# [train] step=15000 epoch=22 epoch_step=447 q=-14.513 critic=3.637 actor=0.448 bc=0.019 lambda=0.026 critic_pen=0.069
# [train] step=16000 epoch=24 epoch_step=61 q=-20.072 critic=1.687 actor=0.563 bc=0.017 lambda=0.025 critic_pen=0.085
# [train] step=17000 epoch=25 epoch_step=368 q=-16.389 critic=2.304 actor=0.467 bc=0.018 lambda=0.024 critic_pen=0.092
# [train] step=18000 epoch=26 epoch_step=675 q=-16.037 critic=1.481 actor=0.483 bc=0.027 lambda=0.023 critic_pen=0.073
# [train] step=19000 epoch=28 epoch_step=289 q=-14.837 critic=1.692 actor=0.381 bc=0.014 lambda=0.022 critic_pen=0.069
# [train] step=20000 epoch=29 epoch_step=596 q=-13.317 critic=3.346 actor=0.347 bc=0.012 lambda=0.022 critic_pen=0.096
# [train] step=21000 epoch=31 epoch_step=210 q=-17.138 critic=1.941 actor=0.424 bc=0.011 lambda=0.022 critic_pen=0.076
# [train] step=22000 epoch=32 epoch_step=517 q=-18.527 critic=2.558 actor=0.448 bc=0.012 lambda=0.021 critic_pen=0.078
# [train] step=23000 epoch=34 epoch_step=131 q=-17.410 critic=1.501 actor=0.394 bc=0.008 lambda=0.021 critic_pen=0.081
# [train] step=24000 epoch=35 epoch_step=438 q=-24.772 critic=1.908 actor=0.534 bc=0.005 lambda=0.021 critic_pen=0.069
# [train] step=25000 epoch=37 epoch_step=52 q=-20.412 critic=1.476 actor=0.457 bc=0.008 lambda=0.021 critic_pen=0.064
# [train] step=26000 epoch=38 epoch_step=359 q=-20.317 critic=1.838 actor=0.489 bc=0.010 lambda=0.022 critic_pen=0.077
# [train] step=27000 epoch=39 epoch_step=666 q=-18.230 critic=2.157 actor=0.496 bc=0.031 lambda=0.020 critic_pen=0.069
# [train] step=28000 epoch=41 epoch_step=280 q=-30.103 critic=2.078 actor=0.675 bc=0.013 lambda=0.021 critic_pen=0.072
# [train] step=29000 epoch=42 epoch_step=587 q=-18.182 critic=2.114 actor=0.478 bc=0.027 lambda=0.020 critic_pen=0.071
# [train] step=30000 epoch=44 epoch_step=201 q=-22.033 critic=1.507 actor=0.512 bc=0.015 lambda=0.020 critic_pen=0.070
# [train] step=31000 epoch=45 epoch_step=508 q=-26.931 critic=1.617 actor=0.627 bc=0.024 lambda=0.020 critic_pen=0.076
# [train] step=32000 epoch=47 epoch_step=122 q=-22.024 critic=2.319 actor=0.469 bc=0.002 lambda=0.021 critic_pen=0.066
# [train] step=33000 epoch=48 epoch_step=429 q=-23.146 critic=2.167 actor=0.494 bc=0.007 lambda=0.020 critic_pen=0.069
# [train] step=34000 epoch=50 epoch_step=43 q=-27.405 critic=1.395 actor=0.600 bc=0.020 lambda=0.019 critic_pen=0.067
# [train] step=35000 epoch=51 epoch_step=350 q=-28.326 critic=19.012 actor=0.563 bc=0.002 lambda=0.020 critic_pen=0.069
# [train] step=36000 epoch=52 epoch_step=657 q=-24.636 critic=2.295 actor=0.527 bc=0.009 lambda=0.020 critic_pen=0.070
# [train] step=37000 epoch=54 epoch_step=271 q=-27.551 critic=2.203 actor=0.547 bc=0.003 lambda=0.019 critic_pen=0.110
# [train] step=38000 epoch=55 epoch_step=578 q=-25.682 critic=2.332 actor=0.551 bc=0.014 lambda=0.019 critic_pen=0.061
# [train] step=39000 epoch=57 epoch_step=192 q=-29.706 critic=2.318 actor=0.605 bc=0.013 lambda=0.019 critic_pen=0.076
# [train] step=40000 epoch=58 epoch_step=499 q=-26.284 critic=1.953 actor=0.539 bc=0.009 lambda=0.019 critic_pen=0.082
# [train] step=41000 epoch=60 epoch_step=113 q=-20.556 critic=12.044 actor=0.415 bc=0.002 lambda=0.020 critic_pen=0.063
# [train] step=42000 epoch=61 epoch_step=420 q=-29.066 critic=17.342 actor=0.564 bc=0.002 lambda=0.019 critic_pen=0.072
# [train] step=43000 epoch=63 epoch_step=34 q=-28.360 critic=1.526 actor=0.560 bc=0.004 lambda=0.019 critic_pen=0.076
# [train] step=44000 epoch=64 epoch_step=341 q=-26.856 critic=1.712 actor=0.536 bc=0.009 lambda=0.019 critic_pen=0.092
#
# [cmd] python -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/seed_46 --agent-file agent_step_00005544.pt --manifest benchmarks/offline_rebrac_broad/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/validation/seed_46/agent_step_00005544.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 42.5%
# avg_return            : -252.05 +/- 209.25
# avg_safety_cost       : 22.864 +/- 44.522
# avg_time_s            : 144.66 +/- 73.97
# avg_time_s_success    : 104.06
# avg_energy            : 88482.35 +/- 44406.37
# avg_path_length_m     : 89.53 +/- 30.79
# avg_progress_ratio    : 0.295 +/- 0.727
# avg_path_efficiency   : 0.244 +/- 0.345
# termination           : {'goal': 17, 'timeout': 13, 'out_of_bounds': 10}
# benchmark_manifest    : benchmarks/offline_rebrac_broad/val_40/single_u10_cross_tgt15.json
#
# [cmd] python -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/seed_46 --agent-file agent_step_00011088.pt --manifest benchmarks/offline_rebrac_broad/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/validation/seed_46/agent_step_00011088.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 72.5%
# avg_return            : -131.25 +/- 144.36
# avg_safety_cost       : 42.905 +/- 55.989
# avg_time_s            : 108.07 +/- 50.93
# avg_time_s_success    : 103.26
# avg_energy            : 67369.66 +/- 32081.74
# avg_path_length_m     : 74.26 +/- 23.99
# avg_progress_ratio    : 0.682 +/- 0.411
# avg_path_efficiency   : 0.443 +/- 0.219
# termination           : {'goal': 29, 'timeout': 4, 'out_of_bounds': 7}
# benchmark_manifest    : benchmarks/offline_rebrac_broad/val_40/single_u10_cross_tgt15.json
#
# [cmd] python -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/seed_46 --agent-file agent_step_00016632.pt --manifest benchmarks/offline_rebrac_broad/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/broad_validation/A1/actorb_4p0__criticb_2p0/validation/seed_46/agent_step_00016632.json
# reward_objective      : efficiency_v2
# ...
# [offline] algo=rebrac transitions=152683 obs_dim=64 action_dim=2 protocol=deployable tensor_replay=on eval_workers=1 sampling=shuffle_no_replacement total_steps=38208
# [train] step=1 epoch=1 epoch_step=1 q=-1.093 critic=9.104 actor=4.630 bc=0.908 lambda=0.915 critic_pen=0.960
# [train] step=1000 epoch=2 epoch_step=403 q=-4.430 critic=29.271 actor=0.949 bc=0.039 lambda=0.179 critic_pen=0.127
# [train] step=2000 epoch=4 epoch_step=209 q=-3.536 critic=23.501 actor=0.503 bc=0.026 lambda=0.113 critic_pen=0.076
# [train] step=3000 epoch=6 epoch_step=15 q=-2.482 critic=12.242 actor=0.344 bc=0.041 lambda=0.072 critic_pen=0.103
# [train] step=4000 epoch=7 epoch_step=418 q=-4.680 critic=6.995 actor=0.353 bc=0.012 lambda=0.065 critic_pen=0.082
# [train] step=5000 epoch=9 epoch_step=224 q=-1.618 critic=3.921 actor=0.147 bc=0.017 lambda=0.048 critic_pen=0.098
# [train] step=6000 epoch=11 epoch_step=30 q=-3.497 critic=7.362 actor=0.209 bc=0.013 lambda=0.045 critic_pen=0.095
# [train] step=7000 epoch=12 epoch_step=433 q=-5.132 critic=2.535 actor=0.243 bc=0.008 lambda=0.041 critic_pen=0.085
# [train] step=8000 epoch=14 epoch_step=239 q=4.739 critic=4.114 actor=0.003 bc=0.037 lambda=0.031 critic_pen=0.098
# [train] step=9000 epoch=16 epoch_step=45 q=-3.284 critic=2.767 actor=0.174 bc=0.017 lambda=0.032 critic_pen=0.081
# [train] step=10000 epoch=17 epoch_step=448 q=0.158 critic=2.830 actor=0.039 bc=0.011 lambda=0.029 critic_pen=0.071
# [train] step=11000 epoch=19 epoch_step=254 q=1.386 critic=2.410 actor=0.063 bc=0.025 lambda=0.027 critic_pen=0.078
# [train] step=12000 epoch=21 epoch_step=60 q=-0.546 critic=3.481 actor=0.214 bc=0.050 lambda=0.026 critic_pen=0.090
# [train] step=13000 epoch=22 epoch_step=463 q=-2.215 critic=2.194 actor=0.189 bc=0.033 lambda=0.026 critic_pen=0.097
# [train] step=14000 epoch=24 epoch_step=269 q=0.112 critic=1.462 actor=0.011 bc=0.003 lambda=0.024 critic_pen=0.063
# [train] step=15000 epoch=26 epoch_step=75 q=-2.558 critic=2.312 actor=0.113 bc=0.013 lambda=0.024 critic_pen=0.086
# [train] step=16000 epoch=27 epoch_step=478 q=-0.360 critic=2.624 actor=0.052 bc=0.011 lambda=0.023 critic_pen=0.077
# [train] step=17000 epoch=29 epoch_step=284 q=-6.346 critic=2.581 actor=0.186 bc=0.008 lambda=0.024 critic_pen=0.096
# [train] step=18000 epoch=31 epoch_step=90 q=-13.799 critic=4.208 actor=0.368 bc=0.005 lambda=0.025 critic_pen=0.081
# [train] step=19000 epoch=32 epoch_step=493 q=-3.240 critic=1.342 actor=0.118 bc=0.011 lambda=0.023 critic_pen=0.071
# [train] step=20000 epoch=34 epoch_step=299 q=-8.733 critic=3.457 actor=0.307 bc=0.027 lambda=0.023 critic_pen=0.095
# [train] step=21000 epoch=36 epoch_step=105 q=-3.932 critic=1.581 actor=0.114 bc=0.006 lambda=0.023 critic_pen=0.078
# [train] step=22000 epoch=37 epoch_step=508 q=-3.843 critic=1.735 actor=0.231 bc=0.037 lambda=0.022 critic_pen=0.076
# [train] step=23000 epoch=39 epoch_step=314 q=-4.134 critic=1.620 actor=0.170 bc=0.019 lambda=0.023 critic_pen=0.081
# [train] step=24000 epoch=41 epoch_step=120 q=-5.693 critic=2.391 actor=0.184 bc=0.015 lambda=0.022 critic_pen=0.064
# [train] step=25000 epoch=42 epoch_step=523 q=-4.235 critic=2.566 actor=0.120 bc=0.007 lambda=0.022 critic_pen=0.106
# [train] step=26000 epoch=44 epoch_step=329 q=0.013 critic=2.187 actor=0.017 bc=0.004 lambda=0.020 critic_pen=0.090
# [train] step=27000 epoch=46 epoch_step=135 q=-5.580 critic=2.487 actor=0.139 bc=0.005 lambda=0.021 critic_pen=0.103
# [train] step=28000 epoch=47 epoch_step=538 q=-2.104 critic=3.063 actor=0.093 bc=0.012 lambda=0.021 critic_pen=0.084
# [train] step=29000 epoch=49 epoch_step=344 q=-5.205 critic=2.508 actor=0.153 bc=0.013 lambda=0.020 critic_pen=0.069
# [train] step=30000 epoch=51 epoch_step=150 q=-7.031 critic=1.653 actor=0.155 bc=0.003 lambda=0.021 critic_pen=0.080
# [train] step=31000 epoch=52 epoch_step=553 q=-6.796 critic=2.664 actor=0.159 bc=0.004 lambda=0.021 critic_pen=0.074
# [train] step=32000 epoch=54 epoch_step=359 q=-4.196 critic=2.587 actor=0.103 bc=0.004 lambda=0.021 critic_pen=0.074
# [train] step=33000 epoch=56 epoch_step=165 q=-6.103 critic=2.951 actor=0.142 bc=0.004 lambda=0.020 critic_pen=0.069
# [train] step=34000 epoch=57 epoch_step=568 q=0.878 critic=2.725 actor=0.070 bc=0.022 lambda=0.020 critic_pen=0.068
# [train] step=35000 epoch=59 epoch_step=374 q=-0.599 critic=3.015 actor=0.114 bc=0.025 lambda=0.020 critic_pen=0.096
# [train] step=36000 epoch=61 epoch_step=180 q=-4.614 critic=2.384 actor=0.154 bc=0.015 lambda=0.021 critic_pen=0.075
# [train] step=37000 epoch=62 epoch_step=583 q=-6.516 critic=2.764 actor=0.211 bc=0.017 lambda=0.022 critic_pen=0.075
# [train] step=38000 epoch=64 epoch_step=389 q=1.549 critic=3.036 actor=0.032 bc=0.016 lambda=0.021 critic_pen=0.087
#
# [cmd] python -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/broad_validation/B2/actorb_4p0__criticb_2p0/seed_46 --agent-file agent_step_00004776.pt --manifest benchmarks/offline_rebrac_broad/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/broad_validation/B2/actorb_4p0__criticb_2p0/validation/seed_46/agent_step_00004776.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 42.5%
# avg_return            : -147.16 +/- 154.72
# avg_safety_cost       : 12.305 +/- 8.749
# avg_time_s            : 98.25 +/- 58.76
# avg_time_s_success    : 93.06
# avg_energy            : 60322.27 +/- 35965.89
# avg_path_length_m     : 69.09 +/- 28.16
# avg_progress_ratio    : 0.515 +/- 0.526
# avg_path_efficiency   : 0.421 +/- 0.310
# termination           : {'goal': 17, 'out_of_bounds': 19, 'timeout': 4}
# benchmark_manifest    : benchmarks/offline_rebrac_broad/val_40/single_u10_cross_tgt15.json
#
# [cmd] python -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/broad_validation/B2/actorb_4p0__criticb_2p0/seed_46 --agent-file agent_step_00009552.pt --manifest benchmarks/offline_rebrac_broad/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/broad_validation/B2/actorb_4p0__criticb_2p0/validation/seed_46/agent_step_00009552.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 50.0%
# avg_return            : -201.55 +/- 211.80
# avg_safety_cost       : 32.821 +/- 67.820
# avg_time_s            : 123.94 +/- 68.65
# avg_time_s_success    : 87.79
# avg_energy            : 77836.61 +/- 43318.04
# avg_path_length_m     : 80.74 +/- 28.82
# avg_progress_ratio    : 0.345 +/- 0.701
# avg_path_efficiency   : 0.310 +/- 0.387
# termination           : {'goal': 20, 'timeout': 8, 'out_of_bounds': 12}
# benchmark_manifest    : benchmarks/offline_rebrac_broad/val_40/single_u10_cross_tgt15.json
#
# [cmd] python -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/broad_validation/B2/actorb_4p0__criticb_2p0/seed_46 --agent-file agent_step_00014328.pt --manifest benchmarks/offline_rebrac_broad/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/broad_validation/B2/actorb_4p0__criticb_2p0/validation/seed_46/agent_step_00014328.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 62.5%
# avg_return            : -126.26 +/- 174.93
# avg_safety_cost       : 20.673 +/- 44.366
# avg_time_s            : 100.58 +/- 59.10
# avg_time_s_success    : 85.41
# avg_energy            : 62396.84 +/- 36493.31
# avg_path_length_m     : 69.03 +/- 27.05
# avg_progress_ratio    : 0.596 +/- 0.556
# avg_path_efficiency   : 0.485 +/- 0.324
# termination           : {'goal': 25, 'out_of_bounds': 12, 'timeout': 3}
# benchmark_manifest    : benchmarks/offline_rebrac_broad/val_40/single_u10_cross_tgt15.json
#
# [cmd] python -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/broad_validation/B2/actorb_4p0__criticb_2p0/seed_46 --agent-file agent_step_00019104.pt --manifest benchmarks/offline_rebrac_broad/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/broad_validation/B2/actorb_4p0__criticb_2p0/validation/seed_46/agent_step_00019104.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 65.0%
# avg_return            : -114.69 +/- 153.48
# avg_safety_cost       : 14.743 +/- 10.558
# avg_time_s            : 97.52 +/- 53.63
# avg_time_s_success    : 87.53
# avg_energy            : 60665.10 +/- 33456.76
# avg_path_length_m     : 67.58 +/- 23.46
# avg_progress_ratio    : 0.621 +/- 0.488
# avg_path_efficiency   : 0.484 +/- 0.305
# termination           : {'goal': 26, 'timeout': 3, 'out_of_bounds': 11}
# benchmark_manifest    : benchmarks/offline_rebrac_broad/val_40/single_u10_cross_tgt15.json
#
# [cmd] python -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/broad_validation/B2/actorb_4p0__criticb_2p0/seed_46 --agent-file agent_step_00023880.pt --manifest benchmarks/offline_rebrac_broad/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/broad_validation/B2/actorb_4p0__criticb_2p0/validation/seed_46/agent_step_00023880.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 72.5%
# avg_return            : -57.69 +/- 53.95
# avg_safety_cost       : 17.473 +/- 15.258
# avg_time_s            : 77.61 +/- 22.03
# avg_time_s_success    : 84.11
# avg_energy            : 48531.86 +/- 13696.81
# avg_path_length_m     : 60.05 +/- 10.52
# avg_progress_ratio    : 0.824 +/- 0.165
# avg_path_efficiency   : 0.606 +/- 0.159
# termination           : {'goal': 29, 'out_of_bounds': 11}
# benchmark_manifest    : benchmarks/offline_rebrac_broad/val_40/single_u10_cross_tgt15.json
#
# [cmd] python -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/broad_validation/B2/actorb_4p0__criticb_2p0/seed_46 --agent-file agent_step_00028656.pt --manifest benchmarks/offline_rebrac_broad/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/broad_validation/B2/actorb_4p0__criticb_2p0/validation/seed_46/agent_step_00028656.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 70.0%
# avg_return            : -74.20 +/- 105.62
# avg_safety_cost       : 16.780 +/- 19.132
# avg_time_s            : 82.78 +/- 34.83
# avg_time_s_success    : 80.96
# avg_energy            : 51471.77 +/- 21542.88
# avg_path_length_m     : 61.73 +/- 15.10
# avg_progress_ratio    : 0.746 +/- 0.329
# avg_path_efficiency   : 0.567 +/- 0.240
# termination           : {'goal': 28, 'out_of_bounds': 11, 'timeout': 1}
# benchmark_manifest    : benchmarks/offline_rebrac_broad/val_40/single_u10_cross_tgt15.json
#
# [cmd] python -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/broad_validation/B2/actorb_4p0__criticb_2p0/seed_46 --agent-file agent_step_00033432.pt --manifest benchmarks/offline_rebrac_broad/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/broad_validation/B2/actorb_4p0__criticb_2p0/validation/seed_46/agent_step_00033432.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 72.5%
# avg_return            : -57.07 +/- 62.62
# avg_safety_cost       : 17.057 +/- 14.903
# avg_time_s            : 77.23 +/- 18.84
# avg_time_s_success    : 79.78
# avg_energy            : 48167.49 +/- 11785.89
# avg_path_length_m     : 59.53 +/- 9.29
# avg_progress_ratio    : 0.817 +/- 0.183
# avg_path_efficiency   : 0.606 +/- 0.173
# termination           : {'goal': 29, 'out_of_bounds': 11}
# benchmark_manifest    : benchmarks/offline_rebrac_broad/val_40/single_u10_cross_tgt15.json
#
# [cmd] python -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/broad_validation/B2/actorb_4p0__criticb_2p0/seed_46 --agent-file agent_step_00038208.pt --manifest benchmarks/offline_rebrac_broad/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/broad_validation/B2/actorb_4p0__criticb_2p0/validation/seed_46/agent_step_00038208.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 80.0%
# avg_return            : -86.63 +/- 159.89
# avg_safety_cost       : 15.975 +/- 15.709
# avg_time_s            : 93.20 +/- 51.45
# avg_time_s_success    : 77.87
# avg_energy            : 58393.60 +/- 32816.67
# avg_path_length_m     : 67.83 +/- 27.02
# avg_progress_ratio    : 0.660 +/- 0.555
# avg_path_efficiency   : 0.539 +/- 0.333
# termination           : {'goal': 32, 'timeout': 2, 'out_of_bounds': 6}
# benchmark_manifest    : benchmarks/offline_rebrac_broad/val_40/single_u10_cross_tgt15.json
#
# [cmd] python -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/broad_validation/B2/actorb_4p0__criticb_2p0/seed_46 --agent-file agent_final.pt --manifest benchmarks/offline_rebrac_broad/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/broad_validation/B2/actorb_4p0__criticb_2p0/validation/seed_46/agent_final.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 80.0%
# avg_return            : -86.63 +/- 159.89
# avg_safety_cost       : 15.975 +/- 15.709
# avg_time_s            : 93.20 +/- 51.45
# avg_time_s_success    : 77.87
# avg_energy            : 58393.60 +/- 32816.67
# avg_path_length_m     : 67.83 +/- 27.02
# avg_progress_ratio    : 0.660 +/- 0.555
# avg_path_efficiency   : 0.539 +/- 0.333
# termination           : {'goal': 32, 'timeout': 2, 'out_of_bounds': 6}
# benchmark_manifest    : benchmarks/offline_rebrac_broad/val_40/single_u10_cross_tgt15.json
#
# [cmd] python - results/offline/rebrac/broad_validation/B2/actorb_4p0__criticb_2p0/validation/seed_46 checkpoints/offline/rebrac/broad_validation/B2/actorb_4p0__criticb_2p0/seed_46/trainer_state.json results/offline/rebrac/broad_validation/B2/actorb_4p0__criticb_2p0/selection/seed_46/selected_checkpoint.json results/offline/rebrac/broad_validation/B2/actorb_4p0__criticb_2p0/selection/seed_46/selected_agent_file.txt
# [write] selection: results/offline/rebrac/broad_validation/B2/actorb_4p0__criticb_2p0/selection/seed_46/selected_checkpoint.json
# [best] agent=agent_final.pt success=0.8000
#
# [cmd] python -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/broad_validation/B2/actorb_4p0__criticb_2p0/seed_46 --agent-file agent_final.pt --manifest benchmarks/offline_rebrac_broad/test_100/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 456 --output-json results/offline/rebrac/broad_validation/B2/actorb_4p0__criticb_2p0/test/seed_46.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 100
# success_rate          : 76.0%
# avg_return            : -108.56 +/- 179.19
# avg_safety_cost       : 15.540 +/- 15.728
# avg_time_s            : 100.79 +/- 57.75
# avg_time_s_success    : 79.42
# avg_energy            : 63092.73 +/- 36499.38
# avg_path_length_m     : 70.93 +/- 30.54
# avg_progress_ratio    : 0.611 +/- 0.606
# avg_path_efficiency   : 0.506 +/- 0.348
# termination           : {'goal': 76, 'timeout': 11, 'out_of_bounds': 13}
# benchmark_manifest    : benchmarks/offline_rebrac_broad/test_100/single_u10_cross_tgt15.json
#
# [done] SPOKE_ID=B2 PHASE=p2_5seed

# %% [markdown]
# ## 5. 重跑 summarize

# %%
# !python -m scripts.summarize_broad_validation
# Out:
# [summary] P1 spokes summarized: 18
# [summary] triggered for P2: 6
#   - A1: mean=0.794 std=0.029 delta_pp=-0.108 reasons=mean_shift
#   - A2: mean=0.606 std=0.157 delta_pp=-0.296 reasons=mean_shift,std_blow_up,td3bc_gap_collapse
#   - A3: mean=0.734 std=0.053 delta_pp=-0.168 reasons=mean_shift,std_blow_up
#   - B2: mean=0.860 std=0.058 delta_pp=-0.042 reasons=std_blow_up
#   - C1: mean=0.218 std=0.007 delta_pp=-0.684 reasons=mean_shift
#   - C3: mean=0.576 std=0.148 delta_pp=-0.326 reasons=mean_shift,std_blow_up

# %% [markdown]
# ## 6. Updated representative-cell 表
#
# 每个 spoke 取 `n_seeds` 最大的 cell 作为 representative。所有 5 个 parity cell 应该升级到 5-seed。

# %%
p1_overview = json.loads((SUMMARIES_DIR / "p1_overview.json").read_text(encoding="utf-8"))

# 每个 spoke 取 n_seeds 最大的 cell
spoke_best = {}
for row in p1_overview:
    sid = row["spoke_id"]
    cur = spoke_best.get(sid)
    if cur is None or row["num_seeds"] > cur["num_seeds"]:
        spoke_best[sid] = row

axis_map = {
    "A1": "A", "A2": "A", "A2-td3bc": "A", "A3": "A",
    "B1": "B", "B2": "B",
    "C1": "C", "C3": "C",
}

print("=" * 100)
print(f"{'axis':<6}{'spoke':<10}{'pair':<32}{'n':>4}{'mean':>9}{'std':>9}{'Δ vs anchor':>14}{'status':>10}")
print("-" * 100)

for sid in ["A1", "A2", "A2-td3bc", "A3", "B1", "B2", "C1", "C3"]:
    row = spoke_best.get(sid)
    if row is None:
        print(f"{axis_map[sid]:<6}{sid:<10}{'MISSING':<32}")
        continue
    m = row["mean_test_success_rate"] or 0.0
    s = row["std_test_success_rate"]  or 0.0
    n = row["num_seeds"]
    status = "✅ 5-seed" if n >= 5 else f"⚠ {n}-seed"
    print(f"{axis_map[sid]:<6}{sid:<10}{row['pair']:<32}{n:>4}"
          f"{m:>9.4f}{s:>9.4f}{(m - ANCHOR_MEAN)*100:>+12.2f}pp{status:>10}")
print("=" * 100)
print(f"\nAnchor: {ANCHOR_MEAN:.3f} ± {ANCHOR_STD:.3f} (5 seeds, Stage C crosscomp/s0/cross_stream)")
# Out:
# ====================================================================================================
# axis  spoke     pair                               n     mean      std   Δ vs anchor    status
# ----------------------------------------------------------------------------------------------------
# A     A1        actorb_4p0__criticb_1p0            5   0.7940   0.0287      -10.80pp  ✅ 5-seed
# A     A2        actorb_4p0__criticb_2p0            5   0.6060   0.1573      -29.60pp  ✅ 5-seed
# A     A2-td3bc  alpha_0p25                         5   0.6040   0.1414      -29.80pp  ✅ 5-seed
# A     A3        actorb_4p0__criticb_1p0            5   0.7340   0.0531      -16.80pp  ✅ 5-seed
# B     B1        actorb_4p0__criticb_2p0            5   0.9000   0.0283       -0.20pp  ✅ 5-seed
# B     B2        actorb_4p0__criticb_2p0            5   0.8600   0.0583       -4.20pp  ✅ 5-seed
# C     C1        actorb_4p0__criticb_2p0            5   0.2180   0.0075      -68.40pp  ✅ 5-seed
# C     C3        actorb_4p0__criticb_2p0            5   0.5760   0.1479      -32.60pp  ✅ 5-seed
# ====================================================================================================
#
# Anchor: 0.902 ± 0.021 (5 seeds, Stage C crosscomp/s0/cross_stream)

# %% [markdown]
# ## 7. A 轴 head-to-head：refit_b vs anchor at 5-seed parity
#
# A1 / A3 在 §6.1 winner select 时基于 1-seed 选了 refit_b。扩到 5-seed 后这个决策是否仍成立？

# %%
def get_cell(spoke_id, pair):
    for row in p1_overview:
        if row["spoke_id"] == spoke_id and row["pair"] == pair:
            return row
    return None

print("=" * 96)
print(f"{'spoke':<8}{'cell':<32}{'n':>4}{'mean':>9}{'std':>9}{'Δ vs anchor':>14}{'verdict':>20}")
print("-" * 96)

for spoke_id in ["A1", "A3"]:
    anchor   = get_cell(spoke_id, "actorb_4p0__criticb_2p0")
    refit_b  = get_cell(spoke_id, "actorb_4p0__criticb_1p0")
    rows = [("anchor", anchor), ("refit_b", refit_b)]
    succs = []
    for tag, row in rows:
        if row is None:
            print(f"{spoke_id:<8}{tag + ' MISSING':<32}")
            continue
        m = row["mean_test_success_rate"] or 0.0
        s = row["std_test_success_rate"]  or 0.0
        n = row["num_seeds"]
        succs.append((tag, m, n))
        print(f"{spoke_id:<8}{tag + ' (' + row['pair'] + ')':<32}{n:>4}"
              f"{m:>9.4f}{s:>9.4f}{(m - ANCHOR_MEAN)*100:>+12.2f}pp")
    if len(succs) == 2:
        a_tag, a_m, a_n = succs[0]
        b_tag, b_m, b_n = succs[1]
        diff = b_m - a_m
        winner = b_tag if b_m > a_m else a_tag
        same_n = "✓ 5v5" if a_n == b_n == 5 else f"⚠ {a_n}v{b_n}"
        print(f"{'':<8}{'  → ' + winner + f' wins by {abs(diff)*100:.2f}pp':<32}{'':<26}{same_n:>20}")
    print()
print("=" * 96)
# Out:
# ================================================================================================
# spoke   cell                               n     mean      std   Δ vs anchor             verdict
# ------------------------------------------------------------------------------------------------
# A1      anchor (actorb_4p0__criticb_2p0)   5   0.7540   0.0467      -14.80pp
# A1      refit_b (actorb_4p0__criticb_1p0)   5   0.7940   0.0287      -10.80pp
#           → refit_b wins by 4.00pp                                               ✓ 5v5
#
# A3      anchor (actorb_4p0__criticb_2p0)   5   0.7520   0.0387      -15.00pp
# A3      refit_b (actorb_4p0__criticb_1p0)   5   0.7340   0.0531      -16.80pp
#           → anchor wins by 1.80pp                                                ✓ 5v5
#
# ================================================================================================

# %% [markdown]
# ## 8. A2 mid-gap：ReBRAC vs TD3+BC at 5-seed parity ⭐
#
# **这是 paper rev.8 claim 的关键检验**。spec §6.1 mid-gap criterion: |ReBRAC − TD3BC| < 5pp 触发。

# %%
rebrac_cell = get_cell("A2",       "actorb_4p0__criticb_2p0")
td3bc_cell  = get_cell("A2-td3bc", "alpha_0p25")

print("=" * 88)
print(f"{'algo':<14}{'cell':<32}{'n':>4}{'mean':>9}{'std':>9}{'Δ vs anchor':>14}")
print("-" * 88)

if rebrac_cell:
    m = rebrac_cell["mean_test_success_rate"] or 0.0
    s = rebrac_cell["std_test_success_rate"]  or 0.0
    n = rebrac_cell["num_seeds"]
    print(f"{'A2 ReBRAC':<14}{rebrac_cell['pair']:<32}{n:>4}{m:>9.4f}{s:>9.4f}{(m - ANCHOR_MEAN)*100:>+12.2f}pp")
    rebrac_m, rebrac_n = m, n
else:
    rebrac_m = rebrac_n = None

if td3bc_cell:
    m = td3bc_cell["mean_test_success_rate"] or 0.0
    s = td3bc_cell["std_test_success_rate"]  or 0.0
    n = td3bc_cell["num_seeds"]
    print(f"{'A2 TD3+BC':<14}{td3bc_cell['pair']:<32}{n:>4}{m:>9.4f}{s:>9.4f}{(m - ANCHOR_MEAN)*100:>+12.2f}pp")
    td3bc_m, td3bc_n = m, n
else:
    td3bc_m = td3bc_n = None

print("=" * 88)
if rebrac_m is not None and td3bc_m is not None:
    diff_pp = (rebrac_m - td3bc_m) * 100
    direction = "ReBRAC > TD3+BC" if diff_pp > 0 else ("ReBRAC < TD3+BC" if diff_pp < 0 else "tied")
    matched = "✓ matched 5v5" if rebrac_n == td3bc_n == 5 else f"⚠ unmatched {rebrac_n}v{td3bc_n}"
    print(f"\n  Δ = {diff_pp:+.2f}pp  ({direction})  [{matched}]")
    if abs(diff_pp) < 5.0:
        print(f"  spec §6.1 mid-gap: |Δ| < 5pp → A2 仍触发 (algorithm 几乎打平)")
    else:
        if diff_pp > 0:
            print(f"  spec §6.1 mid-gap: |Δ| ≥ 5pp 且方向正 → ReBRAC ≥ TD3+BC (paper claim 站住)")
        else:
            print(f"  spec §6.1 mid-gap: |Δ| ≥ 5pp 且方向负 → ⚠ TD3+BC > ReBRAC (paper claim 需要限定条件)")
# Out:
# ========================================================================================
# algo          cell                               n     mean      std   Δ vs anchor
# ----------------------------------------------------------------------------------------
# A2 ReBRAC     actorb_4p0__criticb_2p0            5   0.6060   0.1573      -29.60pp
# A2 TD3+BC     alpha_0p25                         5   0.6040   0.1414      -29.80pp
# ========================================================================================
#
#   Δ = +0.20pp  (ReBRAC > TD3+BC)  [✓ matched 5v5]
#   spec §6.1 mid-gap: |Δ| < 5pp → A2 仍触发 (algorithm 几乎打平)

# %% [markdown]
# ## 9. 最终 verdict — 5-seed parity 后是否可以进入报告
#
# 通过 = 三条都满足：
# 1. 5 个 parity cell 都升到 5-seed（status 列全 ✅）
# 2. A1 / A3 winner 决策与 1-seed refit 决策一致 OR 已经 flagged
# 3. A2 ReBRAC vs TD3+BC 比较是 matched 5v5

# %%
checks = []
for spoke_id, pair in PARITY_CELLS:
    row = get_cell(spoke_id, pair)
    n = row["num_seeds"] if row else 0
    checks.append((f"{spoke_id} / {pair}", n >= 5, f"n={n}"))

# A2 mid-gap check
a2_n      = rebrac_cell["num_seeds"] if rebrac_cell else 0
td3bc_n_  = td3bc_cell["num_seeds"]  if td3bc_cell  else 0
checks.append(("A2 ReBRAC vs TD3+BC matched seeds", a2_n == td3bc_n_ == 5, f"{a2_n}v{td3bc_n_}"))

print("=" * 80)
print(f"{'check':<60}{'pass':>6}{'detail':>14}")
print("-" * 80)
all_pass = True
for name, ok, detail in checks:
    mark = "✅" if ok else "❌"
    if not ok:
        all_pass = False
    print(f"{name:<60}{mark:>6}{detail:>14}")
print("=" * 80)
print(f"\n{'✅ READY for report drafting' if all_pass else '❌ HOLD — re-run failed cells before report'}")
# Out:
# ================================================================================
# check                                                         pass        detail
# --------------------------------------------------------------------------------
# A1 / actorb_4p0__criticb_2p0                                     ✅           n=5
# A2-td3bc / alpha_0p25                                            ✅           n=5
# A3 / actorb_4p0__criticb_2p0                                     ✅           n=5
# B1 / actorb_4p0__criticb_2p0                                     ✅           n=5
# B2 / actorb_4p0__criticb_2p0                                     ✅           n=5
# A2 ReBRAC vs TD3+BC matched seeds                                ✅           5v5
# ================================================================================
#
# ✅ READY for report drafting
