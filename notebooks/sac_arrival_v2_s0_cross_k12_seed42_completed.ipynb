# %% [markdown]
# # SAC arrival_v2 — history k=8→12 monotonicity scan on single_cross_s0 (seed=42, 1M, vanilla)
#
# **Pre-context（commit `7be0956`）**：[`docs/arrival_v2_experiment_report.md`](../docs/arrival_v2_experiment_report.md) §7.8 已闭环。`s0` + vanilla SAC + history k=4→8 单变量 ablation 在 seed=42 上 **PASS**，闭合 §7.6.4 的 80pp gap，证实 actor-side temporal info access 是瓶颈：
#
# | §7.8 闭环              | history | final  | peak@step    | mean39 | OOB   | Gate |
# |---                     |---:     |---:    |---           |---:    |---:   |---   |
# | s0 + k=4 (§7.6.4 base) | 4       | 0.100  | 0.367 @ 975k | 0.221  | 0.667 | FAIL(3/5) |
# | **s0 + k=8 (§7.8)**    | **8**   | **0.900** | **0.900 @ 475k** | **0.636** | **0.100** | **PASS（5/5）** |
#
# 物理量：每 control step ≈ 0.5 s（dt × eval_action_repeat）。
# - k=4 → ~2s 历史窗（涡街周期 10–20 s 的 10–20%）— FAIL
# - k=8 → ~4s 历史窗（20–40%）— PASS
# - **k=12 → ~6s 历史窗（30–60%）** ← 本 notebook
#
# **关键 open question**：k=4→8 不是 linear extrapolation 而是 phase transition。k=12 进一步加窗，效应是否单调、饱和、还是下降？这关系到 thesis 主线如何论述"actor temporal window 充分性"（claim 1：k=8 足够 vs claim 2：更长窗口持续帮助 vs claim 3：信息饱和后过长窗口反害）。
#
# **本 notebook 任务（pure vanilla + history k=8→12 单变量 ablation）**：把 §7.8 anchor 的 `--history-length 8` 替换成 `--history-length 12`，其它全部不动：
#
# | 维度                  | §7.8 anchor (k=8) | 本 notebook (k=12) |
# |---                    |---                |---                 |
# | `--history-length`    | 8                 | **12** ← 唯一变量  |
# | `--seed`              | 42                | 42                 |
# | algorithm             | vanilla SAC       | vanilla SAC        |
# | sensor layout         | s0 (DVL-only)     | s0 (DVL-only)      |
# | reward                | arrival_v2        | arrival_v2         |
# | flow U / target       | 1.5 / 1.5         | 1.5 / 1.5          |
# | total_steps           | 1M                | 1M                 |
# | num_envs              | 6                 | 6                  |
# | benchmark             | `single_u15_cross_tgt15` | 同           |
# | obs_dim               | 10×8 + 8 = 88     | **10×12 + 8 = 128**|
#
# **Gate**（与 §7.8 同口径）：
# - `final_success_rate ≥ 0.85`
# - `last100k_mean ≥ 0.9 × peak`
# - `final_oob_rate ≤ 0.10`
# - `include_episode_context_obs == True`
# - `timeout_bootstrap_semantics == 'terminal'`
#
# **Monotonicity verdict 规则**（驱动 §7.8 续写 + §8 P1#2）：
#
# | Verdict | 触发条件 | 解释 |
# |---|---|---|
# | **SUPER-MONOTONIC** | k=12 PASS 且 (final ≥ 0.95 OR peak_step earlier by ≥100k OR mean ≥ k=8 mean + 0.05) | k>8 仍持续帮助；建议继续扫 k=16 |
# | **MONOTONIC-PLATEAU** | k=12 PASS 且 \|final − 0.900\| ≤ 0.05 且 \|mean − 0.636\| ≤ 0.05 | 饱和点在 k≈8；thesis 主线可定 k=8 |
# | **DECAY** | k=12 STRONG-PARTIAL（final ∈ [0.5, 0.85)）| 信息饱和后过长窗口轻微反害（curse of dim / over-stale） |
# | **COLLAPSE** | k=12 final < 0.5 | 严重下降；强烈支持 k=8 sweet spot；thesis 写 "actor temporal window 必须 narrow-band tuned" |
#
# **输出根**：
# - `experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s0_k12/seed_42/`
#
# **总预算**：~2.5h L4（1 Colab Pro+ session；obs_dim 128 vs 88 增加 ~45% forward cost，但 hidden_dim 仍 256，主要瓶颈是 env step）。
#
# **风格**：训练用 `!python -u -m scripts.train_sac` 直跑，与 §7.8 一致。

# %% [markdown]
# ## 0. GPU sanity

# %%
# !nvidia-smi | head -10
# Out:
# Mon May 18 14:14:30 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA L4                      Off |   00000000:00:03.0 Off |                    0 |
# | N/A   39C    P8             12W /   72W |       0MiB /  23034MiB |      0%      Default |

# %% [markdown]
# ## 1. Mount Drive + cwd

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

REPO_DIR = '/content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5'
# %cd $REPO_DIR
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5

# %% [markdown]
# ## 2. Config — single phase（vanilla SAC + history k=12，与 §7.8 anchor 仅差一个 flag value）

# %%
import json
import os
from pathlib import Path

import pandas as pd

# ==== SAC / env config (与 §7.8 anchor 严格一致，除 history_length 外) ====
OBJECTIVE = 'arrival_v2'
PROBE_LAYOUT = 's0'
HISTORY_LENGTH = 12                     # ← 唯一与 §7.8 anchor (k=8) 不同的值
TARGET_SPEED = 1.5
SEED = 42

RANDOM_STEPS = 5_000
UPDATE_AFTER = 5_000
BATCH_SIZE = 256
HIDDEN_DIM = 256
NUM_ENVS = 6
EVAL_EVERY = 25_000
EVAL_EPISODES = 30
CHECKPOINT_EVERY = 100_000
DEVICE = 'cuda'

# 显式拒绝所有 SAC 改进项 — 与 §7.8 一致
USE_ASYMMETRIC_CRITIC = False
USE_LAYERNORM = False
UPDATES_PER_STEP = 1
DROPOUT_RATE = 0.0

PASS_FINAL_SUCCESS = 0.85
PASS_LAST100_RATIO = 0.90
PASS_OOB_RATE = 0.10

# Flow file（与 §7 全套严格一致）
SINGLE_FLOW = 'wake_data/wake_v8_U1p50_Re250_D12p00_dx0p60_Ti5pct_1200f_roi.npy'

# ==== Single phase — single_cross s0 k=12 seed=42 (X_*) ====
X_BENCHMARK_KEY = 'single_u15_cross_tgt15'
X_TASK_GEOMETRY = 'cross_stream'
X_FLOW_PATH = SINGLE_FLOW
X_TOTAL_STEPS = 1_000_000
X_RUN_ROOT = Path('experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s0_k12/seed_42')
X_CKPT_ROOT = Path('checkpoints/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s0_k12/seed_42')
X_MANIFEST_PATH = Path(f'benchmarks/{X_BENCHMARK_KEY}.json')

# Baselines
X_K8_ANCHOR_ROOT = Path('experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s0_k8/seed_42')      # §7.8 anchor
X_K4_S42_ROOT    = Path('experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s0_k4/seed_42')      # §7.6.4
X_S1_BASELINE_ROOT = Path('experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s1_k4/seed_42')    # §7.1 upper

os.environ['PYTHONUNBUFFERED'] = '1'

print(f'PROBE_LAYOUT          = {PROBE_LAYOUT}')
print(f'OBJECTIVE             = {OBJECTIVE}')
print(f'HISTORY_LENGTH        = {HISTORY_LENGTH}        ← 唯一与 §7.8 anchor (k=8) 不同')
print(f'SEED                  = {SEED}')
print(f'NUM_ENVS              = {NUM_ENVS}')
print(f'USE_ASYMMETRIC_CRITIC = {USE_ASYMMETRIC_CRITIC}')
print(f'USE_LAYERNORM         = {USE_LAYERNORM}')
print(f'UPDATES_PER_STEP      = {UPDATES_PER_STEP}')
print(f'DROPOUT_RATE          = {DROPOUT_RATE}')
print()
print(f'benchmark             : {X_BENCHMARK_KEY}')
print(f'geometry              : {X_TASK_GEOMETRY}')
print(f'total_steps           : {X_TOTAL_STEPS:,}')
print(f'expected obs_dim      : 10 * {HISTORY_LENGTH} + 8 (arrival_v2 context) = {10 * HISTORY_LENGTH + 8}')
print(f'run_root              : {X_RUN_ROOT}')
print(f'§7.8 k=8 anchor       : {X_K8_ANCHOR_ROOT}')
print(f'§7.6.4 k=4 base       : {X_K4_S42_ROOT}')
print(f'§7.1 s1 upper ref     : {X_S1_BASELINE_ROOT}')
# Out:
# PROBE_LAYOUT          = s0
# OBJECTIVE             = arrival_v2
# HISTORY_LENGTH        = 12        ← 唯一与 §7.8 anchor (k=8) 不同
# SEED                  = 42
# NUM_ENVS              = 6
# USE_ASYMMETRIC_CRITIC = False
# USE_LAYERNORM         = False
# UPDATES_PER_STEP      = 1
# DROPOUT_RATE          = 0.0
#
# benchmark             : single_u15_cross_tgt15
# geometry              : cross_stream
# total_steps           : 1,000,000
# expected obs_dim      : 10 * 12 + 8 (arrival_v2 context) = 128
# run_root              : experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s0_k12/seed_42
# §7.8 k=8 anchor       : experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s0_k8/seed_42
# §7.6.4 k=4 base       : experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s0_k4/seed_42
# §7.1 s1 upper ref     : experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s1_k4/seed_42

# %% [markdown]
# ## 3. Preflight — flow / arrival_v2 candidate gate / reward unit tests / manifest / baseline 就位

# %%
# Flow file
fp = Path(X_FLOW_PATH)
if not fp.exists():
    raise FileNotFoundError(f'missing flow file: {fp}')
print(f'[OK] flow file: {fp}  ({fp.stat().st_size / 1e6:.1f} MB)')
# Out:
# [OK] flow file: wake_data/wake_v8_U1p50_Re250_D12p00_dx0p60_Ti5pct_1200f_roi.npy  (230.4 MB)

# %%
# !python -u -m scripts.validate_arrival_v2_candidate
# Out:
# [undiscounted]
# fast_success       144.473
# slow_success       142.023
# unsafe_success      91.048
# timeout_near      -149.800
# timeout_far       -229.800
# late_oob          -274.500
# fast_oob          -280.325
# mid_oob           -319.450
#
# [discounted_gamma_0.995]
# fast_success        88.578
# slow_success        54.683
# unsafe_success      34.857
# timeout_near       -39.480
# timeout_far        -58.269
# late_oob          -103.800
# mid_oob           -190.006
# fast_oob          -212.555
#
# [discounted_shortcut] safe=69.330 risky=62.361
#
# PASS: arrival_v2 candidate pre-integration gates passed.

# %%
# !python -u -m pytest tests/test_reward_objective.py -q
# Out:
# ...............                                                          [100%]
# 15 passed in 24.20s

# %%
if not X_MANIFEST_PATH.exists():
    # !python -u -m scripts.generate_standard_benchmarks --benchmarks {X_BENCHMARK_KEY} --episodes {EVAL_EPISODES}
if not X_MANIFEST_PATH.exists():
    raise FileNotFoundError(f'manifest not generated: {X_MANIFEST_PATH}')
print(f'[OK] manifest ready: {X_MANIFEST_PATH}')
# Out:
# [OK] manifest ready: benchmarks/single_u15_cross_tgt15.json

# %%
# 检查 3 个对比 baseline 是否就位
for label, root, ref_final, ref_oob in [
    ('§7.8 k8 anchor s42  ', X_K8_ANCHOR_ROOT, 0.900, 0.100),
    ('§7.6.4 k4 vanilla s42', X_K4_S42_ROOT, 0.100, 0.667),
    ('§7.1 s1_k4 upper s42 ', X_S1_BASELINE_ROOT, 0.900, 0.100),
]:
    fp = root / 'results' / 'final_eval.json'
    if fp.exists():
        d = json.loads(fp.read_text(encoding='utf-8'))
        f = float(d['eval_success_rate'])
        c = d.get('eval_termination_counts', {})
        n = float(d.get('num_eval_episodes', EVAL_EPISODES))
        oob = float(c.get('out_of_bounds', 0)) / max(n, 1.0)
        match = '✓' if abs(f - ref_final) < 0.05 and abs(oob - ref_oob) < 0.05 else '✗ mismatch'
        print(f'[OK] {label}: final={f:.4f}  oob={oob:.4f}  counts={c}  {match}')
    else:
        print(f'[WARN] {label}: {fp} 不存在 (后续 §5 diff 会回退到 report 转载值)')
# Out:
# [OK] §7.8 k8 anchor s42  : final=0.9000  oob=0.1000  counts={'goal': 27, 'out_of_bounds': 3}  ✓
# [OK] §7.6.4 k4 vanilla s42: final=0.1000  oob=0.6667  counts={'out_of_bounds': 20, 'timeout': 7, 'goal': 3}  ✓
# [OK] §7.1 s1_k4 upper s42 : final=0.9000  oob=0.1000  counts={'goal': 27, 'out_of_bounds': 3}  ✓

# %% [markdown]
# ## 4. Train — single_cross_s0 + history k=12 + seed=42 (1.0M, skip/resume)

# %%
x_state_path = X_RUN_ROOT / 'trainer_state.json'
if x_state_path.exists():
    x_state = json.loads(x_state_path.read_text(encoding='utf-8'))
    x_current_step = int(x_state.get('env_step', 0))
else:
    x_current_step = 0
print(f'[state] X env_step = {x_current_step:,} / target {X_TOTAL_STEPS:,}')

if x_current_step >= X_TOTAL_STEPS:
    print(f'[skip] X already trained to {x_current_step:,} >= {X_TOTAL_STEPS:,}')
elif x_current_step > 0:
    print(f'[resume] X continuing from {x_current_step:,} -> {X_TOTAL_STEPS:,}')
    # !python -u -m scripts.train_sac \
        --resume {str(X_RUN_ROOT)} \
        --total-steps {X_TOTAL_STEPS} \
        --eval-every {EVAL_EVERY} \
        --eval-episodes {EVAL_EPISODES} \
        --checkpoint-every {CHECKPOINT_EVERY} \
        --eval-manifest {str(X_MANIFEST_PATH)} \
        --device {DEVICE}
else:
    print(f'[train] X fresh start -> {X_TOTAL_STEPS:,}')
    # !python -u -m scripts.train_sac \
        --flow {X_FLOW_PATH} \
        --task-geometry {X_TASK_GEOMETRY} \
        --target-speed {TARGET_SPEED} \
        --objective {OBJECTIVE} \
        --probe-layout {PROBE_LAYOUT} \
        --history-length {HISTORY_LENGTH} \
        --total-steps {X_TOTAL_STEPS} \
        --random-steps {RANDOM_STEPS} \
        --update-after {UPDATE_AFTER} \
        --batch-size {BATCH_SIZE} \
        --hidden-dim {HIDDEN_DIM} \
        --num-envs {NUM_ENVS} \
        --eval-every {EVAL_EVERY} \
        --eval-episodes {EVAL_EPISODES} \
        --checkpoint-every {CHECKPOINT_EVERY} \
        --eval-manifest {str(X_MANIFEST_PATH)} \
        --seed {SEED} \
        --device {DEVICE} \
        --save-dir {str(X_RUN_ROOT)} \
        --checkpoint-dir {str(X_CKPT_ROOT)}
# Out:
# [state] X env_step = 0 / target 1,000,000
# [train] X fresh start -> 1,000,000
# [train] episode=5 step=642 return=-251.36 success=False time=17.5s geometry=cross_stream history=12
# [train] episode=10 step=1122 return=-414.93 success=False time=93.3s geometry=cross_stream history=12
# [train] episode=15 step=1326 return=-520.75 success=False time=110.4s geometry=cross_stream history=12
# [train] episode=20 step=1878 return=-403.95 success=False time=61.3s geometry=cross_stream history=12
# [train] episode=25 step=2712 return=-340.63 success=False time=68.7s geometry=cross_stream history=12
# [train] episode=30 step=3330 return=-411.30 success=False time=38.1s geometry=cross_stream history=12
# [train] episode=35 step=3954 return=-267.16 success=False time=8.0s geometry=cross_stream history=12
# [train] episode=40 step=4350 return=-264.62 success=False time=11.7s geometry=cross_stream history=12
# [train] episode=45 step=5046 return=-429.74 success=False time=104.3s geometry=cross_stream history=12 | q1=510.390 actor=0.168 alpha=0.200
# [train] episode=50 step=5544 return=-350.61 success=False time=41.8s geometry=cross_stream history=12 | q1=1021.227 actor=3.164 alpha=0.195
# [train] episode=55 step=5922 return=-365.09 success=False time=30.7s geometry=cross_stream history=12 | q1=578.081 actor=4.222 alpha=0.191
# [train] episode=60 step=6606 return=-357.72 success=False time=67.0s geometry=cross_stream history=12 | q1=844.532 actor=4.016 alpha=0.185
# [train] episode=65 step=6990 return=-336.88 success=False time=26.8s geometry=cross_stream history=12 | q1=1047.452 actor=5.258 alpha=0.182
# [train] episode=70 step=7650 return=-406.54 success=False time=40.0s geometry=cross_stream history=12 | q1=3.959 actor=5.747 alpha=0.177
# [train] episode=75 step=8424 return=-444.66 success=False time=63.7s geometry=cross_stream history=12 | q1=460.693 actor=7.391 alpha=0.172
# [train] episode=80 step=9030 return=-394.68 success=False time=71.5s geometry=cross_stream history=12 | q1=228.343 actor=7.949 alpha=0.168
# [train] episode=85 step=9324 return=-371.54 success=False time=86.8s geometry=cross_stream history=12 | q1=289.930 actor=9.380 alpha=0.166
# [train] episode=90 step=9942 return=-474.10 success=False time=50.8s geometry=cross_stream history=12 | q1=475.619 actor=11.104 alpha=0.163
# [train] episode=95 step=10584 return=-267.92 success=False time=8.5s geometry=cross_stream history=12 | q1=690.728 actor=12.249 alpha=0.159
# [train] episode=100 step=11010 return=-280.86 success=False time=18.0s geometry=cross_stream history=12 | q1=696.452 actor=12.139 alpha=0.156
# [train] episode=105 step=11472 return=-279.58 success=False time=36.4s geometry=cross_stream history=12 | q1=662.457 actor=12.594 alpha=0.154
# [train] episode=110 step=11832 return=-375.72 success=False time=99.5s geometry=cross_stream history=12 | q1=442.120 actor=13.943 alpha=0.152
# [train] episode=115 step=12246 return=-321.03 success=False time=66.9s geometry=cross_stream history=12 | q1=647.156 actor=13.568 alpha=0.149
# [train] episode=120 step=12900 return=-352.18 success=False time=71.9s geometry=cross_stream history=12 | q1=486.293 actor=16.221 alpha=0.144
# [train] episode=125 step=13302 return=-483.35 success=False time=51.9s geometry=cross_stream history=12 | q1=1089.873 actor=17.149 alpha=0.141
# [train] episode=130 step=13812 return=-316.82 success=False time=30.3s geometry=cross_stream history=12 | q1=42.630 actor=20.118 alpha=0.138
# [train] episode=135 step=14478 return=-304.83 success=False time=29.7s geometry=cross_stream history=12 | q1=247.536 actor=18.350 alpha=0.134
# [train] episode=140 step=15336 return=-412.52 success=False time=63.5s geometry=cross_stream history=12 | q1=462.388 actor=19.712 alpha=0.129
# [train] episode=145 step=15888 return=-289.92 success=False time=48.8s geometry=cross_stream history=12 | q1=257.499 actor=21.561 alpha=0.126
# [train] episode=150 step=16368 return=-268.20 success=False time=21.6s geometry=cross_stream history=12 | q1=472.625 actor=22.479 alpha=0.124
# [train] episode=155 step=16956 return=-281.80 success=False time=48.5s geometry=cross_stream history=12 | q1=456.406 actor=22.822 alpha=0.121
# [train] episode=160 step=17412 return=-423.31 success=False time=45.0s geometry=cross_stream history=12 | q1=393.699 actor=23.862 alpha=0.119
# [train] episode=165 step=17928 return=-357.51 success=False time=80.2s geometry=cross_stream history=12 | q1=416.969 actor=25.169 alpha=0.117
# [train] episode=170 step=18636 return=-289.39 success=False time=41.7s geometry=cross_stream history=12 | q1=549.052 actor=26.692 alpha=0.113
# [train] episode=175 step=19224 return=-315.90 success=False time=21.0s geometry=cross_stream history=12 | q1=206.257 actor=27.673 alpha=0.110
# [train] episode=180 step=19950 return=-246.09 success=False time=32.3s geometry=cross_stream history=12 | q1=551.540 actor=30.458 alpha=0.106
# [train] episode=185 step=20394 return=-279.40 success=False time=22.1s geometry=cross_stream history=12 | q1=683.152 actor=29.946 alpha=0.104
# [train] episode=190 step=21066 return=-381.30 success=False time=84.7s geometry=cross_stream history=12 | q1=400.389 actor=32.455 alpha=0.101
# [train] episode=195 step=21768 return=-339.02 success=False time=84.3s geometry=cross_stream history=12 | q1=588.175 actor=30.346 alpha=0.098
# [train] episode=200 step=22260 return=-366.33 success=False time=69.0s geometry=cross_stream history=12 | q1=519.598 actor=34.866 alpha=0.096
# [train] episode=205 step=23028 return=-302.97 success=False time=63.4s geometry=cross_stream history=12 | q1=496.776 actor=37.074 alpha=0.092
# [train] episode=210 step=23766 return=-321.03 success=False time=74.0s geometry=cross_stream history=12 | q1=657.725 actor=33.545 alpha=0.090
# [train] episode=215 step=24198 return=-214.40 success=False time=32.9s geometry=cross_stream history=12 | q1=659.592 actor=36.292 alpha=0.089
# [eval] step=25002 objective=arrival_v2 return=-361.94 safety=25.989 success=0.00% time=71.5s energy=20016.8 path=101.8 prog=-1.19
# [train] episode=220 step=25200 return=-396.06 success=False time=88.0s geometry=cross_stream history=12 | q1=24.731 actor=37.750 alpha=0.086
# [train] episode=225 step=25650 return=-268.58 success=False time=36.9s geometry=cross_stream history=12 | q1=190.957 actor=40.389 alpha=0.084
# [train] episode=230 step=26658 return=-513.50 success=False time=153.3s geometry=cross_stream history=12 | q1=188.065 actor=37.268 alpha=0.081
# [train] episode=235 step=27084 return=-229.59 success=False time=26.8s geometry=cross_stream history=12 | q1=518.273 actor=40.192 alpha=0.080
# [train] episode=240 step=27660 return=-404.05 success=False time=78.0s geometry=cross_stream history=12 | q1=141.797 actor=40.439 alpha=0.078
# [train] episode=245 step=28086 return=-329.61 success=False time=35.8s geometry=cross_stream history=12 | q1=670.493 actor=45.015 alpha=0.077
# [train] episode=250 step=28848 return=-320.35 success=False time=29.2s geometry=cross_stream history=12 | q1=223.999 actor=45.936 alpha=0.075
# [train] episode=255 step=29580 return=-448.88 success=False time=67.9s geometry=cross_stream history=12 | q1=455.811 actor=46.868 alpha=0.072
# [train] episode=260 step=30072 return=-244.76 success=False time=38.9s geometry=cross_stream history=12 | q1=155.514 actor=47.925 alpha=0.071
# [train] episode=265 step=30612 return=-238.75 success=False time=39.4s geometry=cross_stream history=12 | q1=348.348 actor=47.050 alpha=0.069
# [train] episode=270 step=31200 return=-363.14 success=False time=64.8s geometry=cross_stream history=12 | q1=182.082 actor=47.864 alpha=0.068
# [train] episode=275 step=31770 return=-413.73 success=False time=117.6s geometry=cross_stream history=12 | q1=572.633 actor=49.526 alpha=0.067
# [train] episode=280 step=32904 return=-426.89 success=False time=97.7s geometry=cross_stream history=12 | q1=450.981 actor=48.077 alpha=0.064
# [train] episode=285 step=33192 return=-470.92 success=False time=104.8s geometry=cross_stream history=12 | q1=370.533 actor=51.236 alpha=0.063
# [train] episode=290 step=34068 return=-527.58 success=False time=106.8s geometry=cross_stream history=12 | q1=456.979 actor=55.552 alpha=0.061
# [train] episode=295 step=34434 return=-220.62 success=False time=29.8s geometry=cross_stream history=12 | q1=110.646 actor=60.163 alpha=0.060
# [train] episode=300 step=34944 return=-229.01 success=False time=32.3s geometry=cross_stream history=12 | q1=1.682 actor=51.660 alpha=0.059
# [train] episode=305 step=35490 return=-393.15 success=False time=87.3s geometry=cross_stream history=12 | q1=44.169 actor=54.164 alpha=0.058
# [train] episode=310 step=36258 return=-227.58 success=False time=67.3s geometry=cross_stream history=12 | q1=634.903 actor=58.391 alpha=0.058
# [train] episode=315 step=37104 return=-511.45 success=False time=102.6s geometry=cross_stream history=12 | q1=433.058 actor=58.760 alpha=0.058
# [train] episode=320 step=37488 return=-181.61 success=False time=65.8s geometry=cross_stream history=12 | q1=22.955 actor=59.674 alpha=0.057
# [train] episode=325 step=38010 return=-481.70 success=False time=70.8s geometry=cross_stream history=12 | q1=9.890 actor=57.483 alpha=0.057
# [train] episode=330 step=38658 return=-216.91 success=False time=62.0s geometry=cross_stream history=12 | q1=70.918 actor=62.119 alpha=0.056
# [train] episode=335 step=39354 return=-457.56 success=False time=111.2s geometry=cross_stream history=12 | q1=215.078 actor=60.392 alpha=0.055
# [train] episode=340 step=39810 return=-393.68 success=False time=89.1s geometry=cross_stream history=12 | q1=364.616 actor=62.003 alpha=0.055
# [train] episode=345 step=40338 return=-258.59 success=False time=42.8s geometry=cross_stream history=12 | q1=604.765 actor=59.704 alpha=0.054
# [train] episode=350 step=40914 return=-232.09 success=False time=53.0s geometry=cross_stream history=12 | q1=294.316 actor=58.313 alpha=0.054
# [train] episode=355 step=41460 return=-178.89 success=False time=43.0s geometry=cross_stream history=12 | q1=585.801 actor=60.706 alpha=0.053
# [train] episode=360 step=42120 return=143.51 success=True time=54.2s geometry=cross_stream history=12 | q1=205.426 actor=63.575 alpha=0.052
# [train] episode=365 step=43200 return=-259.75 success=False time=13.6s geometry=cross_stream history=12 | q1=182.331 actor=61.586 alpha=0.052
# [train] episode=370 step=44712 return=96.88 success=True time=113.2s geometry=cross_stream history=12 | q1=117.883 actor=65.527 alpha=0.051
# [train] episode=375 step=45360 return=-252.22 success=False time=7.5s geometry=cross_stream history=12 | q1=463.141 actor=68.221 alpha=0.050
# [train] episode=380 step=45762 return=-216.89 success=False time=17.8s geometry=cross_stream history=12 | q1=434.774 actor=72.818 alpha=0.049
# [train] episode=385 step=46746 return=-238.92 success=False time=118.0s geometry=cross_stream history=12 | q1=220.679 actor=66.868 alpha=0.048
# [train] episode=390 step=47628 return=-539.10 success=False time=98.2s geometry=cross_stream history=12 | q1=288.547 actor=69.222 alpha=0.049
# [train] episode=395 step=48276 return=-260.83 success=False time=11.3s geometry=cross_stream history=12 | q1=109.346 actor=72.521 alpha=0.049
# [train] episode=400 step=48996 return=-260.06 success=False time=36.7s geometry=cross_stream history=12 | q1=334.775 actor=72.229 alpha=0.048
# [eval] step=50004 objective=arrival_v2 return=-359.71 safety=23.924 success=0.00% time=109.5s energy=46787.9 path=143.4 prog=-1.40
# [train] episode=405 step=50226 return=-216.59 success=False time=102.0s geometry=cross_stream history=12 | q1=468.374 actor=75.233 alpha=0.047
# [train] episode=410 step=50718 return=-357.76 success=False time=132.2s geometry=cross_stream history=12 | q1=118.711 actor=80.165 alpha=0.048
# [train] episode=415 step=52092 return=-298.13 success=False time=125.6s geometry=cross_stream history=12 | q1=367.191 actor=75.863 alpha=0.050
# [train] episode=420 step=52626 return=-337.36 success=False time=42.1s geometry=cross_stream history=12 | q1=257.405 actor=75.404 alpha=0.051
# [train] episode=425 step=53328 return=-246.79 success=False time=15.5s geometry=cross_stream history=12 | q1=329.000 actor=77.994 alpha=0.052
# [train] episode=430 step=53868 return=-283.92 success=False time=35.5s geometry=cross_stream history=12 | q1=105.883 actor=80.594 alpha=0.053
# [train] episode=435 step=54690 return=-260.49 success=False time=73.7s geometry=cross_stream history=12 | q1=175.676 actor=77.551 alpha=0.054
# [train] episode=440 step=55056 return=-235.73 success=False time=38.6s geometry=cross_stream history=12 | q1=83.490 actor=78.843 alpha=0.053
# [train] episode=445 step=55758 return=-252.69 success=False time=62.4s geometry=cross_stream history=12 | q1=416.018 actor=75.379 alpha=0.053
# [train] episode=450 step=56550 return=-344.97 success=False time=66.2s geometry=cross_stream history=12 | q1=248.085 actor=80.613 alpha=0.054
# [train] episode=455 step=57396 return=-294.44 success=False time=54.9s geometry=cross_stream history=12 | q1=166.933 actor=79.939 alpha=0.054
# [train] episode=460 step=58182 return=-250.69 success=False time=37.9s geometry=cross_stream history=12 | q1=249.798 actor=80.473 alpha=0.056
# [train] episode=465 step=58824 return=-274.89 success=False time=43.9s geometry=cross_stream history=12 | q1=7.245 actor=78.359 alpha=0.057
# [train] episode=470 step=59676 return=-359.34 success=False time=86.6s geometry=cross_stream history=12 | q1=173.916 actor=80.661 alpha=0.058
# [train] episode=475 step=60210 return=-290.65 success=False time=43.6s geometry=cross_stream history=12 | q1=8.861 actor=82.087 alpha=0.058
# [train] episode=480 step=60696 return=-324.28 success=False time=74.5s geometry=cross_stream history=12 | q1=670.344 actor=81.995 alpha=0.057
# [train] episode=485 step=61944 return=-151.86 success=False time=125.2s geometry=cross_stream history=12 | q1=219.034 actor=83.716 alpha=0.057
# [train] episode=490 step=62790 return=-290.96 success=False time=75.1s geometry=cross_stream history=12 | q1=169.682 actor=83.157 alpha=0.057
# [train] episode=495 step=63624 return=-260.52 success=False time=31.0s geometry=cross_stream history=12 | q1=102.453 actor=84.221 alpha=0.057
# [train] episode=500 step=64614 return=-259.69 success=False time=78.3s geometry=cross_stream history=12 | q1=9.476 actor=87.477 alpha=0.057
# [train] episode=505 step=65628 return=-342.53 success=False time=51.0s geometry=cross_stream history=12 | q1=580.867 actor=95.162 alpha=0.058
# [train] episode=510 step=66828 return=-373.95 success=False time=141.3s geometry=cross_stream history=12 | q1=337.418 actor=87.062 alpha=0.058
# [train] episode=515 step=67380 return=-253.96 success=False time=7.4s geometry=cross_stream history=12 | q1=418.579 actor=93.969 alpha=0.057
# [train] episode=520 step=67944 return=-411.59 success=False time=76.7s geometry=cross_stream history=12 | q1=129.484 actor=88.034 alpha=0.058
# [train] episode=525 step=69000 return=-290.36 success=False time=49.2s geometry=cross_stream history=12 | q1=246.469 actor=90.302 alpha=0.058
# [train] episode=530 step=69636 return=-223.26 success=False time=166.4s geometry=cross_stream history=12 | q1=176.520 actor=88.328 alpha=0.059
# [train] episode=535 step=70956 return=-461.74 success=False time=75.4s geometry=cross_stream history=12 | q1=295.084 actor=95.447 alpha=0.063
# [train] episode=540 step=71994 return=-450.77 success=False time=85.8s geometry=cross_stream history=12 | q1=366.967 actor=85.981 alpha=0.062
# [train] episode=545 step=72504 return=-176.23 success=False time=177.6s geometry=cross_stream history=12 | q1=97.521 actor=98.554 alpha=0.063
# [train] episode=550 step=72888 return=-235.08 success=False time=63.9s geometry=cross_stream history=12 | q1=221.386 actor=87.583 alpha=0.063
# [train] episode=555 step=73356 return=-427.96 success=False time=70.1s geometry=cross_stream history=12 | q1=127.414 actor=92.392 alpha=0.062
# [train] episode=560 step=74838 return=-411.33 success=False time=101.8s geometry=cross_stream history=12 | q1=48.911 actor=99.056 alpha=0.064
# [eval] step=75000 objective=arrival_v2 return=-246.36 safety=17.077 success=6.67% time=105.2s energy=66113.5 path=115.3 prog=-0.48
# [train] episode=565 step=75726 return=-234.50 success=False time=234.6s geometry=cross_stream history=12 | q1=281.390 actor=94.455 alpha=0.063
# [train] episode=570 step=76812 return=-411.50 success=False time=67.7s geometry=cross_stream history=12 | q1=53.213 actor=95.885 alpha=0.062
# [train] episode=575 step=78138 return=-413.81 success=False time=82.1s geometry=cross_stream history=12 | q1=323.087 actor=95.962 alpha=0.064
# [train] episode=580 step=78576 return=-237.48 success=False time=24.2s geometry=cross_stream history=12 | q1=135.964 actor=97.425 alpha=0.064
# [train] episode=585 step=79572 return=-225.60 success=False time=22.9s geometry=cross_stream history=12 | q1=248.254 actor=93.570 alpha=0.063
# [train] episode=590 step=80298 return=-312.65 success=False time=56.1s geometry=cross_stream history=12 | q1=41.731 actor=92.443 alpha=0.063
# [train] episode=595 step=81156 return=-161.08 success=False time=240.1s geometry=cross_stream history=12 | q1=147.032 actor=86.507 alpha=0.063
# [train] episode=600 step=82038 return=-195.07 success=False time=130.8s geometry=cross_stream history=12 | q1=5.642 actor=96.927 alpha=0.063
# [train] episode=605 step=83034 return=-247.22 success=False time=27.5s geometry=cross_stream history=12 | q1=201.596 actor=96.680 alpha=0.063
# [train] episode=610 step=84264 return=-90.34 success=False time=240.1s geometry=cross_stream history=12 | q1=83.076 actor=96.673 alpha=0.063
# [train] episode=615 step=85386 return=-276.40 success=False time=40.6s geometry=cross_stream history=12 | q1=21.433 actor=95.788 alpha=0.060
# [train] episode=620 step=87114 return=-55.05 success=False time=240.1s geometry=cross_stream history=12 | q1=357.944 actor=102.291 alpha=0.060
# [train] episode=625 step=88176 return=138.94 success=True time=76.9s geometry=cross_stream history=12 | q1=8.848 actor=100.439 alpha=0.059
# [train] episode=630 step=89298 return=-250.86 success=False time=49.6s geometry=cross_stream history=12 | q1=34.140 actor=94.865 alpha=0.056
# [train] episode=635 step=90828 return=-77.87 success=False time=240.1s geometry=cross_stream history=12 | q1=142.416 actor=98.896 alpha=0.055
# [train] episode=640 step=92190 return=-90.27 success=False time=240.1s geometry=cross_stream history=12 | q1=77.543 actor=98.427 alpha=0.054
# [train] episode=645 step=94014 return=-194.61 success=False time=181.4s geometry=cross_stream history=12 | q1=120.347 actor=94.072 alpha=0.055
# [train] episode=650 step=94980 return=-235.91 success=False time=18.0s geometry=cross_stream history=12 | q1=7.816 actor=97.046 alpha=0.054
# [train] episode=655 step=96612 return=-204.17 success=False time=240.1s geometry=cross_stream history=12 | q1=94.306 actor=95.812 alpha=0.053
# [train] episode=660 step=97296 return=-261.63 success=False time=12.2s geometry=cross_stream history=12 | q1=320.243 actor=95.124 alpha=0.052
# [train] episode=665 step=98262 return=-265.13 success=False time=23.3s geometry=cross_stream history=12 | q1=145.084 actor=100.470 alpha=0.051
# [train] episode=670 step=99252 return=-152.81 success=False time=168.9s geometry=cross_stream history=12 | q1=75.818 actor=97.804 alpha=0.052
# [eval] step=100002 objective=arrival_v2 return=-290.41 safety=23.976 success=0.00% time=104.6s energy=53360.9 path=83.0 prog=-0.46
# [train] episode=675 step=101184 return=-552.22 success=False time=100.4s geometry=cross_stream history=12 | q1=175.826 actor=102.181 alpha=0.053
# [train] episode=680 step=102936 return=-326.77 success=False time=65.2s geometry=cross_stream history=12 | q1=104.113 actor=101.339 alpha=0.054
# [train] episode=685 step=104166 return=-259.71 success=False time=240.1s geometry=cross_stream history=12 | q1=71.624 actor=99.683 alpha=0.055
# [train] episode=690 step=104736 return=-203.10 success=False time=106.1s geometry=cross_stream history=12 | q1=160.175 actor=101.725 alpha=0.055
# [train] episode=695 step=106200 return=-273.16 success=False time=200.8s geometry=cross_stream history=12 | q1=41.757 actor=92.546 alpha=0.056
# [train] episode=700 step=107394 return=-319.95 success=False time=53.6s geometry=cross_stream history=12 | q1=101.503 actor=102.392 alpha=0.055
# [train] episode=705 step=109098 return=-291.56 success=False time=147.0s geometry=cross_stream history=12 | q1=142.118 actor=108.512 alpha=0.054
# [train] episode=710 step=109434 return=-222.66 success=False time=24.0s geometry=cross_stream history=12 | q1=92.412 actor=102.584 alpha=0.054
# [train] episode=715 step=110676 return=-263.81 success=False time=119.3s geometry=cross_stream history=12 | q1=43.081 actor=102.397 alpha=0.055
# [train] episode=720 step=111960 return=-323.88 success=False time=106.5s geometry=cross_stream history=12 | q1=83.236 actor=100.044 alpha=0.055
# [train] episode=725 step=112974 return=-254.32 success=False time=6.2s geometry=cross_stream history=12 | q1=54.329 actor=98.301 alpha=0.055
# [train] episode=730 step=114390 return=-376.53 success=False time=201.8s geometry=cross_stream history=12 | q1=4.279 actor=100.950 alpha=0.053
# [train] episode=735 step=115536 return=-240.40 success=False time=12.0s geometry=cross_stream history=12 | q1=126.663 actor=100.448 alpha=0.052
# [train] episode=740 step=116310 return=-290.60 success=False time=56.8s geometry=cross_stream history=12 | q1=227.427 actor=98.861 alpha=0.053
# [train] episode=745 step=117186 return=-354.24 success=False time=72.4s geometry=cross_stream history=12 | q1=74.522 actor=101.090 alpha=0.053
# [train] episode=750 step=118518 return=-251.71 success=False time=128.4s geometry=cross_stream history=12 | q1=126.930 actor=97.554 alpha=0.055
# [train] episode=755 step=119340 return=-246.52 success=False time=17.3s geometry=cross_stream history=12 | q1=310.597 actor=100.414 alpha=0.055
# [train] episode=760 step=120720 return=-269.76 success=False time=240.1s geometry=cross_stream history=12 | q1=139.123 actor=102.377 alpha=0.056
# [train] episode=765 step=121890 return=-323.66 success=False time=194.4s geometry=cross_stream history=12 | q1=86.110 actor=101.658 alpha=0.054
# [train] episode=770 step=123612 return=-267.29 success=False time=240.1s geometry=cross_stream history=12 | q1=172.924 actor=100.633 alpha=0.054
# [eval] step=125004 objective=arrival_v2 return=-269.22 safety=19.751 success=0.00% time=119.8s energy=69951.0 path=100.0 prog=-0.34
# [train] episode=775 step=125076 return=-395.42 success=False time=76.2s geometry=cross_stream history=12 | q1=88.767 actor=102.584 alpha=0.055
# [train] episode=780 step=126852 return=-211.97 success=False time=207.3s geometry=cross_stream history=12 | q1=139.061 actor=104.385 alpha=0.055
# [train] episode=785 step=128706 return=-356.90 success=False time=113.0s geometry=cross_stream history=12 | q1=173.031 actor=102.413 alpha=0.055
# [train] episode=790 step=129570 return=-235.96 success=False time=15.2s geometry=cross_stream history=12 | q1=78.923 actor=102.161 alpha=0.054
# [train] episode=795 step=130782 return=-260.96 success=False time=31.9s geometry=cross_stream history=12 | q1=344.780 actor=102.705 alpha=0.055
# [train] episode=800 step=132120 return=-114.68 success=False time=240.1s geometry=cross_stream history=12 | q1=181.912 actor=101.608 alpha=0.053
# [train] episode=805 step=132792 return=-207.25 success=False time=80.7s geometry=cross_stream history=12 | q1=200.861 actor=104.152 alpha=0.052
# [train] episode=810 step=133476 return=-236.94 success=False time=16.7s geometry=cross_stream history=12 | q1=118.052 actor=101.518 alpha=0.051
# [train] episode=815 step=134994 return=-335.53 success=False time=232.1s geometry=cross_stream history=12 | q1=115.870 actor=105.553 alpha=0.049
# [train] episode=820 step=136686 return=-250.93 success=False time=11.7s geometry=cross_stream history=12 | q1=130.027 actor=108.316 alpha=0.052
# [train] episode=825 step=138720 return=-130.40 success=False time=240.1s geometry=cross_stream history=12 | q1=73.736 actor=105.541 alpha=0.050
# [train] episode=830 step=139884 return=-128.97 success=False time=240.1s geometry=cross_stream history=12 | q1=199.224 actor=104.751 alpha=0.050
# [train] episode=835 step=141084 return=-451.70 success=False time=99.5s geometry=cross_stream history=12 | q1=25.562 actor=112.083 alpha=0.051
# [train] episode=840 step=141612 return=139.76 success=True time=169.8s geometry=cross_stream history=12 | q1=156.381 actor=110.398 alpha=0.051
# [train] episode=845 step=143514 return=-148.22 success=False time=240.1s geometry=cross_stream history=12 | q1=53.579 actor=102.534 alpha=0.052
# [train] episode=850 step=144348 return=-79.32 success=False time=240.1s geometry=cross_stream history=12 | q1=137.299 actor=105.528 alpha=0.052
# [train] episode=855 step=145314 return=-207.16 success=False time=90.9s geometry=cross_stream history=12 | q1=277.831 actor=98.994 alpha=0.053
# [train] episode=860 step=146670 return=-406.70 success=False time=86.7s geometry=cross_stream history=12 | q1=186.346 actor=105.418 alpha=0.053
# [train] episode=865 step=147894 return=-103.83 success=False time=240.1s geometry=cross_stream history=12 | q1=135.126 actor=111.956 alpha=0.054
# [train] episode=870 step=149772 return=-175.03 success=False time=203.2s geometry=cross_stream history=12 | q1=171.988 actor=101.162 alpha=0.055
# [eval] step=150000 objective=arrival_v2 return=-173.34 safety=15.420 success=13.33% time=131.2s energy=85203.6 path=100.6 prog=-0.05
# [train] episode=875 step=150996 return=133.31 success=True time=75.3s geometry=cross_stream history=12 | q1=101.821 actor=97.825 alpha=0.056
# [train] episode=880 step=151986 return=-256.24 success=False time=42.6s geometry=cross_stream history=12 | q1=31.064 actor=103.442 alpha=0.057
# [train] episode=885 step=153912 return=-364.18 success=False time=240.1s geometry=cross_stream history=12 | q1=149.780 actor=112.982 alpha=0.057
# [train] episode=890 step=154854 return=-374.92 success=False time=77.7s geometry=cross_stream history=12 | q1=45.340 actor=101.517 alpha=0.057
# [train] episode=895 step=156186 return=128.11 success=True time=110.2s geometry=cross_stream history=12 | q1=64.788 actor=106.603 alpha=0.060
# [train] episode=900 step=157386 return=-246.67 success=False time=17.7s geometry=cross_stream history=12 | q1=174.912 actor=105.613 alpha=0.061
# [train] episode=905 step=158934 return=-340.39 success=False time=228.3s geometry=cross_stream history=12 | q1=68.874 actor=105.873 alpha=0.062
# [train] episode=910 step=160044 return=139.59 success=True time=70.4s geometry=cross_stream history=12 | q1=35.942 actor=102.705 alpha=0.061
# [train] episode=915 step=161532 return=-80.98 success=False time=240.1s geometry=cross_stream history=12 | q1=4.595 actor=102.969 alpha=0.060
# [train] episode=920 step=164274 return=-131.14 success=False time=240.1s geometry=cross_stream history=12 | q1=162.702 actor=103.373 alpha=0.060
# [train] episode=925 step=164958 return=-472.30 success=False time=108.2s geometry=cross_stream history=12 | q1=38.273 actor=101.727 alpha=0.060
# [train] episode=930 step=165924 return=-67.97 success=False time=240.1s geometry=cross_stream history=12 | q1=346.608 actor=102.545 alpha=0.059
# [train] episode=935 step=167190 return=137.61 success=True time=89.4s geometry=cross_stream history=12 | q1=38.280 actor=104.258 alpha=0.058
# [train] episode=940 step=168288 return=-54.12 success=False time=240.1s geometry=cross_stream history=12 | q1=81.022 actor=107.481 alpha=0.058
# [train] episode=945 step=169728 return=-254.78 success=False time=14.0s geometry=cross_stream history=12 | q1=85.786 actor=103.617 alpha=0.058
# [train] episode=950 step=170484 return=-231.91 success=False time=12.4s geometry=cross_stream history=12 | q1=68.876 actor=108.906 alpha=0.057
# [train] episode=955 step=171396 return=-251.40 success=False time=29.4s geometry=cross_stream history=12 | q1=45.323 actor=105.230 alpha=0.057
# [train] episode=960 step=173748 return=138.82 success=True time=62.4s geometry=cross_stream history=12 | q1=122.549 actor=105.115 alpha=0.056
# [train] episode=965 step=174294 return=-251.77 success=False time=33.5s geometry=cross_stream history=12 | q1=8.302 actor=103.619 alpha=0.055
# [eval] step=175002 objective=arrival_v2 return=-116.19 safety=15.504 success=36.67% time=97.2s energy=68520.9 path=84.7 prog=0.10
# [train] episode=970 step=175380 return=-271.30 success=False time=135.3s geometry=cross_stream history=12 | q1=72.696 actor=105.294 alpha=0.054
# [train] episode=975 step=176568 return=94.24 success=True time=91.8s geometry=cross_stream history=12 | q1=121.331 actor=106.578 alpha=0.054
# [train] episode=980 step=177912 return=-253.10 success=False time=10.4s geometry=cross_stream history=12 | q1=5.593 actor=102.859 alpha=0.054
# [train] episode=985 step=178542 return=140.82 success=True time=37.3s geometry=cross_stream history=12 | q1=26.913 actor=102.143 alpha=0.053
# [train] episode=990 step=179784 return=-101.21 success=False time=240.1s geometry=cross_stream history=12 | q1=5.760 actor=103.824 alpha=0.053
# [train] episode=995 step=181032 return=-81.09 success=False time=240.1s geometry=cross_stream history=12 | q1=111.943 actor=104.205 alpha=0.053
# [train] episode=1000 step=183126 return=-217.91 success=False time=73.2s geometry=cross_stream history=12 | q1=125.091 actor=101.361 alpha=0.054
# [train] episode=1005 step=184626 return=134.95 success=True time=231.2s geometry=cross_stream history=12 | q1=86.159 actor=103.041 alpha=0.053
# [train] episode=1010 step=186102 return=98.23 success=True time=58.8s geometry=cross_stream history=12 | q1=91.126 actor=106.981 alpha=0.052
# [train] episode=1015 step=186900 return=112.30 success=True time=182.3s geometry=cross_stream history=12 | q1=74.198 actor=107.649 alpha=0.052
# [train] episode=1020 step=187860 return=131.62 success=True time=56.7s geometry=cross_stream history=12 | q1=7.531 actor=112.253 alpha=0.052
# [train] episode=1025 step=189456 return=-58.15 success=False time=240.1s geometry=cross_stream history=12 | q1=5.456 actor=107.188 alpha=0.054
# [train] episode=1030 step=191418 return=136.11 success=True time=235.4s geometry=cross_stream history=12 | q1=95.812 actor=104.061 alpha=0.053
# [train] episode=1035 step=192750 return=142.85 success=True time=32.8s geometry=cross_stream history=12 | q1=43.621 actor=107.401 alpha=0.054
# [train] episode=1040 step=194256 return=111.40 success=True time=158.1s geometry=cross_stream history=12 | q1=25.626 actor=104.117 alpha=0.052
# [train] episode=1045 step=194874 return=-249.41 success=False time=25.2s geometry=cross_stream history=12 | q1=61.084 actor=107.679 alpha=0.051
# [train] episode=1050 step=196248 return=-45.88 success=False time=240.1s geometry=cross_stream history=12 | q1=37.684 actor=105.838 alpha=0.052
# [train] episode=1055 step=197676 return=-228.66 success=False time=26.5s geometry=cross_stream history=12 | q1=24.754 actor=106.374 alpha=0.054
# [train] episode=1060 step=198504 return=-60.60 success=False time=240.1s geometry=cross_stream history=12 | q1=120.471 actor=103.432 alpha=0.054
# [eval] step=200004 objective=arrival_v2 return=-78.41 safety=13.784 success=26.67% time=130.8s energy=94219.0 path=84.7 prog=0.60
# [train] episode=1065 step=200256 return=57.76 success=True time=184.8s geometry=cross_stream history=12 | q1=8.893 actor=103.374 alpha=0.053
# [train] episode=1070 step=201150 return=139.94 success=True time=120.1s geometry=cross_stream history=12 | q1=173.791 actor=108.112 alpha=0.052
# [train] episode=1075 step=202530 return=-257.91 success=False time=5.8s geometry=cross_stream history=12 | q1=115.092 actor=106.922 alpha=0.050
# [train] episode=1080 step=203634 return=-247.99 success=False time=6.0s geometry=cross_stream history=12 | q1=57.926 actor=106.043 alpha=0.050
# [train] episode=1085 step=204042 return=-262.50 success=False time=33.2s geometry=cross_stream history=12 | q1=141.360 actor=99.205 alpha=0.050
# [train] episode=1090 step=204942 return=95.81 success=True time=99.8s geometry=cross_stream history=12 | q1=15.060 actor=97.432 alpha=0.050
# [train] episode=1095 step=205584 return=140.22 success=True time=72.0s geometry=cross_stream history=12 | q1=33.503 actor=101.196 alpha=0.049
# [train] episode=1100 step=207468 return=-75.42 success=False time=240.1s geometry=cross_stream history=12 | q1=30.920 actor=101.201 alpha=0.049
# [train] episode=1105 step=208860 return=125.91 success=True time=140.8s geometry=cross_stream history=12 | q1=15.461 actor=98.282 alpha=0.049
# [train] episode=1110 step=209982 return=142.25 success=True time=67.9s geometry=cross_stream history=12 | q1=62.129 actor=105.794 alpha=0.050
# [train] episode=1115 step=210882 return=135.36 success=True time=92.6s geometry=cross_stream history=12 | q1=64.022 actor=101.261 alpha=0.050
# [train] episode=1120 step=212976 return=-157.41 success=False time=232.6s geometry=cross_stream history=12 | q1=117.439 actor=95.732 alpha=0.053
# [train] episode=1125 step=214656 return=-47.11 success=False time=240.1s geometry=cross_stream history=12 | q1=13.830 actor=98.606 alpha=0.054
# [train] episode=1130 step=215376 return=-255.26 success=False time=28.5s geometry=cross_stream history=12 | q1=48.562 actor=102.416 alpha=0.054
# [train] episode=1135 step=216150 return=-242.32 success=False time=36.3s geometry=cross_stream history=12 | q1=16.988 actor=105.016 alpha=0.054
# [train] episode=1140 step=217476 return=139.53 success=True time=144.8s geometry=cross_stream history=12 | q1=14.964 actor=106.557 alpha=0.052
# [train] episode=1145 step=218724 return=141.99 success=True time=94.7s geometry=cross_stream history=12 | q1=41.929 actor=104.170 alpha=0.051
# [train] episode=1150 step=219954 return=-92.34 success=False time=240.1s geometry=cross_stream history=12 | q1=136.461 actor=96.329 alpha=0.050
# [train] episode=1155 step=221616 return=-152.59 success=False time=240.1s geometry=cross_stream history=12 | q1=45.120 actor=98.839 alpha=0.051
# [train] episode=1160 step=222726 return=132.93 success=True time=76.7s geometry=cross_stream history=12 | q1=143.434 actor=104.474 alpha=0.051
# [train] episode=1165 step=223968 return=-243.28 success=False time=36.1s geometry=cross_stream history=12 | q1=74.643 actor=103.716 alpha=0.050
# [train] episode=1170 step=224682 return=-45.22 success=False time=240.1s geometry=cross_stream history=12 | q1=3.974 actor=103.785 alpha=0.050
# [eval] step=225000 objective=arrival_v2 return=-139.45 safety=29.051 success=16.67% time=145.3s energy=100993.0 path=87.4 prog=0.52
# [train] episode=1175 step=226800 return=127.33 success=True time=176.0s geometry=cross_stream history=12 | q1=166.820 actor=104.494 alpha=0.051
# [train] episode=1180 step=228078 return=-72.39 success=False time=240.1s geometry=cross_stream history=12 | q1=133.547 actor=102.868 alpha=0.052
# [train] episode=1185 step=228996 return=-98.44 success=False time=240.1s geometry=cross_stream history=12 | q1=98.655 actor=100.438 alpha=0.052
# [train] episode=1190 step=230838 return=-78.14 success=False time=240.1s geometry=cross_stream history=12 | q1=71.990 actor=103.239 alpha=0.052
# [train] episode=1195 step=232140 return=-257.13 success=False time=107.6s geometry=cross_stream history=12 | q1=122.375 actor=95.595 alpha=0.050
# [train] episode=1200 step=233028 return=-267.02 success=False time=13.6s geometry=cross_stream history=12 | q1=13.788 actor=96.457 alpha=0.050
# [train] episode=1205 step=234306 return=-250.02 success=False time=17.3s geometry=cross_stream history=12 | q1=20.843 actor=95.879 alpha=0.051
# [train] episode=1210 step=235920 return=-43.76 success=False time=240.1s geometry=cross_stream history=12 | q1=139.366 actor=100.549 alpha=0.053
# [train] episode=1215 step=236802 return=-285.39 success=False time=42.8s geometry=cross_stream history=12 | q1=54.124 actor=101.878 alpha=0.052
# [train] episode=1220 step=237726 return=-389.40 success=False time=83.1s geometry=cross_stream history=12 | q1=171.846 actor=102.556 alpha=0.052
# [train] episode=1225 step=239694 return=-202.71 success=False time=240.1s geometry=cross_stream history=12 | q1=165.380 actor=96.245 alpha=0.053
# [train] episode=1230 step=240618 return=-50.94 success=False time=240.1s geometry=cross_stream history=12 | q1=137.595 actor=100.860 alpha=0.053
# [train] episode=1235 step=241080 return=-238.79 success=False time=37.6s geometry=cross_stream history=12 | q1=134.515 actor=102.266 alpha=0.053
# [train] episode=1240 step=241962 return=-232.50 success=False time=36.3s geometry=cross_stream history=12 | q1=135.496 actor=101.705 alpha=0.054
# [train] episode=1245 step=242892 return=-323.24 success=False time=53.6s geometry=cross_stream history=12 | q1=62.712 actor=104.248 alpha=0.053
# [train] episode=1250 step=244350 return=-239.48 success=False time=37.5s geometry=cross_stream history=12 | q1=205.232 actor=96.637 alpha=0.054
# [train] episode=1255 step=245130 return=132.41 success=True time=152.4s geometry=cross_stream history=12 | q1=28.172 actor=101.249 alpha=0.055
# [train] episode=1260 step=246126 return=134.25 success=True time=50.0s geometry=cross_stream history=12 | q1=29.772 actor=95.936 alpha=0.057
# [train] episode=1265 step=246960 return=133.29 success=True time=68.8s geometry=cross_stream history=12 | q1=107.790 actor=90.871 alpha=0.056
# [train] episode=1270 step=247710 return=141.60 success=True time=80.5s geometry=cross_stream history=12 | q1=4.721 actor=102.984 alpha=0.055
# [train] episode=1275 step=249864 return=-152.55 success=False time=240.1s geometry=cross_stream history=12 | q1=8.486 actor=101.370 alpha=0.053
# [eval] step=250002 objective=arrival_v2 return=-75.48 safety=13.748 success=23.33% time=139.8s energy=97784.9 path=82.8 prog=0.63
# [train] episode=1280 step=250362 return=-346.39 success=False time=65.6s geometry=cross_stream history=12 | q1=124.157 actor=95.222 alpha=0.053
# [train] episode=1285 step=251178 return=137.27 success=True time=67.4s geometry=cross_stream history=12 | q1=45.773 actor=97.017 alpha=0.053
# [train] episode=1290 step=252150 return=-256.16 success=False time=7.5s geometry=cross_stream history=12 | q1=212.210 actor=95.850 alpha=0.052
# [train] episode=1295 step=252924 return=-245.74 success=False time=37.1s geometry=cross_stream history=12 | q1=13.091 actor=94.167 alpha=0.053
# [train] episode=1300 step=253824 return=137.89 success=True time=74.3s geometry=cross_stream history=12 | q1=80.250 actor=101.308 alpha=0.054
# [train] episode=1305 step=254658 return=-255.01 success=False time=11.6s geometry=cross_stream history=12 | q1=3.535 actor=101.626 alpha=0.054
# [train] episode=1310 step=255480 return=138.90 success=True time=43.3s geometry=cross_stream history=12 | q1=66.495 actor=96.512 alpha=0.054
# [train] episode=1315 step=256428 return=-429.54 success=False time=85.7s geometry=cross_stream history=12 | q1=5.341 actor=93.800 alpha=0.055
# [train] episode=1320 step=257202 return=133.14 success=True time=142.9s geometry=cross_stream history=12 | q1=188.966 actor=97.392 alpha=0.057
# [train] episode=1325 step=258114 return=126.93 success=True time=74.2s geometry=cross_stream history=12 | q1=123.691 actor=90.480 alpha=0.057
# [train] episode=1330 step=259098 return=-64.77 success=False time=240.1s geometry=cross_stream history=12 | q1=6.337 actor=94.349 alpha=0.057
# [train] episode=1335 step=260334 return=123.47 success=True time=54.6s geometry=cross_stream history=12 | q1=141.478 actor=89.486 alpha=0.057
# [train] episode=1340 step=261744 return=-168.94 success=False time=240.1s geometry=cross_stream history=12 | q1=21.931 actor=97.434 alpha=0.059
# [train] episode=1345 step=263226 return=-350.15 success=False time=240.1s geometry=cross_stream history=12 | q1=87.251 actor=91.640 alpha=0.058
# [train] episode=1350 step=263802 return=-204.39 success=False time=35.8s geometry=cross_stream history=12 | q1=60.712 actor=97.620 alpha=0.056
# [train] episode=1355 step=264972 return=-255.59 success=False time=16.0s geometry=cross_stream history=12 | q1=145.731 actor=96.985 alpha=0.055
# [train] episode=1360 step=265278 return=-260.66 success=False time=7.1s geometry=cross_stream history=12 | q1=145.733 actor=91.308 alpha=0.054
# [train] episode=1365 step=266580 return=105.66 success=True time=116.8s geometry=cross_stream history=12 | q1=5.404 actor=96.041 alpha=0.054
# [train] episode=1370 step=268152 return=138.28 success=True time=134.8s geometry=cross_stream history=12 | q1=2.774 actor=93.307 alpha=0.056
# [train] episode=1375 step=269532 return=-152.77 success=False time=240.1s geometry=cross_stream history=12 | q1=98.812 actor=96.487 alpha=0.055
# [train] episode=1380 step=270312 return=142.01 success=True time=62.4s geometry=cross_stream history=12 | q1=103.845 actor=98.544 alpha=0.054
# [train] episode=1385 step=271140 return=134.64 success=True time=109.6s geometry=cross_stream history=12 | q1=5.568 actor=94.674 alpha=0.055
# [train] episode=1390 step=272166 return=139.99 success=True time=116.4s geometry=cross_stream history=12 | q1=4.182 actor=96.602 alpha=0.054
# [train] episode=1395 step=273132 return=131.79 success=True time=79.8s geometry=cross_stream history=12 | q1=3.357 actor=92.186 alpha=0.054
# [train] episode=1400 step=273846 return=139.60 success=True time=58.7s geometry=cross_stream history=12 | q1=10.099 actor=93.679 alpha=0.054
# [train] episode=1405 step=274704 return=144.06 success=True time=28.2s geometry=cross_stream history=12 | q1=234.522 actor=94.053 alpha=0.053
# [eval] step=275004 objective=arrival_v2 return=-13.28 safety=18.415 success=56.67% time=105.6s energy=78792.3 path=68.9 prog=0.74
# [train] episode=1410 step=275940 return=138.52 success=True time=104.5s geometry=cross_stream history=12 | q1=30.689 actor=93.044 alpha=0.053
# [train] episode=1415 step=276552 return=-232.71 success=False time=27.1s geometry=cross_stream history=12 | q1=196.389 actor=100.376 alpha=0.053
# [train] episode=1420 step=277332 return=131.16 success=True time=103.7s geometry=cross_stream history=12 | q1=159.519 actor=94.789 alpha=0.052
# [train] episode=1425 step=278220 return=142.26 success=True time=73.4s geometry=cross_stream history=12 | q1=37.901 actor=96.195 alpha=0.052
# [train] episode=1430 step=278934 return=117.84 success=True time=105.4s geometry=cross_stream history=12 | q1=74.407 actor=92.269 alpha=0.054
# [train] episode=1435 step=280398 return=128.69 success=True time=137.5s geometry=cross_stream history=12 | q1=138.876 actor=87.565 alpha=0.055
# [train] episode=1440 step=281454 return=-87.18 success=False time=240.1s geometry=cross_stream history=12 | q1=91.521 actor=88.512 alpha=0.055
# [train] episode=1445 step=282624 return=-231.93 success=False time=32.1s geometry=cross_stream history=12 | q1=179.503 actor=93.518 alpha=0.055
# [train] episode=1450 step=283368 return=121.17 success=True time=105.6s geometry=cross_stream history=12 | q1=43.891 actor=92.762 alpha=0.054
# [train] episode=1455 step=284532 return=100.61 success=True time=105.4s geometry=cross_stream history=12 | q1=175.031 actor=94.467 alpha=0.056
# [train] episode=1460 step=286080 return=-103.08 success=False time=240.1s geometry=cross_stream history=12 | q1=55.012 actor=90.686 alpha=0.056
# [train] episode=1465 step=286974 return=140.44 success=True time=89.8s geometry=cross_stream history=12 | q1=65.240 actor=86.735 alpha=0.058
# [train] episode=1470 step=288282 return=136.02 success=True time=140.0s geometry=cross_stream history=12 | q1=214.240 actor=86.809 alpha=0.059
# [train] episode=1475 step=289116 return=-252.86 success=False time=8.4s geometry=cross_stream history=12 | q1=120.441 actor=92.581 alpha=0.058
# [train] episode=1480 step=290334 return=-123.92 success=False time=240.1s geometry=cross_stream history=12 | q1=194.185 actor=87.888 alpha=0.058
# [train] episode=1485 step=291444 return=143.33 success=True time=46.1s geometry=cross_stream history=12 | q1=4.168 actor=85.273 alpha=0.057
# [train] episode=1490 step=292386 return=142.00 success=True time=48.8s geometry=cross_stream history=12 | q1=31.837 actor=89.727 alpha=0.057
# [train] episode=1495 step=292638 return=99.55 success=True time=162.9s geometry=cross_stream history=12 | q1=5.304 actor=83.978 alpha=0.058
# [train] episode=1500 step=292968 return=-235.24 success=False time=38.3s geometry=cross_stream history=12 | q1=22.825 actor=92.065 alpha=0.058
# [train] episode=1505 step=294108 return=-251.47 success=False time=35.7s geometry=cross_stream history=12 | q1=76.422 actor=85.970 alpha=0.059
# [train] episode=1510 step=295308 return=140.54 success=True time=108.1s geometry=cross_stream history=12 | q1=111.469 actor=86.490 alpha=0.060
# [train] episode=1515 step=296136 return=-244.34 success=False time=22.2s geometry=cross_stream history=12 | q1=64.048 actor=89.293 alpha=0.059
# [train] episode=1520 step=296910 return=138.93 success=True time=118.9s geometry=cross_stream history=12 | q1=22.534 actor=90.138 alpha=0.059
# [train] episode=1525 step=298320 return=120.78 success=True time=147.5s geometry=cross_stream history=12 | q1=54.914 actor=87.708 alpha=0.058
# [train] episode=1530 step=298902 return=105.03 success=True time=57.1s geometry=cross_stream history=12 | q1=74.949 actor=89.210 alpha=0.060
# [train] episode=1535 step=299700 return=121.62 success=True time=87.0s geometry=cross_stream history=12 | q1=20.209 actor=86.145 alpha=0.060
# [eval] step=300000 objective=arrival_v2 return=18.47 safety=19.017 success=73.33% time=83.9s energy=66562.6 path=65.4 prog=0.75
# [train] episode=1540 step=300288 return=143.08 success=True time=52.9s geometry=cross_stream history=12 | q1=209.097 actor=87.252 alpha=0.058
# [train] episode=1545 step=300912 return=129.64 success=True time=81.2s geometry=cross_stream history=12 | q1=5.810 actor=87.020 alpha=0.058
# [train] episode=1550 step=301956 return=131.36 success=True time=96.9s geometry=cross_stream history=12 | q1=3.385 actor=88.925 alpha=0.057
# [train] episode=1555 step=302796 return=127.94 success=True time=151.9s geometry=cross_stream history=12 | q1=159.546 actor=90.709 alpha=0.058
# [train] episode=1560 step=304050 return=135.25 success=True time=135.2s geometry=cross_stream history=12 | q1=49.383 actor=87.967 alpha=0.060
# [train] episode=1565 step=304488 return=91.57 success=True time=88.8s geometry=cross_stream history=12 | q1=18.483 actor=91.856 alpha=0.059
# [train] episode=1570 step=305184 return=125.33 success=True time=79.5s geometry=cross_stream history=12 | q1=179.827 actor=86.944 alpha=0.059
# [train] episode=1575 step=306168 return=-251.74 success=False time=40.0s geometry=cross_stream history=12 | q1=109.662 actor=87.997 alpha=0.059
# [train] episode=1580 step=307044 return=136.50 success=True time=72.1s geometry=cross_stream history=12 | q1=6.930 actor=88.096 alpha=0.058
# [train] episode=1585 step=308028 return=136.74 success=True time=130.8s geometry=cross_stream history=12 | q1=193.746 actor=87.462 alpha=0.060
# [train] episode=1590 step=309012 return=-292.75 success=False time=38.1s geometry=cross_stream history=12 | q1=39.105 actor=82.219 alpha=0.062
# [train] episode=1595 step=310740 return=136.20 success=True time=51.1s geometry=cross_stream history=12 | q1=91.016 actor=84.795 alpha=0.061
# [train] episode=1600 step=311256 return=134.21 success=True time=89.3s geometry=cross_stream history=12 | q1=2.985 actor=82.774 alpha=0.061
# [train] episode=1605 step=312252 return=137.77 success=True time=96.8s geometry=cross_stream history=12 | q1=95.807 actor=87.970 alpha=0.063
# [train] episode=1610 step=313272 return=138.14 success=True time=89.9s geometry=cross_stream history=12 | q1=232.928 actor=88.896 alpha=0.063
# [train] episode=1615 step=314340 return=72.33 success=True time=88.4s geometry=cross_stream history=12 | q1=5.629 actor=86.866 alpha=0.064
# [train] episode=1620 step=315444 return=141.18 success=True time=48.2s geometry=cross_stream history=12 | q1=27.173 actor=84.093 alpha=0.064
# [train] episode=1625 step=316392 return=141.01 success=True time=76.5s geometry=cross_stream history=12 | q1=152.773 actor=89.883 alpha=0.065
# [train] episode=1630 step=317562 return=-91.45 success=False time=240.1s geometry=cross_stream history=12 | q1=94.530 actor=86.656 alpha=0.065
# [train] episode=1635 step=318102 return=-116.34 success=False time=240.1s geometry=cross_stream history=12 | q1=23.895 actor=89.658 alpha=0.065
# ...
# [train] episode=5365 step=919698 return=-228.37 success=False time=11.1s geometry=cross_stream history=12 | q1=22.799 actor=23.213 alpha=0.106
# [train] episode=5370 step=920334 return=84.72 success=True time=74.7s geometry=cross_stream history=12 | q1=250.507 actor=20.123 alpha=0.108
# [train] episode=5375 step=921324 return=137.67 success=True time=81.9s geometry=cross_stream history=12 | q1=29.529 actor=34.391 alpha=0.113
# [train] episode=5380 step=922086 return=55.29 success=True time=128.4s geometry=cross_stream history=12 | q1=2.469 actor=27.149 alpha=0.111
# [train] episode=5385 step=922950 return=98.32 success=True time=57.9s geometry=cross_stream history=12 | q1=31.214 actor=28.164 alpha=0.110
# [train] episode=5390 step=923610 return=81.27 success=True time=127.1s geometry=cross_stream history=12 | q1=99.145 actor=23.869 alpha=0.108
# [train] episode=5395 step=924234 return=51.13 success=True time=106.2s geometry=cross_stream history=12 | q1=108.221 actor=35.906 alpha=0.105
# [eval] step=925002 objective=arrival_v2 return=76.31 safety=15.412 success=90.00% time=76.2s energy=62953.1 path=63.1 prog=0.84
# [train] episode=5400 step=925080 return=83.88 success=True time=71.2s geometry=cross_stream history=12 | q1=229.210 actor=26.945 alpha=0.107
# [train] episode=5405 step=925902 return=141.84 success=True time=80.9s geometry=cross_stream history=12 | q1=50.575 actor=26.585 alpha=0.109
# [train] episode=5410 step=926904 return=138.33 success=True time=87.8s geometry=cross_stream history=12 | q1=30.765 actor=25.846 alpha=0.109
# [train] episode=5415 step=927456 return=138.12 success=True time=57.4s geometry=cross_stream history=12 | q1=62.355 actor=28.574 alpha=0.110
# [train] episode=5420 step=928122 return=136.80 success=True time=90.3s geometry=cross_stream history=12 | q1=17.398 actor=25.376 alpha=0.112
# [train] episode=5425 step=928620 return=123.53 success=True time=72.8s geometry=cross_stream history=12 | q1=21.435 actor=22.418 alpha=0.111
# [train] episode=5430 step=929340 return=142.61 success=True time=55.9s geometry=cross_stream history=12 | q1=38.475 actor=31.250 alpha=0.111
# [train] episode=5435 step=929994 return=135.14 success=True time=88.2s geometry=cross_stream history=12 | q1=34.904 actor=29.023 alpha=0.112
# [train] episode=5440 step=930882 return=142.08 success=True time=73.4s geometry=cross_stream history=12 | q1=26.095 actor=29.584 alpha=0.113
# [train] episode=5445 step=931626 return=141.71 success=True time=61.4s geometry=cross_stream history=12 | q1=42.127 actor=32.159 alpha=0.115
# [train] episode=5450 step=932394 return=17.39 success=True time=119.9s geometry=cross_stream history=12 | q1=185.996 actor=23.337 alpha=0.116
# [train] episode=5455 step=933174 return=75.09 success=True time=67.6s geometry=cross_stream history=12 | q1=101.411 actor=28.593 alpha=0.114
# [train] episode=5460 step=933888 return=141.75 success=True time=72.8s geometry=cross_stream history=12 | q1=56.126 actor=21.645 alpha=0.113
# [train] episode=5465 step=934596 return=142.89 success=True time=58.4s geometry=cross_stream history=12 | q1=3.980 actor=24.051 alpha=0.111
# [train] episode=5470 step=935562 return=138.83 success=True time=79.8s geometry=cross_stream history=12 | q1=4.072 actor=29.987 alpha=0.106
# [train] episode=5475 step=936234 return=142.18 success=True time=60.3s geometry=cross_stream history=12 | q1=34.488 actor=16.730 alpha=0.106
# [train] episode=5480 step=936894 return=-255.91 success=False time=7.8s geometry=cross_stream history=12 | q1=159.957 actor=27.766 alpha=0.106
# [train] episode=5485 step=937554 return=127.02 success=True time=97.4s geometry=cross_stream history=12 | q1=311.190 actor=28.705 alpha=0.108
# [train] episode=5490 step=938286 return=141.00 success=True time=69.6s geometry=cross_stream history=12 | q1=89.052 actor=28.137 alpha=0.107
# [train] episode=5495 step=938940 return=142.64 success=True time=61.4s geometry=cross_stream history=12 | q1=13.518 actor=33.534 alpha=0.106
# [train] episode=5500 step=939576 return=139.84 success=True time=50.1s geometry=cross_stream history=12 | q1=80.423 actor=27.385 alpha=0.107
# [train] episode=5505 step=940038 return=142.93 success=True time=84.8s geometry=cross_stream history=12 | q1=30.668 actor=33.283 alpha=0.107
# [train] episode=5510 step=940788 return=137.55 success=True time=64.8s geometry=cross_stream history=12 | q1=54.883 actor=21.939 alpha=0.110
# [train] episode=5515 step=941490 return=-290.02 success=False time=42.7s geometry=cross_stream history=12 | q1=326.359 actor=23.990 alpha=0.110
# [train] episode=5520 step=942624 return=138.89 success=True time=93.9s geometry=cross_stream history=12 | q1=201.442 actor=24.002 alpha=0.112
# [train] episode=5525 step=943404 return=132.28 success=True time=141.6s geometry=cross_stream history=12 | q1=56.018 actor=25.373 alpha=0.115
# [train] episode=5530 step=943902 return=118.00 success=True time=58.5s geometry=cross_stream history=12 | q1=79.562 actor=20.765 alpha=0.113
# [train] episode=5535 step=944934 return=138.91 success=True time=88.3s geometry=cross_stream history=12 | q1=239.716 actor=31.127 alpha=0.112
# [train] episode=5540 step=945822 return=94.73 success=True time=75.8s geometry=cross_stream history=12 | q1=67.912 actor=19.485 alpha=0.113
# [train] episode=5545 step=946512 return=138.75 success=True time=95.7s geometry=cross_stream history=12 | q1=112.910 actor=26.374 alpha=0.110
# [train] episode=5550 step=947016 return=105.08 success=True time=98.5s geometry=cross_stream history=12 | q1=53.000 actor=19.165 alpha=0.109
# [train] episode=5555 step=947934 return=123.04 success=True time=67.7s geometry=cross_stream history=12 | q1=343.248 actor=34.138 alpha=0.111
# [train] episode=5560 step=948588 return=138.29 success=True time=42.9s geometry=cross_stream history=12 | q1=4.093 actor=22.071 alpha=0.114
# [train] episode=5565 step=949200 return=140.65 success=True time=93.0s geometry=cross_stream history=12 | q1=96.301 actor=26.329 alpha=0.112
# [eval] step=950004 objective=arrival_v2 return=90.35 safety=8.455 success=90.00% time=71.6s energy=59740.6 path=61.7 prog=0.84
# [train] episode=5570 step=950214 return=89.75 success=True time=63.9s geometry=cross_stream history=12 | q1=33.729 actor=26.044 alpha=0.113
# [train] episode=5575 step=951090 return=138.52 success=True time=72.5s geometry=cross_stream history=12 | q1=91.660 actor=34.250 alpha=0.110
# [train] episode=5580 step=951720 return=-260.40 success=False time=4.8s geometry=cross_stream history=12 | q1=42.921 actor=18.857 alpha=0.108
# [train] episode=5585 step=952668 return=136.09 success=True time=122.6s geometry=cross_stream history=12 | q1=16.638 actor=27.339 alpha=0.105
# [train] episode=5590 step=953316 return=137.37 success=True time=52.5s geometry=cross_stream history=12 | q1=75.101 actor=30.292 alpha=0.104
# [train] episode=5595 step=953856 return=138.78 success=True time=98.2s geometry=cross_stream history=12 | q1=111.720 actor=27.988 alpha=0.103
# [train] episode=5600 step=954942 return=140.69 success=True time=94.4s geometry=cross_stream history=12 | q1=195.605 actor=20.890 alpha=0.104
# [train] episode=5605 step=955800 return=129.50 success=True time=75.3s geometry=cross_stream history=12 | q1=20.290 actor=28.883 alpha=0.107
# [train] episode=5610 step=956136 return=136.65 success=True time=96.5s geometry=cross_stream history=12 | q1=32.843 actor=20.717 alpha=0.106
# [train] episode=5615 step=957072 return=133.03 success=True time=97.0s geometry=cross_stream history=12 | q1=140.616 actor=29.898 alpha=0.108
# [train] episode=5620 step=958074 return=137.52 success=True time=82.9s geometry=cross_stream history=12 | q1=50.718 actor=20.701 alpha=0.107
# [train] episode=5625 step=958944 return=140.78 success=True time=59.5s geometry=cross_stream history=12 | q1=248.655 actor=30.102 alpha=0.109
# [train] episode=5630 step=959268 return=-329.48 success=False time=55.3s geometry=cross_stream history=12 | q1=326.312 actor=37.246 alpha=0.108
# [train] episode=5635 step=960534 return=137.85 success=True time=107.0s geometry=cross_stream history=12 | q1=45.623 actor=27.764 alpha=0.102
# [train] episode=5640 step=961290 return=142.56 success=True time=61.3s geometry=cross_stream history=12 | q1=353.124 actor=26.317 alpha=0.100
# [train] episode=5645 step=962040 return=133.32 success=True time=79.2s geometry=cross_stream history=12 | q1=5.398 actor=24.608 alpha=0.099
# [train] episode=5650 step=962676 return=136.15 success=True time=60.8s geometry=cross_stream history=12 | q1=22.990 actor=28.391 alpha=0.098
# [train] episode=5655 step=963318 return=137.51 success=True time=79.9s geometry=cross_stream history=12 | q1=156.892 actor=19.249 alpha=0.097
# [train] episode=5660 step=963882 return=100.83 success=True time=63.3s geometry=cross_stream history=12 | q1=109.403 actor=26.497 alpha=0.097
# [train] episode=5665 step=964602 return=127.73 success=True time=65.0s geometry=cross_stream history=12 | q1=266.061 actor=24.710 alpha=0.096
# [train] episode=5670 step=964926 return=140.89 success=True time=97.7s geometry=cross_stream history=12 | q1=42.081 actor=23.833 alpha=0.097
# [train] episode=5675 step=965628 return=138.87 success=True time=64.5s geometry=cross_stream history=12 | q1=25.418 actor=21.647 alpha=0.098
# [train] episode=5680 step=966444 return=141.01 success=True time=67.2s geometry=cross_stream history=12 | q1=91.059 actor=20.819 alpha=0.100
# [train] episode=5685 step=966858 return=142.25 success=True time=58.6s geometry=cross_stream history=12 | q1=247.190 actor=26.700 alpha=0.100
# [train] episode=5690 step=967692 return=-255.42 success=False time=41.2s geometry=cross_stream history=12 | q1=50.835 actor=24.594 alpha=0.100
# [train] episode=5695 step=968580 return=117.51 success=True time=73.3s geometry=cross_stream history=12 | q1=99.951 actor=26.633 alpha=0.101
# [train] episode=5700 step=969012 return=125.55 success=True time=66.3s geometry=cross_stream history=12 | q1=86.219 actor=26.191 alpha=0.100
# [train] episode=5705 step=970002 return=136.04 success=True time=97.9s geometry=cross_stream history=12 | q1=112.872 actor=29.289 alpha=0.102
# [train] episode=5710 step=970524 return=141.06 success=True time=35.9s geometry=cross_stream history=12 | q1=35.643 actor=24.811 alpha=0.102
# [train] episode=5715 step=971226 return=114.92 success=True time=60.9s geometry=cross_stream history=12 | q1=231.102 actor=33.845 alpha=0.100
# [train] episode=5720 step=972432 return=138.18 success=True time=89.9s geometry=cross_stream history=12 | q1=103.881 actor=25.470 alpha=0.099
# [train] episode=5725 step=972762 return=139.02 success=True time=74.6s geometry=cross_stream history=12 | q1=188.366 actor=24.499 alpha=0.099
# [train] episode=5730 step=973818 return=111.20 success=True time=87.3s geometry=cross_stream history=12 | q1=120.207 actor=26.873 alpha=0.101
# [train] episode=5735 step=974310 return=139.18 success=True time=89.5s geometry=cross_stream history=12 | q1=5.933 actor=31.532 alpha=0.102
# [eval] step=975000 objective=arrival_v2 return=88.38 safety=9.423 success=90.00% time=73.2s energy=60714.9 path=62.1 prog=0.84
# [train] episode=5740 step=975204 return=137.82 success=True time=85.2s geometry=cross_stream history=12 | q1=169.297 actor=26.278 alpha=0.104
# [train] episode=5745 step=976206 return=107.65 success=True time=82.7s geometry=cross_stream history=12 | q1=216.625 actor=24.925 alpha=0.104
# [train] episode=5750 step=977124 return=89.80 success=True time=70.8s geometry=cross_stream history=12 | q1=77.080 actor=25.732 alpha=0.106
# [train] episode=5755 step=977760 return=-220.31 success=False time=37.1s geometry=cross_stream history=12 | q1=4.225 actor=28.882 alpha=0.108
# [train] episode=5760 step=978462 return=124.22 success=True time=103.5s geometry=cross_stream history=12 | q1=25.094 actor=23.706 alpha=0.108
# [train] episode=5765 step=979506 return=138.02 success=True time=86.2s geometry=cross_stream history=12 | q1=37.135 actor=20.789 alpha=0.109
# [train] episode=5770 step=979968 return=-241.73 success=False time=37.9s geometry=cross_stream history=12 | q1=45.952 actor=27.357 alpha=0.108
# [train] episode=5775 step=980826 return=142.02 success=True time=78.1s geometry=cross_stream history=12 | q1=35.619 actor=30.203 alpha=0.109
# [train] episode=5780 step=981576 return=138.27 success=True time=61.7s geometry=cross_stream history=12 | q1=181.871 actor=23.996 alpha=0.108
# [train] episode=5785 step=982272 return=-253.69 success=False time=39.6s geometry=cross_stream history=12 | q1=122.124 actor=33.303 alpha=0.108
# [train] episode=5790 step=983022 return=136.18 success=True time=61.6s geometry=cross_stream history=12 | q1=134.344 actor=35.223 alpha=0.108
# [train] episode=5795 step=983472 return=140.55 success=True time=81.9s geometry=cross_stream history=12 | q1=13.413 actor=25.613 alpha=0.108
# [train] episode=5800 step=984030 return=-315.51 success=False time=58.1s geometry=cross_stream history=12 | q1=97.234 actor=20.013 alpha=0.109
# [train] episode=5805 step=984822 return=136.30 success=True time=65.5s geometry=cross_stream history=12 | q1=189.181 actor=27.894 alpha=0.110
# [train] episode=5810 step=985410 return=139.04 success=True time=57.7s geometry=cross_stream history=12 | q1=32.686 actor=25.229 alpha=0.111
# [train] episode=5815 step=986136 return=142.59 success=True time=74.5s geometry=cross_stream history=12 | q1=189.137 actor=25.640 alpha=0.110
# [train] episode=5820 step=986982 return=-243.44 success=False time=10.1s geometry=cross_stream history=12 | q1=6.542 actor=26.838 alpha=0.107
# [train] episode=5825 step=987162 return=-246.06 success=False time=40.6s geometry=cross_stream history=12 | q1=59.829 actor=18.092 alpha=0.107
# [train] episode=5830 step=988272 return=131.19 success=True time=93.8s geometry=cross_stream history=12 | q1=84.835 actor=21.493 alpha=0.105
# [train] episode=5835 step=988776 return=139.65 success=True time=73.2s geometry=cross_stream history=12 | q1=100.840 actor=28.313 alpha=0.105
# [train] episode=5840 step=989676 return=137.01 success=True time=116.2s geometry=cross_stream history=12 | q1=131.943 actor=29.720 alpha=0.107
# [train] episode=5845 step=990486 return=141.46 success=True time=66.4s geometry=cross_stream history=12 | q1=45.850 actor=23.845 alpha=0.109
# [train] episode=5850 step=991350 return=72.49 success=True time=115.0s geometry=cross_stream history=12 | q1=44.256 actor=25.863 alpha=0.112
# [train] episode=5855 step=991956 return=138.54 success=True time=57.0s geometry=cross_stream history=12 | q1=359.347 actor=28.981 alpha=0.111
# [train] episode=5860 step=992664 return=119.06 success=True time=58.4s geometry=cross_stream history=12 | q1=15.041 actor=25.873 alpha=0.110
# [train] episode=5865 step=993198 return=135.29 success=True time=80.5s geometry=cross_stream history=12 | q1=31.211 actor=30.286 alpha=0.109
# [train] episode=5870 step=993780 return=126.78 success=True time=88.0s geometry=cross_stream history=12 | q1=84.567 actor=21.346 alpha=0.108
# [train] episode=5875 step=994572 return=-254.88 success=False time=5.0s geometry=cross_stream history=12 | q1=4.771 actor=27.233 alpha=0.110
# [train] episode=5880 step=995490 return=138.74 success=True time=63.1s geometry=cross_stream history=12 | q1=159.747 actor=28.630 alpha=0.110
# [train] episode=5885 step=996342 return=141.14 success=True time=70.5s geometry=cross_stream history=12 | q1=47.371 actor=26.594 alpha=0.108
# [train] episode=5890 step=996666 return=140.48 success=True time=97.7s geometry=cross_stream history=12 | q1=246.237 actor=26.624 alpha=0.108
# [train] episode=5895 step=997272 return=-213.19 success=False time=36.2s geometry=cross_stream history=12 | q1=240.635 actor=17.408 alpha=0.108
# [train] episode=5900 step=998196 return=141.04 success=True time=76.1s geometry=cross_stream history=12 | q1=16.786 actor=24.093 alpha=0.106
# [train] episode=5905 step=998694 return=137.24 success=True time=37.1s geometry=cross_stream history=12 | q1=41.402 actor=23.567 alpha=0.105
# [train] episode=5910 step=999336 return=116.82 success=True time=72.1s geometry=cross_stream history=12 | q1=38.189 actor=19.981 alpha=0.104

# %% [markdown]
# ## 5. Summary + gate

# %%
def summarize_phase(run_root: Path, total_steps: int, label: str, gate_filename: str):
    eval_log_path = run_root / 'results' / 'eval_log.csv'
    final_eval_path = run_root / 'results' / 'final_eval.json'
    trainer_state_path = run_root / 'trainer_state.json'
    train_config_path = run_root / 'results' / 'train_config.txt'

    if not eval_log_path.exists():
        raise FileNotFoundError(f'missing eval log: {eval_log_path}')
    if not final_eval_path.exists():
        raise FileNotFoundError(f'missing final eval: {final_eval_path}')

    df = pd.read_csv(eval_log_path)
    final_eval = json.loads(final_eval_path.read_text(encoding='utf-8'))
    trainer_state = json.loads(trainer_state_path.read_text(encoding='utf-8')) if trainer_state_path.exists() else {}

    history_from_config = 'NA'
    if train_config_path.exists():
        for ln in train_config_path.read_text(encoding='utf-8').splitlines():
            if ln.strip().startswith('history_length='):
                history_from_config = ln.strip().split('=', 1)[1]
                break

    peak_success = float(df['eval_success_rate'].max()) if len(df) else 0.0
    peak_step = int(df.loc[df['eval_success_rate'].idxmax(), 'env_step']) if len(df) else 0
    last100 = df[df['env_step'] >= total_steps - 100_000].copy()
    last100_mean = float(last100['eval_success_rate'].mean()) if len(last100) else 0.0
    mean_all = float(df['eval_success_rate'].mean()) if len(df) else 0.0
    n_evals_with_success = int((df['eval_success_rate'] > 0).sum()) if len(df) else 0
    final_success = float(final_eval['eval_success_rate'])
    counts = final_eval.get('eval_termination_counts', {})
    num_eps = float(final_eval.get('num_eval_episodes', EVAL_EPISODES))
    oob_rate = float(counts.get('out_of_bounds', 0)) / max(num_eps, 1.0)

    print('=' * 100)
    print(f'{label}  (arrival_v2 / s0 / k=12 / seed={SEED} / vanilla / {total_steps:,} steps)')
    print('-' * 100)
    print(f"  final_success_rate    : {final_success:.4f}   gate >= {PASS_FINAL_SUCCESS:.2f}")
    print(f"  peak_success_rate     : {peak_success:.4f}   @ {peak_step:,}")
    print(f"  last100k_mean_success : {last100_mean:.4f}   gate >= {PASS_LAST100_RATIO * peak_success:.4f}")
    print(f"  full-traj mean        : {mean_all:.4f}   (39 evals)")
    print(f"  n_evals_with_success  : {n_evals_with_success} / {len(df)}")
    print(f"  final_oob_rate        : {oob_rate:.4f}   gate <= {PASS_OOB_RATE:.2f}")
    print(f"  obs_dim               : {trainer_state.get('observation_dim', 'NA')}   (expect 10*12+8=128)")
    print(f"  history_length        : {history_from_config}   (from train_config.txt)")
    print(f"  context_obs           : {trainer_state.get('include_episode_context_obs', 'NA')}")
    print(f"  timeout_bootstrap     : {trainer_state.get('timeout_bootstrap_semantics', 'NA')}")
    print(f"  termination           : {counts}")
    print('=' * 100)

    if len(df):
        print()
        print('[last 16 eval rows]')
        cols = ['env_step', 'eval_success_rate', 'eval_return', 'eval_safety_cost',
                'eval_time_s', 'eval_progress_ratio']
        available = [c for c in cols if c in df.columns]
        print(df[available].tail(16).to_string(index=False))

    checks = [
        ('final success >= 0.85', final_success >= PASS_FINAL_SUCCESS, f'{final_success:.4f}'),
        ('last100k mean >= 0.9 * peak', last100_mean >= PASS_LAST100_RATIO * peak_success,
         f'{last100_mean:.4f} / peak={peak_success:.4f}'),
        ('final OOB rate <= 0.10', oob_rate <= PASS_OOB_RATE, f'{oob_rate:.4f}'),
        ('arrival_v2 context obs enabled',
         trainer_state.get('include_episode_context_obs') is True,
         str(trainer_state.get('include_episode_context_obs'))),
        ('arrival_v2 timeout terminal semantics',
         trainer_state.get('timeout_bootstrap_semantics') == 'terminal',
         str(trainer_state.get('timeout_bootstrap_semantics'))),
    ]

    print()
    print('=' * 96)
    print(f"{'check':<48}{'pass':>8}{'detail':>40}")
    print('-' * 96)
    all_pass = True
    for name, ok, detail in checks:
        mark = 'PASS' if ok else 'FAIL'
        if not ok:
            all_pass = False
        print(f'{name:<48}{mark:>8}{detail:>40}')
    print('=' * 96)

    summary = {
        'phase': label,
        'objective': OBJECTIVE,
        'probe_layout': PROBE_LAYOUT,
        'history_length': int(history_from_config) if history_from_config != 'NA' else HISTORY_LENGTH,
        'seed': SEED,
        'total_steps': total_steps,
        'algorithm': 'sac_vanilla',
        'final_success_rate': final_success,
        'peak_success_rate': peak_success,
        'peak_step': peak_step,
        'last100k_mean_success': last100_mean,
        'mean_success_full_trajectory': mean_all,
        'n_evals_with_success': n_evals_with_success,
        'n_evals_total': len(df),
        'final_oob_rate': oob_rate,
        'termination_counts': counts,
        'all_pass': bool(all_pass),
        'checks': [{'name': n, 'ok': bool(ok), 'detail': d} for n, ok, d in checks],
    }
    out_path = run_root / 'results' / gate_filename
    out_path.parent.mkdir(parents=True, exist_ok=True)
    out_path.write_text(json.dumps(summary, indent=2), encoding='utf-8')
    print(f'[saved] {out_path}')
    return summary

x_summary = summarize_phase(
    X_RUN_ROOT,
    X_TOTAL_STEPS,
    'SINGLE_CROSS_S0_K12_SEED42',
    'single_cross_s0_k12_seed42_gate_summary.json',
)
X_PASS = x_summary['all_pass']
print()
print(f'X_PASS = {X_PASS}')
# Out:
# ====================================================================================================
# SINGLE_CROSS_S0_K12_SEED42  (arrival_v2 / s0 / k=12 / seed=42 / vanilla / 1,000,000 steps)
# ----------------------------------------------------------------------------------------------------
#   final_success_rate    : 0.9000   gate >= 0.85
#   peak_success_rate     : 0.9000   @ 375,000
#   last100k_mean_success : 0.8917   gate >= 0.8100
#   full-traj mean        : 0.6521   (39 evals)
#   n_evals_with_success  : 35 / 39
#   final_oob_rate        : 0.1000   gate <= 0.10
#   obs_dim               : 144   (expect 10*12+8=128)
#   history_length        : 12   (from train_config.txt)
#   context_obs           : True
#   timeout_bootstrap     : terminal
#   termination           : {'goal': 27, 'out_of_bounds': 3}
# ====================================================================================================
#
# [last 16 eval rows]
#  env_step  eval_success_rate  eval_return  eval_safety_cost  eval_time_s  eval_progress_ratio
#    600000           0.900000    76.739499         14.847397    72.350000             0.828267
#    625002           0.866667    69.453202         12.380298    67.696667             0.799910
#    650004           0.900000    85.938068         10.418186    66.246667             0.830314
#    675000           0.833333    66.929631         14.181018    81.180000             0.821827
#    700002           0.900000    80.211967         13.209909    68.283333             0.829366
#    725004           0.900000    74.227477         16.358561    88.243333             0.836712
#    750000           0.900000    87.804083          9.722047    73.663333             0.836771
#    775002           0.833333    56.149496         18.209029    76.993333             0.823893
#    800004           0.900000    88.522160          9.387916    73.410000             0.837166
#    825000           0.900000    83.346701         11.601700    73.320000             0.829534
#    850002           0.900000    81.703068         12.532658    70.053333             0.830691
#    875004           0.900000    86.602343         10.222408    68.876667             0.833445
#    900000           0.866667    73.506863         11.601668    63.846667             0.820246
#    925002           0.900000    76.310091         15.412322    76.156667             0.836159
#    950004           0.900000    90.349680          8.455220    71.606667             0.836475
#    975000           0.900000    88.381278          9.422580    73.233333             0.836510
#
# ================================================================================================
# check                                               pass                                  detail
# ------------------------------------------------------------------------------------------------
# final success >= 0.85                               PASS                                  0.9000
# last100k mean >= 0.9 * peak                         PASS                    0.8917 / peak=0.9000
# final OOB rate <= 0.10                              PASS                                  0.1000
# arrival_v2 context obs enabled                      PASS                                    True
# arrival_v2 timeout terminal semantics               PASS                                terminal
# ================================================================================================
# [saved] experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s0_k12/seed_42/results/single_cross_s0_k12_seed42_gate_summary.json
#
# X_PASS = True

# %% [markdown]
# ## 6. Monotonicity verdict — k=12 vs k=8 (§7.8 anchor) + k=4 (§7.6.4 floor) + s1_k4 (§7.1 upper)

# %%
def read_baseline(root: Path, ref_final: float, ref_oob: float, ref_mean: float = None):
    fp = root / 'results' / 'final_eval.json'
    log = root / 'results' / 'eval_log.csv'
    out = {'final': ref_final, 'oob': ref_oob, 'mean': ref_mean, 'peak': None, 'peak_step': None, 'source': 'report'}
    if fp.exists():
        d = json.loads(fp.read_text(encoding='utf-8'))
        f = float(d['eval_success_rate'])
        c = d.get('eval_termination_counts', {})
        n = float(d.get('num_eval_episodes', EVAL_EPISODES))
        out['final'] = f
        out['oob'] = float(c.get('out_of_bounds', 0)) / max(n, 1.0)
        out['source'] = 'on-disk'
    if log.exists():
        dlog = pd.read_csv(log)
        out['mean'] = float(dlog['eval_success_rate'].mean())
        out['peak'] = float(dlog['eval_success_rate'].max())
        out['peak_step'] = int(dlog.loc[dlog['eval_success_rate'].idxmax(), 'env_step'])
    return out

print('=' * 100)
print('SINGLE_CROSS — k=8→12 monotonicity verdict (seed=42)')
print('-' * 100)

# 本 run (k=12 seed=42)
k12_final = float(x_summary['final_success_rate'])
k12_oob   = float(x_summary['final_oob_rate'])
k12_peak  = float(x_summary['peak_success_rate'])
k12_peak_step = int(x_summary['peak_step'])
k12_mean  = float(x_summary.get('mean_success_full_trajectory', 0.0))
k12_nsucc = int(x_summary.get('n_evals_with_success', 0))
k12_ntot  = int(x_summary.get('n_evals_total', 0))

# Baselines
b_k8 = read_baseline(X_K8_ANCHOR_ROOT,   0.900, 0.100, 0.636)    # §7.8 anchor
b_k4 = read_baseline(X_K4_S42_ROOT,      0.100, 0.667, 0.221)    # §7.6.4 floor
b_s1 = read_baseline(X_S1_BASELINE_ROOT, 0.900, 0.100, 0.497)    # §7.1 upper

print()
print(f'{"config":<48}{"final":>10}{"mean":>10}{"oob":>10}{"peak":>10}{"peak@":>14}')
print('-' * 100)
print(f'{"k=4 vanilla s42 (§7.6.4 FAIL floor)":<48}{b_k4["final"]:>10.4f}{(b_k4["mean"] or float("nan")):>10.4f}{b_k4["oob"]:>10.4f}{(b_k4["peak"] or float("nan")):>10.4f}{(b_k4["peak_step"] or 0):>14,}')
print(f'{"k=8 vanilla s42 (§7.8 anchor PASS)":<48}{b_k8["final"]:>10.4f}{(b_k8["mean"] or float("nan")):>10.4f}{b_k8["oob"]:>10.4f}{(b_k8["peak"] or float("nan")):>10.4f}{(b_k8["peak_step"] or 0):>14,}')
print(f'{"k=12 vanilla s42 (THIS RUN)":<48}{k12_final:>10.4f}{k12_mean:>10.4f}{k12_oob:>10.4f}{k12_peak:>10.4f}{k12_peak_step:>14,}')
print(f'{"s1_k4 vanilla s42 (§7.1 upper ref)":<48}{b_s1["final"]:>10.4f}{(b_s1["mean"] or float("nan")):>10.4f}{b_s1["oob"]:>10.4f}{(b_s1["peak"] or float("nan")):>10.4f}{(b_s1["peak_step"] or 0):>14,}')
print('=' * 100)

# Δ 行
delta_final_vs_k8 = k12_final - b_k8['final']
delta_mean_vs_k8  = k12_mean  - (b_k8['mean'] or 0.0)
delta_oob_vs_k8   = k12_oob   - b_k8['oob']
delta_peak_step   = k12_peak_step - (b_k8['peak_step'] or 0)

print()
print(f'{"contrast":<60}{"Δ final":>12}{"Δ mean":>12}{"Δ oob":>12}{"Δ peak@":>14}')
print('-' * 110)
print(f'{"k=12 vs k=8 (§7.8 anchor) — monotonicity test":<60}'
      f'{delta_final_vs_k8:>+12.4f}{delta_mean_vs_k8:>+12.4f}{delta_oob_vs_k8:>+12.4f}{delta_peak_step:>+14,}')
print(f'{"k=12 vs k=4 (§7.6.4 floor) — cumulative gain":<60}'
      f'{k12_final - b_k4["final"]:>+12.4f}'
      f'{(k12_mean - (b_k4["mean"] or 0)):>+12.4f}'
      f'{k12_oob - b_k4["oob"]:>+12.4f}'
      f'{"N/A":>14}')
print(f'{"k=12 vs s1_k4 (§7.1 upper) — gap-to-upper":<60}'
      f'{k12_final - b_s1["final"]:>+12.4f}'
      f'{(k12_mean - (b_s1["mean"] or 0)):>+12.4f}'
      f'{k12_oob - b_s1["oob"]:>+12.4f}'
      f'{"N/A":>14}')
print('=' * 110)
print()
print(f'k=12 evals_with_success: {k12_nsucc} / {k12_ntot}  (k=8 was 37/39, k=4 was 35/39)')

# Monotonicity verdict — 4 档
k12_pass = (k12_final >= PASS_FINAL_SUCCESS) and (k12_oob <= PASS_OOB_RATE)
k12_strong_partial = (k12_final >= 0.50) and (k12_final < PASS_FINAL_SUCCESS)
k12_collapse = (k12_final < 0.50)

super_monotonic = (
    k12_pass and (
        k12_final >= 0.95 or
        delta_peak_step <= -100_000 or
        delta_mean_vs_k8 >= 0.05
    )
)
plateau = (
    k12_pass and
    abs(delta_final_vs_k8) <= 0.05 and
    abs(delta_mean_vs_k8) <= 0.05 and
    not super_monotonic
)

if super_monotonic:
    verdict = (
        'SUPER-MONOTONIC — k=12 比 k=8 还好（更高 final / 更早 peak / 更高 mean）；'
        'temporal window 未饱和；建议 §8 P1#2 续扫 k=16，看是否还能进一步压低 peak_step'
    )
elif plateau:
    verdict = (
        'MONOTONIC-PLATEAU — k=12 ≈ k=8（|Δfinal|≤0.05 且 |Δmean|≤0.05）；'
        '饱和点在 k≈8；thesis 主线可定 k=8 为 sweet spot，无需 k=16；'
        '§7.8 续写 "monotonic saturation observed at k=8"'
    )
elif k12_pass and not plateau:
    verdict = (
        'PASS-WITH-SHIFT — k=12 仍 PASS 但 Δfinal 或 Δmean 偏离 plateau 阈值；'
        '可能是 mild-DECAY（mean 略降）或 SUB-OPTIMAL（peak_step 推迟）；'
        '建议 §8 P1#2 续扫 k=16 + multi-seed 才能定论'
    )
elif k12_strong_partial:
    verdict = (
        'DECAY — k=12 STRONG-PARTIAL（final ∈ [0.5, 0.85)）；'
        '信息饱和后过长窗口轻微反害（curse of dim / over-stale history）；'
        '强证据 k=8 是 sweet spot；thesis 写 "actor temporal window 必须 narrow-band tuned"'
    )
else:  # k12_collapse
    verdict = (
        'COLLAPSE — k=12 final<0.50；严重下降；'
        '强烈支持 k=8 sweet spot；thesis 写 "k>8 的 actor window 导致 information dilution / network capacity overload"；'
        '同时启动 audit（确认非训练 bug：obs_dim、grad-norm、loss curve）'
    )

print()
print(f'>>> verdict: {verdict}')

# 落盘 monotonicity summary
mono_out = {
    'experiment': 'arrival_v2_s0_cross_k12_seed42_monotonicity',
    'seed': SEED,
    'benchmark': X_BENCHMARK_KEY,
    'probe_layout': PROBE_LAYOUT,
    'history_length': HISTORY_LENGTH,
    'total_steps': X_TOTAL_STEPS,
    'algorithm': 'sac_vanilla',
    'cli_diff_vs_§7.8_anchor': '--history-length 8 → 12',
    'results': {
        'k12_s42_thisrun': {
            'final': k12_final, 'mean': k12_mean, 'oob': k12_oob,
            'peak': k12_peak, 'peak_step': k12_peak_step,
            'n_evals_with_success': k12_nsucc, 'n_evals_total': k12_ntot,
        },
        'k8_s42_anchor_§7.8': b_k8,
        'k4_s42_floor_§7.6.4': b_k4,
        's1_k4_s42_upper_§7.1': b_s1,
    },
    'delta_vs_§7.8_k8_anchor': {
        'final_pp': round(delta_final_vs_k8 * 100, 2),
        'mean_pp':  round(delta_mean_vs_k8  * 100, 2),
        'oob_pp':   round(delta_oob_vs_k8   * 100, 2),
        'peak_step_shift': int(delta_peak_step),
    },
    'all_pass': bool(x_summary['all_pass']),
    'verdict': verdict,
}
out_dir = Path('experiments/arrival_v2_prototype/s0_cross_k12_seed42_summary')
out_dir.mkdir(parents=True, exist_ok=True)
out_path = out_dir / 'combined_gate_summary.json'
out_path.write_text(json.dumps(mono_out, indent=2), encoding='utf-8')
print(f'\n[saved] {out_path}')
# Out:
# ====================================================================================================
# SINGLE_CROSS — k=8→12 monotonicity verdict (seed=42)
# ----------------------------------------------------------------------------------------------------
#
# config                                               final      mean       oob      peak         peak@
# ----------------------------------------------------------------------------------------------------
# k=4 vanilla s42 (§7.6.4 FAIL floor)                 0.1000    0.2205    0.6667    0.3667       975,000
# k=8 vanilla s42 (§7.8 anchor PASS)                  0.9000    0.6359    0.1000    0.9000       475,002
# k=12 vanilla s42 (THIS RUN)                         0.9000    0.6521    0.1000    0.9000       375,000
# s1_k4 vanilla s42 (§7.1 upper ref)                  0.9000    0.4966    0.1000    0.9000       725,004
# ====================================================================================================
#
# contrast                                                         Δ final      Δ mean       Δ oob       Δ peak@
# --------------------------------------------------------------------------------------------------------------
# k=12 vs k=8 (§7.8 anchor) — monotonicity test                    +0.0000     +0.0162     +0.0000      -100,002
# k=12 vs k=4 (§7.6.4 floor) — cumulative gain                     +0.8000     +0.4316     -0.5667           N/A
# k=12 vs s1_k4 (§7.1 upper) — gap-to-upper                        +0.0000     +0.1556     +0.0000           N/A
# ==============================================================================================================
#
# k=12 evals_with_success: 35 / 39  (k=8 was 37/39, k=4 was 35/39)
#
# >>> verdict: SUPER-MONOTONIC — k=12 比 k=8 还好（更高 final / 更早 peak / 更高 mean）；temporal window 未饱和；建议 §8 P1#2 续扫 k=16，看是否还能进一步压低 peak_step
#
# [saved] experiments/arrival_v2_prototype/s0_cross_k12_seed42_summary/combined_gate_summary.json
