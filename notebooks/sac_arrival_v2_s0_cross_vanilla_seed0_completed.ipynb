# %% [markdown]
# # SAC arrival_v2 — vanilla s0_k4 SEED=0 replication of §7.6.4 (single_cross, 1M)
#
# **Pre-context（commits `01b78ad` / `3d20e86`）**：[`docs/arrival_v2_experiment_report.md`](../docs/arrival_v2_experiment_report.md) §7.6 + §7.7 已闭环，但**所有 single_cross 结果都建立在 `seed=42` 单 seed 之上**。这破坏了 §7.7 negative finding 的稳健性 — 5× mean gap 在方法论上仍可能被 seed variance 解释。
#
# | 已闭环 single_cross cell | algo | sensor | k | seed | final | mean | OOB |
# |---|---|---|---|---|---:|---:|---:|
# | §7.1 single_cross_s1_k4 | vanilla | s1 | 4 | 42 | 0.900 | — | 0.100 |
# | §7.6.4 single_cross_s0_k4 | vanilla | s0 | 4 | **42** | 0.100 | 0.221 | 0.667 |
# | §7.7 single_cross_s0_k4 + asym | sac_asym | s0 | 4 | **42** | 0.167 | 0.044 | 0.633 |
#
# **本 notebook 任务（vanilla k=4 SEED=0 paired-seed replication）**：把 §7.6.4 的 vanilla SAC 配置**唯一变量**换成 `--seed 0`，其它**全部不动**：
#
# | 维度 | §7.6.4 baseline (seed=42) | 本 notebook |
# |---|---|---|
# | `--seed` | 42 | **0** ← 唯一变量 |
# | algorithm | vanilla SAC | vanilla SAC |
# | sensor layout | s0 (DVL-only) | s0 (DVL-only) |
# | history_length | 4 | 4 |
# | reward | arrival_v2 | arrival_v2 |
# | flow U / target | 1.5 / 1.5 | 1.5 / 1.5 |
# | total_steps | 1M | 1M |
# | num_envs | 6 | 6 |
# | benchmark | `single_u15_cross_tgt15` | 同 |
# | obs_dim | 10×4 + 8 = 48 | 同 (48) |
#
# **配对设计**：本 notebook 与 `sac_arrival_v2_s0_cross_asym_seed0.ipynb` 并行跑，构成 2 seed × 2 algo = 4 cell 的 paired ablation：
#
# | | seed=42 (已有) | seed=0 (本 + 姊妹) |
# |---|---|---|
# | **vanilla** | §7.6.4 final=0.100 mean=0.221 | ← **本 notebook** |
# | **sac_asym** | §7.7 final=0.167 mean=0.044 | ← 姊妹 notebook |
#
# **判读规则**（驱动 §7.7 negative finding 升降级）：
# - **REPRO**（seed=0 vanilla mean ∈ [0.10, 0.35]，Δ final 在 ±0.15 以内）→ §7.6.4 baseline 稳定 ✓。配合姊妹 notebook 决定 §7.7：若姊妹 asym seed=0 也复现 negative，则 §7.7 升格为 2-seed hardened claim。
# - **HIGH-VARIANCE**（|Δ mean| > 0.20 vs §7.6.4）→ vanilla k=4 在此任务对 seed 高度敏感 → §7.7 negative claim 暂时**冻结**，需要 3rd seed (=7 或 =1) 才能写进论文。
# - **BREAKOUT**（final ≥ 0.50）→ §7.6.4 的 seed=42 是 unlucky outlier，single_cross 在 s0_k4 上**未必** catastrophic FAIL → §7.6 整章 framing 需重写；§7.7 的 vanilla 对照基线被推翻 → §7.7 claim 自动失效。
# - **FLOOR**（final ≤ 0.05 AND mean ≤ 0.10）→ §7.6.4 的 seed=42 反而是 lucky outlier，vanilla 真实地板更低 → §7.7 asym 反而可能不算更差 → claim 也要重写。
#
# **输出根（与 §7.6.4 seed=42 互不覆盖）**：
# - `experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s0_k4/seed_0/`
#
# **总预算**：~2.5h L4（1 Colab Pro+ session）。可与姊妹 asym seed=0 + 已在跑的 k=8 共 3 session 并行。
#
# **风格**：训练用 `!python -u -m scripts.train_sac` 直跑（实时 stdout），与 §7 / §7.6 / §7.7 一致。

# %% [markdown]
# ## 0. GPU sanity

# %%
# !nvidia-smi | head -10
# Out:
# Mon May 18 04:36:58 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA L4                      Off |   00000000:00:03.0 Off |                    0 |
# | N/A   36C    P8             13W /   72W |       0MiB /  23034MiB |      0%      Default |

# %% [markdown]
# ## 1. Mount Drive + cwd

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

REPO_DIR = '/content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5'
# %cd $REPO_DIR
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5

# %% [markdown]
# ## 2. Config — vanilla SAC + seed=0（与 §7.6.4 baseline 仅差一个 flag value）

# %%
import json
import os
from pathlib import Path

import pandas as pd

# ==== SAC / env config (与 §7.6.4 baseline 严格一致，除 seed 外) ====
OBJECTIVE = 'arrival_v2'
PROBE_LAYOUT = 's0'
HISTORY_LENGTH = 4
TARGET_SPEED = 1.5
SEED = 0                                # ← 唯一与 §7.6.4 不同 (was 42)

RANDOM_STEPS = 5_000
UPDATE_AFTER = 5_000
BATCH_SIZE = 256
HIDDEN_DIM = 256
NUM_ENVS = 6
EVAL_EVERY = 25_000
EVAL_EPISODES = 30
CHECKPOINT_EVERY = 100_000
DEVICE = 'cuda'

# 显式拒绝所有 SAC 改进项 — 与 §7.6.4 一致
USE_ASYMMETRIC_CRITIC = False
USE_LAYERNORM = False
UPDATES_PER_STEP = 1
DROPOUT_RATE = 0.0

PASS_FINAL_SUCCESS = 0.85
PASS_LAST100_RATIO = 0.90
PASS_OOB_RATE = 0.10

# Flow file（与 §7.1 / §7.6.4 / §7.7 严格一致）
SINGLE_FLOW = 'wake_data/wake_v8_U1p50_Re250_D12p00_dx0p60_Ti5pct_1200f_roi.npy'

# ==== Single phase — vanilla s0 k=4 seed=0 (X_*) ====
X_BENCHMARK_KEY = 'single_u15_cross_tgt15'
X_TASK_GEOMETRY = 'cross_stream'
X_FLOW_PATH = SINGLE_FLOW
X_TOTAL_STEPS = 1_000_000
X_RUN_ROOT = Path('experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s0_k4/seed_0')
X_CKPT_ROOT = Path('checkpoints/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s0_k4/seed_0')
X_MANIFEST_PATH = Path(f'benchmarks/{X_BENCHMARK_KEY}.json')

# Baselines（事后对比）
X_K4_SEED42_BASELINE = Path('experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s0_k4/seed_42')   # §7.6.4
X_K4_ASYM_SEED42_BASELINE = Path('experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_asym/s0_k4/seed_42') # §7.7
X_K4_ASYM_SEED0_SISTER = Path('experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_asym/s0_k4/seed_0')     # 姊妹 notebook
X_S1_BASELINE = Path('experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s1_k4/seed_42')          # §7.1 上界 ref

os.environ['PYTHONUNBUFFERED'] = '1'

print(f'PROBE_LAYOUT          = {PROBE_LAYOUT}')
print(f'OBJECTIVE             = {OBJECTIVE}')
print(f'HISTORY_LENGTH        = {HISTORY_LENGTH}')
print(f'SEED                  = {SEED}        ← 唯一与 §7.6.4 不同 (was 42)')
print(f'NUM_ENVS              = {NUM_ENVS}')
print(f'USE_ASYMMETRIC_CRITIC = {USE_ASYMMETRIC_CRITIC}')
print(f'USE_LAYERNORM         = {USE_LAYERNORM}')
print(f'UPDATES_PER_STEP      = {UPDATES_PER_STEP}')
print(f'DROPOUT_RATE          = {DROPOUT_RATE}')
print()
print(f'benchmark             : {X_BENCHMARK_KEY}')
print(f'geometry              : {X_TASK_GEOMETRY}')
print(f'total_steps           : {X_TOTAL_STEPS:,}')
print(f'expected obs_dim      : 10 * {HISTORY_LENGTH} + 8 (arrival_v2 context) = {10 * HISTORY_LENGTH + 8}')
print(f'run_root              : {X_RUN_ROOT}')
print(f'§7.6.4 seed=42 anchor : {X_K4_SEED42_BASELINE}')
print(f'§7.7 seed=42 asym ref : {X_K4_ASYM_SEED42_BASELINE}')
print(f'sister asym seed=0    : {X_K4_ASYM_SEED0_SISTER}')
print(f'§7.1 s1_k4 upper ref  : {X_S1_BASELINE}')
# Out:
# PROBE_LAYOUT          = s0
# OBJECTIVE             = arrival_v2
# HISTORY_LENGTH        = 4
# SEED                  = 0        ← 唯一与 §7.6.4 不同 (was 42)
# NUM_ENVS              = 6
# USE_ASYMMETRIC_CRITIC = False
# USE_LAYERNORM         = False
# UPDATES_PER_STEP      = 1
# DROPOUT_RATE          = 0.0
#
# benchmark             : single_u15_cross_tgt15
# geometry              : cross_stream
# total_steps           : 1,000,000
# expected obs_dim      : 10 * 4 + 8 (arrival_v2 context) = 48
# run_root              : experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s0_k4/seed_0
# §7.6.4 seed=42 anchor : experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s0_k4/seed_42
# §7.7 seed=42 asym ref : experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_asym/s0_k4/seed_42
# sister asym seed=0    : experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_asym/s0_k4/seed_0
# §7.1 s1_k4 upper ref  : experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s1_k4/seed_42

# %% [markdown]
# ## 3. Preflight — flow / arrival_v2 candidate gate / reward unit tests / manifest / baseline 就位

# %%
# Flow file
fp = Path(X_FLOW_PATH)
if not fp.exists():
    raise FileNotFoundError(f'missing flow file: {fp}')
print(f'[OK] flow file: {fp}  ({fp.stat().st_size / 1e6:.1f} MB)')
# Out:
# [OK] flow file: wake_data/wake_v8_U1p50_Re250_D12p00_dx0p60_Ti5pct_1200f_roi.npy  (230.4 MB)

# %%
# !python -u -m scripts.validate_arrival_v2_candidate
# Out:
# [undiscounted]
# fast_success       144.473
# slow_success       142.023
# unsafe_success      91.048
# timeout_near      -149.800
# timeout_far       -229.800
# late_oob          -274.500
# fast_oob          -280.325
# mid_oob           -319.450
#
# [discounted_gamma_0.995]
# fast_success        88.578
# slow_success        54.683
# unsafe_success      34.857
# timeout_near       -39.480
# timeout_far        -58.269
# late_oob          -103.800
# mid_oob           -190.006
# fast_oob          -212.555
#
# [discounted_shortcut] safe=69.330 risky=62.361
#
# PASS: arrival_v2 candidate pre-integration gates passed.

# %%
# !python -u -m pytest tests/test_reward_objective.py -q
# Out:
# ...............                                                          [100%]
# 15 passed in 13.46s

# %%
if not X_MANIFEST_PATH.exists():
    # !python -u -m scripts.generate_standard_benchmarks --benchmarks {X_BENCHMARK_KEY} --episodes {EVAL_EPISODES}
if not X_MANIFEST_PATH.exists():
    raise FileNotFoundError(f'manifest not generated: {X_MANIFEST_PATH}')
print(f'[OK] manifest ready: {X_MANIFEST_PATH}')
# Out:
# [OK] manifest ready: benchmarks/single_u15_cross_tgt15.json

# %%
# 检查对比 baseline 是否就位 — 不影响训练，仅 §6 verdict 用
for label, root, ref_final, ref_oob in [
    ('§7.6.4 vanilla_s0_k4 seed=42 (paired)', X_K4_SEED42_BASELINE, 0.100, 0.667),
    ('§7.7   sac_asym_s0_k4 seed=42        ', X_K4_ASYM_SEED42_BASELINE, 0.167, 0.633),
    ('§7.1   vanilla_s1_k4 seed=42 (upper) ', X_S1_BASELINE, 0.900, 0.100),
    ('SISTER sac_asym_s0_k4 seed=0         ', X_K4_ASYM_SEED0_SISTER, -1, -1),
]:
    fp = root / 'results' / 'final_eval.json'
    if fp.exists():
        d = json.loads(fp.read_text(encoding='utf-8'))
        f = float(d['eval_success_rate'])
        c = d.get('eval_termination_counts', {})
        n = float(d.get('num_eval_episodes', EVAL_EPISODES))
        oob = float(c.get('out_of_bounds', 0)) / max(n, 1.0)
        if ref_final >= 0:
            match = '✓' if abs(f - ref_final) < 0.05 and abs(oob - ref_oob) < 0.05 else '✗ mismatch'
        else:
            match = '(sister, no ref)'
        print(f'[OK] {label}: final={f:.4f}  oob={oob:.4f}  counts={c}  {match}')
    else:
        if 'SISTER' in label:
            print(f'[INFO] {label}: 姊妹 notebook 尚未跑完，§6 verdict 会跳过 2x2 完整设计')
        else:
            print(f'[WARN] {label}: {fp} 不存在 (后续 §6 会回退到 report 转载值)')
# Out:
# [OK] §7.6.4 vanilla_s0_k4 seed=42 (paired): final=0.1000  oob=0.6667  counts={'out_of_bounds': 20, 'timeout': 7, 'goal': 3}  ✓
# [OK] §7.7   sac_asym_s0_k4 seed=42        : final=0.1667  oob=0.6333  counts={'out_of_bounds': 19, 'goal': 5, 'timeout': 6}  ✓
# [OK] §7.1   vanilla_s1_k4 seed=42 (upper) : final=0.9000  oob=0.1000  counts={'goal': 27, 'out_of_bounds': 3}  ✓
# [INFO] SISTER sac_asym_s0_k4 seed=0         : 姊妹 notebook 尚未跑完，§6 verdict 会跳过 2x2 完整设计

# %% [markdown]
# ## 4. Train — vanilla s0 k=4 SEED=0 (1.0M, skip/resume)

# %%
x_state_path = X_RUN_ROOT / 'trainer_state.json'
if x_state_path.exists():
    x_state = json.loads(x_state_path.read_text(encoding='utf-8'))
    x_current_step = int(x_state.get('env_step', 0))
else:
    x_current_step = 0
print(f'[state] X env_step = {x_current_step:,} / target {X_TOTAL_STEPS:,}')

if x_current_step >= X_TOTAL_STEPS:
    print(f'[skip] X already trained to {x_current_step:,} >= {X_TOTAL_STEPS:,}')
elif x_current_step > 0:
    print(f'[resume] X continuing from {x_current_step:,} -> {X_TOTAL_STEPS:,}')
    # !python -u -m scripts.train_sac \
        --resume {str(X_RUN_ROOT)} \
        --total-steps {X_TOTAL_STEPS} \
        --eval-every {EVAL_EVERY} \
        --eval-episodes {EVAL_EPISODES} \
        --checkpoint-every {CHECKPOINT_EVERY} \
        --eval-manifest {str(X_MANIFEST_PATH)} \
        --device {DEVICE}
else:
    print(f'[train] X fresh start -> {X_TOTAL_STEPS:,}')
    # !python -u -m scripts.train_sac \
        --flow {X_FLOW_PATH} \
        --task-geometry {X_TASK_GEOMETRY} \
        --target-speed {TARGET_SPEED} \
        --objective {OBJECTIVE} \
        --probe-layout {PROBE_LAYOUT} \
        --history-length {HISTORY_LENGTH} \
        --total-steps {X_TOTAL_STEPS} \
        --random-steps {RANDOM_STEPS} \
        --update-after {UPDATE_AFTER} \
        --batch-size {BATCH_SIZE} \
        --hidden-dim {HIDDEN_DIM} \
        --num-envs {NUM_ENVS} \
        --eval-every {EVAL_EVERY} \
        --eval-episodes {EVAL_EPISODES} \
        --checkpoint-every {CHECKPOINT_EVERY} \
        --eval-manifest {str(X_MANIFEST_PATH)} \
        --seed {SEED} \
        --device {DEVICE} \
        --save-dir {str(X_RUN_ROOT)} \
        --checkpoint-dir {str(X_CKPT_ROOT)}
# Out:
# [state] X env_step = 0 / target 1,000,000
# [train] X fresh start -> 1,000,000
# [train] episode=5 step=678 return=-310.07 success=False time=56.1s geometry=cross_stream history=4
# [train] episode=10 step=1842 return=-455.98 success=False time=106.2s geometry=cross_stream history=4
# [train] episode=15 step=2268 return=-404.30 success=False time=94.9s geometry=cross_stream history=4
# [train] episode=20 step=2670 return=-324.46 success=False time=31.6s geometry=cross_stream history=4
# [train] episode=25 step=3204 return=-285.89 success=False time=55.0s geometry=cross_stream history=4
# [train] episode=30 step=3702 return=-416.50 success=False time=38.5s geometry=cross_stream history=4
# [train] episode=35 step=4242 return=-432.68 success=False time=49.6s geometry=cross_stream history=4
# [train] episode=40 step=5112 return=-497.85 success=False time=109.5s geometry=cross_stream history=4 | q1=787.015 actor=0.548 alpha=0.199
# [train] episode=45 step=5556 return=-409.35 success=False time=90.7s geometry=cross_stream history=4 | q1=567.507 actor=3.300 alpha=0.195
# [train] episode=50 step=6120 return=-376.51 success=False time=83.1s geometry=cross_stream history=4 | q1=253.411 actor=3.235 alpha=0.189
# [train] episode=55 step=6888 return=-409.72 success=False time=40.6s geometry=cross_stream history=4 | q1=1072.450 actor=4.054 alpha=0.183
# [train] episode=60 step=7416 return=-370.67 success=False time=43.4s geometry=cross_stream history=4 | q1=227.379 actor=5.454 alpha=0.180
# [train] episode=65 step=8136 return=-507.54 success=False time=93.3s geometry=cross_stream history=4 | q1=518.883 actor=7.205 alpha=0.175
# [train] episode=70 step=8784 return=-426.39 success=False time=99.1s geometry=cross_stream history=4 | q1=241.739 actor=7.600 alpha=0.171
# [train] episode=75 step=9210 return=-287.96 success=False time=24.5s geometry=cross_stream history=4 | q1=526.710 actor=7.628 alpha=0.168
# [train] episode=80 step=9930 return=-343.03 success=False time=59.1s geometry=cross_stream history=4 | q1=707.932 actor=9.620 alpha=0.163
# [train] episode=85 step=10662 return=-501.52 success=False time=75.8s geometry=cross_stream history=4 | q1=521.678 actor=11.463 alpha=0.158
# [train] episode=90 step=11052 return=-317.21 success=False time=26.7s geometry=cross_stream history=4 | q1=3.295 actor=11.232 alpha=0.155
# [train] episode=95 step=11838 return=-309.11 success=False time=31.4s geometry=cross_stream history=4 | q1=499.917 actor=13.450 alpha=0.149
# [train] episode=100 step=12354 return=-253.19 success=False time=36.7s geometry=cross_stream history=4 | q1=465.400 actor=14.447 alpha=0.145
# [train] episode=105 step=12822 return=-261.67 success=False time=11.1s geometry=cross_stream history=4 | q1=414.345 actor=14.403 alpha=0.142
# [train] episode=110 step=13026 return=-275.91 success=False time=16.5s geometry=cross_stream history=4 | q1=254.705 actor=14.325 alpha=0.140
# [train] episode=115 step=13842 return=-337.52 success=False time=68.3s geometry=cross_stream history=4 | q1=251.960 actor=15.676 alpha=0.135
# [train] episode=120 step=14502 return=-319.14 success=False time=54.2s geometry=cross_stream history=4 | q1=553.435 actor=18.834 alpha=0.131
# [train] episode=125 step=15012 return=-382.00 success=False time=79.4s geometry=cross_stream history=4 | q1=452.870 actor=17.996 alpha=0.128
# [train] episode=130 step=15756 return=-278.31 success=False time=19.1s geometry=cross_stream history=4 | q1=432.075 actor=20.589 alpha=0.124
# [train] episode=135 step=16380 return=-294.50 success=False time=24.6s geometry=cross_stream history=4 | q1=440.253 actor=21.449 alpha=0.121
# [train] episode=140 step=16854 return=-255.12 success=False time=11.0s geometry=cross_stream history=4 | q1=731.231 actor=19.951 alpha=0.119
# [train] episode=145 step=17802 return=-333.51 success=False time=59.4s geometry=cross_stream history=4 | q1=625.201 actor=25.623 alpha=0.114
# [train] episode=150 step=18228 return=-364.39 success=False time=33.7s geometry=cross_stream history=4 | q1=412.956 actor=23.829 alpha=0.112
# [train] episode=155 step=19176 return=-329.92 success=False time=34.6s geometry=cross_stream history=4 | q1=218.283 actor=27.200 alpha=0.107
# [train] episode=160 step=19692 return=-279.69 success=False time=19.3s geometry=cross_stream history=4 | q1=218.883 actor=25.714 alpha=0.104
# [train] episode=165 step=20106 return=-279.95 success=False time=34.0s geometry=cross_stream history=4 | q1=570.943 actor=29.594 alpha=0.103
# [train] episode=170 step=20748 return=-262.53 success=False time=4.3s geometry=cross_stream history=4 | q1=238.241 actor=27.793 alpha=0.100
# [train] episode=175 step=21798 return=-493.63 success=False time=148.6s geometry=cross_stream history=4 | q1=433.134 actor=32.004 alpha=0.096
# [train] episode=180 step=22722 return=-472.01 success=False time=76.1s geometry=cross_stream history=4 | q1=246.243 actor=30.655 alpha=0.093
# [train] episode=185 step=23904 return=-231.11 success=False time=10.9s geometry=cross_stream history=4 | q1=182.039 actor=33.465 alpha=0.089
# [train] episode=190 step=24612 return=-428.03 success=False time=41.8s geometry=cross_stream history=4 | q1=334.118 actor=35.606 alpha=0.087
# [eval] step=25002 objective=arrival_v2 return=-334.63 safety=16.541 success=0.00% time=63.3s energy=38922.0 path=93.5 prog=-0.95
# [train] episode=195 step=25314 return=-280.38 success=False time=35.6s geometry=cross_stream history=4 | q1=296.420 actor=37.451 alpha=0.085
# [train] episode=200 step=26190 return=-336.55 success=False time=42.8s geometry=cross_stream history=4 | q1=323.216 actor=39.458 alpha=0.083
# [train] episode=205 step=26574 return=-322.91 success=False time=55.1s geometry=cross_stream history=4 | q1=177.791 actor=37.553 alpha=0.082
# [train] episode=210 step=27552 return=-328.48 success=False time=57.4s geometry=cross_stream history=4 | q1=194.896 actor=38.910 alpha=0.079
# [train] episode=215 step=27972 return=-267.70 success=False time=34.4s geometry=cross_stream history=4 | q1=451.468 actor=39.955 alpha=0.078
# [train] episode=220 step=28512 return=-279.02 success=False time=11.7s geometry=cross_stream history=4 | q1=1.859 actor=40.370 alpha=0.077
# [train] episode=225 step=29220 return=-368.32 success=False time=68.1s geometry=cross_stream history=4 | q1=552.566 actor=42.452 alpha=0.074
# [train] episode=230 step=29886 return=-327.11 success=False time=54.8s geometry=cross_stream history=4 | q1=1.851 actor=41.473 alpha=0.073
# [train] episode=235 step=30606 return=-352.36 success=False time=59.1s geometry=cross_stream history=4 | q1=1076.987 actor=43.040 alpha=0.071
# [train] episode=240 step=31074 return=-343.83 success=False time=75.4s geometry=cross_stream history=4 | q1=143.205 actor=42.618 alpha=0.070
# [train] episode=245 step=31746 return=-310.08 success=False time=41.4s geometry=cross_stream history=4 | q1=153.535 actor=46.481 alpha=0.068
# [train] episode=250 step=32418 return=-315.94 success=False time=33.0s geometry=cross_stream history=4 | q1=224.898 actor=44.660 alpha=0.066
# [train] episode=255 step=32712 return=-288.08 success=False time=24.0s geometry=cross_stream history=4 | q1=263.774 actor=45.344 alpha=0.066
# [train] episode=260 step=33360 return=-288.10 success=False time=32.5s geometry=cross_stream history=4 | q1=206.756 actor=48.143 alpha=0.064
# [train] episode=265 step=34254 return=-271.75 success=False time=10.7s geometry=cross_stream history=4 | q1=216.946 actor=46.993 alpha=0.062
# [train] episode=270 step=35328 return=-429.96 success=False time=111.5s geometry=cross_stream history=4 | q1=13.597 actor=49.028 alpha=0.060
# [train] episode=275 step=35940 return=-337.73 success=False time=50.2s geometry=cross_stream history=4 | q1=525.858 actor=48.858 alpha=0.060
# [train] episode=280 step=36450 return=-501.80 success=False time=104.7s geometry=cross_stream history=4 | q1=792.534 actor=53.619 alpha=0.059
# [train] episode=285 step=37140 return=-343.78 success=False time=57.0s geometry=cross_stream history=4 | q1=139.408 actor=52.340 alpha=0.059
# [train] episode=290 step=38328 return=-291.58 success=False time=113.2s geometry=cross_stream history=4 | q1=213.459 actor=51.478 alpha=0.061
# [train] episode=295 step=39324 return=-329.85 success=False time=151.0s geometry=cross_stream history=4 | q1=587.166 actor=57.033 alpha=0.062
# [train] episode=300 step=40158 return=-248.76 success=False time=15.5s geometry=cross_stream history=4 | q1=17.596 actor=55.596 alpha=0.062
# [train] episode=305 step=40560 return=-236.57 success=False time=32.6s geometry=cross_stream history=4 | q1=373.921 actor=55.620 alpha=0.062
# [train] episode=310 step=41070 return=-230.95 success=False time=25.6s geometry=cross_stream history=4 | q1=298.212 actor=53.524 alpha=0.062
# [train] episode=315 step=41766 return=-357.42 success=False time=57.3s geometry=cross_stream history=4 | q1=434.221 actor=55.931 alpha=0.062
# [train] episode=320 step=42072 return=-338.52 success=False time=126.2s geometry=cross_stream history=4 | q1=25.491 actor=56.947 alpha=0.062
# [train] episode=325 step=43218 return=-258.28 success=False time=29.0s geometry=cross_stream history=4 | q1=465.839 actor=56.906 alpha=0.062
# [train] episode=330 step=43410 return=-332.57 success=False time=119.8s geometry=cross_stream history=4 | q1=409.439 actor=58.642 alpha=0.063
# [train] episode=335 step=43968 return=-345.29 success=False time=61.6s geometry=cross_stream history=4 | q1=178.806 actor=58.680 alpha=0.063
# [train] episode=340 step=44610 return=-333.92 success=False time=52.8s geometry=cross_stream history=4 | q1=460.439 actor=57.009 alpha=0.063
# [train] episode=345 step=45084 return=-279.74 success=False time=39.0s geometry=cross_stream history=4 | q1=680.744 actor=61.163 alpha=0.063
# [train] episode=350 step=45582 return=-377.03 success=False time=59.3s geometry=cross_stream history=4 | q1=156.903 actor=61.434 alpha=0.062
# [train] episode=355 step=46632 return=-353.50 success=False time=88.4s geometry=cross_stream history=4 | q1=191.728 actor=59.269 alpha=0.061
# [train] episode=360 step=47238 return=-350.69 success=False time=155.7s geometry=cross_stream history=4 | q1=629.000 actor=59.711 alpha=0.061
# [train] episode=365 step=47778 return=-315.27 success=False time=44.1s geometry=cross_stream history=4 | q1=170.016 actor=61.113 alpha=0.060
# [train] episode=370 step=48510 return=-393.45 success=False time=65.1s geometry=cross_stream history=4 | q1=94.684 actor=63.920 alpha=0.060
# [train] episode=375 step=49350 return=-236.04 success=False time=21.6s geometry=cross_stream history=4 | q1=262.798 actor=65.845 alpha=0.059
# [eval] step=50004 objective=arrival_v2 return=-328.42 safety=18.438 success=0.00% time=73.5s energy=42751.0 path=92.8 prog=-0.89
# [train] episode=380 step=50352 return=-281.64 success=False time=29.3s geometry=cross_stream history=4 | q1=63.561 actor=66.261 alpha=0.060
# [train] episode=385 step=50994 return=-69.70 success=False time=240.1s geometry=cross_stream history=4 | q1=353.877 actor=70.294 alpha=0.059
# [train] episode=390 step=51936 return=-250.36 success=False time=214.7s geometry=cross_stream history=4 | q1=239.632 actor=69.518 alpha=0.059
# [train] episode=395 step=52482 return=-293.90 success=False time=45.7s geometry=cross_stream history=4 | q1=354.438 actor=72.432 alpha=0.059
# [train] episode=400 step=53280 return=-386.59 success=False time=71.8s geometry=cross_stream history=4 | q1=183.857 actor=67.877 alpha=0.060
# [train] episode=405 step=53712 return=-205.38 success=False time=35.3s geometry=cross_stream history=4 | q1=181.779 actor=68.173 alpha=0.061
# [train] episode=410 step=54210 return=-302.48 success=False time=40.6s geometry=cross_stream history=4 | q1=263.624 actor=70.188 alpha=0.061
# [train] episode=415 step=55122 return=-265.30 success=False time=45.8s geometry=cross_stream history=4 | q1=465.547 actor=72.288 alpha=0.061
# [train] episode=420 step=56160 return=-483.37 success=False time=82.5s geometry=cross_stream history=4 | q1=195.266 actor=73.877 alpha=0.060
# [train] episode=425 step=56646 return=-273.22 success=False time=30.1s geometry=cross_stream history=4 | q1=285.609 actor=74.319 alpha=0.060
# [train] episode=430 step=57468 return=-298.30 success=False time=46.4s geometry=cross_stream history=4 | q1=229.282 actor=72.866 alpha=0.059
# [train] episode=435 step=58140 return=-299.45 success=False time=31.6s geometry=cross_stream history=4 | q1=175.964 actor=74.275 alpha=0.058
# [train] episode=440 step=58542 return=-331.74 success=False time=138.6s geometry=cross_stream history=4 | q1=335.902 actor=76.020 alpha=0.058
# [train] episode=445 step=59262 return=-388.43 success=False time=92.8s geometry=cross_stream history=4 | q1=399.115 actor=78.752 alpha=0.059
# [train] episode=450 step=59994 return=-242.91 success=False time=13.8s geometry=cross_stream history=4 | q1=123.617 actor=74.783 alpha=0.059
# [train] episode=455 step=61500 return=-292.65 success=False time=129.8s geometry=cross_stream history=4 | q1=215.781 actor=78.613 alpha=0.058
# [train] episode=460 step=62064 return=-236.86 success=False time=46.1s geometry=cross_stream history=4 | q1=61.384 actor=81.535 alpha=0.059
# [train] episode=465 step=63180 return=-351.48 success=False time=57.8s geometry=cross_stream history=4 | q1=95.898 actor=77.114 alpha=0.059
# [train] episode=470 step=64350 return=-373.04 success=False time=142.5s geometry=cross_stream history=4 | q1=145.715 actor=77.807 alpha=0.060
# [train] episode=475 step=65490 return=-240.19 success=False time=20.6s geometry=cross_stream history=4 | q1=63.874 actor=79.095 alpha=0.061
# [train] episode=480 step=66510 return=-326.12 success=False time=38.1s geometry=cross_stream history=4 | q1=574.036 actor=84.102 alpha=0.062
# [train] episode=485 step=67146 return=-261.72 success=False time=29.8s geometry=cross_stream history=4 | q1=166.167 actor=80.276 alpha=0.062
# [train] episode=490 step=67440 return=-462.72 success=False time=86.7s geometry=cross_stream history=4 | q1=165.294 actor=86.485 alpha=0.061
# [train] episode=495 step=68256 return=-364.02 success=False time=67.1s geometry=cross_stream history=4 | q1=197.982 actor=83.395 alpha=0.061
# [train] episode=500 step=69186 return=-264.15 success=False time=154.4s geometry=cross_stream history=4 | q1=251.551 actor=85.022 alpha=0.061
# [train] episode=505 step=70452 return=-262.90 success=False time=51.6s geometry=cross_stream history=4 | q1=161.885 actor=86.024 alpha=0.063
# [train] episode=510 step=71580 return=-256.11 success=False time=198.9s geometry=cross_stream history=4 | q1=23.925 actor=83.554 alpha=0.066
# [train] episode=515 step=72420 return=-248.53 success=False time=34.4s geometry=cross_stream history=4 | q1=520.212 actor=87.096 alpha=0.066
# [train] episode=520 step=73344 return=-144.74 success=False time=240.1s geometry=cross_stream history=4 | q1=117.611 actor=88.174 alpha=0.066
# [train] episode=525 step=74346 return=-254.11 success=False time=122.6s geometry=cross_stream history=4 | q1=320.707 actor=85.456 alpha=0.065
# [train] episode=530 step=74868 return=-218.24 success=False time=50.9s geometry=cross_stream history=4 | q1=282.886 actor=87.014 alpha=0.066
# [eval] step=75000 objective=arrival_v2 return=-323.89 safety=24.227 success=0.00% time=89.5s energy=46281.2 path=93.2 prog=-0.76
# [train] episode=535 step=75588 return=-309.56 success=False time=27.6s geometry=cross_stream history=4 | q1=160.913 actor=90.813 alpha=0.066
# [train] episode=540 step=76494 return=-345.35 success=False time=145.3s geometry=cross_stream history=4 | q1=108.004 actor=89.936 alpha=0.066
# [train] episode=545 step=78168 return=-186.02 success=False time=166.8s geometry=cross_stream history=4 | q1=283.369 actor=84.341 alpha=0.069
# [train] episode=550 step=79224 return=-413.38 success=False time=80.6s geometry=cross_stream history=4 | q1=101.636 actor=90.534 alpha=0.069
# [train] episode=555 step=79944 return=-347.56 success=False time=55.2s geometry=cross_stream history=4 | q1=14.951 actor=88.884 alpha=0.070
# [train] episode=560 step=80856 return=-282.63 success=False time=144.9s geometry=cross_stream history=4 | q1=2.874 actor=96.676 alpha=0.071
# [train] episode=565 step=81528 return=-260.49 success=False time=4.9s geometry=cross_stream history=4 | q1=153.165 actor=91.126 alpha=0.071
# [train] episode=570 step=81984 return=-286.30 success=False time=42.9s geometry=cross_stream history=4 | q1=37.509 actor=88.252 alpha=0.070
# [train] episode=575 step=82944 return=-347.63 success=False time=57.0s geometry=cross_stream history=4 | q1=231.679 actor=91.738 alpha=0.070
# [train] episode=580 step=84828 return=-151.84 success=False time=240.1s geometry=cross_stream history=4 | q1=330.056 actor=93.435 alpha=0.071
# [train] episode=585 step=86034 return=-293.89 success=False time=51.3s geometry=cross_stream history=4 | q1=96.131 actor=92.572 alpha=0.073
# [train] episode=590 step=86640 return=-331.61 success=False time=156.5s geometry=cross_stream history=4 | q1=252.513 actor=98.048 alpha=0.072
# [train] episode=595 step=87216 return=-272.27 success=False time=22.1s geometry=cross_stream history=4 | q1=190.767 actor=98.322 alpha=0.072
# [train] episode=600 step=88428 return=-347.76 success=False time=68.7s geometry=cross_stream history=4 | q1=185.477 actor=97.284 alpha=0.075
# [train] episode=605 step=89688 return=-276.98 success=False time=42.1s geometry=cross_stream history=4 | q1=102.175 actor=98.553 alpha=0.079
# [train] episode=610 step=90744 return=-353.63 success=False time=62.7s geometry=cross_stream history=4 | q1=61.629 actor=93.508 alpha=0.082
# [train] episode=615 step=91872 return=-382.53 success=False time=79.5s geometry=cross_stream history=4 | q1=257.409 actor=97.545 alpha=0.083
# [train] episode=620 step=92274 return=-418.90 success=False time=147.5s geometry=cross_stream history=4 | q1=293.170 actor=100.889 alpha=0.083
# [train] episode=625 step=93564 return=-318.49 success=False time=127.9s geometry=cross_stream history=4 | q1=98.376 actor=101.379 alpha=0.086
# [train] episode=630 step=94248 return=134.59 success=True time=129.8s geometry=cross_stream history=4 | q1=10.650 actor=95.478 alpha=0.088
# [train] episode=635 step=95010 return=-298.97 success=False time=119.6s geometry=cross_stream history=4 | q1=106.406 actor=96.512 alpha=0.089
# [train] episode=640 step=95448 return=-296.11 success=False time=52.7s geometry=cross_stream history=4 | q1=354.660 actor=99.741 alpha=0.089
# [train] episode=645 step=96096 return=-289.15 success=False time=53.4s geometry=cross_stream history=4 | q1=171.214 actor=101.720 alpha=0.089
# [train] episode=650 step=97080 return=-242.72 success=False time=16.1s geometry=cross_stream history=4 | q1=283.044 actor=102.988 alpha=0.093
# [train] episode=655 step=98364 return=-352.10 success=False time=66.0s geometry=cross_stream history=4 | q1=258.971 actor=104.344 alpha=0.094
# [train] episode=660 step=99972 return=-206.20 success=False time=240.1s geometry=cross_stream history=4 | q1=317.890 actor=101.693 alpha=0.093
# [eval] step=100002 objective=arrival_v2 return=-234.33 safety=20.125 success=3.33% time=133.5s energy=82490.2 path=120.4 prog=-0.33
# [train] episode=665 step=101322 return=-63.14 success=False time=240.1s geometry=cross_stream history=4 | q1=137.038 actor=104.464 alpha=0.094
# [train] episode=670 step=102276 return=-380.52 success=False time=78.6s geometry=cross_stream history=4 | q1=44.224 actor=99.555 alpha=0.094
# [train] episode=675 step=103944 return=-161.52 success=False time=203.7s geometry=cross_stream history=4 | q1=356.550 actor=101.222 alpha=0.097
# [train] episode=680 step=105492 return=-281.48 success=False time=211.0s geometry=cross_stream history=4 | q1=125.661 actor=103.177 alpha=0.097
# [train] episode=685 step=107178 return=-32.44 success=False time=240.1s geometry=cross_stream history=4 | q1=2.154 actor=103.609 alpha=0.097
# [train] episode=690 step=109236 return=-329.29 success=False time=202.2s geometry=cross_stream history=4 | q1=47.827 actor=104.670 alpha=0.099
# [train] episode=695 step=110712 return=-293.84 success=False time=122.5s geometry=cross_stream history=4 | q1=173.050 actor=103.901 alpha=0.102
# [train] episode=700 step=111966 return=-375.57 success=False time=178.7s geometry=cross_stream history=4 | q1=56.276 actor=103.770 alpha=0.104
# [train] episode=705 step=112866 return=-261.31 success=False time=6.4s geometry=cross_stream history=4 | q1=16.263 actor=103.290 alpha=0.104
# [train] episode=710 step=114450 return=-435.56 success=False time=151.8s geometry=cross_stream history=4 | q1=60.747 actor=105.694 alpha=0.103
# [train] episode=715 step=116046 return=-310.74 success=False time=240.1s geometry=cross_stream history=4 | q1=182.722 actor=112.186 alpha=0.102
# [train] episode=720 step=116874 return=-359.40 success=False time=68.5s geometry=cross_stream history=4 | q1=5.165 actor=105.806 alpha=0.104
# [train] episode=725 step=117990 return=-266.08 success=False time=37.5s geometry=cross_stream history=4 | q1=5.857 actor=108.420 alpha=0.105
# [train] episode=730 step=119916 return=-200.84 success=False time=155.5s geometry=cross_stream history=4 | q1=12.502 actor=108.880 alpha=0.110
# [train] episode=735 step=120978 return=-306.39 success=False time=128.8s geometry=cross_stream history=4 | q1=298.934 actor=110.320 alpha=0.112
# [train] episode=740 step=122892 return=-480.17 success=False time=240.1s geometry=cross_stream history=4 | q1=236.371 actor=110.876 alpha=0.112
# [train] episode=745 step=124032 return=-313.99 success=False time=64.7s geometry=cross_stream history=4 | q1=4.260 actor=107.599 alpha=0.115
# [eval] step=125004 objective=arrival_v2 return=-235.15 safety=21.447 success=0.00% time=156.1s energy=95530.4 path=125.9 prog=-0.30
# [train] episode=750 step=125610 return=-333.86 success=False time=136.7s geometry=cross_stream history=4 | q1=50.077 actor=110.419 alpha=0.124
# [train] episode=755 step=126510 return=-216.81 success=False time=74.1s geometry=cross_stream history=4 | q1=46.165 actor=107.979 alpha=0.127
# [train] episode=760 step=129042 return=-83.33 success=False time=240.1s geometry=cross_stream history=4 | q1=138.790 actor=113.407 alpha=0.128
# [train] episode=765 step=129972 return=-242.62 success=False time=46.8s geometry=cross_stream history=4 | q1=160.743 actor=113.290 alpha=0.125
# [train] episode=770 step=131412 return=-228.96 success=False time=196.7s geometry=cross_stream history=4 | q1=106.280 actor=110.352 alpha=0.126
# [train] episode=775 step=133092 return=-299.42 success=False time=192.8s geometry=cross_stream history=4 | q1=97.993 actor=111.656 alpha=0.123
# [train] episode=780 step=135696 return=-292.46 success=False time=52.1s geometry=cross_stream history=4 | q1=91.604 actor=113.955 alpha=0.129
# [train] episode=785 step=136320 return=-291.57 success=False time=51.5s geometry=cross_stream history=4 | q1=150.938 actor=118.637 alpha=0.128
# [train] episode=790 step=137760 return=-285.38 success=False time=147.2s geometry=cross_stream history=4 | q1=91.595 actor=115.882 alpha=0.128
# [train] episode=795 step=138462 return=-319.32 success=False time=225.0s geometry=cross_stream history=4 | q1=111.126 actor=115.656 alpha=0.129
# [train] episode=800 step=139590 return=-333.72 success=False time=55.0s geometry=cross_stream history=4 | q1=106.844 actor=111.567 alpha=0.131
# [train] episode=805 step=141204 return=-69.34 success=False time=240.1s geometry=cross_stream history=4 | q1=102.705 actor=114.827 alpha=0.129
# [train] episode=810 step=142818 return=-345.78 success=False time=59.6s geometry=cross_stream history=4 | q1=197.288 actor=113.645 alpha=0.127
# [train] episode=815 step=144888 return=-285.97 success=False time=49.6s geometry=cross_stream history=4 | q1=296.025 actor=117.721 alpha=0.122
# [train] episode=820 step=146040 return=-52.67 success=False time=240.1s geometry=cross_stream history=4 | q1=10.521 actor=116.919 alpha=0.120
# [train] episode=825 step=147510 return=-120.52 success=False time=218.0s geometry=cross_stream history=4 | q1=112.066 actor=116.120 alpha=0.116
# [train] episode=830 step=148632 return=-252.98 success=False time=42.9s geometry=cross_stream history=4 | q1=121.978 actor=119.775 alpha=0.119
# [train] episode=835 step=149592 return=-63.03 success=False time=240.1s geometry=cross_stream history=4 | q1=156.658 actor=116.771 alpha=0.119
# [eval] step=150000 objective=arrival_v2 return=-228.21 safety=25.162 success=0.00% time=149.1s energy=94576.6 path=111.8 prog=-0.11
# [train] episode=840 step=150468 return=-369.69 success=False time=72.1s geometry=cross_stream history=4 | q1=175.763 actor=116.805 alpha=0.120
# [train] episode=845 step=152196 return=-100.78 success=False time=240.1s geometry=cross_stream history=4 | q1=31.873 actor=119.181 alpha=0.123
# [train] episode=850 step=153780 return=-291.79 success=False time=49.3s geometry=cross_stream history=4 | q1=278.628 actor=119.684 alpha=0.123
# [train] episode=855 step=154614 return=-330.03 success=False time=65.2s geometry=cross_stream history=4 | q1=82.132 actor=120.128 alpha=0.125
# [train] episode=860 step=156048 return=-356.46 success=False time=55.6s geometry=cross_stream history=4 | q1=134.793 actor=120.143 alpha=0.130
# [train] episode=865 step=157044 return=-64.01 success=False time=240.1s geometry=cross_stream history=4 | q1=55.031 actor=117.727 alpha=0.126
# [train] episode=870 step=158616 return=-225.99 success=False time=161.3s geometry=cross_stream history=4 | q1=37.013 actor=120.304 alpha=0.123
# [train] episode=875 step=159408 return=-307.35 success=False time=25.9s geometry=cross_stream history=4 | q1=37.278 actor=120.529 alpha=0.121
# [train] episode=880 step=161718 return=-17.68 success=False time=240.1s geometry=cross_stream history=4 | q1=104.370 actor=125.549 alpha=0.122
# [train] episode=885 step=162402 return=-329.09 success=False time=56.4s geometry=cross_stream history=4 | q1=126.825 actor=122.374 alpha=0.123
# [train] episode=890 step=163428 return=-271.55 success=False time=84.6s geometry=cross_stream history=4 | q1=16.303 actor=125.536 alpha=0.123
# [train] episode=895 step=165156 return=-166.19 success=False time=182.3s geometry=cross_stream history=4 | q1=2.640 actor=122.608 alpha=0.120
# [train] episode=900 step=166170 return=-274.52 success=False time=46.8s geometry=cross_stream history=4 | q1=83.287 actor=118.789 alpha=0.119
# [train] episode=905 step=166884 return=-342.02 success=False time=59.0s geometry=cross_stream history=4 | q1=45.874 actor=123.601 alpha=0.120
# [train] episode=910 step=168366 return=-247.91 success=False time=16.3s geometry=cross_stream history=4 | q1=40.609 actor=121.610 alpha=0.119
# [train] episode=915 step=169092 return=-257.78 success=False time=8.7s geometry=cross_stream history=4 | q1=51.684 actor=123.146 alpha=0.117
# [train] episode=920 step=170952 return=-232.94 success=False time=160.9s geometry=cross_stream history=4 | q1=53.911 actor=123.522 alpha=0.115
# [train] episode=925 step=171810 return=-272.93 success=False time=70.7s geometry=cross_stream history=4 | q1=167.245 actor=122.855 alpha=0.117
# [train] episode=930 step=173688 return=-151.82 success=False time=205.6s geometry=cross_stream history=4 | q1=17.217 actor=119.493 alpha=0.118
# [train] episode=935 step=174678 return=-342.09 success=False time=62.7s geometry=cross_stream history=4 | q1=62.788 actor=124.007 alpha=0.117
# [eval] step=175002 objective=arrival_v2 return=-200.10 safety=21.770 success=6.67% time=141.1s energy=94532.4 path=107.3 prog=-0.00
# [train] episode=940 step=176406 return=-132.83 success=False time=225.9s geometry=cross_stream history=4 | q1=53.213 actor=123.984 alpha=0.118
# [train] episode=945 step=178134 return=133.31 success=True time=192.0s geometry=cross_stream history=4 | q1=68.225 actor=126.696 alpha=0.116
# [train] episode=950 step=178806 return=-261.70 success=False time=16.9s geometry=cross_stream history=4 | q1=70.693 actor=123.743 alpha=0.115
# [train] episode=955 step=179922 return=137.47 success=True time=148.5s geometry=cross_stream history=4 | q1=56.115 actor=126.338 alpha=0.113
# [train] episode=960 step=181806 return=-157.54 success=False time=192.3s geometry=cross_stream history=4 | q1=3.134 actor=122.706 alpha=0.112
# [train] episode=965 step=182664 return=-275.58 success=False time=30.6s geometry=cross_stream history=4 | q1=48.882 actor=126.931 alpha=0.113
# [train] episode=970 step=183810 return=-344.68 success=False time=223.6s geometry=cross_stream history=4 | q1=44.793 actor=123.253 alpha=0.115
# [train] episode=975 step=185424 return=-355.69 success=False time=68.7s geometry=cross_stream history=4 | q1=20.486 actor=127.678 alpha=0.111
# [train] episode=980 step=186594 return=-78.10 success=False time=240.1s geometry=cross_stream history=4 | q1=55.771 actor=125.932 alpha=0.108
# [train] episode=985 step=187308 return=-296.92 success=False time=46.5s geometry=cross_stream history=4 | q1=38.476 actor=128.192 alpha=0.106
# [train] episode=990 step=187944 return=-462.25 success=False time=111.9s geometry=cross_stream history=4 | q1=36.332 actor=127.758 alpha=0.107
# [train] episode=995 step=189372 return=-213.71 success=False time=145.8s geometry=cross_stream history=4 | q1=80.202 actor=125.921 alpha=0.107
# [train] episode=1000 step=189990 return=-366.30 success=False time=96.1s geometry=cross_stream history=4 | q1=129.036 actor=129.457 alpha=0.107
# [train] episode=1005 step=191088 return=-309.81 success=False time=53.7s geometry=cross_stream history=4 | q1=61.397 actor=128.803 alpha=0.107
# [train] episode=1010 step=192732 return=-433.44 success=False time=106.6s geometry=cross_stream history=4 | q1=71.906 actor=125.461 alpha=0.103
# [train] episode=1015 step=193668 return=-369.12 success=False time=72.3s geometry=cross_stream history=4 | q1=46.961 actor=132.899 alpha=0.104
# [train] episode=1020 step=194958 return=-162.32 success=False time=185.0s geometry=cross_stream history=4 | q1=11.973 actor=127.572 alpha=0.102
# [train] episode=1025 step=195972 return=-221.50 success=False time=171.3s geometry=cross_stream history=4 | q1=6.317 actor=129.677 alpha=0.102
# [train] episode=1030 step=197502 return=-204.29 success=False time=153.5s geometry=cross_stream history=4 | q1=35.140 actor=125.854 alpha=0.101
# [train] episode=1035 step=198834 return=-143.44 success=False time=240.1s geometry=cross_stream history=4 | q1=119.707 actor=129.922 alpha=0.101
# [train] episode=1040 step=199740 return=-267.31 success=False time=240.1s geometry=cross_stream history=4 | q1=88.743 actor=128.149 alpha=0.101
# [eval] step=200004 objective=arrival_v2 return=-244.97 safety=19.144 success=3.33% time=142.8s energy=89423.4 path=123.8 prog=-0.53
# [train] episode=1045 step=200910 return=-149.44 success=False time=240.1s geometry=cross_stream history=4 | q1=32.696 actor=129.484 alpha=0.101
# [train] episode=1050 step=201798 return=-171.17 success=False time=202.6s geometry=cross_stream history=4 | q1=137.449 actor=128.953 alpha=0.105
# [train] episode=1055 step=203376 return=-393.82 success=False time=166.2s geometry=cross_stream history=4 | q1=7.068 actor=130.121 alpha=0.105
# [train] episode=1060 step=204492 return=-361.01 success=False time=73.9s geometry=cross_stream history=4 | q1=47.974 actor=129.468 alpha=0.106
# [train] episode=1065 step=205662 return=-259.32 success=False time=240.1s geometry=cross_stream history=4 | q1=2.124 actor=128.274 alpha=0.107
# [train] episode=1070 step=206934 return=-192.47 success=False time=240.1s geometry=cross_stream history=4 | q1=39.388 actor=129.740 alpha=0.107
# [train] episode=1075 step=208152 return=-244.90 success=False time=68.6s geometry=cross_stream history=4 | q1=11.296 actor=130.660 alpha=0.105
# [train] episode=1080 step=209520 return=-90.07 success=False time=240.1s geometry=cross_stream history=4 | q1=3.468 actor=133.598 alpha=0.107
# [train] episode=1085 step=211656 return=-408.13 success=False time=90.8s geometry=cross_stream history=4 | q1=55.491 actor=131.705 alpha=0.107
# [train] episode=1090 step=212034 return=-303.35 success=False time=30.7s geometry=cross_stream history=4 | q1=60.194 actor=130.329 alpha=0.108
# [train] episode=1095 step=213906 return=-374.11 success=False time=85.1s geometry=cross_stream history=4 | q1=28.655 actor=130.040 alpha=0.107
# [train] episode=1100 step=214848 return=-379.93 success=False time=56.8s geometry=cross_stream history=4 | q1=173.806 actor=130.152 alpha=0.105
# [train] episode=1105 step=215874 return=-230.76 success=False time=168.4s geometry=cross_stream history=4 | q1=36.755 actor=131.032 alpha=0.104
# [train] episode=1110 step=218178 return=-152.07 success=False time=240.1s geometry=cross_stream history=4 | q1=60.853 actor=135.697 alpha=0.106
# [train] episode=1115 step=219504 return=-104.83 success=False time=240.1s geometry=cross_stream history=4 | q1=118.745 actor=133.796 alpha=0.108
# [train] episode=1120 step=220692 return=-360.11 success=False time=67.1s geometry=cross_stream history=4 | q1=58.880 actor=133.421 alpha=0.108
# [train] episode=1125 step=222030 return=-178.58 success=False time=209.6s geometry=cross_stream history=4 | q1=134.349 actor=131.756 alpha=0.107
# [train] episode=1130 step=222768 return=-288.28 success=False time=155.6s geometry=cross_stream history=4 | q1=69.886 actor=133.772 alpha=0.107
# [train] episode=1135 step=223830 return=133.05 success=True time=214.5s geometry=cross_stream history=4 | q1=63.775 actor=138.210 alpha=0.105
# [eval] step=225000 objective=arrival_v2 return=-193.78 safety=24.141 success=6.67% time=147.1s energy=99980.9 path=109.2 prog=0.12
# [train] episode=1140 step=226308 return=-263.58 success=False time=27.6s geometry=cross_stream history=4 | q1=268.521 actor=135.503 alpha=0.105
# [train] episode=1145 step=227112 return=-315.90 success=False time=51.0s geometry=cross_stream history=4 | q1=63.864 actor=131.779 alpha=0.105
# [train] episode=1150 step=228042 return=-224.96 success=False time=41.0s geometry=cross_stream history=4 | q1=22.205 actor=130.624 alpha=0.104
# [train] episode=1155 step=229734 return=-245.74 success=False time=18.3s geometry=cross_stream history=4 | q1=28.863 actor=133.369 alpha=0.101
# [train] episode=1160 step=230886 return=-137.45 success=False time=240.1s geometry=cross_stream history=4 | q1=59.626 actor=131.910 alpha=0.101
# [train] episode=1165 step=232332 return=118.96 success=True time=162.4s geometry=cross_stream history=4 | q1=3.836 actor=133.903 alpha=0.102
# [train] episode=1170 step=233148 return=-246.66 success=False time=12.9s geometry=cross_stream history=4 | q1=2.803 actor=133.998 alpha=0.103
# [train] episode=1175 step=234030 return=-173.67 success=False time=206.0s geometry=cross_stream history=4 | q1=3.528 actor=129.565 alpha=0.105
# [train] episode=1180 step=236040 return=-38.91 success=False time=240.1s geometry=cross_stream history=4 | q1=29.433 actor=134.891 alpha=0.102
# [train] episode=1185 step=236868 return=-348.29 success=False time=68.1s geometry=cross_stream history=4 | q1=32.267 actor=135.097 alpha=0.102
# [train] episode=1190 step=238194 return=-334.40 success=False time=57.6s geometry=cross_stream history=4 | q1=66.642 actor=133.267 alpha=0.104
# [train] episode=1195 step=239100 return=-283.80 success=False time=48.3s geometry=cross_stream history=4 | q1=2.449 actor=130.965 alpha=0.104
# [train] episode=1200 step=240054 return=-278.04 success=False time=48.5s geometry=cross_stream history=4 | q1=62.777 actor=132.299 alpha=0.102
# [train] episode=1205 step=242412 return=-190.75 success=False time=220.4s geometry=cross_stream history=4 | q1=7.547 actor=131.359 alpha=0.101
# [train] episode=1210 step=243306 return=-362.32 success=False time=71.1s geometry=cross_stream history=4 | q1=58.991 actor=136.529 alpha=0.100
# [train] episode=1215 step=244056 return=-253.15 success=False time=10.9s geometry=cross_stream history=4 | q1=2.456 actor=135.466 alpha=0.101
# [train] episode=1220 step=245682 return=-139.83 success=False time=217.6s geometry=cross_stream history=4 | q1=115.776 actor=137.233 alpha=0.103
# [train] episode=1225 step=246600 return=-210.91 success=False time=240.1s geometry=cross_stream history=4 | q1=24.601 actor=130.693 alpha=0.103
# [train] episode=1230 step=248586 return=-181.87 success=False time=240.1s geometry=cross_stream history=4 | q1=58.839 actor=132.965 alpha=0.106
# [train] episode=1235 step=249780 return=-281.30 success=False time=53.0s geometry=cross_stream history=4 | q1=41.069 actor=139.662 alpha=0.108
# [eval] step=250002 objective=arrival_v2 return=-213.56 safety=22.366 success=6.67% time=141.6s energy=91284.9 path=110.6 prog=-0.10
# [train] episode=1240 step=250620 return=-51.11 success=False time=240.1s geometry=cross_stream history=4 | q1=23.567 actor=136.830 alpha=0.108
# [train] episode=1245 step=251970 return=-275.84 success=False time=176.8s geometry=cross_stream history=4 | q1=41.679 actor=137.276 alpha=0.107
# [train] episode=1250 step=252702 return=-237.85 success=False time=160.8s geometry=cross_stream history=4 | q1=92.945 actor=135.750 alpha=0.107
# [train] episode=1255 step=254214 return=136.47 success=True time=134.9s geometry=cross_stream history=4 | q1=61.386 actor=132.956 alpha=0.109
# [train] episode=1260 step=256086 return=-118.15 success=False time=240.1s geometry=cross_stream history=4 | q1=66.264 actor=135.109 alpha=0.104
# [train] episode=1265 step=257466 return=-305.07 success=False time=31.1s geometry=cross_stream history=4 | q1=1.990 actor=135.052 alpha=0.102
# [train] episode=1270 step=258708 return=-358.61 success=False time=61.3s geometry=cross_stream history=4 | q1=4.179 actor=137.456 alpha=0.100
# [train] episode=1275 step=260256 return=-72.48 success=False time=240.1s geometry=cross_stream history=4 | q1=15.351 actor=138.878 alpha=0.100
# [train] episode=1280 step=261240 return=-230.44 success=False time=12.9s geometry=cross_stream history=4 | q1=83.301 actor=136.413 alpha=0.099
# [train] episode=1285 step=262182 return=-364.86 success=False time=70.5s geometry=cross_stream history=4 | q1=52.538 actor=133.454 alpha=0.099
# [train] episode=1290 step=263178 return=-404.92 success=False time=82.1s geometry=cross_stream history=4 | q1=22.120 actor=137.932 alpha=0.099
# [train] episode=1295 step=264120 return=-268.72 success=False time=65.4s geometry=cross_stream history=4 | q1=12.110 actor=136.180 alpha=0.100
# [train] episode=1300 step=265980 return=-317.09 success=False time=154.3s geometry=cross_stream history=4 | q1=126.323 actor=138.626 alpha=0.101
# [train] episode=1305 step=266988 return=-388.94 success=False time=97.8s geometry=cross_stream history=4 | q1=186.886 actor=136.417 alpha=0.103
# [train] episode=1310 step=268188 return=-345.94 success=False time=52.6s geometry=cross_stream history=4 | q1=12.402 actor=142.213 alpha=0.099
# [train] episode=1315 step=269514 return=-370.79 success=False time=72.2s geometry=cross_stream history=4 | q1=71.964 actor=139.749 alpha=0.098
# [train] episode=1320 step=270630 return=-248.85 success=False time=108.0s geometry=cross_stream history=4 | q1=175.708 actor=141.253 alpha=0.100
# [train] episode=1325 step=271416 return=-289.44 success=False time=66.0s geometry=cross_stream history=4 | q1=27.692 actor=140.424 alpha=0.099
# [train] episode=1330 step=273066 return=-273.88 success=False time=154.9s geometry=cross_stream history=4 | q1=2.655 actor=140.307 alpha=0.100
# [train] episode=1335 step=274572 return=-279.42 success=False time=124.6s geometry=cross_stream history=4 | q1=30.839 actor=140.531 alpha=0.100
# [eval] step=275004 objective=arrival_v2 return=-190.01 safety=27.829 success=20.00% time=132.3s energy=86810.0 path=105.0 prog=-0.08
# [train] episode=1340 step=275304 return=-259.28 success=False time=54.9s geometry=cross_stream history=4 | q1=50.500 actor=138.516 alpha=0.099
# [train] episode=1345 step=276462 return=-218.87 success=False time=144.2s geometry=cross_stream history=4 | q1=139.589 actor=140.020 alpha=0.098
# [train] episode=1350 step=276990 return=-405.58 success=False time=84.9s geometry=cross_stream history=4 | q1=3.283 actor=141.799 alpha=0.099
# [train] episode=1355 step=278766 return=-234.55 success=False time=167.7s geometry=cross_stream history=4 | q1=13.893 actor=141.433 alpha=0.098
# [train] episode=1360 step=280104 return=142.34 success=True time=110.8s geometry=cross_stream history=4 | q1=80.776 actor=134.574 alpha=0.099
# [train] episode=1365 step=281154 return=-353.44 success=False time=71.6s geometry=cross_stream history=4 | q1=5.481 actor=144.409 alpha=0.098
# [train] episode=1370 step=282234 return=-242.84 success=False time=8.9s geometry=cross_stream history=4 | q1=51.013 actor=141.606 alpha=0.097
# [train] episode=1375 step=282732 return=-227.94 success=False time=40.6s geometry=cross_stream history=4 | q1=29.022 actor=142.462 alpha=0.099
# [train] episode=1380 step=283602 return=-271.84 success=False time=30.2s geometry=cross_stream history=4 | q1=73.867 actor=141.275 alpha=0.098
# [train] episode=1385 step=284826 return=-393.13 success=False time=78.3s geometry=cross_stream history=4 | q1=33.149 actor=141.809 alpha=0.096
# [train] episode=1390 step=285744 return=-259.98 success=False time=178.0s geometry=cross_stream history=4 | q1=65.353 actor=137.777 alpha=0.096
# [train] episode=1395 step=287406 return=-250.13 success=False time=15.0s geometry=cross_stream history=4 | q1=72.455 actor=139.930 alpha=0.096
# [train] episode=1400 step=288402 return=-218.39 success=False time=33.9s geometry=cross_stream history=4 | q1=42.738 actor=142.546 alpha=0.095
# [train] episode=1405 step=289710 return=-245.33 success=False time=41.1s geometry=cross_stream history=4 | q1=16.990 actor=139.109 alpha=0.094
# [train] episode=1410 step=290844 return=-150.05 success=False time=156.4s geometry=cross_stream history=4 | q1=18.187 actor=137.430 alpha=0.095
# [train] episode=1415 step=292488 return=137.66 success=True time=105.6s geometry=cross_stream history=4 | q1=99.766 actor=139.517 alpha=0.095
# [train] episode=1420 step=293628 return=-316.16 success=False time=57.1s geometry=cross_stream history=4 | q1=85.290 actor=141.781 alpha=0.095
# [train] episode=1425 step=294816 return=-224.99 success=False time=14.1s geometry=cross_stream history=4 | q1=28.091 actor=138.333 alpha=0.096
# [train] episode=1430 step=295656 return=-271.50 success=False time=234.9s geometry=cross_stream history=4 | q1=2.790 actor=137.926 alpha=0.097
# [train] episode=1435 step=296382 return=-276.20 success=False time=130.0s geometry=cross_stream history=4 | q1=49.099 actor=143.162 alpha=0.096
# [train] episode=1440 step=297132 return=-223.94 success=False time=114.4s geometry=cross_stream history=4 | q1=44.505 actor=147.116 alpha=0.095
# [train] episode=1445 step=298650 return=-232.40 success=False time=101.6s geometry=cross_stream history=4 | q1=6.274 actor=146.950 alpha=0.094
# [train] episode=1450 step=299118 return=-326.30 success=False time=38.5s geometry=cross_stream history=4 | q1=35.981 actor=141.302 alpha=0.093
# [eval] step=300000 objective=arrival_v2 return=-125.81 safety=16.938 success=30.00% time=131.5s energy=88984.9 path=98.0 prog=0.17
# [train] episode=1455 step=301356 return=106.47 success=True time=140.6s geometry=cross_stream history=4 | q1=32.882 actor=139.293 alpha=0.096
# [train] episode=1460 step=301770 return=131.17 success=True time=128.9s geometry=cross_stream history=4 | q1=2.456 actor=139.333 alpha=0.095
# [train] episode=1465 step=302784 return=-413.41 success=False time=97.5s geometry=cross_stream history=4 | q1=3.121 actor=140.169 alpha=0.097
# [train] episode=1470 step=304236 return=-282.59 success=False time=217.2s geometry=cross_stream history=4 | q1=21.077 actor=142.705 alpha=0.095
# [train] episode=1475 step=304956 return=-366.80 success=False time=60.6s geometry=cross_stream history=4 | q1=17.788 actor=138.389 alpha=0.096
# [train] episode=1480 step=305916 return=-350.45 success=False time=59.8s geometry=cross_stream history=4 | q1=4.122 actor=145.946 alpha=0.096
# [train] episode=1485 step=306924 return=-318.37 success=False time=113.1s geometry=cross_stream history=4 | q1=58.483 actor=138.401 alpha=0.097
# [train] episode=1490 step=308808 return=-105.96 success=False time=240.1s geometry=cross_stream history=4 | q1=14.541 actor=141.434 alpha=0.098
# [train] episode=1495 step=309798 return=-278.26 success=False time=92.3s geometry=cross_stream history=4 | q1=36.380 actor=144.510 alpha=0.096
# [train] episode=1500 step=310422 return=-321.53 success=False time=60.2s geometry=cross_stream history=4 | q1=74.352 actor=144.848 alpha=0.096
# [train] episode=1505 step=312222 return=135.48 success=True time=158.6s geometry=cross_stream history=4 | q1=16.864 actor=139.465 alpha=0.096
# [train] episode=1510 step=313134 return=-252.89 success=False time=38.3s geometry=cross_stream history=4 | q1=3.067 actor=138.242 alpha=0.096
# [train] episode=1515 step=314448 return=-206.41 success=False time=127.0s geometry=cross_stream history=4 | q1=204.909 actor=138.721 alpha=0.096
# [train] episode=1520 step=316026 return=-123.13 success=False time=240.1s geometry=cross_stream history=4 | q1=61.238 actor=139.829 alpha=0.096
# [train] episode=1525 step=318054 return=-349.83 success=False time=77.3s geometry=cross_stream history=4 | q1=2.567 actor=145.563 alpha=0.099
# [train] episode=1530 step=319308 return=-173.29 success=False time=231.7s geometry=cross_stream history=4 | q1=69.833 actor=144.203 alpha=0.099
# [train] episode=1535 step=319932 return=130.63 success=True time=132.9s geometry=cross_stream history=4 | q1=18.107 actor=143.011 alpha=0.100
# [train] episode=1540 step=321456 return=-310.68 success=False time=57.1s geometry=cross_stream history=4 | q1=25.930 actor=138.738 alpha=0.102
# [train] episode=1545 step=322200 return=-391.18 success=False time=81.0s geometry=cross_stream history=4 | q1=2.385 actor=141.638 alpha=0.103
# [train] episode=1550 step=324156 return=132.53 success=True time=162.2s geometry=cross_stream history=4 | q1=49.124 actor=143.881 alpha=0.102
# [train] episode=1555 step=324528 return=-103.96 success=False time=240.1s geometry=cross_stream history=4 | q1=8.532 actor=143.407 alpha=0.104
# [eval] step=325002 objective=arrival_v2 return=-163.25 safety=21.075 success=16.67% time=133.6s energy=92350.5 path=103.0 prog=0.22
# [train] episode=1560 step=326178 return=140.05 success=True time=119.2s geometry=cross_stream history=4 | q1=43.596 actor=138.532 alpha=0.106
# [train] episode=1565 step=327810 return=-365.26 success=False time=236.0s geometry=cross_stream history=4 | q1=161.171 actor=142.769 alpha=0.105
# [train] episode=1570 step=329070 return=-99.71 success=False time=240.1s geometry=cross_stream history=4 | q1=104.758 actor=140.345 alpha=0.104
# [train] episode=1575 step=330828 return=-222.83 success=False time=42.8s geometry=cross_stream history=4 | q1=25.908 actor=142.096 alpha=0.106
# [train] episode=1580 step=331530 return=-218.31 success=False time=57.7s geometry=cross_stream history=4 | q1=34.005 actor=142.231 alpha=0.106
# [train] episode=1585 step=332682 return=-383.07 success=False time=68.0s geometry=cross_stream history=4 | q1=14.083 actor=147.500 alpha=0.108
# [train] episode=1590 step=334056 return=-267.76 success=False time=35.9s geometry=cross_stream history=4 | q1=26.951 actor=144.786 alpha=0.108
# [train] episode=1595 step=335388 return=117.77 success=True time=109.2s geometry=cross_stream history=4 | q1=4.577 actor=145.853 alpha=0.109
# [train] episode=1600 step=336726 return=-365.99 success=False time=57.6s geometry=cross_stream history=4 | q1=21.223 actor=144.000 alpha=0.107
# [train] episode=1605 step=338028 return=-361.57 success=False time=71.6s geometry=cross_stream history=4 | q1=5.602 actor=143.346 alpha=0.108
# [train] episode=1610 step=338946 return=-391.59 success=False time=65.2s geometry=cross_stream history=4 | q1=12.009 actor=144.558 alpha=0.107
# [train] episode=1615 step=340968 return=-251.29 success=False time=37.7s geometry=cross_stream history=4 | q1=72.867 actor=144.004 alpha=0.106
# [train] episode=1620 step=342060 return=-316.34 success=False time=174.3s geometry=cross_stream history=4 | q1=17.868 actor=141.556 alpha=0.105
# [train] episode=1625 step=343164 return=-243.72 success=False time=81.1s geometry=cross_stream history=4 | q1=46.486 actor=143.298 alpha=0.104
# [train] episode=1630 step=343860 return=-312.03 success=False time=52.9s geometry=cross_stream history=4 | q1=8.130 actor=144.788 alpha=0.104
# [train] episode=1635 step=345672 return=134.29 success=True time=102.7s geometry=cross_stream history=4 | q1=189.136 actor=143.239 alpha=0.103
# ...
# [train] episode=3540 step=857064 return=141.69 success=True time=79.4s geometry=cross_stream history=4 | q1=67.584 actor=123.282 alpha=0.124
# [train] episode=3545 step=858642 return=-33.50 success=False time=240.1s geometry=cross_stream history=4 | q1=12.667 actor=120.943 alpha=0.121
# [train] episode=3550 step=859842 return=-39.03 success=False time=240.1s geometry=cross_stream history=4 | q1=2.862 actor=122.044 alpha=0.120
# [train] episode=3555 step=860760 return=139.72 success=True time=77.4s geometry=cross_stream history=4 | q1=45.859 actor=123.343 alpha=0.119
# [train] episode=3560 step=861912 return=97.10 success=True time=124.4s geometry=cross_stream history=4 | q1=9.151 actor=119.724 alpha=0.121
# [train] episode=3565 step=863394 return=-243.96 success=False time=16.4s geometry=cross_stream history=4 | q1=2.822 actor=122.459 alpha=0.124
# [train] episode=3570 step=864198 return=-76.81 success=False time=240.1s geometry=cross_stream history=4 | q1=3.703 actor=118.685 alpha=0.122
# [train] episode=3575 step=865164 return=134.86 success=True time=118.0s geometry=cross_stream history=4 | q1=14.624 actor=119.207 alpha=0.120
# [train] episode=3580 step=866952 return=-308.05 success=False time=61.9s geometry=cross_stream history=4 | q1=27.817 actor=124.901 alpha=0.118
# [train] episode=3585 step=868014 return=-52.65 success=False time=240.1s geometry=cross_stream history=4 | q1=34.035 actor=118.382 alpha=0.119
# [train] episode=3590 step=870834 return=-73.98 success=False time=240.1s geometry=cross_stream history=4 | q1=4.443 actor=122.288 alpha=0.119
# [train] episode=3595 step=871872 return=-242.38 success=False time=82.8s geometry=cross_stream history=4 | q1=48.466 actor=120.111 alpha=0.119
# [train] episode=3600 step=872874 return=-70.27 success=False time=240.1s geometry=cross_stream history=4 | q1=28.547 actor=123.394 alpha=0.121
# [eval] step=875004 objective=arrival_v2 return=-56.69 safety=13.234 success=33.33% time=147.6s energy=102368.1 path=109.0 prog=0.57
# [train] episode=3605 step=875130 return=-220.57 success=False time=87.4s geometry=cross_stream history=4 | q1=3.735 actor=121.831 alpha=0.117
# [train] episode=3610 step=877656 return=-104.25 success=False time=240.1s geometry=cross_stream history=4 | q1=10.295 actor=117.547 alpha=0.118
# [train] episode=3615 step=878790 return=-54.45 success=False time=240.1s geometry=cross_stream history=4 | q1=3.962 actor=123.182 alpha=0.123
# [train] episode=3620 step=880212 return=-303.91 success=False time=55.4s geometry=cross_stream history=4 | q1=159.369 actor=122.644 alpha=0.121
# [train] episode=3625 step=881310 return=-38.17 success=False time=240.1s geometry=cross_stream history=4 | q1=3.478 actor=120.585 alpha=0.119
# [train] episode=3630 step=882108 return=-349.38 success=False time=65.7s geometry=cross_stream history=4 | q1=16.933 actor=124.183 alpha=0.121
# [train] episode=3635 step=882876 return=-91.75 success=False time=240.1s geometry=cross_stream history=4 | q1=20.601 actor=119.525 alpha=0.121
# [train] episode=3640 step=884172 return=-50.22 success=False time=240.1s geometry=cross_stream history=4 | q1=158.801 actor=126.681 alpha=0.121
# [train] episode=3645 step=885918 return=-246.61 success=False time=11.9s geometry=cross_stream history=4 | q1=7.238 actor=117.622 alpha=0.120
# [train] episode=3650 step=887460 return=-42.59 success=False time=240.1s geometry=cross_stream history=4 | q1=27.525 actor=122.855 alpha=0.122
# [train] episode=3655 step=888642 return=-359.37 success=False time=69.1s geometry=cross_stream history=4 | q1=2.921 actor=123.743 alpha=0.120
# [train] episode=3660 step=889314 return=-213.18 success=False time=82.0s geometry=cross_stream history=4 | q1=138.575 actor=119.853 alpha=0.121
# [train] episode=3665 step=891702 return=-82.03 success=False time=240.1s geometry=cross_stream history=4 | q1=2.704 actor=122.058 alpha=0.118
# [train] episode=3670 step=893136 return=-48.01 success=False time=240.1s geometry=cross_stream history=4 | q1=12.308 actor=120.052 alpha=0.116
# [train] episode=3675 step=894552 return=-260.99 success=False time=32.4s geometry=cross_stream history=4 | q1=40.524 actor=123.968 alpha=0.115
# [train] episode=3680 step=895962 return=-58.23 success=False time=240.1s geometry=cross_stream history=4 | q1=77.565 actor=121.956 alpha=0.113
# [train] episode=3685 step=897300 return=-86.72 success=False time=240.1s geometry=cross_stream history=4 | q1=52.906 actor=121.182 alpha=0.119
# [train] episode=3690 step=898122 return=142.56 success=True time=92.0s geometry=cross_stream history=4 | q1=11.266 actor=120.589 alpha=0.120
# [eval] step=900000 objective=arrival_v2 return=-42.55 safety=9.809 success=33.33% time=138.2s energy=96576.8 path=109.0 prog=0.63
# [train] episode=3695 step=900054 return=141.49 success=True time=65.9s geometry=cross_stream history=4 | q1=11.689 actor=119.920 alpha=0.120
# [train] episode=3700 step=901272 return=-465.74 success=False time=101.0s geometry=cross_stream history=4 | q1=12.073 actor=121.246 alpha=0.117
# [train] episode=3705 step=901998 return=-254.96 success=False time=12.4s geometry=cross_stream history=4 | q1=9.296 actor=117.672 alpha=0.116
# [train] episode=3710 step=902778 return=111.91 success=True time=121.4s geometry=cross_stream history=4 | q1=130.032 actor=119.146 alpha=0.116
# [train] episode=3715 step=903414 return=139.10 success=True time=102.4s geometry=cross_stream history=4 | q1=11.689 actor=123.810 alpha=0.115
# [train] episode=3720 step=904518 return=-246.07 success=False time=12.1s geometry=cross_stream history=4 | q1=39.599 actor=118.310 alpha=0.113
# [train] episode=3725 step=905976 return=-77.16 success=False time=240.1s geometry=cross_stream history=4 | q1=48.890 actor=115.397 alpha=0.108
# [train] episode=3730 step=906876 return=-249.04 success=False time=10.7s geometry=cross_stream history=4 | q1=15.985 actor=116.481 alpha=0.109
# [train] episode=3735 step=907854 return=-35.31 success=False time=240.1s geometry=cross_stream history=4 | q1=25.063 actor=122.149 alpha=0.110
# [train] episode=3740 step=908952 return=139.49 success=True time=51.1s geometry=cross_stream history=4 | q1=43.279 actor=124.261 alpha=0.113
# [train] episode=3745 step=910476 return=-48.39 success=False time=240.1s geometry=cross_stream history=4 | q1=5.653 actor=121.125 alpha=0.113
# [train] episode=3750 step=911286 return=-67.15 success=False time=240.1s geometry=cross_stream history=4 | q1=41.959 actor=120.219 alpha=0.115
# [train] episode=3755 step=911856 return=138.03 success=True time=78.3s geometry=cross_stream history=4 | q1=64.766 actor=117.085 alpha=0.115
# [train] episode=3760 step=913278 return=-178.54 success=False time=101.5s geometry=cross_stream history=4 | q1=3.623 actor=122.305 alpha=0.113
# [train] episode=3765 step=914412 return=-211.19 success=False time=93.9s geometry=cross_stream history=4 | q1=56.621 actor=115.763 alpha=0.112
# [train] episode=3770 step=914874 return=-355.68 success=False time=62.5s geometry=cross_stream history=4 | q1=33.303 actor=122.877 alpha=0.113
# [train] episode=3775 step=916236 return=78.94 success=True time=78.6s geometry=cross_stream history=4 | q1=20.697 actor=121.453 alpha=0.111
# [train] episode=3780 step=917496 return=-228.40 success=False time=104.4s geometry=cross_stream history=4 | q1=8.214 actor=119.649 alpha=0.110
# [train] episode=3785 step=918630 return=138.83 success=True time=37.5s geometry=cross_stream history=4 | q1=3.179 actor=120.720 alpha=0.114
# [train] episode=3790 step=920850 return=133.46 success=True time=49.4s geometry=cross_stream history=4 | q1=123.269 actor=116.274 alpha=0.113
# [train] episode=3795 step=921864 return=-78.34 success=False time=240.1s geometry=cross_stream history=4 | q1=152.956 actor=121.639 alpha=0.114
# [train] episode=3800 step=922542 return=143.14 success=True time=55.9s geometry=cross_stream history=4 | q1=33.764 actor=122.878 alpha=0.114
# [train] episode=3805 step=923940 return=-279.95 success=False time=48.3s geometry=cross_stream history=4 | q1=5.282 actor=121.190 alpha=0.117
# [eval] step=925002 objective=arrival_v2 return=-113.66 safety=21.715 success=16.67% time=147.7s energy=104474.5 path=109.5 prog=0.55
# [train] episode=3810 step=925074 return=-235.00 success=False time=34.9s geometry=cross_stream history=4 | q1=8.490 actor=119.866 alpha=0.119
# [train] episode=3815 step=925752 return=140.80 success=True time=55.9s geometry=cross_stream history=4 | q1=2.202 actor=118.513 alpha=0.119
# [train] episode=3820 step=926784 return=-194.67 success=False time=46.3s geometry=cross_stream history=4 | q1=6.984 actor=116.975 alpha=0.118
# [train] episode=3825 step=928782 return=-77.74 success=False time=240.1s geometry=cross_stream history=4 | q1=21.161 actor=119.457 alpha=0.117
# [train] episode=3830 step=930306 return=-351.16 success=False time=64.1s geometry=cross_stream history=4 | q1=10.176 actor=121.441 alpha=0.116
# [train] episode=3835 step=931302 return=-77.09 success=False time=240.1s geometry=cross_stream history=4 | q1=31.703 actor=124.146 alpha=0.113
# [train] episode=3840 step=932850 return=-77.59 success=False time=240.1s geometry=cross_stream history=4 | q1=5.868 actor=118.048 alpha=0.108
# [train] episode=3845 step=934332 return=120.72 success=True time=122.9s geometry=cross_stream history=4 | q1=175.730 actor=117.141 alpha=0.113
# [train] episode=3850 step=935478 return=-477.69 success=False time=115.5s geometry=cross_stream history=4 | q1=36.557 actor=119.680 alpha=0.112
# [train] episode=3855 step=936132 return=-263.58 success=False time=11.1s geometry=cross_stream history=4 | q1=4.576 actor=116.440 alpha=0.110
# [train] episode=3860 step=938724 return=140.19 success=True time=51.6s geometry=cross_stream history=4 | q1=5.121 actor=117.890 alpha=0.111
# [train] episode=3865 step=939456 return=139.50 success=True time=60.2s geometry=cross_stream history=4 | q1=2.413 actor=117.747 alpha=0.109
# [train] episode=3870 step=941280 return=-64.26 success=False time=240.1s geometry=cross_stream history=4 | q1=54.932 actor=118.245 alpha=0.105
# [train] episode=3875 step=942714 return=-321.72 success=False time=65.9s geometry=cross_stream history=4 | q1=2.451 actor=123.327 alpha=0.107
# [train] episode=3880 step=944280 return=-95.88 success=False time=240.1s geometry=cross_stream history=4 | q1=140.293 actor=118.884 alpha=0.106
# [train] episode=3885 step=946392 return=-68.73 success=False time=240.1s geometry=cross_stream history=4 | q1=11.339 actor=118.797 alpha=0.102
# [train] episode=3890 step=947136 return=-259.09 success=False time=6.6s geometry=cross_stream history=4 | q1=2.630 actor=122.165 alpha=0.104
# [train] episode=3895 step=947958 return=-255.93 success=False time=6.4s geometry=cross_stream history=4 | q1=173.320 actor=114.899 alpha=0.105
# [eval] step=950004 objective=arrival_v2 return=-99.77 safety=24.450 success=26.67% time=149.9s energy=105096.1 path=111.5 prog=0.51
# [train] episode=3900 step=950700 return=-87.02 success=False time=240.1s geometry=cross_stream history=4 | q1=6.762 actor=118.335 alpha=0.106
# [train] episode=3905 step=952170 return=-206.97 success=False time=109.1s geometry=cross_stream history=4 | q1=22.831 actor=118.073 alpha=0.105
# [train] episode=3910 step=953850 return=43.27 success=True time=139.2s geometry=cross_stream history=4 | q1=30.589 actor=115.022 alpha=0.106
# [train] episode=3915 step=955638 return=-324.38 success=False time=79.9s geometry=cross_stream history=4 | q1=3.152 actor=118.428 alpha=0.105
# [train] episode=3920 step=957342 return=-52.16 success=False time=240.1s geometry=cross_stream history=4 | q1=14.957 actor=121.449 alpha=0.103
# [train] episode=3925 step=958704 return=-88.87 success=False time=240.1s geometry=cross_stream history=4 | q1=17.635 actor=113.595 alpha=0.101
# [train] episode=3930 step=960072 return=-346.96 success=False time=66.7s geometry=cross_stream history=4 | q1=11.003 actor=116.996 alpha=0.107
# [train] episode=3935 step=961242 return=-187.07 success=False time=83.1s geometry=cross_stream history=4 | q1=2.768 actor=116.995 alpha=0.106
# [train] episode=3940 step=963618 return=-75.50 success=False time=240.1s geometry=cross_stream history=4 | q1=4.897 actor=119.365 alpha=0.109
# [train] episode=3945 step=965844 return=-68.25 success=False time=240.1s geometry=cross_stream history=4 | q1=129.864 actor=117.224 alpha=0.113
# [train] episode=3950 step=967026 return=-71.35 success=False time=240.1s geometry=cross_stream history=4 | q1=133.383 actor=119.637 alpha=0.113
# [train] episode=3955 step=967908 return=-256.92 success=False time=4.9s geometry=cross_stream history=4 | q1=4.593 actor=117.849 alpha=0.110
# [train] episode=3960 step=969570 return=-263.33 success=False time=58.1s geometry=cross_stream history=4 | q1=49.463 actor=111.975 alpha=0.108
# [train] episode=3965 step=970800 return=-76.03 success=False time=240.1s geometry=cross_stream history=4 | q1=13.255 actor=114.442 alpha=0.107
# [train] episode=3970 step=972816 return=-84.89 success=False time=240.1s geometry=cross_stream history=4 | q1=152.152 actor=116.164 alpha=0.106
# [train] episode=3975 step=973560 return=129.06 success=True time=61.4s geometry=cross_stream history=4 | q1=5.580 actor=113.954 alpha=0.104
# [eval] step=975000 objective=arrival_v2 return=-50.35 safety=13.030 success=36.67% time=129.0s energy=95644.0 path=106.6 prog=0.58
# [train] episode=3980 step=975120 return=139.95 success=True time=77.7s geometry=cross_stream history=4 | q1=42.368 actor=119.869 alpha=0.103
# [train] episode=3985 step=976284 return=-65.93 success=False time=240.1s geometry=cross_stream history=4 | q1=35.678 actor=119.773 alpha=0.102
# [train] episode=3990 step=977592 return=-344.04 success=False time=65.3s geometry=cross_stream history=4 | q1=184.184 actor=119.536 alpha=0.103
# [train] episode=3995 step=978636 return=-256.10 success=False time=7.2s geometry=cross_stream history=4 | q1=35.368 actor=112.376 alpha=0.102
# [train] episode=4000 step=979860 return=-177.16 success=False time=240.1s geometry=cross_stream history=4 | q1=29.911 actor=115.970 alpha=0.105
# [train] episode=4005 step=981360 return=-95.76 success=False time=240.1s geometry=cross_stream history=4 | q1=101.020 actor=115.492 alpha=0.104
# [train] episode=4010 step=981954 return=-245.45 success=False time=35.6s geometry=cross_stream history=4 | q1=16.462 actor=115.727 alpha=0.100
# [train] episode=4015 step=982740 return=125.04 success=True time=52.9s geometry=cross_stream history=4 | q1=27.071 actor=112.484 alpha=0.098
# [train] episode=4020 step=985428 return=-86.28 success=False time=240.1s geometry=cross_stream history=4 | q1=138.087 actor=109.954 alpha=0.100
# [train] episode=4025 step=986646 return=-85.51 success=False time=240.1s geometry=cross_stream history=4 | q1=40.826 actor=113.661 alpha=0.102
# [train] episode=4030 step=988032 return=-230.49 success=False time=58.7s geometry=cross_stream history=4 | q1=4.170 actor=121.686 alpha=0.104
# [train] episode=4035 step=988830 return=-199.13 success=False time=58.3s geometry=cross_stream history=4 | q1=2.955 actor=112.057 alpha=0.107
# [train] episode=4040 step=989556 return=138.77 success=True time=59.9s geometry=cross_stream history=4 | q1=8.418 actor=117.345 alpha=0.109
# [train] episode=4045 step=991182 return=141.03 success=True time=68.9s geometry=cross_stream history=4 | q1=106.050 actor=113.420 alpha=0.109
# [train] episode=4050 step=992160 return=-81.96 success=False time=240.1s geometry=cross_stream history=4 | q1=50.047 actor=111.323 alpha=0.110
# [train] episode=4055 step=993834 return=-81.96 success=False time=240.1s geometry=cross_stream history=4 | q1=33.495 actor=119.193 alpha=0.109
# [train] episode=4060 step=995460 return=-85.46 success=False time=240.1s geometry=cross_stream history=4 | q1=132.896 actor=113.412 alpha=0.109
# [train] episode=4065 step=997056 return=142.47 success=True time=74.3s geometry=cross_stream history=4 | q1=20.763 actor=115.070 alpha=0.108
# [train] episode=4070 step=998712 return=-202.02 success=False time=56.3s geometry=cross_stream history=4 | q1=139.581 actor=118.428 alpha=0.110

# %% [markdown]
# ## 5. Summary + gate

# %%
def summarize_phase(run_root: Path, total_steps: int, label: str, gate_filename: str):
    eval_log_path = run_root / 'results' / 'eval_log.csv'
    final_eval_path = run_root / 'results' / 'final_eval.json'
    trainer_state_path = run_root / 'trainer_state.json'
    train_config_path = run_root / 'results' / 'train_config.txt'

    if not eval_log_path.exists():
        raise FileNotFoundError(f'missing eval log: {eval_log_path}')
    if not final_eval_path.exists():
        raise FileNotFoundError(f'missing final eval: {final_eval_path}')

    df = pd.read_csv(eval_log_path)
    final_eval = json.loads(final_eval_path.read_text(encoding='utf-8'))
    trainer_state = json.loads(trainer_state_path.read_text(encoding='utf-8')) if trainer_state_path.exists() else {}

    # Parse train_config.txt for seed / history_length confirmation
    seed_from_config = 'NA'
    history_from_config = 'NA'
    asym_from_config = 'NA'
    if train_config_path.exists():
        for ln in train_config_path.read_text(encoding='utf-8').splitlines():
            s = ln.strip()
            if s.startswith('seed='):
                seed_from_config = s.split('=', 1)[1]
            elif s.startswith('history_length='):
                history_from_config = s.split('=', 1)[1]
            elif s.startswith('privileged_obs_dim='):
                # asym critic 启用时 dim=2，否则字段缺失或为 0
                asym_from_config = f'privileged_obs_dim={s.split("=", 1)[1]}'

    peak_success = float(df['eval_success_rate'].max()) if len(df) else 0.0
    peak_step = int(df.loc[df['eval_success_rate'].idxmax(), 'env_step']) if len(df) else 0
    last100 = df[df['env_step'] >= total_steps - 100_000].copy()
    last100_mean = float(last100['eval_success_rate'].mean()) if len(last100) else 0.0
    mean_all = float(df['eval_success_rate'].mean()) if len(df) else 0.0
    n_evals_with_success = int((df['eval_success_rate'] > 0).sum()) if len(df) else 0
    final_success = float(final_eval['eval_success_rate'])
    counts = final_eval.get('eval_termination_counts', {})
    num_eps = float(final_eval.get('num_eval_episodes', EVAL_EPISODES))
    oob_rate = float(counts.get('out_of_bounds', 0)) / max(num_eps, 1.0)

    print('=' * 100)
    print(f'{label}  (arrival_v2 / s0 / k=4 / vanilla / seed=0 / {total_steps:,} steps)')
    print('-' * 100)
    print(f"  final_success_rate    : {final_success:.4f}   gate >= {PASS_FINAL_SUCCESS:.2f}")
    print(f"  peak_success_rate     : {peak_success:.4f}   @ {peak_step:,}")
    print(f"  last100k_mean_success : {last100_mean:.4f}   gate >= {PASS_LAST100_RATIO * peak_success:.4f}")
    print(f"  full-traj mean        : {mean_all:.4f}   ({len(df)} evals)")
    print(f"  n_evals_with_success  : {n_evals_with_success} / {len(df)}")
    print(f"  final_oob_rate        : {oob_rate:.4f}   gate <= {PASS_OOB_RATE:.2f}")
    print(f"  obs_dim               : {trainer_state.get('observation_dim', 'NA')}   (expect 48)")
    print(f"  seed                  : {seed_from_config}   (expect 0)")
    print(f"  history_length        : {history_from_config}   (expect 4)")
    print(f"  asym_critic_marker    : {asym_from_config}   (expect 'NA' — vanilla 不写该 key)")
    print(f"  context_obs           : {trainer_state.get('include_episode_context_obs', 'NA')}")
    print(f"  timeout_bootstrap     : {trainer_state.get('timeout_bootstrap_semantics', 'NA')}")
    print(f"  termination           : {counts}")
    print('=' * 100)

    if len(df):
        print()
        print('[last 16 eval rows]')
        cols = ['env_step', 'eval_success_rate', 'eval_return', 'eval_safety_cost',
                'eval_time_s', 'eval_progress_ratio']
        available = [c for c in cols if c in df.columns]
        print(df[available].tail(16).to_string(index=False))

    checks = [
        ('final success >= 0.85', final_success >= PASS_FINAL_SUCCESS, f'{final_success:.4f}'),
        ('last100k mean >= 0.9 * peak', last100_mean >= PASS_LAST100_RATIO * peak_success,
         f'{last100_mean:.4f} / peak={peak_success:.4f}'),
        ('final OOB rate <= 0.10', oob_rate <= PASS_OOB_RATE, f'{oob_rate:.4f}'),
        ('arrival_v2 context obs enabled',
         trainer_state.get('include_episode_context_obs') is True,
         str(trainer_state.get('include_episode_context_obs'))),
        ('arrival_v2 timeout terminal semantics',
         trainer_state.get('timeout_bootstrap_semantics') == 'terminal',
         str(trainer_state.get('timeout_bootstrap_semantics'))),
    ]

    print()
    print('=' * 96)
    print(f"{'check':<48}{'pass':>8}{'detail':>40}")
    print('-' * 96)
    all_pass = True
    for name, ok, detail in checks:
        mark = 'PASS' if ok else 'FAIL'
        if not ok:
            all_pass = False
        print(f'{name:<48}{mark:>8}{detail:>40}')
    print('=' * 96)

    summary = {
        'phase': label,
        'objective': OBJECTIVE,
        'probe_layout': PROBE_LAYOUT,
        'history_length': int(history_from_config) if history_from_config != 'NA' else HISTORY_LENGTH,
        'seed': int(seed_from_config) if seed_from_config != 'NA' else SEED,
        'total_steps': total_steps,
        'algorithm': 'sac_vanilla',
        'final_success_rate': final_success,
        'peak_success_rate': peak_success,
        'peak_step': peak_step,
        'last100k_mean_success': last100_mean,
        'mean_success_full_trajectory': mean_all,
        'n_evals_with_success': n_evals_with_success,
        'n_evals_total': len(df),
        'final_oob_rate': oob_rate,
        'termination_counts': counts,
        'all_pass': bool(all_pass),
        'checks': [{'name': n, 'ok': bool(ok), 'detail': d} for n, ok, d in checks],
    }
    out_path = run_root / 'results' / gate_filename
    out_path.parent.mkdir(parents=True, exist_ok=True)
    out_path.write_text(json.dumps(summary, indent=2), encoding='utf-8')
    print(f'[saved] {out_path}')
    return summary

x_summary = summarize_phase(
    X_RUN_ROOT,
    X_TOTAL_STEPS,
    'SINGLE_CROSS_VANILLA_S0_K4_SEED0',
    'vanilla_s0_k4_seed0_gate_summary.json',
)
X_PASS = x_summary['all_pass']
print()
print(f'X_PASS = {X_PASS}')
# Out:
# ====================================================================================================
# SINGLE_CROSS_VANILLA_S0_K4_SEED0  (arrival_v2 / s0 / k=4 / vanilla / seed=0 / 1,000,000 steps)
# ----------------------------------------------------------------------------------------------------
#   final_success_rate    : 0.4000   gate >= 0.85
#   peak_success_rate     : 0.5333   @ 625,002
#   last100k_mean_success : 0.2833   gate >= 0.4800
#   full-traj mean        : 0.2179   (39 evals)
#   n_evals_with_success  : 34 / 39
#   final_oob_rate        : 0.2000   gate <= 0.10
#   obs_dim               : 48   (expect 48)
#   seed                  : 0   (expect 0)
#   history_length        : 4   (expect 4)
#   asym_critic_marker    : privileged_obs_dim=0   (expect 'NA' — vanilla 不写该 key)
#   context_obs           : True
#   timeout_bootstrap     : terminal
#   termination           : {'timeout': 12, 'out_of_bounds': 6, 'goal': 12}
# ====================================================================================================
#
# [last 16 eval rows]
#  env_step  eval_success_rate  eval_return  eval_safety_cost  eval_time_s  eval_progress_ratio
#    600000           0.166667  -117.660332         25.211311   165.480000             0.516424
#    625002           0.533333   -15.638718         16.833956   147.900000             0.709194
#    650004           0.466667   -20.660052         12.136119   144.340000             0.684216
#    675000           0.533333   -33.747746         14.376620   124.896667             0.543997
#    700002           0.266667   -71.776639         16.466556   152.326667             0.583147
#    725004           0.366667   -53.131036         12.693464   130.403333             0.549515
#    750000           0.366667   -61.425239         12.511255   128.376667             0.567077
#    775002           0.300000   -77.411069         15.188177   126.443333             0.595514
#    800004           0.266667   -86.225436         13.181303   121.290000             0.560816
#    825000           0.266667   -75.007732         13.383036   130.856667             0.627220
#    850002           0.333333   -51.902234         10.173896   130.856667             0.586355
#    875004           0.333333   -56.693375         13.233723   147.580000             0.571892
#    900000           0.333333   -42.553554          9.809299   138.186667             0.628522
#    925002           0.166667  -113.663802         21.715191   147.703333             0.547270
#    950004           0.266667   -99.774873         24.450306   149.940000             0.510683
#    975000           0.366667   -50.349029         13.030238   129.020000             0.582791
#
# ================================================================================================
# check                                               pass                                  detail
# ------------------------------------------------------------------------------------------------
# final success >= 0.85                               FAIL                                  0.4000
# last100k mean >= 0.9 * peak                         FAIL                    0.2833 / peak=0.5333
# final OOB rate <= 0.10                              FAIL                                  0.2000
# arrival_v2 context obs enabled                      PASS                                    True
# arrival_v2 timeout terminal semantics               PASS                                terminal
# ================================================================================================
# [saved] experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s0_k4/seed_0/results/vanilla_s0_k4_seed0_gate_summary.json
#
# X_PASS = False

# %% [markdown]
# ## 6. Seed-pair verdict — vanilla seed=0 vs seed=42（验证 §7.6.4 baseline 是否 seed-stable）

# %%
def read_baseline(root: Path, ref_final: float, ref_oob: float, ref_mean: float = None):
    fp = root / 'results' / 'final_eval.json'
    log = root / 'results' / 'eval_log.csv'
    out = {'final': ref_final, 'oob': ref_oob, 'mean': ref_mean, 'peak': None, 'source': 'report-fallback'}
    if fp.exists():
        d = json.loads(fp.read_text(encoding='utf-8'))
        f = float(d['eval_success_rate'])
        c = d.get('eval_termination_counts', {})
        n = float(d.get('num_eval_episodes', EVAL_EPISODES))
        out['final'] = f
        out['oob'] = float(c.get('out_of_bounds', 0)) / max(n, 1.0)
        out['source'] = 'on-disk'
    if log.exists():
        dlog = pd.read_csv(log)
        out['mean'] = float(dlog['eval_success_rate'].mean())
        out['peak'] = float(dlog['eval_success_rate'].max())
    return out

print('=' * 100)
print('VANILLA s0_k4 — paired seed verdict (seed=0 vs seed=42)')
print('-' * 100)

# 当前 seed=0 结果
v0_final = float(x_summary['final_success_rate'])
v0_oob = float(x_summary['final_oob_rate'])
v0_peak = float(x_summary['peak_success_rate'])
v0_mean = float(x_summary.get('mean_success_full_trajectory', 0.0))
v0_n_succ = int(x_summary.get('n_evals_with_success', 0))
v0_n_tot = int(x_summary.get('n_evals_total', 0))

# Baseline (§7.6.4 vanilla seed=42)
b_v42 = read_baseline(X_K4_SEED42_BASELINE,      0.100, 0.667, 0.221)
b_a42 = read_baseline(X_K4_ASYM_SEED42_BASELINE, 0.167, 0.633, 0.044)
b_a0  = read_baseline(X_K4_ASYM_SEED0_SISTER,    -1,    -1,    None)  # 姊妹 notebook
b_s1  = read_baseline(X_S1_BASELINE,             0.900, 0.100, None)

print()
print(f'{"config":<48}{"final":>10}{"mean":>10}{"oob":>10}{"source":>14}')
print('-' * 100)
print(f'{"vanilla SAC, s1_k4 seed=42 (§7.1 upper ref)":<48}{b_s1["final"]:>10.4f}{(b_s1["mean"] or float("nan")):>10.4f}{b_s1["oob"]:>10.4f}{b_s1["source"]:>14}')
print(f'{"vanilla SAC, s0_k4 seed=42 (§7.6.4 anchor)":<48}{b_v42["final"]:>10.4f}{(b_v42["mean"] or float("nan")):>10.4f}{b_v42["oob"]:>10.4f}{b_v42["source"]:>14}')
print(f'{"vanilla SAC, s0_k4 SEED=0 (this run)":<48}{v0_final:>10.4f}{v0_mean:>10.4f}{v0_oob:>10.4f}{"on-disk":>14}')
print(f'{"sac_asym,   s0_k4 seed=42 (§7.7 negative)":<48}{b_a42["final"]:>10.4f}{(b_a42["mean"] or float("nan")):>10.4f}{b_a42["oob"]:>10.4f}{b_a42["source"]:>14}')
if b_a0['source'] == 'on-disk':
    print(f'{"sac_asym,   s0_k4 SEED=0 (sister run)":<48}{b_a0["final"]:>10.4f}{(b_a0["mean"] or float("nan")):>10.4f}{b_a0["oob"]:>10.4f}{b_a0["source"]:>14}')
else:
    print(f'{"sac_asym,   s0_k4 SEED=0 (sister run)":<48}{"PENDING":>10}{"PENDING":>10}{"PENDING":>10}{"not-yet":>14}')
print('=' * 100)

# Δ 行
print()
print(f'{"contrast":<60}{"Δ final":>12}{"Δ mean":>12}{"Δ oob":>12}')
print('-' * 100)
d_final = v0_final - b_v42['final']
d_mean = v0_mean - (b_v42['mean'] or 0)
d_oob = v0_oob - b_v42['oob']
print(f'{"vanilla seed=0 vs seed=42 — paired test":<60}{d_final:>+12.4f}{d_mean:>+12.4f}{d_oob:>+12.4f}')
if b_a0['source'] == 'on-disk':
    print(f'{"asym seed=0 vs vanilla seed=0 — same-seed cross-arm":<60}'
          f'{b_a0["final"] - v0_final:>+12.4f}'
          f'{(b_a0["mean"] or 0) - v0_mean:>+12.4f}'
          f'{b_a0["oob"] - v0_oob:>+12.4f}')
print('=' * 100)
print()
print(f'seed=0 evals_with_success: {v0_n_succ} / {v0_n_tot}  (seed=42 vanilla was 35/39)')

# 判读 — 4 档 paired-seed verdict
ABS_DELTA_FINAL = abs(d_final)
ABS_DELTA_MEAN = abs(d_mean)
if v0_final >= 0.50:
    verdict = ('BREAKOUT — seed=0 final={:.3f} 显著突破 §7.6.4 anchor 的 0.100；'
               'single_cross 在 s0_k4 上未必 catastrophic FAIL，§7.6 整章 framing 需重写，'
               '§7.7 的 vanilla 对照基线被推翻 → §7.7 claim 自动失效'.format(v0_final))
elif v0_final <= 0.05 and v0_mean <= 0.10:
    verdict = ('FLOOR — seed=0 比 §7.6.4 更差（final={:.3f}, mean={:.3f}），seed=42 反而是 lucky outlier；'
               'vanilla 真实地板更低，§7.7 asym 的 negative claim 也要重写'.format(v0_final, v0_mean))
elif ABS_DELTA_FINAL <= 0.15 and ABS_DELTA_MEAN <= 0.10:
    verdict = ('REPRO — seed=0 与 seed=42 在 final/mean 上都吻合（|Δfinal|={:.3f}, |Δmean|={:.3f}）；'
               '§7.6.4 baseline seed-stable ✓。如姊妹 asym seed=0 也复现 negative → §7.7 升格为 2-seed hardened claim'
               .format(ABS_DELTA_FINAL, ABS_DELTA_MEAN))
else:
    verdict = ('HIGH-VARIANCE — |Δfinal|={:.3f} 或 |Δmean|={:.3f} 超阈值；'
               'vanilla k=4 在此任务对 seed 敏感；§7.7 negative claim 暂时冻结，需要 3rd seed (=7 或 =1)'
               .format(ABS_DELTA_FINAL, ABS_DELTA_MEAN))

print()
print(f'>>> verdict: {verdict}')

# 落盘
ablation_out = {
    'experiment': 'arrival_v2_s0_cross_vanilla_seed0_replication',
    'seed': SEED,
    'benchmark': X_BENCHMARK_KEY,
    'probe_layout': PROBE_LAYOUT,
    'history_length': HISTORY_LENGTH,
    'total_steps': X_TOTAL_STEPS,
    'algorithm': 'sac_vanilla',
    'cli_diff_vs_§7.6.4_baseline': '--seed 42 → --seed 0',
    'results': {
        'vanilla_s0_k4_seed0_thisrun': {
            'final': v0_final, 'mean': v0_mean, 'oob': v0_oob, 'peak': v0_peak,
            'n_evals_with_success': v0_n_succ, 'n_evals_total': v0_n_tot,
        },
        'vanilla_s0_k4_seed42_anchor_§7.6.4': b_v42,
        'sac_asym_s0_k4_seed42_§7.7': b_a42,
        'sac_asym_s0_k4_seed0_sister': b_a0,
        'vanilla_s1_k4_seed42_§7.1_upper': b_s1,
    },
    'delta_vs_§7.6.4_seed42_paired': {
        'final_pp': round(d_final * 100, 2),
        'mean_pp': round(d_mean * 100, 2),
        'oob_pp': round(d_oob * 100, 2),
    },
    'all_pass': bool(x_summary['all_pass']),
    'verdict': verdict,
}
out_dir = Path('experiments/arrival_v2_prototype/s0_cross_vanilla_seed0_summary')
out_dir.mkdir(parents=True, exist_ok=True)
out_path = out_dir / 'combined_gate_summary.json'
out_path.write_text(json.dumps(ablation_out, indent=2), encoding='utf-8')
print(f'\n[saved] {out_path}')
# Out:
# ====================================================================================================
# VANILLA s0_k4 — paired seed verdict (seed=0 vs seed=42)
# ----------------------------------------------------------------------------------------------------
#
# config                                               final      mean       oob        source
# ----------------------------------------------------------------------------------------------------
# vanilla SAC, s1_k4 seed=42 (§7.1 upper ref)         0.9000    0.4966    0.1000       on-disk
# vanilla SAC, s0_k4 seed=42 (§7.6.4 anchor)          0.1000    0.2205    0.6667       on-disk
# vanilla SAC, s0_k4 SEED=0 (this run)                0.4000    0.2179    0.2000       on-disk
# sac_asym,   s0_k4 seed=42 (§7.7 negative)           0.1667    0.0436    0.6333       on-disk
# sac_asym,   s0_k4 SEED=0 (sister run)               0.2000    0.0880    0.5667       on-disk
# ====================================================================================================
#
# contrast                                                         Δ final      Δ mean       Δ oob
# ----------------------------------------------------------------------------------------------------
# vanilla seed=0 vs seed=42 — paired test                          +0.3000     -0.0026     -0.4667
# asym seed=0 vs vanilla seed=0 — same-seed cross-arm              -0.2000     -0.1299     +0.3667
# ====================================================================================================
#
# seed=0 evals_with_success: 34 / 39  (seed=42 vanilla was 35/39)
#
# >>> verdict: HIGH-VARIANCE — |Δfinal|=0.300 或 |Δmean|=0.003 超阈值；vanilla k=4 在此任务对 seed 敏感；§7.7 negative claim 暂时冻结，需要 3rd seed (=7 或 =1)
#
# [saved] experiments/arrival_v2_prototype/s0_cross_vanilla_seed0_summary/combined_gate_summary.json
