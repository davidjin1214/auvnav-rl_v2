# %% [markdown]
# # SAC arrival_v2 — Cross extension (600k → 1M) + P1 v6 (1.5M)
#
# **前情**：`sac_arrival_v2_cross_u10_regression_completed.ipynb` 在 600k 时 `final_success=0.867`（gate 阈值 0.85 PASS），但 `last100k_mean=0.6533 < 0.78`（gate FAIL）。Eval 曲线 500k→600k 单调上升（0.60→0.63→0.70→0.87），同时 `path_efficiency` 还在涨（0.57→0.75）、`eval_time` 还在掉（109s→65s）。判断为「未收敛」非「奖励学坏」。
#
# **本 notebook 任务**：
#
# | Phase | 任务 | benchmark | flow | obs | total_steps | 预算 |
# |---|---|---|---|---|---:|---:|
# | 1 | cross extension (resume from 600k) | `single_u10_cross_tgt15` | `wake_v8_U1p00_Re150` | s0 / 10-D | 600k → **1M** | ~1h L4 |
# | 2 | P1 v6 (新启) | `single_u15_upstream_tgt15` | `wake_v8_U1p50_Re250` | s1 / 12-D | 0 → **1.5M** | ~6h L4 |
#
# **Phase 1 gate**：`final ≥ 0.85` AND `last100k_mean ≥ 0.9 × peak` AND `final_oob_rate ≤ 0.10`，且 obs/replay 语义为 `arrival_v2` 设计。
#
# **Phase 2 准入**：Phase 1 gate 全过。否则 Phase 2 自动 hold，回头改 reward / 调超参。
#
# **输出**：
# - Phase 1（与 600k run 同 path，append 续训）：`experiments/arrival_v2_prototype/cross_u10_regression/arrival_v2/sac_vanilla/s0_k4/seed_46/`
# - Phase 2：`experiments/arrival_v2_prototype/p1_v6/arrival_v2/sac_vanilla/s1_k4/seed_46/`
#
# **风格说明**：训练全部用 `!python -u -m scripts.train_sac` 直接调用（不再用 `%%bash` cell magic），Colab 内可实时滚动看到 train log。

# %% [markdown]
# ## 0. GPU sanity

# %%
# !nvidia-smi | head -10
import torch
print(f'torch={torch.__version__}  cuda={torch.cuda.is_available()}  '
      f'device={torch.cuda.get_device_name(0) if torch.cuda.is_available() else "cpu"}')

# %% [markdown]
# ## 1. Mount Drive + cwd
#
# 和 600k run 用同一个 working clone（确保 commit `813096e` arrival_v2 实现 + `online_sac_reward_redesign.md` 修订）。

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

REPO_DIR = '/content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5'
# %cd $REPO_DIR
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5

# %% [markdown]
# ## 2. 通用配置 — Phase 1 (cross extension) + Phase 2 (P1 v6)
#
# Phase 1 与 600k run 完全同 path / 同 hyperparam，仅 `total_steps` 600k → 1M（`--resume` 路径自动 pick up state）。
#
# Phase 2 是新启 run，预算 1.5M（cross 需要 ~600-1000k 才稳，upstream + s1 + 12-D 比 cross 难，留缓冲）。

# %%
import json
import os
from pathlib import Path

import pandas as pd

# ==== Phase 1 — cross extension (resume 600k → 1M) ====
BENCHMARK_KEY = 'single_u10_cross_tgt15'
FLOW_PATH = 'wake_data/wake_v8_U1p00_Re150_D12p00_dx0p60_Ti5pct_1200f_roi.npy'
TASK_GEOMETRY = 'cross_stream'
TARGET_SPEED = 1.5
OBJECTIVE = 'arrival_v2'
PROBE_LAYOUT = 's0'
HISTORY_LENGTH = 4
SEED = 46

TOTAL_STEPS = 1_000_000              # 600k → 1M (净增 400k)
RANDOM_STEPS = 5_000
UPDATE_AFTER = 5_000
BATCH_SIZE = 256
HIDDEN_DIM = 256
NUM_ENVS = 6
EVAL_EVERY = 25_000
EVAL_EPISODES = 30
CHECKPOINT_EVERY = 100_000
DEVICE = 'cuda'

PASS_FINAL_SUCCESS = 0.85
PASS_LAST100_RATIO = 0.90
PASS_OOB_RATE = 0.10

RUN_ROOT = Path('experiments/arrival_v2_prototype/cross_u10_regression/arrival_v2/sac_vanilla/s0_k4/seed_46')
CKPT_ROOT = Path('checkpoints/arrival_v2_prototype/cross_u10_regression/arrival_v2/sac_vanilla/s0_k4/seed_46')
MANIFEST_PATH = Path(f'benchmarks/{BENCHMARK_KEY}.json')
RUN_ROOT_STR = str(RUN_ROOT)
CKPT_ROOT_STR = str(CKPT_ROOT)
MANIFEST_PATH_STR = str(MANIFEST_PATH)

# ==== Phase 2 — P1 v6 (1.5M, 新启) ====
P1_BENCHMARK_KEY = 'single_u15_upstream_tgt15'
P1_FLOW_PATH = 'wake_data/wake_v8_U1p50_Re250_D12p00_dx0p60_Ti5pct_1200f_roi.npy'
P1_PROBE_LAYOUT = 's1'
P1_TASK_GEOMETRY = 'upstream'

P1_TOTAL_STEPS = 1_500_000           # 比 cross 难,留缓冲;若提前稳定,看 trainer_state 早停

P1_RUN_ROOT = Path('experiments/arrival_v2_prototype/p1_v6/arrival_v2/sac_vanilla/s1_k4/seed_46')
P1_CKPT_ROOT = Path('checkpoints/arrival_v2_prototype/p1_v6/arrival_v2/sac_vanilla/s1_k4/seed_46')
P1_MANIFEST_PATH = Path(f'benchmarks/{P1_BENCHMARK_KEY}.json')
P1_RUN_ROOT_STR = str(P1_RUN_ROOT)
P1_CKPT_ROOT_STR = str(P1_CKPT_ROOT)
P1_MANIFEST_PATH_STR = str(P1_MANIFEST_PATH)

os.environ['PYTHONUNBUFFERED'] = '1'

print('---- Phase 1 (cross extension) ----')
print(f'  benchmark    = {BENCHMARK_KEY}')
print(f'  flow         = {FLOW_PATH}')
print(f'  total_steps  = 600,000 → {TOTAL_STEPS:,} (resume + extend)')
print(f'  run_root     = {RUN_ROOT}')
print(f'  ckpt_root    = {CKPT_ROOT}')
print()
print('---- Phase 2 (P1 v6) ----')
print(f'  benchmark    = {P1_BENCHMARK_KEY}')
print(f'  flow         = {P1_FLOW_PATH}')
print(f'  probe        = {P1_PROBE_LAYOUT} / {P1_TASK_GEOMETRY}')
print(f'  total_steps  = {P1_TOTAL_STEPS:,}')
print(f'  run_root     = {P1_RUN_ROOT}')
print(f'  ckpt_root    = {P1_CKPT_ROOT}')
# Out:
# ---- Phase 1 (cross extension) ----
#   benchmark    = single_u10_cross_tgt15
#   flow         = wake_data/wake_v8_U1p00_Re150_D12p00_dx0p60_Ti5pct_1200f_roi.npy
#   total_steps  = 600,000 → 1,000,000 (resume + extend)
#   run_root     = experiments/arrival_v2_prototype/cross_u10_regression/arrival_v2/sac_vanilla/s0_k4/seed_46
#   ckpt_root    = checkpoints/arrival_v2_prototype/cross_u10_regression/arrival_v2/sac_vanilla/s0_k4/seed_46
#
# ---- Phase 2 (P1 v6) ----
#   benchmark    = single_u15_upstream_tgt15
#   flow         = wake_data/wake_v8_U1p50_Re250_D12p00_dx0p60_Ti5pct_1200f_roi.npy
#   probe        = s1 / upstream
#   total_steps  = 1,500,000
#   run_root     = experiments/arrival_v2_prototype/p1_v6/arrival_v2/sac_vanilla/s1_k4/seed_46
#   ckpt_root    = checkpoints/arrival_v2_prototype/p1_v6/arrival_v2/sac_vanilla/s1_k4/seed_46

# %% [markdown]
# ## 3. Preflight — flow / arrival_v2 candidate gate / reward unit tests / manifest
#
# 停止条件：
# - Phase 1 flow 缺失 → 直接 raise；P1 flow 缺失只 warn（Phase 2 跑前再 hard check）
# - `validate_arrival_v2_candidate` 失败 → arrival_v2 reward 公式不满足 discounted unsafe-shortcut / terminal dominance
# - `test_reward_objective.py` 失败 → reward 实现退化
# - manifest 生成失败 → eval 不可重复

# %%
flow_path = Path(FLOW_PATH)
if not flow_path.exists():
    raise FileNotFoundError(f'missing Phase 1 flow file: {flow_path}')
print(f'[OK] Phase 1 flow exists: {flow_path} ({flow_path.stat().st_size / 1e6:.1f} MB)')

p1_flow_path = Path(P1_FLOW_PATH)
if not p1_flow_path.exists():
    print(f'[warn] Phase 2 flow not present yet: {p1_flow_path}')
    print('       Phase 2 cell 会在 hold check 时再 raise，可先把 cross extension 跑掉')
else:
    print(f'[OK] Phase 2 flow exists: {p1_flow_path} ({p1_flow_path.stat().st_size / 1e6:.1f} MB)')
# Out:
# [OK] Phase 1 flow exists: wake_data/wake_v8_U1p00_Re150_D12p00_dx0p60_Ti5pct_1200f_roi.npy (230.4 MB)
# [OK] Phase 2 flow exists: wake_data/wake_v8_U1p50_Re250_D12p00_dx0p60_Ti5pct_1200f_roi.npy (230.4 MB)

# %%
# !python -u -m scripts.validate_arrival_v2_candidate
# Out:
# [undiscounted]
# fast_success       144.473
# slow_success       142.023
# unsafe_success      91.048
# timeout_near      -149.800
# timeout_far       -229.800
# late_oob          -274.500
# fast_oob          -280.325
# mid_oob           -319.450
#
# [discounted_gamma_0.995]
# fast_success        88.578
# slow_success        54.683
# unsafe_success      34.857
# timeout_near       -39.480
# timeout_far        -58.269
# late_oob          -103.800
# mid_oob           -190.006
# fast_oob          -212.555
#
# [discounted_shortcut] safe=69.330 risky=62.361
#
# PASS: arrival_v2 candidate pre-integration gates passed.

# %%
# !python -u -m pytest tests/test_reward_objective.py -q
# Out:
# ...                                                                      [100%]
# 3 passed in 20.40s

# %%
# !python -u -m scripts.generate_standard_benchmarks --benchmarks {BENCHMARK_KEY} --episodes {EVAL_EPISODES}
if not MANIFEST_PATH.exists():
    raise FileNotFoundError(f'manifest not generated: {MANIFEST_PATH}')
print(f'[OK] Phase 1 manifest ready: {MANIFEST_PATH}')
# Out:
# [done] single_u10_cross_tgt15 -> benchmarks/single_u10_cross_tgt15.json
# [OK] Phase 1 manifest ready: benchmarks/single_u10_cross_tgt15.json

# %% [markdown]
# ## 4. Phase 1 — Cross extension 600k → 1M (resume)
#
# `--resume` 会从 `trainer_state.json` 自动读出原 600k run 的全部 config（reward objective、obs context、timeout terminal、num_envs、seed、reward params 等），CLI 上的 default arg 不会覆盖；只有显式传的 `--total-steps 1_000_000` 会替换原 600k。
#
# Skip 逻辑：若 `trainer_state.env_step >= TOTAL_STEPS` 就跳过（重跑 notebook 不会重训）。
#
# 训练日志通过 `python -u` 实时 flush 到 Colab cell。

# %%
for fname in ('agent_latest.pt', 'agent_best.pt', 'agent_final.pt'):
    p = CKPT_ROOT / fname
    print(f'{fname:<18} exists={p.exists()}  size={p.stat().st_size if p.exists() else 0:,}')
print('replay exists:', (RUN_ROOT / 'state/replay_latest.pkl').exists())
# Out:
# agent_latest.pt    exists=True  size=3,514,817
# agent_best.pt      exists=True  size=3,514,613
# agent_final.pt     exists=True  size=3,514,715
# replay exists: True

# %%
import json
from pathlib import Path

state_path = RUN_ROOT / 'trainer_state.json'
state = json.loads(state_path.read_text(encoding='utf-8'))

# 1) env_step / episode_idx 拉回 600k(那次空跑写错了)
state['env_step'] = 600_000
state['episode_idx'] = 3060

# 2) 所有 ckpt path 字段重写成绝对路径,绕开 save_dir-相对累积错误
ckpt_dir = CKPT_ROOT.resolve()
state['checkpoint_dir'] = str(ckpt_dir)
state['agent_path']         = str(ckpt_dir / 'agent_latest.pt')
state['latest_agent_path']  = str(ckpt_dir / 'agent_latest.pt')
if state.get('best_agent_path') is not None:
    state['best_agent_path']  = str(ckpt_dir / 'agent_best.pt')
if state.get('final_agent_path') is not None:
    state['final_agent_path'] = str(ckpt_dir / 'agent_final.pt')

# 3) replay/rng 在 save_dir/state/ 下,不归 ckpt_dir 管
state['replay_path']    = 'state/replay_latest.pkl'
state['rng_state_path'] = 'state/rng_state.pkl'

state_path.write_text(json.dumps(state, indent=2), encoding='utf-8')

for k in ('env_step','episode_idx','checkpoint_dir','agent_path','best_agent_path','replay_path'):
    print(f'{k:<18} = {state.get(k)}')
# Out:
# env_step           = 600000
# episode_idx        = 3060
# checkpoint_dir     = /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5/checkpoints/arrival_v2_prototype/cross_u10_regression/arrival_v2/sac_vanilla/s0_k4/seed_46
# agent_path         = /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5/checkpoints/arrival_v2_prototype/cross_u10_regression/arrival_v2/sac_vanilla/s0_k4/seed_46/agent_latest.pt
# best_agent_path    = /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5/checkpoints/arrival_v2_prototype/cross_u10_regression/arrival_v2/sac_vanilla/s0_k4/seed_46/agent_best.pt
# replay_path        = state/replay_latest.pkl

# %%
state_path = RUN_ROOT / 'trainer_state.json'
if state_path.exists():
    state = json.loads(state_path.read_text(encoding='utf-8'))
    current_step = int(state.get('env_step', 0))
else:
    current_step = 0
print(f'[state] cross run env_step = {current_step:,} / target {TOTAL_STEPS:,}')

if current_step >= TOTAL_STEPS:
    print(f'[skip] cross already extended to {current_step:,} ≥ {TOTAL_STEPS:,}')
elif current_step == 0:
    raise RuntimeError(
        f'no prior run at {RUN_ROOT}; this notebook expects a 600k checkpoint to resume from. '
        f'若需要从 0 开始,先跑 sac_arrival_v2_cross_u10_regression.ipynb'
    )
else:
    print(f'[train] resume from {current_step:,} → {TOTAL_STEPS:,} (extend +{TOTAL_STEPS - current_step:,})')
    # !python -u -m scripts.train_sac \
        --resume {RUN_ROOT_STR} \
        --total-steps {TOTAL_STEPS} \
        --eval-every {EVAL_EVERY} \
        --eval-episodes {EVAL_EPISODES} \
        --checkpoint-every {CHECKPOINT_EVERY} \
        --eval-manifest {MANIFEST_PATH_STR} \
        --device {DEVICE}
# Out:
# [state] cross run env_step = 600,000 / target 1,000,000
# [train] resume from 600,000 → 1,000,000 (extend +400,000)
# [resume] step=600000 episode=3060 from experiments/arrival_v2_prototype/cross_u10_regression/arrival_v2/sac_vanilla/s0_k4/seed_46
# [train] episode=3065 step=600822 return=-174.41 success=False time=68.4s geometry=cross_stream history=4 | q1=162.859 actor=69.056 alpha=0.069
# [train] episode=3070 step=602058 return=143.01 success=True time=39.9s geometry=cross_stream history=4 | q1=45.154 actor=67.685 alpha=0.067
# [train] episode=3075 step=602700 return=-477.55 success=False time=174.3s geometry=cross_stream history=4 | q1=6.401 actor=63.263 alpha=0.066
# [train] episode=3080 step=603552 return=143.61 success=True time=33.4s geometry=cross_stream history=4 | q1=45.621 actor=54.580 alpha=0.068
# [train] episode=3085 step=604206 return=143.61 success=True time=53.9s geometry=cross_stream history=4 | q1=156.134 actor=61.219 alpha=0.070
# [train] episode=3090 step=604656 return=111.37 success=True time=58.3s geometry=cross_stream history=4 | q1=120.739 actor=63.015 alpha=0.070
# [train] episode=3095 step=605178 return=121.56 success=True time=53.5s geometry=cross_stream history=4 | q1=3.316 actor=65.320 alpha=0.072
# [train] episode=3100 step=605622 return=141.55 success=True time=36.2s geometry=cross_stream history=4 | q1=2.881 actor=65.983 alpha=0.072
# [train] episode=3105 step=606306 return=-193.71 success=False time=101.3s geometry=cross_stream history=4 | q1=79.517 actor=65.481 alpha=0.071
# [train] episode=3110 step=607110 return=141.36 success=True time=30.9s geometry=cross_stream history=4 | q1=243.288 actor=61.226 alpha=0.071
# [train] episode=3115 step=607518 return=143.41 success=True time=33.2s geometry=cross_stream history=4 | q1=105.226 actor=66.350 alpha=0.070
# [train] episode=3120 step=608142 return=142.44 success=True time=31.7s geometry=cross_stream history=4 | q1=48.476 actor=66.294 alpha=0.070
# [train] episode=3125 step=608682 return=140.50 success=True time=48.8s geometry=cross_stream history=4 | q1=97.399 actor=64.833 alpha=0.071
# [train] episode=3130 step=609378 return=130.08 success=True time=61.8s geometry=cross_stream history=4 | q1=54.133 actor=61.912 alpha=0.072
# [train] episode=3135 step=610002 return=133.83 success=True time=45.3s geometry=cross_stream history=4 | q1=45.118 actor=56.289 alpha=0.071
# [train] episode=3140 step=610710 return=141.14 success=True time=38.1s geometry=cross_stream history=4 | q1=135.312 actor=51.694 alpha=0.071
# [train] episode=3145 step=611268 return=-80.24 success=False time=240.1s geometry=cross_stream history=4 | q1=165.488 actor=60.616 alpha=0.072
# [train] episode=3150 step=611892 return=143.65 success=True time=28.8s geometry=cross_stream history=4 | q1=202.786 actor=59.817 alpha=0.071
# [train] episode=3155 step=612078 return=119.43 success=True time=66.6s geometry=cross_stream history=4 | q1=62.718 actor=62.203 alpha=0.070
# [train] episode=3160 step=612576 return=138.36 success=True time=46.8s geometry=cross_stream history=4 | q1=48.648 actor=60.982 alpha=0.070
# [train] episode=3165 step=614658 return=139.01 success=True time=41.2s geometry=cross_stream history=4 | q1=82.714 actor=62.746 alpha=0.068
# [train] episode=3170 step=615396 return=-93.83 success=False time=240.1s geometry=cross_stream history=4 | q1=63.739 actor=57.816 alpha=0.068
# [train] episode=3175 step=615906 return=141.23 success=True time=41.9s geometry=cross_stream history=4 | q1=2.300 actor=58.782 alpha=0.070
# [train] episode=3180 step=616290 return=139.64 success=True time=40.1s geometry=cross_stream history=4 | q1=67.472 actor=65.571 alpha=0.072
# [train] episode=3185 step=616956 return=69.32 success=True time=75.8s geometry=cross_stream history=4 | q1=189.715 actor=58.700 alpha=0.074
# [train] episode=3190 step=617448 return=122.58 success=True time=56.7s geometry=cross_stream history=4 | q1=2.353 actor=54.257 alpha=0.074
# [train] episode=3195 step=618072 return=138.33 success=True time=55.2s geometry=cross_stream history=4 | q1=71.008 actor=59.501 alpha=0.074
# [train] episode=3200 step=618366 return=140.07 success=True time=38.4s geometry=cross_stream history=4 | q1=133.649 actor=59.046 alpha=0.074
# [train] episode=3205 step=618876 return=134.91 success=True time=41.9s geometry=cross_stream history=4 | q1=47.384 actor=63.045 alpha=0.072
# [train] episode=3210 step=619608 return=141.74 success=True time=37.6s geometry=cross_stream history=4 | q1=50.759 actor=58.272 alpha=0.073
# [train] episode=3215 step=620634 return=-288.42 success=False time=83.9s geometry=cross_stream history=4 | q1=21.487 actor=52.338 alpha=0.071
# [train] episode=3220 step=621450 return=-428.48 success=False time=181.8s geometry=cross_stream history=4 | q1=138.054 actor=63.933 alpha=0.072
# [train] episode=3225 step=622008 return=140.98 success=True time=54.2s geometry=cross_stream history=4 | q1=73.701 actor=62.921 alpha=0.071
# [train] episode=3230 step=622470 return=141.64 success=True time=44.1s geometry=cross_stream history=4 | q1=82.266 actor=63.034 alpha=0.071
# [train] episode=3235 step=623058 return=142.15 success=True time=51.9s geometry=cross_stream history=4 | q1=2.198 actor=56.533 alpha=0.072
# [train] episode=3240 step=623610 return=139.02 success=True time=53.6s geometry=cross_stream history=4 | q1=292.274 actor=59.866 alpha=0.072
# [train] episode=3245 step=624174 return=127.62 success=True time=61.7s geometry=cross_stream history=4 | q1=2.451 actor=58.927 alpha=0.072
# [train] episode=3250 step=624708 return=137.00 success=True time=49.8s geometry=cross_stream history=4 | q1=225.298 actor=55.481 alpha=0.072
# [eval] step=625002 objective=arrival_v2 return=122.77 safety=3.152 success=93.33% time=56.7s energy=40646.9 path=54.1 prog=0.86
# [train] episode=3255 step=625230 return=128.64 success=True time=50.4s geometry=cross_stream history=4 | q1=241.757 actor=60.357 alpha=0.074
# [train] episode=3260 step=625680 return=133.25 success=True time=36.6s geometry=cross_stream history=4 | q1=120.609 actor=58.469 alpha=0.073
# [train] episode=3265 step=626238 return=142.31 success=True time=45.8s geometry=cross_stream history=4 | q1=26.145 actor=53.301 alpha=0.075
# [train] episode=3270 step=626640 return=141.70 success=True time=32.9s geometry=cross_stream history=4 | q1=2.349 actor=60.560 alpha=0.075
# [train] episode=3275 step=627270 return=139.11 success=True time=47.1s geometry=cross_stream history=4 | q1=3.706 actor=48.719 alpha=0.075
# [train] episode=3280 step=627600 return=-66.88 success=False time=240.1s geometry=cross_stream history=4 | q1=2.264 actor=56.795 alpha=0.075
# [train] episode=3285 step=628158 return=133.28 success=True time=52.8s geometry=cross_stream history=4 | q1=24.535 actor=61.101 alpha=0.075
# [train] episode=3290 step=628530 return=140.59 success=True time=37.7s geometry=cross_stream history=4 | q1=2.830 actor=55.209 alpha=0.074
# [train] episode=3295 step=628962 return=142.60 success=True time=41.0s geometry=cross_stream history=4 | q1=142.786 actor=58.551 alpha=0.073
# [train] episode=3300 step=629580 return=104.92 success=True time=57.6s geometry=cross_stream history=4 | q1=18.147 actor=57.057 alpha=0.073
# [train] episode=3305 step=630138 return=125.72 success=True time=55.3s geometry=cross_stream history=4 | q1=139.027 actor=56.119 alpha=0.072
# [train] episode=3310 step=630576 return=140.94 success=True time=35.6s geometry=cross_stream history=4 | q1=46.113 actor=47.915 alpha=0.072
# [train] episode=3315 step=631158 return=60.85 success=True time=58.8s geometry=cross_stream history=4 | q1=68.074 actor=60.446 alpha=0.072
# [train] episode=3320 step=631812 return=112.94 success=True time=55.5s geometry=cross_stream history=4 | q1=105.481 actor=62.303 alpha=0.074
# [train] episode=3325 step=632304 return=140.67 success=True time=39.1s geometry=cross_stream history=4 | q1=57.352 actor=65.242 alpha=0.074
# [train] episode=3330 step=632760 return=81.58 success=True time=78.2s geometry=cross_stream history=4 | q1=266.914 actor=51.412 alpha=0.073
# [train] episode=3335 step=633120 return=142.36 success=True time=49.5s geometry=cross_stream history=4 | q1=185.651 actor=58.564 alpha=0.073
# [train] episode=3340 step=633636 return=-226.70 success=False time=14.8s geometry=cross_stream history=4 | q1=90.302 actor=59.879 alpha=0.074
# [train] episode=3345 step=634128 return=137.89 success=True time=47.3s geometry=cross_stream history=4 | q1=41.299 actor=53.756 alpha=0.075
# [train] episode=3350 step=634758 return=142.18 success=True time=38.9s geometry=cross_stream history=4 | q1=32.978 actor=53.568 alpha=0.075
# [train] episode=3355 step=635214 return=140.67 success=True time=37.4s geometry=cross_stream history=4 | q1=101.647 actor=58.858 alpha=0.076
# [train] episode=3360 step=635616 return=-506.11 success=False time=160.3s geometry=cross_stream history=4 | q1=3.865 actor=60.295 alpha=0.077
# [train] episode=3365 step=636138 return=133.61 success=True time=54.3s geometry=cross_stream history=4 | q1=2.999 actor=52.505 alpha=0.076
# [train] episode=3370 step=636534 return=137.17 success=True time=55.1s geometry=cross_stream history=4 | q1=85.415 actor=61.770 alpha=0.075
# [train] episode=3375 step=637092 return=138.44 success=True time=45.6s geometry=cross_stream history=4 | q1=89.255 actor=58.217 alpha=0.075
# [train] episode=3380 step=637404 return=140.52 success=True time=38.8s geometry=cross_stream history=4 | q1=39.447 actor=54.116 alpha=0.074
# [train] episode=3385 step=637806 return=141.64 success=True time=32.3s geometry=cross_stream history=4 | q1=99.084 actor=48.837 alpha=0.075
# [train] episode=3390 step=638268 return=119.53 success=True time=50.2s geometry=cross_stream history=4 | q1=145.963 actor=63.347 alpha=0.076
# [train] episode=3395 step=638694 return=142.30 success=True time=38.3s geometry=cross_stream history=4 | q1=177.757 actor=56.794 alpha=0.076
# [train] episode=3400 step=639240 return=140.31 success=True time=50.8s geometry=cross_stream history=4 | q1=58.799 actor=58.773 alpha=0.076
# [train] episode=3405 step=639696 return=143.26 success=True time=37.4s geometry=cross_stream history=4 | q1=29.232 actor=53.661 alpha=0.076
# [train] episode=3410 step=640104 return=138.46 success=True time=51.5s geometry=cross_stream history=4 | q1=4.973 actor=54.243 alpha=0.077
# [train] episode=3415 step=640668 return=127.82 success=True time=43.5s geometry=cross_stream history=4 | q1=70.312 actor=50.768 alpha=0.076
# [train] episode=3420 step=641112 return=140.22 success=True time=58.3s geometry=cross_stream history=4 | q1=82.177 actor=52.459 alpha=0.076
# [train] episode=3425 step=641586 return=81.31 success=True time=72.2s geometry=cross_stream history=4 | q1=78.041 actor=54.783 alpha=0.076
# [train] episode=3430 step=642180 return=139.68 success=True time=60.0s geometry=cross_stream history=4 | q1=129.776 actor=51.201 alpha=0.075
# [train] episode=3435 step=642648 return=141.28 success=True time=38.8s geometry=cross_stream history=4 | q1=11.793 actor=54.209 alpha=0.076
# [train] episode=3440 step=643128 return=136.72 success=True time=39.5s geometry=cross_stream history=4 | q1=40.241 actor=53.001 alpha=0.076
# [train] episode=3445 step=643710 return=140.30 success=True time=47.8s geometry=cross_stream history=4 | q1=87.470 actor=60.445 alpha=0.077
# [train] episode=3450 step=644106 return=141.66 success=True time=32.5s geometry=cross_stream history=4 | q1=21.786 actor=52.609 alpha=0.077
# [train] episode=3455 step=644520 return=142.54 success=True time=41.5s geometry=cross_stream history=4 | q1=107.274 actor=55.049 alpha=0.076
# [train] episode=3460 step=644988 return=139.07 success=True time=63.5s geometry=cross_stream history=4 | q1=163.178 actor=50.284 alpha=0.076
# [train] episode=3465 step=645438 return=140.35 success=True time=37.0s geometry=cross_stream history=4 | q1=137.332 actor=55.392 alpha=0.078
# [train] episode=3470 step=645972 return=136.88 success=True time=46.1s geometry=cross_stream history=4 | q1=28.310 actor=49.219 alpha=0.077
# [train] episode=3475 step=646596 return=139.21 success=True time=45.9s geometry=cross_stream history=4 | q1=251.873 actor=54.006 alpha=0.077
# [train] episode=3480 step=647226 return=140.90 success=True time=51.8s geometry=cross_stream history=4 | q1=78.703 actor=56.673 alpha=0.078
# [train] episode=3485 step=647922 return=117.39 success=True time=36.0s geometry=cross_stream history=4 | q1=25.368 actor=56.111 alpha=0.077
# [train] episode=3490 step=648372 return=-180.32 success=False time=67.9s geometry=cross_stream history=4 | q1=83.684 actor=52.651 alpha=0.075
# [train] episode=3495 step=648888 return=138.47 success=True time=54.6s geometry=cross_stream history=4 | q1=3.814 actor=57.234 alpha=0.076
# [train] episode=3500 step=649482 return=-209.65 success=False time=42.6s geometry=cross_stream history=4 | q1=229.448 actor=49.487 alpha=0.076
# [train] episode=3505 step=649986 return=140.17 success=True time=41.3s geometry=cross_stream history=4 | q1=95.678 actor=50.231 alpha=0.075
# [eval] step=650004 objective=arrival_v2 return=31.20 safety=29.835 success=80.00% time=68.5s energy=45974.0 path=56.3 prog=0.87
# [train] episode=3510 step=650544 return=136.06 success=True time=45.6s geometry=cross_stream history=4 | q1=60.044 actor=47.315 alpha=0.076
# [train] episode=3515 step=650850 return=126.26 success=True time=74.7s geometry=cross_stream history=4 | q1=2.881 actor=56.407 alpha=0.076
# [train] episode=3520 step=651636 return=137.77 success=True time=44.2s geometry=cross_stream history=4 | q1=485.656 actor=51.895 alpha=0.075
# [train] episode=3525 step=652260 return=137.57 success=True time=38.1s geometry=cross_stream history=4 | q1=304.445 actor=50.752 alpha=0.074
# [train] episode=3530 step=652764 return=139.22 success=True time=41.1s geometry=cross_stream history=4 | q1=91.149 actor=51.729 alpha=0.075
# [train] episode=3535 step=653250 return=-201.68 success=False time=39.8s geometry=cross_stream history=4 | q1=215.737 actor=55.041 alpha=0.074
# [train] episode=3540 step=653754 return=137.91 success=True time=41.5s geometry=cross_stream history=4 | q1=98.555 actor=46.479 alpha=0.072
# [train] episode=3545 step=654444 return=127.75 success=True time=61.8s geometry=cross_stream history=4 | q1=11.602 actor=45.621 alpha=0.073
# [train] episode=3550 step=654792 return=140.32 success=True time=38.4s geometry=cross_stream history=4 | q1=190.719 actor=48.858 alpha=0.074
# [train] episode=3555 step=655146 return=142.18 success=True time=36.7s geometry=cross_stream history=4 | q1=194.626 actor=46.718 alpha=0.076
# [train] episode=3560 step=655554 return=141.24 success=True time=36.2s geometry=cross_stream history=4 | q1=19.373 actor=53.701 alpha=0.077
# [train] episode=3565 step=655926 return=92.00 success=True time=35.7s geometry=cross_stream history=4 | q1=36.098 actor=49.367 alpha=0.077
# [train] episode=3570 step=656472 return=139.09 success=True time=47.5s geometry=cross_stream history=4 | q1=3.233 actor=44.270 alpha=0.078
# [train] episode=3575 step=656934 return=136.09 success=True time=48.9s geometry=cross_stream history=4 | q1=179.134 actor=53.867 alpha=0.077
# [train] episode=3580 step=657582 return=103.56 success=True time=64.5s geometry=cross_stream history=4 | q1=37.705 actor=47.112 alpha=0.077
# [train] episode=3585 step=658116 return=143.48 success=True time=30.6s geometry=cross_stream history=4 | q1=84.043 actor=52.629 alpha=0.078
# [train] episode=3590 step=658554 return=138.12 success=True time=41.1s geometry=cross_stream history=4 | q1=6.763 actor=50.819 alpha=0.079
# [train] episode=3595 step=659028 return=136.52 success=True time=38.7s geometry=cross_stream history=4 | q1=139.872 actor=48.851 alpha=0.081
# [train] episode=3600 step=659604 return=140.56 success=True time=31.7s geometry=cross_stream history=4 | q1=14.397 actor=50.264 alpha=0.082
# [train] episode=3605 step=659940 return=142.58 success=True time=39.7s geometry=cross_stream history=4 | q1=80.468 actor=49.167 alpha=0.083
# [train] episode=3610 step=660492 return=138.78 success=True time=70.8s geometry=cross_stream history=4 | q1=65.341 actor=52.579 alpha=0.085
# [train] episode=3615 step=660972 return=142.62 success=True time=42.9s geometry=cross_stream history=4 | q1=103.242 actor=50.914 alpha=0.086
# [train] episode=3620 step=661488 return=139.41 success=True time=40.4s geometry=cross_stream history=4 | q1=57.651 actor=42.599 alpha=0.087
# [train] episode=3625 step=661986 return=139.83 success=True time=51.5s geometry=cross_stream history=4 | q1=45.842 actor=54.474 alpha=0.087
# [train] episode=3630 step=662784 return=126.10 success=True time=47.6s geometry=cross_stream history=4 | q1=100.892 actor=52.068 alpha=0.087
# [train] episode=3635 step=663222 return=61.28 success=True time=102.5s geometry=cross_stream history=4 | q1=25.384 actor=40.939 alpha=0.087
# [train] episode=3640 step=663756 return=137.00 success=True time=45.4s geometry=cross_stream history=4 | q1=4.065 actor=46.262 alpha=0.085
# [train] episode=3645 step=664170 return=139.73 success=True time=36.4s geometry=cross_stream history=4 | q1=7.497 actor=46.622 alpha=0.084
# [train] episode=3650 step=664704 return=132.54 success=True time=42.0s geometry=cross_stream history=4 | q1=92.840 actor=46.764 alpha=0.083
# [train] episode=3655 step=665178 return=140.91 success=True time=40.3s geometry=cross_stream history=4 | q1=4.122 actor=50.570 alpha=0.083
# [train] episode=3660 step=665760 return=143.08 success=True time=48.0s geometry=cross_stream history=4 | q1=34.277 actor=50.395 alpha=0.085
# [train] episode=3665 step=666126 return=143.53 success=True time=29.8s geometry=cross_stream history=4 | q1=199.188 actor=48.561 alpha=0.085
# [train] episode=3670 step=666636 return=138.27 success=True time=59.6s geometry=cross_stream history=4 | q1=37.370 actor=39.924 alpha=0.084
# [train] episode=3675 step=667206 return=142.46 success=True time=35.8s geometry=cross_stream history=4 | q1=102.188 actor=52.846 alpha=0.084
# [train] episode=3680 step=667488 return=143.59 success=True time=42.1s geometry=cross_stream history=4 | q1=81.755 actor=51.681 alpha=0.084
# [train] episode=3685 step=667986 return=139.94 success=True time=54.5s geometry=cross_stream history=4 | q1=171.454 actor=44.041 alpha=0.084
# [train] episode=3690 step=668472 return=139.21 success=True time=41.7s geometry=cross_stream history=4 | q1=236.572 actor=56.741 alpha=0.085
# [train] episode=3695 step=668880 return=142.98 success=True time=31.1s geometry=cross_stream history=4 | q1=84.877 actor=48.257 alpha=0.086
# [train] episode=3700 step=669552 return=140.68 success=True time=46.0s geometry=cross_stream history=4 | q1=3.597 actor=48.510 alpha=0.087
# [train] episode=3705 step=670026 return=129.90 success=True time=38.9s geometry=cross_stream history=4 | q1=2.934 actor=48.730 alpha=0.088
# [train] episode=3710 step=670464 return=141.32 success=True time=36.0s geometry=cross_stream history=4 | q1=14.886 actor=52.104 alpha=0.089
# [train] episode=3715 step=670914 return=142.15 success=True time=36.8s geometry=cross_stream history=4 | q1=3.260 actor=46.442 alpha=0.089
# [train] episode=3720 step=671376 return=143.30 success=True time=38.0s geometry=cross_stream history=4 | q1=229.266 actor=55.036 alpha=0.089
# [train] episode=3725 step=671748 return=85.92 success=True time=47.1s geometry=cross_stream history=4 | q1=164.319 actor=45.631 alpha=0.088
# [train] episode=3730 step=672132 return=-242.71 success=False time=18.6s geometry=cross_stream history=4 | q1=132.791 actor=53.777 alpha=0.088
# [train] episode=3735 step=672618 return=143.94 success=True time=36.6s geometry=cross_stream history=4 | q1=36.981 actor=37.550 alpha=0.087
# [train] episode=3740 step=673050 return=136.76 success=True time=49.9s geometry=cross_stream history=4 | q1=14.524 actor=44.620 alpha=0.087
# [train] episode=3745 step=673410 return=143.41 success=True time=29.4s geometry=cross_stream history=4 | q1=117.751 actor=44.028 alpha=0.087
# [train] episode=3750 step=673830 return=138.02 success=True time=43.9s geometry=cross_stream history=4 | q1=3.256 actor=42.882 alpha=0.087
# [train] episode=3755 step=674244 return=130.63 success=True time=49.8s geometry=cross_stream history=4 | q1=59.912 actor=46.736 alpha=0.085
# [train] episode=3760 step=674688 return=140.60 success=True time=46.0s geometry=cross_stream history=4 | q1=146.139 actor=46.076 alpha=0.085
# [eval] step=675000 objective=arrival_v2 return=139.82 safety=2.371 success=100.00% time=39.3s energy=32167.0 path=45.8 prog=0.91
# [train] episode=3765 step=675036 return=142.34 success=True time=28.3s geometry=cross_stream history=4 | q1=67.801 actor=43.921 alpha=0.084
# [train] episode=3770 step=675414 return=142.15 success=True time=45.0s geometry=cross_stream history=4 | q1=23.943 actor=43.623 alpha=0.085
# [train] episode=3775 step=675870 return=142.21 success=True time=44.3s geometry=cross_stream history=4 | q1=128.568 actor=42.456 alpha=0.084
# [train] episode=3780 step=676386 return=138.75 success=True time=42.1s geometry=cross_stream history=4 | q1=100.082 actor=49.155 alpha=0.084
# [train] episode=3785 step=676812 return=140.80 success=True time=50.2s geometry=cross_stream history=4 | q1=136.449 actor=48.556 alpha=0.083
# [train] episode=3790 step=677364 return=140.10 success=True time=50.6s geometry=cross_stream history=4 | q1=103.441 actor=39.615 alpha=0.082
# [train] episode=3795 step=677574 return=142.61 success=True time=41.2s geometry=cross_stream history=4 | q1=84.576 actor=42.425 alpha=0.082
# [train] episode=3800 step=678000 return=140.10 success=True time=43.4s geometry=cross_stream history=4 | q1=50.979 actor=42.290 alpha=0.083
# [train] episode=3805 step=678396 return=141.43 success=True time=33.7s geometry=cross_stream history=4 | q1=8.920 actor=44.352 alpha=0.082
# [train] episode=3810 step=678828 return=87.38 success=True time=41.5s geometry=cross_stream history=4 | q1=7.832 actor=42.131 alpha=0.082
# [train] episode=3815 step=679362 return=140.22 success=True time=43.8s geometry=cross_stream history=4 | q1=345.806 actor=46.389 alpha=0.083
# [train] episode=3820 step=679782 return=139.74 success=True time=37.7s geometry=cross_stream history=4 | q1=52.774 actor=42.993 alpha=0.083
# [train] episode=3825 step=680142 return=138.30 success=True time=58.7s geometry=cross_stream history=4 | q1=6.221 actor=43.433 alpha=0.083
# [train] episode=3830 step=680478 return=143.00 success=True time=45.7s geometry=cross_stream history=4 | q1=166.514 actor=48.082 alpha=0.082
# [train] episode=3835 step=681030 return=139.15 success=True time=50.2s geometry=cross_stream history=4 | q1=146.451 actor=36.945 alpha=0.081
# [train] episode=3840 step=681402 return=143.60 success=True time=30.3s geometry=cross_stream history=4 | q1=280.053 actor=40.272 alpha=0.081
# [train] episode=3845 step=681792 return=140.91 success=True time=42.1s geometry=cross_stream history=4 | q1=87.000 actor=41.843 alpha=0.081
# [train] episode=3850 step=682218 return=141.14 success=True time=44.5s geometry=cross_stream history=4 | q1=48.201 actor=42.975 alpha=0.082
# [train] episode=3855 step=682584 return=139.47 success=True time=38.3s geometry=cross_stream history=4 | q1=54.197 actor=44.213 alpha=0.083
# [train] episode=3860 step=683028 return=127.23 success=True time=61.0s geometry=cross_stream history=4 | q1=154.915 actor=38.595 alpha=0.085
# [train] episode=3865 step=683412 return=142.50 success=True time=32.6s geometry=cross_stream history=4 | q1=106.473 actor=47.836 alpha=0.084
# [train] episode=3870 step=683814 return=141.00 success=True time=32.9s geometry=cross_stream history=4 | q1=137.479 actor=48.651 alpha=0.083
# [train] episode=3875 step=684276 return=142.74 success=True time=31.2s geometry=cross_stream history=4 | q1=169.819 actor=34.466 alpha=0.085
# [train] episode=3880 step=684750 return=143.80 success=True time=35.4s geometry=cross_stream history=4 | q1=48.522 actor=50.591 alpha=0.084
# [train] episode=3885 step=685284 return=132.89 success=True time=43.7s geometry=cross_stream history=4 | q1=191.606 actor=39.535 alpha=0.083
# [train] episode=3890 step=685944 return=139.53 success=True time=59.8s geometry=cross_stream history=4 | q1=115.900 actor=44.798 alpha=0.082
# [train] episode=3895 step=686076 return=117.02 success=True time=65.3s geometry=cross_stream history=4 | q1=153.405 actor=39.124 alpha=0.082
# [train] episode=3900 step=686640 return=127.16 success=True time=52.7s geometry=cross_stream history=4 | q1=152.393 actor=46.298 alpha=0.081
# [train] episode=3905 step=687036 return=141.98 success=True time=32.2s geometry=cross_stream history=4 | q1=199.414 actor=43.334 alpha=0.081
# [train] episode=3910 step=687474 return=140.85 success=True time=44.6s geometry=cross_stream history=4 | q1=332.208 actor=43.611 alpha=0.081
# [train] episode=3915 step=687954 return=140.50 success=True time=37.8s geometry=cross_stream history=4 | q1=161.683 actor=41.784 alpha=0.083
# [train] episode=3920 step=688320 return=141.11 success=True time=40.3s geometry=cross_stream history=4 | q1=134.709 actor=34.597 alpha=0.083
# [train] episode=3925 step=688740 return=82.67 success=True time=34.2s geometry=cross_stream history=4 | q1=9.260 actor=39.510 alpha=0.085
# [train] episode=3930 step=689172 return=143.38 success=True time=32.6s geometry=cross_stream history=4 | q1=4.707 actor=40.291 alpha=0.086
# [train] episode=3935 step=689538 return=141.76 success=True time=50.9s geometry=cross_stream history=4 | q1=211.638 actor=45.000 alpha=0.086
# [train] episode=3940 step=689892 return=144.15 success=True time=28.8s geometry=cross_stream history=4 | q1=67.967 actor=49.074 alpha=0.086
# [train] episode=3945 step=690306 return=139.73 success=True time=39.0s geometry=cross_stream history=4 | q1=302.032 actor=36.728 alpha=0.085
# [train] episode=3950 step=690726 return=142.62 success=True time=34.3s geometry=cross_stream history=4 | q1=3.367 actor=47.170 alpha=0.086
# [train] episode=3955 step=691116 return=136.16 success=True time=51.6s geometry=cross_stream history=4 | q1=146.727 actor=40.771 alpha=0.088
# [train] episode=3960 step=691554 return=140.25 success=True time=44.8s geometry=cross_stream history=4 | q1=48.323 actor=44.298 alpha=0.087
# [train] episode=3965 step=692106 return=139.35 success=True time=37.6s geometry=cross_stream history=4 | q1=22.494 actor=36.941 alpha=0.086
# [train] episode=3970 step=692406 return=143.73 success=True time=46.5s geometry=cross_stream history=4 | q1=90.383 actor=44.678 alpha=0.085
# [train] episode=3975 step=692736 return=142.14 success=True time=33.5s geometry=cross_stream history=4 | q1=362.178 actor=43.383 alpha=0.084
# [train] episode=3980 step=693234 return=113.22 success=True time=48.7s geometry=cross_stream history=4 | q1=122.192 actor=41.880 alpha=0.084
# [train] episode=3985 step=693618 return=134.17 success=True time=49.9s geometry=cross_stream history=4 | q1=38.840 actor=35.313 alpha=0.085
# [train] episode=3990 step=694020 return=139.94 success=True time=49.5s geometry=cross_stream history=4 | q1=8.909 actor=43.016 alpha=0.084
# [train] episode=3995 step=694488 return=139.42 success=True time=40.6s geometry=cross_stream history=4 | q1=51.182 actor=38.977 alpha=0.083
# [train] episode=4000 step=694992 return=142.30 success=True time=42.9s geometry=cross_stream history=4 | q1=155.362 actor=34.521 alpha=0.082
# [train] episode=4005 step=695514 return=124.32 success=True time=44.4s geometry=cross_stream history=4 | q1=97.816 actor=36.419 alpha=0.084
# [train] episode=4010 step=695706 return=142.02 success=True time=42.9s geometry=cross_stream history=4 | q1=14.674 actor=39.824 alpha=0.083
# [train] episode=4015 step=696288 return=126.98 success=True time=52.0s geometry=cross_stream history=4 | q1=90.768 actor=33.797 alpha=0.083
# [train] episode=4020 step=696786 return=141.32 success=True time=32.4s geometry=cross_stream history=4 | q1=60.332 actor=38.012 alpha=0.085
# [train] episode=4025 step=697266 return=89.86 success=True time=39.5s geometry=cross_stream history=4 | q1=33.863 actor=37.923 alpha=0.086
# [train] episode=4030 step=697572 return=102.87 success=True time=60.7s geometry=cross_stream history=4 | q1=88.795 actor=40.252 alpha=0.086
# [train] episode=4035 step=698352 return=83.21 success=True time=78.4s geometry=cross_stream history=4 | q1=4.867 actor=37.092 alpha=0.086
# [train] episode=4040 step=698724 return=141.40 success=True time=42.6s geometry=cross_stream history=4 | q1=68.005 actor=39.109 alpha=0.088
# [train] episode=4045 step=699174 return=143.49 success=True time=35.8s geometry=cross_stream history=4 | q1=3.460 actor=37.380 alpha=0.087
# [train] episode=4050 step=699630 return=140.93 success=True time=36.1s geometry=cross_stream history=4 | q1=90.260 actor=34.729 alpha=0.086
# [eval] step=700002 objective=arrival_v2 return=96.66 safety=8.717 success=90.00% time=44.6s energy=34925.2 path=50.7 prog=0.89
# [train] episode=4055 step=700086 return=19.02 success=True time=85.8s geometry=cross_stream history=4 | q1=312.534 actor=33.504 alpha=0.085
# [train] episode=4060 step=700482 return=142.22 success=True time=34.7s geometry=cross_stream history=4 | q1=17.876 actor=39.464 alpha=0.087
# [train] episode=4065 step=700854 return=140.02 success=True time=33.9s geometry=cross_stream history=4 | q1=303.918 actor=30.443 alpha=0.088
# [train] episode=4070 step=701310 return=137.29 success=True time=37.4s geometry=cross_stream history=4 | q1=2.550 actor=38.785 alpha=0.089
# [train] episode=4075 step=701808 return=141.92 success=True time=53.7s geometry=cross_stream history=4 | q1=30.315 actor=39.992 alpha=0.089
# [train] episode=4080 step=702246 return=143.38 success=True time=30.8s geometry=cross_stream history=4 | q1=170.762 actor=39.231 alpha=0.090
# [train] episode=4085 step=702612 return=141.68 success=True time=41.1s geometry=cross_stream history=4 | q1=29.462 actor=33.956 alpha=0.090
# [train] episode=4090 step=703194 return=76.24 success=True time=76.8s geometry=cross_stream history=4 | q1=82.799 actor=32.370 alpha=0.090
# [train] episode=4095 step=703656 return=140.98 success=True time=36.1s geometry=cross_stream history=4 | q1=196.780 actor=34.445 alpha=0.089
# [train] episode=4100 step=704064 return=142.77 success=True time=33.5s geometry=cross_stream history=4 | q1=24.854 actor=40.434 alpha=0.089
# [train] episode=4105 step=704316 return=143.46 success=True time=36.7s geometry=cross_stream history=4 | q1=132.326 actor=34.292 alpha=0.089
# [train] episode=4110 step=704832 return=139.14 success=True time=46.3s geometry=cross_stream history=4 | q1=234.825 actor=36.190 alpha=0.088
# [train] episode=4115 step=705312 return=137.84 success=True time=39.3s geometry=cross_stream history=4 | q1=221.641 actor=39.669 alpha=0.089
# [train] episode=4120 step=705768 return=141.35 success=True time=28.7s geometry=cross_stream history=4 | q1=109.357 actor=38.702 alpha=0.089
# [train] episode=4125 step=706182 return=144.47 success=True time=25.6s geometry=cross_stream history=4 | q1=98.432 actor=42.189 alpha=0.088
# [train] episode=4130 step=706578 return=131.81 success=True time=49.9s geometry=cross_stream history=4 | q1=84.516 actor=36.911 alpha=0.088
# [train] episode=4135 step=707010 return=141.35 success=True time=40.4s geometry=cross_stream history=4 | q1=26.392 actor=42.641 alpha=0.090
# [train] episode=4140 step=707658 return=141.16 success=True time=54.7s geometry=cross_stream history=4 | q1=24.708 actor=28.422 alpha=0.090
# [train] episode=4145 step=708168 return=140.99 success=True time=41.6s geometry=cross_stream history=4 | q1=3.365 actor=34.184 alpha=0.091
# [train] episode=4150 step=708492 return=142.66 success=True time=43.2s geometry=cross_stream history=4 | q1=169.711 actor=31.969 alpha=0.092
# [train] episode=4155 step=709026 return=135.13 success=True time=43.8s geometry=cross_stream history=4 | q1=114.913 actor=39.157 alpha=0.093
# [train] episode=4160 step=709596 return=142.90 success=True time=46.9s geometry=cross_stream history=4 | q1=257.314 actor=34.657 alpha=0.094
# [train] episode=4165 step=710028 return=143.84 success=True time=35.2s geometry=cross_stream history=4 | q1=138.329 actor=29.991 alpha=0.096
# [train] episode=4170 step=710388 return=140.45 success=True time=37.1s geometry=cross_stream history=4 | q1=79.619 actor=34.546 alpha=0.097
# [train] episode=4175 step=710976 return=138.15 success=True time=37.9s geometry=cross_stream history=4 | q1=41.747 actor=32.770 alpha=0.098
# [train] episode=4180 step=711402 return=141.85 success=True time=34.8s geometry=cross_stream history=4 | q1=20.731 actor=38.022 alpha=0.097
# [train] episode=4185 step=711840 return=138.66 success=True time=45.5s geometry=cross_stream history=4 | q1=116.430 actor=35.495 alpha=0.096
# [train] episode=4190 step=712314 return=137.91 success=True time=41.4s geometry=cross_stream history=4 | q1=224.527 actor=33.490 alpha=0.095
# [train] episode=4195 step=712878 return=142.00 success=True time=46.4s geometry=cross_stream history=4 | q1=32.128 actor=36.414 alpha=0.094
# [train] episode=4200 step=713430 return=140.13 success=True time=53.4s geometry=cross_stream history=4 | q1=161.987 actor=32.214 alpha=0.092
# [train] episode=4205 step=714018 return=32.63 success=True time=91.9s geometry=cross_stream history=4 | q1=44.137 actor=38.359 alpha=0.092
# [train] episode=4210 step=714474 return=142.50 success=True time=37.3s geometry=cross_stream history=4 | q1=27.453 actor=36.198 alpha=0.091
# [train] episode=4215 step=714738 return=136.15 success=True time=50.2s geometry=cross_stream history=4 | q1=149.386 actor=37.092 alpha=0.090
# [train] episode=4220 step=715242 return=140.79 success=True time=41.5s geometry=cross_stream history=4 | q1=102.105 actor=37.080 alpha=0.091
# [train] episode=4225 step=715614 return=138.70 success=True time=42.3s geometry=cross_stream history=4 | q1=3.900 actor=30.772 alpha=0.093
# [train] episode=4230 step=716088 return=26.76 success=True time=89.4s geometry=cross_stream history=4 | q1=24.534 actor=30.345 alpha=0.095
# [train] episode=4235 step=716580 return=143.40 success=True time=40.2s geometry=cross_stream history=4 | q1=61.504 actor=34.072 alpha=0.095
# [train] episode=4240 step=717036 return=140.61 success=True time=46.6s geometry=cross_stream history=4 | q1=24.291 actor=28.369 alpha=0.095
# [train] episode=4245 step=717594 return=141.05 success=True time=45.9s geometry=cross_stream history=4 | q1=99.775 actor=36.599 alpha=0.097
# [train] episode=4250 step=718038 return=139.35 success=True time=36.2s geometry=cross_stream history=4 | q1=190.256 actor=30.666 alpha=0.098
# [train] episode=4255 step=718500 return=139.22 success=True time=46.6s geometry=cross_stream history=4 | q1=147.628 actor=31.614 alpha=0.094
# [train] episode=4260 step=719010 return=141.08 success=True time=41.9s geometry=cross_stream history=4 | q1=23.340 actor=32.459 alpha=0.094
# [train] episode=4265 step=719250 return=141.58 success=True time=33.7s geometry=cross_stream history=4 | q1=11.820 actor=31.433 alpha=0.094
# [train] episode=4270 step=719784 return=-177.64 success=False time=51.6s geometry=cross_stream history=4 | q1=75.152 actor=28.706 alpha=0.095
# [train] episode=4275 step=720180 return=137.45 success=True time=46.2s geometry=cross_stream history=4 | q1=2.718 actor=31.276 alpha=0.095
# [train] episode=4280 step=720750 return=140.41 success=True time=41.8s geometry=cross_stream history=4 | q1=80.500 actor=31.240 alpha=0.094
# [train] episode=4285 step=721188 return=142.62 success=True time=32.7s geometry=cross_stream history=4 | q1=58.352 actor=30.874 alpha=0.093
# [train] episode=4290 step=721776 return=142.86 success=True time=44.5s geometry=cross_stream history=4 | q1=74.542 actor=29.971 alpha=0.093
# [train] episode=4295 step=722154 return=142.36 success=True time=41.9s geometry=cross_stream history=4 | q1=131.076 actor=41.574 alpha=0.095
# [train] episode=4300 step=722586 return=120.63 success=True time=66.7s geometry=cross_stream history=4 | q1=4.131 actor=42.148 alpha=0.094
# [train] episode=4305 step=722982 return=138.10 success=True time=38.1s geometry=cross_stream history=4 | q1=248.987 actor=32.112 alpha=0.094
# [train] episode=4310 step=723510 return=141.27 success=True time=43.2s geometry=cross_stream history=4 | q1=107.498 actor=31.355 alpha=0.093
# [train] episode=4315 step=724044 return=139.87 success=True time=33.5s geometry=cross_stream history=4 | q1=39.479 actor=30.477 alpha=0.095
# [train] episode=4320 step=724620 return=139.11 success=True time=39.1s geometry=cross_stream history=4 | q1=56.388 actor=27.162 alpha=0.097
# [eval] step=725004 objective=arrival_v2 return=123.90 safety=5.239 success=96.67% time=40.5s energy=33420.6 path=47.4 prog=0.90
# [train] episode=4325 step=725106 return=136.44 success=True time=39.0s geometry=cross_stream history=4 | q1=173.336 actor=32.433 alpha=0.097
# [train] episode=4330 step=725448 return=92.61 success=True time=64.5s geometry=cross_stream history=4 | q1=70.865 actor=34.161 alpha=0.098
# [train] episode=4335 step=725934 return=140.41 success=True time=33.3s geometry=cross_stream history=4 | q1=39.431 actor=31.892 alpha=0.100
# [train] episode=4340 step=726264 return=96.55 success=True time=67.2s geometry=cross_stream history=4 | q1=45.293 actor=30.306 alpha=0.101
# [train] episode=4345 step=726678 return=141.09 success=True time=33.6s geometry=cross_stream history=4 | q1=226.339 actor=36.082 alpha=0.102
# [train] episode=4350 step=727242 return=143.33 success=True time=32.5s geometry=cross_stream history=4 | q1=2.490 actor=24.445 alpha=0.098
# [train] episode=4355 step=727710 return=142.14 success=True time=47.9s geometry=cross_stream history=4 | q1=116.345 actor=25.116 alpha=0.099
# [train] episode=4360 step=727986 return=-228.06 success=False time=12.7s geometry=cross_stream history=4 | q1=249.792 actor=29.163 alpha=0.097
# [train] episode=4365 step=728490 return=98.10 success=True time=57.4s geometry=cross_stream history=4 | q1=37.178 actor=23.762 alpha=0.096
# [train] episode=4370 step=728946 return=81.61 success=True time=64.4s geometry=cross_stream history=4 | q1=53.954 actor=39.979 alpha=0.095
# [train] episode=4375 step=729498 return=140.48 success=True time=34.6s geometry=cross_stream history=4 | q1=227.158 actor=34.211 alpha=0.095
# [train] episode=4380 step=729954 return=140.48 success=True time=40.4s geometry=cross_stream history=4 | q1=203.744 actor=30.083 alpha=0.093
# [train] episode=4385 step=730236 return=142.98 success=True time=35.8s geometry=cross_stream history=4 | q1=4.657 actor=26.262 alpha=0.093
# [train] episode=4390 step=730542 return=142.05 success=True time=32.9s geometry=cross_stream history=4 | q1=114.073 actor=26.443 alpha=0.094
# [train] episode=4395 step=731028 return=137.05 success=True time=41.3s geometry=cross_stream history=4 | q1=199.659 actor=29.250 alpha=0.095
# [train] episode=4400 step=731526 return=-189.57 success=False time=54.4s geometry=cross_stream history=4 | q1=167.781 actor=27.566 alpha=0.094
# [train] episode=4405 step=731976 return=139.96 success=True time=43.9s geometry=cross_stream history=4 | q1=14.886 actor=22.309 alpha=0.092
# [train] episode=4410 step=732402 return=141.86 success=True time=30.8s geometry=cross_stream history=4 | q1=4.204 actor=31.747 alpha=0.091
# [train] episode=4415 step=732936 return=137.89 success=True time=41.9s geometry=cross_stream history=4 | q1=216.458 actor=26.819 alpha=0.091
# [train] episode=4420 step=733314 return=142.76 success=True time=45.2s geometry=cross_stream history=4 | q1=77.693 actor=28.646 alpha=0.091
# [train] episode=4425 step=733680 return=142.33 success=True time=46.3s geometry=cross_stream history=4 | q1=39.964 actor=21.322 alpha=0.092
# [train] episode=4430 step=734382 return=21.45 success=True time=69.7s geometry=cross_stream history=4 | q1=193.940 actor=31.188 alpha=0.091
# [train] episode=4435 step=734820 return=141.76 success=True time=32.5s geometry=cross_stream history=4 | q1=74.772 actor=30.419 alpha=0.091
# [train] episode=4440 step=734988 return=141.83 success=True time=32.5s geometry=cross_stream history=4 | q1=3.949 actor=27.256 alpha=0.091
# [train] episode=4445 step=735510 return=140.49 success=True time=46.0s geometry=cross_stream history=4 | q1=104.773 actor=26.112 alpha=0.090
# [train] episode=4450 step=736098 return=140.10 success=True time=50.0s geometry=cross_stream history=4 | q1=49.151 actor=24.884 alpha=0.091
# [train] episode=4455 step=736590 return=-179.70 success=False time=43.2s geometry=cross_stream history=4 | q1=108.077 actor=32.366 alpha=0.093
# [train] episode=4460 step=736992 return=139.56 success=True time=41.8s geometry=cross_stream history=4 | q1=3.385 actor=25.738 alpha=0.093
# [train] episode=4465 step=737532 return=34.11 success=True time=77.6s geometry=cross_stream history=4 | q1=183.604 actor=29.013 alpha=0.094
# [train] episode=4470 step=737880 return=142.34 success=True time=33.4s geometry=cross_stream history=4 | q1=140.150 actor=14.341 alpha=0.093
# [train] episode=4475 step=738222 return=143.77 success=True time=30.5s geometry=cross_stream history=4 | q1=121.673 actor=24.297 alpha=0.094
# [train] episode=4480 step=738786 return=-181.38 success=False time=47.7s geometry=cross_stream history=4 | q1=159.158 actor=18.419 alpha=0.093
# [train] episode=4485 step=739206 return=133.76 success=True time=45.4s geometry=cross_stream history=4 | q1=34.482 actor=26.192 alpha=0.093
# [train] episode=4490 step=739740 return=42.22 success=True time=76.0s geometry=cross_stream history=4 | q1=97.427 actor=31.501 alpha=0.094
# [train] episode=4495 step=740160 return=137.65 success=True time=34.4s geometry=cross_stream history=4 | q1=212.893 actor=29.095 alpha=0.093
# [train] episode=4500 step=740688 return=142.68 success=True time=37.0s geometry=cross_stream history=4 | q1=260.588 actor=26.159 alpha=0.093
# [train] episode=4505 step=741096 return=140.88 success=True time=38.1s geometry=cross_stream history=4 | q1=76.422 actor=32.449 alpha=0.093
# [train] episode=4510 step=741606 return=142.28 success=True time=41.8s geometry=cross_stream history=4 | q1=7.236 actor=25.164 alpha=0.093
# [train] episode=4515 step=742074 return=129.58 success=True time=51.9s geometry=cross_stream history=4 | q1=11.765 actor=26.915 alpha=0.093
# [train] episode=4520 step=742530 return=138.97 success=True time=38.1s geometry=cross_stream history=4 | q1=89.942 actor=23.920 alpha=0.091
# [train] episode=4525 step=743028 return=139.54 success=True time=42.9s geometry=cross_stream history=4 | q1=28.041 actor=28.648 alpha=0.091
# [train] episode=4530 step=743568 return=139.52 success=True time=34.6s geometry=cross_stream history=4 | q1=15.527 actor=25.607 alpha=0.092
# [train] episode=4535 step=744078 return=143.76 success=True time=41.6s geometry=cross_stream history=4 | q1=168.719 actor=24.616 alpha=0.091
# [train] episode=4540 step=744378 return=140.81 success=True time=38.3s geometry=cross_stream history=4 | q1=133.006 actor=30.036 alpha=0.090
# [train] episode=4545 step=744852 return=144.32 success=True time=27.4s geometry=cross_stream history=4 | q1=17.075 actor=24.002 alpha=0.093
# [train] episode=4550 step=745320 return=139.39 success=True time=57.1s geometry=cross_stream history=4 | q1=251.752 actor=25.771 alpha=0.092
# [train] episode=4555 step=745884 return=-171.95 success=False time=48.3s geometry=cross_stream history=4 | q1=195.951 actor=26.635 alpha=0.090
# [train] episode=4560 step=746382 return=139.63 success=True time=40.9s geometry=cross_stream history=4 | q1=28.790 actor=23.656 alpha=0.091
# [train] episode=4565 step=746844 return=142.80 success=True time=37.8s geometry=cross_stream history=4 | q1=38.794 actor=25.698 alpha=0.091
# [train] episode=4570 step=747246 return=138.96 success=True time=44.2s geometry=cross_stream history=4 | q1=35.499 actor=21.667 alpha=0.092
# [train] episode=4575 step=747660 return=142.29 success=True time=33.6s geometry=cross_stream history=4 | q1=22.470 actor=22.093 alpha=0.092
# [train] episode=4580 step=748092 return=140.11 success=True time=35.3s geometry=cross_stream history=4 | q1=130.602 actor=22.660 alpha=0.093
# [train] episode=4585 step=748416 return=140.33 success=True time=40.2s geometry=cross_stream history=4 | q1=92.852 actor=26.349 alpha=0.093
# [train] episode=4590 step=748848 return=139.43 success=True time=35.2s geometry=cross_stream history=4 | q1=3.088 actor=23.256 alpha=0.095
# [train] episode=4595 step=749322 return=118.00 success=True time=49.2s geometry=cross_stream history=4 | q1=141.600 actor=21.698 alpha=0.094
# [train] episode=4600 step=749634 return=120.20 success=True time=50.9s geometry=cross_stream history=4 | q1=210.044 actor=30.913 alpha=0.094
# [eval] step=750000 objective=arrival_v2 return=124.24 safety=10.092 success=100.00% time=45.1s energy=35095.7 path=49.2 prog=0.91
# [train] episode=4605 step=750048 return=143.75 success=True time=38.9s geometry=cross_stream history=4 | q1=197.790 actor=19.424 alpha=0.095
# [train] episode=4610 step=750450 return=141.41 success=True time=35.8s geometry=cross_stream history=4 | q1=77.164 actor=21.326 alpha=0.095
# [train] episode=4615 step=750954 return=138.61 success=True time=43.9s geometry=cross_stream history=4 | q1=402.467 actor=27.521 alpha=0.096
# [train] episode=4620 step=751470 return=142.98 success=True time=47.1s geometry=cross_stream history=4 | q1=166.877 actor=30.823 alpha=0.094
# [train] episode=4625 step=751878 return=-29.75 success=True time=68.8s geometry=cross_stream history=4 | q1=49.332 actor=12.772 alpha=0.093
# [train] episode=4630 step=752346 return=143.84 success=True time=38.3s geometry=cross_stream history=4 | q1=69.028 actor=17.389 alpha=0.093
# [train] episode=4635 step=752676 return=142.97 success=True time=47.1s geometry=cross_stream history=4 | q1=4.078 actor=19.226 alpha=0.092
# [train] episode=4640 step=753336 return=44.17 success=True time=73.1s geometry=cross_stream history=4 | q1=349.975 actor=21.994 alpha=0.092
# [train] episode=4645 step=753846 return=140.60 success=True time=42.0s geometry=cross_stream history=4 | q1=174.334 actor=23.635 alpha=0.093
# [train] episode=4650 step=754278 return=107.42 success=True time=48.6s geometry=cross_stream history=4 | q1=135.710 actor=22.638 alpha=0.092
# [train] episode=4655 step=754788 return=139.00 success=True time=41.8s geometry=cross_stream history=4 | q1=10.120 actor=21.374 alpha=0.091
# [train] episode=4660 step=755052 return=134.37 success=True time=44.4s geometry=cross_stream history=4 | q1=6.031 actor=18.946 alpha=0.090
# [train] episode=4665 step=755508 return=142.49 success=True time=37.3s geometry=cross_stream history=4 | q1=153.316 actor=18.913 alpha=0.091
# [train] episode=4670 step=755976 return=143.15 success=True time=48.0s geometry=cross_stream history=4 | q1=150.949 actor=20.918 alpha=0.093
# [train] episode=4675 step=756456 return=142.90 success=True time=30.5s geometry=cross_stream history=4 | q1=137.265 actor=24.941 alpha=0.090
# [train] episode=4680 step=756966 return=140.38 success=True time=41.9s geometry=cross_stream history=4 | q1=150.604 actor=24.212 alpha=0.089
# [train] episode=4685 step=757224 return=140.96 success=True time=42.1s geometry=cross_stream history=4 | q1=17.193 actor=21.403 alpha=0.089
# [train] episode=4690 step=757734 return=140.30 success=True time=47.5s geometry=cross_stream history=4 | q1=16.342 actor=22.600 alpha=0.090
# [train] episode=4695 step=758232 return=138.23 success=True time=37.3s geometry=cross_stream history=4 | q1=34.799 actor=27.791 alpha=0.088
# [train] episode=4700 step=758670 return=140.52 success=True time=42.6s geometry=cross_stream history=4 | q1=105.748 actor=28.522 alpha=0.088
# [train] episode=4705 step=759180 return=143.41 success=True time=43.3s geometry=cross_stream history=4 | q1=259.891 actor=20.109 alpha=0.088
# [train] episode=4710 step=759546 return=140.17 success=True time=36.9s geometry=cross_stream history=4 | q1=277.372 actor=25.362 alpha=0.088
# [train] episode=4715 step=760128 return=141.71 success=True time=50.9s geometry=cross_stream history=4 | q1=172.926 actor=21.105 alpha=0.085
# [train] episode=4720 step=760596 return=138.91 success=True time=45.3s geometry=cross_stream history=4 | q1=30.092 actor=16.729 alpha=0.084
# [train] episode=4725 step=761106 return=138.64 success=True time=33.6s geometry=cross_stream history=4 | q1=5.047 actor=17.193 alpha=0.085
# [train] episode=4730 step=761532 return=132.95 success=True time=32.9s geometry=cross_stream history=4 | q1=217.966 actor=21.589 alpha=0.086
# ...
# [train] episode=6935 step=952464 return=142.16 success=True time=41.8s geometry=cross_stream history=4 | q1=35.525 actor=-18.755 alpha=0.089
# [train] episode=6940 step=952944 return=139.63 success=True time=40.9s geometry=cross_stream history=4 | q1=90.677 actor=-15.216 alpha=0.088
# [train] episode=6945 step=953322 return=143.31 success=True time=40.8s geometry=cross_stream history=4 | q1=51.826 actor=-5.060 alpha=0.089
# [train] episode=6950 step=953814 return=137.62 success=True time=40.4s geometry=cross_stream history=4 | q1=246.941 actor=-13.436 alpha=0.088
# [train] episode=6955 step=954198 return=140.60 success=True time=49.9s geometry=cross_stream history=4 | q1=66.723 actor=-14.732 alpha=0.088
# [train] episode=6960 step=954594 return=143.28 success=True time=32.1s geometry=cross_stream history=4 | q1=66.842 actor=-14.380 alpha=0.087
# [train] episode=6965 step=955020 return=141.46 success=True time=34.7s geometry=cross_stream history=4 | q1=156.766 actor=-10.230 alpha=0.087
# [train] episode=6970 step=955482 return=142.95 success=True time=49.3s geometry=cross_stream history=4 | q1=130.061 actor=-10.047 alpha=0.087
# [train] episode=6975 step=955956 return=142.11 success=True time=38.7s geometry=cross_stream history=4 | q1=48.883 actor=-14.820 alpha=0.086
# [train] episode=6980 step=956466 return=139.42 success=True time=42.0s geometry=cross_stream history=4 | q1=11.269 actor=-17.057 alpha=0.085
# [train] episode=6985 step=956748 return=142.20 success=True time=42.7s geometry=cross_stream history=4 | q1=430.865 actor=-12.604 alpha=0.085
# [train] episode=6990 step=957198 return=141.67 success=True time=45.9s geometry=cross_stream history=4 | q1=124.805 actor=-12.066 alpha=0.087
# [train] episode=6995 step=957630 return=139.57 success=True time=35.1s geometry=cross_stream history=4 | q1=92.181 actor=-13.744 alpha=0.086
# [train] episode=7000 step=958104 return=141.60 success=True time=42.5s geometry=cross_stream history=4 | q1=106.124 actor=-14.664 alpha=0.085
# [train] episode=7005 step=958662 return=137.19 success=True time=56.3s geometry=cross_stream history=4 | q1=157.815 actor=-15.445 alpha=0.085
# [train] episode=7010 step=959088 return=140.15 success=True time=42.1s geometry=cross_stream history=4 | q1=173.299 actor=-17.795 alpha=0.084
# [train] episode=7015 step=959340 return=139.80 success=True time=37.4s geometry=cross_stream history=4 | q1=7.464 actor=-11.977 alpha=0.084
# [train] episode=7020 step=959832 return=139.27 success=True time=41.6s geometry=cross_stream history=4 | q1=15.209 actor=-16.116 alpha=0.085
# [train] episode=7025 step=960354 return=142.48 success=True time=46.7s geometry=cross_stream history=4 | q1=102.601 actor=-10.123 alpha=0.086
# [train] episode=7030 step=960942 return=136.96 success=True time=46.2s geometry=cross_stream history=4 | q1=34.013 actor=-6.890 alpha=0.086
# [train] episode=7035 step=961182 return=133.90 success=True time=47.7s geometry=cross_stream history=4 | q1=124.872 actor=-12.605 alpha=0.085
# [train] episode=7040 step=961638 return=135.33 success=True time=55.5s geometry=cross_stream history=4 | q1=109.498 actor=-13.454 alpha=0.084
# [train] episode=7045 step=962076 return=142.66 success=True time=39.8s geometry=cross_stream history=4 | q1=45.773 actor=-12.402 alpha=0.083
# [train] episode=7050 step=962544 return=82.56 success=True time=38.4s geometry=cross_stream history=4 | q1=204.870 actor=-14.732 alpha=0.083
# [train] episode=7055 step=963030 return=124.55 success=True time=32.7s geometry=cross_stream history=4 | q1=112.697 actor=-5.334 alpha=0.084
# [train] episode=7060 step=963474 return=139.30 success=True time=60.9s geometry=cross_stream history=4 | q1=98.967 actor=-8.622 alpha=0.083
# [train] episode=7065 step=963846 return=141.24 success=True time=30.2s geometry=cross_stream history=4 | q1=11.222 actor=-14.996 alpha=0.082
# [train] episode=7070 step=964308 return=136.39 success=True time=49.0s geometry=cross_stream history=4 | q1=22.987 actor=-15.918 alpha=0.083
# [train] episode=7075 step=964818 return=142.33 success=True time=41.6s geometry=cross_stream history=4 | q1=311.983 actor=-16.356 alpha=0.084
# [train] episode=7080 step=965196 return=143.87 success=True time=45.2s geometry=cross_stream history=4 | q1=43.088 actor=-17.146 alpha=0.084
# [train] episode=7085 step=965574 return=142.42 success=True time=41.8s geometry=cross_stream history=4 | q1=83.843 actor=-18.122 alpha=0.084
# [train] episode=7090 step=965958 return=141.84 success=True time=41.8s geometry=cross_stream history=4 | q1=74.694 actor=-17.210 alpha=0.084
# [train] episode=7095 step=966402 return=140.66 success=True time=39.5s geometry=cross_stream history=4 | q1=19.226 actor=-19.829 alpha=0.086
# [train] episode=7100 step=966708 return=139.58 success=True time=39.6s geometry=cross_stream history=4 | q1=200.373 actor=-14.302 alpha=0.087
# [train] episode=7105 step=967116 return=142.84 success=True time=39.3s geometry=cross_stream history=4 | q1=11.092 actor=-11.362 alpha=0.089
# [train] episode=7110 step=967500 return=140.76 success=True time=31.2s geometry=cross_stream history=4 | q1=7.720 actor=-14.687 alpha=0.089
# [train] episode=7115 step=967776 return=138.51 success=True time=45.7s geometry=cross_stream history=4 | q1=11.991 actor=-11.055 alpha=0.089
# [train] episode=7120 step=968346 return=140.71 success=True time=51.5s geometry=cross_stream history=4 | q1=95.792 actor=-21.383 alpha=0.089
# [train] episode=7125 step=968712 return=142.86 success=True time=40.1s geometry=cross_stream history=4 | q1=136.571 actor=-12.409 alpha=0.090
# [train] episode=7130 step=969078 return=140.45 success=True time=39.1s geometry=cross_stream history=4 | q1=288.610 actor=-14.419 alpha=0.090
# [train] episode=7135 step=969582 return=141.94 success=True time=47.9s geometry=cross_stream history=4 | q1=267.702 actor=-13.591 alpha=0.090
# [train] episode=7140 step=969936 return=141.12 success=True time=37.1s geometry=cross_stream history=4 | q1=250.587 actor=-17.730 alpha=0.091
# [train] episode=7145 step=970374 return=142.24 success=True time=35.7s geometry=cross_stream history=4 | q1=7.215 actor=-17.772 alpha=0.092
# [train] episode=7150 step=970740 return=138.81 success=True time=43.6s geometry=cross_stream history=4 | q1=13.702 actor=-7.146 alpha=0.091
# [train] episode=7155 step=971226 return=137.29 success=True time=58.5s geometry=cross_stream history=4 | q1=157.664 actor=-19.494 alpha=0.090
# [train] episode=7160 step=971592 return=141.12 success=True time=33.7s geometry=cross_stream history=4 | q1=120.739 actor=-15.073 alpha=0.091
# [train] episode=7165 step=972090 return=141.56 success=True time=41.0s geometry=cross_stream history=4 | q1=19.243 actor=-23.171 alpha=0.093
# [train] episode=7170 step=972504 return=142.13 success=True time=41.6s geometry=cross_stream history=4 | q1=141.222 actor=-18.806 alpha=0.090
# [train] episode=7175 step=972966 return=84.54 success=True time=40.3s geometry=cross_stream history=4 | q1=170.970 actor=-15.904 alpha=0.089
# [train] episode=7180 step=973356 return=141.03 success=True time=34.3s geometry=cross_stream history=4 | q1=101.156 actor=-17.769 alpha=0.089
# [train] episode=7185 step=973926 return=139.19 success=True time=50.3s geometry=cross_stream history=4 | q1=11.554 actor=-16.443 alpha=0.087
# [train] episode=7190 step=974298 return=143.65 success=True time=41.3s geometry=cross_stream history=4 | q1=133.226 actor=-15.974 alpha=0.088
# [train] episode=7195 step=974808 return=143.00 success=True time=48.5s geometry=cross_stream history=4 | q1=79.455 actor=-17.907 alpha=0.090
# [eval] step=975000 objective=arrival_v2 return=139.35 safety=2.600 success=100.00% time=39.9s energy=32003.2 path=45.0 prog=0.91
# [train] episode=7200 step=975264 return=141.00 success=True time=37.3s geometry=cross_stream history=4 | q1=18.860 actor=-13.330 alpha=0.092
# [train] episode=7205 step=975780 return=83.80 success=True time=51.6s geometry=cross_stream history=4 | q1=79.261 actor=-14.014 alpha=0.092
# [train] episode=7210 step=976176 return=143.34 success=True time=44.4s geometry=cross_stream history=4 | q1=11.712 actor=-14.967 alpha=0.093
# [train] episode=7215 step=976554 return=140.70 success=True time=52.7s geometry=cross_stream history=4 | q1=124.226 actor=-11.814 alpha=0.093
# [train] episode=7220 step=976986 return=139.52 success=True time=41.8s geometry=cross_stream history=4 | q1=550.774 actor=-9.995 alpha=0.093
# [train] episode=7225 step=977508 return=141.14 success=True time=45.9s geometry=cross_stream history=4 | q1=21.141 actor=-15.992 alpha=0.094
# [train] episode=7230 step=977934 return=142.33 success=True time=34.9s geometry=cross_stream history=4 | q1=256.209 actor=-18.393 alpha=0.094
# [train] episode=7235 step=978282 return=140.31 success=True time=34.1s geometry=cross_stream history=4 | q1=246.919 actor=-21.957 alpha=0.094
# [train] episode=7240 step=978594 return=141.32 success=True time=33.8s geometry=cross_stream history=4 | q1=34.964 actor=-18.576 alpha=0.093
# [train] episode=7245 step=978984 return=142.66 success=True time=42.3s geometry=cross_stream history=4 | q1=55.167 actor=-14.487 alpha=0.095
# [train] episode=7250 step=979506 return=138.70 success=True time=43.3s geometry=cross_stream history=4 | q1=169.488 actor=-18.519 alpha=0.094
# [train] episode=7255 step=979944 return=140.28 success=True time=53.7s geometry=cross_stream history=4 | q1=14.059 actor=-21.168 alpha=0.094
# [train] episode=7260 step=980400 return=140.69 success=True time=40.4s geometry=cross_stream history=4 | q1=173.016 actor=-12.826 alpha=0.091
# [train] episode=7265 step=980664 return=141.34 success=True time=34.8s geometry=cross_stream history=4 | q1=418.326 actor=-9.775 alpha=0.091
# [train] episode=7270 step=981156 return=140.00 success=True time=40.9s geometry=cross_stream history=4 | q1=212.700 actor=-19.555 alpha=0.090
# [train] episode=7275 step=981588 return=142.85 success=True time=50.1s geometry=cross_stream history=4 | q1=68.323 actor=-17.203 alpha=0.090
# [train] episode=7280 step=981978 return=143.89 success=True time=31.9s geometry=cross_stream history=4 | q1=108.641 actor=-12.595 alpha=0.090
# [train] episode=7285 step=982434 return=141.46 success=True time=37.3s geometry=cross_stream history=4 | q1=16.214 actor=-12.964 alpha=0.089
# [train] episode=7290 step=982908 return=130.63 success=True time=65.2s geometry=cross_stream history=4 | q1=20.999 actor=-14.999 alpha=0.090
# [train] episode=7295 step=983226 return=140.94 success=True time=36.2s geometry=cross_stream history=4 | q1=62.082 actor=-15.832 alpha=0.089
# [train] episode=7300 step=983574 return=141.62 success=True time=47.0s geometry=cross_stream history=4 | q1=64.413 actor=-7.306 alpha=0.089
# [train] episode=7305 step=984096 return=142.03 success=True time=50.6s geometry=cross_stream history=4 | q1=42.304 actor=-13.106 alpha=0.089
# [train] episode=7310 step=984570 return=139.66 success=True time=46.4s geometry=cross_stream history=4 | q1=120.043 actor=-12.077 alpha=0.090
# [train] episode=7315 step=985038 return=140.06 success=True time=43.4s geometry=cross_stream history=4 | q1=53.761 actor=-10.171 alpha=0.090
# [train] episode=7320 step=985476 return=141.42 success=True time=46.7s geometry=cross_stream history=4 | q1=15.269 actor=-15.946 alpha=0.089
# [train] episode=7325 step=985950 return=139.40 success=True time=52.8s geometry=cross_stream history=4 | q1=5.835 actor=-21.645 alpha=0.087
# [train] episode=7330 step=986316 return=137.94 success=True time=45.5s geometry=cross_stream history=4 | q1=2.815 actor=-20.511 alpha=0.087
# [train] episode=7335 step=986682 return=142.89 success=True time=34.3s geometry=cross_stream history=4 | q1=142.445 actor=-15.799 alpha=0.089
# [train] episode=7340 step=987216 return=138.01 success=True time=44.0s geometry=cross_stream history=4 | q1=71.236 actor=-23.031 alpha=0.088
# [train] episode=7345 step=987636 return=141.66 success=True time=33.7s geometry=cross_stream history=4 | q1=222.425 actor=-12.644 alpha=0.087
# [train] episode=7350 step=988152 return=139.69 success=True time=42.5s geometry=cross_stream history=4 | q1=19.516 actor=-20.957 alpha=0.087
# [train] episode=7355 step=988584 return=138.40 success=True time=42.6s geometry=cross_stream history=4 | q1=583.144 actor=-6.269 alpha=0.087
# [train] episode=7360 step=988830 return=114.88 success=True time=43.4s geometry=cross_stream history=4 | q1=4.637 actor=-12.097 alpha=0.088
# [train] episode=7365 step=989304 return=140.57 success=True time=42.8s geometry=cross_stream history=4 | q1=205.527 actor=-17.855 alpha=0.089
# [train] episode=7370 step=989748 return=143.32 success=True time=44.6s geometry=cross_stream history=4 | q1=68.372 actor=-20.772 alpha=0.089
# [train] episode=7375 step=990102 return=139.94 success=True time=34.8s geometry=cross_stream history=4 | q1=100.107 actor=-21.652 alpha=0.088
# [train] episode=7380 step=990594 return=139.68 success=True time=40.5s geometry=cross_stream history=4 | q1=6.544 actor=-20.522 alpha=0.088
# [train] episode=7385 step=990984 return=138.19 success=True time=47.3s geometry=cross_stream history=4 | q1=85.167 actor=-24.783 alpha=0.087
# [train] episode=7390 step=991506 return=140.40 success=True time=46.3s geometry=cross_stream history=4 | q1=69.780 actor=-13.263 alpha=0.086
# [train] episode=7395 step=991908 return=139.99 success=True time=42.0s geometry=cross_stream history=4 | q1=2.607 actor=-22.587 alpha=0.085
# [train] episode=7400 step=992256 return=142.57 success=True time=48.7s geometry=cross_stream history=4 | q1=134.742 actor=-15.524 alpha=0.084
# [train] episode=7405 step=992724 return=-201.73 success=False time=38.1s geometry=cross_stream history=4 | q1=284.924 actor=-16.497 alpha=0.085
# [train] episode=7410 step=993150 return=143.98 success=True time=34.7s geometry=cross_stream history=4 | q1=88.038 actor=-20.616 alpha=0.085
# [train] episode=7415 step=993546 return=142.65 success=True time=32.4s geometry=cross_stream history=4 | q1=41.291 actor=-22.404 alpha=0.084
# [train] episode=7420 step=993942 return=140.61 success=True time=32.2s geometry=cross_stream history=4 | q1=263.651 actor=-23.050 alpha=0.085
# [train] episode=7425 step=994386 return=139.93 success=True time=36.5s geometry=cross_stream history=4 | q1=183.501 actor=-14.762 alpha=0.085
# [train] episode=7430 step=994758 return=140.46 success=True time=43.1s geometry=cross_stream history=4 | q1=5.614 actor=-15.515 alpha=0.084
# [train] episode=7435 step=995148 return=141.99 success=True time=37.4s geometry=cross_stream history=4 | q1=13.316 actor=-20.287 alpha=0.084
# [train] episode=7440 step=995556 return=141.72 success=True time=29.1s geometry=cross_stream history=4 | q1=8.439 actor=-19.535 alpha=0.085
# [train] episode=7445 step=995904 return=140.85 success=True time=37.7s geometry=cross_stream history=4 | q1=2.113 actor=-13.617 alpha=0.085
# [train] episode=7450 step=996270 return=143.04 success=True time=46.1s geometry=cross_stream history=4 | q1=54.578 actor=-12.905 alpha=0.086
# [train] episode=7455 step=996654 return=141.71 success=True time=35.5s geometry=cross_stream history=4 | q1=6.175 actor=-14.706 alpha=0.088
# [train] episode=7460 step=997080 return=140.39 success=True time=36.5s geometry=cross_stream history=4 | q1=96.019 actor=-17.341 alpha=0.088
# [train] episode=7465 step=997542 return=142.33 success=True time=41.1s geometry=cross_stream history=4 | q1=113.979 actor=-18.124 alpha=0.087
# [train] episode=7470 step=997890 return=141.33 success=True time=28.2s geometry=cross_stream history=4 | q1=193.740 actor=-16.584 alpha=0.087
# [train] episode=7475 step=998178 return=139.75 success=True time=49.7s geometry=cross_stream history=4 | q1=35.921 actor=-18.715 alpha=0.087
# [train] episode=7480 step=998658 return=142.80 success=True time=39.5s geometry=cross_stream history=4 | q1=155.625 actor=-26.906 alpha=0.088
# [train] episode=7485 step=999132 return=134.21 success=True time=50.8s geometry=cross_stream history=4 | q1=344.513 actor=-20.002 alpha=0.085
# [train] episode=7490 step=999594 return=139.80 success=True time=40.4s geometry=cross_stream history=4 | q1=5.701 actor=-16.272 alpha=0.083

# %% [markdown]
# ## 5. Phase 1 — Summarize: eval curve + final termination
#
# 重点看：
# - 600k 之后 eval rows（[625k, 1M] 共 16 个 eval 点）是否收敛
# - `last100k_mean` 是否 ≥ `0.9 × peak`（这次 last100k 跨 4 个 eval 点，比 600k 时方差小）
# - `path_efficiency` / `eval_time` 是否仍在改进（如果 path_efficiency 在 800k 后饱和，说明真稳定了；如果还在涨，说明 1M 仍未收敛）

# %%
eval_log_path = RUN_ROOT / 'results' / 'eval_log.csv'
final_eval_path = RUN_ROOT / 'results' / 'final_eval.json'
trainer_state_path = RUN_ROOT / 'trainer_state.json'

if not eval_log_path.exists():
    raise FileNotFoundError(f'missing eval log: {eval_log_path}')
if not final_eval_path.exists():
    raise FileNotFoundError(f'missing final eval: {final_eval_path}')

df = pd.read_csv(eval_log_path)
final_eval = json.loads(final_eval_path.read_text(encoding='utf-8'))
trainer_state = json.loads(trainer_state_path.read_text(encoding='utf-8')) if trainer_state_path.exists() else {}

peak_success = float(df['eval_success_rate'].max()) if len(df) else 0.0
peak_step = int(df.loc[df['eval_success_rate'].idxmax(), 'env_step']) if len(df) else 0
last100 = df[df['env_step'] >= TOTAL_STEPS - 100_000].copy()
last100_mean = float(last100['eval_success_rate'].mean()) if len(last100) else 0.0
final_success = float(final_eval['eval_success_rate'])
counts = final_eval.get('eval_termination_counts', {})
num_eps = float(final_eval.get('num_eval_episodes', EVAL_EPISODES))
oob_rate = float(counts.get('out_of_bounds', 0)) / max(num_eps, 1.0)

print('=' * 100)
print(f"{'metric':<32}{'value':>20}{'gate / note':>30}")
print('-' * 100)
print(f"{'final_success_rate':<32}{final_success:>20.4f}{f'>= {PASS_FINAL_SUCCESS:.2f}':>30}")
print(f"{'peak_success_rate':<32}{peak_success:>20.4f}{f'@ {peak_step:,}':>30}")
print(f"{'last100k_mean_success':<32}{last100_mean:>20.4f}{f'>= 0.9 * peak = {PASS_LAST100_RATIO * peak_success:.4f}':>30}")
print(f"{'final_oob_rate':<32}{oob_rate:>20.4f}{f'<= {PASS_OOB_RATE:.2f}':>30}")
print(f"{'obs_dim':<32}{trainer_state.get('observation_dim', 'NA'):>20}{'expected 48':>30}")
print(f"{'episode_context_obs':<32}{str(trainer_state.get('include_episode_context_obs', 'NA')):>20}{'expected True':>30}")
print(f"{'timeout_bootstrap':<32}{str(trainer_state.get('timeout_bootstrap_semantics', 'NA')):>20}{'expected terminal':>30}")
print('=' * 100)
print(f'termination_counts: {counts}')

print()
print('[last 16 eval rows — covers extension window 600k → 1M]')
cols = ['env_step', 'eval_success_rate', 'eval_return', 'eval_safety_cost', 'eval_time_s', 'eval_progress_ratio']
available = [c for c in cols if c in df.columns]
print(df[available].tail(16).to_string(index=False))
# Out:
# ====================================================================================================
# metric                                         value                   gate / note
# ----------------------------------------------------------------------------------------------------
# final_success_rate                            1.0000                       >= 0.85
# peak_success_rate                             1.0000                     @ 675,000
# last100k_mean_success                         0.9833        >= 0.9 * peak = 0.9000
# final_oob_rate                                0.0000                       <= 0.10
# obs_dim                                           48                   expected 48
# episode_context_obs                             True                 expected True
# timeout_bootstrap                           terminal             expected terminal
# ====================================================================================================
# termination_counts: {'goal': 30}
#
# [last 16 eval rows — covers extension window 600k → 1M]
#  env_step  eval_success_rate  eval_return  eval_safety_cost  eval_time_s  eval_progress_ratio
#    600000           0.866667   106.009709          4.670083    65.393333             0.852952
#    625002           0.933333   122.772339          3.151973    56.750000             0.859655
#    650004           0.800000    31.197374         29.835048    68.476667             0.871518
#    675000           1.000000   139.821533          2.370801    39.310000             0.907721
#    700002           0.900000    96.660719          8.717123    44.643333             0.889970
#    725004           0.966667   123.902243          5.238883    40.536667             0.901745
#    750000           1.000000   124.240258         10.092209    45.133333             0.907382
#    775002           1.000000   140.503326          2.046318    38.153333             0.907891
#    800004           0.966667   128.507186          2.638072    39.030000             0.896909
#    825000           1.000000   139.076653          2.766543    37.953333             0.908098
#    850002           1.000000   138.557169          2.978717    41.180000             0.907528
#    875004           0.966667   124.753280          4.090006    45.043333             0.889464
#    900000           0.966667   129.170119          2.407130    38.820000             0.897764
#    925002           0.966667   129.349658          1.850518    38.970000             0.888342
#    950004           1.000000   139.697558          2.430163    39.573333             0.907741
#    975000           1.000000   139.352401          2.599667    39.943333             0.907757

# %% [markdown]
# ## 6. Phase 1 — Verdict: 是否允许进入 P1 v6
#
# 5 项 check 全过则 `READY_FOR_P1_V6 = True`。
# Gate summary 落到 `results/cross_u10_extension_1M_gate_summary.json`，可与 600k 时的 `cross_u10_gate_summary.json` 并存。

# %%
checks = [
    ('final success >= 0.85',
     final_success >= PASS_FINAL_SUCCESS,
     f'{final_success:.4f}'),
    ('last100k mean >= 0.9 * peak',
     last100_mean >= PASS_LAST100_RATIO * peak_success,
     f'{last100_mean:.4f} / peak={peak_success:.4f}'),
    ('final OOB rate <= 0.10',
     oob_rate <= PASS_OOB_RATE,
     f'{oob_rate:.4f}'),
    ('arrival_v2 context obs enabled',
     trainer_state.get('include_episode_context_obs') is True,
     str(trainer_state.get('include_episode_context_obs'))),
    ('arrival_v2 timeout terminal semantics',
     trainer_state.get('timeout_bootstrap_semantics') == 'terminal',
     str(trainer_state.get('timeout_bootstrap_semantics'))),
]

print('=' * 96)
print(f"{'check':<48}{'pass':>8}{'detail':>40}")
print('-' * 96)
all_pass = True
for name, ok, detail in checks:
    mark = 'PASS' if ok else 'FAIL'
    if not ok:
        all_pass = False
    print(f'{name:<48}{mark:>8}{detail:>40}')
print('=' * 96)
print()
READY_FOR_P1_V6 = bool(all_pass)
print(f'READY_FOR_P1_V6 = {READY_FOR_P1_V6}')

summary = {
    'phase': 'cross_u10_extension_1M',
    'benchmark': BENCHMARK_KEY,
    'objective': OBJECTIVE,
    'probe_layout': PROBE_LAYOUT,
    'history_length': HISTORY_LENGTH,
    'seed': SEED,
    'total_steps': TOTAL_STEPS,
    'final_success_rate': final_success,
    'peak_success_rate': peak_success,
    'peak_step': peak_step,
    'last100k_mean_success': last100_mean,
    'final_oob_rate': oob_rate,
    'termination_counts': counts,
    'ready_for_p1_v6': READY_FOR_P1_V6,
    'checks': [{'name': n, 'ok': bool(ok), 'detail': d} for n, ok, d in checks],
}
summary_path = RUN_ROOT / 'results' / 'cross_u10_extension_1M_gate_summary.json'
summary_path.write_text(json.dumps(summary, indent=2), encoding='utf-8')
print(f'[saved] {summary_path}')
# Out:
# ================================================================================================
# check                                               pass                                  detail
# ------------------------------------------------------------------------------------------------
# final success >= 0.85                               PASS                                  1.0000
# last100k mean >= 0.9 * peak                         PASS                    0.9833 / peak=1.0000
# final OOB rate <= 0.10                              PASS                                  0.0000
# arrival_v2 context obs enabled                      PASS                                    True
# arrival_v2 timeout terminal semantics               PASS                                terminal
# ================================================================================================
#
# READY_FOR_P1_V6 = True
# [saved] experiments/arrival_v2_prototype/cross_u10_regression/arrival_v2/sac_vanilla/s0_k4/seed_46/results/cross_u10_extension_1M_gate_summary.json

# %% [markdown]
# ## 7. Phase 2 — P1 v6 配置 + manifest 生成
#
# Phase 2 = `single_u15_upstream_tgt15` (s1 / 12-D / 1.5M)。这是真正暴露 efficiency_v2 旧 failure mode 的 benchmark；arrival_v2 是否修好 P1，本节给答案。
#
# 如果 `READY_FOR_P1_V6 == False`，本节仅打印状态，不生成 manifest，不训。

# %%
print(f'READY_FOR_P1_V6 = {READY_FOR_P1_V6}')

if not READY_FOR_P1_V6:
    print('[hold] Phase 1 gate did not pass; Phase 2 stays held.')
    print('       回头看 last100k_mean / peak / OOB 哪条 fail,再决定是 reward 调参还是再延 budget')
else:
    print('[go] Phase 1 gate PASS — prepare Phase 2 manifest + P1 flow check')
    if not Path(P1_FLOW_PATH).exists():
        raise FileNotFoundError(f'missing P1 flow: {P1_FLOW_PATH}')
    if not P1_MANIFEST_PATH.exists():
        # !python -u -m scripts.generate_standard_benchmarks --benchmarks {P1_BENCHMARK_KEY} --episodes {EVAL_EPISODES}
    if not P1_MANIFEST_PATH.exists():
        raise FileNotFoundError(f'P1 manifest still missing after generate: {P1_MANIFEST_PATH}')
    print(f'[OK] P1 flow exists: {P1_FLOW_PATH}')
    print(f'[OK] P1 manifest ready: {P1_MANIFEST_PATH}')
# Out:
# READY_FOR_P1_V6 = True
# [go] Phase 1 gate PASS — prepare Phase 2 manifest + P1 flow check
# [OK] P1 flow exists: wake_data/wake_v8_U1p50_Re250_D12p00_dx0p60_Ti5pct_1200f_roi.npy
# [OK] P1 manifest ready: benchmarks/single_u15_upstream_tgt15.json

# %% [markdown]
# ## 8. Phase 2 — Run P1 v6 (1.5M)
#
# Skip / resume 逻辑：
# - `env_step >= P1_TOTAL_STEPS` → skip
# - `0 < env_step < P1_TOTAL_STEPS` → 用 `--resume` 续训（中断重连场景）
# - `env_step == 0` → 全量 fresh start
#
# 训练日志同样 `python -u` 实时输出，不再用 `%%bash`。
#
# **执行时间**：1.5M × num_envs=6 × s1 obs 12-D ≈ 5-6h L4。Colab Pro 单 session 建议在中点保存 checkpoint（已设 `CHECKPOINT_EVERY=100k`），断线后本 cell 重跑会自动 resume。

# %%
if not READY_FOR_P1_V6:
    print('[hold] Phase 1 gate did not pass; skip Phase 2 training entirely')
else:
    p1_state_path = P1_RUN_ROOT / 'trainer_state.json'
    if p1_state_path.exists():
        p1_state = json.loads(p1_state_path.read_text(encoding='utf-8'))
        p1_current_step = int(p1_state.get('env_step', 0))
    else:
        p1_current_step = 0
    print(f'[state] P1 env_step = {p1_current_step:,} / target {P1_TOTAL_STEPS:,}')

    if p1_current_step >= P1_TOTAL_STEPS:
        print(f'[skip] P1 already trained to {p1_current_step:,} ≥ {P1_TOTAL_STEPS:,}')
    elif p1_current_step > 0:
        print(f'[resume] P1 continuing from {p1_current_step:,} → {P1_TOTAL_STEPS:,}')
        # !python -u -m scripts.train_sac \
            --resume {P1_RUN_ROOT_STR} \
            --total-steps {P1_TOTAL_STEPS} \
            --eval-every {EVAL_EVERY} \
            --eval-episodes {EVAL_EPISODES} \
            --checkpoint-every {CHECKPOINT_EVERY} \
            --eval-manifest {P1_MANIFEST_PATH_STR} \
            --device {DEVICE}
    else:
        print(f'[train] P1 fresh start → {P1_TOTAL_STEPS:,}')
        # !python -u -m scripts.train_sac \
            --flow {P1_FLOW_PATH} \
            --task-geometry {P1_TASK_GEOMETRY} \
            --target-speed {TARGET_SPEED} \
            --objective {OBJECTIVE} \
            --probe-layout {P1_PROBE_LAYOUT} \
            --history-length {HISTORY_LENGTH} \
            --total-steps {P1_TOTAL_STEPS} \
            --random-steps {RANDOM_STEPS} \
            --update-after {UPDATE_AFTER} \
            --batch-size {BATCH_SIZE} \
            --hidden-dim {HIDDEN_DIM} \
            --num-envs {NUM_ENVS} \
            --eval-every {EVAL_EVERY} \
            --eval-episodes {EVAL_EPISODES} \
            --checkpoint-every {CHECKPOINT_EVERY} \
            --eval-manifest {P1_MANIFEST_PATH_STR} \
            --seed {SEED} \
            --device {DEVICE} \
            --save-dir {P1_RUN_ROOT_STR} \
            --checkpoint-dir {P1_CKPT_ROOT_STR}
# Out:
# [state] P1 env_step = 0 / target 1,500,000
# [train] P1 fresh start → 1,500,000
# [train] episode=5 step=660 return=-326.51 success=False time=54.8s geometry=upstream history=4
# [train] episode=10 step=1158 return=-444.79 success=False time=96.1s geometry=upstream history=4
# [train] episode=15 step=2046 return=-370.90 success=False time=77.2s geometry=upstream history=4
# [train] episode=20 step=2460 return=-313.08 success=False time=69.0s geometry=upstream history=4
# [train] episode=25 step=3216 return=-281.26 success=False time=14.2s geometry=upstream history=4
# [train] episode=30 step=3882 return=-338.59 success=False time=39.7s geometry=upstream history=4
# [train] episode=35 step=4548 return=-381.99 success=False time=151.3s geometry=upstream history=4
# [train] episode=40 step=5280 return=-333.10 success=False time=97.5s geometry=upstream history=4 | q1=1095.397 actor=2.588 alpha=0.197
# [train] episode=45 step=5892 return=-360.67 success=False time=62.7s geometry=upstream history=4 | q1=541.155 actor=2.489 alpha=0.192
# [train] episode=50 step=6546 return=-336.33 success=False time=42.2s geometry=upstream history=4 | q1=515.969 actor=3.834 alpha=0.186
# [train] episode=55 step=6948 return=-278.05 success=False time=20.9s geometry=upstream history=4 | q1=250.081 actor=4.559 alpha=0.182
# [train] episode=60 step=7422 return=-304.89 success=False time=18.6s geometry=upstream history=4 | q1=4.929 actor=5.453 alpha=0.178
# [train] episode=65 step=7974 return=-368.23 success=False time=45.4s geometry=upstream history=4 | q1=7.586 actor=6.751 alpha=0.174
# [train] episode=70 step=8412 return=-282.44 success=False time=26.5s geometry=upstream history=4 | q1=262.487 actor=6.830 alpha=0.170
# [train] episode=75 step=8922 return=-334.26 success=False time=52.9s geometry=upstream history=4 | q1=528.772 actor=7.566 alpha=0.166
# [train] episode=80 step=9270 return=-341.97 success=False time=92.5s geometry=upstream history=4 | q1=257.319 actor=8.211 alpha=0.163
# [train] episode=85 step=10122 return=-286.15 success=False time=72.2s geometry=upstream history=4 | q1=5.456 actor=10.191 alpha=0.156
# [train] episode=90 step=10692 return=-302.86 success=False time=26.3s geometry=upstream history=4 | q1=496.612 actor=9.048 alpha=0.152
# [train] episode=95 step=11262 return=-291.66 success=False time=46.6s geometry=upstream history=4 | q1=241.708 actor=11.977 alpha=0.148
# [train] episode=100 step=11922 return=-356.52 success=False time=95.9s geometry=upstream history=4 | q1=467.147 actor=11.640 alpha=0.144
# [train] episode=105 step=12600 return=-275.46 success=False time=17.5s geometry=upstream history=4 | q1=10.175 actor=14.353 alpha=0.140
# [train] episode=110 step=13182 return=-356.11 success=False time=36.3s geometry=upstream history=4 | q1=473.002 actor=16.390 alpha=0.137
# [train] episode=115 step=13824 return=-301.82 success=False time=24.6s geometry=upstream history=4 | q1=702.677 actor=17.211 alpha=0.133
# [train] episode=120 step=14466 return=-270.41 success=False time=26.9s geometry=upstream history=4 | q1=11.508 actor=17.689 alpha=0.130
# [train] episode=125 step=15102 return=-378.52 success=False time=70.7s geometry=upstream history=4 | q1=230.546 actor=20.443 alpha=0.126
# [train] episode=130 step=15648 return=-280.39 success=False time=15.2s geometry=upstream history=4 | q1=15.797 actor=19.722 alpha=0.123
# [train] episode=135 step=16518 return=-391.21 success=False time=106.6s geometry=upstream history=4 | q1=449.385 actor=22.126 alpha=0.119
# [train] episode=140 step=16818 return=-444.51 success=False time=96.8s geometry=upstream history=4 | q1=652.079 actor=20.507 alpha=0.118
# [train] episode=145 step=17598 return=-350.15 success=False time=73.3s geometry=upstream history=4 | q1=644.861 actor=25.072 alpha=0.114
# [train] episode=150 step=18420 return=-291.43 success=False time=36.0s geometry=upstream history=4 | q1=410.238 actor=25.132 alpha=0.110
# [train] episode=155 step=18852 return=-363.26 success=False time=106.1s geometry=upstream history=4 | q1=19.325 actor=26.982 alpha=0.108
# [train] episode=160 step=20028 return=-277.70 success=False time=79.3s geometry=upstream history=4 | q1=245.338 actor=28.703 alpha=0.103
# [train] episode=165 step=20484 return=-303.71 success=False time=136.3s geometry=upstream history=4 | q1=168.458 actor=30.099 alpha=0.101
# [train] episode=170 step=21186 return=-580.49 success=False time=87.9s geometry=upstream history=4 | q1=382.076 actor=30.684 alpha=0.099
# [train] episode=175 step=22026 return=-368.38 success=False time=69.3s geometry=upstream history=4 | q1=809.277 actor=30.058 alpha=0.096
# [train] episode=180 step=22596 return=-310.69 success=False time=53.9s geometry=upstream history=4 | q1=32.963 actor=31.523 alpha=0.094
# [train] episode=185 step=23388 return=-360.00 success=False time=47.7s geometry=upstream history=4 | q1=334.190 actor=33.143 alpha=0.092
# [train] episode=190 step=23880 return=-308.53 success=False time=27.0s geometry=upstream history=4 | q1=439.639 actor=33.031 alpha=0.091
# [train] episode=195 step=24738 return=-274.08 success=False time=70.7s geometry=upstream history=4 | q1=411.849 actor=33.382 alpha=0.090
# [eval] step=25002 objective=arrival_v2 return=-297.42 safety=19.953 success=0.00% time=58.9s energy=37096.6 path=44.4 prog=-0.31
# [train] episode=200 step=25116 return=-300.09 success=False time=53.3s geometry=upstream history=4 | q1=19.217 actor=32.793 alpha=0.090
# [train] episode=205 step=25860 return=-279.97 success=False time=31.4s geometry=upstream history=4 | q1=253.641 actor=33.782 alpha=0.088
# [train] episode=210 step=26370 return=-260.92 success=False time=122.7s geometry=upstream history=4 | q1=247.474 actor=38.696 alpha=0.088
# [train] episode=215 step=27102 return=-362.50 success=False time=90.2s geometry=upstream history=4 | q1=127.123 actor=37.404 alpha=0.086
# [train] episode=220 step=28188 return=-257.58 success=False time=119.3s geometry=upstream history=4 | q1=376.561 actor=35.294 alpha=0.083
# [train] episode=225 step=29808 return=-305.83 success=False time=224.9s geometry=upstream history=4 | q1=20.679 actor=36.573 alpha=0.078
# [train] episode=230 step=30708 return=-285.04 success=False time=41.7s geometry=upstream history=4 | q1=480.563 actor=40.454 alpha=0.077
# [train] episode=235 step=31116 return=-265.52 success=False time=33.3s geometry=upstream history=4 | q1=332.193 actor=40.272 alpha=0.075
# [train] episode=240 step=31662 return=-227.40 success=False time=153.7s geometry=upstream history=4 | q1=582.835 actor=40.601 alpha=0.074
# [train] episode=245 step=32766 return=-279.52 success=False time=92.9s geometry=upstream history=4 | q1=381.286 actor=43.601 alpha=0.071
# [train] episode=250 step=33648 return=-271.83 success=False time=47.4s geometry=upstream history=4 | q1=186.516 actor=41.743 alpha=0.069
# [train] episode=255 step=34104 return=-280.89 success=False time=32.3s geometry=upstream history=4 | q1=1200.004 actor=43.782 alpha=0.069
# [train] episode=260 step=35808 return=-289.93 success=False time=48.2s geometry=upstream history=4 | q1=162.526 actor=42.266 alpha=0.068
# [train] episode=265 step=36936 return=-330.48 success=False time=168.4s geometry=upstream history=4 | q1=223.169 actor=45.418 alpha=0.068
# [train] episode=270 step=37764 return=-234.30 success=False time=94.1s geometry=upstream history=4 | q1=327.809 actor=44.748 alpha=0.067
# [train] episode=275 step=39828 return=-54.18 success=False time=240.1s geometry=upstream history=4 | q1=807.339 actor=43.950 alpha=0.069
# [train] episode=280 step=41124 return=-89.60 success=False time=240.1s geometry=upstream history=4 | q1=112.295 actor=47.356 alpha=0.070
# [train] episode=285 step=42720 return=-122.22 success=False time=240.1s geometry=upstream history=4 | q1=357.295 actor=45.742 alpha=0.073
# [train] episode=290 step=44760 return=142.94 success=True time=169.2s geometry=upstream history=4 | q1=143.757 actor=46.186 alpha=0.082
# [train] episode=295 step=46002 return=143.35 success=True time=90.4s geometry=upstream history=4 | q1=207.757 actor=50.790 alpha=0.085
# [train] episode=300 step=47562 return=-120.00 success=False time=232.9s geometry=upstream history=4 | q1=188.843 actor=47.508 alpha=0.090
# [train] episode=305 step=49962 return=-67.60 success=False time=240.1s geometry=upstream history=4 | q1=285.998 actor=50.399 alpha=0.098
# [eval] step=50004 objective=arrival_v2 return=-46.10 safety=12.905 success=36.67% time=154.7s energy=134382.1 path=109.0 prog=0.64
# [train] episode=310 step=52140 return=-51.68 success=False time=240.1s geometry=upstream history=4 | q1=2.333 actor=46.310 alpha=0.106
# [train] episode=315 step=53346 return=-65.74 success=False time=240.1s geometry=upstream history=4 | q1=258.419 actor=46.460 alpha=0.109
# [train] episode=320 step=55122 return=-83.64 success=False time=240.1s geometry=upstream history=4 | q1=160.089 actor=48.352 alpha=0.113
# [train] episode=325 step=56802 return=102.82 success=True time=129.2s geometry=upstream history=4 | q1=70.610 actor=50.171 alpha=0.119
# [train] episode=330 step=58134 return=134.87 success=True time=155.3s geometry=upstream history=4 | q1=12.715 actor=46.196 alpha=0.122
# [train] episode=335 step=59646 return=-124.34 success=False time=197.2s geometry=upstream history=4 | q1=96.807 actor=51.291 alpha=0.125
# [train] episode=340 step=61830 return=-162.38 success=False time=237.6s geometry=upstream history=4 | q1=392.570 actor=44.678 alpha=0.127
# [train] episode=345 step=63462 return=143.57 success=True time=202.5s geometry=upstream history=4 | q1=391.384 actor=42.714 alpha=0.128
# [train] episode=350 step=65544 return=144.21 success=True time=131.2s geometry=upstream history=4 | q1=111.122 actor=43.024 alpha=0.132
# [train] episode=355 step=67188 return=-141.68 success=False time=175.8s geometry=upstream history=4 | q1=335.471 actor=46.195 alpha=0.136
# [train] episode=360 step=69270 return=-196.25 success=False time=206.9s geometry=upstream history=4 | q1=141.410 actor=43.006 alpha=0.140
# [train] episode=365 step=71328 return=-158.81 success=False time=240.1s geometry=upstream history=4 | q1=49.743 actor=46.857 alpha=0.144
# [train] episode=370 step=73782 return=-135.44 success=False time=204.3s geometry=upstream history=4 | q1=176.606 actor=43.717 alpha=0.140
# [eval] step=75000 objective=arrival_v2 return=-94.84 safety=28.402 success=20.00% time=213.5s energy=170279.6 path=105.6 prog=0.56
# [train] episode=375 step=75624 return=-355.53 success=False time=152.9s geometry=upstream history=4 | q1=15.410 actor=44.326 alpha=0.134
# [train] episode=380 step=77952 return=-253.96 success=False time=224.2s geometry=upstream history=4 | q1=244.193 actor=48.587 alpha=0.128
# [train] episode=385 step=80844 return=-135.69 success=False time=240.1s geometry=upstream history=4 | q1=7.285 actor=39.235 alpha=0.124
# [train] episode=390 step=82290 return=-298.54 success=False time=192.4s geometry=upstream history=4 | q1=3.160 actor=46.364 alpha=0.118
# [train] episode=395 step=84780 return=-146.87 success=False time=206.7s geometry=upstream history=4 | q1=7.378 actor=44.683 alpha=0.113
# [train] episode=400 step=85944 return=-140.55 success=False time=185.9s geometry=upstream history=4 | q1=201.770 actor=45.171 alpha=0.109
# [train] episode=405 step=88008 return=-252.83 success=False time=212.0s geometry=upstream history=4 | q1=212.364 actor=47.367 alpha=0.107
# [train] episode=410 step=90798 return=-134.43 success=False time=231.7s geometry=upstream history=4 | q1=42.233 actor=47.446 alpha=0.103
# [train] episode=415 step=92736 return=-195.99 success=False time=180.1s geometry=upstream history=4 | q1=6.179 actor=46.855 alpha=0.099
# [train] episode=420 step=94212 return=-90.83 success=False time=240.1s geometry=upstream history=4 | q1=6.233 actor=47.194 alpha=0.096
# [train] episode=425 step=96582 return=-91.42 success=False time=240.1s geometry=upstream history=4 | q1=164.178 actor=43.913 alpha=0.094
# [train] episode=430 step=99138 return=-427.91 success=False time=112.4s geometry=upstream history=4 | q1=3.092 actor=43.923 alpha=0.091
# [eval] step=100002 objective=arrival_v2 return=-158.74 safety=24.123 success=0.00% time=195.6s energy=146450.5 path=94.2 prog=0.54
# [train] episode=435 step=101094 return=-51.84 success=False time=240.1s geometry=upstream history=4 | q1=6.217 actor=44.420 alpha=0.087
# [train] episode=440 step=102366 return=-53.17 success=False time=240.1s geometry=upstream history=4 | q1=253.858 actor=44.890 alpha=0.083
# [train] episode=445 step=105096 return=-64.06 success=False time=240.1s geometry=upstream history=4 | q1=70.566 actor=46.774 alpha=0.078
# [train] episode=450 step=107676 return=-82.14 success=False time=240.1s geometry=upstream history=4 | q1=62.899 actor=47.525 alpha=0.078
# [train] episode=455 step=110526 return=-66.27 success=False time=240.1s geometry=upstream history=4 | q1=3.131 actor=44.370 alpha=0.074
# [train] episode=460 step=111264 return=-38.09 success=False time=240.1s geometry=upstream history=4 | q1=124.057 actor=45.241 alpha=0.074
# [train] episode=465 step=113736 return=-65.95 success=False time=240.1s geometry=upstream history=4 | q1=8.759 actor=44.007 alpha=0.071
# [train] episode=470 step=116310 return=-29.08 success=False time=240.1s geometry=upstream history=4 | q1=255.239 actor=51.437 alpha=0.069
# [train] episode=475 step=117672 return=142.38 success=True time=194.2s geometry=upstream history=4 | q1=58.648 actor=47.005 alpha=0.068
# [train] episode=480 step=120018 return=-250.71 success=False time=240.1s geometry=upstream history=4 | q1=188.871 actor=46.108 alpha=0.066
# [train] episode=485 step=121926 return=-194.09 success=False time=226.2s geometry=upstream history=4 | q1=54.229 actor=47.245 alpha=0.066
# [train] episode=490 step=124284 return=141.38 success=True time=217.8s geometry=upstream history=4 | q1=116.065 actor=48.183 alpha=0.065
# [eval] step=125004 objective=arrival_v2 return=-181.53 safety=34.758 success=0.00% time=181.9s energy=139086.4 path=81.4 prog=0.46
# [train] episode=495 step=126420 return=143.16 success=True time=192.7s geometry=upstream history=4 | q1=4.109 actor=46.007 alpha=0.062
# [train] episode=500 step=128136 return=-264.16 success=False time=240.1s geometry=upstream history=4 | q1=79.808 actor=47.800 alpha=0.058
# [train] episode=505 step=130638 return=-57.08 success=False time=240.1s geometry=upstream history=4 | q1=13.331 actor=48.318 alpha=0.056
# [train] episode=510 step=132864 return=139.62 success=True time=168.4s geometry=upstream history=4 | q1=101.739 actor=46.910 alpha=0.055
# [train] episode=515 step=135096 return=-67.72 success=False time=240.1s geometry=upstream history=4 | q1=118.280 actor=48.010 alpha=0.054
# [train] episode=520 step=136872 return=142.62 success=True time=147.2s geometry=upstream history=4 | q1=130.454 actor=46.198 alpha=0.054
# [train] episode=525 step=138702 return=-177.97 success=False time=223.5s geometry=upstream history=4 | q1=89.429 actor=47.109 alpha=0.054
# [train] episode=530 step=141216 return=-185.88 success=False time=138.0s geometry=upstream history=4 | q1=120.401 actor=45.427 alpha=0.055
# [train] episode=535 step=142818 return=142.81 success=True time=120.7s geometry=upstream history=4 | q1=77.854 actor=47.257 alpha=0.057
# [train] episode=540 step=143730 return=143.89 success=True time=177.4s geometry=upstream history=4 | q1=40.992 actor=43.566 alpha=0.057
# [train] episode=545 step=146070 return=-88.01 success=False time=240.1s geometry=upstream history=4 | q1=2.590 actor=44.434 alpha=0.059
# [train] episode=550 step=148704 return=-100.57 success=False time=240.1s geometry=upstream history=4 | q1=118.441 actor=47.145 alpha=0.062
# [eval] step=150000 objective=arrival_v2 return=-167.35 safety=21.790 success=6.67% time=175.0s energy=149499.2 path=121.1 prog=0.41
# [train] episode=555 step=150396 return=-176.69 success=False time=128.6s geometry=upstream history=4 | q1=51.475 actor=43.461 alpha=0.065
# [train] episode=560 step=152130 return=-59.22 success=False time=240.1s geometry=upstream history=4 | q1=5.792 actor=48.186 alpha=0.067
# [train] episode=565 step=153864 return=-157.66 success=False time=183.9s geometry=upstream history=4 | q1=215.379 actor=46.600 alpha=0.070
# [train] episode=570 step=156042 return=-106.63 success=False time=240.1s geometry=upstream history=4 | q1=5.399 actor=46.330 alpha=0.073
# [train] episode=575 step=157950 return=144.11 success=True time=174.7s geometry=upstream history=4 | q1=2.928 actor=45.593 alpha=0.073
# [train] episode=580 step=160032 return=143.54 success=True time=112.8s geometry=upstream history=4 | q1=86.293 actor=45.274 alpha=0.077
# [train] episode=585 step=161604 return=144.32 success=True time=130.4s geometry=upstream history=4 | q1=12.622 actor=45.062 alpha=0.078
# [train] episode=590 step=162684 return=-195.88 success=False time=199.7s geometry=upstream history=4 | q1=19.775 actor=48.684 alpha=0.079
# [train] episode=595 step=165354 return=144.17 success=True time=134.9s geometry=upstream history=4 | q1=64.474 actor=44.331 alpha=0.079
# [train] episode=600 step=166806 return=143.36 success=True time=121.0s geometry=upstream history=4 | q1=112.124 actor=44.156 alpha=0.080
# [train] episode=605 step=168468 return=-32.76 success=False time=240.1s geometry=upstream history=4 | q1=18.974 actor=44.959 alpha=0.083
# [train] episode=610 step=170268 return=58.96 success=True time=133.2s geometry=upstream history=4 | q1=2.705 actor=44.300 alpha=0.086
# [train] episode=615 step=171564 return=142.36 success=True time=155.1s geometry=upstream history=4 | q1=98.370 actor=46.683 alpha=0.085
# [train] episode=620 step=173652 return=-98.10 success=False time=240.1s geometry=upstream history=4 | q1=57.810 actor=45.604 alpha=0.085
# [eval] step=175002 objective=arrival_v2 return=36.07 safety=3.559 success=50.00% time=175.2s energy=144444.2 path=101.2 prog=0.78
# [train] episode=625 step=175080 return=-74.36 success=False time=240.1s geometry=upstream history=4 | q1=219.757 actor=44.179 alpha=0.083
# [train] episode=630 step=176832 return=144.63 success=True time=148.9s geometry=upstream history=4 | q1=8.169 actor=46.165 alpha=0.084
# [train] episode=635 step=178446 return=138.30 success=True time=179.1s geometry=upstream history=4 | q1=11.004 actor=41.854 alpha=0.083
# [train] episode=640 step=180534 return=-66.71 success=False time=240.1s geometry=upstream history=4 | q1=179.445 actor=44.350 alpha=0.083
# [train] episode=645 step=182352 return=-46.37 success=False time=240.1s geometry=upstream history=4 | q1=93.061 actor=44.900 alpha=0.082
# [train] episode=650 step=184482 return=142.90 success=True time=110.3s geometry=upstream history=4 | q1=142.679 actor=41.908 alpha=0.078
# [train] episode=655 step=186534 return=-263.33 success=False time=115.3s geometry=upstream history=4 | q1=58.742 actor=43.078 alpha=0.078
# [train] episode=660 step=188136 return=-119.11 success=False time=240.1s geometry=upstream history=4 | q1=7.860 actor=45.405 alpha=0.073
# [train] episode=665 step=189738 return=-18.98 success=False time=240.1s geometry=upstream history=4 | q1=2.598 actor=41.748 alpha=0.071
# [train] episode=670 step=191550 return=144.17 success=True time=172.2s geometry=upstream history=4 | q1=14.459 actor=44.549 alpha=0.067
# [train] episode=675 step=194070 return=-29.67 success=False time=240.1s geometry=upstream history=4 | q1=63.399 actor=43.206 alpha=0.062
# [train] episode=680 step=196068 return=-27.04 success=False time=240.1s geometry=upstream history=4 | q1=1.744 actor=42.649 alpha=0.062
# [train] episode=685 step=198228 return=-155.53 success=False time=240.1s geometry=upstream history=4 | q1=140.003 actor=42.795 alpha=0.060
# [eval] step=200004 objective=arrival_v2 return=10.90 safety=11.644 success=46.67% time=176.5s energy=140120.3 path=101.7 prog=0.84
# [train] episode=690 step=200622 return=-133.67 success=False time=183.2s geometry=upstream history=4 | q1=3.537 actor=42.996 alpha=0.061
# [train] episode=695 step=202668 return=135.51 success=True time=139.9s geometry=upstream history=4 | q1=56.603 actor=43.061 alpha=0.059
# [train] episode=700 step=203886 return=-224.54 success=False time=90.2s geometry=upstream history=4 | q1=15.825 actor=41.869 alpha=0.059
# [train] episode=705 step=205956 return=-156.16 success=False time=171.9s geometry=upstream history=4 | q1=59.720 actor=40.999 alpha=0.061
# [train] episode=710 step=207720 return=144.42 success=True time=103.9s geometry=upstream history=4 | q1=5.412 actor=38.560 alpha=0.062
# [train] episode=715 step=209532 return=-155.65 success=False time=153.9s geometry=upstream history=4 | q1=69.079 actor=41.973 alpha=0.060
# [train] episode=720 step=211062 return=143.52 success=True time=125.9s geometry=upstream history=4 | q1=1.766 actor=39.853 alpha=0.058
# [train] episode=725 step=213024 return=-194.49 success=False time=162.6s geometry=upstream history=4 | q1=150.483 actor=41.765 alpha=0.057
# [train] episode=730 step=214674 return=-100.03 success=False time=234.1s geometry=upstream history=4 | q1=66.508 actor=40.271 alpha=0.058
# [train] episode=735 step=216504 return=143.67 success=True time=110.1s geometry=upstream history=4 | q1=7.315 actor=42.387 alpha=0.057
# [train] episode=740 step=218454 return=143.21 success=True time=170.8s geometry=upstream history=4 | q1=37.844 actor=41.282 alpha=0.055
# [train] episode=745 step=220434 return=-24.98 success=False time=240.1s geometry=upstream history=4 | q1=14.548 actor=40.605 alpha=0.056
# [train] episode=750 step=222258 return=136.23 success=True time=151.4s geometry=upstream history=4 | q1=2.360 actor=41.287 alpha=0.057
# [train] episode=755 step=224394 return=-23.03 success=False time=240.1s geometry=upstream history=4 | q1=182.720 actor=42.298 alpha=0.057
# [eval] step=225000 objective=arrival_v2 return=-12.11 safety=5.803 success=33.33% time=182.9s energy=152648.0 path=108.3 prog=0.75
# [train] episode=760 step=226404 return=-14.83 success=False time=240.1s geometry=upstream history=4 | q1=2.219 actor=38.691 alpha=0.057
# [train] episode=765 step=228132 return=-24.12 success=False time=240.1s geometry=upstream history=4 | q1=1.968 actor=39.375 alpha=0.057
# [train] episode=770 step=230280 return=-102.11 success=False time=240.1s geometry=upstream history=4 | q1=4.026 actor=41.728 alpha=0.058
# [train] episode=775 step=231786 return=-138.26 success=False time=135.1s geometry=upstream history=4 | q1=15.321 actor=39.230 alpha=0.058
# [train] episode=780 step=233670 return=144.02 success=True time=155.8s geometry=upstream history=4 | q1=16.802 actor=39.179 alpha=0.058
# [train] episode=785 step=235956 return=-94.67 success=False time=203.8s geometry=upstream history=4 | q1=109.699 actor=40.248 alpha=0.059
# [train] episode=790 step=237294 return=-138.65 success=False time=235.8s geometry=upstream history=4 | q1=3.971 actor=41.669 alpha=0.059
# [train] episode=795 step=239526 return=-9.84 success=True time=191.9s geometry=upstream history=4 | q1=7.650 actor=37.532 alpha=0.059
# [train] episode=800 step=241566 return=-128.36 success=False time=237.6s geometry=upstream history=4 | q1=19.174 actor=37.312 alpha=0.058
# [train] episode=805 step=243912 return=136.49 success=True time=152.7s geometry=upstream history=4 | q1=159.043 actor=38.285 alpha=0.059
# [train] episode=810 step=245424 return=-175.61 success=False time=217.4s geometry=upstream history=4 | q1=56.582 actor=40.672 alpha=0.059
# [train] episode=815 step=247320 return=144.23 success=True time=83.3s geometry=upstream history=4 | q1=61.416 actor=38.138 alpha=0.058
# [train] episode=820 step=249804 return=-109.00 success=False time=232.6s geometry=upstream history=4 | q1=2.254 actor=42.564 alpha=0.059
# [eval] step=250002 objective=arrival_v2 return=-12.87 safety=8.019 success=23.33% time=217.6s energy=164210.0 path=109.3 prog=0.74
# [train] episode=825 step=250860 return=-48.48 success=False time=240.1s geometry=upstream history=4 | q1=4.368 actor=37.159 alpha=0.057
# [train] episode=830 step=253104 return=-36.23 success=False time=240.1s geometry=upstream history=4 | q1=16.348 actor=39.269 alpha=0.060
# [train] episode=835 step=254142 return=-33.70 success=False time=240.1s geometry=upstream history=4 | q1=93.318 actor=37.955 alpha=0.059
# [train] episode=840 step=256632 return=-19.92 success=False time=240.1s geometry=upstream history=4 | q1=7.061 actor=38.493 alpha=0.058
# [train] episode=845 step=257718 return=142.89 success=True time=120.3s geometry=upstream history=4 | q1=54.565 actor=38.689 alpha=0.057
# [train] episode=850 step=259998 return=-23.38 success=False time=240.1s geometry=upstream history=4 | q1=207.158 actor=37.322 alpha=0.058
# [train] episode=855 step=261588 return=-22.94 success=False time=240.1s geometry=upstream history=4 | q1=117.965 actor=40.752 alpha=0.057
# [train] episode=860 step=263886 return=135.41 success=True time=144.3s geometry=upstream history=4 | q1=110.578 actor=40.126 alpha=0.058
# [train] episode=865 step=265854 return=-13.73 success=False time=240.1s geometry=upstream history=4 | q1=4.979 actor=37.674 alpha=0.058
# [train] episode=870 step=268674 return=-80.19 success=False time=240.1s geometry=upstream history=4 | q1=2.520 actor=35.948 alpha=0.055
# [train] episode=875 step=269670 return=-28.38 success=False time=240.1s geometry=upstream history=4 | q1=145.155 actor=36.221 alpha=0.053
# [train] episode=880 step=272154 return=142.29 success=True time=206.5s geometry=upstream history=4 | q1=47.882 actor=38.299 alpha=0.052
# [train] episode=885 step=273774 return=143.84 success=True time=177.2s geometry=upstream history=4 | q1=42.489 actor=36.271 alpha=0.051
# [eval] step=275004 objective=arrival_v2 return=15.09 safety=7.985 success=43.33% time=179.7s energy=141815.7 path=109.2 prog=0.82
# [train] episode=890 step=276414 return=-27.24 success=False time=240.1s geometry=upstream history=4 | q1=5.792 actor=38.487 alpha=0.052
# [train] episode=895 step=277872 return=144.25 success=True time=79.9s geometry=upstream history=4 | q1=2.705 actor=37.829 alpha=0.052
# [train] episode=900 step=279594 return=134.82 success=True time=92.3s geometry=upstream history=4 | q1=54.259 actor=36.464 alpha=0.053
# [train] episode=905 step=281592 return=142.31 success=True time=165.7s geometry=upstream history=4 | q1=15.247 actor=37.983 alpha=0.052
# [train] episode=910 step=282372 return=-133.55 success=False time=154.9s geometry=upstream history=4 | q1=11.811 actor=38.776 alpha=0.053
# [train] episode=915 step=284520 return=126.42 success=True time=178.4s geometry=upstream history=4 | q1=22.927 actor=40.335 alpha=0.051
# [train] episode=920 step=286092 return=144.04 success=True time=130.5s geometry=upstream history=4 | q1=321.668 actor=37.699 alpha=0.050
# [train] episode=925 step=288132 return=-42.86 success=False time=240.1s geometry=upstream history=4 | q1=9.375 actor=38.605 alpha=0.049
# [train] episode=930 step=289842 return=144.45 success=True time=146.5s geometry=upstream history=4 | q1=156.718 actor=39.382 alpha=0.050
# [train] episode=935 step=291786 return=-51.98 success=False time=240.1s geometry=upstream history=4 | q1=2.423 actor=34.220 alpha=0.050
# [train] episode=940 step=293832 return=-53.03 success=False time=240.1s geometry=upstream history=4 | q1=83.648 actor=35.403 alpha=0.050
# [train] episode=945 step=295440 return=-37.98 success=False time=240.1s geometry=upstream history=4 | q1=24.199 actor=35.554 alpha=0.049
# [train] episode=950 step=297384 return=-84.89 success=False time=240.1s geometry=upstream history=4 | q1=2.732 actor=37.339 alpha=0.049
# [train] episode=955 step=299226 return=132.64 success=True time=202.0s geometry=upstream history=4 | q1=102.753 actor=37.619 alpha=0.050
# [eval] step=300000 objective=arrival_v2 return=51.59 safety=11.297 success=66.67% time=166.2s energy=128613.9 path=108.2 prog=0.75
# [train] episode=960 step=300744 return=144.77 success=True time=125.7s geometry=upstream history=4 | q1=5.855 actor=38.342 alpha=0.051
# [train] episode=965 step=302268 return=-45.10 success=False time=240.1s geometry=upstream history=4 | q1=20.903 actor=36.206 alpha=0.050
# [train] episode=970 step=303660 return=128.94 success=True time=115.5s geometry=upstream history=4 | q1=50.829 actor=34.627 alpha=0.049
# [train] episode=975 step=306060 return=-64.86 success=False time=240.1s geometry=upstream history=4 | q1=3.834 actor=34.471 alpha=0.049
# [train] episode=980 step=307476 return=143.99 success=True time=74.3s geometry=upstream history=4 | q1=67.986 actor=35.136 alpha=0.047
# [train] episode=985 step=309444 return=-209.42 success=False time=240.1s geometry=upstream history=4 | q1=4.790 actor=36.432 alpha=0.047
# [train] episode=990 step=311190 return=144.64 success=True time=108.1s geometry=upstream history=4 | q1=83.215 actor=35.969 alpha=0.048
# [train] episode=995 step=312510 return=142.56 success=True time=161.1s geometry=upstream history=4 | q1=3.882 actor=34.992 alpha=0.050
# [train] episode=1000 step=315114 return=-39.75 success=False time=240.1s geometry=upstream history=4 | q1=3.132 actor=34.089 alpha=0.049
# [train] episode=1005 step=316416 return=-36.61 success=False time=240.1s geometry=upstream history=4 | q1=36.007 actor=33.872 alpha=0.049
# [train] episode=1010 step=318120 return=-42.79 success=False time=240.1s geometry=upstream history=4 | q1=129.805 actor=35.200 alpha=0.050
# [train] episode=1015 step=319806 return=134.39 success=True time=174.3s geometry=upstream history=4 | q1=11.180 actor=33.376 alpha=0.049
# [train] episode=1020 step=321408 return=144.01 success=True time=174.4s geometry=upstream history=4 | q1=9.109 actor=37.335 alpha=0.050
# [train] episode=1025 step=321918 return=143.33 success=True time=175.4s geometry=upstream history=4 | q1=4.403 actor=33.519 alpha=0.050
# [train] episode=1030 step=323976 return=142.47 success=True time=171.4s geometry=upstream history=4 | q1=46.737 actor=31.931 alpha=0.052
# [eval] step=325002 objective=arrival_v2 return=61.14 safety=5.606 success=66.67% time=160.4s energy=124946.7 path=96.1 prog=0.80
# [train] episode=1035 step=326256 return=-24.76 success=False time=240.1s geometry=upstream history=4 | q1=139.325 actor=33.094 alpha=0.051
# [train] episode=1040 step=328248 return=142.01 success=True time=153.1s geometry=upstream history=4 | q1=77.926 actor=34.462 alpha=0.051
# [train] episode=1045 step=329148 return=-99.38 success=False time=240.1s geometry=upstream history=4 | q1=6.418 actor=33.687 alpha=0.052
# [train] episode=1050 step=331542 return=-49.60 success=False time=240.1s geometry=upstream history=4 | q1=2.014 actor=34.667 alpha=0.053
# [train] episode=1055 step=333036 return=144.00 success=True time=157.3s geometry=upstream history=4 | q1=2.434 actor=33.304 alpha=0.053
# [train] episode=1060 step=334788 return=141.36 success=True time=109.3s geometry=upstream history=4 | q1=47.207 actor=33.340 alpha=0.051
# [train] episode=1065 step=336774 return=144.47 success=True time=122.8s geometry=upstream history=4 | q1=3.101 actor=33.667 alpha=0.051
# [train] episode=1070 step=338124 return=143.89 success=True time=110.8s geometry=upstream history=4 | q1=102.419 actor=31.451 alpha=0.050
# [train] episode=1075 step=339858 return=-66.74 success=False time=240.1s geometry=upstream history=4 | q1=49.103 actor=33.242 alpha=0.051
# [train] episode=1080 step=341502 return=144.74 success=True time=121.3s geometry=upstream history=4 | q1=61.918 actor=32.996 alpha=0.053
# [train] episode=1085 step=343266 return=-52.95 success=False time=240.1s geometry=upstream history=4 | q1=3.547 actor=30.370 alpha=0.051
# [train] episode=1090 step=345222 return=144.26 success=True time=98.6s geometry=upstream history=4 | q1=1.765 actor=33.956 alpha=0.050
# [train] episode=1095 step=346362 return=144.31 success=True time=152.1s geometry=upstream history=4 | q1=8.244 actor=31.070 alpha=0.049
# [train] episode=1100 step=347760 return=143.11 success=True time=210.7s geometry=upstream history=4 | q1=3.386 actor=32.872 alpha=0.049
# [eval] step=350004 objective=arrival_v2 return=99.08 safety=6.118 success=83.33% time=153.2s energy=125078.0 path=95.0 prog=0.89
# [train] episode=1105 step=350094 return=136.57 success=True time=205.1s geometry=upstream history=4 | q1=184.714 actor=32.127 alpha=0.050
# [train] episode=1110 step=351762 return=142.24 success=True time=128.7s geometry=upstream history=4 | q1=15.765 actor=35.343 alpha=0.050
# [train] episode=1115 step=353274 return=142.37 success=True time=125.1s geometry=upstream history=4 | q1=16.188 actor=33.640 alpha=0.048
# [train] episode=1120 step=354984 return=-80.56 success=False time=240.1s geometry=upstream history=4 | q1=161.472 actor=34.792 alpha=0.047
# [train] episode=1125 step=356214 return=140.92 success=True time=164.0s geometry=upstream history=4 | q1=65.078 actor=31.375 alpha=0.046
# [train] episode=1130 step=358026 return=-65.45 success=False time=240.1s geometry=upstream history=4 | q1=10.095 actor=29.630 alpha=0.046
# [train] episode=1135 step=359808 return=143.81 success=True time=161.3s geometry=upstream history=4 | q1=3.700 actor=32.108 alpha=0.046
# [train] episode=1140 step=361122 return=144.45 success=True time=120.3s geometry=upstream history=4 | q1=4.498 actor=31.298 alpha=0.045
# [train] episode=1145 step=363696 return=-65.05 success=False time=240.1s geometry=upstream history=4 | q1=5.684 actor=32.499 alpha=0.044
# [train] episode=1150 step=365286 return=-27.74 success=False time=240.1s geometry=upstream history=4 | q1=2.887 actor=32.030 alpha=0.044
# [train] episode=1155 step=367806 return=-53.60 success=False time=240.1s geometry=upstream history=4 | q1=1.712 actor=30.003 alpha=0.043
# [train] episode=1160 step=369348 return=144.10 success=True time=127.8s geometry=upstream history=4 | q1=46.977 actor=28.574 alpha=0.045
# [train] episode=1165 step=371244 return=143.49 success=True time=137.9s geometry=upstream history=4 | q1=3.347 actor=29.251 alpha=0.046
# [train] episode=1170 step=372486 return=143.79 success=True time=151.1s geometry=upstream history=4 | q1=75.444 actor=29.936 alpha=0.046
# [train] episode=1175 step=374430 return=-94.97 success=False time=240.1s geometry=upstream history=4 | q1=112.965 actor=28.422 alpha=0.045
# [eval] step=375000 objective=arrival_v2 return=121.17 safety=3.071 success=90.00% time=138.2s energy=114894.9 path=84.8 prog=0.92
# [train] episode=1180 step=375570 return=144.72 success=True time=94.5s geometry=upstream history=4 | q1=2.243 actor=32.327 alpha=0.046
# [train] episode=1185 step=376734 return=144.05 success=True time=80.3s geometry=upstream history=4 | q1=2.076 actor=31.815 alpha=0.045
# [train] episode=1190 step=378510 return=-25.19 success=False time=240.1s geometry=upstream history=4 | q1=165.815 actor=31.225 alpha=0.046
# [train] episode=1195 step=379428 return=143.77 success=True time=156.4s geometry=upstream history=4 | q1=41.332 actor=28.320 alpha=0.046
# [train] episode=1200 step=380868 return=144.05 success=True time=133.7s geometry=upstream history=4 | q1=253.378 actor=32.134 alpha=0.046
# [train] episode=1205 step=382944 return=-65.48 success=False time=240.1s geometry=upstream history=4 | q1=3.876 actor=30.593 alpha=0.044
# [train] episode=1210 step=384174 return=-146.70 success=False time=240.1s geometry=upstream history=4 | q1=10.297 actor=30.915 alpha=0.044
# [train] episode=1215 step=385860 return=144.58 success=True time=128.5s geometry=upstream history=4 | q1=107.816 actor=29.802 alpha=0.044
# [train] episode=1220 step=387240 return=144.26 success=True time=165.9s geometry=upstream history=4 | q1=21.529 actor=28.473 alpha=0.046
# [train] episode=1225 step=388668 return=144.05 success=True time=118.1s geometry=upstream history=4 | q1=23.712 actor=30.555 alpha=0.045
# [train] episode=1230 step=391350 return=-30.43 success=False time=240.1s geometry=upstream history=4 | q1=2.599 actor=30.576 alpha=0.044
# [train] episode=1235 step=393504 return=-41.92 success=False time=240.1s geometry=upstream history=4 | q1=6.496 actor=30.000 alpha=0.042
# [train] episode=1240 step=395016 return=-20.74 success=False time=240.1s geometry=upstream history=4 | q1=3.135 actor=31.177 alpha=0.044
# [train] episode=1245 step=396870 return=141.27 success=True time=153.9s geometry=upstream history=4 | q1=7.221 actor=28.967 alpha=0.044
# [train] episode=1250 step=397926 return=143.71 success=True time=83.5s geometry=upstream history=4 | q1=141.346 actor=30.355 alpha=0.045
# [train] episode=1255 step=399576 return=142.79 success=True time=196.8s geometry=upstream history=4 | q1=53.638 actor=28.124 alpha=0.048
# [eval] step=400002 objective=arrival_v2 return=37.86 safety=5.910 success=50.00% time=184.7s energy=140655.4 path=119.8 prog=0.79
# [train] episode=1260 step=401196 return=91.50 success=True time=153.2s geometry=upstream history=4 | q1=47.565 actor=28.831 alpha=0.048
# [train] episode=1265 step=402468 return=-19.32 success=False time=240.1s geometry=upstream history=4 | q1=6.173 actor=27.204 alpha=0.048
# [train] episode=1270 step=404664 return=142.75 success=True time=189.2s geometry=upstream history=4 | q1=144.455 actor=28.049 alpha=0.048
# [train] episode=1275 step=405996 return=143.09 success=True time=110.3s geometry=upstream history=4 | q1=6.304 actor=27.159 alpha=0.047
# [train] episode=1280 step=408318 return=140.41 success=True time=81.0s geometry=upstream history=4 | q1=117.206 actor=28.522 alpha=0.047
# [train] episode=1285 step=409338 return=144.71 success=True time=124.7s geometry=upstream history=4 | q1=84.295 actor=25.723 alpha=0.047
# [train] episode=1290 step=410652 return=144.42 success=True time=146.3s geometry=upstream history=4 | q1=15.091 actor=28.842 alpha=0.047
# [train] episode=1295 step=412824 return=142.92 success=True time=105.9s geometry=upstream history=4 | q1=73.298 actor=25.604 alpha=0.048
# [train] episode=1300 step=414546 return=138.06 success=True time=142.7s geometry=upstream history=4 | q1=7.342 actor=25.484 alpha=0.050
# [train] episode=1305 step=416166 return=143.40 success=True time=134.5s geometry=upstream history=4 | q1=67.874 actor=25.525 alpha=0.049
# [train] episode=1310 step=417402 return=143.28 success=True time=213.2s geometry=upstream history=4 | q1=127.944 actor=26.558 alpha=0.049
# [train] episode=1315 step=418944 return=144.14 success=True time=161.1s geometry=upstream history=4 | q1=150.522 actor=28.884 alpha=0.050
# [train] episode=1320 step=421128 return=-29.18 success=False time=240.1s geometry=upstream history=4 | q1=32.915 actor=29.304 alpha=0.050
# [train] episode=1325 step=422736 return=-60.78 success=False time=240.1s geometry=upstream history=4 | q1=41.076 actor=26.628 alpha=0.052
# [train] episode=1330 step=424014 return=144.04 success=True time=87.2s geometry=upstream history=4 | q1=42.202 actor=28.880 alpha=0.053
# [eval] step=425004 objective=arrival_v2 return=68.11 safety=13.077 success=76.67% time=148.9s energy=121564.1 path=92.1 prog=0.88
# [train] episode=1335 step=425814 return=144.02 success=True time=149.4s geometry=upstream history=4 | q1=235.149 actor=29.319 alpha=0.054
# [train] episode=1340 step=427344 return=144.43 success=True time=92.4s geometry=upstream history=4 | q1=73.243 actor=26.429 alpha=0.053
# [train] episode=1345 step=428922 return=-24.01 success=False time=240.1s geometry=upstream history=4 | q1=20.135 actor=28.265 alpha=0.052
# [train] episode=1350 step=430470 return=143.73 success=True time=111.6s geometry=upstream history=4 | q1=19.093 actor=27.214 alpha=0.051
# [train] episode=1355 step=432408 return=142.00 success=True time=176.8s geometry=upstream history=4 | q1=19.961 actor=25.300 alpha=0.049
# [train] episode=1360 step=434208 return=143.64 success=True time=149.3s geometry=upstream history=4 | q1=23.215 actor=25.218 alpha=0.049
# [train] episode=1365 step=436188 return=143.88 success=True time=164.4s geometry=upstream history=4 | q1=19.860 actor=25.496 alpha=0.050
# [train] episode=1370 step=437598 return=-22.34 success=False time=240.1s geometry=upstream history=4 | q1=46.180 actor=22.362 alpha=0.050
# [train] episode=1375 step=439188 return=140.77 success=True time=131.7s geometry=upstream history=4 | q1=72.803 actor=26.700 alpha=0.050
# [train] episode=1380 step=440916 return=144.44 success=True time=139.4s geometry=upstream history=4 | q1=162.899 actor=24.298 alpha=0.049
# [train] episode=1385 step=442314 return=143.94 success=True time=108.6s geometry=upstream history=4 | q1=3.827 actor=25.075 alpha=0.049
# [train] episode=1390 step=444654 return=143.78 success=True time=117.4s geometry=upstream history=4 | q1=20.487 actor=25.917 alpha=0.048
# [train] episode=1395 step=446292 return=143.70 success=True time=123.3s geometry=upstream history=4 | q1=127.089 actor=25.104 alpha=0.048
# [train] episode=1400 step=448302 return=136.63 success=True time=198.1s geometry=upstream history=4 | q1=90.017 actor=27.005 alpha=0.048
# [train] episode=1405 step=449850 return=144.66 success=True time=115.5s geometry=upstream history=4 | q1=97.470 actor=26.815 alpha=0.048
# [eval] step=450000 objective=arrival_v2 return=114.55 safety=4.099 success=86.67% time=138.5s energy=114599.6 path=82.0 prog=0.93
# [train] episode=1410 step=450990 return=-14.86 success=False time=240.1s geometry=upstream history=4 | q1=8.372 actor=23.954 alpha=0.048
# [train] episode=1415 step=452520 return=138.11 success=True time=134.1s geometry=upstream history=4 | q1=24.014 actor=22.747 alpha=0.048
# [train] episode=1420 step=454212 return=144.21 success=True time=140.4s geometry=upstream history=4 | q1=2.323 actor=25.693 alpha=0.047
# [train] episode=1425 step=455724 return=143.38 success=True time=104.8s geometry=upstream history=4 | q1=223.379 actor=23.898 alpha=0.048
# [train] episode=1430 step=457104 return=-27.72 success=False time=240.1s geometry=upstream history=4 | q1=17.414 actor=24.974 alpha=0.047
# [train] episode=1435 step=459048 return=140.07 success=True time=118.8s geometry=upstream history=4 | q1=57.608 actor=24.080 alpha=0.048
# [train] episode=1440 step=460032 return=140.15 success=True time=123.6s geometry=upstream history=4 | q1=4.547 actor=25.370 alpha=0.048
# [train] episode=1445 step=461430 return=136.96 success=True time=161.0s geometry=upstream history=4 | q1=52.153 actor=25.416 alpha=0.047
# [train] episode=1450 step=462948 return=143.52 success=True time=183.8s geometry=upstream history=4 | q1=50.570 actor=22.439 alpha=0.047
# [train] episode=1455 step=464610 return=144.48 success=True time=138.0s geometry=upstream history=4 | q1=5.937 actor=23.250 alpha=0.049
# [train] episode=1460 step=465702 return=141.43 success=True time=83.0s geometry=upstream history=4 | q1=6.290 actor=24.970 alpha=0.050
# [train] episode=1465 step=467562 return=-17.74 success=False time=240.1s geometry=upstream history=4 | q1=5.304 actor=21.172 alpha=0.046
# [train] episode=1470 step=469140 return=142.25 success=True time=216.8s geometry=upstream history=4 | q1=131.367 actor=24.639 alpha=0.046
# [train] episode=1475 step=471060 return=143.61 success=True time=159.1s geometry=upstream history=4 | q1=81.853 actor=21.561 alpha=0.046
# [train] episode=1480 step=472692 return=110.68 success=True time=183.6s geometry=upstream history=4 | q1=145.993 actor=22.154 alpha=0.044
# [train] episode=1485 step=474612 return=143.33 success=True time=109.4s geometry=upstream history=4 | q1=1.841 actor=23.647 alpha=0.043
# [eval] step=475002 objective=arrival_v2 return=114.21 safety=1.472 success=83.33% time=140.5s energy=116646.3 path=86.8 prog=0.92
# [train] episode=1490 step=475884 return=144.13 success=True time=88.7s geometry=upstream history=4 | q1=72.014 actor=20.823 alpha=0.045
# [train] episode=1495 step=478404 return=144.06 success=True time=155.0s geometry=upstream history=4 | q1=9.365 actor=20.906 alpha=0.046
# [train] episode=1500 step=479274 return=143.26 success=True time=116.0s geometry=upstream history=4 | q1=63.769 actor=21.396 alpha=0.045
# [train] episode=1505 step=481296 return=-13.35 success=False time=240.1s geometry=upstream history=4 | q1=55.147 actor=23.086 alpha=0.045
# [train] episode=1510 step=482508 return=139.18 success=True time=144.3s geometry=upstream history=4 | q1=1.825 actor=21.617 alpha=0.047
# [train] episode=1515 step=484170 return=136.18 success=True time=137.6s geometry=upstream history=4 | q1=114.925 actor=22.243 alpha=0.048
# [train] episode=1520 step=485670 return=143.71 success=True time=80.3s geometry=upstream history=4 | q1=2.207 actor=24.408 alpha=0.048
# [train] episode=1525 step=487518 return=114.19 success=True time=153.1s geometry=upstream history=4 | q1=9.815 actor=23.019 alpha=0.048
# [train] episode=1530 step=489120 return=-26.26 success=False time=240.1s geometry=upstream history=4 | q1=32.868 actor=23.483 alpha=0.046
# [train] episode=1535 step=491238 return=143.44 success=True time=203.7s geometry=upstream history=4 | q1=40.870 actor=19.077 alpha=0.045
# [train] episode=1540 step=492666 return=143.21 success=True time=118.3s geometry=upstream history=4 | q1=23.651 actor=22.077 alpha=0.045
# [train] episode=1545 step=493938 return=142.57 success=True time=150.8s geometry=upstream history=4 | q1=7.334 actor=21.816 alpha=0.046
# [train] episode=1550 step=495558 return=-19.34 success=False time=240.1s geometry=upstream history=4 | q1=14.775 actor=22.478 alpha=0.046
# [train] episode=1555 step=497190 return=79.25 success=True time=105.0s geometry=upstream history=4 | q1=23.808 actor=21.200 alpha=0.047
# [train] episode=1560 step=498642 return=143.90 success=True time=139.6s geometry=upstream history=4 | q1=25.961 actor=23.482 alpha=0.048
# [eval] step=500004 objective=arrival_v2 return=119.45 safety=1.404 success=86.67% time=140.3s energy=115811.1 path=85.0 prog=0.92
# [train] episode=1565 step=500154 return=144.36 success=True time=125.1s geometry=upstream history=4 | q1=19.288 actor=18.853 alpha=0.049
# [train] episode=1570 step=501930 return=143.55 success=True time=186.6s geometry=upstream history=4 | q1=34.262 actor=20.844 alpha=0.048
# [train] episode=1575 step=503466 return=138.11 success=True time=165.2s geometry=upstream history=4 | q1=116.399 actor=18.599 alpha=0.049
# [train] episode=1580 step=505446 return=132.59 success=True time=168.8s geometry=upstream history=4 | q1=137.162 actor=21.933 alpha=0.048
# [train] episode=1585 step=507276 return=144.40 success=True time=112.8s geometry=upstream history=4 | q1=1.767 actor=20.212 alpha=0.047
# [train] episode=1590 step=507978 return=115.18 success=True time=124.5s geometry=upstream history=4 | q1=1.529 actor=17.629 alpha=0.048
# [train] episode=1595 step=510408 return=-18.08 success=False time=240.1s geometry=upstream history=4 | q1=5.551 actor=20.311 alpha=0.049
# [train] episode=1600 step=512094 return=143.34 success=True time=203.5s geometry=upstream history=4 | q1=2.342 actor=19.374 alpha=0.048
# [train] episode=1605 step=513594 return=144.40 success=True time=161.1s geometry=upstream history=4 | q1=1.987 actor=19.490 alpha=0.049
# [train] episode=1610 step=515124 return=143.71 success=True time=192.5s geometry=upstream history=4 | q1=5.821 actor=19.688 alpha=0.049
# [train] episode=1615 step=516972 return=143.91 success=True time=153.2s geometry=upstream history=4 | q1=13.540 actor=20.554 alpha=0.050
# [train] episode=1620 step=518592 return=144.50 success=True time=104.8s geometry=upstream history=4 | q1=54.017 actor=17.952 alpha=0.050
# [train] episode=1625 step=519864 return=-36.47 success=False time=240.1s geometry=upstream history=4 | q1=66.322 actor=19.570 alpha=0.049
# [train] episode=1630 step=521712 return=136.64 success=True time=126.8s geometry=upstream history=4 | q1=135.263 actor=20.300 alpha=0.051
# [train] episode=1635 step=523782 return=144.41 success=True time=136.6s geometry=upstream history=4 | q1=34.826 actor=19.299 alpha=0.051
# [train] episode=1640 step=524778 return=143.08 success=True time=131.8s geometry=upstream history=4 | q1=124.633 actor=19.296 alpha=0.050
# [eval] step=525000 objective=arrival_v2 return=121.05 safety=0.573 success=86.67% time=139.3s energy=114520.0 path=81.4 prog=0.92
# [train] episode=1645 step=526698 return=143.86 success=True time=114.2s geometry=upstream history=4 | q1=2.744 actor=15.426 alpha=0.048
# [train] episode=1650 step=528204 return=136.02 success=True time=124.6s geometry=upstream history=4 | q1=25.263 actor=17.079 alpha=0.047
# [train] episode=1655 step=529632 return=-31.80 success=False time=240.1s geometry=upstream history=4 | q1=14.522 actor=17.002 alpha=0.048
# [train] episode=1660 step=531894 return=144.27 success=True time=162.2s geometry=upstream history=4 | q1=3.169 actor=16.845 alpha=0.050
# ...
# [train] episode=4960 step=1371588 return=142.02 success=True time=151.8s geometry=upstream history=4 | q1=0.675 actor=-29.747 alpha=0.046
# [train] episode=4965 step=1372758 return=144.76 success=True time=97.0s geometry=upstream history=4 | q1=0.603 actor=-28.652 alpha=0.046
# [train] episode=4970 step=1373814 return=144.76 success=True time=110.2s geometry=upstream history=4 | q1=16.137 actor=-29.539 alpha=0.045
# [train] episode=4975 step=1374774 return=144.55 success=True time=93.9s geometry=upstream history=4 | q1=0.738 actor=-30.982 alpha=0.047
# [eval] step=1375002 objective=arrival_v2 return=144.20 safety=0.129 success=100.00% time=111.4s energy=97232.0 path=79.6 prog=0.94
# [train] episode=4980 step=1376022 return=143.93 success=True time=88.4s geometry=upstream history=4 | q1=17.235 actor=-28.211 alpha=0.046
# [train] episode=4985 step=1377198 return=144.67 success=True time=137.1s geometry=upstream history=4 | q1=19.724 actor=-31.850 alpha=0.045
# [train] episode=4990 step=1378182 return=144.84 success=True time=114.6s geometry=upstream history=4 | q1=4.748 actor=-29.934 alpha=0.047
# [train] episode=4995 step=1379742 return=144.78 success=True time=140.4s geometry=upstream history=4 | q1=7.589 actor=-29.590 alpha=0.047
# [train] episode=5000 step=1380492 return=143.78 success=True time=62.1s geometry=upstream history=4 | q1=45.624 actor=-32.008 alpha=0.045
# [train] episode=5005 step=1381380 return=138.63 success=True time=111.1s geometry=upstream history=4 | q1=8.450 actor=-29.980 alpha=0.046
# [train] episode=5010 step=1382544 return=144.14 success=True time=104.9s geometry=upstream history=4 | q1=7.519 actor=-29.427 alpha=0.044
# [train] episode=5015 step=1383822 return=144.63 success=True time=119.2s geometry=upstream history=4 | q1=7.879 actor=-31.362 alpha=0.044
# [train] episode=5020 step=1385376 return=143.80 success=True time=135.0s geometry=upstream history=4 | q1=22.799 actor=-30.438 alpha=0.045
# [train] episode=5025 step=1386534 return=143.96 success=True time=169.3s geometry=upstream history=4 | q1=7.240 actor=-31.038 alpha=0.046
# [train] episode=5030 step=1387284 return=143.92 success=True time=58.5s geometry=upstream history=4 | q1=7.672 actor=-31.773 alpha=0.047
# [train] episode=5035 step=1388394 return=143.89 success=True time=80.4s geometry=upstream history=4 | q1=8.257 actor=-29.039 alpha=0.050
# [train] episode=5040 step=1389438 return=137.59 success=True time=86.4s geometry=upstream history=4 | q1=7.721 actor=-29.820 alpha=0.051
# [train] episode=5045 step=1390206 return=143.74 success=True time=63.1s geometry=upstream history=4 | q1=21.759 actor=-32.063 alpha=0.052
# [train] episode=5050 step=1391580 return=143.71 success=True time=141.6s geometry=upstream history=4 | q1=25.102 actor=-30.922 alpha=0.052
# [train] episode=5055 step=1392822 return=144.91 success=True time=98.6s geometry=upstream history=4 | q1=34.139 actor=-29.758 alpha=0.050
# [train] episode=5060 step=1394064 return=143.62 success=True time=103.0s geometry=upstream history=4 | q1=33.337 actor=-30.932 alpha=0.051
# [train] episode=5065 step=1395348 return=143.57 success=True time=129.7s geometry=upstream history=4 | q1=18.315 actor=-31.894 alpha=0.054
# [train] episode=5070 step=1396536 return=144.89 success=True time=98.3s geometry=upstream history=4 | q1=11.472 actor=-30.174 alpha=0.054
# [train] episode=5075 step=1397694 return=143.17 success=True time=144.5s geometry=upstream history=4 | q1=43.004 actor=-32.212 alpha=0.051
# [train] episode=5080 step=1398702 return=144.62 success=True time=147.6s geometry=upstream history=4 | q1=5.685 actor=-30.975 alpha=0.050
# [eval] step=1400004 objective=arrival_v2 return=144.31 safety=0.109 success=100.00% time=107.8s energy=94053.1 path=76.8 prog=0.94
# [train] episode=5085 step=1400028 return=144.01 success=True time=73.2s geometry=upstream history=4 | q1=34.567 actor=-30.883 alpha=0.049
# [train] episode=5090 step=1401120 return=143.61 success=True time=92.6s geometry=upstream history=4 | q1=0.652 actor=-29.985 alpha=0.046
# [train] episode=5095 step=1402644 return=144.06 success=True time=140.5s geometry=upstream history=4 | q1=7.155 actor=-32.774 alpha=0.044
# [train] episode=5100 step=1403574 return=143.60 success=True time=106.8s geometry=upstream history=4 | q1=41.599 actor=-31.413 alpha=0.045
# [train] episode=5105 step=1405008 return=144.03 success=True time=84.8s geometry=upstream history=4 | q1=24.363 actor=-31.838 alpha=0.045
# [train] episode=5110 step=1406436 return=144.81 success=True time=111.9s geometry=upstream history=4 | q1=38.881 actor=-31.483 alpha=0.044
# [train] episode=5115 step=1407276 return=144.69 success=True time=111.7s geometry=upstream history=4 | q1=0.568 actor=-29.406 alpha=0.044
# [train] episode=5120 step=1408446 return=144.65 success=True time=131.6s geometry=upstream history=4 | q1=11.641 actor=-30.875 alpha=0.045
# [train] episode=5125 step=1410012 return=139.08 success=True time=129.9s geometry=upstream history=4 | q1=18.072 actor=-31.742 alpha=0.045
# [train] episode=5130 step=1411200 return=144.37 success=True time=156.0s geometry=upstream history=4 | q1=7.350 actor=-31.275 alpha=0.043
# [train] episode=5135 step=1411752 return=143.73 success=True time=144.3s geometry=upstream history=4 | q1=16.970 actor=-32.256 alpha=0.042
# [train] episode=5140 step=1413258 return=144.75 success=True time=128.2s geometry=upstream history=4 | q1=20.014 actor=-30.910 alpha=0.044
# [train] episode=5145 step=1414692 return=144.59 success=True time=119.6s geometry=upstream history=4 | q1=3.095 actor=-31.274 alpha=0.045
# [train] episode=5150 step=1415640 return=144.36 success=True time=93.1s geometry=upstream history=4 | q1=10.465 actor=-30.575 alpha=0.047
# [train] episode=5155 step=1416918 return=143.57 success=True time=105.9s geometry=upstream history=4 | q1=7.402 actor=-31.663 alpha=0.047
# [train] episode=5160 step=1418046 return=144.23 success=True time=93.2s geometry=upstream history=4 | q1=15.810 actor=-32.652 alpha=0.046
# [train] episode=5165 step=1419288 return=142.03 success=True time=112.0s geometry=upstream history=4 | q1=0.566 actor=-30.956 alpha=0.045
# [train] episode=5170 step=1420404 return=144.50 success=True time=92.2s geometry=upstream history=4 | q1=19.099 actor=-33.053 alpha=0.043
# [train] episode=5175 step=1421700 return=145.00 success=True time=107.3s geometry=upstream history=4 | q1=16.629 actor=-32.037 alpha=0.044
# [train] episode=5180 step=1423224 return=144.69 success=True time=75.4s geometry=upstream history=4 | q1=13.230 actor=-31.258 alpha=0.044
# [train] episode=5185 step=1423572 return=137.89 success=True time=83.4s geometry=upstream history=4 | q1=14.406 actor=-30.951 alpha=0.044
# [eval] step=1425000 objective=arrival_v2 return=144.16 safety=0.168 success=100.00% time=109.5s energy=95349.1 path=78.8 prog=0.94
# [train] episode=5190 step=1425120 return=143.83 success=True time=129.1s geometry=upstream history=4 | q1=7.041 actor=-30.278 alpha=0.044
# [train] episode=5195 step=1426338 return=145.03 success=True time=102.5s geometry=upstream history=4 | q1=35.823 actor=-31.049 alpha=0.043
# [train] episode=5200 step=1427580 return=144.83 success=True time=139.4s geometry=upstream history=4 | q1=50.330 actor=-32.550 alpha=0.045
# [train] episode=5205 step=1429056 return=144.53 success=True time=109.4s geometry=upstream history=4 | q1=23.184 actor=-32.360 alpha=0.048
# [train] episode=5210 step=1430184 return=144.74 success=True time=93.5s geometry=upstream history=4 | q1=14.983 actor=-32.610 alpha=0.048
# [train] episode=5215 step=1431132 return=144.69 success=True time=82.2s geometry=upstream history=4 | q1=0.752 actor=-33.039 alpha=0.046
# [train] episode=5220 step=1431792 return=144.79 success=True time=104.9s geometry=upstream history=4 | q1=36.552 actor=-30.602 alpha=0.045
# [train] episode=5225 step=1433526 return=142.24 success=True time=144.0s geometry=upstream history=4 | q1=3.288 actor=-31.903 alpha=0.044
# [train] episode=5230 step=1434570 return=143.82 success=True time=75.7s geometry=upstream history=4 | q1=18.752 actor=-31.691 alpha=0.044
# [train] episode=5235 step=1435854 return=143.99 success=True time=142.6s geometry=upstream history=4 | q1=7.329 actor=-33.196 alpha=0.043
# [train] episode=5240 step=1437084 return=144.51 success=True time=101.7s geometry=upstream history=4 | q1=18.566 actor=-30.752 alpha=0.044
# [train] episode=5245 step=1437936 return=144.72 success=True time=132.8s geometry=upstream history=4 | q1=8.614 actor=-31.402 alpha=0.046
# [train] episode=5250 step=1439124 return=144.51 success=True time=156.5s geometry=upstream history=4 | q1=20.290 actor=-33.129 alpha=0.046
# [train] episode=5255 step=1439808 return=144.13 success=True time=91.3s geometry=upstream history=4 | q1=39.309 actor=-33.297 alpha=0.045
# [train] episode=5260 step=1441512 return=143.06 success=True time=150.8s geometry=upstream history=4 | q1=0.670 actor=-31.001 alpha=0.044
# [train] episode=5265 step=1442544 return=143.81 success=True time=85.5s geometry=upstream history=4 | q1=8.334 actor=-31.691 alpha=0.044
# [train] episode=5270 step=1443936 return=145.00 success=True time=126.3s geometry=upstream history=4 | q1=17.810 actor=-33.163 alpha=0.044
# [train] episode=5275 step=1445004 return=144.85 success=True time=88.1s geometry=upstream history=4 | q1=11.430 actor=-33.206 alpha=0.045
# [train] episode=5280 step=1446324 return=144.61 success=True time=109.3s geometry=upstream history=4 | q1=37.701 actor=-32.194 alpha=0.046
# [train] episode=5285 step=1447338 return=126.67 success=True time=151.2s geometry=upstream history=4 | q1=38.992 actor=-31.280 alpha=0.045
# [train] episode=5290 step=1448604 return=142.97 success=True time=160.1s geometry=upstream history=4 | q1=9.204 actor=-33.237 alpha=0.046
# [train] episode=5295 step=1449936 return=144.71 success=True time=148.9s geometry=upstream history=4 | q1=17.187 actor=-32.442 alpha=0.048
# [eval] step=1450002 objective=arrival_v2 return=144.26 safety=0.133 success=100.00% time=108.0s energy=94518.9 path=79.2 prog=0.94
# [train] episode=5300 step=1450842 return=144.46 success=True time=136.7s geometry=upstream history=4 | q1=19.648 actor=-33.290 alpha=0.046
# [train] episode=5305 step=1452330 return=129.94 success=True time=163.4s geometry=upstream history=4 | q1=19.225 actor=-33.180 alpha=0.047
# [train] episode=5310 step=1453344 return=144.39 success=True time=69.4s geometry=upstream history=4 | q1=12.944 actor=-32.972 alpha=0.048
# [train] episode=5315 step=1454790 return=144.72 success=True time=138.6s geometry=upstream history=4 | q1=21.828 actor=-34.419 alpha=0.048
# [train] episode=5320 step=1455708 return=144.43 success=True time=159.6s geometry=upstream history=4 | q1=22.583 actor=-32.742 alpha=0.048
# [train] episode=5325 step=1457286 return=144.60 success=True time=140.7s geometry=upstream history=4 | q1=12.255 actor=-33.093 alpha=0.048
# [train] episode=5330 step=1458546 return=143.54 success=True time=104.2s geometry=upstream history=4 | q1=19.176 actor=-31.613 alpha=0.049
# [train] episode=5335 step=1459722 return=141.48 success=True time=96.6s geometry=upstream history=4 | q1=23.412 actor=-32.643 alpha=0.051
# [train] episode=5340 step=1460706 return=144.77 success=True time=107.9s geometry=upstream history=4 | q1=4.009 actor=-32.285 alpha=0.051
# [train] episode=5345 step=1462104 return=144.44 success=True time=116.0s geometry=upstream history=4 | q1=7.135 actor=-32.275 alpha=0.050
# [train] episode=5350 step=1463154 return=144.70 success=True time=88.4s geometry=upstream history=4 | q1=14.631 actor=-32.493 alpha=0.051
# [train] episode=5355 step=1463958 return=144.60 success=True time=138.6s geometry=upstream history=4 | q1=23.891 actor=-32.580 alpha=0.051
# [train] episode=5360 step=1465188 return=144.53 success=True time=112.6s geometry=upstream history=4 | q1=24.706 actor=-31.067 alpha=0.051
# [train] episode=5365 step=1466850 return=139.65 success=True time=137.7s geometry=upstream history=4 | q1=8.551 actor=-35.006 alpha=0.047
# [train] episode=5370 step=1467678 return=144.42 success=True time=111.0s geometry=upstream history=4 | q1=0.456 actor=-31.049 alpha=0.048
# [train] episode=5375 step=1469022 return=132.90 success=True time=160.4s geometry=upstream history=4 | q1=7.736 actor=-33.237 alpha=0.047
# [train] episode=5380 step=1470174 return=143.73 success=True time=95.6s geometry=upstream history=4 | q1=3.506 actor=-31.469 alpha=0.047
# [train] episode=5385 step=1471308 return=144.62 success=True time=138.0s geometry=upstream history=4 | q1=0.498 actor=-33.575 alpha=0.048
# [train] episode=5390 step=1472148 return=137.47 success=True time=141.6s geometry=upstream history=4 | q1=17.384 actor=-32.917 alpha=0.049
# [train] episode=5395 step=1473660 return=144.61 success=True time=71.6s geometry=upstream history=4 | q1=0.725 actor=-32.171 alpha=0.049
# [train] episode=5400 step=1474662 return=144.01 success=True time=82.6s geometry=upstream history=4 | q1=19.944 actor=-33.207 alpha=0.049
# [eval] step=1475004 objective=arrival_v2 return=143.44 safety=0.502 success=100.00% time=111.6s energy=96911.4 path=77.5 prog=0.94
# [train] episode=5405 step=1475790 return=142.50 success=True time=84.6s geometry=upstream history=4 | q1=0.617 actor=-32.067 alpha=0.050
# [train] episode=5410 step=1476942 return=144.54 success=True time=123.6s geometry=upstream history=4 | q1=26.688 actor=-32.666 alpha=0.052
# [train] episode=5415 step=1477656 return=143.82 success=True time=73.3s geometry=upstream history=4 | q1=33.976 actor=-32.188 alpha=0.051
# [train] episode=5420 step=1479036 return=135.82 success=True time=114.3s geometry=upstream history=4 | q1=11.032 actor=-33.064 alpha=0.052
# [train] episode=5425 step=1480260 return=136.07 success=True time=146.2s geometry=upstream history=4 | q1=2.699 actor=-31.574 alpha=0.052
# [train] episode=5430 step=1481682 return=144.76 success=True time=100.2s geometry=upstream history=4 | q1=22.149 actor=-32.796 alpha=0.049
# [train] episode=5435 step=1482636 return=137.94 success=True time=107.0s geometry=upstream history=4 | q1=18.519 actor=-33.697 alpha=0.048
# [train] episode=5440 step=1483626 return=144.31 success=True time=81.6s geometry=upstream history=4 | q1=7.879 actor=-32.256 alpha=0.048
# [train] episode=5445 step=1485018 return=144.58 success=True time=153.0s geometry=upstream history=4 | q1=31.885 actor=-32.221 alpha=0.048
# [train] episode=5450 step=1486326 return=144.53 success=True time=121.5s geometry=upstream history=4 | q1=14.051 actor=-33.121 alpha=0.044
# [train] episode=5455 step=1487652 return=144.50 success=True time=97.5s geometry=upstream history=4 | q1=4.633 actor=-32.779 alpha=0.042
# [train] episode=5460 step=1488654 return=143.54 success=True time=82.6s geometry=upstream history=4 | q1=6.336 actor=-34.315 alpha=0.044
# [train] episode=5465 step=1489854 return=144.34 success=True time=134.6s geometry=upstream history=4 | q1=32.250 actor=-33.813 alpha=0.044
# [train] episode=5470 step=1490964 return=144.64 success=True time=127.7s geometry=upstream history=4 | q1=14.770 actor=-33.474 alpha=0.044
# [train] episode=5475 step=1491966 return=144.89 success=True time=127.3s geometry=upstream history=4 | q1=27.925 actor=-33.609 alpha=0.044
# [train] episode=5480 step=1493586 return=144.41 success=True time=160.4s geometry=upstream history=4 | q1=13.375 actor=-33.094 alpha=0.046
# [train] episode=5485 step=1494282 return=143.96 success=True time=57.2s geometry=upstream history=4 | q1=13.877 actor=-35.682 alpha=0.047
# [train] episode=5490 step=1495518 return=142.93 success=True time=156.1s geometry=upstream history=4 | q1=15.375 actor=-34.095 alpha=0.047
# [train] episode=5495 step=1496586 return=144.76 success=True time=88.5s geometry=upstream history=4 | q1=13.169 actor=-31.808 alpha=0.048
# [train] episode=5500 step=1497690 return=144.67 success=True time=100.4s geometry=upstream history=4 | q1=15.042 actor=-34.536 alpha=0.047
# [train] episode=5505 step=1499322 return=144.91 success=True time=126.8s geometry=upstream history=4 | q1=0.595 actor=-33.311 alpha=0.047
# [eval] step=1500000 objective=arrival_v2 return=143.87 safety=0.292 success=100.00% time=111.2s energy=96496.6 path=79.0 prog=0.94

# %% [markdown]
# ## 9. Phase 2 — Summarize: P1 v6 final eval + curve
#
# 若 Phase 1 hold，直接打印 hold 状态。
#
# P1 v6 关注点：
# - `final_success_rate` 是否 ≥ 0.85（arrival_v2 修好 efficiency_v2 旧 failure mode 的核心证据）
# - `last100k_mean` ≥ 0.9 × peak 是否成立（与 cross 同一稳定性判据）
# - termination 分布：goal vs timeout vs out_of_bounds 各占多少（P1 旧版的核心问题就是 success 退化到 0、return 上升）
# - 如果 1.5M 仍未收敛但仍在上升，再决定是否 extend 到 2M

# %%
if not READY_FOR_P1_V6:
    print('[hold] Phase 1 gate did not pass; no P1 results to summarize.')
else:
    p1_eval_log = P1_RUN_ROOT / 'results' / 'eval_log.csv'
    p1_final_eval = P1_RUN_ROOT / 'results' / 'final_eval.json'
    p1_trainer_state = P1_RUN_ROOT / 'trainer_state.json'

    if not p1_final_eval.exists():
        raise FileNotFoundError(f'missing P1 final eval: {p1_final_eval}')

    p1_df = pd.read_csv(p1_eval_log) if p1_eval_log.exists() else pd.DataFrame()
    p1_final = json.loads(p1_final_eval.read_text(encoding='utf-8'))
    p1_state_d = json.loads(p1_trainer_state.read_text(encoding='utf-8')) if p1_trainer_state.exists() else {}
    p1_counts = p1_final.get('eval_termination_counts', {})

    p1_peak = float(p1_df['eval_success_rate'].max()) if len(p1_df) else 0.0
    p1_peak_step = int(p1_df.loc[p1_df['eval_success_rate'].idxmax(), 'env_step']) if len(p1_df) else 0
    p1_last100 = p1_df[p1_df['env_step'] >= P1_TOTAL_STEPS - 100_000] if len(p1_df) else p1_df
    p1_last100_mean = float(p1_last100['eval_success_rate'].mean()) if len(p1_last100) else 0.0

    print('=' * 96)
    print('P1_V6_FINAL  (arrival_v2 / s1 / upstream / 1.5M)')
    print('-' * 96)
    print(f"  final_success_rate    : {p1_final['eval_success_rate']:.4f}")
    print(f"  peak_success_rate     : {p1_peak:.4f}  @ {p1_peak_step:,}")
    print(f"  last100k_mean_success : {p1_last100_mean:.4f}  (gate {PASS_LAST100_RATIO * p1_peak:.4f})")
    print(f"  avg_return            : {p1_final.get('eval_return', 0):.2f}")
    print(f"  avg_time_s            : {p1_final.get('eval_time_s', 0):.2f}")
    print(f"  progress_ratio        : {p1_final.get('eval_progress_ratio', 0):.4f}")
    print(f"  safety_cost           : {p1_final.get('eval_safety_cost', 0):.4f}")
    print(f"  termination           : {p1_counts}")
    print(f"  obs_dim               : {p1_state_d.get('observation_dim', 'NA')}")
    print(f"  context_obs           : {p1_state_d.get('include_episode_context_obs', 'NA')}")
    print(f"  timeout_bootstrap     : {p1_state_d.get('timeout_bootstrap_semantics', 'NA')}")
    print('=' * 96)

    if len(p1_df):
        print()
        print('[last 16 eval rows]')
        cols = ['env_step', 'eval_success_rate', 'eval_return', 'eval_safety_cost',
                'eval_time_s', 'eval_progress_ratio']
        available = [c for c in cols if c in p1_df.columns]
        print(p1_df[available].tail(16).to_string(index=False))
# Out:
# ================================================================================================
# P1_V6_FINAL  (arrival_v2 / s1 / upstream / 1.5M)
# ------------------------------------------------------------------------------------------------
#   final_success_rate    : 1.0000
#   peak_success_rate     : 1.0000  @ 675,000
#   last100k_mean_success : 1.0000  (gate 0.9000)
#   avg_return            : 143.87
#   avg_time_s            : 111.18
#   progress_ratio        : 0.9355
#   safety_cost           : 0.2919
#   termination           : {'goal': 30}
#   obs_dim               : 56
#   context_obs           : True
#   timeout_bootstrap     : terminal
# ================================================================================================
#
# [last 16 eval rows]
#  env_step  eval_success_rate  eval_return  eval_safety_cost  eval_time_s  eval_progress_ratio
#   1125000                1.0   144.196200          0.117472   112.373333             0.935512
#   1150002                1.0   144.099545          0.160068   112.993333             0.935560
#   1175004                1.0   140.159095          2.058352   119.860000             0.935544
#   1200000                1.0   144.136851          0.124777   114.573333             0.935568
#   1225002                1.0   143.334606          0.555201   111.860000             0.935581
#   1250004                1.0   142.176907          1.075968   117.200000             0.935507
#   1275000                1.0   143.250659          0.571498   114.160000             0.935533
#   1300002                1.0   144.030762          0.183292   114.066667             0.935544
#   1325004                1.0   141.799230          1.179031   125.596667             0.935556
#   1350000                1.0   144.299468          0.072811   111.706667             0.935527
#   1375002                1.0   144.198137          0.128867   111.446667             0.935652
#   1400004                1.0   144.311916          0.109093   107.820000             0.935602
#   1425000                1.0   144.156630          0.168117   109.533333             0.935580
#   1450002                1.0   144.261746          0.133125   107.960000             0.935616
#   1475004                1.0   143.442749          0.502235   111.650000             0.935535
#   1500000                1.0   143.871083          0.291937   111.180000             0.935544
