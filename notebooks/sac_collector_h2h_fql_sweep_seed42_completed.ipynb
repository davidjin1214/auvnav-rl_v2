# %% [markdown]
# # SAC Collector Head-to-Head — Sprint 2 (seed=42): FQL × 4 tier sweep
#
# **状态**：ACTIVE — sprint 2 启动决策 land 2026-05-25 (expert review 完成 commit `4edee37`)。Per-seed shard。
#
# **目标**：执行 [`docs/arrival_v2_sac_collector_design.md`](../docs/arrival_v2_sac_collector_design.md) **rev.3 §4.0.8 v2 + §4.0.9** Sprint 2 — FQL（flow_steps=10, distill_alpha_bc=1.0）× 4 tier × **seed 42** = **4 run**（per-seed shard）。与 sprint 1 ReBRAC seed shard 1:1 对位组成 SAC-collector head-to-head 完整矩阵（algorithm × tier × seed）。
#
# **Seed-split rationale**：原 12-run sweep 按 seed 拆成 3 个 notebook (seed=42 / 0 / 7)，每份 4 run / ~3.5h L4，可在 Colab Pro 多 session 并发开跑（理想 wall ~3.5h vs 串行 10-11h）。三份共同输出 12 run 与原协议完全等价。其它两份：[`_seed42`](./sac_collector_h2h_fql_sweep_seed42.ipynb) / [`_seed0`](./sac_collector_h2h_fql_sweep_seed0.ipynb) / [`_seed7`](./sac_collector_h2h_fql_sweep_seed7.ipynb)。
#
# **前置 commits（已闭环）**：
# - `97d394c` — SACCheckpointPolicy adapter (5 tests pass)
# - `032b527` — Plan A 4 tier dataset collection completed
# - `3cfd18a` — spec rev.3 §4.0.7 actual results land
# - `5070862` — IPython shell magic refactor (sprint 1 style)
# - `104c14c` — sprint 1 ReBRAC 24 run completed
# - `4edee37` — sprint 1 expert-review verdict correction
#
# **配置（spec §4.0.8 v2 锁定）**：
#
# | 项 | 值 | 来源 |
# |---|---|---|
# | Algo | FQL（vanilla critic） | FQL P2 v1.4 standard |
# | Flow-matching teacher | `--flow-steps 10 --flow-time-embed-dim 32 --teacher-lr 3e-4` | FQL P2 c1 alpha sweep frozen |
# | Distill α_bc | `--distill-alpha-bc 1.0` | FQL P2 C-1 baseline (RESCUE-FAIL reference) |
# | Datasets | 4 tier (random/medium/mexp/expert, step25k/425k/575k/600k) | Plan A 4 tier completed |
# | Seed (本 shard) | **[42]** | 与 sprint 1 ReBRAC paired (full set = [42, 0, 7]) |
# | Total steps | 200_000 (uniform sampling) — FQL P2 §6.2 sister | FQL P2 v1.4 |
# | batch / hidden / layers | 256 / 256 / 3 | 同上 |
# | lr / γ / τ | 3e-4 / 0.99 / 0.005 | 同上 |
# | Manifest (eval) | `benchmarks/single_u10_cross_tgt15.json` (30 ep/run, test_seed=456) | 与 sprint 1 paired |
#
# **预算 (本 shard, seed=42)**：
#
# | 阶段 | run | wallclock |
# |---|---:|---:|
# | Train: FQL × 4 tier × 1 seed | 4 | ~3.3h L4 |
# | evaluate_offline × 4 run | 4 | ~10 min L4 |
# | **Sprint 2 (seed=42) total** | **4** | **~3.5h L4** |
#
# → 1 个 Colab Pro L4 session 紧凑可完。三份 (seed=42/0/7) 同时启动 → 理想总 wall ~3.5h。
#
# **实测要点**（基于 sprint 1 expert review）：
# 1. **唯一可被 sprint 2 reliably falsify 的 finding 是 finding 2** (FQL vs ReBRAC β1=1 on SAC clean expert)。sprint 1 已知 SAC expert ceiling = 0.889 (ReBRAC β1∈{1,4} 都达到此值)。
# 2. **SAC mexp tier 是有 statistical power 的 cell** — sprint 1 显示 β1=1 stratified CI 不跨 0 (β1=1 wins). FQL on mexp 数字关键：是否 ≥ ReBRAC β1=1 的 0.800？
# 3. **SAC random tier degenerate** — FQL 几乎必然也 0%，不会带来 finding signal。
# 4. **SAC medium tier informative**: ReBRAC β1=1 0.656 vs β1=4 0.633 (direction-only, CI 跨 0)。FQL 数字定 finding 1 cross-algo generalization。
#
# **Pre-registered finding 2 + 加强 narrative**（详 spec §4.0.9）：
# - **Finding 2 verify**: FQL on SAC expert ↔ ReBRAC β1=1 paired Δ CI 不跨 0 + Δ < 0 → 复现 FQL P2 C-1 RESCUE-FAIL on SAC clean regime; CI 跨 0 / Δ ≥ 0 → SAC dataset-bound regime 允许 FQL 也达到 ceiling
# - **Cross-algorithm matrix complete**: ReBRAC β1∈{1,4} + FQL 全 12 cell × 4 tier × 3 seed (sprint 1 + sprint 2 共 36 run)

# %% [markdown]
# ## 0. 环境检查

# %%
import torch
print(f"PyTorch:        {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"Device name:    {torch.cuda.get_device_name(0)}")
# Out:
# PyTorch:        2.10.0+cu128
# CUDA available: True
# Device name:    NVIDIA L4

# %% [markdown]
# ## 1. 挂载 Drive + cd 到项目根

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/"MyDrive"/"Colab Notebooks"/"new_offRL"/"rl_v2_5"
# !pwd
# Out:
# /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5
# /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5

# %% [markdown]
# ## 2. Sanity check — 4 dataset + manifest 存在
#
# **预期**：5 项 ✅。任何 ⚠️ 都需停下定位（不要跳过 sanity 直接开跑）。

# %%
from pathlib import Path

TIERS = [
    ("random", "step25k"),
    ("medium", "step425k"),
    ("mexp",   "step575k"),
    ("expert", "step600k"),
]

def dataset_dir(tier: str, step_tag: str) -> Path:
    return Path(f"offline_data/sac_{tier}_s0_h4_arrival_v2_re150_u10cross_seed46_{step_tag}_ep1000")

MANIFEST = Path("benchmarks/single_u10_cross_tgt15.json")

all_ok = True
for tier, step_tag in TIERS:
    d = dataset_dir(tier, step_tag)
    npz = d / "transitions.npz"
    if npz.exists():
        print(f"  ✅ {tier:10s}  {npz}  ({npz.stat().st_size/1e6:.1f} MB)")
    else:
        print(f"  ⚠️ {tier:10s}  {npz}  NOT FOUND")
        all_ok = False

print()
if MANIFEST.exists():
    print(f"  ✅ manifest  {MANIFEST}  ({MANIFEST.stat().st_size/1e3:.1f} KB)")
else:
    print(f"  ⚠️ manifest  {MANIFEST}  NOT FOUND — 用 generate_standard_benchmarks 先生成")
    all_ok = False

print()
if all_ok:
    print("✅ Sanity check passed — 可以开始 training.")
else:
    raise FileNotFoundError("Sanity check failed — 见上面 ⚠️ 项，定位后 rerun.")
# Out:
#   ✅ random      offline_data/sac_random_s0_h4_arrival_v2_re150_u10cross_seed46_step25k_ep1000/transitions.npz  (21.4 MB)
#   ✅ medium      offline_data/sac_medium_s0_h4_arrival_v2_re150_u10cross_seed46_step425k_ep1000/transitions.npz  (29.9 MB)
#   ✅ mexp        offline_data/sac_mexp_s0_h4_arrival_v2_re150_u10cross_seed46_step575k_ep1000/transitions.npz  (20.6 MB)
#   ✅ expert      offline_data/sac_expert_s0_h4_arrival_v2_re150_u10cross_seed46_step600k_ep1000/transitions.npz  (13.7 MB)
#
#   ✅ manifest  benchmarks/single_u10_cross_tgt15.json  (17.0 KB)
#
# ✅ Sanity check passed — 可以开始 training.

# %% [markdown]
# ## 3. Config matrix — 12 run plan
#
# **Run identifier**：`fql__{tier}__seed_{42|0|7}` — 与 spec §4.0.8 v2 输出 schema 对齐。
#
# **Skip-resume 协议**：per run 检查 `<save-dir>/agent_final.pt` 是否存在；存在则 skip（train 函数末尾才写，不会 false-positive）。

# %%
SEEDS = [42]  # per-seed shard; full set = [42, 0, 7] (seed42 / seed0 / seed7 notebooks)

CKPT_ROOT = Path("checkpoints/offline/sac_collector_h2h/fql")
RESULTS_ROOT = Path("results/offline/sac_collector_h2h/fql")

def save_dir(tier: str, seed: int) -> Path:
    return CKPT_ROOT / tier / f"seed_{seed}"

def test_result_path(tier: str, seed: int) -> Path:
    return RESULTS_ROOT / tier / f"seed_{seed}" / "test_result.json"

# Print plan + check skip-state
n_total = 0
n_done = 0
for tier, step_tag in TIERS:
    for seed in SEEDS:
        n_total += 1
        sd = save_dir(tier, seed)
        done_marker = sd / "agent_final.pt"
        status = "✅ DONE" if done_marker.exists() else "⏳ TODO"
        if done_marker.exists():
            n_done += 1
        print(f"  [{status}]  fql | {tier:10s} | seed={seed}  →  {sd}")
    print()

print(f"=== {n_done}/{n_total} runs already complete (skip-resume) ===")
# Out:
#   [⏳ TODO]  fql | random     | seed=42  →  checkpoints/offline/sac_collector_h2h/fql/random/seed_42
#
#   [⏳ TODO]  fql | medium     | seed=42  →  checkpoints/offline/sac_collector_h2h/fql/medium/seed_42
#
#   [⏳ TODO]  fql | mexp       | seed=42  →  checkpoints/offline/sac_collector_h2h/fql/mexp/seed_42
#
#   [⏳ TODO]  fql | expert     | seed=42  →  checkpoints/offline/sac_collector_h2h/fql/expert/seed_42
#
# === 0/4 runs already complete (skip-resume) ===

# %% [markdown]
# ## 4. Train — FQL × 4 tier × 3 seed = 12 run (~10h L4)
#
# **协议**（spec §4.0.8 v2 + FQL P2 c1 alpha sweep frozen flags）：`--algo fql --flow-steps 10 --distill-alpha-bc 1.0 --teacher-lr 3e-4 --flow-time-embed-dim 32`。
#
# **Per-run skip-resume**：若 `<save-dir>/agent_final.pt` 已存在则跳过。Colab session crash 后重新运行本 cell 自动接续。
#
# **实时输出**：训练用 `!python ...` IPython shell magic，stdout 直接流式 → 每 1000 step 的 `actor_loss/critic_loss/teacher_loss` 实时滚动显示。
#
# **注意**：12 run × 50 min ≈ 10h，单 Colab Pro L4 session 接近 12h limit。若 session 中断，重启再跑本 cell 会自动 skip 已完成 run。需缩短 wall 时建议按 sprint 1 同样的脚本 (`/tmp/split_sprint1_by_seed.py` 改 SEEDS → 3 份 by seed)，理想 3 session 并发 wall ~3.5h。

# %%
import time
from pathlib import Path

t_start = time.time()

for tier, step_tag in TIERS:
    for seed in SEEDS:
        sd = save_dir(tier, seed)
        sd_str = str(sd)
        npz = str(dataset_dir(tier, step_tag) / "transitions.npz")
        manifest_str = str(MANIFEST)
        if (sd / "agent_final.pt").exists():
            print(f"[skip-train] fql | {tier} | seed={seed} (agent_final.pt exists)")
            continue
        sd.mkdir(parents=True, exist_ok=True)
        print(f"\n{'=' * 72}")
        print(f"  train fql | {tier} | seed={seed}  →  {sd}")
        print(f"{'=' * 72}")
        t0 = time.time()
        # !python -m scripts.train_offline \
            --algo fql \
            --offline-data '{npz}' \
            --manifest '{manifest_str}' \
            --probe-layout s0 \
            --history-length 4 \
            --task-geometry cross_stream \
            --target-speed 1.5 \
            --objective arrival_v2 \
            --sampling-mode uniform \
            --total-steps 200000 \
            --batch-size 256 \
            --hidden-dim 256 \
            --num-hidden-layers 3 \
            --actor-lr 3e-4 \
            --critic-lr 3e-4 \
            --gamma 0.99 \
            --tau 0.005 \
            --flow-steps 10 \
            --flow-time-embed-dim 32 \
            --teacher-lr 3e-4 \
            --distill-alpha-bc 1.0 \
            --grad-clip-norm 10.0 \
            --normalizer-eps 1e-3 \
            --eval-every 0 \
            --skip-final-eval \
            --log-every 1000 \
            --seed {seed} \
            --device cuda \
            --save-dir '{sd_str}'
        print(f"[train done] fql | {tier} | seed={seed} in {(time.time() - t0) / 60:.1f} min")

print(f"\n=== Sprint 2 FQL train complete, total = {(time.time() - t_start) / 60:.1f} min ===")
# Out:
# ========================================================================
#   train fql | random | seed=42  →  checkpoints/offline/sac_collector_h2h/fql/random/seed_42
# ========================================================================
# [offline] algo=fql transitions=180067 obs_dim=48 action_dim=2 protocol=deployable tensor_replay=on eval_workers=1 sampling=uniform total_steps=200000
# [train] step=1 q=-1.028 critic=221.754 actor=2.063 bc=1.063 lambda=0.973
# [train] step=1000 q=-5.791 critic=1.719 actor=1.075 bc=0.075 lambda=0.173
# [train] step=2000 q=-8.499 critic=713.649 actor=1.072 bc=0.072 lambda=0.118
# [train] step=3000 q=-12.253 critic=2.452 actor=1.088 bc=0.088 lambda=0.082
# [train] step=4000 q=-13.604 critic=209.505 actor=1.075 bc=0.075 lambda=0.074
# [train] step=5000 q=-17.436 critic=1.543 actor=1.069 bc=0.069 lambda=0.057
# [train] step=6000 q=-20.044 critic=133.056 actor=1.072 bc=0.072 lambda=0.050
# [train] step=7000 q=-24.261 critic=192.307 actor=1.079 bc=0.079 lambda=0.041
# [train] step=8000 q=-28.328 critic=477.064 actor=1.087 bc=0.087 lambda=0.035
# [train] step=9000 q=-31.779 critic=171.926 actor=1.069 bc=0.069 lambda=0.031
# [train] step=10000 q=-35.804 critic=243.440 actor=1.066 bc=0.066 lambda=0.028
# [train] step=11000 q=-37.140 critic=498.688 actor=1.071 bc=0.071 lambda=0.027
# [train] step=12000 q=-40.595 critic=121.916 actor=1.066 bc=0.066 lambda=0.025
# [train] step=13000 q=-45.663 critic=5.086 actor=1.072 bc=0.072 lambda=0.022
# [train] step=14000 q=-46.853 critic=410.283 actor=1.080 bc=0.080 lambda=0.021
# [train] step=15000 q=-54.767 critic=147.666 actor=1.073 bc=0.073 lambda=0.018
# [train] step=16000 q=-49.130 critic=4.368 actor=1.075 bc=0.075 lambda=0.020
# [train] step=17000 q=-63.567 critic=168.510 actor=1.064 bc=0.064 lambda=0.016
# [train] step=18000 q=-62.911 critic=4.314 actor=1.070 bc=0.070 lambda=0.016
# [train] step=19000 q=-64.561 critic=172.678 actor=1.069 bc=0.069 lambda=0.015
# [train] step=20000 q=-70.688 critic=6.384 actor=1.058 bc=0.058 lambda=0.014
# [train] step=21000 q=-72.194 critic=8.890 actor=1.075 bc=0.075 lambda=0.014
# [train] step=22000 q=-77.691 critic=36.040 actor=1.067 bc=0.067 lambda=0.013
# [train] step=23000 q=-81.955 critic=13.906 actor=1.068 bc=0.068 lambda=0.012
# [train] step=24000 q=-82.818 critic=8.633 actor=1.070 bc=0.070 lambda=0.012
# [train] step=25000 q=-84.478 critic=252.448 actor=1.064 bc=0.064 lambda=0.012
# [train] step=26000 q=-85.644 critic=4.773 actor=1.063 bc=0.063 lambda=0.012
# [train] step=27000 q=-96.166 critic=267.116 actor=1.078 bc=0.078 lambda=0.010
# [train] step=28000 q=-101.452 critic=100.796 actor=1.066 bc=0.066 lambda=0.010
# [train] step=29000 q=-111.134 critic=10.740 actor=1.074 bc=0.074 lambda=0.009
# [train] step=30000 q=-102.363 critic=5.429 actor=1.077 bc=0.077 lambda=0.010
# [train] step=31000 q=-102.211 critic=147.887 actor=1.060 bc=0.060 lambda=0.010
# [train] step=32000 q=-112.483 critic=32.519 actor=1.072 bc=0.072 lambda=0.009
# [train] step=33000 q=-110.175 critic=8.418 actor=1.076 bc=0.076 lambda=0.009
# [train] step=34000 q=-109.583 critic=140.771 actor=1.063 bc=0.063 lambda=0.009
# [train] step=35000 q=-118.700 critic=9.415 actor=1.066 bc=0.066 lambda=0.008
# [train] step=36000 q=-117.342 critic=126.748 actor=1.079 bc=0.079 lambda=0.009
# [train] step=37000 q=-117.911 critic=12.078 actor=1.083 bc=0.083 lambda=0.008
# [train] step=38000 q=-127.521 critic=8.947 actor=1.069 bc=0.069 lambda=0.008
# [train] step=39000 q=-128.214 critic=11.950 actor=1.062 bc=0.062 lambda=0.008
# [train] step=40000 q=-128.641 critic=50.124 actor=1.081 bc=0.081 lambda=0.008
# [train] step=41000 q=-130.631 critic=10.515 actor=1.060 bc=0.060 lambda=0.008
# [train] step=42000 q=-130.053 critic=12.315 actor=1.059 bc=0.059 lambda=0.008
# [train] step=43000 q=-129.197 critic=13.969 actor=1.067 bc=0.067 lambda=0.008
# [train] step=44000 q=-138.976 critic=11.716 actor=1.077 bc=0.077 lambda=0.007
# [train] step=45000 q=-140.986 critic=12.684 actor=1.059 bc=0.059 lambda=0.007
# [train] step=46000 q=-142.447 critic=10.821 actor=1.078 bc=0.078 lambda=0.007
# [train] step=47000 q=-147.929 critic=31.340 actor=1.074 bc=0.074 lambda=0.007
# [train] step=48000 q=-149.408 critic=10.061 actor=1.072 bc=0.072 lambda=0.007
# [train] step=49000 q=-142.759 critic=13.391 actor=1.057 bc=0.057 lambda=0.007
# [train] step=50000 q=-143.918 critic=13.325 actor=1.062 bc=0.062 lambda=0.007
# [train] step=51000 q=-155.832 critic=11.876 actor=1.052 bc=0.052 lambda=0.006
# [train] step=52000 q=-148.242 critic=52.958 actor=1.071 bc=0.071 lambda=0.007
# [train] step=53000 q=-149.774 critic=11.194 actor=1.071 bc=0.071 lambda=0.007
# [train] step=54000 q=-153.831 critic=39.208 actor=1.069 bc=0.069 lambda=0.007
# [train] step=55000 q=-155.221 critic=9.385 actor=1.068 bc=0.068 lambda=0.006
# [train] step=56000 q=-153.056 critic=13.638 actor=1.074 bc=0.074 lambda=0.007
# [train] step=57000 q=-161.538 critic=9.236 actor=1.069 bc=0.069 lambda=0.006
# [train] step=58000 q=-158.841 critic=9.811 actor=1.075 bc=0.075 lambda=0.006
# [train] step=59000 q=-164.750 critic=29.420 actor=1.072 bc=0.072 lambda=0.006
# [train] step=60000 q=-164.598 critic=22.851 actor=1.062 bc=0.062 lambda=0.006
# [train] step=61000 q=-164.682 critic=15.959 actor=1.067 bc=0.067 lambda=0.006
# [train] step=62000 q=-163.438 critic=13.211 actor=1.070 bc=0.070 lambda=0.006
# [train] step=63000 q=-164.686 critic=16.244 actor=1.065 bc=0.065 lambda=0.006
# [train] step=64000 q=-164.648 critic=7.366 actor=1.067 bc=0.067 lambda=0.006
# [train] step=65000 q=-164.060 critic=8.511 actor=1.071 bc=0.071 lambda=0.006
# [train] step=66000 q=-166.350 critic=17.515 actor=1.063 bc=0.063 lambda=0.006
# [train] step=67000 q=-168.870 critic=9.299 actor=1.078 bc=0.078 lambda=0.006
# [train] step=68000 q=-171.712 critic=17.722 actor=1.073 bc=0.073 lambda=0.006
# [train] step=69000 q=-175.733 critic=12.355 actor=1.079 bc=0.079 lambda=0.006
# [train] step=70000 q=-168.124 critic=8.900 actor=1.072 bc=0.072 lambda=0.006
# [train] step=71000 q=-167.724 critic=11.126 actor=1.058 bc=0.058 lambda=0.006
# [train] step=72000 q=-166.377 critic=14.085 actor=1.065 bc=0.065 lambda=0.006
# [train] step=73000 q=-169.638 critic=84.045 actor=1.068 bc=0.068 lambda=0.006
# [train] step=74000 q=-173.253 critic=6.583 actor=1.052 bc=0.052 lambda=0.006
# [train] step=75000 q=-168.146 critic=10.389 actor=1.069 bc=0.069 lambda=0.006
# [train] step=76000 q=-166.382 critic=13.763 actor=1.071 bc=0.071 lambda=0.006
# [train] step=77000 q=-177.234 critic=14.875 actor=1.078 bc=0.078 lambda=0.006
# [train] step=78000 q=-176.629 critic=11.715 actor=1.067 bc=0.067 lambda=0.006
# [train] step=79000 q=-176.350 critic=10.791 actor=1.068 bc=0.068 lambda=0.006
# [train] step=80000 q=-170.167 critic=10.929 actor=1.064 bc=0.065 lambda=0.006
# [train] step=81000 q=-167.755 critic=8.684 actor=1.067 bc=0.067 lambda=0.006
# [train] step=82000 q=-175.043 critic=10.948 actor=1.063 bc=0.063 lambda=0.006
# [train] step=83000 q=-171.071 critic=11.308 actor=1.083 bc=0.083 lambda=0.006
# [train] step=84000 q=-171.669 critic=7.972 actor=1.068 bc=0.068 lambda=0.006
# [train] step=85000 q=-170.412 critic=10.079 actor=1.071 bc=0.071 lambda=0.006
# [train] step=86000 q=-176.863 critic=8.437 actor=1.061 bc=0.063 lambda=0.006
# [train] step=87000 q=-176.747 critic=10.620 actor=1.066 bc=0.066 lambda=0.006
# [train] step=88000 q=-170.318 critic=11.266 actor=1.068 bc=0.068 lambda=0.006
# [train] step=89000 q=-178.581 critic=17.822 actor=1.059 bc=0.059 lambda=0.006
# [train] step=90000 q=-175.655 critic=14.114 actor=1.066 bc=0.066 lambda=0.006
# [train] step=91000 q=-171.183 critic=14.243 actor=1.068 bc=0.068 lambda=0.006
# [train] step=92000 q=-178.168 critic=25.109 actor=1.061 bc=0.061 lambda=0.006
# [train] step=93000 q=-176.671 critic=6.915 actor=1.078 bc=0.080 lambda=0.006
# [train] step=94000 q=-174.467 critic=9.334 actor=1.070 bc=0.072 lambda=0.006
# [train] step=95000 q=-177.097 critic=13.224 actor=1.072 bc=0.073 lambda=0.006
# [train] step=96000 q=-176.589 critic=10.003 actor=1.065 bc=0.065 lambda=0.006
# [train] step=97000 q=-175.665 critic=11.731 actor=1.061 bc=0.061 lambda=0.006
# [train] step=98000 q=-173.688 critic=38.592 actor=1.062 bc=0.062 lambda=0.006
# [train] step=99000 q=-168.307 critic=12.653 actor=1.058 bc=0.058 lambda=0.006
# [train] step=100000 q=-179.897 critic=9.620 actor=1.068 bc=0.068 lambda=0.006
# [train] step=101000 q=-176.138 critic=11.573 actor=1.075 bc=0.075 lambda=0.006
# [train] step=102000 q=-175.493 critic=11.470 actor=1.081 bc=0.081 lambda=0.006
# [train] step=103000 q=-176.540 critic=19.043 actor=1.064 bc=0.067 lambda=0.006
# [train] step=104000 q=-176.071 critic=22.375 actor=1.050 bc=0.050 lambda=0.006
# [train] step=105000 q=-176.099 critic=8.855 actor=1.067 bc=0.067 lambda=0.006
# [train] step=106000 q=-175.163 critic=9.244 actor=1.069 bc=0.069 lambda=0.006
# [train] step=107000 q=-176.495 critic=11.697 actor=1.067 bc=0.069 lambda=0.006
# [train] step=108000 q=-175.012 critic=10.565 actor=1.061 bc=0.061 lambda=0.006
# [train] step=109000 q=-178.986 critic=17.324 actor=1.067 bc=0.067 lambda=0.006
# [train] step=110000 q=-172.701 critic=15.879 actor=1.064 bc=0.064 lambda=0.006
# [train] step=111000 q=-175.874 critic=8.515 actor=1.071 bc=0.071 lambda=0.006
# [train] step=112000 q=-182.245 critic=14.658 actor=1.069 bc=0.069 lambda=0.005
# [train] step=113000 q=-170.484 critic=9.854 actor=1.073 bc=0.073 lambda=0.006
# [train] step=114000 q=-182.561 critic=8.693 actor=1.075 bc=0.077 lambda=0.005
# [train] step=115000 q=-180.487 critic=15.175 actor=1.062 bc=0.062 lambda=0.006
# [train] step=116000 q=-175.005 critic=18.989 actor=1.069 bc=0.071 lambda=0.006
# [train] step=117000 q=-174.313 critic=10.901 actor=1.068 bc=0.068 lambda=0.006
# [train] step=118000 q=-180.537 critic=7.642 actor=1.071 bc=0.071 lambda=0.006
# [train] step=119000 q=-178.186 critic=9.116 actor=1.064 bc=0.064 lambda=0.006
# [train] step=120000 q=-171.539 critic=8.739 actor=1.071 bc=0.071 lambda=0.006
# [train] step=121000 q=-178.759 critic=11.913 actor=1.059 bc=0.059 lambda=0.006
# [train] step=122000 q=-176.128 critic=9.966 actor=1.058 bc=0.058 lambda=0.006
# [train] step=123000 q=-176.539 critic=10.618 actor=1.065 bc=0.065 lambda=0.006
# [train] step=124000 q=-177.497 critic=11.135 actor=1.060 bc=0.060 lambda=0.006
# [train] step=125000 q=-175.845 critic=14.055 actor=1.061 bc=0.061 lambda=0.006
# [train] step=126000 q=-173.020 critic=7.262 actor=1.072 bc=0.072 lambda=0.006
# [train] step=127000 q=-179.325 critic=6.984 actor=1.055 bc=0.061 lambda=0.006
# [train] step=128000 q=-171.671 critic=8.907 actor=1.053 bc=0.059 lambda=0.006
# [train] step=129000 q=-173.884 critic=9.684 actor=1.065 bc=0.073 lambda=0.006
# [train] step=130000 q=-180.012 critic=12.992 actor=1.061 bc=0.069 lambda=0.006
# [train] step=131000 q=-172.434 critic=8.088 actor=1.065 bc=0.065 lambda=0.006
# [train] step=132000 q=-176.444 critic=8.658 actor=1.073 bc=0.073 lambda=0.006
# [train] step=133000 q=-180.190 critic=10.289 actor=1.077 bc=0.077 lambda=0.006
# [train] step=134000 q=-175.832 critic=11.796 actor=1.063 bc=0.064 lambda=0.006
# [train] step=135000 q=-172.628 critic=11.656 actor=1.056 bc=0.063 lambda=0.006
# [train] step=136000 q=-178.106 critic=10.835 actor=1.058 bc=0.058 lambda=0.006
# [train] step=137000 q=-171.889 critic=16.102 actor=1.070 bc=0.070 lambda=0.006
# [train] step=138000 q=-176.775 critic=25.231 actor=1.065 bc=0.065 lambda=0.006
# [train] step=139000 q=-177.404 critic=9.533 actor=1.069 bc=0.069 lambda=0.006
# [train] step=140000 q=-177.427 critic=8.564 actor=1.070 bc=0.070 lambda=0.006
# [train] step=141000 q=-175.837 critic=9.460 actor=1.059 bc=0.059 lambda=0.006
# [train] step=142000 q=-173.388 critic=7.122 actor=1.052 bc=0.066 lambda=0.006
# [train] step=143000 q=-182.644 critic=9.400 actor=1.063 bc=0.063 lambda=0.005
# [train] step=144000 q=-169.434 critic=14.939 actor=1.067 bc=0.075 lambda=0.006
# [train] step=145000 q=-181.520 critic=13.597 actor=1.063 bc=0.063 lambda=0.006
# [train] step=146000 q=-176.575 critic=18.440 actor=1.062 bc=0.065 lambda=0.006
# [train] step=147000 q=-173.808 critic=11.006 actor=1.064 bc=0.069 lambda=0.006
# [train] step=148000 q=-180.632 critic=11.127 actor=1.061 bc=0.061 lambda=0.006
# [train] step=149000 q=-177.028 critic=11.013 actor=1.059 bc=0.059 lambda=0.006
# [train] step=150000 q=-179.542 critic=19.327 actor=1.053 bc=0.058 lambda=0.006
# [train] step=151000 q=-176.666 critic=17.230 actor=1.076 bc=0.076 lambda=0.006
# [train] step=152000 q=-178.064 critic=9.592 actor=1.064 bc=0.071 lambda=0.006
# [train] step=153000 q=-183.294 critic=15.492 actor=1.067 bc=0.067 lambda=0.005
# [train] step=154000 q=-179.793 critic=14.013 actor=1.065 bc=0.072 lambda=0.006
# [train] step=155000 q=-179.439 critic=11.453 actor=1.066 bc=0.066 lambda=0.006
# [train] step=156000 q=-180.060 critic=11.095 actor=1.066 bc=0.066 lambda=0.006
# [train] step=157000 q=-185.183 critic=16.279 actor=1.061 bc=0.061 lambda=0.005
# [train] step=158000 q=-175.824 critic=14.448 actor=1.065 bc=0.073 lambda=0.006
# [train] step=159000 q=-178.206 critic=16.812 actor=1.069 bc=0.070 lambda=0.006
# [train] step=160000 q=-183.584 critic=17.036 actor=1.059 bc=0.059 lambda=0.005
# [train] step=161000 q=-177.132 critic=11.316 actor=1.068 bc=0.074 lambda=0.006
# [train] step=162000 q=-187.713 critic=17.882 actor=1.061 bc=0.061 lambda=0.005
# [train] step=163000 q=-182.584 critic=20.831 actor=1.062 bc=0.063 lambda=0.005
# [train] step=164000 q=-173.552 critic=9.883 actor=1.069 bc=0.069 lambda=0.006
# [train] step=165000 q=-185.798 critic=13.384 actor=1.061 bc=0.061 lambda=0.005
# [train] step=166000 q=-179.282 critic=15.639 actor=1.067 bc=0.067 lambda=0.006
# [train] step=167000 q=-184.003 critic=18.027 actor=1.065 bc=0.065 lambda=0.005
# [train] step=168000 q=-181.583 critic=14.713 actor=1.081 bc=0.084 lambda=0.005
# [train] step=169000 q=-183.470 critic=96.639 actor=1.061 bc=0.061 lambda=0.005
# [train] step=170000 q=-179.773 critic=18.655 actor=1.065 bc=0.065 lambda=0.006
# [train] step=171000 q=-175.560 critic=12.912 actor=1.076 bc=0.076 lambda=0.006
# [train] step=172000 q=-180.803 critic=16.996 actor=1.062 bc=0.062 lambda=0.006
# [train] step=173000 q=-174.739 critic=10.015 actor=1.065 bc=0.065 lambda=0.006
# [train] step=174000 q=-178.459 critic=30.631 actor=1.054 bc=0.062 lambda=0.006
# [train] step=175000 q=-176.802 critic=12.381 actor=1.066 bc=0.071 lambda=0.006
# [train] step=176000 q=-181.856 critic=25.280 actor=1.063 bc=0.063 lambda=0.005
# [train] step=177000 q=-177.587 critic=27.304 actor=1.065 bc=0.065 lambda=0.006
# [train] step=178000 q=-176.606 critic=14.244 actor=1.061 bc=0.061 lambda=0.006
# [train] step=179000 q=-179.146 critic=18.582 actor=1.059 bc=0.059 lambda=0.006
# [train] step=180000 q=-180.101 critic=29.807 actor=1.056 bc=0.060 lambda=0.006
# [train] step=181000 q=-178.363 critic=12.038 actor=1.070 bc=0.070 lambda=0.006
# [train] step=182000 q=-176.815 critic=11.503 actor=1.063 bc=0.065 lambda=0.006
# [train] step=183000 q=-185.572 critic=15.795 actor=1.059 bc=0.064 lambda=0.005
# [train] step=184000 q=-185.156 critic=24.510 actor=1.052 bc=0.052 lambda=0.005
# [train] step=185000 q=-184.445 critic=13.411 actor=1.060 bc=0.060 lambda=0.005
# [train] step=186000 q=-181.323 critic=22.786 actor=1.075 bc=0.076 lambda=0.006
# [train] step=187000 q=-186.873 critic=15.026 actor=1.064 bc=0.064 lambda=0.005
# [train] step=188000 q=-181.523 critic=14.094 actor=1.063 bc=0.063 lambda=0.006
# [train] step=189000 q=-174.875 critic=19.932 actor=1.070 bc=0.073 lambda=0.006
# [train] step=190000 q=-179.601 critic=13.600 actor=1.060 bc=0.063 lambda=0.006
# [train] step=191000 q=-189.689 critic=22.025 actor=1.068 bc=0.070 lambda=0.005
# [train] step=192000 q=-181.884 critic=17.148 actor=1.074 bc=0.074 lambda=0.005
# [train] step=193000 q=-185.747 critic=92.420 actor=1.058 bc=0.058 lambda=0.005
# [train] step=194000 q=-180.644 critic=14.928 actor=1.064 bc=0.068 lambda=0.006
# [train] step=195000 q=-186.651 critic=13.382 actor=1.062 bc=0.063 lambda=0.005
# [train] step=196000 q=-179.930 critic=14.969 actor=1.064 bc=0.064 lambda=0.006
# [train] step=197000 q=-183.517 critic=15.723 actor=1.065 bc=0.066 lambda=0.005
# [train] step=198000 q=-182.456 critic=15.657 actor=1.047 bc=0.048 lambda=0.005
# [train] step=199000 q=-185.418 critic=23.494 actor=1.060 bc=0.060 lambda=0.005
# [train] step=200000 q=-190.725 critic=520.252 actor=1.061 bc=0.061 lambda=0.005
# [train done] fql | random | seed=42 in 41.3 min
#
# ========================================================================
#   train fql | medium | seed=42  →  checkpoints/offline/sac_collector_h2h/fql/medium/seed_42
# ========================================================================
# [offline] algo=fql transitions=250544 obs_dim=48 action_dim=2 protocol=deployable tensor_replay=on eval_workers=1 sampling=uniform total_steps=200000
# [train] step=1 q=-0.601 critic=25.346 actor=2.064 bc=1.064 lambda=1.665
# [train] step=1000 q=-0.404 critic=95.002 actor=0.286 bc=0.090 lambda=0.485
# [train] step=2000 q=0.177 critic=75.054 actor=0.027 bc=0.076 lambda=0.278
# [train] step=3000 q=-0.820 critic=0.536 actor=0.280 bc=0.078 lambda=0.246
# [train] step=4000 q=-0.844 critic=104.431 actor=0.250 bc=0.083 lambda=0.198
# [train] step=5000 q=0.415 critic=125.568 actor=0.010 bc=0.062 lambda=0.126
# [train] step=6000 q=0.491 critic=95.429 actor=-0.001 bc=0.058 lambda=0.119
# [train] step=7000 q=1.661 critic=2.310 actor=-0.092 bc=0.072 lambda=0.099
# [train] step=8000 q=-0.423 critic=15.305 actor=0.105 bc=0.066 lambda=0.090
# [train] step=9000 q=1.545 critic=4.179 actor=-0.054 bc=0.072 lambda=0.081
# [train] step=10000 q=0.009 critic=236.643 actor=0.056 bc=0.057 lambda=0.069
# [train] step=11000 q=-1.334 critic=9.638 actor=0.163 bc=0.057 lambda=0.079
# [train] step=12000 q=3.554 critic=7.069 actor=-0.137 bc=0.053 lambda=0.053
# [train] step=13000 q=0.926 critic=4.383 actor=0.013 bc=0.059 lambda=0.050
# [train] step=14000 q=0.697 critic=4.038 actor=0.026 bc=0.064 lambda=0.054
# [train] step=15000 q=1.260 critic=6.051 actor=0.006 bc=0.056 lambda=0.040
# [train] step=16000 q=5.320 critic=4.457 actor=-0.175 bc=0.066 lambda=0.045
# [train] step=17000 q=-1.358 critic=11.775 actor=0.113 bc=0.057 lambda=0.041
# [train] step=18000 q=1.850 critic=6.257 actor=-0.015 bc=0.062 lambda=0.041
# [train] step=19000 q=1.647 critic=6.988 actor=-0.003 bc=0.063 lambda=0.040
# [train] step=20000 q=4.040 critic=5.593 actor=-0.083 bc=0.065 lambda=0.037
# [train] step=21000 q=4.365 critic=11.451 actor=-0.099 bc=0.060 lambda=0.036
# [train] step=22000 q=-0.520 critic=8.885 actor=0.059 bc=0.042 lambda=0.033
# [train] step=23000 q=-3.804 critic=71.038 actor=0.179 bc=0.056 lambda=0.032
# [train] step=24000 q=-0.667 critic=9.353 actor=0.069 bc=0.048 lambda=0.032
# [train] step=25000 q=-1.698 critic=10.770 actor=0.109 bc=0.053 lambda=0.033
# [train] step=26000 q=3.336 critic=5.187 actor=-0.055 bc=0.048 lambda=0.031
# [train] step=27000 q=1.253 critic=10.475 actor=0.028 bc=0.067 lambda=0.031
# [train] step=28000 q=2.393 critic=9.624 actor=-0.017 bc=0.055 lambda=0.030
# [train] step=29000 q=-1.118 critic=8.591 actor=0.082 bc=0.052 lambda=0.027
# [train] step=30000 q=-2.945 critic=6.098 actor=0.148 bc=0.057 lambda=0.031
# [train] step=31000 q=-3.718 critic=9.270 actor=0.142 bc=0.048 lambda=0.025
# [train] step=32000 q=-4.119 critic=27.188 actor=0.166 bc=0.056 lambda=0.027
# [train] step=33000 q=4.909 critic=11.779 actor=-0.075 bc=0.058 lambda=0.027
# [train] step=34000 q=-0.917 critic=9.642 actor=0.071 bc=0.045 lambda=0.028
# [train] step=35000 q=-4.149 critic=14.500 actor=0.154 bc=0.049 lambda=0.025
# [train] step=36000 q=-7.400 critic=9.990 actor=0.233 bc=0.051 lambda=0.024
# [train] step=37000 q=-4.730 critic=8.619 actor=0.165 bc=0.050 lambda=0.024
# [train] step=38000 q=-6.546 critic=9.200 actor=0.222 bc=0.055 lambda=0.026
# [train] step=39000 q=-11.083 critic=10.492 actor=0.322 bc=0.046 lambda=0.025
# [train] step=40000 q=-8.438 critic=14.361 actor=0.259 bc=0.043 lambda=0.026
# [train] step=41000 q=-9.607 critic=10.380 actor=0.282 bc=0.040 lambda=0.025
# [train] step=42000 q=-6.425 critic=10.593 actor=0.200 bc=0.042 lambda=0.025
# [train] step=43000 q=-9.863 critic=9.503 actor=0.300 bc=0.046 lambda=0.026
# [train] step=44000 q=-14.045 critic=19.271 actor=0.404 bc=0.047 lambda=0.025
# [train] step=45000 q=-10.654 critic=12.077 actor=0.282 bc=0.045 lambda=0.022
# [train] step=46000 q=-12.170 critic=18.928 actor=0.355 bc=0.068 lambda=0.024
# [train] step=47000 q=-16.745 critic=10.791 actor=0.444 bc=0.054 lambda=0.023
# [train] step=48000 q=-14.546 critic=12.158 actor=0.408 bc=0.050 lambda=0.025
# [train] step=49000 q=-6.705 critic=7.685 actor=0.212 bc=0.048 lambda=0.025
# [train] step=50000 q=-11.018 critic=8.803 actor=0.335 bc=0.051 lambda=0.026
# [train] step=51000 q=-18.273 critic=14.597 actor=0.468 bc=0.045 lambda=0.023
# [train] step=52000 q=-14.471 critic=7.504 actor=0.421 bc=0.055 lambda=0.025
# [train] step=53000 q=-18.640 critic=44.184 actor=0.523 bc=0.061 lambda=0.025
# [train] step=54000 q=-17.962 critic=17.460 actor=0.469 bc=0.058 lambda=0.023
# [train] step=55000 q=-13.907 critic=15.272 actor=0.394 bc=0.055 lambda=0.024
# [train] step=56000 q=-16.150 critic=9.492 actor=0.446 bc=0.048 lambda=0.025
# [train] step=57000 q=-18.626 critic=13.045 actor=0.479 bc=0.044 lambda=0.023
# [train] step=58000 q=-16.315 critic=59.912 actor=0.437 bc=0.050 lambda=0.024
# [train] step=59000 q=-21.676 critic=8.877 actor=0.543 bc=0.044 lambda=0.023
# [train] step=60000 q=-19.829 critic=13.258 actor=0.507 bc=0.055 lambda=0.023
# [train] step=61000 q=-14.766 critic=12.204 actor=0.393 bc=0.039 lambda=0.024
# [train] step=62000 q=-21.889 critic=9.167 actor=0.529 bc=0.047 lambda=0.022
# [train] step=63000 q=-20.796 critic=9.829 actor=0.528 bc=0.051 lambda=0.023
# [train] step=64000 q=-25.827 critic=34.276 actor=0.610 bc=0.047 lambda=0.022
# [train] step=65000 q=-18.171 critic=11.669 actor=0.437 bc=0.038 lambda=0.022
# [train] step=66000 q=-23.378 critic=15.900 actor=0.579 bc=0.044 lambda=0.023
# [train] step=67000 q=-26.160 critic=242.786 actor=0.632 bc=0.056 lambda=0.022
# [train] step=68000 q=-21.152 critic=36.354 actor=0.556 bc=0.059 lambda=0.023
# [train] step=69000 q=-21.466 critic=12.951 actor=0.572 bc=0.059 lambda=0.024
# [train] step=70000 q=-19.851 critic=10.620 actor=0.466 bc=0.045 lambda=0.021
# [train] step=71000 q=-16.378 critic=17.122 actor=0.432 bc=0.044 lambda=0.024
# [train] step=72000 q=-22.294 critic=10.694 actor=0.553 bc=0.048 lambda=0.023
# [train] step=73000 q=-16.104 critic=8.240 actor=0.409 bc=0.047 lambda=0.022
# [train] step=74000 q=-29.675 critic=9.505 actor=0.665 bc=0.038 lambda=0.021
# [train] step=75000 q=-20.477 critic=17.087 actor=0.533 bc=0.055 lambda=0.023
# [train] step=76000 q=-24.382 critic=94.794 actor=0.593 bc=0.049 lambda=0.022
# [train] step=77000 q=-17.759 critic=18.625 actor=0.432 bc=0.047 lambda=0.022
# [train] step=78000 q=-24.849 critic=14.858 actor=0.596 bc=0.056 lambda=0.022
# [train] step=79000 q=-24.172 critic=11.435 actor=0.560 bc=0.041 lambda=0.021
# [train] step=80000 q=-20.829 critic=10.580 actor=0.518 bc=0.052 lambda=0.022
# [train] step=81000 q=-22.771 critic=29.170 actor=0.517 bc=0.049 lambda=0.021
# [train] step=82000 q=-26.817 critic=16.091 actor=0.566 bc=0.049 lambda=0.019
# [train] step=83000 q=-25.153 critic=230.044 actor=0.597 bc=0.049 lambda=0.022
# [train] step=84000 q=-32.387 critic=53.129 actor=0.723 bc=0.042 lambda=0.021
# [train] step=85000 q=-24.484 critic=9.179 actor=0.572 bc=0.052 lambda=0.021
# [train] step=86000 q=-21.125 critic=6.189 actor=0.487 bc=0.047 lambda=0.021
# [train] step=87000 q=-17.361 critic=10.503 actor=0.438 bc=0.062 lambda=0.022
# [train] step=88000 q=-18.165 critic=10.642 actor=0.465 bc=0.055 lambda=0.023
# [train] step=89000 q=-30.942 critic=10.340 actor=0.689 bc=0.049 lambda=0.021
# [train] step=90000 q=-27.606 critic=9.882 actor=0.584 bc=0.052 lambda=0.019
# [train] step=91000 q=-27.686 critic=285.390 actor=0.639 bc=0.062 lambda=0.021
# [train] step=92000 q=-26.529 critic=8.429 actor=0.582 bc=0.052 lambda=0.020
# [train] step=93000 q=-28.589 critic=12.899 actor=0.598 bc=0.036 lambda=0.020
# [train] step=94000 q=-26.315 critic=16.244 actor=0.564 bc=0.053 lambda=0.019
# [train] step=95000 q=-32.686 critic=8.945 actor=0.651 bc=0.040 lambda=0.019
# [train] step=96000 q=-27.277 critic=15.487 actor=0.603 bc=0.044 lambda=0.020
# [train] step=97000 q=-30.437 critic=46.859 actor=0.650 bc=0.049 lambda=0.020
# [train] step=98000 q=-23.272 critic=12.030 actor=0.513 bc=0.047 lambda=0.020
# [train] step=99000 q=-29.131 critic=4.956 actor=0.667 bc=0.045 lambda=0.021
# [train] step=100000 q=-31.869 critic=12.591 actor=0.660 bc=0.045 lambda=0.019
# [train] step=101000 q=-22.281 critic=24.702 actor=0.495 bc=0.048 lambda=0.020
# [train] step=102000 q=-25.104 critic=13.148 actor=0.543 bc=0.048 lambda=0.020
# [train] step=103000 q=-29.858 critic=12.828 actor=0.640 bc=0.038 lambda=0.020
# [train] step=104000 q=-28.537 critic=8.195 actor=0.586 bc=0.035 lambda=0.019
# [train] step=105000 q=-30.913 critic=5.776 actor=0.698 bc=0.045 lambda=0.021
# [train] step=106000 q=-28.124 critic=8.755 actor=0.579 bc=0.037 lambda=0.019
# [train] step=107000 q=-29.680 critic=9.381 actor=0.629 bc=0.041 lambda=0.020
# [train] step=108000 q=-28.586 critic=19.173 actor=0.616 bc=0.048 lambda=0.020
# [train] step=109000 q=-31.417 critic=12.197 actor=0.626 bc=0.051 lambda=0.018
# [train] step=110000 q=-28.611 critic=162.274 actor=0.611 bc=0.046 lambda=0.020
# [train] step=111000 q=-34.596 critic=10.433 actor=0.722 bc=0.044 lambda=0.020
# [train] step=112000 q=-30.838 critic=10.552 actor=0.682 bc=0.055 lambda=0.020
# [train] step=113000 q=-32.407 critic=60.828 actor=0.655 bc=0.057 lambda=0.018
# [train] step=114000 q=-30.724 critic=23.102 actor=0.615 bc=0.047 lambda=0.018
# [train] step=115000 q=-34.621 critic=20.228 actor=0.723 bc=0.042 lambda=0.020
# [train] step=116000 q=-29.986 critic=43.763 actor=0.640 bc=0.052 lambda=0.020
# [train] step=117000 q=-31.527 critic=9.396 actor=0.636 bc=0.048 lambda=0.019
# [train] step=118000 q=-32.916 critic=13.013 actor=0.627 bc=0.047 lambda=0.018
# [train] step=119000 q=-31.464 critic=13.495 actor=0.683 bc=0.036 lambda=0.021
# [train] step=120000 q=-32.567 critic=7.110 actor=0.656 bc=0.034 lambda=0.019
# [train] step=121000 q=-32.418 critic=15.131 actor=0.685 bc=0.039 lambda=0.020
# [train] step=122000 q=-32.393 critic=11.865 actor=0.679 bc=0.044 lambda=0.020
# [train] step=123000 q=-33.737 critic=13.445 actor=0.689 bc=0.048 lambda=0.019
# [train] step=124000 q=-33.741 critic=17.018 actor=0.698 bc=0.046 lambda=0.019
# [train] step=125000 q=-36.341 critic=21.628 actor=0.742 bc=0.042 lambda=0.019
# [train] step=126000 q=-37.172 critic=11.165 actor=0.751 bc=0.063 lambda=0.019
# [train] step=127000 q=-37.427 critic=8.865 actor=0.750 bc=0.050 lambda=0.019
# [train] step=128000 q=-33.840 critic=9.797 actor=0.669 bc=0.041 lambda=0.019
# [train] step=129000 q=-36.601 critic=20.213 actor=0.683 bc=0.056 lambda=0.017
# [train] step=130000 q=-35.627 critic=11.302 actor=0.709 bc=0.046 lambda=0.019
# [train] step=131000 q=-30.776 critic=13.489 actor=0.636 bc=0.044 lambda=0.019
# [train] step=132000 q=-40.826 critic=19.303 actor=0.796 bc=0.056 lambda=0.018
# [train] step=133000 q=-32.742 critic=16.781 actor=0.650 bc=0.049 lambda=0.018
# [train] step=134000 q=-35.101 critic=18.140 actor=0.649 bc=0.050 lambda=0.017
# [train] step=135000 q=-38.240 critic=9.315 actor=0.709 bc=0.050 lambda=0.017
# [train] step=136000 q=-36.788 critic=15.300 actor=0.722 bc=0.041 lambda=0.019
# [train] step=137000 q=-37.253 critic=10.465 actor=0.715 bc=0.047 lambda=0.018
# [train] step=138000 q=-37.478 critic=24.447 actor=0.658 bc=0.043 lambda=0.016
# [train] step=139000 q=-34.903 critic=6.525 actor=0.714 bc=0.055 lambda=0.019
# [train] step=140000 q=-39.824 critic=14.793 actor=0.719 bc=0.047 lambda=0.017
# [train] step=141000 q=-31.854 critic=26.453 actor=0.628 bc=0.039 lambda=0.018
# [train] step=142000 q=-38.907 critic=17.157 actor=0.713 bc=0.054 lambda=0.017
# [train] step=143000 q=-37.202 critic=18.287 actor=0.690 bc=0.049 lambda=0.017
# [train] step=144000 q=-37.539 critic=11.783 actor=0.698 bc=0.044 lambda=0.017
# [train] step=145000 q=-38.178 critic=9.210 actor=0.729 bc=0.048 lambda=0.018
# [train] step=146000 q=-43.461 critic=9.312 actor=0.759 bc=0.042 lambda=0.017
# [train] step=147000 q=-41.505 critic=11.827 actor=0.742 bc=0.042 lambda=0.017
# [train] step=148000 q=-37.610 critic=36.616 actor=0.703 bc=0.054 lambda=0.017
# [train] step=149000 q=-35.359 critic=10.116 actor=0.684 bc=0.060 lambda=0.018
# [train] step=150000 q=-40.610 critic=43.431 actor=0.726 bc=0.045 lambda=0.017
# [train] step=151000 q=-41.375 critic=28.618 actor=0.718 bc=0.056 lambda=0.016
# [train] step=152000 q=-33.389 critic=22.448 actor=0.649 bc=0.039 lambda=0.018
# [train] step=153000 q=-43.270 critic=30.857 actor=0.772 bc=0.054 lambda=0.017
# [train] step=154000 q=-40.060 critic=18.175 actor=0.739 bc=0.049 lambda=0.017
# [train] step=155000 q=-42.435 critic=18.991 actor=0.745 bc=0.050 lambda=0.016
# [train] step=156000 q=-37.102 critic=19.283 actor=0.696 bc=0.036 lambda=0.018
# [train] step=157000 q=-42.562 critic=21.716 actor=0.757 bc=0.040 lambda=0.017
# [train] step=158000 q=-42.654 critic=15.831 actor=0.724 bc=0.038 lambda=0.016
# [train] step=159000 q=-40.792 critic=10.704 actor=0.717 bc=0.054 lambda=0.016
# [train] step=160000 q=-47.610 critic=8.687 actor=0.835 bc=0.045 lambda=0.017
# [train] step=161000 q=-45.088 critic=28.936 actor=0.743 bc=0.049 lambda=0.015
# [train] step=162000 q=-44.222 critic=14.281 actor=0.766 bc=0.039 lambda=0.016
# [train] step=163000 q=-39.695 critic=16.327 actor=0.742 bc=0.060 lambda=0.017
# [train] step=164000 q=-47.441 critic=11.369 actor=0.801 bc=0.041 lambda=0.016
# [train] step=165000 q=-35.348 critic=13.525 actor=0.620 bc=0.045 lambda=0.016
# [train] step=166000 q=-37.833 critic=10.650 actor=0.720 bc=0.044 lambda=0.018
# [train] step=167000 q=-45.421 critic=18.005 actor=0.799 bc=0.047 lambda=0.017
# [train] step=168000 q=-40.036 critic=16.029 actor=0.720 bc=0.056 lambda=0.017
# [train] step=169000 q=-41.284 critic=14.974 actor=0.740 bc=0.045 lambda=0.017
# [train] step=170000 q=-40.281 critic=27.657 actor=0.747 bc=0.051 lambda=0.017
# [train] step=171000 q=-44.920 critic=9.435 actor=0.792 bc=0.048 lambda=0.017
# [train] step=172000 q=-39.093 critic=40.295 actor=0.730 bc=0.039 lambda=0.018
# [train] step=173000 q=-48.422 critic=11.077 actor=0.811 bc=0.043 lambda=0.016
# [train] step=174000 q=-37.188 critic=15.595 actor=0.700 bc=0.049 lambda=0.018
# [train] step=175000 q=-47.291 critic=12.955 actor=0.792 bc=0.040 lambda=0.016
# [train] step=176000 q=-43.179 critic=15.495 actor=0.732 bc=0.041 lambda=0.016
# [train] step=177000 q=-43.252 critic=14.505 actor=0.762 bc=0.037 lambda=0.017
# [train] step=178000 q=-44.195 critic=15.214 actor=0.753 bc=0.051 lambda=0.016
# [train] step=179000 q=-44.744 critic=20.089 actor=0.769 bc=0.055 lambda=0.016
# [train] step=180000 q=-39.748 critic=16.776 actor=0.748 bc=0.039 lambda=0.018
# [train] step=181000 q=-39.796 critic=13.551 actor=0.720 bc=0.056 lambda=0.017
# [train] step=182000 q=-44.040 critic=10.919 actor=0.778 bc=0.039 lambda=0.017
# [train] step=183000 q=-47.957 critic=19.072 actor=0.811 bc=0.059 lambda=0.016
# [train] step=184000 q=-45.674 critic=8.059 actor=0.798 bc=0.034 lambda=0.017
# [train] step=185000 q=-45.877 critic=9.890 actor=0.762 bc=0.047 lambda=0.016
# [train] step=186000 q=-46.397 critic=27.677 actor=0.852 bc=0.052 lambda=0.017
# [train] step=187000 q=-45.784 critic=22.089 actor=0.782 bc=0.048 lambda=0.016
# [train] step=188000 q=-47.622 critic=15.701 actor=0.746 bc=0.034 lambda=0.015
# [train] step=189000 q=-47.554 critic=12.385 actor=0.830 bc=0.041 lambda=0.017
# [train] step=190000 q=-46.928 critic=17.893 actor=0.766 bc=0.043 lambda=0.015
# [train] step=191000 q=-45.094 critic=14.181 actor=0.754 bc=0.049 lambda=0.016
# [train] step=192000 q=-52.399 critic=25.804 actor=0.807 bc=0.047 lambda=0.015
# [train] step=193000 q=-46.274 critic=16.783 actor=0.780 bc=0.044 lambda=0.016
# [train] step=194000 q=-49.968 critic=18.075 actor=0.842 bc=0.053 lambda=0.016
# [train] step=195000 q=-42.744 critic=19.803 actor=0.773 bc=0.047 lambda=0.017
# [train] step=196000 q=-55.680 critic=29.335 actor=0.850 bc=0.046 lambda=0.014
# [train] step=197000 q=-48.470 critic=14.189 actor=0.814 bc=0.051 lambda=0.016
# [train] step=198000 q=-41.878 critic=12.317 actor=0.765 bc=0.033 lambda=0.017
# [train] step=199000 q=-48.215 critic=10.609 actor=0.807 bc=0.045 lambda=0.016
# [train] step=200000 q=-48.580 critic=21.619 actor=0.803 bc=0.039 lambda=0.016
# [train done] fql | medium | seed=42 in 42.5 min
#
# ========================================================================
#   train fql | mexp | seed=42  →  checkpoints/offline/sac_collector_h2h/fql/mexp/seed_42
# ========================================================================
# [offline] algo=fql transitions=171394 obs_dim=48 action_dim=2 protocol=deployable tensor_replay=on eval_workers=1 sampling=uniform total_steps=200000
# [train] step=1 q=-0.074 critic=78.161 actor=1.552 bc=1.058 lambda=6.636
# [train] step=1000 q=0.864 critic=50.552 actor=-0.299 bc=0.084 lambda=0.443
# [train] step=2000 q=2.121 critic=29.754 actor=-0.596 bc=0.064 lambda=0.311
# [train] step=3000 q=2.278 critic=22.732 actor=-0.441 bc=0.063 lambda=0.221
# [train] step=4000 q=2.264 critic=18.024 actor=-0.338 bc=0.041 lambda=0.167
# [train] step=5000 q=4.663 critic=6.718 actor=-0.442 bc=0.058 lambda=0.107
# [train] step=6000 q=5.086 critic=36.824 actor=-0.502 bc=0.063 lambda=0.111
# [train] step=7000 q=8.402 critic=14.563 actor=-0.552 bc=0.066 lambda=0.074
# [train] step=8000 q=6.938 critic=43.439 actor=-0.417 bc=0.059 lambda=0.069
# [train] step=9000 q=12.561 critic=2.157 actor=-0.588 bc=0.068 lambda=0.052
# [train] step=10000 q=11.920 critic=3.969 actor=-0.535 bc=0.059 lambda=0.050
# [train] step=11000 q=10.010 critic=4.575 actor=-0.500 bc=0.053 lambda=0.055
# [train] step=12000 q=12.016 critic=5.452 actor=-0.561 bc=0.056 lambda=0.051
# [train] step=13000 q=14.266 critic=3.814 actor=-0.592 bc=0.063 lambda=0.046
# [train] step=14000 q=14.481 critic=3.584 actor=-0.555 bc=0.055 lambda=0.042
# [train] step=15000 q=12.114 critic=4.392 actor=-0.447 bc=0.052 lambda=0.041
# [train] step=16000 q=15.816 critic=4.311 actor=-0.528 bc=0.057 lambda=0.037
# [train] step=17000 q=15.875 critic=3.978 actor=-0.517 bc=0.051 lambda=0.036
# [train] step=18000 q=18.529 critic=3.299 actor=-0.527 bc=0.051 lambda=0.031
# [train] step=19000 q=10.404 critic=3.356 actor=-0.345 bc=0.055 lambda=0.038
# [train] step=20000 q=17.820 critic=2.781 actor=-0.567 bc=0.045 lambda=0.034
# [train] step=21000 q=16.965 critic=6.484 actor=-0.456 bc=0.060 lambda=0.030
# [train] step=22000 q=20.619 critic=3.428 actor=-0.545 bc=0.039 lambda=0.028
# [train] step=23000 q=15.276 critic=5.124 actor=-0.452 bc=0.057 lambda=0.033
# [train] step=24000 q=16.303 critic=6.009 actor=-0.422 bc=0.040 lambda=0.028
# [train] step=25000 q=14.997 critic=70.060 actor=-0.417 bc=0.046 lambda=0.031
# [train] step=26000 q=22.174 critic=7.492 actor=-0.579 bc=0.051 lambda=0.028
# [train] step=27000 q=13.773 critic=4.809 actor=-0.335 bc=0.059 lambda=0.029
# [train] step=28000 q=18.883 critic=7.846 actor=-0.445 bc=0.046 lambda=0.026
# [train] step=29000 q=20.556 critic=3.335 actor=-0.511 bc=0.047 lambda=0.027
# [train] step=30000 q=22.464 critic=5.769 actor=-0.503 bc=0.051 lambda=0.025
# [train] step=31000 q=18.125 critic=5.984 actor=-0.422 bc=0.048 lambda=0.026
# [train] step=32000 q=17.352 critic=4.155 actor=-0.408 bc=0.050 lambda=0.026
# [train] step=33000 q=17.335 critic=4.200 actor=-0.384 bc=0.056 lambda=0.025
# [train] step=34000 q=24.709 critic=7.389 actor=-0.514 bc=0.041 lambda=0.022
# [train] step=35000 q=17.733 critic=6.225 actor=-0.388 bc=0.045 lambda=0.024
# [train] step=36000 q=25.569 critic=4.455 actor=-0.505 bc=0.054 lambda=0.022
# [train] step=37000 q=17.514 critic=4.350 actor=-0.346 bc=0.051 lambda=0.023
# [train] step=38000 q=18.913 critic=3.916 actor=-0.369 bc=0.054 lambda=0.022
# [train] step=39000 q=23.182 critic=9.436 actor=-0.466 bc=0.048 lambda=0.022
# [train] step=40000 q=16.922 critic=5.134 actor=-0.348 bc=0.048 lambda=0.023
# [train] step=41000 q=25.720 critic=5.856 actor=-0.538 bc=0.041 lambda=0.023
# [train] step=42000 q=20.570 critic=10.401 actor=-0.433 bc=0.040 lambda=0.023
# [train] step=43000 q=21.490 critic=4.597 actor=-0.429 bc=0.045 lambda=0.022
# [train] step=44000 q=13.880 critic=3.765 actor=-0.266 bc=0.047 lambda=0.023
# [train] step=45000 q=20.189 critic=3.608 actor=-0.397 bc=0.043 lambda=0.022
# [train] step=46000 q=20.154 critic=4.681 actor=-0.396 bc=0.053 lambda=0.022
# [train] step=47000 q=15.179 critic=5.094 actor=-0.277 bc=0.062 lambda=0.022
# [train] step=48000 q=22.352 critic=4.675 actor=-0.435 bc=0.046 lambda=0.021
# [train] step=49000 q=18.765 critic=3.732 actor=-0.387 bc=0.044 lambda=0.023
# [train] step=50000 q=25.953 critic=12.278 actor=-0.479 bc=0.047 lambda=0.020
# [train] step=51000 q=16.505 critic=5.510 actor=-0.340 bc=0.031 lambda=0.023
# [train] step=52000 q=15.951 critic=4.121 actor=-0.304 bc=0.047 lambda=0.022
# [train] step=53000 q=15.674 critic=4.950 actor=-0.296 bc=0.056 lambda=0.022
# [train] step=54000 q=18.292 critic=7.143 actor=-0.340 bc=0.065 lambda=0.022
# [train] step=55000 q=18.247 critic=149.075 actor=-0.374 bc=0.042 lambda=0.023
# [train] step=56000 q=14.622 critic=6.920 actor=-0.284 bc=0.038 lambda=0.022
# [train] step=57000 q=14.271 critic=8.835 actor=-0.268 bc=0.047 lambda=0.022
# [train] step=58000 q=15.227 critic=298.106 actor=-0.281 bc=0.053 lambda=0.022
# [train] step=59000 q=10.827 critic=5.134 actor=-0.193 bc=0.050 lambda=0.022
# [train] step=60000 q=9.182 critic=3.918 actor=-0.166 bc=0.048 lambda=0.023
# [train] step=61000 q=11.973 critic=8.797 actor=-0.228 bc=0.046 lambda=0.023
# [train] step=62000 q=15.042 critic=5.529 actor=-0.297 bc=0.043 lambda=0.023
# [train] step=63000 q=16.682 critic=5.232 actor=-0.323 bc=0.047 lambda=0.022
# [train] step=64000 q=15.540 critic=3.066 actor=-0.284 bc=0.052 lambda=0.022
# [train] step=65000 q=10.882 critic=15.584 actor=-0.185 bc=0.042 lambda=0.021
# [train] step=66000 q=14.828 critic=11.300 actor=-0.261 bc=0.041 lambda=0.020
# [train] step=67000 q=13.162 critic=12.082 actor=-0.241 bc=0.053 lambda=0.022
# [train] step=68000 q=12.801 critic=7.043 actor=-0.217 bc=0.055 lambda=0.021
# [train] step=69000 q=12.538 critic=29.632 actor=-0.220 bc=0.053 lambda=0.022
# [train] step=70000 q=17.483 critic=4.917 actor=-0.311 bc=0.043 lambda=0.020
# [train] step=71000 q=13.618 critic=2.987 actor=-0.259 bc=0.033 lambda=0.021
# [train] step=72000 q=22.061 critic=5.218 actor=-0.396 bc=0.051 lambda=0.020
# [train] step=73000 q=12.699 critic=3.313 actor=-0.226 bc=0.044 lambda=0.021
# [train] step=74000 q=10.402 critic=6.157 actor=-0.189 bc=0.037 lambda=0.022
# [train] step=75000 q=14.027 critic=6.218 actor=-0.260 bc=0.046 lambda=0.022
# [train] step=76000 q=10.064 critic=3.902 actor=-0.178 bc=0.049 lambda=0.023
# [train] step=77000 q=13.298 critic=8.221 actor=-0.219 bc=0.051 lambda=0.020
# [train] step=78000 q=12.353 critic=4.339 actor=-0.227 bc=0.041 lambda=0.022
# [train] step=79000 q=11.625 critic=37.798 actor=-0.206 bc=0.042 lambda=0.021
# [train] step=80000 q=9.903 critic=4.170 actor=-0.170 bc=0.048 lambda=0.022
# [train] step=81000 q=12.210 critic=3.594 actor=-0.218 bc=0.040 lambda=0.021
# [train] step=82000 q=13.978 critic=5.001 actor=-0.250 bc=0.048 lambda=0.021
# [train] step=83000 q=14.414 critic=3.477 actor=-0.253 bc=0.055 lambda=0.021
# [train] step=84000 q=14.295 critic=7.646 actor=-0.250 bc=0.044 lambda=0.021
# [train] step=85000 q=15.227 critic=4.987 actor=-0.277 bc=0.038 lambda=0.021
# [train] step=86000 q=11.270 critic=4.131 actor=-0.193 bc=0.042 lambda=0.021
# [train] step=87000 q=9.937 critic=4.822 actor=-0.139 bc=0.055 lambda=0.020
# [train] step=88000 q=7.400 critic=2.925 actor=-0.120 bc=0.042 lambda=0.022
# [train] step=89000 q=12.544 critic=2.615 actor=-0.229 bc=0.040 lambda=0.021
# [train] step=90000 q=10.041 critic=1.990 actor=-0.176 bc=0.045 lambda=0.022
# [train] step=91000 q=14.565 critic=11.147 actor=-0.263 bc=0.045 lambda=0.021
# [train] step=92000 q=9.918 critic=5.467 actor=-0.172 bc=0.045 lambda=0.022
# [train] step=93000 q=7.257 critic=4.611 actor=-0.110 bc=0.042 lambda=0.021
# [train] step=94000 q=3.127 critic=8.808 actor=-0.015 bc=0.054 lambda=0.022
# [train] step=95000 q=14.737 critic=270.882 actor=-0.274 bc=0.046 lambda=0.022
# [train] step=96000 q=8.800 critic=5.042 actor=-0.128 bc=0.044 lambda=0.020
# [train] step=97000 q=5.727 critic=5.770 actor=-0.084 bc=0.038 lambda=0.021
# [train] step=98000 q=5.279 critic=5.451 actor=-0.057 bc=0.054 lambda=0.021
# [train] step=99000 q=8.663 critic=11.959 actor=-0.143 bc=0.036 lambda=0.021
# [train] step=100000 q=10.162 critic=3.728 actor=-0.174 bc=0.044 lambda=0.021
# [train] step=101000 q=10.236 critic=7.558 actor=-0.182 bc=0.044 lambda=0.022
# [train] step=102000 q=4.324 critic=9.674 actor=-0.048 bc=0.044 lambda=0.021
# [train] step=103000 q=2.537 critic=12.726 actor=-0.013 bc=0.042 lambda=0.022
# [train] step=104000 q=10.979 critic=4.533 actor=-0.189 bc=0.041 lambda=0.021
# [train] step=105000 q=9.475 critic=5.269 actor=-0.158 bc=0.041 lambda=0.021
# [train] step=106000 q=10.638 critic=7.092 actor=-0.176 bc=0.040 lambda=0.020
# [train] step=107000 q=12.211 critic=9.693 actor=-0.217 bc=0.044 lambda=0.021
# [train] step=108000 q=8.850 critic=7.966 actor=-0.143 bc=0.040 lambda=0.021
# [train] step=109000 q=12.227 critic=7.878 actor=-0.220 bc=0.044 lambda=0.022
# [train] step=110000 q=14.546 critic=6.338 actor=-0.264 bc=0.042 lambda=0.021
# [train] step=111000 q=16.309 critic=10.007 actor=-0.291 bc=0.037 lambda=0.020
# [train] step=112000 q=9.389 critic=4.406 actor=-0.145 bc=0.048 lambda=0.021
# [train] step=113000 q=9.981 critic=4.434 actor=-0.177 bc=0.045 lambda=0.022
# [train] step=114000 q=10.475 critic=3.137 actor=-0.163 bc=0.042 lambda=0.020
# [train] step=115000 q=8.747 critic=326.260 actor=-0.132 bc=0.047 lambda=0.020
# [train] step=116000 q=9.615 critic=15.757 actor=-0.157 bc=0.046 lambda=0.021
# [train] step=117000 q=5.702 critic=7.487 actor=-0.079 bc=0.038 lambda=0.020
# [train] step=118000 q=8.262 critic=4.411 actor=-0.139 bc=0.036 lambda=0.021
# [train] step=119000 q=7.757 critic=10.283 actor=-0.117 bc=0.045 lambda=0.021
# [train] step=120000 q=8.175 critic=4.314 actor=-0.125 bc=0.047 lambda=0.021
# [train] step=121000 q=11.722 critic=3.549 actor=-0.200 bc=0.039 lambda=0.020
# [train] step=122000 q=8.177 critic=7.010 actor=-0.132 bc=0.041 lambda=0.021
# [train] step=123000 q=9.023 critic=11.920 actor=-0.145 bc=0.042 lambda=0.021
# [train] step=124000 q=9.632 critic=5.414 actor=-0.164 bc=0.027 lambda=0.020
# [train] step=125000 q=12.963 critic=12.937 actor=-0.230 bc=0.039 lambda=0.021
# [train] step=126000 q=14.093 critic=4.070 actor=-0.249 bc=0.046 lambda=0.021
# [train] step=127000 q=5.459 critic=5.190 actor=-0.083 bc=0.037 lambda=0.022
# [train] step=128000 q=5.221 critic=8.877 actor=-0.065 bc=0.047 lambda=0.021
# [train] step=129000 q=12.298 critic=7.709 actor=-0.213 bc=0.046 lambda=0.021
# [train] step=130000 q=13.111 critic=5.545 actor=-0.231 bc=0.045 lambda=0.021
# [train] step=131000 q=12.917 critic=2.552 actor=-0.219 bc=0.044 lambda=0.020
# [train] step=132000 q=8.792 critic=10.186 actor=-0.124 bc=0.051 lambda=0.020
# [train] step=133000 q=7.413 critic=265.959 actor=-0.108 bc=0.050 lambda=0.021
# [train] step=134000 q=12.934 critic=2.751 actor=-0.221 bc=0.044 lambda=0.020
# [train] step=135000 q=10.334 critic=18.153 actor=-0.169 bc=0.043 lambda=0.020
# [train] step=136000 q=13.988 critic=10.156 actor=-0.240 bc=0.043 lambda=0.020
# [train] step=137000 q=9.662 critic=5.239 actor=-0.154 bc=0.038 lambda=0.020
# [train] step=138000 q=10.052 critic=8.468 actor=-0.146 bc=0.048 lambda=0.019
# [train] step=139000 q=5.479 critic=5.192 actor=-0.070 bc=0.046 lambda=0.021
# [train] step=140000 q=6.469 critic=3.733 actor=-0.107 bc=0.034 lambda=0.022
# [train] step=141000 q=6.066 critic=6.353 actor=-0.088 bc=0.044 lambda=0.022
# [train] step=142000 q=8.871 critic=11.902 actor=-0.127 bc=0.046 lambda=0.020
# [train] step=143000 q=8.245 critic=4.128 actor=-0.120 bc=0.048 lambda=0.020
# [train] step=144000 q=11.859 critic=6.177 actor=-0.186 bc=0.037 lambda=0.019
# [train] step=145000 q=5.110 critic=4.156 actor=-0.058 bc=0.052 lambda=0.022
# [train] step=146000 q=12.660 critic=6.547 actor=-0.220 bc=0.041 lambda=0.021
# [train] step=147000 q=12.675 critic=5.390 actor=-0.219 bc=0.038 lambda=0.020
# [train] step=148000 q=7.645 critic=5.786 actor=-0.109 bc=0.039 lambda=0.019
# [train] step=149000 q=11.049 critic=3.906 actor=-0.185 bc=0.044 lambda=0.021
# [train] step=150000 q=12.692 critic=3.289 actor=-0.213 bc=0.043 lambda=0.020
# [train] step=151000 q=4.818 critic=5.313 actor=-0.059 bc=0.044 lambda=0.021
# [train] step=152000 q=5.554 critic=4.366 actor=-0.077 bc=0.041 lambda=0.021
# [train] step=153000 q=8.856 critic=2.807 actor=-0.134 bc=0.041 lambda=0.020
# [train] step=154000 q=7.406 critic=2.657 actor=-0.122 bc=0.041 lambda=0.022
# [train] step=155000 q=9.765 critic=36.910 actor=-0.162 bc=0.039 lambda=0.021
# [train] step=156000 q=14.828 critic=5.412 actor=-0.273 bc=0.036 lambda=0.021
# [train] step=157000 q=8.003 critic=7.823 actor=-0.128 bc=0.039 lambda=0.021
# [train] step=158000 q=6.998 critic=9.125 actor=-0.109 bc=0.040 lambda=0.021
# [train] step=159000 q=9.601 critic=34.955 actor=-0.143 bc=0.042 lambda=0.019
# [train] step=160000 q=5.701 critic=5.742 actor=-0.082 bc=0.039 lambda=0.021
# [train] step=161000 q=11.330 critic=4.810 actor=-0.187 bc=0.042 lambda=0.020
# [train] step=162000 q=11.849 critic=5.958 actor=-0.214 bc=0.036 lambda=0.021
# [train] step=163000 q=7.817 critic=9.073 actor=-0.114 bc=0.048 lambda=0.021
# [train] step=164000 q=8.208 critic=4.355 actor=-0.131 bc=0.043 lambda=0.021
# [train] step=165000 q=8.530 critic=8.333 actor=-0.146 bc=0.034 lambda=0.021
# [train] step=166000 q=7.643 critic=6.015 actor=-0.115 bc=0.040 lambda=0.020
# [train] step=167000 q=5.196 critic=55.716 actor=-0.068 bc=0.043 lambda=0.021
# [train] step=168000 q=4.373 critic=5.572 actor=-0.038 bc=0.048 lambda=0.019
# [train] step=169000 q=6.966 critic=4.857 actor=-0.106 bc=0.040 lambda=0.021
# [train] step=170000 q=10.541 critic=2.867 actor=-0.177 bc=0.045 lambda=0.021
# [train] step=171000 q=13.024 critic=6.348 actor=-0.226 bc=0.041 lambda=0.021
# [train] step=172000 q=8.823 critic=16.784 actor=-0.144 bc=0.039 lambda=0.021
# [train] step=173000 q=6.920 critic=3.859 actor=-0.102 bc=0.049 lambda=0.022
# [train] step=174000 q=10.774 critic=9.205 actor=-0.180 bc=0.043 lambda=0.021
# [train] step=175000 q=6.924 critic=6.687 actor=-0.098 bc=0.042 lambda=0.020
# [train] step=176000 q=6.436 critic=7.677 actor=-0.096 bc=0.042 lambda=0.021
# [train] step=177000 q=12.344 critic=10.988 actor=-0.217 bc=0.040 lambda=0.021
# [train] step=178000 q=4.012 critic=106.739 actor=-0.031 bc=0.051 lambda=0.020
# [train] step=179000 q=7.644 critic=7.530 actor=-0.116 bc=0.042 lambda=0.021
# [train] step=180000 q=3.280 critic=4.970 actor=-0.029 bc=0.037 lambda=0.020
# [train] step=181000 q=10.284 critic=5.069 actor=-0.181 bc=0.039 lambda=0.021
# [train] step=182000 q=7.864 critic=7.838 actor=-0.122 bc=0.041 lambda=0.021
# [train] step=183000 q=7.382 critic=3.104 actor=-0.120 bc=0.040 lambda=0.022
# [train] step=184000 q=7.965 critic=4.261 actor=-0.127 bc=0.037 lambda=0.021
# [train] step=185000 q=9.098 critic=5.490 actor=-0.150 bc=0.039 lambda=0.021
# [train] step=186000 q=12.952 critic=2.510 actor=-0.216 bc=0.044 lambda=0.020
# [train] step=187000 q=9.810 critic=4.806 actor=-0.161 bc=0.041 lambda=0.021
# [train] step=188000 q=3.847 critic=3.490 actor=-0.049 bc=0.035 lambda=0.022
# [train] step=189000 q=0.008 critic=4.910 actor=0.039 bc=0.039 lambda=0.020
# [train] step=190000 q=10.984 critic=35.434 actor=-0.182 bc=0.035 lambda=0.020
# [train] step=191000 q=13.591 critic=3.168 actor=-0.217 bc=0.048 lambda=0.020
# [train] step=192000 q=9.175 critic=8.675 actor=-0.143 bc=0.048 lambda=0.021
# [train] step=193000 q=8.872 critic=5.211 actor=-0.137 bc=0.041 lambda=0.020
# [train] step=194000 q=12.223 critic=2.970 actor=-0.204 bc=0.043 lambda=0.020
# [train] step=195000 q=8.848 critic=4.134 actor=-0.131 bc=0.043 lambda=0.020
# [train] step=196000 q=4.420 critic=5.413 actor=-0.041 bc=0.050 lambda=0.021
# [train] step=197000 q=17.156 critic=3.883 actor=-0.306 bc=0.037 lambda=0.020
# [train] step=198000 q=9.859 critic=8.651 actor=-0.162 bc=0.039 lambda=0.020
# [train] step=199000 q=7.701 critic=7.358 actor=-0.115 bc=0.039 lambda=0.020
# [train] step=200000 q=7.404 critic=4.001 actor=-0.108 bc=0.040 lambda=0.020
# [train done] fql | mexp | seed=42 in 41.8 min
#
# ========================================================================
#   train fql | expert | seed=42  →  checkpoints/offline/sac_collector_h2h/fql/expert/seed_42
# ========================================================================
# [offline] algo=fql transitions=114832 obs_dim=48 action_dim=2 protocol=deployable tensor_replay=on eval_workers=1 sampling=uniform total_steps=200000
# [train] step=1 q=-0.139 critic=246.714 actor=1.773 bc=1.062 lambda=5.101
# [train] step=1000 q=2.172 critic=1.974 actor=-0.701 bc=0.084 lambda=0.361
# [train] step=2000 q=3.652 critic=37.382 actor=-0.708 bc=0.064 lambda=0.211
# [train] step=3000 q=4.815 critic=2.781 actor=-0.735 bc=0.057 lambda=0.164
# [train] step=4000 q=9.459 critic=2.969 actor=-0.797 bc=0.047 lambda=0.089
# [train] step=5000 q=13.861 critic=4.273 actor=-0.801 bc=0.042 lambda=0.061
# [train] step=6000 q=11.554 critic=1.050 actor=-0.751 bc=0.053 lambda=0.070
# [train] step=7000 q=13.527 critic=27.164 actor=-0.761 bc=0.040 lambda=0.059
# [train] step=8000 q=13.423 critic=2.999 actor=-0.782 bc=0.040 lambda=0.061
# [train] step=9000 q=20.106 critic=238.134 actor=-0.783 bc=0.050 lambda=0.041
# [train] step=10000 q=19.634 critic=2.487 actor=-0.732 bc=0.052 lambda=0.040
# [train] step=11000 q=21.006 critic=3.617 actor=-0.745 bc=0.046 lambda=0.038
# [train] step=12000 q=24.648 critic=2.303 actor=-0.817 bc=0.044 lambda=0.035
# [train] step=13000 q=25.566 critic=7.981 actor=-0.758 bc=0.051 lambda=0.032
# [train] step=14000 q=29.630 critic=5.333 actor=-0.795 bc=0.047 lambda=0.028
# [train] step=15000 q=26.313 critic=4.873 actor=-0.695 bc=0.039 lambda=0.028
# [train] step=16000 q=26.955 critic=2.302 actor=-0.719 bc=0.048 lambda=0.028
# [train] step=17000 q=31.629 critic=9.435 actor=-0.785 bc=0.043 lambda=0.026
# [train] step=18000 q=30.754 critic=231.925 actor=-0.734 bc=0.035 lambda=0.025
# [train] step=19000 q=37.743 critic=2.637 actor=-0.785 bc=0.045 lambda=0.022
# [train] step=20000 q=36.034 critic=3.225 actor=-0.816 bc=0.040 lambda=0.024
# [train] step=21000 q=37.950 critic=4.045 actor=-0.810 bc=0.039 lambda=0.022
# [train] step=22000 q=31.383 critic=14.422 actor=-0.704 bc=0.042 lambda=0.024
# [train] step=23000 q=37.590 critic=3.608 actor=-0.754 bc=0.033 lambda=0.021
# [train] step=24000 q=35.310 critic=6.670 actor=-0.708 bc=0.039 lambda=0.021
# [train] step=25000 q=36.172 critic=5.120 actor=-0.705 bc=0.038 lambda=0.021
# [train] step=26000 q=30.937 critic=2.801 actor=-0.637 bc=0.052 lambda=0.022
# [train] step=27000 q=39.084 critic=8.594 actor=-0.695 bc=0.040 lambda=0.019
# [train] step=28000 q=38.545 critic=5.421 actor=-0.703 bc=0.041 lambda=0.019
# [train] step=29000 q=33.737 critic=3.807 actor=-0.600 bc=0.036 lambda=0.019
# [train] step=30000 q=42.370 critic=8.123 actor=-0.734 bc=0.029 lambda=0.018
# [train] step=31000 q=39.661 critic=19.734 actor=-0.690 bc=0.035 lambda=0.018
# [train] step=32000 q=43.078 critic=3.404 actor=-0.766 bc=0.035 lambda=0.019
# [train] step=33000 q=43.373 critic=20.882 actor=-0.662 bc=0.043 lambda=0.016
# [train] step=34000 q=39.199 critic=7.425 actor=-0.655 bc=0.034 lambda=0.018
# [train] step=35000 q=39.461 critic=3.343 actor=-0.651 bc=0.035 lambda=0.017
# [train] step=36000 q=38.798 critic=6.638 actor=-0.693 bc=0.038 lambda=0.019
# [train] step=37000 q=40.914 critic=6.679 actor=-0.693 bc=0.037 lambda=0.018
# [train] step=38000 q=43.845 critic=5.091 actor=-0.738 bc=0.034 lambda=0.018
# [train] step=39000 q=41.481 critic=3.392 actor=-0.674 bc=0.038 lambda=0.017
# [train] step=40000 q=41.966 critic=205.591 actor=-0.648 bc=0.048 lambda=0.017
# [train] step=41000 q=40.537 critic=6.535 actor=-0.650 bc=0.037 lambda=0.017
# [train] step=42000 q=40.970 critic=2.500 actor=-0.648 bc=0.023 lambda=0.016
# [train] step=43000 q=40.969 critic=3.783 actor=-0.627 bc=0.042 lambda=0.016
# [train] step=44000 q=36.117 critic=5.248 actor=-0.583 bc=0.040 lambda=0.017
# [train] step=45000 q=42.111 critic=5.800 actor=-0.643 bc=0.038 lambda=0.016
# [train] step=46000 q=45.874 critic=4.803 actor=-0.701 bc=0.037 lambda=0.016
# [train] step=47000 q=38.808 critic=2.987 actor=-0.624 bc=0.046 lambda=0.017
# [train] step=48000 q=37.191 critic=5.243 actor=-0.594 bc=0.032 lambda=0.017
# [train] step=49000 q=41.931 critic=5.662 actor=-0.700 bc=0.027 lambda=0.017
# [train] step=50000 q=41.332 critic=5.307 actor=-0.667 bc=0.028 lambda=0.017
# [train] step=51000 q=36.019 critic=4.816 actor=-0.603 bc=0.031 lambda=0.018
# [train] step=52000 q=34.532 critic=7.003 actor=-0.571 bc=0.028 lambda=0.017
# [train] step=53000 q=42.819 critic=3.915 actor=-0.678 bc=0.034 lambda=0.017
# [train] step=54000 q=45.445 critic=7.166 actor=-0.688 bc=0.036 lambda=0.016
# [train] step=55000 q=29.009 critic=15.112 actor=-0.464 bc=0.040 lambda=0.017
# [train] step=56000 q=36.944 critic=22.645 actor=-0.613 bc=0.031 lambda=0.017
# [train] step=57000 q=34.035 critic=5.980 actor=-0.540 bc=0.037 lambda=0.017
# [train] step=58000 q=32.625 critic=3.500 actor=-0.557 bc=0.028 lambda=0.018
# [train] step=59000 q=36.339 critic=5.855 actor=-0.584 bc=0.032 lambda=0.017
# [train] step=60000 q=25.103 critic=7.540 actor=-0.402 bc=0.034 lambda=0.017
# [train] step=61000 q=36.643 critic=5.412 actor=-0.609 bc=0.036 lambda=0.018
# [train] step=62000 q=36.321 critic=10.545 actor=-0.575 bc=0.024 lambda=0.017
# [train] step=63000 q=34.016 critic=7.776 actor=-0.512 bc=0.031 lambda=0.016
# [train] step=64000 q=28.045 critic=40.090 actor=-0.439 bc=0.037 lambda=0.017
# [train] step=65000 q=31.383 critic=9.916 actor=-0.493 bc=0.034 lambda=0.017
# [train] step=66000 q=27.967 critic=7.497 actor=-0.433 bc=0.035 lambda=0.017
# [train] step=67000 q=32.191 critic=13.970 actor=-0.490 bc=0.028 lambda=0.016
# [train] step=68000 q=35.695 critic=31.465 actor=-0.538 bc=0.034 lambda=0.016
# [train] step=69000 q=29.660 critic=9.907 actor=-0.478 bc=0.036 lambda=0.017
# [train] step=70000 q=24.572 critic=36.218 actor=-0.383 bc=0.039 lambda=0.017
# [train] step=71000 q=28.539 critic=6.093 actor=-0.463 bc=0.028 lambda=0.017
# [train] step=72000 q=23.249 critic=10.441 actor=-0.356 bc=0.042 lambda=0.017
# [train] step=73000 q=34.888 critic=5.816 actor=-0.545 bc=0.041 lambda=0.017
# [train] step=74000 q=37.032 critic=10.884 actor=-0.617 bc=0.024 lambda=0.017
# [train] step=75000 q=25.059 critic=8.492 actor=-0.371 bc=0.027 lambda=0.016
# [train] step=76000 q=26.596 critic=8.320 actor=-0.425 bc=0.030 lambda=0.017
# [train] step=77000 q=28.211 critic=15.588 actor=-0.443 bc=0.029 lambda=0.017
# [train] step=78000 q=31.871 critic=6.217 actor=-0.504 bc=0.039 lambda=0.017
# [train] step=79000 q=32.454 critic=8.734 actor=-0.526 bc=0.033 lambda=0.017
# [train] step=80000 q=30.488 critic=17.424 actor=-0.488 bc=0.036 lambda=0.017
# [train] step=81000 q=32.240 critic=11.308 actor=-0.504 bc=0.028 lambda=0.017
# [train] step=82000 q=28.721 critic=7.721 actor=-0.451 bc=0.032 lambda=0.017
# [train] step=83000 q=26.743 critic=30.946 actor=-0.431 bc=0.032 lambda=0.017
# [train] step=84000 q=26.593 critic=10.458 actor=-0.403 bc=0.040 lambda=0.017
# [train] step=85000 q=25.531 critic=8.680 actor=-0.389 bc=0.033 lambda=0.017
# [train] step=86000 q=32.236 critic=24.691 actor=-0.494 bc=0.029 lambda=0.016
# [train] step=87000 q=25.644 critic=34.900 actor=-0.400 bc=0.029 lambda=0.017
# [train] step=88000 q=22.718 critic=13.125 actor=-0.324 bc=0.035 lambda=0.016
# [train] step=89000 q=34.208 critic=3.654 actor=-0.517 bc=0.029 lambda=0.016
# [train] step=90000 q=31.201 critic=17.888 actor=-0.475 bc=0.028 lambda=0.016
# [train] step=91000 q=24.823 critic=30.707 actor=-0.344 bc=0.047 lambda=0.016
# [train] step=92000 q=23.659 critic=9.139 actor=-0.359 bc=0.034 lambda=0.017
# [train] step=93000 q=20.657 critic=10.710 actor=-0.315 bc=0.037 lambda=0.017
# [train] step=94000 q=29.112 critic=34.280 actor=-0.454 bc=0.034 lambda=0.017
# [train] step=95000 q=22.830 critic=10.668 actor=-0.332 bc=0.033 lambda=0.016
# [train] step=96000 q=23.050 critic=11.899 actor=-0.369 bc=0.028 lambda=0.017
# [train] step=97000 q=34.388 critic=9.776 actor=-0.543 bc=0.032 lambda=0.017
# [train] step=98000 q=23.452 critic=44.141 actor=-0.355 bc=0.037 lambda=0.017
# [train] step=99000 q=21.133 critic=11.169 actor=-0.310 bc=0.035 lambda=0.016
# [train] step=100000 q=27.556 critic=62.543 actor=-0.417 bc=0.026 lambda=0.016
# [train] step=101000 q=23.788 critic=9.390 actor=-0.355 bc=0.027 lambda=0.016
# [train] step=102000 q=31.407 critic=7.144 actor=-0.469 bc=0.041 lambda=0.016
# [train] step=103000 q=27.199 critic=20.828 actor=-0.411 bc=0.028 lambda=0.016
# [train] step=104000 q=29.214 critic=6.676 actor=-0.436 bc=0.033 lambda=0.016
# [train] step=105000 q=27.481 critic=20.673 actor=-0.430 bc=0.029 lambda=0.017
# [train] step=106000 q=25.424 critic=11.614 actor=-0.378 bc=0.028 lambda=0.016
# [train] step=107000 q=24.981 critic=16.824 actor=-0.356 bc=0.030 lambda=0.015
# [train] step=108000 q=26.065 critic=45.093 actor=-0.390 bc=0.040 lambda=0.017
# [train] step=109000 q=24.561 critic=51.938 actor=-0.362 bc=0.030 lambda=0.016
# [train] step=110000 q=21.884 critic=5.536 actor=-0.313 bc=0.036 lambda=0.016
# [train] step=111000 q=20.273 critic=11.693 actor=-0.295 bc=0.028 lambda=0.016
# [train] step=112000 q=30.436 critic=6.933 actor=-0.468 bc=0.035 lambda=0.017
# [train] step=113000 q=28.444 critic=11.510 actor=-0.439 bc=0.034 lambda=0.017
# [train] step=114000 q=30.560 critic=5.427 actor=-0.474 bc=0.028 lambda=0.016
# [train] step=115000 q=23.435 critic=7.288 actor=-0.344 bc=0.031 lambda=0.016
# [train] step=116000 q=25.880 critic=5.002 actor=-0.394 bc=0.034 lambda=0.017
# [train] step=117000 q=25.779 critic=99.144 actor=-0.374 bc=0.031 lambda=0.016
# [train] step=118000 q=26.370 critic=7.529 actor=-0.389 bc=0.036 lambda=0.016
# [train] step=119000 q=27.079 critic=4.101 actor=-0.418 bc=0.030 lambda=0.017
# [train] step=120000 q=21.735 critic=9.965 actor=-0.316 bc=0.040 lambda=0.016
# [train] step=121000 q=14.826 critic=12.088 actor=-0.203 bc=0.034 lambda=0.016
# [train] step=122000 q=18.415 critic=8.493 actor=-0.257 bc=0.038 lambda=0.016
# [train] step=123000 q=21.288 critic=5.444 actor=-0.312 bc=0.040 lambda=0.017
# [train] step=124000 q=27.004 critic=7.921 actor=-0.397 bc=0.025 lambda=0.016
# [train] step=125000 q=28.611 critic=6.226 actor=-0.425 bc=0.027 lambda=0.016
# [train] step=126000 q=26.605 critic=6.878 actor=-0.373 bc=0.038 lambda=0.015
# [train] step=127000 q=23.888 critic=72.632 actor=-0.335 bc=0.028 lambda=0.015
# [train] step=128000 q=27.461 critic=3.744 actor=-0.412 bc=0.030 lambda=0.016
# [train] step=129000 q=27.275 critic=6.616 actor=-0.402 bc=0.028 lambda=0.016
# [train] step=130000 q=33.254 critic=6.851 actor=-0.502 bc=0.029 lambda=0.016
# [train] step=131000 q=20.908 critic=5.446 actor=-0.298 bc=0.033 lambda=0.016
# [train] step=132000 q=20.656 critic=8.304 actor=-0.317 bc=0.030 lambda=0.017
# [train] step=133000 q=26.241 critic=6.789 actor=-0.385 bc=0.033 lambda=0.016
# [train] step=134000 q=30.098 critic=5.860 actor=-0.506 bc=0.023 lambda=0.018
# [train] step=135000 q=23.078 critic=17.819 actor=-0.337 bc=0.031 lambda=0.016
# [train] step=136000 q=26.648 critic=16.040 actor=-0.413 bc=0.029 lambda=0.017
# [train] step=137000 q=21.395 critic=19.748 actor=-0.304 bc=0.031 lambda=0.016
# [train] step=138000 q=29.079 critic=7.318 actor=-0.467 bc=0.027 lambda=0.017
# [train] step=139000 q=20.597 critic=3.538 actor=-0.316 bc=0.033 lambda=0.017
# [train] step=140000 q=21.641 critic=5.906 actor=-0.315 bc=0.030 lambda=0.016
# [train] step=141000 q=25.985 critic=93.963 actor=-0.393 bc=0.034 lambda=0.016
# [train] step=142000 q=21.374 critic=6.005 actor=-0.306 bc=0.032 lambda=0.016
# [train] step=143000 q=20.866 critic=6.714 actor=-0.297 bc=0.032 lambda=0.016
# [train] step=144000 q=26.189 critic=2.454 actor=-0.387 bc=0.029 lambda=0.016
# [train] step=145000 q=24.643 critic=5.852 actor=-0.347 bc=0.040 lambda=0.016
# [train] step=146000 q=23.558 critic=6.931 actor=-0.352 bc=0.029 lambda=0.016
# [train] step=147000 q=25.297 critic=39.127 actor=-0.388 bc=0.022 lambda=0.016
# [train] step=148000 q=31.544 critic=11.270 actor=-0.480 bc=0.027 lambda=0.016
# [train] step=149000 q=28.815 critic=3.602 actor=-0.423 bc=0.028 lambda=0.016
# [train] step=150000 q=33.576 critic=11.720 actor=-0.491 bc=0.029 lambda=0.016
# [train] step=151000 q=23.361 critic=3.031 actor=-0.331 bc=0.039 lambda=0.016
# [train] step=152000 q=23.327 critic=3.359 actor=-0.351 bc=0.040 lambda=0.017
# [train] step=153000 q=30.692 critic=3.453 actor=-0.446 bc=0.027 lambda=0.015
# [train] step=154000 q=26.068 critic=4.447 actor=-0.365 bc=0.034 lambda=0.015
# [train] step=155000 q=23.271 critic=37.085 actor=-0.341 bc=0.027 lambda=0.016
# [train] step=156000 q=26.906 critic=9.559 actor=-0.421 bc=0.028 lambda=0.017
# [train] step=157000 q=27.812 critic=6.089 actor=-0.401 bc=0.027 lambda=0.015
# [train] step=158000 q=24.993 critic=3.757 actor=-0.389 bc=0.029 lambda=0.017
# [train] step=159000 q=25.360 critic=9.616 actor=-0.390 bc=0.029 lambda=0.017
# [train] step=160000 q=32.950 critic=7.192 actor=-0.530 bc=0.020 lambda=0.017
# [train] step=161000 q=24.389 critic=12.603 actor=-0.344 bc=0.034 lambda=0.016
# [train] step=162000 q=25.490 critic=2.037 actor=-0.380 bc=0.028 lambda=0.016
# [train] step=163000 q=34.504 critic=5.229 actor=-0.506 bc=0.034 lambda=0.016
# [train] step=164000 q=31.130 critic=6.169 actor=-0.450 bc=0.027 lambda=0.015
# [train] step=165000 q=24.185 critic=9.486 actor=-0.361 bc=0.032 lambda=0.016
# [train] step=166000 q=30.206 critic=3.057 actor=-0.436 bc=0.026 lambda=0.015
# [train] step=167000 q=27.782 critic=4.830 actor=-0.402 bc=0.027 lambda=0.015
# [train] step=168000 q=23.713 critic=3.484 actor=-0.367 bc=0.035 lambda=0.017
# [train] step=169000 q=30.764 critic=2.246 actor=-0.440 bc=0.029 lambda=0.015
# [train] step=170000 q=32.439 critic=24.053 actor=-0.498 bc=0.033 lambda=0.016
# [train] step=171000 q=24.284 critic=7.127 actor=-0.373 bc=0.037 lambda=0.017
# [train] step=172000 q=32.093 critic=2.239 actor=-0.497 bc=0.024 lambda=0.016
# [train] step=173000 q=29.401 critic=2.866 actor=-0.432 bc=0.030 lambda=0.016
# [train] step=174000 q=32.409 critic=7.386 actor=-0.468 bc=0.029 lambda=0.015
# [train] step=175000 q=29.731 critic=4.346 actor=-0.421 bc=0.027 lambda=0.015
# [train] step=176000 q=18.284 critic=10.135 actor=-0.281 bc=0.028 lambda=0.017
# [train] step=177000 q=32.395 critic=1.774 actor=-0.463 bc=0.027 lambda=0.015
# [train] step=178000 q=28.762 critic=3.075 actor=-0.422 bc=0.031 lambda=0.016
# [train] step=179000 q=30.267 critic=2.840 actor=-0.432 bc=0.029 lambda=0.015
# [train] step=180000 q=25.432 critic=2.587 actor=-0.372 bc=0.035 lambda=0.016
# [train] step=181000 q=27.748 critic=3.018 actor=-0.398 bc=0.032 lambda=0.015
# [train] step=182000 q=35.564 critic=21.987 actor=-0.532 bc=0.024 lambda=0.016
# [train] step=183000 q=36.301 critic=6.196 actor=-0.545 bc=0.025 lambda=0.016
# [train] step=184000 q=36.952 critic=5.073 actor=-0.580 bc=0.029 lambda=0.016
# [train] step=185000 q=29.301 critic=2.122 actor=-0.439 bc=0.029 lambda=0.016
# [train] step=186000 q=25.501 critic=3.813 actor=-0.381 bc=0.027 lambda=0.016
# [train] step=187000 q=37.516 critic=3.043 actor=-0.560 bc=0.033 lambda=0.016
# [train] step=188000 q=28.750 critic=8.527 actor=-0.432 bc=0.026 lambda=0.016
# [train] step=189000 q=26.801 critic=4.775 actor=-0.407 bc=0.025 lambda=0.016
# [train] step=190000 q=24.995 critic=1.406 actor=-0.369 bc=0.027 lambda=0.016
# [train] step=191000 q=31.257 critic=2.579 actor=-0.460 bc=0.028 lambda=0.016
# [train] step=192000 q=28.320 critic=44.809 actor=-0.406 bc=0.037 lambda=0.016
# [train] step=193000 q=28.648 critic=1.999 actor=-0.450 bc=0.032 lambda=0.017
# [train] step=194000 q=31.850 critic=1.590 actor=-0.462 bc=0.033 lambda=0.016
# [train] step=195000 q=26.603 critic=44.335 actor=-0.410 bc=0.024 lambda=0.016
# [train] step=196000 q=37.061 critic=2.102 actor=-0.583 bc=0.026 lambda=0.016
# [train] step=197000 q=31.348 critic=2.020 actor=-0.477 bc=0.022 lambda=0.016
# [train] step=198000 q=31.478 critic=1.852 actor=-0.462 bc=0.034 lambda=0.016
# [train] step=199000 q=30.884 critic=3.509 actor=-0.444 bc=0.029 lambda=0.015
# [train] step=200000 q=25.267 critic=2.057 actor=-0.360 bc=0.030 lambda=0.015
# [train done] fql | expert | seed=42 in 41.1 min
#
# === Sprint 2 FQL train complete, total = 166.7 min ===

# %% [markdown]
# ## 5. Evaluate — 12 run × 100 ep test on `single_u10_cross_tgt15`
#
# **Per-run skip-resume**：若 `<results-dir>/test_result.json` 已存在则跳过；若 `<save-dir>/agent_final.pt` 不存在则跳过并打 warn（train 未完）。
#
# **预算**：12 × 2 min ≈ 25 min L4。

# %%
import time

t_start_eval = time.time()

for tier, _ in TIERS:
    for seed in SEEDS:
        sd = save_dir(tier, seed)
        sd_str = str(sd)
        out_path = test_result_path(tier, seed)
        out_path_str = str(out_path)
        manifest_str = str(MANIFEST)
        if out_path.exists():
            print(f"[skip-eval] fql | {tier} | seed={seed} (test_result.json exists)")
            continue
        if not (sd / "agent_final.pt").exists():
            print(f"[warn] fql | {tier} | seed={seed}  missing agent_final.pt — train not done?")
            continue
        out_path.parent.mkdir(parents=True, exist_ok=True)
        print(f"\n{'=' * 72}")
        print(f"  eval  fql | {tier} | seed={seed}  →  {out_path}")
        print(f"{'=' * 72}")
        t0 = time.time()
        # !python -m scripts.evaluate_offline \
            --checkpoint '{sd_str}' \
            --manifest '{manifest_str}' \
            --episodes 100 \
            --seed 456 \
            --device cuda \
            --output-json '{out_path_str}'
        print(f"[eval done] fql | {tier} | seed={seed} in {(time.time() - t0) / 60:.1f} min")

print(f"\n=== Eval all complete, total = {(time.time() - t_start_eval) / 60:.1f} min ===")
# Out:
# ========================================================================
#   eval  fql | random | seed=42  →  results/offline/sac_collector_h2h/fql/random/seed_42/test_result.json
# ========================================================================
# reward_objective      : arrival_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.000000
# episodes              : 30
# success_rate          : 0.0%
# avg_return            : -338.55 +/- 56.47
# avg_safety_cost       : 19.629 +/- 14.123
# avg_time_s            : 86.53 +/- 39.02
# avg_time_s_success    : nan
# avg_energy            : 24088.25 +/- 13501.59
# avg_path_length_m     : 86.79 +/- 38.66
# avg_progress_ratio    : -0.994 +/- 0.811
# avg_path_efficiency   : -0.400 +/- 0.246
# termination           : {'out_of_bounds': 30}
# benchmark_manifest    : benchmarks/single_u10_cross_tgt15.json
# [eval done] fql | random | seed=42 in 1.3 min
#
# ========================================================================
#   eval  fql | medium | seed=42  →  results/offline/sac_collector_h2h/fql/medium/seed_42/test_result.json
# ========================================================================
# reward_objective      : arrival_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.000000
# episodes              : 30
# success_rate          : 73.3%
# avg_return            : 41.32 +/- 164.15
# avg_safety_cost       : 10.326 +/- 19.871
# avg_time_s            : 72.44 +/- 61.05
# avg_time_s_success    : 51.70
# avg_energy            : 47615.93 +/- 27628.15
# avg_path_length_m     : 66.24 +/- 31.54
# avg_progress_ratio    : 0.703 +/- 0.440
# avg_path_efficiency   : 0.574 +/- 0.292
# termination           : {'out_of_bounds': 5, 'goal': 22, 'timeout': 3}
# benchmark_manifest    : benchmarks/single_u10_cross_tgt15.json
# [eval done] fql | medium | seed=42 in 0.9 min
#
# ========================================================================
#   eval  fql | mexp | seed=42  →  results/offline/sac_collector_h2h/fql/mexp/seed_42/test_result.json
# ========================================================================
# reward_objective      : arrival_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.000000
# episodes              : 30
# success_rate          : 90.0%
# avg_return            : 110.64 +/- 88.28
# avg_safety_cost       : 3.274 +/- 3.238
# avg_time_s            : 49.18 +/- 36.29
# avg_time_s_success    : 43.39
# avg_energy            : 36805.37 +/- 17164.27
# avg_path_length_m     : 49.47 +/- 12.56
# avg_progress_ratio    : 0.882 +/- 0.079
# avg_path_efficiency   : 0.796 +/- 0.134
# termination           : {'goal': 27, 'timeout': 1, 'out_of_bounds': 2}
# benchmark_manifest    : benchmarks/single_u10_cross_tgt15.json
# [eval done] fql | mexp | seed=42 in 0.6 min
#
# ========================================================================
#   eval  fql | expert | seed=42  →  results/offline/sac_collector_h2h/fql/expert/seed_42/test_result.json
# ========================================================================
# reward_objective      : arrival_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.000000
# episodes              : 30
# success_rate          : 90.0%
# avg_return            : 112.52 +/- 84.24
# avg_safety_cost       : 4.603 +/- 10.753
# avg_time_s            : 58.33 +/- 54.98
# avg_time_s_success    : 40.39
# avg_energy            : 41732.84 +/- 26218.51
# avg_path_length_m     : 53.37 +/- 20.39
# avg_progress_ratio    : 0.863 +/- 0.138
# avg_path_efficiency   : 0.776 +/- 0.214
# termination           : {'goal': 27, 'timeout': 2, 'out_of_bounds': 1}
# benchmark_manifest    : benchmarks/single_u10_cross_tgt15.json
# [eval done] fql | expert | seed=42 in 0.7 min
#
# === Eval all complete, total = 3.5 min ===

# %% [markdown]
# ## 6. Verify summary — 12 test_result.json → table
#
# **输出**：
# - per-tier mean ± std across 3 seeds (success_rate)
# - (Optional) sprint 1 ReBRAC β1=1 / β1=4 per-tier paired comparison — 详细 paired bootstrap CI 留给本地 sprint 1+2 联合 analysis notebook

# %%
import json
import numpy as np

results: dict[str, list[float]] = {}
missing = []
for tier, _ in TIERS:
    seed_successes = []
    for seed in SEEDS:
        p = test_result_path(tier, seed)
        if not p.exists():
            missing.append((tier, seed))
            continue
        data = json.loads(p.read_text())
        sr = float(data.get("eval_success_rate", float("nan")))  # evaluate_offline.py outputs eval_success_rate in [0,1]
        seed_successes.append(sr)
    results[tier] = seed_successes

print("=== FQL head-to-head on SAC tier datasets (test 100 ep × 3 seed) ===\n")
print(f"{'tier':12s} {'FQL α_bc=1 (mean ± std)':25s} {'seeds':>20s}")
print("-" * 70)
for tier, _ in TIERS:
    s = results.get(tier, [])
    m = float(np.mean(s)) if s else float("nan")
    sd_ = float(np.std(s, ddof=0)) if len(s) > 1 else 0.0
    seed_repr = "  ".join(f"{v:.3f}" for v in s) if s else "(empty)"
    print(f"{tier:12s} {m:.3f} ± {sd_:.3f}{'':>13} {seed_repr:>20s}")

print()
if missing:
    print(f"⚠️ {len(missing)} runs missing test_result.json:")
    for m in missing:
        print(f"    {m}")
else:
    print("✅ All 12 runs have test_result.json — sprint 2 complete.")
# Out:
# === FQL head-to-head on SAC tier datasets (test 100 ep × 3 seed) ===
#
# tier         FQL α_bc=1 (mean ± std)                  seeds
# ----------------------------------------------------------------------
# random       0.000 ± 0.000                             0.000
# medium       0.733 ± 0.000                             0.733
# mexp         0.900 ± 0.000                             0.900
# expert       0.900 ± 0.000                             0.900
#
# ✅ All 12 runs have test_result.json — sprint 2 complete.

# %% [markdown]
# ## 7. Next steps（sprint 2 完成后）
#
# 1. **Paired bootstrap analysis（本地 + sprint 1）**：合并 sprint 1 (24 ReBRAC) + sprint 2 (12 FQL) = 36 run 的 test_result.json，对 (tier × algo) 矩阵跑 paired bootstrap 1000 resample CI。重点对位：
#    - expert ↔ FQL P2 E-uni（FQL vs ReBRAC β1=1 paired CI of Δ）
#    - mexp ↔ FQL P2 M-uni-noise
#    - medium ↔ FQL P2 M-multi-mix
# 2. **Finding 候选 2 判定**：在 expert tier, FQL distill_α_bc=1.0 vs ReBRAC β1=1 paired Δ 的 95% CI 若跨 0 → 复现 FQL P2 C-1 RESCUE-FAIL；CI 显著 < 0 → FQL 在 SAC clean expert 上更差（强化 paper 1 结论）。
# 3. **结果回收**：本 notebook 跑完结果落 `_completed.ipynb` 副本 commit 进 git 作实验记录（参考 audit / collection completed 模式）。
