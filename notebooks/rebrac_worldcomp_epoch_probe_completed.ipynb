# %%
# !lscpu
# Out:
# Architecture:                x86_64
#   CPU op-mode(s):            32-bit, 64-bit
#   Address sizes:             46 bits physical, 48 bits virtual
#   Byte Order:                Little Endian
# CPU(s):                      12
#   On-line CPU(s) list:       0-11
# Vendor ID:                   GenuineIntel
#   Model name:                Intel(R) Xeon(R) CPU @ 2.20GHz
#     CPU family:              6
#     Model:                   85
#     Thread(s) per core:      2
#     Core(s) per socket:      6
#     Socket(s):               1
#     Stepping:                7
#     BogoMIPS:                4400.45
#     Flags:                   fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pg
#                              e mca cmov pat pse36 clflush mmx fxsr sse sse2 ss h
#                              t syscall nx pdpe1gb rdtscp lm constant_tsc rep_goo
#                              d nopl xtopology nonstop_tsc cpuid tsc_known_freq p
#                              ni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2ap
#                              ic movbe popcnt aes xsave avx f16c rdrand hyperviso
#                              r lahf_lm abm 3dnowprefetch ssbd ibrs ibpb stibp ib
#                              rs_enhanced fsgsbase tsc_adjust bmi1 hle avx2 smep
#                              bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed a
#                              dx smap clflushopt clwb avx512cd avx512bw avx512vl
#                              xsaveopt xsavec xgetbv1 xsaves arat avx512_vnni md_
#                              clear arch_capabilities
# Virtualization features:
#   Hypervisor vendor:         KVM
#   Virtualization type:       full
# Caches (sum of all):
#   L1d:                       192 KiB (6 instances)
#   L1i:                       192 KiB (6 instances)
#   L2:                        6 MiB (6 instances)
#   L3:                        38.5 MiB (1 instance)
# NUMA:
#   NUMA node(s):              1
#   NUMA node0 CPU(s):         0-11
# Vulnerabilities:
#   Gather data sampling:      Not affected
#   Indirect target selection: Vulnerable
#   Itlb multihit:             Not affected
#   L1tf:                      Not affected
#   Mds:                       Not affected
#   Meltdown:                  Not affected
#   Mmio stale data:           Vulnerable
#   Reg file data sampling:    Not affected
#   Retbleed:                  Vulnerable
#   Spec rstack overflow:      Not affected
#   Spec store bypass:         Vulnerable
#   Spectre v1:                Vulnerable: __user pointer sanitization and usercop
#                              y barriers only; no swapgs barriers
#   Spectre v2:                Vulnerable; IBPB: disabled; STIBP: disabled; PBRSB-
#                              eIBRS: Vulnerable; BHI: Vulnerable
#   Srbds:                     Not affected
#   Tsa:                       Not affected
#   Tsx async abort:           Vulnerable
#   Vmscape:                   Not affected

# %%
# !nvidia-smi
# Out:
# Sat Apr 25 03:59:17 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA L4                      Off |   00000000:00:03.0 Off |                    0 |
# | N/A   40C    P8             12W /   72W |       0MiB /  23034MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
import torch
print(f"PyTorch: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"cuDNN version: {torch.backends.cudnn.version()}")
# Out:
# PyTorch: 2.10.0+cu128
# CUDA available: True
# cuDNN version: 91002

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/"MyDrive"/"Colab Notebooks"/"new_offRL"/"rl_v2_5"
# Out:
# /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5

# %% [markdown]
# # ReBRAC Stage D Phase 1 — worldcomp epoch probe
#
# **目的**：在启动 Stage D Phase 1 deployable formal 之前，确认 `TRAIN_EPOCHS` 在 `worldcomp-1000` 数据上的合适值。`crosscomp` 上 Stage B0 已经验证过 `TRAIN_EPOCHS=64` 够用，但 `worldcomp` 数据的瓶颈性质不同（teacher 不是 deployable，critic penalty 的 next_actions target 可能更 noisy），有必要在 worldcomp 数据上单独验证。
#
# **方法**：复用 Stage B0 的 "长训读中间 ckpt" 思路——训一次 128 epoch，每 8 epoch 保存 ckpt，每个 ckpt 上跑 val 拿到 16 个 val 点。**只跑 deployable 轨道**，因为 epoch 选择是为了让训练充分（不依赖于 actor 是否看到 privileged obs）。
#
# **实验 scope**：
#
# | 轴 | 配置 | 说明 |
# |---|---|---|
# | β1 / β2 | `4.0 / 2.0` | Stage C 锁定的 finalist，Stage D 不再扫超参 |
# | dataset | `worldcomp-1000` | Stage D 的核心 dataset |
# | seeds | `42 43` | 只用 2 seed；epoch peak 不需要精确点估，需要的是 "≤64 / ∈(64,96] / >96" 三档判定 |
# | TRAIN_EPOCHS | `128` | 产出 16 个 ckpt（每 8 epoch 一个） |
# | manifest | val=40 / test=40 | 与 Stage B0 协议一致；Stage D formal 才升 test=100 |
# | 轨道 | deployable | privileged-critic 不在 epoch probe 阶段做（参见 plan §6.5.2 Step 1） |
#
# **预算**：1 cell × 1 dataset × 2 seed = 2 个 run，约 `1/3` 个 deployable formal 的代价。
#
# **输出树**：刻意与 Stage D formal 隔离，避免 ckpt / 结果交叉污染：
# - `checkpoints/offline/rebrac/worldcomp_epoch_probe/`
# - `results/offline/rebrac/worldcomp_epoch_probe/`
#
# **判据**（驱动 Stage D Phase 1 deployable formal 的 `TRAIN_EPOCHS` 决策）：
#
# | 观察 | 决策 |
# |---|---|
# | 两 seed 的 val peak epoch 都 ≤ 64 | Stage D Phase 1 取 `TRAIN_EPOCHS=64` |
# | 任一 seed 的 peak epoch ∈ (64, 96] | Stage D Phase 1 取 `TRAIN_EPOCHS=96`（对齐 TD3BC worldcomp teacher-gap 预算） |
# | 任一 seed 的 peak epoch > 96 | Stage D Phase 1 暂停，回查 worldcomp 训练动力学（critic penalty 与 noisy teacher target 的相互作用） |

# %% [markdown]
# ## 0. 环境配置

# %%
import os

# —— 通用（与其它 ReBRAC / TD3BC 实验一致）——
os.environ["PYTHON_BIN"]         = "python3"
os.environ["DEVICE"]             = "cuda"
os.environ["EVAL_WORKERS"]       = "6"
os.environ["EVAL_WORKER_DEVICE"] = "cpu"

# —— Stage D 在 worldcomp 上跑，覆盖 driver 默认（默认是 worldcomp）——
# DATASET_POLICY=worldcomp 已经是 teacher-gap driver 默认，这里不需要再设。

# —— Phase 1 epoch probe 网格点（覆盖 driver 默认）——
os.environ["EPOCH_PROBE_SEEDS"]                       = "42 43"
os.environ["EPOCH_PROBE_TRAIN_EPOCHS"]                = "128"
os.environ["EPOCH_PROBE_CHECKPOINT_EVERY_EPOCHS"]     = "8"
os.environ["EPOCH_PROBE_VAL_MANIFEST_EPISODES"]       = "40"
os.environ["EPOCH_PROBE_TEST_MANIFEST_EPISODES"]      = "40"

# —— Stage C 锁定的 finalist（Stage D 不扫超参）——
os.environ["ACTOR_PENALTY_COEF"]  = "4.0"
os.environ["CRITIC_PENALTY_COEF"] = "2.0"

# 其余（DATASET_POLICY=worldcomp, DATASET_EPISODES_VALUE=1000,
# BENCHMARK_KEY=single_u10_cross_tgt15, PROBE_LAYOUT=s0,
# HISTORY_LENGTH=4, TASK_GEOMETRY=cross_stream, TARGET_SPEED=1.5,
# OBJECTIVE=efficiency_v2, SAMPLING_MODE=shuffle_no_replacement,
# BATCH_SIZE=256）使用 driver 默认值。

# %% [markdown]
# ## 1. 生成 val / test manifest
#
# 只跑一次。已经存在的文件会被跳过。

# %%
os.environ["MODE"] = "epoch_probe_manifests"
# !bash scripts/run_offline_rebrac_worldcomp_teacher_gap.sh
# Out:
# [cmd] env MODE=manifests PYTHON_BIN=python3 DEVICE=cuda BENCHMARK_KEY=single_u10_cross_tgt15 FLOW_PATH=wake_data/wake_v8_U1p00_Re150_D12p00_dx0p60_Ti5pct_1200f_roi.npy TASK_GEOMETRY=cross_stream TARGET_SPEED=1.5 OBJECTIVE=efficiency_v2 PROBE_LAYOUT=s0 HISTORY_LENGTH=4 DATASET_POLICY=worldcomp DATASET_EPISODES=1000 DATASET_SEED=0 COLLECT_WORKERS=8 ACTOR_PENALTY_COEFS=4.0 CRITIC_PENALTY_COEFS=2.0 BATCH_SIZE=256 DROP_LAST_BATCH=0 SAMPLING_MODE=shuffle_no_replacement HIDDEN_DIM=256 NUM_HIDDEN_LAYERS=3 ACTOR_LR=3e-4 CRITIC_LR=3e-4 GAMMA=0.99 TAU=0.005 POLICY_NOISE=0.2 NOISE_CLIP=0.5 POLICY_FREQ=2 GRAD_CLIP_NORM=10.0 NORMALIZER_EPS=1e-3 LOG_EVERY=1000 TRAIN_METRICS_WINDOW_FRACTION=0.25 EVAL_WORKERS=6 EVAL_WORKER_DEVICE=cpu VALIDATION_SEED=123 TEST_SEED=456 FORCE_REEVAL=0 SEEDS=42 43 TRAIN_EPOCHS=128 CHECKPOINT_EVERY_EPOCHS=8 VAL_MANIFEST_EPISODES=40 TEST_MANIFEST_EPISODES=40 MANIFEST_ROOT=benchmarks/offline_rebrac_worldcomp_epoch_probe CHECKPOINT_ROOT=checkpoints/offline/rebrac/worldcomp_epoch_probe RESULTS_ROOT=results/offline/rebrac/worldcomp_epoch_probe USE_ASYMMETRIC_CRITIC=0 bash scripts/run_offline_rebrac_screen.sh
#
# [cmd] python3 -m scripts.generate_standard_benchmarks --benchmarks single_u10_cross_tgt15 --episodes 40 --output-dir benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40
# [done] single_u10_cross_tgt15 -> benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.generate_standard_benchmarks --benchmarks single_u10_cross_tgt15 --episodes 40 --output-dir benchmarks/offline_rebrac_worldcomp_epoch_probe/test_40
# [done] single_u10_cross_tgt15 -> benchmarks/offline_rebrac_worldcomp_epoch_probe/test_40/single_u10_cross_tgt15.json

# %% [markdown]
# ## 2. 收集 worldcomp-1000 离线数据
#
# 如果之前 TD3BC worldcomp teacher-gap 已经跑过 collect 生成了 `offline_data/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000`，这步会打印 `[skip] dataset exists` 并跳过。否则会用 `worldcomp` baseline policy 跑 1000 episodes 的数据收集。

# %%
os.environ["MODE"] = "epoch_probe_collect"
# !bash scripts/run_offline_rebrac_worldcomp_teacher_gap.sh
# Out:
# [cmd] env MODE=collect PYTHON_BIN=python3 DEVICE=cuda BENCHMARK_KEY=single_u10_cross_tgt15 FLOW_PATH=wake_data/wake_v8_U1p00_Re150_D12p00_dx0p60_Ti5pct_1200f_roi.npy TASK_GEOMETRY=cross_stream TARGET_SPEED=1.5 OBJECTIVE=efficiency_v2 PROBE_LAYOUT=s0 HISTORY_LENGTH=4 DATASET_POLICY=worldcomp DATASET_EPISODES=1000 DATASET_SEED=0 COLLECT_WORKERS=8 ACTOR_PENALTY_COEFS=4.0 CRITIC_PENALTY_COEFS=2.0 BATCH_SIZE=256 DROP_LAST_BATCH=0 SAMPLING_MODE=shuffle_no_replacement HIDDEN_DIM=256 NUM_HIDDEN_LAYERS=3 ACTOR_LR=3e-4 CRITIC_LR=3e-4 GAMMA=0.99 TAU=0.005 POLICY_NOISE=0.2 NOISE_CLIP=0.5 POLICY_FREQ=2 GRAD_CLIP_NORM=10.0 NORMALIZER_EPS=1e-3 LOG_EVERY=1000 TRAIN_METRICS_WINDOW_FRACTION=0.25 EVAL_WORKERS=6 EVAL_WORKER_DEVICE=cpu VALIDATION_SEED=123 TEST_SEED=456 FORCE_REEVAL=0 SEEDS=42 43 TRAIN_EPOCHS=128 CHECKPOINT_EVERY_EPOCHS=8 VAL_MANIFEST_EPISODES=40 TEST_MANIFEST_EPISODES=40 MANIFEST_ROOT=benchmarks/offline_rebrac_worldcomp_epoch_probe CHECKPOINT_ROOT=checkpoints/offline/rebrac/worldcomp_epoch_probe RESULTS_ROOT=results/offline/rebrac/worldcomp_epoch_probe USE_ASYMMETRIC_CRITIC=0 bash scripts/run_offline_rebrac_screen.sh
#
# [cmd] python3 -m scripts.collect_offline_data --policy worldcomp --flow wake_data/wake_v8_U1p00_Re150_D12p00_dx0p60_Ti5pct_1200f_roi.npy --probe-layout s0 --history-length 4 --task-geometry cross_stream --target-speed 1.5 --objective efficiency_v2 --episodes 1000 --seed 0 --num-workers 8 --output-dir offline_data/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000
# [collect] ep=125/1000 transitions=12888 success_rate=96.00% elapsed=164.5s
# [collect] ep=250/1000 transitions=26386 success_rate=97.60% elapsed=178.6s
# [collect] ep=375/1000 transitions=39197 success_rate=96.00% elapsed=178.6s
# [collect] ep=500/1000 transitions=52476 success_rate=96.00% elapsed=216.0s
# [collect] ep=625/1000 transitions=65183 success_rate=95.20% elapsed=216.0s
# [collect] ep=750/1000 transitions=78533 success_rate=95.47% elapsed=216.0s
# [collect] ep=875/1000 transitions=91399 success_rate=95.66% elapsed=216.0s
# [collect] ep=1000/1000 transitions=104360 success_rate=95.80% elapsed=216.0s
#
# [done] Saved 104360 transitions to offline_data/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/transitions.npz
#   policy=worldcomp  obs_dim=40  action_dim=2
#   episodes=1000  success_rate=95.80%
#   mean_return=27.36 +/- 28.88

# %% [markdown]
# ## 3. 全流程：train → validate（每个 ckpt）→ select → test → summarize
#
# 这一步产出 2 个 run，每个 run 16 个 ckpt，每个 ckpt 在 val manifest 上评估 1 次。耗时主体是 train（128 epoch × 2 seed）。

# %%
# 跑全部 epoch_probe 流程：train + validate + test + summarize
for mode in ["epoch_probe_train", "epoch_probe_validate", "epoch_probe_test", "epoch_probe_summarize"]:
    os.environ["MODE"] = mode
    # !bash scripts/run_offline_rebrac_worldcomp_teacher_gap.sh
# Out:
# [cmd] env MODE=train PYTHON_BIN=python3 DEVICE=cuda BENCHMARK_KEY=single_u10_cross_tgt15 FLOW_PATH=wake_data/wake_v8_U1p00_Re150_D12p00_dx0p60_Ti5pct_1200f_roi.npy TASK_GEOMETRY=cross_stream TARGET_SPEED=1.5 OBJECTIVE=efficiency_v2 PROBE_LAYOUT=s0 HISTORY_LENGTH=4 DATASET_POLICY=worldcomp DATASET_EPISODES=1000 DATASET_SEED=0 COLLECT_WORKERS=8 ACTOR_PENALTY_COEFS=4.0 CRITIC_PENALTY_COEFS=2.0 BATCH_SIZE=256 DROP_LAST_BATCH=0 SAMPLING_MODE=shuffle_no_replacement HIDDEN_DIM=256 NUM_HIDDEN_LAYERS=3 ACTOR_LR=3e-4 CRITIC_LR=3e-4 GAMMA=0.99 TAU=0.005 POLICY_NOISE=0.2 NOISE_CLIP=0.5 POLICY_FREQ=2 GRAD_CLIP_NORM=10.0 NORMALIZER_EPS=1e-3 LOG_EVERY=1000 TRAIN_METRICS_WINDOW_FRACTION=0.25 EVAL_WORKERS=6 EVAL_WORKER_DEVICE=cpu VALIDATION_SEED=123 TEST_SEED=456 FORCE_REEVAL=0 SEEDS=42 43 TRAIN_EPOCHS=128 CHECKPOINT_EVERY_EPOCHS=8 VAL_MANIFEST_EPISODES=40 TEST_MANIFEST_EPISODES=40 MANIFEST_ROOT=benchmarks/offline_rebrac_worldcomp_epoch_probe CHECKPOINT_ROOT=checkpoints/offline/rebrac/worldcomp_epoch_probe RESULTS_ROOT=results/offline/rebrac/worldcomp_epoch_probe USE_ASYMMETRIC_CRITIC=0 bash scripts/run_offline_rebrac_screen.sh
# [skip] manifest exists: benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json
# [skip] manifest exists: benchmarks/offline_rebrac_worldcomp_epoch_probe/test_40/single_u10_cross_tgt15.json
# [skip] dataset exists: offline_data/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/transitions.npz
#
# [cmd] python3 -m scripts.train_offline --algo rebrac --offline-data offline_data/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/transitions.npz --flow wake_data/wake_v8_U1p00_Re150_D12p00_dx0p60_Ti5pct_1200f_roi.npy --manifest benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json --probe-layout s0 --history-length 4 --task-geometry cross_stream --target-speed 1.5 --objective efficiency_v2 --sampling-mode shuffle_no_replacement --num-epochs 128 --total-steps 52224 --batch-size 256 --hidden-dim 256 --num-hidden-layers 3 --actor-lr 3e-4 --critic-lr 3e-4 --gamma 0.99 --tau 0.005 --actor-penalty-coef 4.0 --critic-penalty-coef 2.0 --policy-noise 0.2 --noise-clip 0.5 --policy-freq 2 --grad-clip-norm 10.0 --normalizer-eps 1e-3 --eval-every 0 --checkpoint-every 3264 --skip-final-eval --log-every 1000 --critic-layernorm --no-actor-layernorm --save-dir checkpoints/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_42 --seed 42 --device cuda
# [offline] algo=rebrac transitions=104360 obs_dim=40 action_dim=2 protocol=deployable tensor_replay=on eval_workers=1 sampling=shuffle_no_replacement total_steps=52224
# [train] step=1 epoch=1 epoch_step=1 q=-0.965 critic=89.871 actor=5.424 bc=1.106 lambda=1.036 critic_pen=1.223
# [train] step=1000 epoch=3 epoch_step=184 q=-2.560 critic=20.424 actor=0.538 bc=0.022 lambda=0.177 critic_pen=0.097
# [train] step=2000 epoch=5 epoch_step=368 q=-4.087 critic=2.241 actor=0.588 bc=0.023 lambda=0.122 critic_pen=0.092
# [train] step=3000 epoch=8 epoch_step=144 q=1.441 critic=7.315 actor=0.031 bc=0.032 lambda=0.066 critic_pen=0.099
# [train] step=4000 epoch=10 epoch_step=328 q=3.800 critic=3.814 actor=-0.146 bc=0.011 lambda=0.050 critic_pen=0.096
# [train] step=5000 epoch=13 epoch_step=104 q=2.748 critic=3.118 actor=-0.017 bc=0.028 lambda=0.047 critic_pen=0.086
# [train] step=6000 epoch=15 epoch_step=288 q=4.834 critic=4.239 actor=-0.155 bc=0.010 lambda=0.040 critic_pen=0.088
# [train] step=7000 epoch=18 epoch_step=64 q=5.976 critic=3.166 actor=-0.207 bc=0.002 lambda=0.036 critic_pen=0.074
# [train] step=8000 epoch=20 epoch_step=248 q=9.787 critic=2.786 actor=-0.244 bc=0.016 lambda=0.031 critic_pen=0.090
# [train] step=9000 epoch=23 epoch_step=24 q=4.596 critic=1.603 actor=-0.118 bc=0.008 lambda=0.033 critic_pen=0.073
# [train] step=10000 epoch=25 epoch_step=208 q=10.965 critic=2.195 actor=-0.300 bc=0.001 lambda=0.028 critic_pen=0.079
# [train] step=11000 epoch=27 epoch_step=392 q=9.526 critic=1.727 actor=-0.198 bc=0.014 lambda=0.027 critic_pen=0.067
# [train] step=12000 epoch=30 epoch_step=168 q=11.729 critic=2.133 actor=-0.218 bc=0.021 lambda=0.026 critic_pen=0.089
# [train] step=13000 epoch=32 epoch_step=352 q=11.881 critic=1.660 actor=-0.265 bc=0.009 lambda=0.025 critic_pen=0.083
# [train] step=14000 epoch=35 epoch_step=128 q=13.127 critic=3.382 actor=-0.304 bc=0.002 lambda=0.024 critic_pen=0.073
# [train] step=15000 epoch=37 epoch_step=312 q=15.200 critic=1.444 actor=-0.335 bc=0.004 lambda=0.023 critic_pen=0.068
# [train] step=16000 epoch=40 epoch_step=88 q=9.471 critic=1.179 actor=-0.161 bc=0.018 lambda=0.025 critic_pen=0.072
# [train] step=17000 epoch=42 epoch_step=272 q=21.256 critic=1.815 actor=-0.439 bc=0.001 lambda=0.021 critic_pen=0.088
# [train] step=18000 epoch=45 epoch_step=48 q=13.387 critic=1.456 actor=-0.295 bc=0.000 lambda=0.022 critic_pen=0.087
# [train] step=19000 epoch=47 epoch_step=232 q=15.520 critic=2.346 actor=-0.331 bc=0.003 lambda=0.022 critic_pen=0.072
# [train] step=20000 epoch=50 epoch_step=8 q=11.003 critic=1.993 actor=-0.216 bc=0.007 lambda=0.022 critic_pen=0.083
# [train] step=21000 epoch=52 epoch_step=192 q=22.016 critic=2.633 actor=-0.433 bc=0.006 lambda=0.021 critic_pen=0.081
# [train] step=22000 epoch=54 epoch_step=376 q=16.753 critic=2.447 actor=-0.336 bc=0.002 lambda=0.021 critic_pen=0.077
# [train] step=23000 epoch=57 epoch_step=152 q=15.454 critic=1.645 actor=-0.316 bc=0.000 lambda=0.021 critic_pen=0.081
# [train] step=24000 epoch=59 epoch_step=336 q=16.103 critic=2.802 actor=-0.314 bc=0.009 lambda=0.022 critic_pen=0.080
# [train] step=25000 epoch=62 epoch_step=112 q=22.352 critic=2.311 actor=-0.454 bc=0.001 lambda=0.020 critic_pen=0.076
# [train] step=26000 epoch=64 epoch_step=296 q=9.693 critic=2.907 actor=-0.110 bc=0.028 lambda=0.023 critic_pen=0.083
# [train] step=27000 epoch=67 epoch_step=72 q=17.900 critic=3.279 actor=-0.373 bc=0.000 lambda=0.021 critic_pen=0.080
# [train] step=28000 epoch=69 epoch_step=256 q=23.335 critic=5.446 actor=-0.495 bc=0.001 lambda=0.021 critic_pen=0.085
# [train] step=29000 epoch=72 epoch_step=32 q=18.767 critic=3.262 actor=-0.290 bc=0.026 lambda=0.021 critic_pen=0.070
# [train] step=30000 epoch=74 epoch_step=216 q=14.603 critic=3.648 actor=-0.304 bc=0.003 lambda=0.021 critic_pen=0.081
# [train] step=31000 epoch=76 epoch_step=400 q=19.258 critic=3.239 actor=-0.414 bc=0.001 lambda=0.022 critic_pen=0.076
# [train] step=32000 epoch=79 epoch_step=176 q=16.525 critic=5.118 actor=-0.395 bc=0.001 lambda=0.024 critic_pen=0.068
# [train] step=33000 epoch=81 epoch_step=360 q=22.214 critic=4.818 actor=-0.514 bc=0.001 lambda=0.023 critic_pen=0.068
# [train] step=34000 epoch=84 epoch_step=136 q=20.728 critic=4.167 actor=-0.452 bc=0.001 lambda=0.022 critic_pen=0.065
# [train] step=35000 epoch=86 epoch_step=320 q=23.692 critic=5.241 actor=-0.558 bc=0.001 lambda=0.024 critic_pen=0.078
# [train] step=36000 epoch=89 epoch_step=96 q=20.375 critic=4.431 actor=-0.441 bc=0.009 lambda=0.023 critic_pen=0.083
# [train] step=37000 epoch=91 epoch_step=280 q=18.694 critic=4.241 actor=-0.416 bc=0.004 lambda=0.023 critic_pen=0.082
# [train] step=38000 epoch=94 epoch_step=56 q=21.004 critic=8.326 actor=-0.482 bc=0.001 lambda=0.023 critic_pen=0.067
# [train] step=39000 epoch=96 epoch_step=240 q=20.224 critic=4.788 actor=-0.470 bc=0.002 lambda=0.024 critic_pen=0.073
# [train] step=40000 epoch=99 epoch_step=16 q=24.699 critic=3.790 actor=-0.566 bc=0.003 lambda=0.023 critic_pen=0.070
# [train] step=41000 epoch=101 epoch_step=200 q=26.518 critic=2.919 actor=-0.564 bc=0.007 lambda=0.022 critic_pen=0.083
# [train] step=42000 epoch=103 epoch_step=384 q=22.145 critic=3.123 actor=-0.502 bc=0.004 lambda=0.023 critic_pen=0.094
# [train] step=43000 epoch=106 epoch_step=160 q=23.321 critic=3.072 actor=-0.587 bc=0.001 lambda=0.025 critic_pen=0.077
# [train] step=44000 epoch=108 epoch_step=344 q=25.213 critic=2.699 actor=-0.633 bc=0.001 lambda=0.025 critic_pen=0.070
# [train] step=45000 epoch=111 epoch_step=120 q=23.160 critic=5.049 actor=-0.498 bc=0.017 lambda=0.024 critic_pen=0.092
# [train] step=46000 epoch=113 epoch_step=304 q=22.775 critic=2.604 actor=-0.545 bc=0.001 lambda=0.024 critic_pen=0.104
# [train] step=47000 epoch=116 epoch_step=80 q=28.365 critic=2.818 actor=-0.563 bc=0.019 lambda=0.023 critic_pen=0.088
# [train] step=48000 epoch=118 epoch_step=264 q=23.416 critic=3.938 actor=-0.554 bc=0.008 lambda=0.025 critic_pen=0.078
# [train] step=49000 epoch=121 epoch_step=40 q=21.866 critic=2.640 actor=-0.555 bc=0.004 lambda=0.026 critic_pen=0.096
# [train] step=50000 epoch=123 epoch_step=224 q=22.390 critic=2.507 actor=-0.577 bc=0.002 lambda=0.026 critic_pen=0.076
# [train] step=51000 epoch=125 epoch_step=408 q=24.186 critic=2.575 actor=-0.629 bc=0.000 lambda=0.026 critic_pen=0.075
# [train] step=52000 epoch=128 epoch_step=184 q=28.140 critic=2.955 actor=-0.664 bc=0.002 lambda=0.024 critic_pen=0.084
#
# [cmd] python3 -m scripts.train_offline --algo rebrac --offline-data offline_data/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/transitions.npz --flow wake_data/wake_v8_U1p00_Re150_D12p00_dx0p60_Ti5pct_1200f_roi.npy --manifest benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json --probe-layout s0 --history-length 4 --task-geometry cross_stream --target-speed 1.5 --objective efficiency_v2 --sampling-mode shuffle_no_replacement --num-epochs 128 --total-steps 52224 --batch-size 256 --hidden-dim 256 --num-hidden-layers 3 --actor-lr 3e-4 --critic-lr 3e-4 --gamma 0.99 --tau 0.005 --actor-penalty-coef 4.0 --critic-penalty-coef 2.0 --policy-noise 0.2 --noise-clip 0.5 --policy-freq 2 --grad-clip-norm 10.0 --normalizer-eps 1e-3 --eval-every 0 --checkpoint-every 3264 --skip-final-eval --log-every 1000 --critic-layernorm --no-actor-layernorm --save-dir checkpoints/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_43 --seed 43 --device cuda
# [offline] algo=rebrac transitions=104360 obs_dim=40 action_dim=2 protocol=deployable tensor_replay=on eval_workers=1 sampling=shuffle_no_replacement total_steps=52224
# [train] step=1 epoch=1 epoch_step=1 q=-0.697 critic=88.467 actor=5.503 bc=1.126 lambda=1.434 critic_pen=1.204
# [train] step=1000 epoch=3 epoch_step=184 q=-1.545 critic=20.699 actor=0.361 bc=0.028 lambda=0.160 critic_pen=0.118
# [train] step=2000 epoch=5 epoch_step=368 q=-1.690 critic=15.907 actor=0.238 bc=0.014 lambda=0.107 critic_pen=0.077
# [train] step=3000 epoch=8 epoch_step=144 q=-1.469 critic=3.356 actor=0.160 bc=0.010 lambda=0.081 critic_pen=0.085
# [train] step=4000 epoch=10 epoch_step=328 q=1.967 critic=2.620 actor=-0.040 bc=0.018 lambda=0.056 critic_pen=0.093
# [train] step=5000 epoch=13 epoch_step=104 q=1.981 critic=3.806 actor=-0.088 bc=0.003 lambda=0.050 critic_pen=0.073
# [train] step=6000 epoch=15 epoch_step=288 q=2.356 critic=2.535 actor=0.013 bc=0.028 lambda=0.042 critic_pen=0.078
# [train] step=7000 epoch=18 epoch_step=64 q=6.041 critic=2.431 actor=-0.170 bc=0.012 lambda=0.036 critic_pen=0.082
# [train] step=8000 epoch=20 epoch_step=248 q=8.984 critic=2.726 actor=-0.153 bc=0.032 lambda=0.031 critic_pen=0.089
# [train] step=9000 epoch=23 epoch_step=24 q=8.778 critic=1.580 actor=-0.202 bc=0.014 lambda=0.029 critic_pen=0.088
# [train] step=10000 epoch=25 epoch_step=208 q=7.988 critic=2.186 actor=-0.228 bc=0.002 lambda=0.030 critic_pen=0.074
# [train] step=11000 epoch=27 epoch_step=392 q=10.588 critic=1.710 actor=-0.285 bc=0.001 lambda=0.027 critic_pen=0.075
# [train] step=12000 epoch=30 epoch_step=168 q=12.073 critic=2.171 actor=-0.300 bc=0.002 lambda=0.026 critic_pen=0.077
# [train] step=13000 epoch=32 epoch_step=352 q=14.668 critic=2.277 actor=-0.344 bc=0.004 lambda=0.024 critic_pen=0.079
# [train] step=14000 epoch=35 epoch_step=128 q=15.324 critic=1.660 actor=-0.344 bc=0.004 lambda=0.023 critic_pen=0.086
# [train] step=15000 epoch=37 epoch_step=312 q=10.988 critic=1.504 actor=-0.261 bc=0.001 lambda=0.024 critic_pen=0.079
# [train] step=16000 epoch=40 epoch_step=88 q=20.112 critic=1.455 actor=-0.428 bc=0.002 lambda=0.022 critic_pen=0.074
# [train] step=17000 epoch=42 epoch_step=272 q=10.343 critic=1.606 actor=-0.240 bc=0.003 lambda=0.024 critic_pen=0.088
# [train] step=18000 epoch=45 epoch_step=48 q=13.896 critic=1.347 actor=-0.304 bc=0.001 lambda=0.022 critic_pen=0.084
# [train] step=19000 epoch=47 epoch_step=232 q=14.689 critic=2.029 actor=-0.334 bc=0.000 lambda=0.023 critic_pen=0.074
# [train] step=20000 epoch=50 epoch_step=8 q=15.536 critic=1.808 actor=-0.312 bc=0.006 lambda=0.022 critic_pen=0.071
# [train] step=21000 epoch=52 epoch_step=192 q=14.148 critic=1.764 actor=-0.308 bc=0.003 lambda=0.022 critic_pen=0.083
# [train] step=22000 epoch=54 epoch_step=376 q=20.345 critic=2.040 actor=-0.349 bc=0.019 lambda=0.021 critic_pen=0.087
# [train] step=23000 epoch=57 epoch_step=152 q=17.148 critic=3.448 actor=-0.270 bc=0.028 lambda=0.022 critic_pen=0.089
# [train] step=24000 epoch=59 epoch_step=336 q=18.475 critic=3.093 actor=-0.392 bc=0.003 lambda=0.022 critic_pen=0.081
# [train] step=25000 epoch=62 epoch_step=112 q=14.556 critic=6.005 actor=-0.310 bc=0.000 lambda=0.021 critic_pen=0.079
# [train] step=26000 epoch=64 epoch_step=296 q=14.777 critic=2.610 actor=-0.272 bc=0.016 lambda=0.023 critic_pen=0.080
# [train] step=27000 epoch=67 epoch_step=72 q=16.619 critic=3.571 actor=-0.318 bc=0.013 lambda=0.022 critic_pen=0.079
# [train] step=28000 epoch=69 epoch_step=256 q=20.262 critic=3.205 actor=-0.356 bc=0.022 lambda=0.022 critic_pen=0.079
# [train] step=29000 epoch=72 epoch_step=32 q=21.382 critic=3.517 actor=-0.453 bc=0.002 lambda=0.022 critic_pen=0.074
# [train] step=30000 epoch=74 epoch_step=216 q=21.938 critic=7.511 actor=-0.447 bc=0.004 lambda=0.021 critic_pen=0.069
# [train] step=31000 epoch=76 epoch_step=400 q=19.259 critic=3.660 actor=-0.400 bc=0.005 lambda=0.022 critic_pen=0.089
# [train] step=32000 epoch=79 epoch_step=176 q=23.466 critic=4.200 actor=-0.424 bc=0.023 lambda=0.022 critic_pen=0.088
# [train] step=33000 epoch=81 epoch_step=360 q=21.179 critic=4.771 actor=-0.467 bc=0.001 lambda=0.022 critic_pen=0.088
# [train] step=34000 epoch=84 epoch_step=136 q=13.980 critic=3.692 actor=-0.336 bc=0.001 lambda=0.024 critic_pen=0.083
# [train] step=35000 epoch=86 epoch_step=320 q=21.822 critic=6.756 actor=-0.501 bc=0.001 lambda=0.023 critic_pen=0.077
# [train] step=36000 epoch=89 epoch_step=96 q=24.540 critic=6.616 actor=-0.557 bc=0.005 lambda=0.024 critic_pen=0.100
# [train] step=37000 epoch=91 epoch_step=280 q=24.333 critic=4.366 actor=-0.549 bc=0.003 lambda=0.023 critic_pen=0.094
# [train] step=38000 epoch=94 epoch_step=56 q=25.529 critic=3.973 actor=-0.571 bc=0.002 lambda=0.023 critic_pen=0.068
# [train] step=39000 epoch=96 epoch_step=240 q=22.436 critic=4.777 actor=-0.562 bc=0.002 lambda=0.025 critic_pen=0.080
# [train] step=40000 epoch=99 epoch_step=16 q=22.775 critic=3.366 actor=-0.518 bc=0.001 lambda=0.023 critic_pen=0.085
# [train] step=41000 epoch=101 epoch_step=200 q=24.759 critic=3.946 actor=-0.608 bc=0.001 lambda=0.025 critic_pen=0.070
# [train] step=42000 epoch=103 epoch_step=384 q=21.251 critic=3.648 actor=-0.500 bc=0.007 lambda=0.025 critic_pen=0.085
# [train] step=43000 epoch=106 epoch_step=160 q=24.213 critic=3.093 actor=-0.520 bc=0.024 lambda=0.025 critic_pen=0.066
# [train] step=44000 epoch=108 epoch_step=344 q=25.852 critic=3.524 actor=-0.622 bc=0.002 lambda=0.024 critic_pen=0.080
# [train] step=45000 epoch=111 epoch_step=120 q=28.023 critic=2.795 actor=-0.685 bc=0.001 lambda=0.025 critic_pen=0.076
# [train] step=46000 epoch=113 epoch_step=304 q=27.883 critic=3.428 actor=-0.684 bc=0.001 lambda=0.025 critic_pen=0.101
# [train] step=47000 epoch=116 epoch_step=80 q=25.511 critic=3.124 actor=-0.632 bc=0.001 lambda=0.025 critic_pen=0.087
# [train] step=48000 epoch=118 epoch_step=264 q=27.096 critic=3.149 actor=-0.651 bc=0.001 lambda=0.024 critic_pen=0.079
# [train] step=49000 epoch=121 epoch_step=40 q=26.803 critic=3.153 actor=-0.632 bc=0.002 lambda=0.024 critic_pen=0.085
# [train] step=50000 epoch=123 epoch_step=224 q=25.025 critic=2.679 actor=-0.642 bc=0.004 lambda=0.026 critic_pen=0.070
# [train] step=51000 epoch=125 epoch_step=408 q=27.297 critic=3.371 actor=-0.703 bc=0.001 lambda=0.026 critic_pen=0.079
# [train] step=52000 epoch=128 epoch_step=184 q=26.553 critic=2.480 actor=-0.659 bc=0.006 lambda=0.026 critic_pen=0.095
#
# [cmd] env MODE=validate PYTHON_BIN=python3 DEVICE=cuda BENCHMARK_KEY=single_u10_cross_tgt15 FLOW_PATH=wake_data/wake_v8_U1p00_Re150_D12p00_dx0p60_Ti5pct_1200f_roi.npy TASK_GEOMETRY=cross_stream TARGET_SPEED=1.5 OBJECTIVE=efficiency_v2 PROBE_LAYOUT=s0 HISTORY_LENGTH=4 DATASET_POLICY=worldcomp DATASET_EPISODES=1000 DATASET_SEED=0 COLLECT_WORKERS=8 ACTOR_PENALTY_COEFS=4.0 CRITIC_PENALTY_COEFS=2.0 BATCH_SIZE=256 DROP_LAST_BATCH=0 SAMPLING_MODE=shuffle_no_replacement HIDDEN_DIM=256 NUM_HIDDEN_LAYERS=3 ACTOR_LR=3e-4 CRITIC_LR=3e-4 GAMMA=0.99 TAU=0.005 POLICY_NOISE=0.2 NOISE_CLIP=0.5 POLICY_FREQ=2 GRAD_CLIP_NORM=10.0 NORMALIZER_EPS=1e-3 LOG_EVERY=1000 TRAIN_METRICS_WINDOW_FRACTION=0.25 EVAL_WORKERS=6 EVAL_WORKER_DEVICE=cpu VALIDATION_SEED=123 TEST_SEED=456 FORCE_REEVAL=0 SEEDS=42 43 TRAIN_EPOCHS=128 CHECKPOINT_EVERY_EPOCHS=8 VAL_MANIFEST_EPISODES=40 TEST_MANIFEST_EPISODES=40 MANIFEST_ROOT=benchmarks/offline_rebrac_worldcomp_epoch_probe CHECKPOINT_ROOT=checkpoints/offline/rebrac/worldcomp_epoch_probe RESULTS_ROOT=results/offline/rebrac/worldcomp_epoch_probe USE_ASYMMETRIC_CRITIC=0 bash scripts/run_offline_rebrac_screen.sh
# [skip] manifest exists: benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_42 --agent-file agent_step_00003264.pt --manifest benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_42/agent_step_00003264.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 20.0%
# avg_return            : -85.30 +/- 78.05
# avg_safety_cost       : 11.605 +/- 5.759
# avg_time_s            : 57.09 +/- 17.06
# avg_time_s_success    : 44.33
# avg_energy            : 39763.83 +/- 11863.73
# avg_path_length_m     : 57.23 +/- 14.33
# avg_progress_ratio    : 0.657 +/- 0.285
# avg_path_efficiency   : 0.540 +/- 0.224
# termination           : {'out_of_bounds': 32, 'goal': 8}
# benchmark_manifest    : benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_42 --agent-file agent_step_00006528.pt --manifest benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_42/agent_step_00006528.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 40.0%
# avg_return            : -77.46 +/- 126.09
# avg_safety_cost       : 16.145 +/- 22.603
# avg_time_s            : 63.80 +/- 35.45
# avg_time_s_success    : 54.31
# avg_energy            : 45828.13 +/- 27721.87
# avg_path_length_m     : 60.60 +/- 23.63
# avg_progress_ratio    : 0.625 +/- 0.513
# avg_path_efficiency   : 0.540 +/- 0.292
# termination           : {'out_of_bounds': 24, 'goal': 16}
# benchmark_manifest    : benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_42 --agent-file agent_step_00009792.pt --manifest benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_42/agent_step_00009792.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 62.5%
# avg_return            : -51.56 +/- 150.94
# avg_safety_cost       : 14.953 +/- 22.610
# avg_time_s            : 66.08 +/- 44.43
# avg_time_s_success    : 53.79
# avg_energy            : 47598.16 +/- 34637.69
# avg_path_length_m     : 59.66 +/- 29.76
# avg_progress_ratio    : 0.696 +/- 0.614
# avg_path_efficiency   : 0.650 +/- 0.316
# termination           : {'out_of_bounds': 14, 'goal': 25, 'timeout': 1}
# benchmark_manifest    : benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_42 --agent-file agent_step_00013056.pt --manifest benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_42/agent_step_00013056.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 82.5%
# avg_return            : -3.98 +/- 109.29
# avg_safety_cost       : 9.577 +/- 14.272
# avg_time_s            : 57.48 +/- 31.14
# avg_time_s_success    : 52.35
# avg_energy            : 41138.15 +/- 24482.71
# avg_path_length_m     : 53.89 +/- 20.99
# avg_progress_ratio    : 0.815 +/- 0.421
# avg_path_efficiency   : 0.731 +/- 0.234
# termination           : {'out_of_bounds': 6, 'goal': 33, 'timeout': 1}
# benchmark_manifest    : benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_42 --agent-file agent_step_00016320.pt --manifest benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_42/agent_step_00016320.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 82.5%
# avg_return            : -5.53 +/- 106.44
# avg_safety_cost       : 9.302 +/- 9.904
# avg_time_s            : 58.58 +/- 30.92
# avg_time_s_success    : 53.18
# avg_energy            : 41870.76 +/- 24090.89
# avg_path_length_m     : 54.84 +/- 23.93
# avg_progress_ratio    : 0.827 +/- 0.394
# avg_path_efficiency   : 0.733 +/- 0.209
# termination           : {'goal': 33, 'timeout': 1, 'out_of_bounds': 6}
# benchmark_manifest    : benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_42 --agent-file agent_step_00019584.pt --manifest benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_42/agent_step_00019584.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 80.0%
# avg_return            : -10.24 +/- 100.50
# avg_safety_cost       : 9.422 +/- 8.326
# avg_time_s            : 59.40 +/- 29.08
# avg_time_s_success    : 55.58
# avg_energy            : 42312.38 +/- 22667.03
# avg_path_length_m     : 56.02 +/- 24.16
# avg_progress_ratio    : 0.821 +/- 0.407
# avg_path_efficiency   : 0.710 +/- 0.196
# termination           : {'goal': 32, 'out_of_bounds': 8}
# benchmark_manifest    : benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_42 --agent-file agent_step_00022848.pt --manifest benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_42/agent_step_00022848.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 80.0%
# avg_return            : 2.97 +/- 52.13
# avg_safety_cost       : 8.610 +/- 7.141
# avg_time_s            : 54.10 +/- 10.06
# avg_time_s_success    : 54.94
# avg_energy            : 38265.67 +/- 7162.21
# avg_path_length_m     : 51.68 +/- 6.18
# avg_progress_ratio    : 0.879 +/- 0.080
# avg_path_efficiency   : 0.740 +/- 0.111
# termination           : {'goal': 32, 'out_of_bounds': 8}
# benchmark_manifest    : benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_42 --agent-file agent_step_00026112.pt --manifest benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_42/agent_step_00026112.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 100.0%
# avg_return            : 30.85 +/- 20.86
# avg_safety_cost       : 6.633 +/- 7.867
# avg_time_s            : 53.05 +/- 10.23
# avg_time_s_success    : 53.05
# avg_energy            : 37598.89 +/- 7355.15
# avg_path_length_m     : 50.79 +/- 7.79
# avg_progress_ratio    : 0.907 +/- 0.004
# avg_path_efficiency   : 0.780 +/- 0.092
# termination           : {'goal': 40}
# benchmark_manifest    : benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_42 --agent-file agent_step_00029376.pt --manifest benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_42/agent_step_00029376.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 100.0%
# avg_return            : 31.43 +/- 22.04
# avg_safety_cost       : 6.699 +/- 8.837
# avg_time_s            : 52.72 +/- 10.75
# avg_time_s_success    : 52.72
# avg_energy            : 37465.79 +/- 7741.66
# avg_path_length_m     : 50.45 +/- 7.92
# avg_progress_ratio    : 0.907 +/- 0.004
# avg_path_efficiency   : 0.786 +/- 0.095
# termination           : {'goal': 40}
# benchmark_manifest    : benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_42 --agent-file agent_step_00032640.pt --manifest benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_42/agent_step_00032640.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 92.5%
# avg_return            : 23.15 +/- 37.14
# avg_safety_cost       : 7.114 +/- 8.751
# avg_time_s            : 52.19 +/- 9.83
# avg_time_s_success    : 52.48
# avg_energy            : 37131.50 +/- 7085.46
# avg_path_length_m     : 50.37 +/- 7.60
# avg_progress_ratio    : 0.901 +/- 0.023
# avg_path_efficiency   : 0.781 +/- 0.096
# termination           : {'goal': 37, 'out_of_bounds': 3}
# benchmark_manifest    : benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_42 --agent-file agent_step_00035904.pt --manifest benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_42/agent_step_00035904.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 90.0%
# avg_return            : 15.67 +/- 41.99
# avg_safety_cost       : 8.220 +/- 8.329
# avg_time_s            : 54.18 +/- 10.31
# avg_time_s_success    : 54.51
# avg_energy            : 38431.53 +/- 7450.93
# avg_path_length_m     : 51.54 +/- 7.38
# avg_progress_ratio    : 0.896 +/- 0.034
# avg_path_efficiency   : 0.758 +/- 0.096
# termination           : {'goal': 36, 'out_of_bounds': 4}
# benchmark_manifest    : benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_42 --agent-file agent_step_00039168.pt --manifest benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_42/agent_step_00039168.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 100.0%
# avg_return            : 33.23 +/- 20.91
# avg_safety_cost       : 5.808 +/- 7.921
# avg_time_s            : 51.93 +/- 10.27
# avg_time_s_success    : 51.93
# avg_energy            : 36898.65 +/- 7433.76
# avg_path_length_m     : 49.73 +/- 8.02
# avg_progress_ratio    : 0.907 +/- 0.004
# avg_path_efficiency   : 0.799 +/- 0.103
# termination           : {'goal': 40}
# benchmark_manifest    : benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_42 --agent-file agent_step_00042432.pt --manifest benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_42/agent_step_00042432.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 100.0%
# avg_return            : 33.75 +/- 19.41
# avg_safety_cost       : 5.929 +/- 6.550
# avg_time_s            : 51.66 +/- 9.56
# avg_time_s_success    : 51.66
# avg_energy            : 36808.13 +/- 6983.67
# avg_path_length_m     : 49.98 +/- 7.38
# avg_progress_ratio    : 0.907 +/- 0.004
# avg_path_efficiency   : 0.792 +/- 0.092
# termination           : {'goal': 40}
# benchmark_manifest    : benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_42 --agent-file agent_step_00045696.pt --manifest benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_42/agent_step_00045696.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 100.0%
# avg_return            : 33.80 +/- 20.68
# avg_safety_cost       : 5.755 +/- 6.999
# avg_time_s            : 51.67 +/- 10.16
# avg_time_s_success    : 51.67
# avg_energy            : 36738.06 +/- 7417.75
# avg_path_length_m     : 49.82 +/- 7.77
# avg_progress_ratio    : 0.907 +/- 0.004
# avg_path_efficiency   : 0.796 +/- 0.099
# termination           : {'goal': 40}
# benchmark_manifest    : benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_42 --agent-file agent_step_00048960.pt --manifest benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_42/agent_step_00048960.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 97.5%
# avg_return            : 30.70 +/- 26.39
# avg_safety_cost       : 5.883 +/- 7.060
# avg_time_s            : 51.70 +/- 9.50
# avg_time_s_success    : 51.82
# avg_energy            : 36764.06 +/- 6948.44
# avg_path_length_m     : 49.85 +/- 7.43
# avg_progress_ratio    : 0.906 +/- 0.010
# avg_path_efficiency   : 0.792 +/- 0.093
# termination           : {'goal': 39, 'out_of_bounds': 1}
# benchmark_manifest    : benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_42 --agent-file agent_step_00052224.pt --manifest benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_42/agent_step_00052224.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 100.0%
# avg_return            : 32.32 +/- 19.71
# avg_safety_cost       : 6.221 +/- 6.734
# avg_time_s            : 52.37 +/- 9.77
# avg_time_s_success    : 52.37
# avg_energy            : 37168.17 +/- 7087.69
# avg_path_length_m     : 50.15 +/- 7.37
# avg_progress_ratio    : 0.907 +/- 0.004
# avg_path_efficiency   : 0.789 +/- 0.092
# termination           : {'goal': 40}
# benchmark_manifest    : benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_42 --agent-file agent_final.pt --manifest benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_42/agent_final.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 100.0%
# avg_return            : 32.32 +/- 19.71
# avg_safety_cost       : 6.221 +/- 6.734
# avg_time_s            : 52.37 +/- 9.77
# avg_time_s_success    : 52.37
# avg_energy            : 37168.17 +/- 7087.69
# avg_path_length_m     : 50.15 +/- 7.37
# avg_progress_ratio    : 0.907 +/- 0.004
# avg_path_efficiency   : 0.789 +/- 0.092
# termination           : {'goal': 40}
# benchmark_manifest    : benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 - results/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_42 checkpoints/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_42/trainer_state.json results/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/selection/seed_42/selected_checkpoint.json results/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/selection/seed_42/selected_agent_file.txt
# [write] selection: results/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/selection/seed_42/selected_checkpoint.json
# [best] agent=agent_step_00045696.pt success=1.0000 return=33.7986
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_43 --agent-file agent_step_00003264.pt --manifest benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_43/agent_step_00003264.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 22.5%
# avg_return            : -91.06 +/- 92.26
# avg_safety_cost       : 10.950 +/- 6.133
# avg_time_s            : 60.18 +/- 19.82
# avg_time_s_success    : 41.97
# avg_energy            : 42625.03 +/- 15766.17
# avg_path_length_m     : 59.47 +/- 16.95
# avg_progress_ratio    : 0.590 +/- 0.495
# avg_path_efficiency   : 0.517 +/- 0.341
# termination           : {'out_of_bounds': 31, 'goal': 9}
# benchmark_manifest    : benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_43 --agent-file agent_step_00006528.pt --manifest benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_43/agent_step_00006528.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 20.0%
# avg_return            : -120.93 +/- 122.92
# avg_safety_cost       : 16.170 +/- 10.994
# avg_time_s            : 72.43 +/- 36.17
# avg_time_s_success    : 46.88
# avg_energy            : 52655.87 +/- 29036.10
# avg_path_length_m     : 66.69 +/- 28.51
# avg_progress_ratio    : 0.572 +/- 0.599
# avg_path_efficiency   : 0.506 +/- 0.356
# termination           : {'out_of_bounds': 32, 'goal': 8}
# benchmark_manifest    : benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_43 --agent-file agent_step_00009792.pt --manifest benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_43/agent_step_00009792.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 37.5%
# avg_return            : -70.68 +/- 97.20
# avg_safety_cost       : 15.722 +/- 13.266
# avg_time_s            : 61.83 +/- 22.72
# avg_time_s_success    : 53.34
# avg_energy            : 44143.74 +/- 17653.10
# avg_path_length_m     : 58.09 +/- 15.57
# avg_progress_ratio    : 0.752 +/- 0.365
# avg_path_efficiency   : 0.618 +/- 0.247
# termination           : {'goal': 15, 'out_of_bounds': 25}
# benchmark_manifest    : benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_43 --agent-file agent_step_00013056.pt --manifest benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_43/agent_step_00013056.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 72.5%
# avg_return            : -29.88 +/- 118.10
# avg_safety_cost       : 12.588 +/- 12.939
# avg_time_s            : 62.52 +/- 29.04
# avg_time_s_success    : 52.47
# avg_energy            : 44933.32 +/- 22433.15
# avg_path_length_m     : 58.16 +/- 20.77
# avg_progress_ratio    : 0.740 +/- 0.441
# avg_path_efficiency   : 0.653 +/- 0.311
# termination           : {'goal': 29, 'out_of_bounds': 11}
# benchmark_manifest    : benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_43 --agent-file agent_step_00016320.pt --manifest benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_43/agent_step_00016320.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 72.5%
# avg_return            : -5.21 +/- 64.09
# avg_safety_cost       : 8.062 +/- 6.458
# avg_time_s            : 53.13 +/- 9.93
# avg_time_s_success    : 52.48
# avg_energy            : 37540.45 +/- 7154.44
# avg_path_length_m     : 52.00 +/- 6.87
# avg_progress_ratio    : 0.850 +/- 0.115
# avg_path_efficiency   : 0.716 +/- 0.145
# termination           : {'goal': 29, 'out_of_bounds': 11}
# benchmark_manifest    : benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_43 --agent-file agent_step_00019584.pt --manifest benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_43/agent_step_00019584.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 87.5%
# avg_return            : -4.56 +/- 122.37
# avg_safety_cost       : 9.310 +/- 12.505
# avg_time_s            : 60.46 +/- 35.77
# avg_time_s_success    : 52.03
# avg_energy            : 42896.43 +/- 26065.49
# avg_path_length_m     : 55.47 +/- 22.56
# avg_progress_ratio    : 0.791 +/- 0.460
# avg_path_efficiency   : 0.719 +/- 0.267
# termination           : {'goal': 35, 'timeout': 1, 'out_of_bounds': 4}
# benchmark_manifest    : benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_43 --agent-file agent_step_00022848.pt --manifest benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_43/agent_step_00022848.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 100.0%
# avg_return            : 30.86 +/- 23.11
# avg_safety_cost       : 6.953 +/- 9.050
# avg_time_s            : 53.00 +/- 11.10
# avg_time_s_success    : 53.00
# avg_energy            : 37527.82 +/- 7993.75
# avg_path_length_m     : 50.91 +/- 8.48
# avg_progress_ratio    : 0.907 +/- 0.004
# avg_path_efficiency   : 0.781 +/- 0.105
# termination           : {'goal': 40}
# benchmark_manifest    : benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json
#
# ...
# avg_time_s_success    : 50.97
# avg_energy            : 39754.72 +/- 16223.92
# avg_path_length_m     : 52.51 +/- 15.29
# avg_progress_ratio    : 0.863 +/- 0.189
# avg_path_efficiency   : 0.766 +/- 0.207
# termination           : {'goal': 37, 'out_of_bounds': 3}
# benchmark_manifest    : benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_43 --agent-file agent_step_00032640.pt --manifest benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_43/agent_step_00032640.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 97.5%
# avg_return            : 24.70 +/- 54.76
# avg_safety_cost       : 7.389 +/- 9.029
# avg_time_s            : 54.11 +/- 16.41
# avg_time_s_success    : 52.12
# avg_energy            : 38675.52 +/- 11999.90
# avg_path_length_m     : 51.65 +/- 10.89
# avg_progress_ratio    : 0.888 +/- 0.123
# avg_path_efficiency   : 0.769 +/- 0.152
# termination           : {'goal': 39, 'out_of_bounds': 1}
# benchmark_manifest    : benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_43 --agent-file agent_step_00035904.pt --manifest benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_43/agent_step_00035904.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 97.5%
# avg_return            : 24.73 +/- 72.31
# avg_safety_cost       : 6.436 +/- 9.426
# avg_time_s            : 53.78 +/- 21.45
# avg_time_s_success    : 50.74
# avg_energy            : 38379.76 +/- 15611.37
# avg_path_length_m     : 51.27 +/- 13.97
# avg_progress_ratio    : 0.865 +/- 0.265
# avg_path_efficiency   : 0.778 +/- 0.194
# termination           : {'goal': 39, 'out_of_bounds': 1}
# benchmark_manifest    : benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_43 --agent-file agent_step_00039168.pt --manifest benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_43/agent_step_00039168.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 100.0%
# avg_return            : 36.83 +/- 19.97
# avg_safety_cost       : 4.750 +/- 5.885
# avg_time_s            : 50.25 +/- 9.85
# avg_time_s_success    : 50.25
# avg_energy            : 35849.97 +/- 7219.32
# avg_path_length_m     : 48.79 +/- 7.88
# avg_progress_ratio    : 0.907 +/- 0.004
# avg_path_efficiency   : 0.814 +/- 0.103
# termination           : {'goal': 40}
# benchmark_manifest    : benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_43 --agent-file agent_step_00042432.pt --manifest benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_43/agent_step_00042432.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 100.0%
# avg_return            : 37.45 +/- 20.38
# avg_safety_cost       : 5.029 +/- 6.457
# avg_time_s            : 49.91 +/- 10.04
# avg_time_s_success    : 49.91
# avg_energy            : 35834.50 +/- 7344.56
# avg_path_length_m     : 48.87 +/- 8.00
# avg_progress_ratio    : 0.907 +/- 0.004
# avg_path_efficiency   : 0.813 +/- 0.105
# termination           : {'goal': 40}
# benchmark_manifest    : benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_43 --agent-file agent_step_00045696.pt --manifest benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_43/agent_step_00045696.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 100.0%
# avg_return            : 32.91 +/- 21.22
# avg_safety_cost       : 6.182 +/- 6.880
# avg_time_s            : 52.02 +/- 10.41
# avg_time_s_success    : 52.02
# avg_energy            : 37048.43 +/- 7596.72
# avg_path_length_m     : 50.07 +/- 7.82
# avg_progress_ratio    : 0.907 +/- 0.004
# avg_path_efficiency   : 0.792 +/- 0.101
# termination           : {'goal': 40}
# benchmark_manifest    : benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_43 --agent-file agent_step_00048960.pt --manifest benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_43/agent_step_00048960.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 100.0%
# avg_return            : 35.41 +/- 19.39
# avg_safety_cost       : 5.315 +/- 6.512
# avg_time_s            : 50.88 +/- 9.61
# avg_time_s_success    : 50.88
# avg_energy            : 36276.35 +/- 7035.89
# avg_path_length_m     : 49.27 +/- 7.64
# avg_progress_ratio    : 0.907 +/- 0.004
# avg_path_efficiency   : 0.805 +/- 0.098
# termination           : {'goal': 40}
# benchmark_manifest    : benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_43 --agent-file agent_step_00052224.pt --manifest benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_43/agent_step_00052224.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 95.0%
# avg_return            : 22.33 +/- 59.31
# avg_safety_cost       : 6.875 +/- 8.094
# avg_time_s            : 53.85 +/- 16.37
# avg_time_s_success    : 51.34
# avg_energy            : 38408.12 +/- 11951.89
# avg_path_length_m     : 51.36 +/- 10.83
# avg_progress_ratio    : 0.888 +/- 0.119
# avg_path_efficiency   : 0.774 +/- 0.153
# termination           : {'goal': 38, 'out_of_bounds': 2}
# benchmark_manifest    : benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_43 --agent-file agent_final.pt --manifest benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_43/agent_final.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 95.0%
# avg_return            : 22.33 +/- 59.31
# avg_safety_cost       : 6.875 +/- 8.094
# avg_time_s            : 53.85 +/- 16.37
# avg_time_s_success    : 51.34
# avg_energy            : 38408.12 +/- 11951.89
# avg_path_length_m     : 51.36 +/- 10.83
# avg_progress_ratio    : 0.888 +/- 0.119
# avg_path_efficiency   : 0.774 +/- 0.153
# termination           : {'goal': 38, 'out_of_bounds': 2}
# benchmark_manifest    : benchmarks/offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 - results/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_43 checkpoints/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_43/trainer_state.json results/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/selection/seed_43/selected_checkpoint.json results/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/selection/seed_43/selected_agent_file.txt
# [write] selection: results/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/selection/seed_43/selected_checkpoint.json
# [best] agent=agent_step_00042432.pt success=1.0000 return=37.4500
#
# [cmd] env MODE=test PYTHON_BIN=python3 DEVICE=cuda BENCHMARK_KEY=single_u10_cross_tgt15 FLOW_PATH=wake_data/wake_v8_U1p00_Re150_D12p00_dx0p60_Ti5pct_1200f_roi.npy TASK_GEOMETRY=cross_stream TARGET_SPEED=1.5 OBJECTIVE=efficiency_v2 PROBE_LAYOUT=s0 HISTORY_LENGTH=4 DATASET_POLICY=worldcomp DATASET_EPISODES=1000 DATASET_SEED=0 COLLECT_WORKERS=8 ACTOR_PENALTY_COEFS=4.0 CRITIC_PENALTY_COEFS=2.0 BATCH_SIZE=256 DROP_LAST_BATCH=0 SAMPLING_MODE=shuffle_no_replacement HIDDEN_DIM=256 NUM_HIDDEN_LAYERS=3 ACTOR_LR=3e-4 CRITIC_LR=3e-4 GAMMA=0.99 TAU=0.005 POLICY_NOISE=0.2 NOISE_CLIP=0.5 POLICY_FREQ=2 GRAD_CLIP_NORM=10.0 NORMALIZER_EPS=1e-3 LOG_EVERY=1000 TRAIN_METRICS_WINDOW_FRACTION=0.25 EVAL_WORKERS=6 EVAL_WORKER_DEVICE=cpu VALIDATION_SEED=123 TEST_SEED=456 FORCE_REEVAL=0 SEEDS=42 43 TRAIN_EPOCHS=128 CHECKPOINT_EVERY_EPOCHS=8 VAL_MANIFEST_EPISODES=40 TEST_MANIFEST_EPISODES=40 MANIFEST_ROOT=benchmarks/offline_rebrac_worldcomp_epoch_probe CHECKPOINT_ROOT=checkpoints/offline/rebrac/worldcomp_epoch_probe RESULTS_ROOT=results/offline/rebrac/worldcomp_epoch_probe USE_ASYMMETRIC_CRITIC=0 bash scripts/run_offline_rebrac_screen.sh
# [skip] manifest exists: benchmarks/offline_rebrac_worldcomp_epoch_probe/test_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_42 --agent-file agent_step_00045696.pt --manifest benchmarks/offline_rebrac_worldcomp_epoch_probe/test_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 456 --output-json results/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/test/seed_42.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 100.0%
# avg_return            : 33.80 +/- 20.68
# avg_safety_cost       : 5.755 +/- 6.999
# avg_time_s            : 51.67 +/- 10.16
# avg_time_s_success    : 51.67
# avg_energy            : 36738.06 +/- 7417.75
# avg_path_length_m     : 49.82 +/- 7.77
# avg_progress_ratio    : 0.907 +/- 0.004
# avg_path_efficiency   : 0.796 +/- 0.099
# termination           : {'goal': 40}
# benchmark_manifest    : benchmarks/offline_rebrac_worldcomp_epoch_probe/test_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_43 --agent-file agent_step_00042432.pt --manifest benchmarks/offline_rebrac_worldcomp_epoch_probe/test_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 456 --output-json results/offline/rebrac/worldcomp_epoch_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/test/seed_43.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 100.0%
# avg_return            : 37.45 +/- 20.38
# avg_safety_cost       : 5.029 +/- 6.457
# avg_time_s            : 49.91 +/- 10.04
# avg_time_s_success    : 49.91
# avg_energy            : 35834.50 +/- 7344.56
# avg_path_length_m     : 48.87 +/- 8.00
# avg_progress_ratio    : 0.907 +/- 0.004
# avg_path_efficiency   : 0.813 +/- 0.105
# termination           : {'goal': 40}
# benchmark_manifest    : benchmarks/offline_rebrac_worldcomp_epoch_probe/test_40/single_u10_cross_tgt15.json
#
# [cmd] env MODE=summarize PYTHON_BIN=python3 DEVICE=cuda BENCHMARK_KEY=single_u10_cross_tgt15 FLOW_PATH=wake_data/wake_v8_U1p00_Re150_D12p00_dx0p60_Ti5pct_1200f_roi.npy TASK_GEOMETRY=cross_stream TARGET_SPEED=1.5 OBJECTIVE=efficiency_v2 PROBE_LAYOUT=s0 HISTORY_LENGTH=4 DATASET_POLICY=worldcomp DATASET_EPISODES=1000 DATASET_SEED=0 COLLECT_WORKERS=8 ACTOR_PENALTY_COEFS=4.0 CRITIC_PENALTY_COEFS=2.0 BATCH_SIZE=256 DROP_LAST_BATCH=0 SAMPLING_MODE=shuffle_no_replacement HIDDEN_DIM=256 NUM_HIDDEN_LAYERS=3 ACTOR_LR=3e-4 CRITIC_LR=3e-4 GAMMA=0.99 TAU=0.005 POLICY_NOISE=0.2 NOISE_CLIP=0.5 POLICY_FREQ=2 GRAD_CLIP_NORM=10.0 NORMALIZER_EPS=1e-3 LOG_EVERY=1000 TRAIN_METRICS_WINDOW_FRACTION=0.25 EVAL_WORKERS=6 EVAL_WORKER_DEVICE=cpu VALIDATION_SEED=123 TEST_SEED=456 FORCE_REEVAL=0 SEEDS=42 43 TRAIN_EPOCHS=128 CHECKPOINT_EVERY_EPOCHS=8 VAL_MANIFEST_EPISODES=40 TEST_MANIFEST_EPISODES=40 MANIFEST_ROOT=benchmarks/offline_rebrac_worldcomp_epoch_probe CHECKPOINT_ROOT=checkpoints/offline/rebrac/worldcomp_epoch_probe RESULTS_ROOT=results/offline/rebrac/worldcomp_epoch_probe USE_ASYMMETRIC_CRITIC=0 bash scripts/run_offline_rebrac_screen.sh
#
# [cmd] python3 - results/offline/rebrac/worldcomp_epoch_probe checkpoints/offline/rebrac/worldcomp_epoch_probe results/offline/rebrac/worldcomp_epoch_probe/summaries 0.25
# [write] summary: results/offline/rebrac/worldcomp_epoch_probe/summaries/overview.csv
# [write] summary: results/offline/rebrac/worldcomp_epoch_probe/summaries/overview.json

# %% [markdown]
# ## 4. 分析：val 曲线 vs epoch
#
# `select_best_checkpoint`（screen.sh 内部调用）写出的 `selected_checkpoint.json` 里有 `candidates` 数组，每个元素就是一个 `(train_step, eval_success_rate, eval_return, …)` 点——现成的 val 曲线。
#
# 把 `train_step` 换算成 epoch：最后一个 ckpt 对应 `TRAIN_EPOCHS=128`，所以 `epoch = train_step / (max_train_step / 128)`。

# %%
import json
from pathlib import Path

import matplotlib.pyplot as plt

RESULTS_ROOT     = Path("results/offline/rebrac/worldcomp_epoch_probe")
TRAIN_EPOCHS     = int(os.environ["EPOCH_PROBE_TRAIN_EPOCHS"])
PAIR_TAG         = "actorb_4p0__criticb_2p0"
DATASET_NAME     = "worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000"
SEEDS            = os.environ["EPOCH_PROBE_SEEDS"].split()
EPOCH_THRESHOLDS = [64, 96]  # 决策三档分界


def load_candidates(seed: str) -> list[dict]:
    selection_path = (
        RESULTS_ROOT / DATASET_NAME / PAIR_TAG / "selection" / f"seed_{seed}" / "selected_checkpoint.json"
    )
    if not selection_path.exists():
        print(f"[warn] missing: {selection_path}")
        return []
    payload = json.loads(selection_path.read_text(encoding="utf-8"))
    cands = [c for c in payload["candidates"] if c.get("train_step") is not None]
    cands.sort(key=lambda c: c["train_step"])
    return cands


def to_epoch(candidates: list[dict], train_epochs: int) -> list[float]:
    max_step = max(c["train_step"] for c in candidates)
    steps_per_epoch = max_step / train_epochs
    return [c["train_step"] / steps_per_epoch for c in candidates]

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 4.5))

for seed in SEEDS:
    cands = load_candidates(seed)
    if not cands:
        continue
    epochs = to_epoch(cands, TRAIN_EPOCHS)
    succ   = [c["eval_success_rate"] for c in cands]
    ax.plot(epochs, succ, marker="o", alpha=0.8, label=f"seed_{seed}")

for thr in EPOCH_THRESHOLDS:
    ax.axvline(thr, linestyle="--", color="gray", alpha=0.5, label=f"decision boundary ({thr})")

ax.set_title(f"ReBRAC val curve vs training budget on {DATASET_NAME}\n"
             f"(β1={os.environ['ACTOR_PENALTY_COEF']}, β2={os.environ['CRITIC_PENALTY_COEF']}, deployable track)")
ax.set_xlabel("epoch")
ax.set_ylabel("val success_rate")
ax.grid(True, alpha=0.3)
ax.legend(fontsize=8, loc="lower right")
fig.tight_layout()
plt.show()

# %%
# Peak epoch 汇总表 + 决策建议
print(f"{'seed':<8}{'peak_epoch':<14}{'peak_success':<16}{'succ@ep64':<14}{'succ@ep96':<14}")
print("-" * 70)

peak_epochs = []
for seed in SEEDS:
    cands = load_candidates(seed)
    if not cands:
        continue
    epochs = to_epoch(cands, TRAIN_EPOCHS)
    succ   = [c["eval_success_rate"] for c in cands]
    peak_idx  = max(range(len(succ)), key=lambda i: succ[i])
    peak_ep   = epochs[peak_idx]
    peak_succ = succ[peak_idx]
    ref64_idx = min(range(len(epochs)), key=lambda i: abs(epochs[i] - 64))
    ref96_idx = min(range(len(epochs)), key=lambda i: abs(epochs[i] - 96))
    print(f"{seed:<8}{peak_ep:<14.1f}{peak_succ:<16.4f}{succ[ref64_idx]:<14.4f}{succ[ref96_idx]:<14.4f}")
    peak_epochs.append(peak_ep)

print()
if peak_epochs:
    max_peak = max(peak_epochs)
    if max_peak <= 64:
        decision = "TRAIN_EPOCHS=64 (Phase 1 deployable formal 用 64)"
    elif max_peak <= 96:
        decision = "TRAIN_EPOCHS=96 (对齐 TD3BC worldcomp teacher-gap 的预算)"
    else:
        decision = "暂停 Phase 1，回查 worldcomp 训练动力学（critic penalty 与 noisy teacher target 的相互作用）"
    print(f"[decision] max peak epoch = {max_peak:.1f} → Stage D Phase 1: {decision}")
# Out:
# seed    peak_epoch    peak_success    succ@ep64     succ@ep96
# ----------------------------------------------------------------------
# 42      64.0          1.0000          1.0000        1.0000
# 43      56.0          1.0000          0.9000        1.0000
#
# [decision] max peak epoch = 64.0 → Stage D Phase 1: TRAIN_EPOCHS=64 (Phase 1 deployable formal 用 64)

# %% [markdown]
# ## 5. 决策记录
#
# 跑完上面 cell 后，把 `[decision]` 那一行的内容写入 `docs/rebrac_experiment_report.md` 的 Stage D 章节（Phase 1 epoch-probe 小节），并据此设置 Stage D Phase 1 deployable formal 的 `DEPLOYABLE_FINAL_TRAIN_EPOCHS` 环境变量（在下一个 notebook `rebrac_worldcomp_teacher_gap.ipynb` 的开头）。
#
# ## 6. （可选）Stage B0 等价性 sanity check
#
# Stage B0 在 `crosscomp` 上做了 "长训中间 ckpt ≈ 单独训到该 epoch" 的间接验证；如果想在 `worldcomp` 上也做一次严格的 `state_dict_l2_distance` 交叉比对，可在 Phase 1 deployable formal 跑完后比较：
#
# - `checkpoints/offline/rebrac/worldcomp_epoch_probe/.../seed_42/agent_step_<step_at_ep64>.pt`
# - `checkpoints/offline/rebrac/worldcomp_teacher_gap/deployable/.../seed_42/agent_final.pt`（如果 Phase 1 用 64 epoch）
#
# 理论上两者权重应该完全一致（同 RNG seed、同 sampling、同 LR schedule）。这一项不是必须，但能闭环 [report §9 局限性](../docs/rebrac_experiment_report.md) 第 1 项。
