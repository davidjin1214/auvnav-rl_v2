# %% [markdown]
# # SAC arrival_v2 — history k=12 cross-seed sister (seed=0) on single_cross_s0 (1M, vanilla)
#
# **Pre-context（commit `352ed78` + k=12 seed=42 PASS-PLATEAU 回流 + k=8 multi-seed 3-anchor 回流 2026-05-19）**：[`docs/arrival_v2_experiment_report.md`](../docs/arrival_v2_experiment_report.md) 当前 single_cross_s0 vanilla SAC 完整画像（6 runs）：
#
# | run                                | seed | k    | final  | peak@step    | mean39 | OOB    | n_succ | Gate         |
# |---                                 |---:  |---:  |---:    |---           |---:    |---:    |---:    |---           |
# | §7.6.4 s0_k4                       | 42   | 4    | 0.100  | 0.367 @ 975k | 0.221  | 0.667  | 35/39  | FAIL floor   |
# | §7.7.1 s0_k4 sister                | 0    | 4    | 0.400  | 0.533 @ 625k | 0.218  | 0.200  | 34/39  | FAIL         |
# | **§7.8 s0_k8 anchor**              | 42   | 8    | **0.900** | 0.900 @ 475k | **0.636** | **0.100** | 37/39 | **PASS 5/5** |
# | §7.8' s0_k8                        | 0    | 8    | 0.500  | 0.500 @ 925k | 0.260  | 0.133  | 32/39  | PARTIAL 2/5  |
# | §7.8'' s0_k8                       | 7    | 8    | 0.867  | 0.900 @ 550k | 0.518  | 0.133  | 31/39  | BORDER 4/5   |
# | **§8P1#2 s0_k12 anchor**           | 42   | 12   | **0.900** | 0.900 @ **375k** | 0.652 | **0.100** | 35/39 | **PASS 5/5 PLATEAU** |
# | **本 notebook s0_k12 sister**     | **0**| 12   | ?      | ?            | ?      | ?      | ?      | ?            |
#
# **关键 open questions（本 notebook 必须区分）**：
#
# | Hypothesis | 含义 |
# |---|---|
# | **H_rescue: k=12 真有 + monotonic 增益，k=8 seed=0 仅是窗口不够长** | k=12 s0 应 5/5 PASS（或 BORDER），与 k=12 s42 类似 |
# | **H_seed-stall: seed=0 有 init-dep local minimum，与 k 无关** | k=12 s0 应仍 PARTIAL（final ≈ 0.5），与 k=8 s0 类似 |
# | **H_overstale: k=12 在 seed=0 上 over-stale，反害** | k=12 s0 final < k=8 s0 final |
# | **H_collapse: severe regression** | k=12 s0 final < 0.4，需 audit |
#
# **本 notebook 任务（pure vanilla + history k=12，单变量 seed swap from k=12 anchor）**：
#
# | 维度                  | §8P1#2 anchor (k=12, seed=42) | 本 notebook (k=12, seed=0) |
# |---                    |---                            |---                          |
# | `--seed`              | 42                            | **0** ← 唯一变量            |
# | `--history-length`    | 12                            | 12                          |
# | algorithm             | vanilla SAC                   | vanilla SAC                 |
# | sensor layout         | s0 (DVL-only)                 | s0 (DVL-only)               |
# | reward                | arrival_v2                    | arrival_v2                  |
# | flow U / target       | 1.5 / 1.5                     | 1.5 / 1.5                   |
# | total_steps           | 1M                            | 1M                          |
# | num_envs              | 6                             | 6                           |
# | benchmark             | `single_u15_cross_tgt15`      | 同                          |
# | obs_dim               | 144 (12×12)                   | 144                         |
#
# **Seed 选择 = 0 的理由**：与 k=4 sister (§7.7.1) + k=8 sister (§7.8') seed 对齐，构成完整 `k ∈ {4, 8, 12} × seed=0` 三元 paired contrast。
#
# **Gate**（与 §7 / §7.6 / §7.7 / §7.8 / §8P1#2 同口径）：
# - `final_success_rate ≥ 0.85`
# - `last100k_mean ≥ 0.9 × peak`
# - `final_oob_rate ≤ 0.10`
# - `include_episode_context_obs == True`
# - `timeout_bootstrap_semantics == 'terminal'`
#
# **Cross-seed monotonicity verdict 规则（5-tier，吸取 build_k8_seed7.py 4-tier BORDERLINE 漏覆盖 bug 教训）**：
#
# | Verdict | 触发条件 | §7.8 / §8P1#2 主张含义 |
# |---|---|---|
# | **CROSS-SEED-RESCUE** | k=12 s0 strict 5/5 PASS（final≥0.85 AND OOB≤0.10）| 强证据 H_rescue。§7.8 主张升格「k=4→8 closes gap on lucky seeds; k=8→12 进一步 rescue unlucky seeds」；§8 P1#2 升格 monotonic claim |
# | **CROSS-SEED-BORDERLINE-PASS** | final≥0.85 AND 0.10 < OOB ≤ 0.135 | final 维度 H_rescue 但 OOB 仍 seed-dep（与 §7.8'' seed=7 BORDER 一致）；说明 SAC variance 主要表现在 OOB 末端而非 final goal 率；motivates §8 P0 variance reduction 但 history 路径仍 viable |
# | **PERSISTENT-STALL** | 0.50 ≤ final < 0.85 AND \|final − k=8 s0 final\| ≤ 0.20 | 强证据 H_seed-stall。seed=0 有 init-dep local minimum 与 history length 无关；§8 P0 (DroQ / SimBa / N-Step) variance reduction 必要 |
# | **UNEXPECTED-DECAY** | k=12 s0 final < k=8 s0 final − 0.05 OR 0.40 ≤ final < 0.50 | H_overstale 部分支持；over-stale history 在 seed=0 上反害；§8 P1#2 主张回退「k=8 sweet spot」 |
# | **COLLAPSE** | final < 0.40 | H_collapse。严重下降；audit trainer_state（grad-norm / loss curve / obs_dim）排除 training bug |
#
# **输出根（与 §8P1#2 k=12 anchor / §7.8' k=8 seed=0 互不覆盖）**：
# - `experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s0_k12/seed_0/`
#
# **总预算**：~2.5h L4（1 Colab Pro+ session；obs_dim 144 vs 96 增加 ~50% forward cost，但 hidden_dim 仍 256，主要瓶颈是 env step）。
#
# **风格**：训练用 `!python -u -m scripts.train_sac` 直跑，与 §7.8 / §8P1#2 一致。

# %% [markdown]
# ## 0. GPU sanity

# %%
# !nvidia-smi | head -10
# Out:
# Tue May 19 02:56:32 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA L4                      Off |   00000000:00:03.0 Off |                    0 |
# | N/A   40C    P8             12W /   72W |       0MiB /  23034MiB |      0%      Default |

# %% [markdown]
# ## 1. Mount Drive + cwd

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

REPO_DIR = '/content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5'
# %cd $REPO_DIR
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5

# %% [markdown]
# ## 2. Config — single phase（vanilla SAC + history k=12 + seed=0，与 §8P1#2 k=12 anchor 仅差一个 flag value）

# %%
import json
import os
from pathlib import Path

import pandas as pd

# ==== SAC / env config (与 §8P1#2 k=12 anchor 严格一致，除 seed 外) ====
OBJECTIVE = 'arrival_v2'
PROBE_LAYOUT = 's0'
HISTORY_LENGTH = 12
TARGET_SPEED = 1.5
SEED = 0                                # ← 唯一与 §8P1#2 k=12 anchor (seed=42) 不同；cross-seed sister

RANDOM_STEPS = 5_000
UPDATE_AFTER = 5_000
BATCH_SIZE = 256
HIDDEN_DIM = 256
NUM_ENVS = 6
EVAL_EVERY = 25_000
EVAL_EPISODES = 30
CHECKPOINT_EVERY = 100_000
DEVICE = 'cuda'

# 显式拒绝所有 SAC 改进项 — 与 §7.8 / §8P1#2 一致
USE_ASYMMETRIC_CRITIC = False
USE_LAYERNORM = False
UPDATES_PER_STEP = 1
DROPOUT_RATE = 0.0

PASS_FINAL_SUCCESS = 0.85
PASS_LAST100_RATIO = 0.90
PASS_OOB_RATE = 0.10
BORDERLINE_OOB_RATE = 0.135  # BORDERLINE-PASS tier 上限

# Flow file（与 §7 / §8P1#2 全套严格一致）
SINGLE_FLOW = 'wake_data/wake_v8_U1p50_Re250_D12p00_dx0p60_Ti5pct_1200f_roi.npy'

# ==== Single phase — single_cross s0 k=12 seed=0 (X_*) ====
X_BENCHMARK_KEY = 'single_u15_cross_tgt15'
X_TASK_GEOMETRY = 'cross_stream'
X_FLOW_PATH = SINGLE_FLOW
X_TOTAL_STEPS = 1_000_000
X_RUN_ROOT = Path('experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s0_k12/seed_0')
X_CKPT_ROOT = Path('checkpoints/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s0_k12/seed_0')
X_MANIFEST_PATH = Path(f'benchmarks/{X_BENCHMARK_KEY}.json')

# Baselines（cross-seed monotonicity 需要全 7-run 对照）
X_K12_S42_ROOT = Path('experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s0_k12/seed_42')  # §8P1#2 anchor PASS
X_K8_S42_ROOT  = Path('experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s0_k8/seed_42')   # §7.8 anchor PASS
X_K8_S0_ROOT   = Path('experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s0_k8/seed_0')    # §7.8' PARTIAL (主对照 — same seed)
X_K8_S7_ROOT   = Path('experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s0_k8/seed_7')    # §7.8'' BORDERLINE-PASS
X_K4_S42_ROOT  = Path('experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s0_k4/seed_42')   # §7.6.4 floor
X_K4_S0_ROOT   = Path('experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s0_k4/seed_0')    # §7.7.1 sister
X_S1_UPPER_ROOT = Path('experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s1_k4/seed_42')  # §7.1 upper

os.environ['PYTHONUNBUFFERED'] = '1'

print(f'PROBE_LAYOUT          = {PROBE_LAYOUT}')
print(f'OBJECTIVE             = {OBJECTIVE}')
print(f'HISTORY_LENGTH        = {HISTORY_LENGTH}')
print(f'SEED                  = {SEED}        ← cross-seed sister; 与 §8P1#2 anchor (seed=42) 不同')
print(f'NUM_ENVS              = {NUM_ENVS}')
print(f'USE_ASYMMETRIC_CRITIC = {USE_ASYMMETRIC_CRITIC}')
print(f'USE_LAYERNORM         = {USE_LAYERNORM}')
print(f'UPDATES_PER_STEP      = {UPDATES_PER_STEP}')
print(f'DROPOUT_RATE          = {DROPOUT_RATE}')
print()
print(f'benchmark             : {X_BENCHMARK_KEY}')
print(f'geometry              : {X_TASK_GEOMETRY}')
print(f'total_steps           : {X_TOTAL_STEPS:,}')
print(f'expected obs_dim      : 12 * {HISTORY_LENGTH} = {12 * HISTORY_LENGTH} (per train_config.txt across all baselines)')
print(f'run_root              : {X_RUN_ROOT}')
print(f'§8P1#2 k=12 s42 PASS  : {X_K12_S42_ROOT}')
print(f'§7.8   k=8  s42 PASS  : {X_K8_S42_ROOT}')
print(f"§7.8'  k=8  s0  PART  : {X_K8_S0_ROOT}")
print(f"§7.8'' k=8  s7  BORDER: {X_K8_S7_ROOT}")
print(f'§7.6.4 k=4  s42 floor : {X_K4_S42_ROOT}')
print(f'§7.7.1 k=4  s0  sister: {X_K4_S0_ROOT}')
print(f'§7.1   s1 k4 s42 upper: {X_S1_UPPER_ROOT}')
# Out:
# PROBE_LAYOUT          = s0
# OBJECTIVE             = arrival_v2
# HISTORY_LENGTH        = 12
# SEED                  = 0        ← cross-seed sister; 与 §8P1#2 anchor (seed=42) 不同
# NUM_ENVS              = 6
# USE_ASYMMETRIC_CRITIC = False
# USE_LAYERNORM         = False
# UPDATES_PER_STEP      = 1
# DROPOUT_RATE          = 0.0
#
# benchmark             : single_u15_cross_tgt15
# geometry              : cross_stream
# total_steps           : 1,000,000
# expected obs_dim      : 12 * 12 = 144 (per train_config.txt across all baselines)
# run_root              : experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s0_k12/seed_0
# §8P1#2 k=12 s42 PASS  : experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s0_k12/seed_42
# §7.8   k=8  s42 PASS  : experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s0_k8/seed_42
# §7.8'  k=8  s0  PART  : experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s0_k8/seed_0
# §7.8'' k=8  s7  BORDER: experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s0_k8/seed_7
# §7.6.4 k=4  s42 floor : experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s0_k4/seed_42
# §7.7.1 k=4  s0  sister: experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s0_k4/seed_0
# §7.1   s1 k4 s42 upper: experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s1_k4/seed_42

# %% [markdown]
# ## 3. Preflight — flow / arrival_v2 candidate gate / reward unit tests / manifest / baseline 就位

# %%
# Flow file
fp = Path(X_FLOW_PATH)
if not fp.exists():
    raise FileNotFoundError(f'missing flow file: {fp}')
print(f'[OK] flow file: {fp}  ({fp.stat().st_size / 1e6:.1f} MB)')
# Out:
# [OK] flow file: wake_data/wake_v8_U1p50_Re250_D12p00_dx0p60_Ti5pct_1200f_roi.npy  (230.4 MB)

# %%
# !python -u -m scripts.validate_arrival_v2_candidate
# Out:
# [undiscounted]
# fast_success       144.473
# slow_success       142.023
# unsafe_success      91.048
# timeout_near      -149.800
# timeout_far       -229.800
# late_oob          -274.500
# fast_oob          -280.325
# mid_oob           -319.450
#
# [discounted_gamma_0.995]
# fast_success        88.578
# slow_success        54.683
# unsafe_success      34.857
# timeout_near       -39.480
# timeout_far        -58.269
# late_oob          -103.800
# mid_oob           -190.006
# fast_oob          -212.555
#
# [discounted_shortcut] safe=69.330 risky=62.361
#
# PASS: arrival_v2 candidate pre-integration gates passed.

# %%
# !python -u -m pytest tests/test_reward_objective.py -q
# Out:
# ...............                                                          [100%]
# 15 passed in 19.39s

# %%
if not X_MANIFEST_PATH.exists():
    # !python -u -m scripts.generate_standard_benchmarks --benchmarks {X_BENCHMARK_KEY} --episodes {EVAL_EPISODES}
if not X_MANIFEST_PATH.exists():
    raise FileNotFoundError(f'manifest not generated: {X_MANIFEST_PATH}')
print(f'[OK] manifest ready: {X_MANIFEST_PATH}')
# Out:
# [OK] manifest ready: benchmarks/single_u15_cross_tgt15.json

# %%
# 检查 7 个对比 baseline 是否就位
for label, root, ref_final, ref_oob in [
    ('§8P1#2 k12 s42 PASS-PLAT  ', X_K12_S42_ROOT, 0.900, 0.100),
    ('§7.8   k8  s42 PASS       ', X_K8_S42_ROOT,  0.900, 0.100),
    ("§7.8'  k8  s0  PARTIAL    ", X_K8_S0_ROOT,   0.500, 0.133),
    ("§7.8'' k8  s7  BORDER     ", X_K8_S7_ROOT,   0.867, 0.133),
    ('§7.6.4 k4  s42 floor      ', X_K4_S42_ROOT,  0.100, 0.667),
    ('§7.7.1 k4  s0  sister     ', X_K4_S0_ROOT,   0.400, 0.200),
    ('§7.1   s1  k4 upper       ', X_S1_UPPER_ROOT, 0.900, 0.100),
]:
    fp = root / 'results' / 'final_eval.json'
    if fp.exists():
        d = json.loads(fp.read_text(encoding='utf-8'))
        f = float(d['eval_success_rate'])
        c = d.get('eval_termination_counts', {})
        n = float(d.get('num_eval_episodes', EVAL_EPISODES))
        oob = float(c.get('out_of_bounds', 0)) / max(n, 1.0)
        match = '✓' if abs(f - ref_final) < 0.05 and abs(oob - ref_oob) < 0.05 else '✗ mismatch'
        print(f'[OK] {label}: final={f:.4f}  oob={oob:.4f}  counts={c}  {match}')
    else:
        print(f'[WARN] {label}: {fp} 不存在 (后续 §5 diff 会回退到 report 转载值)')
# Out:
# [OK] §8P1#2 k12 s42 PASS-PLAT  : final=0.9000  oob=0.1000  counts={'goal': 27, 'out_of_bounds': 3}  ✓
# [OK] §7.8   k8  s42 PASS       : final=0.9000  oob=0.1000  counts={'goal': 27, 'out_of_bounds': 3}  ✓
# [OK] §7.8'  k8  s0  PARTIAL    : final=0.5000  oob=0.1333  counts={'timeout': 11, 'goal': 15, 'out_of_bounds': 4}  ✓
# [OK] §7.8'' k8  s7  BORDER     : final=0.8667  oob=0.1333  counts={'goal': 26, 'out_of_bounds': 4}  ✓
# [OK] §7.6.4 k4  s42 floor      : final=0.1000  oob=0.6667  counts={'out_of_bounds': 20, 'timeout': 7, 'goal': 3}  ✓
# [OK] §7.7.1 k4  s0  sister     : final=0.4000  oob=0.2000  counts={'timeout': 12, 'out_of_bounds': 6, 'goal': 12}  ✓
# [OK] §7.1   s1  k4 upper       : final=0.9000  oob=0.1000  counts={'goal': 27, 'out_of_bounds': 3}  ✓

# %% [markdown]
# ## 4. Train — single_cross_s0 + history k=12 + seed=0 (1.0M, skip/resume)

# %%
x_state_path = X_RUN_ROOT / 'trainer_state.json'
if x_state_path.exists():
    x_state = json.loads(x_state_path.read_text(encoding='utf-8'))
    x_current_step = int(x_state.get('env_step', 0))
else:
    x_current_step = 0
print(f'[state] X env_step = {x_current_step:,} / target {X_TOTAL_STEPS:,}')

if x_current_step >= X_TOTAL_STEPS:
    print(f'[skip] X already trained to {x_current_step:,} >= {X_TOTAL_STEPS:,}')
elif x_current_step > 0:
    print(f'[resume] X continuing from {x_current_step:,} -> {X_TOTAL_STEPS:,}')
    # !python -u -m scripts.train_sac \
        --resume {str(X_RUN_ROOT)} \
        --total-steps {X_TOTAL_STEPS} \
        --eval-every {EVAL_EVERY} \
        --eval-episodes {EVAL_EPISODES} \
        --checkpoint-every {CHECKPOINT_EVERY} \
        --eval-manifest {str(X_MANIFEST_PATH)} \
        --device {DEVICE}
else:
    print(f'[train] X fresh start -> {X_TOTAL_STEPS:,}')
    # !python -u -m scripts.train_sac \
        --flow {X_FLOW_PATH} \
        --task-geometry {X_TASK_GEOMETRY} \
        --target-speed {TARGET_SPEED} \
        --objective {OBJECTIVE} \
        --probe-layout {PROBE_LAYOUT} \
        --history-length {HISTORY_LENGTH} \
        --total-steps {X_TOTAL_STEPS} \
        --random-steps {RANDOM_STEPS} \
        --update-after {UPDATE_AFTER} \
        --batch-size {BATCH_SIZE} \
        --hidden-dim {HIDDEN_DIM} \
        --num-envs {NUM_ENVS} \
        --eval-every {EVAL_EVERY} \
        --eval-episodes {EVAL_EPISODES} \
        --checkpoint-every {CHECKPOINT_EVERY} \
        --eval-manifest {str(X_MANIFEST_PATH)} \
        --seed {SEED} \
        --device {DEVICE} \
        --save-dir {str(X_RUN_ROOT)} \
        --checkpoint-dir {str(X_CKPT_ROOT)}
# Out:
# [state] X env_step = 0 / target 1,000,000
# [train] X fresh start -> 1,000,000
# [train] episode=5 step=678 return=-310.07 success=False time=56.1s geometry=cross_stream history=12
# [train] episode=10 step=1842 return=-455.98 success=False time=106.2s geometry=cross_stream history=12
# [train] episode=15 step=2268 return=-404.30 success=False time=94.9s geometry=cross_stream history=12
# [train] episode=20 step=2670 return=-324.46 success=False time=31.6s geometry=cross_stream history=12
# [train] episode=25 step=3204 return=-285.89 success=False time=55.0s geometry=cross_stream history=12
# [train] episode=30 step=3702 return=-416.50 success=False time=38.5s geometry=cross_stream history=12
# [train] episode=35 step=4242 return=-432.68 success=False time=49.6s geometry=cross_stream history=12
# [train] episode=40 step=5112 return=-497.91 success=False time=109.5s geometry=cross_stream history=12 | q1=785.324 actor=0.728 alpha=0.199
# [train] episode=45 step=5490 return=-399.05 success=False time=85.1s geometry=cross_stream history=12 | q1=1341.422 actor=3.023 alpha=0.195
# [train] episode=50 step=6072 return=-276.04 success=False time=27.0s geometry=cross_stream history=12 | q1=4.127 actor=3.233 alpha=0.190
# [train] episode=55 step=6936 return=-394.36 success=False time=78.8s geometry=cross_stream history=12 | q1=289.988 actor=5.443 alpha=0.183
# [train] episode=60 step=7458 return=-473.74 success=False time=114.7s geometry=cross_stream history=12 | q1=450.210 actor=5.606 alpha=0.178
# [train] episode=65 step=8406 return=-452.00 success=False time=84.5s geometry=cross_stream history=12 | q1=248.761 actor=7.179 alpha=0.171
# [train] episode=70 step=9048 return=-374.31 success=False time=100.8s geometry=cross_stream history=12 | q1=5.515 actor=7.651 alpha=0.167
# [train] episode=75 step=9858 return=-453.41 success=False time=53.0s geometry=cross_stream history=12 | q1=461.796 actor=9.771 alpha=0.161
# [train] episode=80 step=10404 return=-426.01 success=False time=122.8s geometry=cross_stream history=12 | q1=8.095 actor=10.026 alpha=0.157
# [train] episode=85 step=11154 return=-346.15 success=False time=64.8s geometry=cross_stream history=12 | q1=498.796 actor=11.972 alpha=0.152
# [train] episode=90 step=11706 return=-366.12 success=False time=42.5s geometry=cross_stream history=12 | q1=4.650 actor=12.170 alpha=0.148
# [train] episode=95 step=12126 return=-281.01 success=False time=34.2s geometry=cross_stream history=12 | q1=646.078 actor=13.018 alpha=0.146
# [train] episode=100 step=12810 return=-275.67 success=False time=44.6s geometry=cross_stream history=12 | q1=680.993 actor=13.227 alpha=0.143
# [train] episode=105 step=13326 return=-245.29 success=False time=21.9s geometry=cross_stream history=12 | q1=519.409 actor=15.730 alpha=0.140
# [train] episode=110 step=13800 return=-325.21 success=False time=65.0s geometry=cross_stream history=12 | q1=227.008 actor=15.632 alpha=0.138
# [train] episode=115 step=14538 return=-363.32 success=False time=67.9s geometry=cross_stream history=12 | q1=212.139 actor=15.843 alpha=0.134
# [train] episode=120 step=14934 return=-258.82 success=False time=11.4s geometry=cross_stream history=12 | q1=462.140 actor=16.854 alpha=0.132
# [train] episode=125 step=15408 return=-273.46 success=False time=25.6s geometry=cross_stream history=12 | q1=228.038 actor=18.924 alpha=0.129
# [train] episode=130 step=15900 return=-267.34 success=False time=11.0s geometry=cross_stream history=12 | q1=225.460 actor=18.391 alpha=0.126
# [train] episode=135 step=16500 return=-332.76 success=False time=56.1s geometry=cross_stream history=12 | q1=454.423 actor=19.423 alpha=0.123
# [train] episode=140 step=17172 return=-352.46 success=False time=82.9s geometry=cross_stream history=12 | q1=239.500 actor=21.157 alpha=0.118
# [train] episode=145 step=17616 return=-265.97 success=False time=12.9s geometry=cross_stream history=12 | q1=189.977 actor=23.604 alpha=0.116
# [train] episode=150 step=18054 return=-420.38 success=False time=72.9s geometry=cross_stream history=12 | q1=635.888 actor=23.578 alpha=0.113
# [train] episode=155 step=18480 return=-348.61 success=False time=71.2s geometry=cross_stream history=12 | q1=437.061 actor=23.383 alpha=0.110
# [train] episode=160 step=19362 return=-535.70 success=False time=108.3s geometry=cross_stream history=12 | q1=217.859 actor=26.532 alpha=0.105
# [train] episode=165 step=19932 return=-387.85 success=False time=76.3s geometry=cross_stream history=12 | q1=463.986 actor=26.937 alpha=0.103
# [train] episode=170 step=20220 return=-258.29 success=False time=35.0s geometry=cross_stream history=12 | q1=201.280 actor=24.432 alpha=0.101
# [train] episode=175 step=20994 return=-240.92 success=False time=11.0s geometry=cross_stream history=12 | q1=628.756 actor=26.524 alpha=0.098
# [train] episode=180 step=21504 return=-386.46 success=False time=71.4s geometry=cross_stream history=12 | q1=651.873 actor=27.843 alpha=0.095
# [train] episode=185 step=22452 return=-583.17 success=False time=100.3s geometry=cross_stream history=12 | q1=246.952 actor=30.375 alpha=0.091
# [train] episode=190 step=23226 return=-491.88 success=False time=87.3s geometry=cross_stream history=12 | q1=1016.509 actor=33.625 alpha=0.088
# [train] episode=195 step=23532 return=-337.56 success=False time=59.4s geometry=cross_stream history=12 | q1=235.020 actor=32.700 alpha=0.087
# [train] episode=200 step=24216 return=-325.40 success=False time=56.3s geometry=cross_stream history=12 | q1=235.155 actor=33.270 alpha=0.085
# [eval] step=25002 objective=arrival_v2 return=-349.80 safety=15.099 success=0.00% time=61.9s energy=34374.1 path=97.6 prog=-1.22
# [train] episode=205 step=25260 return=-363.47 success=False time=62.4s geometry=cross_stream history=12 | q1=171.127 actor=39.293 alpha=0.081
# [train] episode=210 step=25686 return=-311.38 success=False time=51.6s geometry=cross_stream history=12 | q1=219.616 actor=36.429 alpha=0.080
# [train] episode=215 step=26616 return=-444.58 success=False time=76.6s geometry=cross_stream history=12 | q1=422.667 actor=37.569 alpha=0.078
# [train] episode=220 step=27240 return=-290.92 success=False time=32.1s geometry=cross_stream history=12 | q1=537.585 actor=37.832 alpha=0.077
# [train] episode=225 step=27774 return=-281.28 success=False time=39.9s geometry=cross_stream history=12 | q1=425.060 actor=41.494 alpha=0.076
# [train] episode=230 step=28608 return=-381.53 success=False time=80.9s geometry=cross_stream history=12 | q1=537.471 actor=39.391 alpha=0.075
# [train] episode=235 step=28968 return=-221.99 success=False time=25.4s geometry=cross_stream history=12 | q1=396.089 actor=42.161 alpha=0.074
# [train] episode=240 step=29568 return=-309.82 success=False time=25.0s geometry=cross_stream history=12 | q1=375.630 actor=41.282 alpha=0.072
# [train] episode=245 step=30480 return=-343.03 success=False time=53.7s geometry=cross_stream history=12 | q1=473.975 actor=43.550 alpha=0.069
# [train] episode=250 step=31002 return=-354.37 success=False time=72.6s geometry=cross_stream history=12 | q1=354.672 actor=45.838 alpha=0.068
# [train] episode=255 step=31326 return=-331.90 success=False time=65.0s geometry=cross_stream history=12 | q1=152.759 actor=45.053 alpha=0.067
# [train] episode=260 step=31854 return=-219.08 success=False time=34.8s geometry=cross_stream history=12 | q1=353.306 actor=46.174 alpha=0.066
# [train] episode=265 step=32568 return=-332.97 success=False time=42.4s geometry=cross_stream history=12 | q1=726.738 actor=45.326 alpha=0.064
# [train] episode=270 step=32982 return=-324.53 success=False time=33.3s geometry=cross_stream history=12 | q1=180.586 actor=43.606 alpha=0.063
# [train] episode=275 step=33786 return=-416.98 success=False time=93.8s geometry=cross_stream history=12 | q1=104.545 actor=46.330 alpha=0.061
# [train] episode=280 step=34314 return=-369.63 success=False time=69.4s geometry=cross_stream history=12 | q1=222.401 actor=49.687 alpha=0.060
# [train] episode=285 step=34998 return=-339.09 success=False time=70.4s geometry=cross_stream history=12 | q1=224.827 actor=51.586 alpha=0.059
# [train] episode=290 step=35628 return=-261.59 success=False time=43.8s geometry=cross_stream history=12 | q1=298.451 actor=48.455 alpha=0.058
# [train] episode=295 step=36198 return=-274.03 success=False time=9.6s geometry=cross_stream history=12 | q1=345.719 actor=50.565 alpha=0.057
# [train] episode=300 step=36600 return=-353.57 success=False time=58.1s geometry=cross_stream history=12 | q1=281.265 actor=54.967 alpha=0.056
# [train] episode=305 step=37056 return=-270.96 success=False time=10.8s geometry=cross_stream history=12 | q1=243.369 actor=50.628 alpha=0.055
# [train] episode=310 step=37956 return=-321.48 success=False time=74.5s geometry=cross_stream history=12 | q1=356.975 actor=49.416 alpha=0.054
# [train] episode=315 step=38454 return=-239.81 success=False time=38.8s geometry=cross_stream history=12 | q1=222.110 actor=56.083 alpha=0.053
# [train] episode=320 step=39000 return=-350.52 success=False time=59.3s geometry=cross_stream history=12 | q1=449.300 actor=54.027 alpha=0.052
# [train] episode=325 step=39360 return=-434.35 success=False time=90.9s geometry=cross_stream history=12 | q1=116.394 actor=55.742 alpha=0.052
# [train] episode=330 step=40134 return=-317.48 success=False time=53.7s geometry=cross_stream history=12 | q1=373.397 actor=52.298 alpha=0.051
# [train] episode=335 step=40848 return=-420.08 success=False time=78.8s geometry=cross_stream history=12 | q1=96.490 actor=58.453 alpha=0.050
# [train] episode=340 step=41088 return=-234.49 success=False time=19.5s geometry=cross_stream history=12 | q1=299.996 actor=57.675 alpha=0.050
# [train] episode=345 step=41808 return=-351.93 success=False time=61.0s geometry=cross_stream history=12 | q1=319.593 actor=56.018 alpha=0.049
# [train] episode=350 step=42456 return=-325.78 success=False time=53.5s geometry=cross_stream history=12 | q1=98.080 actor=56.592 alpha=0.049
# [train] episode=355 step=42882 return=-269.48 success=False time=35.0s geometry=cross_stream history=12 | q1=3.227 actor=57.419 alpha=0.048
# [train] episode=360 step=43512 return=-381.60 success=False time=71.3s geometry=cross_stream history=12 | q1=332.971 actor=60.571 alpha=0.048
# [train] episode=365 step=44364 return=-385.95 success=False time=70.4s geometry=cross_stream history=12 | q1=311.523 actor=61.291 alpha=0.046
# [train] episode=370 step=45054 return=-305.15 success=False time=56.6s geometry=cross_stream history=12 | q1=44.865 actor=60.910 alpha=0.046
# [train] episode=375 step=45456 return=-274.30 success=False time=32.8s geometry=cross_stream history=12 | q1=243.670 actor=64.475 alpha=0.045
# [train] episode=380 step=46080 return=-258.75 success=False time=54.0s geometry=cross_stream history=12 | q1=181.013 actor=65.739 alpha=0.045
# [train] episode=385 step=46698 return=-268.12 success=False time=15.5s geometry=cross_stream history=12 | q1=173.916 actor=63.261 alpha=0.044
# [train] episode=390 step=47004 return=-266.88 success=False time=31.8s geometry=cross_stream history=12 | q1=270.125 actor=68.644 alpha=0.044
# [train] episode=395 step=47436 return=-343.09 success=False time=61.0s geometry=cross_stream history=12 | q1=264.394 actor=62.104 alpha=0.044
# [train] episode=400 step=48396 return=-306.93 success=False time=44.6s geometry=cross_stream history=12 | q1=530.531 actor=64.119 alpha=0.043
# [train] episode=405 step=48636 return=-263.57 success=False time=18.4s geometry=cross_stream history=12 | q1=121.315 actor=66.953 alpha=0.043
# [train] episode=410 step=49194 return=-350.43 success=False time=61.6s geometry=cross_stream history=12 | q1=283.508 actor=69.729 alpha=0.042
# [train] episode=415 step=49788 return=-283.50 success=False time=48.8s geometry=cross_stream history=12 | q1=430.989 actor=66.886 alpha=0.042
# [eval] step=50004 objective=arrival_v2 return=-337.51 safety=12.866 success=0.00% time=67.1s energy=28043.7 path=95.0 prog=-1.10
# [train] episode=420 step=50430 return=-300.98 success=False time=27.1s geometry=cross_stream history=12 | q1=390.041 actor=67.293 alpha=0.042
# [train] episode=425 step=50898 return=-479.02 success=False time=125.3s geometry=cross_stream history=12 | q1=267.634 actor=69.255 alpha=0.042
# [train] episode=430 step=51468 return=-236.66 success=False time=17.9s geometry=cross_stream history=12 | q1=70.434 actor=68.614 alpha=0.042
# [train] episode=435 step=51876 return=-235.10 success=False time=21.1s geometry=cross_stream history=12 | q1=2.895 actor=67.978 alpha=0.041
# [train] episode=440 step=52452 return=-236.95 success=False time=13.0s geometry=cross_stream history=12 | q1=371.528 actor=69.840 alpha=0.041
# [train] episode=445 step=53046 return=-331.36 success=False time=60.7s geometry=cross_stream history=12 | q1=24.879 actor=72.419 alpha=0.041
# [train] episode=450 step=53580 return=-298.11 success=False time=36.2s geometry=cross_stream history=12 | q1=324.691 actor=72.430 alpha=0.041
# [train] episode=455 step=54216 return=-364.77 success=False time=64.9s geometry=cross_stream history=12 | q1=357.839 actor=73.307 alpha=0.041
# [train] episode=460 step=55140 return=-290.13 success=False time=43.8s geometry=cross_stream history=12 | q1=441.710 actor=73.590 alpha=0.042
# [train] episode=465 step=55740 return=-212.30 success=False time=42.0s geometry=cross_stream history=12 | q1=162.285 actor=71.211 alpha=0.043
# [train] episode=470 step=56262 return=-248.15 success=False time=32.2s geometry=cross_stream history=12 | q1=70.615 actor=77.473 alpha=0.043
# [train] episode=475 step=56718 return=-362.09 success=False time=69.8s geometry=cross_stream history=12 | q1=169.632 actor=81.664 alpha=0.042
# [train] episode=480 step=57594 return=-384.43 success=False time=72.4s geometry=cross_stream history=12 | q1=110.562 actor=77.592 alpha=0.042
# [train] episode=485 step=58020 return=-416.99 success=False time=115.0s geometry=cross_stream history=12 | q1=275.085 actor=80.517 alpha=0.042
# [train] episode=490 step=59064 return=-414.25 success=False time=121.7s geometry=cross_stream history=12 | q1=85.054 actor=75.157 alpha=0.042
# [train] episode=495 step=60006 return=-347.79 success=False time=63.6s geometry=cross_stream history=12 | q1=183.573 actor=72.963 alpha=0.040
# [train] episode=500 step=60480 return=-233.96 success=False time=33.4s geometry=cross_stream history=12 | q1=623.220 actor=83.242 alpha=0.040
# [train] episode=505 step=61164 return=-413.31 success=False time=126.7s geometry=cross_stream history=12 | q1=414.750 actor=77.369 alpha=0.039
# [train] episode=510 step=61632 return=-343.49 success=False time=64.8s geometry=cross_stream history=12 | q1=339.063 actor=80.353 alpha=0.040
# [train] episode=515 step=62052 return=-258.80 success=False time=34.3s geometry=cross_stream history=12 | q1=194.341 actor=79.986 alpha=0.041
# [train] episode=520 step=63228 return=-385.20 success=False time=97.5s geometry=cross_stream history=12 | q1=59.225 actor=83.579 alpha=0.043
# [train] episode=525 step=64158 return=-391.33 success=False time=139.5s geometry=cross_stream history=12 | q1=489.960 actor=86.015 alpha=0.044
# [train] episode=530 step=64872 return=-348.19 success=False time=59.8s geometry=cross_stream history=12 | q1=5.814 actor=82.194 alpha=0.043
# [train] episode=535 step=65904 return=-341.60 success=False time=52.9s geometry=cross_stream history=12 | q1=193.989 actor=88.186 alpha=0.042
# [train] episode=540 step=67050 return=-292.39 success=False time=240.1s geometry=cross_stream history=12 | q1=109.900 actor=90.387 alpha=0.043
# [train] episode=545 step=67590 return=-337.17 success=False time=124.9s geometry=cross_stream history=12 | q1=244.376 actor=91.704 alpha=0.043
# [train] episode=550 step=68448 return=-339.72 success=False time=97.3s geometry=cross_stream history=12 | q1=256.317 actor=87.375 alpha=0.043
# [train] episode=555 step=69126 return=-386.97 success=False time=158.4s geometry=cross_stream history=12 | q1=484.903 actor=96.822 alpha=0.042
# [train] episode=560 step=69822 return=-240.48 success=False time=35.4s geometry=cross_stream history=12 | q1=453.610 actor=92.671 alpha=0.040
# [train] episode=565 step=70386 return=-502.89 success=False time=99.0s geometry=cross_stream history=12 | q1=56.492 actor=92.450 alpha=0.040
# [train] episode=570 step=71742 return=-236.06 success=False time=31.9s geometry=cross_stream history=12 | q1=24.983 actor=94.346 alpha=0.038
# [train] episode=575 step=72246 return=-244.64 success=False time=20.9s geometry=cross_stream history=12 | q1=115.037 actor=98.260 alpha=0.038
# [train] episode=580 step=72432 return=-263.68 success=False time=8.1s geometry=cross_stream history=12 | q1=304.051 actor=95.325 alpha=0.038
# [train] episode=585 step=73134 return=-241.59 success=False time=28.0s geometry=cross_stream history=12 | q1=5.713 actor=93.917 alpha=0.038
# [train] episode=590 step=73824 return=-326.91 success=False time=56.8s geometry=cross_stream history=12 | q1=211.092 actor=92.785 alpha=0.037
# [train] episode=595 step=74724 return=-349.66 success=False time=62.8s geometry=cross_stream history=12 | q1=350.893 actor=99.026 alpha=0.037
# [eval] step=75000 objective=arrival_v2 return=-249.14 safety=12.861 success=6.67% time=97.7s energy=66043.0 path=98.9 prog=-0.38
# [train] episode=600 step=76242 return=-344.55 success=False time=58.4s geometry=cross_stream history=12 | q1=556.687 actor=98.608 alpha=0.038
# [train] episode=605 step=77394 return=-145.58 success=False time=221.9s geometry=cross_stream history=12 | q1=97.176 actor=101.096 alpha=0.038
# [train] episode=610 step=78540 return=-260.97 success=False time=192.2s geometry=cross_stream history=12 | q1=223.423 actor=104.349 alpha=0.037
# [train] episode=615 step=78846 return=-284.69 success=False time=41.2s geometry=cross_stream history=12 | q1=2.349 actor=102.173 alpha=0.037
# [train] episode=620 step=79644 return=-359.49 success=False time=73.6s geometry=cross_stream history=12 | q1=163.540 actor=102.023 alpha=0.037
# [train] episode=625 step=80328 return=-318.80 success=False time=56.2s geometry=cross_stream history=12 | q1=196.381 actor=104.524 alpha=0.037
# [train] episode=630 step=81384 return=-365.40 success=False time=233.3s geometry=cross_stream history=12 | q1=73.238 actor=104.768 alpha=0.036
# [train] episode=635 step=81606 return=-452.36 success=False time=120.1s geometry=cross_stream history=12 | q1=477.320 actor=108.834 alpha=0.036
# [train] episode=640 step=82236 return=-313.80 success=False time=52.0s geometry=cross_stream history=12 | q1=173.083 actor=97.714 alpha=0.036
# [train] episode=645 step=82980 return=-347.06 success=False time=60.8s geometry=cross_stream history=12 | q1=62.942 actor=105.679 alpha=0.035
# [train] episode=650 step=83544 return=-404.02 success=False time=67.1s geometry=cross_stream history=12 | q1=72.253 actor=107.005 alpha=0.035
# [train] episode=655 step=84024 return=-261.67 success=False time=44.4s geometry=cross_stream history=12 | q1=173.050 actor=112.945 alpha=0.035
# [train] episode=660 step=85962 return=-333.23 success=False time=178.2s geometry=cross_stream history=12 | q1=181.591 actor=107.207 alpha=0.033
# [train] episode=665 step=86358 return=-291.50 success=False time=153.5s geometry=cross_stream history=12 | q1=207.608 actor=107.863 alpha=0.033
# [train] episode=670 step=86838 return=-340.49 success=False time=64.7s geometry=cross_stream history=12 | q1=241.378 actor=109.841 alpha=0.032
# [train] episode=675 step=87780 return=-330.92 success=False time=77.7s geometry=cross_stream history=12 | q1=299.010 actor=111.109 alpha=0.032
# [train] episode=680 step=89034 return=-236.29 success=False time=222.2s geometry=cross_stream history=12 | q1=221.291 actor=110.570 alpha=0.032
# [train] episode=685 step=89616 return=-269.26 success=False time=195.2s geometry=cross_stream history=12 | q1=156.974 actor=113.410 alpha=0.031
# [train] episode=690 step=90378 return=-321.28 success=False time=62.9s geometry=cross_stream history=12 | q1=85.556 actor=113.438 alpha=0.030
# [train] episode=695 step=90930 return=-310.75 success=False time=52.0s geometry=cross_stream history=12 | q1=164.509 actor=114.809 alpha=0.031
# [train] episode=700 step=92202 return=-310.17 success=False time=52.3s geometry=cross_stream history=12 | q1=168.294 actor=112.441 alpha=0.031
# [train] episode=705 step=93270 return=-272.92 success=False time=240.1s geometry=cross_stream history=12 | q1=95.070 actor=111.169 alpha=0.031
# [train] episode=710 step=94410 return=-267.31 success=False time=53.3s geometry=cross_stream history=12 | q1=202.984 actor=117.062 alpha=0.033
# [train] episode=715 step=96186 return=-237.41 success=False time=224.2s geometry=cross_stream history=12 | q1=145.450 actor=116.466 alpha=0.035
# [train] episode=720 step=96870 return=-271.82 success=False time=147.3s geometry=cross_stream history=12 | q1=135.824 actor=119.421 alpha=0.035
# [train] episode=725 step=97722 return=-306.34 success=False time=52.2s geometry=cross_stream history=12 | q1=393.494 actor=115.195 alpha=0.035
# [train] episode=730 step=98688 return=-257.93 success=False time=79.8s geometry=cross_stream history=12 | q1=264.395 actor=123.740 alpha=0.035
# [train] episode=735 step=99354 return=-298.34 success=False time=206.2s geometry=cross_stream history=12 | q1=138.639 actor=120.719 alpha=0.034
# [eval] step=100002 objective=arrival_v2 return=-325.26 safety=16.992 success=0.00% time=80.1s energy=39037.4 path=93.4 prog=-0.85
# [train] episode=740 step=100068 return=-263.93 success=False time=114.1s geometry=cross_stream history=12 | q1=240.779 actor=124.674 alpha=0.034
# [train] episode=745 step=100956 return=-287.64 success=False time=53.7s geometry=cross_stream history=12 | q1=82.255 actor=122.853 alpha=0.034
# [train] episode=750 step=101598 return=-226.12 success=False time=41.6s geometry=cross_stream history=12 | q1=4.005 actor=121.613 alpha=0.034
# [train] episode=755 step=102336 return=-310.98 success=False time=125.3s geometry=cross_stream history=12 | q1=94.649 actor=119.833 alpha=0.033
# [train] episode=760 step=103062 return=-258.22 success=False time=9.8s geometry=cross_stream history=12 | q1=105.739 actor=120.827 alpha=0.032
# [train] episode=765 step=104268 return=-358.40 success=False time=103.3s geometry=cross_stream history=12 | q1=18.776 actor=122.172 alpha=0.033
# [train] episode=770 step=104550 return=-260.66 success=False time=7.3s geometry=cross_stream history=12 | q1=85.978 actor=128.895 alpha=0.033
# [train] episode=775 step=105180 return=-296.73 success=False time=53.1s geometry=cross_stream history=12 | q1=68.705 actor=119.258 alpha=0.032
# [train] episode=780 step=105876 return=-241.49 success=False time=52.8s geometry=cross_stream history=12 | q1=45.065 actor=120.869 alpha=0.033
# [train] episode=785 step=106650 return=-366.41 success=False time=76.6s geometry=cross_stream history=12 | q1=190.585 actor=124.464 alpha=0.032
# [train] episode=790 step=107574 return=-406.16 success=False time=86.9s geometry=cross_stream history=12 | q1=121.531 actor=127.223 alpha=0.032
# [train] episode=795 step=108294 return=-316.75 success=False time=55.0s geometry=cross_stream history=12 | q1=238.946 actor=126.353 alpha=0.032
# [train] episode=800 step=108954 return=-241.23 success=False time=49.1s geometry=cross_stream history=12 | q1=156.750 actor=127.795 alpha=0.034
# [train] episode=805 step=109746 return=-361.24 success=False time=63.5s geometry=cross_stream history=12 | q1=171.988 actor=122.485 alpha=0.034
# [train] episode=810 step=110526 return=-233.62 success=False time=42.7s geometry=cross_stream history=12 | q1=242.437 actor=132.611 alpha=0.035
# [train] episode=815 step=111600 return=-354.70 success=False time=61.8s geometry=cross_stream history=12 | q1=221.328 actor=130.286 alpha=0.035
# [train] episode=820 step=112470 return=-350.30 success=False time=66.6s geometry=cross_stream history=12 | q1=58.244 actor=129.340 alpha=0.036
# [train] episode=825 step=113580 return=-255.32 success=False time=135.7s geometry=cross_stream history=12 | q1=128.638 actor=129.325 alpha=0.035
# [train] episode=830 step=114312 return=-348.55 success=False time=73.8s geometry=cross_stream history=12 | q1=74.438 actor=129.956 alpha=0.035
# [train] episode=835 step=115146 return=-307.43 success=False time=56.5s geometry=cross_stream history=12 | q1=33.277 actor=134.090 alpha=0.034
# [train] episode=840 step=116046 return=-351.28 success=False time=71.2s geometry=cross_stream history=12 | q1=54.073 actor=126.095 alpha=0.033
# [train] episode=845 step=117054 return=-332.51 success=False time=58.2s geometry=cross_stream history=12 | q1=67.768 actor=132.849 alpha=0.032
# [train] episode=850 step=117564 return=-258.91 success=False time=41.6s geometry=cross_stream history=12 | q1=133.084 actor=131.700 alpha=0.031
# [train] episode=855 step=118470 return=-358.35 success=False time=67.1s geometry=cross_stream history=12 | q1=91.604 actor=129.793 alpha=0.030
# [train] episode=860 step=119610 return=-341.14 success=False time=68.8s geometry=cross_stream history=12 | q1=6.109 actor=135.328 alpha=0.030
# [train] episode=865 step=120102 return=-305.99 success=False time=58.2s geometry=cross_stream history=12 | q1=120.304 actor=134.041 alpha=0.030
# [train] episode=870 step=121110 return=-263.53 success=False time=83.4s geometry=cross_stream history=12 | q1=20.117 actor=133.896 alpha=0.030
# [train] episode=875 step=121332 return=-328.81 success=False time=116.2s geometry=cross_stream history=12 | q1=174.455 actor=131.247 alpha=0.030
# [train] episode=880 step=121956 return=-350.06 success=False time=59.9s geometry=cross_stream history=12 | q1=142.620 actor=135.614 alpha=0.030
# [train] episode=885 step=122700 return=-335.08 success=False time=61.3s geometry=cross_stream history=12 | q1=24.167 actor=131.051 alpha=0.029
# [train] episode=890 step=123672 return=-325.84 success=False time=110.0s geometry=cross_stream history=12 | q1=233.515 actor=135.410 alpha=0.031
# [train] episode=895 step=124794 return=-305.58 success=False time=58.1s geometry=cross_stream history=12 | q1=64.964 actor=140.132 alpha=0.031
# [eval] step=125004 objective=arrival_v2 return=-310.54 safety=16.896 success=0.00% time=91.9s energy=43633.8 path=94.4 prog=-0.76
# [train] episode=900 step=125634 return=-240.93 success=False time=240.1s geometry=cross_stream history=12 | q1=24.320 actor=135.267 alpha=0.031
# [train] episode=905 step=126756 return=-342.59 success=False time=65.2s geometry=cross_stream history=12 | q1=229.633 actor=133.089 alpha=0.032
# [train] episode=910 step=127344 return=-195.19 success=False time=240.1s geometry=cross_stream history=12 | q1=14.658 actor=134.285 alpha=0.033
# [train] episode=915 step=128028 return=-505.69 success=False time=120.0s geometry=cross_stream history=12 | q1=204.188 actor=136.850 alpha=0.032
# [train] episode=920 step=128652 return=-306.53 success=False time=71.2s geometry=cross_stream history=12 | q1=157.425 actor=138.532 alpha=0.032
# [train] episode=925 step=129312 return=-318.32 success=False time=81.4s geometry=cross_stream history=12 | q1=128.274 actor=137.401 alpha=0.031
# [train] episode=930 step=129852 return=-295.26 success=False time=24.3s geometry=cross_stream history=12 | q1=260.293 actor=136.045 alpha=0.031
# [train] episode=935 step=130572 return=-356.22 success=False time=68.9s geometry=cross_stream history=12 | q1=166.510 actor=137.706 alpha=0.031
# [train] episode=940 step=131280 return=-278.72 success=False time=118.1s geometry=cross_stream history=12 | q1=62.957 actor=133.552 alpha=0.031
# [train] episode=945 step=131748 return=-329.55 success=False time=80.1s geometry=cross_stream history=12 | q1=133.086 actor=139.620 alpha=0.031
# [train] episode=950 step=133038 return=-268.17 success=False time=18.2s geometry=cross_stream history=12 | q1=194.949 actor=138.887 alpha=0.031
# [train] episode=955 step=133836 return=-301.72 success=False time=56.6s geometry=cross_stream history=12 | q1=62.292 actor=139.181 alpha=0.031
# [train] episode=960 step=134832 return=-386.19 success=False time=76.3s geometry=cross_stream history=12 | q1=78.665 actor=140.786 alpha=0.032
# [train] episode=965 step=135816 return=-374.00 success=False time=81.4s geometry=cross_stream history=12 | q1=83.629 actor=139.571 alpha=0.033
# [train] episode=970 step=136890 return=-352.72 success=False time=81.6s geometry=cross_stream history=12 | q1=24.201 actor=141.396 alpha=0.033
# [train] episode=975 step=137502 return=-360.49 success=False time=61.8s geometry=cross_stream history=12 | q1=100.111 actor=138.982 alpha=0.032
# [train] episode=980 step=137814 return=-373.05 success=False time=75.5s geometry=cross_stream history=12 | q1=17.381 actor=142.757 alpha=0.032
# [train] episode=985 step=138666 return=-262.23 success=False time=23.2s geometry=cross_stream history=12 | q1=38.545 actor=142.582 alpha=0.032
# [train] episode=990 step=139554 return=-397.49 success=False time=84.4s geometry=cross_stream history=12 | q1=90.925 actor=141.920 alpha=0.032
# [train] episode=995 step=140112 return=-384.00 success=False time=115.3s geometry=cross_stream history=12 | q1=116.392 actor=139.375 alpha=0.031
# [train] episode=1000 step=141192 return=-223.55 success=False time=108.3s geometry=cross_stream history=12 | q1=38.786 actor=138.460 alpha=0.031
# [train] episode=1005 step=141918 return=-239.58 success=False time=16.1s geometry=cross_stream history=12 | q1=145.221 actor=140.064 alpha=0.031
# [train] episode=1010 step=142356 return=-272.24 success=False time=192.9s geometry=cross_stream history=12 | q1=96.152 actor=141.412 alpha=0.031
# [train] episode=1015 step=143112 return=-327.39 success=False time=65.8s geometry=cross_stream history=12 | q1=94.796 actor=142.494 alpha=0.031
# [train] episode=1020 step=143550 return=-248.82 success=False time=9.3s geometry=cross_stream history=12 | q1=74.907 actor=143.304 alpha=0.032
# [train] episode=1025 step=144660 return=-299.36 success=False time=55.7s geometry=cross_stream history=12 | q1=60.341 actor=144.436 alpha=0.031
# [train] episode=1030 step=145824 return=-320.66 success=False time=202.4s geometry=cross_stream history=12 | q1=74.067 actor=142.764 alpha=0.031
# [train] episode=1035 step=146580 return=-348.78 success=False time=208.1s geometry=cross_stream history=12 | q1=8.156 actor=146.634 alpha=0.032
# [train] episode=1040 step=147222 return=-290.84 success=False time=47.7s geometry=cross_stream history=12 | q1=56.317 actor=145.028 alpha=0.032
# [train] episode=1045 step=148290 return=-396.72 success=False time=80.5s geometry=cross_stream history=12 | q1=79.250 actor=147.264 alpha=0.032
# [train] episode=1050 step=148692 return=-317.19 success=False time=121.9s geometry=cross_stream history=12 | q1=68.523 actor=148.907 alpha=0.032
# [train] episode=1055 step=149004 return=-208.79 success=False time=28.8s geometry=cross_stream history=12 | q1=70.835 actor=142.494 alpha=0.031
# [train] episode=1060 step=149916 return=-289.14 success=False time=53.6s geometry=cross_stream history=12 | q1=112.417 actor=144.901 alpha=0.031
# [eval] step=150000 objective=arrival_v2 return=-253.31 safety=14.357 success=3.33% time=71.1s energy=47489.0 path=76.7 prog=-0.12
# [train] episode=1065 step=151380 return=-262.41 success=False time=214.5s geometry=cross_stream history=12 | q1=148.893 actor=146.247 alpha=0.030
# [train] episode=1070 step=152292 return=-374.68 success=False time=75.4s geometry=cross_stream history=12 | q1=59.076 actor=147.211 alpha=0.030
# [train] episode=1075 step=153012 return=-221.34 success=False time=59.1s geometry=cross_stream history=12 | q1=55.061 actor=144.386 alpha=0.030
# [train] episode=1080 step=153780 return=-348.21 success=False time=63.1s geometry=cross_stream history=12 | q1=185.873 actor=149.299 alpha=0.030
# [train] episode=1085 step=154542 return=-351.70 success=False time=62.6s geometry=cross_stream history=12 | q1=179.224 actor=148.748 alpha=0.030
# [train] episode=1090 step=155838 return=-385.89 success=False time=146.3s geometry=cross_stream history=12 | q1=95.554 actor=146.233 alpha=0.030
# [train] episode=1095 step=156228 return=-254.13 success=False time=18.0s geometry=cross_stream history=12 | q1=147.053 actor=148.964 alpha=0.030
# [train] episode=1100 step=156870 return=-357.57 success=False time=71.1s geometry=cross_stream history=12 | q1=145.986 actor=149.193 alpha=0.029
# [train] episode=1105 step=157884 return=-292.00 success=False time=54.2s geometry=cross_stream history=12 | q1=2.130 actor=148.920 alpha=0.029
# [train] episode=1110 step=158658 return=-350.53 success=False time=71.1s geometry=cross_stream history=12 | q1=117.623 actor=148.686 alpha=0.028
# [train] episode=1115 step=159768 return=-255.17 success=False time=18.4s geometry=cross_stream history=12 | q1=27.531 actor=148.148 alpha=0.029
# [train] episode=1120 step=160266 return=-275.39 success=False time=46.8s geometry=cross_stream history=12 | q1=38.175 actor=150.266 alpha=0.029
# [train] episode=1125 step=161160 return=-458.07 success=False time=104.4s geometry=cross_stream history=12 | q1=85.828 actor=149.564 alpha=0.028
# [train] episode=1130 step=162132 return=-325.45 success=False time=158.3s geometry=cross_stream history=12 | q1=98.230 actor=151.310 alpha=0.028
# [train] episode=1135 step=162840 return=-314.04 success=False time=48.7s geometry=cross_stream history=12 | q1=114.533 actor=150.556 alpha=0.029
# [train] episode=1140 step=163488 return=-237.61 success=False time=21.3s geometry=cross_stream history=12 | q1=124.753 actor=151.696 alpha=0.028
# [train] episode=1145 step=164220 return=-243.08 success=False time=12.9s geometry=cross_stream history=12 | q1=47.953 actor=150.493 alpha=0.028
# [train] episode=1150 step=165084 return=-352.06 success=False time=71.5s geometry=cross_stream history=12 | q1=131.265 actor=149.867 alpha=0.028
# [train] episode=1155 step=165546 return=-236.44 success=False time=110.9s geometry=cross_stream history=12 | q1=37.646 actor=150.716 alpha=0.028
# [train] episode=1160 step=166182 return=-269.52 success=False time=28.4s geometry=cross_stream history=12 | q1=107.318 actor=153.038 alpha=0.028
# [train] episode=1165 step=167760 return=-204.00 success=False time=85.7s geometry=cross_stream history=12 | q1=112.820 actor=154.595 alpha=0.028
# [train] episode=1170 step=168276 return=-300.70 success=False time=45.8s geometry=cross_stream history=12 | q1=51.469 actor=150.787 alpha=0.028
# [train] episode=1175 step=168846 return=-278.53 success=False time=21.2s geometry=cross_stream history=12 | q1=80.945 actor=148.924 alpha=0.028
# [train] episode=1180 step=169296 return=-252.86 success=False time=37.0s geometry=cross_stream history=12 | q1=2.858 actor=153.512 alpha=0.029
# [train] episode=1185 step=170070 return=-305.93 success=False time=78.3s geometry=cross_stream history=12 | q1=30.162 actor=153.847 alpha=0.030
# [train] episode=1190 step=170772 return=-263.53 success=False time=44.7s geometry=cross_stream history=12 | q1=3.386 actor=154.773 alpha=0.029
# [train] episode=1195 step=171912 return=-167.60 success=False time=94.2s geometry=cross_stream history=12 | q1=42.398 actor=149.331 alpha=0.029
# [train] episode=1200 step=172662 return=-170.07 success=False time=109.1s geometry=cross_stream history=12 | q1=112.991 actor=152.658 alpha=0.029
# [train] episode=1205 step=173760 return=-440.25 success=False time=90.6s geometry=cross_stream history=12 | q1=69.853 actor=151.133 alpha=0.029
# [train] episode=1210 step=174840 return=-209.72 success=False time=97.4s geometry=cross_stream history=12 | q1=101.801 actor=156.740 alpha=0.029
# [eval] step=175002 objective=arrival_v2 return=-276.13 safety=12.738 success=0.00% time=60.6s energy=36384.5 path=73.9 prog=-0.30
# [train] episode=1215 step=175878 return=-353.79 success=False time=66.0s geometry=cross_stream history=12 | q1=138.374 actor=156.776 alpha=0.029
# [train] episode=1220 step=176736 return=-360.20 success=False time=70.8s geometry=cross_stream history=12 | q1=127.923 actor=156.135 alpha=0.029
# [train] episode=1225 step=177210 return=-336.18 success=False time=55.3s geometry=cross_stream history=12 | q1=74.977 actor=155.800 alpha=0.030
# [train] episode=1230 step=177720 return=-288.88 success=False time=42.7s geometry=cross_stream history=12 | q1=127.810 actor=156.021 alpha=0.029
# [train] episode=1235 step=178104 return=-348.75 success=False time=62.3s geometry=cross_stream history=12 | q1=65.383 actor=152.689 alpha=0.028
# [train] episode=1240 step=178944 return=-167.31 success=False time=74.1s geometry=cross_stream history=12 | q1=65.843 actor=156.127 alpha=0.029
# [train] episode=1245 step=179964 return=-362.00 success=False time=73.3s geometry=cross_stream history=12 | q1=2.495 actor=156.002 alpha=0.028
# [train] episode=1250 step=180612 return=-311.80 success=False time=53.4s geometry=cross_stream history=12 | q1=82.378 actor=155.759 alpha=0.028
# [train] episode=1255 step=181290 return=-354.81 success=False time=66.1s geometry=cross_stream history=12 | q1=128.368 actor=157.644 alpha=0.027
# [train] episode=1260 step=182502 return=-345.62 success=False time=51.8s geometry=cross_stream history=12 | q1=45.012 actor=156.241 alpha=0.027
# [train] episode=1265 step=183078 return=-296.12 success=False time=58.6s geometry=cross_stream history=12 | q1=152.718 actor=157.001 alpha=0.028
# [train] episode=1270 step=184026 return=-215.69 success=False time=60.5s geometry=cross_stream history=12 | q1=240.215 actor=154.649 alpha=0.028
# [train] episode=1275 step=184758 return=-289.16 success=False time=58.9s geometry=cross_stream history=12 | q1=47.018 actor=157.157 alpha=0.026
# [train] episode=1280 step=185376 return=-283.35 success=False time=31.9s geometry=cross_stream history=12 | q1=105.119 actor=155.060 alpha=0.026
# [train] episode=1285 step=185712 return=-244.43 success=False time=24.9s geometry=cross_stream history=12 | q1=58.977 actor=156.099 alpha=0.026
# [train] episode=1290 step=186156 return=-183.32 success=False time=61.1s geometry=cross_stream history=12 | q1=47.536 actor=157.149 alpha=0.026
# [train] episode=1295 step=186792 return=-304.63 success=False time=65.5s geometry=cross_stream history=12 | q1=42.691 actor=154.917 alpha=0.026
# [train] episode=1300 step=187416 return=-197.18 success=False time=74.8s geometry=cross_stream history=12 | q1=10.657 actor=157.017 alpha=0.026
# [train] episode=1305 step=188172 return=-308.97 success=False time=55.7s geometry=cross_stream history=12 | q1=80.629 actor=157.430 alpha=0.026
# [train] episode=1310 step=188754 return=-266.13 success=False time=163.0s geometry=cross_stream history=12 | q1=82.595 actor=158.664 alpha=0.026
# [train] episode=1315 step=189534 return=-302.76 success=False time=57.1s geometry=cross_stream history=12 | q1=196.597 actor=161.288 alpha=0.026
# [train] episode=1320 step=190410 return=-348.70 success=False time=72.9s geometry=cross_stream history=12 | q1=74.360 actor=157.920 alpha=0.026
# [train] episode=1325 step=190872 return=-253.32 success=False time=47.5s geometry=cross_stream history=12 | q1=65.200 actor=158.292 alpha=0.026
# [train] episode=1330 step=191244 return=-280.22 success=False time=50.4s geometry=cross_stream history=12 | q1=38.301 actor=157.476 alpha=0.026
# [train] episode=1335 step=191802 return=-311.68 success=False time=45.7s geometry=cross_stream history=12 | q1=65.367 actor=157.285 alpha=0.025
# [train] episode=1340 step=192438 return=-250.00 success=False time=28.6s geometry=cross_stream history=12 | q1=42.095 actor=159.844 alpha=0.025
# [train] episode=1345 step=193038 return=-245.32 success=False time=13.6s geometry=cross_stream history=12 | q1=77.739 actor=160.706 alpha=0.025
# [train] episode=1350 step=193758 return=-309.67 success=False time=52.1s geometry=cross_stream history=12 | q1=88.870 actor=159.285 alpha=0.025
# [train] episode=1355 step=194412 return=-260.95 success=False time=17.4s geometry=cross_stream history=12 | q1=73.607 actor=159.742 alpha=0.025
# [train] episode=1360 step=194898 return=-235.15 success=False time=27.2s geometry=cross_stream history=12 | q1=31.776 actor=157.414 alpha=0.024
# [train] episode=1365 step=195522 return=-181.30 success=False time=83.4s geometry=cross_stream history=12 | q1=109.385 actor=160.460 alpha=0.024
# [train] episode=1370 step=195984 return=-187.27 success=False time=48.9s geometry=cross_stream history=12 | q1=113.556 actor=161.092 alpha=0.024
# [train] episode=1375 step=196290 return=-195.52 success=False time=52.9s geometry=cross_stream history=12 | q1=68.957 actor=158.644 alpha=0.024
# [train] episode=1380 step=197154 return=-347.97 success=False time=71.1s geometry=cross_stream history=12 | q1=37.680 actor=161.681 alpha=0.024
# [train] episode=1385 step=197550 return=-201.72 success=False time=58.5s geometry=cross_stream history=12 | q1=82.649 actor=160.304 alpha=0.024
# [train] episode=1390 step=198102 return=-319.67 success=False time=60.8s geometry=cross_stream history=12 | q1=4.818 actor=158.064 alpha=0.024
# [train] episode=1395 step=198636 return=-361.16 success=False time=61.1s geometry=cross_stream history=12 | q1=98.363 actor=161.724 alpha=0.024
# [train] episode=1400 step=199110 return=-330.07 success=False time=88.4s geometry=cross_stream history=12 | q1=79.794 actor=156.101 alpha=0.025
# [train] episode=1405 step=199794 return=-381.30 success=False time=68.9s geometry=cross_stream history=12 | q1=46.774 actor=160.927 alpha=0.024
# [eval] step=200004 objective=arrival_v2 return=-293.27 safety=13.489 success=0.00% time=57.8s energy=34815.3 path=80.9 prog=-0.52
# [train] episode=1410 step=200508 return=-311.75 success=False time=58.7s geometry=cross_stream history=12 | q1=36.513 actor=160.822 alpha=0.024
# [train] episode=1415 step=201258 return=-274.46 success=False time=121.7s geometry=cross_stream history=12 | q1=32.161 actor=162.164 alpha=0.025
# [train] episode=1420 step=202044 return=-330.50 success=False time=64.7s geometry=cross_stream history=12 | q1=46.312 actor=162.211 alpha=0.025
# [train] episode=1425 step=202686 return=-181.29 success=False time=69.2s geometry=cross_stream history=12 | q1=28.268 actor=163.254 alpha=0.025
# [train] episode=1430 step=203430 return=-302.73 success=False time=48.2s geometry=cross_stream history=12 | q1=47.587 actor=159.341 alpha=0.025
# [train] episode=1435 step=204090 return=-259.91 success=False time=43.9s geometry=cross_stream history=12 | q1=15.175 actor=161.412 alpha=0.025
# [train] episode=1440 step=204840 return=-191.21 success=False time=56.6s geometry=cross_stream history=12 | q1=74.698 actor=160.441 alpha=0.026
# [train] episode=1445 step=205434 return=-209.91 success=False time=43.3s geometry=cross_stream history=12 | q1=74.321 actor=162.619 alpha=0.026
# [train] episode=1450 step=206034 return=-333.02 success=False time=151.3s geometry=cross_stream history=12 | q1=61.238 actor=159.642 alpha=0.026
# [train] episode=1455 step=206712 return=-237.95 success=False time=60.0s geometry=cross_stream history=12 | q1=40.318 actor=162.250 alpha=0.026
# [train] episode=1460 step=207294 return=-306.45 success=False time=52.7s geometry=cross_stream history=12 | q1=42.373 actor=162.604 alpha=0.027
# [train] episode=1465 step=207978 return=-254.06 success=False time=16.4s geometry=cross_stream history=12 | q1=36.861 actor=159.567 alpha=0.027
# [train] episode=1470 step=208206 return=-379.80 success=False time=77.0s geometry=cross_stream history=12 | q1=130.457 actor=161.539 alpha=0.027
# [train] episode=1475 step=209370 return=-265.55 success=False time=110.8s geometry=cross_stream history=12 | q1=71.643 actor=162.754 alpha=0.027
# [train] episode=1480 step=209784 return=-257.31 success=False time=131.0s geometry=cross_stream history=12 | q1=97.056 actor=161.919 alpha=0.028
# [train] episode=1485 step=210498 return=-349.74 success=False time=66.1s geometry=cross_stream history=12 | q1=62.796 actor=160.340 alpha=0.028
# [train] episode=1490 step=211074 return=-267.29 success=False time=47.5s geometry=cross_stream history=12 | q1=50.771 actor=163.389 alpha=0.028
# [train] episode=1495 step=211560 return=-281.69 success=False time=40.0s geometry=cross_stream history=12 | q1=57.028 actor=161.665 alpha=0.028
# [train] episode=1500 step=211878 return=-232.27 success=False time=18.8s geometry=cross_stream history=12 | q1=69.507 actor=160.055 alpha=0.028
# [train] episode=1505 step=212424 return=-258.76 success=False time=45.0s geometry=cross_stream history=12 | q1=94.148 actor=163.565 alpha=0.029
# [train] episode=1510 step=212910 return=-235.86 success=False time=36.8s geometry=cross_stream history=12 | q1=57.948 actor=162.484 alpha=0.030
# [train] episode=1515 step=213492 return=-183.30 success=False time=57.2s geometry=cross_stream history=12 | q1=71.860 actor=161.425 alpha=0.030
# [train] episode=1520 step=214530 return=-352.52 success=False time=61.4s geometry=cross_stream history=12 | q1=25.357 actor=163.194 alpha=0.031
# [train] episode=1525 step=215448 return=-191.42 success=False time=57.8s geometry=cross_stream history=12 | q1=58.607 actor=162.099 alpha=0.031
# [train] episode=1530 step=215862 return=-274.01 success=False time=28.7s geometry=cross_stream history=12 | q1=64.370 actor=161.459 alpha=0.032
# [train] episode=1535 step=216540 return=-251.76 success=False time=15.7s geometry=cross_stream history=12 | q1=20.765 actor=160.038 alpha=0.032
# [train] episode=1540 step=217002 return=-247.19 success=False time=37.9s geometry=cross_stream history=12 | q1=25.025 actor=160.747 alpha=0.032
# [train] episode=1545 step=217560 return=-311.83 success=False time=50.9s geometry=cross_stream history=12 | q1=34.796 actor=161.780 alpha=0.031
# [train] episode=1550 step=218328 return=-270.99 success=False time=64.6s geometry=cross_stream history=12 | q1=63.771 actor=160.047 alpha=0.031
# [train] episode=1555 step=219078 return=-170.92 success=False time=61.9s geometry=cross_stream history=12 | q1=120.207 actor=162.638 alpha=0.032
# [train] episode=1560 step=219750 return=-345.69 success=False time=55.3s geometry=cross_stream history=12 | q1=113.458 actor=169.037 alpha=0.032
# [train] episode=1565 step=220482 return=-283.54 success=False time=37.6s geometry=cross_stream history=12 | q1=16.845 actor=162.972 alpha=0.033
# [train] episode=1570 step=221280 return=-256.58 success=False time=113.3s geometry=cross_stream history=12 | q1=36.362 actor=162.549 alpha=0.033
# [train] episode=1575 step=221922 return=-201.77 success=False time=60.3s geometry=cross_stream history=12 | q1=12.915 actor=162.617 alpha=0.032
# [train] episode=1580 step=222372 return=-245.42 success=False time=90.5s geometry=cross_stream history=12 | q1=57.608 actor=160.566 alpha=0.032
# [train] episode=1585 step=223116 return=-249.70 success=False time=85.7s geometry=cross_stream history=12 | q1=48.277 actor=162.229 alpha=0.032
# [train] episode=1590 step=223692 return=-301.54 success=False time=47.1s geometry=cross_stream history=12 | q1=64.394 actor=161.874 alpha=0.032
# [train] episode=1595 step=224328 return=-222.54 success=False time=14.0s geometry=cross_stream history=12 | q1=69.748 actor=163.119 alpha=0.032
# [train] episode=1600 step=224856 return=-247.32 success=False time=9.0s geometry=cross_stream history=12 | q1=28.461 actor=160.373 alpha=0.032
# [eval] step=225000 objective=arrival_v2 return=-214.85 safety=13.784 success=10.00% time=64.1s energy=51076.1 path=67.2 prog=0.09
# [train] episode=1605 step=225432 return=-257.43 success=False time=47.2s geometry=cross_stream history=12 | q1=21.046 actor=160.591 alpha=0.032
# [train] episode=1610 step=226566 return=-302.06 success=False time=48.7s geometry=cross_stream history=12 | q1=7.161 actor=161.275 alpha=0.032
# [train] episode=1615 step=226950 return=-257.62 success=False time=125.6s geometry=cross_stream history=12 | q1=25.146 actor=162.129 alpha=0.033
# [train] episode=1620 step=228186 return=-267.31 success=False time=104.7s geometry=cross_stream history=12 | q1=70.430 actor=163.364 alpha=0.035
# [train] episode=1625 step=229014 return=-334.82 success=False time=55.1s geometry=cross_stream history=12 | q1=75.925 actor=164.821 alpha=0.035
# [train] episode=1630 step=230160 return=-334.82 success=False time=62.1s geometry=cross_stream history=12 | q1=79.991 actor=163.917 alpha=0.034
# [train] episode=1635 step=231162 return=-186.30 success=False time=240.1s geometry=cross_stream history=12 | q1=7.911 actor=165.802 alpha=0.034
# [train] episode=1640 step=231846 return=-329.35 success=False time=56.3s geometry=cross_stream history=12 | q1=6.822 actor=159.066 alpha=0.035
# ...
# [train] episode=4910 step=911970 return=135.40 success=True time=99.8s geometry=cross_stream history=12 | q1=49.301 actor=61.437 alpha=0.132
# [train] episode=4915 step=912720 return=-354.57 success=False time=61.6s geometry=cross_stream history=12 | q1=6.221 actor=59.431 alpha=0.130
# [train] episode=4920 step=913770 return=138.94 success=True time=96.3s geometry=cross_stream history=12 | q1=92.111 actor=59.459 alpha=0.135
# [train] episode=4925 step=914604 return=-249.42 success=False time=11.5s geometry=cross_stream history=12 | q1=143.242 actor=58.273 alpha=0.137
# [train] episode=4930 step=915348 return=135.36 success=True time=130.7s geometry=cross_stream history=12 | q1=42.867 actor=62.713 alpha=0.141
# [train] episode=4935 step=916464 return=134.68 success=True time=92.5s geometry=cross_stream history=12 | q1=71.396 actor=60.975 alpha=0.141
# [train] episode=4940 step=917376 return=137.11 success=True time=99.6s geometry=cross_stream history=12 | q1=143.968 actor=57.099 alpha=0.146
# [train] episode=4945 step=918642 return=85.97 success=True time=104.9s geometry=cross_stream history=12 | q1=62.308 actor=57.409 alpha=0.142
# [train] episode=4950 step=918900 return=118.04 success=True time=115.6s geometry=cross_stream history=12 | q1=23.950 actor=57.147 alpha=0.141
# [train] episode=4955 step=919662 return=140.20 success=True time=72.8s geometry=cross_stream history=12 | q1=28.724 actor=62.514 alpha=0.139
# [train] episode=4960 step=920580 return=136.81 success=True time=68.3s geometry=cross_stream history=12 | q1=44.487 actor=62.394 alpha=0.136
# [train] episode=4965 step=921594 return=92.47 success=True time=76.7s geometry=cross_stream history=12 | q1=187.098 actor=58.195 alpha=0.130
# [train] episode=4970 step=922500 return=139.89 success=True time=74.9s geometry=cross_stream history=12 | q1=155.179 actor=61.013 alpha=0.129
# [train] episode=4975 step=922932 return=140.77 success=True time=88.7s geometry=cross_stream history=12 | q1=63.681 actor=58.129 alpha=0.128
# [train] episode=4980 step=923868 return=136.77 success=True time=92.9s geometry=cross_stream history=12 | q1=97.420 actor=56.559 alpha=0.131
# [eval] step=925002 objective=arrival_v2 return=74.96 safety=13.026 success=86.67% time=88.6s energy=69969.1 path=67.8 prog=0.83
# [train] episode=4985 step=925038 return=121.88 success=True time=96.0s geometry=cross_stream history=12 | q1=113.488 actor=57.895 alpha=0.133
# [train] episode=4990 step=925650 return=142.22 success=True time=74.6s geometry=cross_stream history=12 | q1=58.716 actor=50.723 alpha=0.137
# [train] episode=4995 step=926718 return=-375.93 success=False time=88.2s geometry=cross_stream history=12 | q1=5.440 actor=55.616 alpha=0.138
# [train] episode=5000 step=927570 return=138.61 success=True time=99.4s geometry=cross_stream history=12 | q1=85.915 actor=59.043 alpha=0.135
# [train] episode=5005 step=928050 return=114.82 success=True time=99.4s geometry=cross_stream history=12 | q1=47.614 actor=57.723 alpha=0.133
# [train] episode=5010 step=928812 return=138.06 success=True time=77.4s geometry=cross_stream history=12 | q1=50.882 actor=50.674 alpha=0.134
# [train] episode=5015 step=929646 return=140.62 success=True time=68.8s geometry=cross_stream history=12 | q1=80.084 actor=55.229 alpha=0.131
# [train] episode=5020 step=930768 return=114.28 success=True time=97.7s geometry=cross_stream history=12 | q1=136.812 actor=57.202 alpha=0.130
# [train] episode=5025 step=931476 return=134.94 success=True time=151.6s geometry=cross_stream history=12 | q1=7.366 actor=57.817 alpha=0.131
# [train] episode=5030 step=932178 return=-216.46 success=False time=31.8s geometry=cross_stream history=12 | q1=107.637 actor=53.074 alpha=0.134
# [train] episode=5035 step=932910 return=139.79 success=True time=73.5s geometry=cross_stream history=12 | q1=66.382 actor=57.381 alpha=0.136
# [train] episode=5040 step=933516 return=138.62 success=True time=49.9s geometry=cross_stream history=12 | q1=31.854 actor=52.319 alpha=0.137
# [train] episode=5045 step=934290 return=133.34 success=True time=63.9s geometry=cross_stream history=12 | q1=81.464 actor=61.891 alpha=0.138
# [train] episode=5050 step=934920 return=23.03 success=True time=72.3s geometry=cross_stream history=12 | q1=239.271 actor=57.112 alpha=0.137
# [train] episode=5055 step=935736 return=81.94 success=True time=67.3s geometry=cross_stream history=12 | q1=237.202 actor=57.549 alpha=0.138
# [train] episode=5060 step=936408 return=138.72 success=True time=110.4s geometry=cross_stream history=12 | q1=21.842 actor=58.248 alpha=0.136
# [train] episode=5065 step=937080 return=94.19 success=True time=87.8s geometry=cross_stream history=12 | q1=5.947 actor=60.262 alpha=0.136
# [train] episode=5070 step=937632 return=-276.88 success=False time=45.4s geometry=cross_stream history=12 | q1=223.586 actor=66.640 alpha=0.135
# [train] episode=5075 step=938676 return=141.30 success=True time=90.0s geometry=cross_stream history=12 | q1=96.538 actor=56.662 alpha=0.138
# [train] episode=5080 step=939354 return=138.60 success=True time=55.7s geometry=cross_stream history=12 | q1=8.651 actor=53.148 alpha=0.141
# [train] episode=5085 step=940080 return=137.96 success=True time=60.0s geometry=cross_stream history=12 | q1=212.618 actor=60.088 alpha=0.142
# [train] episode=5090 step=941436 return=138.28 success=True time=112.4s geometry=cross_stream history=12 | q1=50.382 actor=59.164 alpha=0.143
# [train] episode=5095 step=942240 return=137.60 success=True time=109.8s geometry=cross_stream history=12 | q1=31.264 actor=53.570 alpha=0.142
# [train] episode=5100 step=943236 return=137.82 success=True time=111.7s geometry=cross_stream history=12 | q1=41.724 actor=60.945 alpha=0.140
# [train] episode=5105 step=944274 return=138.44 success=True time=73.1s geometry=cross_stream history=12 | q1=190.941 actor=55.749 alpha=0.141
# [train] episode=5110 step=944568 return=134.40 success=True time=110.5s geometry=cross_stream history=12 | q1=132.061 actor=59.549 alpha=0.141
# [train] episode=5115 step=946104 return=-50.68 success=True time=108.5s geometry=cross_stream history=12 | q1=70.739 actor=54.171 alpha=0.136
# [train] episode=5120 step=947400 return=141.29 success=True time=107.1s geometry=cross_stream history=12 | q1=110.456 actor=53.417 alpha=0.134
# [train] episode=5125 step=948078 return=136.10 success=True time=239.6s geometry=cross_stream history=12 | q1=30.707 actor=61.721 alpha=0.131
# [train] episode=5130 step=948810 return=125.55 success=True time=65.1s geometry=cross_stream history=12 | q1=8.431 actor=51.545 alpha=0.131
# [train] episode=5135 step=949452 return=141.46 success=True time=52.8s geometry=cross_stream history=12 | q1=22.735 actor=59.643 alpha=0.129
# [train] episode=5140 step=949662 return=-257.84 success=False time=5.8s geometry=cross_stream history=12 | q1=74.054 actor=57.506 alpha=0.128
# [eval] step=950004 objective=arrival_v2 return=80.75 safety=10.089 success=86.67% time=85.0s energy=67072.4 path=66.5 prog=0.83
# [train] episode=5145 step=950844 return=139.92 success=True time=77.0s geometry=cross_stream history=12 | q1=38.897 actor=54.759 alpha=0.128
# [train] episode=5150 step=951960 return=137.82 success=True time=76.1s geometry=cross_stream history=12 | q1=112.333 actor=51.422 alpha=0.126
# [train] episode=5155 step=952434 return=-275.30 success=False time=27.4s geometry=cross_stream history=12 | q1=129.039 actor=63.656 alpha=0.128
# [train] episode=5160 step=953322 return=141.99 success=True time=76.2s geometry=cross_stream history=12 | q1=200.327 actor=53.607 alpha=0.129
# [train] episode=5165 step=954444 return=122.80 success=True time=104.2s geometry=cross_stream history=12 | q1=89.927 actor=56.747 alpha=0.127
# [train] episode=5170 step=955236 return=140.31 success=True time=76.0s geometry=cross_stream history=12 | q1=75.390 actor=56.112 alpha=0.127
# [train] episode=5175 step=955812 return=140.24 success=True time=56.5s geometry=cross_stream history=12 | q1=49.958 actor=54.428 alpha=0.126
# [train] episode=5180 step=956394 return=123.29 success=True time=48.0s geometry=cross_stream history=12 | q1=76.774 actor=56.109 alpha=0.124
# [train] episode=5185 step=957462 return=70.51 success=True time=102.3s geometry=cross_stream history=12 | q1=150.131 actor=61.102 alpha=0.125
# [train] episode=5190 step=957972 return=138.29 success=True time=53.1s geometry=cross_stream history=12 | q1=15.160 actor=62.499 alpha=0.126
# [train] episode=5195 step=958824 return=138.20 success=True time=83.6s geometry=cross_stream history=12 | q1=144.010 actor=55.543 alpha=0.125
# [train] episode=5200 step=959640 return=115.53 success=True time=78.8s geometry=cross_stream history=12 | q1=111.853 actor=51.913 alpha=0.127
# [train] episode=5205 step=960642 return=140.93 success=True time=85.6s geometry=cross_stream history=12 | q1=205.833 actor=53.469 alpha=0.130
# [train] episode=5210 step=961680 return=138.18 success=True time=93.9s geometry=cross_stream history=12 | q1=163.148 actor=46.232 alpha=0.130
# [train] episode=5215 step=962088 return=125.85 success=True time=111.6s geometry=cross_stream history=12 | q1=115.595 actor=49.742 alpha=0.130
# [train] episode=5220 step=962712 return=140.20 success=True time=76.3s geometry=cross_stream history=12 | q1=206.204 actor=50.149 alpha=0.133
# [train] episode=5225 step=963810 return=133.03 success=True time=98.6s geometry=cross_stream history=12 | q1=35.031 actor=49.088 alpha=0.136
# [train] episode=5230 step=964932 return=129.04 success=True time=104.9s geometry=cross_stream history=12 | q1=51.765 actor=59.660 alpha=0.136
# [train] episode=5235 step=965790 return=138.61 success=True time=55.5s geometry=cross_stream history=12 | q1=30.219 actor=53.840 alpha=0.134
# [train] episode=5240 step=966630 return=-228.87 success=False time=35.1s geometry=cross_stream history=12 | q1=120.789 actor=54.143 alpha=0.135
# [train] episode=5245 step=967164 return=141.58 success=True time=96.7s geometry=cross_stream history=12 | q1=9.251 actor=61.139 alpha=0.137
# [train] episode=5250 step=968010 return=99.53 success=True time=73.9s geometry=cross_stream history=12 | q1=86.397 actor=49.005 alpha=0.137
# [train] episode=5255 step=968412 return=-286.98 success=False time=38.2s geometry=cross_stream history=12 | q1=210.439 actor=53.538 alpha=0.138
# [train] episode=5260 step=969150 return=-246.96 success=False time=13.5s geometry=cross_stream history=12 | q1=130.974 actor=61.522 alpha=0.139
# [train] episode=5265 step=969810 return=139.96 success=True time=46.5s geometry=cross_stream history=12 | q1=62.082 actor=56.813 alpha=0.138
# [train] episode=5270 step=970644 return=35.28 success=True time=68.6s geometry=cross_stream history=12 | q1=101.595 actor=57.973 alpha=0.140
# [train] episode=5275 step=971484 return=134.38 success=True time=69.5s geometry=cross_stream history=12 | q1=87.793 actor=57.134 alpha=0.142
# [train] episode=5280 step=972120 return=142.46 success=True time=33.5s geometry=cross_stream history=12 | q1=315.361 actor=56.533 alpha=0.143
# [train] episode=5285 step=972882 return=-83.14 success=True time=109.5s geometry=cross_stream history=12 | q1=53.612 actor=60.487 alpha=0.141
# [train] episode=5290 step=973458 return=33.60 success=True time=116.0s geometry=cross_stream history=12 | q1=46.785 actor=51.208 alpha=0.140
# [train] episode=5295 step=974652 return=124.94 success=True time=100.9s geometry=cross_stream history=12 | q1=267.681 actor=62.126 alpha=0.138
# [eval] step=975000 objective=arrival_v2 return=60.88 safety=8.928 success=73.33% time=103.5s energy=78079.9 path=75.5 prog=0.82
# [train] episode=5300 step=975414 return=-114.22 success=True time=141.9s geometry=cross_stream history=12 | q1=94.040 actor=56.125 alpha=0.140
# [train] episode=5305 step=976284 return=-132.02 success=True time=135.2s geometry=cross_stream history=12 | q1=171.165 actor=53.174 alpha=0.139
# [train] episode=5310 step=977118 return=134.32 success=True time=122.4s geometry=cross_stream history=12 | q1=247.951 actor=63.938 alpha=0.138
# [train] episode=5315 step=978048 return=87.02 success=True time=76.9s geometry=cross_stream history=12 | q1=131.596 actor=56.869 alpha=0.139
# [train] episode=5320 step=978762 return=136.72 success=True time=56.4s geometry=cross_stream history=12 | q1=238.464 actor=57.237 alpha=0.138
# [train] episode=5325 step=979836 return=139.62 success=True time=88.7s geometry=cross_stream history=12 | q1=117.356 actor=56.958 alpha=0.136
# [train] episode=5330 step=980526 return=120.08 success=True time=55.3s geometry=cross_stream history=12 | q1=5.306 actor=57.478 alpha=0.137
# [train] episode=5335 step=981366 return=137.39 success=True time=103.8s geometry=cross_stream history=12 | q1=83.154 actor=61.674 alpha=0.134
# [train] episode=5340 step=981840 return=52.47 success=True time=95.9s geometry=cross_stream history=12 | q1=34.190 actor=53.467 alpha=0.132
# [train] episode=5345 step=982602 return=141.71 success=True time=75.2s geometry=cross_stream history=12 | q1=34.745 actor=56.083 alpha=0.135
# [train] episode=5350 step=983424 return=138.99 success=True time=86.9s geometry=cross_stream history=12 | q1=21.842 actor=40.165 alpha=0.133
# [train] episode=5355 step=984006 return=-240.15 success=False time=11.8s geometry=cross_stream history=12 | q1=189.368 actor=57.778 alpha=0.134
# [train] episode=5360 step=984996 return=136.51 success=True time=117.1s geometry=cross_stream history=12 | q1=58.823 actor=47.371 alpha=0.136
# [train] episode=5365 step=985698 return=138.04 success=True time=101.6s geometry=cross_stream history=12 | q1=186.846 actor=51.910 alpha=0.136
# [train] episode=5370 step=986460 return=91.78 success=True time=105.7s geometry=cross_stream history=12 | q1=70.177 actor=56.267 alpha=0.137
# [train] episode=5375 step=986892 return=141.34 success=True time=99.2s geometry=cross_stream history=12 | q1=70.518 actor=50.562 alpha=0.138
# [train] episode=5380 step=987798 return=140.97 success=True time=74.9s geometry=cross_stream history=12 | q1=122.034 actor=57.730 alpha=0.141
# [train] episode=5385 step=988626 return=140.15 success=True time=78.1s geometry=cross_stream history=12 | q1=94.004 actor=52.374 alpha=0.142
# [train] episode=5390 step=989100 return=140.18 success=True time=31.6s geometry=cross_stream history=12 | q1=12.029 actor=53.785 alpha=0.141
# [train] episode=5395 step=989970 return=141.43 success=True time=83.3s geometry=cross_stream history=12 | q1=110.468 actor=52.740 alpha=0.138
# [train] episode=5400 step=990366 return=136.44 success=True time=36.1s geometry=cross_stream history=12 | q1=22.859 actor=47.169 alpha=0.138
# [train] episode=5405 step=991194 return=124.82 success=True time=71.5s geometry=cross_stream history=12 | q1=13.276 actor=50.853 alpha=0.135
# [train] episode=5410 step=992190 return=142.43 success=True time=73.3s geometry=cross_stream history=12 | q1=55.342 actor=51.709 alpha=0.130
# [train] episode=5415 step=993210 return=139.23 success=True time=98.3s geometry=cross_stream history=12 | q1=98.659 actor=54.502 alpha=0.130
# [train] episode=5420 step=993762 return=137.47 success=True time=93.2s geometry=cross_stream history=12 | q1=82.493 actor=49.223 alpha=0.133
# [train] episode=5425 step=994842 return=133.84 success=True time=95.6s geometry=cross_stream history=12 | q1=175.517 actor=55.972 alpha=0.132
# [train] episode=5430 step=995616 return=138.19 success=True time=67.2s geometry=cross_stream history=12 | q1=254.147 actor=51.129 alpha=0.130
# [train] episode=5435 step=996594 return=139.72 success=True time=80.9s geometry=cross_stream history=12 | q1=207.643 actor=52.358 alpha=0.130
# [train] episode=5440 step=997302 return=140.49 success=True time=62.4s geometry=cross_stream history=12 | q1=112.122 actor=54.263 alpha=0.132
# [train] episode=5445 step=998172 return=-255.53 success=False time=8.3s geometry=cross_stream history=12 | q1=5.358 actor=48.991 alpha=0.131
# [train] episode=5450 step=999114 return=139.59 success=True time=124.8s geometry=cross_stream history=12 | q1=240.070 actor=57.913 alpha=0.134
# [train] episode=5455 step=999678 return=135.77 success=True time=104.3s geometry=cross_stream history=12 | q1=4.290 actor=48.609 alpha=0.136

# %% [markdown]
# ## 5. Summary + gate

# %%
def summarize_phase(run_root: Path, total_steps: int, label: str, gate_filename: str):
    eval_log_path = run_root / 'results' / 'eval_log.csv'
    final_eval_path = run_root / 'results' / 'final_eval.json'
    trainer_state_path = run_root / 'trainer_state.json'
    train_config_path = run_root / 'results' / 'train_config.txt'

    if not eval_log_path.exists():
        raise FileNotFoundError(f'missing eval log: {eval_log_path}')
    if not final_eval_path.exists():
        raise FileNotFoundError(f'missing final eval: {final_eval_path}')

    df = pd.read_csv(eval_log_path)
    final_eval = json.loads(final_eval_path.read_text(encoding='utf-8'))
    trainer_state = json.loads(trainer_state_path.read_text(encoding='utf-8')) if trainer_state_path.exists() else {}

    history_from_config = 'NA'
    obs_dim_from_config = 'NA'
    if train_config_path.exists():
        for ln in train_config_path.read_text(encoding='utf-8').splitlines():
            s = ln.strip()
            if s.startswith('history_length='):
                history_from_config = s.split('=', 1)[1]
            elif s.startswith('obs_dim='):
                obs_dim_from_config = s.split('=', 1)[1]

    peak_success = float(df['eval_success_rate'].max()) if len(df) else 0.0
    peak_step = int(df.loc[df['eval_success_rate'].idxmax(), 'env_step']) if len(df) else 0
    last100 = df[df['env_step'] >= total_steps - 100_000].copy()
    last100_mean = float(last100['eval_success_rate'].mean()) if len(last100) else 0.0
    mean_all = float(df['eval_success_rate'].mean()) if len(df) else 0.0
    n_evals_with_success = int((df['eval_success_rate'] > 0).sum()) if len(df) else 0
    final_success = float(final_eval['eval_success_rate'])
    counts = final_eval.get('eval_termination_counts', {})
    num_eps = float(final_eval.get('num_eval_episodes', EVAL_EPISODES))
    oob_rate = float(counts.get('out_of_bounds', 0)) / max(num_eps, 1.0)

    print('=' * 100)
    print(f'{label}  (arrival_v2 / s0 / k=12 / seed={SEED} / vanilla / {total_steps:,} steps)')
    print('-' * 100)
    print(f"  final_success_rate    : {final_success:.4f}   gate >= {PASS_FINAL_SUCCESS:.2f}")
    print(f"  peak_success_rate     : {peak_success:.4f}   @ {peak_step:,}")
    print(f"  last100k_mean_success : {last100_mean:.4f}   gate >= {PASS_LAST100_RATIO * peak_success:.4f}")
    print(f"  full-traj mean        : {mean_all:.4f}   (39 evals)")
    print(f"  n_evals_with_success  : {n_evals_with_success} / {len(df)}")
    print(f"  final_oob_rate        : {oob_rate:.4f}   gate <= {PASS_OOB_RATE:.2f}")
    print(f"  obs_dim               : {obs_dim_from_config}   (expect 12*12=144)")
    print(f"  history_length        : {history_from_config}   (from train_config.txt)")
    print(f"  context_obs           : {trainer_state.get('include_episode_context_obs', 'NA')}")
    print(f"  timeout_bootstrap     : {trainer_state.get('timeout_bootstrap_semantics', 'NA')}")
    print(f"  termination           : {counts}")
    print('=' * 100)

    if len(df):
        print()
        print('[last 16 eval rows]')
        cols = ['env_step', 'eval_success_rate', 'eval_return', 'eval_safety_cost',
                'eval_time_s', 'eval_progress_ratio']
        available = [c for c in cols if c in df.columns]
        print(df[available].tail(16).to_string(index=False))

    checks = [
        ('final success >= 0.85', final_success >= PASS_FINAL_SUCCESS, f'{final_success:.4f}'),
        ('last100k mean >= 0.9 * peak', last100_mean >= PASS_LAST100_RATIO * peak_success,
         f'{last100_mean:.4f} / peak={peak_success:.4f}'),
        ('final OOB rate <= 0.10', oob_rate <= PASS_OOB_RATE, f'{oob_rate:.4f}'),
        ('arrival_v2 context obs enabled',
         trainer_state.get('include_episode_context_obs') is True,
         str(trainer_state.get('include_episode_context_obs'))),
        ('arrival_v2 timeout terminal semantics',
         trainer_state.get('timeout_bootstrap_semantics') == 'terminal',
         str(trainer_state.get('timeout_bootstrap_semantics'))),
    ]

    print()
    print('=' * 96)
    print(f"{'check':<48}{'pass':>8}{'detail':>40}")
    print('-' * 96)
    all_pass = True
    for name, ok, detail in checks:
        mark = 'PASS' if ok else 'FAIL'
        if not ok:
            all_pass = False
        print(f'{name:<48}{mark:>8}{detail:>40}')
    print('=' * 96)

    summary = {
        'phase': label,
        'objective': OBJECTIVE,
        'probe_layout': PROBE_LAYOUT,
        'history_length': int(history_from_config) if history_from_config != 'NA' else HISTORY_LENGTH,
        'seed': SEED,
        'total_steps': total_steps,
        'algorithm': 'sac_vanilla',
        'final_success_rate': final_success,
        'peak_success_rate': peak_success,
        'peak_step': peak_step,
        'last100k_mean_success': last100_mean,
        'mean_success_full_trajectory': mean_all,
        'n_evals_with_success': n_evals_with_success,
        'n_evals_total': len(df),
        'final_oob_rate': oob_rate,
        'termination_counts': counts,
        'all_pass': bool(all_pass),
        'checks': [{'name': n, 'ok': bool(ok), 'detail': d} for n, ok, d in checks],
    }
    out_path = run_root / 'results' / gate_filename
    out_path.parent.mkdir(parents=True, exist_ok=True)
    out_path.write_text(json.dumps(summary, indent=2), encoding='utf-8')
    print(f'[saved] {out_path}')
    return summary

x_summary = summarize_phase(
    X_RUN_ROOT,
    X_TOTAL_STEPS,
    'SINGLE_CROSS_S0_K12_SEED0',
    'single_cross_s0_k12_seed0_gate_summary.json',
)
X_PASS = x_summary['all_pass']
print()
print(f'X_PASS = {X_PASS}')
# Out:
# ====================================================================================================
# SINGLE_CROSS_S0_K12_SEED0  (arrival_v2 / s0 / k=12 / seed=0 / vanilla / 1,000,000 steps)
# ----------------------------------------------------------------------------------------------------
#   final_success_rate    : 0.9000   gate >= 0.85
#   peak_success_rate     : 0.9000   @ 525,000
#   last100k_mean_success : 0.8333   gate >= 0.8100
#   full-traj mean        : 0.5248   (39 evals)
#   n_evals_with_success  : 32 / 39
#   final_oob_rate        : 0.1000   gate <= 0.10
#   obs_dim               : 144   (expect 12*12=144)
#   history_length        : 12   (from train_config.txt)
#   context_obs           : True
#   timeout_bootstrap     : terminal
#   termination           : {'goal': 27, 'out_of_bounds': 3}
# ====================================================================================================
#
# [last 16 eval rows]
#  env_step  eval_success_rate  eval_return  eval_safety_cost  eval_time_s  eval_progress_ratio
#    600000           0.666667     1.888858         18.417790    92.166667             0.753094
#    625002           0.766667    32.993699         25.402278   115.723333             0.816938
#    650004           0.800000    40.680606         17.439615    89.470000             0.763346
#    675000           0.833333    54.019919         19.481123   110.230000             0.823027
#    700002           0.866667    79.166137         10.731851    91.036667             0.825681
#    725004           0.866667    72.274567         14.411197    91.220000             0.830527
#    750000           0.866667    78.117351         11.303214    88.256667             0.826059
#    775002           0.866667    74.227976         13.218923    93.056667             0.826503
#    800004           0.900000    73.156547         16.701181   102.120000             0.835723
#    825000           0.866667    77.575224         11.512571    88.346667             0.824786
#    850002           0.900000    83.607032         11.618733    85.720000             0.835126
#    875004           0.866667    77.620298         11.760190    89.656667             0.830550
#    900000           0.866667    78.259935         11.547567    85.820000             0.831981
#    925002           0.866667    74.958028         13.025741    88.603333             0.828535
#    950004           0.866667    80.753690         10.088571    84.983333             0.827482
#    975000           0.733333    60.876578          8.928220   103.513333             0.815608
#
# ================================================================================================
# check                                               pass                                  detail
# ------------------------------------------------------------------------------------------------
# final success >= 0.85                               PASS                                  0.9000
# last100k mean >= 0.9 * peak                         PASS                    0.8333 / peak=0.9000
# final OOB rate <= 0.10                              PASS                                  0.1000
# arrival_v2 context obs enabled                      PASS                                    True
# arrival_v2 timeout terminal semantics               PASS                                terminal
# ================================================================================================
# [saved] experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s0_k12/seed_0/results/single_cross_s0_k12_seed0_gate_summary.json
#
# X_PASS = True

# %% [markdown]
# ## 6. Cross-seed monotonicity verdict — k=12 seed=0 vs §8P1#2 k=12 anchor + §7.8' k=8 sister + 全 7-run 对照

# %%
def read_baseline(root: Path, ref_final: float, ref_oob: float, ref_mean: float = None):
    fp = root / 'results' / 'final_eval.json'
    log = root / 'results' / 'eval_log.csv'
    out = {'final': ref_final, 'oob': ref_oob, 'mean': ref_mean, 'peak': None, 'peak_step': None, 'source': 'report'}
    if fp.exists():
        d = json.loads(fp.read_text(encoding='utf-8'))
        f = float(d['eval_success_rate'])
        c = d.get('eval_termination_counts', {})
        n = float(d.get('num_eval_episodes', EVAL_EPISODES))
        out['final'] = f
        out['oob'] = float(c.get('out_of_bounds', 0)) / max(n, 1.0)
        out['source'] = 'on-disk'
    if log.exists():
        dlog = pd.read_csv(log)
        out['mean'] = float(dlog['eval_success_rate'].mean())
        out['peak'] = float(dlog['eval_success_rate'].max())
        out['peak_step'] = int(dlog.loc[dlog['eval_success_rate'].idxmax(), 'env_step'])
    return out

print('=' * 110)
print('SINGLE_CROSS — k=12 cross-seed monotonicity verdict (seed=0 vs k=12 s42 anchor + k=8 s0 sister)')
print('-' * 110)

# 本 run (k=12 seed=0)
k12s0_final = float(x_summary['final_success_rate'])
k12s0_oob   = float(x_summary['final_oob_rate'])
k12s0_peak  = float(x_summary['peak_success_rate'])
k12s0_peak_step = int(x_summary['peak_step'])
k12s0_mean  = float(x_summary.get('mean_success_full_trajectory', 0.0))
k12s0_nsucc = int(x_summary.get('n_evals_with_success', 0))
k12s0_ntot  = int(x_summary.get('n_evals_total', 0))

# 7 个 baseline
b_k12_s42 = read_baseline(X_K12_S42_ROOT, 0.900, 0.100, 0.652)  # §8P1#2 anchor PASS-PLATEAU
b_k8_s42  = read_baseline(X_K8_S42_ROOT,  0.900, 0.100, 0.636)  # §7.8 anchor PASS
b_k8_s0   = read_baseline(X_K8_S0_ROOT,   0.500, 0.133, 0.260)  # §7.8' PARTIAL — 主对照
b_k8_s7   = read_baseline(X_K8_S7_ROOT,   0.867, 0.133, 0.518)  # §7.8'' BORDERLINE-PASS
b_k4_s42  = read_baseline(X_K4_S42_ROOT,  0.100, 0.667, 0.221)  # §7.6.4 floor
b_k4_s0   = read_baseline(X_K4_S0_ROOT,   0.400, 0.200, 0.218)  # §7.7.1 sister
b_s1      = read_baseline(X_S1_UPPER_ROOT, 0.900, 0.100, 0.497) # §7.1 upper

print()
print(f'{"config":<48}{"final":>10}{"mean":>10}{"oob":>10}{"peak":>10}{"peak@":>14}')
print('-' * 110)
label_k8_s7  = "vanilla s0_k8 s7  (§7.8'' BORDER)"
label_k8_s0  = "vanilla s0_k8 s0  (§7.8' PARTIAL)"
print(f'{"vanilla s1_k4 s42 (§7.1 upper ref)":<48}{b_s1["final"]:>10.4f}{(b_s1["mean"] or float("nan")):>10.4f}{b_s1["oob"]:>10.4f}{(b_s1["peak"] or float("nan")):>10.4f}{(b_s1["peak_step"] or 0):>14,}')
print(f'{"vanilla s0_k4 s42 (§7.6.4 FAIL floor)":<48}{b_k4_s42["final"]:>10.4f}{(b_k4_s42["mean"] or float("nan")):>10.4f}{b_k4_s42["oob"]:>10.4f}{(b_k4_s42["peak"] or float("nan")):>10.4f}{(b_k4_s42["peak_step"] or 0):>14,}')
print(f'{"vanilla s0_k4 s0  (§7.7.1 sister)":<48}{b_k4_s0["final"]:>10.4f}{(b_k4_s0["mean"] or float("nan")):>10.4f}{b_k4_s0["oob"]:>10.4f}{(b_k4_s0["peak"] or float("nan")):>10.4f}{(b_k4_s0["peak_step"] or 0):>14,}')
print(f'{"vanilla s0_k8 s42 (§7.8 anchor PASS)":<48}{b_k8_s42["final"]:>10.4f}{(b_k8_s42["mean"] or float("nan")):>10.4f}{b_k8_s42["oob"]:>10.4f}{(b_k8_s42["peak"] or float("nan")):>10.4f}{(b_k8_s42["peak_step"] or 0):>14,}')
print(f'{label_k8_s0:<48}{b_k8_s0["final"]:>10.4f}{(b_k8_s0["mean"] or float("nan")):>10.4f}{b_k8_s0["oob"]:>10.4f}{(b_k8_s0["peak"] or float("nan")):>10.4f}{(b_k8_s0["peak_step"] or 0):>14,}')
print(f'{label_k8_s7:<48}{b_k8_s7["final"]:>10.4f}{(b_k8_s7["mean"] or float("nan")):>10.4f}{b_k8_s7["oob"]:>10.4f}{(b_k8_s7["peak"] or float("nan")):>10.4f}{(b_k8_s7["peak_step"] or 0):>14,}')
print(f'{"vanilla s0_k12 s42 (§8P1#2 anchor PLAT)":<48}{b_k12_s42["final"]:>10.4f}{(b_k12_s42["mean"] or float("nan")):>10.4f}{b_k12_s42["oob"]:>10.4f}{(b_k12_s42["peak"] or float("nan")):>10.4f}{(b_k12_s42["peak_step"] or 0):>14,}')
print(f'{"vanilla s0_k12 s0  (THIS RUN, sister)":<48}{k12s0_final:>10.4f}{k12s0_mean:>10.4f}{k12s0_oob:>10.4f}{k12s0_peak:>10.4f}{k12s0_peak_step:>14,}')
print('=' * 110)

# Δ 行
delta_final_vs_k12_s42 = k12s0_final - b_k12_s42['final']
delta_mean_vs_k12_s42  = k12s0_mean  - (b_k12_s42['mean'] or 0.0)
delta_oob_vs_k12_s42   = k12s0_oob   - b_k12_s42['oob']
delta_final_vs_k8_s0   = k12s0_final - b_k8_s0['final']
delta_mean_vs_k8_s0    = k12s0_mean  - (b_k8_s0['mean'] or 0.0)
delta_oob_vs_k8_s0     = k12s0_oob   - b_k8_s0['oob']
delta_final_vs_s1      = k12s0_final - b_s1['final']

print()
print(f'{"contrast":<60}{"Δ final":>12}{"Δ mean":>12}{"Δ oob":>12}')
print('-' * 110)
print(f'{"k=12 s0 vs k=12 s42 (vs PASS-PLATEAU anchor)":<60}'
      f'{delta_final_vs_k12_s42:>+12.4f}{delta_mean_vs_k12_s42:>+12.4f}{delta_oob_vs_k12_s42:>+12.4f}')
print(f'{"k=12 s0 vs k=8 s0  (cross-history, same seed)":<60}'
      f'{delta_final_vs_k8_s0:>+12.4f}{delta_mean_vs_k8_s0:>+12.4f}{delta_oob_vs_k8_s0:>+12.4f}')
print(f'{"k=12 s0 vs s1_k4 s42 (gap-to-upper)":<60}'
      f'{delta_final_vs_s1:>+12.4f}'
      f'{(k12s0_mean - (b_s1["mean"] or 0)):>+12.4f}'
      f'{k12s0_oob - b_s1["oob"]:>+12.4f}')
print('=' * 110)
print()
print(f'k=12 seed=0 evals_with_success: {k12s0_nsucc} / {k12s0_ntot}  '
      f'(k=12 s42 was 35/39 PASS-PLATEAU, k=8 s0 was 32/39 PARTIAL, k=8 s7 was 31/39 BORDER)')

# Cross-seed monotonicity verdict — 5-tier
# (吸取 build_k8_seed7.py 4-tier 漏 BORDERLINE 教训 — 必须显式判 final≥0.85 但 OOB 卡线的情形)
strict_pass = (k12s0_final >= PASS_FINAL_SUCCESS) and (k12s0_oob <= PASS_OOB_RATE)
borderline_pass = (k12s0_final >= PASS_FINAL_SUCCESS) and (PASS_OOB_RATE < k12s0_oob <= BORDERLINE_OOB_RATE)
persistent_stall = (0.50 <= k12s0_final < PASS_FINAL_SUCCESS) and (abs(k12s0_final - b_k8_s0['final']) <= 0.20)
unexpected_decay = ((k12s0_final < b_k8_s0['final'] - 0.05) or (0.40 <= k12s0_final < 0.50))
collapse = k12s0_final < 0.40

# Priority order: strict_pass → borderline_pass → unexpected_decay → persistent_stall → collapse
# (unexpected_decay 优先于 persistent_stall 因为它是 cross-history regression 信号)
if strict_pass:
    verdict = (
        f'CROSS-SEED-RESCUE — k=12 s0 strict 5/5 PASS (final={k12s0_final:.3f}≥0.85, OOB={k12s0_oob:.3f}≤0.10); '
        f'与 k=12 s42 anchor (final=0.900) tight cluster, |Δfinal|={abs(delta_final_vs_k12_s42):.3f}; '
        f'cross-history vs k=8 s0 Δfinal=+{delta_final_vs_k8_s0:.3f} 大幅 rescue seed=0 stall. '
        f'强证据 H_rescue: history extension 不仅提升 lucky seed (s42)，还能 rescue unlucky seed (s0) local minimum. '
        f'§7.8 主张升格「k=4→8→12 monotonic; k=12 cross-seed robust 闭合 gap」; '
        f'§8 P1#2 升格「monotonic improvement extends to k=12 across seeds」; '
        f'下一步可选: 跑 k=8 seed=11 第 4 anchor 测 k=8 strict 边界，或 pivot §8 P0 variance reduction'
    )
elif borderline_pass:
    verdict = (
        f'CROSS-SEED-BORDERLINE-PASS — k=12 s0 final={k12s0_final:.3f}≥0.85 ✓ 但 OOB={k12s0_oob:.3f}>0.10 ✗ (≤0.135 BORDER); '
        f'final 维度 rescue 成立 (vs k=8 s0 Δ=+{delta_final_vs_k8_s0:.3f}); '
        f'但 OOB 仍 seed-dep noise 与 k=8 s7 BORDER (OOB=0.133) 一致; '
        f'SAC variance 主要表现在 OOB 末端而非 final goal 率. '
        f'§7.8 主张可升格「history extension cross-seed buys final rescue 但 OOB residual variance 不可忽略」; '
        f'§8 P0 variance reduction (DroQ / SimBa / N-Step) priority elevated — 用于压低 OOB tail 而非 final 提升'
    )
elif unexpected_decay:
    verdict = (
        f'UNEXPECTED-DECAY — k=12 s0 final={k12s0_final:.3f} <= k=8 s0 final={b_k8_s0["final"]:.3f}-0.05={b_k8_s0["final"]-0.05:.3f}; '
        f'over-stale history 在 seed=0 上反害, history extension 不再 monotonic. '
        f'§8 P1#2 主张回退「k=8 是 cross-seed sweet spot; k=12 仅在 lucky seed (s42) 有 mild speedup but seed=0 上 regress」; '
        f'强烈推荐 pivot §8 P0 variance reduction (DroQ / SimBa / N-Step) 代替 history extension'
    )
elif persistent_stall:
    verdict = (
        f'PERSISTENT-STALL — k=12 s0 final={k12s0_final:.3f} ∈ [0.5, 0.85), 与 k=8 s0 final={b_k8_s0["final"]:.3f} 在 0.20 范围内; '
        f'seed=0 stall 跨 history length 持续 (k=4: 0.40, k=8: 0.50, k=12: {k12s0_final:.3f}). '
        f'强证据 H_seed-stall: seed=0 有 init-dep local minimum 与 history length 弱相关; '
        f'§7.8 主张维持「k=4→8 在 2/3 seeds 闭合 gap; seed=0 stall 是 init-dep, 非 information bottleneck」; '
        f'§8 P0 variance reduction 必要 — 必须先解 seed-stall 才能再讨论 history extension'
    )
elif collapse:
    verdict = (
        f'COLLAPSE — k=12 s0 final={k12s0_final:.3f}<0.40, 严重下降. '
        f'必须 audit: trainer_state grad-norm / actor-critic loss curve / obs_dim 排除 training bug; '
        f'若非 bug，则 thesis claim 严重 reframe — history extension 不仅非 monotonic, 还在 unlucky seed 上 catastrophic'
    )
else:
    # 兜底分支 (理论上不应触发；保留以避免 catch-all bug 重现)
    verdict = (
        f'UNCLASSIFIED — final={k12s0_final:.3f} OOB={k12s0_oob:.3f}; '
        f'5-tier schema 未触发任何明确条件; 需 manual 审视 (本 verdict 应被视为 bug 报告 — 类似 §7.8'' seed=7 误判教训)'
    )

print()
print(f'>>> verdict: {verdict}')

# 落盘 cross-seed monotonicity summary
mono_out = {
    'experiment': 'arrival_v2_s0_cross_k12_seed0_crossseed_monotonicity',
    'seed': SEED,
    'benchmark': X_BENCHMARK_KEY,
    'probe_layout': PROBE_LAYOUT,
    'history_length': HISTORY_LENGTH,
    'total_steps': X_TOTAL_STEPS,
    'algorithm': 'sac_vanilla',
    'cli_diff_vs_§8P1#2_anchor': '--seed 42 → 0',
    'results': {
        'k12_s0_thisrun': {
            'final': k12s0_final, 'mean': k12s0_mean, 'oob': k12s0_oob,
            'peak': k12s0_peak, 'peak_step': k12s0_peak_step,
            'n_evals_with_success': k12s0_nsucc, 'n_evals_total': k12s0_ntot,
        },
        'k12_s42_anchor_§8P1#2_PASS_PLATEAU': b_k12_s42,
        'k8_s42_anchor_§7.8_PASS': b_k8_s42,
        "k8_s0_§7.8'_PARTIAL_main_contrast": b_k8_s0,
        "k8_s7_§7.8''_BORDERLINE_PASS": b_k8_s7,
        '§7.6.4_k4_s42_floor': b_k4_s42,
        '§7.7.1_k4_s0_sister': b_k4_s0,
        '§7.1_s1_k4_s42_upper': b_s1,
    },
    'delta_vs_§8P1#2_k12_anchor_seed42': {
        'final_pp': round(delta_final_vs_k12_s42 * 100, 2),
        'mean_pp':  round(delta_mean_vs_k12_s42  * 100, 2),
        'oob_pp':   round(delta_oob_vs_k12_s42   * 100, 2),
    },
    "delta_vs_§7.8'_k8_seed0": {
        'final_pp': round(delta_final_vs_k8_s0 * 100, 2),
        'mean_pp':  round(delta_mean_vs_k8_s0  * 100, 2),
        'oob_pp':   round(delta_oob_vs_k8_s0   * 100, 2),
    },
    'seed0_cross_history_trajectory': {
        'k4':  b_k4_s0['final'],
        'k8':  b_k8_s0['final'],
        'k12': k12s0_final,
    },
    'verdict_tier': (
        'CROSS-SEED-RESCUE' if strict_pass
        else 'CROSS-SEED-BORDERLINE-PASS' if borderline_pass
        else 'UNEXPECTED-DECAY' if unexpected_decay
        else 'PERSISTENT-STALL' if persistent_stall
        else 'COLLAPSE' if collapse
        else 'UNCLASSIFIED'
    ),
    'all_pass': bool(x_summary['all_pass']),
    'verdict': verdict,
}
out_dir = Path('experiments/arrival_v2_prototype/s0_cross_k12_seed0_summary')
out_dir.mkdir(parents=True, exist_ok=True)
out_path = out_dir / 'combined_gate_summary.json'
out_path.write_text(json.dumps(mono_out, indent=2), encoding='utf-8')
print(f'\n[saved] {out_path}')
# Out:
# ==============================================================================================================
# SINGLE_CROSS — k=12 cross-seed monotonicity verdict (seed=0 vs k=12 s42 anchor + k=8 s0 sister)
# --------------------------------------------------------------------------------------------------------------
#
# config                                               final      mean       oob      peak         peak@
# --------------------------------------------------------------------------------------------------------------
# vanilla s1_k4 s42 (§7.1 upper ref)                  0.9000    0.4966    0.1000    0.9000       725,004
# vanilla s0_k4 s42 (§7.6.4 FAIL floor)               0.1000    0.2205    0.6667    0.3667       975,000
# vanilla s0_k4 s0  (§7.7.1 sister)                   0.4000    0.2179    0.2000    0.5333       625,002
# vanilla s0_k8 s42 (§7.8 anchor PASS)                0.9000    0.6359    0.1000    0.9000       475,002
# vanilla s0_k8 s0  (§7.8' PARTIAL)                   0.5000    0.2598    0.1333    0.5000       925,002
# vanilla s0_k8 s7  (§7.8'' BORDER)                   0.8667    0.5179    0.1333    0.9000       550,002
# vanilla s0_k12 s42 (§8P1#2 anchor PLAT)             0.9000    0.6521    0.1000    0.9000       375,000
# vanilla s0_k12 s0  (THIS RUN, sister)               0.9000    0.5248    0.1000    0.9000       525,000
# ==============================================================================================================
#
# contrast                                                         Δ final      Δ mean       Δ oob
# --------------------------------------------------------------------------------------------------------------
# k=12 s0 vs k=12 s42 (vs PASS-PLATEAU anchor)                     +0.0000     -0.1274     +0.0000
# k=12 s0 vs k=8 s0  (cross-history, same seed)                    +0.4000     +0.2650     -0.0333
# k=12 s0 vs s1_k4 s42 (gap-to-upper)                              +0.0000     +0.0282     +0.0000
# ==============================================================================================================
#
# k=12 seed=0 evals_with_success: 32 / 39  (k=12 s42 was 35/39 PASS-PLATEAU, k=8 s0 was 32/39 PARTIAL, k=8 s7 was 31/39 BORDER)
#
# >>> verdict: CROSS-SEED-RESCUE — k=12 s0 strict 5/5 PASS (final=0.900≥0.85, OOB=0.100≤0.10); 与 k=12 s42 anchor (final=0.900) tight cluster, |Δfinal|=0.000; cross-history vs k=8 s0 Δfinal=+0.400 大幅 rescue seed=0 stall. 强证据 H_rescue: history extension 不仅提升 lucky seed (s42)，还能 rescue unlucky seed (s0) local minimum. §7.8 主张升格「k=4→8→12 monotonic; k=12 cross-seed robust 闭合 gap」; §8 P1#2 升格「monotonic improvement extends to k=12 across seeds」; 下一步可选: 跑 k=8 seed=11 第 4 anchor 测 k=8 strict 边界，或 pivot §8 P0 variance reduction
#
# [saved] experiments/arrival_v2_prototype/s0_cross_k12_seed0_summary/combined_gate_summary.json
