# %% [markdown]
# # FQL Succession P2 — E-uni (Expert, Unimodal)
#
# > Sub-optimal × Multi-modal 矩阵的 **baseline ✓ ✓** 角
# >
# > 文档锚点:[`docs/fql_succession_p2_main_spec.md`](../docs/fql_succession_p2_main_spec.md) v1.3 + [`docs/fql_succession_p2_collection_log.md`](../docs/fql_succession_p2_collection_log.md)
# >
# > 参考 notebook 风格:[`notebooks/rebrac_c1_asym_critic_ablation.ipynb`](rebrac_c1_asym_critic_ablation.ipynb)
#
# ## 前传 — Gate B 已知事实
#
# Gate B(P1 finalization 2026-05-12)在 E-uni 上跑 4 run(rebrac + fql × seed [42, 0]),test success Δ_E-uni = -4.4pp(FQL 略低于 ReBRAC,marginal)。P2 在 100-episode test manifest(ep100,Bug 2 fix)下重 collect E-uni + 新 collect M-uni-noise / M-multi-mix,以 12-run primary(3 cell × 2 algo × 2 seed [42, 0])跑完整 iff verdict。
#
# ## 本 notebook scope
#
# - **Cell**:E-uni (Expert, Unimodal)
# - **Dataset**:`offline_data/privileged_s0_h4_arrival_v2_re150_u10cross_fixdone_ep1000`
# - **Collection**:privileged policy × 1000 ep,action_noise_std=0.0(reused from Task D 2026-05-19,不在 P2 sprint 0 重新 collect)
# - **预期 verdict**:**NULL** — FQL ≈ ReBRAC on optimal-unimodal data(paper claim 的 baseline 验证)
#
# **该 cell 角色**:E-uni 是 P2 三 cell 矩阵的 **baseline 角**——数据质量 high(success=0.985)+ 构造 unimodal(single privileged policy,无噪声)。Paper claim 是 FQL 优势仅在 sub-optimal × multi-modal 出现,所以 E-uni 上 **预期** FQL 与 ReBRAC 无显著差距(|Δ| < 0.03)。如果 E-uni 上 FQL 明显赢,意味着 paper claim 的 iff 失败(FQL 不只在 multi-modal 赢,在 unimodal 也赢)→ paper 主结论要重写。
#
# ## 隔离表(本 cell vs 另两 cell)
#
# | Cell | Optimality | Modality | Paper claim 预期 |
# |---|---|---|---|
# | **E-uni** ✓ | optimal (success 0.985) | unimodal (single privileged) | NULL (FQL ≈ ReBRAC) |
# | M-uni-noise | sub-opt (success 0.632) | unimodal (noise-widened, audit advisory) | NULL (FQL ≈ ReBRAC) |
# | M-multi-mix | sub-opt (~0.83 mix) | multi-modal (2-policy, audit confirms) | **POSITIVE** (FQL > ReBRAC ≥5pp) |
#
# ## Verdict 规则(effect-size + 方向一致性 primary,from spec §5.4)
#
# **阈值**:`δ_null = 0.03`(3pp,null band)+ `δ_signal = 0.05`(5pp,signal threshold)+ **gray band [3pp, 5pp]** 或方向不一致 → 加 seed 7 扩 n_seeds=3 再判。
#
# **本 cell 预期 verdict 方向**:`null` — 若 NULL → P2 进 §3 / §4(优秀;符合 paper claim:FQL 优势只在 sub-optimal × multi-modal)。若 unexpected POSITIVE(FQL > ReBRAC ≥5pp)→ ANOMALY,触发 sprint 1 重审(BC penalty 配置 / data leak 可能)
#
# | 本 cell verdict | 判定 | 后续 |
# |---|---|---|
# | `\|Δ\| < 0.03` AND \|diff_seed\| < 0.04 both | **NULL CONFIRMED** ✓ | 符合 paper claim 预期 |
# | `Δ ≥ 0.05` 同方向 | **UNEXPECTED POSITIVE** ⚠ | paper claim 失败(FQL 也在本 cell 赢)→ sprint 1 重审 |
# | 3pp ≤ \|Δ\| < 5pp 或方向不一致 | **GRAY** | 加 seed 7 扩 n_seeds=3,在 sprint 1 跑 |
#
# **c4 stability monitor**(per spec §5.6,n=2 threshold = -0.01549):aggregated slope = mean of last-30%-eval-pts linregress slope per seed。FQL c4 FAIL → §7 verdict 附 caveat。

# %% [markdown]
# ## 1. 环境 sanity
#
# 确认 Colab L4 + CUDA + Drive 挂载 + `%cd` 进 project root。

# %%
# !nvidia-smi | head -15
# !lscpu | head -10
# Out:
# Thu May 21 12:46:38 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA L4                      Off |   00000000:00:03.0 Off |                    0 |
# | N/A   37C    P8             12W /   72W |       0MiB /  23034MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# Architecture:                            x86_64
# CPU op-mode(s):                          32-bit, 64-bit
# Address sizes:                           46 bits physical, 48 bits virtual
# Byte Order:                              Little Endian
# CPU(s):                                  12
# On-line CPU(s) list:                     0-11
# Vendor ID:                               GenuineIntel
# Model name:                              Intel(R) Xeon(R) CPU @ 2.20GHz
# CPU family:                              6
# Model:                                   85

# %%
import torch
print(f'torch={torch.__version__}  CUDA available={torch.cuda.is_available()}')
if torch.cuda.is_available():
    print(f'device={torch.cuda.get_device_name(0)}')
# Out:
# torch=2.10.0+cu128  CUDA available=True
# device=NVIDIA L4

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=False)
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5'
# !pwd && ls scripts/train_offline.py scripts/evaluate_offline.py
# Out:
# /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5
# /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5
# scripts/evaluate_offline.py  scripts/train_offline.py

# %% [markdown]
# ## 2. 通用配置
#
# 定义 `CELL_ID` / `DATASET` / `FLOW` / `MANIFEST` / `CHECKPOINT_ROOT` / `RESULTS_ROOT` + `REBRAC_FLAGS` / `FQL_FLAGS` + `TRAIN_SEEDS=[42, 0]`(primary,n=2)。Helper 路径函数定义在此处,§4 / §5 / §6 共用。
#
# `CHECKPOINT_ROOT`(大文件,留 Drive)和 `RESULTS_ROOT`(小文件,可 sync 回 local 绘图)**分树存储**(per spec §4.2 D21)。

# %%
import os
import shutil
from pathlib import Path

# ---- per-cell config ----
CELL_ID  = 'e_uni'
DATASET  = 'offline_data/privileged_s0_h4_arrival_v2_re150_u10cross_fixdone_ep1000'

# ---- shared (3 notebooks 一致) ----
FLOW     = 'wake_data/wake_v8_U1p00_Re150_D12p00_dx0p60_Ti5pct_1200f_roi.npy'
MANIFEST = 'benchmarks/single_u10_cross_tgt15_ep100.json'

PROBE_LAYOUT   = 's0'
HISTORY_LENGTH = 4
TARGET_SPEED   = 1.5
TASK_GEOMETRY  = 'cross_stream'
OBJECTIVE      = 'arrival_v2'

TOTAL_STEPS    = 200_000
BATCH_SIZE     = 256
EVAL_EVERY     = 10_000
EVAL_EPISODES  = 100
TEST_EPISODES  = 100
EVAL_NUM_WORKERS = 6

# ReBRAC anchor (β1=4.0, β2=2.0) + critic LayerNorm only (Gate B frozen)
REBRAC_FLAGS = (
    '--actor-penalty-coef 4.0 --critic-penalty-coef 2.0 '
    '--critic-layernorm --no-actor-layernorm'
)

# FQL teacher + student distill (Gate B frozen)
FQL_FLAGS = (
    '--flow-steps 10 --distill-alpha-bc 1.0 '
    '--teacher-lr 3e-4 --flow-time-embed-dim 32'
)

# n=2 primary; 扩 n=3 时改为 [42, 0, 7] 并重跑本 notebook
TRAIN_SEEDS = [42, 0]
ALGOS = ['rebrac', 'fql']

# ---- paths ----
CHECKPOINT_ROOT = Path(f'checkpoints/fql_succession/p2/{CELL_ID}')
RESULTS_ROOT    = Path(f'results/fql_succession/p2/{CELL_ID}')
TEST_DIR        = RESULTS_ROOT / 'test'
CURVES_DIR      = RESULTS_ROOT / 'training_curves'

# Mirror these 4 small files from checkpoints → results/training_curves/
MIRROR_FILES = ('train_log.jsonl', 'eval_log.csv', 'trainer_state.json', 'train_config.txt')

def save_dir(algo: str, seed: int) -> Path:
    return CHECKPOINT_ROOT / f'{algo}_seed{seed}'

def test_json(algo: str, seed: int) -> Path:
    return TEST_DIR / f'{algo}_seed{seed}.json'

def mirror_dir(algo: str, seed: int) -> Path:
    return CURVES_DIR / f'{algo}_seed{seed}'

print(f'CELL_ID         = {CELL_ID}')
print(f'DATASET         = {DATASET}')
print(f'CHECKPOINT_ROOT = {CHECKPOINT_ROOT}')
print(f'RESULTS_ROOT    = {RESULTS_ROOT}')
print(f'TRAIN_SEEDS     = {TRAIN_SEEDS}')
print(f'ALGOS           = {ALGOS}  ({len(ALGOS)*len(TRAIN_SEEDS)} runs total)')
# Out:
# CELL_ID         = e_uni
# DATASET         = offline_data/privileged_s0_h4_arrival_v2_re150_u10cross_fixdone_ep1000
# CHECKPOINT_ROOT = checkpoints/fql_succession/p2/e_uni
# RESULTS_ROOT    = results/fql_succession/p2/e_uni
# TRAIN_SEEDS     = [42, 0]
# ALGOS           = ['rebrac', 'fql']  (4 runs total)

# %% [markdown]
# ## 3. Pre-flight — dataset / manifest / flow sanity
#
# 在跑 4 run 之前确认:
# 1. **Dataset 路径存在** + `transitions.npz` + `metadata.json` 都 readable
# 2. **`policy_mixture` metadata 符合 cell 定义**(本 cell 期望:[{'policy': 'privileged', 'weight': 1.0}])— 这是 Gate C.2 cell-construction integrity check(per spec v1.3 §6.2,不依赖 audit verdict)
# 3. **Manifest + flow 存在**
# 4. **Transition 数量 sanity**(本 cell 期望 ~{n_tx} transitions)
#
# **如果 §3 任一 assert FAIL → 停止,不要进 §4 训练**(可能 dataset 错配)。

# %%
import json
import numpy as np

DATASET_DIR  = Path(DATASET)
TRANSITIONS  = DATASET_DIR / 'transitions.npz'
METADATA     = DATASET_DIR / 'metadata.json'
MANIFEST_P   = Path(MANIFEST)
FLOW_P       = Path(FLOW)

# ---- existence checks ----
for p in [DATASET_DIR, TRANSITIONS, METADATA, MANIFEST_P, FLOW_P]:
    assert p.exists(), f'[FAIL] missing path: {p}'
print('[ok] all 5 required paths exist')

# ---- metadata: policy_mixture sanity (Gate C.2 cell-construction integrity) ----
meta = json.loads(METADATA.read_text())
print(f'\n[metadata] {METADATA}')
for k in ['policy_mixture', 'action_noise_std', 'num_episodes', 'num_transitions',
          'probe_layout', 'task_geometry', 'objective', 'mean_return', 'success_rate']:
    if k in meta:
        v = meta[k]
        if isinstance(v, float):
            print(f'  {k}: {v:.4f}')
        else:
            print(f'  {k}: {v}')

# ---- cell-specific expected check ----
# Expected: policy_mixture ≈ "[{'policy': 'privileged', 'weight': 1.0}]"
# Expected: action_noise_std ≈ 0.0
# Expected: num_transitions ≈ 86685

n_tx = meta.get('num_transitions', None)
if n_tx is not None:
    assert abs(n_tx - 86685) < 86685 * 0.1, (
        f'[WARN] num_transitions {n_tx} 偏离预期 86685 >10%; '
        f'check dataset path correctness'
    )
    print(f'[ok] num_transitions sanity: {n_tx}')

# ---- transitions.npz key dump ----
with np.load(TRANSITIONS) as data:
    print(f'\n[transitions.npz] keys = {list(data.keys())}')
    for k in data.keys():
        arr = data[k]
        print(f'  {k}: shape={arr.shape}, dtype={arr.dtype}')

# ---- manifest sanity ----
manifest_data = json.loads(MANIFEST_P.read_text())
n_ep_in_manifest = len(manifest_data.get('episodes', []))
print(f'\n[manifest] {MANIFEST_P}  episodes={n_ep_in_manifest}')
assert n_ep_in_manifest >= TEST_EPISODES, (
    f'[FAIL] manifest only has {n_ep_in_manifest} ep, need >= {TEST_EPISODES}')
print(f'[ok] manifest covers >= {TEST_EPISODES} episodes')

print('\n[PRE-FLIGHT PASS] ready to train.')
# Out:
# [ok] all 5 required paths exist
#
# [metadata] offline_data/privileged_s0_h4_arrival_v2_re150_u10cross_fixdone_ep1000/metadata.json
#   policy_mixture: [{'policy': 'privileged', 'weight': 1.0}]
#   action_noise_std: 0.0000
#   num_episodes: 1000
#   num_transitions: 86685
#   probe_layout: s0
#   task_geometry: cross_stream
#   objective: arrival_v2
#   mean_return: 132.5550
#   success_rate: 0.9850
# [ok] num_transitions sanity: 86685
#
# [transitions.npz] keys = ['obs', 'actions', 'next_actions', 'rewards', 'costs', 'next_obs', 'dones', 'terminateds', 'truncateds', 'terminal_reason_codes', 'behavior_policy_codes', 'privileged_obs', 'next_privileged_obs']
#   obs: shape=(86685, 48), dtype=float32
#   actions: shape=(86685, 2), dtype=float32
#   next_actions: shape=(86685, 2), dtype=float32
#   rewards: shape=(86685,), dtype=float32
#   costs: shape=(86685,), dtype=float32
#   next_obs: shape=(86685, 48), dtype=float32
#   dones: shape=(86685,), dtype=float32
#   terminateds: shape=(86685,), dtype=float32
#   truncateds: shape=(86685,), dtype=float32
#   terminal_reason_codes: shape=(86685,), dtype=int8
#   behavior_policy_codes: shape=(86685,), dtype=int8
#   privileged_obs: shape=(86685, 2), dtype=float32
#   next_privileged_obs: shape=(86685, 2), dtype=float32
#
# [manifest] benchmarks/single_u10_cross_tgt15_ep100.json  episodes=100
# [ok] manifest covers >= 100 episodes
#
# [PRE-FLIGHT PASS] ready to train.

# %% [markdown]
# ## 4. 训练 — 2 algo × 2 seeds = 4 runs
#
# `!python` magic 实时 stream(per spec Bug 4 mitigation);路径单引号包裹(per Bug 5,handles Colab `Colab Notebooks` Drive 空格)。
#
# **Skip-resume**:`agent_final.pt` 存在则 skip 该 (algo, seed) 训练。**Mirror**:每 run 训完后立刻 mirror 4 个小文件(`train_log.jsonl`, `eval_log.csv`, `trainer_state.json`, `train_config.txt`)到 `results/.../training_curves/`,便于本机 sync 后画 learning curve(per spec §4.2 D21)。
#
# **`--skip-final-eval`**:训练阶段不跑 final eval,由 §5 独立 `evaluate_offline` 跑 100-ep test(per spec §4.2 two-step protocol)。
#
# **预期 wallclock**:每 run ~30-45 min(L4,200k steps + 20 in-training eval pts × 100 ep)。4 runs 串行 ~2-3h。

# %%
import time

t_start_train = time.time()

for algo in ALGOS:
    ALGO_FLAGS = REBRAC_FLAGS if algo == 'rebrac' else FQL_FLAGS
    for seed in TRAIN_SEEDS:
        sd = save_dir(algo, seed)
        sd_str = str(sd)

        if (sd / 'agent_final.pt').exists():
            print(f'[skip-train] {algo} seed={seed} (agent_final.pt exists at {sd})')
            continue

        sd.mkdir(parents=True, exist_ok=True)
        print(f'\n{"=" * 72}')
        print(f'  train {algo} seed={seed} → {sd}')
        print(f'{"=" * 72}')
        t0 = time.time()

        # !python -m scripts.train_offline \
            --algo {algo} \
            --offline-data '{DATASET}/transitions.npz' \
            --flow '{FLOW}' \
            --manifest '{MANIFEST}' \
            --probe-layout {PROBE_LAYOUT} \
            --history-length {HISTORY_LENGTH} \
            --target-speed {TARGET_SPEED} \
            --task-geometry {TASK_GEOMETRY} \
            --objective {OBJECTIVE} \
            --total-steps {TOTAL_STEPS} \
            --batch-size {BATCH_SIZE} \
            --eval-every {EVAL_EVERY} \
            --eval-episodes {EVAL_EPISODES} \
            {ALGO_FLAGS} \
            --skip-final-eval \
            --seed {seed} \
            --save-dir '{sd_str}' \
            --device cuda

        print(f'[train done] {algo} seed={seed} in {(time.time() - t0) / 60:.1f} min')

print(f'\n[all train] total = {(time.time() - t_start_train) / 60:.1f} min')

# ---- Mirror small files (idempotent overwrite) ----
print(f'\n{"=" * 72}')
print('  mirror training curves → results/.../training_curves/')
print(f'{"=" * 72}')

for algo in ALGOS:
    for seed in TRAIN_SEEDS:
        src_dir = save_dir(algo, seed)
        dst_dir = mirror_dir(algo, seed)
        dst_dir.mkdir(parents=True, exist_ok=True)
        n_copied = 0
        for fname in MIRROR_FILES:
            src = src_dir / fname
            if src.exists():
                shutil.copy2(src, dst_dir / fname)
                n_copied += 1
        marker = '✓' if n_copied == len(MIRROR_FILES) else '⚠'
        print(f'  {marker} {algo}_seed{seed}: {n_copied}/{len(MIRROR_FILES)} → {dst_dir}')
# Out:
# ========================================================================
#   train rebrac seed=42 → checkpoints/fql_succession/p2/e_uni/rebrac_seed42
# ========================================================================
# [offline] algo=rebrac transitions=86685 obs_dim=48 action_dim=2 protocol=deployable tensor_replay=on eval_workers=1 sampling=uniform total_steps=200000
# [train] step=1 q=-0.639 critic=124.113 actor=6.047 bc=1.269 lambda=1.517 critic_pen=1.364
# [train] step=1000 q=2.265 critic=123.339 actor=-0.306 bc=0.032 lambda=0.191 critic_pen=0.134
# [train] step=2000 q=4.683 critic=15.152 actor=-0.518 bc=0.036 lambda=0.142 critic_pen=0.117
# [train] step=3000 q=9.673 critic=3.315 actor=-0.658 bc=0.039 lambda=0.084 critic_pen=0.101
# [train] step=4000 q=13.934 critic=5.235 actor=-0.703 bc=0.039 lambda=0.062 critic_pen=0.096
# [train] step=5000 q=17.733 critic=2.811 actor=-0.743 bc=0.037 lambda=0.050 critic_pen=0.084
# [train] step=6000 q=18.168 critic=3.995 actor=-0.773 bc=0.027 lambda=0.048 critic_pen=0.111
# [train] step=7000 q=23.870 critic=2.880 actor=-0.788 bc=0.027 lambda=0.038 critic_pen=0.105
# [train] step=8000 q=24.921 critic=5.559 actor=-0.713 bc=0.049 lambda=0.036 critic_pen=0.128
# [train] step=9000 q=28.621 critic=3.924 actor=-0.833 bc=0.021 lambda=0.032 critic_pen=0.070
# [train] step=10000 q=34.886 critic=2.565 actor=-0.852 bc=0.019 lambda=0.027 critic_pen=0.114
# [eval] step=10000 success=70.00% return=37.70 time=47.60s energy=36882.46 path=50.78 prog=0.791
# [train] step=11000 q=35.534 critic=4.536 actor=-0.826 bc=0.025 lambda=0.026 critic_pen=0.101
# [train] step=12000 q=36.148 critic=4.163 actor=-0.926 bc=0.006 lambda=0.026 critic_pen=0.090
# [train] step=13000 q=40.375 critic=3.053 actor=-0.777 bc=0.040 lambda=0.023 critic_pen=0.097
# [train] step=14000 q=45.735 critic=2.999 actor=-0.901 bc=0.012 lambda=0.021 critic_pen=0.091
# [train] step=15000 q=51.419 critic=2.608 actor=-0.859 bc=0.025 lambda=0.019 critic_pen=0.076
# [train] step=16000 q=48.836 critic=2.815 actor=-0.870 bc=0.019 lambda=0.019 critic_pen=0.083
# [train] step=17000 q=56.445 critic=2.917 actor=-0.961 bc=0.004 lambda=0.017 critic_pen=0.092
# [train] step=18000 q=54.976 critic=4.001 actor=-0.932 bc=0.004 lambda=0.017 critic_pen=0.103
# [train] step=19000 q=56.491 critic=2.519 actor=-0.873 bc=0.017 lambda=0.017 critic_pen=0.096
# [train] step=20000 q=57.071 critic=2.287 actor=-0.900 bc=0.007 lambda=0.016 critic_pen=0.078
# [eval] step=20000 success=51.00% return=-31.30 time=47.94s energy=37140.64 path=54.86 prog=0.637
# [train] step=21000 q=63.581 critic=4.604 actor=-0.924 bc=0.011 lambda=0.015 critic_pen=0.085
# [train] step=22000 q=65.809 critic=5.378 actor=-0.948 bc=0.004 lambda=0.015 critic_pen=0.127
# [train] step=23000 q=66.818 critic=3.750 actor=-0.820 bc=0.036 lambda=0.014 critic_pen=0.111
# [train] step=24000 q=69.043 critic=3.189 actor=-0.871 bc=0.025 lambda=0.014 critic_pen=0.082
# [train] step=25000 q=69.067 critic=8.064 actor=-0.879 bc=0.023 lambda=0.014 critic_pen=0.105
# [train] step=26000 q=72.570 critic=6.243 actor=-0.877 bc=0.022 lambda=0.013 critic_pen=0.117
# [train] step=27000 q=68.194 critic=7.056 actor=-0.841 bc=0.031 lambda=0.014 critic_pen=0.091
# [train] step=28000 q=72.932 critic=5.696 actor=-0.912 bc=0.011 lambda=0.013 critic_pen=0.099
# [train] step=29000 q=75.852 critic=254.940 actor=-0.954 bc=0.005 lambda=0.013 critic_pen=0.085
# [train] step=30000 q=73.882 critic=6.163 actor=-0.967 bc=0.002 lambda=0.013 critic_pen=0.075
# [eval] step=30000 success=47.00% return=-47.08 time=46.90s energy=36650.89 path=54.99 prog=0.621
# [train] step=31000 q=79.935 critic=2.292 actor=-0.968 bc=0.003 lambda=0.012 critic_pen=0.074
# [train] step=32000 q=78.465 critic=3.295 actor=-0.971 bc=0.002 lambda=0.012 critic_pen=0.095
# [train] step=33000 q=81.127 critic=3.542 actor=-0.971 bc=0.003 lambda=0.012 critic_pen=0.077
# [train] step=34000 q=80.171 critic=5.712 actor=-0.973 bc=0.002 lambda=0.012 critic_pen=0.083
# [train] step=35000 q=78.930 critic=5.368 actor=-0.916 bc=0.018 lambda=0.013 critic_pen=0.075
# [train] step=36000 q=80.146 critic=4.422 actor=-0.933 bc=0.012 lambda=0.012 critic_pen=0.105
# [train] step=37000 q=82.639 critic=4.318 actor=-0.901 bc=0.022 lambda=0.012 critic_pen=0.097
# [train] step=38000 q=82.121 critic=2.241 actor=-0.892 bc=0.023 lambda=0.012 critic_pen=0.093
# [train] step=39000 q=81.115 critic=3.842 actor=-0.946 bc=0.010 lambda=0.012 critic_pen=0.090
# [train] step=40000 q=82.768 critic=352.716 actor=-0.947 bc=0.011 lambda=0.012 critic_pen=0.083
# [eval] step=40000 success=59.00% return=-3.62 time=46.59s energy=36294.92 path=52.99 prog=0.698
# [train] step=41000 q=85.304 critic=2.972 actor=-0.961 bc=0.007 lambda=0.012 critic_pen=0.086
# [train] step=42000 q=86.788 critic=1.774 actor=-0.912 bc=0.021 lambda=0.011 critic_pen=0.117
# [train] step=43000 q=84.823 critic=2.186 actor=-0.942 bc=0.013 lambda=0.012 critic_pen=0.090
# [train] step=44000 q=86.270 critic=1.779 actor=-0.976 bc=0.006 lambda=0.012 critic_pen=0.066
# [train] step=45000 q=84.797 critic=4.028 actor=-0.951 bc=0.011 lambda=0.012 critic_pen=0.100
# [train] step=46000 q=87.077 critic=1.251 actor=-0.973 bc=0.007 lambda=0.011 critic_pen=0.086
# [train] step=47000 q=88.437 critic=0.782 actor=-0.961 bc=0.010 lambda=0.011 critic_pen=0.092
# [train] step=48000 q=84.077 critic=1.580 actor=-0.945 bc=0.013 lambda=0.012 critic_pen=0.079
# [train] step=49000 q=84.027 critic=1.183 actor=-0.909 bc=0.021 lambda=0.012 critic_pen=0.064
# [train] step=50000 q=86.963 critic=0.945 actor=-0.963 bc=0.009 lambda=0.011 critic_pen=0.084
# [eval] step=50000 success=83.00% return=80.35 time=44.99s energy=35091.15 path=49.42 prog=0.818
# [train] step=51000 q=84.560 critic=1.419 actor=-0.949 bc=0.013 lambda=0.012 critic_pen=0.072
# [train] step=52000 q=87.447 critic=1.173 actor=-0.977 bc=0.006 lambda=0.011 critic_pen=0.071
# [train] step=53000 q=86.755 critic=0.944 actor=-0.979 bc=0.005 lambda=0.012 critic_pen=0.070
# [train] step=54000 q=85.111 critic=1.029 actor=-0.912 bc=0.022 lambda=0.012 critic_pen=0.071
# [train] step=55000 q=87.514 critic=1.181 actor=-0.942 bc=0.015 lambda=0.011 critic_pen=0.097
# [train] step=56000 q=85.910 critic=258.743 actor=-0.871 bc=0.032 lambda=0.012 critic_pen=0.102
# [train] step=57000 q=86.579 critic=0.757 actor=-0.911 bc=0.022 lambda=0.012 critic_pen=0.075
# [train] step=58000 q=83.454 critic=1.236 actor=-0.884 bc=0.026 lambda=0.012 critic_pen=0.082
# [train] step=59000 q=82.414 critic=0.938 actor=-0.899 bc=0.022 lambda=0.012 critic_pen=0.075
# [train] step=60000 q=83.795 critic=0.952 actor=-0.920 bc=0.015 lambda=0.012 critic_pen=0.064
# [eval] step=60000 success=35.00% return=-79.22 time=47.09s energy=36745.46 path=54.41 prog=0.677
# [train] step=61000 q=86.785 critic=0.784 actor=-0.928 bc=0.018 lambda=0.012 critic_pen=0.077
# [train] step=62000 q=85.825 critic=1.135 actor=-0.983 bc=0.004 lambda=0.012 critic_pen=0.084
# [train] step=63000 q=86.869 critic=0.860 actor=-0.979 bc=0.002 lambda=0.011 critic_pen=0.086
# [train] step=64000 q=87.591 critic=0.899 actor=-0.964 bc=0.009 lambda=0.011 critic_pen=0.082
# [train] step=65000 q=83.258 critic=6.079 actor=-0.960 bc=0.004 lambda=0.012 critic_pen=0.074
# [train] step=66000 q=86.192 critic=1.056 actor=-0.925 bc=0.018 lambda=0.012 critic_pen=0.082
# [train] step=67000 q=86.633 critic=1.163 actor=-0.987 bc=0.003 lambda=0.012 critic_pen=0.072
# [train] step=68000 q=84.432 critic=1.083 actor=-0.920 bc=0.011 lambda=0.011 critic_pen=0.091
# [train] step=69000 q=86.763 critic=1.260 actor=-0.891 bc=0.027 lambda=0.012 critic_pen=0.096
# [train] step=70000 q=84.794 critic=5.191 actor=-0.919 bc=0.017 lambda=0.012 critic_pen=0.071
# [eval] step=70000 success=74.00% return=48.96 time=46.44s energy=36234.17 path=51.99 prog=0.778
# [train] step=71000 q=86.854 critic=1.329 actor=-0.931 bc=0.017 lambda=0.012 critic_pen=0.073
# [train] step=72000 q=86.773 critic=1.052 actor=-0.985 bc=0.004 lambda=0.012 critic_pen=0.088
# [train] step=73000 q=88.443 critic=0.806 actor=-0.978 bc=0.006 lambda=0.011 critic_pen=0.101
# [train] step=74000 q=85.518 critic=1.152 actor=-0.992 bc=0.002 lambda=0.012 critic_pen=0.082
# [train] step=75000 q=84.867 critic=1.384 actor=-0.930 bc=0.009 lambda=0.011 critic_pen=0.101
# [train] step=76000 q=85.987 critic=1.077 actor=-0.960 bc=0.002 lambda=0.011 critic_pen=0.086
# [train] step=77000 q=86.493 critic=0.940 actor=-0.944 bc=0.014 lambda=0.012 critic_pen=0.086
# [train] step=78000 q=86.160 critic=0.940 actor=-0.980 bc=0.001 lambda=0.011 critic_pen=0.072
# [train] step=79000 q=87.700 critic=0.776 actor=-0.913 bc=0.022 lambda=0.011 critic_pen=0.080
# [train] step=80000 q=87.812 critic=1.578 actor=-0.974 bc=0.006 lambda=0.011 critic_pen=0.063
# [eval] step=80000 success=78.00% return=66.18 time=47.84s energy=37338.38 path=52.24 prog=0.828
# [train] step=81000 q=87.776 critic=0.866 actor=-0.968 bc=0.008 lambda=0.011 critic_pen=0.077
# [train] step=82000 q=85.976 critic=0.935 actor=-0.966 bc=0.003 lambda=0.011 critic_pen=0.073
# [train] step=83000 q=86.125 critic=1.359 actor=-0.985 bc=0.001 lambda=0.011 critic_pen=0.077
# [train] step=84000 q=87.422 critic=0.885 actor=-0.976 bc=0.001 lambda=0.011 critic_pen=0.092
# [train] step=85000 q=86.410 critic=1.482 actor=-0.974 bc=0.003 lambda=0.011 critic_pen=0.077
# [train] step=86000 q=86.159 critic=0.828 actor=-0.881 bc=0.025 lambda=0.011 critic_pen=0.072
# [train] step=87000 q=84.934 critic=0.962 actor=-0.927 bc=0.013 lambda=0.012 critic_pen=0.071
# [train] step=88000 q=86.428 critic=1.467 actor=-0.947 bc=0.013 lambda=0.012 critic_pen=0.079
# [train] step=89000 q=85.113 critic=1.072 actor=-0.960 bc=0.004 lambda=0.011 critic_pen=0.076
# [train] step=90000 q=83.541 critic=1.472 actor=-0.928 bc=0.009 lambda=0.012 critic_pen=0.095
# [eval] step=90000 success=82.00% return=74.40 time=45.18s energy=35217.71 path=49.71 prog=0.799
# [train] step=91000 q=87.037 critic=1.369 actor=-0.957 bc=0.005 lambda=0.011 critic_pen=0.084
# [train] step=92000 q=85.645 critic=1.175 actor=-0.945 bc=0.003 lambda=0.011 critic_pen=0.069
# [train] step=93000 q=88.972 critic=1.289 actor=-0.975 bc=0.006 lambda=0.011 critic_pen=0.064
# [train] step=94000 q=85.344 critic=1.829 actor=-0.968 bc=0.006 lambda=0.012 critic_pen=0.059
# [train] step=95000 q=85.704 critic=1.140 actor=-0.956 bc=0.001 lambda=0.011 critic_pen=0.073
# [train] step=96000 q=81.496 critic=14.515 actor=-0.876 bc=0.011 lambda=0.011 critic_pen=0.081
# [train] step=97000 q=88.390 critic=0.690 actor=-0.950 bc=0.013 lambda=0.011 critic_pen=0.077
# [train] step=98000 q=87.099 critic=0.713 actor=-0.925 bc=0.014 lambda=0.011 critic_pen=0.084
# [train] step=99000 q=88.639 critic=0.681 actor=-0.928 bc=0.018 lambda=0.011 critic_pen=0.077
# [train] step=100000 q=86.971 critic=1.720 actor=-0.958 bc=0.008 lambda=0.011 critic_pen=0.092
# [eval] step=100000 success=79.00% return=71.52 time=47.44s energy=37015.64 path=51.08 prog=0.849
# [train] step=101000 q=85.705 critic=0.812 actor=-0.944 bc=0.014 lambda=0.012 critic_pen=0.081
# [train] step=102000 q=86.999 critic=1.128 actor=-0.933 bc=0.017 lambda=0.011 critic_pen=0.073
# [train] step=103000 q=86.061 critic=1.170 actor=-0.926 bc=0.013 lambda=0.011 critic_pen=0.078
# [train] step=104000 q=87.786 critic=1.944 actor=-0.979 bc=0.004 lambda=0.011 critic_pen=0.103
# [train] step=105000 q=86.388 critic=0.865 actor=-0.917 bc=0.021 lambda=0.012 critic_pen=0.075
# [train] step=106000 q=88.527 critic=0.991 actor=-0.986 bc=0.004 lambda=0.011 critic_pen=0.068
# [train] step=107000 q=85.717 critic=1.766 actor=-0.971 bc=0.007 lambda=0.012 critic_pen=0.080
# [train] step=108000 q=85.979 critic=0.826 actor=-0.961 bc=0.003 lambda=0.011 critic_pen=0.083
# [train] step=109000 q=86.413 critic=2.823 actor=-0.983 bc=0.003 lambda=0.011 critic_pen=0.095
# [train] step=110000 q=86.403 critic=1.192 actor=-0.935 bc=0.013 lambda=0.011 critic_pen=0.079
# [eval] step=110000 success=79.00% return=69.95 time=45.05s energy=35092.46 path=49.35 prog=0.841
# [train] step=111000 q=86.822 critic=1.051 actor=-0.981 bc=0.005 lambda=0.012 critic_pen=0.092
# [train] step=112000 q=86.157 critic=1.549 actor=-0.986 bc=0.002 lambda=0.012 critic_pen=0.093
# [train] step=113000 q=87.042 critic=1.908 actor=-0.968 bc=0.005 lambda=0.011 critic_pen=0.104
# [train] step=114000 q=82.933 critic=1.229 actor=-0.909 bc=0.007 lambda=0.011 critic_pen=0.065
# [train] step=115000 q=87.296 critic=0.799 actor=-0.962 bc=0.005 lambda=0.011 critic_pen=0.089
# [train] step=116000 q=87.311 critic=1.135 actor=-0.940 bc=0.007 lambda=0.011 critic_pen=0.076
# [train] step=117000 q=89.065 critic=0.542 actor=-0.992 bc=0.002 lambda=0.011 critic_pen=0.085
# [train] step=118000 q=90.335 critic=0.491 actor=-0.971 bc=0.007 lambda=0.011 critic_pen=0.086
# [train] step=119000 q=87.923 critic=0.880 actor=-0.989 bc=0.003 lambda=0.011 critic_pen=0.072
# [train] step=120000 q=86.840 critic=0.955 actor=-0.937 bc=0.011 lambda=0.011 critic_pen=0.076
# [eval] step=120000 success=65.00% return=20.48 time=47.72s energy=37254.88 path=53.27 prog=0.767
# [train] step=121000 q=86.958 critic=1.682 actor=-0.951 bc=0.007 lambda=0.011 critic_pen=0.070
# [train] step=122000 q=86.927 critic=0.951 actor=-0.979 bc=0.005 lambda=0.012 critic_pen=0.086
# [train] step=123000 q=89.028 critic=0.776 actor=-0.939 bc=0.015 lambda=0.011 critic_pen=0.077
# [train] step=124000 q=85.705 critic=2.690 actor=-0.976 bc=0.001 lambda=0.011 critic_pen=0.092
# [train] step=125000 q=88.014 critic=0.899 actor=-0.948 bc=0.008 lambda=0.011 critic_pen=0.089
# [train] step=126000 q=86.501 critic=0.756 actor=-0.948 bc=0.008 lambda=0.011 critic_pen=0.093
# [train] step=127000 q=86.375 critic=1.038 actor=-0.917 bc=0.011 lambda=0.011 critic_pen=0.095
# [train] step=128000 q=87.314 critic=0.954 actor=-0.940 bc=0.015 lambda=0.011 critic_pen=0.081
# [train] step=129000 q=86.871 critic=0.586 actor=-0.948 bc=0.002 lambda=0.011 critic_pen=0.080
# [train] step=130000 q=84.164 critic=0.550 actor=-0.849 bc=0.027 lambda=0.011 critic_pen=0.085
# [eval] step=130000 success=80.00% return=69.41 time=45.57s energy=35536.80 path=50.42 prog=0.819
# [train] step=131000 q=88.467 critic=0.810 actor=-0.974 bc=0.004 lambda=0.011 critic_pen=0.071
# [train] step=132000 q=87.792 critic=0.793 actor=-0.946 bc=0.010 lambda=0.011 critic_pen=0.087
# [train] step=133000 q=88.023 critic=0.671 actor=-0.997 bc=0.001 lambda=0.011 critic_pen=0.072
# [train] step=134000 q=85.598 critic=9.158 actor=-0.963 bc=0.002 lambda=0.011 critic_pen=0.082
# [train] step=135000 q=86.852 critic=0.745 actor=-0.943 bc=0.006 lambda=0.011 critic_pen=0.083
# [train] step=136000 q=84.534 critic=1.126 actor=-0.924 bc=0.007 lambda=0.011 critic_pen=0.084
# [train] step=137000 q=87.512 critic=0.681 actor=-0.945 bc=0.012 lambda=0.011 critic_pen=0.086
# [train] step=138000 q=86.900 critic=0.701 actor=-0.980 bc=0.005 lambda=0.012 critic_pen=0.071
# [train] step=139000 q=89.082 critic=0.516 actor=-0.947 bc=0.013 lambda=0.011 critic_pen=0.098
# [train] step=140000 q=85.150 critic=0.615 actor=-0.925 bc=0.002 lambda=0.011 critic_pen=0.087
# [eval] step=140000 success=81.00% return=75.22 time=44.89s energy=35016.22 path=49.30 prog=0.830
# [train] step=141000 q=85.968 critic=1.913 actor=-0.934 bc=0.011 lambda=0.011 critic_pen=0.060
# [train] step=142000 q=89.365 critic=0.464 actor=-0.881 bc=0.025 lambda=0.011 critic_pen=0.088
# [train] step=143000 q=83.260 critic=0.988 actor=-0.925 bc=0.001 lambda=0.011 critic_pen=0.091
# [train] step=144000 q=87.877 critic=0.787 actor=-0.998 bc=0.001 lambda=0.011 critic_pen=0.096
# [train] step=145000 q=81.740 critic=1.923 actor=-0.870 bc=0.010 lambda=0.011 critic_pen=0.106
# [train] step=146000 q=87.149 critic=0.698 actor=-0.916 bc=0.012 lambda=0.011 critic_pen=0.095
# [train] step=147000 q=87.789 critic=0.569 actor=-0.979 bc=0.001 lambda=0.011 critic_pen=0.070
# [train] step=148000 q=86.077 critic=0.771 actor=-0.908 bc=0.014 lambda=0.011 critic_pen=0.106
# [train] step=149000 q=89.348 critic=0.635 actor=-0.987 bc=0.003 lambda=0.011 critic_pen=0.087
# [train] step=150000 q=87.626 critic=0.590 actor=-0.919 bc=0.016 lambda=0.011 critic_pen=0.087
# [eval] step=150000 success=75.00% return=56.00 time=46.44s energy=36242.77 path=51.02 prog=0.818
# [train] step=151000 q=87.088 critic=0.989 actor=-0.982 bc=0.005 lambda=0.011 critic_pen=0.084
# [train] step=152000 q=86.351 critic=0.777 actor=-0.924 bc=0.013 lambda=0.011 critic_pen=0.085
# [train] step=153000 q=87.908 critic=0.680 actor=-0.978 bc=0.001 lambda=0.011 critic_pen=0.077
# [train] step=154000 q=89.276 critic=0.609 actor=-0.961 bc=0.010 lambda=0.011 critic_pen=0.078
# [train] step=155000 q=85.111 critic=0.957 actor=-0.947 bc=0.004 lambda=0.011 critic_pen=0.078
# [train] step=156000 q=84.862 critic=0.588 actor=-0.954 bc=0.002 lambda=0.011 critic_pen=0.077
# [train] step=157000 q=89.302 critic=0.562 actor=-0.967 bc=0.008 lambda=0.011 critic_pen=0.071
# [train] step=158000 q=88.126 critic=0.512 actor=-0.974 bc=0.006 lambda=0.011 critic_pen=0.079
# [train] step=159000 q=86.941 critic=0.863 actor=-0.963 bc=0.001 lambda=0.011 critic_pen=0.094
# [train] step=160000 q=84.938 critic=0.650 actor=-0.935 bc=0.002 lambda=0.011 critic_pen=0.083
# [eval] step=160000 success=71.00% return=34.64 time=48.96s energy=38350.25 path=56.02 prog=0.686
# [train] step=161000 q=85.643 critic=0.645 actor=-0.915 bc=0.011 lambda=0.011 critic_pen=0.074
# [train] step=162000 q=88.166 critic=0.575 actor=-0.974 bc=0.003 lambda=0.011 critic_pen=0.078
# [train] step=163000 q=90.137 critic=0.598 actor=-0.954 bc=0.012 lambda=0.011 critic_pen=0.068
# [train] step=164000 q=87.777 critic=0.736 actor=-0.953 bc=0.010 lambda=0.011 critic_pen=0.072
# [train] step=165000 q=88.110 critic=0.715 actor=-0.991 bc=0.002 lambda=0.011 critic_pen=0.082
# [train] step=166000 q=87.845 critic=0.466 actor=-0.974 bc=0.001 lambda=0.011 critic_pen=0.072
# [train] step=167000 q=88.512 critic=0.696 actor=-0.972 bc=0.002 lambda=0.011 critic_pen=0.071
# [train] step=168000 q=88.301 critic=0.561 actor=-0.932 bc=0.013 lambda=0.011 critic_pen=0.080
# [train] step=169000 q=86.747 critic=0.804 actor=-0.964 bc=0.004 lambda=0.011 critic_pen=0.095
# [train] step=170000 q=87.399 critic=1.039 actor=-0.963 bc=0.005 lambda=0.011 critic_pen=0.087
# [eval] step=170000 success=59.00% return=-0.46 time=48.85s energy=38166.62 path=54.61 prog=0.742
# [train] step=171000 q=85.627 critic=0.560 actor=-0.922 bc=0.002 lambda=0.011 critic_pen=0.071
# [train] step=172000 q=85.410 critic=0.792 actor=-0.953 bc=0.003 lambda=0.011 critic_pen=0.072
# [train] step=173000 q=88.761 critic=0.464 actor=-0.995 bc=0.001 lambda=0.011 critic_pen=0.100
# [train] step=174000 q=87.539 critic=0.538 actor=-0.975 bc=0.001 lambda=0.011 critic_pen=0.075
# [train] step=175000 q=85.311 critic=0.573 actor=-0.908 bc=0.009 lambda=0.011 critic_pen=0.078
# [train] step=176000 q=86.083 critic=0.523 actor=-0.910 bc=0.013 lambda=0.011 critic_pen=0.068
# [train] step=177000 q=88.656 critic=0.569 actor=-0.990 bc=0.002 lambda=0.011 critic_pen=0.083
# [train] step=178000 q=87.579 critic=0.630 actor=-0.964 bc=0.004 lambda=0.011 critic_pen=0.087
# [train] step=179000 q=86.989 critic=0.549 actor=-0.913 bc=0.017 lambda=0.011 critic_pen=0.090
# [train] step=180000 q=89.100 critic=2.415 actor=-0.972 bc=0.007 lambda=0.011 critic_pen=0.069
# [eval] step=180000 success=71.00% return=40.43 time=47.80s energy=37346.98 path=52.99 prog=0.781
# [train] step=181000 q=87.584 critic=0.647 actor=-0.995 bc=0.001 lambda=0.011 critic_pen=0.064
# [train] step=182000 q=86.331 critic=0.663 actor=-0.938 bc=0.002 lambda=0.011 critic_pen=0.087
# [train] step=183000 q=87.557 critic=0.578 actor=-0.978 bc=0.001 lambda=0.011 critic_pen=0.074
# [train] step=184000 q=89.389 critic=0.574 actor=-0.939 bc=0.015 lambda=0.011 critic_pen=0.104
# [train] step=185000 q=84.604 critic=0.771 actor=-0.843 bc=0.021 lambda=0.011 critic_pen=0.102
# [train] step=186000 q=87.741 critic=0.674 actor=-0.934 bc=0.006 lambda=0.011 critic_pen=0.104
# [train] step=187000 q=87.474 critic=0.649 actor=-0.981 bc=0.000 lambda=0.011 critic_pen=0.082
# [train] step=188000 q=88.067 critic=1.248 actor=-0.973 bc=0.002 lambda=0.011 critic_pen=0.081
# [train] step=189000 q=84.696 critic=0.571 actor=-0.925 bc=0.001 lambda=0.011 critic_pen=0.079
# [train] step=190000 q=85.989 critic=0.561 actor=-0.931 bc=0.002 lambda=0.011 critic_pen=0.067
# [eval] step=190000 success=80.00% return=67.31 time=46.27s energy=36107.28 path=51.21 prog=0.798
# [train] step=191000 q=89.049 critic=0.547 actor=-0.987 bc=0.003 lambda=0.011 critic_pen=0.094
# [train] step=192000 q=83.296 critic=0.944 actor=-0.921 bc=0.001 lambda=0.011 critic_pen=0.060
# [train] step=193000 q=87.852 critic=1.026 actor=-0.958 bc=0.010 lambda=0.011 critic_pen=0.078
# [train] step=194000 q=85.410 critic=0.526 actor=-0.940 bc=0.000 lambda=0.011 critic_pen=0.079
# [train] step=195000 q=88.072 critic=0.416 actor=-0.997 bc=0.001 lambda=0.011 critic_pen=0.074
# [train] step=196000 q=87.149 critic=0.570 actor=-0.936 bc=0.011 lambda=0.011 critic_pen=0.084
# [train] step=197000 q=89.560 critic=7.198 actor=-0.985 bc=0.004 lambda=0.011 critic_pen=0.094
# [train] step=198000 q=87.251 critic=0.661 actor=-0.977 bc=0.001 lambda=0.011 critic_pen=0.085
# [train] step=199000 q=90.264 critic=0.408 actor=-0.994 bc=0.001 lambda=0.011 critic_pen=0.058
# [train] step=200000 q=89.837 critic=0.485 actor=-0.993 bc=0.002 lambda=0.011 critic_pen=0.078
# [eval] step=200000 success=89.00% return=102.32 time=44.96s energy=35060.47 path=49.01 prog=0.862
# [train done] rebrac seed=42 in 65.8 min
#
# ========================================================================
#   train rebrac seed=0 → checkpoints/fql_succession/p2/e_uni/rebrac_seed0
# ========================================================================
# [offline] algo=rebrac transitions=86685 obs_dim=48 action_dim=2 protocol=deployable tensor_replay=on eval_workers=1 sampling=uniform total_steps=200000
# [train] step=1 q=-0.791 critic=228.173 actor=6.217 bc=1.304 lambda=1.264 critic_pen=1.368
# [train] step=1000 q=1.331 critic=49.085 actor=-0.151 bc=0.042 lambda=0.239 critic_pen=0.131
# [train] step=2000 q=2.906 critic=10.010 actor=-0.417 bc=0.025 lambda=0.177 critic_pen=0.096
# [train] step=3000 q=7.748 critic=2.655 actor=-0.705 bc=0.013 lambda=0.097 critic_pen=0.088
# [train] step=4000 q=17.018 critic=5.280 actor=-0.674 bc=0.055 lambda=0.053 critic_pen=0.114
# [train] step=5000 q=15.861 critic=4.013 actor=-0.735 bc=0.031 lambda=0.054 critic_pen=0.085
# [train] step=6000 q=21.048 critic=1.750 actor=-0.898 bc=0.004 lambda=0.044 critic_pen=0.089
# [train] step=7000 q=24.761 critic=3.975 actor=-0.851 bc=0.019 lambda=0.037 critic_pen=0.096
# [train] step=8000 q=25.300 critic=3.302 actor=-0.702 bc=0.053 lambda=0.036 critic_pen=0.103
# [train] step=9000 q=26.726 critic=3.374 actor=-0.876 bc=0.008 lambda=0.034 critic_pen=0.096
# [train] step=10000 q=26.476 critic=4.160 actor=-0.886 bc=0.007 lambda=0.035 critic_pen=0.082
# [eval] step=10000 success=57.00% return=-21.66 time=48.58s energy=37792.57 path=57.66 prog=0.541
# [train] step=11000 q=36.810 critic=2.160 actor=-0.811 bc=0.031 lambda=0.025 critic_pen=0.097
# [train] step=12000 q=41.142 critic=3.026 actor=-0.889 bc=0.015 lambda=0.023 critic_pen=0.121
# [train] step=13000 q=40.637 critic=10.453 actor=-0.889 bc=0.016 lambda=0.023 critic_pen=0.088
# [train] step=14000 q=48.522 critic=1.868 actor=-0.924 bc=0.004 lambda=0.019 critic_pen=0.067
# [train] step=15000 q=49.468 critic=2.668 actor=-0.784 bc=0.042 lambda=0.019 critic_pen=0.098
# [train] step=16000 q=47.669 critic=5.276 actor=-0.905 bc=0.007 lambda=0.020 critic_pen=0.070
# [train] step=17000 q=50.340 critic=10.920 actor=-0.799 bc=0.029 lambda=0.018 critic_pen=0.092
# [train] step=18000 q=50.753 critic=154.342 actor=-0.936 bc=0.002 lambda=0.019 critic_pen=0.071
# [train] step=19000 q=52.203 critic=2.090 actor=-0.919 bc=0.003 lambda=0.018 critic_pen=0.091
# [train] step=20000 q=61.871 critic=5.566 actor=-0.842 bc=0.029 lambda=0.015 critic_pen=0.105
# [eval] step=20000 success=55.00% return=-19.25 time=47.83s energy=37163.81 path=54.51 prog=0.663
# [train] step=21000 q=64.183 critic=5.291 actor=-0.836 bc=0.026 lambda=0.015 critic_pen=0.092
# [train] step=22000 q=64.339 critic=6.705 actor=-0.903 bc=0.013 lambda=0.015 critic_pen=0.076
# [train] step=23000 q=59.929 critic=5.413 actor=-0.856 bc=0.024 lambda=0.016 critic_pen=0.081
# [train] step=24000 q=61.180 critic=4.993 actor=-0.912 bc=0.008 lambda=0.015 critic_pen=0.080
# [train] step=25000 q=67.349 critic=4.848 actor=-0.862 bc=0.026 lambda=0.014 critic_pen=0.079
# [train] step=26000 q=66.470 critic=5.875 actor=-0.826 bc=0.030 lambda=0.014 critic_pen=0.080
# [train] step=27000 q=69.953 critic=6.240 actor=-0.912 bc=0.010 lambda=0.014 critic_pen=0.089
# [train] step=28000 q=69.310 critic=7.144 actor=-0.880 bc=0.020 lambda=0.014 critic_pen=0.102
# [train] step=29000 q=73.926 critic=5.680 actor=-0.950 bc=0.005 lambda=0.013 critic_pen=0.089
# [train] step=30000 q=75.148 critic=4.739 actor=-0.907 bc=0.016 lambda=0.013 critic_pen=0.092
# [eval] step=30000 success=66.00% return=13.93 time=50.47s energy=39451.60 path=58.03 prog=0.632
# [train] step=31000 q=75.607 critic=5.195 actor=-0.889 bc=0.018 lambda=0.013 critic_pen=0.086
# [train] step=32000 q=74.962 critic=4.787 actor=-0.924 bc=0.010 lambda=0.013 critic_pen=0.071
# [train] step=33000 q=78.485 critic=4.912 actor=-0.964 bc=0.002 lambda=0.012 critic_pen=0.084
# [train] step=34000 q=76.833 critic=4.181 actor=-0.912 bc=0.014 lambda=0.013 critic_pen=0.080
# [train] step=35000 q=80.635 critic=3.928 actor=-0.962 bc=0.003 lambda=0.012 critic_pen=0.096
# [train] step=36000 q=78.698 critic=154.422 actor=-0.955 bc=0.005 lambda=0.012 critic_pen=0.084
# [train] step=37000 q=82.299 critic=6.397 actor=-0.968 bc=0.006 lambda=0.012 critic_pen=0.084
# [train] step=38000 q=79.165 critic=5.751 actor=-0.924 bc=0.014 lambda=0.012 critic_pen=0.101
# [train] step=39000 q=82.951 critic=10.290 actor=-0.917 bc=0.017 lambda=0.012 critic_pen=0.107
# [train] step=40000 q=83.551 critic=2.099 actor=-0.926 bc=0.014 lambda=0.012 critic_pen=0.090
# [eval] step=40000 success=55.00% return=-16.80 time=47.63s energy=37195.81 path=54.39 prog=0.679
# [train] step=41000 q=83.429 critic=2.160 actor=-0.926 bc=0.016 lambda=0.012 critic_pen=0.101
# [train] step=42000 q=85.442 critic=2.265 actor=-0.907 bc=0.022 lambda=0.012 critic_pen=0.072
# [train] step=43000 q=85.562 critic=1.945 actor=-0.898 bc=0.024 lambda=0.012 critic_pen=0.101
# [train] step=44000 q=86.605 critic=2.863 actor=-0.964 bc=0.009 lambda=0.012 critic_pen=0.099
# [train] step=45000 q=85.302 critic=1.923 actor=-0.987 bc=0.002 lambda=0.012 critic_pen=0.086
# [train] step=46000 q=86.270 critic=6.769 actor=-0.941 bc=0.014 lambda=0.012 critic_pen=0.083
# [train] step=47000 q=84.560 critic=1.746 actor=-0.987 bc=0.001 lambda=0.012 critic_pen=0.083
# [train] step=48000 q=84.846 critic=1.519 actor=-0.902 bc=0.021 lambda=0.012 critic_pen=0.102
# [train] step=49000 q=86.879 critic=0.988 actor=-0.936 bc=0.016 lambda=0.011 critic_pen=0.082
# [train] step=50000 q=86.553 critic=1.330 actor=-0.981 bc=0.003 lambda=0.011 critic_pen=0.075
# [eval] step=50000 success=52.00% return=-25.19 time=48.77s energy=38122.38 path=54.90 prog=0.708
# [train] step=51000 q=87.916 critic=1.029 actor=-0.970 bc=0.007 lambda=0.011 critic_pen=0.079
# [train] step=52000 q=85.838 critic=1.676 actor=-0.953 bc=0.012 lambda=0.012 critic_pen=0.074
# [train] step=53000 q=86.989 critic=0.810 actor=-0.948 bc=0.011 lambda=0.011 critic_pen=0.065
# [train] step=54000 q=85.867 critic=1.125 actor=-0.919 bc=0.020 lambda=0.012 critic_pen=0.096
# [train] step=55000 q=86.051 critic=399.178 actor=-0.964 bc=0.009 lambda=0.012 critic_pen=0.100
# [train] step=56000 q=85.491 critic=1.421 actor=-0.898 bc=0.023 lambda=0.012 critic_pen=0.068
# [train] step=57000 q=86.714 critic=0.807 actor=-0.982 bc=0.004 lambda=0.012 critic_pen=0.076
# [train] step=58000 q=87.230 critic=1.009 actor=-0.976 bc=0.006 lambda=0.011 critic_pen=0.077
# [train] step=59000 q=87.721 critic=0.714 actor=-0.944 bc=0.014 lambda=0.011 critic_pen=0.072
# [train] step=60000 q=87.156 critic=0.816 actor=-0.961 bc=0.010 lambda=0.011 critic_pen=0.078
# [eval] step=60000 success=67.00% return=26.53 time=48.19s energy=37631.01 path=52.87 prog=0.760
# [train] step=61000 q=88.103 critic=0.826 actor=-0.981 bc=0.005 lambda=0.011 critic_pen=0.090
# [train] step=62000 q=87.079 critic=386.433 actor=-0.939 bc=0.015 lambda=0.011 critic_pen=0.087
# [train] step=63000 q=86.097 critic=1.633 actor=-0.991 bc=0.002 lambda=0.012 critic_pen=0.107
# [train] step=64000 q=88.451 critic=1.144 actor=-0.981 bc=0.005 lambda=0.011 critic_pen=0.113
# [train] step=65000 q=87.693 critic=1.277 actor=-0.968 bc=0.008 lambda=0.011 critic_pen=0.089
# [train] step=66000 q=87.801 critic=1.176 actor=-0.974 bc=0.006 lambda=0.011 critic_pen=0.087
# [train] step=67000 q=85.231 critic=1.441 actor=-0.966 bc=0.006 lambda=0.012 critic_pen=0.074
# [train] step=68000 q=86.482 critic=0.870 actor=-0.961 bc=0.006 lambda=0.011 critic_pen=0.086
# [train] step=69000 q=87.745 critic=0.986 actor=-0.937 bc=0.015 lambda=0.011 critic_pen=0.097
# [train] step=70000 q=86.120 critic=1.063 actor=-0.869 bc=0.030 lambda=0.011 critic_pen=0.087
# [eval] step=70000 success=85.00% return=88.49 time=45.47s energy=35455.47 path=48.73 prog=0.851
# [train] step=71000 q=87.522 critic=1.020 actor=-0.937 bc=0.016 lambda=0.011 critic_pen=0.090
# [train] step=72000 q=84.291 critic=0.910 actor=-0.929 bc=0.004 lambda=0.011 critic_pen=0.077
# [train] step=73000 q=88.268 critic=0.764 actor=-0.938 bc=0.016 lambda=0.011 critic_pen=0.092
# [train] step=74000 q=87.928 critic=0.761 actor=-0.989 bc=0.003 lambda=0.011 critic_pen=0.073
# [train] step=75000 q=83.977 critic=1.654 actor=-0.836 bc=0.028 lambda=0.011 critic_pen=0.093
# [train] step=76000 q=86.928 critic=1.272 actor=-0.988 bc=0.003 lambda=0.012 critic_pen=0.065
# [train] step=77000 q=87.956 critic=0.891 actor=-0.989 bc=0.003 lambda=0.011 critic_pen=0.072
# [train] step=78000 q=86.860 critic=1.008 actor=-0.951 bc=0.011 lambda=0.011 critic_pen=0.079
# [train] step=79000 q=87.689 critic=1.246 actor=-0.966 bc=0.008 lambda=0.011 critic_pen=0.102
# [train] step=80000 q=87.575 critic=1.476 actor=-0.898 bc=0.021 lambda=0.011 critic_pen=0.100
# [eval] step=80000 success=73.00% return=43.93 time=48.86s energy=38278.16 path=54.07 prog=0.747
# [train] step=81000 q=85.787 critic=0.967 actor=-0.953 bc=0.012 lambda=0.012 critic_pen=0.084
# [train] step=82000 q=84.577 critic=1.288 actor=-0.927 bc=0.013 lambda=0.012 critic_pen=0.078
# [train] step=83000 q=86.218 critic=5.417 actor=-0.896 bc=0.019 lambda=0.011 critic_pen=0.112
# [train] step=84000 q=84.560 critic=3.139 actor=-0.898 bc=0.012 lambda=0.011 critic_pen=0.089
# [train] step=85000 q=88.088 critic=0.760 actor=-0.979 bc=0.005 lambda=0.011 critic_pen=0.080
# [train] step=86000 q=86.886 critic=0.923 actor=-0.964 bc=0.004 lambda=0.011 critic_pen=0.085
# [train] step=87000 q=85.867 critic=1.361 actor=-0.901 bc=0.021 lambda=0.011 critic_pen=0.084
# [train] step=88000 q=85.414 critic=1.118 actor=-0.940 bc=0.005 lambda=0.011 critic_pen=0.088
# [train] step=89000 q=87.339 critic=0.882 actor=-0.950 bc=0.007 lambda=0.011 critic_pen=0.073
# [train] step=90000 q=86.423 critic=0.991 actor=-0.935 bc=0.011 lambda=0.011 critic_pen=0.082
# [eval] step=90000 success=64.00% return=19.78 time=48.18s energy=37630.60 path=52.90 prog=0.808
# [train] step=91000 q=85.810 critic=3.101 actor=-0.936 bc=0.016 lambda=0.012 critic_pen=0.091
# [train] step=92000 q=86.913 critic=0.871 actor=-0.902 bc=0.019 lambda=0.011 critic_pen=0.093
# [train] step=93000 q=84.412 critic=1.171 actor=-0.954 bc=0.002 lambda=0.011 critic_pen=0.106
# [train] step=94000 q=82.900 critic=2.975 actor=-0.874 bc=0.014 lambda=0.011 critic_pen=0.064
# [train] step=95000 q=88.119 critic=0.880 actor=-0.964 bc=0.009 lambda=0.011 critic_pen=0.100
# [train] step=96000 q=84.364 critic=1.619 actor=-0.927 bc=0.007 lambda=0.011 critic_pen=0.080
# [train] step=97000 q=86.027 critic=0.999 actor=-0.904 bc=0.024 lambda=0.012 critic_pen=0.071
# [train] step=98000 q=86.423 critic=1.611 actor=-0.979 bc=0.001 lambda=0.011 critic_pen=0.075
# [train] step=99000 q=85.966 critic=1.036 actor=-0.931 bc=0.012 lambda=0.011 critic_pen=0.063
# [train] step=100000 q=88.638 critic=0.745 actor=-0.987 bc=0.003 lambda=0.011 critic_pen=0.096
# [eval] step=100000 success=61.00% return=-5.93 time=49.95s energy=39080.45 path=57.76 prog=0.606
# [train] step=101000 q=87.130 critic=0.878 actor=-0.957 bc=0.006 lambda=0.011 critic_pen=0.074
# [train] step=102000 q=83.723 critic=2.242 actor=-0.950 bc=0.002 lambda=0.011 critic_pen=0.078
# [train] step=103000 q=87.261 critic=1.496 actor=-0.962 bc=0.010 lambda=0.011 critic_pen=0.074
# [train] step=104000 q=87.358 critic=0.756 actor=-0.991 bc=0.002 lambda=0.011 critic_pen=0.059
# [train] step=105000 q=88.622 critic=0.656 actor=-0.995 bc=0.001 lambda=0.011 critic_pen=0.077
# [train] step=106000 q=87.250 critic=2.584 actor=-0.963 bc=0.004 lambda=0.011 critic_pen=0.076
# [train] step=107000 q=87.563 critic=0.660 actor=-0.945 bc=0.008 lambda=0.011 critic_pen=0.077
# [train] step=108000 q=86.004 critic=0.839 actor=-0.994 bc=0.001 lambda=0.012 critic_pen=0.083
# [train] step=109000 q=87.000 critic=0.676 actor=-0.967 bc=0.008 lambda=0.011 critic_pen=0.100
# [train] step=110000 q=87.370 critic=0.974 actor=-0.950 bc=0.007 lambda=0.011 critic_pen=0.074
# [eval] step=110000 success=86.00% return=92.86 time=48.06s energy=37530.92 path=51.38 prog=0.859
# [train] step=111000 q=84.761 critic=1.162 actor=-0.960 bc=0.005 lambda=0.012 critic_pen=0.081
# [train] step=112000 q=88.260 critic=0.761 actor=-0.995 bc=0.001 lambda=0.011 critic_pen=0.062
# [train] step=113000 q=88.146 critic=0.899 actor=-0.907 bc=0.021 lambda=0.011 critic_pen=0.120
# [train] step=114000 q=86.073 critic=1.338 actor=-0.969 bc=0.001 lambda=0.011 critic_pen=0.082
# [train] step=115000 q=87.576 critic=2.649 actor=-0.950 bc=0.007 lambda=0.011 critic_pen=0.073
# [train] step=116000 q=85.647 critic=94.061 actor=-0.949 bc=0.007 lambda=0.011 critic_pen=0.079
# [train] step=117000 q=86.745 critic=1.323 actor=-0.974 bc=0.001 lambda=0.011 critic_pen=0.065
# [train] step=118000 q=87.287 critic=0.916 actor=-0.939 bc=0.007 lambda=0.011 critic_pen=0.087
# [train] step=119000 q=88.827 critic=0.758 actor=-0.947 bc=0.013 lambda=0.011 critic_pen=0.074
# [train] step=120000 q=87.704 critic=1.383 actor=-0.950 bc=0.008 lambda=0.011 critic_pen=0.094
# [eval] step=120000 success=75.00% return=55.32 time=47.04s energy=36697.25 path=51.50 prog=0.810
# [train] step=121000 q=86.927 critic=2.204 actor=-0.934 bc=0.013 lambda=0.011 critic_pen=0.090
# [train] step=122000 q=87.375 critic=1.271 actor=-0.978 bc=0.003 lambda=0.011 critic_pen=0.098
# [train] step=123000 q=87.743 critic=0.675 actor=-0.970 bc=0.002 lambda=0.011 critic_pen=0.070
# [train] step=124000 q=84.388 critic=0.703 actor=-0.928 bc=0.002 lambda=0.011 critic_pen=0.086
# [train] step=125000 q=90.499 critic=0.649 actor=-0.945 bc=0.014 lambda=0.011 critic_pen=0.088
# [train] step=126000 q=88.184 critic=0.696 actor=-0.979 bc=0.005 lambda=0.011 critic_pen=0.067
# [train] step=127000 q=85.756 critic=0.796 actor=-0.952 bc=0.002 lambda=0.011 critic_pen=0.080
# [train] step=128000 q=86.457 critic=0.805 actor=-0.995 bc=0.001 lambda=0.012 critic_pen=0.081
# [train] step=129000 q=88.229 critic=1.515 actor=-0.991 bc=0.002 lambda=0.011 critic_pen=0.082
# [train] step=130000 q=83.706 critic=1.364 actor=-0.898 bc=0.010 lambda=0.011 critic_pen=0.080
# [eval] step=130000 success=85.00% return=84.95 time=46.98s energy=36670.98 path=50.90 prog=0.816
# [train] step=131000 q=86.852 critic=0.721 actor=-0.913 bc=0.017 lambda=0.011 critic_pen=0.082
# [train] step=132000 q=85.922 critic=0.929 actor=-0.974 bc=0.002 lambda=0.011 critic_pen=0.073
# [train] step=133000 q=89.578 critic=0.609 actor=-0.958 bc=0.010 lambda=0.011 critic_pen=0.087
# [train] step=134000 q=85.824 critic=0.604 actor=-0.972 bc=0.001 lambda=0.011 critic_pen=0.065
# [train] step=135000 q=85.855 critic=2.174 actor=-0.965 bc=0.001 lambda=0.011 critic_pen=0.063
# [train] step=136000 q=89.931 critic=0.625 actor=-0.995 bc=0.001 lambda=0.011 critic_pen=0.072
# [train] step=137000 q=85.956 critic=2.344 actor=-0.924 bc=0.009 lambda=0.011 critic_pen=0.091
# [train] step=138000 q=89.026 critic=0.917 actor=-0.994 bc=0.002 lambda=0.011 critic_pen=0.083
# [train] step=139000 q=87.126 critic=0.573 actor=-0.965 bc=0.005 lambda=0.011 critic_pen=0.076
# [train] step=140000 q=88.582 critic=0.548 actor=-0.986 bc=0.004 lambda=0.011 critic_pen=0.095
# [eval] step=140000 success=78.00% return=55.41 time=47.20s energy=36871.14 path=53.46 prog=0.710
# [train] step=141000 q=87.836 critic=0.909 actor=-0.964 bc=0.004 lambda=0.011 critic_pen=0.074
# [train] step=142000 q=87.258 critic=0.711 actor=-0.959 bc=0.005 lambda=0.011 critic_pen=0.080
# [train] step=143000 q=87.141 critic=0.718 actor=-0.976 bc=0.001 lambda=0.011 critic_pen=0.083
# [train] step=144000 q=87.297 critic=33.605 actor=-0.962 bc=0.007 lambda=0.011 critic_pen=0.098
# [train] step=145000 q=88.388 critic=0.722 actor=-0.996 bc=0.001 lambda=0.011 critic_pen=0.071
# [train] step=146000 q=83.854 critic=7.617 actor=-0.930 bc=0.004 lambda=0.011 critic_pen=0.083
# [train] step=147000 q=86.654 critic=0.739 actor=-0.969 bc=0.002 lambda=0.011 critic_pen=0.071
# [train] step=148000 q=85.831 critic=1.053 actor=-0.932 bc=0.006 lambda=0.011 critic_pen=0.070
# [train] step=149000 q=88.587 critic=0.905 actor=-0.949 bc=0.009 lambda=0.011 critic_pen=0.079
# [train] step=150000 q=89.380 critic=1.241 actor=-0.967 bc=0.007 lambda=0.011 critic_pen=0.086
# [eval] step=150000 success=89.00% return=103.09 time=45.29s energy=35300.69 path=48.70 prog=0.869
# [train] step=151000 q=88.742 critic=1.070 actor=-0.960 bc=0.006 lambda=0.011 critic_pen=0.098
# [train] step=152000 q=85.578 critic=0.712 actor=-0.901 bc=0.015 lambda=0.011 critic_pen=0.092
# [train] step=153000 q=88.228 critic=0.699 actor=-0.986 bc=0.004 lambda=0.011 critic_pen=0.094
# [train] step=154000 q=86.640 critic=0.642 actor=-0.906 bc=0.014 lambda=0.011 critic_pen=0.078
# [train] step=155000 q=90.365 critic=0.450 actor=-0.989 bc=0.003 lambda=0.011 critic_pen=0.073
# [train] step=156000 q=89.891 critic=0.666 actor=-0.931 bc=0.017 lambda=0.011 critic_pen=0.074
# [train] step=157000 q=86.405 critic=1.054 actor=-0.934 bc=0.003 lambda=0.011 critic_pen=0.096
# [train] step=158000 q=87.518 critic=0.649 actor=-0.965 bc=0.004 lambda=0.011 critic_pen=0.081
# [train] step=159000 q=89.407 critic=0.537 actor=-0.958 bc=0.011 lambda=0.011 critic_pen=0.093
# [train] step=160000 q=88.975 critic=0.549 actor=-0.997 bc=0.001 lambda=0.011 critic_pen=0.077
# [eval] step=160000 success=76.00% return=58.02 time=46.34s energy=36182.82 path=50.90 prog=0.804
# [train] step=161000 q=86.318 critic=0.622 actor=-0.957 bc=0.001 lambda=0.011 critic_pen=0.074
# [train] step=162000 q=89.902 critic=0.452 actor=-0.980 bc=0.001 lambda=0.011 critic_pen=0.059
# [train] step=163000 q=88.327 critic=0.811 actor=-0.994 bc=0.001 lambda=0.011 critic_pen=0.077
# [train] step=164000 q=88.189 critic=2.018 actor=-0.958 bc=0.007 lambda=0.011 critic_pen=0.087
# [train] step=165000 q=88.102 critic=0.516 actor=-0.965 bc=0.004 lambda=0.011 critic_pen=0.063
# [train] step=166000 q=86.295 critic=135.758 actor=-0.943 bc=0.008 lambda=0.011 critic_pen=0.104
# [train] step=167000 q=88.453 critic=0.470 actor=-0.989 bc=0.003 lambda=0.011 critic_pen=0.080
# [train] step=168000 q=87.288 critic=0.620 actor=-0.978 bc=0.001 lambda=0.011 critic_pen=0.063
# [train] step=169000 q=89.293 critic=0.468 actor=-0.970 bc=0.008 lambda=0.011 critic_pen=0.077
# [train] step=170000 q=89.553 critic=0.493 actor=-0.984 bc=0.004 lambda=0.011 critic_pen=0.077
# [eval] step=170000 success=84.00% return=86.10 time=46.02s energy=35917.88 path=49.72 prog=0.859
# [train] step=171000 q=87.393 critic=361.636 actor=-0.941 bc=0.004 lambda=0.011 critic_pen=0.070
# [train] step=172000 q=89.287 critic=0.430 actor=-0.995 bc=0.001 lambda=0.011 critic_pen=0.075
# [train] step=173000 q=89.159 critic=0.821 actor=-0.975 bc=0.006 lambda=0.011 critic_pen=0.060
# [train] step=174000 q=87.320 critic=178.401 actor=-0.946 bc=0.006 lambda=0.011 critic_pen=0.091
# [train] step=175000 q=89.449 critic=0.567 actor=-0.997 bc=0.001 lambda=0.011 critic_pen=0.071
# [train] step=176000 q=89.051 critic=0.830 actor=-0.966 bc=0.004 lambda=0.011 critic_pen=0.090
# [train] step=177000 q=88.886 critic=0.519 actor=-0.970 bc=0.003 lambda=0.011 critic_pen=0.087
# [train] step=178000 q=88.056 critic=0.475 actor=-0.995 bc=0.001 lambda=0.011 critic_pen=0.083
# [train] step=179000 q=85.634 critic=4.305 actor=-0.932 bc=0.003 lambda=0.011 critic_pen=0.075
# [train] step=180000 q=88.968 critic=0.588 actor=-0.982 bc=0.005 lambda=0.011 critic_pen=0.091
# [eval] step=180000 success=84.00% return=85.97 time=44.94s energy=35013.84 path=48.65 prog=0.844
# [train] step=181000 q=87.920 critic=0.575 actor=-0.996 bc=0.001 lambda=0.011 critic_pen=0.093
# [train] step=182000 q=89.038 critic=0.458 actor=-0.947 bc=0.009 lambda=0.011 critic_pen=0.077
# [train] step=183000 q=90.338 critic=0.403 actor=-0.963 bc=0.009 lambda=0.011 critic_pen=0.081
# [train] step=184000 q=89.026 critic=0.386 actor=-0.970 bc=0.003 lambda=0.011 critic_pen=0.073
# [train] step=185000 q=89.249 critic=0.603 actor=-0.927 bc=0.018 lambda=0.011 critic_pen=0.069
# [train] step=186000 q=87.907 critic=0.441 actor=-0.976 bc=0.001 lambda=0.011 critic_pen=0.071
# [train] step=187000 q=88.810 critic=0.446 actor=-0.988 bc=0.003 lambda=0.011 critic_pen=0.064
# [train] step=188000 q=88.767 critic=0.660 actor=-0.977 bc=0.006 lambda=0.011 critic_pen=0.071
# [train] step=189000 q=85.138 critic=5.277 actor=-0.918 bc=0.008 lambda=0.011 critic_pen=0.082
# [train] step=190000 q=88.893 critic=0.569 actor=-0.985 bc=0.004 lambda=0.011 critic_pen=0.088
# [eval] step=190000 success=73.00% return=50.11 time=46.83s energy=36529.17 path=50.97 prog=0.835
# [train] step=191000 q=84.084 critic=11.708 actor=-0.896 bc=0.010 lambda=0.011 critic_pen=0.076
# [train] step=192000 q=88.161 critic=0.624 actor=-0.978 bc=0.002 lambda=0.011 critic_pen=0.077
# [train] step=193000 q=89.506 critic=0.365 actor=-0.988 bc=0.003 lambda=0.011 critic_pen=0.066
# [train] step=194000 q=88.967 critic=0.795 actor=-0.992 bc=0.002 lambda=0.011 critic_pen=0.078
# [train] step=195000 q=87.052 critic=0.652 actor=-0.979 bc=0.002 lambda=0.011 critic_pen=0.073
# [train] step=196000 q=88.968 critic=0.457 actor=-0.970 bc=0.008 lambda=0.011 critic_pen=0.077
# [train] step=197000 q=85.967 critic=0.477 actor=-0.958 bc=0.001 lambda=0.011 critic_pen=0.070
# [train] step=198000 q=87.060 critic=0.468 actor=-0.957 bc=0.001 lambda=0.011 critic_pen=0.067
# [train] step=199000 q=89.196 critic=0.450 actor=-0.978 bc=0.001 lambda=0.011 critic_pen=0.066
# [train] step=200000 q=90.129 critic=0.829 actor=-0.982 bc=0.005 lambda=0.011 critic_pen=0.070
# [eval] step=200000 success=72.00% return=47.47 time=46.90s energy=36605.02 path=51.05 prog=0.834
# [train done] rebrac seed=0 in 65.8 min
#
# ========================================================================
#   train fql seed=42 → checkpoints/fql_succession/p2/e_uni/fql_seed42
# ========================================================================
# [offline] algo=fql transitions=86685 obs_dim=48 action_dim=2 protocol=deployable tensor_replay=on eval_workers=1 sampling=uniform total_steps=200000
# [train] step=1 q=0.110 critic=117.852 actor=0.394 bc=1.060 lambda=6.046
# [train] step=1000 q=5.022 critic=319.460 actor=-0.903 bc=0.068 lambda=0.193
# [train] step=2000 q=9.794 critic=6.595 actor=-0.925 bc=0.064 lambda=0.101
# [train] step=3000 q=15.941 critic=2.451 actor=-0.934 bc=0.058 lambda=0.062
# [train] step=4000 q=20.577 critic=1.637 actor=-0.955 bc=0.032 lambda=0.048
# [train] step=5000 q=28.140 critic=1.227 actor=-0.960 bc=0.028 lambda=0.035
# [train] step=6000 q=33.435 critic=1.692 actor=-0.974 bc=0.022 lambda=0.030
# [train] step=7000 q=33.500 critic=0.675 actor=-0.956 bc=0.037 lambda=0.030
# [train] step=8000 q=37.963 critic=1.094 actor=-0.977 bc=0.014 lambda=0.026
# [train] step=9000 q=35.780 critic=1.544 actor=-0.978 bc=0.010 lambda=0.028
# [train] step=10000 q=44.328 critic=4.501 actor=-0.969 bc=0.024 lambda=0.022
# [eval] step=10000 success=33.00% return=-109.48 time=51.01s energy=40237.84 path=61.99 prog=0.385
# [train] step=11000 q=46.008 critic=1.768 actor=-0.979 bc=0.016 lambda=0.022
# [train] step=12000 q=43.908 critic=1.105 actor=-0.971 bc=0.026 lambda=0.023
# [train] step=13000 q=56.160 critic=0.745 actor=-0.989 bc=0.010 lambda=0.018
# [train] step=14000 q=53.039 critic=227.258 actor=-0.980 bc=0.015 lambda=0.019
# [train] step=15000 q=62.858 critic=2.849 actor=-0.967 bc=0.028 lambda=0.016
# [train] step=16000 q=63.535 critic=2.114 actor=-0.965 bc=0.027 lambda=0.016
# [train] step=17000 q=63.901 critic=2.095 actor=-0.973 bc=0.025 lambda=0.016
# [train] step=18000 q=66.953 critic=3.626 actor=-0.987 bc=0.008 lambda=0.015
# [train] step=19000 q=70.154 critic=1.843 actor=-0.972 bc=0.024 lambda=0.014
# [train] step=20000 q=73.574 critic=2.157 actor=-0.985 bc=0.011 lambda=0.014
# [eval] step=20000 success=78.00% return=61.07 time=43.46s energy=34110.13 path=49.29 prog=0.770
# [train] step=21000 q=79.067 critic=2.994 actor=-0.982 bc=0.018 lambda=0.013
# [train] step=22000 q=80.485 critic=1.818 actor=-0.984 bc=0.015 lambda=0.012
# [train] step=23000 q=83.433 critic=2.497 actor=-0.970 bc=0.027 lambda=0.012
# [train] step=24000 q=85.156 critic=3.820 actor=-0.978 bc=0.022 lambda=0.012
# [train] step=25000 q=84.887 critic=2.638 actor=-0.993 bc=0.007 lambda=0.012
# [train] step=26000 q=86.828 critic=2.956 actor=-0.986 bc=0.014 lambda=0.012
# [train] step=27000 q=90.975 critic=1.600 actor=-0.988 bc=0.012 lambda=0.011
# [train] step=28000 q=89.793 critic=1.659 actor=-0.979 bc=0.021 lambda=0.011
# [train] step=29000 q=90.915 critic=2.080 actor=-0.976 bc=0.024 lambda=0.011
# [train] step=30000 q=90.841 critic=2.119 actor=-0.978 bc=0.022 lambda=0.011
# [eval] step=30000 success=54.00% return=-17.42 time=44.98s energy=35002.81 path=51.03 prog=0.711
# [train] step=31000 q=92.647 critic=1.087 actor=-0.975 bc=0.025 lambda=0.011
# [train] step=32000 q=92.553 critic=0.904 actor=-0.989 bc=0.011 lambda=0.011
# [train] step=33000 q=93.948 critic=0.609 actor=-0.988 bc=0.012 lambda=0.011
# [train] step=34000 q=93.789 critic=0.422 actor=-0.993 bc=0.007 lambda=0.011
# [train] step=35000 q=94.783 critic=0.981 actor=-0.990 bc=0.010 lambda=0.011
# [train] step=36000 q=94.086 critic=1.013 actor=-0.984 bc=0.011 lambda=0.011
# [train] step=37000 q=94.116 critic=0.578 actor=-0.979 bc=0.018 lambda=0.011
# [train] step=38000 q=94.101 critic=0.646 actor=-0.980 bc=0.020 lambda=0.011
# [train] step=39000 q=94.192 critic=381.569 actor=-0.987 bc=0.013 lambda=0.011
# [train] step=40000 q=94.933 critic=0.462 actor=-0.978 bc=0.022 lambda=0.011
# [eval] step=40000 success=51.00% return=-29.88 time=46.09s energy=36072.79 path=53.05 prog=0.673
# [train] step=41000 q=96.483 critic=0.411 actor=-0.991 bc=0.009 lambda=0.010
# [train] step=42000 q=93.645 critic=0.360 actor=-0.984 bc=0.006 lambda=0.011
# [train] step=43000 q=94.126 critic=0.401 actor=-0.988 bc=0.012 lambda=0.011
# [train] step=44000 q=95.617 critic=0.295 actor=-0.980 bc=0.020 lambda=0.010
# [train] step=45000 q=94.308 critic=0.740 actor=-0.986 bc=0.007 lambda=0.011
# [train] step=46000 q=95.293 critic=0.341 actor=-0.990 bc=0.010 lambda=0.010
# [train] step=47000 q=94.070 critic=0.419 actor=-0.976 bc=0.024 lambda=0.011
# [train] step=48000 q=94.058 critic=0.463 actor=-0.975 bc=0.017 lambda=0.011
# [train] step=49000 q=94.278 critic=0.488 actor=-0.987 bc=0.010 lambda=0.011
# [train] step=50000 q=95.281 critic=0.617 actor=-0.995 bc=0.005 lambda=0.010
# [eval] step=50000 success=57.00% return=-11.76 time=46.11s energy=35791.10 path=52.77 prog=0.660
# [train] step=51000 q=94.771 critic=266.278 actor=-0.980 bc=0.017 lambda=0.011
# [train] step=52000 q=94.699 critic=0.472 actor=-0.984 bc=0.016 lambda=0.011
# [train] step=53000 q=95.204 critic=0.711 actor=-0.981 bc=0.019 lambda=0.011
# [train] step=54000 q=96.149 critic=0.366 actor=-0.993 bc=0.007 lambda=0.010
# [train] step=55000 q=94.403 critic=1.495 actor=-0.996 bc=0.004 lambda=0.011
# [train] step=56000 q=94.279 critic=0.482 actor=-0.978 bc=0.022 lambda=0.011
# [train] step=57000 q=94.626 critic=3.196 actor=-0.991 bc=0.009 lambda=0.011
# [train] step=58000 q=96.212 critic=1.427 actor=-0.988 bc=0.012 lambda=0.010
# [train] step=59000 q=94.533 critic=0.585 actor=-0.982 bc=0.008 lambda=0.010
# [train] step=60000 q=96.367 critic=0.421 actor=-0.991 bc=0.009 lambda=0.010
# [eval] step=60000 success=60.00% return=-1.17 time=45.09s energy=35165.95 path=51.59 prog=0.694
# [train] step=61000 q=95.180 critic=1.289 actor=-0.993 bc=0.007 lambda=0.011
# ...
# [train] step=23000 q=83.101 critic=4.130 actor=-0.983 bc=0.017 lambda=0.012
# [train] step=24000 q=85.667 critic=3.986 actor=-0.987 bc=0.010 lambda=0.012
# [train] step=25000 q=86.797 critic=2.088 actor=-0.976 bc=0.024 lambda=0.012
# [train] step=26000 q=86.846 critic=2.291 actor=-0.983 bc=0.015 lambda=0.011
# [train] step=27000 q=89.282 critic=2.579 actor=-0.982 bc=0.018 lambda=0.011
# [train] step=28000 q=92.245 critic=1.214 actor=-0.991 bc=0.009 lambda=0.011
# [train] step=29000 q=91.434 critic=1.676 actor=-0.976 bc=0.024 lambda=0.011
# [train] step=30000 q=89.979 critic=1.491 actor=-0.980 bc=0.017 lambda=0.011
# [eval] step=30000 success=45.00% return=-47.34 time=45.91s energy=35496.05 path=52.10 prog=0.682
# [train] step=31000 q=92.335 critic=1.524 actor=-0.982 bc=0.018 lambda=0.011
# [train] step=32000 q=91.946 critic=317.754 actor=-0.984 bc=0.016 lambda=0.011
# [train] step=33000 q=93.715 critic=0.681 actor=-0.974 bc=0.026 lambda=0.011
# [train] step=34000 q=93.145 critic=0.966 actor=-0.989 bc=0.011 lambda=0.011
# [train] step=35000 q=94.896 critic=0.597 actor=-0.976 bc=0.024 lambda=0.011
# [train] step=36000 q=94.999 critic=0.666 actor=-0.988 bc=0.012 lambda=0.011
# [train] step=37000 q=93.819 critic=0.683 actor=-0.980 bc=0.020 lambda=0.011
# [train] step=38000 q=93.456 critic=0.575 actor=-0.987 bc=0.008 lambda=0.011
# [train] step=39000 q=93.899 critic=0.815 actor=-0.979 bc=0.021 lambda=0.011
# [train] step=40000 q=95.395 critic=213.248 actor=-0.996 bc=0.004 lambda=0.010
# [eval] step=40000 success=53.00% return=-31.69 time=47.94s energy=36882.84 path=55.22 prog=0.606
# [train] step=41000 q=94.016 critic=1.046 actor=-0.994 bc=0.006 lambda=0.011
# [train] step=42000 q=94.489 critic=0.474 actor=-0.979 bc=0.021 lambda=0.011
# [train] step=43000 q=94.182 critic=0.657 actor=-0.987 bc=0.013 lambda=0.011
# [train] step=44000 q=94.781 critic=1.284 actor=-0.977 bc=0.023 lambda=0.011
# [train] step=45000 q=95.647 critic=0.495 actor=-0.986 bc=0.014 lambda=0.010
# [train] step=46000 q=95.418 critic=0.446 actor=-0.981 bc=0.019 lambda=0.010
# [train] step=47000 q=96.529 critic=0.332 actor=-0.980 bc=0.020 lambda=0.010
# [train] step=48000 q=95.139 critic=0.549 actor=-0.989 bc=0.008 lambda=0.010
# [train] step=49000 q=95.099 critic=0.460 actor=-0.990 bc=0.010 lambda=0.011
# [train] step=50000 q=94.425 critic=0.706 actor=-0.978 bc=0.012 lambda=0.010
# [eval] step=50000 success=73.00% return=39.99 time=45.41s energy=35076.85 path=51.39 prog=0.697
# [train] step=51000 q=95.247 critic=0.557 actor=-0.994 bc=0.006 lambda=0.010
# [train] step=52000 q=94.990 critic=0.579 actor=-0.983 bc=0.009 lambda=0.010
# [train] step=53000 q=96.375 critic=0.847 actor=-0.985 bc=0.015 lambda=0.010
# [train] step=54000 q=95.820 critic=0.428 actor=-0.986 bc=0.008 lambda=0.010
# [train] step=55000 q=95.777 critic=0.495 actor=-0.995 bc=0.005 lambda=0.010
# [train] step=56000 q=95.846 critic=0.591 actor=-0.978 bc=0.022 lambda=0.010
# [train] step=57000 q=95.301 critic=0.604 actor=-0.986 bc=0.014 lambda=0.010
# [train] step=58000 q=95.657 critic=0.701 actor=-0.983 bc=0.017 lambda=0.010
# [train] step=59000 q=95.996 critic=0.505 actor=-0.981 bc=0.019 lambda=0.010
# [train] step=60000 q=95.782 critic=0.496 actor=-0.995 bc=0.005 lambda=0.010
# [eval] step=60000 success=70.00% return=22.19 time=46.74s energy=36173.16 path=54.45 prog=0.611
# [train] step=61000 q=95.468 critic=0.507 actor=-0.977 bc=0.023 lambda=0.010
# [train] step=62000 q=95.334 critic=0.991 actor=-0.974 bc=0.013 lambda=0.010
# [train] step=63000 q=94.781 critic=19.802 actor=-0.965 bc=0.019 lambda=0.010
# [train] step=64000 q=96.344 critic=0.404 actor=-0.985 bc=0.015 lambda=0.010
# [train] step=65000 q=93.154 critic=0.461 actor=-0.962 bc=0.011 lambda=0.010
# [train] step=66000 q=96.269 critic=0.413 actor=-0.993 bc=0.007 lambda=0.010
# [train] step=67000 q=96.174 critic=5.874 actor=-0.992 bc=0.007 lambda=0.010
# [train] step=68000 q=96.376 critic=0.471 actor=-0.983 bc=0.017 lambda=0.010
# [train] step=69000 q=95.975 critic=0.525 actor=-0.984 bc=0.016 lambda=0.010
# [train] step=70000 q=94.500 critic=0.945 actor=-0.982 bc=0.018 lambda=0.011
# [eval] step=70000 success=64.00% return=0.10 time=46.60s energy=36189.04 path=55.28 prog=0.566
# [train] step=71000 q=94.609 critic=0.794 actor=-0.982 bc=0.018 lambda=0.011
# [train] step=72000 q=94.675 critic=2.754 actor=-0.976 bc=0.015 lambda=0.010
# [train] step=73000 q=94.407 critic=2.229 actor=-0.985 bc=0.011 lambda=0.011
# [train] step=74000 q=94.574 critic=1.317 actor=-0.960 bc=0.021 lambda=0.010
# [train] step=75000 q=95.213 critic=1.145 actor=-0.980 bc=0.001 lambda=0.010
# [train] step=76000 q=93.865 critic=2.110 actor=-0.958 bc=0.021 lambda=0.010
# [train] step=77000 q=96.459 critic=0.449 actor=-0.987 bc=0.013 lambda=0.010
# [train] step=78000 q=95.263 critic=0.683 actor=-0.975 bc=0.006 lambda=0.010
# [train] step=79000 q=95.793 critic=0.662 actor=-0.984 bc=0.016 lambda=0.010
# [train] step=80000 q=95.594 critic=0.606 actor=-0.996 bc=0.004 lambda=0.010
# [eval] step=80000 success=60.00% return=-11.63 time=47.20s energy=36222.43 path=55.46 prog=0.552
# [train] step=81000 q=95.928 critic=0.444 actor=-0.994 bc=0.006 lambda=0.010
# [train] step=82000 q=95.555 critic=0.604 actor=-0.976 bc=0.010 lambda=0.010
# [train] step=83000 q=96.490 critic=0.379 actor=-0.996 bc=0.004 lambda=0.010
# [train] step=84000 q=91.987 critic=0.795 actor=-0.929 bc=0.020 lambda=0.010
# [train] step=85000 q=93.401 critic=0.609 actor=-0.944 bc=0.019 lambda=0.010
# [train] step=86000 q=95.608 critic=0.424 actor=-0.985 bc=0.015 lambda=0.010
# [train] step=87000 q=95.955 critic=0.559 actor=-0.991 bc=0.009 lambda=0.010
# [train] step=88000 q=95.784 critic=0.923 actor=-0.986 bc=0.014 lambda=0.010
# [train] step=89000 q=93.977 critic=0.584 actor=-0.968 bc=0.007 lambda=0.010
# [train] step=90000 q=95.251 critic=3.147 actor=-0.990 bc=0.007 lambda=0.010
# [eval] step=90000 success=57.00% return=-7.08 time=46.91s energy=36530.07 path=52.46 prog=0.728
# [train] step=91000 q=92.864 critic=0.593 actor=-0.944 bc=0.018 lambda=0.010
# [train] step=92000 q=94.998 critic=0.474 actor=-0.983 bc=0.006 lambda=0.010
# [train] step=93000 q=94.793 critic=0.504 actor=-0.958 bc=0.024 lambda=0.010
# [train] step=94000 q=94.430 critic=0.461 actor=-0.973 bc=0.008 lambda=0.010
# [train] step=95000 q=95.806 critic=0.552 actor=-0.977 bc=0.008 lambda=0.010
# [train] step=96000 q=96.174 critic=0.564 actor=-0.995 bc=0.005 lambda=0.010
# [train] step=97000 q=93.508 critic=0.612 actor=-0.969 bc=0.013 lambda=0.011
# [train] step=98000 q=94.447 critic=0.678 actor=-0.969 bc=0.016 lambda=0.010
# [train] step=99000 q=95.901 critic=0.470 actor=-0.990 bc=0.010 lambda=0.010
# [train] step=100000 q=92.250 critic=1.056 actor=-0.936 bc=0.014 lambda=0.010
# [eval] step=100000 success=49.00% return=-38.97 time=46.69s energy=36321.05 path=53.76 prog=0.656
# [train] step=101000 q=93.481 critic=1.490 actor=-0.949 bc=0.011 lambda=0.010
# [train] step=102000 q=93.969 critic=0.459 actor=-0.973 bc=0.006 lambda=0.010
# [train] step=103000 q=95.845 critic=0.314 actor=-0.982 bc=0.018 lambda=0.010
# [train] step=104000 q=91.046 critic=0.498 actor=-0.931 bc=0.010 lambda=0.010
# [train] step=105000 q=95.708 critic=0.643 actor=-0.986 bc=0.014 lambda=0.010
# [train] step=106000 q=93.850 critic=0.430 actor=-0.982 bc=0.009 lambda=0.011
# [train] step=107000 q=95.382 critic=0.531 actor=-0.981 bc=0.004 lambda=0.010
# [train] step=108000 q=94.560 critic=0.295 actor=-0.971 bc=0.010 lambda=0.010
# [train] step=109000 q=95.864 critic=0.482 actor=-0.992 bc=0.008 lambda=0.010
# [train] step=110000 q=94.678 critic=0.563 actor=-0.984 bc=0.016 lambda=0.011
# [eval] step=110000 success=72.00% return=40.50 time=45.62s energy=35205.72 path=50.28 prog=0.764
# [train] step=111000 q=96.708 critic=0.346 actor=-0.986 bc=0.014 lambda=0.010
# [train] step=112000 q=95.564 critic=0.974 actor=-0.976 bc=0.007 lambda=0.010
# [train] step=113000 q=94.643 critic=1.499 actor=-0.975 bc=0.006 lambda=0.010
# [train] step=114000 q=93.666 critic=170.195 actor=-0.953 bc=0.017 lambda=0.010
# [train] step=115000 q=93.845 critic=0.482 actor=-0.971 bc=0.007 lambda=0.010
# [train] step=116000 q=92.946 critic=0.544 actor=-0.939 bc=0.017 lambda=0.010
# [train] step=117000 q=95.095 critic=1.102 actor=-0.997 bc=0.003 lambda=0.011
# [train] step=118000 q=94.816 critic=0.455 actor=-0.974 bc=0.006 lambda=0.010
# [train] step=119000 q=93.847 critic=0.232 actor=-0.959 bc=0.001 lambda=0.010
# [train] step=120000 q=95.120 critic=0.374 actor=-0.974 bc=0.011 lambda=0.010
# [eval] step=120000 success=61.00% return=9.32 time=45.85s energy=35596.92 path=50.63 prog=0.768
# [train] step=121000 q=92.720 critic=1.516 actor=-0.945 bc=0.013 lambda=0.010
# [train] step=122000 q=95.897 critic=0.351 actor=-0.974 bc=0.026 lambda=0.010
# [train] step=123000 q=95.037 critic=0.541 actor=-0.985 bc=0.015 lambda=0.011
# [train] step=124000 q=95.832 critic=0.362 actor=-0.998 bc=0.002 lambda=0.010
# [train] step=125000 q=93.019 critic=1.999 actor=-0.970 bc=0.005 lambda=0.010
# [train] step=126000 q=93.698 critic=0.332 actor=-0.978 bc=0.002 lambda=0.010
# [train] step=127000 q=96.300 critic=0.657 actor=-0.998 bc=0.002 lambda=0.010
# [train] step=128000 q=95.536 critic=0.326 actor=-0.993 bc=0.007 lambda=0.010
# [train] step=129000 q=96.495 critic=0.289 actor=-0.997 bc=0.003 lambda=0.010
# [train] step=130000 q=95.647 critic=1.200 actor=-0.995 bc=0.005 lambda=0.010
# [eval] step=130000 success=79.00% return=61.16 time=46.74s energy=36327.03 path=52.51 prog=0.724
# [train] step=131000 q=94.181 critic=0.354 actor=-0.944 bc=0.018 lambda=0.010
# [train] step=132000 q=92.154 critic=0.619 actor=-0.943 bc=0.012 lambda=0.010
# [train] step=133000 q=94.481 critic=0.410 actor=-0.986 bc=0.005 lambda=0.010
# [train] step=134000 q=95.763 critic=0.438 actor=-0.994 bc=0.006 lambda=0.010
# [train] step=135000 q=90.621 critic=0.313 actor=-0.931 bc=0.011 lambda=0.010
# [train] step=136000 q=93.758 critic=0.350 actor=-0.965 bc=0.005 lambda=0.010
# [train] step=137000 q=95.109 critic=0.715 actor=-0.967 bc=0.023 lambda=0.010
# [train] step=138000 q=95.607 critic=0.376 actor=-0.977 bc=0.023 lambda=0.010
# [train] step=139000 q=95.276 critic=0.486 actor=-0.982 bc=0.010 lambda=0.010
# [train] step=140000 q=94.193 critic=1.936 actor=-0.963 bc=0.013 lambda=0.010
# [eval] step=140000 success=90.00% return=104.44 time=43.07s energy=33258.17 path=46.15 prog=0.848
# [train] step=141000 q=93.873 critic=0.267 actor=-0.950 bc=0.012 lambda=0.010
# [train] step=142000 q=96.288 critic=0.294 actor=-0.990 bc=0.010 lambda=0.010
# [train] step=143000 q=95.692 critic=0.436 actor=-0.998 bc=0.002 lambda=0.010
# [train] step=144000 q=92.352 critic=0.375 actor=-0.935 bc=0.009 lambda=0.010
# [train] step=145000 q=93.366 critic=0.442 actor=-0.979 bc=0.003 lambda=0.011
# [train] step=146000 q=90.266 critic=0.534 actor=-0.917 bc=0.014 lambda=0.010
# [train] step=147000 q=96.549 critic=0.282 actor=-0.985 bc=0.015 lambda=0.010
# [train] step=148000 q=93.029 critic=0.487 actor=-0.960 bc=0.008 lambda=0.010
# [train] step=149000 q=93.888 critic=0.595 actor=-0.976 bc=0.008 lambda=0.010
# [train] step=150000 q=90.487 critic=1.383 actor=-0.911 bc=0.020 lambda=0.010
# [eval] step=150000 success=54.00% return=-14.99 time=46.09s energy=35616.85 path=51.02 prog=0.739
# [train] step=151000 q=93.337 critic=0.504 actor=-0.954 bc=0.010 lambda=0.010
# [train] step=152000 q=92.947 critic=2.335 actor=-0.952 bc=0.013 lambda=0.010
# [train] step=153000 q=94.228 critic=1.012 actor=-0.972 bc=0.013 lambda=0.010
# [train] step=154000 q=92.933 critic=0.408 actor=-0.957 bc=0.009 lambda=0.010
# [train] step=155000 q=93.559 critic=0.503 actor=-0.964 bc=0.003 lambda=0.010
# [train] step=156000 q=96.222 critic=0.280 actor=-0.993 bc=0.007 lambda=0.010
# [train] step=157000 q=93.783 critic=0.407 actor=-0.957 bc=0.013 lambda=0.010
# [train] step=158000 q=94.230 critic=0.408 actor=-0.960 bc=0.007 lambda=0.010
# [train] step=159000 q=96.056 critic=0.425 actor=-0.998 bc=0.002 lambda=0.010
# [train] step=160000 q=91.324 critic=0.335 actor=-0.942 bc=0.006 lambda=0.010
# [eval] step=160000 success=58.00% return=-1.62 time=47.19s energy=36555.98 path=52.20 prog=0.759
# [train] step=161000 q=92.194 critic=0.410 actor=-0.926 bc=0.017 lambda=0.010
# [train] step=162000 q=93.723 critic=0.296 actor=-0.950 bc=0.011 lambda=0.010
# [train] step=163000 q=94.740 critic=0.358 actor=-0.972 bc=0.011 lambda=0.010
# [train] step=164000 q=94.590 critic=0.356 actor=-0.961 bc=0.019 lambda=0.010
# [train] step=165000 q=91.749 critic=0.589 actor=-0.946 bc=0.013 lambda=0.010
# [train] step=166000 q=95.959 critic=0.312 actor=-0.983 bc=0.017 lambda=0.010
# [train] step=167000 q=95.460 critic=0.283 actor=-0.986 bc=0.014 lambda=0.010
# [train] step=168000 q=95.094 critic=0.341 actor=-0.985 bc=0.015 lambda=0.011
# [train] step=169000 q=92.134 critic=0.402 actor=-0.941 bc=0.020 lambda=0.010
# [train] step=170000 q=95.229 critic=0.285 actor=-0.975 bc=0.009 lambda=0.010
# [eval] step=170000 success=73.00% return=46.64 time=45.50s energy=34791.85 path=49.32 prog=0.791
# [train] step=171000 q=94.719 critic=0.334 actor=-0.983 bc=0.002 lambda=0.010
# [train] step=172000 q=92.610 critic=0.349 actor=-0.945 bc=0.003 lambda=0.010
# [train] step=173000 q=96.153 critic=0.304 actor=-0.979 bc=0.021 lambda=0.010
# [train] step=174000 q=94.972 critic=0.342 actor=-0.975 bc=0.011 lambda=0.010
# [train] step=175000 q=93.169 critic=0.389 actor=-0.941 bc=0.022 lambda=0.010
# [train] step=176000 q=95.247 critic=0.581 actor=-0.986 bc=0.006 lambda=0.010
# [train] step=177000 q=97.104 critic=0.308 actor=-0.999 bc=0.001 lambda=0.010
# [train] step=178000 q=94.846 critic=0.224 actor=-0.966 bc=0.017 lambda=0.010
# [train] step=179000 q=94.611 critic=0.311 actor=-0.966 bc=0.016 lambda=0.010
# [train] step=180000 q=92.899 critic=0.351 actor=-0.944 bc=0.009 lambda=0.010
# [eval] step=180000 success=71.00% return=32.84 time=45.02s energy=34906.86 path=51.11 prog=0.709
# [train] step=181000 q=96.473 critic=0.259 actor=-0.987 bc=0.013 lambda=0.010
# [train] step=182000 q=95.260 critic=0.253 actor=-0.987 bc=0.013 lambda=0.010
# [train] step=183000 q=94.966 critic=0.370 actor=-0.999 bc=0.001 lambda=0.011
# [train] step=184000 q=94.834 critic=3.669 actor=-0.981 bc=0.004 lambda=0.010
# [train] step=185000 q=94.451 critic=0.347 actor=-0.977 bc=0.005 lambda=0.010
# [train] step=186000 q=94.915 critic=0.397 actor=-0.974 bc=0.008 lambda=0.010
# [train] step=187000 q=93.042 critic=0.333 actor=-0.952 bc=0.001 lambda=0.010
# [train] step=188000 q=94.731 critic=0.307 actor=-0.997 bc=0.003 lambda=0.011
# [train] step=189000 q=92.835 critic=0.437 actor=-0.942 bc=0.007 lambda=0.010
# [train] step=190000 q=94.622 critic=0.327 actor=-0.977 bc=0.005 lambda=0.010
# [eval] step=190000 success=88.00% return=100.03 time=43.43s energy=33646.60 path=46.80 prog=0.866
# [train] step=191000 q=93.689 critic=0.708 actor=-0.968 bc=0.003 lambda=0.010
# [train] step=192000 q=96.263 critic=0.214 actor=-0.991 bc=0.009 lambda=0.010
# [train] step=193000 q=93.280 critic=0.386 actor=-0.952 bc=0.011 lambda=0.010
# [train] step=194000 q=95.313 critic=0.247 actor=-0.976 bc=0.007 lambda=0.010
# [train] step=195000 q=96.178 critic=0.282 actor=-0.987 bc=0.013 lambda=0.010
# [train] step=196000 q=94.394 critic=0.409 actor=-0.976 bc=0.007 lambda=0.010
# [train] step=197000 q=96.389 critic=0.381 actor=-0.986 bc=0.014 lambda=0.010
# [train] step=198000 q=93.336 critic=0.267 actor=-0.951 bc=0.013 lambda=0.010
# [train] step=199000 q=94.951 critic=0.446 actor=-0.987 bc=0.013 lambda=0.011
# [train] step=200000 q=94.592 critic=0.393 actor=-0.979 bc=0.002 lambda=0.010
# [eval] step=200000 success=68.00% return=33.86 time=45.11s energy=35021.99 path=49.66 prog=0.808
# [train done] fql seed=0 in 76.6 min
#
# [all train] total = 286.5 min
#
# ========================================================================
#   mirror training curves → results/.../training_curves/
# ========================================================================
#   ✓ rebrac_seed42: 4/4 → results/fql_succession/p2/e_uni/training_curves/rebrac_seed42
#   ✓ rebrac_seed0: 4/4 → results/fql_succession/p2/e_uni/training_curves/rebrac_seed0
#   ✓ fql_seed42: 4/4 → results/fql_succession/p2/e_uni/training_curves/fql_seed42
#   ✓ fql_seed0: 4/4 → results/fql_succession/p2/e_uni/training_curves/fql_seed0

# %% [markdown]
# ## 5. Test eval — 100-episode 在 ep100 manifest 上
#
# 用 `scripts.evaluate_offline` 加载每个 (algo, seed) 的 `agent_final.pt`,在 100-episode test manifest 上跑评估。结果写到 `results/.../test/{algo}_seed{S}.json`(per spec §4.2 + §9.3.1)。
#
# **Skip-resume**:test json 存在则 skip。
# **并行**:6 worker × CPU(与 broad bash 一致),~3-5 min/run。

# %%
import time

TEST_DIR.mkdir(parents=True, exist_ok=True)

t_start_eval = time.time()

for algo in ALGOS:
    for seed in TRAIN_SEEDS:
        sd = save_dir(algo, seed)
        sd_str = str(sd)
        out_path = test_json(algo, seed)
        out_path_str = str(out_path)

        if out_path.exists():
            print(f'[skip-eval] {algo} seed={seed}: {out_path}')
            continue

        if not (sd / 'agent_final.pt').exists():
            print(f'[warn] missing agent_final.pt at {sd} — training not done?')
            continue

        print(f'\n{"=" * 72}')
        print(f'  eval {algo} seed={seed} → {out_path}')
        print(f'{"=" * 72}')
        t0 = time.time()

        # !python -m scripts.evaluate_offline \
            --checkpoint '{sd_str}' \
            --manifest '{MANIFEST}' \
            --episodes {TEST_EPISODES} \
            --num-workers {EVAL_NUM_WORKERS} \
            --worker-device cpu \
            --device cuda \
            --output-json '{out_path_str}'

        print(f'[eval done] {algo} seed={seed} in {(time.time() - t0) / 60:.1f} min')

print(f'\n[all eval] total = {(time.time() - t_start_eval) / 60:.1f} min')
# Out:
# ========================================================================
#   eval rebrac seed=42 → results/fql_succession/p2/e_uni/test/rebrac_seed42.json
# ========================================================================
# reward_objective      : arrival_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.000000
# episodes              : 100
# success_rate          : 89.0%
# avg_return            : 101.84 +/- 107.55
# avg_safety_cost       : 3.439 +/- 4.204
# avg_time_s            : 44.87 +/- 11.83
# avg_time_s_success    : 43.96
# avg_energy            : 34992.80 +/- 9474.24
# avg_path_length_m     : 48.92 +/- 12.70
# avg_progress_ratio    : 0.861 +/- 0.169
# avg_path_efficiency   : 0.791 +/- 0.201
# termination           : {'goal': 89, 'out_of_bounds': 11}
# benchmark_manifest    : benchmarks/single_u10_cross_tgt15_ep100.json
# [eval done] rebrac seed=42 in 1.2 min
#
# ========================================================================
#   eval rebrac seed=0 → results/fql_succession/p2/e_uni/test/rebrac_seed0.json
# ========================================================================
# reward_objective      : arrival_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.000000
# episodes              : 100
# success_rate          : 88.0%
# avg_return            : 99.93 +/- 110.56
# avg_safety_cost       : 3.372 +/- 5.446
# avg_time_s            : 45.20 +/- 13.25
# avg_time_s_success    : 43.03
# avg_energy            : 35225.89 +/- 10572.62
# avg_path_length_m     : 48.62 +/- 12.00
# avg_progress_ratio    : 0.865 +/- 0.148
# avg_path_efficiency   : 0.795 +/- 0.187
# termination           : {'goal': 88, 'out_of_bounds': 12}
# benchmark_manifest    : benchmarks/single_u10_cross_tgt15_ep100.json
# [eval done] rebrac seed=0 in 1.2 min
#
# ========================================================================
#   eval fql seed=42 → results/fql_succession/p2/e_uni/test/fql_seed42.json
# ========================================================================
# reward_objective      : arrival_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.000000
# episodes              : 100
# success_rate          : 80.0%
# avg_return            : 65.88 +/- 154.27
# avg_safety_cost       : 4.683 +/- 7.335
# avg_time_s            : 45.44 +/- 13.34
# avg_time_s_success    : 42.28
# avg_energy            : 35337.20 +/- 10566.54
# avg_path_length_m     : 49.93 +/- 19.54
# avg_progress_ratio    : 0.763 +/- 0.533
# avg_path_efficiency   : 0.755 +/- 0.311
# termination           : {'out_of_bounds': 20, 'goal': 80}
# benchmark_manifest    : benchmarks/single_u10_cross_tgt15_ep100.json
# [eval done] fql seed=42 in 1.2 min
#
# ========================================================================
#   eval fql seed=0 → results/fql_succession/p2/e_uni/test/fql_seed0.json
# ========================================================================
# reward_objective      : arrival_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.000000
# episodes              : 100
# success_rate          : 91.0%
# avg_return            : 107.66 +/- 106.86
# avg_safety_cost       : 2.748 +/- 3.396
# avg_time_s            : 43.14 +/- 7.12
# avg_time_s_success    : 42.64
# avg_energy            : 33313.04 +/- 5520.82
# avg_path_length_m     : 46.21 +/- 7.01
# avg_progress_ratio    : 0.850 +/- 0.231
# avg_path_efficiency   : 0.816 +/- 0.220
# termination           : {'out_of_bounds': 9, 'goal': 91}
# benchmark_manifest    : benchmarks/single_u10_cross_tgt15_ep100.json
# [eval done] fql seed=0 in 1.1 min
#
# [all eval] total = 4.7 min

# %% [markdown]
# ## 6. 三向对比 — 4 run × test json + learning curves
#
# **Guard**:所有 4 个 test json 都存在才进 §6 / §7(per spec §9.3.2)。
#
# **输出**:
# 1. DataFrame:per (algo, seed) 的 `success_rate`,`mean_return`,`safety_cost`,`path_efficiency`,`progress_ratio`,termination 分布(goal / timeout / oob)
# 2. Aggregate table:per algo(mean ± std over 2 seeds)
# 3. Inline matplotlib:**success rate bar**(rebrac vs fql,with seed dots)+ **learning curve**(eval success vs train_step,4 lines,from eval_log.csv mirror)

# %%
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# ---- guard ----
missing = [(a, s) for a in ALGOS for s in TRAIN_SEEDS if not test_json(a, s).exists()]
if missing:
    raise RuntimeError(
        f'[not ready] {len(missing)} runs pending: '
        + ', '.join(f'{a}_seed{s}' for a, s in missing)
    )
print(f'[ok] all {len(ALGOS) * len(TRAIN_SEEDS)} test json present')

# ---- read 4 test json ----
rows = []
for algo in ALGOS:
    for seed in TRAIN_SEEDS:
        p = test_json(algo, seed)
        d = json.loads(p.read_text(encoding='utf-8'))
        n = max(int(d.get('num_eval_episodes', TEST_EPISODES)), 1)
        term = d.get('eval_termination_counts', {})
        rows.append({
            'algo': algo,
            'seed': seed,
            'success_rate': d['eval_success_rate'],
            'mean_return':  d['eval_return'],
            'return_std':   d.get('eval_return_std', float('nan')),
            'safety_cost':  d['eval_safety_cost'],
            'path_eff':     d.get('eval_path_efficiency', float('nan')),
            'progress':     d.get('eval_progress_ratio', float('nan')),
            'goal_pct':     term.get('goal', 0) / n,
            'timeout_pct':  term.get('timeout', 0) / n,
            'oob_pct':      term.get('out_of_bounds', 0) / n,
        })
df = pd.DataFrame(rows)
print('[per-seed test results]')
print(df.to_string(index=False, float_format=lambda x: f'{x:.4f}'))

# ---- aggregate per algo (mean ± std over 2 seeds) ----
agg = df.groupby('algo').agg(
    success_mean=('success_rate', 'mean'),
    success_std=('success_rate', lambda x: x.std(ddof=0)),
    return_mean=('mean_return', 'mean'),
    return_std=('mean_return', lambda x: x.std(ddof=0)),
    safety_mean=('safety_cost', 'mean'),
    path_eff_mean=('path_eff', 'mean'),
    goal_pct_mean=('goal_pct', 'mean'),
    timeout_pct_mean=('timeout_pct', 'mean'),
    oob_pct_mean=('oob_pct', 'mean'),
).reset_index()
print('\n[per-algo aggregate (mean ± std over n=2 seeds)]')
print(agg.to_string(index=False, float_format=lambda x: f'{x:.4f}'))

# ---- plot 1: success rate bar (rebrac vs fql, with seed dots) ----
fig, axes = plt.subplots(1, 2, figsize=(13, 4))

ax = axes[0]
x_pos = np.arange(len(ALGOS))
means = [agg.query(f'algo == {a!r}')['success_mean'].iloc[0] for a in ALGOS]
stds  = [agg.query(f'algo == {a!r}')['success_std'].iloc[0]  for a in ALGOS]
ax.bar(x_pos, means, yerr=stds, capsize=10, color=['#4C72B0', '#DD8452'], alpha=0.7)
# overlay per-seed dots
for i, algo in enumerate(ALGOS):
    seed_succ = df.query(f'algo == {algo!r}')['success_rate'].values
    ax.scatter([i] * len(seed_succ), seed_succ, color='black', zorder=10, s=40)
ax.set_xticks(x_pos)
ax.set_xticklabels(ALGOS)
ax.set_ylabel('test success rate (100 ep)')
ax.set_title(f'{CELL_ID}: test success per algo (n={len(TRAIN_SEEDS)} seeds)')
ax.set_ylim(0, 1.0)
ax.grid(True, alpha=0.3)

# ---- plot 2: learning curve from eval_log.csv ----
ax = axes[1]
for algo in ALGOS:
    for seed in TRAIN_SEEDS:
        csv_p = mirror_dir(algo, seed) / 'eval_log.csv'
        if not csv_p.exists():
            continue
        eval_df = pd.read_csv(csv_p)
        # dedup by train_step (keep last)
        eval_df = eval_df.drop_duplicates(subset='train_step', keep='last')
        label = f'{algo}_seed{seed}'
        style = '-' if algo == 'rebrac' else '--'
        ax.plot(eval_df['train_step'], eval_df['eval_success_rate'],
                style, label=label, alpha=0.8)
ax.set_xlabel('train_step')
ax.set_ylabel('in-training eval success (every 10k step, 100 ep)')
ax.set_title(f'{CELL_ID}: learning curves (eval_log.csv)')
ax.set_ylim(0, 1.0)
ax.legend(loc='lower right', fontsize=9)
ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# [ok] all 4 test json present
# [per-seed test results]
#   algo  seed  success_rate  mean_return  return_std  safety_cost  path_eff  progress  goal_pct  timeout_pct  oob_pct
# rebrac    42        0.8900     101.8399    107.5487       3.4390    0.7912    0.8614    0.8900       0.0000   0.1100
# rebrac     0        0.8800      99.9315    110.5621       3.3715    0.7946    0.8648    0.8800       0.0000   0.1200
#    fql    42        0.8000      65.8790    154.2703       4.6832    0.7551    0.7626    0.8000       0.0000   0.2000
#    fql     0        0.9100     107.6623    106.8644       2.7483    0.8156    0.8504    0.9100       0.0000   0.0900
#
# [per-algo aggregate (mean ± std over n=2 seeds)]
#   algo  success_mean  success_std  return_mean  return_std  safety_mean  path_eff_mean  goal_pct_mean  timeout_pct_mean  oob_pct_mean
#    fql        0.8550       0.0550      86.7707     20.8917       3.7158         0.7853         0.8550            0.0000        0.1450
# rebrac        0.8850       0.0050     100.8857      0.9542       3.4053         0.7929         0.8850            0.0000        0.1150

# %% [markdown]
# ## 7. 自动 verdict — effect-size + 方向一致性(per spec §5.4)
#
# **本 cell 预期方向**:`null` — 若 NULL → P2 进 §3 / §4(优秀;符合 paper claim:FQL 优势只在 sub-optimal × multi-modal)。若 unexpected POSITIVE(FQL > ReBRAC ≥5pp)→ ANOMALY,触发 sprint 1 重审(BC penalty 配置 / data leak 可能)
#
# **阈值**:`δ_null = 0.03` + `δ_signal = 0.05` + gray band [3pp, 5pp]。
#
# **输出**:
# 1. `Δ = mean(success_fql) - mean(success_rebrac)` over seeds
# 2. paired diff per seed:`Δ_seed = success_fql_seed - success_rebrac_seed`
# 3. 方向一致性:两 seed paired diff 同号 ?
# 4. c4 stability(per spec §5.6,n=2 threshold = −0.01549,from `eval_log.csv` last 30%)
# 5. **Verdict**:NULL / POSITIVE / GRAY(per §5.4 表)

# %%
import numpy as np
from scipy.stats import linregress

DELTA_NULL = 0.03
DELTA_SIGNAL = 0.05
C4_THRESHOLD_N2 = -0.01549  # per spec §5.6 n=2 Option α
EXPECTED_DIRECTION = 'null'  # 'null' or 'positive'

# ---- 1. Aggregate success per algo ----
succ_rebrac = df.query("algo == 'rebrac'")['success_rate'].values
succ_fql    = df.query("algo == 'fql'")['success_rate'].values
delta_mean = succ_fql.mean() - succ_rebrac.mean()

# ---- 2. Paired diff per seed ----
paired = {}
for seed in TRAIN_SEEDS:
    s_r = df.query(f'algo == "rebrac" and seed == {seed}')['success_rate'].iloc[0]
    s_f = df.query(f'algo == "fql" and seed == {seed}')['success_rate'].iloc[0]
    paired[seed] = s_f - s_r

all_positive = all(d > 0 for d in paired.values())
all_negative = all(d < 0 for d in paired.values())
all_near_zero = all(abs(d) < 0.04 for d in paired.values())
direction_consistent = all_positive or all_negative or all_near_zero

# ---- 3. c4 stability per algo ----
c4 = {}
for algo in ALGOS:
    slopes = []
    for seed in TRAIN_SEEDS:
        csv_p = mirror_dir(algo, seed) / 'eval_log.csv'
        if not csv_p.exists():
            continue
        ed = pd.read_csv(csv_p).drop_duplicates(subset='train_step', keep='last')
        # last 30% of eval points
        n_pts = max(int(round(len(ed) * 0.3)), 3)
        tail = ed.tail(n_pts)
        if len(tail) >= 3:
            slope, *_ = linregress(tail['train_step'], tail['eval_success_rate'])
            slopes.append(slope)
    if slopes:
        c4[algo] = {
            'per_seed_slopes': slopes,
            'agg_slope': float(np.mean(slopes)),
            'verdict': 'PASS' if np.mean(slopes) >= C4_THRESHOLD_N2 else 'FAIL',
        }

# ---- 4. Verdict logic (per spec §5.4) ----
print('=' * 72)
print(f'  CELL_ID = {CELL_ID}   expected = {EXPECTED_DIRECTION}')
print('-' * 72)
print(f'  ReBRAC success mean = {succ_rebrac.mean():.4f}   per-seed = {dict(zip(TRAIN_SEEDS, succ_rebrac.tolist()))}')
print(f'  FQL    success mean = {succ_fql.mean():.4f}   per-seed = {dict(zip(TRAIN_SEEDS, succ_fql.tolist()))}')
print(f'  Δ (FQL − ReBRAC) mean = {delta_mean:+.4f} ({delta_mean*100:+.2f} pp)')
print(f'  paired diff per seed  = {dict((s, round(d, 4)) for s, d in paired.items())}')
print(f'  direction_consistent  = {direction_consistent} '
      f'(all_pos={all_positive}, all_neg={all_negative}, all_near_zero={all_near_zero})')
print('-' * 72)
print('  c4 stability monitor (per spec §5.6, n=2 threshold = -0.01549):')
for algo, info in c4.items():
    print(f'    {algo}: agg_slope = {info["agg_slope"]:+.5f}   verdict = {info["verdict"]}'
          f'   per-seed = {[round(s, 5) for s in info["per_seed_slopes"]]}')
print('-' * 72)

# ---- 5. Verdict decision ----
abs_delta = abs(delta_mean)
if EXPECTED_DIRECTION == 'null':
    # paper wants null: |Δ| < 0.03 AND seed diffs all near zero
    if abs_delta < DELTA_NULL and all_near_zero:
        verdict = 'NULL CONFIRMED ✓ (符合 paper claim 预期)'
        next_step = 'log to verdict report; proceed with other cells'
    elif delta_mean >= DELTA_SIGNAL and all_positive:
        verdict = 'UNEXPECTED POSITIVE ⚠ (FQL 在本 cell 也赢 — paper claim 失败)'
        next_step = (
            'paper claim 失败:FQL 不止在 multi-modal 赢,在本 cell 也赢 → '
            'sprint 1 加 seed 7;若仍 positive 则 paper claim 重写'
        )
    elif delta_mean <= -DELTA_SIGNAL and all_negative:
        verdict = 'UNEXPECTED NEGATIVE ⚠ (ReBRAC 在本 cell 显著强于 FQL — paper claim 弱化)'
        next_step = (
            'paper claim 弱化:本 cell 上 ReBRAC > FQL,可能数据 quality 高时 ReBRAC 占优 → '
            'sprint 1 加 seed 7 后写 caveat 段'
        )
    else:
        verdict = 'GRAY (3pp ≤ |Δ| < 5pp 或方向不一致) — 加 seed 7'
        next_step = '扩 n_seeds=3 [42, 0, 7],在 sprint 1 跑'
elif EXPECTED_DIRECTION == 'positive':
    # paper wants positive: Δ ≥ 0.05 AND both seeds positive
    if delta_mean >= DELTA_SIGNAL and all_positive:
        verdict = 'POSITIVE CONFIRMED ✓ (符合 paper claim 预期)'
        next_step = 'paper claim 主结论确证:本 cell 是 iff 的右侧(FQL > ReBRAC on sub-opt × multi-modal)'
    elif abs_delta < DELTA_NULL:
        verdict = 'NULL ❌ (paper claim 失败 — FQL ≯ ReBRAC on multi-modal)'
        next_step = (
            'paper claim 主结论失败:本 cell 是 iff 主证据,如果 NULL → iff 不成立 → '
            'sprint 1 加 seed 7;若仍 NULL 则 paper claim 重写或重设计 dataset'
        )
    elif not all_positive:
        verdict = 'GRAY (mixed direction across seeds) — 加 seed 7'
        next_step = '扩 n_seeds=3 [42, 0, 7];方向一致性 critical for paper claim'
    else:
        verdict = 'GRAY (3pp ≤ Δ < 5pp,方向一致但 effect size 小) — 加 seed 7'
        next_step = '扩 n_seeds=3 [42, 0, 7];考虑 paper 弱化措辞'
else:
    verdict = f'UNKNOWN expected direction {EXPECTED_DIRECTION!r}'
    next_step = 'spec error: §0 verdict 规则需要更新'

print(f'  VERDICT  : {verdict}')
print(f'  NEXT     : {next_step}')

# ---- 6. c4 caveat ----
fql_c4 = c4.get('fql', {}).get('verdict')
if fql_c4 == 'FAIL':
    print(f'  CAVEAT   : FQL c4 FAIL (slope < -0.01549) — paper 写 "FQL stability marginally fails in {CELL_ID}"')
elif fql_c4 == 'PASS':
    print(f'  CAVEAT   : FQL c4 PASS — stability monitor OK')
print('=' * 72)
# Out:
# ========================================================================
#   CELL_ID = e_uni   expected = null
# ------------------------------------------------------------------------
#   ReBRAC success mean = 0.8850   per-seed = {42: 0.89, 0: 0.88}
#   FQL    success mean = 0.8550   per-seed = {42: 0.8, 0: 0.91}
#   Δ (FQL − ReBRAC) mean = -0.0300 (-3.00 pp)
#   paired diff per seed  = {42: np.float64(-0.09), 0: np.float64(0.03)}
#   direction_consistent  = False (all_pos=False, all_neg=False, all_near_zero=False)
# ------------------------------------------------------------------------
#   c4 stability monitor (per spec §5.6, n=2 threshold = -0.01549):
#     rebrac: agg_slope = +0.00000   verdict = PASS   per-seed = [np.float64(0.0), np.float64(-0.0)]
#     fql: agg_slope = +0.00000   verdict = PASS   per-seed = [np.float64(-0.0), np.float64(0.0)]
# ------------------------------------------------------------------------
#   VERDICT  : GRAY (3pp ≤ |Δ| < 5pp 或方向不一致) — 加 seed 7
#   NEXT     : 扩 n_seeds=3 [42, 0, 7],在 sprint 1 跑
#   CAVEAT   : FQL c4 PASS — stability monitor OK
# ========================================================================

# %% [markdown]
# ## 8. 报告写入清单
#
# **任何 verdict(必填)**
#
# - [`docs/fql_succession_p2_main_spec.md`](../docs/fql_succession_p2_main_spec.md) §5(verdict)→ e_uni 行填写:n_seeds,Δ_mean,paired diff,direction,verdict
# - `docs/fql_succession_p2_results.md`(待 P2 闭环时创建)→ 本 cell 段:per-seed table + verdict + c4 monitor
# - [`docs/fql_succession_plan_v0.md`](../docs/fql_succession_plan_v0.md) P2 进度行:本 cell run done
#
# **预期 verdict = NULL**
#
# - 符合 paper claim:**NULL** — FQL ≈ ReBRAC on optimal-unimodal data(paper claim 的 baseline 验证)
# - 待 3 cell 都跑完后,在 verdict notebook(`fql_succession_p2_verdict.ipynb`,P2 闭环时创建)做 iff 总判:E-uni null ∧ M-uni-noise null ∧ M-multi-mix positive → paper claim 主结论确证
#
# **verdict = 与预期相反(详见 §7 的 next_step)**
#
# - UNEXPECTED POSITIVE → sprint 1 加 seed 7 复查;若仍 positive → paper claim 重写为「FQL 在 sub-optimal 数据上普遍占优」(less specific iff claim)
# - UNEXPECTED NEGATIVE → 写 caveat:本 cell 上 ReBRAC > FQL 可能因 normalized-Q 配置差异,sprint 1 验证
#
# **verdict = GRAY**
#
# - 扩 n_seeds=3 [42, 0, 7] 跑本 notebook(把 `TRAIN_SEEDS = [42, 0]` 改成 `[42, 0, 7]` 然后重跑 §4 / §5;§3 skip-resume 会跳过已 done 的 seed 42 / 0,只新跑 seed 7)
# - 重新跑 §6 / §7,新 c4 阈值 = −0.01267(spec §5.6 n=3 行)
#
# **跨 cell aggregation(待 3 cell 都跑完)**
#
# - `notebooks/fql_succession_p2_verdict.ipynb`(P2 闭环时另起):一次 sweep 3 cell × 4 run = 12 个 test json
# - aggregation 命令(本机 sync `results/` 后):
#   ```python
#   import json
#   from pathlib import Path
#   rows = []
#   for cell in ['e_uni', 'm_uni_noise', 'm_multi_mix']:
#       for algo in ['rebrac', 'fql']:
#           for seed in [42, 0]:
#               p = Path(f'results/fql_succession/p2/{cell}/test/{algo}_seed{seed}.json')
#               d = json.loads(p.read_text())
#               rows.append({'cell': cell, 'algo': algo, 'seed': seed,
#                            'success': d['eval_success_rate'],
#                            'return':  d['eval_return']})
#   ```
