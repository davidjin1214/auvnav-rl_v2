# %% [markdown]
# # ReBRAC Stage D — `worldcomp-1000` critic-penalty-off mechanism probe
#
# **目的**：验证 Phase 1 Step 2 暴露的 **Finding 1**——ReBRAC 在 worldcomp 上 dual penalty 几乎退化为单 penalty（`β2·critic_penalty_ratio = 0.0111`，比 crosscomp Stage C 低 1–2 个数量级）。
#
# **机制猜想**：worldcomp 是 deterministic teacher policy，`next_actions = π_teacher(s')` 与 ReBRAC 自己的 `π_target(s')` 高度一致 → critic penalty `||π_target(s') + noise − a'||²` 退化为接近恒等约束。如果这个解释成立，那么把 β2 降到 0 应该几乎不影响最终成绩。
#
# **核心问题**：`(β1=4.0, β2=0)` 在 `worldcomp-1000` deployable 上的 `mean_test_success` 是否落在 Phase 1 主 finalist `(β1=4.0, β2=2.0)` 的 `0.928 ± 0.077` 的 ±2pp 区间内？
#
# **实验 scope**：
#
# | 轴 | 配置 | 说明 |
# |---|---|---|
# | β1 | `4.0` | 与 Phase 1 主 finalist 一致 |
# | β2 | **`0.0`** | 关键操纵：critic penalty off |
# | dataset | `worldcomp-1000` | 与 Phase 1 同 dataset |
# | seeds | `42 43` | 与 epoch-probe / Phase 1 baseline 重叠；**刻意不含 seed 44**——Phase 1 已暴露 seed 44 是 outlier，这里只验证 typical regime |
# | TRAIN_EPOCHS | `64` | 与 Phase 1 一致 |
# | 轨道 | deployable | 与 Phase 1 同协议 |
# | val manifest | 40 episodes | 与 Phase 1 对齐（复用） |
# | test manifest | 100 episodes | 与 Phase 1 对齐（复用） |
#
# **预算**：2 seeds × 1 配置 × 64 epoch ≈ Phase 1 deployable 的 40% 算力。manifest 与离线数据集完全复用 Phase 1 已生成的资源。
#
# **判据**：
#
# | 情形 | mean_test_success | 解读 |
# | --- | --- | --- |
# | **A** 几乎一致 | `0.928 ± 2pp`（即 `0.908 ~ 0.948`） | Finding 1 机制猜想成立；Stage E ablation 中 critic-penalty-off 这一格直接收口 |
# | **B** 略有下降 | `0.88 ~ 0.91` | dual penalty 在 worldcomp 上虽弱但仍非零；Stage E 仍需保留 critic-penalty-off 完整 5-seed ablation |
# | **C** 显著下降 | `< 0.88` | Finding 1 机制猜想被证伪——critic penalty 在 worldcomp 上虽然 ratio 极小，但仍是关键稳定项；需要回查 Phase 1 `mean_critic_penalty_ratio` 的 per-seed 拆分 |
#
# **输出树**（与 deployable / privileged_critic 完全隔离）：
# - `checkpoints/offline/rebrac/worldcomp_critic_penalty_off_probe/`
# - `results/offline/rebrac/worldcomp_critic_penalty_off_probe/`

# %% [markdown]
# ## 0. 环境 sanity check

# %%
# !lscpu | head -10
print()
# !nvidia-smi
# Out:
# Architecture:                            x86_64
# CPU op-mode(s):                          32-bit, 64-bit
# Address sizes:                           46 bits physical, 48 bits virtual
# Byte Order:                              Little Endian
# CPU(s):                                  12
# On-line CPU(s) list:                     0-11
# Vendor ID:                               GenuineIntel
# Model name:                              Intel(R) Xeon(R) CPU @ 2.20GHz
# CPU family:                              6
# Model:                                   85
#
# Wed Apr 29 13:54:43 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA L4                      Off |   00000000:00:03.0 Off |                    0 |
# | N/A   35C    P8             12W /   72W |       0MiB /  23034MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
import torch
print(f"PyTorch: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
# Out:
# PyTorch: 2.10.0+cu128
# CUDA available: True

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# %cd /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5

# %% [markdown]
# ## 1. 环境配置
#
# 复用 driver `run_offline_rebrac_worldcomp_teacher_gap.sh` 的 deployable 通路，但把：
# - β2 设为 0；
# - 输出根目录隔离到 `worldcomp_critic_penalty_off_probe/`；
# - seeds 收紧到 2（42/43）。

# %%
import os

# —— 通用 ——
os.environ["PYTHON_BIN"]         = "python3"
os.environ["DEVICE"]             = "cuda"
os.environ["EVAL_WORKERS"]       = "6"
os.environ["EVAL_WORKER_DEVICE"] = "cpu"

# —— 关键操纵：β2=0 ——
os.environ["ACTOR_PENALTY_COEF"]  = "4.0"
os.environ["CRITIC_PENALTY_COEF"] = "0.0"

# —— 协议（与 Phase 1 deployable 对齐）——
os.environ["DEPLOYABLE_FINAL_SEEDS"]                       = "42 43"
os.environ["DEPLOYABLE_FINAL_TRAIN_EPOCHS"]                = "64"
os.environ["DEPLOYABLE_FINAL_CHECKPOINT_EVERY_EPOCHS"]     = "8"
os.environ["FINAL_VAL_MANIFEST_EPISODES"]                  = "40"
os.environ["FINAL_TEST_MANIFEST_EPISODES"]                 = "100"

# —— 输出根目录隔离（不污染 Phase 1 / Phase 2）——
os.environ["DEPLOYABLE_RESULTS_ROOT"]    = "results/offline/rebrac/worldcomp_critic_penalty_off_probe"
os.environ["DEPLOYABLE_CHECKPOINT_ROOT"] = "checkpoints/offline/rebrac/worldcomp_critic_penalty_off_probe"

# manifest / 离线数据集复用 Phase 1（FINAL_MANIFEST_ROOT 用 driver 默认值）

# %% [markdown]
# ## 2. 复用 sanity check
#
# manifest 与离线数据集应已由 epoch-probe / Phase 1 生成；如果缺失，driver 会自动重建。

# %%
import pathlib

manifest_val  = pathlib.Path("benchmarks/offline_rebrac_worldcomp_final/val_40/single_u10_cross_tgt15.json")
manifest_test = pathlib.Path("benchmarks/offline_rebrac_worldcomp_final/test_100/single_u10_cross_tgt15.json")
dataset       = pathlib.Path("offline_data/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/transitions.npz")

for label, p in [("val manifest", manifest_val), ("test manifest", manifest_test), ("offline dataset", dataset)]:
    if p.exists():
        print(f"[reuse] {label}: {p}")
    else:
        print(f"[warn] {label} 缺失：{p}（driver 会自动重建/重收）")
# Out:
# [reuse] val manifest: benchmarks/offline_rebrac_worldcomp_final/val_40/single_u10_cross_tgt15.json
# [reuse] test manifest: benchmarks/offline_rebrac_worldcomp_final/test_100/single_u10_cross_tgt15.json
# [reuse] offline dataset: offline_data/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/transitions.npz

# %% [markdown]
# ## 3. 全流程：deployable_train → validate → select → test → summarize
#
# 2 个 train run × 1 配置 × 64 epoch，每 8 epoch 一个 ckpt → val=40 选最佳 → test=100 出最终成绩。

# %%
# 跑 critic-penalty-off probe 全流程
for mode in ["deployable_train", "deployable_validate", "deployable_test", "deployable_summarize"]:
    os.environ["MODE"] = mode
    # !bash scripts/run_offline_rebrac_worldcomp_teacher_gap.sh
# Out:
# [cmd] env MODE=train PYTHON_BIN=python3 DEVICE=cuda BENCHMARK_KEY=single_u10_cross_tgt15 FLOW_PATH=wake_data/wake_v8_U1p00_Re150_D12p00_dx0p60_Ti5pct_1200f_roi.npy TASK_GEOMETRY=cross_stream TARGET_SPEED=1.5 OBJECTIVE=efficiency_v2 PROBE_LAYOUT=s0 HISTORY_LENGTH=4 DATASET_POLICY=worldcomp DATASET_EPISODES=1000 DATASET_SEED=0 COLLECT_WORKERS=8 ACTOR_PENALTY_COEFS=4.0 CRITIC_PENALTY_COEFS=0.0 BATCH_SIZE=256 DROP_LAST_BATCH=0 SAMPLING_MODE=shuffle_no_replacement HIDDEN_DIM=256 NUM_HIDDEN_LAYERS=3 ACTOR_LR=3e-4 CRITIC_LR=3e-4 GAMMA=0.99 TAU=0.005 POLICY_NOISE=0.2 NOISE_CLIP=0.5 POLICY_FREQ=2 GRAD_CLIP_NORM=10.0 NORMALIZER_EPS=1e-3 LOG_EVERY=1000 TRAIN_METRICS_WINDOW_FRACTION=0.25 EVAL_WORKERS=6 EVAL_WORKER_DEVICE=cpu VALIDATION_SEED=123 TEST_SEED=456 FORCE_REEVAL=0 SEEDS=42 43 TRAIN_EPOCHS=64 CHECKPOINT_EVERY_EPOCHS=8 VAL_MANIFEST_EPISODES=40 TEST_MANIFEST_EPISODES=100 MANIFEST_ROOT=benchmarks/offline_rebrac_worldcomp_final CHECKPOINT_ROOT=checkpoints/offline/rebrac/worldcomp_critic_penalty_off_probe RESULTS_ROOT=results/offline/rebrac/worldcomp_critic_penalty_off_probe USE_ASYMMETRIC_CRITIC=0 bash scripts/run_offline_rebrac_screen.sh
# [skip] manifest exists: benchmarks/offline_rebrac_worldcomp_final/val_40/single_u10_cross_tgt15.json
# [skip] manifest exists: benchmarks/offline_rebrac_worldcomp_final/test_100/single_u10_cross_tgt15.json
# [skip] dataset exists: offline_data/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/transitions.npz
#
# [cmd] python3 -m scripts.train_offline --algo rebrac --offline-data offline_data/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/transitions.npz --flow wake_data/wake_v8_U1p00_Re150_D12p00_dx0p60_Ti5pct_1200f_roi.npy --manifest benchmarks/offline_rebrac_worldcomp_final/val_40/single_u10_cross_tgt15.json --probe-layout s0 --history-length 4 --task-geometry cross_stream --target-speed 1.5 --objective efficiency_v2 --sampling-mode shuffle_no_replacement --num-epochs 64 --total-steps 26112 --batch-size 256 --hidden-dim 256 --num-hidden-layers 3 --actor-lr 3e-4 --critic-lr 3e-4 --gamma 0.99 --tau 0.005 --actor-penalty-coef 4.0 --critic-penalty-coef 0.0 --policy-noise 0.2 --noise-clip 0.5 --policy-freq 2 --grad-clip-norm 10.0 --normalizer-eps 1e-3 --eval-every 0 --checkpoint-every 3264 --skip-final-eval --log-every 1000 --critic-layernorm --no-actor-layernorm --save-dir checkpoints/offline/rebrac/worldcomp_critic_penalty_off_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_0p0/seed_42 --seed 42 --device cuda
# [offline] algo=rebrac transitions=104360 obs_dim=40 action_dim=2 protocol=deployable tensor_replay=on eval_workers=1 sampling=shuffle_no_replacement total_steps=26112
# [train] step=1 epoch=1 epoch_step=1 q=-0.527 critic=78.520 actor=5.422 bc=1.106 lambda=1.894 critic_pen=1.223
# [train] step=1000 epoch=3 epoch_step=184 q=-0.035 critic=20.269 actor=0.104 bc=0.024 lambda=0.271 critic_pen=0.100
# [train] step=2000 epoch=5 epoch_step=368 q=-0.804 critic=2.373 actor=0.231 bc=0.023 lambda=0.173 critic_pen=0.094
# [train] step=3000 epoch=8 epoch_step=144 q=4.489 critic=7.309 actor=-0.234 bc=0.030 lambda=0.079 critic_pen=0.100
# [train] step=4000 epoch=10 epoch_step=328 q=7.048 critic=3.335 actor=-0.357 bc=0.013 lambda=0.058 critic_pen=0.097
# [train] step=5000 epoch=13 epoch_step=104 q=6.263 critic=2.981 actor=-0.228 bc=0.028 lambda=0.054 critic_pen=0.086
# [train] step=6000 epoch=15 epoch_step=288 q=8.210 critic=3.270 actor=-0.336 bc=0.009 lambda=0.046 critic_pen=0.089
# [train] step=7000 epoch=18 epoch_step=64 q=9.449 critic=2.532 actor=-0.373 bc=0.002 lambda=0.040 critic_pen=0.074
# [train] step=8000 epoch=20 epoch_step=248 q=13.241 critic=2.243 actor=-0.394 bc=0.016 lambda=0.034 critic_pen=0.090
# [train] step=9000 epoch=23 epoch_step=24 q=8.438 critic=1.722 actor=-0.279 bc=0.008 lambda=0.037 critic_pen=0.073
# [train] step=10000 epoch=25 epoch_step=208 q=14.776 critic=2.304 actor=-0.441 bc=0.001 lambda=0.030 critic_pen=0.079
# [train] step=11000 epoch=27 epoch_step=392 q=13.611 critic=1.782 actor=-0.346 bc=0.013 lambda=0.029 critic_pen=0.068
# [train] step=12000 epoch=30 epoch_step=168 q=15.878 critic=1.755 actor=-0.375 bc=0.018 lambda=0.028 critic_pen=0.089
# [train] step=13000 epoch=32 epoch_step=352 q=16.075 critic=1.596 actor=-0.422 bc=0.005 lambda=0.028 critic_pen=0.083
# [train] step=14000 epoch=35 epoch_step=128 q=17.193 critic=2.793 actor=-0.429 bc=0.004 lambda=0.026 critic_pen=0.073
# [train] step=15000 epoch=37 epoch_step=312 q=19.942 critic=1.507 actor=-0.474 bc=0.004 lambda=0.025 critic_pen=0.069
# [train] step=16000 epoch=40 epoch_step=88 q=14.418 critic=1.067 actor=-0.306 bc=0.019 lambda=0.027 critic_pen=0.072
# [train] step=17000 epoch=42 epoch_step=272 q=25.747 critic=1.444 actor=-0.557 bc=0.001 lambda=0.022 critic_pen=0.088
# [train] step=18000 epoch=45 epoch_step=48 q=18.341 critic=1.335 actor=-0.431 bc=0.000 lambda=0.024 critic_pen=0.087
# [train] step=19000 epoch=47 epoch_step=232 q=20.773 critic=1.798 actor=-0.473 bc=0.001 lambda=0.023 critic_pen=0.072
# [train] step=20000 epoch=50 epoch_step=8 q=16.570 critic=1.850 actor=-0.354 bc=0.010 lambda=0.024 critic_pen=0.081
# [train] step=21000 epoch=52 epoch_step=192 q=26.926 critic=2.778 actor=-0.557 bc=0.005 lambda=0.021 critic_pen=0.081
# [train] step=22000 epoch=54 epoch_step=376 q=22.270 critic=2.066 actor=-0.476 bc=0.001 lambda=0.022 critic_pen=0.076
# [train] step=23000 epoch=57 epoch_step=152 q=21.142 critic=1.419 actor=-0.455 bc=0.000 lambda=0.022 critic_pen=0.081
# [train] step=24000 epoch=59 epoch_step=336 q=21.963 critic=2.225 actor=-0.460 bc=0.009 lambda=0.023 critic_pen=0.082
# [train] step=25000 epoch=62 epoch_step=112 q=27.774 critic=2.269 actor=-0.580 bc=0.001 lambda=0.021 critic_pen=0.074
# [train] step=26000 epoch=64 epoch_step=296 q=16.827 critic=3.428 actor=-0.290 bc=0.030 lambda=0.024 critic_pen=0.083
#
# [cmd] python3 -m scripts.train_offline --algo rebrac --offline-data offline_data/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/transitions.npz --flow wake_data/wake_v8_U1p00_Re150_D12p00_dx0p60_Ti5pct_1200f_roi.npy --manifest benchmarks/offline_rebrac_worldcomp_final/val_40/single_u10_cross_tgt15.json --probe-layout s0 --history-length 4 --task-geometry cross_stream --target-speed 1.5 --objective efficiency_v2 --sampling-mode shuffle_no_replacement --num-epochs 64 --total-steps 26112 --batch-size 256 --hidden-dim 256 --num-hidden-layers 3 --actor-lr 3e-4 --critic-lr 3e-4 --gamma 0.99 --tau 0.005 --actor-penalty-coef 4.0 --critic-penalty-coef 0.0 --policy-noise 0.2 --noise-clip 0.5 --policy-freq 2 --grad-clip-norm 10.0 --normalizer-eps 1e-3 --eval-every 0 --checkpoint-every 3264 --skip-final-eval --log-every 1000 --critic-layernorm --no-actor-layernorm --save-dir checkpoints/offline/rebrac/worldcomp_critic_penalty_off_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_0p0/seed_43 --seed 43 --device cuda
# [offline] algo=rebrac transitions=104360 obs_dim=40 action_dim=2 protocol=deployable tensor_replay=on eval_workers=1 sampling=shuffle_no_replacement total_steps=26112
# [train] step=1 epoch=1 epoch_step=1 q=-0.346 critic=77.798 actor=5.488 bc=1.126 lambda=2.844 critic_pen=1.204
# [train] step=1000 epoch=3 epoch_step=184 q=1.190 critic=19.965 actor=-0.167 bc=0.030 lambda=0.243 critic_pen=0.122
# [train] step=2000 epoch=5 epoch_step=368 q=1.047 critic=17.200 actor=-0.094 bc=0.014 lambda=0.143 critic_pen=0.078
# [train] step=3000 epoch=8 epoch_step=144 q=1.544 critic=2.780 actor=-0.115 bc=0.011 lambda=0.104 critic_pen=0.086
# [train] step=4000 epoch=10 epoch_step=328 q=5.335 critic=2.141 actor=-0.281 bc=0.018 lambda=0.066 critic_pen=0.093
# [train] step=5000 epoch=13 epoch_step=104 q=5.383 critic=3.060 actor=-0.305 bc=0.003 lambda=0.059 critic_pen=0.073
# [train] step=6000 epoch=15 epoch_step=288 q=6.293 critic=2.114 actor=-0.185 bc=0.030 lambda=0.048 critic_pen=0.078
# [train] step=7000 epoch=18 epoch_step=64 q=9.594 critic=1.880 actor=-0.351 bc=0.008 lambda=0.040 critic_pen=0.082
# [train] step=8000 epoch=20 epoch_step=248 q=12.794 critic=2.024 actor=-0.346 bc=0.025 lambda=0.035 critic_pen=0.088
# [train] step=9000 epoch=23 epoch_step=24 q=12.748 critic=1.218 actor=-0.359 bc=0.014 lambda=0.032 critic_pen=0.088
# [train] step=10000 epoch=25 epoch_step=208 q=11.983 critic=1.949 actor=-0.382 bc=0.003 lambda=0.033 critic_pen=0.074
# [train] step=11000 epoch=27 epoch_step=392 q=14.838 critic=1.549 actor=-0.435 bc=0.001 lambda=0.030 critic_pen=0.075
# [train] step=12000 epoch=30 epoch_step=168 q=16.341 critic=2.172 actor=-0.441 bc=0.002 lambda=0.027 critic_pen=0.077
# [train] step=13000 epoch=32 epoch_step=352 q=18.802 critic=1.740 actor=-0.476 bc=0.003 lambda=0.026 critic_pen=0.078
# [train] step=14000 epoch=35 epoch_step=128 q=19.746 critic=1.417 actor=-0.479 bc=0.003 lambda=0.025 critic_pen=0.086
# [train] step=15000 epoch=37 epoch_step=312 q=15.632 critic=1.196 actor=-0.396 bc=0.002 lambda=0.026 critic_pen=0.079
# [train] step=16000 epoch=40 epoch_step=88 q=24.416 critic=1.247 actor=-0.540 bc=0.003 lambda=0.023 critic_pen=0.075
# [train] step=17000 epoch=42 epoch_step=272 q=15.339 critic=1.347 actor=-0.383 bc=0.003 lambda=0.026 critic_pen=0.089
# [train] step=18000 epoch=45 epoch_step=48 q=18.598 critic=1.569 actor=-0.429 bc=0.001 lambda=0.023 critic_pen=0.084
# [train] step=19000 epoch=47 epoch_step=232 q=20.005 critic=1.808 actor=-0.474 bc=0.000 lambda=0.024 critic_pen=0.075
# [train] step=20000 epoch=50 epoch_step=8 q=21.009 critic=2.049 actor=-0.451 bc=0.006 lambda=0.023 critic_pen=0.072
# [train] step=21000 epoch=52 epoch_step=192 q=19.684 critic=1.532 actor=-0.452 bc=0.001 lambda=0.023 critic_pen=0.084
# [train] step=22000 epoch=54 epoch_step=376 q=25.938 critic=2.435 actor=-0.487 bc=0.016 lambda=0.021 critic_pen=0.087
# [train] step=23000 epoch=57 epoch_step=152 q=23.063 critic=3.520 actor=-0.433 bc=0.023 lambda=0.023 critic_pen=0.090
# [train] step=24000 epoch=59 epoch_step=336 q=24.956 critic=2.068 actor=-0.535 bc=0.004 lambda=0.022 critic_pen=0.081
# [train] step=25000 epoch=62 epoch_step=112 q=20.832 critic=6.273 actor=-0.461 bc=0.000 lambda=0.022 critic_pen=0.079
# [train] step=26000 epoch=64 epoch_step=296 q=21.873 critic=1.909 actor=-0.448 bc=0.017 lambda=0.023 critic_pen=0.081
#
# [cmd] env MODE=validate PYTHON_BIN=python3 DEVICE=cuda BENCHMARK_KEY=single_u10_cross_tgt15 FLOW_PATH=wake_data/wake_v8_U1p00_Re150_D12p00_dx0p60_Ti5pct_1200f_roi.npy TASK_GEOMETRY=cross_stream TARGET_SPEED=1.5 OBJECTIVE=efficiency_v2 PROBE_LAYOUT=s0 HISTORY_LENGTH=4 DATASET_POLICY=worldcomp DATASET_EPISODES=1000 DATASET_SEED=0 COLLECT_WORKERS=8 ACTOR_PENALTY_COEFS=4.0 CRITIC_PENALTY_COEFS=0.0 BATCH_SIZE=256 DROP_LAST_BATCH=0 SAMPLING_MODE=shuffle_no_replacement HIDDEN_DIM=256 NUM_HIDDEN_LAYERS=3 ACTOR_LR=3e-4 CRITIC_LR=3e-4 GAMMA=0.99 TAU=0.005 POLICY_NOISE=0.2 NOISE_CLIP=0.5 POLICY_FREQ=2 GRAD_CLIP_NORM=10.0 NORMALIZER_EPS=1e-3 LOG_EVERY=1000 TRAIN_METRICS_WINDOW_FRACTION=0.25 EVAL_WORKERS=6 EVAL_WORKER_DEVICE=cpu VALIDATION_SEED=123 TEST_SEED=456 FORCE_REEVAL=0 SEEDS=42 43 TRAIN_EPOCHS=64 CHECKPOINT_EVERY_EPOCHS=8 VAL_MANIFEST_EPISODES=40 TEST_MANIFEST_EPISODES=100 MANIFEST_ROOT=benchmarks/offline_rebrac_worldcomp_final CHECKPOINT_ROOT=checkpoints/offline/rebrac/worldcomp_critic_penalty_off_probe RESULTS_ROOT=results/offline/rebrac/worldcomp_critic_penalty_off_probe USE_ASYMMETRIC_CRITIC=0 bash scripts/run_offline_rebrac_screen.sh
# [skip] manifest exists: benchmarks/offline_rebrac_worldcomp_final/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/worldcomp_critic_penalty_off_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_0p0/seed_42 --agent-file agent_step_00003264.pt --manifest benchmarks/offline_rebrac_worldcomp_final/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/worldcomp_critic_penalty_off_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_0p0/validation/seed_42/agent_step_00003264.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 15.0%
# avg_return            : -87.08 +/- 62.08
# avg_safety_cost       : 11.571 +/- 5.496
# avg_time_s            : 54.33 +/- 10.55
# avg_time_s_success    : 44.07
# avg_energy            : 37778.81 +/- 7281.54
# avg_path_length_m     : 55.98 +/- 9.55
# avg_progress_ratio    : 0.628 +/- 0.240
# avg_path_efficiency   : 0.510 +/- 0.217
# termination           : {'out_of_bounds': 34, 'goal': 6}
# benchmark_manifest    : benchmarks/offline_rebrac_worldcomp_final/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/worldcomp_critic_penalty_off_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_0p0/seed_42 --agent-file agent_step_00006528.pt --manifest benchmarks/offline_rebrac_worldcomp_final/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/worldcomp_critic_penalty_off_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_0p0/validation/seed_42/agent_step_00006528.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 15.0%
# avg_return            : -113.03 +/- 126.40
# avg_safety_cost       : 15.149 +/- 13.642
# avg_time_s            : 65.52 +/- 42.38
# avg_time_s_success    : 42.08
# avg_energy            : 46956.00 +/- 32357.31
# avg_path_length_m     : 62.86 +/- 28.23
# avg_progress_ratio    : 0.558 +/- 0.527
# avg_path_efficiency   : 0.500 +/- 0.288
# termination           : {'out_of_bounds': 33, 'goal': 6, 'timeout': 1}
# benchmark_manifest    : benchmarks/offline_rebrac_worldcomp_final/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/worldcomp_critic_penalty_off_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_0p0/seed_42 --agent-file agent_step_00009792.pt --manifest benchmarks/offline_rebrac_worldcomp_final/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/worldcomp_critic_penalty_off_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_0p0/validation/seed_42/agent_step_00009792.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 27.5%
# avg_return            : -110.09 +/- 139.91
# avg_safety_cost       : 20.219 +/- 16.847
# avg_time_s            : 71.65 +/- 46.05
# avg_time_s_success    : 60.13
# avg_energy            : 51299.17 +/- 35168.07
# avg_path_length_m     : 65.05 +/- 30.64
# avg_progress_ratio    : 0.596 +/- 0.580
# avg_path_efficiency   : 0.522 +/- 0.295
# termination           : {'out_of_bounds': 27, 'timeout': 2, 'goal': 11}
# benchmark_manifest    : benchmarks/offline_rebrac_worldcomp_final/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/worldcomp_critic_penalty_off_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_0p0/seed_42 --agent-file agent_step_00013056.pt --manifest benchmarks/offline_rebrac_worldcomp_final/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/worldcomp_critic_penalty_off_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_0p0/validation/seed_42/agent_step_00013056.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 55.0%
# avg_return            : -55.02 +/- 109.16
# avg_safety_cost       : 14.392 +/- 12.328
# avg_time_s            : 63.87 +/- 27.00
# avg_time_s_success    : 56.27
# avg_energy            : 45396.73 +/- 19463.53
# avg_path_length_m     : 60.61 +/- 24.78
# avg_progress_ratio    : 0.719 +/- 0.430
# avg_path_efficiency   : 0.616 +/- 0.281
# termination           : {'out_of_bounds': 18, 'goal': 22}
# benchmark_manifest    : benchmarks/offline_rebrac_worldcomp_final/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/worldcomp_critic_penalty_off_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_0p0/seed_42 --agent-file agent_step_00016320.pt --manifest benchmarks/offline_rebrac_worldcomp_final/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/worldcomp_critic_penalty_off_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_0p0/validation/seed_42/agent_step_00016320.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 60.0%
# avg_return            : -26.43 +/- 65.93
# avg_safety_cost       : 10.627 +/- 6.747
# avg_time_s            : 55.98 +/- 10.15
# avg_time_s_success    : 55.86
# avg_energy            : 39532.32 +/- 7248.17
# avg_path_length_m     : 53.33 +/- 6.05
# avg_progress_ratio    : 0.854 +/- 0.095
# avg_path_efficiency   : 0.696 +/- 0.114
# termination           : {'out_of_bounds': 16, 'goal': 24}
# benchmark_manifest    : benchmarks/offline_rebrac_worldcomp_final/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/worldcomp_critic_penalty_off_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_0p0/seed_42 --agent-file agent_step_00019584.pt --manifest benchmarks/offline_rebrac_worldcomp_final/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/worldcomp_critic_penalty_off_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_0p0/validation/seed_42/agent_step_00019584.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 60.0%
# avg_return            : -27.28 +/- 72.60
# avg_safety_cost       : 9.819 +/- 6.917
# avg_time_s            : 55.70 +/- 13.74
# avg_time_s_success    : 55.70
# avg_energy            : 39338.02 +/- 9695.85
# avg_path_length_m     : 54.26 +/- 11.17
# avg_progress_ratio    : 0.815 +/- 0.184
# avg_path_efficiency   : 0.673 +/- 0.162
# termination           : {'goal': 24, 'out_of_bounds': 16}
# benchmark_manifest    : benchmarks/offline_rebrac_worldcomp_final/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/worldcomp_critic_penalty_off_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_0p0/seed_42 --agent-file agent_step_00022848.pt --manifest benchmarks/offline_rebrac_worldcomp_final/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/worldcomp_critic_penalty_off_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_0p0/validation/seed_42/agent_step_00022848.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 87.5%
# avg_return            : 14.62 +/- 46.03
# avg_safety_cost       : 7.690 +/- 6.519
# avg_time_s            : 53.04 +/- 9.92
# avg_time_s_success    : 53.21
# avg_energy            : 37665.48 +/- 7092.04
# avg_path_length_m     : 51.12 +/- 6.72
# avg_progress_ratio    : 0.887 +/- 0.071
# avg_path_efficiency   : 0.757 +/- 0.112
# termination           : {'goal': 35, 'out_of_bounds': 5}
# benchmark_manifest    : benchmarks/offline_rebrac_worldcomp_final/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/worldcomp_critic_penalty_off_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_0p0/seed_42 --agent-file agent_step_00026112.pt --manifest benchmarks/offline_rebrac_worldcomp_final/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/worldcomp_critic_penalty_off_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_0p0/validation/seed_42/agent_step_00026112.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 80.0%
# avg_return            : -18.66 +/- 126.82
# avg_safety_cost       : 11.023 +/- 15.204
# avg_time_s            : 62.51 +/- 37.51
# avg_time_s_success    : 53.45
# avg_energy            : 44837.09 +/- 28780.38
# avg_path_length_m     : 58.44 +/- 28.53
# avg_progress_ratio    : 0.785 +/- 0.409
# avg_path_efficiency   : 0.687 +/- 0.250
# termination           : {'goal': 32, 'out_of_bounds': 7, 'timeout': 1}
# benchmark_manifest    : benchmarks/offline_rebrac_worldcomp_final/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/worldcomp_critic_penalty_off_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_0p0/seed_42 --agent-file agent_final.pt --manifest benchmarks/offline_rebrac_worldcomp_final/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/worldcomp_critic_penalty_off_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_0p0/validation/seed_42/agent_final.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 80.0%
# avg_return            : -18.66 +/- 126.82
# avg_safety_cost       : 11.023 +/- 15.204
# avg_time_s            : 62.51 +/- 37.51
# avg_time_s_success    : 53.45
# avg_energy            : 44837.09 +/- 28780.38
# avg_path_length_m     : 58.44 +/- 28.53
# avg_progress_ratio    : 0.785 +/- 0.409
# avg_path_efficiency   : 0.687 +/- 0.250
# termination           : {'goal': 32, 'out_of_bounds': 7, 'timeout': 1}
# benchmark_manifest    : benchmarks/offline_rebrac_worldcomp_final/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 - results/offline/rebrac/worldcomp_critic_penalty_off_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_0p0/validation/seed_42 checkpoints/offline/rebrac/worldcomp_critic_penalty_off_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_0p0/seed_42/trainer_state.json results/offline/rebrac/worldcomp_critic_penalty_off_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_0p0/selection/seed_42/selected_checkpoint.json results/offline/rebrac/worldcomp_critic_penalty_off_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_0p0/selection/seed_42/selected_agent_file.txt
# [write] selection: results/offline/rebrac/worldcomp_critic_penalty_off_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_0p0/selection/seed_42/selected_checkpoint.json
# [best] agent=agent_step_00022848.pt success=0.8750 return=14.6206
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/worldcomp_critic_penalty_off_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_0p0/seed_43 --agent-file agent_step_00003264.pt --manifest benchmarks/offline_rebrac_worldcomp_final/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/worldcomp_critic_penalty_off_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_0p0/validation/seed_43/agent_step_00003264.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 32.5%
# avg_return            : -77.22 +/- 104.84
# avg_safety_cost       : 9.398 +/- 5.999
# avg_time_s            : 59.26 +/- 21.46
# avg_time_s_success    : 43.64
# avg_energy            : 42281.10 +/- 17111.31
# avg_path_length_m     : 59.73 +/- 20.16
# avg_progress_ratio    : 0.578 +/- 0.616
# avg_path_efficiency   : 0.542 +/- 0.381
# termination           : {'out_of_bounds': 27, 'goal': 13}
# benchmark_manifest    : benchmarks/offline_rebrac_worldcomp_final/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/worldcomp_critic_penalty_off_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_0p0/seed_43 --agent-file agent_step_00006528.pt --manifest benchmarks/offline_rebrac_worldcomp_final/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/worldcomp_critic_penalty_off_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_0p0/validation/seed_43/agent_step_00006528.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 12.5%
# avg_return            : -133.83 +/- 117.68
# avg_safety_cost       : 15.049 +/- 8.479
# avg_time_s            : 72.55 +/- 36.90
# avg_time_s_success    : 47.28
# avg_energy            : 53446.33 +/- 30230.65
# avg_path_length_m     : 67.68 +/- 27.84
# avg_progress_ratio    : 0.482 +/- 0.629
# avg_path_efficiency   : 0.442 +/- 0.364
# termination           : {'out_of_bounds': 35, 'goal': 5}
# benchmark_manifest    : benchmarks/offline_rebrac_worldcomp_final/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/worldcomp_critic_penalty_off_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_0p0/seed_43 --agent-file agent_step_00009792.pt --manifest benchmarks/offline_rebrac_worldcomp_final/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/worldcomp_critic_penalty_off_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_0p0/validation/seed_43/agent_step_00009792.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 12.5%
# avg_return            : -117.94 +/- 106.13
# avg_safety_cost       : 16.167 +/- 11.049
# avg_time_s            : 67.24 +/- 32.38
# avg_time_s_success    : 41.82
# avg_energy            : 48622.79 +/- 25823.66
# avg_path_length_m     : 63.72 +/- 25.63
# avg_progress_ratio    : 0.611 +/- 0.515
# avg_path_efficiency   : 0.525 +/- 0.312
# termination           : {'out_of_bounds': 35, 'goal': 5}
# benchmark_manifest    : benchmarks/offline_rebrac_worldcomp_final/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/worldcomp_critic_penalty_off_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_0p0/seed_43 --agent-file agent_step_00013056.pt --manifest benchmarks/offline_rebrac_worldcomp_final/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/worldcomp_critic_penalty_off_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_0p0/validation/seed_43/agent_step_00013056.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 60.0%
# avg_return            : -29.94 +/- 67.93
# avg_safety_cost       : 14.067 +/- 11.085
# avg_time_s            : 57.65 +/- 11.17
# avg_time_s_success    : 56.81
# avg_energy            : 40868.85 +/- 7989.06
# avg_path_length_m     : 54.51 +/- 8.33
# avg_progress_ratio    : 0.868 +/- 0.069
# avg_path_efficiency   : 0.697 +/- 0.114
# termination           : {'goal': 24, 'out_of_bounds': 16}
# benchmark_manifest    : benchmarks/offline_rebrac_worldcomp_final/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/worldcomp_critic_penalty_off_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_0p0/seed_43 --agent-file agent_step_00016320.pt --manifest benchmarks/offline_rebrac_worldcomp_final/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/worldcomp_critic_penalty_off_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_0p0/validation/seed_43/agent_step_00016320.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 70.0%
# avg_return            : -10.43 +/- 64.76
# avg_safety_cost       : 8.727 +/- 7.437
# avg_time_s            : 53.48 +/- 10.55
# avg_time_s_success    : 53.65
# avg_energy            : 37767.22 +/- 7676.41
# avg_path_length_m     : 52.53 +/- 6.67
# avg_progress_ratio    : 0.818 +/- 0.142
# avg_path_efficiency   : 0.682 +/- 0.157
# termination           : {'goal': 28, 'out_of_bounds': 12}
# benchmark_manifest    : benchmarks/offline_rebrac_worldcomp_final/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/worldcomp_critic_penalty_off_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_0p0/seed_43 --agent-file agent_step_00019584.pt --manifest benchmarks/offline_rebrac_worldcomp_final/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/worldcomp_critic_penalty_off_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_0p0/validation/seed_43/agent_step_00019584.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 77.5%
# avg_return            : -3.62 +/- 61.21
# avg_safety_cost       : 10.756 +/- 10.276
# avg_time_s            : 55.58 +/- 11.72
# avg_time_s_success    : 54.76
# avg_energy            : 39412.61 +/- 8448.16
# avg_path_length_m     : 53.10 +/- 8.72
# avg_progress_ratio    : 0.875 +/- 0.081
# avg_path_efficiency   : 0.725 +/- 0.132
# termination           : {'goal': 31, 'out_of_bounds': 9}
# benchmark_manifest    : benchmarks/offline_rebrac_worldcomp_final/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/worldcomp_critic_penalty_off_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_0p0/seed_43 --agent-file agent_step_00022848.pt --manifest benchmarks/offline_rebrac_worldcomp_final/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/worldcomp_critic_penalty_off_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_0p0/validation/seed_43/agent_step_00022848.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 92.5%
# avg_return            : 7.53 +/- 83.60
# avg_safety_cost       : 10.926 +/- 12.155
# avg_time_s            : 58.68 +/- 24.99
# avg_time_s_success    : 54.97
# avg_energy            : 41863.93 +/- 19109.87
# avg_path_length_m     : 55.39 +/- 19.89
# avg_progress_ratio    : 0.859 +/- 0.270
# avg_path_efficiency   : 0.728 +/- 0.174
# termination           : {'goal': 37, 'out_of_bounds': 3}
# benchmark_manifest    : benchmarks/offline_rebrac_worldcomp_final/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/worldcomp_critic_penalty_off_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_0p0/seed_43 --agent-file agent_step_00026112.pt --manifest benchmarks/offline_rebrac_worldcomp_final/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/worldcomp_critic_penalty_off_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_0p0/validation/seed_43/agent_step_00026112.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 95.0%
# avg_return            : 24.23 +/- 40.22
# avg_safety_cost       : 7.503 +/- 8.473
# avg_time_s            : 53.17 +/- 11.20
# avg_time_s_success    : 52.42
# avg_energy            : 37953.86 +/- 8140.18
# avg_path_length_m     : 51.07 +/- 8.44
# avg_progress_ratio    : 0.906 +/- 0.008
# avg_path_efficiency   : 0.777 +/- 0.106
# termination           : {'goal': 38, 'out_of_bounds': 2}
# benchmark_manifest    : benchmarks/offline_rebrac_worldcomp_final/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/worldcomp_critic_penalty_off_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_0p0/seed_43 --agent-file agent_final.pt --manifest benchmarks/offline_rebrac_worldcomp_final/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/worldcomp_critic_penalty_off_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_0p0/validation/seed_43/agent_final.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 95.0%
# avg_return            : 24.23 +/- 40.22
# avg_safety_cost       : 7.503 +/- 8.473
# avg_time_s            : 53.17 +/- 11.20
# avg_time_s_success    : 52.42
# avg_energy            : 37953.86 +/- 8140.18
# avg_path_length_m     : 51.07 +/- 8.44
# avg_progress_ratio    : 0.906 +/- 0.008
# avg_path_efficiency   : 0.777 +/- 0.106
# termination           : {'goal': 38, 'out_of_bounds': 2}
# benchmark_manifest    : benchmarks/offline_rebrac_worldcomp_final/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 - results/offline/rebrac/worldcomp_critic_penalty_off_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_0p0/validation/seed_43 checkpoints/offline/rebrac/worldcomp_critic_penalty_off_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_0p0/seed_43/trainer_state.json results/offline/rebrac/worldcomp_critic_penalty_off_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_0p0/selection/seed_43/selected_checkpoint.json results/offline/rebrac/worldcomp_critic_penalty_off_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_0p0/selection/seed_43/selected_agent_file.txt
# [write] selection: results/offline/rebrac/worldcomp_critic_penalty_off_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_0p0/selection/seed_43/selected_checkpoint.json
# [best] agent=agent_final.pt success=0.9500 return=24.2307
#
# [cmd] env MODE=test PYTHON_BIN=python3 DEVICE=cuda BENCHMARK_KEY=single_u10_cross_tgt15 FLOW_PATH=wake_data/wake_v8_U1p00_Re150_D12p00_dx0p60_Ti5pct_1200f_roi.npy TASK_GEOMETRY=cross_stream TARGET_SPEED=1.5 OBJECTIVE=efficiency_v2 PROBE_LAYOUT=s0 HISTORY_LENGTH=4 DATASET_POLICY=worldcomp DATASET_EPISODES=1000 DATASET_SEED=0 COLLECT_WORKERS=8 ACTOR_PENALTY_COEFS=4.0 CRITIC_PENALTY_COEFS=0.0 BATCH_SIZE=256 DROP_LAST_BATCH=0 SAMPLING_MODE=shuffle_no_replacement HIDDEN_DIM=256 NUM_HIDDEN_LAYERS=3 ACTOR_LR=3e-4 CRITIC_LR=3e-4 GAMMA=0.99 TAU=0.005 POLICY_NOISE=0.2 NOISE_CLIP=0.5 POLICY_FREQ=2 GRAD_CLIP_NORM=10.0 NORMALIZER_EPS=1e-3 LOG_EVERY=1000 TRAIN_METRICS_WINDOW_FRACTION=0.25 EVAL_WORKERS=6 EVAL_WORKER_DEVICE=cpu VALIDATION_SEED=123 TEST_SEED=456 FORCE_REEVAL=0 SEEDS=42 43 TRAIN_EPOCHS=64 CHECKPOINT_EVERY_EPOCHS=8 VAL_MANIFEST_EPISODES=40 TEST_MANIFEST_EPISODES=100 MANIFEST_ROOT=benchmarks/offline_rebrac_worldcomp_final CHECKPOINT_ROOT=checkpoints/offline/rebrac/worldcomp_critic_penalty_off_probe RESULTS_ROOT=results/offline/rebrac/worldcomp_critic_penalty_off_probe USE_ASYMMETRIC_CRITIC=0 bash scripts/run_offline_rebrac_screen.sh
# [skip] manifest exists: benchmarks/offline_rebrac_worldcomp_final/test_100/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/worldcomp_critic_penalty_off_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_0p0/seed_42 --agent-file agent_step_00022848.pt --manifest benchmarks/offline_rebrac_worldcomp_final/test_100/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 456 --output-json results/offline/rebrac/worldcomp_critic_penalty_off_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_0p0/test/seed_42.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 100
# success_rate          : 92.0%
# avg_return            : 15.03 +/- 46.06
# avg_safety_cost       : 8.725 +/- 8.603
# avg_time_s            : 55.43 +/- 12.39
# avg_time_s_success    : 55.07
# avg_energy            : 39410.45 +/- 8857.10
# avg_path_length_m     : 51.52 +/- 8.47
# avg_progress_ratio    : 0.889 +/- 0.078
# avg_path_efficiency   : 0.755 +/- 0.118
# termination           : {'goal': 92, 'out_of_bounds': 8}
# benchmark_manifest    : benchmarks/offline_rebrac_worldcomp_final/test_100/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/worldcomp_critic_penalty_off_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_0p0/seed_43 --agent-file agent_final.pt --manifest benchmarks/offline_rebrac_worldcomp_final/test_100/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 456 --output-json results/offline/rebrac/worldcomp_critic_penalty_off_probe/worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_0p0/test/seed_43.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 100
# success_rate          : 90.0%
# avg_return            : 3.72 +/- 98.72
# avg_safety_cost       : 9.130 +/- 16.826
# avg_time_s            : 58.86 +/- 28.93
# avg_time_s_success    : 54.18
# avg_energy            : 42131.47 +/- 21565.81
# avg_path_length_m     : 54.04 +/- 20.54
# avg_progress_ratio    : 0.840 +/- 0.389
# avg_path_efficiency   : 0.738 +/- 0.199
# termination           : {'goal': 90, 'out_of_bounds': 8, 'timeout': 2}
# benchmark_manifest    : benchmarks/offline_rebrac_worldcomp_final/test_100/single_u10_cross_tgt15.json
#
# [cmd] env MODE=summarize PYTHON_BIN=python3 DEVICE=cuda BENCHMARK_KEY=single_u10_cross_tgt15 FLOW_PATH=wake_data/wake_v8_U1p00_Re150_D12p00_dx0p60_Ti5pct_1200f_roi.npy TASK_GEOMETRY=cross_stream TARGET_SPEED=1.5 OBJECTIVE=efficiency_v2 PROBE_LAYOUT=s0 HISTORY_LENGTH=4 DATASET_POLICY=worldcomp DATASET_EPISODES=1000 DATASET_SEED=0 COLLECT_WORKERS=8 ACTOR_PENALTY_COEFS=4.0 CRITIC_PENALTY_COEFS=0.0 BATCH_SIZE=256 DROP_LAST_BATCH=0 SAMPLING_MODE=shuffle_no_replacement HIDDEN_DIM=256 NUM_HIDDEN_LAYERS=3 ACTOR_LR=3e-4 CRITIC_LR=3e-4 GAMMA=0.99 TAU=0.005 POLICY_NOISE=0.2 NOISE_CLIP=0.5 POLICY_FREQ=2 GRAD_CLIP_NORM=10.0 NORMALIZER_EPS=1e-3 LOG_EVERY=1000 TRAIN_METRICS_WINDOW_FRACTION=0.25 EVAL_WORKERS=6 EVAL_WORKER_DEVICE=cpu VALIDATION_SEED=123 TEST_SEED=456 FORCE_REEVAL=0 SEEDS=42 43 TRAIN_EPOCHS=64 CHECKPOINT_EVERY_EPOCHS=8 VAL_MANIFEST_EPISODES=40 TEST_MANIFEST_EPISODES=100 MANIFEST_ROOT=benchmarks/offline_rebrac_worldcomp_final CHECKPOINT_ROOT=checkpoints/offline/rebrac/worldcomp_critic_penalty_off_probe RESULTS_ROOT=results/offline/rebrac/worldcomp_critic_penalty_off_probe USE_ASYMMETRIC_CRITIC=0 bash scripts/run_offline_rebrac_screen.sh
#
# [cmd] python3 - results/offline/rebrac/worldcomp_critic_penalty_off_probe checkpoints/offline/rebrac/worldcomp_critic_penalty_off_probe results/offline/rebrac/worldcomp_critic_penalty_off_probe/summaries 0.25
# [write] summary: results/offline/rebrac/worldcomp_critic_penalty_off_probe/summaries/overview.csv
# [write] summary: results/offline/rebrac/worldcomp_critic_penalty_off_probe/summaries/overview.json

# %% [markdown]
# ## 4. 结果与 Phase 1 主 finalist 对照

# %%
import json
from pathlib import Path

import pandas as pd

RESULTS_ROOT = Path("results/offline/rebrac/worldcomp_critic_penalty_off_probe")
DATASET_NAME = "worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000"
PAIR_TAG     = "actorb_4p0__criticb_0p0"
SEEDS        = os.environ["DEPLOYABLE_FINAL_SEEDS"].split()


def load_test_per_seed() -> pd.DataFrame:
    rows = []
    for seed in SEEDS:
        path = RESULTS_ROOT / DATASET_NAME / PAIR_TAG / "test" / f"seed_{seed}.json"
        if not path.exists():
            print(f"[warn] missing: {path}")
            continue
        payload = json.loads(path.read_text(encoding="utf-8"))
        rows.append({
            "seed": seed,
            "success_rate": payload["eval_success_rate"],
            "return": payload["eval_return"],
            "safety_cost": payload["eval_safety_cost"],
            "time_s": payload["eval_time_s"],
        })
    return pd.DataFrame(rows)


per_seed = load_test_per_seed()
print("[critic-penalty-off probe — per-seed test results]")
print(per_seed.to_string(index=False, float_format=lambda x: f"{x:.4f}" if isinstance(x, float) else str(x)))

if not per_seed.empty:
    print()
    probe_mean = per_seed["success_rate"].mean()
    probe_std  = per_seed["success_rate"].std() if len(per_seed) > 1 else 0.0
    probe_ret  = per_seed["return"].mean()

    # Phase 1 主 finalist 同 seeds (42/43) 的 test 成绩
    phase1_42 = 0.990
    phase1_43 = 0.930
    phase1_42_43_mean = (phase1_42 + phase1_43) / 2

    # Phase 1 5-seed mean (含 seed 44 outlier)
    phase1_5seed_mean = 0.928

    print("=" * 64)
    print("critic-penalty-off probe vs Phase 1 主 finalist 对照")
    print("-" * 64)
    print(f"{'config':<40}{'mean':>10}{'std':>10}")
    print("-" * 64)
    print(f"{'(β1=4.0, β2=0)  probe (2 seeds 42/43)':<40}{probe_mean:>10.4f}{probe_std:>10.4f}")
    print(f"{'(β1=4.0, β2=2)  Phase 1 (seeds 42/43)':<40}{phase1_42_43_mean:>10.4f}{'-':>10}")
    print(f"{'(β1=4.0, β2=2)  Phase 1 (5 seeds 42-46)':<40}{phase1_5seed_mean:>10.4f}{0.077:>10.4f}")
    print("=" * 64)
    print()

    delta_same_seeds = probe_mean - phase1_42_43_mean
    print(f"Δ vs Phase 1 同 seeds (42/43): {delta_same_seeds:+.4f} ({delta_same_seeds*100:+.1f}pp)")
    print()

    if abs(delta_same_seeds) <= 0.02:
        verdict = "情形 A：几乎一致 → Finding 1 机制猜想成立；Stage E critic-penalty-off 收口"
    elif probe_mean >= 0.88:
        verdict = "情形 B：略有下降 → dual penalty 在 worldcomp 上虽弱但非零；Stage E 仍需 5-seed ablation"
    else:
        verdict = "情形 C：显著下降 → Finding 1 机制猜想被证伪；需要 per-seed 复盘 Phase 1 critic_penalty_ratio"

    print(f"[probe 结论] {verdict}")
# Out:
# [critic-penalty-off probe — per-seed test results]
# seed  success_rate  return  safety_cost  time_s
#   42        0.9200 15.0299       8.7248 55.4270
#   43        0.9000  3.7178       9.1296 58.8550
#
# ================================================================
# critic-penalty-off probe vs Phase 1 主 finalist 对照
# ----------------------------------------------------------------
# config                                        mean       std
# ----------------------------------------------------------------
# (β1=4.0, β2=0)  probe (2 seeds 42/43)       0.9100    0.0141
# (β1=4.0, β2=2)  Phase 1 (seeds 42/43)       0.9600         -
# (β1=4.0, β2=2)  Phase 1 (5 seeds 42-46)     0.9280    0.0770
# ================================================================
#
# Δ vs Phase 1 同 seeds (42/43): -0.0500 (-5.0pp)
#
# [probe 结论] 情形 B：略有下降 → dual penalty 在 worldcomp 上虽弱但非零；Stage E 仍需 5-seed ablation

# %%
# overview summary（critic_penalty / target_q）
import csv

overview_path = RESULTS_ROOT / "summaries" / "overview.csv"
if overview_path.exists():
    with overview_path.open(encoding="utf-8") as fp:
        reader = csv.DictReader(fp)
        for row in reader:
            print(f"[overview] dataset={row['dataset']} pair={row['pair']} num_seeds={row['num_seeds']}")
            print(f"  mean_test_success_rate    = {float(row['mean_test_success_rate']):.4f}")
            print(f"  std_test_success_rate     = {float(row['std_test_success_rate']):.4f}")
            print(f"  mean_test_return          = {float(row['mean_test_return']):.3f}")
            print(f"  mean_critic_penalty       = {float(row['mean_critic_penalty']):.4f}  (β2=0 时 critic loss 中无 penalty 项；这只是 logging 量)")
            print(f"  mean_target_q             = {float(row['mean_target_q']):.3f}")
            penalty_ratio = float(row['mean_critic_penalty_ratio'])
            print(f"  mean_critic_penalty_ratio = {penalty_ratio:.4f}  (β2=0 → β2·ratio = 0，但 ratio 本身仍可与 Phase 1 比较)")
else:
    print(f"[warn] overview.csv missing at {overview_path}")
# Out:
# [overview] dataset=worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000 pair=actorb_4p0__criticb_0p0 num_seeds=2
#   mean_test_success_rate    = 0.9100
#   std_test_success_rate     = 0.0100
#   mean_test_return          = 9.374
#   mean_critic_penalty       = 0.0807  (β2=0 时 critic loss 中无 penalty 项；这只是 logging 量)
#   mean_target_q             = 22.297
#   mean_critic_penalty_ratio = 0.0037  (β2=0 → β2·ratio = 0，但 ratio 本身仍可与 Phase 1 比较)

# %% [markdown]
# ## 5. 报告写入清单
#
# 跑完上面 cell 后：
#
# 1. 把 probe 数字 + 情形判定写入 [docs/rebrac_experiment_report.md](../docs/rebrac_experiment_report.md) §7.10.6 Finding 1 末尾（作为 "Finding 1 已被独立 probe 验证/证伪" 的补强）。
# 2. 在 [docs/rebrac_experiment_plan.md](../docs/rebrac_experiment_plan.md) §6.5.3 末尾的 "可选追加：critic-penalty-off probe" 段落标记为 `【已完成】`。
# 3. 根据情形：
#    - **情形 A**：Stage E ablation 中 critic-penalty-off 这一格不再需要 5-seed 复跑，直接引用 probe 结果作为收口；
#    - **情形 B**：Stage E 仍跑 5-seed `(β1=4.0, β2=0)` ablation；
#    - **情形 C**：触发 Phase 1 per-seed `mean_critic_penalty_ratio` 复盘，重写 Finding 1 章节。
