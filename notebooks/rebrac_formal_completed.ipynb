# %%
# !lscpu
# Out:
# Architecture:                x86_64
#   CPU op-mode(s):            32-bit, 64-bit
#   Address sizes:             46 bits physical, 48 bits virtual
#   Byte Order:                Little Endian
# CPU(s):                      12
#   On-line CPU(s) list:       0-11
# Vendor ID:                   GenuineIntel
#   Model name:                Intel(R) Xeon(R) CPU @ 2.20GHz
#     CPU family:              6
#     Model:                   85
#     Thread(s) per core:      2
#     Core(s) per socket:      6
#     Socket(s):               1
#     Stepping:                7
#     BogoMIPS:                4400.56
#     Flags:                   fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pg
#                              e mca cmov pat pse36 clflush mmx fxsr sse sse2 ss h
#                              t syscall nx pdpe1gb rdtscp lm constant_tsc rep_goo
#                              d nopl xtopology nonstop_tsc cpuid tsc_known_freq p
#                              ni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2ap
#                              ic movbe popcnt aes xsave avx f16c rdrand hyperviso
#                              r lahf_lm abm 3dnowprefetch ssbd ibrs ibpb stibp ib
#                              rs_enhanced fsgsbase tsc_adjust bmi1 hle avx2 smep
#                              bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed a
#                              dx smap clflushopt clwb avx512cd avx512bw avx512vl
#                              xsaveopt xsavec xgetbv1 xsaves arat avx512_vnni md_
#                              clear arch_capabilities
# Virtualization features:
#   Hypervisor vendor:         KVM
#   Virtualization type:       full
# Caches (sum of all):
#   L1d:                       192 KiB (6 instances)
#   L1i:                       192 KiB (6 instances)
#   L2:                        6 MiB (6 instances)
#   L3:                        38.5 MiB (1 instance)
# NUMA:
#   NUMA node(s):              1
#   NUMA node0 CPU(s):         0-11
# Vulnerabilities:
#   Gather data sampling:      Not affected
#   Indirect target selection: Vulnerable
#   Itlb multihit:             Not affected
#   L1tf:                      Not affected
#   Mds:                       Not affected
#   Meltdown:                  Not affected
#   Mmio stale data:           Vulnerable
#   Reg file data sampling:    Not affected
#   Retbleed:                  Vulnerable
#   Spec rstack overflow:      Not affected
#   Spec store bypass:         Vulnerable
#   Spectre v1:                Vulnerable: __user pointer sanitization and usercop
#                              y barriers only; no swapgs barriers
#   Spectre v2:                Vulnerable; IBPB: disabled; STIBP: disabled; PBRSB-
#                              eIBRS: Vulnerable; BHI: Vulnerable
#   Srbds:                     Not affected
#   Tsa:                       Not affected
#   Tsx async abort:           Vulnerable
#   Vmscape:                   Not affected

# %%
# !nvidia-smi
# Out:
# Fri Apr 24 09:46:25 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA L4                      Off |   00000000:00:03.0 Off |                    0 |
# | N/A   41C    P8             13W /   72W |       0MiB /  23034MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
import torch
print(f"PyTorch: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"cuDNN version: {torch.backends.cudnn.version()}")
# Out:
# PyTorch: 2.10.0+cu128
# CUDA available: True
# cuDNN version: 91002

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/"MyDrive"/"Colab Notebooks"/"new_offRL"/"rl_v2_5"
# Out:
# /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5

# %% [markdown]
# # ReBRAC formal Stage C —— 5-seed 正式复核
#
# **定位**：[rebrac_experiment_plan.md §6.4](../docs/rebrac_experiment_plan.md) Stage C 的正式执行入口。
#
# **前置**：
#
# - Stage B0 确认 `TRAIN_EPOCHS=64` 足够（[report §5](../docs/rebrac_experiment_report.md)）。
# - Stage B 已完成；screening winner `(β1=4.0, β2=2.0)` 在两个 `crosscomp` 数据集上都显著超越 TD3BC phase0c（[report §6](../docs/rebrac_experiment_report.md)）。
#
# **目标**：把 Stage B 的 3-seed screening 结论升级到 5-seed 正式结果，且与 TD3BC phase0c Stage C 的正式成绩同口径可比。
#
# **Finalist（由 Stage B 锁定）**：
#
# - **主 finalist**：`(β1=4.0, β2=2.0)`，在 `crosscomp-1000` 和 `crosscomp-2000` 上共用。
# - **ep2000 backup finalist**：`(β1=4.0, β2=1.0)`——仅在 `crosscomp-2000` 上追加 5-seed，作为 主 finalist 在更多 seed 下若方差放大的接盘配置。
#
# **协议变化**（相对 Stage B）：
#
# - seeds：`42 / 43 / 44 / 45 / 46`（新增 45/46）；
# - test manifest 提升到 **100 episodes**（Stage B 是 40）；
# - val manifest 保持 40 episodes（只用来挑 ckpt，不需要更大）；
# - CHECKPOINT_ROOT / RESULTS_ROOT 完全独立 Stage B 的目录，避免语义混淆；
# - 因为 Stage B 的 finalist winner 已有 3 seeds × 2 dataset 的数据，本 notebook 不重复 β1×β2 全网格——只跑 finalist 网格，共 15 runs。
#
# **成功判据**：
#
# 1. ep1000 主 finalist `mean_test_success_rate ≥ 0.672`（TD3BC phase0c `α=0.25` 正式成绩）；
# 2. ep2000 至少一个 finalist `mean_test_success_rate ≥ 0.75`；
# 3. 所有 finalist `std_test_success_rate ≤ 0.10`。
#
# 任一失败将触发 plan §6.4 末尾的分类分流。

# %% [markdown]
# ## 0. 共享环境配置
#
# Stage C 独立输出路径：
#
# - `checkpoints/offline/rebrac/formal/`
# - `results/offline/rebrac/formal/`
# - `results/offline/rebrac/formal/summaries/overview.csv`
#
# Manifest 复用 Stage B 的同 BENCHMARK_KEY 目录树（`benchmarks/offline_rebrac_screen/`），但 test 走新的 `test_100/` 子目录。

# %%
import os

# —— 通用（与 Stage B / Stage B0 对齐）——
os.environ["PYTHON_BIN"]         = "python3"
os.environ["DEVICE"]             = "cuda"
os.environ["EVAL_WORKERS"]       = "6"
os.environ["EVAL_WORKER_DEVICE"] = "cpu"

# —— Stage C 独有：5 seeds，更大 test manifest ——
os.environ["SEEDS"]                   = "42 43 44 45 46"
os.environ["TRAIN_EPOCHS"]            = "64"
os.environ["CHECKPOINT_EVERY_EPOCHS"] = "8"
os.environ["VAL_MANIFEST_EPISODES"]   = "40"
os.environ["TEST_MANIFEST_EPISODES"]  = "100"

# —— 输出目录独立 ——
os.environ["CHECKPOINT_ROOT"] = "checkpoints/offline/rebrac/formal"
os.environ["RESULTS_ROOT"]    = "results/offline/rebrac/formal"
os.environ["SUMMARY_ROOT"]    = "results/offline/rebrac/formal/summaries"

# 其余默认：BENCHMARK_KEY=single_u10_cross_tgt15,
# BASELINE_POLICY=crosscomp, PROBE_LAYOUT=s0, HISTORY_LENGTH=4,
# TASK_GEOMETRY=cross_stream, TARGET_SPEED=1.5, OBJECTIVE=efficiency_v2,
# SAMPLING_MODE=shuffle_no_replacement, BATCH_SIZE=256,
# critic_layernorm=on, actor_layernorm=off, normalize_q=on

# %% [markdown]
# ## 1. 生成 manifest
#
# val_40 manifest 已经在 Stage B 时生成，会被 skip；test_100 是 Stage C 新增。
#
# 这里需要先**暂时用 finalist 网格 A 的变量**来驱动 manifest 生成（脚本只读 `VAL_MANIFEST_EPISODES / TEST_MANIFEST_EPISODES`，不依赖网格内容）。

# %%
os.environ["MODE"]                 = "manifests"
os.environ["DATASET_EPISODES"]     = "1000 2000"
os.environ["ACTOR_PENALTY_COEFS"]  = "4.0"
os.environ["CRITIC_PENALTY_COEFS"] = "2.0"
# !bash scripts/run_offline_rebrac_screen.sh
# Out:
# [cmd] python3 -m scripts.generate_standard_benchmarks --benchmarks single_u10_cross_tgt15 --episodes 40 --output-dir benchmarks/offline_rebrac_screen/val_40
# [done] single_u10_cross_tgt15 -> benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.generate_standard_benchmarks --benchmarks single_u10_cross_tgt15 --episodes 100 --output-dir benchmarks/offline_rebrac_screen/test_100
# [done] single_u10_cross_tgt15 -> benchmarks/offline_rebrac_screen/test_100/single_u10_cross_tgt15.json

# %% [markdown]
# ## 2. 离线数据（应已由 phase0c / Stage B0 / Stage B 产生）
#
# `offline_data/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep{1000,2000}/transitions.npz` 两份数据集应当都在，会被 skip。

# %%
os.environ["MODE"]             = "collect"
os.environ["DATASET_EPISODES"] = "1000 2000"
# !bash scripts/run_offline_rebrac_screen.sh
# Out:
# [cmd] python3 -m scripts.collect_offline_data --policy crosscomp --flow wake_data/wake_v8_U1p00_Re150_D12p00_dx0p60_Ti5pct_1200f_roi.npy --probe-layout s0 --history-length 4 --task-geometry cross_stream --target-speed 1.5 --objective efficiency_v2 --episodes 1000 --seed 0 --num-workers 8 --output-dir offline_data/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000
# [collect] ep=125/1000 transitions=18777 success_rate=86.40% elapsed=207.1s
# [collect] ep=250/1000 transitions=38614 success_rate=89.20% elapsed=272.1s
# [collect] ep=375/1000 transitions=57162 success_rate=87.20% elapsed=272.1s
# [collect] ep=500/1000 transitions=75975 success_rate=86.40% elapsed=272.1s
# [collect] ep=625/1000 transitions=93993 success_rate=85.44% elapsed=272.1s
# [collect] ep=750/1000 transitions=113991 success_rate=86.27% elapsed=290.4s
# [collect] ep=875/1000 transitions=133260 success_rate=86.74% elapsed=290.4s
# [collect] ep=1000/1000 transitions=152683 success_rate=87.00% elapsed=290.4s
#
# [done] Saved 152683 transitions to offline_data/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/transitions.npz
#   policy=crosscomp  obs_dim=40  action_dim=2
#   episodes=1000  success_rate=87.00%
#   mean_return=-36.48 +/- 39.19
#
# [cmd] python3 -m scripts.collect_offline_data --policy crosscomp --flow wake_data/wake_v8_U1p00_Re150_D12p00_dx0p60_Ti5pct_1200f_roi.npy --probe-layout s0 --history-length 4 --task-geometry cross_stream --target-speed 1.5 --objective efficiency_v2 --episodes 2000 --seed 0 --num-workers 8 --output-dir offline_data/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000
# [collect] ep=250/2000 transitions=38614 success_rate=89.20% elapsed=568.2s
# [collect] ep=500/2000 transitions=75975 success_rate=86.40% elapsed=568.2s
# [collect] ep=750/2000 transitions=113991 success_rate=86.27% elapsed=568.2s
# [collect] ep=1000/2000 transitions=152683 success_rate=87.00% elapsed=568.2s
# [collect] ep=1250/2000 transitions=190798 success_rate=87.68% elapsed=568.2s
# [collect] ep=1500/2000 transitions=229234 success_rate=88.27% elapsed=568.2s
# [collect] ep=1750/2000 transitions=267574 success_rate=88.51% elapsed=568.2s
# [collect] ep=2000/2000 transitions=304967 success_rate=88.55% elapsed=568.2s
#
# [done] Saved 304967 transitions to offline_data/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/transitions.npz
#   policy=crosscomp  obs_dim=40  action_dim=2
#   episodes=2000  success_rate=88.55%
#   mean_return=-33.89 +/- 38.34

# %% [markdown]
# ## 2.5 复用 Stage B 已产出的训练 + val 结果（9 个 seed）
#
# Stage B 和 Stage C 的训练代码、超参、RNG 捕获完全一致，在同 `(dataset, pair, seed)` 下训练得到的 agent 权重是 bit-identical 的。因此对以下 9 个 seed，不需要在 Stage C 重新训练：
#
# - `crosscomp-1000 (β1=4.0, β2=2.0)` × seeds 42/43/44
# - `crosscomp-2000 (β1=4.0, β2=2.0)` × seeds 42/43/44
# - `crosscomp-2000 (β1=4.0, β2=1.0)` × seeds 42/43/44
#
# 下面这段 cell 会把 Stage B 对应目录**物理拷贝**（不是 symlink，因为 Google Drive/drivefs 下 `os.symlink` 不可靠）到 Stage C 的独立 `CHECKPOINT_ROOT` / `RESULTS_ROOT` 下。拷贝一次的代价是 Drive→Drive 的几百个小文件同步（约 1–2 分钟），换回来的是：
#
# - `train_one` 识别到 `trainer_state.json + agent_final.pt` 存在 → **9 个训练全部 skip**；
# - `validate_one` 识别到每个 `agent_step_*.json` 存在 → **72 个 val checkpoint 评估全部 skip**；
# - `select_best_checkpoint` 按 Stage B 搬过来的 val 重新选 ckpt（结果与 Stage B 一致）；
# - `test/` 不复用——100-ep manifest 是 Stage C 新增的，所有 15 个 seed 的 test 都要重新跑。
#
# **幂等性**：`shutil.copytree(..., dirs_exist_ok=True)` 并且用 `agent_final.pt` 作为完成标记，重复执行不会重拷已有数据。
#
# **回退**：如果 Stage B 目录不存在（干净环境、别人的机器等），此 cell 是 noop，后续训练会照常跑满 15 个 run。

# %%
import os
import shutil
from pathlib import Path

STAGE_B_CHECKPOINT_ROOT = Path("checkpoints/offline/rebrac/screening")
STAGE_B_RESULTS_ROOT    = Path("results/offline/rebrac/screening")
STAGE_C_CHECKPOINT_ROOT = Path(os.environ["CHECKPOINT_ROOT"])
STAGE_C_RESULTS_ROOT    = Path(os.environ["RESULTS_ROOT"])

# 复用的 9 个 (dataset, pair, seed)：Stage B 已训练并验证过的 finalist × seeds 42/43/44。
# test/ 不复用（Stage C 的 test manifest 是新 100-ep，必须重跑）。
REUSE_TARGETS = [
    ("crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000",
     "actorb_4p0__criticb_2p0", seed) for seed in ("42", "43", "44")
] + [
    ("crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000",
     "actorb_4p0__criticb_2p0", seed) for seed in ("42", "43", "44")
] + [
    ("crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000",
     "actorb_4p0__criticb_1p0", seed) for seed in ("42", "43", "44")
]

def _copy_if_exists(src: Path, dst: Path, kind: str) -> str:
    if not src.exists():
        return f"[miss]    {kind:<11} {src}  (Stage B 未产出；Stage C 将重新跑)"
    # 对 checkpoint 目录，用 agent_final.pt 作为训练完成标记，避免复用半成品
    if kind == "checkpoint" and not (src / "agent_final.pt").exists():
        return f"[partial] {kind:<11} {src}  (缺 agent_final.pt；Stage C 将重新训练)"
    dst.parent.mkdir(parents=True, exist_ok=True)
    shutil.copytree(src, dst, dirs_exist_ok=True)
    return f"[ok]      {kind:<11} {src} -> {dst}"

for dataset, pair, seed in REUSE_TARGETS:
    ck_src = STAGE_B_CHECKPOINT_ROOT / dataset / pair / f"seed_{seed}"
    ck_dst = STAGE_C_CHECKPOINT_ROOT / dataset / pair / f"seed_{seed}"
    print(_copy_if_exists(ck_src, ck_dst, "checkpoint"))

    val_src = STAGE_B_RESULTS_ROOT / dataset / pair / "validation" / f"seed_{seed}"
    val_dst = STAGE_C_RESULTS_ROOT / dataset / pair / "validation" / f"seed_{seed}"
    print(_copy_if_exists(val_src, val_dst, "validation"))

print()
print("下面 §3 / §4 的 train_one 会对上述 seed 识别到 trainer_state.json + agent_final.pt，直接 skip。")
print("如果上面出现 [miss] / [partial]，对应 seed 会照常重新训练，不会影响结果正确性。")
# Out:
# [ok]      checkpoint  checkpoints/offline/rebrac/screening/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_42 -> checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_42
# [ok]      validation  results/offline/rebrac/screening/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_42 -> results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_42
# [ok]      checkpoint  checkpoints/offline/rebrac/screening/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_43 -> checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_43
# [ok]      validation  results/offline/rebrac/screening/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_43 -> results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_43
# [ok]      checkpoint  checkpoints/offline/rebrac/screening/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_44 -> checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_44
# [ok]      validation  results/offline/rebrac/screening/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_44 -> results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_44
# [ok]      checkpoint  checkpoints/offline/rebrac/screening/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/seed_42 -> checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/seed_42
# [ok]      validation  results/offline/rebrac/screening/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/validation/seed_42 -> results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/validation/seed_42
# [ok]      checkpoint  checkpoints/offline/rebrac/screening/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/seed_43 -> checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/seed_43
# [ok]      validation  results/offline/rebrac/screening/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/validation/seed_43 -> results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/validation/seed_43
# [ok]      checkpoint  checkpoints/offline/rebrac/screening/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/seed_44 -> checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/seed_44
# [ok]      validation  results/offline/rebrac/screening/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/validation/seed_44 -> results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/validation/seed_44
# [ok]      checkpoint  checkpoints/offline/rebrac/screening/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_1p0/seed_42 -> checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_1p0/seed_42
# [ok]      validation  results/offline/rebrac/screening/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_1p0/validation/seed_42 -> results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_1p0/validation/seed_42
# [ok]      checkpoint  checkpoints/offline/rebrac/screening/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_1p0/seed_43 -> checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_1p0/seed_43
# [ok]      validation  results/offline/rebrac/screening/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_1p0/validation/seed_43 -> results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_1p0/validation/seed_43
# [ok]      checkpoint  checkpoints/offline/rebrac/screening/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_1p0/seed_44 -> checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_1p0/seed_44
# [ok]      validation  results/offline/rebrac/screening/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_1p0/validation/seed_44 -> results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_1p0/validation/seed_44
#
# 下面 §3 / §4 的 train_one 会对上述 seed 识别到 trainer_state.json + agent_final.pt，直接 skip。
# 如果上面出现 [miss] / [partial]，对应 seed 会照常重新训练，不会影响结果正确性。

# %% [markdown]
# ## 3. 批 A 训练：主 finalist `(β1=4.0, β2=2.0)` on `crosscomp-{1000, 2000}` × 5 seeds
#
# **网格展开**：2 datasets × 1 β1 × 1 β2 × 5 seeds = **10 runs**；其中 seeds 42/43/44 在 §2.5 已从 Stage B 复用，**本 cell 实际只新训 seeds 45/46 × 2 datasets = 4 runs**。
#
# **`MODE=train`**：只做训练，不走 validate / test / summarize。validate + test + summarize 合并到 §4.5 批 A/B 训练都完成后统一跑——这样避免批 A 先写一份只含自己的 `overview.csv`、批 B 跑完再覆写的中间态，也能防止 `run_validate` / `run_test` 在网格里误扫到 Stage C finalist 之外的格子（详见 §4.5）。
#
# 每个新训的 seed 产出 8 个 `agent_step_*.pt` + `agent_final.pt`。`train_one` 的 skip 条件是 `trainer_state.json` 与 `agent_final.pt` 同时存在——只要 §2.5 的 copytree 对该 seed 报 `[ok]`，下面就会立刻 `[skip]`。

# %%
os.environ["MODE"]                 = "train"
os.environ["DATASET_EPISODES"]     = "1000 2000"
os.environ["ACTOR_PENALTY_COEFS"]  = "4.0"
os.environ["CRITIC_PENALTY_COEFS"] = "2.0"
# !bash scripts/run_offline_rebrac_screen.sh
# Out:
# [skip] manifest exists: benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json
# [skip] manifest exists: benchmarks/offline_rebrac_screen/test_100/single_u10_cross_tgt15.json
# [skip] dataset exists: offline_data/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/transitions.npz
# [skip] trained run exists: checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_42
# [skip] trained run exists: checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_43
# [skip] trained run exists: checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_44
#
# [cmd] python3 -m scripts.train_offline --algo rebrac --offline-data offline_data/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/transitions.npz --flow wake_data/wake_v8_U1p00_Re150_D12p00_dx0p60_Ti5pct_1200f_roi.npy --manifest benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json --probe-layout s0 --history-length 4 --task-geometry cross_stream --target-speed 1.5 --objective efficiency_v2 --sampling-mode shuffle_no_replacement --num-epochs 64 --total-steps 38208 --batch-size 256 --hidden-dim 256 --num-hidden-layers 3 --actor-lr 3e-4 --critic-lr 3e-4 --gamma 0.99 --tau 0.005 --actor-penalty-coef 4.0 --critic-penalty-coef 2.0 --policy-noise 0.2 --noise-clip 0.5 --policy-freq 2 --grad-clip-norm 10.0 --normalizer-eps 1e-3 --eval-every 0 --checkpoint-every 4776 --skip-final-eval --log-every 1000 --critic-layernorm --no-actor-layernorm --save-dir checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_45 --seed 45 --device cuda
# [offline] algo=rebrac transitions=152683 obs_dim=40 action_dim=2 protocol=deployable tensor_replay=on eval_workers=1 sampling=shuffle_no_replacement total_steps=38208
# [train] step=1 epoch=1 epoch_step=1 q=-0.769 critic=86.676 actor=4.602 bc=0.901 lambda=1.300 critic_pen=1.014
# [train] step=1000 epoch=2 epoch_step=403 q=-3.582 critic=1.539 actor=0.858 bc=0.053 lambda=0.180 critic_pen=0.137
# [train] step=2000 epoch=4 epoch_step=209 q=-2.686 critic=34.964 actor=0.388 bc=0.029 lambda=0.102 critic_pen=0.099
# [train] step=3000 epoch=6 epoch_step=15 q=-1.487 critic=6.795 actor=0.330 bc=0.056 lambda=0.072 critic_pen=0.086
# [train] step=4000 epoch=7 epoch_step=418 q=-2.827 critic=4.766 actor=0.239 bc=0.018 lambda=0.059 critic_pen=0.080
# [train] step=5000 epoch=9 epoch_step=224 q=1.276 critic=5.393 actor=0.008 bc=0.016 lambda=0.044 critic_pen=0.076
# [train] step=6000 epoch=11 epoch_step=30 q=3.413 critic=5.980 actor=0.003 bc=0.032 lambda=0.037 critic_pen=0.083
# [train] step=7000 epoch=12 epoch_step=433 q=0.780 critic=4.067 actor=0.103 bc=0.032 lambda=0.035 critic_pen=0.091
# [train] step=8000 epoch=14 epoch_step=239 q=0.259 critic=2.684 actor=0.006 bc=0.004 lambda=0.033 critic_pen=0.090
# [train] step=9000 epoch=16 epoch_step=45 q=2.860 critic=1.795 actor=-0.027 bc=0.014 lambda=0.029 critic_pen=0.093
# [train] step=10000 epoch=17 epoch_step=448 q=4.583 critic=2.403 actor=-0.059 bc=0.017 lambda=0.027 critic_pen=0.080
# [train] step=11000 epoch=19 epoch_step=254 q=-3.300 critic=3.447 actor=0.144 bc=0.011 lambda=0.030 critic_pen=0.088
# [train] step=12000 epoch=21 epoch_step=60 q=-1.087 critic=3.446 actor=0.146 bc=0.029 lambda=0.027 critic_pen=0.096
# [train] step=13000 epoch=22 epoch_step=463 q=-5.759 critic=2.864 actor=0.349 bc=0.047 lambda=0.028 critic_pen=0.082
# [train] step=14000 epoch=24 epoch_step=269 q=1.359 critic=3.307 actor=0.062 bc=0.024 lambda=0.025 critic_pen=0.076
line_data/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/transitions.npz --flow wake_data/wake_v8_U1p00_Re150_D12p00_dx0p60_Ti5pct_1200f_roi.npy --manifest benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json --probe-layout s0 --history-length 4 --task-geometry cross_stream --target-speed 1.5 --objective efficiency_v2 --sampling-mode shuffle_no_replacement --num-epochs 64 --total-steps 38208 --batch-size 256 --hidden-dim 256 --num-hidden-layers 3 --actor-lr 3e-4 --critic-lr 3e-4 --gamma 0.99 --tau 0.005 --actor-penalty-coef 4.0 --critic-penalty-coef 2.0 --policy-noise 0.2 --noise-clip 0.5 --policy-freq 2 --grad-clip-norm 10.0 --normalizer-eps 1e-3 --eval-every 0 --checkpoint-every 4776 --skip-final-eval --log-every 1000 --critic-layernorm --no-actor-layernorm --save-dir checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_46 --seed 46 --device cuda
# [offline] algo=rebrac transitions=152683 obs_dim=40 action_dim=2 protocol=deployable tensor_replay=on eval_workers=1 sampling=shuffle_no_replacement total_steps=38208
# [train] step=1 epoch=1 epoch_step=1 q=-1.130 critic=9.207 actor=4.654 bc=0.913 lambda=0.885 critic_pen=0.966
# [train] step=1000 epoch=2 epoch_step=403 q=-4.610 critic=27.026 actor=0.919 bc=0.030 lambda=0.174 critic_pen=0.118
# [train] step=2000 epoch=4 epoch_step=209 q=-4.024 critic=21.022 actor=0.505 bc=0.015 lambda=0.110 critic_pen=0.074
# [train] step=3000 epoch=6 epoch_step=15 q=-2.768 critic=9.943 actor=0.383 bc=0.046 lambda=0.072 critic_pen=0.102
# [train] step=4000 epoch=7 epoch_step=418 q=-5.458 critic=3.593 actor=0.395 bc=0.009 lambda=0.066 critic_pen=0.080
# [train] step=5000 epoch=9 epoch_step=224 q=-3.373 critic=4.178 actor=0.290 bc=0.031 lambda=0.050 critic_pen=0.089
# [train] step=6000 epoch=11 epoch_step=30 q=-5.710 critic=3.111 actor=0.321 bc=0.013 lambda=0.047 critic_pen=0.094
# [train] step=7000 epoch=12 epoch_step=433 q=-6.436 critic=1.933 actor=0.284 bc=0.004 lambda=0.041 critic_pen=0.087
# [train] step=8000 epoch=14 epoch_step=239 q=2.150 critic=3.883 actor=0.041 bc=0.028 lambda=0.032 critic_pen=0.098
# [train] step=9000 epoch=16 epoch_step=45 q=-5.520 critic=2.947 actor=0.323 bc=0.034 lambda=0.034 critic_pen=0.085
# [train] step=10000 epoch=17 epoch_step=448 q=-1.693 critic=2.035 actor=0.099 bc=0.012 lambda=0.030 critic_pen=0.069
# [train] step=11000 epoch=19 epoch_step=254 q=-1.221 critic=2.640 actor=0.094 bc=0.015 lambda=0.028 critic_pen=0.079
# [train] step=12000 epoch=21 epoch_step=60 q=-2.517 critic=2.894 actor=0.218 bc=0.037 lambda=0.027 critic_pen=0.090
# [train] step=13000 epoch=22 epoch_step=463 q=-5.247 critic=2.381 actor=0.320 bc=0.044 lambda=0.028 critic_pen=0.094
line_data/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/transitions.npz
# [skip] trained run exists: checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/seed_42
# [skip] trained run exists: checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/seed_43
# [skip] trained run exists: checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/seed_44
#
# [cmd] python3 -m scripts.train_offline --algo rebrac --offline-data offline_data/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/transitions.npz --flow wake_data/wake_v8_U1p00_Re150_D12p00_dx0p60_Ti5pct_1200f_roi.npy --manifest benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json --probe-layout s0 --history-length 4 --task-geometry cross_stream --target-speed 1.5 --objective efficiency_v2 --sampling-mode shuffle_no_replacement --num-epochs 64 --total-steps 76288 --batch-size 256 --hidden-dim 256 --num-hidden-layers 3 --actor-lr 3e-4 --critic-lr 3e-4 --gamma 0.99 --tau 0.005 --actor-penalty-coef 4.0 --critic-penalty-coef 2.0 --policy-noise 0.2 --noise-clip 0.5 --policy-freq 2 --grad-clip-norm 10.0 --normalizer-eps 1e-3 --eval-every 0 --checkpoint-every 9536 --skip-final-eval --log-every 1000 --critic-layernorm --no-actor-layernorm --save-dir checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/seed_45 --seed 45 --device cuda
# [offline] algo=rebrac transitions=304967 obs_dim=40 action_dim=2 protocol=deployable tensor_replay=on eval_workers=1 sampling=shuffle_no_replacement total_steps=76288
# [train] step=1 epoch=1 epoch_step=1 q=-0.789 critic=50.024 actor=4.710 bc=0.927 lambda=1.268 critic_pen=1.019
# [train] step=1000 epoch=1 epoch_step=1000 q=-3.225 critic=1.888 actor=0.763 bc=0.050 lambda=0.174 critic_pen=0.123
# [train] step=2000 epoch=2 epoch_step=808 q=-2.244 critic=26.019 actor=0.385 bc=0.041 lambda=0.098 critic_pen=0.111
# [train] step=3000 epoch=3 epoch_step=616 q=-1.210 critic=11.965 actor=0.167 bc=0.020 lambda=0.070 critic_pen=0.082
# [train] step=4000 epoch=4 epoch_step=424 q=-1.130 critic=8.265 actor=0.313 bc=0.062 lambda=0.058 critic_pen=0.096
# [train] step=5000 epoch=5 epoch_step=232 q=0.979 critic=4.151 actor=-0.001 bc=0.011 lambda=0.045 critic_pen=0.076
# [train] step=6000 epoch=6 epoch_step=40 q=-2.637 critic=2.999 actor=0.173 bc=0.014 lambda=0.044 critic_pen=0.082
# [train] step=7000 epoch=6 epoch_step=1040 q=-0.572 critic=4.142 actor=0.121 bc=0.025 lambda=0.037 critic_pen=0.091
# [train] step=8000 epoch=7 epoch_step=848 q=-1.538 critic=3.981 actor=0.113 bc=0.015 lambda=0.035 critic_pen=0.079
# [train] step=9000 epoch=8 epoch_step=656 q=0.834 critic=3.592 actor=-0.002 bc=0.006 lambda=0.031 critic_pen=0.078
# [train] step=10000 epoch=9 epoch_step=464 q=2.524 critic=3.436 actor=0.103 bc=0.044 lambda=0.029 critic_pen=0.095
# [train] step=11000 epoch=10 epoch_step=272 q=-0.389 critic=1.999 actor=0.036 bc=0.006 lambda=0.028 critic_pen=0.085
# [train] step=12000 epoch=11 epoch_step=80 q=-0.169 critic=3.120 actor=0.134 bc=0.032 lambda=0.027 critic_pen=0.102
ake_data/wake_v8_U1p00_Re150_D12p00_dx0p60_Ti5pct_1200f_roi.npy --manifest benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json --probe-layout s0 --history-length 4 --task-geometry cross_stream --target-speed 1.5 --objective efficiency_v2 --sampling-mode shuffle_no_replacement --num-epochs 64 --total-steps 76288 --batch-size 256 --hidden-dim 256 --num-hidden-layers 3 --actor-lr 3e-4 --critic-lr 3e-4 --gamma 0.99 --tau 0.005 --actor-penalty-coef 4.0 --critic-penalty-coef 2.0 --policy-noise 0.2 --noise-clip 0.5 --policy-freq 2 --grad-clip-norm 10.0 --normalizer-eps 1e-3 --eval-every 0 --checkpoint-every 9536 --skip-final-eval --log-every 1000 --critic-layernorm --no-actor-layernorm --save-dir checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/seed_46 --seed 46 --device cuda
# [offline] algo=rebrac transitions=304967 obs_dim=40 action_dim=2 protocol=deployable tensor_replay=on eval_workers=1 sampling=shuffle_no_replacement total_steps=76288
# [train] step=1 epoch=1 epoch_step=1 q=-1.110 critic=13.423 actor=4.651 bc=0.913 lambda=0.901 critic_pen=1.026
# [train] step=1000 epoch=1 epoch_step=1000 q=-4.390 critic=1.965 actor=0.922 bc=0.042 lambda=0.172 critic_pen=0.113
# [train] step=2000 epoch=2 epoch_step=808 q=-3.491 critic=23.928 actor=0.448 bc=0.021 lambda=0.105 critic_pen=0.111
# [train] step=3000 epoch=3 epoch_step=616 q=-2.810 critic=11.438 actor=0.342 bc=0.032 lambda=0.076 critic_pen=0.096
# [train] step=4000 epoch=4 epoch_step=424 q=-1.338 critic=5.522 actor=0.159 bc=0.021 lambda=0.056 critic_pen=0.077
# [train] step=5000 epoch=5 epoch_step=232 q=-2.754 critic=2.314 actor=0.265 bc=0.032 lambda=0.050 critic_pen=0.075
# [train] step=6000 epoch=6 epoch_step=40 q=-0.040 critic=3.368 actor=0.036 bc=0.009 lambda=0.040 critic_pen=0.092
# [train] step=7000 epoch=6 epoch_step=1040 q=-2.101 critic=3.218 actor=0.089 bc=0.003 lambda=0.037 critic_pen=0.089
# [train] step=8000 epoch=7 epoch_step=848 q=-2.828 critic=2.474 actor=0.200 bc=0.025 lambda=0.035 critic_pen=0.088
# [train] step=9000 epoch=8 epoch_step=656 q=-1.129 critic=3.043 actor=0.072 bc=0.009 lambda=0.033 critic_pen=0.092
# [train] step=10000 epoch=9 epoch_step=464 q=-4.921 critic=1.381 actor=0.195 bc=0.009 lambda=0.032 critic_pen=0.082
# [train] step=11000 epoch=10 epoch_step=272 q=-1.799 critic=2.608 actor=0.115 bc=0.016 lambda=0.029 critic_pen=0.085
# [train] step=12000 epoch=11 epoch_step=80 q=2.481 critic=2.237 actor=-0.034 bc=0.008 lambda=0.027 critic_pen=0.077
# [train] step=13000 epoch=11 epoch_step=1080 q=-5.572 critic=1.637 actor=0.278 bc=0.030 lambda=0.029 critic_pen=0.090
# [train] step=14000 epoch=12 epoch_step=888 q=-5.340 critic=1.599 actor=0.152 bc=0.003 lambda=0.026 critic_pen=0.077
# [train] step=15000 epoch=13 epoch_step=696 q=-4.298 critic=1.352 actor=0.204 bc=0.024 lambda=0.025 critic_pen=0.078
# [train] step=16000 epoch=14 epoch_step=504 q=-8.835 critic=1.382 actor=0.253 bc=0.007 lambda=0.025 critic_pen=0.075
# [train] step=17000 epoch=15 epoch_step=312 q=-4.002 critic=0.935 actor=0.218 bc=0.029 lambda=0.025 critic_pen=0.074
# [train] step=18000 epoch=16 epoch_step=120 q=-1.982 critic=1.640 actor=0.137 bc=0.023 lambda=0.023 critic_pen=0.126
# [train] step=63000 epoch=53 epoch_step=1016 q=-6.771 critic=7.888 actor=0.195 bc=0.011 lambda=0.022 critic_pen=0.078
# [train] step=64000 epoch=54 epoch_step=824 q=-1.952 critic=2.205 actor=0.064 bc=0.006 lambda=0.021 critic_pen=0.083
# [train] step=65000 epoch=55 epoch_step=632 q=-3.868 critic=2.508 actor=0.140 bc=0.015 lambda=0.021 critic_pen=0.092
# [train] step=66000 epoch=56 epoch_step=440 q=-5.897 critic=2.703 actor=0.187 bc=0.016 lambda=0.021 critic_pen=0.066
# [train] step=67000 epoch=57 epoch_step=248 q=-9.391 critic=2.362 actor=0.222 bc=0.003 lambda=0.022 critic_pen=0.093
# [train] step=68000 epoch=58 epoch_step=56 q=-4.109 critic=2.163 actor=0.121 bc=0.007 lambda=0.023 critic_pen=0.073
# [train] step=69000 epoch=58 epoch_step=1056 q=-6.385 critic=2.385 actor=0.147 bc=0.001 lambda=0.023 critic_pen=0.083
# [train] step=70000 epoch=59 epoch_step=864 q=-11.406 critic=2.484 actor=0.307 bc=0.017 lambda=0.021 critic_pen=0.079
# [train] step=71000 epoch=60 epoch_step=672 q=-6.007 critic=2.687 actor=0.162 bc=0.007 lambda=0.022 critic_pen=0.073
# [train] step=72000 epoch=61 epoch_step=480 q=-8.725 critic=3.146 actor=0.183 bc=0.001 lambda=0.021 critic_pen=0.068
# [train] step=73000 epoch=62 epoch_step=288 q=-4.564 critic=3.149 actor=0.138 bc=0.009 lambda=0.022 critic_pen=0.072
# [train] step=74000 epoch=63 epoch_step=96 q=-4.540 critic=2.701 actor=0.142 bc=0.011 lambda=0.021 critic_pen=0.077
# [train] step=75000 epoch=63 epoch_step=1096 q=-3.314 critic=2.618 actor=0.106 bc=0.008 lambda=0.022 critic_pen=0.075
# [train] step=76000 epoch=64 epoch_step=904 q=-3.841 critic=2.865 actor=0.169 bc=0.022 lambda=0.021 critic_pen=0.074

# %% [markdown]
# ## 4. 批 B 训练：backup finalist `(β1=4.0, β2=1.0)` on `crosscomp-2000` × 5 seeds
#
# **网格展开**：1 dataset × 1 β1 × 1 β2 × 5 seeds = **5 runs**；其中 seeds 42/43/44 在 §2.5 已从 Stage B 复用，**本 cell 实际只新训 seeds 45/46 = 2 runs**。
#
# **`MODE=train`**：同 §3，只训练不评估，validate/test/summarize 合并到 §4.5。
#
# 理由见 [rebrac_experiment_report.md §6.7](../docs/rebrac_experiment_report.md)：
# 在 Stage B 的 `crosscomp-2000` 上，`(β1=4.0, β2=1.0)` 与主 finalist 的差距是测量噪声量级（Δmean 1.7pp、Δstd 0.008），追加一组 5-seed 只多 5 runs 但能在主 finalist 若在 Stage C 下方差放大时直接接盘，避免 rework。
#
# `crosscomp-1000` 不追加 backup——那里主 finalist 相对第二名的差距是 3.3pp，没有同等质量的候选。

# %%
os.environ["MODE"]                 = "train"
os.environ["DATASET_EPISODES"]     = "2000"
os.environ["ACTOR_PENALTY_COEFS"]  = "4.0"
os.environ["CRITIC_PENALTY_COEFS"] = "1.0"
# !bash scripts/run_offline_rebrac_screen.sh
# Out:
# [skip] manifest exists: benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json
# [skip] manifest exists: benchmarks/offline_rebrac_screen/test_100/single_u10_cross_tgt15.json
# [skip] dataset exists: offline_data/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/transitions.npz
# [skip] trained run exists: checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_1p0/seed_42
# [skip] trained run exists: checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_1p0/seed_43
# [skip] trained run exists: checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_1p0/seed_44
#
# [cmd] python3 -m scripts.train_offline --algo rebrac --offline-data offline_data/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/transitions.npz --flow wake_data/wake_v8_U1p00_Re150_D12p00_dx0p60_Ti5pct_1200f_roi.npy --manifest benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json --probe-layout s0 --history-length 4 --task-geometry cross_stream --target-speed 1.5 --objective efficiency_v2 --sampling-mode shuffle_no_replacement --num-epochs 64 --total-steps 76288 --batch-size 256 --hidden-dim 256 --num-hidden-layers 3 --actor-lr 3e-4 --critic-lr 3e-4 --gamma 0.99 --tau 0.005 --actor-penalty-coef 4.0 --critic-penalty-coef 1.0 --policy-noise 0.2 --noise-clip 0.5 --policy-freq 2 --grad-clip-norm 10.0 --normalizer-eps 1e-3 --eval-every 0 --checkpoint-every 9536 --skip-final-eval --log-every 1000 --critic-layernorm --no-actor-layernorm --save-dir checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_1p0/seed_45 --seed 45 --device cuda
# [offline] algo=rebrac transitions=304967 obs_dim=40 action_dim=2 protocol=deployable tensor_replay=on eval_workers=1 sampling=shuffle_no_replacement total_steps=76288
# [train] step=1 epoch=1 epoch_step=1 q=-0.773 critic=44.330 actor=4.710 bc=0.927 lambda=1.293 critic_pen=1.019
# [train] step=1000 epoch=1 epoch_step=1000 q=-2.068 critic=1.190 actor=0.641 bc=0.051 lambda=0.211 critic_pen=0.124
# [train] step=2000 epoch=2 epoch_step=808 q=-0.929 critic=25.359 actor=0.271 bc=0.043 lambda=0.108 critic_pen=0.112
# [train] step=3000 epoch=3 epoch_step=616 q=0.399 critic=11.239 actor=0.054 bc=0.021 lambda=0.076 critic_pen=0.083
# [train] step=4000 epoch=4 epoch_step=424 q=0.219 critic=7.491 actor=0.242 bc=0.064 lambda=0.062 critic_pen=0.097
# [train] step=5000 epoch=5 epoch_step=232 q=2.719 critic=3.962 actor=-0.085 bc=0.011 lambda=0.047 critic_pen=0.077
# [train] step=6000 epoch=6 epoch_step=40 q=-0.947 critic=2.851 actor=0.098 bc=0.014 lambda=0.047 critic_pen=0.083
# [train] step=7000 epoch=6 epoch_step=1040 q=1.085 critic=3.790 actor=0.087 bc=0.032 lambda=0.040 critic_pen=0.092
# [train] step=8000 epoch=7 epoch_step=848 q=0.205 critic=3.612 actor=0.048 bc=0.014 lambda=0.037 critic_pen=0.081
# [train] step=9000 epoch=8 epoch_step=656 q=2.812 critic=3.192 actor=-0.058 bc=0.008 lambda=0.032 critic_pen=0.079
# [train] step=10000 epoch=9 epoch_step=464 q=4.619 critic=3.062 actor=0.054 bc=0.048 lambda=0.030 critic_pen=0.096
# [train] step=11000 epoch=10 epoch_step=272 q=1.869 critic=1.802 actor=-0.024 bc=0.008 lambda=0.029 critic_pen=0.085
# [train] step=12000 epoch=11 epoch_step=80 q=2.050 critic=2.873 actor=0.075 bc=0.033 lambda=0.028 critic_pen=0.105
# [train] step=13000 epoch=11 epoch_step=1080 q=1.455 critic=3.008 actor=0.016 bc=0.014 lambda=0.027 critic_pen=0.073
# [train] step=14000 epoch=12 epoch_step=888 q=0.698 critic=2.832 actor=0.117 bc=0.034 lambda=0.027 critic_pen=0.080
# [train] step=59000 epoch=50 epoch_step=592 q=-4.204 critic=3.497 actor=0.143 bc=0.012 lambda=0.023 critic_pen=0.074
# [train] step=60000 epoch=51 epoch_step=400 q=-2.208 critic=5.652 actor=0.059 bc=0.001 lambda=0.024 critic_pen=0.083
# [train] step=61000 epoch=52 epoch_step=208 q=4.000 critic=2.633 actor=-0.083 bc=0.001 lambda=0.022 critic_pen=0.078
# [train] step=62000 epoch=53 epoch_step=16 q=-6.987 critic=3.853 actor=0.237 bc=0.021 lambda=0.022 critic_pen=0.079
# [train] step=63000 epoch=53 epoch_step=1016 q=2.296 critic=3.159 actor=0.005 bc=0.014 lambda=0.021 critic_pen=0.075
# [train] step=64000 epoch=54 epoch_step=824 q=-2.099 critic=2.670 actor=0.052 bc=0.001 lambda=0.022 critic_pen=0.073
# [train] step=65000 epoch=55 epoch_step=632 q=-0.403 critic=2.823 actor=0.057 bc=0.012 lambda=0.023 critic_pen=0.092
# [train] step=66000 epoch=56 epoch_step=440 q=-1.787 critic=2.732 actor=0.089 bc=0.012 lambda=0.024 critic_pen=0.091
# [train] step=67000 epoch=57 epoch_step=248 q=-7.008 critic=2.777 actor=0.207 bc=0.011 lambda=0.024 critic_pen=0.067
# [train] step=68000 epoch=58 epoch_step=56 q=-0.086 critic=2.135 actor=0.075 bc=0.018 lambda=0.023 critic_pen=0.076
# [train] step=69000 epoch=58 epoch_step=1056 q=-0.394 critic=3.785 actor=0.095 bc=0.022 lambda=0.022 critic_pen=0.081
# [train] step=70000 epoch=59 epoch_step=864 q=-4.136 critic=2.319 actor=0.178 bc=0.020 lambda=0.023 critic_pen=0.072
# [train] step=71000 epoch=60 epoch_step=672 q=-3.403 critic=3.223 actor=0.090 bc=0.003 lambda=0.023 critic_pen=0.076
# [train] step=72000 epoch=61 epoch_step=480 q=1.615 critic=3.462 actor=-0.021 bc=0.004 lambda=0.023 critic_pen=0.086
# [train] step=73000 epoch=62 epoch_step=288 q=0.476 critic=3.560 actor=0.115 bc=0.031 lambda=0.022 critic_pen=0.073
# [train] step=74000 epoch=63 epoch_step=96 q=1.563 critic=2.917 actor=0.019 bc=0.014 lambda=0.022 critic_pen=0.083
# [train] step=75000 epoch=63 epoch_step=1096 q=5.401 critic=6.691 actor=-0.117 bc=0.001 lambda=0.022 critic_pen=0.091
# [train] step=76000 epoch=64 epoch_step=904 q=2.819 critic=5.916 actor=-0.033 bc=0.007 lambda=0.022 critic_pen=0.088
#
# [cmd] python3 -m scripts.train_offline --algo rebrac --offline-data offline_data/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/transitions.npz --flow wake_data/wake_v8_U1p00_Re150_D12p00_dx0p60_Ti5pct_1200f_roi.npy --manifest benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json --probe-layout s0 --history-length 4 --task-geometry cross_stream --target-speed 1.5 --objective efficiency_v2 --sampling-mode shuffle_no_replacement --num-epochs 64 --total-steps 76288 --batch-size 256 --hidden-dim 256 --num-hidden-layers 3 --actor-lr 3e-4 --critic-lr 3e-4 --gamma 0.99 --tau 0.005 --actor-penalty-coef 4.0 --critic-penalty-coef 1.0 --policy-noise 0.2 --noise-clip 0.5 --policy-freq 2 --grad-clip-norm 10.0 --normalizer-eps 1e-3 --eval-every 0 --checkpoint-every 9536 --skip-final-eval --log-every 1000 --critic-layernorm --no-actor-layernorm --save-dir checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_1p0/seed_
# [train] step=65000 epoch=55 epoch_step=632 q=-0.556 critic=2.839 actor=0.082 bc=0.017 lambda=0.022 critic_pen=0.094
# [train] step=66000 epoch=56 epoch_step=440 q=-2.475 critic=2.677 actor=0.122 bc=0.017 lambda=0.022 critic_pen=0.067
# [train] step=67000 epoch=57 epoch_step=248 q=-5.486 critic=2.081 actor=0.142 bc=0.003 lambda=0.024 critic_pen=0.095
# [train] step=68000 epoch=58 epoch_step=56 q=-1.074 critic=2.103 actor=0.087 bc=0.015 lambda=0.024 critic_pen=0.074
# [train] step=69000 epoch=58 epoch_step=1056 q=-3.480 critic=2.639 actor=0.088 bc=0.001 lambda=0.024 critic_pen=0.083
# [train] step=70000 epoch=59 epoch_step=864 q=-7.954 critic=2.274 actor=0.247 bc=0.017 lambda=0.022 critic_pen=0.080
# [train] step=71000 epoch=60 epoch_step=672 q=-2.851 critic=3.231 actor=0.071 bc=0.001 lambda=0.024 critic_pen=0.072
# [train] step=72000 epoch=61 epoch_step=480 q=-5.170 critic=3.506 actor=0.119 bc=0.001 lambda=0.022 critic_pen=0.068
# [train] step=73000 epoch=62 epoch_step=288 q=-1.420 critic=3.242 actor=0.065 bc=0.008 lambda=0.024 critic_pen=0.074
# [train] step=74000 epoch=63 epoch_step=96 q=-1.681 critic=3.001 actor=0.067 bc=0.007 lambda=0.023 critic_pen=0.077
# [train] step=75000 epoch=63 epoch_step=1096 q=-0.333 critic=2.834 actor=0.043 bc=0.009 lambda=0.023 critic_pen=0.076
# [train] step=76000 epoch=64 epoch_step=904 q=-0.970 critic=2.794 actor=0.067 bc=0.011 lambda=0.022 critic_pen=0.076

# %% [markdown]
# ## 4.5 统一 validate → test → summarize（3 个 finalist × 5 seeds = 15 runs）
#
# 把 validate / test / summarize 从 §3 / §4 的 `MODE=all` 里拆出来，放到两批训练都落盘之后再跑，原因有二：
#
# 1. **Summary 一次成型**：`write_summary` 扫描 `RESULTS_ROOT` 下所有 `(dataset, pair)/test/seed_*.json`。若在 §3 后就先跑一次 summarize，会先写一个只含批 A 的 `overview.csv`；批 B 跑完再覆写——中间态会让 §5/§6/§7 的显示短暂错乱。合并之后 `overview.csv` 只写一次。
# 2. **网格拆分正确**：`run_validate` / `run_test` 遍历的是 `DATASET_EPISODES × ACTOR_PENALTY_COEFS × CRITIC_PENALTY_COEFS × SEEDS` 笛卡尔积。如果一次性放 `DATASET_EPISODES="1000 2000"` + `CRITIC_PENALTY_COEFS="1.0 2.0"`，就会扫到 ep1000 × β2=1.0（Stage C finalist 之外的格子）。所以下方按批 A / 批 B 各跑一遍 validate + test，最后再 summarize 一次。
#
# **对 §2.5 已复用 val 的 9 个 seed**：每个 `agent_*.json` 的 `[skip] validation exists` 会命中，本次只新算 6 个新 seed × 8 ckpt = **48 次 val**。
# **test 全部新跑**（Stage C 是 100-ep 新 manifest），共 **15 次 test**。

# %%
# --- 半 A：主 finalist on crosscomp-1000 & crosscomp-2000（β1=4.0, β2=2.0）---
os.environ["DATASET_EPISODES"]     = "1000 2000"
os.environ["ACTOR_PENALTY_COEFS"]  = "4.0"
os.environ["CRITIC_PENALTY_COEFS"] = "2.0"
os.environ["MODE"]                 = "validate"
# !bash scripts/run_offline_rebrac_screen.sh
os.environ["MODE"]                 = "test"
# !bash scripts/run_offline_rebrac_screen.sh

# --- 半 B：backup finalist 仅 crosscomp-2000（β1=4.0, β2=1.0）---
os.environ["DATASET_EPISODES"]     = "2000"
os.environ["ACTOR_PENALTY_COEFS"]  = "4.0"
os.environ["CRITIC_PENALTY_COEFS"] = "1.0"
os.environ["MODE"]                 = "validate"
# !bash scripts/run_offline_rebrac_screen.sh
os.environ["MODE"]                 = "test"
# !bash scripts/run_offline_rebrac_screen.sh

# --- Summarize：扫 RESULTS_ROOT 下所有 (dataset, pair)/test/seed_*.json，只写一次 overview ---
os.environ["MODE"]                 = "summarize"
# !bash scripts/run_offline_rebrac_screen.sh
# Out:
# [skip] manifest exists: benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json
# [skip] validation exists: results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_42/agent_step_00004776.json
# [skip] validation exists: results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_42/agent_step_00009552.json
# [skip] validation exists: results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_42/agent_step_00014328.json
# [skip] validation exists: results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_42/agent_step_00019104.json
# [skip] validation exists: results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_42/agent_step_00023880.json
# [skip] validation exists: results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_42/agent_step_00028656.json
# [skip] validation exists: results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_42/agent_step_00033432.json
# [skip] validation exists: results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_42/agent_step_00038208.json
# [skip] validation exists: results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_42/agent_final.json
#
# [cmd] python3 - results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_42 checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_42/trainer_state.json results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/selection/seed_42/selected_checkpoint.json results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/selection/seed_42/selected_agent_file.txt
# [write] selection: results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/selection/seed_42/selected_checkpoint.json
# [best] agent=agent_step_00033432.pt success=0.8750 return=-44.3176
# [skip] validation exists: results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_43/agent_step_00004776.json
# [skip] validation exists: results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_43/agent_step_00009552.json
# [skip] validation exists: results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_43/agent_step_00014328.json
# [skip] validation exists: results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_43/agent_step_00019104.json
# [skip] validation exists: results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_43/agent_step_00023880.json
# [skip] validation exists: results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_43/agent_step_00028656.json
# [skip] validation exists: results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_43/agent_step_00033432.json
# [skip] validation exists: results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_43/agent_step_00038208.json
# [skip] validation exists: results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_43/agent_final.json
#
# [cmd] python3 - results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_43 checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_43/trainer_state.json results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/selection/seed_43/selected_checkpoint.json results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/selection/seed_43/selected_agent_file.txt
# [write] selection: results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/selection/seed_43/selected_checkpoint.json
# [best] agent=agent_step_00033432.pt success=0.9250 return=-34.3029
# [skip] validation exists: results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_44/agent_step_00004776.json
# [skip] validation exists: results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_44/agent_step_00009552.json
# [skip] validation exists: results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_44/agent_step_00014328.json
# [skip] validation exists: results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_44/agent_step_00019104.json
# [skip] validation exists: results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_44/agent_step_00023880.json
# [skip] validation exists: results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_44/agent_step_00028656.json
# [skip] validation exists: results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_44/agent_step_00033432.json
# [skip] validation exists: results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_44/agent_step_00038208.json
# [skip] validation exists: results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_44/agent_final.json
#
# [cmd] python3 - results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_44 checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_44/trainer_state.json results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/selection/seed_44/selected_checkpoint.json results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/selection/seed_44/selected_agent_file.txt
# [write] selection: results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/selection/seed_44/selected_checkpoint.json
# [best] agent=agent_step_00033432.pt success=0.8500 return=-40.5993
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_45 --agent-file agent_step_00004776.pt --manifest benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_45/agent_step_00004776.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 55.0%
# avg_return            : -156.03 +/- 172.02
# avg_safety_cost       : 14.360 +/- 18.283
# avg_time_s            : 111.39 +/- 63.52
# avg_time_s_success    : 97.02
# avg_energy            : 67688.52 +/- 38998.76
# avg_path_length_m     : 71.06 +/- 25.19
# avg_progress_ratio    : 0.585 +/- 0.463
# avg_path_efficiency   : 0.442 +/- 0.297
# termination           : {'goal': 22, 'out_of_bounds': 11, 'timeout': 7}
# benchmark_manifest    : benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_45 --agent-file agent_step_00009552.pt --manifest benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_45/agent_step_00009552.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 32.5%
# avg_return            : -152.42 +/- 136.22
# avg_safety_cost       : 23.093 +/- 22.920
# avg_time_s            : 94.04 +/- 45.32
# avg_time_s_success    : 81.64
# avg_energy            : 59113.52 +/- 30271.13
# avg_path_length_m     : 70.67 +/- 27.29
# avg_progress_ratio    : 0.534 +/- 0.608
# avg_path_efficiency   : 0.431 +/- 0.313
# termination           : {'goal': 13, 'out_of_bounds': 26, 'timeout': 1}
# benchmark_manifest    : benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_45 --agent-file agent_step_00014328.pt --manifest benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_45/agent_step_00014328.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 12.5%
# avg_return            : -161.89 +/- 135.26
# avg_safety_cost       : 17.237 +/- 11.391
# avg_time_s            : 88.25 +/- 56.16
# avg_time_s_success    : 73.48
# avg_energy            : 54710.45 +/- 34587.37
# avg_path_length_m     : 65.97 +/- 24.97
# avg_progress_ratio    : 0.569 +/- 0.386
# avg_path_efficiency   : 0.443 +/- 0.252
# termination           : {'out_of_bounds': 32, 'goal': 5, 'timeout': 3}
# benchmark_manifest    : benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_45 --agent-file agent_step_00019104.pt --manifest benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_45/agent_step_00019104.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 70.0%
# avg_return            : -110.84 +/- 167.97
# avg_safety_cost       : 16.186 +/- 16.289
# avg_time_s            : 97.93 +/- 54.92
# avg_time_s_success    : 80.62
# avg_energy            : 60736.27 +/- 33993.47
# avg_path_length_m     : 70.31 +/- 28.32
# avg_progress_ratio    : 0.601 +/- 0.590
# avg_path_efficiency   : 0.483 +/- 0.336
# termination           : {'out_of_bounds': 9, 'goal': 28, 'timeout': 3}
# benchmark_manifest    : benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_45 --agent-file agent_step_00023880.pt --manifest benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_45/agent_step_00023880.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 55.0%
# avg_return            : -111.95 +/- 135.38
# avg_safety_cost       : 19.532 +/- 16.043
# avg_time_s            : 92.03 +/- 48.70
# avg_time_s_success    : 83.83
# avg_energy            : 57270.53 +/- 30579.64
# avg_path_length_m     : 66.64 +/- 25.31
# avg_progress_ratio    : 0.735 +/- 0.296
# avg_path_efficiency   : 0.545 +/- 0.230
# termination           : {'goal': 22, 'out_of_bounds': 15, 'timeout': 3}
# benchmark_manifest    : benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_45 --agent-file agent_step_00028656.pt --manifest benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_45/agent_step_00028656.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 75.0%
# avg_return            : -61.86 +/- 66.51
# avg_safety_cost       : 17.796 +/- 10.905
# avg_time_s            : 81.18 +/- 26.20
# avg_time_s_success    : 85.42
# avg_energy            : 50397.71 +/- 16369.67
# avg_path_length_m     : 60.74 +/- 14.56
# avg_progress_ratio    : 0.825 +/- 0.175
# avg_path_efficiency   : 0.605 +/- 0.158
# termination           : {'goal': 30, 'out_of_bounds': 10}
# benchmark_manifest    : benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_45 --agent-file agent_step_00033432.pt --manifest benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_45/agent_step_00033432.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 70.0%
# avg_return            : -94.08 +/- 146.02
# avg_safety_cost       : 17.959 +/- 15.440
# avg_time_s            : 92.35 +/- 51.79
# avg_time_s_success    : 82.03
# avg_energy            : 57526.87 +/- 32517.09
# avg_path_length_m     : 68.01 +/- 29.87
# avg_progress_ratio    : 0.732 +/- 0.344
# avg_path_efficiency   : 0.559 +/- 0.256
# termination           : {'goal': 28, 'out_of_bounds': 10, 'timeout': 2}
# benchmark_manifest    : benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_45 --agent-file agent_step_00038208.pt --manifest benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_45/agent_step_00038208.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 87.5%
# avg_return            : -41.89 +/- 40.21
# avg_safety_cost       : 15.974 +/- 10.363
# avg_time_s            : 79.39 +/- 21.98
# avg_time_s_success    : 84.64
# avg_energy            : 49491.07 +/- 13734.48
# avg_path_length_m     : 59.18 +/- 11.80
# avg_progress_ratio    : 0.848 +/- 0.166
# avg_path_efficiency   : 0.631 +/- 0.142
# termination           : {'goal': 35, 'out_of_bounds': 5}
# benchmark_manifest    : benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_45 --agent-file agent_final.pt --manifest benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_45/agent_final.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 87.5%
# avg_return            : -41.89 +/- 40.21
# avg_safety_cost       : 15.974 +/- 10.363
# avg_time_s            : 79.39 +/- 21.98
# avg_time_s_success    : 84.64
# avg_energy            : 49491.07 +/- 13734.48
# avg_path_length_m     : 59.18 +/- 11.80
# avg_progress_ratio    : 0.848 +/- 0.166
# avg_path_efficiency   : 0.631 +/- 0.142
# termination           : {'goal': 35, 'out_of_bounds': 5}
# benchmark_manifest    : benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 - results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_45 checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_45/trainer_state.json results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/selection/seed_45/selected_checkpoint.json results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/selection/seed_45/selected_agent_file.txt
# [write] selection: results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/selection/seed_45/selected_checkpoint.json
# [best] agent=agent_final.pt success=0.8750 return=-41.8945
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_46 --agent-file agent_step_00004776.pt --manifest benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_46/agent_step_00004776.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 62.5%
# avg_return            : -103.88 +/- 111.85
# avg_safety_cost       : 20.177 +/- 21.696
# avg_time_s            : 92.86 +/- 42.39
# avg_time_s_success    : 92.58
# avg_energy            : 55970.23 +/- 23925.68
# avg_path_length_m     : 62.56 +/- 13.16
# avg_progress_ratio    : 0.755 +/- 0.238
# avg_path_efficiency   : 0.542 +/- 0.193
# termination           : {'goal': 25, 'out_of_bounds': 13, 'timeout': 2}
# benchmark_manifest    : benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_46 --agent-file agent_step_00009552.pt --manifest benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_46/agent_step_00009552.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 35.0%
# avg_return            : -276.03 +/- 232.24
# avg_safety_cost       : 15.386 +/- 22.304
# avg_time_s            : 148.87 +/- 81.16
# avg_time_s_success    : 83.17
# avg_energy            : 91766.09 +/- 49702.82
# avg_path_length_m     : 92.49 +/- 35.03
# avg_progress_ratio    : 0.098 +/- 0.739
# avg_path_efficiency   : 0.186 +/- 0.407
# termination           : {'timeout': 15, 'goal': 14, 'out_of_bounds': 11}
# benchmark_manifest    : benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_46 --agent-file agent_step_00014328.pt --manifest benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_46/agent_step_00014328.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 67.5%
# avg_return            : -93.78 +/- 130.97
# avg_safety_cost       : 18.815 +/- 15.685
# avg_time_s            : 90.30 +/- 47.77
# avg_time_s_success    : 85.78
# avg_energy            : 55895.91 +/- 29079.13
# avg_path_length_m     : 64.19 +/- 18.31
# avg_progress_ratio    : 0.727 +/- 0.364
# avg_path_efficiency   : 0.539 +/- 0.242
# termination           : {'timeout': 3, 'goal': 27, 'out_of_bounds': 10}
# benchmark_manifest    : benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_46 --agent-file agent_step_00019104.pt --manifest benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_46/agent_step_00019104.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 75.0%
# avg_return            : -50.16 +/- 48.29
# avg_safety_cost       : 13.487 +/- 8.172
# avg_time_s            : 75.32 +/- 21.00
# avg_time_s_success    : 82.61
# avg_energy            : 47020.60 +/- 13187.21
# avg_path_length_m     : 58.36 +/- 9.60
# avg_progress_ratio    : 0.801 +/- 0.205
# avg_path_efficiency   : 0.602 +/- 0.171
# termination           : {'goal': 30, 'out_of_bounds': 10}
# benchmark_manifest    : benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_46 --agent-file agent_step_00023880.pt --manifest benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_46/agent_step_00023880.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 90.0%
# avg_return            : -38.29 +/- 68.29
# avg_safety_cost       : 15.809 +/- 16.130
# avg_time_s            : 78.94 +/- 23.93
# avg_time_s_success    : 79.11
# avg_energy            : 49461.09 +/- 14996.98
# avg_path_length_m     : 59.64 +/- 11.32
# avg_progress_ratio    : 0.838 +/- 0.214
# avg_path_efficiency   : 0.629 +/- 0.194
# termination           : {'goal': 36, 'out_of_bounds': 4}
# benchmark_manifest    : benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_46 --agent-file agent_step_00028656.pt --manifest benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_46/agent_step_00028656.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 95.0%
# avg_return            : -27.48 +/- 39.42
# avg_safety_cost       : 15.309 +/- 13.141
# avg_time_s            : 77.38 +/- 18.25
# avg_time_s_success    : 78.91
# avg_energy            : 48198.56 +/- 11478.81
# avg_path_length_m     : 59.01 +/- 10.16
# avg_progress_ratio    : 0.873 +/- 0.147
# avg_path_efficiency   : 0.653 +/- 0.151
# termination           : {'goal': 38, 'out_of_bounds': 2}
# benchmark_manifest    : benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_46 --agent-file agent_step_00033432.pt --manifest benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_46/agent_step_00033432.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 92.5%
# avg_return            : -30.31 +/- 43.22
# avg_safety_cost       : 15.613 +/- 14.988
# avg_time_s            : 77.14 +/- 19.91
# avg_time_s_success    : 79.44
# avg_energy            : 48088.24 +/- 12471.84
# avg_path_length_m     : 58.78 +/- 11.20
# avg_progress_ratio    : 0.869 +/- 0.146
# avg_path_efficiency   : 0.656 +/- 0.160
# termination           : {'goal': 37, 'out_of_bounds': 3}
# benchmark_manifest    : benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_46 --agent-file agent_step_00038208.pt --manifest benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_46/agent_step_00038208.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 87.5%
# avg_return            : -47.32 +/- 40.42
# avg_safety_cost       : 18.816 +/- 14.832
# avg_time_s            : 81.78 +/- 19.50
# avg_time_s_success    : 85.83
# avg_energy            : 50800.40 +/- 12146.10
# avg_path_length_m     : 61.14 +/- 9.60
# avg_progress_ratio    : 0.850 +/- 0.164
# avg_path_efficiency   : 0.609 +/- 0.142
# termination           : {'goal': 35, 'out_of_bounds': 5}
# benchmark_manifest    : benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_46 --agent-file agent_final.pt --manifest benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_46/agent_final.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 87.5%
# avg_return            : -47.32 +/- 40.42
# avg_safety_cost       : 18.816 +/- 14.832
# avg_time_s            : 81.78 +/- 19.50
# avg_time_s_success    : 85.83
# avg_energy            : 50800.40 +/- 12146.10
# avg_path_length_m     : 61.14 +/- 9.60
# avg_progress_ratio    : 0.850 +/- 0.164
# avg_path_efficiency   : 0.609 +/- 0.142
# termination           : {'goal': 35, 'out_of_bounds': 5}
# benchmark_manifest    : benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 - results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/validation/seed_46 checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/seed_46/trainer_state.json results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/selection/seed_46/selected_checkpoint.json results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/selection/seed_46/selected_agent_file.txt
# [write] selection: results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000/actorb_4p0__criticb_2p0/selection/seed_46/selected_checkpoint.json
# [best] agent=agent_step_00028656.pt success=0.9500 return=-27.4804
# [skip] validation exists: results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/validation/seed_42/agent_step_00009536.json
# [skip] validation exists: results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/validation/seed_42/agent_step_00019072.json
# [skip] validation exists: results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/validation/seed_42/agent_step_00028608.json
# [skip] validation exists: results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/validation/seed_42/agent_step_00038144.json
# [skip] validation exists: results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/validation/seed_42/agent_step_00047680.json
# [skip] validation exists: results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/validation/seed_42/agent_step_00057216.json
# [skip] validation exists: results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/validation/seed_42/agent_step_00066752.json
# [skip] validation exists: results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/validation/seed_42/agent_step_00076288.json
# [skip] validation exists: results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/validation/seed_42/agent_final.json
#
# [cmd] python3 - results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/validation/seed_42 checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/seed_42/trainer_state.json results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/selection/seed_42/selected_checkpoint.json results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/selection/seed_42/selected_agent_file.txt
# [write] selection: results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/selection/seed_42/selected_checkpoint.json
# [best] agent=agent_step_00066752.pt success=0.9250 return=-36.8961
# [skip] validation exists: results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/validation/seed_43/agent_step_00009536.json
# [skip] validation exists: results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/validation/seed_43/agent_step_00019072.json
# [skip] validation exists: results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/validation/seed_43/agent_step_00028608.json
# [skip] validation exists: results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/validation/seed_43/agent_step_00038144.json
# [skip] validation exists: results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/validation/seed_43/agent_step_00047680.json
# [skip] validation exists: results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/validation/seed_43/agent_step_00057216.json
# [skip] validation exists: results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/validation/seed_43/agent_step_00066752.json
# [skip] validation exists: results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/validation/seed_43/agent_step_00076288.json
# [skip] validation exists: results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/validation/seed_43/agent_final.json
#
# [cmd] python3 - results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/validation/seed_43 checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/seed_43/trainer_state.json results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/selection/seed_43/selected_checkpoint.json results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/selection/seed_43/selected_agent_file.txt
# [write] selection: results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/selection/seed_43/selected_checkpoint.json
# [best] agent=agent_step_00066752.pt success=0.9250 return=-33.3724
# [skip] validation exists: results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/validation/seed_44/agent_step_00009536.json
# [skip] validation exists: results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/validation/seed_44/agent_step_00019072.json
# [skip] validation exists: results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/validation/seed_44/agent_step_00028608.json
# [skip] validation exists: results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/validation/seed_44/agent_step_00038144.json
# [skip] validation exists: results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/validation/seed_44/agent_step_00047680.json
# [skip] validation exists: results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/validation/seed_44/agent_step_00057216.json
# [skip] validation exists: results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/validation/seed_44/agent_step_00066752.json
# [skip] validation exists: results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/validation/seed_44/agent_step_00076288.json
# [skip] validation exists: results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/validation/seed_44/agent_final.json
#
# [cmd] python3 - results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/validation/seed_44 checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/seed_44/trainer_state.json results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/selection/seed_44/selected_checkpoint.json results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/selection/seed_44/selected_agent_file.txt
# [write] selection: results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/selection/seed_44/selected_checkpoint.json
# [best] agent=agent_step_00057216.pt success=0.9000 return=-37.0644
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/seed_45 --agent-file agent_step_00009536.pt --manifest benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/validation/seed_45/agent_step_00009536.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 50.0%
# avg_return            : -151.99 +/- 176.66
# avg_safety_cost       : 19.312 +/- 42.651
# avg_time_s            : 103.47 +/- 59.35
# avg_time_s_success    : 84.63
# avg_energy            : 64560.11 +/- 38154.53
# avg_path_length_m     : 72.36 +/- 31.88
# avg_progress_ratio    : 0.473 +/- 0.618
# avg_path_efficiency   : 0.416 +/- 0.352
# termination           : {'goal': 20, 'out_of_bounds': 17, 'timeout': 3}
# benchmark_manifest    : benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/seed_45 --agent-file agent_step_00019072.pt --manifest benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/validation/seed_45/agent_step_00019072.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 7.5%
# avg_return            : -177.81 +/- 129.97
# avg_safety_cost       : 18.722 +/- 12.518
# avg_time_s            : 91.38 +/- 54.44
# avg_time_s_success    : 79.27
# avg_energy            : 56658.15 +/- 34146.85
# avg_path_length_m     : 69.39 +/- 25.94
# avg_progress_ratio    : 0.491 +/- 0.414
# avg_path_efficiency   : 0.383 +/- 0.256
# termination           : {'out_of_bounds': 35, 'goal': 3, 'timeout': 2}
# benchmark_manifest    : benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/seed_45 --agent-file agent_step_00028608.pt --manifest benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/validation/seed_45/agent_step_00028608.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 72.5%
# avg_return            : -63.96 +/- 80.36
# avg_safety_cost       : 17.927 +/- 14.905
# avg_time_s            : 79.94 +/- 26.49
# avg_time_s_success    : 81.71
# avg_energy            : 49872.39 +/- 16545.80
# avg_path_length_m     : 61.65 +/- 18.41
# avg_progress_ratio    : 0.791 +/- 0.273
# avg_path_efficiency   : 0.595 +/- 0.201
# termination           : {'out_of_bounds': 11, 'goal': 29}
# benchmark_manifest    : benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/seed_45 --agent-file agent_step_00038144.pt --manifest benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/validation/seed_45/agent_step_00038144.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 57.5%
# avg_return            : -89.19 +/- 72.89
# avg_safety_cost       : 18.858 +/- 13.420
# avg_time_s            : 83.82 +/- 33.88
# avg_time_s_success    : 95.23
# avg_energy            : 52378.33 +/- 21470.71
# avg_path_length_m     : 64.02 +/- 22.19
# avg_progress_ratio    : 0.805 +/- 0.161
# avg_path_efficiency   : 0.572 +/- 0.154
# termination           : {'out_of_bounds': 17, 'goal': 23}
# benchmark_manifest    : benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/seed_45 --agent-file agent_step_00047680.pt --manifest benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/validation/seed_45/agent_step_00047680.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 72.5%
# avg_return            : -62.10 +/- 66.15
# avg_safety_cost       : 20.304 +/- 18.157
# avg_time_s            : 79.92 +/- 20.32
# avg_time_s_success    : 81.98
# avg_energy            : 49891.36 +/- 12784.70
# avg_path_length_m     : 60.89 +/- 11.24
# avg_progress_ratio    : 0.843 +/- 0.149
# avg_path_efficiency   : 0.613 +/- 0.152
# termination           : {'goal': 29, 'out_of_bounds': 11}
# benchmark_manifest    : benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/seed_45 --agent-file agent_step_00057216.pt --manifest benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/validation/seed_45/agent_step_00057216.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 62.5%
# avg_return            : -77.41 +/- 90.50
# avg_safety_cost       : 18.059 +/- 15.805
# avg_time_s            : 81.41 +/- 33.44
# avg_time_s_success    : 82.34
# avg_energy            : 51021.32 +/- 21332.27
# avg_path_length_m     : 62.83 +/- 23.63
# avg_progress_ratio    : 0.825 +/- 0.165
# avg_path_efficiency   : 0.603 +/- 0.168
# termination           : {'goal': 25, 'out_of_bounds': 14, 'timeout': 1}
# benchmark_manifest    : benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/seed_45 --agent-file agent_step_00066752.pt --manifest benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/validation/seed_45/agent_step_00066752.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 80.0%
# avg_return            : -45.24 +/- 48.98
# avg_safety_cost       : 15.863 +/- 11.174
# avg_time_s            : 76.34 +/- 19.67
# avg_time_s_success    : 81.18
# avg_energy            : 47677.36 +/- 12344.69
# avg_path_length_m     : 58.41 +/- 10.09
# avg_progress_ratio    : 0.835 +/- 0.173
# avg_path_efficiency   : 0.629 +/- 0.157
# termination           : {'out_of_bounds': 8, 'goal': 32}
# benchmark_manifest    : benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/seed_45 --agent-file agent_step_00076288.pt --manifest benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/validation/seed_45/agent_step_00076288.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 80.0%
# avg_return            : -51.45 +/- 68.98
# avg_safety_cost       : 16.359 +/- 15.506
# avg_time_s            : 79.05 +/- 23.79
# avg_time_s_success    : 81.83
# avg_energy            : 49368.67 +/- 15041.11
# avg_path_length_m     : 60.12 +/- 15.72
# avg_progress_ratio    : 0.818 +/- 0.224
# avg_path_efficiency   : 0.621 +/- 0.181
# termination           : {'goal': 32, 'out_of_bounds': 8}
# benchmark_manifest    : benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/seed_45 --agent-file agent_final.pt --manifest benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_2p0/validation/seed_45/agent_final.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 80.0%
# avg_return            : -51.45 +/- 68.98
# avg_safety_cost       : 16.359 +/- 15.506
# avg_time_s            : 79.05 +/- 23.79
# avg_time_s_success    : 81.83
# avg_energy            : 49368.67 +/- 15041.11
# avg_path_length_m     : 60.12 +/- 15.72
# ...
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 50.0%
# avg_return            : -136.19 +/- 167.22
# avg_safety_cost       : 20.362 +/- 37.444
# avg_time_s            : 96.68 +/- 59.11
# avg_time_s_success    : 86.47
# avg_energy            : 60261.60 +/- 36831.56
# avg_path_length_m     : 70.58 +/- 26.19
# avg_progress_ratio    : 0.531 +/- 0.568
# avg_path_efficiency   : 0.419 +/- 0.314
# termination           : {'out_of_bounds': 15, 'goal': 20, 'timeout': 5}
# benchmark_manifest    : benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_1p0/seed_46 --agent-file agent_step_00028608.pt --manifest benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_1p0/validation/seed_46/agent_step_00028608.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 60.0%
# avg_return            : -160.04 +/- 194.52
# avg_safety_cost       : 22.854 +/- 23.751
# avg_time_s            : 112.73 +/- 61.19
# avg_time_s_success    : 84.10
# avg_energy            : 71033.31 +/- 39195.03
# avg_path_length_m     : 76.78 +/- 30.19
# avg_progress_ratio    : 0.459 +/- 0.715
# avg_path_efficiency   : 0.392 +/- 0.380
# termination           : {'timeout': 4, 'goal': 24, 'out_of_bounds': 12}
# benchmark_manifest    : benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_1p0/seed_46 --agent-file agent_step_00038144.pt --manifest benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_1p0/validation/seed_46/agent_step_00038144.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 80.0%
# avg_return            : -40.70 +/- 44.45
# avg_safety_cost       : 12.851 +/- 9.121
# avg_time_s            : 74.01 +/- 20.63
# avg_time_s_success    : 80.60
# avg_energy            : 46082.87 +/- 12888.36
# avg_path_length_m     : 57.66 +/- 10.28
# avg_progress_ratio    : 0.815 +/- 0.191
# avg_path_efficiency   : 0.623 +/- 0.167
# termination           : {'goal': 32, 'out_of_bounds': 8}
# benchmark_manifest    : benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_1p0/seed_46 --agent-file agent_step_00047680.pt --manifest benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_1p0/validation/seed_46/agent_step_00047680.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 77.5%
# avg_return            : -48.66 +/- 43.46
# avg_safety_cost       : 15.266 +/- 10.465
# avg_time_s            : 76.16 +/- 21.45
# avg_time_s_success    : 83.95
# avg_energy            : 47486.58 +/- 13454.33
# avg_path_length_m     : 58.65 +/- 10.77
# avg_progress_ratio    : 0.813 +/- 0.186
# avg_path_efficiency   : 0.609 +/- 0.152
# termination           : {'goal': 31, 'out_of_bounds': 9}
# benchmark_manifest    : benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_1p0/seed_46 --agent-file agent_step_00057216.pt --manifest benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_1p0/validation/seed_46/agent_step_00057216.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 77.5%
# avg_return            : -49.48 +/- 45.33
# avg_safety_cost       : 13.951 +/- 9.773
# avg_time_s            : 76.62 +/- 21.37
# avg_time_s_success    : 83.92
# avg_energy            : 47750.33 +/- 13410.25
# avg_path_length_m     : 58.44 +/- 10.56
# avg_progress_ratio    : 0.809 +/- 0.197
# avg_path_efficiency   : 0.608 +/- 0.159
# termination           : {'goal': 31, 'out_of_bounds': 9}
# benchmark_manifest    : benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_1p0/seed_46 --agent-file agent_step_00066752.pt --manifest benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_1p0/validation/seed_46/agent_step_00066752.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 77.5%
# avg_return            : -44.64 +/- 42.38
# avg_safety_cost       : 14.970 +/- 10.088
# avg_time_s            : 74.31 +/- 18.83
# avg_time_s_success    : 81.25
# avg_energy            : 46588.43 +/- 11870.90
# avg_path_length_m     : 57.94 +/- 9.07
# avg_progress_ratio    : 0.821 +/- 0.182
# avg_path_efficiency   : 0.620 +/- 0.155
# termination           : {'goal': 31, 'out_of_bounds': 9}
# benchmark_manifest    : benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_1p0/seed_46 --agent-file agent_step_00076288.pt --manifest benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_1p0/validation/seed_46/agent_step_00076288.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 80.0%
# avg_return            : -38.02 +/- 44.16
# avg_safety_cost       : 12.474 +/- 7.767
# avg_time_s            : 72.91 +/- 19.29
# avg_time_s_success    : 78.89
# avg_energy            : 45644.68 +/- 12126.72
# avg_path_length_m     : 56.92 +/- 9.66
# avg_progress_ratio    : 0.824 +/- 0.177
# avg_path_efficiency   : 0.637 +/- 0.158
# termination           : {'goal': 32, 'out_of_bounds': 8}
# benchmark_manifest    : benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_1p0/seed_46 --agent-file agent_final.pt --manifest benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 123 --output-json results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_1p0/validation/seed_46/agent_final.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 40
# success_rate          : 80.0%
# avg_return            : -38.02 +/- 44.16
# avg_safety_cost       : 12.474 +/- 7.767
# avg_time_s            : 72.91 +/- 19.29
# avg_time_s_success    : 78.89
# avg_energy            : 45644.68 +/- 12126.72
# avg_path_length_m     : 56.92 +/- 9.66
# avg_progress_ratio    : 0.824 +/- 0.177
# avg_path_efficiency   : 0.637 +/- 0.158
# termination           : {'goal': 32, 'out_of_bounds': 8}
# benchmark_manifest    : benchmarks/offline_rebrac_screen/val_40/single_u10_cross_tgt15.json
#
# [cmd] python3 - results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_1p0/validation/seed_46 checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_1p0/seed_46/trainer_state.json results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_1p0/selection/seed_46/selected_checkpoint.json results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_1p0/selection/seed_46/selected_agent_file.txt
# [write] selection: results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_1p0/selection/seed_46/selected_checkpoint.json
# [best] agent=agent_final.pt success=0.8000 return=-38.0154
# [skip] manifest exists: benchmarks/offline_rebrac_screen/test_100/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_1p0/seed_42 --agent-file agent_step_00066752.pt --manifest benchmarks/offline_rebrac_screen/test_100/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 456 --output-json results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_1p0/test/seed_42.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 100
# success_rate          : 93.0%
# avg_return            : -37.63 +/- 38.13
# avg_safety_cost       : 15.920 +/- 13.414
# avg_time_s            : 81.20 +/- 17.82
# avg_time_s_success    : 83.34
# avg_energy            : 50506.30 +/- 11208.44
# avg_path_length_m     : 59.34 +/- 10.21
# avg_progress_ratio    : 0.877 +/- 0.132
# avg_path_efficiency   : 0.646 +/- 0.130
# termination           : {'goal': 93, 'out_of_bounds': 7}
# benchmark_manifest    : benchmarks/offline_rebrac_screen/test_100/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_1p0/seed_43 --agent-file agent_step_00066752.pt --manifest benchmarks/offline_rebrac_screen/test_100/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 456 --output-json results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_1p0/test/seed_43.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 100
# success_rate          : 93.0%
# avg_return            : -37.59 +/- 35.02
# avg_safety_cost       : 15.233 +/- 10.905
# avg_time_s            : 81.07 +/- 17.87
# avg_time_s_success    : 83.75
# avg_energy            : 50249.74 +/- 11121.14
# avg_path_length_m     : 59.02 +/- 9.38
# avg_progress_ratio    : 0.868 +/- 0.146
# avg_path_efficiency   : 0.640 +/- 0.130
# termination           : {'goal': 93, 'out_of_bounds': 7}
# benchmark_manifest    : benchmarks/offline_rebrac_screen/test_100/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_1p0/seed_44 --agent-file agent_step_00057216.pt --manifest benchmarks/offline_rebrac_screen/test_100/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 456 --output-json results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_1p0/test/seed_44.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 100
# success_rate          : 93.0%
# avg_return            : -41.20 +/- 77.19
# avg_safety_cost       : 13.813 +/- 13.041
# avg_time_s            : 82.76 +/- 28.64
# avg_time_s_success    : 81.48
# avg_energy            : 51607.53 +/- 18247.57
# avg_path_length_m     : 60.12 +/- 16.28
# avg_progress_ratio    : 0.855 +/- 0.214
# avg_path_efficiency   : 0.645 +/- 0.168
# termination           : {'goal': 93, 'out_of_bounds': 5, 'timeout': 2}
# benchmark_manifest    : benchmarks/offline_rebrac_screen/test_100/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_1p0/seed_45 --agent-file agent_step_00028608.pt --manifest benchmarks/offline_rebrac_screen/test_100/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 456 --output-json results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_1p0/test/seed_45.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 100
# success_rate          : 81.0%
# avg_return            : -65.18 +/- 69.25
# avg_safety_cost       : 18.976 +/- 16.334
# avg_time_s            : 86.91 +/- 30.21
# avg_time_s_success    : 90.88
# avg_energy            : 54275.36 +/- 19034.79
# avg_path_length_m     : 63.69 +/- 18.48
# avg_progress_ratio    : 0.855 +/- 0.149
# avg_path_efficiency   : 0.604 +/- 0.152
# termination           : {'out_of_bounds': 19, 'goal': 81}
# benchmark_manifest    : benchmarks/offline_rebrac_screen/test_100/single_u10_cross_tgt15.json
#
# [cmd] python3 -m scripts.evaluate_offline --checkpoint checkpoints/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_1p0/seed_46 --agent-file agent_final.pt --manifest benchmarks/offline_rebrac_screen/test_100/single_u10_cross_tgt15.json --device cuda --num-workers 6 --worker-device cpu --seed 456 --output-json results/offline/rebrac/formal/crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000/actorb_4p0__criticb_1p0/test/seed_46.json
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 100
# success_rate          : 87.0%
# avg_return            : -33.47 +/- 40.44
# avg_safety_cost       : 11.920 +/- 8.157
# avg_time_s            : 75.33 +/- 18.55
# avg_time_s_success    : 79.47
# avg_energy            : 47164.59 +/- 11678.93
# avg_path_length_m     : 57.05 +/- 9.58
# avg_progress_ratio    : 0.845 +/- 0.171
# avg_path_efficiency   : 0.648 +/- 0.154
# termination           : {'goal': 87, 'out_of_bounds': 13}
# benchmark_manifest    : benchmarks/offline_rebrac_screen/test_100/single_u10_cross_tgt15.json
#
# [cmd] python3 - results/offline/rebrac/formal checkpoints/offline/rebrac/formal results/offline/rebrac/formal/summaries 0.25
# [write] summary: results/offline/rebrac/formal/summaries/overview.csv
# [write] summary: results/offline/rebrac/formal/summaries/overview.json

# %% [markdown]
# ## 5. Overview：5-seed 正式成绩
#
# 把 `summaries/overview.csv` 按 `(dataset, mean_test_success_rate desc)` 排序显示。
#
# 此时表里应有 **3 行**：
#
# | dataset | pair | 说明 |
# | --- | --- | --- |
# | `crosscomp-1000` | `actorb_4p0__criticb_2p0` | 主 finalist |
# | `crosscomp-2000` | `actorb_4p0__criticb_2p0` | 主 finalist |
# | `crosscomp-2000` | `actorb_4p0__criticb_1p0` | backup finalist |
#
# **关键读法**：对照 Stage B 的 3-seed 结果（表格下方并排展示），看均值和 std 是否稳定。

# %%
import csv
from pathlib import Path

import pandas as pd

SUMMARY_CSV = Path(os.environ["SUMMARY_ROOT"]) / "overview.csv"

if not SUMMARY_CSV.exists():
    print(f"[missing] {SUMMARY_CSV} — run §3/§4 first.")
else:
    df = pd.read_csv(SUMMARY_CSV)

    def _fmt(x, precision=4):
        try:
            return f"{float(x):.{precision}f}"
        except Exception:
            return str(x)

    display_cols = [
        "dataset",
        "pair",
        "num_seeds",
        "mean_test_success_rate",
        "std_test_success_rate",
        "mean_test_return",
        "std_test_return",
        "mean_test_safety_cost",
        "mean_test_time_s",
        "mean_critic_penalty",
        "mean_target_q",
        "mean_critic_penalty_ratio",
    ]
    view = df[display_cols].copy()
    view = view.sort_values(
        ["dataset", "mean_test_success_rate"], ascending=[True, False]
    ).reset_index(drop=True)
    for col in [
        "mean_test_success_rate",
        "std_test_success_rate",
        "mean_critic_penalty_ratio",
    ]:
        view[col] = view[col].map(lambda v: _fmt(v, 4))
    for col in [
        "mean_test_return",
        "std_test_return",
        "mean_test_safety_cost",
        "mean_test_time_s",
        "mean_critic_penalty",
        "mean_target_q",
    ]:
        view[col] = view[col].map(lambda v: _fmt(v, 2))
    print(view.to_string(index=False))
# Out:
#                                                     dataset                    pair  num_seeds mean_test_success_rate std_test_success_rate mean_test_return std_test_return mean_test_safety_cost mean_test_time_s mean_critic_penalty mean_target_q mean_critic_penalty_ratio
# crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000 actorb_4p0__criticb_2p0          5                 0.9020                0.0214           -38.72            4.87                 14.51            79.75                0.08         -8.25                    0.0431
# crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000 actorb_4p0__criticb_2p0          5                 0.9180                0.0299           -39.91            6.81                 15.41            81.41                0.08         -5.47                    0.1094
# crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000 actorb_4p0__criticb_1p0          5                 0.8940                0.0480           -43.01           11.35                 15.17            81.46                0.08         -1.85                    0.3583

# %% [markdown]
# ## 6. Per-seed 分布
#
# 把 5 个 seed 的 test success 全部打出来，同时附上 Stage B 的 3-seed 对应 seed 作对照（如果在同 pair 下）。
#
# **必须检查**：
#
# 1. seed 44 是否在 Stage C 下仍然恢复（Stage B 下 ep1000 主 finalist 上 seed 44 = 0.850）；
# 2. 新增的 seed 45 / seed 46 是否也落在 `0.85 ~ 0.95` 区间，还是出现新的 outlier；
# 3. backup finalist `(β1=4.0, β2=1.0)` ep2000 的 min-max spread 是否确实小于主 finalist（Stage B 下 spread=0.050 vs 0.025）。

# %%
import json

RESULTS_ROOT = Path(os.environ["RESULTS_ROOT"])

def load_test_payload(dataset: str, pair: str, seed: str) -> dict | None:
    path = RESULTS_ROOT / dataset / pair / "test" / f"seed_{seed}.json"
    if not path.exists():
        return None
    return json.loads(path.read_text(encoding="utf-8"))

if not SUMMARY_CSV.exists():
    print(f"[missing] {SUMMARY_CSV}")
else:
    SEEDS = os.environ["SEEDS"].split()
    header = f"{'dataset':<60}{'pair':<28}" + "".join(f"seed_{s:<7}" for s in SEEDS) + "min-max spread"
    print(header)
    print("-" * len(header))
    for dataset in sorted(df["dataset"].unique()):
        sub = df[df["dataset"] == dataset].sort_values("mean_test_success_rate", ascending=False)
        for _, r in sub.iterrows():
            pair = r["pair"]
            per_seed = []
            for seed in SEEDS:
                payload = load_test_payload(dataset, pair, seed)
                if payload is None:
                    per_seed.append(None)
                else:
                    per_seed.append(float(payload["eval_success_rate"]))
            seed_cells = "".join(
                f"{v:<12.4f}" if v is not None else f"{'N/A':<12}" for v in per_seed
            )
            valid = [v for v in per_seed if v is not None]
            spread = (max(valid) - min(valid)) if len(valid) >= 2 else 0.0
            print(f"{dataset:<60}{pair:<28}{seed_cells}{spread:.4f}")
# Out:
# dataset                                                     pair                        seed_42     seed_43     seed_44     seed_45     seed_46     min-max spread
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------
# crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000 actorb_4p0__criticb_2p0     0.8900      0.9300      0.8700      0.9000      0.9200      0.0600
# crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000 actorb_4p0__criticb_2p0     0.9600      0.9400      0.8900      0.8800      0.9200      0.0800
# crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000 actorb_4p0__criticb_1p0     0.9300      0.9300      0.9300      0.8100      0.8700      0.1200

# %% [markdown]
# ## 7. 三张表对比：Stage B（3 seeds, test 40）vs Stage C（5 seeds, test 100）vs TD3BC phase0c
#
# 手工硬编码 Stage B 和 TD3BC phase0c 的数字，与当前 Stage C `overview.csv` 拼成一张总表。
#
# **判定规则**：
#
# - 每一 dataset 取 Stage C finalist 中 `mean_test_success_rate` 最高者作为该 dataset 的 ReBRAC 官方成绩；
# - Stage C mean ≥ Stage B mean − 0.05（允许 test manifest 变大带来的量级波动）视为 Stage B 结论可复现；
# - Stage C mean ≥ TD3BC phase0c 对应 dataset winner + 0.05 视为显著超越；
# - 若任何 finalist std_test_success_rate > 0.10，触发 plan §6.4 末尾的失败分流。

# %%
# 硬编码对照组（与 rebrac_experiment_report.md §6.3 / §6.6 保持一致）
STAGE_B_3SEED = {
    ("crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000", "actorb_4p0__criticb_2p0"): (0.883, 0.031),
    ("crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000", "actorb_4p0__criticb_2p0"): (0.917, 0.012),
    ("crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000", "actorb_4p0__criticb_1p0"): (0.900, 0.020),
}
TD3BC_PHASE0C = {
    "crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000": ("α=0.25", 0.672, 0.045),
    "crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000": ("α=0.15", 0.596, 0.036),
}

if not SUMMARY_CSV.exists():
    print(f"[missing] {SUMMARY_CSV}")
else:
    out_rows = []
    for _, r in df.iterrows():
        dataset, pair = r["dataset"], r["pair"]
        c_mean, c_std = float(r["mean_test_success_rate"]), float(r["std_test_success_rate"])
        b_mean, b_std = STAGE_B_3SEED.get((dataset, pair), (None, None))
        td3_info = TD3BC_PHASE0C.get(dataset)
        out_rows.append(
            dict(
                dataset=dataset.replace("crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_", ""),
                pair=pair.replace("actorb_", "β1=").replace("__criticb_", ", β2=").replace("p", "."),
                stage_b_3seed=f"{b_mean:.3f} ± {b_std:.3f}" if b_mean is not None else "—",
                stage_c_5seed=f"{c_mean:.3f} ± {c_std:.3f}",
                td3bc_phase0c=(
                    f"{td3_info[1]:.3f} ± {td3_info[2]:.3f} (TD3BC {td3_info[0]})" if td3_info else "—"
                ),
                delta_vs_td3bc=(
                    f"{(c_mean - td3_info[1])*100:+.1f}pp" if td3_info else "—"
                ),
                delta_vs_stage_b=(
                    f"{(c_mean - b_mean)*100:+.1f}pp" if b_mean is not None else "—"
                ),
            )
        )
    out_df = pd.DataFrame(out_rows)
    print(out_df.to_string(index=False))
# Out:
# dataset           pair stage_b_3seed stage_c_5seed                td3bc_phase0c delta_vs_td3bc delta_vs_stage_b
#  ep1000 β1=4.0, β2=2.0 0.883 ± 0.031 0.902 ± 0.021 0.672 ± 0.045 (TD3BC α=0.25)        +23.0pp           +1.9pp
#  ep2000 β1=4.0, β2=2.0 0.917 ± 0.012 0.918 ± 0.030 0.596 ± 0.036 (TD3BC α=0.15)        +32.2pp           +0.1pp
#  ep2000 β1=4.0, β2=1.0 0.900 ± 0.020 0.894 ± 0.048 0.596 ± 0.036 (TD3BC α=0.15)        +29.8pp           -0.6pp

# %% [markdown]
# ## 8. Critic penalty 诊断（β2 · ratio）
#
# Stage B 上这个图是 12 个格子的全扫，Stage C 只有 3 格，依然保留用来做 sanity check：
#
# - 所有条不超过 1.0 → critic 没被 penalty 支配；
# - 如果 Stage C 的 `β2·ratio` 相比 Stage B 显著飘（例如主 finalist ep2000 从 0.311 跳到 0.7 以上），说明 `target_q` 的量级在更多 seed 下出现偏移，值得回到训练日志排查。

# %%
import matplotlib.pyplot as plt

if not SUMMARY_CSV.exists():
    print(f"[missing] {SUMMARY_CSV}")
else:
    def _beta2_from_pair(pair):
        return float(pair.split("criticb_")[-1].replace("p", "."))

    datasets = sorted(df["dataset"].unique())
    fig, axes = plt.subplots(1, len(datasets), figsize=(5.5 * len(datasets), 3.6), sharey=True)
    if len(datasets) == 1:
        axes = [axes]
    for ax, dataset in zip(axes, datasets):
        sub = df[df["dataset"] == dataset].copy()
        sub["beta2"] = sub["pair"].map(_beta2_from_pair)
        sub["effective"] = sub["beta2"] * sub["mean_critic_penalty_ratio"]
        sub = sub.sort_values("pair")
        ax.bar(sub["pair"], sub["effective"])
        ax.axhline(1.0, linestyle="--", color="red", alpha=0.7, label="dominance threshold (1.0)")
        ax.axhline(1.5, linestyle="--", color="darkred", alpha=0.9, label="veto threshold (1.5)")
        ax.set_title(dataset.replace("crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_", ""))
        ax.set_ylabel("β2 · mean_critic_penalty_ratio")
        ax.tick_params(axis="x", rotation=45)
        ax.grid(True, alpha=0.3)
        ax.legend(fontsize=8)
    fig.suptitle("Stage C: critic penalty dominance check")
    fig.tight_layout()
    plt.show()

# %% [markdown]
# ## 9. Stage C → Stage D 决策规则
#
# 跑完上述所有单元后，按以下规则决定是否推进到 Stage D（`worldcomp-1000` teacher-gap follow-up）：
#
# 1. **全部通过**（三个 finalist 都满足 §8 的成功判据）：进入 Stage D。报告正式成绩：每个 dataset 取 mean 最高者作为该 dataset 的 ReBRAC 官方成绩。
# 2. **主 finalist 在 ep2000 上掉队但 backup 撑住**：直接用 backup 作为 ep2000 的 ReBRAC 官方成绩，不做 rework。进入 Stage D。
# 3. **主 finalist 在 ep1000 上掉队**：回到 Stage B 补跑 `(β1=4.0, β2=1.0)` + 其他邻近格子在 ep1000 上的 5-seed，重新选 finalist；暂停 Stage D。
# 4. **任一 finalist std > 0.10 但 mean 通过**：挂起 Stage D，回到 Stage B 分析 seed 45/46 是否出现 Stage B 未见的 outlier；可以选择追加 seeds 47/48 到 7-seed 再判一次。
# 5. **全员崩盘**：停止扩 ReBRAC 主线 screening；按 plan §10 第 5 条转向 XQL。
#
# 决策结果和对应的 rework / follow-up 计划，需要写入 [docs/rebrac_experiment_report.md](../docs/rebrac_experiment_report.md) 的新 §7（Stage C 结果）。
