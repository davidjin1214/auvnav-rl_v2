# %% [markdown]
# # 第 5 章数据完整性 —— Drive 侧探针 + ①-c 干净 manifest 补评
#
# **背景**：`docs/data_integrity_open_items.md` 第 ① ③ 条已核实成立；波及面评估的独立复核见
# `paper/thesis_ch5/data_integrity_impact_assessment_review.md`。③ 已在本机用现存逐回合记录
# 零成本量化完毕，本 notebook 只处理**必须在 Drive 侧才能做**的两件事。
#
# | 段 | 目的 | 开销 |
# |---|---|---|
# | §1 探针 A | 2000 / 1000 格的 ReBRAC-Q 检查点（`.pt`）是否还在 Drive | 秒级，纯 I/O |
# | §2 探针 B | 含噪 2000 数据集的 `seed`；全量 `offline_data/` 污染面审计 | 分钟级，无 GPU |
# | §3 ①-c | 在干净 manifest 上补评 2000 与 1000 两格 × 5 种子 | 10 次纯评估，无训练 |
# | §4 回传 | 该同步回 git 的小文件清单 | — |
#
# ---
#
# ## 第二轮（本次要跑的）
#
# 首轮（2026-08-16）§1 §2 已回，结论进了 `docs/data_integrity_open_items.md`：
#
# - **探针 A 通过** —— 10 个选中检查点全部在位 → `RUN_CLEAN_PROBE` **已在 §3 改为 `True`**；
# - **探针 B 钉死第 ⑤ 条** —— 含噪 2000 同样 `seed=0`、100/100 逐条相同；
# - **但探针 B 自曝一个坑**：`audit_seed_overlap` 的 range pass 只列出 24 个数据集，**漏掉了那个
#   确实存在、且同样被污染的含噪 2000**（`--verify` 按路径直读得到了它）。Drive FUSE 的目录列举
#   不可信 → §2 新增一格用 `os.listdir` 逐名 stat 重建全集并就地重判，**污染面要以那一格为准**。
#
# 本轮从头跑到尾即可：§1 §2 秒级到分钟级，§3 是 10 次纯评估（无训练、无重采）。
#
# **不训练、不重采数据、不动任何 `.tex`。**

# %% [markdown]
# ## 0. 挂载 Drive + cd 进项目

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/"MyDrive"/"Colab Notebooks"/"new_offRL"/"rl_v2_5"
# !pwd
# !git log --oneline -3
# Out:
# /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5
# /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %% [markdown]
# ## 1. 探针 A —— 2000 / 1000 格的检查点还在吗
#
# 这一条决定处置格局：**检查点在 → ①-c（补评，测出污染幅度）成立；已清 → 只剩「重采重跑」与
# 「保留数字 + 降级翻转论述」二选一。**
#
# 本机（Windows 副机）`results/offline/**` 下 `.pt` 计数为 **0**，选点记录 `selected_checkpoint.json`
# 里只留了文件名（如 `agent_step_00066752.pt`）。下面既查目录存在性，也查**被选中的那个** `.pt`
# 是否还在——目录里有一堆 `.pt` 但恰好缺选中那个，等于没有。

# %%
import json, glob
from pathlib import Path

CELLS = {
    "cross-1000": "crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000",
    "cross-2000": "crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000",
}
PAIR   = "actorb_4p0__criticb_2p0"
SEEDS  = [42, 43, 44, 45, 46]
CKPT_ROOT = Path("checkpoints/offline/rebrac/formal")
RES_ROOT  = Path("results/offline/rebrac/formal")

PROBE_A = {}
print(f"{'cell':11s} {'seed':>4s} {'run_dir':>8s} {'#.pt':>5s} {'selected agent_file':32s} {'selected .pt':>12s}")
print("-" * 82)
for label, ds in CELLS.items():
    for seed in SEEDS:
        run_dir = CKPT_ROOT / ds / PAIR / f"seed_{seed}"
        sel     = RES_ROOT / ds / PAIR / "selection" / f"seed_{seed}" / "selected_checkpoint.json"
        agent_file = None
        if sel.exists():
            agent_file = json.loads(sel.read_text(encoding="utf-8"))["best"]["agent_file"]
        n_pt = len(list(run_dir.glob("*.pt"))) if run_dir.is_dir() else 0
        ok   = bool(agent_file) and (run_dir / agent_file).exists()
        PROBE_A[(label, seed)] = {"run_dir": str(run_dir), "agent_file": agent_file, "ok": ok}
        print(f"{label:11s} {seed:4d} {str(run_dir.is_dir()):>8s} {n_pt:5d} "
              f"{str(agent_file):32s} {('YES' if ok else 'NO'):>12s}")

READY = all(v["ok"] for v in PROBE_A.values())
print()
print("=" * 82)
print("探针 A 判定:", "全部 10 个选中检查点在位 → ①-c 可做" if READY
      else "有缺失 → 见下一格的兜底搜索；仍缺则 ①-c 作废")
# Out:
# cell        seed  run_dir  #.pt selected agent_file              selected .pt
# ----------------------------------------------------------------------------------
# cross-1000    42     True    10 agent_step_00033432.pt                    YES
# cross-1000    43     True    10 agent_step_00033432.pt                    YES
# cross-1000    44     True    10 agent_step_00033432.pt                    YES
# cross-1000    45     True    10 agent_final.pt                            YES
# cross-1000    46     True    10 agent_step_00028656.pt                    YES
# cross-2000    42     True    10 agent_step_00066752.pt                    YES
# cross-2000    43     True    10 agent_step_00066752.pt                    YES
# cross-2000    44     True    10 agent_step_00057216.pt                    YES
# cross-2000    45     True    10 agent_step_00066752.pt                    YES
# cross-2000    46     True    10 agent_step_00066752.pt                    YES
#
# ==================================================================================
# 探针 A 判定: 全部 10 个选中检查点在位 → ①-c 可做

# %%
# 兜底：若上面路径落空，说明 Drive 侧目录布局与预期不同，在 checkpoints/ 下全局搜一遍
if not READY:
    print("checkpoints/ 下所有含 ep1000 / ep2000 的 seed 目录：")
    for p in sorted(glob.glob("checkpoints/**/*_ep[12]000/**/seed_*", recursive=True))[:80]:
        n = len(list(Path(p).glob("*.pt")))
        print(f"  {n:3d} .pt   {p}")
    print()
    print("checkpoints/ 顶层：")
    for p in sorted(glob.glob("checkpoints/*")):
        print("  ", p)
else:
    print("（探针 A 已通过，跳过兜底搜索）")
# Out:
# （探针 A 已通过，跳过兜底搜索）

# %% [markdown]
# ## 2. 探针 B —— 含噪 2000 数据集 + 全量污染面审计
#
# 复核发现的漏项：§5.6.2 的 noisy-support 诊断有一半坐在 **2000 回合**数据上，其中含噪 2000
# 数据集（`crosscomp_..._noise0p05clip0p15_ep2000`）**从未进过污染面枚举**——之前那句「10 个数据集
# 只有一个受影响」数的是本机 `offline_data/` 目录，而该数据集只在 Drive。
#
# `collect_offline_data.py` 的 `--seed` 默认为 `0`，本机现存 10 个数据集无一例外都是 0。若含噪 2000
# 沿用同一调用，其训练种子区间同为 0–1999，**完整包含评估 manifest 的 1250–1349**。

# %%
import json
from pathlib import Path

print(f"{'dataset':78s} {'seed':>5s} {'episodes':>9s} {'succ':>6s}  风险")
print("-" * 108)
MIN_MANIFEST_SEED = 1100   # 全部 8 个 benchmark key 中最小的 manifest_seed
for meta_path in sorted(Path("offline_data").glob("*/metadata.json")):
    m = json.loads(meta_path.read_text(encoding="utf-8"))
    seed, eps = m.get("seed"), m.get("num_episodes")
    risky = (seed is not None and eps is not None
             and seed <= MIN_MANIFEST_SEED < seed + eps)
    print(f"{meta_path.parent.name:78s} {str(seed):>5s} {str(eps):>9s} "
          f"{str(m.get('success_rate')):>6s}  {'⚠ 可能相交' if risky else 'ok'}")
# Out:
# dataset                                                                         seed  episodes   succ  风险
# ------------------------------------------------------------------------------------------------------------
# crosscomp_s0_h4_arrival_v2_re150_u10cross_fixdone_ep1000                           0      1000   0.87  ok
# crosscomp_s0_h4_arrival_v2_simple_re150_u10upstream_fixdone_ep1000                 0      1000    1.0  ok
# crosscomp_s0_h4_efficiency_v2_re150_u10cross                                       0       500  0.864  ok
# crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000                        0      1000   0.87  ok
# crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000                        0      2000 0.8855  ⚠ 可能相交
# crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_noise0p05clip0p15_ep1000      0      1000  0.863  ok
# crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_noise0p05clip0p15_ep2000      0      2000 0.8795  ⚠ 可能相交
# crosscomp_s0_h4_efficiency_v2_re150_u10upstream_fixdone_ep1000                     0      1000    1.0  ok
# crosscomp_s0_h4_efficiency_v2_re150tandem_u10cross_fixdone_ep1000                  0      1000  0.964  ok
# crosscomp_s0_h4_effv2_re150_u10cross                                               0       500  0.864  ok
# crosscomp_s1_h4_efficiency_v2_re150_u10cross_fixdone_ep1000                        0      1000   0.87  ok
# crosscomp_s1_h4_efficiency_v2_re150_u10upstream_fixdone_ep1000                     0      1000    1.0  ok
# crosscomp_s2_h4_efficiency_v2_re150_u10cross_fixdone_ep1000                        0      1000   0.87  ok
# goalseek_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000                         0      1000  0.768  ok
# mix5050_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000                       None      1000  0.825  ok
# mix_tmp_crosscomp_500ep_seed1                                                      1       500  0.866  ok
# mix_tmp_goalseek_500ep_seed0                                                       0       500  0.784  ok
# privileged_s0_h4_arrival_v2_re150_u10cross_fixdone_ep1000                          0      1000  0.985  ok
# privileged_s0_h4_arrival_v2_re250_u15cross_fixdone_ep1000                          0      1000  0.718  ok
# privileged_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000                       0      1000  0.985  ok
# sac_expert_s0_h4_arrival_v2_re150_u10cross_seed46_step600k_ep1000                  0      1000  0.899  ok
# sac_medium_s0_h4_arrival_v2_re150_u10cross_seed46_step425k_ep1000                  0      1000  0.515  ok
# sac_mexp_s0_h4_arrival_v2_re150_u10cross_seed46_step575k_ep1000                    0      1000  0.751  ok
# sac_random_s0_h4_arrival_v2_re150_u10cross_seed46_step25k_ep1000                   0      1000  0.002  ok
# worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone                               0      1000  0.958  ok
# worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000                        0      1000  0.958  ok

# %%
# 权威判定：range pass 覆盖 Drive 侧全部数据集 × 全部 manifest（只比对同流场/几何/目标速度的组合）
# !python -m scripts.audit_seed_overlap
# Out:
# datasets: 26   manifests: 24
#
# [clean  ] crosscomp_s0_h4_arrival_v2_re150_u10cross_fixdone_ep1000  seeds 0..999
# [clean  ] crosscomp_s0_h4_arrival_v2_simple_re150_u10upstream_fixdone_ep1000  seeds 0..999
# [clean  ] crosscomp_s0_h4_efficiency_v2_re150_u10cross  seeds 0..499
# [clean  ] crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000  seeds 0..999
# [OVERLAP] crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep2000  seeds 0..1999
#     OVERLAP 100/100 with clean_probe/_repro_check_s1250.json (seeds 1250..1349)
#     OVERLAP 100/100 with offline_rebrac_broad/test_100/single_u10_cross_tgt15.json (seeds 1250..1349)
#     OVERLAP 40/40 with offline_rebrac_broad/val_40/single_u10_cross_tgt15.json (seeds 1250..1289)
#     OVERLAP 100/100 with offline_rebrac_screen/test_100/single_u10_cross_tgt15.json (seeds 1250..1349)
#     OVERLAP 40/40 with offline_rebrac_screen/val_40/single_u10_cross_tgt15.json (seeds 1250..1289)
#     OVERLAP 40/40 with offline_rebrac_worldcomp_epoch_probe/test_40/single_u10_cross_tgt15.json (seeds 1250..1289)
#     OVERLAP 40/40 with offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json (seeds 1250..1289)
#     OVERLAP 100/100 with offline_rebrac_worldcomp_final/test_100/single_u10_cross_tgt15.json (seeds 1250..1349)
#     OVERLAP 40/40 with offline_rebrac_worldcomp_final/val_40/single_u10_cross_tgt15.json (seeds 1250..1289)
#     OVERLAP 30/30 with single_u10_cross_tgt15.json (seeds 1250..1279)
#     OVERLAP 100/100 with single_u10_cross_tgt15_ep100.json (seeds 1250..1349)
# [clean  ] crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_noise0p05clip0p15_ep1000  seeds 0..999
# [OVERLAP] crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_noise0p05clip0p15_ep2000  seeds 0..1999
#     OVERLAP 100/100 with clean_probe/_repro_check_s1250.json (seeds 1250..1349)
#     OVERLAP 100/100 with offline_rebrac_broad/test_100/single_u10_cross_tgt15.json (seeds 1250..1349)
#     OVERLAP 40/40 with offline_rebrac_broad/val_40/single_u10_cross_tgt15.json (seeds 1250..1289)
#     OVERLAP 100/100 with offline_rebrac_screen/test_100/single_u10_cross_tgt15.json (seeds 1250..1349)
#     OVERLAP 40/40 with offline_rebrac_screen/val_40/single_u10_cross_tgt15.json (seeds 1250..1289)
#     OVERLAP 40/40 with offline_rebrac_worldcomp_epoch_probe/test_40/single_u10_cross_tgt15.json (seeds 1250..1289)
#     OVERLAP 40/40 with offline_rebrac_worldcomp_epoch_probe/val_40/single_u10_cross_tgt15.json (seeds 1250..1289)
#     OVERLAP 100/100 with offline_rebrac_worldcomp_final/test_100/single_u10_cross_tgt15.json (seeds 1250..1349)
#     OVERLAP 40/40 with offline_rebrac_worldcomp_final/val_40/single_u10_cross_tgt15.json (seeds 1250..1289)
#     OVERLAP 30/30 with single_u10_cross_tgt15.json (seeds 1250..1279)
#     OVERLAP 100/100 with single_u10_cross_tgt15_ep100.json (seeds 1250..1349)
# [clean  ] crosscomp_s0_h4_efficiency_v2_re150_u10upstream_fixdone_ep1000  seeds 0..999
# [clean  ] crosscomp_s0_h4_efficiency_v2_re150tandem_u10cross_fixdone_ep1000  seeds 0..999
# [clean  ] crosscomp_s0_h4_effv2_re150_u10cross  seeds 0..499
# [clean  ] crosscomp_s1_h4_efficiency_v2_re150_u10cross_fixdone_ep1000  seeds 0..999
# [clean  ] crosscomp_s1_h4_efficiency_v2_re150_u10upstream_fixdone_ep1000  seeds 0..999
# [clean  ] crosscomp_s2_h4_efficiency_v2_re150_u10cross_fixdone_ep1000  seeds 0..999
# [clean  ] goalseek_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000  seeds 0..999
# [clean  ] mix5050_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000  seeds 0..999
# [clean  ] mix_tmp_crosscomp_500ep_seed1  seeds 1..500
# [clean  ] mix_tmp_goalseek_500ep_seed0  seeds 0..499
# [clean  ] privileged_s0_h4_arrival_v2_re150_u10cross_fixdone_ep1000  seeds 0..999
# [clean  ] privileged_s0_h4_arrival_v2_re250_u15cross_fixdone_ep1000  seeds 0..999
# [clean  ] privileged_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000  seeds 0..999
# [clean  ] sac_expert_s0_h4_arrival_v2_re150_u10cross_seed46_step600k_ep1000  seeds 0..999
# [clean  ] sac_medium_s0_h4_arrival_v2_re150_u10cross_seed46_step425k_ep1000  seeds 0..999
# [clean  ] sac_mexp_s0_h4_arrival_v2_re150_u10cross_seed46_step575k_ep1000  seeds 0..999
# [clean  ] sac_random_s0_h4_arrival_v2_re150_u10cross_seed46_step25k_ep1000  seeds 0..999
# [clean  ] worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone  seeds 0..999
# [clean  ] worldcomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_ep1000  seeds 0..999
#
# Overlap means the evaluation episode is a training episode: same seed, same reset.

# %%
# 若上一格报出含噪 2000 相交，用实例级比对钉死（重放 reset RNG，不跑仿真）
NOISY_2000 = "crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_noise0p05clip0p15_ep2000"
import os
if os.path.isdir(f"offline_data/{NOISY_2000}"):
    # !python -m scripts.audit_seed_overlap --verify {NOISY_2000} single_u10_cross_tgt15_ep100
else:
    print(f"{NOISY_2000} 不在 Drive 侧 offline_data/ 下；若确已删除，则该读数无法再复核，")
    print("§5.6.2 的 noisy-support 段只能走披露路线。")
# Out:
# dataset : crosscomp_s0_h4_efficiency_v2_re150_u10cross_fixdone_noise0p05clip0p15_ep2000  seeds 0..1999
# manifest: single_u10_cross_tgt15_ep100.json  100 episodes
# seeds in both ranges     : 100/100
# identical task instances : 100/100

# %%
# ⚠ 枚举修复（2026-08-16 首轮探针发现）：上面 range pass 报 24 个数据集、只有一个 OVERLAP，
#   但同一次会话里 --verify 按路径直读到了含噪 2000 的 metadata.json 并判出 100/100 污染，
#   而它从未出现在那 24 行里 —— glob 的目录列举是残缺的（多半是 Drive FUSE 分页/缓存）。
#   于是「只有一个数据集受影响」这个结论作废。这里改用 listdir 逐名 stat，重建全集后就地重判。
import os, json
from pathlib import Path
import scripts.audit_seed_overlap as A

ODD = Path("offline_data")
glob_names = {p.parent.name for p in ODD.glob("*/metadata.json")}
list_names = {n for n in os.listdir(ODD) if (ODD / n / "metadata.json").is_file()}

print(f"glob 命中 {len(glob_names)} 个；listdir 逐名 stat 命中 {len(list_names)} 个")
print("glob 漏掉：", sorted(list_names - glob_names) or "（无）")
if glob_names - list_names:
    print("listdir 漏掉：", sorted(glob_names - list_names))

manifests = A._load_manifests()
print(f"\n=== 以 listdir 全集（{len(list_names)} 个）重跑 range 判定 · manifests {len(manifests)} 份 ===")
overlapped = []
for name in sorted(list_names):
    meta = json.loads((ODD / name / "metadata.json").read_text(encoding="utf-8"))
    base, eps = int(meta.get("seed") or 0), int(meta.get("num_episodes") or 0)
    train = set(range(base, base + eps))
    flags = []
    for mname, man in manifests.items():
        if A._task_key_dataset(meta) != A._task_key_manifest(man):
            continue
        ev = {int(e["seed"]) for e in man["episodes"]}
        sh = sorted(ev & train)
        if sh:
            flags.append(f"    OVERLAP {len(sh)}/{len(ev)} with {mname} (seeds {sh[0]}..{sh[-1]})")
    print(f"[{'OVERLAP' if flags else 'clean  '}] {name}  seeds {base}..{base + eps - 1}")
    for f in flags:
        print(f)
    if flags:
        overlapped.append(name)

print(f"\n受影响数据集 {len(overlapped)} / {len(list_names)}：")
for n in overlapped:
    print("  ", n)
print("\n注：range 相交只是必要条件，实例级确认要走 --verify（同种子 ⇒ 同 reset，实践上必然相同）。")

# %% [markdown]
# ## 3. ①-c —— 干净 manifest 补评（**首轮探针已放行**）
#
# 只有在**训练区间 0-1999** 与**现测试集 1250-1349** 都不相交的评估集上，才能测出 ① 的污染幅度 δ。
#
# - 配方本机已验证：`scripts/generate_benchmark_manifest.py --seed 1250` 逐条重现现有
#   `benchmarks/single_u10_cross_tgt15_ep100.json`（100/100，`flow_time`/`start_xy`/`goal_xy`/
#   `initial_heading` 全等）→ 换 `--seed 3000` 即得等价但不相交的评估集。**零改代码。**
# - **1000 与 2000 两格必须同 manifest** —— 翻转是两格之差，只补 2000 而拿 1000 的旧数字比是混口径。
# - 只评估、不训练：`scripts.evaluate_offline` 从 `trainer_state.json` 读回全部协议设定。
#
# **口径提醒（首轮探针新增）**：被补评的检查点，其选点用的 40 条 val 在 2000 格上**本身就是训练
# episode**（① 与 ③ 在该格叠加，见 `docs/data_integrity_open_items.md` 第 1 节）。因此这里测到的 δ
# 是 **①③ 合并效应**，不是纯粹的训练集污染——这恰好是正确的口径，两条本就要合成一批整改。
#
# 另：干净集自带一份未知的**固有难度偏移**（首轮已实测到这种偏移的存在——从未做过任何选点的采集器
# 基线，在前 40 条与后 60 条之间也差 −8.3 pp）。所以**单格 δ 的绝对值不可尽信**，真正承重的读数是
# 下面 3c 里**同一份干净集上 2000 与 1000 的配对差**。

# %%
RUN_CLEAN_PROBE = True    # 2026-08-16 首轮探针：§1 判定 READY（10/10 选中检查点在位）→ 已放开
CLEAN_SEED      = 3000    # 训练 0..1999 / 现测试集 1250..1349 之外

# %%
import json, subprocess
from pathlib import Path

FLOW = "wake_data/wake_v8_U1p00_Re150_D12p00_dx0p60_Ti5pct_1200f_roi.npy"
CLEAN_MANIFEST = Path(f"benchmarks/clean_probe/single_u10_cross_tgt15_ep100_s{CLEAN_SEED}.json")
REPRO_MANIFEST = Path("benchmarks/clean_probe/_repro_check_s1250.json")


def run(cmd):
    """Stream a subprocess into the cell output. Colab hides inherited stderr — the
    first attempt at this notebook failed with a bare CalledProcessError and no message."""
    proc = subprocess.Popen(cmd, stdout=subprocess.PIPE, stderr=subprocess.STDOUT,
                            text=True, bufsize=1)
    tail = []
    for line in proc.stdout:
        print(line, end="")
        tail.append(line)
    rc = proc.wait()
    if rc != 0:
        raise RuntimeError(f"exit {rc}: {' '.join(cmd)}\n--- last 20 lines ---\n{''.join(tail[-20:])}")


# 协议参数从检查点自身读，别写死：manifest 头部的 probe_layout / history_length 与检查点不符时
# evaluate_offline 会直接抛 ValueError（这正是第一次跑挂掉的原因 —— 缺 --history-length，
# 默认写进了 1，而检查点是 4）。已刊 manifest 由 generate_standard_benchmarks.py 生成，
# 这两个字段是 null，那道断言从未触发过；本 CLI 发不出 null，于是填真值，等于多一道防呆。
_ts = json.loads((Path(PROBE_A[("cross-1000", 42)]["run_dir"]) / "trainer_state.json").read_text())
PROBE_LAYOUT   = str(_ts.get("probe_layout") or "s0")
HISTORY_LENGTH = int(_ts.get("history_length") or 4)
print(f"检查点协议：probe_layout={PROBE_LAYOUT}  history_length={HISTORY_LENGTH}")


def gen_manifest(seed, out):
    out.parent.mkdir(parents=True, exist_ok=True)
    run([
        "python", "-m", "scripts.generate_benchmark_manifest",
        "--flow", FLOW,
        "--probe-layout", PROBE_LAYOUT,
        "--history-length", str(HISTORY_LENGTH),
        "--task-geometry", "cross_stream",
        "--target-speed", "1.5",
        "--initial-speed", "0.3",
        "--episodes", "100",
        "--seed", str(seed),
        "--output", str(out),
    ])


if RUN_CLEAN_PROBE:
    # 3a. 自检：同种子必须逐条重现现有 manifest，否则配方与原始生成环境不一致，后面全部作废。
    #     注意这一步也在验"任务实例与 history_length 无关"——上一版自检用的是默认 1，本版用 4，
    #     若仍 100/100 即证实例不随协议参数漂移。
    gen_manifest(1250, REPRO_MANIFEST)
    a = json.loads(Path("benchmarks/single_u10_cross_tgt15_ep100.json").read_text())["episodes"]
    b = json.loads(REPRO_MANIFEST.read_text())["episodes"]
    KEYS = ["flow_time", "start_xy", "goal_xy", "initial_heading"]
    def same(x, y):
        if x["seed"] != y["seed"]:
            return False
        for k in KEYS:
            u, v = x["reset_options"][k], y["reset_options"][k]
            if isinstance(u, list):
                if any(abs(p - q) > 1e-9 for p, q in zip(u, v)):
                    return False
            elif abs(u - v) > 1e-9:
                return False
        return True
    n_same = sum(same(x, y) for x, y in zip(a, b))
    print(f"\n配方自检：{n_same}/100 逐条相同")
    assert n_same == 100, "配方与原始 manifest 不一致 —— 停下，不要继续补评"

    # 3b. 生成干净集
    gen_manifest(CLEAN_SEED, CLEAN_MANIFEST)
    cm = json.loads(CLEAN_MANIFEST.read_text())
    seeds_new = {e["seed"] for e in cm["episodes"]}
    assert not (seeds_new & set(range(0, 2000))),    "与训练区间 0..1999 相交"
    assert not (seeds_new & set(range(1250, 1350))), "与现测试集相交"
    assert cm.get("history_length") == HISTORY_LENGTH, cm.get("history_length")
    assert cm.get("probe_layout") == PROBE_LAYOUT, cm.get("probe_layout")
    print(f"\n干净集 OK：{len(seeds_new)} 条，种子 {min(seeds_new)}..{max(seeds_new)}，"
          f"与两个区间均不相交；协议头 {PROBE_LAYOUT}/h{HISTORY_LENGTH} 与检查点一致")
else:
    print("RUN_CLEAN_PROBE = False —— 跳过。先看 §1 §2 的结果。")
# Out:
# 检查点协议：probe_layout=s0  history_length=4
# [done] wrote benchmark manifest with 100 episodes to benchmarks/clean_probe/_repro_check_s1250.json
#   flow=wake_data/wake_v8_U1p00_Re150_D12p00_dx0p60_Ti5pct_1200f_roi.npy
#   probe_layout=s0 history_length=4
#
# 配方自检：100/100 逐条相同
# [done] wrote benchmark manifest with 100 episodes to benchmarks/clean_probe/single_u10_cross_tgt15_ep100_s3000.json
#   flow=wake_data/wake_v8_U1p00_Re150_D12p00_dx0p60_Ti5pct_1200f_roi.npy
#   probe_layout=s0 history_length=4
#
# 干净集 OK：100 条，种子 3000..3099，与两个区间均不相交；协议头 s0/h4 与检查点一致

# %%
OUT_ROOT = Path("results/offline/rebrac/clean_probe")

if RUN_CLEAN_PROBE:
    assert READY, "§1 未通过：选中检查点不全，不能补评"
    for (label, seed), info in PROBE_A.items():
        out_json = OUT_ROOT / label / f"seed_{seed}.json"
        if out_json.exists():
            print(f"[skip] {out_json}")
            continue
        out_json.parent.mkdir(parents=True, exist_ok=True)
        print(f"\n=== [eval] {label} seed {seed} — {info['agent_file']} ===")
        run([
            "python", "-m", "scripts.evaluate_offline",
            "--checkpoint", info["run_dir"],
            "--agent-file", info["agent_file"],
            "--manifest", str(CLEAN_MANIFEST),
            "--output-json", str(out_json),
            "--device", "cuda",
            "--num-workers", "6",
            "--worker-device", "cpu",
        ])
    print("\n补评完成")
else:
    print("RUN_CLEAN_PROBE = False —— 跳过。")
# Out:
# === [eval] cross-1000 seed 42 — agent_step_00033432.pt ===
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 100
# success_rate          : 85.0%
# avg_return            : -42.01 +/- 42.03
# avg_safety_cost       : 13.650 +/- 8.698
# avg_time_s            : 77.59 +/- 20.36
# avg_time_s_success    : 83.04
# avg_energy            : 48124.74 +/- 12661.53
# avg_path_length_m     : 58.60 +/- 10.88
# avg_progress_ratio    : 0.812 +/- 0.241
# avg_path_efficiency   : 0.610 +/- 0.185
# termination           : {'goal': 85, 'out_of_bounds': 15}
# benchmark_manifest    : benchmarks/clean_probe/single_u10_cross_tgt15_ep100_s3000.json
#
# === [eval] cross-1000 seed 43 — agent_step_00033432.pt ===
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 100
# success_rate          : 89.0%
# avg_return            : -34.60 +/- 42.84
# avg_safety_cost       : 12.913 +/- 13.046
# avg_time_s            : 76.86 +/- 20.54
# avg_time_s_success    : 80.93
# avg_energy            : 47765.61 +/- 12815.49
# avg_path_length_m     : 58.22 +/- 11.69
# avg_progress_ratio    : 0.837 +/- 0.214
# avg_path_efficiency   : 0.635 +/- 0.172
# termination           : {'goal': 89, 'out_of_bounds': 11}
# benchmark_manifest    : benchmarks/clean_probe/single_u10_cross_tgt15_ep100_s3000.json
#
# === [eval] cross-1000 seed 44 — agent_step_00033432.pt ===
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 100
# success_rate          : 84.0%
# avg_return            : -44.32 +/- 64.55
# avg_safety_cost       : 12.402 +/- 8.442
# avg_time_s            : 78.02 +/- 25.04
# avg_time_s_success    : 81.38
# avg_energy            : 48762.30 +/- 16142.17
# avg_path_length_m     : 59.50 +/- 15.14
# avg_progress_ratio    : 0.801 +/- 0.272
# avg_path_efficiency   : 0.606 +/- 0.199
# termination           : {'goal': 84, 'out_of_bounds': 16}
# benchmark_manifest    : benchmarks/clean_probe/single_u10_cross_tgt15_ep100_s3000.json
#
# === [eval] cross-1000 seed 45 — agent_final.pt ===
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 100
# success_rate          : 88.0%
# avg_return            : -39.74 +/- 41.49
# avg_safety_cost       : 13.949 +/- 11.065
# avg_time_s            : 78.54 +/- 20.80
# avg_time_s_success    : 83.22
# avg_energy            : 48935.84 +/- 13036.83
# avg_path_length_m     : 59.05 +/- 11.35
# avg_progress_ratio    : 0.829 +/- 0.226
# avg_path_efficiency   : 0.618 +/- 0.174
# termination           : {'goal': 88, 'out_of_bounds': 12}
# benchmark_manifest    : benchmarks/clean_probe/single_u10_cross_tgt15_ep100_s3000.json
#
# === [eval] cross-1000 seed 46 — agent_step_00028656.pt ===
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 100
# success_rate          : 85.0%
# avg_return            : -38.76 +/- 73.83
# avg_safety_cost       : 12.781 +/- 12.789
# avg_time_s            : 75.52 +/- 25.30
# avg_time_s_success    : 77.55
# avg_energy            : 47083.99 +/- 15756.06
# avg_path_length_m     : 59.37 +/- 20.37
# avg_progress_ratio    : 0.788 +/- 0.349
# avg_path_efficiency   : 0.615 +/- 0.215
# termination           : {'goal': 85, 'timeout': 1, 'out_of_bounds': 14}
# benchmark_manifest    : benchmarks/clean_probe/single_u10_cross_tgt15_ep100_s3000.json
#
# === [eval] cross-2000 seed 42 — agent_step_00066752.pt ===
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 100
# success_rate          : 89.0%
# avg_return            : -36.84 +/- 38.89
# avg_safety_cost       : 14.025 +/- 10.729
# avg_time_s            : 77.80 +/- 19.26
# avg_time_s_success    : 82.02
# avg_energy            : 48454.55 +/- 12112.17
# avg_path_length_m     : 58.53 +/- 10.91
# avg_progress_ratio    : 0.834 +/- 0.219
# avg_path_efficiency   : 0.627 +/- 0.170
# termination           : {'goal': 89, 'out_of_bounds': 11}
# benchmark_manifest    : benchmarks/clean_probe/single_u10_cross_tgt15_ep100_s3000.json
#
# === [eval] cross-2000 seed 43 — agent_step_00066752.pt ===
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 100
# success_rate          : 87.0%
# avg_return            : -42.62 +/- 73.65
# avg_safety_cost       : 14.057 +/- 14.156
# avg_time_s            : 79.11 +/- 26.48
# avg_time_s_success    : 79.78
# avg_energy            : 49399.64 +/- 16869.31
# avg_path_length_m     : 60.04 +/- 16.89
# avg_progress_ratio    : 0.818 +/- 0.243
# avg_path_efficiency   : 0.621 +/- 0.193
# termination           : {'goal': 87, 'out_of_bounds': 13}
# benchmark_manifest    : benchmarks/clean_probe/single_u10_cross_tgt15_ep100_s3000.json
#
# === [eval] cross-2000 seed 44 — agent_step_00057216.pt ===
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 100
# success_rate          : 86.0%
# avg_return            : -45.18 +/- 75.55
# avg_safety_cost       : 13.630 +/- 12.307
# avg_time_s            : 79.68 +/- 27.19
# avg_time_s_success    : 80.70
# avg_energy            : 49667.90 +/- 17341.04
# avg_path_length_m     : 59.47 +/- 14.39
# avg_progress_ratio    : 0.809 +/- 0.278
# avg_path_efficiency   : 0.617 +/- 0.203
# termination           : {'goal': 86, 'out_of_bounds': 14}
# benchmark_manifest    : benchmarks/clean_probe/single_u10_cross_tgt15_ep100_s3000.json
#
# === [eval] cross-2000 seed 45 — agent_step_00066752.pt ===
# reward_objective      : efficiency_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.250000
# episodes              : 100
# success_rate          : 83.0%
# avg_return            : -40.78 +/- 49.08
# avg_safety_cost       : 13.349 +/- 9.905
# avg_time_s            : 76.03 +/- 19.30
# avg_time_s_success    : 80.03
# avg_energy            : 47448.90 +/- 12147.73
# avg_path_length_m     : 58.41 +/- 10.94
# avg_progress_ratio    : 0.823 +/- 0.226
# avg_path_efficiency   : 0.621 +/- 0.175
# termination           : {'goal': 83, 'out_of_bounds': 17}
# benchmark_manifest    : benchmarks/clean_probe/single_u10_cross_tgt15_ep100_s3000.json
#
# === [eval] cross-2000 seed 46 — agent_step_00066752.pt ===

# %% [markdown]
# ### 3c. 读数与判定
#
# 判定门槛（依据 `paper/thesis_ch5/data_integrity_impact_assessment_review.md` §4 ★3）：
#
# - 章内真实断言是「**未再检出**回落」，不是「2000 > 1000」；
# - δ ≳ 2 pp → 「点估计反而略高」半句失效；
# - δ ≳ 5–7 pp → 才构成与 TD3+BC（−7.6 pp）/ 纯 BC（−5.4 pp）同量级的回落，翻转论述才真被推翻。
#
# 已刊值：cross-1000 = 0.902 ± 0.021、cross-2000 = 0.918 ± 0.030，差 **+1.6 pp**。
# 剔除参与选点的 40 条后（本机已算）：0.907 / 0.937，差 **+3.0 pp**，5/5 种子不为负。

# %%
import math

def load_cell(label):
    vals = []
    for seed in SEEDS:
        p = OUT_ROOT / label / f"seed_{seed}.json"
        if p.exists():
            vals.append((seed, json.loads(p.read_text(encoding="utf-8"))["eval_success_rate"]))
    return vals

if RUN_CLEAN_PROBE:
    PUBLISHED = {"cross-1000": 0.902, "cross-2000": 0.918}
    means = {}
    for label in CELLS:
        vals = load_cell(label)
        if not vals:
            print(f"{label}: 无结果"); continue
        xs = [v for _, v in vals]
        m  = sum(xs) / len(xs)
        sd = math.sqrt(sum((x - m) ** 2 for x in xs) / len(xs))   # 总体口径，与章内刊值一致
        means[label] = xs
        print(f"{label}: 逐种子 {[round(x, 3) for x in xs]}  干净集 {m:.4f} ± {sd:.4f}  "
              f"已刊 {PUBLISHED[label]:.3f}  δ = {100 * (PUBLISHED[label] - m):+.1f} pp")

    if len(means) == 2:
        a, b = means["cross-2000"], means["cross-1000"]
        d = [x - y for x, y in zip(a, b)]
        md_ = sum(d) / len(d)
        sd_ = math.sqrt(sum((x - md_) ** 2 for x in d) / (len(d) - 1))
        se  = sd_ / math.sqrt(len(d))
        print()
        print(f"干净集上的翻转：{sum(a)/len(a):.4f} 对 {sum(b)/len(b):.4f} = {100*md_:+.1f} pp")
        print(f"  配对 t = {md_/se:+.3f}，95% CI = [{100*(md_-2.776*se):+.1f}, {100*(md_+2.776*se):+.1f}] pp")
        print(f"  逐种子差 {[round(x, 3) for x in d]}，其中不为负 {sum(x >= 0 for x in d)}/5")
        print()
        print("对照：已刊 100 回合 +1.6 pp（t=1.06，1 负种子）；剔除选点 40 条后 +3.0 pp（t=2.09，5/5 不为负）")
else:
    print("RUN_CLEAN_PROBE = False —— 跳过。")
# Out:
# cross-1000: 逐种子 [0.85, 0.89, 0.84, 0.88, 0.85]  干净集 0.8620 ± 0.0194  已刊 0.902  δ = +4.0 pp
# cross-2000: 逐种子 [0.89, 0.87, 0.86, 0.83, 0.9]  干净集 0.8700 ± 0.0245  已刊 0.918  δ = +4.8 pp
#
# 干净集上的翻转：0.8700 对 0.8620 = +0.8 pp
#   配对 t = +0.425，95% CI = [-4.4, +6.0] pp
#   逐种子差 [0.04, -0.02, 0.02, -0.05, 0.05]，其中不为负 3/5
#
# 对照：已刊 100 回合 +1.6 pp（t=1.06，1 负种子）；剔除选点 40 条后 +3.0 pp（t=2.09，5/5 不为负）

# %% [markdown]
# ## 4. 回传 git 的清单
#
# 只回传小文件，**不回传 `.pt`**：
#
# - `benchmarks/clean_probe/single_u10_cross_tgt15_ep100_s3000.json`（干净评估集，可复现凭据）
# - `results/offline/rebrac/clean_probe/**/seed_*.json`（10 份补评结果，含逐回合记录）
# - 本 notebook 的 `_completed` 版本
#
# `benchmarks/clean_probe/_repro_check_s1250.json` 是一次性自检产物，**不回传**。
#
# 回传后在本机：把读数写进 `docs/data_integrity_open_items.md` 第 ① 条，并按
# `paper/thesis_ch5/data_integrity_impact_assessment_review.md` §5 的 P4 把 ① 与 ③ 合成**一批**
# 整改（重流程只付一次）。**在那之前不要动任何 `.tex`。**
