# %% [markdown]
# # SAC arrival_v2 — single U=1.5 cross + upstream control rerun (seed=42, 1M, s1)
#
# **前情**：commit `f179c5b` / commit-after `1adee4e` 已闭环 arrival_v2 reward 在四个 benchmark 上的 vanilla SAC 验证（详见 [`docs/arrival_v2_experiment_report.md`](../docs/arrival_v2_experiment_report.md)）：
# - `single_u10_cross_tgt15` (s0/10-D, U=1.0, seed=46, 1M)         : 5/5 PASS
# - `single_u15_upstream_tgt15` (s1/12-D, U=1.5, seed=46, **1.5M**): 5/5 PASS  ← P1 v6
# - `tandem_u15_upstream_tgt15` (s1/12-D, U=1.5, seed=42, 1M)      : 5/5 PASS
# - `sbs_u15_upstream_tgt15`    (s1/12-D, U=1.5, seed=42, 1M)      : 5/5 PASS
#
# **本 notebook 任务（控制实验）**：作为 tandem/sbs 的拓扑横向对照，§3 P1 v6 (seed=46/1.5M) 与 §2 cross_u10 (U=1.0/seed=46) 在 seed/step/U 上都和 tandem/sbs 不一致，**confounded**。补两个**严格控制对照**：
# - Phase 1 — `single_u15_cross_tgt15`:    单柱 cross_stream, U=1.5, seed=42, **1.0M**
# - Phase 2 — `single_u15_upstream_tgt15`: 单柱 upstream,     U=1.5, seed=42, **1.0M**
#
# 补完后，§7.3 横向对照表的所有四组运行严格控制（s1 / k4 / U=1.5 / target=1.5 / arrival_v2 / seed=42 / 1M），唯一变量 = topology × geometry：
#
# | Run | Geometry | Topology |
# |---|---|---|
# | Phase 1 (本 notebook) | cross_stream | single |
# | Phase 2 (本 notebook) | upstream     | single |
# | §7.1 tandem  | upstream     | double tandem (G/D=3.5) |
# | §7.2 sbs     | upstream     | double side-by-side (G/D=3.5) |
#
# **配置矩阵**：
#
# | Phase | benchmark | flow | obs | total_steps | 预算 |
# |---|---|---|---|---:|---:|
# | 1 | `single_u15_cross_tgt15`    | `wake_v8_U1p50_Re250` | s1 / 12-D | 1.0M | ~2.5h L4 |
# | 2 | `single_u15_upstream_tgt15` | `wake_v8_U1p50_Re250` | s1 / 12-D | 1.0M | ~2.5h L4 |
#
# **Gate**（每个 phase 独立判定，与 P1 v6 §8.3 同口径）：
# - `final_success_rate ≥ 0.85`
# - `last100k_mean ≥ 0.9 × peak`
# - `final_oob_rate ≤ 0.10`
# - `include_episode_context_obs == True`
# - `timeout_bootstrap_semantics == 'terminal'`
#
# **Single seed**：`seed=42`（与 tandem/sbs 同步）。如果 1.0M 收敛了就闭环；如果某一 phase eval 曲线尚在上升，把对应的 `TOTAL_STEPS` 改大（如 1.5M）后重跑同一 cell — `--resume` 会自动从 `trainer_state.json` 续训。
#
# **注意**：Phase 2 (`single_u15_upstream_tgt15`) 与 §3 P1 v6 同一 benchmark，但 seed=42（vs §3 seed=46）+ budget=1M（vs §3 1.5M）。两次 run 输出在不同 seed 子目录下，互不覆盖。
#
# **输出根**：
# - Phase 1: `experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s1_k4/seed_42/`
# - Phase 2: `experiments/arrival_v2_prototype/single_u15_upstream_tgt15/arrival_v2/sac_vanilla/s1_k4/seed_42/`
#
# **风格**：训练用 `!python -u -m scripts.train_sac` 直跑（实时 stdout）。

# %% [markdown]
# ## 0. GPU sanity

# %%
# !nvidia-smi | head -10
import torch
print(f'torch={torch.__version__}  cuda={torch.cuda.is_available()}  '
      f'device={torch.cuda.get_device_name(0) if torch.cuda.is_available() else "cpu"}')
# Out:
# Fri May  8 14:17:27 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA L4                      Off |   00000000:00:03.0 Off |                    0 |
# | N/A   32C    P8             12W /   72W |       0MiB /  23034MiB |      0%      Default |
# torch=2.10.0+cu128  cuda=True  device=NVIDIA L4

# %% [markdown]
# ## 1. Mount Drive + cwd
#
# 和 commit `f179c5b` / `1adee4e` 同一个 working clone（含 arrival_v2 实现 + train_sac resume bug 修复 + tandem/sbs notebook 闭环）。

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

REPO_DIR = '/content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5'
# %cd $REPO_DIR
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5

# %% [markdown]
# ## 2. 通用配置 — Phase 1 (single_cross) + Phase 2 (single_upstream)
#
# 唯一变量是 `task_geometry` (cross_stream vs upstream) + `benchmark_key`。所有 SAC / env / reward 超参与 tandem/sbs 完全一致（s1 / k4 / seed=42 / num_envs=6 / arrival_v2），便于做严格控制对照。
#
# 若某 phase 1.0M 不够，把对应 `TOTAL_STEPS` 改成 `1_500_000` 或 `2_000_000` 后重跑该 phase 的 train cell — skip/resume 逻辑会自动续训。

# %%
import json
import os
from pathlib import Path

import pandas as pd

# ==== 全局 SAC / env config (两个 phase 共用) ====
OBJECTIVE = 'arrival_v2'
PROBE_LAYOUT = 's1'
HISTORY_LENGTH = 4
TARGET_SPEED = 1.5
SEED = 42

RANDOM_STEPS = 5_000
UPDATE_AFTER = 5_000
BATCH_SIZE = 256
HIDDEN_DIM = 256
NUM_ENVS = 6
EVAL_EVERY = 25_000
EVAL_EPISODES = 30
CHECKPOINT_EVERY = 100_000
DEVICE = 'cuda'

PASS_FINAL_SUCCESS = 0.85
PASS_LAST100_RATIO = 0.90
PASS_OOB_RATE = 0.10

# Single U=1.5 flow file (shared by both phases)
SHARED_FLOW_PATH = 'wake_data/wake_v8_U1p50_Re250_D12p00_dx0p60_Ti5pct_1200f_roi.npy'

# ==== Phase 1 — single_cross ====
C_BENCHMARK_KEY = 'single_u15_cross_tgt15'
C_TASK_GEOMETRY = 'cross_stream'
C_FLOW_PATH = SHARED_FLOW_PATH
C_TOTAL_STEPS = 1_000_000           # 起步 1M;不够就改大重跑此 cell
C_RUN_ROOT = Path('experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s1_k4/seed_42')
C_CKPT_ROOT = Path('checkpoints/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s1_k4/seed_42')
C_MANIFEST_PATH = Path(f'benchmarks/{C_BENCHMARK_KEY}.json')
C_RUN_ROOT_STR = str(C_RUN_ROOT)
C_CKPT_ROOT_STR = str(C_CKPT_ROOT)
C_MANIFEST_PATH_STR = str(C_MANIFEST_PATH)

# ==== Phase 2 — single_upstream ====
U_BENCHMARK_KEY = 'single_u15_upstream_tgt15'
U_TASK_GEOMETRY = 'upstream'
U_FLOW_PATH = SHARED_FLOW_PATH
U_TOTAL_STEPS = 1_000_000           # 起步 1M
U_RUN_ROOT = Path('experiments/arrival_v2_prototype/single_u15_upstream_tgt15/arrival_v2/sac_vanilla/s1_k4/seed_42')
U_CKPT_ROOT = Path('checkpoints/arrival_v2_prototype/single_u15_upstream_tgt15/arrival_v2/sac_vanilla/s1_k4/seed_42')
U_MANIFEST_PATH = Path(f'benchmarks/{U_BENCHMARK_KEY}.json')
U_RUN_ROOT_STR = str(U_RUN_ROOT)
U_CKPT_ROOT_STR = str(U_CKPT_ROOT)
U_MANIFEST_PATH_STR = str(U_MANIFEST_PATH)

os.environ['PYTHONUNBUFFERED'] = '1'

print('---- Phase 1 (single_cross) ----')
print(f'  benchmark    = {C_BENCHMARK_KEY}')
print(f'  flow         = {C_FLOW_PATH}')
print(f'  probe        = {PROBE_LAYOUT} / {C_TASK_GEOMETRY} / target={TARGET_SPEED}')
print(f'  total_steps  = {C_TOTAL_STEPS:,} (initial; bump and re-run if not converged)')
print(f'  run_root     = {C_RUN_ROOT}')
print(f'  ckpt_root    = {C_CKPT_ROOT}')
print()
print('---- Phase 2 (single_upstream) ----')
print(f'  benchmark    = {U_BENCHMARK_KEY}')
print(f'  flow         = {U_FLOW_PATH}')
print(f'  probe        = {PROBE_LAYOUT} / {U_TASK_GEOMETRY} / target={TARGET_SPEED}')
print(f'  total_steps  = {U_TOTAL_STEPS:,} (initial)')
print(f'  run_root     = {U_RUN_ROOT}')
print(f'  ckpt_root    = {U_CKPT_ROOT}')
print()
print(f'  seed={SEED}  num_envs={NUM_ENVS}  eval_every={EVAL_EVERY:,}  eval_episodes={EVAL_EPISODES}')
print()
print('NOTE: Phase 2 与 §3 P1 v6 同 benchmark; seed=42 子目录与 §3 seed=46 互不覆盖。')
# Out:
# ---- Phase 1 (single_cross) ----
#   benchmark    = single_u15_cross_tgt15
#   flow         = wake_data/wake_v8_U1p50_Re250_D12p00_dx0p60_Ti5pct_1200f_roi.npy
#   probe        = s1 / cross_stream / target=1.5
#   total_steps  = 1,000,000 (initial; bump and re-run if not converged)
#   run_root     = experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s1_k4/seed_42
#   ckpt_root    = checkpoints/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s1_k4/seed_42
#
# ---- Phase 2 (single_upstream) ----
#   benchmark    = single_u15_upstream_tgt15
#   flow         = wake_data/wake_v8_U1p50_Re250_D12p00_dx0p60_Ti5pct_1200f_roi.npy
#   probe        = s1 / upstream / target=1.5
#   total_steps  = 1,000,000 (initial)
#   run_root     = experiments/arrival_v2_prototype/single_u15_upstream_tgt15/arrival_v2/sac_vanilla/s1_k4/seed_42
#   ckpt_root    = checkpoints/arrival_v2_prototype/single_u15_upstream_tgt15/arrival_v2/sac_vanilla/s1_k4/seed_42
#
#   seed=42  num_envs=6  eval_every=25,000  eval_episodes=30
#
# NOTE: Phase 2 与 §3 P1 v6 同 benchmark; seed=42 子目录与 §3 seed=46 互不覆盖。

# %% [markdown]
# ## 3. Preflight — flow files / arrival_v2 candidate gate / reward unit tests / manifests
#
# 停止条件：
# - 任一 phase flow 缺失 → raise（用户已确认 Drive 有；此处兜底）
# - `validate_arrival_v2_candidate` 失败 → reward 公式不再满足 discounted unsafe-shortcut / terminal dominance
# - `test_reward_objective.py` 失败 → reward 实现退化
# - 任一 manifest 生成失败 → eval 不可重复

# %%
# 两个 phase 共用同一个 single U=1.5 flow file; 检查一次即可
p = Path(SHARED_FLOW_PATH)
if not p.exists():
    raise FileNotFoundError(f'missing single U=1.5 flow file: {p}')
print(f'[OK] shared flow: {p} ({p.stat().st_size / 1e6:.1f} MB)')
# Out:
# [OK] shared flow: wake_data/wake_v8_U1p50_Re250_D12p00_dx0p60_Ti5pct_1200f_roi.npy (230.4 MB)

# %%
# !python -u -m scripts.validate_arrival_v2_candidate
# Out:
# [undiscounted]
# fast_success       144.473
# slow_success       142.023
# unsafe_success      91.048
# timeout_near      -149.800
# timeout_far       -229.800
# late_oob          -274.500
# fast_oob          -280.325
# mid_oob           -319.450
#
# [discounted_gamma_0.995]
# fast_success        88.578
# slow_success        54.683
# unsafe_success      34.857
# timeout_near       -39.480
# timeout_far        -58.269
# late_oob          -103.800
# mid_oob           -190.006
# fast_oob          -212.555
#
# [discounted_shortcut] safe=69.330 risky=62.361
#
# PASS: arrival_v2 candidate pre-integration gates passed.

# %%
# !python -u -m pytest tests/test_reward_objective.py -q
# Out:
# ...............                                                          [100%]
# 15 passed in 20.25s

# %%
for key, mp in ((C_BENCHMARK_KEY, C_MANIFEST_PATH), (U_BENCHMARK_KEY, U_MANIFEST_PATH)):
    if not mp.exists():
        # !python -u -m scripts.generate_standard_benchmarks --benchmarks {key} --episodes {EVAL_EPISODES}
    if not mp.exists():
        raise FileNotFoundError(f'manifest not generated: {mp}')
    print(f'[OK] manifest ready: {mp}')
# Out:
# [OK] manifest ready: benchmarks/single_u15_cross_tgt15.json
# [OK] manifest ready: benchmarks/single_u15_upstream_tgt15.json

# %% [markdown]
# ## 4. Phase 1 — single_cross train (1.0M, fresh start with skip/resume)
#
# Skip/resume 逻辑：
# - `env_step >= C_TOTAL_STEPS` → skip（重跑此 cell 不会重训；要继续训需把 `C_TOTAL_STEPS` 改大后重跑此 cell + 上面 config cell）
# - `0 < env_step < C_TOTAL_STEPS` → 用 `--resume` 续训（中断重连）
# - `env_step == 0` → fresh start
#
# 训练时长（L4 / num_envs=6 / 1M steps）≈ 2.5h。Colab Pro+ 5h session 应可吃下两个 phase。

# %%
c_state_path = C_RUN_ROOT / 'trainer_state.json'
if c_state_path.exists():
    c_state = json.loads(c_state_path.read_text(encoding='utf-8'))
    c_current_step = int(c_state.get('env_step', 0))
else:
    c_current_step = 0
print(f'[state] single_cross env_step = {c_current_step:,} / target {C_TOTAL_STEPS:,}')

if c_current_step >= C_TOTAL_STEPS:
    print(f'[skip] single_cross already trained to {c_current_step:,} >= {C_TOTAL_STEPS:,}')
    print('       要继续训:把 C_TOTAL_STEPS 改大,重跑 config cell + 此 cell')
elif c_current_step > 0:
    print(f'[resume] single_cross continuing from {c_current_step:,} -> {C_TOTAL_STEPS:,}')
    # !python -u -m scripts.train_sac \
        --resume {C_RUN_ROOT_STR} \
        --total-steps {C_TOTAL_STEPS} \
        --eval-every {EVAL_EVERY} \
        --eval-episodes {EVAL_EPISODES} \
        --checkpoint-every {CHECKPOINT_EVERY} \
        --eval-manifest {C_MANIFEST_PATH_STR} \
        --device {DEVICE}
else:
    print(f'[train] single_cross fresh start -> {C_TOTAL_STEPS:,}')
    # !python -u -m scripts.train_sac \
        --flow {C_FLOW_PATH} \
        --task-geometry {C_TASK_GEOMETRY} \
        --target-speed {TARGET_SPEED} \
        --objective {OBJECTIVE} \
        --probe-layout {PROBE_LAYOUT} \
        --history-length {HISTORY_LENGTH} \
        --total-steps {C_TOTAL_STEPS} \
        --random-steps {RANDOM_STEPS} \
        --update-after {UPDATE_AFTER} \
        --batch-size {BATCH_SIZE} \
        --hidden-dim {HIDDEN_DIM} \
        --num-envs {NUM_ENVS} \
        --eval-every {EVAL_EVERY} \
        --eval-episodes {EVAL_EPISODES} \
        --checkpoint-every {CHECKPOINT_EVERY} \
        --eval-manifest {C_MANIFEST_PATH_STR} \
        --seed {SEED} \
        --device {DEVICE} \
        --save-dir {C_RUN_ROOT_STR} \
        --checkpoint-dir {C_CKPT_ROOT_STR}
# Out:
# [state] single_cross env_step = 0 / target 1,000,000
# [train] single_cross fresh start -> 1,000,000
# [train] episode=5 step=642 return=-251.36 success=False time=17.5s geometry=cross_stream history=4
# [train] episode=10 step=1122 return=-414.93 success=False time=93.3s geometry=cross_stream history=4
# [train] episode=15 step=1326 return=-520.75 success=False time=110.4s geometry=cross_stream history=4
# [train] episode=20 step=1878 return=-403.95 success=False time=61.3s geometry=cross_stream history=4
# [train] episode=25 step=2712 return=-340.63 success=False time=68.7s geometry=cross_stream history=4
# [train] episode=30 step=3330 return=-411.30 success=False time=38.1s geometry=cross_stream history=4
# [train] episode=35 step=3954 return=-267.16 success=False time=8.0s geometry=cross_stream history=4
# [train] episode=40 step=4350 return=-264.62 success=False time=11.7s geometry=cross_stream history=4
# [train] episode=45 step=5046 return=-429.74 success=False time=104.3s geometry=cross_stream history=4 | q1=510.865 actor=0.135 alpha=0.200
# [train] episode=50 step=5550 return=-346.04 success=False time=42.1s geometry=cross_stream history=4 | q1=1670.963 actor=3.197 alpha=0.195
# [train] episode=55 step=5934 return=-367.73 success=False time=31.1s geometry=cross_stream history=4 | q1=1326.005 actor=3.928 alpha=0.191
# [train] episode=60 step=6606 return=-322.92 success=False time=55.1s geometry=cross_stream history=4 | q1=1385.341 actor=4.395 alpha=0.185
# [train] episode=65 step=6996 return=-334.17 success=False time=26.8s geometry=cross_stream history=4 | q1=778.515 actor=6.158 alpha=0.182
# [train] episode=70 step=7722 return=-356.09 success=False time=39.9s geometry=cross_stream history=4 | q1=551.125 actor=5.864 alpha=0.176
# [train] episode=75 step=8586 return=-438.38 success=False time=89.2s geometry=cross_stream history=4 | q1=1022.248 actor=7.352 alpha=0.171
# [train] episode=80 step=9048 return=-261.44 success=False time=4.6s geometry=cross_stream history=4 | q1=4.189 actor=8.202 alpha=0.168
# [train] episode=85 step=9450 return=-301.36 success=False time=18.4s geometry=cross_stream history=4 | q1=718.549 actor=9.156 alpha=0.166
# [train] episode=90 step=9966 return=-423.53 success=False time=114.5s geometry=cross_stream history=4 | q1=650.499 actor=11.168 alpha=0.163
# [train] episode=95 step=10614 return=-320.06 success=False time=56.6s geometry=cross_stream history=4 | q1=946.916 actor=11.902 alpha=0.159
# [train] episode=100 step=11046 return=-281.86 success=False time=17.9s geometry=cross_stream history=4 | q1=460.071 actor=12.288 alpha=0.157
# [train] episode=105 step=11472 return=-313.70 success=False time=34.7s geometry=cross_stream history=4 | q1=509.162 actor=12.159 alpha=0.154
# [train] episode=110 step=11784 return=-464.36 success=False time=100.1s geometry=cross_stream history=4 | q1=246.839 actor=13.253 alpha=0.152
# [train] episode=115 step=12366 return=-270.16 success=False time=38.4s geometry=cross_stream history=4 | q1=476.822 actor=14.962 alpha=0.147
# [train] episode=120 step=12882 return=-264.32 success=False time=16.9s geometry=cross_stream history=4 | q1=469.538 actor=16.150 alpha=0.142
# [train] episode=125 step=13284 return=-420.25 success=False time=63.5s geometry=cross_stream history=4 | q1=921.205 actor=16.928 alpha=0.139
# [train] episode=130 step=13608 return=-359.73 success=False time=35.0s geometry=cross_stream history=4 | q1=445.795 actor=17.782 alpha=0.136
# [train] episode=135 step=14460 return=-304.50 success=False time=29.7s geometry=cross_stream history=4 | q1=170.823 actor=19.310 alpha=0.130
# [train] episode=140 step=15222 return=-357.04 success=False time=58.5s geometry=cross_stream history=4 | q1=452.270 actor=22.715 alpha=0.125
# [train] episode=145 step=15810 return=-299.49 success=False time=47.1s geometry=cross_stream history=4 | q1=627.366 actor=23.202 alpha=0.122
# [train] episode=150 step=16260 return=-277.24 success=False time=22.3s geometry=cross_stream history=4 | q1=613.219 actor=23.893 alpha=0.120
# [train] episode=155 step=16698 return=-306.57 success=False time=35.7s geometry=cross_stream history=4 | q1=2.878 actor=23.896 alpha=0.117
# [train] episode=160 step=17286 return=-297.38 success=False time=31.8s geometry=cross_stream history=4 | q1=685.854 actor=25.269 alpha=0.114
# [train] episode=165 step=17748 return=-467.15 success=False time=94.1s geometry=cross_stream history=4 | q1=629.991 actor=26.305 alpha=0.111
# [train] episode=170 step=18504 return=-352.80 success=False time=66.3s geometry=cross_stream history=4 | q1=849.992 actor=28.900 alpha=0.107
# [train] episode=175 step=18906 return=-317.55 success=False time=21.0s geometry=cross_stream history=4 | q1=338.537 actor=27.544 alpha=0.104
# [train] episode=180 step=19464 return=-305.78 success=False time=57.9s geometry=cross_stream history=4 | q1=221.709 actor=29.565 alpha=0.101
# [train] episode=185 step=20166 return=-391.04 success=False time=64.7s geometry=cross_stream history=4 | q1=397.427 actor=31.096 alpha=0.098
# [train] episode=190 step=20796 return=-387.15 success=False time=87.5s geometry=cross_stream history=4 | q1=218.543 actor=32.110 alpha=0.096
# [train] episode=195 step=21348 return=-323.37 success=False time=32.1s geometry=cross_stream history=4 | q1=504.285 actor=33.350 alpha=0.093
# [train] episode=200 step=21858 return=-290.69 success=False time=46.0s geometry=cross_stream history=4 | q1=432.709 actor=35.370 alpha=0.092
# [train] episode=205 step=22770 return=-414.50 success=False time=96.2s geometry=cross_stream history=4 | q1=935.660 actor=38.640 alpha=0.088
# [train] episode=210 step=23340 return=-294.82 success=False time=51.7s geometry=cross_stream history=4 | q1=712.915 actor=37.113 alpha=0.086
# [train] episode=215 step=24324 return=-473.04 success=False time=87.9s geometry=cross_stream history=4 | q1=773.998 actor=38.101 alpha=0.082
# [train] episode=220 step=24600 return=-485.56 success=False time=95.9s geometry=cross_stream history=4 | q1=528.195 actor=41.246 alpha=0.081
# [eval] step=25002 objective=arrival_v2 return=-369.60 safety=22.058 success=0.00% time=57.6s energy=19724.0 path=91.2 prog=-1.27
# [train] episode=225 step=25338 return=-348.83 success=False time=68.3s geometry=cross_stream history=4 | q1=240.051 actor=39.596 alpha=0.079
# [train] episode=230 step=25800 return=-244.87 success=False time=32.1s geometry=cross_stream history=4 | q1=204.425 actor=39.725 alpha=0.077
# [train] episode=235 step=26364 return=-253.51 success=False time=28.8s geometry=cross_stream history=4 | q1=276.114 actor=40.187 alpha=0.076
# [train] episode=240 step=26952 return=-442.68 success=False time=95.5s geometry=cross_stream history=4 | q1=1009.616 actor=44.917 alpha=0.073
# [train] episode=245 step=27552 return=-410.25 success=False time=93.8s geometry=cross_stream history=4 | q1=209.221 actor=42.465 alpha=0.071
# [train] episode=250 step=28542 return=-487.10 success=False time=131.6s geometry=cross_stream history=4 | q1=159.005 actor=46.406 alpha=0.069
# [train] episode=255 step=29010 return=-356.93 success=False time=26.1s geometry=cross_stream history=4 | q1=369.378 actor=48.441 alpha=0.068
# [train] episode=260 step=29436 return=-383.72 success=False time=73.8s geometry=cross_stream history=4 | q1=220.800 actor=45.680 alpha=0.067
# [train] episode=265 step=29952 return=-265.24 success=False time=36.0s geometry=cross_stream history=4 | q1=588.322 actor=46.340 alpha=0.065
# [train] episode=270 step=31044 return=-273.42 success=False time=43.2s geometry=cross_stream history=4 | q1=205.535 actor=49.211 alpha=0.063
# [train] episode=275 step=31590 return=-327.25 success=False time=37.5s geometry=cross_stream history=4 | q1=355.499 actor=54.309 alpha=0.062
# [train] episode=280 step=32226 return=-437.93 success=False time=60.4s geometry=cross_stream history=4 | q1=246.437 actor=53.748 alpha=0.061
# [train] episode=285 step=32802 return=-251.94 success=False time=12.1s geometry=cross_stream history=4 | q1=398.452 actor=54.569 alpha=0.060
# [train] episode=290 step=33186 return=-239.13 success=False time=31.4s geometry=cross_stream history=4 | q1=586.829 actor=56.059 alpha=0.059
# [train] episode=295 step=34026 return=-300.61 success=False time=51.9s geometry=cross_stream history=4 | q1=274.762 actor=56.033 alpha=0.058
# [train] episode=300 step=34524 return=-303.88 success=False time=44.3s geometry=cross_stream history=4 | q1=115.287 actor=56.397 alpha=0.056
# [train] episode=305 step=35166 return=-287.24 success=False time=37.8s geometry=cross_stream history=4 | q1=306.421 actor=56.138 alpha=0.055
# [train] episode=310 step=35760 return=-412.04 success=False time=46.1s geometry=cross_stream history=4 | q1=217.977 actor=55.900 alpha=0.054
# [train] episode=315 step=36282 return=-282.79 success=False time=14.7s geometry=cross_stream history=4 | q1=13.518 actor=56.833 alpha=0.053
# [train] episode=320 step=36906 return=-598.13 success=False time=94.9s geometry=cross_stream history=4 | q1=191.552 actor=64.942 alpha=0.052
# [train] episode=325 step=37662 return=-499.67 success=False time=59.0s geometry=cross_stream history=4 | q1=562.128 actor=58.915 alpha=0.051
# [train] episode=330 step=37944 return=-312.61 success=False time=22.9s geometry=cross_stream history=4 | q1=1.431 actor=62.635 alpha=0.050
# [train] episode=335 step=38490 return=-375.60 success=False time=44.8s geometry=cross_stream history=4 | q1=264.650 actor=64.950 alpha=0.049
# [train] episode=340 step=39000 return=-269.22 success=False time=9.2s geometry=cross_stream history=4 | q1=106.975 actor=64.509 alpha=0.048
# [train] episode=345 step=39450 return=-357.18 success=False time=79.2s geometry=cross_stream history=4 | q1=135.103 actor=63.637 alpha=0.048
# [train] episode=350 step=40146 return=-319.48 success=False time=56.2s geometry=cross_stream history=4 | q1=382.908 actor=67.924 alpha=0.047
# [train] episode=355 step=40710 return=-306.29 success=False time=46.3s geometry=cross_stream history=4 | q1=402.375 actor=64.564 alpha=0.046
# [train] episode=360 step=41460 return=-266.25 success=False time=52.4s geometry=cross_stream history=4 | q1=772.614 actor=64.818 alpha=0.045
# [train] episode=365 step=42570 return=-224.03 success=False time=51.3s geometry=cross_stream history=4 | q1=204.159 actor=66.538 alpha=0.044
# [train] episode=370 step=43020 return=-258.32 success=False time=36.6s geometry=cross_stream history=4 | q1=156.364 actor=68.790 alpha=0.043
# [train] episode=375 step=43650 return=-292.67 success=False time=42.0s geometry=cross_stream history=4 | q1=268.162 actor=69.751 alpha=0.043
# [train] episode=380 step=44346 return=-502.89 success=False time=115.9s geometry=cross_stream history=4 | q1=141.517 actor=75.724 alpha=0.042
# [train] episode=385 step=44760 return=-224.38 success=False time=16.7s geometry=cross_stream history=4 | q1=221.142 actor=69.272 alpha=0.042
# [train] episode=390 step=45294 return=-252.70 success=False time=19.4s geometry=cross_stream history=4 | q1=287.453 actor=70.359 alpha=0.041
# [train] episode=395 step=45510 return=-443.30 success=False time=131.5s geometry=cross_stream history=4 | q1=475.118 actor=71.806 alpha=0.041
# [train] episode=400 step=46314 return=-363.58 success=False time=71.9s geometry=cross_stream history=4 | q1=449.275 actor=74.058 alpha=0.040
# [train] episode=405 step=46788 return=-339.00 success=False time=112.2s geometry=cross_stream history=4 | q1=139.242 actor=78.346 alpha=0.040
# [train] episode=410 step=47172 return=-261.07 success=False time=5.4s geometry=cross_stream history=4 | q1=478.041 actor=73.280 alpha=0.039
# [train] episode=415 step=47796 return=-530.57 success=False time=92.3s geometry=cross_stream history=4 | q1=434.565 actor=73.091 alpha=0.039
# [train] episode=420 step=48114 return=-350.24 success=False time=61.1s geometry=cross_stream history=4 | q1=431.796 actor=75.780 alpha=0.038
# [train] episode=425 step=48660 return=-403.97 success=False time=44.9s geometry=cross_stream history=4 | q1=395.682 actor=76.994 alpha=0.038
# [train] episode=430 step=49224 return=-260.04 success=False time=37.8s geometry=cross_stream history=4 | q1=397.741 actor=75.582 alpha=0.037
# [train] episode=435 step=49686 return=-398.82 success=False time=104.6s geometry=cross_stream history=4 | q1=267.477 actor=75.747 alpha=0.037
# [eval] step=50004 objective=arrival_v2 return=-314.79 safety=15.464 success=0.00% time=57.5s energy=29692.6 path=86.1 prog=-0.72
# [train] episode=440 step=50400 return=-405.58 success=False time=65.6s geometry=cross_stream history=4 | q1=427.915 actor=74.455 alpha=0.037
# [train] episode=445 step=51138 return=-345.44 success=False time=83.0s geometry=cross_stream history=4 | q1=295.458 actor=80.330 alpha=0.037
# [train] episode=450 step=51876 return=-350.11 success=False time=72.0s geometry=cross_stream history=4 | q1=157.437 actor=81.847 alpha=0.037
# [train] episode=455 step=52560 return=-389.87 success=False time=56.2s geometry=cross_stream history=4 | q1=235.004 actor=80.566 alpha=0.037
# [train] episode=460 step=53166 return=-408.04 success=False time=67.5s geometry=cross_stream history=4 | q1=342.370 actor=84.452 alpha=0.036
# [train] episode=465 step=53772 return=-272.40 success=False time=44.9s geometry=cross_stream history=4 | q1=535.836 actor=81.715 alpha=0.035
# [train] episode=470 step=54216 return=-305.76 success=False time=66.0s geometry=cross_stream history=4 | q1=963.980 actor=82.241 alpha=0.035
# [train] episode=475 step=54516 return=-249.70 success=False time=10.1s geometry=cross_stream history=4 | q1=261.232 actor=82.022 alpha=0.035
# [train] episode=480 step=55056 return=-473.10 success=False time=118.8s geometry=cross_stream history=4 | q1=661.990 actor=81.843 alpha=0.035
# [train] episode=485 step=55986 return=-246.47 success=False time=42.3s geometry=cross_stream history=4 | q1=248.954 actor=84.446 alpha=0.034
# [train] episode=490 step=56262 return=-272.10 success=False time=22.1s geometry=cross_stream history=4 | q1=277.988 actor=85.658 alpha=0.034
# [train] episode=495 step=56910 return=-270.15 success=False time=73.6s geometry=cross_stream history=4 | q1=21.924 actor=83.040 alpha=0.033
# [train] episode=500 step=57912 return=-523.15 success=False time=95.1s geometry=cross_stream history=4 | q1=142.286 actor=84.414 alpha=0.032
# [train] episode=505 step=58104 return=-356.49 success=False time=66.8s geometry=cross_stream history=4 | q1=293.790 actor=89.556 alpha=0.032
# [train] episode=510 step=59034 return=-290.82 success=False time=46.0s geometry=cross_stream history=4 | q1=129.885 actor=86.943 alpha=0.031
# [train] episode=515 step=60030 return=-405.50 success=False time=171.1s geometry=cross_stream history=4 | q1=201.205 actor=85.889 alpha=0.030
# [train] episode=520 step=60618 return=-389.15 success=False time=79.2s geometry=cross_stream history=4 | q1=503.315 actor=89.236 alpha=0.030
# [train] episode=525 step=61812 return=-274.75 success=False time=41.9s geometry=cross_stream history=4 | q1=128.937 actor=95.012 alpha=0.030
# [train] episode=530 step=62406 return=-347.09 success=False time=66.9s geometry=cross_stream history=4 | q1=184.058 actor=93.610 alpha=0.029
# [train] episode=535 step=63174 return=-408.92 success=False time=99.0s geometry=cross_stream history=4 | q1=298.467 actor=91.934 alpha=0.029
# [train] episode=540 step=63924 return=51.07 success=True time=137.9s geometry=cross_stream history=4 | q1=232.479 actor=91.269 alpha=0.029
# [train] episode=545 step=64656 return=-220.20 success=False time=21.3s geometry=cross_stream history=4 | q1=280.135 actor=94.666 alpha=0.029
# [train] episode=550 step=65550 return=-408.36 success=False time=94.1s geometry=cross_stream history=4 | q1=502.851 actor=98.790 alpha=0.030
# [train] episode=555 step=66240 return=-459.61 success=False time=116.9s geometry=cross_stream history=4 | q1=65.855 actor=92.355 alpha=0.031
# [train] episode=560 step=66702 return=-283.57 success=False time=37.6s geometry=cross_stream history=4 | q1=174.087 actor=90.784 alpha=0.031
# [train] episode=565 step=67860 return=-252.01 success=False time=96.0s geometry=cross_stream history=4 | q1=274.636 actor=97.038 alpha=0.031
# [train] episode=570 step=68154 return=-283.93 success=False time=15.3s geometry=cross_stream history=4 | q1=192.205 actor=96.209 alpha=0.030
# [train] episode=575 step=69474 return=-294.29 success=False time=114.3s geometry=cross_stream history=4 | q1=207.126 actor=95.564 alpha=0.031
# [train] episode=580 step=70050 return=-300.82 success=False time=160.6s geometry=cross_stream history=4 | q1=271.924 actor=100.973 alpha=0.031
# [train] episode=585 step=70650 return=-404.34 success=False time=56.1s geometry=cross_stream history=4 | q1=476.697 actor=99.730 alpha=0.032
# [train] episode=590 step=71382 return=-184.63 success=False time=69.3s geometry=cross_stream history=4 | q1=30.413 actor=101.958 alpha=0.032
# [train] episode=595 step=72036 return=-260.12 success=False time=11.0s geometry=cross_stream history=4 | q1=111.441 actor=98.439 alpha=0.032
# [train] episode=600 step=73212 return=-372.15 success=False time=78.7s geometry=cross_stream history=4 | q1=67.788 actor=98.805 alpha=0.032
# [train] episode=605 step=74172 return=-321.12 success=False time=53.9s geometry=cross_stream history=4 | q1=554.914 actor=100.463 alpha=0.033
# [train] episode=610 step=74958 return=-196.80 success=False time=240.1s geometry=cross_stream history=4 | q1=183.522 actor=99.941 alpha=0.035
# [eval] step=75000 objective=arrival_v2 return=-259.81 safety=20.431 success=3.33% time=106.7s energy=82702.0 path=80.2 prog=-0.25
# [train] episode=615 step=75552 return=-254.15 success=False time=21.2s geometry=cross_stream history=4 | q1=91.510 actor=100.419 alpha=0.034
# [train] episode=620 step=77442 return=-375.75 success=False time=74.6s geometry=cross_stream history=4 | q1=284.772 actor=104.981 alpha=0.035
# [train] episode=625 step=78444 return=-61.88 success=False time=240.1s geometry=cross_stream history=4 | q1=123.219 actor=101.282 alpha=0.035
# [train] episode=630 step=80166 return=-359.09 success=False time=68.1s geometry=cross_stream history=4 | q1=85.757 actor=103.446 alpha=0.035
# [train] episode=635 step=81624 return=-54.72 success=False time=240.1s geometry=cross_stream history=4 | q1=28.843 actor=102.023 alpha=0.035
# [train] episode=640 step=83178 return=-368.13 success=False time=66.1s geometry=cross_stream history=4 | q1=90.851 actor=100.020 alpha=0.036
# [train] episode=645 step=85182 return=-325.06 success=False time=56.8s geometry=cross_stream history=4 | q1=56.718 actor=107.332 alpha=0.038
# [train] episode=650 step=86592 return=-370.58 success=False time=87.5s geometry=cross_stream history=4 | q1=161.483 actor=109.965 alpha=0.039
# [train] episode=655 step=87216 return=-311.70 success=False time=69.8s geometry=cross_stream history=4 | q1=59.353 actor=103.897 alpha=0.040
# [train] episode=660 step=87978 return=-251.23 success=False time=24.9s geometry=cross_stream history=4 | q1=139.184 actor=104.474 alpha=0.040
# [train] episode=665 step=89790 return=-141.60 success=False time=240.1s geometry=cross_stream history=4 | q1=326.707 actor=105.948 alpha=0.040
# [train] episode=670 step=90954 return=-66.45 success=False time=240.1s geometry=cross_stream history=4 | q1=289.008 actor=107.129 alpha=0.040
# [train] episode=675 step=91482 return=-293.08 success=False time=50.1s geometry=cross_stream history=4 | q1=130.719 actor=103.699 alpha=0.040
# [train] episode=680 step=92790 return=-226.39 success=False time=240.1s geometry=cross_stream history=4 | q1=134.458 actor=107.809 alpha=0.038
# [train] episode=685 step=93708 return=-275.62 success=False time=42.3s geometry=cross_stream history=4 | q1=68.296 actor=102.711 alpha=0.038
# [train] episode=690 step=95160 return=-249.73 success=False time=55.6s geometry=cross_stream history=4 | q1=4.584 actor=108.881 alpha=0.038
# [train] episode=695 step=96690 return=-225.92 success=False time=240.1s geometry=cross_stream history=4 | q1=162.897 actor=108.122 alpha=0.037
# [train] episode=700 step=98574 return=-200.75 success=False time=240.1s geometry=cross_stream history=4 | q1=90.195 actor=105.114 alpha=0.038
# [train] episode=705 step=98970 return=-168.35 success=False time=240.1s geometry=cross_stream history=4 | q1=27.199 actor=103.693 alpha=0.039
# [eval] step=100002 objective=arrival_v2 return=-302.04 safety=20.230 success=0.00% time=122.2s energy=64853.3 path=113.5 prog=-0.79
# [train] episode=710 step=100086 return=-402.30 success=False time=69.0s geometry=cross_stream history=4 | q1=275.066 actor=110.894 alpha=0.038
# [train] episode=715 step=101862 return=-156.77 success=False time=240.1s geometry=cross_stream history=4 | q1=48.411 actor=106.668 alpha=0.040
# [train] episode=720 step=102918 return=-216.69 success=False time=240.1s geometry=cross_stream history=4 | q1=26.388 actor=107.178 alpha=0.041
# [train] episode=725 step=104292 return=-198.74 success=False time=240.1s geometry=cross_stream history=4 | q1=267.370 actor=104.433 alpha=0.041
# [train] episode=730 step=105354 return=-328.54 success=False time=202.1s geometry=cross_stream history=4 | q1=114.196 actor=105.895 alpha=0.041
# [train] episode=735 step=106428 return=-222.74 success=False time=240.1s geometry=cross_stream history=4 | q1=93.587 actor=106.042 alpha=0.041
# [train] episode=740 step=107400 return=-318.14 success=False time=206.9s geometry=cross_stream history=4 | q1=231.326 actor=103.971 alpha=0.042
# [train] episode=745 step=108408 return=-385.47 success=False time=229.3s geometry=cross_stream history=4 | q1=303.550 actor=107.875 alpha=0.042
# [train] episode=750 step=110286 return=-430.39 success=False time=156.0s geometry=cross_stream history=4 | q1=56.097 actor=107.115 alpha=0.041
# [train] episode=755 step=111108 return=-353.98 success=False time=59.0s geometry=cross_stream history=4 | q1=242.412 actor=107.941 alpha=0.042
# [train] episode=760 step=111864 return=-235.76 success=False time=49.1s geometry=cross_stream history=4 | q1=61.744 actor=106.343 alpha=0.041
# [train] episode=765 step=112686 return=-292.06 success=False time=38.0s geometry=cross_stream history=4 | q1=74.565 actor=111.937 alpha=0.042
# [train] episode=770 step=113598 return=-312.99 success=False time=143.6s geometry=cross_stream history=4 | q1=164.214 actor=106.749 alpha=0.043
# [train] episode=775 step=115128 return=-377.96 success=False time=69.3s geometry=cross_stream history=4 | q1=87.145 actor=112.152 alpha=0.044
# [train] episode=780 step=116184 return=-450.15 success=False time=63.1s geometry=cross_stream history=4 | q1=127.071 actor=111.039 alpha=0.045
# [train] episode=785 step=117528 return=-284.70 success=False time=98.2s geometry=cross_stream history=4 | q1=181.954 actor=108.409 alpha=0.046
# [train] episode=790 step=119076 return=-184.28 success=False time=240.1s geometry=cross_stream history=4 | q1=202.608 actor=105.649 alpha=0.045
# [train] episode=795 step=119814 return=-274.18 success=False time=47.7s geometry=cross_stream history=4 | q1=227.109 actor=107.717 alpha=0.046
# [train] episode=800 step=122244 return=-71.77 success=False time=240.1s geometry=cross_stream history=4 | q1=3.436 actor=106.717 alpha=0.046
# [train] episode=805 step=123978 return=-320.53 success=False time=54.1s geometry=cross_stream history=4 | q1=56.412 actor=112.709 alpha=0.046
# [train] episode=810 step=124932 return=-364.02 success=False time=78.8s geometry=cross_stream history=4 | q1=160.336 actor=109.214 alpha=0.046
# [eval] step=125004 objective=arrival_v2 return=-165.85 safety=25.770 success=0.00% time=178.7s energy=115439.8 path=89.7 prog=0.33
# [train] episode=815 step=126684 return=-240.04 success=False time=15.3s geometry=cross_stream history=4 | q1=82.343 actor=107.652 alpha=0.048
# [train] episode=820 step=128226 return=-53.40 success=False time=240.1s geometry=cross_stream history=4 | q1=19.306 actor=108.400 alpha=0.048
# [train] episode=825 step=129852 return=-89.07 success=False time=240.1s geometry=cross_stream history=4 | q1=213.908 actor=110.819 alpha=0.048
# [train] episode=830 step=131538 return=-224.35 success=False time=224.5s geometry=cross_stream history=4 | q1=256.524 actor=105.568 alpha=0.048
# [train] episode=835 step=133188 return=-273.29 success=False time=49.3s geometry=cross_stream history=4 | q1=83.110 actor=108.534 alpha=0.048
# [train] episode=840 step=133950 return=-250.88 success=False time=5.3s geometry=cross_stream history=4 | q1=40.131 actor=109.496 alpha=0.048
# [train] episode=845 step=135606 return=-70.21 success=False time=240.1s geometry=cross_stream history=4 | q1=105.182 actor=112.965 alpha=0.048
# [train] episode=850 step=136662 return=-250.14 success=False time=14.7s geometry=cross_stream history=4 | q1=148.617 actor=113.165 alpha=0.048
# [train] episode=855 step=138606 return=-374.20 success=False time=72.9s geometry=cross_stream history=4 | q1=280.641 actor=108.742 alpha=0.046
# [train] episode=860 step=139404 return=-93.64 success=False time=240.1s geometry=cross_stream history=4 | q1=150.207 actor=107.576 alpha=0.046
# [train] episode=865 step=139944 return=-263.99 success=False time=14.1s geometry=cross_stream history=4 | q1=76.008 actor=113.072 alpha=0.046
# [train] episode=870 step=142272 return=-186.71 success=False time=240.1s geometry=cross_stream history=4 | q1=234.901 actor=113.449 alpha=0.047
# [train] episode=875 step=143304 return=-287.62 success=False time=53.5s geometry=cross_stream history=4 | q1=229.343 actor=109.786 alpha=0.046
# [train] episode=880 step=145554 return=-96.64 success=False time=240.1s geometry=cross_stream history=4 | q1=65.213 actor=107.605 alpha=0.050
# [train] episode=885 step=146832 return=-101.39 success=False time=240.1s geometry=cross_stream history=4 | q1=211.806 actor=104.575 alpha=0.049
# [train] episode=890 step=147870 return=-309.52 success=False time=57.1s geometry=cross_stream history=4 | q1=183.377 actor=104.034 alpha=0.050
# [train] episode=895 step=148680 return=137.89 success=True time=104.0s geometry=cross_stream history=4 | q1=80.746 actor=109.074 alpha=0.050
# [train] episode=900 step=149622 return=-260.57 success=False time=11.3s geometry=cross_stream history=4 | q1=203.094 actor=111.350 alpha=0.050
# [eval] step=150000 objective=arrival_v2 return=-195.28 safety=24.444 success=6.67% time=140.6s energy=101352.7 path=93.2 prog=0.14
# [train] episode=905 step=151152 return=-241.27 success=False time=22.3s geometry=cross_stream history=4 | q1=3.434 actor=110.670 alpha=0.054
# [train] episode=910 step=152514 return=-65.60 success=False time=240.1s geometry=cross_stream history=4 | q1=89.830 actor=106.222 alpha=0.053
# [train] episode=915 step=154044 return=-87.48 success=False time=240.1s geometry=cross_stream history=4 | q1=109.707 actor=106.503 alpha=0.052
# [train] episode=920 step=155856 return=33.12 success=True time=150.1s geometry=cross_stream history=4 | q1=211.551 actor=108.772 alpha=0.053
# [train] episode=925 step=157602 return=-122.52 success=False time=240.1s geometry=cross_stream history=4 | q1=73.928 actor=103.230 alpha=0.052
# [train] episode=930 step=159258 return=-222.29 success=False time=100.9s geometry=cross_stream history=4 | q1=76.835 actor=110.164 alpha=0.052
# [train] episode=935 step=160494 return=-115.55 success=False time=240.1s geometry=cross_stream history=4 | q1=114.112 actor=105.334 alpha=0.051
# [train] episode=940 step=162132 return=-256.51 success=False time=42.2s geometry=cross_stream history=4 | q1=186.502 actor=107.991 alpha=0.051
# [train] episode=945 step=163020 return=-379.81 success=False time=82.9s geometry=cross_stream history=4 | q1=23.429 actor=106.914 alpha=0.051
# [train] episode=950 step=165024 return=-121.61 success=False time=240.1s geometry=cross_stream history=4 | q1=119.138 actor=104.646 alpha=0.050
# [train] episode=955 step=166110 return=-105.21 success=False time=240.1s geometry=cross_stream history=4 | q1=46.833 actor=106.983 alpha=0.050
# [train] episode=960 step=167946 return=-450.84 success=False time=240.1s geometry=cross_stream history=4 | q1=231.273 actor=103.798 alpha=0.048
# [train] episode=965 step=168804 return=-353.08 success=False time=71.0s geometry=cross_stream history=4 | q1=274.107 actor=106.943 alpha=0.048
# [train] episode=970 step=170964 return=-105.17 success=False time=240.1s geometry=cross_stream history=4 | q1=38.339 actor=110.973 alpha=0.048
# [train] episode=975 step=171738 return=-257.45 success=False time=12.1s geometry=cross_stream history=4 | q1=177.357 actor=107.743 alpha=0.049
# [train] episode=980 step=172722 return=-280.91 success=False time=46.6s geometry=cross_stream history=4 | q1=49.030 actor=111.367 alpha=0.050
# [train] episode=985 step=174330 return=-75.78 success=False time=240.1s geometry=cross_stream history=4 | q1=38.131 actor=109.472 alpha=0.050
# [eval] step=175002 objective=arrival_v2 return=-180.41 safety=22.288 success=10.00% time=143.8s energy=102384.5 path=92.4 prog=0.16
# [train] episode=990 step=175614 return=-86.19 success=False time=240.1s geometry=cross_stream history=4 | q1=263.335 actor=105.374 alpha=0.050
# [train] episode=995 step=177438 return=-89.02 success=False time=240.1s geometry=cross_stream history=4 | q1=111.329 actor=107.247 alpha=0.048
# [train] episode=1000 step=178710 return=-260.03 success=False time=5.7s geometry=cross_stream history=4 | q1=79.291 actor=111.837 alpha=0.047
# [train] episode=1005 step=180474 return=-65.44 success=False time=240.1s geometry=cross_stream history=4 | q1=35.878 actor=108.000 alpha=0.045
# [train] episode=1010 step=181926 return=134.98 success=True time=150.3s geometry=cross_stream history=4 | q1=48.990 actor=105.524 alpha=0.044
# [train] episode=1015 step=182880 return=-258.63 success=False time=5.9s geometry=cross_stream history=4 | q1=47.319 actor=108.329 alpha=0.045
# [train] episode=1020 step=184314 return=-227.74 success=False time=15.6s geometry=cross_stream history=4 | q1=83.047 actor=107.904 alpha=0.047
# [train] episode=1025 step=185358 return=-293.65 success=False time=86.1s geometry=cross_stream history=4 | q1=96.962 actor=108.905 alpha=0.046
# [train] episode=1030 step=186258 return=-80.68 success=False time=240.1s geometry=cross_stream history=4 | q1=95.644 actor=107.948 alpha=0.045
# [train] episode=1035 step=188424 return=-245.56 success=False time=13.8s geometry=cross_stream history=4 | q1=154.656 actor=108.019 alpha=0.048
# [train] episode=1040 step=189540 return=-269.79 success=False time=47.1s geometry=cross_stream history=4 | q1=57.835 actor=106.652 alpha=0.051
# [train] episode=1045 step=192042 return=-127.04 success=False time=240.1s geometry=cross_stream history=4 | q1=78.705 actor=109.931 alpha=0.049
# [train] episode=1050 step=193464 return=-227.54 success=False time=26.5s geometry=cross_stream history=4 | q1=4.387 actor=104.188 alpha=0.049
# [train] episode=1055 step=194952 return=-234.47 success=False time=19.1s geometry=cross_stream history=4 | q1=3.173 actor=106.556 alpha=0.048
# [train] episode=1060 step=196848 return=-124.14 success=False time=240.1s geometry=cross_stream history=4 | q1=45.502 actor=109.122 alpha=0.046
# [train] episode=1065 step=198024 return=-224.39 success=False time=38.1s geometry=cross_stream history=4 | q1=5.717 actor=110.347 alpha=0.045
# [train] episode=1070 step=199056 return=-261.27 success=False time=44.7s geometry=cross_stream history=4 | q1=180.592 actor=108.934 alpha=0.044
# [eval] step=200004 objective=arrival_v2 return=-120.22 safety=18.263 success=13.33% time=160.6s energy=114796.9 path=96.6 prog=0.47
# [train] episode=1075 step=201036 return=-137.05 success=False time=240.1s geometry=cross_stream history=4 | q1=84.450 actor=107.897 alpha=0.044
# [train] episode=1080 step=202356 return=141.73 success=True time=33.5s geometry=cross_stream history=4 | q1=90.394 actor=106.693 alpha=0.046
# [train] episode=1085 step=204324 return=-79.04 success=False time=240.1s geometry=cross_stream history=4 | q1=158.710 actor=104.087 alpha=0.045
# [train] episode=1090 step=206160 return=-246.13 success=False time=172.6s geometry=cross_stream history=4 | q1=76.890 actor=106.199 alpha=0.045
# [train] episode=1095 step=207696 return=-50.82 success=False time=240.1s geometry=cross_stream history=4 | q1=39.490 actor=105.183 alpha=0.044
# [train] episode=1100 step=209748 return=-201.49 success=False time=110.5s geometry=cross_stream history=4 | q1=17.125 actor=104.970 alpha=0.043
# [train] episode=1105 step=212250 return=-75.91 success=False time=240.1s geometry=cross_stream history=4 | q1=86.367 actor=101.966 alpha=0.043
# [train] episode=1110 step=213090 return=-40.29 success=False time=240.1s geometry=cross_stream history=4 | q1=5.275 actor=110.796 alpha=0.042
# [train] episode=1115 step=215568 return=-90.54 success=False time=240.1s geometry=cross_stream history=4 | q1=18.839 actor=101.744 alpha=0.044
# [train] episode=1120 step=216372 return=-323.53 success=False time=240.1s geometry=cross_stream history=4 | q1=2.496 actor=108.900 alpha=0.044
# [train] episode=1125 step=218862 return=-335.27 success=False time=219.2s geometry=cross_stream history=4 | q1=5.329 actor=103.490 alpha=0.044
# [train] episode=1130 step=221316 return=-92.25 success=False time=240.1s geometry=cross_stream history=4 | q1=120.773 actor=110.642 alpha=0.046
# [train] episode=1135 step=222096 return=-257.79 success=False time=240.1s geometry=cross_stream history=4 | q1=5.021 actor=106.929 alpha=0.046
# [train] episode=1140 step=224664 return=-41.10 success=False time=240.1s geometry=cross_stream history=4 | q1=74.970 actor=105.636 alpha=0.047
# [eval] step=225000 objective=arrival_v2 return=-187.42 safety=30.925 success=3.33% time=160.0s energy=101354.9 path=93.6 prog=0.31
# [train] episode=1145 step=227076 return=-82.19 success=False time=240.1s geometry=cross_stream history=4 | q1=64.723 actor=111.878 alpha=0.048
# [train] episode=1150 step=228840 return=-103.28 success=False time=240.1s geometry=cross_stream history=4 | q1=96.408 actor=106.051 alpha=0.048
# [train] episode=1155 step=230742 return=-316.68 success=False time=238.0s geometry=cross_stream history=4 | q1=86.867 actor=100.156 alpha=0.048
# [train] episode=1160 step=233088 return=-116.26 success=False time=240.1s geometry=cross_stream history=4 | q1=13.634 actor=101.323 alpha=0.048
# [train] episode=1165 step=234402 return=-234.88 success=False time=12.3s geometry=cross_stream history=4 | q1=149.351 actor=100.670 alpha=0.049
# [train] episode=1170 step=236934 return=-243.62 success=False time=16.9s geometry=cross_stream history=4 | q1=88.403 actor=104.258 alpha=0.050
# [train] episode=1175 step=238602 return=-432.46 success=False time=217.6s geometry=cross_stream history=4 | q1=114.352 actor=100.077 alpha=0.050
# [train] episode=1180 step=240642 return=-49.02 success=False time=240.1s geometry=cross_stream history=4 | q1=3.265 actor=100.338 alpha=0.052
# [train] episode=1185 step=241854 return=-69.63 success=False time=240.1s geometry=cross_stream history=4 | q1=18.126 actor=109.477 alpha=0.053
# [train] episode=1190 step=243948 return=-311.59 success=False time=240.1s geometry=cross_stream history=4 | q1=120.979 actor=109.425 alpha=0.054
# [train] episode=1195 step=245772 return=-253.17 success=False time=12.8s geometry=cross_stream history=4 | q1=38.314 actor=103.448 alpha=0.054
# [train] episode=1200 step=246726 return=-222.02 success=False time=36.9s geometry=cross_stream history=4 | q1=53.437 actor=101.178 alpha=0.055
# [train] episode=1205 step=248172 return=-266.70 success=False time=71.1s geometry=cross_stream history=4 | q1=106.361 actor=106.280 alpha=0.054
# [train] episode=1210 step=249402 return=133.58 success=True time=190.0s geometry=cross_stream history=4 | q1=119.372 actor=97.966 alpha=0.053
# [eval] step=250002 objective=arrival_v2 return=-75.18 safety=16.280 success=26.67% time=144.6s energy=96899.7 path=87.4 prog=0.62
# [train] episode=1215 step=251664 return=-47.06 success=False time=240.1s geometry=cross_stream history=4 | q1=40.430 actor=99.727 alpha=0.054
# [train] episode=1220 step=253626 return=-20.67 success=False time=240.1s geometry=cross_stream history=4 | q1=72.244 actor=107.982 alpha=0.055
# [train] episode=1225 step=254994 return=-20.88 success=False time=240.1s geometry=cross_stream history=4 | q1=180.765 actor=98.439 alpha=0.056
# [train] episode=1230 step=256080 return=-225.67 success=False time=89.8s geometry=cross_stream history=4 | q1=127.254 actor=102.194 alpha=0.055
# [train] episode=1235 step=257694 return=-254.71 success=False time=5.5s geometry=cross_stream history=4 | q1=124.405 actor=97.702 alpha=0.054
# [train] episode=1240 step=258972 return=-139.30 success=False time=240.1s geometry=cross_stream history=4 | q1=238.444 actor=100.512 alpha=0.055
# [train] episode=1245 step=261288 return=-25.95 success=False time=240.1s geometry=cross_stream history=4 | q1=98.873 actor=100.760 alpha=0.056
# [train] episode=1250 step=262680 return=139.28 success=True time=58.0s geometry=cross_stream history=4 | q1=129.773 actor=104.570 alpha=0.055
# [train] episode=1255 step=264180 return=-51.77 success=False time=240.1s geometry=cross_stream history=4 | q1=3.004 actor=105.738 alpha=0.054
# [train] episode=1260 step=265518 return=-90.08 success=False time=240.1s geometry=cross_stream history=4 | q1=21.261 actor=104.908 alpha=0.053
# [train] episode=1265 step=267666 return=-66.35 success=False time=240.1s geometry=cross_stream history=4 | q1=82.203 actor=100.940 alpha=0.052
# [train] episode=1270 step=268722 return=-61.45 success=False time=240.1s geometry=cross_stream history=4 | q1=84.153 actor=106.384 alpha=0.052
# [train] episode=1275 step=271140 return=-237.11 success=False time=37.7s geometry=cross_stream history=4 | q1=17.229 actor=105.047 alpha=0.051
# [train] episode=1280 step=272964 return=125.89 success=True time=151.3s geometry=cross_stream history=4 | q1=45.919 actor=100.117 alpha=0.051
# [train] episode=1285 step=274194 return=-57.73 success=False time=240.1s geometry=cross_stream history=4 | q1=120.474 actor=101.418 alpha=0.052
# [eval] step=275004 objective=arrival_v2 return=-93.83 safety=17.176 success=13.33% time=179.2s energy=120782.9 path=102.9 prog=0.57
# [train] episode=1290 step=277044 return=-62.78 success=False time=240.1s geometry=cross_stream history=4 | q1=93.853 actor=98.098 alpha=0.054
# [train] episode=1295 step=278808 return=-66.75 success=False time=240.1s geometry=cross_stream history=4 | q1=85.921 actor=102.916 alpha=0.055
# [train] episode=1300 step=280416 return=-254.46 success=False time=39.3s geometry=cross_stream history=4 | q1=33.836 actor=98.542 alpha=0.055
# [train] episode=1305 step=282780 return=104.13 success=True time=232.7s geometry=cross_stream history=4 | q1=38.812 actor=95.251 alpha=0.055
# [train] episode=1310 step=284514 return=-15.97 success=True time=126.3s geometry=cross_stream history=4 | q1=28.803 actor=97.038 alpha=0.055
# [train] episode=1315 step=285672 return=-30.85 success=False time=240.1s geometry=cross_stream history=4 | q1=11.207 actor=98.676 alpha=0.056
# [train] episode=1320 step=287340 return=107.12 success=True time=63.0s geometry=cross_stream history=4 | q1=117.720 actor=99.416 alpha=0.057
# [train] episode=1325 step=288564 return=-43.57 success=False time=240.1s geometry=cross_stream history=4 | q1=150.204 actor=92.700 alpha=0.059
# [train] episode=1330 step=290592 return=-95.10 success=False time=240.1s geometry=cross_stream history=4 | q1=45.754 actor=99.470 alpha=0.056
# [train] episode=1335 step=291498 return=-94.73 success=False time=240.1s geometry=cross_stream history=4 | q1=156.576 actor=96.280 alpha=0.057
# [train] episode=1340 step=293124 return=-62.68 success=False time=240.1s geometry=cross_stream history=4 | q1=21.389 actor=95.293 alpha=0.058
# [train] episode=1345 step=294744 return=-36.17 success=False time=240.1s geometry=cross_stream history=4 | q1=117.441 actor=96.600 alpha=0.059
# [train] episode=1350 step=296808 return=-58.63 success=False time=240.1s geometry=cross_stream history=4 | q1=43.435 actor=98.058 alpha=0.059
# [train] episode=1355 step=298566 return=140.17 success=True time=36.6s geometry=cross_stream history=4 | q1=115.295 actor=100.247 alpha=0.060
# [train] episode=1360 step=299700 return=-33.20 success=False time=240.1s geometry=cross_stream history=4 | q1=79.122 actor=98.283 alpha=0.062
# [eval] step=300000 objective=arrival_v2 return=-58.32 safety=24.713 success=30.00% time=171.5s energy=123999.2 path=89.8 prog=0.73
# [train] episode=1365 step=301458 return=-41.88 success=False time=240.1s geometry=cross_stream history=4 | q1=149.991 actor=96.655 alpha=0.065
# [train] episode=1370 step=303132 return=-38.38 success=False time=240.1s geometry=cross_stream history=4 | q1=21.556 actor=98.043 alpha=0.065
# [train] episode=1375 step=305376 return=-38.10 success=False time=240.1s geometry=cross_stream history=4 | q1=104.533 actor=94.475 alpha=0.062
# [train] episode=1380 step=306696 return=21.59 success=True time=90.7s geometry=cross_stream history=4 | q1=53.534 actor=94.086 alpha=0.061
# [train] episode=1385 step=308340 return=134.35 success=True time=214.9s geometry=cross_stream history=4 | q1=2.693 actor=92.113 alpha=0.064
# [train] episode=1390 step=310902 return=-164.44 success=False time=240.1s geometry=cross_stream history=4 | q1=2.509 actor=94.040 alpha=0.063
# [train] episode=1395 step=313068 return=-29.32 success=False time=240.1s geometry=cross_stream history=4 | q1=10.647 actor=94.434 alpha=0.063
# [train] episode=1400 step=314580 return=142.21 success=True time=35.9s geometry=cross_stream history=4 | q1=3.839 actor=91.169 alpha=0.065
# [train] episode=1405 step=315732 return=137.14 success=True time=85.5s geometry=cross_stream history=4 | q1=29.594 actor=96.787 alpha=0.063
# [train] episode=1410 step=317472 return=-52.45 success=False time=240.1s geometry=cross_stream history=4 | q1=141.579 actor=95.079 alpha=0.063
# [train] episode=1415 step=319620 return=-66.71 success=False time=240.1s geometry=cross_stream history=4 | q1=11.393 actor=93.945 alpha=0.061
# [train] episode=1420 step=320304 return=-90.05 success=False time=240.1s geometry=cross_stream history=4 | q1=90.980 actor=94.431 alpha=0.062
# [train] episode=1425 step=320628 return=-251.09 success=False time=7.8s geometry=cross_stream history=4 | q1=200.223 actor=91.398 alpha=0.061
# [train] episode=1430 step=321348 return=42.60 success=True time=81.4s geometry=cross_stream history=4 | q1=2.526 actor=92.494 alpha=0.060
# [train] episode=1435 step=322776 return=-25.98 success=False time=240.1s geometry=cross_stream history=4 | q1=73.969 actor=96.075 alpha=0.059
# [train] episode=1440 step=324894 return=-35.60 success=False time=240.1s geometry=cross_stream history=4 | q1=141.658 actor=89.621 alpha=0.060
# [eval] step=325002 objective=arrival_v2 return=-57.92 safety=23.284 success=26.67% time=164.6s energy=120606.3 path=86.2 prog=0.72
# [train] episode=1445 step=327132 return=-31.61 success=False time=240.1s geometry=cross_stream history=4 | q1=174.093 actor=92.970 alpha=0.064
# [train] episode=1450 step=328572 return=-35.44 success=False time=240.1s geometry=cross_stream history=4 | q1=10.660 actor=93.330 alpha=0.061
# [train] episode=1455 step=330552 return=-262.81 success=False time=43.5s geometry=cross_stream history=4 | q1=57.119 actor=101.537 alpha=0.063
# [train] episode=1460 step=333150 return=-28.50 success=False time=240.1s geometry=cross_stream history=4 | q1=4.125 actor=91.977 alpha=0.061
# [train] episode=1465 step=335874 return=-33.15 success=False time=240.1s geometry=cross_stream history=4 | q1=51.664 actor=94.392 alpha=0.060
# [train] episode=1470 step=338508 return=86.15 success=True time=218.6s geometry=cross_stream history=4 | q1=55.849 actor=93.790 alpha=0.057
# [train] episode=1475 step=338994 return=123.08 success=True time=199.6s geometry=cross_stream history=4 | q1=28.713 actor=91.127 alpha=0.057
# [train] episode=1480 step=341616 return=-49.49 success=False time=240.1s geometry=cross_stream history=4 | q1=26.268 actor=90.888 alpha=0.054
# [train] episode=1485 step=343482 return=-277.19 success=False time=40.7s geometry=cross_stream history=4 | q1=29.488 actor=93.223 alpha=0.052
# [train] episode=1490 step=344778 return=-16.68 success=False time=240.1s geometry=cross_stream history=4 | q1=17.439 actor=95.090 alpha=0.054
# [train] episode=1495 step=346374 return=-28.84 success=False time=240.1s geometry=cross_stream history=4 | q1=44.154 actor=87.188 alpha=0.054
# [train] episode=1500 step=348114 return=-41.64 success=False time=240.1s geometry=cross_stream history=4 | q1=30.295 actor=88.878 alpha=0.054
# [eval] step=350004 objective=arrival_v2 return=-27.79 safety=21.663 success=46.67% time=154.3s energy=110503.7 path=89.1 prog=0.72
# [train] episode=1505 step=350058 return=130.60 success=True time=207.6s geometry=cross_stream history=4 | q1=42.445 actor=91.195 alpha=0.056
# [train] episode=1510 step=352782 return=-31.04 success=False time=240.1s geometry=cross_stream history=4 | q1=2.350 actor=90.227 alpha=0.054
# [train] episode=1515 step=354072 return=60.59 success=True time=106.6s geometry=cross_stream history=4 | q1=3.706 actor=91.706 alpha=0.054
# [train] episode=1520 step=355554 return=84.64 success=True time=125.7s geometry=cross_stream history=4 | q1=15.452 actor=91.246 alpha=0.055
# [train] episode=1525 step=356574 return=106.44 success=True time=60.3s geometry=cross_stream history=4 | q1=236.930 actor=94.046 alpha=0.055
# [train] episode=1530 step=358530 return=97.37 success=True time=225.6s geometry=cross_stream history=4 | q1=27.173 actor=89.862 alpha=0.054
# [train] episode=1535 step=360456 return=-46.93 success=False time=240.1s geometry=cross_stream history=4 | q1=171.162 actor=94.551 alpha=0.053
# [train] episode=1540 step=361260 return=137.90 success=True time=208.3s geometry=cross_stream history=4 | q1=61.361 actor=88.151 alpha=0.054
# [train] episode=1545 step=362886 return=73.97 success=True time=62.1s geometry=cross_stream history=4 | q1=5.806 actor=90.137 alpha=0.054
# [train] episode=1550 step=363852 return=-248.59 success=False time=9.6s geometry=cross_stream history=4 | q1=5.462 actor=88.315 alpha=0.055
# [train] episode=1555 step=364566 return=-242.30 success=False time=18.5s geometry=cross_stream history=4 | q1=135.987 actor=88.736 alpha=0.056
# [train] episode=1560 step=366162 return=120.13 success=True time=61.9s geometry=cross_stream history=4 | q1=185.276 actor=90.813 alpha=0.057
# [train] episode=1565 step=367140 return=-256.99 success=False time=37.2s geometry=cross_stream history=4 | q1=2.648 actor=86.033 alpha=0.056
# [train] episode=1570 step=369264 return=-35.96 success=False time=240.1s geometry=cross_stream history=4 | q1=1.639 actor=88.028 alpha=0.057
# [train] episode=1575 step=370224 return=141.03 success=True time=51.1s geometry=cross_stream history=4 | q1=9.075 actor=87.498 alpha=0.056
# [train] episode=1580 step=372474 return=-22.59 success=False time=240.1s geometry=cross_stream history=4 | q1=2.384 actor=83.579 alpha=0.056
# [train] episode=1585 step=373254 return=-29.16 success=False time=240.1s geometry=cross_stream history=4 | q1=58.299 actor=88.796 alpha=0.058
# [eval] step=375000 objective=arrival_v2 return=-60.19 safety=21.425 success=26.67% time=157.1s energy=115475.2 path=91.2 prog=0.70
# [train] episode=1590 step=375636 return=130.18 success=True time=224.7s geometry=cross_stream history=4 | q1=36.633 actor=89.543 alpha=0.058
# [train] episode=1595 step=377184 return=115.20 success=True time=61.7s geometry=cross_stream history=4 | q1=81.141 actor=82.334 alpha=0.059
# [train] episode=1600 step=378282 return=49.18 success=True time=219.9s geometry=cross_stream history=4 | q1=208.763 actor=89.960 alpha=0.059
# [train] episode=1605 step=379392 return=-228.69 success=False time=38.3s geometry=cross_stream history=4 | q1=41.938 actor=84.234 alpha=0.060
# [train] episode=1610 step=381018 return=-262.08 success=False time=9.6s geometry=cross_stream history=4 | q1=19.044 actor=90.320 alpha=0.059
# [train] episode=1615 step=382842 return=137.42 success=True time=215.0s geometry=cross_stream history=4 | q1=4.781 actor=86.607 alpha=0.058
# [train] episode=1620 step=383952 return=-25.44 success=False time=240.1s geometry=cross_stream history=4 | q1=3.526 actor=85.603 alpha=0.058
# [train] episode=1625 step=386178 return=-35.47 success=False time=240.1s geometry=cross_stream history=4 | q1=119.964 actor=84.706 alpha=0.060
# [train] episode=1630 step=387372 return=-94.34 success=False time=240.1s geometry=cross_stream history=4 | q1=135.666 actor=85.445 alpha=0.059
# ...
# [train] episode=4230 step=913542 return=139.62 success=True time=116.9s geometry=cross_stream history=4 | q1=131.654 actor=33.268 alpha=0.072
# [train] episode=4235 step=914598 return=141.76 success=True time=62.0s geometry=cross_stream history=4 | q1=192.311 actor=31.364 alpha=0.071
# [train] episode=4240 step=914892 return=-243.02 success=False time=12.0s geometry=cross_stream history=4 | q1=246.495 actor=28.888 alpha=0.072
# [train] episode=4245 step=915954 return=139.57 success=True time=91.2s geometry=cross_stream history=4 | q1=46.859 actor=31.238 alpha=0.072
# [train] episode=4250 step=916752 return=136.12 success=True time=60.4s geometry=cross_stream history=4 | q1=77.907 actor=30.047 alpha=0.073
# [train] episode=4255 step=917676 return=139.39 success=True time=84.0s geometry=cross_stream history=4 | q1=31.305 actor=36.521 alpha=0.075
# [train] episode=4260 step=918216 return=139.55 success=True time=60.1s geometry=cross_stream history=4 | q1=75.860 actor=36.560 alpha=0.074
# [train] episode=4265 step=918912 return=136.24 success=True time=89.1s geometry=cross_stream history=4 | q1=172.700 actor=29.993 alpha=0.074
# [train] episode=4270 step=919764 return=138.16 success=True time=63.0s geometry=cross_stream history=4 | q1=72.337 actor=32.459 alpha=0.076
# [train] episode=4275 step=920622 return=32.63 success=True time=92.2s geometry=cross_stream history=4 | q1=28.975 actor=28.063 alpha=0.075
# [train] episode=4280 step=921432 return=140.08 success=True time=59.4s geometry=cross_stream history=4 | q1=60.174 actor=31.855 alpha=0.076
# [train] episode=4285 step=922284 return=120.29 success=True time=70.2s geometry=cross_stream history=4 | q1=127.485 actor=30.732 alpha=0.077
# [train] episode=4290 step=922782 return=-256.65 success=False time=40.6s geometry=cross_stream history=4 | q1=182.099 actor=32.883 alpha=0.075
# [train] episode=4295 step=923220 return=139.22 success=True time=120.5s geometry=cross_stream history=4 | q1=24.197 actor=29.293 alpha=0.076
# [train] episode=4300 step=924192 return=139.73 success=True time=85.5s geometry=cross_stream history=4 | q1=35.968 actor=27.840 alpha=0.077
# [eval] step=925002 objective=arrival_v2 return=88.65 safety=9.161 success=90.00% time=78.9s energy=63174.0 path=62.8 prog=0.84
# [train] episode=4305 step=925164 return=136.06 success=True time=106.4s geometry=cross_stream history=4 | q1=40.711 actor=36.502 alpha=0.076
# [train] episode=4310 step=925812 return=101.49 success=True time=134.4s geometry=cross_stream history=4 | q1=63.534 actor=32.977 alpha=0.077
# [train] episode=4315 step=926754 return=139.44 success=True time=84.4s geometry=cross_stream history=4 | q1=156.070 actor=28.634 alpha=0.074
# [train] episode=4320 step=927606 return=140.75 success=True time=82.2s geometry=cross_stream history=4 | q1=163.329 actor=31.769 alpha=0.073
# [train] episode=4325 step=928110 return=-231.25 success=False time=37.4s geometry=cross_stream history=4 | q1=104.330 actor=27.462 alpha=0.072
# [train] episode=4330 step=929334 return=137.58 success=True time=131.0s geometry=cross_stream history=4 | q1=63.958 actor=29.773 alpha=0.069
# [train] episode=4335 step=930042 return=-237.34 success=False time=22.7s geometry=cross_stream history=4 | q1=38.594 actor=27.020 alpha=0.069
# [train] episode=4340 step=930918 return=123.67 success=True time=71.4s geometry=cross_stream history=4 | q1=3.024 actor=29.791 alpha=0.069
# [train] episode=4345 step=931476 return=-252.03 success=False time=36.7s geometry=cross_stream history=4 | q1=35.436 actor=29.244 alpha=0.071
# [train] episode=4350 step=932436 return=-237.87 success=False time=19.5s geometry=cross_stream history=4 | q1=32.937 actor=31.749 alpha=0.072
# [train] episode=4355 step=933330 return=142.33 success=True time=73.7s geometry=cross_stream history=4 | q1=24.083 actor=27.777 alpha=0.074
# [train] episode=4360 step=933972 return=140.37 success=True time=52.9s geometry=cross_stream history=4 | q1=178.291 actor=28.365 alpha=0.074
# [train] episode=4365 step=934596 return=119.23 success=True time=136.2s geometry=cross_stream history=4 | q1=11.033 actor=32.685 alpha=0.075
# [train] episode=4370 step=935460 return=140.51 success=True time=104.1s geometry=cross_stream history=4 | q1=12.247 actor=31.814 alpha=0.074
# [train] episode=4375 step=936456 return=138.43 success=True time=90.9s geometry=cross_stream history=4 | q1=22.646 actor=29.772 alpha=0.073
# [train] episode=4380 step=937470 return=142.20 success=True time=96.1s geometry=cross_stream history=4 | q1=76.609 actor=29.688 alpha=0.073
# [train] episode=4385 step=938160 return=133.02 success=True time=56.8s geometry=cross_stream history=4 | q1=144.177 actor=30.214 alpha=0.073
# [train] episode=4390 step=939006 return=80.28 success=True time=69.7s geometry=cross_stream history=4 | q1=100.273 actor=30.543 alpha=0.074
# [train] episode=4395 step=939798 return=135.29 success=True time=102.9s geometry=cross_stream history=4 | q1=29.663 actor=34.300 alpha=0.072
# [train] episode=4400 step=940488 return=124.87 success=True time=100.7s geometry=cross_stream history=4 | q1=130.186 actor=30.297 alpha=0.072
# [train] episode=4405 step=941502 return=138.98 success=True time=86.6s geometry=cross_stream history=4 | q1=142.593 actor=36.313 alpha=0.074
# [train] episode=4410 step=942258 return=141.89 success=True time=35.1s geometry=cross_stream history=4 | q1=44.557 actor=28.000 alpha=0.075
# [train] episode=4415 step=942708 return=-211.99 success=False time=14.3s geometry=cross_stream history=4 | q1=56.828 actor=30.559 alpha=0.074
# [train] episode=4420 step=943566 return=136.85 success=True time=87.8s geometry=cross_stream history=4 | q1=55.213 actor=31.730 alpha=0.073
# [train] episode=4425 step=944010 return=138.92 success=True time=63.9s geometry=cross_stream history=4 | q1=101.427 actor=34.355 alpha=0.072
# [train] episode=4430 step=944802 return=-232.60 success=False time=15.8s geometry=cross_stream history=4 | q1=101.944 actor=35.857 alpha=0.071
# [train] episode=4435 step=945258 return=-253.78 success=False time=13.9s geometry=cross_stream history=4 | q1=34.523 actor=24.390 alpha=0.072
# [train] episode=4440 step=945954 return=-222.87 success=False time=19.4s geometry=cross_stream history=4 | q1=126.493 actor=25.628 alpha=0.072
# [train] episode=4445 step=946836 return=-2.02 success=True time=97.3s geometry=cross_stream history=4 | q1=226.548 actor=32.024 alpha=0.074
# [train] episode=4450 step=947466 return=-209.90 success=False time=35.5s geometry=cross_stream history=4 | q1=130.718 actor=24.682 alpha=0.073
# [train] episode=4455 step=948300 return=135.19 success=True time=105.0s geometry=cross_stream history=4 | q1=13.687 actor=31.051 alpha=0.076
# [train] episode=4460 step=949098 return=132.44 success=True time=62.7s geometry=cross_stream history=4 | q1=106.650 actor=33.527 alpha=0.076
# [eval] step=950004 objective=arrival_v2 return=84.30 safety=11.367 success=90.00% time=75.1s energy=61473.5 path=62.6 prog=0.84
# [train] episode=4465 step=950100 return=139.63 success=True time=97.0s geometry=cross_stream history=4 | q1=63.445 actor=33.592 alpha=0.076
# [train] episode=4470 step=950946 return=127.35 success=True time=133.6s geometry=cross_stream history=4 | q1=35.847 actor=28.222 alpha=0.077
# [train] episode=4475 step=951618 return=-243.36 success=False time=44.2s geometry=cross_stream history=4 | q1=53.122 actor=28.268 alpha=0.077
# [train] episode=4480 step=952506 return=134.12 success=True time=68.0s geometry=cross_stream history=4 | q1=28.206 actor=31.917 alpha=0.073
# [train] episode=4485 step=953346 return=142.91 success=True time=83.3s geometry=cross_stream history=4 | q1=313.775 actor=35.555 alpha=0.074
# [train] episode=4490 step=954018 return=-217.98 success=False time=22.0s geometry=cross_stream history=4 | q1=12.879 actor=31.520 alpha=0.071
# [train] episode=4495 step=954936 return=48.94 success=True time=110.0s geometry=cross_stream history=4 | q1=44.353 actor=26.491 alpha=0.070
# [train] episode=4500 step=955680 return=138.69 success=True time=131.9s geometry=cross_stream history=4 | q1=54.324 actor=27.386 alpha=0.070
# [train] episode=4505 step=956622 return=129.66 success=True time=82.6s geometry=cross_stream history=4 | q1=53.975 actor=28.442 alpha=0.071
# [train] episode=4510 step=957240 return=137.58 success=True time=81.2s geometry=cross_stream history=4 | q1=171.154 actor=25.075 alpha=0.071
# [train] episode=4515 step=958008 return=137.45 success=True time=110.8s geometry=cross_stream history=4 | q1=45.422 actor=31.034 alpha=0.072
# [train] episode=4520 step=958722 return=-239.86 success=False time=13.4s geometry=cross_stream history=4 | q1=2.649 actor=26.873 alpha=0.073
# [train] episode=4525 step=959568 return=-214.59 success=False time=37.2s geometry=cross_stream history=4 | q1=49.418 actor=33.503 alpha=0.071
# [train] episode=4530 step=960528 return=131.98 success=True time=62.3s geometry=cross_stream history=4 | q1=50.310 actor=22.881 alpha=0.072
# [train] episode=4535 step=961512 return=-54.89 success=True time=180.7s geometry=cross_stream history=4 | q1=26.777 actor=25.818 alpha=0.076
# [train] episode=4540 step=961806 return=118.03 success=True time=81.3s geometry=cross_stream history=4 | q1=38.782 actor=26.436 alpha=0.076
# [train] episode=4545 step=962646 return=141.55 success=True time=83.8s geometry=cross_stream history=4 | q1=87.667 actor=30.557 alpha=0.076
# [train] episode=4550 step=963690 return=137.11 success=True time=81.3s geometry=cross_stream history=4 | q1=28.717 actor=27.908 alpha=0.076
# [train] episode=4555 step=964482 return=137.42 success=True time=97.4s geometry=cross_stream history=4 | q1=10.009 actor=30.585 alpha=0.076
# [train] episode=4560 step=965274 return=141.53 success=True time=53.2s geometry=cross_stream history=4 | q1=99.835 actor=30.001 alpha=0.074
# [train] episode=4565 step=966054 return=139.27 success=True time=64.4s geometry=cross_stream history=4 | q1=37.179 actor=27.586 alpha=0.072
# [train] episode=4570 step=966912 return=139.15 success=True time=101.4s geometry=cross_stream history=4 | q1=4.368 actor=26.678 alpha=0.073
# [train] episode=4575 step=967620 return=-210.65 success=False time=40.8s geometry=cross_stream history=4 | q1=43.888 actor=31.304 alpha=0.071
# [train] episode=4580 step=968532 return=68.66 success=True time=99.6s geometry=cross_stream history=4 | q1=25.576 actor=30.826 alpha=0.070
# [train] episode=4585 step=969024 return=110.08 success=True time=73.3s geometry=cross_stream history=4 | q1=166.442 actor=32.851 alpha=0.070
# [train] episode=4590 step=970032 return=122.56 success=True time=83.4s geometry=cross_stream history=4 | q1=107.476 actor=25.011 alpha=0.071
# [train] episode=4595 step=970692 return=130.85 success=True time=108.5s geometry=cross_stream history=4 | q1=134.394 actor=29.820 alpha=0.072
# [train] episode=4600 step=971736 return=137.69 success=True time=86.3s geometry=cross_stream history=4 | q1=25.342 actor=26.454 alpha=0.071
# [train] episode=4605 step=972264 return=-226.96 success=False time=18.5s geometry=cross_stream history=4 | q1=68.119 actor=25.691 alpha=0.070
# [train] episode=4610 step=973176 return=-355.39 success=False time=75.2s geometry=cross_stream history=4 | q1=64.621 actor=26.911 alpha=0.073
# [train] episode=4615 step=973962 return=114.28 success=True time=77.4s geometry=cross_stream history=4 | q1=84.557 actor=27.901 alpha=0.073
# [eval] step=975000 objective=arrival_v2 return=75.77 safety=10.771 success=86.67% time=77.3s energy=61836.8 path=61.4 prog=0.83
# [train] episode=4620 step=975006 return=134.44 success=True time=151.9s geometry=cross_stream history=4 | q1=21.187 actor=22.504 alpha=0.074
# [train] episode=4625 step=975402 return=-248.42 success=False time=9.3s geometry=cross_stream history=4 | q1=94.116 actor=21.284 alpha=0.073
# [train] episode=4630 step=976488 return=140.65 success=True time=111.0s geometry=cross_stream history=4 | q1=31.500 actor=36.298 alpha=0.074
# [train] episode=4635 step=977688 return=115.69 success=True time=108.3s geometry=cross_stream history=4 | q1=63.200 actor=24.254 alpha=0.072
# [train] episode=4640 step=978330 return=139.97 success=True time=76.5s geometry=cross_stream history=4 | q1=37.967 actor=31.215 alpha=0.071
# [train] episode=4645 step=979002 return=139.58 success=True time=106.5s geometry=cross_stream history=4 | q1=109.627 actor=29.751 alpha=0.071
# [train] episode=4650 step=979764 return=139.15 success=True time=73.9s geometry=cross_stream history=4 | q1=55.882 actor=36.464 alpha=0.072
# [train] episode=4655 step=980622 return=140.97 success=True time=73.0s geometry=cross_stream history=4 | q1=117.514 actor=34.278 alpha=0.074
# [train] episode=4660 step=981336 return=141.45 success=True time=84.5s geometry=cross_stream history=4 | q1=71.610 actor=32.507 alpha=0.073
# [train] episode=4665 step=982080 return=75.18 success=True time=86.6s geometry=cross_stream history=4 | q1=30.497 actor=29.397 alpha=0.073
# [train] episode=4670 step=982944 return=131.63 success=True time=57.4s geometry=cross_stream history=4 | q1=3.459 actor=31.436 alpha=0.074
# [train] episode=4675 step=983820 return=139.42 success=True time=102.3s geometry=cross_stream history=4 | q1=37.916 actor=33.487 alpha=0.074
# [train] episode=4680 step=984522 return=140.03 success=True time=81.1s geometry=cross_stream history=4 | q1=56.543 actor=32.014 alpha=0.076
# [train] episode=4685 step=984924 return=142.00 success=True time=81.7s geometry=cross_stream history=4 | q1=9.163 actor=28.170 alpha=0.076
# [train] episode=4690 step=985998 return=137.28 success=True time=110.1s geometry=cross_stream history=4 | q1=29.112 actor=32.835 alpha=0.074
# [train] episode=4695 step=986730 return=139.05 success=True time=93.8s geometry=cross_stream history=4 | q1=50.321 actor=29.258 alpha=0.075
# [train] episode=4700 step=987396 return=140.67 success=True time=89.9s geometry=cross_stream history=4 | q1=63.716 actor=27.808 alpha=0.075
# [train] episode=4705 step=988056 return=141.87 success=True time=97.0s geometry=cross_stream history=4 | q1=61.269 actor=30.200 alpha=0.075
# [train] episode=4710 step=988818 return=96.35 success=True time=100.6s geometry=cross_stream history=4 | q1=49.200 actor=30.249 alpha=0.075
# [train] episode=4715 step=989718 return=126.45 success=True time=97.9s geometry=cross_stream history=4 | q1=78.221 actor=28.896 alpha=0.074
# [train] episode=4720 step=990336 return=99.49 success=True time=125.6s geometry=cross_stream history=4 | q1=187.205 actor=36.193 alpha=0.073
# [train] episode=4725 step=991134 return=119.95 success=True time=65.7s geometry=cross_stream history=4 | q1=180.868 actor=29.952 alpha=0.073
# [train] episode=4730 step=992160 return=138.90 success=True time=85.0s geometry=cross_stream history=4 | q1=52.907 actor=26.459 alpha=0.073
# [train] episode=4735 step=993150 return=138.82 success=True time=82.0s geometry=cross_stream history=4 | q1=214.323 actor=28.702 alpha=0.072
# [train] episode=4740 step=993864 return=139.40 success=True time=116.4s geometry=cross_stream history=4 | q1=157.168 actor=27.796 alpha=0.072
# [train] episode=4745 step=994530 return=141.22 success=True time=75.4s geometry=cross_stream history=4 | q1=145.424 actor=27.837 alpha=0.072
# [train] episode=4750 step=995562 return=-252.34 success=False time=34.5s geometry=cross_stream history=4 | q1=47.423 actor=26.584 alpha=0.073
# [train] episode=4755 step=996066 return=139.60 success=True time=80.1s geometry=cross_stream history=4 | q1=121.524 actor=25.956 alpha=0.072
# [train] episode=4760 step=996840 return=137.94 success=True time=76.7s geometry=cross_stream history=4 | q1=105.149 actor=28.667 alpha=0.071
# [train] episode=4765 step=997758 return=138.86 success=True time=56.3s geometry=cross_stream history=4 | q1=112.686 actor=18.421 alpha=0.071
# [train] episode=4770 step=998652 return=137.98 success=True time=73.7s geometry=cross_stream history=4 | q1=279.364 actor=23.249 alpha=0.071
# [train] episode=4775 step=999102 return=-240.81 success=False time=35.3s geometry=cross_stream history=4 | q1=204.722 actor=24.146 alpha=0.071

# %% [markdown]
# ## 5. Phase 1 — single_cross summary + gate
#
# Gate 5 条与 P1 v6 / tandem / sbs 同口径。Gate summary 落到 `results/single_cross_validation_gate_summary.json`。

# %%
def summarize_phase(run_root: Path, total_steps: int, label: str, gate_filename: str):
    eval_log_path = run_root / 'results' / 'eval_log.csv'
    final_eval_path = run_root / 'results' / 'final_eval.json'
    trainer_state_path = run_root / 'trainer_state.json'

    if not eval_log_path.exists():
        raise FileNotFoundError(f'missing eval log: {eval_log_path}')
    if not final_eval_path.exists():
        raise FileNotFoundError(f'missing final eval: {final_eval_path}')

    df = pd.read_csv(eval_log_path)
    final_eval = json.loads(final_eval_path.read_text(encoding='utf-8'))
    trainer_state = json.loads(trainer_state_path.read_text(encoding='utf-8')) if trainer_state_path.exists() else {}

    peak_success = float(df['eval_success_rate'].max()) if len(df) else 0.0
    peak_step = int(df.loc[df['eval_success_rate'].idxmax(), 'env_step']) if len(df) else 0
    last100 = df[df['env_step'] >= total_steps - 100_000].copy()
    last100_mean = float(last100['eval_success_rate'].mean()) if len(last100) else 0.0
    final_success = float(final_eval['eval_success_rate'])
    counts = final_eval.get('eval_termination_counts', {})
    num_eps = float(final_eval.get('num_eval_episodes', EVAL_EPISODES))
    oob_rate = float(counts.get('out_of_bounds', 0)) / max(num_eps, 1.0)

    print('=' * 100)
    print(f'{label}  (arrival_v2 / s1 / {total_steps:,} steps)')
    print('-' * 100)
    print(f"  final_success_rate    : {final_success:.4f}   gate >= {PASS_FINAL_SUCCESS:.2f}")
    print(f"  peak_success_rate     : {peak_success:.4f}   @ {peak_step:,}")
    print(f"  last100k_mean_success : {last100_mean:.4f}   gate >= {PASS_LAST100_RATIO * peak_success:.4f}")
    print(f"  final_oob_rate        : {oob_rate:.4f}   gate <= {PASS_OOB_RATE:.2f}")
    print(f"  obs_dim               : {trainer_state.get('observation_dim', 'NA')}")
    print(f"  context_obs           : {trainer_state.get('include_episode_context_obs', 'NA')}")
    print(f"  timeout_bootstrap     : {trainer_state.get('timeout_bootstrap_semantics', 'NA')}")
    print(f"  termination           : {counts}")
    print('=' * 100)

    if len(df):
        print()
        print('[last 16 eval rows]')
        cols = ['env_step', 'eval_success_rate', 'eval_return', 'eval_safety_cost',
                'eval_time_s', 'eval_progress_ratio']
        available = [c for c in cols if c in df.columns]
        print(df[available].tail(16).to_string(index=False))

    checks = [
        ('final success >= 0.85', final_success >= PASS_FINAL_SUCCESS, f'{final_success:.4f}'),
        ('last100k mean >= 0.9 * peak', last100_mean >= PASS_LAST100_RATIO * peak_success,
         f'{last100_mean:.4f} / peak={peak_success:.4f}'),
        ('final OOB rate <= 0.10', oob_rate <= PASS_OOB_RATE, f'{oob_rate:.4f}'),
        ('arrival_v2 context obs enabled',
         trainer_state.get('include_episode_context_obs') is True,
         str(trainer_state.get('include_episode_context_obs'))),
        ('arrival_v2 timeout terminal semantics',
         trainer_state.get('timeout_bootstrap_semantics') == 'terminal',
         str(trainer_state.get('timeout_bootstrap_semantics'))),
    ]

    print()
    print('=' * 96)
    print(f"{'check':<48}{'pass':>8}{'detail':>40}")
    print('-' * 96)
    all_pass = True
    for name, ok, detail in checks:
        mark = 'PASS' if ok else 'FAIL'
        if not ok:
            all_pass = False
        print(f'{name:<48}{mark:>8}{detail:>40}')
    print('=' * 96)

    summary = {
        'phase': label,
        'objective': OBJECTIVE,
        'probe_layout': PROBE_LAYOUT,
        'history_length': HISTORY_LENGTH,
        'seed': SEED,
        'total_steps': total_steps,
        'final_success_rate': final_success,
        'peak_success_rate': peak_success,
        'peak_step': peak_step,
        'last100k_mean_success': last100_mean,
        'final_oob_rate': oob_rate,
        'termination_counts': counts,
        'all_pass': bool(all_pass),
        'checks': [{'name': n, 'ok': bool(ok), 'detail': d} for n, ok, d in checks],
    }
    out_path = run_root / 'results' / gate_filename
    out_path.write_text(json.dumps(summary, indent=2), encoding='utf-8')
    print(f'[saved] {out_path}')
    return summary

cross_summary = summarize_phase(
    C_RUN_ROOT,
    C_TOTAL_STEPS,
    'SINGLE_CROSS_VALIDATION',
    'single_cross_validation_gate_summary.json',
)
CROSS_PASS = cross_summary['all_pass']
print()
print(f'CROSS_PASS = {CROSS_PASS}')
# Out:
# ====================================================================================================
# SINGLE_CROSS_VALIDATION  (arrival_v2 / s1 / 1,000,000 steps)
# ----------------------------------------------------------------------------------------------------
#   final_success_rate    : 0.9000   gate >= 0.85
#   peak_success_rate     : 0.9000   @ 725,004
#   last100k_mean_success : 0.8833   gate >= 0.8100
#   final_oob_rate        : 0.1000   gate <= 0.10
#   obs_dim               : 56
#   context_obs           : True
#   timeout_bootstrap     : terminal
#   termination           : {'goal': 27, 'out_of_bounds': 3}
# ====================================================================================================
#
# [last 16 eval rows]
#  env_step  eval_success_rate  eval_return  eval_safety_cost  eval_time_s  eval_progress_ratio
#    600000           0.866667    50.771376         22.718896   109.606667             0.825197
#    625002           0.800000    59.309862         13.842890   104.976667             0.825660
#    650004           0.866667    65.233458         16.058267    87.226667             0.828478
#    675000           0.866667    71.165225         12.833410    83.506667             0.823431
#    700002           0.066667  -215.939105         41.527897   161.560000             0.184278
#    725004           0.900000    84.378239         11.153070    91.616667             0.835079
#    750000           0.833333    63.357079         12.881119    88.550000             0.829642
#    775002           0.866667    64.235255         16.286363    87.896667             0.824128
#    800004           0.533333    -2.998318         11.380420   124.396667             0.576550
#    825000           0.900000    88.273840          9.335408    79.006667             0.835006
#    850002           0.866667    73.124728         11.073324    80.430000             0.812736
#    875004           0.900000    88.887538          9.081412    77.680000             0.835764
#    900000           0.866667    75.716873          9.651844    76.183333             0.809965
#    925002           0.900000    88.652144          9.161447    78.883333             0.835296
#    950004           0.900000    84.300290         11.367274    75.053333             0.835054
#    975000           0.866667    75.773047         10.770754    77.310000             0.826381
#
# ================================================================================================
# check                                               pass                                  detail
# ------------------------------------------------------------------------------------------------
# final success >= 0.85                               PASS                                  0.9000
# last100k mean >= 0.9 * peak                         PASS                    0.8833 / peak=0.9000
# final OOB rate <= 0.10                              PASS                                  0.1000
# arrival_v2 context obs enabled                      PASS                                    True
# arrival_v2 timeout terminal semantics               PASS                                terminal
# ================================================================================================
# [saved] experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s1_k4/seed_42/results/single_cross_validation_gate_summary.json
#
# CROSS_PASS = True

# %% [markdown]
# ## 6. Phase 2 — single_upstream train (1.0M, independent)
#
# **独立运行**：upstream 不门控于 cross。两种 geometry 物理任务不同（侧向跨流 vs 逆流前进），都值得独立看一看。
#
# Skip/resume 逻辑同 single_cross。

# %%
u_state_path = U_RUN_ROOT / 'trainer_state.json'
if u_state_path.exists():
    u_state = json.loads(u_state_path.read_text(encoding='utf-8'))
    u_current_step = int(u_state.get('env_step', 0))
else:
    u_current_step = 0
print(f'[state] single_upstream env_step = {u_current_step:,} / target {U_TOTAL_STEPS:,}')

if u_current_step >= U_TOTAL_STEPS:
    print(f'[skip] single_upstream already trained to {u_current_step:,} >= {U_TOTAL_STEPS:,}')
    print('       要继续训:把 U_TOTAL_STEPS 改大,重跑 config cell + 此 cell')
elif u_current_step > 0:
    print(f'[resume] single_upstream continuing from {u_current_step:,} -> {U_TOTAL_STEPS:,}')
    # !python -u -m scripts.train_sac \
        --resume {U_RUN_ROOT_STR} \
        --total-steps {U_TOTAL_STEPS} \
        --eval-every {EVAL_EVERY} \
        --eval-episodes {EVAL_EPISODES} \
        --checkpoint-every {CHECKPOINT_EVERY} \
        --eval-manifest {U_MANIFEST_PATH_STR} \
        --device {DEVICE}
else:
    print(f'[train] single_upstream fresh start -> {U_TOTAL_STEPS:,}')
    # !python -u -m scripts.train_sac \
        --flow {U_FLOW_PATH} \
        --task-geometry {U_TASK_GEOMETRY} \
        --target-speed {TARGET_SPEED} \
        --objective {OBJECTIVE} \
        --probe-layout {PROBE_LAYOUT} \
        --history-length {HISTORY_LENGTH} \
        --total-steps {U_TOTAL_STEPS} \
        --random-steps {RANDOM_STEPS} \
        --update-after {UPDATE_AFTER} \
        --batch-size {BATCH_SIZE} \
        --hidden-dim {HIDDEN_DIM} \
        --num-envs {NUM_ENVS} \
        --eval-every {EVAL_EVERY} \
        --eval-episodes {EVAL_EPISODES} \
        --checkpoint-every {CHECKPOINT_EVERY} \
        --eval-manifest {U_MANIFEST_PATH_STR} \
        --seed {SEED} \
        --device {DEVICE} \
        --save-dir {U_RUN_ROOT_STR} \
        --checkpoint-dir {U_CKPT_ROOT_STR}
# Out:
# [state] single_upstream env_step = 0 / target 1,000,000
# [train] single_upstream fresh start -> 1,000,000
# [train] episode=5 step=636 return=-276.64 success=False time=52.7s geometry=upstream history=4
# [train] episode=10 step=1416 return=-319.62 success=False time=64.3s geometry=upstream history=4
# [train] episode=15 step=1962 return=-310.80 success=False time=17.7s geometry=upstream history=4
# [train] episode=20 step=2490 return=-364.13 success=False time=84.5s geometry=upstream history=4
# [train] episode=25 step=3360 return=-369.14 success=False time=84.5s geometry=upstream history=4
# [train] episode=30 step=4104 return=-327.25 success=False time=29.5s geometry=upstream history=4
# [train] episode=35 step=4698 return=-287.36 success=False time=44.3s geometry=upstream history=4
# [train] episode=40 step=5448 return=-334.36 success=False time=72.3s geometry=upstream history=4 | q1=501.006 actor=2.821 alpha=0.196
# [train] episode=45 step=6096 return=-275.50 success=False time=9.4s geometry=upstream history=4 | q1=1033.930 actor=3.053 alpha=0.190
# [train] episode=50 step=6618 return=-421.37 success=False time=65.5s geometry=upstream history=4 | q1=256.179 actor=3.667 alpha=0.185
# [train] episode=55 step=7146 return=-318.57 success=False time=43.1s geometry=upstream history=4 | q1=236.891 actor=4.330 alpha=0.181
# [train] episode=60 step=8034 return=-347.21 success=False time=68.0s geometry=upstream history=4 | q1=4.441 actor=5.714 alpha=0.173
# [train] episode=65 step=8430 return=-302.19 success=False time=32.1s geometry=upstream history=4 | q1=710.687 actor=5.430 alpha=0.170
# [train] episode=70 step=9156 return=-396.38 success=False time=122.2s geometry=upstream history=4 | q1=256.067 actor=7.429 alpha=0.165
# [train] episode=75 step=9846 return=-312.92 success=False time=56.9s geometry=upstream history=4 | q1=989.765 actor=9.145 alpha=0.160
# [train] episode=80 step=11070 return=-402.30 success=False time=171.2s geometry=upstream history=4 | q1=260.789 actor=9.959 alpha=0.152
# [train] episode=85 step=11994 return=-282.48 success=False time=47.6s geometry=upstream history=4 | q1=726.684 actor=12.310 alpha=0.146
# [train] episode=90 step=12954 return=-248.67 success=False time=79.2s geometry=upstream history=4 | q1=220.482 actor=12.911 alpha=0.142
# [train] episode=95 step=13674 return=-259.77 success=False time=81.7s geometry=upstream history=4 | q1=262.060 actor=13.392 alpha=0.139
# [train] episode=100 step=16080 return=-193.25 success=False time=199.6s geometry=upstream history=4 | q1=14.572 actor=14.231 alpha=0.128
# [train] episode=105 step=17412 return=-218.99 success=False time=240.1s geometry=upstream history=4 | q1=1020.692 actor=14.023 alpha=0.123
# [train] episode=110 step=19332 return=-262.91 success=False time=240.1s geometry=upstream history=4 | q1=413.853 actor=17.610 alpha=0.118
# [train] episode=115 step=21162 return=-211.32 success=False time=165.9s geometry=upstream history=4 | q1=557.715 actor=16.169 alpha=0.114
# [train] episode=120 step=22740 return=-250.25 success=False time=171.6s geometry=upstream history=4 | q1=19.977 actor=15.860 alpha=0.110
# [train] episode=125 step=24480 return=-201.63 success=False time=142.2s geometry=upstream history=4 | q1=170.838 actor=16.377 alpha=0.105
# [train] episode=130 step=24822 return=-196.69 success=False time=162.2s geometry=upstream history=4 | q1=375.496 actor=17.013 alpha=0.105
# [eval] step=25002 objective=arrival_v2 return=-240.22 safety=17.974 success=0.00% time=97.5s energy=72786.3 path=47.5 prog=0.07
# [train] episode=135 step=25266 return=-251.24 success=False time=81.4s geometry=upstream history=4 | q1=12.961 actor=16.683 alpha=0.104
# [train] episode=140 step=28044 return=-81.38 success=False time=240.1s geometry=upstream history=4 | q1=124.243 actor=18.916 alpha=0.097
# [train] episode=145 step=29844 return=-168.68 success=False time=214.2s geometry=upstream history=4 | q1=216.448 actor=17.951 alpha=0.095
# [train] episode=150 step=30936 return=-62.89 success=False time=240.1s geometry=upstream history=4 | q1=136.212 actor=18.504 alpha=0.094
# [train] episode=155 step=32370 return=-206.41 success=False time=115.0s geometry=upstream history=4 | q1=406.118 actor=18.304 alpha=0.094
# [train] episode=160 step=34110 return=-158.79 success=False time=208.8s geometry=upstream history=4 | q1=241.550 actor=18.567 alpha=0.095
# [train] episode=165 step=35742 return=-228.47 success=False time=135.4s geometry=upstream history=4 | q1=362.064 actor=20.105 alpha=0.097
# [train] episode=170 step=37458 return=-237.22 success=False time=153.0s geometry=upstream history=4 | q1=86.970 actor=18.540 alpha=0.098
# [train] episode=175 step=38760 return=-237.41 success=False time=187.0s geometry=upstream history=4 | q1=25.656 actor=19.402 alpha=0.100
# [train] episode=180 step=40566 return=143.64 success=True time=147.9s geometry=upstream history=4 | q1=1.056 actor=17.971 alpha=0.099
# [train] episode=185 step=42354 return=-187.47 success=False time=240.1s geometry=upstream history=4 | q1=11.431 actor=21.310 alpha=0.102
# [train] episode=190 step=44052 return=-157.42 success=False time=143.3s geometry=upstream history=4 | q1=765.721 actor=20.216 alpha=0.104
# [train] episode=195 step=46470 return=-61.60 success=False time=240.1s geometry=upstream history=4 | q1=241.316 actor=20.013 alpha=0.108
# [train] episode=200 step=46956 return=-105.33 success=False time=240.1s geometry=upstream history=4 | q1=204.933 actor=19.880 alpha=0.108
# [train] episode=205 step=49428 return=142.24 success=True time=121.9s geometry=upstream history=4 | q1=25.210 actor=21.795 alpha=0.106
# [eval] step=50004 objective=arrival_v2 return=-106.69 safety=9.900 success=16.67% time=173.5s energy=143033.8 path=100.2 prog=0.31
# [train] episode=210 step=50742 return=141.78 success=True time=109.0s geometry=upstream history=4 | q1=327.961 actor=20.512 alpha=0.103
# [train] episode=215 step=52506 return=143.58 success=True time=111.2s geometry=upstream history=4 | q1=63.576 actor=19.114 alpha=0.102
# [train] episode=220 step=54414 return=143.10 success=True time=138.6s geometry=upstream history=4 | q1=2.240 actor=18.732 alpha=0.096
# [train] episode=225 step=55548 return=143.73 success=True time=94.0s geometry=upstream history=4 | q1=64.893 actor=20.913 alpha=0.093
# [train] episode=230 step=58068 return=-239.98 success=False time=238.4s geometry=upstream history=4 | q1=37.258 actor=20.787 alpha=0.090
# [train] episode=235 step=60234 return=-80.18 success=False time=240.1s geometry=upstream history=4 | q1=55.435 actor=20.790 alpha=0.088
# [train] episode=240 step=61614 return=143.81 success=True time=91.8s geometry=upstream history=4 | q1=3.433 actor=20.338 alpha=0.085
# [train] episode=245 step=64134 return=-111.42 success=False time=240.1s geometry=upstream history=4 | q1=33.903 actor=20.587 alpha=0.078
# [train] episode=250 step=65634 return=144.08 success=True time=124.1s geometry=upstream history=4 | q1=349.925 actor=22.151 alpha=0.075
# [train] episode=255 step=68310 return=-23.90 success=False time=240.1s geometry=upstream history=4 | q1=5.216 actor=22.834 alpha=0.068
# [train] episode=260 step=69756 return=-21.35 success=False time=240.1s geometry=upstream history=4 | q1=161.843 actor=21.095 alpha=0.065
# [train] episode=265 step=71394 return=-23.42 success=False time=240.1s geometry=upstream history=4 | q1=2.548 actor=19.445 alpha=0.062
# [train] episode=270 step=74094 return=-58.99 success=False time=240.1s geometry=upstream history=4 | q1=17.362 actor=19.470 alpha=0.059
# [eval] step=75000 objective=arrival_v2 return=40.75 safety=4.221 success=53.33% time=193.2s energy=151377.9 path=98.1 prog=0.76
# [train] episode=275 step=76188 return=-28.32 success=False time=240.1s geometry=upstream history=4 | q1=180.383 actor=18.218 alpha=0.054
# [train] episode=280 step=78642 return=-60.64 success=False time=240.1s geometry=upstream history=4 | q1=137.032 actor=21.464 alpha=0.050
# [train] episode=285 step=81198 return=69.19 success=True time=109.4s geometry=upstream history=4 | q1=182.234 actor=20.768 alpha=0.047
# [train] episode=290 step=82854 return=-15.19 success=False time=240.1s geometry=upstream history=4 | q1=63.490 actor=20.937 alpha=0.046
# [train] episode=295 step=84570 return=-70.04 success=False time=240.1s geometry=upstream history=4 | q1=470.618 actor=22.619 alpha=0.045
# [train] episode=300 step=87384 return=-81.67 success=False time=240.1s geometry=upstream history=4 | q1=1.843 actor=18.570 alpha=0.044
# [train] episode=305 step=89904 return=-169.75 success=False time=240.1s geometry=upstream history=4 | q1=84.527 actor=21.845 alpha=0.042
# [train] episode=310 step=91638 return=-66.76 success=False time=240.1s geometry=upstream history=4 | q1=205.693 actor=19.092 alpha=0.041
# [train] episode=315 step=94434 return=-43.68 success=False time=240.1s geometry=upstream history=4 | q1=1.247 actor=21.279 alpha=0.040
# [train] episode=320 step=96138 return=-19.97 success=False time=240.1s geometry=upstream history=4 | q1=163.905 actor=20.073 alpha=0.040
# [train] episode=325 step=98580 return=-384.58 success=False time=240.1s geometry=upstream history=4 | q1=2.577 actor=22.287 alpha=0.040
# [eval] step=100002 objective=arrival_v2 return=0.83 safety=8.017 success=30.00% time=212.1s energy=163421.2 path=95.9 prog=0.78
# [train] episode=330 step=100314 return=-33.16 success=False time=240.1s geometry=upstream history=4 | q1=9.518 actor=18.740 alpha=0.040
# [train] episode=335 step=103110 return=-43.68 success=False time=240.1s geometry=upstream history=4 | q1=103.280 actor=20.316 alpha=0.041
# [train] episode=340 step=105306 return=126.63 success=True time=182.2s geometry=upstream history=4 | q1=17.682 actor=18.894 alpha=0.043
# [train] episode=345 step=106890 return=143.72 success=True time=131.5s geometry=upstream history=4 | q1=177.216 actor=20.663 alpha=0.045
# [train] episode=350 step=108450 return=143.62 success=True time=129.2s geometry=upstream history=4 | q1=6.035 actor=21.610 alpha=0.045
# [train] episode=355 step=110532 return=143.33 success=True time=130.3s geometry=upstream history=4 | q1=2.008 actor=24.299 alpha=0.047
# [train] episode=360 step=112290 return=143.61 success=True time=78.5s geometry=upstream history=4 | q1=1.334 actor=19.858 alpha=0.049
# [train] episode=365 step=113676 return=143.47 success=True time=114.6s geometry=upstream history=4 | q1=11.282 actor=20.425 alpha=0.050
# [train] episode=370 step=115344 return=-10.29 success=False time=240.1s geometry=upstream history=4 | q1=1.959 actor=20.405 alpha=0.050
# [train] episode=375 step=116958 return=-200.50 success=False time=191.7s geometry=upstream history=4 | q1=15.637 actor=22.968 alpha=0.050
# [train] episode=380 step=118650 return=144.12 success=True time=140.1s geometry=upstream history=4 | q1=19.041 actor=21.213 alpha=0.052
# [train] episode=385 step=120552 return=143.88 success=True time=136.3s geometry=upstream history=4 | q1=270.348 actor=21.346 alpha=0.054
# [train] episode=390 step=122250 return=-134.62 success=False time=240.1s geometry=upstream history=4 | q1=47.447 actor=19.520 alpha=0.056
# [train] episode=395 step=123468 return=143.96 success=True time=115.2s geometry=upstream history=4 | q1=173.480 actor=20.603 alpha=0.055
# [train] episode=400 step=124974 return=143.90 success=True time=132.5s geometry=upstream history=4 | q1=3.427 actor=20.908 alpha=0.053
# [eval] step=125004 objective=arrival_v2 return=67.56 safety=3.050 success=66.67% time=164.8s energy=134105.9 path=86.5 prog=0.82
# [train] episode=405 step=126984 return=36.75 success=True time=207.0s geometry=upstream history=4 | q1=3.322 actor=19.281 alpha=0.055
# [train] episode=410 step=128808 return=-151.57 success=False time=240.1s geometry=upstream history=4 | q1=32.643 actor=20.560 alpha=0.056
# [train] episode=415 step=130932 return=143.26 success=True time=87.0s geometry=upstream history=4 | q1=23.614 actor=20.539 alpha=0.055
# [train] episode=420 step=132540 return=141.07 success=True time=155.7s geometry=upstream history=4 | q1=1.335 actor=19.649 alpha=0.054
# [train] episode=425 step=134382 return=-200.12 success=False time=236.7s geometry=upstream history=4 | q1=8.524 actor=18.480 alpha=0.055
# [train] episode=430 step=136122 return=-36.50 success=False time=240.1s geometry=upstream history=4 | q1=2.003 actor=22.445 alpha=0.055
# [train] episode=435 step=137436 return=143.15 success=True time=213.3s geometry=upstream history=4 | q1=97.499 actor=20.670 alpha=0.055
# [train] episode=440 step=139248 return=107.27 success=True time=164.2s geometry=upstream history=4 | q1=43.178 actor=20.088 alpha=0.055
# [train] episode=445 step=140784 return=-266.32 success=False time=95.6s geometry=upstream history=4 | q1=1.134 actor=20.708 alpha=0.055
# [train] episode=450 step=143136 return=-305.40 success=False time=195.5s geometry=upstream history=4 | q1=39.916 actor=19.569 alpha=0.052
# [train] episode=455 step=144576 return=-32.78 success=False time=240.1s geometry=upstream history=4 | q1=79.220 actor=20.943 alpha=0.051
# [train] episode=460 step=146808 return=-64.46 success=False time=240.1s geometry=upstream history=4 | q1=70.800 actor=20.269 alpha=0.050
# [train] episode=465 step=148230 return=-23.74 success=False time=240.1s geometry=upstream history=4 | q1=1.311 actor=19.859 alpha=0.049
# [eval] step=150000 objective=arrival_v2 return=-9.53 safety=14.008 success=36.67% time=182.3s energy=142178.9 path=93.3 prog=0.79
# [train] episode=470 step=150372 return=-303.59 success=False time=135.7s geometry=upstream history=4 | q1=2.507 actor=19.960 alpha=0.047
# [train] episode=475 step=152328 return=142.79 success=True time=196.4s geometry=upstream history=4 | q1=247.883 actor=20.388 alpha=0.045
# [train] episode=480 step=153996 return=-177.29 success=False time=145.6s geometry=upstream history=4 | q1=1.859 actor=19.781 alpha=0.045
# [train] episode=485 step=155706 return=142.38 success=True time=141.8s geometry=upstream history=4 | q1=8.785 actor=18.870 alpha=0.044
# [train] episode=490 step=157656 return=142.99 success=True time=223.8s geometry=upstream history=4 | q1=121.888 actor=18.185 alpha=0.045
# [train] episode=495 step=159384 return=143.35 success=True time=124.8s geometry=upstream history=4 | q1=3.421 actor=19.740 alpha=0.045
# [train] episode=500 step=161364 return=-456.29 success=False time=240.1s geometry=upstream history=4 | q1=15.638 actor=18.984 alpha=0.044
# [train] episode=505 step=163764 return=143.39 success=True time=123.3s geometry=upstream history=4 | q1=3.644 actor=17.685 alpha=0.046
# [train] episode=510 step=165744 return=141.24 success=True time=164.1s geometry=upstream history=4 | q1=44.890 actor=21.850 alpha=0.045
# [train] episode=515 step=167136 return=143.06 success=True time=115.5s geometry=upstream history=4 | q1=37.560 actor=20.693 alpha=0.045
# [train] episode=520 step=169530 return=129.30 success=True time=198.9s geometry=upstream history=4 | q1=73.471 actor=21.273 alpha=0.046
# [train] episode=525 step=170964 return=-39.99 success=False time=240.1s geometry=upstream history=4 | q1=207.436 actor=19.127 alpha=0.046
# [train] episode=530 step=173022 return=-71.81 success=False time=240.1s geometry=upstream history=4 | q1=64.506 actor=15.605 alpha=0.048
# [train] episode=535 step=174546 return=-329.93 success=False time=141.2s geometry=upstream history=4 | q1=28.346 actor=18.581 alpha=0.048
# [eval] step=175002 objective=arrival_v2 return=7.25 safety=7.308 success=33.33% time=209.8s energy=157026.9 path=97.6 prog=0.81
# [train] episode=540 step=176658 return=-21.35 success=False time=240.1s geometry=upstream history=4 | q1=2.090 actor=19.656 alpha=0.048
# [train] episode=545 step=178962 return=-23.90 success=False time=240.1s geometry=upstream history=4 | q1=1.414 actor=20.405 alpha=0.049
# [train] episode=550 step=180720 return=-32.47 success=False time=240.1s geometry=upstream history=4 | q1=25.231 actor=20.700 alpha=0.051
# [train] episode=555 step=182886 return=-43.10 success=False time=240.1s geometry=upstream history=4 | q1=11.941 actor=18.046 alpha=0.053
# [train] episode=560 step=184770 return=143.23 success=True time=218.2s geometry=upstream history=4 | q1=2.116 actor=21.736 alpha=0.051
# [train] episode=565 step=186294 return=144.08 success=True time=167.6s geometry=upstream history=4 | q1=106.582 actor=19.606 alpha=0.050
# [train] episode=570 step=188670 return=-17.24 success=False time=240.1s geometry=upstream history=4 | q1=88.641 actor=20.177 alpha=0.047
# [train] episode=575 step=190254 return=144.32 success=True time=107.0s geometry=upstream history=4 | q1=17.786 actor=16.829 alpha=0.046
# [train] episode=580 step=192324 return=144.34 success=True time=160.9s geometry=upstream history=4 | q1=141.071 actor=22.296 alpha=0.047
# [train] episode=585 step=193674 return=-34.57 success=False time=240.1s geometry=upstream history=4 | q1=1.712 actor=22.479 alpha=0.046
# [train] episode=590 step=195450 return=-15.13 success=False time=240.1s geometry=upstream history=4 | q1=14.795 actor=18.019 alpha=0.045
# [train] episode=595 step=197574 return=142.86 success=True time=213.7s geometry=upstream history=4 | q1=58.721 actor=19.464 alpha=0.044
# [train] episode=600 step=199458 return=-23.14 success=False time=240.1s geometry=upstream history=4 | q1=2.336 actor=18.091 alpha=0.043
# [eval] step=200004 objective=arrival_v2 return=2.81 safety=16.892 success=46.67% time=180.8s energy=137935.9 path=91.1 prog=0.75
# [train] episode=605 step=201552 return=-14.97 success=False time=240.1s geometry=upstream history=4 | q1=1.707 actor=20.220 alpha=0.042
# [train] episode=610 step=203382 return=143.79 success=True time=178.5s geometry=upstream history=4 | q1=87.444 actor=18.790 alpha=0.042
# [train] episode=615 step=206148 return=-32.87 success=False time=240.1s geometry=upstream history=4 | q1=2.075 actor=19.603 alpha=0.041
# [train] episode=620 step=208290 return=143.72 success=True time=167.1s geometry=upstream history=4 | q1=1.552 actor=21.030 alpha=0.040
# [train] episode=625 step=210012 return=-44.94 success=False time=240.1s geometry=upstream history=4 | q1=30.041 actor=18.555 alpha=0.040
# [train] episode=630 step=211866 return=115.47 success=True time=153.7s geometry=upstream history=4 | q1=1.697 actor=21.320 alpha=0.040
# [train] episode=635 step=214542 return=-54.40 success=False time=240.1s geometry=upstream history=4 | q1=145.473 actor=21.174 alpha=0.038
# [train] episode=640 step=216366 return=144.05 success=True time=133.2s geometry=upstream history=4 | q1=210.410 actor=20.847 alpha=0.039
# [train] episode=645 step=218970 return=-27.13 success=False time=240.1s geometry=upstream history=4 | q1=1.454 actor=17.568 alpha=0.041
# [train] episode=650 step=220326 return=-234.81 success=False time=240.1s geometry=upstream history=4 | q1=20.141 actor=20.387 alpha=0.041
# [train] episode=655 step=223002 return=-33.40 success=False time=240.1s geometry=upstream history=4 | q1=57.508 actor=19.835 alpha=0.043
# [train] episode=660 step=224718 return=143.57 success=True time=132.0s geometry=upstream history=4 | q1=45.965 actor=21.323 alpha=0.043
# [eval] step=225000 objective=arrival_v2 return=-47.43 safety=27.004 success=33.33% time=193.7s energy=146279.5 path=94.5 prog=0.73
# [train] episode=665 step=226320 return=143.44 success=True time=106.0s geometry=upstream history=4 | q1=12.793 actor=19.209 alpha=0.042
# [train] episode=670 step=228786 return=-122.51 success=False time=240.1s geometry=upstream history=4 | q1=28.178 actor=19.846 alpha=0.042
# [train] episode=675 step=230280 return=-47.21 success=False time=240.1s geometry=upstream history=4 | q1=12.440 actor=20.306 alpha=0.042
# [train] episode=680 step=232104 return=-42.77 success=False time=240.1s geometry=upstream history=4 | q1=30.547 actor=20.797 alpha=0.042
# [train] episode=685 step=233958 return=-14.89 success=False time=240.1s geometry=upstream history=4 | q1=87.110 actor=18.712 alpha=0.041
# [train] episode=690 step=236328 return=-60.93 success=False time=240.1s geometry=upstream history=4 | q1=2.768 actor=19.733 alpha=0.041
# [train] episode=695 step=238248 return=143.67 success=True time=127.8s geometry=upstream history=4 | q1=98.388 actor=18.597 alpha=0.041
# [train] episode=700 step=239778 return=-18.48 success=False time=240.1s geometry=upstream history=4 | q1=1.994 actor=17.857 alpha=0.041
# [train] episode=705 step=241554 return=-66.40 success=False time=240.1s geometry=upstream history=4 | q1=2.156 actor=19.036 alpha=0.041
# [train] episode=710 step=243300 return=143.81 success=True time=165.1s geometry=upstream history=4 | q1=93.743 actor=19.915 alpha=0.040
# [train] episode=715 step=246018 return=-26.93 success=False time=240.1s geometry=upstream history=4 | q1=2.123 actor=18.603 alpha=0.041
# [train] episode=720 step=247350 return=140.94 success=True time=90.8s geometry=upstream history=4 | q1=1.873 actor=20.537 alpha=0.041
# [eval] step=250002 objective=arrival_v2 return=24.53 safety=4.527 success=40.00% time=186.3s energy=143910.4 path=106.0 prog=0.85
# [train] episode=725 step=250182 return=-49.71 success=False time=240.1s geometry=upstream history=4 | q1=3.563 actor=19.153 alpha=0.041
# [train] episode=730 step=251742 return=143.90 success=True time=73.4s geometry=upstream history=4 | q1=3.383 actor=19.442 alpha=0.040
# [train] episode=735 step=253134 return=-143.76 success=False time=240.1s geometry=upstream history=4 | q1=4.733 actor=18.929 alpha=0.041
# [train] episode=740 step=255192 return=140.95 success=True time=174.0s geometry=upstream history=4 | q1=37.767 actor=19.777 alpha=0.042
# [train] episode=745 step=257766 return=143.38 success=True time=186.7s geometry=upstream history=4 | q1=1.821 actor=22.051 alpha=0.042
# [train] episode=750 step=258918 return=-36.54 success=False time=240.1s geometry=upstream history=4 | q1=2.584 actor=18.404 alpha=0.042
# [train] episode=755 step=261534 return=-16.74 success=False time=240.1s geometry=upstream history=4 | q1=3.931 actor=20.709 alpha=0.041
# [train] episode=760 step=263550 return=-49.25 success=False time=240.1s geometry=upstream history=4 | q1=30.988 actor=18.807 alpha=0.041
# [train] episode=765 step=264702 return=-83.46 success=False time=240.1s geometry=upstream history=4 | q1=2.793 actor=19.596 alpha=0.041
# [train] episode=770 step=267570 return=-25.24 success=False time=240.1s geometry=upstream history=4 | q1=78.542 actor=16.922 alpha=0.042
# [train] episode=775 step=269334 return=-78.21 success=False time=240.1s geometry=upstream history=4 | q1=2.706 actor=23.106 alpha=0.042
# [train] episode=780 step=271278 return=143.54 success=True time=153.9s geometry=upstream history=4 | q1=228.414 actor=20.732 alpha=0.042
# [train] episode=785 step=273354 return=-337.02 success=False time=240.1s geometry=upstream history=4 | q1=1.753 actor=17.830 alpha=0.042
# [eval] step=275004 objective=arrival_v2 return=37.74 safety=3.996 success=43.33% time=189.1s energy=144105.5 path=104.5 prog=0.89
# [train] episode=790 step=275076 return=-12.95 success=False time=240.1s geometry=upstream history=4 | q1=1.714 actor=19.282 alpha=0.041
# [train] episode=795 step=277392 return=-23.20 success=False time=240.1s geometry=upstream history=4 | q1=39.795 actor=19.482 alpha=0.041
# [train] episode=800 step=278976 return=-253.69 success=False time=89.5s geometry=upstream history=4 | q1=27.199 actor=19.698 alpha=0.040
# [train] episode=805 step=280434 return=143.76 success=True time=121.0s geometry=upstream history=4 | q1=2.272 actor=20.233 alpha=0.040
# [train] episode=810 step=282216 return=139.98 success=True time=214.5s geometry=upstream history=4 | q1=36.955 actor=20.787 alpha=0.041
# [train] episode=815 step=284730 return=-25.58 success=False time=240.1s geometry=upstream history=4 | q1=7.392 actor=18.359 alpha=0.041
# [train] episode=820 step=286836 return=143.65 success=True time=174.6s geometry=upstream history=4 | q1=1.809 actor=20.698 alpha=0.040
# [train] episode=825 step=287958 return=-36.45 success=False time=240.1s geometry=upstream history=4 | q1=2.496 actor=18.897 alpha=0.040
# [train] episode=830 step=290232 return=-38.74 success=False time=240.1s geometry=upstream history=4 | q1=13.117 actor=18.830 alpha=0.040
# [train] episode=835 step=291912 return=-247.91 success=False time=160.6s geometry=upstream history=4 | q1=1.718 actor=21.585 alpha=0.040
# [train] episode=840 step=293952 return=-32.09 success=False time=240.1s geometry=upstream history=4 | q1=106.674 actor=20.490 alpha=0.038
# [train] episode=845 step=296016 return=-30.39 success=False time=240.1s geometry=upstream history=4 | q1=41.220 actor=18.663 alpha=0.039
# [train] episode=850 step=297912 return=-25.21 success=False time=240.1s geometry=upstream history=4 | q1=37.471 actor=16.423 alpha=0.039
# [train] episode=855 step=299874 return=-41.26 success=False time=240.1s geometry=upstream history=4 | q1=43.870 actor=17.441 alpha=0.040
# [eval] step=300000 objective=arrival_v2 return=55.75 safety=8.055 success=63.33% time=174.8s energy=131737.6 path=96.9 prog=0.85
# [train] episode=860 step=301812 return=142.60 success=True time=124.2s geometry=upstream history=4 | q1=1.476 actor=18.709 alpha=0.041
# [train] episode=865 step=302994 return=141.58 success=True time=207.5s geometry=upstream history=4 | q1=3.013 actor=18.732 alpha=0.041
# [train] episode=870 step=305574 return=142.54 success=True time=225.0s geometry=upstream history=4 | q1=164.743 actor=19.736 alpha=0.041
# [train] episode=875 step=306174 return=-52.61 success=False time=240.1s geometry=upstream history=4 | q1=11.851 actor=18.504 alpha=0.041
# [train] episode=880 step=308778 return=-25.21 success=False time=240.1s geometry=upstream history=4 | q1=11.410 actor=19.483 alpha=0.039
# [train] episode=885 step=310446 return=143.51 success=True time=181.2s geometry=upstream history=4 | q1=87.880 actor=20.170 alpha=0.040
# [train] episode=890 step=311742 return=-41.53 success=False time=240.1s geometry=upstream history=4 | q1=1.286 actor=17.131 alpha=0.039
# [train] episode=895 step=313968 return=-25.93 success=False time=240.1s geometry=upstream history=4 | q1=63.005 actor=19.721 alpha=0.038
# [train] episode=900 step=315798 return=-49.20 success=False time=240.1s geometry=upstream history=4 | q1=1.675 actor=15.199 alpha=0.039
# [train] episode=905 step=318144 return=141.25 success=True time=157.3s geometry=upstream history=4 | q1=28.455 actor=18.604 alpha=0.039
# [train] episode=910 step=319920 return=144.30 success=True time=147.1s geometry=upstream history=4 | q1=45.891 actor=20.071 alpha=0.039
# [train] episode=915 step=321210 return=143.42 success=True time=83.1s geometry=upstream history=4 | q1=2.507 actor=20.292 alpha=0.039
# [train] episode=920 step=322620 return=140.37 success=True time=135.4s geometry=upstream history=4 | q1=14.955 actor=18.580 alpha=0.039
# [train] episode=925 step=324252 return=143.89 success=True time=135.2s geometry=upstream history=4 | q1=7.783 actor=17.378 alpha=0.038
# [eval] step=325002 objective=arrival_v2 return=90.14 safety=3.987 success=73.33% time=175.3s energy=134796.9 path=92.1 prog=0.89
# [train] episode=930 step=327006 return=-97.88 success=False time=240.1s geometry=upstream history=4 | q1=53.686 actor=20.371 alpha=0.036
# [train] episode=935 step=328146 return=123.37 success=True time=82.7s geometry=upstream history=4 | q1=32.854 actor=17.582 alpha=0.036
# [train] episode=940 step=329970 return=143.45 success=True time=177.2s geometry=upstream history=4 | q1=29.740 actor=17.899 alpha=0.036
# [train] episode=945 step=331638 return=141.90 success=True time=234.4s geometry=upstream history=4 | q1=52.602 actor=14.972 alpha=0.037
# [train] episode=950 step=333522 return=142.75 success=True time=199.4s geometry=upstream history=4 | q1=87.477 actor=18.342 alpha=0.037
# [train] episode=955 step=334632 return=142.93 success=True time=209.4s geometry=upstream history=4 | q1=127.815 actor=17.518 alpha=0.036
# [train] episode=960 step=336960 return=100.52 success=True time=91.8s geometry=upstream history=4 | q1=5.838 actor=17.157 alpha=0.036
# [train] episode=965 step=338670 return=143.22 success=True time=187.2s geometry=upstream history=4 | q1=30.287 actor=15.562 alpha=0.037
# [train] episode=970 step=340350 return=144.16 success=True time=139.3s geometry=upstream history=4 | q1=126.168 actor=17.658 alpha=0.037
# [train] episode=975 step=342120 return=143.56 success=True time=197.7s geometry=upstream history=4 | q1=76.829 actor=14.877 alpha=0.037
# [train] episode=980 step=344226 return=144.05 success=True time=81.3s geometry=upstream history=4 | q1=41.238 actor=15.442 alpha=0.036
# [train] episode=985 step=346116 return=144.10 success=True time=156.6s geometry=upstream history=4 | q1=1.371 actor=17.546 alpha=0.036
# [train] episode=990 step=347226 return=144.51 success=True time=141.9s geometry=upstream history=4 | q1=211.297 actor=18.531 alpha=0.036
# [train] episode=995 step=349428 return=-18.51 success=False time=240.1s geometry=upstream history=4 | q1=2.035 actor=17.314 alpha=0.036
# [eval] step=350004 objective=arrival_v2 return=32.69 safety=5.346 success=43.33% time=197.5s energy=143724.4 path=97.4 prog=0.81
# [train] episode=1000 step=350742 return=139.96 success=True time=85.2s geometry=upstream history=4 | q1=40.777 actor=16.570 alpha=0.036
# [train] episode=1005 step=352752 return=144.46 success=True time=124.1s geometry=upstream history=4 | q1=1.777 actor=16.508 alpha=0.036
# [train] episode=1010 step=354186 return=121.02 success=True time=154.8s geometry=upstream history=4 | q1=1.300 actor=17.626 alpha=0.037
# [train] episode=1015 step=355980 return=-13.38 success=False time=240.1s geometry=upstream history=4 | q1=4.739 actor=20.786 alpha=0.036
# [train] episode=1020 step=358632 return=140.04 success=True time=220.2s geometry=upstream history=4 | q1=49.529 actor=14.758 alpha=0.035
# [train] episode=1025 step=360102 return=-28.74 success=False time=240.1s geometry=upstream history=4 | q1=37.547 actor=16.311 alpha=0.036
# [train] episode=1030 step=362748 return=-22.41 success=False time=240.1s geometry=upstream history=4 | q1=43.006 actor=16.096 alpha=0.035
# [train] episode=1035 step=364470 return=101.97 success=True time=136.3s geometry=upstream history=4 | q1=2.150 actor=17.907 alpha=0.035
# [train] episode=1040 step=366270 return=142.70 success=True time=194.0s geometry=upstream history=4 | q1=148.062 actor=16.358 alpha=0.035
# [train] episode=1045 step=368106 return=143.09 success=True time=124.0s geometry=upstream history=4 | q1=28.542 actor=17.509 alpha=0.034
# [train] episode=1050 step=369402 return=-27.07 success=False time=240.1s geometry=upstream history=4 | q1=22.383 actor=14.726 alpha=0.035
# [train] episode=1055 step=370944 return=144.29 success=True time=127.8s geometry=upstream history=4 | q1=3.606 actor=20.576 alpha=0.036
# [train] episode=1060 step=373074 return=141.93 success=True time=151.6s geometry=upstream history=4 | q1=4.035 actor=15.053 alpha=0.035
# [train] episode=1065 step=374706 return=-99.69 success=False time=240.1s geometry=upstream history=4 | q1=2.504 actor=17.118 alpha=0.035
# [eval] step=375000 objective=arrival_v2 return=61.56 safety=5.090 success=66.67% time=172.2s energy=130569.7 path=90.0 prog=0.83
# [train] episode=1070 step=375966 return=143.20 success=True time=211.8s geometry=upstream history=4 | q1=3.010 actor=17.950 alpha=0.035
# [train] episode=1075 step=377622 return=144.22 success=True time=137.1s geometry=upstream history=4 | q1=43.819 actor=17.546 alpha=0.035
# [train] episode=1080 step=379362 return=140.11 success=True time=144.5s geometry=upstream history=4 | q1=41.016 actor=15.196 alpha=0.036
# [train] episode=1085 step=380712 return=143.34 success=True time=169.1s geometry=upstream history=4 | q1=29.041 actor=14.893 alpha=0.037
# [train] episode=1090 step=382326 return=-21.89 success=False time=240.1s geometry=upstream history=4 | q1=3.937 actor=19.666 alpha=0.037
# [train] episode=1095 step=384312 return=143.63 success=True time=164.7s geometry=upstream history=4 | q1=4.055 actor=17.086 alpha=0.038
# [train] episode=1100 step=385086 return=141.39 success=True time=128.2s geometry=upstream history=4 | q1=27.836 actor=17.162 alpha=0.038
# [train] episode=1105 step=386562 return=143.60 success=True time=149.3s geometry=upstream history=4 | q1=142.010 actor=16.173 alpha=0.039
# [train] episode=1110 step=388188 return=144.46 success=True time=134.9s geometry=upstream history=4 | q1=17.351 actor=15.777 alpha=0.040
# [train] episode=1115 step=389646 return=144.33 success=True time=94.6s geometry=upstream history=4 | q1=2.521 actor=15.529 alpha=0.041
# [train] episode=1120 step=390930 return=-25.33 success=False time=240.1s geometry=upstream history=4 | q1=1.907 actor=17.145 alpha=0.040
# [train] episode=1125 step=392670 return=138.61 success=True time=156.8s geometry=upstream history=4 | q1=18.522 actor=16.310 alpha=0.043
# [train] episode=1130 step=393990 return=139.91 success=True time=158.9s geometry=upstream history=4 | q1=30.112 actor=16.824 alpha=0.042
# [train] episode=1135 step=395886 return=144.23 success=True time=139.9s geometry=upstream history=4 | q1=10.247 actor=16.182 alpha=0.042
# [train] episode=1140 step=397710 return=137.98 success=True time=181.1s geometry=upstream history=4 | q1=1.567 actor=15.888 alpha=0.043
# [train] episode=1145 step=399036 return=144.02 success=True time=127.4s geometry=upstream history=4 | q1=41.294 actor=17.616 alpha=0.043
# [eval] step=400002 objective=arrival_v2 return=95.42 safety=3.968 success=76.67% time=147.1s energy=120243.4 path=86.5 prog=0.92
# [train] episode=1150 step=400578 return=143.72 success=True time=81.9s geometry=upstream history=4 | q1=18.810 actor=15.115 alpha=0.043
# [train] episode=1155 step=401748 return=120.22 success=True time=225.2s geometry=upstream history=4 | q1=1.328 actor=14.978 alpha=0.043
# [train] episode=1160 step=403566 return=143.55 success=True time=164.7s geometry=upstream history=4 | q1=34.369 actor=17.188 alpha=0.042
# [train] episode=1165 step=404976 return=140.75 success=True time=168.1s geometry=upstream history=4 | q1=13.106 actor=15.307 alpha=0.042
# [train] episode=1170 step=405966 return=143.75 success=True time=112.0s geometry=upstream history=4 | q1=25.589 actor=17.014 alpha=0.042
# [train] episode=1175 step=407868 return=-39.51 success=False time=240.1s geometry=upstream history=4 | q1=85.224 actor=15.172 alpha=0.042
# [train] episode=1180 step=409188 return=142.38 success=True time=109.4s geometry=upstream history=4 | q1=32.703 actor=15.516 alpha=0.041
# [train] episode=1185 step=410604 return=142.93 success=True time=113.9s geometry=upstream history=4 | q1=182.545 actor=15.318 alpha=0.040
# [train] episode=1190 step=412038 return=144.19 success=True time=118.9s geometry=upstream history=4 | q1=75.083 actor=15.621 alpha=0.040
# [train] episode=1195 step=413022 return=-114.91 success=False time=240.1s geometry=upstream history=4 | q1=1.136 actor=13.853 alpha=0.040
# [train] episode=1200 step=415134 return=141.67 success=True time=186.7s geometry=upstream history=4 | q1=7.955 actor=13.889 alpha=0.040
# [train] episode=1205 step=416604 return=137.65 success=True time=202.9s geometry=upstream history=4 | q1=1.941 actor=14.794 alpha=0.040
# [train] episode=1210 step=418212 return=143.49 success=True time=83.5s geometry=upstream history=4 | q1=24.957 actor=16.596 alpha=0.041
# [train] episode=1215 step=419844 return=142.25 success=True time=135.4s geometry=upstream history=4 | q1=5.694 actor=16.667 alpha=0.041
# [train] episode=1220 step=420786 return=144.07 success=True time=177.1s geometry=upstream history=4 | q1=5.509 actor=15.094 alpha=0.040
# [train] episode=1225 step=422064 return=143.16 success=True time=105.6s geometry=upstream history=4 | q1=8.509 actor=13.174 alpha=0.040
# [train] episode=1230 step=423780 return=144.17 success=True time=142.3s geometry=upstream history=4 | q1=21.228 actor=16.180 alpha=0.040
# [eval] step=425004 objective=arrival_v2 return=86.27 safety=2.492 success=70.00% time=185.6s energy=142229.8 path=113.5 prog=0.88
# [train] episode=1235 step=425484 return=144.59 success=True time=130.3s geometry=upstream history=4 | q1=75.955 actor=15.289 alpha=0.040
# [train] episode=1240 step=427140 return=144.37 success=True time=96.3s geometry=upstream history=4 | q1=21.211 actor=15.723 alpha=0.040
# [train] episode=1245 step=427932 return=143.47 success=True time=203.5s geometry=upstream history=4 | q1=5.064 actor=13.132 alpha=0.039
# [train] episode=1250 step=429378 return=144.02 success=True time=119.8s geometry=upstream history=4 | q1=6.359 actor=15.457 alpha=0.041
# [train] episode=1255 step=431028 return=144.11 success=True time=175.2s geometry=upstream history=4 | q1=16.887 actor=12.152 alpha=0.042
# [train] episode=1260 step=432318 return=140.85 success=True time=129.0s geometry=upstream history=4 | q1=16.323 actor=14.520 alpha=0.041
# [train] episode=1265 step=433632 return=141.13 success=True time=108.7s geometry=upstream history=4 | q1=1.866 actor=13.580 alpha=0.043
# [train] episode=1270 step=435258 return=144.49 success=True time=142.6s geometry=upstream history=4 | q1=32.883 actor=14.004 alpha=0.042
# [train] episode=1275 step=436848 return=144.06 success=True time=86.9s geometry=upstream history=4 | q1=3.598 actor=14.742 alpha=0.042
# [train] episode=1280 step=438192 return=117.18 success=True time=111.3s geometry=upstream history=4 | q1=128.128 actor=14.554 alpha=0.043
# [train] episode=1285 step=439650 return=141.37 success=True time=120.9s geometry=upstream history=4 | q1=1.552 actor=15.179 alpha=0.043
# [train] episode=1290 step=441132 return=144.28 success=True time=162.4s geometry=upstream history=4 | q1=10.059 actor=11.931 alpha=0.044
# [train] episode=1295 step=442662 return=138.76 success=True time=139.5s geometry=upstream history=4 | q1=3.137 actor=11.217 alpha=0.042
# [train] episode=1300 step=443928 return=142.71 success=True time=113.7s geometry=upstream history=4 | q1=39.357 actor=13.597 alpha=0.044
# [train] episode=1305 step=445074 return=143.98 success=True time=74.3s geometry=upstream history=4 | q1=4.427 actor=14.684 alpha=0.046
# [train] episode=1310 step=446574 return=144.83 success=True time=118.2s geometry=upstream history=4 | q1=9.210 actor=14.106 alpha=0.047
# [train] episode=1315 step=447636 return=130.42 success=True time=152.2s geometry=upstream history=4 | q1=31.847 actor=13.564 alpha=0.046
# [train] episode=1320 step=449100 return=124.72 success=True time=121.3s geometry=upstream history=4 | q1=11.064 actor=13.229 alpha=0.047
# [eval] step=450000 objective=arrival_v2 return=134.16 safety=2.069 success=96.67% time=134.5s energy=111942.5 path=78.1 prog=0.93
# [train] episode=1325 step=450534 return=143.98 success=True time=168.6s geometry=upstream history=4 | q1=15.579 actor=13.003 alpha=0.048
# [train] episode=1330 step=451926 return=144.41 success=True time=112.3s geometry=upstream history=4 | q1=18.340 actor=10.704 alpha=0.048
# [train] episode=1335 step=453624 return=141.65 success=True time=140.9s geometry=upstream history=4 | q1=20.636 actor=14.333 alpha=0.047
# [train] episode=1340 step=454884 return=-24.54 success=False time=240.1s geometry=upstream history=4 | q1=48.200 actor=13.622 alpha=0.048
# [train] episode=1345 step=455946 return=134.36 success=True time=151.8s geometry=upstream history=4 | q1=1.994 actor=13.109 alpha=0.047
# [train] episode=1350 step=457314 return=144.56 success=True time=117.8s geometry=upstream history=4 | q1=10.257 actor=11.813 alpha=0.046
# [train] episode=1355 step=458502 return=141.06 success=True time=88.9s geometry=upstream history=4 | q1=1.557 actor=10.792 alpha=0.045
# [train] episode=1360 step=460206 return=138.89 success=True time=120.5s geometry=upstream history=4 | q1=3.958 actor=9.872 alpha=0.046
# [train] episode=1365 step=462156 return=143.62 success=True time=106.7s geometry=upstream history=4 | q1=2.221 actor=12.242 alpha=0.044
# [train] episode=1370 step=463398 return=130.12 success=True time=102.8s geometry=upstream history=4 | q1=7.352 actor=14.947 alpha=0.046
# [train] episode=1375 step=464898 return=129.76 success=True time=138.1s geometry=upstream history=4 | q1=17.616 actor=11.314 alpha=0.047
# [train] episode=1380 step=466266 return=143.60 success=True time=189.8s geometry=upstream history=4 | q1=16.751 actor=11.399 alpha=0.045
# [train] episode=1385 step=467820 return=143.81 success=True time=159.1s geometry=upstream history=4 | q1=50.367 actor=8.206 alpha=0.045
# [train] episode=1390 step=469428 return=139.66 success=True time=180.7s geometry=upstream history=4 | q1=20.152 actor=12.927 alpha=0.047
# [train] episode=1395 step=470328 return=129.05 success=True time=147.5s geometry=upstream history=4 | q1=2.610 actor=10.196 alpha=0.047
# [train] episode=1400 step=472158 return=144.29 success=True time=158.4s geometry=upstream history=4 | q1=2.175 actor=9.982 alpha=0.046
# [train] episode=1405 step=473700 return=144.07 success=True time=175.5s geometry=upstream history=4 | q1=1.674 actor=13.275 alpha=0.046
# [train] episode=1410 step=474894 return=139.00 success=True time=95.3s geometry=upstream history=4 | q1=32.593 actor=11.255 alpha=0.047
# [eval] step=475002 objective=arrival_v2 return=134.23 safety=4.851 success=100.00% time=136.3s energy=112883.0 path=76.0 prog=0.94
# [train] episode=1415 step=476268 return=143.22 success=True time=95.1s geometry=upstream history=4 | q1=2.268 actor=11.187 alpha=0.047
# [train] episode=1420 step=477666 return=143.94 success=True time=92.1s geometry=upstream history=4 | q1=71.528 actor=9.409 alpha=0.047
# [train] episode=1425 step=478968 return=-53.51 success=False time=240.1s geometry=upstream history=4 | q1=132.914 actor=14.401 alpha=0.046
# [train] episode=1430 step=480192 return=140.31 success=True time=101.2s geometry=upstream history=4 | q1=20.781 actor=12.015 alpha=0.047
# [train] episode=1435 step=481266 return=142.62 success=True time=140.5s geometry=upstream history=4 | q1=8.481 actor=10.303 alpha=0.047
# [train] episode=1440 step=482922 return=128.53 success=True time=187.2s geometry=upstream history=4 | q1=2.768 actor=10.586 alpha=0.047
# [train] episode=1445 step=484758 return=129.94 success=True time=188.9s geometry=upstream history=4 | q1=119.159 actor=7.775 alpha=0.047
# [train] episode=1450 step=486132 return=144.13 success=True time=113.9s geometry=upstream history=4 | q1=2.152 actor=9.771 alpha=0.047
# [train] episode=1455 step=487488 return=120.64 success=True time=112.2s geometry=upstream history=4 | q1=2.126 actor=8.493 alpha=0.048
# [train] episode=1460 step=489096 return=144.07 success=True time=129.0s geometry=upstream history=4 | q1=36.807 actor=5.867 alpha=0.046
# [train] episode=1465 step=489984 return=144.07 success=True time=73.3s geometry=upstream history=4 | q1=2.641 actor=8.902 alpha=0.047
# [train] episode=1470 step=491586 return=144.51 success=True time=150.5s geometry=upstream history=4 | q1=2.626 actor=9.301 alpha=0.046
# [train] episode=1475 step=492966 return=143.90 success=True time=91.2s geometry=upstream history=4 | q1=36.537 actor=8.222 alpha=0.045
# [train] episode=1480 step=494160 return=143.89 success=True time=123.4s geometry=upstream history=4 | q1=143.524 actor=11.106 alpha=0.045
# [train] episode=1485 step=495744 return=143.14 success=True time=83.0s geometry=upstream history=4 | q1=17.943 actor=6.931 alpha=0.047
# [train] episode=1490 step=496758 return=141.77 success=True time=83.9s geometry=upstream history=4 | q1=57.559 actor=8.388 alpha=0.047
# [train] episode=1495 step=498096 return=144.41 success=True time=132.2s geometry=upstream history=4 | q1=42.305 actor=8.476 alpha=0.048
# [train] episode=1500 step=499638 return=144.61 success=True time=139.0s geometry=upstream history=4 | q1=127.636 actor=11.164 alpha=0.048
# [eval] step=500004 objective=arrival_v2 return=111.72 safety=9.517 success=93.33% time=142.9s energy=117604.3 path=76.6 prog=0.93
# [train] episode=1505 step=501156 return=144.17 success=True time=125.8s geometry=upstream history=4 | q1=2.282 actor=8.745 alpha=0.047
# [train] episode=1510 step=502644 return=144.37 success=True time=123.2s geometry=upstream history=4 | q1=4.399 actor=7.628 alpha=0.046
# [train] episode=1515 step=503634 return=142.79 success=True time=165.0s geometry=upstream history=4 | q1=11.953 actor=9.293 alpha=0.045
# [train] episode=1520 step=504852 return=143.68 success=True time=103.2s geometry=upstream history=4 | q1=2.275 actor=8.952 alpha=0.047
# [train] episode=1525 step=505992 return=139.32 success=True time=131.3s geometry=upstream history=4 | q1=19.237 actor=7.365 alpha=0.048
# [train] episode=1530 step=507834 return=143.50 success=True time=152.7s geometry=upstream history=4 | q1=17.784 actor=8.951 alpha=0.048
# [train] episode=1535 step=508998 return=135.86 success=True time=134.6s geometry=upstream history=4 | q1=53.248 actor=7.403 alpha=0.048
# [train] episode=1540 step=510252 return=144.27 success=True time=95.5s geometry=upstream history=4 | q1=2.411 actor=8.546 alpha=0.049
# [train] episode=1545 step=511890 return=138.80 success=True time=178.1s geometry=upstream history=4 | q1=45.549 actor=10.403 alpha=0.049
# [train] episode=1550 step=512814 return=143.68 success=True time=166.6s geometry=upstream history=4 | q1=4.219 actor=6.922 alpha=0.049
# [train] episode=1555 step=514452 return=143.90 success=True time=179.5s geometry=upstream history=4 | q1=5.060 actor=8.332 alpha=0.049
# [train] episode=1560 step=516210 return=143.21 success=True time=177.4s geometry=upstream history=4 | q1=22.002 actor=11.321 alpha=0.049
# [train] episode=1565 step=517230 return=143.39 success=True time=107.7s geometry=upstream history=4 | q1=40.583 actor=7.587 alpha=0.049
# [train] episode=1570 step=518796 return=142.31 success=True time=151.6s geometry=upstream history=4 | q1=93.371 actor=7.239 alpha=0.048
# [train] episode=1575 step=519750 return=144.11 success=True time=78.9s geometry=upstream history=4 | q1=27.034 actor=5.041 alpha=0.049
# [train] episode=1580 step=520842 return=143.88 success=True time=177.2s geometry=upstream history=4 | q1=21.624 actor=7.526 alpha=0.049
# [train] episode=1585 step=522636 return=143.44 success=True time=183.7s geometry=upstream history=4 | q1=10.120 actor=9.052 alpha=0.050
# [train] episode=1590 step=524112 return=143.87 success=True time=126.6s geometry=upstream history=4 | q1=7.530 actor=5.878 alpha=0.050
# [eval] step=525000 objective=arrival_v2 return=132.31 safety=5.962 success=100.00% time=122.1s energy=105216.7 path=72.4 prog=0.94
# [train] episode=1595 step=525540 return=144.32 success=True time=80.3s geometry=upstream history=4 | q1=59.941 actor=7.853 alpha=0.051
# [train] episode=1600 step=526146 return=136.86 success=True time=100.7s geometry=upstream history=4 | q1=134.026 actor=7.946 alpha=0.053
# [train] episode=1605 step=527940 return=144.30 success=True time=150.3s geometry=upstream history=4 | q1=27.443 actor=5.141 alpha=0.053
# [train] episode=1610 step=529116 return=144.17 success=True time=140.9s geometry=upstream history=4 | q1=30.212 actor=5.361 alpha=0.054
# [train] episode=1615 step=530502 return=144.03 success=True time=136.4s geometry=upstream history=4 | q1=32.557 actor=11.630 alpha=0.053
# [train] episode=1620 step=531858 return=144.43 success=True time=105.5s geometry=upstream history=4 | q1=130.778 actor=6.312 alpha=0.053
# [train] episode=1625 step=532998 return=144.13 success=True time=174.2s geometry=upstream history=4 | q1=2.473 actor=8.144 alpha=0.053
# [train] episode=1630 step=534276 return=144.23 success=True time=125.4s geometry=upstream history=4 | q1=9.246 actor=5.984 alpha=0.052
# [train] episode=1635 step=535716 return=139.93 success=True time=138.7s geometry=upstream history=4 | q1=21.944 actor=1.885 alpha=0.052
# [train] episode=1640 step=537126 return=144.12 success=True time=134.7s geometry=upstream history=4 | q1=16.211 actor=5.562 alpha=0.053
# [train] episode=1645 step=538032 return=143.99 success=True time=75.0s geometry=upstream history=4 | q1=73.125 actor=6.997 alpha=0.053
# [train] episode=1650 step=539244 return=135.93 success=True time=100.4s geometry=upstream history=4 | q1=7.722 actor=3.422 alpha=0.052
# [train] episode=1655 step=541182 return=143.72 success=True time=75.8s geometry=upstream history=4 | q1=2.131 actor=6.126 alpha=0.053
# [train] episode=1660 step=542802 return=144.06 success=True time=111.2s geometry=upstream history=4 | q1=2.056 actor=5.281 alpha=0.052
# [train] episode=1665 step=543894 return=141.79 success=True time=86.2s geometry=upstream history=4 | q1=41.161 actor=6.703 alpha=0.052
# ...
# [train] episode=2845 step=859002 return=143.69 success=True time=191.9s geometry=upstream history=4 | q1=15.331 actor=-12.257 alpha=0.051
# [train] episode=2850 step=860418 return=133.57 success=True time=168.3s geometry=upstream history=4 | q1=64.619 actor=-11.640 alpha=0.050
# [train] episode=2855 step=861498 return=143.51 success=True time=145.5s geometry=upstream history=4 | q1=15.591 actor=-13.322 alpha=0.048
# [train] episode=2860 step=863208 return=136.60 success=True time=144.0s geometry=upstream history=4 | q1=46.314 actor=-13.778 alpha=0.045
# [train] episode=2865 step=864036 return=133.14 success=True time=160.2s geometry=upstream history=4 | q1=24.665 actor=-12.914 alpha=0.045
# [train] episode=2870 step=865572 return=143.24 success=True time=127.5s geometry=upstream history=4 | q1=2.559 actor=-14.026 alpha=0.043
# [train] episode=2875 step=866736 return=144.66 success=True time=141.0s geometry=upstream history=4 | q1=23.728 actor=-12.943 alpha=0.042
# [train] episode=2880 step=868188 return=144.37 success=True time=120.1s geometry=upstream history=4 | q1=38.569 actor=-13.375 alpha=0.043
# [train] episode=2885 step=869976 return=144.33 success=True time=156.6s geometry=upstream history=4 | q1=1.929 actor=-9.138 alpha=0.045
# [train] episode=2890 step=871194 return=141.98 success=True time=100.7s geometry=upstream history=4 | q1=1.524 actor=-11.830 alpha=0.044
# [train] episode=2895 step=872358 return=139.04 success=True time=174.0s geometry=upstream history=4 | q1=225.208 actor=-12.490 alpha=0.046
# [train] episode=2900 step=873612 return=144.73 success=True time=107.7s geometry=upstream history=4 | q1=45.407 actor=-11.795 alpha=0.045
# [train] episode=2905 step=874692 return=139.48 success=True time=115.7s geometry=upstream history=4 | q1=19.685 actor=-13.346 alpha=0.046
# [eval] step=875004 objective=arrival_v2 return=131.76 safety=0.926 success=93.33% time=131.9s energy=110097.6 path=77.2 prog=0.93
# [train] episode=2910 step=875778 return=143.87 success=True time=71.9s geometry=upstream history=4 | q1=15.219 actor=-12.347 alpha=0.045
# [train] episode=2915 step=877134 return=144.23 success=True time=72.5s geometry=upstream history=4 | q1=2.256 actor=-12.810 alpha=0.047
# [train] episode=2920 step=878112 return=144.43 success=True time=80.9s geometry=upstream history=4 | q1=18.834 actor=-12.573 alpha=0.048
# [train] episode=2925 step=879894 return=143.46 success=True time=163.9s geometry=upstream history=4 | q1=14.093 actor=-13.823 alpha=0.050
# [train] episode=2930 step=880794 return=139.63 success=True time=127.5s geometry=upstream history=4 | q1=1.717 actor=-13.338 alpha=0.051
# [train] episode=2935 step=882384 return=142.51 success=True time=132.0s geometry=upstream history=4 | q1=1.506 actor=-12.796 alpha=0.050
# [train] episode=2940 step=883632 return=143.93 success=True time=164.0s geometry=upstream history=4 | q1=1.587 actor=-15.370 alpha=0.051
# [train] episode=2945 step=885288 return=139.96 success=True time=183.5s geometry=upstream history=4 | q1=40.272 actor=-13.453 alpha=0.048
# [train] episode=2950 step=886770 return=144.17 success=True time=99.9s geometry=upstream history=4 | q1=5.333 actor=-15.787 alpha=0.048
# [train] episode=2955 step=888882 return=144.20 success=True time=72.9s geometry=upstream history=4 | q1=10.129 actor=-12.970 alpha=0.045
# [train] episode=2960 step=889590 return=130.58 success=True time=205.2s geometry=upstream history=4 | q1=32.125 actor=-12.770 alpha=0.046
# [train] episode=2965 step=890976 return=132.91 success=True time=114.9s geometry=upstream history=4 | q1=31.849 actor=-12.032 alpha=0.049
# [train] episode=2970 step=892134 return=144.47 success=True time=106.3s geometry=upstream history=4 | q1=1.290 actor=-11.897 alpha=0.049
# [train] episode=2975 step=893430 return=143.48 success=True time=107.3s geometry=upstream history=4 | q1=9.106 actor=-11.741 alpha=0.050
# [train] episode=2980 step=895044 return=144.63 success=True time=138.7s geometry=upstream history=4 | q1=32.944 actor=-13.146 alpha=0.051
# [train] episode=2985 step=895782 return=144.57 success=True time=84.2s geometry=upstream history=4 | q1=15.740 actor=-12.805 alpha=0.051
# [train] episode=2990 step=896988 return=144.58 success=True time=122.6s geometry=upstream history=4 | q1=2.064 actor=-12.605 alpha=0.050
# [train] episode=2995 step=898362 return=144.64 success=True time=125.0s geometry=upstream history=4 | q1=28.723 actor=-14.525 alpha=0.049
# [train] episode=3000 step=899376 return=144.43 success=True time=95.5s geometry=upstream history=4 | q1=42.181 actor=-13.790 alpha=0.048
# [eval] step=900000 objective=arrival_v2 return=144.03 safety=0.178 success=100.00% time=114.6s energy=99262.7 path=73.0 prog=0.94
# [train] episode=3005 step=900930 return=144.51 success=True time=152.3s geometry=upstream history=4 | q1=39.849 actor=-14.699 alpha=0.048
# [train] episode=3010 step=901458 return=143.95 success=True time=98.7s geometry=upstream history=4 | q1=50.178 actor=-11.756 alpha=0.048
# [train] episode=3015 step=903018 return=144.59 success=True time=135.2s geometry=upstream history=4 | q1=26.697 actor=-14.710 alpha=0.049
# [train] episode=3020 step=904266 return=142.82 success=True time=103.5s geometry=upstream history=4 | q1=26.619 actor=-12.888 alpha=0.050
# [train] episode=3025 step=905454 return=137.69 success=True time=166.1s geometry=upstream history=4 | q1=6.754 actor=-12.012 alpha=0.048
# [train] episode=3030 step=906744 return=144.89 success=True time=107.0s geometry=upstream history=4 | q1=31.262 actor=-14.837 alpha=0.049
# [train] episode=3035 step=908202 return=144.26 success=True time=153.8s geometry=upstream history=4 | q1=13.710 actor=-12.642 alpha=0.049
# [train] episode=3040 step=909306 return=143.95 success=True time=145.2s geometry=upstream history=4 | q1=94.206 actor=-11.322 alpha=0.049
# [train] episode=3045 step=910866 return=142.45 success=True time=221.3s geometry=upstream history=4 | q1=12.614 actor=-14.707 alpha=0.050
# [train] episode=3050 step=912306 return=143.69 success=True time=175.7s geometry=upstream history=4 | q1=36.707 actor=-12.985 alpha=0.052
# [train] episode=3055 step=913224 return=144.61 success=True time=102.1s geometry=upstream history=4 | q1=43.328 actor=-13.097 alpha=0.053
# [train] episode=3060 step=914184 return=142.22 success=True time=74.3s geometry=upstream history=4 | q1=42.891 actor=-15.210 alpha=0.054
# [train] episode=3065 step=915582 return=120.49 success=True time=166.7s geometry=upstream history=4 | q1=46.530 actor=-12.078 alpha=0.054
# [train] episode=3070 step=916788 return=144.42 success=True time=95.7s geometry=upstream history=4 | q1=22.036 actor=-13.348 alpha=0.054
# [train] episode=3075 step=917652 return=143.59 success=True time=74.3s geometry=upstream history=4 | q1=10.316 actor=-15.418 alpha=0.053
# [train] episode=3080 step=918330 return=137.50 success=True time=119.6s geometry=upstream history=4 | q1=5.161 actor=-13.866 alpha=0.055
# [train] episode=3085 step=919872 return=143.87 success=True time=142.5s geometry=upstream history=4 | q1=16.626 actor=-11.484 alpha=0.057
# [train] episode=3090 step=921228 return=143.36 success=True time=87.7s geometry=upstream history=4 | q1=1.698 actor=-10.758 alpha=0.056
# [train] episode=3095 step=922332 return=143.23 success=True time=210.3s geometry=upstream history=4 | q1=41.414 actor=-14.546 alpha=0.054
# [train] episode=3100 step=923724 return=143.86 success=True time=125.4s geometry=upstream history=4 | q1=20.203 actor=-15.566 alpha=0.051
# [eval] step=925002 objective=arrival_v2 return=143.73 safety=0.333 success=100.00% time=114.2s energy=99176.5 path=74.9 prog=0.94
# [train] episode=3105 step=925026 return=144.57 success=True time=97.3s geometry=upstream history=4 | q1=15.406 actor=-14.352 alpha=0.052
# [train] episode=3110 step=926202 return=141.93 success=True time=142.7s geometry=upstream history=4 | q1=10.198 actor=-14.308 alpha=0.052
# [train] episode=3115 step=927684 return=143.50 success=True time=78.7s geometry=upstream history=4 | q1=14.126 actor=-12.690 alpha=0.050
# [train] episode=3120 step=928758 return=143.18 success=True time=180.0s geometry=upstream history=4 | q1=43.915 actor=-15.518 alpha=0.050
# [train] episode=3125 step=929922 return=144.29 success=True time=108.8s geometry=upstream history=4 | q1=25.363 actor=-14.369 alpha=0.050
# [train] episode=3130 step=931296 return=144.69 success=True time=96.4s geometry=upstream history=4 | q1=11.925 actor=-13.291 alpha=0.050
# [train] episode=3135 step=932124 return=139.32 success=True time=138.5s geometry=upstream history=4 | q1=17.466 actor=-15.963 alpha=0.049
# [train] episode=3140 step=933456 return=93.61 success=True time=110.3s geometry=upstream history=4 | q1=41.079 actor=-13.980 alpha=0.047
# [train] episode=3145 step=935034 return=140.49 success=True time=96.1s geometry=upstream history=4 | q1=13.486 actor=-13.057 alpha=0.045
# [train] episode=3150 step=936192 return=144.49 success=True time=156.0s geometry=upstream history=4 | q1=28.019 actor=-13.710 alpha=0.045
# [train] episode=3155 step=937584 return=135.30 success=True time=141.0s geometry=upstream history=4 | q1=27.491 actor=-15.094 alpha=0.047
# [train] episode=3160 step=938508 return=144.38 success=True time=76.3s geometry=upstream history=4 | q1=16.390 actor=-15.899 alpha=0.048
# [train] episode=3165 step=940020 return=140.43 success=True time=125.2s geometry=upstream history=4 | q1=30.781 actor=-12.199 alpha=0.047
# [train] episode=3170 step=941124 return=144.26 success=True time=83.6s geometry=upstream history=4 | q1=8.719 actor=-16.150 alpha=0.048
# [train] episode=3175 step=942558 return=144.33 success=True time=82.7s geometry=upstream history=4 | q1=32.556 actor=-16.397 alpha=0.050
# [train] episode=3180 step=943656 return=143.79 success=True time=77.2s geometry=upstream history=4 | q1=35.681 actor=-14.950 alpha=0.049
# [train] episode=3185 step=944694 return=144.36 success=True time=141.6s geometry=upstream history=4 | q1=96.124 actor=-12.494 alpha=0.048
# [train] episode=3190 step=946338 return=144.00 success=True time=136.3s geometry=upstream history=4 | q1=17.597 actor=-12.729 alpha=0.046
# [train] episode=3195 step=947730 return=144.64 success=True time=115.4s geometry=upstream history=4 | q1=2.774 actor=-15.908 alpha=0.046
# [train] episode=3200 step=949230 return=144.63 success=True time=133.3s geometry=upstream history=4 | q1=31.081 actor=-15.944 alpha=0.047
# [eval] step=950004 objective=arrival_v2 return=143.67 safety=0.361 success=100.00% time=114.1s energy=99205.8 path=74.8 prog=0.94
# [train] episode=3205 step=950712 return=144.07 success=True time=165.3s geometry=upstream history=4 | q1=3.111 actor=-12.841 alpha=0.048
# [train] episode=3210 step=951684 return=143.99 success=True time=151.6s geometry=upstream history=4 | q1=15.200 actor=-18.470 alpha=0.050
# [train] episode=3215 step=952920 return=139.58 success=True time=162.4s geometry=upstream history=4 | q1=1.457 actor=-16.935 alpha=0.048
# [train] episode=3220 step=954294 return=144.85 success=True time=113.6s geometry=upstream history=4 | q1=25.094 actor=-13.904 alpha=0.049
# [train] episode=3225 step=955734 return=143.77 success=True time=119.2s geometry=upstream history=4 | q1=2.232 actor=-16.038 alpha=0.048
# [train] episode=3230 step=956910 return=144.70 success=True time=97.4s geometry=upstream history=4 | q1=1.594 actor=-14.365 alpha=0.046
# [train] episode=3235 step=958230 return=125.33 success=True time=109.1s geometry=upstream history=4 | q1=20.075 actor=-15.965 alpha=0.045
# [train] episode=3240 step=960072 return=143.22 success=True time=152.6s geometry=upstream history=4 | q1=21.274 actor=-14.536 alpha=0.044
# [train] episode=3245 step=961206 return=90.93 success=True time=82.8s geometry=upstream history=4 | q1=1.804 actor=-15.752 alpha=0.046
# [train] episode=3250 step=962316 return=125.56 success=True time=127.0s geometry=upstream history=4 | q1=2.232 actor=-13.010 alpha=0.046
# [train] episode=3255 step=963660 return=143.92 success=True time=174.5s geometry=upstream history=4 | q1=30.586 actor=-18.476 alpha=0.046
# [train] episode=3260 step=965088 return=144.66 success=True time=123.4s geometry=upstream history=4 | q1=10.939 actor=-15.003 alpha=0.045
# [train] episode=3265 step=966204 return=144.55 success=True time=92.5s geometry=upstream history=4 | q1=1.389 actor=-14.599 alpha=0.046
# [train] episode=3270 step=967188 return=144.28 success=True time=81.2s geometry=upstream history=4 | q1=17.366 actor=-14.750 alpha=0.048
# [train] episode=3275 step=968550 return=144.24 success=True time=157.6s geometry=upstream history=4 | q1=26.476 actor=-14.135 alpha=0.046
# [train] episode=3280 step=969828 return=138.41 success=True time=154.6s geometry=upstream history=4 | q1=24.462 actor=-14.176 alpha=0.045
# [train] episode=3285 step=971058 return=144.89 success=True time=125.8s geometry=upstream history=4 | q1=14.805 actor=-14.607 alpha=0.046
# [train] episode=3290 step=972240 return=141.16 success=True time=153.6s geometry=upstream history=4 | q1=1.533 actor=-15.097 alpha=0.045
# [train] episode=3295 step=973752 return=144.26 success=True time=141.6s geometry=upstream history=4 | q1=102.081 actor=-15.812 alpha=0.045
# [train] episode=3300 step=974700 return=144.15 success=True time=99.6s geometry=upstream history=4 | q1=13.548 actor=-16.305 alpha=0.047
# [eval] step=975000 objective=arrival_v2 return=124.63 safety=0.546 success=90.00% time=120.8s energy=103871.4 path=76.9 prog=0.93
# [train] episode=3305 step=976284 return=143.69 success=True time=81.9s geometry=upstream history=4 | q1=71.564 actor=-15.501 alpha=0.047
# [train] episode=3310 step=977436 return=143.94 success=True time=95.1s geometry=upstream history=4 | q1=1.735 actor=-12.852 alpha=0.048
# [train] episode=3315 step=978558 return=144.96 success=True time=92.6s geometry=upstream history=4 | q1=73.994 actor=-13.587 alpha=0.049
# [train] episode=3320 step=979614 return=144.20 success=True time=56.3s geometry=upstream history=4 | q1=1.869 actor=-15.389 alpha=0.050
# [train] episode=3325 step=980736 return=143.02 success=True time=188.2s geometry=upstream history=4 | q1=37.754 actor=-15.758 alpha=0.049
# [train] episode=3330 step=981918 return=144.40 success=True time=113.4s geometry=upstream history=4 | q1=17.397 actor=-16.102 alpha=0.047
# [train] episode=3335 step=983244 return=143.87 success=True time=124.6s geometry=upstream history=4 | q1=1.637 actor=-16.481 alpha=0.046
# [train] episode=3340 step=984852 return=144.03 success=True time=133.3s geometry=upstream history=4 | q1=1.583 actor=-14.248 alpha=0.045
# [train] episode=3345 step=985716 return=140.98 success=True time=92.3s geometry=upstream history=4 | q1=56.420 actor=-16.186 alpha=0.046
# [train] episode=3350 step=986988 return=144.54 success=True time=138.9s geometry=upstream history=4 | q1=23.587 actor=-17.290 alpha=0.047
# [train] episode=3355 step=988218 return=144.22 success=True time=146.8s geometry=upstream history=4 | q1=20.377 actor=-19.975 alpha=0.046
# [train] episode=3360 step=989526 return=144.57 success=True time=108.1s geometry=upstream history=4 | q1=24.419 actor=-15.642 alpha=0.047
# [train] episode=3365 step=990996 return=144.06 success=True time=125.3s geometry=upstream history=4 | q1=30.939 actor=-15.559 alpha=0.045
# [train] episode=3370 step=992382 return=144.66 success=True time=140.8s geometry=upstream history=4 | q1=12.085 actor=-16.270 alpha=0.045
# [train] episode=3375 step=993882 return=144.01 success=True time=124.1s geometry=upstream history=4 | q1=23.692 actor=-16.161 alpha=0.045
# [train] episode=3380 step=995064 return=144.64 success=True time=142.6s geometry=upstream history=4 | q1=1.554 actor=-15.409 alpha=0.046
# [train] episode=3385 step=996792 return=143.97 success=True time=177.3s geometry=upstream history=4 | q1=34.526 actor=-17.727 alpha=0.044
# [train] episode=3390 step=998346 return=143.16 success=True time=204.2s geometry=upstream history=4 | q1=23.879 actor=-16.085 alpha=0.043
# [train] episode=3395 step=999852 return=132.88 success=True time=112.9s geometry=upstream history=4 | q1=15.148 actor=-14.555 alpha=0.043

# %% [markdown]
# ## 7. Phase 2 — single_upstream summary + gate

# %%
upstream_summary = summarize_phase(
    U_RUN_ROOT,
    U_TOTAL_STEPS,
    'SINGLE_UPSTREAM_VALIDATION',
    'single_upstream_validation_gate_summary.json',
)
UPSTREAM_PASS = upstream_summary['all_pass']
print()
print(f'UPSTREAM_PASS = {UPSTREAM_PASS}')
# Out:
# ====================================================================================================
# SINGLE_UPSTREAM_VALIDATION  (arrival_v2 / s1 / 1,000,000 steps)
# ----------------------------------------------------------------------------------------------------
#   final_success_rate    : 1.0000   gate >= 0.85
#   peak_success_rate     : 1.0000   @ 475,002
#   last100k_mean_success : 0.9750   gate >= 0.9000
#   final_oob_rate        : 0.0000   gate <= 0.10
#   obs_dim               : 56
#   context_obs           : True
#   timeout_bootstrap     : terminal
#   termination           : {'goal': 30}
# ====================================================================================================
#
# [last 16 eval rows]
#  env_step  eval_success_rate  eval_return  eval_safety_cost  eval_time_s  eval_progress_ratio
#    600000           0.933333   131.775395          0.756298   136.243333             0.930647
#    625002           1.000000   143.091053          0.619703   117.313333             0.935602
#    650004           1.000000   138.494965          2.896428   119.430000             0.935597
#    675000           1.000000   143.138327          0.551586   121.316667             0.935469
#    700002           1.000000   142.394089          0.932553   120.670000             0.935545
#    725004           1.000000   143.855545          0.188945   121.983333             0.935578
#    750000           0.933333   133.323679          0.197152   126.623333             0.932920
#    775002           1.000000   143.497822          0.445057   114.530000             0.935550
#    800004           1.000000   144.093427          0.079430   121.043333             0.935553
#    825000           1.000000   143.292618          0.466675   122.223333             0.935533
#    850002           1.000000   144.164889          0.117195   113.900000             0.935499
#    875004           0.933333   131.756440          0.925871   131.893333             0.932888
#    900000           1.000000   144.026869          0.177992   114.643333             0.935511
#    925002           1.000000   143.725814          0.333351   114.156667             0.935531
#    950004           1.000000   143.670493          0.360657   114.150000             0.935510
#    975000           0.900000   124.625454          0.546036   120.760000             0.931129
#
# ================================================================================================
# check                                               pass                                  detail
# ------------------------------------------------------------------------------------------------
# final success >= 0.85                               PASS                                  1.0000
# last100k mean >= 0.9 * peak                         PASS                    0.9750 / peak=1.0000
# final OOB rate <= 0.10                              PASS                                  0.0000
# arrival_v2 context obs enabled                      PASS                                    True
# arrival_v2 timeout terminal semantics               PASS                                terminal
# ================================================================================================
# [saved] experiments/arrival_v2_prototype/single_u15_upstream_tgt15/arrival_v2/sac_vanilla/s1_k4/seed_42/results/single_upstream_validation_gate_summary.json
#
# UPSTREAM_PASS = True

# %% [markdown]
# ## 8. Combined verdict + 如何延长训练
#
# 总结两个 phase 的 5/5 gate 状态。两个 phase 互不门控；任一 phase fail，单独看其 last100k_mean / peak / OOB 哪条 fail，再决定延长 budget 还是改 reward。
#
# **延长训练的标准流程**（不需要重跑 preflight）：
#
# 1. 在 §2 config cell 把对应的 `C_TOTAL_STEPS` 或 `U_TOTAL_STEPS` 改大（如 `1_500_000`）
# 2. 重跑该 phase 的 config cell（让新值生效）
# 3. 重跑该 phase 的 train cell — `--resume` 自动续训
# 4. 重跑该 phase 的 summary cell — gate summary JSON 会被覆盖
#
# **对照预期**：与 tandem/sbs 在严格控制（s1 / k4 / U=1.5 / target=1.5 / arrival_v2 / seed=42 / 1M）下的对比，将填入 `arrival_v2_experiment_report.md` §7.3 修订版。Phase 2 同 benchmark 的 §3 P1 v6 (seed=46/1.5M) 仍保留作为 multi-seed sample 1（P1 v6 + 本 Phase 2 = 同 benchmark 上的 seed=46 / seed=42 二点观测）。

# %%
print('=' * 96)
print('SINGLE U=1.5 CONTROL VALIDATION — combined verdict')
print('-' * 96)
print(f"  CROSS_PASS    = {CROSS_PASS}")
print(f"    final={cross_summary['final_success_rate']:.4f}  "
      f"peak={cross_summary['peak_success_rate']:.4f} @ {cross_summary['peak_step']:,}  "
      f"last100k_mean={cross_summary['last100k_mean_success']:.4f}  "
      f"oob={cross_summary['final_oob_rate']:.4f}")
print(f"  UPSTREAM_PASS = {UPSTREAM_PASS}")
print(f"    final={upstream_summary['final_success_rate']:.4f}  "
      f"peak={upstream_summary['peak_success_rate']:.4f} @ {upstream_summary['peak_step']:,}  "
      f"last100k_mean={upstream_summary['last100k_mean_success']:.4f}  "
      f"oob={upstream_summary['final_oob_rate']:.4f}")
print('=' * 96)

combined = {
    'experiment': 'arrival_v2_single_u15_seed42_1M_control',
    'commit_baseline': 'f179c5b / 1adee4e',
    'seed': SEED,
    'cross': cross_summary,
    'upstream': upstream_summary,
    'cross_pass': CROSS_PASS,
    'upstream_pass': UPSTREAM_PASS,
    'both_pass': bool(CROSS_PASS and UPSTREAM_PASS),
}
out_dir = Path('experiments/arrival_v2_prototype/single_u15_seed42_1M_control_summary')
out_dir.mkdir(parents=True, exist_ok=True)
out_path = out_dir / 'combined_gate_summary.json'
out_path.write_text(json.dumps(combined, indent=2), encoding='utf-8')
print(f'[saved] {out_path}')
# Out:
# ================================================================================================
# SINGLE U=1.5 CONTROL VALIDATION — combined verdict
# ------------------------------------------------------------------------------------------------
#   CROSS_PASS    = True
#     final=0.9000  peak=0.9000 @ 725,004  last100k_mean=0.8833  oob=0.1000
#   UPSTREAM_PASS = True
#     final=1.0000  peak=1.0000 @ 475,002  last100k_mean=0.9750  oob=0.0000
# ================================================================================================
# [saved] experiments/arrival_v2_prototype/single_u15_seed42_1M_control_summary/combined_gate_summary.json
