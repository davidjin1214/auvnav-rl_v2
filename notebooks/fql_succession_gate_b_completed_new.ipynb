# %% [markdown]
# # FQL Succession Gate B — E-uni Sanity (Colab) [rev.3.1 notebook — real-time streaming + 2-seed + path-quote fix]
#
# > 文档对应：
# > - Spec：[`docs/archive/fql_succession/fql_succession_p0p1_spec.md`](../docs/archive/fql_succession/fql_succession_p0p1_spec.md) §5 (Task E — Gate B FQL E-uni sanity)
# > - Plan：[`docs/archive/fql_succession/fql_succession_plan_v0.md`](../docs/archive/fql_succession/fql_succession_plan_v0.md) §3 (Lean MVP)
# > - Dataset card：[`docs/fql_e_uni_anchor_dataset_card.md`](../docs/fql_e_uni_anchor_dataset_card.md)
# > - **Interim report (rev.2 触发点)**：[`docs/archive/fql_succession/fql_succession_gate_b_interim_report.md`](../docs/archive/fql_succession/fql_succession_gate_b_interim_report.md) — rev.1 seed=42 单 seed 3/4 PASS marginal-fail，3 bugs 诊断完毕
# > - Pre-flight Task A：[`docs/archive/fql_succession/fql_audit_dryrun_report.md`](../docs/archive/fql_succession/fql_audit_dryrun_report.md) (audit tool verified, Gate A.2 PASS on 200-ep dry-run)
# > - Pre-flight Gate A.1：[`docs/rebrac_broad_validation_v2_report.md`](../docs/rebrac_broad_validation_v2_report.md) §2 (arrival_v2 reward bridge HOLDS at 0.85)
# >
# > **本 notebook rev.3.1 (2026-05-19)** — path-quote fix (Bug 5)：
# > - **Bug 5 fix (rev.3.1 新增)**：§2 train / §3 eval 把 `--save-dir {ckpt_dir_str}` / `--checkpoint {ckpt_dir_str}` / `--output-json {test_json_str}` 三处都用单引号包起来。Colab 项目路径 `/content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5/` 含**空格**（"Colab Notebooks"），未加引号时 Jupyter `{var}` 内插后 shell 按空格分词，argparse 拒收尾部，rev.3 实测 `[FAIL] rebrac seed=0 agent_final.pt missing after 0.4 min` (`unrecognized arguments: Notebooks/...`)。seed=42 两 run 没炸只是因为它们走 Python `Path.exists()` skip-resume 没过 shell
# >
# > **rev.3 (2026-05-19) 沿用 (未变)**：
# > - **Bug 4 fix**：§2 train / §3 eval 从 `os.system(cmd_str)` 改为 Jupyter `!python ... \` magic + `{var}` 内插。`os.system` 在 Colab 实测**不 stream**（rev.1+rev.2 FQL 训练 49 min 全程空白），切换到 `!python` magic 后训练 loss/eval 逐行实时打到 cell（早期 `rebrac_c1_*` notebook 一直用此 pattern）
# > - **代价**：~30 行 common flag 在 rebrac/fql 两 if/elif 分支重复，无 `_common_cli` 抽象 —— 换 stream 的可见性，trade-off 合理
# >
# > **rev.2 (2026-05-19) 沿用 (未变)**：
# > - **Bug 1 fix**：§5 verdict `_dedup_by_train_step()` 处理 append-mode log 污染
# > - **Bug 3 fix**：§5.5 字段名 `eval_avg_*` → `eval_*`
# > - **Option B 扩展**：`SEEDS = [42, 0]` 4 runs = 2 algo × 2 seed
# >
# > **Bug 2 (留 next，未在本 rev 处理)**：`--episodes 100` 被 manifest 静默 override 至 30 ep；verdict 报告 noise floor 给上下文
#
# 目的：在 E-uni 1000-ep paper anchor 上跑 **paired** ReBRAC + FQL × 2 seed sanity，应用 spec §5.3 四条 Gate B 判据（aggregated across seeds）决定是否进入 P2 main comparison。
#
# ## 执行摘要（4 paired runs，2 seed × 2 algo）
#
# | Run | Algo | Dataset | Manifest | Steps | Seed | Status | Notes |
# |---|---|---|---|---|---|---|---|
# | 1 | **ReBRAC** | `privileged_s0_h4_arrival_v2_re150_u10cross_fixdone_ep1000` | `single_u10_cross_tgt15` | 200k | 42 | rev.1 done | skip-resume |
# | 2 | **FQL** | 同上 | 同上 | 200k | 42 | rev.1 done (logs 污染) | skip-resume + §5 dedup |
# | 3 | **ReBRAC** | 同上 | 同上 | 200k | 0 | rev.3.1 new | fresh run，real-time stream + path-quote |
# | 4 | **FQL** | 同上 | 同上 | 200k | 0 | rev.3.1 new | fresh run，real-time stream + path-quote |
#
# **Wallclock 预算**：seed=42 两 run 已完成 (~75 min)，本 rev 只需跑 seed=0 两 run ≈ **75 min L4**（ReBRAC ~25 + FQL ~50）。
#
# ## 输出位置
#
# | 类型 | 路径 | Sync 回 git? |
# |---|---|---|
# | Train artifacts | `checkpoints/offline/fql_succession/gate_b/<algo>_e_uni_seed<n>/{agent_final.pt, trainer_state.json, train_log.jsonl, eval_log.csv}` | 否（大文件，gitignore） |
# | Final eval | `results/offline/fql_succession/gate_b/<algo>_e_uni_seed<n>/test_result.json` | **是** |
# | In-training eval traj | `results/offline/fql_succession/gate_b/<algo>_e_uni_seed<n>/eval_log.csv`（从 checkpoint dir copy） | **是** |
# | 汇总 | `results/offline/fql_succession/gate_b/summaries/{gate_b_verdict.json, gate_b_overview.csv}` | **是** |
#
# ## Gate B 判据 (spec §5.3, pre-registered; rev.2 across 2 seeds per algo aggregated mean)
#
# | # | 指标 | 通过条件 |
# |---|---|---|
# | c1 | FQL `test_success` last 3 eval mean（across-seed mean） | **≥ ReBRAC same − 0.08** |
# | c2 | FQL `loss_flow` 末段（across-seed mean of last 5% train log） | **< 0.05**（teacher 收敛） |
# | c3 | FQL `actor_loss` 末段数量级 | **vs ReBRAC same，比值在 [0.1, 10]** |
# | c4 | FQL eval 曲线 monotonicity（across-seed mean of last 30% slope） | **slope ≥ 0**（no collapse） |
#
# **4 条全过 → Gate B pass → 进入 P2 main comparison spec 写作。** 任一失败按 spec §5.3 / interim report §8 mitigation 处理。
#
# ## 已知 noise / contamination caveat
#
# | Source | 描述 | 处理 |
# |---|---|---|
# | Bug 1 | rev.1 FQL seed=42 因 train script append-mode + skip-resume race 导致 `train_log.jsonl` (386 行) 和 `eval_log.csv` (38 行) 跨 run 拼接 | rev.2 §5 verdict `_dedup_by_train_step()` 去重 |
# | Bug 2 | `--manifest` override `--episodes` → 实际 30 ep eval（CI ±8.4pp/eval） | verdict 报告中 noted；P2 spec 写作时考虑大 manifest 或调整 c1/c4 阈值 |
# | Bug 4 | rev.1 / rev.2 用 `os.system` Colab 实测**不 stream**（cell 训练时全程空白） | rev.3 改用 Jupyter `!python` magic，逐行实时输出 |
# | Bug 5 | rev.3 `--save-dir {ckpt_dir_str}` 内插后 Colab 路径含空格被 shell 分词 → argparse fail | rev.3.1 给 3 处路径 `{var}` 包单引号 |
# | Single-seed power | rev.1 仅 seed=42，c4 单点 noise 不可分辨 | rev.2 双 seed = 标准方差估计起点 |
#
# ## Spec CLI ↔ 实际代码 字段映射（rev.1 不动 spec，rev.2/rev.3 沿用）
#
# 本 notebook 用**实际代码**字段名；spec 写作时的字段名已 deprecated 但 spec 待 Task E 闭环统一更新到 v1.1。
#
# | Spec 名称 | 实际名称 |
# |---|---|
# | `--algorithm` | `--algo` |
# | `--eval-every-steps` | `--eval-every` |
# | `--rebrac-actor-bc-coef` | `--actor-penalty-coef` |
# | `--rebrac-critic-bc-coef` | `--critic-penalty-coef` |
# | `--rebrac-critic-use-layernorm` | `--critic-layernorm` |
# | `--fql-flow-steps` | `--flow-steps` |
# | `--fql-distill-alpha-bc` | `--distill-alpha-bc` |
#
# Dataset path：spec 的 placeholder `offline_data/fql_succession/e_uni_1000/` → 实际采用现有 naming convention `offline_data/privileged_s0_h4_arrival_v2_re150_u10cross_fixdone_ep1000/`。

# %% [markdown]
# ## 0. 环境 sanity

# %%
# !lscpu | head -8
print()
# !nvidia-smi
# Out:
# Architecture:                            x86_64
# CPU op-mode(s):                          32-bit, 64-bit
# Address sizes:                           46 bits physical, 48 bits virtual
# Byte Order:                              Little Endian
# CPU(s):                                  12
# On-line CPU(s) list:                     0-11
# Vendor ID:                               GenuineIntel
# Model name:                              Intel(R) Xeon(R) CPU @ 2.20GHz
#
# Tue May 19 16:27:42 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA L4                      Off |   00000000:00:03.0 Off |                    0 |
# | N/A   40C    P8             12W /   72W |       0MiB /  23034MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
import torch
print(f'PyTorch       : {torch.__version__}')
print(f'CUDA available: {torch.cuda.is_available()}')
if torch.cuda.is_available():
    print(f'Device 0      : {torch.cuda.get_device_name(0)}')
    print(f'cuDNN         : {torch.backends.cudnn.version()}')
# Out:
# PyTorch       : 2.10.0+cu128
# CUDA available: True
# Device 0      : NVIDIA L4
# cuDNN         : 91002

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# %cd /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5

# %%
# !pwd
# !ls scripts/train_offline.py scripts/evaluate_offline.py
# !ls docs/archive/fql_succession/fql_succession_p0p1_spec.md docs/fql_e_uni_anchor_dataset_card.md
# !ls auv_nav/fql.py auv_nav/rebrac.py
# !ls offline_data/privileged_s0_h4_arrival_v2_re150_u10cross_fixdone_ep1000/transitions.npz \
    offline_data/privileged_s0_h4_arrival_v2_re150_u10cross_fixdone_ep1000/metadata.json
# !ls benchmarks/single_u10_cross_tgt15.json
# !ls wake_data/wake_v8_U1p00_Re150_D12p00_dx0p60_Ti5pct_1200f_roi.npy \
    wake_data/wake_v8_U1p00_Re150_D12p00_dx0p60_Ti5pct_1200f_roi_meta.json
# Out:
# /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5
# scripts/evaluate_offline.py  scripts/train_offline.py
# docs/fql_e_uni_anchor_dataset_card.md  docs/archive/fql_succession/fql_succession_p0p1_spec.md
# auv_nav/fql.py	auv_nav/rebrac.py
# offline_data/privileged_s0_h4_arrival_v2_re150_u10cross_fixdone_ep1000/metadata.json
# offline_data/privileged_s0_h4_arrival_v2_re150_u10cross_fixdone_ep1000/transitions.npz
# benchmarks/single_u10_cross_tgt15.json
# wake_data/wake_v8_U1p00_Re150_D12p00_dx0p60_Ti5pct_1200f_roi_meta.json
# wake_data/wake_v8_U1p00_Re150_D12p00_dx0p60_Ti5pct_1200f_roi.npy

# %%
# Optional sanity: confirm FQL unit tests still pass on the Colab runtime
# (skip with shift+enter if you've already verified locally).
# !python -m pytest tests/test_fql.py -q --no-header 2>&1 | tail -20

# %% [markdown]
# ## 1. Run matrix
#
# 4 runs = ReBRAC + FQL × seeds=[42, 0]。所有 run 共用：
# - 同 dataset（E-uni 1000-ep privileged）
# - 同 eval manifest（`single_u10_cross_tgt15`，实际 30 ep — Bug 2 caveat）
# - 同 total-steps（200k）
# - 同 eval-every（10k step → 20 个 eval point per run）
# - 同 sampling-mode（`uniform`，spec §5.2；与 broad val v2 `shuffle_no_replacement` 不同）
#
# 差异只在 algo + algo-specific CLI flags：
# - ReBRAC：`--actor-penalty-coef 4.0 --critic-penalty-coef 2.0 --critic-layernorm --no-actor-layernorm`
# - FQL：`--flow-steps 10 --distill-alpha-bc 1.0`（teacher_lr / time_embed_dim 用默认 3e-4 / 32）
#
# Skip-resume：
# - **train 阶段** 看 `<ckpt_dir>/trainer_state.json` + `<ckpt_dir>/agent_final.pt` 都存在则跳过
# - **eval 阶段** 看 `<result_dir>/test_result.json` 存在则跳过
#
# rev.1 已完成的 (ReBRAC, seed=42) + (FQL, seed=42) 走 skip-resume；本 rev 新跑 (ReBRAC, seed=0) + (FQL, seed=0)。

# %%
import os
from pathlib import Path

REPO_ROOT = Path('.').resolve()
CKPT_ROOT = REPO_ROOT / 'checkpoints' / 'offline' / 'fql_succession' / 'gate_b'
RESULT_ROOT = REPO_ROOT / 'results' / 'offline' / 'fql_succession' / 'gate_b'
SUMMARIES_DIR = RESULT_ROOT / 'summaries'
SUMMARIES_DIR.mkdir(parents=True, exist_ok=True)

DATASET_DIR = 'offline_data/privileged_s0_h4_arrival_v2_re150_u10cross_fixdone_ep1000'
DATASET_NPZ = f'{DATASET_DIR}/transitions.npz'
FLOW_PATH = 'wake_data/wake_v8_U1p00_Re150_D12p00_dx0p60_Ti5pct_1200f_roi.npy'
MANIFEST = 'benchmarks/single_u10_cross_tgt15.json'
SEEDS = [42, 0]  # rev.2: seed=42 carried over from rev.1, seed=0 added for Option B power
TOTAL_STEPS = 200_000
EVAL_EVERY = 10_000
EVAL_EPISODES = 100  # CLI value; effective is min(this, manifest_size) — see Bug 2 caveat

ALGOS = ['rebrac', 'fql']

RUNS = []
for seed in SEEDS:
    for algo in ALGOS:
        run_id = f'{algo}_e_uni_seed{seed}'
        ckpt_dir = CKPT_ROOT / run_id
        result_dir = RESULT_ROOT / run_id
        RUNS.append({
            'run_id': run_id,
            'algo': algo,
            'seed': seed,
            'dataset': DATASET_NPZ,
            'manifest': MANIFEST,
            'flow': FLOW_PATH,
            'ckpt_dir': str(ckpt_dir),
            'result_dir': str(result_dir),
        })

print(f'{"#":>2} {"algo":<8} {"seed":>5}  ckpt_dir / result_dir')
print('-' * 110)
for i, r in enumerate(RUNS, 1):
    print(f'{i:>2} {r["algo"]:<8} {r["seed"]:>5}  ckpt:   {r["ckpt_dir"]}')
    print(f'   {"":<8} {"":>5}  result: {r["result_dir"]}')
# Out:
#  # algo      seed  ckpt_dir / result_dir
# --------------------------------------------------------------------------------------------------------------
#  1 rebrac      42  ckpt:   /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5/checkpoints/offline/fql_succession/gate_b/rebrac_e_uni_seed42
#                    result: /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5/results/offline/fql_succession/gate_b/rebrac_e_uni_seed42
#  2 fql         42  ckpt:   /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5/checkpoints/offline/fql_succession/gate_b/fql_e_uni_seed42
#                    result: /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5/results/offline/fql_succession/gate_b/fql_e_uni_seed42
#  3 rebrac       0  ckpt:   /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5/checkpoints/offline/fql_succession/gate_b/rebrac_e_uni_seed0
#                    result: /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5/results/offline/fql_succession/gate_b/rebrac_e_uni_seed0
#  4 fql          0  ckpt:   /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5/checkpoints/offline/fql_succession/gate_b/fql_e_uni_seed0
#                    result: /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5/results/offline/fql_succession/gate_b/fql_e_uni_seed0

# %% [markdown]
# ## 2. Training (4 runs, ~75 min L4 — 2 已完成 skip + 2 fresh)
#
# **rev.3 关键改动 (Bug 4 fix)**：本 cell 从 `os.system(cmd_str)` 改为 Jupyter `!python ... \` magic + `{var}` 内插，让训练 loss / in-training eval 逐行实时打到 cell（早期 `rebrac_c1_*` notebook 一直用此 pattern；`os.system` 在 Colab 实测**不 stream**）。代价：~30 行 common flag 在 rebrac/fql 两 if/elif 分支重复。
#
# 训练时**保留** `--eval-every 10000 --eval-episodes 100`，Gate B c1/c4 需要 in-training eval 轨迹。
#
# 训练输出文件：
# - `<ckpt_dir>/train_log.jsonl`：每 `--log-every`（默认 1000 step）的 loss metrics（含 FQL `loss_flow`）
# - `<ckpt_dir>/eval_log.csv`：每 `--eval-every` 的 in-training eval（实际 30 ep — Bug 2）→ Gate B c1/c4 数据源
# - `<ckpt_dir>/agent_final.pt`：最终 checkpoint
# - `<ckpt_dir>/trainer_state.json`：完整 trainer state（含 algo / agent_config，用于 evaluate_offline 自动 dispatch）
#
# Skip-resume：先看 `<ckpt_dir>/trainer_state.json + agent_final.pt` 都在则跳过 — rev.1 已完成的 (ReBRAC, seed=42) + (FQL, seed=42) 走此路径；本 rev 实跑 seed=0 两 run。

# %%
import time
from pathlib import Path

for i, r in enumerate(RUNS, 1):
    algo = r['algo']
    seed = r['seed']
    ckpt_dir = Path(r['ckpt_dir'])
    ckpt_dir_str = str(ckpt_dir)
    trainer_state = ckpt_dir / 'trainer_state.json'
    agent_final = ckpt_dir / 'agent_final.pt'

    # Per-run vars (used by !python {var} interpolation below)
    DATASET = r['dataset']
    FLOW = r['flow']
    MFST = r['manifest']

    print(f'\n========== [{i}/{len(RUNS)}] train {algo} seed={seed} ==========')

    if trainer_state.exists() and agent_final.exists():
        print(f'[skip] already complete: {ckpt_dir}')
        continue

    ckpt_dir.mkdir(parents=True, exist_ok=True)
    t0 = time.time()

    # rev.3: Jupyter !python magic for real-time streaming (was os.system in rev.2).
    # rev.3.1 (Bug 5 fix): single-quote {ckpt_dir_str} because Colab path
    #   `/content/drive/MyDrive/Colab Notebooks/...` has a SPACE — without quotes
    #   the shell splits the arg and argparse rejects the tail as positional.
    # Per-algo branches duplicate common flags — trade-off for early-style streaming.
    if algo == 'rebrac':
        # !python -m scripts.train_offline \
            --algo rebrac \
            --offline-data {DATASET} \
            --flow {FLOW} \
            --manifest {MFST} \
            --probe-layout s0 \
            --history-length 4 \
            --task-geometry cross_stream \
            --target-speed 1.5 \
            --objective arrival_v2 \
            --total-steps {TOTAL_STEPS} \
            --batch-size 256 \
            --sampling-mode uniform \
            --hidden-dim 256 \
            --num-hidden-layers 3 \
            --actor-lr 3e-4 \
            --critic-lr 3e-4 \
            --gamma 0.99 \
            --tau 0.005 \
            --policy-noise 0.2 \
            --noise-clip 0.5 \
            --policy-freq 2 \
            --grad-clip-norm 10.0 \
            --normalizer-eps 1e-3 \
            --eval-every {EVAL_EVERY} \
            --eval-episodes {EVAL_EPISODES} \
            --eval-workers 4 \
            --eval-worker-device cpu \
            --log-every 1000 \
            --checkpoint-every 0 \
            --seed {seed} \
            --device cuda \
            --save-dir '{ckpt_dir_str}' \
            --actor-penalty-coef 4.0 \
            --critic-penalty-coef 2.0 \
            --critic-layernorm \
            --no-actor-layernorm
    elif algo == 'fql':
        # !python -m scripts.train_offline \
            --algo fql \
            --offline-data {DATASET} \
            --flow {FLOW} \
            --manifest {MFST} \
            --probe-layout s0 \
            --history-length 4 \
            --task-geometry cross_stream \
            --target-speed 1.5 \
            --objective arrival_v2 \
            --total-steps {TOTAL_STEPS} \
            --batch-size 256 \
            --sampling-mode uniform \
            --hidden-dim 256 \
            --num-hidden-layers 3 \
            --actor-lr 3e-4 \
            --critic-lr 3e-4 \
            --gamma 0.99 \
            --tau 0.005 \
            --policy-noise 0.2 \
            --noise-clip 0.5 \
            --policy-freq 2 \
            --grad-clip-norm 10.0 \
            --normalizer-eps 1e-3 \
            --eval-every {EVAL_EVERY} \
            --eval-episodes {EVAL_EPISODES} \
            --eval-workers 4 \
            --eval-worker-device cpu \
            --log-every 1000 \
            --checkpoint-every 0 \
            --seed {seed} \
            --device cuda \
            --save-dir '{ckpt_dir_str}' \
            --flow-steps 10 \
            --distill-alpha-bc 1.0 \
            --teacher-lr 3e-4 \
            --flow-time-embed-dim 32
    else:
        raise ValueError(f'Unknown algo: {algo}')

    elapsed = (time.time() - t0) / 60
    if agent_final.exists():
        print(f'[done] {algo} seed={seed} → {ckpt_dir} ({elapsed:.1f} min)')
    else:
        print(f'\n[FAIL] {algo} seed={seed} agent_final.pt missing after {elapsed:.1f} min')
        break
# Out:
# ========== [1/4] train rebrac seed=42 ==========
# [skip] already complete: /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5/checkpoints/offline/fql_succession/gate_b/rebrac_e_uni_seed42
#
# ========== [2/4] train fql seed=42 ==========
# [skip] already complete: /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5/checkpoints/offline/fql_succession/gate_b/fql_e_uni_seed42
#
# ========== [3/4] train rebrac seed=0 ==========
# [offline] algo=rebrac transitions=86685 obs_dim=48 action_dim=2 protocol=deployable tensor_replay=on eval_workers=4 sampling=uniform total_steps=200000
# [train] step=1 q=-0.791 critic=228.093 actor=6.217 bc=1.304 lambda=1.264 critic_pen=1.368
# [train] step=1000 q=1.326 critic=49.702 actor=-0.156 bc=0.042 lambda=0.244 critic_pen=0.131
# [train] step=2000 q=3.014 critic=9.568 actor=-0.449 bc=0.025 lambda=0.182 critic_pen=0.096
# [train] step=3000 q=7.498 critic=2.306 actor=-0.708 bc=0.012 lambda=0.101 critic_pen=0.088
# [train] step=4000 q=16.722 critic=4.669 actor=-0.680 bc=0.055 lambda=0.054 critic_pen=0.114
# [train] step=5000 q=15.454 critic=3.394 actor=-0.733 bc=0.032 lambda=0.056 critic_pen=0.085
# [train] step=6000 q=20.391 critic=1.626 actor=-0.898 bc=0.005 lambda=0.045 critic_pen=0.089
# [train] step=7000 q=23.992 critic=2.556 actor=-0.852 bc=0.019 lambda=0.039 critic_pen=0.095
# [train] step=8000 q=24.397 critic=3.105 actor=-0.705 bc=0.053 lambda=0.038 critic_pen=0.103
# [train] step=9000 q=25.156 critic=2.625 actor=-0.876 bc=0.008 lambda=0.036 critic_pen=0.096
# [train] step=10000 q=25.208 critic=3.108 actor=-0.895 bc=0.007 lambda=0.037 critic_pen=0.082
# [eval] step=10000 success=60.00% return=-0.70 time=44.06s energy=34104.30 path=51.08 prog=0.690
# [train] step=11000 q=34.180 critic=1.804 actor=-0.810 bc=0.031 lambda=0.027 critic_pen=0.097
# [train] step=12000 q=38.284 critic=2.839 actor=-0.893 bc=0.015 lambda=0.025 critic_pen=0.121
# [train] step=13000 q=37.760 critic=7.681 actor=-0.897 bc=0.015 lambda=0.025 critic_pen=0.088
# [train] step=14000 q=44.742 critic=1.670 actor=-0.927 bc=0.004 lambda=0.021 critic_pen=0.067
# [train] step=15000 q=45.406 critic=2.211 actor=-0.782 bc=0.043 lambda=0.021 critic_pen=0.098
# [train] step=16000 q=43.250 critic=3.704 actor=-0.905 bc=0.008 lambda=0.022 critic_pen=0.069
# [train] step=17000 q=45.754 critic=3.107 actor=-0.813 bc=0.025 lambda=0.020 critic_pen=0.092
# [train] step=18000 q=45.568 critic=158.344 actor=-0.938 bc=0.002 lambda=0.021 critic_pen=0.071
# [train] step=19000 q=47.349 critic=1.769 actor=-0.923 bc=0.004 lambda=0.020 critic_pen=0.091
# [train] step=20000 q=54.987 critic=4.217 actor=-0.849 bc=0.028 lambda=0.017 critic_pen=0.106
# [eval] step=20000 success=56.67% return=-15.78 time=46.93s energy=36611.72 path=55.07 prog=0.640
# [train] step=21000 q=57.461 critic=3.244 actor=-0.838 bc=0.026 lambda=0.016 critic_pen=0.092
# [train] step=22000 q=56.802 critic=6.014 actor=-0.909 bc=0.011 lambda=0.017 critic_pen=0.075
# [train] step=23000 q=51.881 critic=2.452 actor=-0.857 bc=0.023 lambda=0.018 critic_pen=0.080
# [train] step=24000 q=54.176 critic=4.136 actor=-0.915 bc=0.009 lambda=0.018 critic_pen=0.080
# [train] step=25000 q=58.711 critic=3.224 actor=-0.856 bc=0.028 lambda=0.016 critic_pen=0.080
# [train] step=26000 q=57.502 critic=3.704 actor=-0.828 bc=0.031 lambda=0.017 critic_pen=0.077
# [train] step=27000 q=60.453 critic=3.836 actor=-0.917 bc=0.010 lambda=0.016 critic_pen=0.090
# [train] step=28000 q=59.837 critic=5.634 actor=-0.884 bc=0.021 lambda=0.016 critic_pen=0.103
# [train] step=29000 q=63.085 critic=3.579 actor=-0.948 bc=0.006 lambda=0.015 critic_pen=0.093
# [train] step=30000 q=63.811 critic=3.107 actor=-0.916 bc=0.015 lambda=0.015 critic_pen=0.091
# [eval] step=30000 success=53.33% return=-31.77 time=50.15s energy=38955.13 path=60.15 prog=0.521
# [train] step=31000 q=64.175 critic=3.046 actor=-0.895 bc=0.016 lambda=0.015 critic_pen=0.086
# [train] step=32000 q=63.721 critic=2.981 actor=-0.934 bc=0.008 lambda=0.015 critic_pen=0.071
# [train] step=33000 q=65.565 critic=2.791 actor=-0.960 bc=0.002 lambda=0.015 critic_pen=0.085
# [train] step=34000 q=64.236 critic=2.087 actor=-0.901 bc=0.017 lambda=0.015 critic_pen=0.078
# [train] step=35000 q=67.278 critic=2.528 actor=-0.949 bc=0.006 lambda=0.014 critic_pen=0.097
# [train] step=36000 q=63.692 critic=137.642 actor=-0.944 bc=0.007 lambda=0.015 critic_pen=0.083
# [train] step=37000 q=67.353 critic=3.552 actor=-0.971 bc=0.005 lambda=0.015 critic_pen=0.083
# [train] step=38000 q=64.795 critic=3.385 actor=-0.932 bc=0.012 lambda=0.015 critic_pen=0.102
# [train] step=39000 q=68.770 critic=5.146 actor=-0.933 bc=0.013 lambda=0.014 critic_pen=0.105
# [train] step=40000 q=68.755 critic=1.818 actor=-0.926 bc=0.014 lambda=0.014 critic_pen=0.090
# [eval] step=40000 success=63.33% return=10.21 time=46.17s energy=35938.85 path=53.53 prog=0.688
# [train] step=41000 q=68.567 critic=1.792 actor=-0.916 bc=0.019 lambda=0.014 critic_pen=0.101
# [train] step=42000 q=69.833 critic=1.787 actor=-0.925 bc=0.018 lambda=0.014 critic_pen=0.074
# [train] step=43000 q=69.195 critic=1.864 actor=-0.903 bc=0.023 lambda=0.014 critic_pen=0.098
# [train] step=44000 q=71.388 critic=1.474 actor=-0.963 bc=0.009 lambda=0.014 critic_pen=0.100
# [train] step=45000 q=68.993 critic=1.570 actor=-0.977 bc=0.004 lambda=0.014 critic_pen=0.088
# [train] step=46000 q=70.624 critic=3.673 actor=-0.939 bc=0.014 lambda=0.014 critic_pen=0.083
# [train] step=47000 q=68.366 critic=2.123 actor=-0.985 bc=0.001 lambda=0.014 critic_pen=0.081
# [train] step=48000 q=69.401 critic=1.286 actor=-0.895 bc=0.023 lambda=0.014 critic_pen=0.104
# [train] step=49000 q=71.879 critic=1.190 actor=-0.959 bc=0.010 lambda=0.014 critic_pen=0.082
# [train] step=50000 q=70.146 critic=1.629 actor=-0.985 bc=0.002 lambda=0.014 critic_pen=0.075
# [eval] step=50000 success=53.33% return=-34.80 time=51.90s energy=40622.93 path=61.86 prog=0.534
# [train] step=51000 q=71.841 critic=1.315 actor=-0.952 bc=0.012 lambda=0.014 critic_pen=0.080
# [train] step=52000 q=68.331 critic=1.931 actor=-0.955 bc=0.011 lambda=0.015 critic_pen=0.074
# [train] step=53000 q=71.124 critic=1.172 actor=-0.937 bc=0.014 lambda=0.014 critic_pen=0.067
# [train] step=54000 q=69.523 critic=1.629 actor=-0.908 bc=0.022 lambda=0.014 critic_pen=0.098
# [train] step=55000 q=69.550 critic=338.838 actor=-0.945 bc=0.013 lambda=0.014 critic_pen=0.099
# [train] step=56000 q=69.377 critic=1.425 actor=-0.900 bc=0.022 lambda=0.014 critic_pen=0.070
# [train] step=57000 q=70.497 critic=1.324 actor=-0.991 bc=0.002 lambda=0.014 critic_pen=0.076
# [train] step=58000 q=71.822 critic=1.001 actor=-0.968 bc=0.008 lambda=0.014 critic_pen=0.079
# [train] step=59000 q=71.629 critic=1.142 actor=-0.952 bc=0.012 lambda=0.014 critic_pen=0.072
# [train] step=60000 q=70.968 critic=0.854 actor=-0.953 bc=0.012 lambda=0.014 critic_pen=0.080
# [eval] step=60000 success=66.67% return=29.87 time=45.07s energy=35156.12 path=50.04 prog=0.804
# [train] step=61000 q=72.231 critic=0.959 actor=-0.990 bc=0.002 lambda=0.014 critic_pen=0.088
# [train] step=62000 q=71.437 critic=302.218 actor=-0.929 bc=0.018 lambda=0.014 critic_pen=0.088
# [train] step=63000 q=70.158 critic=2.512 actor=-0.981 bc=0.001 lambda=0.014 critic_pen=0.104
# [train] step=64000 q=72.811 critic=1.166 actor=-0.966 bc=0.008 lambda=0.014 critic_pen=0.116
# [train] step=65000 q=71.856 critic=1.249 actor=-0.959 bc=0.010 lambda=0.014 critic_pen=0.091
# [train] step=66000 q=71.369 critic=1.376 actor=-0.980 bc=0.004 lambda=0.014 critic_pen=0.086
# [train] step=67000 q=69.894 critic=1.530 actor=-0.957 bc=0.008 lambda=0.014 critic_pen=0.075
# [train] step=68000 q=70.262 critic=0.999 actor=-0.950 bc=0.008 lambda=0.014 critic_pen=0.083
# [train] step=69000 q=72.248 critic=2.629 actor=-0.944 bc=0.013 lambda=0.014 critic_pen=0.097
# [train] step=70000 q=70.702 critic=1.497 actor=-0.881 bc=0.026 lambda=0.014 critic_pen=0.086
# [eval] step=70000 success=80.00% return=69.15 time=46.12s energy=35933.27 path=51.90 prog=0.785
# [train] step=71000 q=70.463 critic=1.010 actor=-0.945 bc=0.014 lambda=0.014 critic_pen=0.088
# [train] step=72000 q=69.124 critic=1.106 actor=-0.918 bc=0.005 lambda=0.014 critic_pen=0.078
# [train] step=73000 q=72.672 critic=0.915 actor=-0.942 bc=0.014 lambda=0.014 critic_pen=0.093
# [train] step=74000 q=72.606 critic=0.710 actor=-0.997 bc=0.001 lambda=0.014 critic_pen=0.074
# [train] step=75000 q=68.660 critic=1.888 actor=-0.831 bc=0.029 lambda=0.014 critic_pen=0.092
# [train] step=76000 q=70.640 critic=1.130 actor=-0.992 bc=0.002 lambda=0.014 critic_pen=0.065
# [train] step=77000 q=71.924 critic=0.965 actor=-0.986 bc=0.003 lambda=0.014 critic_pen=0.073
# [train] step=78000 q=71.119 critic=1.015 actor=-0.956 bc=0.009 lambda=0.014 critic_pen=0.081
# [train] step=79000 q=71.891 critic=1.080 actor=-0.932 bc=0.017 lambda=0.014 critic_pen=0.101
# [train] step=80000 q=71.772 critic=0.916 actor=-0.931 bc=0.012 lambda=0.014 critic_pen=0.097
# [eval] step=80000 success=83.33% return=87.70 time=45.29s energy=35309.57 path=49.48 prog=0.876
# [train] step=81000 q=69.177 critic=0.991 actor=-0.921 bc=0.020 lambda=0.014 critic_pen=0.084
# [train] step=82000 q=68.144 critic=4.918 actor=-0.895 bc=0.020 lambda=0.014 critic_pen=0.079
# [train] step=83000 q=71.409 critic=2.364 actor=-0.901 bc=0.021 lambda=0.014 critic_pen=0.110
# [train] step=84000 q=69.624 critic=2.911 actor=-0.913 bc=0.007 lambda=0.013 critic_pen=0.089
# [train] step=85000 q=72.264 critic=1.391 actor=-0.986 bc=0.003 lambda=0.014 critic_pen=0.082
# [train] step=86000 q=71.535 critic=0.920 actor=-0.952 bc=0.007 lambda=0.014 critic_pen=0.086
# [train] step=87000 q=69.440 critic=2.008 actor=-0.903 bc=0.019 lambda=0.014 critic_pen=0.084
# [train] step=88000 q=69.961 critic=1.370 actor=-0.886 bc=0.016 lambda=0.014 critic_pen=0.089
# [train] step=89000 q=72.622 critic=1.273 actor=-0.961 bc=0.006 lambda=0.014 critic_pen=0.073
# [train] step=90000 q=70.495 critic=1.078 actor=-0.934 bc=0.011 lambda=0.014 critic_pen=0.082
# [eval] step=90000 success=73.33% return=51.18 time=47.01s energy=36669.40 path=51.20 prog=0.853
# [train] step=91000 q=70.432 critic=2.588 actor=-0.953 bc=0.011 lambda=0.014 critic_pen=0.091
# [train] step=92000 q=70.635 critic=1.214 actor=-0.901 bc=0.019 lambda=0.014 critic_pen=0.092
# [train] step=93000 q=68.690 critic=1.429 actor=-0.949 bc=0.002 lambda=0.014 critic_pen=0.106
# [train] step=94000 q=67.014 critic=1.222 actor=-0.860 bc=0.013 lambda=0.014 critic_pen=0.063
# [train] step=95000 q=71.839 critic=1.078 actor=-0.980 bc=0.005 lambda=0.014 critic_pen=0.102
# [train] step=96000 q=68.617 critic=1.675 actor=-0.916 bc=0.006 lambda=0.014 critic_pen=0.080
# [train] step=97000 q=70.144 critic=0.961 actor=-0.902 bc=0.024 lambda=0.014 critic_pen=0.074
# [train] step=98000 q=70.507 critic=0.988 actor=-0.979 bc=0.001 lambda=0.014 critic_pen=0.072
# [train] step=99000 q=69.962 critic=0.901 actor=-0.913 bc=0.013 lambda=0.014 critic_pen=0.063
# [train] step=100000 q=73.644 critic=1.259 actor=-0.980 bc=0.004 lambda=0.014 critic_pen=0.095
# [eval] step=100000 success=56.67% return=-4.62 time=55.39s energy=43425.82 path=58.63 prog=0.756
# [train] step=101000 q=71.910 critic=1.148 actor=-0.965 bc=0.003 lambda=0.014 critic_pen=0.074
# [train] step=102000 q=68.533 critic=1.171 actor=-0.951 bc=0.001 lambda=0.014 critic_pen=0.077
# [train] step=103000 q=70.964 critic=0.992 actor=-0.974 bc=0.006 lambda=0.014 critic_pen=0.076
# [train] step=104000 q=70.734 critic=0.821 actor=-0.991 bc=0.002 lambda=0.014 critic_pen=0.059
# [train] step=105000 q=72.573 critic=1.757 actor=-0.994 bc=0.002 lambda=0.014 critic_pen=0.077
# [train] step=106000 q=71.626 critic=3.968 actor=-0.959 bc=0.003 lambda=0.014 critic_pen=0.075
# [train] step=107000 q=72.140 critic=0.732 actor=-0.923 bc=0.014 lambda=0.014 critic_pen=0.078
# [train] step=108000 q=69.791 critic=0.813 actor=-0.993 bc=0.002 lambda=0.014 critic_pen=0.083
# [train] step=109000 q=72.061 critic=0.994 actor=-0.978 bc=0.006 lambda=0.014 critic_pen=0.102
# [train] step=110000 q=72.307 critic=1.049 actor=-0.908 bc=0.017 lambda=0.013 critic_pen=0.076
# [eval] step=110000 success=90.00% return=103.69 time=47.05s energy=36688.29 path=50.95 prog=0.864
# [train] step=111000 q=68.932 critic=2.530 actor=-0.961 bc=0.003 lambda=0.014 critic_pen=0.079
# [train] step=112000 q=72.589 critic=0.685 actor=-0.997 bc=0.001 lambda=0.014 critic_pen=0.062
# [train] step=113000 q=73.448 critic=1.336 actor=-0.918 bc=0.019 lambda=0.014 critic_pen=0.121
# [train] step=114000 q=70.773 critic=0.994 actor=-0.956 bc=0.004 lambda=0.014 critic_pen=0.082
# [train] step=115000 q=72.533 critic=1.199 actor=-0.955 bc=0.005 lambda=0.013 critic_pen=0.074
# [train] step=116000 q=69.886 critic=1.868 actor=-0.910 bc=0.010 lambda=0.014 critic_pen=0.078
# [train] step=117000 q=71.768 critic=1.013 actor=-0.969 bc=0.001 lambda=0.014 critic_pen=0.067
# [train] step=118000 q=72.514 critic=1.090 actor=-0.931 bc=0.009 lambda=0.013 critic_pen=0.083
# [train] step=119000 q=73.251 critic=0.957 actor=-0.962 bc=0.010 lambda=0.014 critic_pen=0.075
# [train] step=120000 q=72.685 critic=1.332 actor=-0.906 bc=0.019 lambda=0.014 critic_pen=0.093
# [eval] step=120000 success=83.33% return=80.74 time=45.07s energy=35209.77 path=50.80 prog=0.823
# [train] step=121000 q=71.727 critic=1.712 actor=-0.932 bc=0.015 lambda=0.014 critic_pen=0.090
# [train] step=122000 q=71.651 critic=5.862 actor=-0.951 bc=0.008 lambda=0.014 critic_pen=0.098
# [train] step=123000 q=71.809 critic=0.848 actor=-0.958 bc=0.004 lambda=0.014 critic_pen=0.069
# [train] step=124000 q=68.578 critic=4.985 actor=-0.923 bc=0.001 lambda=0.014 critic_pen=0.085
# [train] step=125000 q=75.108 critic=0.659 actor=-0.945 bc=0.014 lambda=0.013 critic_pen=0.089
# [train] step=126000 q=71.906 critic=0.800 actor=-0.978 bc=0.006 lambda=0.014 critic_pen=0.067
# [train] step=127000 q=70.119 critic=0.755 actor=-0.952 bc=0.002 lambda=0.014 critic_pen=0.079
# [train] step=128000 q=70.801 critic=0.838 actor=-0.997 bc=0.001 lambda=0.014 critic_pen=0.086
# [train] step=129000 q=72.090 critic=1.902 actor=-0.972 bc=0.007 lambda=0.014 critic_pen=0.082
# [train] step=130000 q=68.519 critic=1.249 actor=-0.882 bc=0.011 lambda=0.014 critic_pen=0.078
# [eval] step=130000 success=90.00% return=107.59 time=42.98s energy=33412.22 path=47.20 prog=0.887
# [train] step=131000 q=71.264 critic=0.791 actor=-0.915 bc=0.015 lambda=0.014 critic_pen=0.080
# [train] step=132000 q=69.626 critic=2.093 actor=-0.954 bc=0.006 lambda=0.014 critic_pen=0.074
# [train] step=133000 q=74.707 critic=0.742 actor=-0.960 bc=0.010 lambda=0.013 critic_pen=0.087
# [train] step=134000 q=69.606 critic=0.820 actor=-0.964 bc=0.002 lambda=0.014 critic_pen=0.065
# [train] step=135000 q=70.776 critic=0.824 actor=-0.961 bc=0.001 lambda=0.014 critic_pen=0.061
# [train] step=136000 q=74.208 critic=0.821 actor=-0.995 bc=0.001 lambda=0.013 critic_pen=0.071
# [train] step=137000 q=70.768 critic=1.513 actor=-0.916 bc=0.009 lambda=0.013 critic_pen=0.094
# [train] step=138000 q=74.417 critic=0.911 actor=-0.995 bc=0.001 lambda=0.013 critic_pen=0.081
# [train] step=139000 q=71.277 critic=0.711 actor=-0.944 bc=0.011 lambda=0.014 critic_pen=0.075
# [train] step=140000 q=72.791 critic=0.779 actor=-0.996 bc=0.001 lambda=0.014 critic_pen=0.090
# [eval] step=140000 success=86.67% return=96.90 time=45.09s energy=35112.02 path=48.87 prog=0.900
# [train] step=141000 q=71.475 critic=0.812 actor=-0.969 bc=0.001 lambda=0.014 critic_pen=0.074
# [train] step=142000 q=72.121 critic=0.990 actor=-0.959 bc=0.004 lambda=0.014 critic_pen=0.080
# [train] step=143000 q=71.631 critic=1.004 actor=-0.973 bc=0.001 lambda=0.014 critic_pen=0.085
# [train] step=144000 q=71.064 critic=2.749 actor=-0.950 bc=0.007 lambda=0.014 critic_pen=0.097
# [train] step=145000 q=72.051 critic=0.958 actor=-0.997 bc=0.001 lambda=0.014 critic_pen=0.070
# [train] step=146000 q=67.546 critic=2.197 actor=-0.923 bc=0.003 lambda=0.014 critic_pen=0.081
# [train] step=147000 q=70.763 critic=0.856 actor=-0.948 bc=0.007 lambda=0.014 critic_pen=0.071
# [train] step=148000 q=69.865 critic=1.948 actor=-0.935 bc=0.002 lambda=0.014 critic_pen=0.070
# [train] step=149000 q=72.595 critic=0.939 actor=-0.957 bc=0.008 lambda=0.014 critic_pen=0.079
# [train] step=150000 q=73.768 critic=1.686 actor=-0.966 bc=0.005 lambda=0.013 critic_pen=0.086
# [eval] step=150000 success=86.67% return=90.74 time=51.55s energy=40401.50 path=54.80 prog=0.778
# [train] step=151000 q=73.961 critic=1.960 actor=-0.970 bc=0.003 lambda=0.013 critic_pen=0.098
# [train] step=152000 q=69.398 critic=0.854 actor=-0.896 bc=0.016 lambda=0.014 critic_pen=0.092
# [train] step=153000 q=72.816 critic=0.867 actor=-0.981 bc=0.005 lambda=0.014 critic_pen=0.093
# [train] step=154000 q=71.422 critic=0.965 actor=-0.905 bc=0.012 lambda=0.013 critic_pen=0.078
# [train] step=155000 q=74.694 critic=0.594 actor=-0.997 bc=0.001 lambda=0.013 critic_pen=0.074
# [train] step=156000 q=74.331 critic=0.920 actor=-0.919 bc=0.020 lambda=0.013 critic_pen=0.074
# [train] step=157000 q=71.030 critic=0.860 actor=-0.899 bc=0.010 lambda=0.013 critic_pen=0.096
# [train] step=158000 q=71.580 critic=0.638 actor=-0.915 bc=0.015 lambda=0.014 critic_pen=0.081
# [train] step=159000 q=73.555 critic=0.741 actor=-0.959 bc=0.010 lambda=0.014 critic_pen=0.093
# [train] step=160000 q=73.461 critic=0.711 actor=-0.997 bc=0.001 lambda=0.014 critic_pen=0.076
# [eval] step=160000 success=83.33% return=88.72 time=45.93s energy=35814.84 path=49.66 prog=0.886
# [train] step=161000 q=70.674 critic=0.600 actor=-0.948 bc=0.002 lambda=0.014 critic_pen=0.074
# [train] step=162000 q=74.076 critic=0.667 actor=-0.976 bc=0.001 lambda=0.013 critic_pen=0.060
# [train] step=163000 q=72.008 critic=1.018 actor=-0.984 bc=0.000 lambda=0.014 critic_pen=0.077
# [train] step=164000 q=72.839 critic=1.183 actor=-0.967 bc=0.003 lambda=0.013 critic_pen=0.088
# [train] step=165000 q=73.115 critic=0.600 actor=-0.944 bc=0.008 lambda=0.013 critic_pen=0.064
# [train] step=166000 q=70.160 critic=14.146 actor=-0.931 bc=0.006 lambda=0.014 critic_pen=0.102
# [train] step=167000 q=72.599 critic=0.522 actor=-0.973 bc=0.007 lambda=0.014 critic_pen=0.081
# [train] step=168000 q=71.471 critic=0.821 actor=-0.976 bc=0.001 lambda=0.014 critic_pen=0.063
# [train] step=169000 q=73.886 critic=0.731 actor=-0.971 bc=0.007 lambda=0.014 critic_pen=0.077
# [train] step=170000 q=73.715 critic=0.586 actor=-0.973 bc=0.007 lambda=0.014 critic_pen=0.072
# [eval] step=170000 success=66.67% return=27.18 time=44.59s energy=34773.36 path=50.72 prog=0.783
# [train] step=171000 q=72.139 critic=307.531 actor=-0.918 bc=0.009 lambda=0.013 critic_pen=0.070
# [train] step=172000 q=73.142 critic=0.993 actor=-0.996 bc=0.001 lambda=0.014 critic_pen=0.077
# [train] step=173000 q=73.400 critic=1.089 actor=-0.931 bc=0.017 lambda=0.014 critic_pen=0.061
# [train] step=174000 q=71.405 critic=28.760 actor=-0.916 bc=0.007 lambda=0.013 critic_pen=0.095
# [train] step=175000 q=73.728 critic=0.782 actor=-0.995 bc=0.001 lambda=0.014 critic_pen=0.072
# [train] step=176000 q=74.042 critic=1.041 actor=-0.971 bc=0.002 lambda=0.013 critic_pen=0.090
# [train] step=177000 q=73.127 critic=0.651 actor=-0.943 bc=0.009 lambda=0.013 critic_pen=0.086
# [train] step=178000 q=71.779 critic=0.667 actor=-0.994 bc=0.001 lambda=0.014 critic_pen=0.083
# [train] step=179000 q=70.737 critic=2.598 actor=-0.934 bc=0.001 lambda=0.013 critic_pen=0.075
# [train] step=180000 q=73.147 critic=0.641 actor=-0.991 bc=0.002 lambda=0.014 critic_pen=0.093
# [eval] step=180000 success=96.67% return=128.97 time=43.06s energy=33565.12 path=47.34 prog=0.899
# [train] step=181000 q=72.129 critic=0.880 actor=-0.990 bc=0.002 lambda=0.014 critic_pen=0.093
# [train] step=182000 q=73.388 critic=0.673 actor=-0.945 bc=0.009 lambda=0.013 critic_pen=0.078
# [train] step=183000 q=75.473 critic=0.531 actor=-0.945 bc=0.014 lambda=0.013 critic_pen=0.075
# [train] step=184000 q=73.299 critic=0.711 actor=-0.948 bc=0.008 lambda=0.013 critic_pen=0.073
# [train] step=185000 q=73.184 critic=0.703 actor=-0.967 bc=0.008 lambda=0.014 critic_pen=0.073
# [train] step=186000 q=72.339 critic=0.540 actor=-0.977 bc=0.001 lambda=0.014 critic_pen=0.071
# [train] step=187000 q=72.538 critic=0.612 actor=-0.995 bc=0.001 lambda=0.014 critic_pen=0.064
# [train] step=188000 q=72.874 critic=0.687 actor=-0.990 bc=0.002 lambda=0.014 critic_pen=0.070
# [train] step=189000 q=71.182 critic=6.353 actor=-0.923 bc=0.008 lambda=0.013 critic_pen=0.081
# [train] step=190000 q=73.978 critic=0.606 actor=-0.984 bc=0.004 lambda=0.014 critic_pen=0.088
# [eval] step=190000 success=90.00% return=104.96 time=45.17s energy=35225.37 path=49.79 prog=0.854
# [train] step=191000 q=68.355 critic=9.994 actor=-0.916 bc=0.002 lambda=0.014 critic_pen=0.076
# [train] step=192000 q=72.463 critic=0.753 actor=-0.977 bc=0.002 lambda=0.014 critic_pen=0.078
# [train] step=193000 q=74.803 critic=0.497 actor=-0.987 bc=0.003 lambda=0.013 critic_pen=0.066
# [train] step=194000 q=73.376 critic=0.781 actor=-0.996 bc=0.001 lambda=0.014 critic_pen=0.077
# [train] step=195000 q=71.650 critic=0.771 actor=-0.976 bc=0.001 lambda=0.014 critic_pen=0.073
# [train] step=196000 q=73.513 critic=0.669 actor=-0.967 bc=0.008 lambda=0.014 critic_pen=0.079
# [train] step=197000 q=70.123 critic=0.598 actor=-0.951 bc=0.001 lambda=0.014 critic_pen=0.076
# [train] step=198000 q=70.910 critic=0.525 actor=-0.941 bc=0.003 lambda=0.013 critic_pen=0.065
# [train] step=199000 q=73.783 critic=0.613 actor=-0.976 bc=0.001 lambda=0.013 critic_pen=0.066
# [train] step=200000 q=74.190 critic=0.868 actor=-0.982 bc=0.005 lambda=0.013 critic_pen=0.069
# [eval] step=200000 success=86.67% return=97.14 time=44.01s energy=34252.86 path=48.17 prog=0.887
# [done] rebrac seed=0 → /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5/checkpoints/offline/fql_succession/gate_b/rebrac_e_uni_seed0 (39.3 min)
#
# ========== [4/4] train fql seed=0 ==========
# [offline] algo=fql transitions=86685 obs_dim=48 action_dim=2 protocol=deployable tensor_replay=on eval_workers=4 sampling=uniform total_steps=200000
# [train] step=1 q=-0.537 critic=221.182 actor=1.977 bc=0.980 lambda=1.857
# [train] step=1000 q=4.519 critic=82.521 actor=-0.916 bc=0.059 lambda=0.216
# [train] step=2000 q=10.800 critic=42.417 actor=-0.939 bc=0.042 lambda=0.091
# [train] step=3000 q=15.562 critic=2.546 actor=-0.932 bc=0.044 lambda=0.063
# [train] step=4000 q=18.770 critic=0.953 actor=-0.961 bc=0.029 lambda=0.053
# [train] step=5000 q=23.101 critic=0.818 actor=-0.960 bc=0.022 lambda=0.042
# [train] step=6000 q=29.788 critic=0.977 actor=-0.960 bc=0.028 lambda=0.033
# [train] step=7000 q=32.863 critic=1.662 actor=-0.974 bc=0.017 lambda=0.030
# [train] step=8000 q=38.218 critic=1.503 actor=-0.975 bc=0.019 lambda=0.026
# [train] step=9000 q=33.375 critic=0.656 actor=-0.967 bc=0.021 lambda=0.030
# [train] step=10000 q=40.966 critic=1.547 actor=-0.974 bc=0.014 lambda=0.024
# [eval] step=10000 success=30.00% return=-88.41 time=49.29s energy=38282.13 path=53.06 prog=0.724
# [train] step=11000 q=40.058 critic=0.994 actor=-0.978 bc=0.014 lambda=0.025
# [train] step=12000 q=48.885 critic=1.254 actor=-0.968 bc=0.023 lambda=0.020
# [train] step=13000 q=52.503 critic=1.294 actor=-0.979 bc=0.020 lambda=0.019
# [train] step=14000 q=49.897 critic=2.124 actor=-0.974 bc=0.026 lambda=0.020
# [train] step=15000 q=51.554 critic=1.505 actor=-0.980 bc=0.013 lambda=0.019
# [train] step=16000 q=56.935 critic=1.712 actor=-0.988 bc=0.005 lambda=0.017
# [train] step=17000 q=57.921 critic=3.183 actor=-0.962 bc=0.036 lambda=0.017
# [train] step=18000 q=61.908 critic=2.366 actor=-0.973 bc=0.022 lambda=0.016
# [train] step=19000 q=67.559 critic=1.631 actor=-0.972 bc=0.028 lambda=0.015
# [train] step=20000 q=64.405 critic=2.658 actor=-0.985 bc=0.013 lambda=0.016
# [eval] step=20000 success=43.33% return=-55.99 time=43.64s energy=34394.03 path=52.64 prog=0.637
# [train] step=21000 q=71.486 critic=2.502 actor=-0.984 bc=0.015 lambda=0.014
# [train] step=22000 q=70.220 critic=5.666 actor=-0.981 bc=0.019 lambda=0.014
# [train] step=23000 q=71.597 critic=2.738 actor=-0.983 bc=0.016 lambda=0.014
# [train] step=24000 q=73.541 critic=5.049 actor=-0.985 bc=0.011 lambda=0.014
# [train] step=25000 q=74.692 critic=2.146 actor=-0.976 bc=0.024 lambda=0.013
# [train] step=26000 q=74.499 critic=1.847 actor=-0.983 bc=0.016 lambda=0.013
# [train] step=27000 q=76.509 critic=1.729 actor=-0.982 bc=0.018 lambda=0.013
# [train] step=28000 q=78.423 critic=0.800 actor=-0.990 bc=0.010 lambda=0.013
# [train] step=29000 q=77.296 critic=1.288 actor=-0.976 bc=0.024 lambda=0.013
# [train] step=30000 q=76.059 critic=1.265 actor=-0.980 bc=0.016 lambda=0.013
# [eval] step=30000 success=40.00% return=-62.65 time=44.68s energy=34823.92 path=52.29 prog=0.670
# [train] step=31000 q=78.437 critic=1.279 actor=-0.982 bc=0.018 lambda=0.013
# [train] step=32000 q=77.149 critic=279.198 actor=-0.985 bc=0.015 lambda=0.013
# [train] step=33000 q=79.352 critic=0.637 actor=-0.974 bc=0.026 lambda=0.013
# [train] step=34000 q=77.426 critic=0.708 actor=-0.989 bc=0.011 lambda=0.013
# [train] step=35000 q=79.187 critic=0.823 actor=-0.975 bc=0.025 lambda=0.013
# [train] step=36000 q=79.776 critic=0.802 actor=-0.988 bc=0.012 lambda=0.013
# [train] step=37000 q=79.358 critic=0.691 actor=-0.980 bc=0.020 lambda=0.013
# [train] step=38000 q=77.362 critic=0.653 actor=-0.986 bc=0.008 lambda=0.013
# [train] step=39000 q=78.700 critic=0.757 actor=-0.978 bc=0.022 lambda=0.013
# [train] step=40000 q=79.763 critic=200.044 actor=-0.996 bc=0.004 lambda=0.013
# [eval] step=40000 success=73.33% return=40.23 time=43.99s energy=33917.58 path=50.65 prog=0.712
# [train] step=41000 q=77.934 critic=0.689 actor=-0.994 bc=0.006 lambda=0.013
# [train] step=42000 q=78.342 critic=0.760 actor=-0.979 bc=0.021 lambda=0.013
# [train] step=43000 q=79.025 critic=0.900 actor=-0.987 bc=0.013 lambda=0.013
# [train] step=44000 q=78.896 critic=0.913 actor=-0.976 bc=0.024 lambda=0.013
# [train] step=45000 q=80.323 critic=0.785 actor=-0.986 bc=0.014 lambda=0.012
# [train] step=46000 q=79.655 critic=0.504 actor=-0.980 bc=0.020 lambda=0.013
# [train] step=47000 q=81.312 critic=0.652 actor=-0.980 bc=0.020 lambda=0.012
# [train] step=48000 q=79.761 critic=0.648 actor=-0.987 bc=0.008 lambda=0.012
# [train] step=49000 q=79.537 critic=0.613 actor=-0.991 bc=0.009 lambda=0.013
# [train] step=50000 q=78.878 critic=0.610 actor=-0.975 bc=0.011 lambda=0.013
# [eval] step=50000 success=80.00% return=60.89 time=43.38s energy=33310.65 path=49.90 prog=0.710
# [train] step=51000 q=80.081 critic=0.581 actor=-0.993 bc=0.007 lambda=0.012
# [train] step=52000 q=79.420 critic=0.728 actor=-0.982 bc=0.010 lambda=0.012
# [train] step=53000 q=80.053 critic=0.596 actor=-0.985 bc=0.015 lambda=0.012
# [train] step=54000 q=80.673 critic=0.540 actor=-0.984 bc=0.008 lambda=0.012
# [train] step=55000 q=80.050 critic=0.670 actor=-0.995 bc=0.005 lambda=0.012
# [train] step=56000 q=79.673 critic=0.723 actor=-0.978 bc=0.022 lambda=0.013
# [train] step=57000 q=80.119 critic=0.652 actor=-0.984 bc=0.016 lambda=0.012
# [train] step=58000 q=80.186 critic=0.496 actor=-0.983 bc=0.017 lambda=0.012
# [train] step=59000 q=79.152 critic=0.656 actor=-0.980 bc=0.020 lambda=0.013
# [train] step=60000 q=80.475 critic=0.580 actor=-0.994 bc=0.006 lambda=0.012
# [eval] step=60000 success=76.67% return=57.36 time=43.06s energy=33315.31 path=48.57 prog=0.784
# [train] step=61000 q=79.806 critic=0.577 actor=-0.977 bc=0.023 lambda=0.013
# [train] step=62000 q=79.824 critic=0.803 actor=-0.973 bc=0.013 lambda=0.012
# [train] step=63000 q=80.247 critic=32.132 actor=-0.966 bc=0.020 lambda=0.012
# [train] step=64000 q=81.615 critic=0.674 actor=-0.986 bc=0.014 lambda=0.012
# [train] step=65000 q=78.243 critic=1.382 actor=-0.973 bc=0.011 lambda=0.013
# [train] step=66000 q=80.063 critic=0.816 actor=-0.992 bc=0.008 lambda=0.012
# [train] step=67000 q=79.912 critic=0.863 actor=-0.993 bc=0.007 lambda=0.013
# [train] step=68000 q=80.424 critic=0.534 actor=-0.985 bc=0.015 lambda=0.012
# [train] step=69000 q=79.927 critic=0.557 actor=-0.984 bc=0.016 lambda=0.013
# [train] step=70000 q=78.420 critic=0.717 actor=-0.981 bc=0.019 lambda=0.013
# [eval] step=70000 success=63.33% return=9.78 time=44.16s energy=34147.51 path=50.60 prog=0.727
# [train] step=71000 q=79.993 critic=0.542 actor=-0.983 bc=0.017 lambda=0.013
# [train] step=72000 q=78.870 critic=0.594 actor=-0.982 bc=0.016 lambda=0.013
# [train] step=73000 q=79.421 critic=1.647 actor=-0.988 bc=0.012 lambda=0.013
# [train] step=74000 q=79.608 critic=0.787 actor=-0.959 bc=0.021 lambda=0.012
# [train] step=75000 q=79.996 critic=0.708 actor=-0.979 bc=0.001 lambda=0.012
# [train] step=76000 q=78.368 critic=5.097 actor=-0.953 bc=0.022 lambda=0.012
# [train] step=77000 q=81.290 critic=0.493 actor=-0.987 bc=0.013 lambda=0.012
# [train] step=78000 q=79.583 critic=2.217 actor=-0.973 bc=0.006 lambda=0.012
# [train] step=79000 q=80.028 critic=0.629 actor=-0.983 bc=0.017 lambda=0.012
# [train] step=80000 q=80.523 critic=0.575 actor=-0.996 bc=0.004 lambda=0.012
# [eval] step=80000 success=60.00% return=8.21 time=45.03s energy=34933.04 path=49.90 prog=0.789
# [train] step=81000 q=79.551 critic=0.544 actor=-0.994 bc=0.006 lambda=0.013
# [train] step=82000 q=80.332 critic=1.052 actor=-0.983 bc=0.011 lambda=0.012
# [train] step=83000 q=79.665 critic=0.897 actor=-0.996 bc=0.004 lambda=0.013
# [train] step=84000 q=77.592 critic=2.001 actor=-0.928 bc=0.022 lambda=0.012
# [train] step=85000 q=78.314 critic=0.547 actor=-0.944 bc=0.018 lambda=0.012
# [train] step=86000 q=79.768 critic=0.550 actor=-0.985 bc=0.015 lambda=0.013
# [train] step=87000 q=80.164 critic=0.496 actor=-0.989 bc=0.011 lambda=0.012
# [train] step=88000 q=81.648 critic=0.819 actor=-0.986 bc=0.014 lambda=0.012
# [train] step=89000 q=79.379 critic=0.702 actor=-0.970 bc=0.007 lambda=0.012
# [train] step=90000 q=79.611 critic=0.694 actor=-0.994 bc=0.006 lambda=0.013
# [eval] step=90000 success=73.33% return=56.08 time=46.21s energy=35978.74 path=49.92 prog=0.866
# [train] step=91000 q=77.373 critic=4.251 actor=-0.939 bc=0.018 lambda=0.012
# [train] step=92000 q=80.181 critic=0.711 actor=-0.983 bc=0.007 lambda=0.012
# [train] step=93000 q=79.412 critic=0.854 actor=-0.955 bc=0.024 lambda=0.012
# [train] step=94000 q=78.810 critic=0.565 actor=-0.975 bc=0.009 lambda=0.012
# [train] step=95000 q=79.811 critic=0.823 actor=-0.980 bc=0.008 lambda=0.012
# [train] step=96000 q=79.951 critic=0.587 actor=-0.995 bc=0.005 lambda=0.013
# [train] step=97000 q=78.087 critic=3.375 actor=-0.976 bc=0.013 lambda=0.013
# [train] step=98000 q=79.805 critic=0.541 actor=-0.973 bc=0.016 lambda=0.012
# [train] step=99000 q=80.480 critic=0.852 actor=-0.990 bc=0.010 lambda=0.012
# [train] step=100000 q=76.941 critic=2.014 actor=-0.926 bc=0.014 lambda=0.012
# [eval] step=100000 success=63.33% return=19.11 time=45.94s energy=35635.78 path=50.68 prog=0.802
# [train] step=101000 q=78.541 critic=1.325 actor=-0.946 bc=0.012 lambda=0.012
# [train] step=102000 q=79.561 critic=0.619 actor=-0.969 bc=0.006 lambda=0.012
# [train] step=103000 q=79.973 critic=0.483 actor=-0.982 bc=0.018 lambda=0.013
# [train] step=104000 q=76.044 critic=0.792 actor=-0.924 bc=0.010 lambda=0.012
# [train] step=105000 q=80.600 critic=0.705 actor=-0.986 bc=0.014 lambda=0.012
# [train] step=106000 q=78.681 critic=0.884 actor=-0.987 bc=0.010 lambda=0.013
# [train] step=107000 q=81.267 critic=0.587 actor=-0.985 bc=0.005 lambda=0.012
# [train] step=108000 q=79.237 critic=0.564 actor=-0.970 bc=0.010 lambda=0.012
# [train] step=109000 q=80.752 critic=0.432 actor=-0.991 bc=0.009 lambda=0.012
# [train] step=110000 q=79.560 critic=0.577 actor=-0.984 bc=0.016 lambda=0.013
# [eval] step=110000 success=83.33% return=82.09 time=42.92s energy=33250.52 path=47.18 prog=0.832
# [train] step=111000 q=81.629 critic=0.442 actor=-0.986 bc=0.014 lambda=0.012
# [train] step=112000 q=80.894 critic=0.566 actor=-0.984 bc=0.007 lambda=0.012
# [train] step=113000 q=79.523 critic=1.032 actor=-0.980 bc=0.007 lambda=0.012
# [train] step=114000 q=78.341 critic=138.215 actor=-0.933 bc=0.016 lambda=0.012
# [train] step=115000 q=78.704 critic=0.921 actor=-0.972 bc=0.008 lambda=0.012
# [train] step=116000 q=77.209 critic=0.830 actor=-0.917 bc=0.018 lambda=0.012
# [train] step=117000 q=80.227 critic=0.560 actor=-0.997 bc=0.003 lambda=0.012
# [train] step=118000 q=79.242 critic=0.455 actor=-0.971 bc=0.006 lambda=0.012
# [train] step=119000 q=78.815 critic=0.466 actor=-0.954 bc=0.001 lambda=0.012
# [train] step=120000 q=80.783 critic=0.457 actor=-0.976 bc=0.012 lambda=0.012
# [eval] step=120000 success=70.00% return=44.04 time=44.04s energy=34143.94 path=48.44 prog=0.840
# [train] step=121000 q=77.231 critic=0.730 actor=-0.943 bc=0.012 lambda=0.012
# [train] step=122000 q=80.999 critic=0.469 actor=-0.974 bc=0.026 lambda=0.012
# [train] step=123000 q=79.133 critic=0.511 actor=-0.985 bc=0.015 lambda=0.013
# [train] step=124000 q=80.506 critic=0.410 actor=-0.997 bc=0.003 lambda=0.012
# [train] step=125000 q=77.687 critic=4.130 actor=-0.965 bc=0.005 lambda=0.012
# [train] step=126000 q=79.152 critic=0.520 actor=-0.976 bc=0.003 lambda=0.012
# [train] step=127000 q=81.209 critic=0.448 actor=-0.998 bc=0.002 lambda=0.012
# [train] step=128000 q=79.653 critic=0.526 actor=-0.993 bc=0.007 lambda=0.013
# [train] step=129000 q=80.735 critic=0.401 actor=-0.997 bc=0.003 lambda=0.012
# [train] step=130000 q=79.796 critic=0.507 actor=-0.976 bc=0.004 lambda=0.012
# [eval] step=130000 success=63.33% return=20.90 time=44.81s energy=34844.70 path=49.44 prog=0.837
# [train] step=131000 q=79.454 critic=0.611 actor=-0.941 bc=0.017 lambda=0.012
# [train] step=132000 q=77.725 critic=0.903 actor=-0.939 bc=0.011 lambda=0.012
# [train] step=133000 q=79.306 critic=0.406 actor=-0.984 bc=0.006 lambda=0.012
# [train] step=134000 q=80.883 critic=0.576 actor=-0.994 bc=0.006 lambda=0.012
# [train] step=135000 q=76.301 critic=0.678 actor=-0.944 bc=0.011 lambda=0.013
# [train] step=136000 q=79.797 critic=0.566 actor=-0.973 bc=0.005 lambda=0.012
# [train] step=137000 q=79.310 critic=0.507 actor=-0.976 bc=0.022 lambda=0.013
# [train] step=138000 q=79.801 critic=0.522 actor=-0.977 bc=0.023 lambda=0.013
# [train] step=139000 q=79.977 critic=0.860 actor=-0.988 bc=0.011 lambda=0.012
# [train] step=140000 q=79.582 critic=1.177 actor=-0.963 bc=0.013 lambda=0.012
# [eval] step=140000 success=90.00% return=109.26 time=43.04s energy=33231.52 path=46.33 prog=0.892
# [train] step=141000 q=78.689 critic=0.562 actor=-0.944 bc=0.013 lambda=0.012
# [train] step=142000 q=80.719 critic=0.445 actor=-0.990 bc=0.010 lambda=0.012
# [train] step=143000 q=80.517 critic=0.593 actor=-0.998 bc=0.002 lambda=0.012
# [train] step=144000 q=77.757 critic=0.661 actor=-0.930 bc=0.008 lambda=0.012
# [train] step=145000 q=77.921 critic=9.213 actor=-0.986 bc=0.002 lambda=0.013
# [train] step=146000 q=75.290 critic=0.653 actor=-0.912 bc=0.014 lambda=0.012
# [train] step=147000 q=81.286 critic=0.426 actor=-0.984 bc=0.016 lambda=0.012
# [train] step=148000 q=78.919 critic=0.996 actor=-0.969 bc=0.008 lambda=0.012
# [train] step=149000 q=78.982 critic=0.575 actor=-0.977 bc=0.009 lambda=0.012
# [train] step=150000 q=76.449 critic=0.704 actor=-0.925 bc=0.022 lambda=0.012
# [eval] step=150000 success=66.67% return=27.25 time=44.98s energy=34993.64 path=50.35 prog=0.773
# [train] step=151000 q=78.006 critic=0.570 actor=-0.950 bc=0.008 lambda=0.012
# [train] step=152000 q=77.745 critic=2.105 actor=-0.952 bc=0.012 lambda=0.012
# [train] step=153000 q=79.862 critic=0.314 actor=-0.980 bc=0.011 lambda=0.012
# [train] step=154000 q=77.556 critic=0.512 actor=-0.956 bc=0.011 lambda=0.012
# [train] step=155000 q=78.610 critic=0.605 actor=-0.970 bc=0.003 lambda=0.012
# [train] step=156000 q=80.212 critic=0.377 actor=-0.994 bc=0.006 lambda=0.012
# [train] step=157000 q=78.886 critic=1.027 actor=-0.971 bc=0.013 lambda=0.012
# [train] step=158000 q=79.519 critic=0.392 actor=-0.959 bc=0.009 lambda=0.012
# [train] step=159000 q=79.899 critic=0.522 actor=-0.985 bc=0.002 lambda=0.012
# [train] step=160000 q=75.838 critic=0.361 actor=-0.939 bc=0.006 lambda=0.012
# [eval] step=160000 success=73.33% return=53.55 time=43.86s energy=34038.67 path=48.57 prog=0.831
# [train] step=161000 q=77.774 critic=0.505 actor=-0.920 bc=0.017 lambda=0.012
# [train] step=162000 q=77.364 critic=0.516 actor=-0.944 bc=0.012 lambda=0.012
# [train] step=163000 q=78.937 critic=0.367 actor=-0.969 bc=0.010 lambda=0.012
# [train] step=164000 q=78.663 critic=0.471 actor=-0.961 bc=0.017 lambda=0.012
# [train] step=165000 q=76.048 critic=0.591 actor=-0.950 bc=0.012 lambda=0.013
# [train] step=166000 q=79.764 critic=0.445 actor=-0.981 bc=0.019 lambda=0.013
# [train] step=167000 q=80.264 critic=0.388 actor=-0.988 bc=0.012 lambda=0.012
# [train] step=168000 q=79.193 critic=0.302 actor=-0.986 bc=0.014 lambda=0.013
# [train] step=169000 q=76.357 critic=0.554 actor=-0.938 bc=0.018 lambda=0.013
# [train] step=170000 q=80.328 critic=0.387 actor=-0.974 bc=0.009 lambda=0.012
# [eval] step=170000 success=56.67% return=1.20 time=47.46s energy=36898.95 path=52.34 prog=0.806
# [train] step=171000 q=79.717 critic=0.546 actor=-0.981 bc=0.002 lambda=0.012
# [train] step=172000 q=77.519 critic=0.402 actor=-0.938 bc=0.003 lambda=0.012
# [train] step=173000 q=80.883 critic=0.401 actor=-0.977 bc=0.023 lambda=0.012
# [train] step=174000 q=80.961 critic=0.386 actor=-0.975 bc=0.011 lambda=0.012
# [train] step=175000 q=79.064 critic=0.765 actor=-0.943 bc=0.022 lambda=0.012
# [train] step=176000 q=80.938 critic=0.532 actor=-0.980 bc=0.007 lambda=0.012
# [train] step=177000 q=82.402 critic=0.451 actor=-0.988 bc=0.001 lambda=0.012
# [train] step=178000 q=79.608 critic=0.344 actor=-0.971 bc=0.017 lambda=0.012
# [train] step=179000 q=81.044 critic=0.369 actor=-0.968 bc=0.017 lambda=0.012
# [train] step=180000 q=77.581 critic=0.676 actor=-0.942 bc=0.009 lambda=0.012
# [eval] step=180000 success=70.00% return=40.51 time=46.25s energy=36061.84 path=51.62 prog=0.816
# [train] step=181000 q=81.063 critic=0.424 actor=-0.987 bc=0.013 lambda=0.012
# [train] step=182000 q=80.095 critic=0.376 actor=-0.986 bc=0.014 lambda=0.012
# [train] step=183000 q=79.105 critic=0.440 actor=-0.999 bc=0.001 lambda=0.013
# [train] step=184000 q=80.098 critic=0.635 actor=-0.984 bc=0.004 lambda=0.012
# [train] step=185000 q=79.584 critic=0.586 actor=-0.977 bc=0.005 lambda=0.012
# [train] step=186000 q=79.397 critic=0.866 actor=-0.976 bc=0.008 lambda=0.012
# [train] step=187000 q=78.236 critic=0.563 actor=-0.962 bc=0.001 lambda=0.012
# [train] step=188000 q=79.202 critic=0.433 actor=-0.997 bc=0.003 lambda=0.013
# [train] step=189000 q=78.415 critic=0.369 actor=-0.946 bc=0.006 lambda=0.012
# [train] step=190000 q=79.487 critic=0.328 actor=-0.966 bc=0.006 lambda=0.012
# [eval] step=190000 success=90.00% return=105.69 time=42.74s energy=33150.48 path=47.22 prog=0.861
# [train] step=191000 q=78.355 critic=0.590 actor=-0.965 bc=0.004 lambda=0.012
# [train] step=192000 q=81.060 critic=0.282 actor=-0.990 bc=0.010 lambda=0.012
# [train] step=193000 q=76.962 critic=0.500 actor=-0.947 bc=0.012 lambda=0.012
# [train] step=194000 q=79.988 critic=0.404 actor=-0.975 bc=0.008 lambda=0.012
# [train] step=195000 q=80.898 critic=0.307 actor=-0.986 bc=0.014 lambda=0.012
# [train] step=196000 q=79.235 critic=0.454 actor=-0.974 bc=0.006 lambda=0.012
# [train] step=197000 q=81.113 critic=0.334 actor=-0.986 bc=0.014 lambda=0.012
# [train] step=198000 q=77.730 critic=0.361 actor=-0.949 bc=0.013 lambda=0.012
# [train] step=199000 q=78.794 critic=0.560 actor=-0.989 bc=0.011 lambda=0.013
# [train] step=200000 q=78.953 critic=0.550 actor=-0.977 bc=0.002 lambda=0.012
# [eval] step=200000 success=70.00% return=45.43 time=43.67s energy=33827.95 path=48.08 prog=0.857
# [done] fql seed=0 → /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5/checkpoints/offline/fql_succession/gate_b/fql_e_uni_seed0 (49.3 min)

# %% [markdown]
# ## 3. Final evaluation (2 runs × 100 episodes against fixed manifest)
#
# 训练内 eval 已经写在 `eval_log.csv`（最后一行 = train_step=200000 的 eval），这里 separately 再跑一次 `scripts.evaluate_offline` 作为 **canonical final eval**（与 broad val v2 protocol 一致）。
#
# `evaluate_offline` 通过 `trainer_state.json` 自动 dispatch 到正确的 agent class（rebrac / fql），无需手动指定 algo。

# %%
from pathlib import Path

for i, r in enumerate(RUNS, 1):
    algo = r['algo']
    seed = r['seed']
    ckpt_dir = Path(r['ckpt_dir'])
    result_dir = Path(r['result_dir'])
    test_json = result_dir / 'test_result.json'
    ckpt_dir_str = str(ckpt_dir)
    test_json_str = str(test_json)
    MFST = r['manifest']

    print(f'\n========== [{i}/{len(RUNS)}] eval {algo} seed={seed} ==========')

    if test_json.exists():
        print(f'[skip] test_result.json exists: {test_json}')
        continue
    if not (ckpt_dir / 'agent_final.pt').exists():
        print(f'[skip] no agent_final.pt at {ckpt_dir} (training not done?)')
        continue

    result_dir.mkdir(parents=True, exist_ok=True)

    # rev.3: Jupyter !python magic for real-time streaming (was os.system in rev.2).
    # rev.3.1 (Bug 5 fix): single-quote {ckpt_dir_str} / {test_json_str} because
    #   Colab path `/content/drive/MyDrive/Colab Notebooks/...` has a SPACE — without
    #   quotes the shell splits the arg and argparse rejects the tail as positional.
    # evaluate_offline auto-dispatches via trainer_state.json (no per-algo branching).
    # !python -m scripts.evaluate_offline \
        --checkpoint '{ckpt_dir_str}' \
        --agent-file agent_final.pt \
        --manifest {MFST} \
        --episodes 100 \
        --seed 123 \
        --device cuda \
        --num-workers 4 \
        --worker-device cpu \
        --output-json '{test_json_str}'

    if test_json.exists():
        print(f'[done] {test_json}')
    else:
        print(f'[FAIL] {algo} seed={seed} test_result.json missing after eval')
        break
# Out:
# ========== [1/4] eval rebrac seed=42 ==========
# [skip] test_result.json exists: /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5/results/offline/fql_succession/gate_b/rebrac_e_uni_seed42/test_result.json
#
# ========== [2/4] eval fql seed=42 ==========
# [skip] test_result.json exists: /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5/results/offline/fql_succession/gate_b/fql_e_uni_seed42/test_result.json
#
# ========== [3/4] eval rebrac seed=0 ==========
# reward_objective      : arrival_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.000000
# episodes              : 30
# success_rate          : 86.7%
# avg_return            : 97.14 +/- 109.13
# avg_safety_cost       : 3.972 +/- 4.628
# avg_time_s            : 44.01 +/- 10.44
# avg_time_s_success    : 41.73
# avg_energy            : 34252.86 +/- 8269.30
# avg_path_length_m     : 48.17 +/- 8.05
# avg_progress_ratio    : 0.887 +/- 0.059
# avg_path_efficiency   : 0.815 +/- 0.142
# termination           : {'goal': 26, 'out_of_bounds': 4}
# benchmark_manifest    : benchmarks/single_u10_cross_tgt15.json
# [done] /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5/results/offline/fql_succession/gate_b/rebrac_e_uni_seed0/test_result.json
#
# ========== [4/4] eval fql seed=0 ==========
# reward_objective      : arrival_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.000000
# episodes              : 30
# success_rate          : 70.0%
# avg_return            : 45.43 +/- 144.09
# avg_safety_cost       : 4.593 +/- 3.847
# avg_time_s            : 43.67 +/- 8.51
# avg_time_s_success    : 39.99
# avg_energy            : 33827.95 +/- 6749.02
# avg_path_length_m     : 48.08 +/- 7.06
# avg_progress_ratio    : 0.857 +/- 0.096
# avg_path_efficiency   : 0.788 +/- 0.161
# termination           : {'out_of_bounds': 9, 'goal': 21}
# benchmark_manifest    : benchmarks/single_u10_cross_tgt15.json
# [done] /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5/results/offline/fql_succession/gate_b/fql_e_uni_seed0/test_result.json

# %% [markdown]
# ## 3.5 Archive in-training eval_log.csv → results/
#
# Gate B c1 (last 3 eval mean) + c4 (last 30% monotonicity) 都依赖 `eval_log.csv`。`eval_log.csv` 由训练写入 checkpoint dir，但 checkpoint dir 是 gitignored —— 把它 copy 到 `results/` 一份，sync 回 git 留痕。

# %%
import shutil
for r in RUNS:
    src = Path(r['ckpt_dir']) / 'eval_log.csv'
    dst = Path(r['result_dir']) / 'eval_log.csv'
    if not src.exists():
        print(f'[noop] {src} missing (training not done)')
        continue
    dst.parent.mkdir(parents=True, exist_ok=True)
    shutil.copy2(src, dst)
    print(f'[archive] {src} → {dst}')
# Out:
# [archive] /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5/checkpoints/offline/fql_succession/gate_b/rebrac_e_uni_seed42/eval_log.csv → /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5/results/offline/fql_succession/gate_b/rebrac_e_uni_seed42/eval_log.csv
# [archive] /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5/checkpoints/offline/fql_succession/gate_b/fql_e_uni_seed42/eval_log.csv → /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5/results/offline/fql_succession/gate_b/fql_e_uni_seed42/eval_log.csv
# [archive] /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5/checkpoints/offline/fql_succession/gate_b/rebrac_e_uni_seed0/eval_log.csv → /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5/results/offline/fql_succession/gate_b/rebrac_e_uni_seed0/eval_log.csv
# [archive] /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5/checkpoints/offline/fql_succession/gate_b/fql_e_uni_seed0/eval_log.csv → /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5/results/offline/fql_succession/gate_b/fql_e_uni_seed0/eval_log.csv

# %% [markdown]
# ## 4. Raw diagnostic — test_result.json 字段 + eval_log.csv 末 3 行 + train_log.jsonl 末 5 行
#
# 在跑 §5 verdict 前打印 raw 数字，便于排查 verdict 出 bug 时定位是哪一步出问题。

# %%
import csv
import json

for r in RUNS:
    print(f'\n=== {r["algo"]} seed={r["seed"]} ===')

    # 4a. test_result.json (final 100-ep eval)
    test_json = Path(r['result_dir']) / 'test_result.json'
    print(f'\n[a] test_result.json @ {test_json}')
    if not test_json.exists():
        print('  MISSING')
    else:
        d = json.loads(test_json.read_text())
        for k in sorted(d.keys()):
            v = d[k]
            if isinstance(v, (int, float, str, bool, type(None))):
                print(f'  {k}: {v}')
            elif isinstance(v, list):
                print(f'  {k}: list(len={len(v)})')
            elif isinstance(v, dict):
                print(f'  {k}: dict(keys={list(v.keys())[:5]}{"..." if len(v) > 5 else ""})')

    # 4b. eval_log.csv 末 3 行
    eval_csv = Path(r['result_dir']) / 'eval_log.csv'
    if not eval_csv.exists():
        eval_csv = Path(r['ckpt_dir']) / 'eval_log.csv'
    print(f'\n[b] eval_log.csv (last 3) @ {eval_csv}')
    if not eval_csv.exists():
        print('  MISSING')
    else:
        with eval_csv.open() as fp:
            rows = list(csv.DictReader(fp))
        for row in rows[-3:]:
            step = row.get('train_step', '?')
            succ = row.get('eval_success_rate', '?')
            ret_ = row.get('eval_return', '?')
            prog = row.get('eval_progress_ratio', '?')
            print(f'  step={step}  success={succ}  return={ret_}  progress={prog}')

    # 4c. train_log.jsonl 末 5 行（FQL 看 loss_flow，ReBRAC 看 loss_actor）
    train_jsonl = Path(r['ckpt_dir']) / 'train_log.jsonl'
    print(f'\n[c] train_log.jsonl (last 5) @ {train_jsonl}')
    if not train_jsonl.exists():
        print('  MISSING')
    else:
        with train_jsonl.open() as fp:
            lines = fp.readlines()
        for line in lines[-5:]:
            row = json.loads(line)
            step = row.get('train_step', '?')
            keys_of_interest = ['critic_loss', 'actor_loss', 'bc_loss', 'mean_q', 'lambda',
                                 'loss_flow', 'td_abs_error', 'critic_penalty']
            vals = ' '.join(
                f'{k}={row[k]:.4f}' if isinstance(row.get(k), (int, float)) else ''
                for k in keys_of_interest if k in row
            )
            print(f'  step={step}  {vals.strip()}')
# Out:
# === rebrac seed=42 ===
#
# [a] test_result.json @ /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5/results/offline/fql_succession/gate_b/rebrac_e_uni_seed42/test_result.json
#   energy_cost_gain: 0.0
#   eval_cost: 5.116436818315553
#   eval_cost_std: 4.167896057910432
#   eval_energy: 36358.532245120776
#   eval_energy_std: 12702.883196123963
#   eval_energy_success: 32818.245860246425
#   eval_episode_results: list(len=30)
#   eval_manifest_flow_path: wake_data/wake_v8_U1p00_Re150_D12p00_dx0p60_Ti5pct_1200f_roi.npy
#   eval_path_efficiency: 0.7203049725691424
#   eval_path_efficiency_std: 0.2262267744265688
#   eval_path_length_m: 52.4364250001808
#   eval_path_length_m_std: 14.293157153631395
#   eval_path_length_success: 47.20815257392824
#   eval_progress_ratio: 0.8229818937298737
#   eval_progress_ratio_std: 0.17138001711891038
#   eval_return: 31.90033046591861
#   eval_return_std: 152.6415453324755
#   eval_safety_cost: 5.116436818315553
#   eval_safety_cost_std: 4.167896057910432
#   eval_success_rate: 0.6666666666666666
#   eval_termination_counts: dict(keys=['out_of_bounds', 'goal'])
#   eval_time_s: 46.57666666666692
#   eval_time_s_std: 15.918389435561998
#   eval_time_s_success: 42.1900000000003
#   num_eval_episodes: 30.0
#   reward_objective: arrival_v2
#   safety_cost_gain: 0.0
#
# [b] eval_log.csv (last 3) @ /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5/results/offline/fql_succession/gate_b/rebrac_e_uni_seed42/eval_log.csv
#   step=180000  success=0.5666666666666667  return=-1.2265250678631778  progress=0.8111536556007556
#   step=190000  success=0.6666666666666666  return=29.462109861793845  progress=0.8033871534952671
#   step=200000  success=0.6666666666666666  return=31.90033046591861  progress=0.8229818937298737
#
# [c] train_log.jsonl (last 5) @ /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5/checkpoints/offline/fql_succession/gate_b/rebrac_e_uni_seed42/train_log.jsonl
#   step=196000  critic_loss=0.7656 actor_loss=-0.9385 bc_loss=0.0096 mean_q=71.4911 lambda=0.0137 td_abs_error=0.6401 critic_penalty=0.0833
#   step=197000  critic_loss=24.6825 actor_loss=-0.9862 bc_loss=0.0034 mean_q=73.6729 lambda=0.0136 td_abs_error=0.8821 critic_penalty=0.0918
#   step=198000  critic_loss=0.7143 actor_loss=-0.9751 bc_loss=0.0008 mean_q=71.5395 lambda=0.0137 td_abs_error=0.6018 critic_penalty=0.0866
#   step=199000  critic_loss=0.5225 actor_loss=-0.9925 bc_loss=0.0019 mean_q=74.0693 lambda=0.0135 td_abs_error=0.5248 critic_penalty=0.0586
#   step=200000  critic_loss=0.5634 actor_loss=-0.9923 bc_loss=0.0019 mean_q=73.9926 lambda=0.0135 td_abs_error=0.6009 critic_penalty=0.0783
#
# === fql seed=42 ===
#
# [a] test_result.json @ /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5/results/offline/fql_succession/gate_b/fql_e_uni_seed42/test_result.json
#   energy_cost_gain: 0.0
#   eval_cost: 6.483262808909441
#   eval_cost_std: 6.136030813257916
#   eval_energy: 36990.73852777572
#   eval_energy_std: 12630.84370941599
#   eval_energy_success: 35156.40004008208
#   eval_episode_results: list(len=30)
#   eval_manifest_flow_path: wake_data/wake_v8_U1p00_Re150_D12p00_dx0p60_Ti5pct_1200f_roi.npy
#   eval_path_efficiency: 0.6764088566227406
#   eval_path_efficiency_std: 0.2675792832392194
#   eval_path_length_m: 53.33592117726803
#   eval_path_length_m_std: 15.394085248537907
#   eval_path_length_success: 48.2370215440169
#   eval_progress_ratio: 0.7480572720694575
#   eval_progress_ratio_std: 0.3952552513327146
#   eval_return: -16.575771563268283
#   eval_return_std: 171.62754692162528
#   eval_safety_cost: 6.483262808909441
#   eval_safety_cost_std: 6.136030813257916
#   eval_success_rate: 0.5333333333333333
#   eval_termination_counts: dict(keys=['goal', 'out_of_bounds'])
#   eval_time_s: 47.280000000000236
#   eval_time_s_std: 15.55035690908701
#   eval_time_s_success: 45.225000000000236
#   num_eval_episodes: 30.0
#   reward_objective: arrival_v2
#   safety_cost_gain: 0.0
#
# [b] eval_log.csv (last 3) @ /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5/results/offline/fql_succession/gate_b/fql_e_uni_seed42/eval_log.csv
#   step=180000  success=0.7666666666666667  return=56.53919876782747  progress=0.7514911387914497
#   step=190000  success=0.7666666666666667  return=47.32217069679473  progress=0.5955803676384065
#   step=200000  success=0.5333333333333333  return=-16.575771563268283  progress=0.7480572720694575
#
# [c] train_log.jsonl (last 5) @ /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5/checkpoints/offline/fql_succession/gate_b/fql_e_uni_seed42/train_log.jsonl
#   step=196000  critic_loss=0.3121 actor_loss=-0.9949 bc_loss=0.0051 mean_q=80.7403 lambda=0.0124 loss_flow=0.0354 td_abs_error=0.3917
#   step=197000  critic_loss=0.3917 actor_loss=-0.9737 bc_loss=0.0057 mean_q=79.2983 lambda=0.0124 loss_flow=0.0271 td_abs_error=0.4424
#   step=198000  critic_loss=0.6960 actor_loss=-0.9924 bc_loss=0.0076 mean_q=80.5086 lambda=0.0124 loss_flow=0.0089 td_abs_error=0.5048
#   step=199000  critic_loss=320.8339 actor_loss=-0.9774 bc_loss=0.0078 mean_q=79.0765 lambda=0.0125 loss_flow=0.0160 td_abs_error=1.5585
#   step=200000  critic_loss=0.4153 actor_loss=-0.9746 bc_loss=0.0145 mean_q=81.1151 lambda=0.0122 loss_flow=0.0235 td_abs_error=0.4547
#
# === rebrac seed=0 ===
#
# [a] test_result.json @ /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5/results/offline/fql_succession/gate_b/rebrac_e_uni_seed0/test_result.json
#   energy_cost_gain: 0.0
#   eval_cost: 3.9721890342176085
#   eval_cost_std: 4.628337167712534
#   eval_energy: 34252.860189130915
#   eval_energy_std: 8269.298337779404
#   eval_energy_success: 32444.637730192182
#   eval_episode_results: list(len=30)
#   eval_manifest_flow_path: wake_data/wake_v8_U1p00_Re150_D12p00_dx0p60_Ti5pct_1200f_roi.npy
#   eval_path_efficiency: 0.8146227038852895
#   eval_path_efficiency_std: 0.14175572549365464
#   eval_path_length_m: 48.16515757665038
#   eval_path_length_m_std: 8.048278564568257
#   eval_path_length_success: 45.92206973783099
#   eval_progress_ratio: 0.8872623459047522
#   eval_progress_ratio_std: 0.05852275457915523
#   eval_return: 97.13850287997674
#   eval_return_std: 109.13375789321368
#   eval_safety_cost: 3.9721890342176085
#   eval_safety_cost_std: 4.628337167712534
#   eval_success_rate: 0.8666666666666667
#   eval_termination_counts: dict(keys=['goal', 'out_of_bounds'])
#   eval_time_s: 44.01000000000033
#   eval_time_s_std: 10.438785050633758
#   eval_time_s_success: 41.73461538461571
#   num_eval_episodes: 30.0
#   reward_objective: arrival_v2
#   safety_cost_gain: 0.0
#
# [b] eval_log.csv (last 3) @ /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5/results/offline/fql_succession/gate_b/rebrac_e_uni_seed0/eval_log.csv
#   step=180000  success=0.9666666666666667  return=128.96985301069725  progress=0.8993900374286913
#   step=190000  success=0.9  return=104.96197375541216  progress=0.8536572453974622
#   step=200000  success=0.8666666666666667  return=97.13850287997674  progress=0.8872623459047522
#
# [c] train_log.jsonl (last 5) @ /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5/checkpoints/offline/fql_succession/gate_b/rebrac_e_uni_seed0/train_log.jsonl
#   step=196000  critic_loss=0.6691 actor_loss=-0.9669 bc_loss=0.0083 mean_q=73.5134 lambda=0.0136 td_abs_error=0.6116 critic_penalty=0.0789
#   step=197000  critic_loss=0.5984 actor_loss=-0.9513 bc_loss=0.0006 mean_q=70.1227 lambda=0.0136 td_abs_error=0.5670 critic_penalty=0.0763
#   step=198000  critic_loss=0.5250 actor_loss=-0.9412 bc_loss=0.0033 mean_q=70.9100 lambda=0.0135 td_abs_error=0.5139 critic_penalty=0.0655
#   step=199000  critic_loss=0.6134 actor_loss=-0.9760 bc_loss=0.0010 mean_q=73.7831 lambda=0.0133 td_abs_error=0.5790 critic_penalty=0.0661
#   step=200000  critic_loss=0.8684 actor_loss=-0.9818 bc_loss=0.0046 mean_q=74.1897 lambda=0.0135 td_abs_error=0.5629 critic_penalty=0.0692
#
# === fql seed=0 ===
#
# [a] test_result.json @ /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5/results/offline/fql_succession/gate_b/fql_e_uni_seed0/test_result.json
#   energy_cost_gain: 0.0
#   eval_cost: 4.5932900717886636
#   eval_cost_std: 3.846993076284098
#   eval_energy: 33827.94598200886
#   eval_energy_std: 6749.021907653538
#   eval_energy_success: 30894.745655430852
#   eval_episode_results: list(len=30)
#   eval_manifest_flow_path: wake_data/wake_v8_U1p00_Re150_D12p00_dx0p60_Ti5pct_1200f_roi.npy
#   eval_path_efficiency: 0.7877433642753974
#   eval_path_efficiency_std: 0.1612179888142648
#   eval_path_length_m: 48.07824539244175
#   eval_path_length_m_std: 7.062107728320413
#   eval_path_length_success: 44.291042354135286
#   eval_progress_ratio: 0.8573818704417419
#   eval_progress_ratio_std: 0.09602223398150221
#   eval_return: 45.42897155106819
#   eval_return_std: 144.08629513680825
#   eval_safety_cost: 4.5932900717886636
#   eval_safety_cost_std: 3.846993076284098
#   eval_success_rate: 0.7
#   eval_termination_counts: dict(keys=['out_of_bounds', 'goal'])
#   eval_time_s: 43.66666666666701
#   eval_time_s_std: 8.507970119573624
#   eval_time_s_success: 39.98571428571457
#   num_eval_episodes: 30.0
#   reward_objective: arrival_v2
#   safety_cost_gain: 0.0
#
# [b] eval_log.csv (last 3) @ /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5/results/offline/fql_succession/gate_b/fql_e_uni_seed0/eval_log.csv
#   step=180000  success=0.7  return=40.51379118210553  progress=0.8155381391559305
#   step=190000  success=0.9  return=105.68872956170968  progress=0.861314267394919
#   step=200000  success=0.7  return=45.42897155106819  progress=0.8573818704417419
#
# [c] train_log.jsonl (last 5) @ /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5/checkpoints/offline/fql_succession/gate_b/fql_e_uni_seed0/train_log.jsonl
#   step=196000  critic_loss=0.4541 actor_loss=-0.9745 bc_loss=0.0058 mean_q=79.2345 lambda=0.0124 loss_flow=0.0395 td_abs_error=0.4733
#   step=197000  critic_loss=0.3336 actor_loss=-0.9862 bc_loss=0.0138 mean_q=81.1134 lambda=0.0123 loss_flow=0.0398 td_abs_error=0.4171
#   step=198000  critic_loss=0.3611 actor_loss=-0.9489 bc_loss=0.0130 mean_q=77.7296 lambda=0.0124 loss_flow=0.0155 td_abs_error=0.4209
#   step=199000  critic_loss=0.5597 actor_loss=-0.9893 bc_loss=0.0107 mean_q=78.7940 lambda=0.0127 loss_flow=0.0176 td_abs_error=0.4742
#   step=200000  critic_loss=0.5499 actor_loss=-0.9770 bc_loss=0.0022 mean_q=78.9525 lambda=0.0124 loss_flow=0.0580 td_abs_error=0.4903

# %% [markdown]
# ## 5. Gate B verdict — 4 criteria (rev.2: 2-seed aggregated + log dedup)
#
# 判据来源 spec §5.3（pre-registered）；rev.2 扩展为多 seed aggregation。
#
# **rev.2 关键改动 (Bug 1 fix)**：本 cell 加 `_dedup_by_train_step()` helper，对 `eval_log.csv` / `train_log.jsonl` 按 `train_step` 去重，**保留最后一次出现**（last write wins）。这修复 rev.1 因 train script append-mode + skip-resume race 导致的跨 run 拼接污染（rev.1 FQL seed=42 eval log 38 行实际是同一 seed 两次 run 拼接）。
#
# | # | 指标 | 数据源 | 通过条件 (across-seed mean) |
# |---|---|---|---|
# | c1 | FQL last-3-eval success mean | `eval_log.csv` 末 3 行 dedup 后 `eval_success_rate` mean | ≥ ReBRAC same − 0.08 |
# | c2 | FQL loss_flow 末段 | `train_log.jsonl` 末 5% 行 dedup 后 `loss_flow` mean | < 0.05 |
# | c3 | FQL actor_loss 末段 OOM | `train_log.jsonl` 末 5% 行 dedup 后 `actor_loss` mean | vs ReBRAC same，比值在 [0.1, 10] |
# | c4 | FQL eval 曲线 monotonicity | `eval_log.csv` 末 30% 行 dedup 后 `eval_success_rate` 线性 slope | slope ≥ 0 |
#
# **Aggregation**：每个 seed 单独算 4 个指标 → 同 algo 跨 seed mean → 应用阈值。
#
# **4 条全过 → Gate B PASS → 进入 P2 main comparison spec**。任一失败 → 按 spec §5.3 + interim report §8 mitigation 处理。

# %%
import csv
import json
import math
import statistics
from collections import defaultdict


def _dedup_by_train_step(rows, key='train_step'):
    """Bug 1 fix: keep the last occurrence per train_step (handles append-mode contamination
    from re-runs where the training script appended to existing logs without truncation).
    Returns rows sorted by train_step ascending.
    """
    seen = {}
    for row in rows:
        try:
            step = int(float(row.get(key, -1)))
        except (TypeError, ValueError):
            continue
        seen[step] = row  # last write wins
    return [seen[s] for s in sorted(seen.keys())]


def _load_eval_log(run):
    """Return dedup-by-train_step list of dicts from eval_log.csv."""
    for candidate in [Path(run['result_dir']) / 'eval_log.csv',
                       Path(run['ckpt_dir']) / 'eval_log.csv']:
        if candidate.exists():
            with candidate.open() as fp:
                rows = list(csv.DictReader(fp))
            return _dedup_by_train_step(rows)
    return []


def _load_train_jsonl(run):
    path = Path(run['ckpt_dir']) / 'train_log.jsonl'
    if not path.exists():
        return []
    with path.open() as fp:
        rows = [json.loads(line) for line in fp if line.strip()]
    return _dedup_by_train_step(rows)


def _safe_float(x):
    try:
        f = float(x)
        return None if math.isnan(f) else f
    except (TypeError, ValueError):
        return None


def _linear_slope(ys):
    n = len(ys)
    if n < 2:
        return 0.0
    xs = list(range(n))
    mean_x = sum(xs) / n
    mean_y = sum(ys) / n
    num = sum((x - mean_x) * (y - mean_y) for x, y in zip(xs, ys))
    den = sum((x - mean_x) ** 2 for x in xs)
    return num / den if den > 0 else 0.0


def _per_seed_metrics(run):
    eval_rows = _load_eval_log(run)
    train_rows = _load_train_jsonl(run)

    succ_traj = [_safe_float(row.get('eval_success_rate')) for row in eval_rows]
    succ_traj = [s for s in succ_traj if s is not None]
    last3_mean = statistics.mean(succ_traj[-3:]) if len(succ_traj) >= 3 else (
        statistics.mean(succ_traj) if succ_traj else float('nan'))
    last30pct_idx = max(1, int(0.7 * len(succ_traj)))
    last30pct_slope = _linear_slope(succ_traj[last30pct_idx:]) if succ_traj else 0.0

    # 末段 = 末 5% rows of (dedup'd) train_log.jsonl
    tail_n = max(1, int(0.05 * len(train_rows)))
    tail = train_rows[-tail_n:]
    loss_flow_tail = [_safe_float(row.get('loss_flow')) for row in tail]
    loss_flow_tail = [v for v in loss_flow_tail if v is not None]
    actor_loss_tail = [_safe_float(row.get('actor_loss')) for row in tail]
    actor_loss_tail = [v for v in actor_loss_tail if v is not None]

    return {
        'seed': run['seed'],
        'n_eval_points_dedup': len(succ_traj),
        'eval_success_trajectory': succ_traj,
        'last3_eval_success_mean': last3_mean,
        'last30pct_eval_slope': last30pct_slope,
        'n_train_log_rows_dedup': len(train_rows),
        'loss_flow_last_5pct_mean': statistics.mean(loss_flow_tail) if loss_flow_tail else float('nan'),
        'actor_loss_last_5pct_mean': statistics.mean(actor_loss_tail) if actor_loss_tail else float('nan'),
    }


# ---- Extract per-seed metrics, then aggregate by algo ----
per_algo = defaultdict(dict)
for r in RUNS:
    per_algo[r['algo']][r['seed']] = _per_seed_metrics(r)


def _agg(values):
    """Across-seed mean over non-nan values; nan if all missing."""
    clean = [v for v in values if not (isinstance(v, float) and math.isnan(v))]
    return statistics.mean(clean) if clean else float('nan')


agg_by_algo = {}
for algo, by_seed in per_algo.items():
    seeds = sorted(by_seed.keys())
    agg_by_algo[algo] = {
        'seeds': seeds,
        'n_seeds': len(seeds),
        'last3_mean': _agg([by_seed[s]['last3_eval_success_mean'] for s in seeds]),
        'last30pct_slope_mean': _agg([by_seed[s]['last30pct_eval_slope'] for s in seeds]),
        'loss_flow_mean': _agg([by_seed[s]['loss_flow_last_5pct_mean'] for s in seeds]),
        'actor_loss_mean': _agg([by_seed[s]['actor_loss_last_5pct_mean'] for s in seeds]),
    }


# ---- Pretty-print per-seed + per-algo ----
print('=' * 110)
print('Gate B raw inputs (per-seed, dedup applied):')
for algo in ['rebrac', 'fql']:
    print(f'\n  {algo}:')
    for seed, s in sorted(per_algo[algo].items()):
        print(f'    seed={seed}:')
        print(f'      n_eval_points_dedup    = {s["n_eval_points_dedup"]}')
        print(f'      last3_eval_success     = {s["last3_eval_success_mean"]:.4f}')
        print(f'      last30pct_eval_slope   = {s["last30pct_eval_slope"]:+.5f}')
        print(f'      n_train_log_rows_dedup = {s["n_train_log_rows_dedup"]}')
        print(f'      loss_flow_last_5pct    = {s["loss_flow_last_5pct_mean"]:.4f}')
        print(f'      actor_loss_last_5pct   = {s["actor_loss_last_5pct_mean"]:+.4f}')

print('\n' + '=' * 110)
print('Gate B aggregated (per-algo across-seed mean):')
for algo in ['rebrac', 'fql']:
    a = agg_by_algo[algo]
    print(f'\n  {algo} ({a["n_seeds"]} seeds {a["seeds"]}):')
    print(f'    last3_mean           = {a["last3_mean"]:.4f}')
    print(f'    last30pct_slope_mean = {a["last30pct_slope_mean"]:+.5f}')
    print(f'    loss_flow_mean       = {a["loss_flow_mean"]:.4f}')
    print(f'    actor_loss_mean      = {a["actor_loss_mean"]:+.4f}')


# ---- Apply Gate B criteria on aggregated values ----
rebrac = agg_by_algo.get('rebrac', {})
fql = agg_by_algo.get('fql', {})

rebrac_last3 = rebrac.get('last3_mean', float('nan'))
fql_last3 = fql.get('last3_mean', float('nan'))
fql_loss_flow = fql.get('loss_flow_mean', float('nan'))
fql_actor_loss = fql.get('actor_loss_mean', float('nan'))
rebrac_actor_loss = rebrac.get('actor_loss_mean', float('nan'))
fql_slope = fql.get('last30pct_slope_mean', 0.0)

# c1: FQL last-3 ≥ ReBRAC last-3 − 0.08
c1_pass = (fql_last3 >= rebrac_last3 - 0.08) if not (math.isnan(fql_last3) or math.isnan(rebrac_last3)) else False
c1_gap = fql_last3 - rebrac_last3

# c2: FQL loss_flow < 0.05
c2_pass = (fql_loss_flow < 0.05) if not math.isnan(fql_loss_flow) else False

# c3: FQL/ReBRAC actor_loss within ±1 OOM
if not math.isnan(fql_actor_loss) and not math.isnan(rebrac_actor_loss) and abs(rebrac_actor_loss) > 1e-9:
    ratio = abs(fql_actor_loss) / abs(rebrac_actor_loss)
    c3_pass = (0.1 <= ratio <= 10.0)
else:
    ratio = float('nan')
    c3_pass = False

# c4: FQL last 30% eval slope ≥ 0
c4_pass = fql_slope >= 0

verdict_block = {
    'c1_last3_parity': {
        'fql_last3_mean': fql_last3, 'rebrac_last3_mean': rebrac_last3,
        'gap_fql_minus_rebrac': c1_gap,
        'threshold': -0.08, 'pass': bool(c1_pass),
    },
    'c2_loss_flow_converged': {
        'fql_loss_flow_mean': fql_loss_flow,
        'threshold': 0.05, 'pass': bool(c2_pass),
    },
    'c3_actor_loss_oom_parity': {
        'fql_actor_loss_mean': fql_actor_loss,
        'rebrac_actor_loss_mean': rebrac_actor_loss,
        'abs_ratio_fql_over_rebrac': ratio,
        'threshold': '[0.1, 10.0]', 'pass': bool(c3_pass),
    },
    'c4_eval_monotonicity_last_30pct': {
        'fql_slope_mean': fql_slope, 'threshold': 0.0, 'pass': bool(c4_pass),
    },
    'overall_pass': bool(c1_pass and c2_pass and c3_pass and c4_pass),
}

summary = {
    'per_seed': {algo: per_algo[algo] for algo in per_algo},
    'aggregated': agg_by_algo,
    'verdict': verdict_block,
    'notes': {
        'bug1_dedup_applied': True,
        'bug2_caveat': 'eval used manifest size (30 ep) instead of CLI --episodes 100; CI ±8.4pp/eval',
        'aggregation': 'per-algo mean across seeds; verdict on aggregated mean (looser than per-seed AND)',
    },
}

print('\n' + '=' * 110)
print('Gate B verdict:')
print(f'  c1 last-3 parity:        FQL={fql_last3:.4f} vs ReBRAC={rebrac_last3:.4f} '
      f'(Δ={c1_gap:+.4f}, threshold ≥ −0.08) → {"PASS" if c1_pass else "FAIL"}')
print(f'  c2 loss_flow converged:  FQL loss_flow={fql_loss_flow:.4f} '
      f'(threshold < 0.05) → {"PASS" if c2_pass else "FAIL"}')
print(f'  c3 actor_loss OOM:       |FQL|/|ReBRAC|={ratio:.3f} '
      f'(threshold ∈ [0.1, 10]) → {"PASS" if c3_pass else "FAIL"}')
print(f'  c4 monotonicity:         FQL last-30% slope_mean={fql_slope:+.5f} '
      f'(threshold ≥ 0) → {"PASS" if c4_pass else "FAIL"}')
print()
print(f'  OVERALL: {"Gate B PASS" if verdict_block["overall_pass"] else "Gate B FAIL"}')

# ---- Write verdict + overview to results/ ----
verdict_path = SUMMARIES_DIR / 'gate_b_verdict.json'
verdict_path.write_text(json.dumps(summary, indent=2, default=str))
print(f'\n[wrote] {verdict_path}')

csv_path = SUMMARIES_DIR / 'gate_b_overview.csv'
with csv_path.open('w', newline='') as fp:
    w = csv.writer(fp)
    w.writerow(['algo', 'seed', 'last3_eval_success_mean', 'last30pct_eval_slope',
                 'loss_flow_last_5pct_mean', 'actor_loss_last_5pct_mean', 'n_eval_points_dedup'])
    for algo in ['rebrac', 'fql']:
        for seed in sorted(per_algo[algo].keys()):
            s = per_algo[algo][seed]
            w.writerow([algo, seed,
                         f'{s["last3_eval_success_mean"]:.4f}',
                         f'{s["last30pct_eval_slope"]:+.5f}',
                         f'{s["loss_flow_last_5pct_mean"]:.4f}',
                         f'{s["actor_loss_last_5pct_mean"]:+.4f}',
                         s['n_eval_points_dedup']])
    # Append aggregated row per algo
    for algo in ['rebrac', 'fql']:
        a = agg_by_algo[algo]
        w.writerow([algo, f'mean({a["seeds"]})',
                     f'{a["last3_mean"]:.4f}',
                     f'{a["last30pct_slope_mean"]:+.5f}',
                     f'{a["loss_flow_mean"]:.4f}',
                     f'{a["actor_loss_mean"]:+.4f}',
                     '—'])
print(f'[wrote] {csv_path}')
# Out:
# ==============================================================================================================
# Gate B raw inputs (per-seed, dedup applied):
#
#   rebrac:
#     seed=0:
#       n_eval_points_dedup    = 20
#       last3_eval_success     = 0.9111
#       last30pct_eval_slope   = +0.01429
#       n_train_log_rows_dedup = 201
#       loss_flow_last_5pct    = nan
#       actor_loss_last_5pct   = -0.9670
#     seed=42:
#       n_eval_points_dedup    = 20
#       last3_eval_success     = 0.6333
#       last30pct_eval_slope   = -0.01333
#       n_train_log_rows_dedup = 201
#       loss_flow_last_5pct    = nan
#       actor_loss_last_5pct   = -0.9669
#
#   fql:
#     seed=0:
#       n_eval_points_dedup    = 20
#       last3_eval_success     = 0.7667
#       last30pct_eval_slope   = +0.02286
#       n_train_log_rows_dedup = 201
#       loss_flow_last_5pct    = 0.0302
#       actor_loss_last_5pct   = -0.9740
#     seed=42:
#       n_eval_points_dedup    = 20
#       last3_eval_success     = 0.6889
#       last30pct_eval_slope   = -0.03048
#       n_train_log_rows_dedup = 201
#       loss_flow_last_5pct    = 0.0227
#       actor_loss_last_5pct   = -0.9814
#
# ==============================================================================================================
# Gate B aggregated (per-algo across-seed mean):
#
#   rebrac (2 seeds [0, 42]):
#     last3_mean           = 0.7722
#     last30pct_slope_mean = +0.00048
#     loss_flow_mean       = nan
#     actor_loss_mean      = -0.9669
#
#   fql (2 seeds [0, 42]):
#     last3_mean           = 0.7278
#     last30pct_slope_mean = -0.00381
#     loss_flow_mean       = 0.0264
#     actor_loss_mean      = -0.9777
#
# ==============================================================================================================
# Gate B verdict:
#   c1 last-3 parity:        FQL=0.7278 vs ReBRAC=0.7722 (Δ=-0.0444, threshold ≥ −0.08) → PASS
#   c2 loss_flow converged:  FQL loss_flow=0.0264 (threshold < 0.05) → PASS
#   c3 actor_loss OOM:       |FQL|/|ReBRAC|=1.011 (threshold ∈ [0.1, 10]) → PASS
#   c4 monotonicity:         FQL last-30% slope_mean=-0.00381 (threshold ≥ 0) → FAIL
#
#   OVERALL: Gate B FAIL
#
# [wrote] /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5/results/offline/fql_succession/gate_b/summaries/gate_b_verdict.json
# [wrote] /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5/results/offline/fql_succession/gate_b/summaries/gate_b_overview.csv

# %% [markdown]
# ## 5.5 Final 100-ep test_result.json side-by-side (供 paper anchor 引用)
#
# Gate B 判据 c1 用的是 in-training last-3 eval mean（spec §5.3 强调避免 single-shot fluctuation）。但 paper 写作时通常 cite **single canonical final-eval number**——把 §3 写入的 `test_result.json` 也列出来便于参考。

# %%
import json
print('=' * 100)
print(f'{"algo":<8} {"seed":>5} {"success":>10} {"return":>10} {"safety":>10} {"prog":>10} {"path_eff":>10}')
print('-' * 100)
for r in RUNS:
    test_json = Path(r['result_dir']) / 'test_result.json'
    if not test_json.exists():
        print(f'{r["algo"]:<8} {r["seed"]:>5} MISSING')
        continue
    d = json.loads(test_json.read_text())
    # Bug 3 fix: actual field names are eval_* not eval_avg_*
    succ = d.get('eval_success_rate', float('nan'))
    ret_ = d.get('eval_return', float('nan'))
    safety = d.get('eval_safety_cost', float('nan'))
    prog = d.get('eval_progress_ratio', float('nan'))
    path_eff = d.get('eval_path_efficiency', float('nan'))
    print(f'{r["algo"]:<8} {r["seed"]:>5} {succ:>10.4f} {ret_:>10.2f} {safety:>10.3f} {prog:>10.4f} {path_eff:>10.4f}')
print('=' * 100)
print('\nReBRAC anchor reference (broad val v2 N0, crosscomp dataset, 2 seed): 0.850 ± 0.024')
print('FQL Gate B target on this dataset: ≥ ReBRAC last-3 − 0.08 (aggregated across seeds)')
print('Caveat (Bug 2): num_eval_episodes is bounded by manifest (30 ep), not --episodes 100')
# Out:
# ====================================================================================================
# algo      seed    success     return     safety       prog   path_eff
# ----------------------------------------------------------------------------------------------------
# rebrac      42     0.6667      31.90      5.116     0.8230     0.7203
# fql         42     0.5333     -16.58      6.483     0.7481     0.6764
# rebrac       0     0.8667      97.14      3.972     0.8873     0.8146
# fql          0     0.7000      45.43      4.593     0.8574     0.7877
# ====================================================================================================
#
# ReBRAC anchor reference (broad val v2 N0, crosscomp dataset, 2 seed): 0.850 ± 0.024
# FQL Gate B target on this dataset: ≥ ReBRAC last-3 − 0.08 (aggregated across seeds)
# Caveat (Bug 2): num_eval_episodes is bounded by manifest (30 ep), not --episodes 100

# %% [markdown]
# ## 6. 跑完后清单（回到 local）
#
# ### Sync 回 git 仓库（只取 `results/`）
#
# ```bash
# # 在本地 repo root：
# rsync -av '<drive>/results/offline/fql_succession/gate_b/' \
#   results/offline/fql_succession/gate_b/
# ```
#
# 包含：
# - `results/offline/fql_succession/gate_b/{rebrac,fql}_e_uni_seed{42,0}/test_result.json` × 4
# - `results/offline/fql_succession/gate_b/{rebrac,fql}_e_uni_seed{42,0}/eval_log.csv` × 4
# - `results/offline/fql_succession/gate_b/summaries/{gate_b_verdict.json, gate_b_overview.csv}`
#
# **checkpoint 不动**（agent_final.pt 大文件，gitignore；只在 P2 spec 想 reuse seed=42/0 anchor 时回到 Drive）。
#
# ### 后续步骤
#
# 1. **写** `docs/archive/fql_succession/fql_succession_gate_b_report.md`（升级 interim report → final report）：
#    - 4 runs × 2 seed aggregated 数字
#    - 4 criteria verdict + 每 seed 单独 breakdown
#    - 与 broad val v2 N0 anchor 对比（dataset / protocol 差异分析）
#    - 与 rev.1 single-seed interim report 数字对照（验证 Bug 1 fix 实际影响）
# 2. **Verdict-conditional 分支**：
#    - **Gate B aggregated PASS**：升级 `docs/archive/fql_succession/fql_succession_plan_v0.md` 到 v1.1，开始 P2 main comparison spec
#    - **c4 FAIL（双 seed 都呈负 slope）**：systematic 末段不稳定 → Option D (FQL stability ablation：critic LN / tau=0.001 / 100k step / actor warm-up)
#    - **c1 FAIL（FQL << ReBRAC across seeds）**：implementation issue → debug 3 iter；仍失败 STOP (plan v1 R4 mitigation)
#    - **混合 (c4 一 seed fail / 一 seed pass)**：单点 noise，标 caveat 进 P2，做 3-seed extension 看是否复现
# 3. **Bug 2 处理**：决定生成 `single_u10_cross_tgt15_ep100` 大 manifest，或修 `evaluate_offline` 让 `--episodes` 不被 manifest 覆盖；P2 spec 起草时定
# 4. **Spec CLI rename** (deferred)：Task E 闭环后 patch `docs/archive/fql_succession/fql_succession_p0p1_spec.md` §5.1/§5.2 字段名对齐实际代码
# 5. **N0 1000-ep audit**（可选 paper appendix evidence）：Gate B 顺利通过后，用 §Task A audit 工具在 N0 cell 跑 1000-ep audit 作为 paper §appendix evidence
