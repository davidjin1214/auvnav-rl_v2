# %% [markdown]
# # FQL Succession P2 — M-multi-mix (Sub-optimal, Multi-modal)  [PRIMARY CELL]
#
# > Sub-optimal × Multi-modal 矩阵的 **iff claim primary 角**
# >
# > 文档锚点:[`docs/fql_succession_p2_main_spec.md`](../docs/fql_succession_p2_main_spec.md) v1.3 + [`docs/fql_succession_p2_collection_log.md`](../docs/fql_succession_p2_collection_log.md)
# >
# > 参考 notebook 风格:[`notebooks/rebrac_c1_asym_critic_ablation.ipynb`](rebrac_c1_asym_critic_ablation.ipynb)
#
# ## 前传 — Gate B 已知事实
#
# Gate B(P1 finalization 2026-05-12)在 E-uni 上跑 4 run(rebrac + fql × seed [42, 0]),test success Δ_E-uni = -4.4pp(FQL 略低于 ReBRAC,marginal)。P2 在 100-episode test manifest(ep100,Bug 2 fix)下重 collect E-uni + 新 collect M-uni-noise / M-multi-mix,以 12-run primary(3 cell × 2 algo × 2 seed [42, 0])跑完整 iff verdict。
#
# ## 本 notebook scope
#
# - **Cell**:M-multi-mix (Sub-optimal, Multi-modal)  [PRIMARY CELL]
# - **Dataset**:`offline_data/fql_succession/m_multi_mix_50priv_50goal_1000`
# - **Collection**:50% privileged + 50% goalseek 两 policy 在 episode-level mix × 1000 ep total(P2 sprint 0 新 collect via concat_offline_datasets);mean success ≈ 0.83(两 policy 加权)
# - **预期 verdict**:**POSITIVE** — FQL > ReBRAC by ≥5pp 且两 seed 同方向(paper claim 的 iff 主要支撑)
#
# **该 cell 角色**:M-multi-mix 是 paper claim 的 **primary 证据 cell**——sub-optimal(整体 ~83%,两 policy 都 sub-expert)且物理上是 2-policy mixture(multi-modal by construction)。**Audit confirms multi-modal**(A3 p_≥2=0.414 ∈ [0.35, 0.50] marginal band + Δp(≥2) lower CI 0.25 > 0.10 + Welch p ≈ 1.5e-29 < 0.07 ✓)。Paper §results 主表的 **「FQL > ReBRAC iff sub-opt AND multi-modal」** iff claim 的右侧(positive direction)就是这个 cell。
#
# ## 隔离表(本 cell vs 另两 cell)
#
# | Cell | Optimality | Modality | Paper claim 预期 |
# |---|---|---|---|
# | E-uni | optimal (success 0.985) | unimodal (single privileged) | NULL (FQL ≈ ReBRAC) |
# | M-uni-noise | sub-opt (success 0.632) | unimodal (noise-widened, audit advisory) | NULL (FQL ≈ ReBRAC) |
# | **M-multi-mix** ✓ | sub-opt (~0.83 mix) | multi-modal (2-policy, audit confirms) | **POSITIVE** (FQL > ReBRAC ≥5pp) |
#
# ## Verdict 规则(effect-size + 方向一致性 primary,from spec §5.4)
#
# **阈值**:`δ_null = 0.03`(3pp,null band)+ `δ_signal = 0.05`(5pp,signal threshold)+ **gray band [3pp, 5pp]** 或方向不一致 → 加 seed 7 扩 n_seeds=3 再判。
#
# **本 cell 预期 verdict 方向**:`positive` — 若 POSITIVE → paper claim 主结论确证。若 NULL → paper claim 失败,iff 部分(FQL>ReBRAC 在 sub-opt × multi-modal)未被复现 → P2 重审或 paper claim 重写。
#
# | 本 cell verdict | 判定 | 后续 |
# |---|---|---|
# | `Δ ≥ 0.05` AND 两 seed paired diff 均 > 0 | **POSITIVE CONFIRMED** ✓ | 符合 paper claim 预期 |
# | `Δ < 0.03` 或两 seed 方向反 | **NULL** ❌ | paper claim 失败(FQL ≯ ReBRAC on multi-modal)→ sprint 1 重审 |
# | 3pp ≤ \|Δ\| < 5pp 或方向不一致 | **GRAY** | 加 seed 7 扩 n_seeds=3,在 sprint 1 跑 |
#
# **c4 stability monitor**(per spec §5.6,n=2 threshold = -0.01549):aggregated slope = mean of last-30%-eval-pts linregress slope per seed。FQL c4 FAIL → §7 verdict 附 caveat。

# %% [markdown]
# ## 1. 环境 sanity
#
# 确认 Colab L4 + CUDA + Drive 挂载 + `%cd` 进 project root。

# %%
# !nvidia-smi | head -15
# !lscpu | head -10
# Out:
# Thu May 21 12:50:59 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA L4                      Off |   00000000:00:03.0 Off |                    0 |
# | N/A   39C    P8             12W /   72W |       0MiB /  23034MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# Architecture:                            x86_64
# CPU op-mode(s):                          32-bit, 64-bit
# Address sizes:                           46 bits physical, 48 bits virtual
# Byte Order:                              Little Endian
# CPU(s):                                  12
# On-line CPU(s) list:                     0-11
# Vendor ID:                               GenuineIntel
# Model name:                              Intel(R) Xeon(R) CPU @ 2.20GHz
# CPU family:                              6
# Model:                                   85

# %%
import torch
print(f'torch={torch.__version__}  CUDA available={torch.cuda.is_available()}')
if torch.cuda.is_available():
    print(f'device={torch.cuda.get_device_name(0)}')
# Out:
# torch=2.10.0+cu128  CUDA available=True
# device=NVIDIA L4

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=False)
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5'
# !pwd && ls scripts/train_offline.py scripts/evaluate_offline.py
# Out:
# /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5
# /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5
# scripts/evaluate_offline.py  scripts/train_offline.py

# %% [markdown]
# ## 2. 通用配置
#
# 定义 `CELL_ID` / `DATASET` / `FLOW` / `MANIFEST` / `CHECKPOINT_ROOT` / `RESULTS_ROOT` + `REBRAC_FLAGS` / `FQL_FLAGS` + `TRAIN_SEEDS=[42, 0]`(primary,n=2)。Helper 路径函数定义在此处,§4 / §5 / §6 共用。
#
# `CHECKPOINT_ROOT`(大文件,留 Drive)和 `RESULTS_ROOT`(小文件,可 sync 回 local 绘图)**分树存储**(per spec §4.2 D21)。

# %%
import os
import shutil
from pathlib import Path

# ---- per-cell config ----
CELL_ID  = 'm_multi_mix'
DATASET  = 'offline_data/fql_succession/m_multi_mix_50priv_50goal_1000'

# ---- shared (3 notebooks 一致) ----
FLOW     = 'wake_data/wake_v8_U1p00_Re150_D12p00_dx0p60_Ti5pct_1200f_roi.npy'
MANIFEST = 'benchmarks/single_u10_cross_tgt15_ep100.json'

PROBE_LAYOUT   = 's0'
HISTORY_LENGTH = 4
TARGET_SPEED   = 1.5
TASK_GEOMETRY  = 'cross_stream'
OBJECTIVE      = 'arrival_v2'

TOTAL_STEPS    = 200_000
BATCH_SIZE     = 256
EVAL_EVERY     = 10_000
EVAL_EPISODES  = 100
TEST_EPISODES  = 100
EVAL_NUM_WORKERS = 6

# ReBRAC anchor (β1=4.0, β2=2.0) + critic LayerNorm only (Gate B frozen)
REBRAC_FLAGS = (
    '--actor-penalty-coef 4.0 --critic-penalty-coef 2.0 '
    '--critic-layernorm --no-actor-layernorm'
)

# FQL teacher + student distill (Gate B frozen)
FQL_FLAGS = (
    '--flow-steps 10 --distill-alpha-bc 1.0 '
    '--teacher-lr 3e-4 --flow-time-embed-dim 32'
)

# n=2 primary; 扩 n=3 时改为 [42, 0, 7] 并重跑本 notebook
TRAIN_SEEDS = [42, 0]
ALGOS = ['rebrac', 'fql']

# ---- paths ----
CHECKPOINT_ROOT = Path(f'checkpoints/fql_succession/p2/{CELL_ID}')
RESULTS_ROOT    = Path(f'results/fql_succession/p2/{CELL_ID}')
TEST_DIR        = RESULTS_ROOT / 'test'
CURVES_DIR      = RESULTS_ROOT / 'training_curves'

# Mirror these 4 small files from checkpoints → results/training_curves/
MIRROR_FILES = ('train_log.jsonl', 'eval_log.csv', 'trainer_state.json', 'train_config.txt')

def save_dir(algo: str, seed: int) -> Path:
    return CHECKPOINT_ROOT / f'{algo}_seed{seed}'

def test_json(algo: str, seed: int) -> Path:
    return TEST_DIR / f'{algo}_seed{seed}.json'

def mirror_dir(algo: str, seed: int) -> Path:
    return CURVES_DIR / f'{algo}_seed{seed}'

print(f'CELL_ID         = {CELL_ID}')
print(f'DATASET         = {DATASET}')
print(f'CHECKPOINT_ROOT = {CHECKPOINT_ROOT}')
print(f'RESULTS_ROOT    = {RESULTS_ROOT}')
print(f'TRAIN_SEEDS     = {TRAIN_SEEDS}')
print(f'ALGOS           = {ALGOS}  ({len(ALGOS)*len(TRAIN_SEEDS)} runs total)')
# Out:
# CELL_ID         = m_multi_mix
# DATASET         = offline_data/fql_succession/m_multi_mix_50priv_50goal_1000
# CHECKPOINT_ROOT = checkpoints/fql_succession/p2/m_multi_mix
# RESULTS_ROOT    = results/fql_succession/p2/m_multi_mix
# TRAIN_SEEDS     = [42, 0]
# ALGOS           = ['rebrac', 'fql']  (4 runs total)

# %% [markdown]
# ## 3. Pre-flight — dataset / manifest / flow sanity
#
# 在跑 4 run 之前确认:
# 1. **Dataset 路径存在** + `transitions.npz` + `metadata.json` 都 readable
# 2. **`policy_mixture` metadata 符合 cell 定义**(本 cell 期望:至少两个不同 policy(privileged + goalseek)+ episode-level mix)— 这是 Gate C.2 cell-construction integrity check(per spec v1.3 §6.2,不依赖 audit verdict)
# 3. **Manifest + flow 存在**
# 4. **Transition 数量 sanity**(本 cell 期望 ~{n_tx} transitions)
#
# **如果 §3 任一 assert FAIL → 停止,不要进 §4 训练**(可能 dataset 错配)。

# %%
import json
import numpy as np

DATASET_DIR  = Path(DATASET)
TRANSITIONS  = DATASET_DIR / 'transitions.npz'
METADATA     = DATASET_DIR / 'metadata.json'
MANIFEST_P   = Path(MANIFEST)
FLOW_P       = Path(FLOW)

# ---- existence checks ----
for p in [DATASET_DIR, TRANSITIONS, METADATA, MANIFEST_P, FLOW_P]:
    assert p.exists(), f'[FAIL] missing path: {p}'
print('[ok] all 5 required paths exist')

# ---- metadata: policy_mixture sanity (Gate C.2 cell-construction integrity) ----
meta = json.loads(METADATA.read_text())
print(f'\n[metadata] {METADATA}')
for k in ['policy_mixture', 'action_noise_std', 'num_episodes', 'num_transitions',
          'probe_layout', 'task_geometry', 'objective', 'mean_return', 'success_rate']:
    if k in meta:
        v = meta[k]
        if isinstance(v, float):
            print(f'  {k}: {v:.4f}')
        else:
            print(f'  {k}: {v}')

# ---- cell-specific expected check ----
# Expected: policy_mixture ≈ '至少两个不同 policy(privileged + goalseek)+ episode-level mix'
# Expected: action_noise_std ≈ 0.1
# Expected: num_transitions ≈ 138290

n_tx = meta.get('num_transitions', None)
if n_tx is not None:
    assert abs(n_tx - 138290) < 138290 * 0.1, (
        f'[WARN] num_transitions {n_tx} 偏离预期 138290 >10%; '
        f'check dataset path correctness'
    )
    print(f'[ok] num_transitions sanity: {n_tx}')

# ---- transitions.npz key dump ----
with np.load(TRANSITIONS) as data:
    print(f'\n[transitions.npz] keys = {list(data.keys())}')
    for k in data.keys():
        arr = data[k]
        print(f'  {k}: shape={arr.shape}, dtype={arr.dtype}')

# ---- manifest sanity ----
manifest_data = json.loads(MANIFEST_P.read_text())
n_ep_in_manifest = len(manifest_data.get('episodes', []))
print(f'\n[manifest] {MANIFEST_P}  episodes={n_ep_in_manifest}')
assert n_ep_in_manifest >= TEST_EPISODES, (
    f'[FAIL] manifest only has {n_ep_in_manifest} ep, need >= {TEST_EPISODES}')
print(f'[ok] manifest covers >= {TEST_EPISODES} episodes')

print('\n[PRE-FLIGHT PASS] ready to train.')
# Out:
# [ok] all 5 required paths exist
#
# [metadata] offline_data/fql_succession/m_multi_mix_50priv_50goal_1000/metadata.json
#   policy_mixture: [{'policy': 'privileged', 'weight': 1.0}]
#   action_noise_std: 0.1000
#   num_episodes: 1000
#   num_transitions: 138290
#   probe_layout: s0
#   task_geometry: cross_stream
#   objective: arrival_v2
#   mean_return: 48.2727
#   success_rate: 0.8260
# [ok] num_transitions sanity: 138290
#
# [transitions.npz] keys = ['actions', 'behavior_policy_codes', 'costs', 'dones', 'next_actions', 'next_obs', 'next_privileged_obs', 'obs', 'privileged_obs', 'rewards', 'terminal_reason_codes', 'terminateds', 'truncateds']
#   actions: shape=(138290, 2), dtype=float32
#   behavior_policy_codes: shape=(138290,), dtype=int8
#   costs: shape=(138290,), dtype=float32
#   dones: shape=(138290,), dtype=float32
#   next_actions: shape=(138290, 2), dtype=float32
#   next_obs: shape=(138290, 48), dtype=float32
#   next_privileged_obs: shape=(138290, 2), dtype=float32
#   obs: shape=(138290, 48), dtype=float32
#   privileged_obs: shape=(138290, 2), dtype=float32
#   rewards: shape=(138290,), dtype=float32
#   terminal_reason_codes: shape=(138290,), dtype=int8
#   terminateds: shape=(138290,), dtype=float32
#   truncateds: shape=(138290,), dtype=float32
#
# [manifest] benchmarks/single_u10_cross_tgt15_ep100.json  episodes=100
# [ok] manifest covers >= 100 episodes
#
# [PRE-FLIGHT PASS] ready to train.

# %% [markdown]
# ## 4. 训练 — 2 algo × 2 seeds = 4 runs
#
# `!python` magic 实时 stream(per spec Bug 4 mitigation);路径单引号包裹(per Bug 5,handles Colab `Colab Notebooks` Drive 空格)。
#
# **Skip-resume**:`agent_final.pt` 存在则 skip 该 (algo, seed) 训练。**Mirror**:每 run 训完后立刻 mirror 4 个小文件(`train_log.jsonl`, `eval_log.csv`, `trainer_state.json`, `train_config.txt`)到 `results/.../training_curves/`,便于本机 sync 后画 learning curve(per spec §4.2 D21)。
#
# **`--skip-final-eval`**:训练阶段不跑 final eval,由 §5 独立 `evaluate_offline` 跑 100-ep test(per spec §4.2 two-step protocol)。
#
# **预期 wallclock**:每 run ~30-45 min(L4,200k steps + 20 in-training eval pts × 100 ep)。4 runs 串行 ~2-3h。

# %%
import time

t_start_train = time.time()

for algo in ALGOS:
    ALGO_FLAGS = REBRAC_FLAGS if algo == 'rebrac' else FQL_FLAGS
    for seed in TRAIN_SEEDS:
        sd = save_dir(algo, seed)
        sd_str = str(sd)

        if (sd / 'agent_final.pt').exists():
            print(f'[skip-train] {algo} seed={seed} (agent_final.pt exists at {sd})')
            continue

        sd.mkdir(parents=True, exist_ok=True)
        print(f'\n{"=" * 72}')
        print(f'  train {algo} seed={seed} → {sd}')
        print(f'{"=" * 72}')
        t0 = time.time()

        # !python -m scripts.train_offline \
            --algo {algo} \
            --offline-data '{DATASET}/transitions.npz' \
            --flow '{FLOW}' \
            --manifest '{MANIFEST}' \
            --probe-layout {PROBE_LAYOUT} \
            --history-length {HISTORY_LENGTH} \
            --target-speed {TARGET_SPEED} \
            --task-geometry {TASK_GEOMETRY} \
            --objective {OBJECTIVE} \
            --total-steps {TOTAL_STEPS} \
            --batch-size {BATCH_SIZE} \
            --eval-every {EVAL_EVERY} \
            --eval-episodes {EVAL_EPISODES} \
            {ALGO_FLAGS} \
            --skip-final-eval \
            --seed {seed} \
            --save-dir '{sd_str}' \
            --device cuda

        print(f'[train done] {algo} seed={seed} in {(time.time() - t0) / 60:.1f} min')

print(f'\n[all train] total = {(time.time() - t_start_train) / 60:.1f} min')

# ---- Mirror small files (idempotent overwrite) ----
print(f'\n{"=" * 72}')
print('  mirror training curves → results/.../training_curves/')
print(f'{"=" * 72}')

for algo in ALGOS:
    for seed in TRAIN_SEEDS:
        src_dir = save_dir(algo, seed)
        dst_dir = mirror_dir(algo, seed)
        dst_dir.mkdir(parents=True, exist_ok=True)
        n_copied = 0
        for fname in MIRROR_FILES:
            src = src_dir / fname
            if src.exists():
                shutil.copy2(src, dst_dir / fname)
                n_copied += 1
        marker = '✓' if n_copied == len(MIRROR_FILES) else '⚠'
        print(f'  {marker} {algo}_seed{seed}: {n_copied}/{len(MIRROR_FILES)} → {dst_dir}')
# Out:
# ========================================================================
#   train rebrac seed=42 → checkpoints/fql_succession/p2/m_multi_mix/rebrac_seed42
# ========================================================================
# [offline] algo=rebrac transitions=138290 obs_dim=48 action_dim=2 protocol=deployable tensor_replay=on eval_workers=1 sampling=uniform total_steps=200000
# [train] step=1 q=-0.859 critic=45.996 actor=5.231 bc=1.058 lambda=1.165 critic_pen=1.136
# [train] step=1000 q=-2.923 critic=1.351 actor=0.943 bc=0.071 lambda=0.225 critic_pen=0.165
# [train] step=2000 q=-1.962 critic=2.621 actor=0.550 bc=0.070 lambda=0.137 critic_pen=0.140
# [train] step=3000 q=-0.133 critic=167.191 actor=0.444 bc=0.108 lambda=0.091 critic_pen=0.152
# [train] step=4000 q=-1.958 critic=3.482 actor=0.436 bc=0.065 lambda=0.091 critic_pen=0.135
# [train] step=5000 q=-4.038 critic=205.993 actor=0.571 bc=0.072 lambda=0.070 critic_pen=0.182
# [train] step=6000 q=-1.269 critic=181.831 actor=0.301 bc=0.056 lambda=0.062 critic_pen=0.132
# [train] step=7000 q=-4.290 critic=2.044 actor=0.491 bc=0.062 lambda=0.056 critic_pen=0.110
# [train] step=8000 q=-2.053 critic=2.511 actor=0.425 bc=0.081 lambda=0.049 critic_pen=0.119
# [train] step=9000 q=-2.069 critic=2.414 actor=0.452 bc=0.094 lambda=0.038 critic_pen=0.135
# [train] step=10000 q=-2.845 critic=3.227 actor=0.277 bc=0.042 lambda=0.039 critic_pen=0.127
# [eval] step=10000 success=48.00% return=-46.07 time=67.95s energy=51674.51 path=60.85 prog=0.595
# [train] step=11000 q=0.569 critic=3.557 actor=0.130 bc=0.038 lambda=0.039 critic_pen=0.099
# [train] step=12000 q=-7.278 critic=4.030 actor=0.423 bc=0.049 lambda=0.031 critic_pen=0.128
# [train] step=13000 q=-2.401 critic=46.634 actor=0.339 bc=0.068 lambda=0.028 critic_pen=0.121
# [train] step=14000 q=-6.632 critic=66.045 actor=0.484 bc=0.075 lambda=0.028 critic_pen=0.117
# [train] step=15000 q=-1.623 critic=3.481 actor=0.262 bc=0.054 lambda=0.028 critic_pen=0.121
# [train] step=16000 q=-4.563 critic=20.585 actor=0.280 bc=0.040 lambda=0.027 critic_pen=0.116
# [train] step=17000 q=-3.378 critic=5.365 actor=0.259 bc=0.042 lambda=0.027 critic_pen=0.101
# [train] step=18000 q=0.271 critic=4.806 actor=0.155 bc=0.040 lambda=0.023 critic_pen=0.113
# [train] step=19000 q=-7.301 critic=4.009 actor=0.386 bc=0.052 lambda=0.024 critic_pen=0.099
# [train] step=20000 q=2.173 critic=6.027 actor=0.138 bc=0.046 lambda=0.021 critic_pen=0.095
# [eval] step=20000 success=84.00% return=86.06 time=52.84s energy=39545.93 path=50.19 prog=0.855
# [train] step=21000 q=-2.484 critic=7.520 actor=0.303 bc=0.062 lambda=0.022 critic_pen=0.117
# [train] step=22000 q=-1.578 critic=6.030 actor=0.239 bc=0.052 lambda=0.021 critic_pen=0.095
# [train] step=23000 q=-2.900 critic=4.533 actor=0.285 bc=0.057 lambda=0.019 critic_pen=0.110
# [train] step=24000 q=-4.793 critic=6.643 actor=0.231 bc=0.034 lambda=0.020 critic_pen=0.110
# [train] step=25000 q=-8.739 critic=86.853 actor=0.292 bc=0.032 lambda=0.019 critic_pen=0.117
# [train] step=26000 q=-7.527 critic=9.198 actor=0.331 bc=0.049 lambda=0.018 critic_pen=0.125
# [train] step=27000 q=-4.367 critic=8.245 actor=0.224 bc=0.038 lambda=0.017 critic_pen=0.092
# [train] step=28000 q=-10.834 critic=8.233 actor=0.302 bc=0.030 lambda=0.017 critic_pen=0.102
# [train] step=29000 q=-8.044 critic=11.185 actor=0.411 bc=0.070 lambda=0.016 critic_pen=0.105
# [train] step=30000 q=-11.957 critic=108.678 actor=0.546 bc=0.087 lambda=0.016 critic_pen=0.109
# [eval] step=30000 success=84.00% return=82.89 time=52.59s energy=40344.00 path=52.28 prog=0.813
# [train] step=31000 q=-8.850 critic=10.519 actor=0.373 bc=0.058 lambda=0.016 critic_pen=0.105
# [train] step=32000 q=-2.665 critic=156.528 actor=0.214 bc=0.044 lambda=0.015 critic_pen=0.109
# [train] step=33000 q=-4.727 critic=92.003 actor=0.245 bc=0.044 lambda=0.015 critic_pen=0.094
# [train] step=34000 q=-14.059 critic=12.288 actor=0.347 bc=0.038 lambda=0.014 critic_pen=0.133
# [train] step=35000 q=-17.308 critic=23.790 actor=0.447 bc=0.048 lambda=0.015 critic_pen=0.103
# [train] step=36000 q=-11.425 critic=17.145 actor=0.277 bc=0.027 lambda=0.015 critic_pen=0.088
# [train] step=37000 q=-5.498 critic=15.362 actor=0.293 bc=0.053 lambda=0.015 critic_pen=0.091
# [train] step=38000 q=-1.719 critic=66.580 actor=0.179 bc=0.039 lambda=0.014 critic_pen=0.141
# [train] step=39000 q=-23.876 critic=14.668 actor=0.504 bc=0.045 lambda=0.014 critic_pen=0.109
# [train] step=40000 q=-12.556 critic=24.361 actor=0.322 bc=0.040 lambda=0.013 critic_pen=0.096
# [eval] step=40000 success=93.00% return=117.12 time=45.59s energy=35292.06 path=46.73 prog=0.886
# [train] step=41000 q=-9.320 critic=12.881 actor=0.260 bc=0.034 lambda=0.013 critic_pen=0.126
# [train] step=42000 q=-14.842 critic=21.259 actor=0.351 bc=0.040 lambda=0.013 critic_pen=0.091
# [train] step=43000 q=-1.382 critic=18.488 actor=0.186 bc=0.042 lambda=0.014 critic_pen=0.091
# [train] step=44000 q=-7.826 critic=15.360 actor=0.235 bc=0.033 lambda=0.013 critic_pen=0.090
# [train] step=45000 q=-18.849 critic=17.953 actor=0.476 bc=0.059 lambda=0.013 critic_pen=0.109
# [train] step=46000 q=-18.668 critic=21.026 actor=0.393 bc=0.035 lambda=0.014 critic_pen=0.107
# [train] step=47000 q=-8.683 critic=22.286 actor=0.303 bc=0.046 lambda=0.014 critic_pen=0.131
# [train] step=48000 q=-7.478 critic=24.187 actor=0.220 bc=0.028 lambda=0.015 critic_pen=0.091
# [train] step=49000 q=-7.079 critic=40.570 actor=0.236 bc=0.036 lambda=0.013 critic_pen=0.083
# [train] step=50000 q=-16.059 critic=35.375 actor=0.404 bc=0.048 lambda=0.013 critic_pen=0.096
# [eval] step=50000 success=90.00% return=104.53 time=49.22s energy=37159.22 path=49.02 prog=0.873
# [train] step=51000 q=-12.338 critic=12.623 actor=0.323 bc=0.043 lambda=0.012 critic_pen=0.107
# [train] step=52000 q=-4.084 critic=29.941 actor=0.223 bc=0.042 lambda=0.014 critic_pen=0.090
# [train] step=53000 q=-19.448 critic=27.496 actor=0.451 bc=0.053 lambda=0.012 critic_pen=0.091
# [train] step=54000 q=-12.293 critic=20.355 actor=0.346 bc=0.045 lambda=0.014 critic_pen=0.094
# [train] step=55000 q=-12.381 critic=32.062 actor=0.353 bc=0.048 lambda=0.013 critic_pen=0.097
# [train] step=56000 q=-12.738 critic=34.334 actor=0.274 bc=0.028 lambda=0.013 critic_pen=0.094
# [train] step=57000 q=-4.541 critic=19.038 actor=0.182 bc=0.030 lambda=0.013 critic_pen=0.096
# [train] step=58000 q=-5.940 critic=16.668 actor=0.173 bc=0.025 lambda=0.013 critic_pen=0.086
# [train] step=59000 q=-12.575 critic=36.353 actor=0.391 bc=0.058 lambda=0.013 critic_pen=0.101
# [train] step=60000 q=-22.860 critic=25.603 actor=0.448 bc=0.044 lambda=0.012 critic_pen=0.101
# [eval] step=60000 success=90.00% return=103.34 time=46.06s energy=35329.08 path=47.92 prog=0.874
# [train] step=61000 q=-13.766 critic=20.156 actor=0.263 bc=0.023 lambda=0.012 critic_pen=0.090
# [train] step=62000 q=-9.077 critic=32.409 actor=0.285 bc=0.041 lambda=0.013 critic_pen=0.107
# [train] step=63000 q=-0.319 critic=31.041 actor=0.146 bc=0.035 lambda=0.013 critic_pen=0.089
# [train] step=64000 q=-8.137 critic=20.623 actor=0.238 bc=0.032 lambda=0.013 critic_pen=0.088
# [train] step=65000 q=-16.511 critic=34.161 actor=0.421 bc=0.051 lambda=0.013 critic_pen=0.110
# [train] step=66000 q=-14.067 critic=105.801 actor=0.379 bc=0.047 lambda=0.014 critic_pen=0.092
# [train] step=67000 q=-12.752 critic=35.028 actor=0.316 bc=0.039 lambda=0.012 critic_pen=0.082
# [train] step=68000 q=-15.146 critic=65.063 actor=0.318 bc=0.032 lambda=0.013 critic_pen=0.093
# [train] step=69000 q=-22.233 critic=33.908 actor=0.429 bc=0.040 lambda=0.012 critic_pen=0.098
# [train] step=70000 q=-3.844 critic=17.744 actor=0.240 bc=0.048 lambda=0.013 critic_pen=0.100
# [eval] step=70000 success=94.00% return=115.92 time=46.66s energy=36488.13 path=49.08 prog=0.867
# [train] step=71000 q=-13.797 critic=31.323 actor=0.356 bc=0.047 lambda=0.012 critic_pen=0.108
# [train] step=72000 q=-2.707 critic=39.171 actor=0.174 bc=0.034 lambda=0.014 critic_pen=0.090
# [train] step=73000 q=-8.498 critic=45.042 actor=0.247 bc=0.033 lambda=0.013 critic_pen=0.097
# [train] step=74000 q=-7.209 critic=30.951 actor=0.321 bc=0.057 lambda=0.013 critic_pen=0.092
# [train] step=75000 q=-10.875 critic=36.780 actor=0.308 bc=0.043 lambda=0.012 critic_pen=0.093
# [train] step=76000 q=-19.281 critic=26.894 actor=0.336 bc=0.026 lambda=0.012 critic_pen=0.092
# [train] step=77000 q=-13.973 critic=145.177 actor=0.282 bc=0.024 lambda=0.013 critic_pen=0.088
# [train] step=78000 q=-9.840 critic=12.288 actor=0.244 bc=0.030 lambda=0.013 critic_pen=0.098
# [train] step=79000 q=-7.789 critic=60.546 actor=0.319 bc=0.055 lambda=0.013 critic_pen=0.082
# [train] step=80000 q=-0.057 critic=48.372 actor=0.110 bc=0.027 lambda=0.013 critic_pen=0.105
# [eval] step=80000 success=93.00% return=112.11 time=47.81s energy=36564.55 path=48.39 prog=0.874
# [train] step=81000 q=-1.873 critic=45.068 actor=0.201 bc=0.044 lambda=0.013 critic_pen=0.085
# [train] step=82000 q=-7.188 critic=21.663 actor=0.207 bc=0.027 lambda=0.014 critic_pen=0.091
# [train] step=83000 q=-10.124 critic=35.560 actor=0.236 bc=0.028 lambda=0.012 critic_pen=0.100
# [train] step=84000 q=-2.073 critic=22.594 actor=0.178 bc=0.037 lambda=0.014 critic_pen=0.106
# [train] step=85000 q=-7.774 critic=257.137 actor=0.286 bc=0.045 lambda=0.014 critic_pen=0.087
# [train] step=86000 q=-10.713 critic=42.627 actor=0.239 bc=0.026 lambda=0.013 critic_pen=0.084
# [train] step=87000 q=-11.863 critic=47.859 actor=0.309 bc=0.038 lambda=0.013 critic_pen=0.110
# [train] step=88000 q=-14.213 critic=46.736 actor=0.305 bc=0.032 lambda=0.012 critic_pen=0.097
# [train] step=89000 q=-3.097 critic=28.589 actor=0.141 bc=0.025 lambda=0.013 critic_pen=0.088
# [train] step=90000 q=-5.488 critic=24.001 actor=0.194 bc=0.031 lambda=0.013 critic_pen=0.090
# [eval] step=90000 success=90.00% return=102.68 time=48.36s energy=37299.37 path=49.34 prog=0.870
# [train] step=91000 q=-1.945 critic=51.969 actor=0.169 bc=0.036 lambda=0.013 critic_pen=0.082
# [train] step=92000 q=-8.973 critic=18.042 actor=0.305 bc=0.048 lambda=0.013 critic_pen=0.092
# [train] step=93000 q=-8.028 critic=28.913 actor=0.235 bc=0.032 lambda=0.013 critic_pen=0.085
# [train] step=94000 q=-8.593 critic=47.653 actor=0.246 bc=0.032 lambda=0.014 critic_pen=0.091
# [train] step=95000 q=-15.486 critic=23.019 actor=0.339 bc=0.035 lambda=0.013 critic_pen=0.100
# [train] step=96000 q=-6.412 critic=38.685 actor=0.270 bc=0.046 lambda=0.014 critic_pen=0.094
# [train] step=97000 q=-9.018 critic=17.862 actor=0.300 bc=0.046 lambda=0.013 critic_pen=0.086
# [train] step=98000 q=-9.963 critic=71.776 actor=0.288 bc=0.039 lambda=0.013 critic_pen=0.090
# [train] step=99000 q=-1.791 critic=25.984 actor=0.275 bc=0.063 lambda=0.014 critic_pen=0.083
# [train] step=100000 q=2.064 critic=53.252 actor=0.083 bc=0.029 lambda=0.015 critic_pen=0.103
# [eval] step=100000 success=99.00% return=135.54 time=43.84s energy=34079.09 path=46.29 prog=0.907
# [train] step=101000 q=-17.203 critic=29.439 actor=0.314 bc=0.023 lambda=0.013 critic_pen=0.095
# [train] step=102000 q=-1.653 critic=38.035 actor=0.122 bc=0.025 lambda=0.014 critic_pen=0.093
# [train] step=103000 q=-15.113 critic=54.041 actor=0.384 bc=0.048 lambda=0.013 critic_pen=0.092
# [train] step=104000 q=-7.016 critic=40.691 actor=0.281 bc=0.047 lambda=0.014 critic_pen=0.087
# [eval] step=180000 success=100.00% return=139.63 time=43.31s energy=33852.18 path=46.07 prog=0.907
# [train] step=181000 q=-10.659 critic=18.018 actor=0.226 bc=0.021 lambda=0.013 critic_pen=0.085
# [train] step=182000 q=-6.157 critic=22.346 actor=0.163 bc=0.020 lambda=0.013 critic_pen=0.080
# [train] step=183000 q=0.835 critic=35.732 actor=0.093 bc=0.026 lambda=0.014 critic_pen=0.092
# [train] step=184000 q=-3.073 critic=45.098 actor=0.141 bc=0.024 lambda=0.014 critic_pen=0.090
# [train] step=185000 q=-2.852 critic=85.444 actor=0.161 bc=0.030 lambda=0.014 critic_pen=0.084
# [train] step=186000 q=-13.389 critic=49.792 actor=0.293 bc=0.029 lambda=0.013 critic_pen=0.086
# [train] step=187000 q=-1.735 critic=25.971 actor=0.154 bc=0.033 lambda=0.013 critic_pen=0.085
# [train] step=188000 q=-4.762 critic=33.278 actor=0.181 bc=0.028 lambda=0.014 critic_pen=0.077
# [train] step=189000 q=-10.663 critic=38.137 actor=0.238 bc=0.025 lambda=0.013 critic_pen=0.087
# [train] step=190000 q=-1.396 critic=65.282 actor=0.111 bc=0.023 lambda=0.015 critic_pen=0.089
# [eval] step=190000 success=98.00% return=131.57 time=45.95s energy=35458.97 path=47.62 prog=0.903
# [train] step=191000 q=-8.831 critic=22.279 actor=0.256 bc=0.033 lambda=0.014 critic_pen=0.089
# [train] step=192000 q=-6.190 critic=16.144 actor=0.218 bc=0.033 lambda=0.014 critic_pen=0.086
# [train] step=193000 q=-11.294 critic=36.041 actor=0.252 bc=0.026 lambda=0.013 critic_pen=0.075
# [train] step=194000 q=-3.346 critic=37.175 actor=0.127 bc=0.021 lambda=0.013 critic_pen=0.081
# [train] step=195000 q=2.880 critic=11.518 actor=0.052 bc=0.023 lambda=0.014 critic_pen=0.095
# [train] step=196000 q=-9.720 critic=35.889 actor=0.251 bc=0.030 lambda=0.013 critic_pen=0.085
# [train] step=197000 q=-5.280 critic=29.901 actor=0.173 bc=0.025 lambda=0.013 critic_pen=0.083
# [train] step=198000 q=-3.856 critic=14.625 actor=0.133 bc=0.021 lambda=0.013 critic_pen=0.096
# [train] step=199000 q=-9.338 critic=36.509 actor=0.217 bc=0.022 lambda=0.014 critic_pen=0.068
# [train] step=200000 q=-14.131 critic=25.057 actor=0.258 bc=0.018 lambda=0.013 critic_pen=0.078
# [eval] step=200000 success=99.00% return=137.31 time=43.00s energy=33563.90 path=45.76 prog=0.907
# [train done] rebrac seed=42 in 68.8 min
#
# ========================================================================
#   train rebrac seed=0 → checkpoints/fql_succession/p2/m_multi_mix/rebrac_seed0
# ========================================================================
# [offline] algo=rebrac transitions=138290 obs_dim=48 action_dim=2 protocol=deployable tensor_replay=on eval_workers=1 sampling=uniform total_steps=200000
# [train] step=1 q=-0.708 critic=84.938 actor=5.369 bc=1.092 lambda=1.412 critic_pen=1.118
# [train] step=1000 q=-1.927 critic=52.966 actor=1.078 bc=0.166 lambda=0.216 critic_pen=0.196
# [train] step=2000 q=-3.281 critic=174.274 actor=0.817 bc=0.082 lambda=0.149 critic_pen=0.166
# [train] step=3000 q=-3.541 critic=11.993 actor=0.672 bc=0.057 lambda=0.126 critic_pen=0.142
# [train] step=4000 q=-3.340 critic=192.208 actor=0.569 bc=0.065 lambda=0.092 critic_pen=0.139
# [train] step=5000 q=-3.072 critic=3.746 actor=0.467 bc=0.065 lambda=0.068 critic_pen=0.119
# [train] step=6000 q=-4.678 critic=2.802 actor=0.497 bc=0.048 lambda=0.065 critic_pen=0.125
# [train] step=7000 q=0.379 critic=2.311 actor=0.196 bc=0.054 lambda=0.050 critic_pen=0.100
# [train] step=8000 q=-3.506 critic=182.630 actor=0.398 bc=0.054 lambda=0.052 critic_pen=0.113
# [train] step=9000 q=-3.037 critic=67.629 actor=0.311 bc=0.044 lambda=0.044 critic_pen=0.114
# [train] step=10000 q=-3.932 critic=169.396 actor=0.376 bc=0.054 lambda=0.041 critic_pen=0.100
# [eval] step=10000 success=46.00% return=-38.83 time=60.81s energy=45934.54 path=57.05 prog=0.719
# [train] step=11000 q=-4.963 critic=2.711 actor=0.475 bc=0.075 lambda=0.036 critic_pen=0.098
# [train] step=12000 q=-4.331 critic=4.885 actor=0.313 bc=0.043 lambda=0.033 critic_pen=0.119
# [train] step=13000 q=-6.080 critic=3.822 actor=0.385 bc=0.047 lambda=0.032 critic_pen=0.120
# [train] step=14000 q=-5.144 critic=44.550 actor=0.377 bc=0.057 lambda=0.029 critic_pen=0.095
# [train] step=15000 q=-1.018 critic=3.350 actor=0.193 bc=0.041 lambda=0.028 critic_pen=0.106
# [train] step=16000 q=-3.737 critic=4.060 actor=0.319 bc=0.056 lambda=0.026 critic_pen=0.093
# [train] step=17000 q=-3.883 critic=5.655 actor=0.247 bc=0.038 lambda=0.024 critic_pen=0.106
# [train] step=18000 q=-6.821 critic=7.498 actor=0.382 bc=0.057 lambda=0.022 critic_pen=0.101
# [train] step=19000 q=-4.315 critic=6.351 actor=0.228 bc=0.034 lambda=0.021 critic_pen=0.120
# [train] step=20000 q=-5.283 critic=7.470 actor=0.332 bc=0.057 lambda=0.019 critic_pen=0.095
# [eval] step=20000 success=58.00% return=-10.66 time=76.01s energy=55632.21 path=69.66 prog=0.674
# [train] step=21000 q=-1.941 critic=5.588 actor=0.181 bc=0.036 lambda=0.020 critic_pen=0.114
# [train] step=22000 q=-4.741 critic=8.402 actor=0.364 bc=0.069 lambda=0.018 critic_pen=0.111
# [train] step=23000 q=-0.197 critic=175.286 actor=0.194 bc=0.048 lambda=0.020 critic_pen=0.120
# [train] step=24000 q=-5.769 critic=5.202 actor=0.271 bc=0.043 lambda=0.017 critic_pen=0.106
# [train] step=25000 q=-8.228 critic=7.883 actor=0.305 bc=0.042 lambda=0.017 critic_pen=0.098
# [train] step=26000 q=-2.691 critic=9.159 actor=0.184 bc=0.035 lambda=0.017 critic_pen=0.099
# [train] step=27000 q=7.359 critic=8.446 actor=0.058 bc=0.045 lambda=0.017 critic_pen=0.113
# [train] step=28000 q=-4.901 critic=9.519 actor=0.338 bc=0.063 lambda=0.017 critic_pen=0.131
# [train] step=29000 q=-0.864 critic=7.585 actor=0.230 bc=0.054 lambda=0.017 critic_pen=0.088
# [train] step=30000 q=-3.382 critic=10.391 actor=0.278 bc=0.056 lambda=0.016 critic_pen=0.106
# [eval] step=30000 success=82.00% return=69.60 time=52.77s energy=39629.38 path=50.65 prog=0.840
# [train] step=31000 q=-3.144 critic=15.221 actor=0.191 bc=0.036 lambda=0.016 critic_pen=0.098
# [train] step=32000 q=-15.731 critic=14.306 actor=0.364 bc=0.033 lambda=0.015 critic_pen=0.091
# [train] step=33000 q=-14.682 critic=12.304 actor=0.358 bc=0.036 lambda=0.015 critic_pen=0.095
# [train] step=34000 q=5.949 critic=9.877 actor=0.014 bc=0.027 lambda=0.016 critic_pen=0.101
# [train] step=35000 q=-1.445 critic=9.321 actor=0.148 bc=0.032 lambda=0.015 critic_pen=0.104
# [train] step=36000 q=-14.856 critic=12.286 actor=0.416 bc=0.052 lambda=0.014 critic_pen=0.110
# [train] step=37000 q=-15.248 critic=26.945 actor=0.342 bc=0.034 lambda=0.013 critic_pen=0.092
# [train] step=38000 q=-11.535 critic=20.842 actor=0.327 bc=0.043 lambda=0.014 critic_pen=0.096
# [train] step=39000 q=-6.389 critic=22.167 actor=0.245 bc=0.038 lambda=0.014 critic_pen=0.099
# [train] step=40000 q=-6.015 critic=23.329 actor=0.227 bc=0.035 lambda=0.014 critic_pen=0.118
# [eval] step=40000 success=77.00% return=47.28 time=59.04s energy=43723.53 path=54.60 prog=0.812
# [train] step=41000 q=-12.558 critic=127.578 actor=0.314 bc=0.036 lambda=0.014 critic_pen=0.104
# [train] step=42000 q=-8.436 critic=17.780 actor=0.259 bc=0.037 lambda=0.013 critic_pen=0.100
# [train] step=43000 q=-8.369 critic=27.545 actor=0.285 bc=0.043 lambda=0.013 critic_pen=0.095
# [train] step=44000 q=-26.479 critic=44.255 actor=0.491 bc=0.043 lambda=0.012 critic_pen=0.118
# [train] step=45000 q=-16.585 critic=17.750 actor=0.340 bc=0.034 lambda=0.012 critic_pen=0.085
# [train] step=46000 q=-16.523 critic=34.191 actor=0.347 bc=0.035 lambda=0.013 critic_pen=0.082
# [train] step=47000 q=-4.052 critic=19.987 actor=0.214 bc=0.040 lambda=0.014 critic_pen=0.095
# [train] step=48000 q=-14.729 critic=18.013 actor=0.382 bc=0.048 lambda=0.013 critic_pen=0.107
# [train] step=49000 q=-12.873 critic=28.449 actor=0.292 bc=0.031 lambda=0.013 critic_pen=0.092
# [train] step=50000 q=-19.115 critic=25.028 actor=0.418 bc=0.046 lambda=0.012 critic_pen=0.113
# [eval] step=50000 success=91.00% return=107.97 time=48.10s energy=36959.60 path=48.42 prog=0.859
# [train] step=51000 q=-13.906 critic=27.077 actor=0.327 bc=0.038 lambda=0.013 critic_pen=0.095
# [train] step=52000 q=-12.962 critic=33.363 actor=0.307 bc=0.037 lambda=0.012 critic_pen=0.085
# [train] step=53000 q=-14.412 critic=34.529 actor=0.316 bc=0.032 lambda=0.013 critic_pen=0.098
# [train] step=54000 q=-9.789 critic=44.033 actor=0.300 bc=0.044 lambda=0.013 critic_pen=0.125
# [train] step=55000 q=-12.005 critic=32.079 actor=0.246 bc=0.024 lambda=0.012 critic_pen=0.096
# [train] step=56000 q=-26.381 critic=38.906 actor=0.521 bc=0.048 lambda=0.012 critic_pen=0.108
# [train] step=57000 q=-6.041 critic=28.252 actor=0.229 bc=0.038 lambda=0.013 critic_pen=0.095
# [train] step=58000 q=-23.601 critic=23.591 actor=0.370 bc=0.023 lambda=0.012 critic_pen=0.111
# [train] step=59000 q=-15.555 critic=29.885 actor=0.367 bc=0.045 lambda=0.012 critic_pen=0.102
# [train] step=60000 q=-14.401 critic=18.716 actor=0.311 bc=0.032 lambda=0.013 critic_pen=0.095
# [eval] step=60000 success=91.00% return=102.02 time=56.94s energy=42270.04 path=52.34 prog=0.794
# [train] step=61000 q=-24.396 critic=28.601 actor=0.403 bc=0.027 lambda=0.012 critic_pen=0.106
# [train] step=62000 q=-6.159 critic=21.377 actor=0.257 bc=0.045 lambda=0.013 critic_pen=0.109
# [train] step=63000 q=-17.635 critic=42.546 actor=0.319 bc=0.026 lambda=0.012 critic_pen=0.095
# [train] step=64000 q=-19.371 critic=50.529 actor=0.364 bc=0.032 lambda=0.012 critic_pen=0.089
# [train] step=65000 q=1.982 critic=15.780 actor=0.093 bc=0.030 lambda=0.014 critic_pen=0.086
# [train] step=66000 q=-16.856 critic=35.036 actor=0.385 bc=0.041 lambda=0.013 critic_pen=0.089
# [train] step=67000 q=-8.958 critic=60.856 actor=0.270 bc=0.038 lambda=0.013 critic_pen=0.096
# [train] step=68000 q=-13.316 critic=56.908 actor=0.314 bc=0.039 lambda=0.012 critic_pen=0.096
# [train] step=69000 q=-10.749 critic=23.416 actor=0.331 bc=0.048 lambda=0.013 critic_pen=0.109
# [train] step=70000 q=-9.210 critic=35.834 actor=0.220 bc=0.027 lambda=0.012 critic_pen=0.098
# [eval] step=70000 success=95.00% return=121.88 time=46.10s energy=35551.98 path=47.14 prog=0.881
# [train] step=71000 q=-1.917 critic=40.115 actor=0.133 bc=0.027 lambda=0.013 critic_pen=0.099
# [train] step=72000 q=-11.852 critic=25.628 actor=0.277 bc=0.030 lambda=0.013 critic_pen=0.092
# [train] step=73000 q=-14.925 critic=29.238 actor=0.306 bc=0.030 lambda=0.012 critic_pen=0.105
# [train] step=74000 q=-0.889 critic=33.342 actor=0.173 bc=0.040 lambda=0.013 critic_pen=0.094
# [train] step=75000 q=-19.388 critic=90.987 actor=0.427 bc=0.050 lambda=0.012 critic_pen=0.103
# [train] step=76000 q=-17.141 critic=35.682 actor=0.289 bc=0.023 lambda=0.012 critic_pen=0.093
# [train] step=77000 q=-15.637 critic=29.498 actor=0.280 bc=0.021 lambda=0.013 critic_pen=0.099
# [train] step=78000 q=-7.331 critic=30.611 actor=0.273 bc=0.045 lambda=0.013 critic_pen=0.119
# [train] step=79000 q=-16.071 critic=37.485 actor=0.321 bc=0.030 lambda=0.013 critic_pen=0.085
# [train] step=80000 q=-16.434 critic=32.896 actor=0.335 bc=0.034 lambda=0.012 critic_pen=0.092
# [eval] step=80000 success=92.00% return=107.19 time=50.30s energy=38225.02 path=49.70 prog=0.850
# [train] step=81000 q=-6.010 critic=137.924 actor=0.179 bc=0.026 lambda=0.013 critic_pen=0.105
# [train] step=82000 q=-10.132 critic=35.925 actor=0.223 bc=0.025 lambda=0.012 critic_pen=0.098
# [train] step=83000 q=-12.899 critic=41.817 actor=0.279 bc=0.030 lambda=0.012 critic_pen=0.102
# [train] step=84000 q=-13.284 critic=33.668 actor=0.253 bc=0.024 lambda=0.012 critic_pen=0.115
# [train] step=85000 q=-9.659 critic=66.420 actor=0.255 bc=0.033 lambda=0.013 critic_pen=0.097
# [train] step=86000 q=-10.035 critic=29.817 actor=0.278 bc=0.038 lambda=0.013 critic_pen=0.120
# [train] step=87000 q=-22.069 critic=34.949 actor=0.403 bc=0.033 lambda=0.012 critic_pen=0.090
# [train] step=88000 q=-4.433 critic=13.764 actor=0.163 bc=0.027 lambda=0.012 critic_pen=0.090
# [train] step=89000 q=-1.593 critic=25.211 actor=0.137 bc=0.029 lambda=0.013 critic_pen=0.082
# [train] step=90000 q=-5.718 critic=19.028 actor=0.330 bc=0.063 lambda=0.014 critic_pen=0.085
# [eval] step=90000 success=97.00% return=130.01 time=45.03s energy=34727.36 path=46.75 prog=0.903
# [train] step=91000 q=-6.890 critic=18.365 actor=0.197 bc=0.027 lambda=0.013 critic_pen=0.095
# [train] step=92000 q=-12.832 critic=50.630 actor=0.298 bc=0.033 lambda=0.013 critic_pen=0.099
# [train] step=93000 q=-9.327 critic=26.066 actor=0.212 bc=0.024 lambda=0.013 critic_pen=0.096
# [train] step=94000 q=-9.183 critic=32.734 actor=0.298 bc=0.041 lambda=0.014 critic_pen=0.086
# [train] step=95000 q=-1.100 critic=22.387 actor=0.113 bc=0.024 lambda=0.014 critic_pen=0.089
# [train] step=96000 q=-2.448 critic=83.543 actor=0.184 bc=0.038 lambda=0.013 critic_pen=0.098
# [train] step=97000 q=-14.898 critic=54.566 actor=0.325 bc=0.035 lambda=0.012 critic_pen=0.100
# [train] step=98000 q=-1.116 critic=24.532 actor=0.147 bc=0.033 lambda=0.013 critic_pen=0.117
# [train] step=99000 q=-3.496 critic=24.429 actor=0.135 bc=0.022 lambda=0.013 critic_pen=0.083
# [train] step=100000 q=-4.618 critic=37.073 actor=0.144 bc=0.021 lambda=0.013 critic_pen=0.081
# [eval] step=100000 success=98.00% return=130.94 time=45.15s energy=34748.31 path=47.13 prog=0.904
# [train] step=101000 q=-14.188 critic=20.353 actor=0.282 bc=0.026 lambda=0.013 critic_pen=0.084
# [train] step=102000 q=-14.537 critic=25.723 actor=0.281 bc=0.026 lambda=0.012 critic_pen=0.088
# [train] step=103000 q=-1.919 critic=39.478 actor=0.231 bc=0.051 lambda=0.014 critic_pen=0.101
# [train] step=104000 q=-3.233 critic=27.588 actor=0.142 bc=0.025 lambda=0.013 critic_pen=0.104
# [train] step=105000 q=-10.376 critic=27.451 actor=0.249 bc=0.029 lambda=0.013 critic_pen=0.082
# [train] step=106000 q=-9.324 critic=13.105 actor=0.257 bc=0.034 lambda=0.013 critic_pen=0.097
# [train] step=107000 q=-0.160 critic=23.976 actor=0.179 bc=0.044 lambda=0.013 critic_pen=0.092
# [train] step=108000 q=-0.379 critic=65.896 actor=0.178 bc=0.043 lambda=0.013 critic_pen=0.100
# [train] step=109000 q=-23.519 critic=25.593 actor=0.416 bc=0.033 lambda=0.012 critic_pen=0.112
# [train] step=110000 q=-11.206 critic=30.607 actor=0.243 bc=0.025 lambda=0.013 critic_pen=0.108
# [eval] step=110000 success=92.00% return=106.37 time=50.00s energy=37923.69 path=49.12 prog=0.885
# [train] step=111000 q=-16.347 critic=21.404 actor=0.321 bc=0.028 lambda=0.013 critic_pen=0.099
# [train] step=112000 q=-1.613 critic=46.481 actor=0.183 bc=0.040 lambda=0.014 critic_pen=0.075
# [train] step=113000 q=-6.744 critic=127.602 actor=0.230 bc=0.035 lambda=0.013 critic_pen=0.100
# [train] step=114000 q=-9.843 critic=33.052 actor=0.273 bc=0.036 lambda=0.013 critic_pen=0.091
# [train] step=115000 q=-9.608 critic=32.210 actor=0.218 bc=0.022 lambda=0.014 critic_pen=0.083
# [train] step=116000 q=-17.634 critic=53.715 actor=0.321 bc=0.023 lambda=0.013 critic_pen=0.084
# [train] step=117000 q=-1.206 critic=166.878 actor=0.154 bc=0.034 lambda=0.014 critic_pen=0.098
# [train] step=118000 q=-7.624 critic=24.901 actor=0.206 bc=0.027 lambda=0.013 critic_pen=0.113
# [train] step=119000 q=-11.554 critic=19.671 actor=0.337 bc=0.045 lambda=0.014 critic_pen=0.093
# [train] step=120000 q=-5.839 critic=29.244 actor=0.202 bc=0.031 lambda=0.013 critic_pen=0.091
# [eval] step=120000 success=95.00% return=119.44 time=46.65s energy=35925.32 path=47.83 prog=0.877
# [train] step=121000 q=-6.494 critic=19.596 actor=0.167 bc=0.020 lambda=0.013 critic_pen=0.081
# [train] step=122000 q=-10.858 critic=29.288 actor=0.231 bc=0.022 lambda=0.013 critic_pen=0.096
# [train] step=123000 q=-11.762 critic=36.603 actor=0.274 bc=0.032 lambda=0.012 critic_pen=0.095
# [train] step=124000 q=-9.259 critic=18.627 actor=0.254 bc=0.033 lambda=0.013 critic_pen=0.090
# [train] step=125000 q=-11.998 critic=80.306 actor=0.308 bc=0.035 lambda=0.014 critic_pen=0.093
# [train] step=126000 q=-2.486 critic=34.075 actor=0.188 bc=0.039 lambda=0.013 critic_pen=0.087
# [train] step=127000 q=-5.334 critic=24.397 actor=0.156 bc=0.022 lambda=0.013 critic_pen=0.094
# [train] step=128000 q=-5.067 critic=19.400 actor=0.184 bc=0.030 lambda=0.012 critic_pen=0.084
# [train] step=129000 q=-6.222 critic=125.135 actor=0.259 bc=0.044 lambda=0.013 critic_pen=0.086
# [train] step=130000 q=-9.518 critic=50.293 actor=0.232 bc=0.026 lambda=0.013 critic_pen=0.094
# [eval] step=130000 success=97.00% return=129.28 time=44.83s energy=34611.64 path=46.94 prog=0.901
# [train] step=131000 q=-0.108 critic=19.036 actor=0.140 bc=0.035 lambda=0.013 critic_pen=0.094
# [train] step=132000 q=-5.466 critic=66.841 actor=0.163 bc=0.023 lambda=0.013 critic_pen=0.104
# [train] step=133000 q=-17.949 critic=25.081 actor=0.314 bc=0.023 lambda=0.012 critic_pen=0.097
# [train] step=134000 q=-7.532 critic=80.631 actor=0.202 bc=0.025 lambda=0.013 critic_pen=0.107
# [train] step=135000 q=-5.243 critic=32.309 actor=0.224 bc=0.038 lambda=0.014 critic_pen=0.084
# [train] step=136000 q=-12.331 critic=37.545 actor=0.394 bc=0.058 lambda=0.013 critic_pen=0.094
# [train] step=137000 q=-7.892 critic=69.258 actor=0.220 bc=0.027 lambda=0.014 critic_pen=0.089
# [train] step=138000 q=-0.200 critic=31.988 actor=0.088 bc=0.021 lambda=0.014 critic_pen=0.093
# [train] step=139000 q=1.745 critic=13.997 actor=0.154 bc=0.044 lambda=0.014 critic_pen=0.098
# [train] step=140000 q=-12.374 critic=106.699 actor=0.242 bc=0.019 lambda=0.013 critic_pen=0.089
# [eval] step=140000 success=99.00% return=136.50 time=42.82s energy=33542.13 path=45.94 prog=0.907
# [train] step=141000 q=-5.773 critic=18.475 actor=0.166 bc=0.023 lambda=0.013 critic_pen=0.105
# [train] step=142000 q=-9.009 critic=33.238 actor=0.216 bc=0.025 lambda=0.013 critic_pen=0.096
# [train] step=143000 q=-1.844 critic=20.419 actor=0.154 bc=0.032 lambda=0.013 critic_pen=0.087
# [train] step=144000 q=-1.501 critic=98.491 actor=0.150 bc=0.032 lambda=0.014 critic_pen=0.095
# [train] step=145000 q=0.147 critic=48.191 actor=0.106 bc=0.027 lambda=0.013 critic_pen=0.094
# [train] step=146000 q=-2.726 critic=13.732 actor=0.179 bc=0.036 lambda=0.013 critic_pen=0.088
# [train] step=147000 q=-18.421 critic=15.263 actor=0.379 bc=0.037 lambda=0.012 critic_pen=0.087
# [train] step=148000 q=-10.649 critic=55.095 actor=0.247 bc=0.028 lambda=0.013 critic_pen=0.090
# [train] step=149000 q=0.334 critic=14.578 actor=0.163 bc=0.042 lambda=0.014 critic_pen=0.087
# [train] step=150000 q=-13.242 critic=31.728 actor=0.256 bc=0.021 lambda=0.013 critic_pen=0.082
# [eval] step=150000 success=98.00% return=133.70 time=43.19s energy=33647.60 path=46.20 prog=0.904
# [train] step=151000 q=-7.467 critic=42.553 actor=0.227 bc=0.031 lambda=0.014 critic_pen=0.087
# [train] step=152000 q=-8.490 critic=56.501 actor=0.222 bc=0.028 lambda=0.013 critic_pen=0.097
# [train] step=153000 q=0.121 critic=30.783 actor=0.094 bc=0.024 lambda=0.015 critic_pen=0.096
# [train] step=154000 q=-2.376 critic=8.717 actor=0.198 bc=0.041 lambda=0.014 critic_pen=0.088
# [train] step=155000 q=-5.553 critic=48.826 actor=0.204 bc=0.032 lambda=0.014 critic_pen=0.087
# [train] step=181000 q=-3.557 critic=33.212 actor=0.158 bc=0.027 lambda=0.014 critic_pen=0.093
# [train] step=182000 q=1.306 critic=16.834 actor=0.120 bc=0.034 lambda=0.014 critic_pen=0.091
# [train] step=183000 q=-1.546 critic=12.282 actor=0.133 bc=0.028 lambda=0.014 critic_pen=0.075
# [train] step=184000 q=-1.910 critic=49.820 actor=0.133 bc=0.027 lambda=0.013 critic_pen=0.098
# [train] step=185000 q=7.582 critic=20.290 actor=0.019 bc=0.030 lambda=0.014 critic_pen=0.091
# [train] step=186000 q=-10.535 critic=25.438 actor=0.326 bc=0.045 lambda=0.014 critic_pen=0.075
# [train] step=187000 q=-6.644 critic=11.214 actor=0.188 bc=0.025 lambda=0.013 critic_pen=0.096
# [train] step=188000 q=-4.411 critic=19.934 actor=0.234 bc=0.042 lambda=0.015 critic_pen=0.075
# [train] step=189000 q=-2.061 critic=64.222 actor=0.134 bc=0.026 lambda=0.014 critic_pen=0.086
# [train] step=190000 q=-1.711 critic=89.656 actor=0.117 bc=0.023 lambda=0.014 critic_pen=0.083
# [eval] step=190000 success=97.00% return=129.04 time=43.44s energy=33958.78 path=46.62 prog=0.895
# [train] step=191000 q=-6.181 critic=11.809 actor=0.175 bc=0.023 lambda=0.014 critic_pen=0.097
# [train] step=192000 q=-11.588 critic=43.290 actor=0.226 bc=0.019 lambda=0.013 critic_pen=0.088
# [train] step=193000 q=-0.403 critic=24.576 actor=0.100 bc=0.024 lambda=0.014 critic_pen=0.086
# [train] step=194000 q=-10.187 critic=66.640 actor=0.288 bc=0.037 lambda=0.014 critic_pen=0.087
# [train] step=195000 q=-2.573 critic=41.512 actor=0.205 bc=0.043 lambda=0.013 critic_pen=0.111
# [train] step=196000 q=-15.157 critic=27.091 actor=0.362 bc=0.043 lambda=0.013 critic_pen=0.093
# [train] step=197000 q=0.418 critic=17.945 actor=0.080 bc=0.021 lambda=0.013 critic_pen=0.085
# [train] step=198000 q=-1.723 critic=49.166 actor=0.220 bc=0.049 lambda=0.014 critic_pen=0.088
# [train] step=199000 q=0.448 critic=10.184 actor=0.218 bc=0.056 lambda=0.014 critic_pen=0.082
# [train] step=200000 q=10.608 critic=31.632 actor=-0.069 bc=0.020 lambda=0.014 critic_pen=0.087
# [eval] step=200000 success=99.00% return=132.52 time=45.27s energy=34930.38 path=47.40 prog=0.904
# [train done] rebrac seed=0 in 68.4 min
#
# ========================================================================
#   train fql seed=42 → checkpoints/fql_succession/p2/m_multi_mix/fql_seed42
# ========================================================================
# [offline] algo=fql transitions=138290 obs_dim=48 action_dim=2 protocol=deployable tensor_replay=on eval_workers=1 sampling=uniform total_steps=200000
# [train] step=1 q=-0.279 critic=39.411 actor=2.027 bc=1.062 lambda=3.454
# [train] step=1000 q=0.886 critic=28.631 actor=-0.264 bc=0.084 lambda=0.393
# [train] step=2000 q=1.331 critic=16.389 actor=-0.171 bc=0.086 lambda=0.193
# [train] step=3000 q=3.022 critic=16.127 actor=-0.364 bc=0.059 lambda=0.140
# [train] step=181000 q=22.907 critic=24.403 actor=-0.309 bc=0.024 lambda=0.015
# [train] step=182000 q=29.713 critic=5.109 actor=-0.418 bc=0.023 lambda=0.015
# [train] step=183000 q=26.632 critic=24.089 actor=-0.360 bc=0.032 lambda=0.015
# [train] step=184000 q=19.779 critic=68.650 actor=-0.259 bc=0.023 lambda=0.014
# [train] step=185000 q=19.854 critic=11.213 actor=-0.285 bc=0.023 lambda=0.016
# [train] step=186000 q=21.828 critic=7.070 actor=-0.319 bc=0.016 lambda=0.015
# [train] step=187000 q=24.662 critic=11.427 actor=-0.345 bc=0.022 lambda=0.015
# [train] step=188000 q=24.074 critic=14.681 actor=-0.340 bc=0.032 lambda=0.015
# [train] step=189000 q=15.788 critic=14.207 actor=-0.190 bc=0.028 lambda=0.014
# [train] step=190000 q=32.202 critic=16.367 actor=-0.490 bc=0.016 lambda=0.016
# [eval] step=190000 success=93.00% return=113.57 time=42.23s energy=33168.63 path=45.90 prog=0.855
# [train] step=191000 q=23.534 critic=10.149 actor=-0.358 bc=0.022 lambda=0.016
# [train] step=192000 q=27.143 critic=38.228 actor=-0.367 bc=0.020 lambda=0.014
# [train] step=193000 q=22.990 critic=11.648 actor=-0.333 bc=0.024 lambda=0.016
# [train] step=194000 q=26.201 critic=6.422 actor=-0.401 bc=0.022 lambda=0.016
# [train] step=195000 q=32.954 critic=8.010 actor=-0.468 bc=0.020 lambda=0.015
# [train] step=196000 q=21.096 critic=10.479 actor=-0.285 bc=0.021 lambda=0.015
# [train] step=197000 q=29.767 critic=7.227 actor=-0.460 bc=0.028 lambda=0.016
# [train] step=198000 q=26.581 critic=9.089 actor=-0.367 bc=0.018 lambda=0.014
# [train] step=199000 q=23.494 critic=14.132 actor=-0.307 bc=0.022 lambda=0.014
# [train] step=200000 q=32.828 critic=5.485 actor=-0.500 bc=0.023 lambda=0.016
# [eval] step=200000 success=94.00% return=119.36 time=42.72s energy=33627.20 path=45.75 prog=0.880
# [train done] fql seed=0 in 76.4 min
#
# [all train] total = 290.2 min
#
# ========================================================================
#   mirror training curves → results/.../training_curves/
# ========================================================================
#   ✓ rebrac_seed42: 4/4 → results/fql_succession/p2/m_multi_mix/training_curves/rebrac_seed42
#   ✓ rebrac_seed0: 4/4 → results/fql_succession/p2/m_multi_mix/training_curves/rebrac_seed0
#   ✓ fql_seed42: 4/4 → results/fql_succession/p2/m_multi_mix/training_curves/fql_seed42
#   ✓ fql_seed0: 4/4 → results/fql_succession/p2/m_multi_mix/training_curves/fql_seed0

# %% [markdown]
# ## 5. Test eval — 100-episode 在 ep100 manifest 上
#
# 用 `scripts.evaluate_offline` 加载每个 (algo, seed) 的 `agent_final.pt`,在 100-episode test manifest 上跑评估。结果写到 `results/.../test/{algo}_seed{S}.json`(per spec §4.2 + §9.3.1)。
#
# **Skip-resume**:test json 存在则 skip。
# **并行**:6 worker × CPU(与 broad bash 一致),~3-5 min/run。

# %%
import time

TEST_DIR.mkdir(parents=True, exist_ok=True)

t_start_eval = time.time()

for algo in ALGOS:
    for seed in TRAIN_SEEDS:
        sd = save_dir(algo, seed)
        sd_str = str(sd)
        out_path = test_json(algo, seed)
        out_path_str = str(out_path)

        if out_path.exists():
            print(f'[skip-eval] {algo} seed={seed}: {out_path}')
            continue

        if not (sd / 'agent_final.pt').exists():
            print(f'[warn] missing agent_final.pt at {sd} — training not done?')
            continue

        print(f'\n{"=" * 72}')
        print(f'  eval {algo} seed={seed} → {out_path}')
        print(f'{"=" * 72}')
        t0 = time.time()

        # !python -m scripts.evaluate_offline \
            --checkpoint '{sd_str}' \
            --manifest '{MANIFEST}' \
            --episodes {TEST_EPISODES} \
            --num-workers {EVAL_NUM_WORKERS} \
            --worker-device cpu \
            --device cuda \
            --output-json '{out_path_str}'

        print(f'[eval done] {algo} seed={seed} in {(time.time() - t0) / 60:.1f} min')

print(f'\n[all eval] total = {(time.time() - t_start_eval) / 60:.1f} min')
# Out:
# ========================================================================
#   eval rebrac seed=42 → results/fql_succession/p2/m_multi_mix/test/rebrac_seed42.json
# ========================================================================
# reward_objective      : arrival_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.000000
# episodes              : 100
# success_rate          : 100.0%
# avg_return            : 140.16 +/- 3.80
# avg_safety_cost       : 2.154 +/- 1.902
# avg_time_s            : 43.18 +/- 9.10
# avg_time_s_success    : 43.18
# avg_energy            : 33747.43 +/- 6752.83
# avg_path_length_m     : 45.95 +/- 6.36
# avg_progress_ratio    : 0.907 +/- 0.004
# avg_path_efficiency   : 0.858 +/- 0.092
# termination           : {'goal': 100}
# benchmark_manifest    : benchmarks/single_u10_cross_tgt15_ep100.json
# [eval done] rebrac seed=42 in 1.2 min
#
# ========================================================================
#   eval rebrac seed=0 → results/fql_succession/p2/m_multi_mix/test/rebrac_seed0.json
# ========================================================================
# reward_objective      : arrival_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.000000
# episodes              : 100
# success_rate          : 98.0%
# avg_return            : 133.55 +/- 44.62
# avg_safety_cost       : 2.471 +/- 3.970
# avg_time_s            : 42.76 +/- 6.96
# avg_time_s_success    : 42.75
# avg_energy            : 33498.77 +/- 5510.74
# avg_path_length_m     : 45.92 +/- 6.20
# avg_progress_ratio    : 0.905 +/- 0.019
# avg_path_efficiency   : 0.856 +/- 0.094
# termination           : {'goal': 98, 'out_of_bounds': 2}
# benchmark_manifest    : benchmarks/single_u10_cross_tgt15_ep100.json
# [eval done] rebrac seed=0 in 1.1 min
#
# ========================================================================
#   eval fql seed=42 → results/fql_succession/p2/m_multi_mix/test/fql_seed42.json
# ========================================================================
# reward_objective      : arrival_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.000000
# episodes              : 100
# success_rate          : 96.0%
# avg_return            : 128.57 +/- 62.06
# avg_safety_cost       : 2.059 +/- 2.386
# avg_time_s            : 41.45 +/- 6.44
# avg_time_s_success    : 40.85
# avg_energy            : 32617.50 +/- 5264.69
# avg_path_length_m     : 44.56 +/- 4.96
# avg_progress_ratio    : 0.902 +/- 0.030
# avg_path_efficiency   : 0.876 +/- 0.088
# termination           : {'out_of_bounds': 4, 'goal': 96}
# benchmark_manifest    : benchmarks/single_u10_cross_tgt15_ep100.json
# [eval done] fql seed=42 in 1.1 min
#
# ========================================================================
#   eval fql seed=0 → results/fql_succession/p2/m_multi_mix/test/fql_seed0.json
# ========================================================================
# reward_objective      : arrival_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.000000
# episodes              : 100
# success_rate          : 95.0%
# avg_return            : 125.09 +/- 70.12
# avg_safety_cost       : 2.188 +/- 2.557
# avg_time_s            : 40.76 +/- 7.35
# avg_time_s_success    : 39.85
# avg_energy            : 32447.18 +/- 5338.72
# avg_path_length_m     : 44.57 +/- 4.70
# avg_progress_ratio    : 0.897 +/- 0.054
# avg_path_efficiency   : 0.871 +/- 0.098
# termination           : {'goal': 95, 'out_of_bounds': 5}
# benchmark_manifest    : benchmarks/single_u10_cross_tgt15_ep100.json
# [eval done] fql seed=0 in 1.1 min
#
# [all eval] total = 4.5 min

# %% [markdown]
# ## 6. 三向对比 — 4 run × test json + learning curves
#
# **Guard**:所有 4 个 test json 都存在才进 §6 / §7(per spec §9.3.2)。
#
# **输出**:
# 1. DataFrame:per (algo, seed) 的 `success_rate`,`mean_return`,`safety_cost`,`path_efficiency`,`progress_ratio`,termination 分布(goal / timeout / oob)
# 2. Aggregate table:per algo(mean ± std over 2 seeds)
# 3. Inline matplotlib:**success rate bar**(rebrac vs fql,with seed dots)+ **learning curve**(eval success vs train_step,4 lines,from eval_log.csv mirror)

# %%
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# ---- guard ----
missing = [(a, s) for a in ALGOS for s in TRAIN_SEEDS if not test_json(a, s).exists()]
if missing:
    raise RuntimeError(
        f'[not ready] {len(missing)} runs pending: '
        + ', '.join(f'{a}_seed{s}' for a, s in missing)
    )
print(f'[ok] all {len(ALGOS) * len(TRAIN_SEEDS)} test json present')

# ---- read 4 test json ----
rows = []
for algo in ALGOS:
    for seed in TRAIN_SEEDS:
        p = test_json(algo, seed)
        d = json.loads(p.read_text(encoding='utf-8'))
        n = max(int(d.get('num_eval_episodes', TEST_EPISODES)), 1)
        term = d.get('eval_termination_counts', {})
        rows.append({
            'algo': algo,
            'seed': seed,
            'success_rate': d['eval_success_rate'],
            'mean_return':  d['eval_return'],
            'return_std':   d.get('eval_return_std', float('nan')),
            'safety_cost':  d['eval_safety_cost'],
            'path_eff':     d.get('eval_path_efficiency', float('nan')),
            'progress':     d.get('eval_progress_ratio', float('nan')),
            'goal_pct':     term.get('goal', 0) / n,
            'timeout_pct':  term.get('timeout', 0) / n,
            'oob_pct':      term.get('out_of_bounds', 0) / n,
        })
df = pd.DataFrame(rows)
print('[per-seed test results]')
print(df.to_string(index=False, float_format=lambda x: f'{x:.4f}'))

# ---- aggregate per algo (mean ± std over 2 seeds) ----
agg = df.groupby('algo').agg(
    success_mean=('success_rate', 'mean'),
    success_std=('success_rate', lambda x: x.std(ddof=0)),
    return_mean=('mean_return', 'mean'),
    return_std=('mean_return', lambda x: x.std(ddof=0)),
    safety_mean=('safety_cost', 'mean'),
    path_eff_mean=('path_eff', 'mean'),
    goal_pct_mean=('goal_pct', 'mean'),
    timeout_pct_mean=('timeout_pct', 'mean'),
    oob_pct_mean=('oob_pct', 'mean'),
).reset_index()
print('\n[per-algo aggregate (mean ± std over n=2 seeds)]')
print(agg.to_string(index=False, float_format=lambda x: f'{x:.4f}'))

# ---- plot 1: success rate bar (rebrac vs fql, with seed dots) ----
fig, axes = plt.subplots(1, 2, figsize=(13, 4))

ax = axes[0]
x_pos = np.arange(len(ALGOS))
means = [agg.query(f'algo == {a!r}')['success_mean'].iloc[0] for a in ALGOS]
stds  = [agg.query(f'algo == {a!r}')['success_std'].iloc[0]  for a in ALGOS]
ax.bar(x_pos, means, yerr=stds, capsize=10, color=['#4C72B0', '#DD8452'], alpha=0.7)
# overlay per-seed dots
for i, algo in enumerate(ALGOS):
    seed_succ = df.query(f'algo == {algo!r}')['success_rate'].values
    ax.scatter([i] * len(seed_succ), seed_succ, color='black', zorder=10, s=40)
ax.set_xticks(x_pos)
ax.set_xticklabels(ALGOS)
ax.set_ylabel('test success rate (100 ep)')
ax.set_title(f'{CELL_ID}: test success per algo (n={len(TRAIN_SEEDS)} seeds)')
ax.set_ylim(0, 1.0)
ax.grid(True, alpha=0.3)

# ---- plot 2: learning curve from eval_log.csv ----
ax = axes[1]
for algo in ALGOS:
    for seed in TRAIN_SEEDS:
        csv_p = mirror_dir(algo, seed) / 'eval_log.csv'
        if not csv_p.exists():
            continue
        eval_df = pd.read_csv(csv_p)
        # dedup by train_step (keep last)
        eval_df = eval_df.drop_duplicates(subset='train_step', keep='last')
        label = f'{algo}_seed{seed}'
        style = '-' if algo == 'rebrac' else '--'
        ax.plot(eval_df['train_step'], eval_df['eval_success_rate'],
                style, label=label, alpha=0.8)
ax.set_xlabel('train_step')
ax.set_ylabel('in-training eval success (every 10k step, 100 ep)')
ax.set_title(f'{CELL_ID}: learning curves (eval_log.csv)')
ax.set_ylim(0, 1.0)
ax.legend(loc='lower right', fontsize=9)
ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# [ok] all 4 test json present
# [per-seed test results]
#   algo  seed  success_rate  mean_return  return_std  safety_cost  path_eff  progress  goal_pct  timeout_pct  oob_pct
# rebrac    42        1.0000     140.1589      3.8005       2.1539    0.8577    0.9074    1.0000       0.0000   0.0000
# rebrac     0        0.9800     133.5454     44.6152       2.4712    0.8557    0.9049    0.9800       0.0000   0.0200
#    fql    42        0.9600     128.5734     62.0559       2.0589    0.8758    0.9019    0.9600       0.0000   0.0400
#    fql     0        0.9500     125.0902     70.1180       2.1882    0.8708    0.8971    0.9500       0.0000   0.0500
#
# [per-algo aggregate (mean ± std over n=2 seeds)]
#   algo  success_mean  success_std  return_mean  return_std  safety_mean  path_eff_mean  goal_pct_mean  timeout_pct_mean  oob_pct_mean
#    fql        0.9550       0.0050     126.8318      1.7416       2.1236         0.8733         0.9550            0.0000        0.0450
# rebrac        0.9900       0.0100     136.8522      3.3067       2.3125         0.8567         0.9900            0.0000        0.0100

# %% [markdown]
# ## 7. 自动 verdict — effect-size + 方向一致性(per spec §5.4)
#
# **本 cell 预期方向**:`positive` — 若 POSITIVE → paper claim 主结论确证。若 NULL → paper claim 失败,iff 部分(FQL>ReBRAC 在 sub-opt × multi-modal)未被复现 → P2 重审或 paper claim 重写。
#
# **阈值**:`δ_null = 0.03` + `δ_signal = 0.05` + gray band [3pp, 5pp]。
#
# **输出**:
# 1. `Δ = mean(success_fql) - mean(success_rebrac)` over seeds
# 2. paired diff per seed:`Δ_seed = success_fql_seed - success_rebrac_seed`
# 3. 方向一致性:两 seed paired diff 同号 ?
# 4. c4 stability(per spec §5.6,n=2 threshold = −0.01549,from `eval_log.csv` last 30%)
# 5. **Verdict**:NULL / POSITIVE / GRAY(per §5.4 表)

# %%
import numpy as np
from scipy.stats import linregress

DELTA_NULL = 0.03
DELTA_SIGNAL = 0.05
C4_THRESHOLD_N2 = -0.01549  # per spec §5.6 n=2 Option α
EXPECTED_DIRECTION = 'positive'  # 'null' or 'positive'

# ---- 1. Aggregate success per algo ----
succ_rebrac = df.query("algo == 'rebrac'")['success_rate'].values
succ_fql    = df.query("algo == 'fql'")['success_rate'].values
delta_mean = succ_fql.mean() - succ_rebrac.mean()

# ---- 2. Paired diff per seed ----
paired = {}
for seed in TRAIN_SEEDS:
    s_r = df.query(f'algo == "rebrac" and seed == {seed}')['success_rate'].iloc[0]
    s_f = df.query(f'algo == "fql" and seed == {seed}')['success_rate'].iloc[0]
    paired[seed] = s_f - s_r

all_positive = all(d > 0 for d in paired.values())
all_negative = all(d < 0 for d in paired.values())
all_near_zero = all(abs(d) < 0.04 for d in paired.values())
direction_consistent = all_positive or all_negative or all_near_zero

# ---- 3. c4 stability per algo ----
c4 = {}
for algo in ALGOS:
    slopes = []
    for seed in TRAIN_SEEDS:
        csv_p = mirror_dir(algo, seed) / 'eval_log.csv'
        if not csv_p.exists():
            continue
        ed = pd.read_csv(csv_p).drop_duplicates(subset='train_step', keep='last')
        # last 30% of eval points
        n_pts = max(int(round(len(ed) * 0.3)), 3)
        tail = ed.tail(n_pts)
        if len(tail) >= 3:
            slope, *_ = linregress(tail['train_step'], tail['eval_success_rate'])
            slopes.append(slope)
    if slopes:
        c4[algo] = {
            'per_seed_slopes': slopes,
            'agg_slope': float(np.mean(slopes)),
            'verdict': 'PASS' if np.mean(slopes) >= C4_THRESHOLD_N2 else 'FAIL',
        }

# ---- 4. Verdict logic (per spec §5.4) ----
print('=' * 72)
print(f'  CELL_ID = {CELL_ID}   expected = {EXPECTED_DIRECTION}')
print('-' * 72)
print(f'  ReBRAC success mean = {succ_rebrac.mean():.4f}   per-seed = {dict(zip(TRAIN_SEEDS, succ_rebrac.tolist()))}')
print(f'  FQL    success mean = {succ_fql.mean():.4f}   per-seed = {dict(zip(TRAIN_SEEDS, succ_fql.tolist()))}')
print(f'  Δ (FQL − ReBRAC) mean = {delta_mean:+.4f} ({delta_mean*100:+.2f} pp)')
print(f'  paired diff per seed  = {dict((s, round(d, 4)) for s, d in paired.items())}')
print(f'  direction_consistent  = {direction_consistent} '
      f'(all_pos={all_positive}, all_neg={all_negative}, all_near_zero={all_near_zero})')
print('-' * 72)
print('  c4 stability monitor (per spec §5.6, n=2 threshold = -0.01549):')
for algo, info in c4.items():
    print(f'    {algo}: agg_slope = {info["agg_slope"]:+.5f}   verdict = {info["verdict"]}'
          f'   per-seed = {[round(s, 5) for s in info["per_seed_slopes"]]}')
print('-' * 72)

# ---- 5. Verdict decision ----
abs_delta = abs(delta_mean)
if EXPECTED_DIRECTION == 'null':
    # paper wants null: |Δ| < 0.03 AND seed diffs all near zero
    if abs_delta < DELTA_NULL and all_near_zero:
        verdict = 'NULL CONFIRMED ✓ (符合 paper claim 预期)'
        next_step = 'log to verdict report; proceed with other cells'
    elif delta_mean >= DELTA_SIGNAL and all_positive:
        verdict = 'UNEXPECTED POSITIVE ⚠ (FQL 在本 cell 也赢 — paper claim 失败)'
        next_step = (
            'paper claim 失败:FQL 不止在 multi-modal 赢,在本 cell 也赢 → '
            'sprint 1 加 seed 7;若仍 positive 则 paper claim 重写'
        )
    elif delta_mean <= -DELTA_SIGNAL and all_negative:
        verdict = 'UNEXPECTED NEGATIVE ⚠ (ReBRAC 在本 cell 显著强于 FQL — paper claim 弱化)'
        next_step = (
            'paper claim 弱化:本 cell 上 ReBRAC > FQL,可能数据 quality 高时 ReBRAC 占优 → '
            'sprint 1 加 seed 7 后写 caveat 段'
        )
    else:
        verdict = 'GRAY (3pp ≤ |Δ| < 5pp 或方向不一致) — 加 seed 7'
        next_step = '扩 n_seeds=3 [42, 0, 7],在 sprint 1 跑'
elif EXPECTED_DIRECTION == 'positive':
    # paper wants positive: Δ ≥ 0.05 AND both seeds positive
    if delta_mean >= DELTA_SIGNAL and all_positive:
        verdict = 'POSITIVE CONFIRMED ✓ (符合 paper claim 预期)'
        next_step = 'paper claim 主结论确证:本 cell 是 iff 的右侧(FQL > ReBRAC on sub-opt × multi-modal)'
    elif abs_delta < DELTA_NULL:
        verdict = 'NULL ❌ (paper claim 失败 — FQL ≯ ReBRAC on multi-modal)'
        next_step = (
            'paper claim 主结论失败:本 cell 是 iff 主证据,如果 NULL → iff 不成立 → '
            'sprint 1 加 seed 7;若仍 NULL 则 paper claim 重写或重设计 dataset'
        )
    elif not all_positive:
        verdict = 'GRAY (mixed direction across seeds) — 加 seed 7'
        next_step = '扩 n_seeds=3 [42, 0, 7];方向一致性 critical for paper claim'
    else:
        verdict = 'GRAY (3pp ≤ Δ < 5pp,方向一致但 effect size 小) — 加 seed 7'
        next_step = '扩 n_seeds=3 [42, 0, 7];考虑 paper 弱化措辞'
else:
    verdict = f'UNKNOWN expected direction {EXPECTED_DIRECTION!r}'
    next_step = 'spec error: §0 verdict 规则需要更新'

print(f'  VERDICT  : {verdict}')
print(f'  NEXT     : {next_step}')

# ---- 6. c4 caveat ----
fql_c4 = c4.get('fql', {}).get('verdict')
if fql_c4 == 'FAIL':
    print(f'  CAVEAT   : FQL c4 FAIL (slope < -0.01549) — paper 写 "FQL stability marginally fails in {CELL_ID}"')
elif fql_c4 == 'PASS':
    print(f'  CAVEAT   : FQL c4 PASS — stability monitor OK')
print('=' * 72)
# Out:
# ========================================================================
#   CELL_ID = m_multi_mix   expected = positive
# ------------------------------------------------------------------------
#   ReBRAC success mean = 0.9900   per-seed = {42: 1.0, 0: 0.98}
#   FQL    success mean = 0.9550   per-seed = {42: 0.96, 0: 0.95}
#   Δ (FQL − ReBRAC) mean = -0.0350 (-3.50 pp)
#   paired diff per seed  = {42: np.float64(-0.04), 0: np.float64(-0.03)}
#   direction_consistent  = True (all_pos=False, all_neg=True, all_near_zero=False)
# ------------------------------------------------------------------------
#   c4 stability monitor (per spec §5.6, n=2 threshold = -0.01549):
#     rebrac: agg_slope = +0.00000   verdict = PASS   per-seed = [np.float64(0.0), np.float64(-0.0)]
#     fql: agg_slope = +0.00000   verdict = PASS   per-seed = [np.float64(0.0), np.float64(0.0)]
# ------------------------------------------------------------------------
#   VERDICT  : GRAY (mixed direction across seeds) — 加 seed 7
#   NEXT     : 扩 n_seeds=3 [42, 0, 7];方向一致性 critical for paper claim
#   CAVEAT   : FQL c4 PASS — stability monitor OK
# ========================================================================

# %% [markdown]
# ## 8. 报告写入清单
#
# **任何 verdict(必填)**
#
# - [`docs/fql_succession_p2_main_spec.md`](../docs/fql_succession_p2_main_spec.md) §5(verdict)→ m_multi_mix 行填写:n_seeds,Δ_mean,paired diff,direction,verdict
# - `docs/fql_succession_p2_results.md`(待 P2 闭环时创建)→ 本 cell 段:per-seed table + verdict + c4 monitor
# - [`docs/fql_succession_plan_v0.md`](../docs/fql_succession_plan_v0.md) P2 进度行:本 cell run done
#
# **预期 verdict = POSITIVE**
#
# - 符合 paper claim:**POSITIVE** — FQL > ReBRAC by ≥5pp 且两 seed 同方向(paper claim 的 iff 主要支撑)
# - 本 cell 是 iff 的右侧(POSITIVE 期望角),3 cell 都对则 paper §results 主表的 iff 行确证
#
# **verdict = 与预期相反(详见 §7 的 next_step)**
#
# - NULL → paper claim 主结论失败,本 cell 是 iff 主证据;sprint 1 加 seed 7 + 检查 dataset modality (若 audit p_≥2 略低于 0.35 → 触发 spec §2.4 conditional 3-way mix upgrade)
#
#
# **verdict = GRAY**
#
# - 扩 n_seeds=3 [42, 0, 7] 跑本 notebook(把 `TRAIN_SEEDS = [42, 0]` 改成 `[42, 0, 7]` 然后重跑 §4 / §5;§3 skip-resume 会跳过已 done 的 seed 42 / 0,只新跑 seed 7)
# - 重新跑 §6 / §7,新 c4 阈值 = −0.01267(spec §5.6 n=3 行)
#
# **跨 cell aggregation(待 3 cell 都跑完)**
#
# - `notebooks/fql_succession_p2_verdict.ipynb`(P2 闭环时另起):一次 sweep 3 cell × 4 run = 12 个 test json
# - aggregation 命令(本机 sync `results/` 后):
#   ```python
#   import json
#   from pathlib import Path
#   rows = []
#   for cell in ['e_uni', 'm_uni_noise', 'm_multi_mix']:
#       for algo in ['rebrac', 'fql']:
#           for seed in [42, 0]:
#               p = Path(f'results/fql_succession/p2/{cell}/test/{algo}_seed{seed}.json')
#               d = json.loads(p.read_text())
#               rows.append({'cell': cell, 'algo': algo, 'seed': seed,
#                            'success': d['eval_success_rate'],
#                            'return':  d['eval_return']})
#   ```
