# %% [markdown]
# # SAC Collector Head-to-Head — Sprint 2 (seed=0): FQL × 4 tier sweep
#
# **状态**：ACTIVE — sprint 2 启动决策 land 2026-05-25 (expert review 完成 commit `4edee37`)。Per-seed shard。
#
# **目标**：执行 [`docs/arrival_v2_sac_collector_design.md`](../docs/arrival_v2_sac_collector_design.md) **rev.3 §4.0.8 v2 + §4.0.9** Sprint 2 — FQL（flow_steps=10, distill_alpha_bc=1.0）× 4 tier × **seed 0** = **4 run**（per-seed shard）。与 sprint 1 ReBRAC seed shard 1:1 对位组成 SAC-collector head-to-head 完整矩阵（algorithm × tier × seed）。
#
# **Seed-split rationale**：原 12-run sweep 按 seed 拆成 3 个 notebook (seed=42 / 0 / 7)，每份 4 run / ~3.5h L4，可在 Colab Pro 多 session 并发开跑（理想 wall ~3.5h vs 串行 10-11h）。三份共同输出 12 run 与原协议完全等价。其它两份：[`_seed42`](./sac_collector_h2h_fql_sweep_seed42.ipynb) / [`_seed0`](./sac_collector_h2h_fql_sweep_seed0.ipynb) / [`_seed7`](./sac_collector_h2h_fql_sweep_seed7.ipynb)。
#
# **前置 commits（已闭环）**：
# - `97d394c` — SACCheckpointPolicy adapter (5 tests pass)
# - `032b527` — Plan A 4 tier dataset collection completed
# - `3cfd18a` — spec rev.3 §4.0.7 actual results land
# - `5070862` — IPython shell magic refactor (sprint 1 style)
# - `104c14c` — sprint 1 ReBRAC 24 run completed
# - `4edee37` — sprint 1 expert-review verdict correction
#
# **配置（spec §4.0.8 v2 锁定）**：
#
# | 项 | 值 | 来源 |
# |---|---|---|
# | Algo | FQL（vanilla critic） | FQL P2 v1.4 standard |
# | Flow-matching teacher | `--flow-steps 10 --flow-time-embed-dim 32 --teacher-lr 3e-4` | FQL P2 c1 alpha sweep frozen |
# | Distill α_bc | `--distill-alpha-bc 1.0` | FQL P2 C-1 baseline (RESCUE-FAIL reference) |
# | Datasets | 4 tier (random/medium/mexp/expert, step25k/425k/575k/600k) | Plan A 4 tier completed |
# | Seed (本 shard) | **[0]** | 与 sprint 1 ReBRAC paired (full set = [42, 0, 7]) |
# | Total steps | 200_000 (uniform sampling) — FQL P2 §6.2 sister | FQL P2 v1.4 |
# | batch / hidden / layers | 256 / 256 / 3 | 同上 |
# | lr / γ / τ | 3e-4 / 0.99 / 0.005 | 同上 |
# | Manifest (eval) | `benchmarks/single_u10_cross_tgt15.json` (30 ep/run, test_seed=456) | 与 sprint 1 paired |
#
# **预算 (本 shard, seed=0)**：
#
# | 阶段 | run | wallclock |
# |---|---:|---:|
# | Train: FQL × 4 tier × 1 seed | 4 | ~3.3h L4 |
# | evaluate_offline × 4 run | 4 | ~10 min L4 |
# | **Sprint 2 (seed=0) total** | **4** | **~3.5h L4** |
#
# → 1 个 Colab Pro L4 session 紧凑可完。三份 (seed=42/0/7) 同时启动 → 理想总 wall ~3.5h。
#
# **实测要点**（基于 sprint 1 expert review）：
# 1. **唯一可被 sprint 2 reliably falsify 的 finding 是 finding 2** (FQL vs ReBRAC β1=1 on SAC clean expert)。sprint 1 已知 SAC expert ceiling = 0.889 (ReBRAC β1∈{1,4} 都达到此值)。
# 2. **SAC mexp tier 是有 statistical power 的 cell** — sprint 1 显示 β1=1 stratified CI 不跨 0 (β1=1 wins). FQL on mexp 数字关键：是否 ≥ ReBRAC β1=1 的 0.800？
# 3. **SAC random tier degenerate** — FQL 几乎必然也 0%，不会带来 finding signal。
# 4. **SAC medium tier informative**: ReBRAC β1=1 0.656 vs β1=4 0.633 (direction-only, CI 跨 0)。FQL 数字定 finding 1 cross-algo generalization。
#
# **Pre-registered finding 2 + 加强 narrative**（详 spec §4.0.9）：
# - **Finding 2 verify**: FQL on SAC expert ↔ ReBRAC β1=1 paired Δ CI 不跨 0 + Δ < 0 → 复现 FQL P2 C-1 RESCUE-FAIL on SAC clean regime; CI 跨 0 / Δ ≥ 0 → SAC dataset-bound regime 允许 FQL 也达到 ceiling
# - **Cross-algorithm matrix complete**: ReBRAC β1∈{1,4} + FQL 全 12 cell × 4 tier × 3 seed (sprint 1 + sprint 2 共 36 run)

# %% [markdown]
# ## 0. 环境检查

# %%
import torch
print(f"PyTorch:        {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"Device name:    {torch.cuda.get_device_name(0)}")
# Out:
# PyTorch:        2.10.0+cu128
# CUDA available: True
# Device name:    NVIDIA L4

# %% [markdown]
# ## 1. 挂载 Drive + cd 到项目根

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/"MyDrive"/"Colab Notebooks"/"new_offRL"/"rl_v2_5"
# !pwd
# Out:
# /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5
# /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5

# %% [markdown]
# ## 2. Sanity check — 4 dataset + manifest 存在
#
# **预期**：5 项 ✅。任何 ⚠️ 都需停下定位（不要跳过 sanity 直接开跑）。

# %%
from pathlib import Path

TIERS = [
    ("random", "step25k"),
    ("medium", "step425k"),
    ("mexp",   "step575k"),
    ("expert", "step600k"),
]

def dataset_dir(tier: str, step_tag: str) -> Path:
    return Path(f"offline_data/sac_{tier}_s0_h4_arrival_v2_re150_u10cross_seed46_{step_tag}_ep1000")

MANIFEST = Path("benchmarks/single_u10_cross_tgt15.json")

all_ok = True
for tier, step_tag in TIERS:
    d = dataset_dir(tier, step_tag)
    npz = d / "transitions.npz"
    if npz.exists():
        print(f"  ✅ {tier:10s}  {npz}  ({npz.stat().st_size/1e6:.1f} MB)")
    else:
        print(f"  ⚠️ {tier:10s}  {npz}  NOT FOUND")
        all_ok = False

print()
if MANIFEST.exists():
    print(f"  ✅ manifest  {MANIFEST}  ({MANIFEST.stat().st_size/1e3:.1f} KB)")
else:
    print(f"  ⚠️ manifest  {MANIFEST}  NOT FOUND — 用 generate_standard_benchmarks 先生成")
    all_ok = False

print()
if all_ok:
    print("✅ Sanity check passed — 可以开始 training.")
else:
    raise FileNotFoundError("Sanity check failed — 见上面 ⚠️ 项，定位后 rerun.")
# Out:
#   ✅ random      offline_data/sac_random_s0_h4_arrival_v2_re150_u10cross_seed46_step25k_ep1000/transitions.npz  (21.4 MB)
#   ✅ medium      offline_data/sac_medium_s0_h4_arrival_v2_re150_u10cross_seed46_step425k_ep1000/transitions.npz  (29.9 MB)
#   ✅ mexp        offline_data/sac_mexp_s0_h4_arrival_v2_re150_u10cross_seed46_step575k_ep1000/transitions.npz  (20.6 MB)
#   ✅ expert      offline_data/sac_expert_s0_h4_arrival_v2_re150_u10cross_seed46_step600k_ep1000/transitions.npz  (13.7 MB)
#
#   ✅ manifest  benchmarks/single_u10_cross_tgt15.json  (17.0 KB)
#
# ✅ Sanity check passed — 可以开始 training.

# %% [markdown]
# ## 3. Config matrix — 12 run plan
#
# **Run identifier**：`fql__{tier}__seed_{42|0|7}` — 与 spec §4.0.8 v2 输出 schema 对齐。
#
# **Skip-resume 协议**：per run 检查 `<save-dir>/agent_final.pt` 是否存在；存在则 skip（train 函数末尾才写，不会 false-positive）。

# %%
SEEDS = [0]  # per-seed shard; full set = [42, 0, 7] (seed42 / seed0 / seed7 notebooks)

CKPT_ROOT = Path("checkpoints/offline/sac_collector_h2h/fql")
RESULTS_ROOT = Path("results/offline/sac_collector_h2h/fql")

def save_dir(tier: str, seed: int) -> Path:
    return CKPT_ROOT / tier / f"seed_{seed}"

def test_result_path(tier: str, seed: int) -> Path:
    return RESULTS_ROOT / tier / f"seed_{seed}" / "test_result.json"

# Print plan + check skip-state
n_total = 0
n_done = 0
for tier, step_tag in TIERS:
    for seed in SEEDS:
        n_total += 1
        sd = save_dir(tier, seed)
        done_marker = sd / "agent_final.pt"
        status = "✅ DONE" if done_marker.exists() else "⏳ TODO"
        if done_marker.exists():
            n_done += 1
        print(f"  [{status}]  fql | {tier:10s} | seed={seed}  →  {sd}")
    print()

print(f"=== {n_done}/{n_total} runs already complete (skip-resume) ===")
# Out:
#   [⏳ TODO]  fql | random     | seed=0  →  checkpoints/offline/sac_collector_h2h/fql/random/seed_0
#
#   [⏳ TODO]  fql | medium     | seed=0  →  checkpoints/offline/sac_collector_h2h/fql/medium/seed_0
#
#   [⏳ TODO]  fql | mexp       | seed=0  →  checkpoints/offline/sac_collector_h2h/fql/mexp/seed_0
#
#   [⏳ TODO]  fql | expert     | seed=0  →  checkpoints/offline/sac_collector_h2h/fql/expert/seed_0
#
# === 0/4 runs already complete (skip-resume) ===

# %% [markdown]
# ## 4. Train — FQL × 4 tier × 3 seed = 12 run (~10h L4)
#
# **协议**（spec §4.0.8 v2 + FQL P2 c1 alpha sweep frozen flags）：`--algo fql --flow-steps 10 --distill-alpha-bc 1.0 --teacher-lr 3e-4 --flow-time-embed-dim 32`。
#
# **Per-run skip-resume**：若 `<save-dir>/agent_final.pt` 已存在则跳过。Colab session crash 后重新运行本 cell 自动接续。
#
# **实时输出**：训练用 `!python ...` IPython shell magic，stdout 直接流式 → 每 1000 step 的 `actor_loss/critic_loss/teacher_loss` 实时滚动显示。
#
# **注意**：12 run × 50 min ≈ 10h，单 Colab Pro L4 session 接近 12h limit。若 session 中断，重启再跑本 cell 会自动 skip 已完成 run。需缩短 wall 时建议按 sprint 1 同样的脚本 (`/tmp/split_sprint1_by_seed.py` 改 SEEDS → 3 份 by seed)，理想 3 session 并发 wall ~3.5h。

# %%
import time
from pathlib import Path

t_start = time.time()

for tier, step_tag in TIERS:
    for seed in SEEDS:
        sd = save_dir(tier, seed)
        sd_str = str(sd)
        npz = str(dataset_dir(tier, step_tag) / "transitions.npz")
        manifest_str = str(MANIFEST)
        if (sd / "agent_final.pt").exists():
            print(f"[skip-train] fql | {tier} | seed={seed} (agent_final.pt exists)")
            continue
        sd.mkdir(parents=True, exist_ok=True)
        print(f"\n{'=' * 72}")
        print(f"  train fql | {tier} | seed={seed}  →  {sd}")
        print(f"{'=' * 72}")
        t0 = time.time()
        # !python -m scripts.train_offline \
            --algo fql \
            --offline-data '{npz}' \
            --manifest '{manifest_str}' \
            --probe-layout s0 \
            --history-length 4 \
            --task-geometry cross_stream \
            --target-speed 1.5 \
            --objective arrival_v2 \
            --sampling-mode uniform \
            --total-steps 200000 \
            --batch-size 256 \
            --hidden-dim 256 \
            --num-hidden-layers 3 \
            --actor-lr 3e-4 \
            --critic-lr 3e-4 \
            --gamma 0.99 \
            --tau 0.005 \
            --flow-steps 10 \
            --flow-time-embed-dim 32 \
            --teacher-lr 3e-4 \
            --distill-alpha-bc 1.0 \
            --grad-clip-norm 10.0 \
            --normalizer-eps 1e-3 \
            --eval-every 0 \
            --skip-final-eval \
            --log-every 1000 \
            --seed {seed} \
            --device cuda \
            --save-dir '{sd_str}'
        print(f"[train done] fql | {tier} | seed={seed} in {(time.time() - t0) / 60:.1f} min")

print(f"\n=== Sprint 2 FQL train complete, total = {(time.time() - t_start) / 60:.1f} min ===")
# Out:
# ========================================================================
#   train fql | random | seed=0  →  checkpoints/offline/sac_collector_h2h/fql/random/seed_0
# ========================================================================
# [offline] algo=fql transitions=180067 obs_dim=48 action_dim=2 protocol=deployable tensor_replay=on eval_workers=1 sampling=uniform total_steps=200000
# [train] step=1 q=-1.270 critic=257.993 actor=1.969 bc=0.969 lambda=0.787
# [train] step=1000 q=-5.343 critic=230.055 actor=1.079 bc=0.079 lambda=0.187
# [train] step=2000 q=-8.420 critic=0.913 actor=1.094 bc=0.094 lambda=0.119
# [train] step=3000 q=-11.961 critic=444.791 actor=1.080 bc=0.080 lambda=0.084
# [train] step=4000 q=-14.697 critic=187.462 actor=1.065 bc=0.065 lambda=0.068
# [train] step=5000 q=-18.012 critic=469.873 actor=1.064 bc=0.064 lambda=0.056
# [train] step=6000 q=-22.397 critic=313.630 actor=1.070 bc=0.070 lambda=0.045
# [train] step=7000 q=-23.823 critic=510.801 actor=1.068 bc=0.068 lambda=0.042
# [train] step=8000 q=-28.408 critic=106.080 actor=1.064 bc=0.064 lambda=0.035
# [train] step=9000 q=-29.251 critic=452.976 actor=1.076 bc=0.076 lambda=0.034
# [train] step=10000 q=-36.883 critic=247.448 actor=1.080 bc=0.080 lambda=0.027
# [train] step=11000 q=-38.482 critic=291.245 actor=1.077 bc=0.077 lambda=0.026
# [train] step=12000 q=-39.525 critic=40.991 actor=1.075 bc=0.075 lambda=0.025
# [train] step=13000 q=-43.054 critic=233.760 actor=1.069 bc=0.069 lambda=0.023
# [train] step=14000 q=-47.763 critic=35.372 actor=1.072 bc=0.072 lambda=0.021
# [train] step=15000 q=-49.432 critic=164.687 actor=1.082 bc=0.082 lambda=0.020
# [train] step=16000 q=-61.085 critic=7.737 actor=1.079 bc=0.079 lambda=0.016
# [train] step=17000 q=-65.261 critic=413.053 actor=1.068 bc=0.068 lambda=0.015
# [train] step=18000 q=-62.698 critic=5.917 actor=1.062 bc=0.062 lambda=0.016
# [train] step=19000 q=-68.890 critic=4.688 actor=1.081 bc=0.081 lambda=0.015
# [train] step=20000 q=-71.799 critic=6.164 actor=1.070 bc=0.070 lambda=0.014
# [train] step=21000 q=-74.968 critic=191.548 actor=1.061 bc=0.061 lambda=0.013
# [train] step=22000 q=-75.744 critic=13.793 actor=1.061 bc=0.061 lambda=0.013
# [train] step=23000 q=-84.374 critic=87.501 actor=1.074 bc=0.074 lambda=0.012
# [train] step=24000 q=-88.487 critic=7.817 actor=1.069 bc=0.069 lambda=0.011
# [train] step=25000 q=-88.158 critic=42.665 actor=1.070 bc=0.070 lambda=0.011
# [train] step=26000 q=-91.181 critic=9.999 actor=1.065 bc=0.065 lambda=0.011
# [train] step=27000 q=-91.998 critic=103.588 actor=1.073 bc=0.073 lambda=0.011
# [train] step=28000 q=-101.733 critic=16.833 actor=1.091 bc=0.091 lambda=0.010
# [train] step=29000 q=-106.124 critic=97.055 actor=1.067 bc=0.067 lambda=0.009
# [train] step=30000 q=-108.928 critic=10.959 actor=1.073 bc=0.073 lambda=0.009
# [train] step=31000 q=-105.474 critic=22.568 actor=1.065 bc=0.065 lambda=0.009
# [train] step=32000 q=-111.805 critic=12.131 actor=1.074 bc=0.074 lambda=0.009
# [train] step=33000 q=-118.954 critic=8.129 actor=1.058 bc=0.058 lambda=0.008
# [train] step=34000 q=-119.436 critic=149.106 actor=1.061 bc=0.061 lambda=0.008
# [train] step=35000 q=-119.597 critic=42.395 actor=1.061 bc=0.061 lambda=0.008
# [train] step=36000 q=-117.702 critic=33.278 actor=1.055 bc=0.055 lambda=0.008
# [train] step=37000 q=-123.841 critic=13.701 actor=1.081 bc=0.081 lambda=0.008
# [train] step=38000 q=-125.269 critic=10.559 actor=1.072 bc=0.072 lambda=0.008
# [train] step=39000 q=-127.672 critic=46.200 actor=1.054 bc=0.054 lambda=0.008
# [train] step=40000 q=-134.924 critic=60.544 actor=1.065 bc=0.065 lambda=0.007
# [train] step=41000 q=-136.396 critic=27.477 actor=1.068 bc=0.068 lambda=0.007
# [train] step=42000 q=-140.025 critic=14.081 actor=1.070 bc=0.070 lambda=0.007
# [train] step=43000 q=-139.440 critic=11.359 actor=1.068 bc=0.068 lambda=0.007
# [train] step=44000 q=-138.688 critic=12.149 actor=1.071 bc=0.071 lambda=0.007
# [train] step=45000 q=-142.990 critic=18.120 actor=1.051 bc=0.051 lambda=0.007
# [train] step=46000 q=-141.693 critic=22.976 actor=1.071 bc=0.071 lambda=0.007
# [train] step=47000 q=-147.068 critic=17.987 actor=1.073 bc=0.073 lambda=0.007
# [train] step=48000 q=-146.976 critic=103.973 actor=1.065 bc=0.065 lambda=0.007
# [train] step=49000 q=-152.686 critic=55.992 actor=1.068 bc=0.068 lambda=0.007
# [train] step=50000 q=-149.251 critic=28.470 actor=1.070 bc=0.070 lambda=0.007
# [train] step=51000 q=-155.958 critic=23.305 actor=1.073 bc=0.073 lambda=0.006
# [train] step=52000 q=-150.598 critic=9.262 actor=1.066 bc=0.066 lambda=0.007
# [train] step=53000 q=-161.048 critic=20.061 actor=1.070 bc=0.070 lambda=0.006
# [train] step=54000 q=-159.930 critic=15.427 actor=1.068 bc=0.068 lambda=0.006
# [train] step=55000 q=-158.995 critic=37.332 actor=1.073 bc=0.073 lambda=0.006
# [train] step=56000 q=-163.698 critic=33.623 actor=1.073 bc=0.073 lambda=0.006
# [train] step=57000 q=-163.896 critic=11.790 actor=1.078 bc=0.078 lambda=0.006
# [train] step=58000 q=-161.716 critic=17.105 actor=1.065 bc=0.065 lambda=0.006
# [train] step=59000 q=-165.044 critic=17.662 actor=1.064 bc=0.064 lambda=0.006
# [train] step=60000 q=-163.377 critic=40.535 actor=1.063 bc=0.063 lambda=0.006
# [train] step=61000 q=-165.224 critic=21.387 actor=1.063 bc=0.063 lambda=0.006
# [train] step=62000 q=-164.007 critic=9.677 actor=1.082 bc=0.082 lambda=0.006
# [train] step=63000 q=-163.882 critic=8.899 actor=1.065 bc=0.065 lambda=0.006
# [train] step=64000 q=-160.648 critic=11.261 actor=1.063 bc=0.063 lambda=0.006
# [train] step=65000 q=-176.089 critic=14.820 actor=1.063 bc=0.063 lambda=0.006
# [train] step=66000 q=-174.290 critic=10.781 actor=1.067 bc=0.067 lambda=0.006
# [train] step=67000 q=-165.470 critic=10.493 actor=1.073 bc=0.073 lambda=0.006
# [train] step=68000 q=-168.769 critic=9.485 actor=1.063 bc=0.063 lambda=0.006
# [train] step=69000 q=-164.736 critic=9.463 actor=1.062 bc=0.062 lambda=0.006
# [train] step=70000 q=-171.273 critic=13.355 actor=1.067 bc=0.067 lambda=0.006
# [train] step=71000 q=-173.427 critic=9.056 actor=1.079 bc=0.079 lambda=0.006
# [train] step=72000 q=-172.014 critic=12.753 actor=1.064 bc=0.064 lambda=0.006
# [train] step=73000 q=-171.104 critic=8.432 actor=1.062 bc=0.062 lambda=0.006
# [train] step=74000 q=-174.470 critic=18.713 actor=1.065 bc=0.065 lambda=0.006
# [train] step=75000 q=-172.819 critic=7.837 actor=1.070 bc=0.070 lambda=0.006
# [train] step=76000 q=-176.080 critic=11.561 actor=1.073 bc=0.073 lambda=0.006
# [train] step=77000 q=-175.702 critic=12.204 actor=1.066 bc=0.066 lambda=0.006
# [train] step=78000 q=-172.042 critic=17.197 actor=1.077 bc=0.077 lambda=0.006
# [train] step=79000 q=-171.320 critic=8.915 actor=1.057 bc=0.057 lambda=0.006
# [train] step=80000 q=-172.726 critic=9.539 actor=1.060 bc=0.060 lambda=0.006
# [train] step=81000 q=-178.402 critic=12.929 actor=1.064 bc=0.064 lambda=0.006
# [train] step=82000 q=-174.565 critic=15.060 actor=1.059 bc=0.059 lambda=0.006
# [train] step=83000 q=-174.982 critic=11.754 actor=1.057 bc=0.057 lambda=0.006
# [train] step=84000 q=-175.580 critic=8.424 actor=1.059 bc=0.059 lambda=0.006
# [train] step=85000 q=-179.326 critic=42.875 actor=1.060 bc=0.060 lambda=0.006
# [train] step=86000 q=-180.679 critic=11.163 actor=1.057 bc=0.058 lambda=0.006
# [train] step=87000 q=-176.305 critic=9.379 actor=1.067 bc=0.070 lambda=0.006
# [train] step=88000 q=-179.293 critic=10.689 actor=1.063 bc=0.063 lambda=0.006
# [train] step=89000 q=-177.654 critic=23.232 actor=1.070 bc=0.070 lambda=0.006
# [train] step=90000 q=-172.900 critic=7.291 actor=1.071 bc=0.072 lambda=0.006
# [train] step=91000 q=-180.092 critic=26.806 actor=1.064 bc=0.064 lambda=0.006
# [train] step=92000 q=-178.797 critic=10.505 actor=1.063 bc=0.063 lambda=0.006
# [train] step=93000 q=-175.880 critic=14.415 actor=1.065 bc=0.066 lambda=0.006
# [train] step=94000 q=-174.813 critic=11.904 actor=1.065 bc=0.065 lambda=0.006
# [train] step=95000 q=-179.791 critic=24.412 actor=1.061 bc=0.061 lambda=0.006
# [train] step=96000 q=-178.039 critic=8.520 actor=1.072 bc=0.072 lambda=0.006
# [train] step=97000 q=-173.813 critic=8.926 actor=1.066 bc=0.066 lambda=0.006
# [train] step=98000 q=-178.881 critic=13.242 actor=1.066 bc=0.066 lambda=0.006
# [train] step=99000 q=-179.461 critic=12.426 actor=1.069 bc=0.069 lambda=0.006
# [train] step=100000 q=-178.940 critic=22.395 actor=1.066 bc=0.067 lambda=0.006
# [train] step=101000 q=-174.149 critic=14.221 actor=1.065 bc=0.065 lambda=0.006
# [train] step=102000 q=-170.248 critic=9.297 actor=1.071 bc=0.071 lambda=0.006
# [train] step=103000 q=-183.804 critic=7.434 actor=1.067 bc=0.067 lambda=0.005
# [train] step=104000 q=-175.004 critic=6.987 actor=1.078 bc=0.078 lambda=0.006
# [train] step=105000 q=-175.967 critic=6.798 actor=1.068 bc=0.068 lambda=0.006
# [train] step=106000 q=-175.190 critic=9.501 actor=1.063 bc=0.063 lambda=0.006
# [train] step=107000 q=-169.982 critic=9.480 actor=1.065 bc=0.070 lambda=0.006
# [train] step=108000 q=-174.368 critic=10.254 actor=1.062 bc=0.063 lambda=0.006
# [train] step=109000 q=-176.577 critic=9.253 actor=1.065 bc=0.066 lambda=0.006
# [train] step=110000 q=-171.176 critic=8.378 actor=1.062 bc=0.062 lambda=0.006
# [train] step=111000 q=-179.625 critic=14.653 actor=1.051 bc=0.057 lambda=0.006
# [train] step=112000 q=-185.257 critic=18.344 actor=1.061 bc=0.061 lambda=0.005
# [train] step=113000 q=-177.222 critic=14.201 actor=1.071 bc=0.071 lambda=0.006
# [train] step=114000 q=-174.779 critic=24.357 actor=1.062 bc=0.065 lambda=0.006
# [train] step=115000 q=-176.173 critic=10.758 actor=1.061 bc=0.061 lambda=0.006
# [train] step=116000 q=-173.586 critic=14.004 actor=1.057 bc=0.063 lambda=0.006
# [train] step=117000 q=-181.279 critic=7.696 actor=1.062 bc=0.062 lambda=0.006
# [train] step=118000 q=-175.909 critic=7.397 actor=1.063 bc=0.063 lambda=0.006
# [train] step=119000 q=-176.335 critic=7.445 actor=1.059 bc=0.059 lambda=0.006
# [train] step=120000 q=-178.389 critic=9.506 actor=1.067 bc=0.067 lambda=0.006
# [train] step=121000 q=-177.323 critic=16.564 actor=1.070 bc=0.070 lambda=0.006
# [train] step=122000 q=-171.428 critic=7.654 actor=1.056 bc=0.063 lambda=0.006
# [train] step=123000 q=-172.802 critic=7.666 actor=1.054 bc=0.061 lambda=0.006
# [train] step=124000 q=-174.370 critic=11.396 actor=1.064 bc=0.072 lambda=0.006
# [train] step=125000 q=-173.300 critic=10.467 actor=1.066 bc=0.066 lambda=0.006
# [train] step=126000 q=-179.012 critic=13.017 actor=1.057 bc=0.057 lambda=0.006
# [train] step=127000 q=-178.636 critic=9.760 actor=1.065 bc=0.073 lambda=0.006
# [train] step=128000 q=-177.356 critic=9.691 actor=1.069 bc=0.069 lambda=0.006
# [train] step=129000 q=-178.346 critic=7.241 actor=1.069 bc=0.069 lambda=0.006
# [train] step=130000 q=-180.628 critic=29.393 actor=1.066 bc=0.069 lambda=0.006
# [train] step=131000 q=-175.375 critic=11.123 actor=1.072 bc=0.076 lambda=0.006
# [train] step=132000 q=-174.761 critic=8.322 actor=1.063 bc=0.063 lambda=0.006
# [train] step=133000 q=-179.959 critic=10.896 actor=1.061 bc=0.061 lambda=0.006
# [train] step=134000 q=-176.057 critic=8.393 actor=1.064 bc=0.071 lambda=0.006
# [train] step=135000 q=-177.085 critic=12.680 actor=1.062 bc=0.062 lambda=0.006
# [train] step=136000 q=-177.761 critic=20.299 actor=1.058 bc=0.058 lambda=0.006
# [train] step=137000 q=-173.108 critic=12.918 actor=1.051 bc=0.066 lambda=0.006
# [train] step=138000 q=-182.001 critic=20.803 actor=1.075 bc=0.075 lambda=0.005
# [train] step=139000 q=-177.068 critic=8.750 actor=1.068 bc=0.068 lambda=0.006
# [train] step=140000 q=-176.889 critic=9.271 actor=1.064 bc=0.071 lambda=0.006
# [train] step=141000 q=-176.952 critic=8.830 actor=1.051 bc=0.063 lambda=0.006
# [train] step=142000 q=-179.752 critic=10.741 actor=1.052 bc=0.069 lambda=0.005
# [train] step=143000 q=-178.582 critic=11.914 actor=1.045 bc=0.062 lambda=0.006
# [train] step=144000 q=-179.944 critic=13.079 actor=1.067 bc=0.071 lambda=0.006
# [train] step=145000 q=-180.740 critic=19.872 actor=1.058 bc=0.063 lambda=0.006
# [train] step=146000 q=-175.111 critic=17.248 actor=1.058 bc=0.065 lambda=0.006
# [train] step=147000 q=-178.859 critic=18.079 actor=1.060 bc=0.067 lambda=0.006
# [train] step=148000 q=-179.842 critic=8.860 actor=1.062 bc=0.062 lambda=0.006
# [train] step=149000 q=-179.658 critic=12.811 actor=1.055 bc=0.061 lambda=0.006
# [train] step=150000 q=-176.816 critic=10.946 actor=1.072 bc=0.072 lambda=0.006
# [train] step=151000 q=-178.105 critic=14.257 actor=1.069 bc=0.072 lambda=0.006
# [train] step=152000 q=-183.623 critic=13.375 actor=1.060 bc=0.060 lambda=0.005
# [train] step=153000 q=-178.397 critic=15.630 actor=1.063 bc=0.063 lambda=0.006
# [train] step=154000 q=-178.706 critic=28.335 actor=1.068 bc=0.069 lambda=0.006
# [train] step=155000 q=-181.909 critic=19.389 actor=1.062 bc=0.062 lambda=0.005
# [train] step=156000 q=-173.994 critic=11.508 actor=1.060 bc=0.072 lambda=0.006
# [train] step=157000 q=-180.276 critic=10.908 actor=1.066 bc=0.066 lambda=0.006
# [train] step=158000 q=-178.492 critic=11.509 actor=1.069 bc=0.069 lambda=0.006
# [train] step=159000 q=-184.220 critic=13.924 actor=1.051 bc=0.051 lambda=0.005
# [train] step=160000 q=-182.807 critic=18.942 actor=1.059 bc=0.059 lambda=0.005
# [train] step=161000 q=-175.737 critic=10.980 actor=1.063 bc=0.063 lambda=0.006
# [train] step=162000 q=-181.895 critic=11.649 actor=1.073 bc=0.073 lambda=0.005
# [train] step=163000 q=-187.094 critic=13.203 actor=1.053 bc=0.053 lambda=0.005
# [train] step=164000 q=-179.012 critic=19.998 actor=1.058 bc=0.058 lambda=0.006
# [train] step=165000 q=-184.163 critic=13.148 actor=1.061 bc=0.061 lambda=0.005
# [train] step=166000 q=-179.687 critic=19.931 actor=1.075 bc=0.075 lambda=0.006
# [train] step=167000 q=-182.461 critic=17.857 actor=1.061 bc=0.061 lambda=0.005
# [train] step=168000 q=-183.056 critic=18.701 actor=1.069 bc=0.069 lambda=0.005
# [train] step=169000 q=-175.289 critic=20.403 actor=1.057 bc=0.062 lambda=0.006
# [train] step=170000 q=-185.186 critic=31.853 actor=1.068 bc=0.068 lambda=0.005
# [train] step=171000 q=-174.423 critic=15.523 actor=1.062 bc=0.062 lambda=0.006
# [train] step=172000 q=-182.341 critic=44.914 actor=1.068 bc=0.068 lambda=0.005
# [train] step=173000 q=-190.783 critic=37.915 actor=1.067 bc=0.067 lambda=0.005
# [train] step=174000 q=-190.687 critic=34.159 actor=1.060 bc=0.069 lambda=0.005
# [train] step=175000 q=-190.655 critic=17.726 actor=1.069 bc=0.069 lambda=0.005
# [train] step=176000 q=-186.195 critic=21.952 actor=1.059 bc=0.063 lambda=0.005
# [train] step=177000 q=-184.259 critic=19.452 actor=1.063 bc=0.065 lambda=0.005
# [train] step=178000 q=-180.980 critic=17.340 actor=1.077 bc=0.077 lambda=0.006
# [train] step=179000 q=-190.787 critic=36.502 actor=1.064 bc=0.069 lambda=0.005
# [train] step=180000 q=-192.553 critic=37.223 actor=1.060 bc=0.060 lambda=0.005
# [train] step=181000 q=-188.380 critic=21.329 actor=1.054 bc=0.054 lambda=0.005
# [train] step=182000 q=-181.355 critic=14.434 actor=1.079 bc=0.079 lambda=0.006
# [train] step=183000 q=-191.151 critic=36.691 actor=1.060 bc=0.060 lambda=0.005
# [train] step=184000 q=-185.069 critic=58.263 actor=1.068 bc=0.071 lambda=0.005
# [train] step=185000 q=-181.868 critic=26.148 actor=1.058 bc=0.058 lambda=0.005
# [train] step=186000 q=-189.034 critic=26.944 actor=1.066 bc=0.066 lambda=0.005
# [train] step=187000 q=-191.599 critic=31.349 actor=1.065 bc=0.065 lambda=0.005
# [train] step=188000 q=-193.425 critic=47.201 actor=1.066 bc=0.066 lambda=0.005
# [train] step=189000 q=-184.514 critic=34.815 actor=1.052 bc=0.057 lambda=0.005
# [train] step=190000 q=-186.095 critic=16.733 actor=1.051 bc=0.068 lambda=0.005
# [train] step=191000 q=-190.117 critic=43.836 actor=1.059 bc=0.059 lambda=0.005
# [train] step=192000 q=-196.489 critic=35.500 actor=1.062 bc=0.063 lambda=0.005
# [train] step=193000 q=-199.026 critic=23.311 actor=1.067 bc=0.067 lambda=0.005
# [train] step=194000 q=-189.742 critic=36.952 actor=1.058 bc=0.058 lambda=0.005
# [train] step=195000 q=-186.424 critic=40.706 actor=1.069 bc=0.073 lambda=0.005
# [train] step=196000 q=-203.336 critic=78.534 actor=1.072 bc=0.072 lambda=0.005
# [train] step=197000 q=-195.892 critic=46.674 actor=1.064 bc=0.065 lambda=0.005
# [train] step=198000 q=-195.211 critic=87.774 actor=1.063 bc=0.077 lambda=0.005
# [train] step=199000 q=-184.798 critic=33.157 actor=1.052 bc=0.071 lambda=0.005
# [train] step=200000 q=-193.543 critic=83.477 actor=1.066 bc=0.066 lambda=0.005
# [train done] fql | random | seed=0 in 47.4 min
#
# ========================================================================
#   train fql | medium | seed=0  →  checkpoints/offline/sac_collector_h2h/fql/medium/seed_0
# ========================================================================
# [offline] algo=fql transitions=250544 obs_dim=48 action_dim=2 protocol=deployable tensor_replay=on eval_workers=1 sampling=uniform total_steps=200000
# [train] step=1 q=-0.476 critic=39.517 actor=1.973 bc=0.975 lambda=2.096
# [train] step=1000 q=-0.545 critic=0.192 actor=0.440 bc=0.087 lambda=0.648
# [train] step=2000 q=-0.889 critic=0.277 actor=0.397 bc=0.073 lambda=0.365
# [train] step=3000 q=-1.087 critic=29.412 actor=0.323 bc=0.082 lambda=0.222
# [train] step=4000 q=-1.257 critic=82.960 actor=0.308 bc=0.062 lambda=0.195
# [train] step=5000 q=-1.019 critic=20.791 actor=0.235 bc=0.079 lambda=0.153
# [train] step=6000 q=-1.863 critic=2.454 actor=0.310 bc=0.074 lambda=0.127
# [train] step=7000 q=-2.064 critic=5.141 actor=0.293 bc=0.067 lambda=0.110
# [train] step=8000 q=-1.797 critic=6.504 actor=0.240 bc=0.064 lambda=0.098
# [train] step=9000 q=-0.259 critic=2.218 actor=0.093 bc=0.071 lambda=0.087
# [train] step=10000 q=-2.751 critic=6.283 actor=0.260 bc=0.056 lambda=0.074
# [train] step=11000 q=-1.465 critic=5.209 actor=0.168 bc=0.064 lambda=0.071
# [train] step=12000 q=2.779 critic=4.203 actor=-0.092 bc=0.074 lambda=0.060
# [train] step=13000 q=-1.506 critic=3.125 actor=0.153 bc=0.069 lambda=0.056
# [train] step=14000 q=1.197 critic=6.065 actor=0.011 bc=0.074 lambda=0.052
# [train] step=15000 q=1.967 critic=19.141 actor=-0.022 bc=0.067 lambda=0.045
# [train] step=16000 q=-1.364 critic=7.878 actor=0.111 bc=0.049 lambda=0.045
# [train] step=17000 q=1.975 critic=4.621 actor=-0.030 bc=0.057 lambda=0.044
# [train] step=18000 q=3.013 critic=6.021 actor=-0.084 bc=0.041 lambda=0.042
# [train] step=19000 q=-1.700 critic=4.600 actor=0.119 bc=0.052 lambda=0.040
# [train] step=20000 q=3.133 critic=7.635 actor=-0.055 bc=0.053 lambda=0.034
# [train] step=21000 q=1.629 critic=4.467 actor=-0.009 bc=0.054 lambda=0.039
# [train] step=22000 q=-1.565 critic=8.043 actor=0.114 bc=0.062 lambda=0.033
# [train] step=23000 q=2.338 critic=8.235 actor=-0.020 bc=0.059 lambda=0.034
# [train] step=24000 q=4.108 critic=8.117 actor=-0.068 bc=0.055 lambda=0.030
# [train] step=25000 q=-2.306 critic=5.731 actor=0.121 bc=0.047 lambda=0.032
# [train] step=26000 q=0.299 critic=15.032 actor=0.049 bc=0.059 lambda=0.034
# [train] step=27000 q=0.931 critic=6.860 actor=0.022 bc=0.050 lambda=0.030
# [train] step=28000 q=2.385 critic=12.115 actor=0.004 bc=0.072 lambda=0.029
# [train] step=29000 q=-1.136 critic=8.370 actor=0.090 bc=0.053 lambda=0.033
# [train] step=30000 q=-1.399 critic=14.535 actor=0.087 bc=0.045 lambda=0.030
# [train] step=31000 q=-9.178 critic=22.258 actor=0.294 bc=0.051 lambda=0.026
# [train] step=32000 q=-5.958 critic=6.674 actor=0.208 bc=0.049 lambda=0.027
# [train] step=33000 q=-7.042 critic=23.130 actor=0.222 bc=0.043 lambda=0.025
# [train] step=34000 q=-8.370 critic=19.613 actor=0.268 bc=0.046 lambda=0.027
# [train] step=35000 q=-2.079 critic=10.630 actor=0.109 bc=0.048 lambda=0.029
# [train] step=36000 q=-6.511 critic=22.229 actor=0.231 bc=0.060 lambda=0.026
# [train] step=37000 q=-3.271 critic=17.853 actor=0.139 bc=0.047 lambda=0.028
# [train] step=38000 q=0.205 critic=9.065 actor=0.035 bc=0.040 lambda=0.025
# [train] step=39000 q=-4.870 critic=18.340 actor=0.177 bc=0.043 lambda=0.027
# [train] step=40000 q=-12.231 critic=8.042 actor=0.374 bc=0.049 lambda=0.027
# [train] step=41000 q=-10.232 critic=11.931 actor=0.326 bc=0.049 lambda=0.027
# [train] step=42000 q=-9.765 critic=7.525 actor=0.283 bc=0.051 lambda=0.024
# [train] step=43000 q=-12.898 critic=9.375 actor=0.372 bc=0.052 lambda=0.025
# [train] step=44000 q=-9.930 critic=8.443 actor=0.301 bc=0.049 lambda=0.025
# [train] step=45000 q=-7.416 critic=73.505 actor=0.233 bc=0.041 lambda=0.026
# [train] step=46000 q=-9.504 critic=6.734 actor=0.309 bc=0.054 lambda=0.027
# [train] step=47000 q=-9.895 critic=9.237 actor=0.296 bc=0.051 lambda=0.025
# [train] step=48000 q=-12.424 critic=7.783 actor=0.391 bc=0.057 lambda=0.027
# [train] step=49000 q=-15.976 critic=34.189 actor=0.417 bc=0.040 lambda=0.024
# [train] step=50000 q=-14.122 critic=13.434 actor=0.420 bc=0.058 lambda=0.026
# [train] step=51000 q=-13.098 critic=21.513 actor=0.382 bc=0.057 lambda=0.025
# [train] step=52000 q=-14.927 critic=12.177 actor=0.411 bc=0.047 lambda=0.024
# [train] step=53000 q=-17.800 critic=28.614 actor=0.463 bc=0.054 lambda=0.023
# [train] step=54000 q=-13.951 critic=9.332 actor=0.371 bc=0.039 lambda=0.024
# [train] step=55000 q=-12.922 critic=7.916 actor=0.371 bc=0.058 lambda=0.024
# [train] step=56000 q=-17.496 critic=128.901 actor=0.426 bc=0.051 lambda=0.021
# [train] step=57000 q=-14.581 critic=6.824 actor=0.383 bc=0.046 lambda=0.023
# [train] step=58000 q=-11.456 critic=7.538 actor=0.336 bc=0.056 lambda=0.024
# [train] step=59000 q=-17.658 critic=5.990 actor=0.502 bc=0.044 lambda=0.026
# [train] step=60000 q=-20.127 critic=11.988 actor=0.507 bc=0.049 lambda=0.023
# [train] step=61000 q=-18.284 critic=314.661 actor=0.491 bc=0.058 lambda=0.024
# [train] step=62000 q=-20.409 critic=12.077 actor=0.547 bc=0.062 lambda=0.024
# [train] step=63000 q=-20.360 critic=18.603 actor=0.526 bc=0.045 lambda=0.024
# [train] step=64000 q=-19.759 critic=15.122 actor=0.476 bc=0.040 lambda=0.022
# [train] step=65000 q=-21.494 critic=9.551 actor=0.548 bc=0.049 lambda=0.023
# [train] step=66000 q=-21.293 critic=21.940 actor=0.535 bc=0.048 lambda=0.023
# [train] step=67000 q=-10.488 critic=9.221 actor=0.299 bc=0.045 lambda=0.024
# [train] step=68000 q=-22.019 critic=11.695 actor=0.556 bc=0.055 lambda=0.023
# [train] step=69000 q=-20.302 critic=17.356 actor=0.519 bc=0.048 lambda=0.023
# [train] step=70000 q=-21.882 critic=11.080 actor=0.563 bc=0.050 lambda=0.023
# [train] step=71000 q=-17.216 critic=9.331 actor=0.453 bc=0.063 lambda=0.023
# [train] step=72000 q=-18.326 critic=7.578 actor=0.481 bc=0.047 lambda=0.024
# [train] step=73000 q=-20.141 critic=8.859 actor=0.508 bc=0.046 lambda=0.023
# [train] step=74000 q=-22.407 critic=277.974 actor=0.534 bc=0.052 lambda=0.021
# [train] step=75000 q=-24.425 critic=8.758 actor=0.585 bc=0.042 lambda=0.022
# [train] step=76000 q=-21.329 critic=11.715 actor=0.503 bc=0.050 lambda=0.021
# [train] step=77000 q=-23.309 critic=23.725 actor=0.576 bc=0.057 lambda=0.022
# [train] step=78000 q=-20.799 critic=10.868 actor=0.474 bc=0.053 lambda=0.020
# [train] step=79000 q=-23.836 critic=12.633 actor=0.567 bc=0.051 lambda=0.022
# [train] step=80000 q=-24.821 critic=6.951 actor=0.588 bc=0.042 lambda=0.022
# [train] step=81000 q=-24.236 critic=8.005 actor=0.551 bc=0.053 lambda=0.021
# [train] step=82000 q=-24.912 critic=13.217 actor=0.599 bc=0.040 lambda=0.022
# [train] step=83000 q=-30.468 critic=6.384 actor=0.696 bc=0.046 lambda=0.021
# [train] step=84000 q=-22.740 critic=13.714 actor=0.528 bc=0.047 lambda=0.021
# [train] step=85000 q=-25.655 critic=8.459 actor=0.594 bc=0.055 lambda=0.021
# [train] step=86000 q=-19.676 critic=43.490 actor=0.478 bc=0.044 lambda=0.022
# [train] step=87000 q=-24.352 critic=12.389 actor=0.555 bc=0.050 lambda=0.021
# [train] step=88000 q=-29.165 critic=8.632 actor=0.670 bc=0.053 lambda=0.021
# [train] step=89000 q=-25.390 critic=6.547 actor=0.564 bc=0.039 lambda=0.021
# [train] step=90000 q=-24.387 critic=12.466 actor=0.566 bc=0.060 lambda=0.021
# [train] step=91000 q=-29.048 critic=12.663 actor=0.655 bc=0.046 lambda=0.021
# [train] step=92000 q=-23.865 critic=12.225 actor=0.567 bc=0.043 lambda=0.022
# [train] step=93000 q=-24.041 critic=8.472 actor=0.581 bc=0.045 lambda=0.022
# [train] step=94000 q=-27.241 critic=17.434 actor=0.594 bc=0.047 lambda=0.020
# [train] step=95000 q=-24.283 critic=35.876 actor=0.539 bc=0.041 lambda=0.021
# [train] step=96000 q=-22.996 critic=15.502 actor=0.520 bc=0.045 lambda=0.021
# [train] step=97000 q=-28.317 critic=6.002 actor=0.656 bc=0.048 lambda=0.021
# [train] step=98000 q=-33.178 critic=12.480 actor=0.715 bc=0.054 lambda=0.020
# [train] step=99000 q=-31.645 critic=6.925 actor=0.730 bc=0.050 lambda=0.021
# [train] step=100000 q=-25.321 critic=76.001 actor=0.570 bc=0.047 lambda=0.021
# [train] step=101000 q=-34.493 critic=20.684 actor=0.722 bc=0.050 lambda=0.019
# [train] step=102000 q=-36.623 critic=13.270 actor=0.734 bc=0.051 lambda=0.019
# [train] step=103000 q=-33.548 critic=24.775 actor=0.700 bc=0.042 lambda=0.020
# [train] step=104000 q=-28.048 critic=6.231 actor=0.614 bc=0.045 lambda=0.020
# [train] step=105000 q=-29.750 critic=10.391 actor=0.602 bc=0.045 lambda=0.019
# [train] step=106000 q=-28.042 critic=12.396 actor=0.612 bc=0.043 lambda=0.020
# [train] step=107000 q=-33.824 critic=43.413 actor=0.691 bc=0.052 lambda=0.019
# [train] step=108000 q=-36.450 critic=7.867 actor=0.731 bc=0.052 lambda=0.019
# [train] step=109000 q=-31.427 critic=5.548 actor=0.682 bc=0.048 lambda=0.020
# [train] step=110000 q=-27.268 critic=11.016 actor=0.575 bc=0.046 lambda=0.019
# [train] step=111000 q=-34.298 critic=21.212 actor=0.708 bc=0.048 lambda=0.019
# [train] step=112000 q=-31.763 critic=9.020 actor=0.663 bc=0.048 lambda=0.019
# [train] step=113000 q=-41.339 critic=198.509 actor=0.795 bc=0.062 lambda=0.018
# [train] step=114000 q=-36.649 critic=26.925 actor=0.735 bc=0.046 lambda=0.019
# [train] step=115000 q=-30.568 critic=18.731 actor=0.601 bc=0.042 lambda=0.018
# [train] step=116000 q=-37.686 critic=28.468 actor=0.771 bc=0.047 lambda=0.019
# [train] step=117000 q=-35.881 critic=13.409 actor=0.718 bc=0.050 lambda=0.019
# [train] step=118000 q=-33.151 critic=8.953 actor=0.691 bc=0.048 lambda=0.019
# [train] step=119000 q=-36.442 critic=11.677 actor=0.703 bc=0.052 lambda=0.018
# [train] step=120000 q=-36.321 critic=9.967 actor=0.749 bc=0.046 lambda=0.019
# [train] step=121000 q=-34.149 critic=8.782 actor=0.695 bc=0.043 lambda=0.019
# [train] step=122000 q=-39.549 critic=26.341 actor=0.710 bc=0.048 lambda=0.017
# [train] step=123000 q=-37.389 critic=8.057 actor=0.735 bc=0.048 lambda=0.018
# [train] step=124000 q=-33.013 critic=15.684 actor=0.686 bc=0.044 lambda=0.019
# [train] step=125000 q=-39.394 critic=25.747 actor=0.776 bc=0.045 lambda=0.019
# [train] step=126000 q=-33.131 critic=19.104 actor=0.667 bc=0.040 lambda=0.019
# [train] step=127000 q=-38.585 critic=7.682 actor=0.737 bc=0.042 lambda=0.018
# [train] step=128000 q=-36.904 critic=6.881 actor=0.777 bc=0.048 lambda=0.020
# [train] step=129000 q=-39.343 critic=27.271 actor=0.742 bc=0.045 lambda=0.018
# [train] step=130000 q=-34.633 critic=17.396 actor=0.707 bc=0.054 lambda=0.019
# [train] step=131000 q=-49.752 critic=85.993 actor=0.860 bc=0.051 lambda=0.016
# [train] step=132000 q=-33.230 critic=13.674 actor=0.671 bc=0.049 lambda=0.019
# [train] step=133000 q=-30.866 critic=15.630 actor=0.665 bc=0.047 lambda=0.020
# [train] step=134000 q=-31.529 critic=13.890 actor=0.638 bc=0.050 lambda=0.019
# [train] step=135000 q=-37.106 critic=13.622 actor=0.736 bc=0.043 lambda=0.019
# [train] step=136000 q=-38.929 critic=67.790 actor=0.728 bc=0.043 lambda=0.018
# [train] step=137000 q=-37.144 critic=12.920 actor=0.741 bc=0.045 lambda=0.019
# [train] step=138000 q=-32.047 critic=39.570 actor=0.666 bc=0.058 lambda=0.019
# [train] step=139000 q=-40.888 critic=17.581 actor=0.733 bc=0.049 lambda=0.017
# [train] step=140000 q=-40.748 critic=10.987 actor=0.795 bc=0.047 lambda=0.018
# [train] step=141000 q=-39.792 critic=15.748 actor=0.765 bc=0.047 lambda=0.018
# [train] step=142000 q=-41.891 critic=14.959 actor=0.765 bc=0.043 lambda=0.017
# [train] step=143000 q=-41.449 critic=11.394 actor=0.792 bc=0.042 lambda=0.018
# [train] step=144000 q=-34.624 critic=27.186 actor=0.659 bc=0.042 lambda=0.018
# [train] step=145000 q=-40.212 critic=25.742 actor=0.768 bc=0.044 lambda=0.018
# [train] step=146000 q=-34.038 critic=18.357 actor=0.676 bc=0.043 lambda=0.019
# [train] step=147000 q=-35.384 critic=13.779 actor=0.708 bc=0.060 lambda=0.018
# [train] step=148000 q=-36.121 critic=9.841 actor=0.725 bc=0.045 lambda=0.019
# [train] step=149000 q=-35.427 critic=30.509 actor=0.669 bc=0.047 lambda=0.018
# [train] step=150000 q=-35.500 critic=26.096 actor=0.734 bc=0.044 lambda=0.019
# [train] step=151000 q=-41.699 critic=19.673 actor=0.766 bc=0.048 lambda=0.017
# [train] step=152000 q=-38.411 critic=36.791 actor=0.697 bc=0.041 lambda=0.017
# [train] step=153000 q=-46.787 critic=21.823 actor=0.816 bc=0.046 lambda=0.016
# [train] step=154000 q=-44.112 critic=47.613 actor=0.811 bc=0.047 lambda=0.017
# [train] step=155000 q=-40.242 critic=11.144 actor=0.764 bc=0.053 lambda=0.018
# [train] step=156000 q=-40.910 critic=21.467 actor=0.738 bc=0.053 lambda=0.017
# [train] step=157000 q=-37.002 critic=12.374 actor=0.761 bc=0.048 lambda=0.019
# [train] step=158000 q=-38.749 critic=13.056 actor=0.707 bc=0.040 lambda=0.017
# [train] step=159000 q=-47.686 critic=31.804 actor=0.846 bc=0.044 lambda=0.017
# [train] step=160000 q=-33.577 critic=21.826 actor=0.667 bc=0.054 lambda=0.018
# [train] step=161000 q=-39.043 critic=12.992 actor=0.743 bc=0.048 lambda=0.018
# [train] step=162000 q=-45.029 critic=23.067 actor=0.814 bc=0.041 lambda=0.017
# [train] step=163000 q=-43.741 critic=24.762 actor=0.769 bc=0.054 lambda=0.016
# [train] step=164000 q=-40.300 critic=19.440 actor=0.730 bc=0.037 lambda=0.017
# [train] step=165000 q=-42.016 critic=15.683 actor=0.748 bc=0.049 lambda=0.017
# [train] step=166000 q=-37.886 critic=48.460 actor=0.677 bc=0.033 lambda=0.017
# [train] step=167000 q=-43.233 critic=26.306 actor=0.772 bc=0.054 lambda=0.017
# [train] step=168000 q=-40.334 critic=20.016 actor=0.762 bc=0.042 lambda=0.018
# [train] step=169000 q=-47.577 critic=34.016 actor=0.817 bc=0.045 lambda=0.016
# [train] step=170000 q=-43.987 critic=8.877 actor=0.760 bc=0.048 lambda=0.016
# [train] step=171000 q=-42.892 critic=11.546 actor=0.786 bc=0.046 lambda=0.017
# [train] step=172000 q=-46.505 critic=20.078 actor=0.820 bc=0.048 lambda=0.017
# [train] step=173000 q=-44.662 critic=19.651 actor=0.779 bc=0.054 lambda=0.016
# [train] step=174000 q=-48.444 critic=20.103 actor=0.836 bc=0.060 lambda=0.016
# [train] step=175000 q=-44.121 critic=22.370 actor=0.767 bc=0.048 lambda=0.016
# [train] step=176000 q=-43.576 critic=14.244 actor=0.752 bc=0.044 lambda=0.016
# [train] step=177000 q=-47.735 critic=15.350 actor=0.794 bc=0.047 lambda=0.016
# [train] step=178000 q=-43.367 critic=28.794 actor=0.796 bc=0.045 lambda=0.017
# [train] step=179000 q=-47.168 critic=18.471 actor=0.809 bc=0.048 lambda=0.016
# [train] step=180000 q=-48.346 critic=14.419 actor=0.785 bc=0.044 lambda=0.015
# [train] step=181000 q=-57.946 critic=30.324 actor=0.886 bc=0.047 lambda=0.014
# [train] step=182000 q=-46.043 critic=38.123 actor=0.799 bc=0.055 lambda=0.016
# [train] step=183000 q=-43.095 critic=15.965 actor=0.733 bc=0.040 lambda=0.016
# [train] step=184000 q=-52.786 critic=17.345 actor=0.843 bc=0.049 lambda=0.015
# [train] step=185000 q=-49.186 critic=29.074 actor=0.790 bc=0.051 lambda=0.015
# [train] step=186000 q=-53.458 critic=20.990 actor=0.839 bc=0.050 lambda=0.015
# [train] step=187000 q=-51.290 critic=21.068 actor=0.803 bc=0.048 lambda=0.015
# [train] step=188000 q=-52.545 critic=30.909 actor=0.829 bc=0.051 lambda=0.015
# [train] step=189000 q=-46.961 critic=97.954 actor=0.769 bc=0.037 lambda=0.016
# [train] step=190000 q=-48.864 critic=41.168 actor=0.794 bc=0.039 lambda=0.015
# [train] step=191000 q=-55.796 critic=21.001 actor=0.872 bc=0.039 lambda=0.015
# [train] step=192000 q=-51.658 critic=20.278 actor=0.825 bc=0.054 lambda=0.015
# [train] step=193000 q=-49.433 critic=12.268 actor=0.820 bc=0.047 lambda=0.016
# [train] step=194000 q=-52.488 critic=26.809 actor=0.829 bc=0.045 lambda=0.015
# [train] step=195000 q=-58.930 critic=20.766 actor=0.863 bc=0.046 lambda=0.014
# [train] step=196000 q=-50.414 critic=31.963 actor=0.848 bc=0.047 lambda=0.016
# [train] step=197000 q=-46.812 critic=24.158 actor=0.798 bc=0.053 lambda=0.016
# [train] step=198000 q=-49.415 critic=22.258 actor=0.814 bc=0.046 lambda=0.016
# [train] step=199000 q=-54.464 critic=23.809 actor=0.840 bc=0.055 lambda=0.014
# [train] step=200000 q=-52.446 critic=45.277 actor=0.807 bc=0.037 lambda=0.015
# [train done] fql | medium | seed=0 in 47.2 min
#
# ========================================================================
#   train fql | mexp | seed=0  →  checkpoints/offline/sac_collector_h2h/fql/mexp/seed_0
# ========================================================================
# [offline] algo=fql transitions=171394 obs_dim=48 action_dim=2 protocol=deployable tensor_replay=on eval_workers=1 sampling=uniform total_steps=200000
# [train] step=1 q=-0.552 critic=0.375 actor=1.974 bc=0.974 lambda=1.810
# [train] step=1000 q=0.525 critic=0.936 actor=-0.178 bc=0.088 lambda=0.506
# [train] step=2000 q=-0.231 critic=204.900 actor=0.143 bc=0.071 lambda=0.314
# [train] step=3000 q=3.828 critic=27.475 actor=-0.529 bc=0.061 lambda=0.154
# [train] step=4000 q=2.202 critic=0.590 actor=-0.369 bc=0.070 lambda=0.200
# [train] step=5000 q=3.924 critic=2.256 actor=-0.429 bc=0.054 lambda=0.123
# [train] step=6000 q=4.524 critic=0.734 actor=-0.447 bc=0.057 lambda=0.111
# [train] step=7000 q=5.683 critic=2.255 actor=-0.355 bc=0.085 lambda=0.077
# [train] step=8000 q=8.941 critic=2.946 actor=-0.551 bc=0.056 lambda=0.068
# [train] step=9000 q=7.087 critic=2.864 actor=-0.420 bc=0.059 lambda=0.068
# [train] step=10000 q=7.364 critic=1.682 actor=-0.415 bc=0.059 lambda=0.064
# [train] step=11000 q=10.354 critic=87.592 actor=-0.513 bc=0.070 lambda=0.056
# [train] step=12000 q=12.835 critic=130.452 actor=-0.486 bc=0.071 lambda=0.043
# [train] step=13000 q=12.646 critic=4.230 actor=-0.523 bc=0.060 lambda=0.046
# [train] step=14000 q=16.352 critic=6.355 actor=-0.529 bc=0.059 lambda=0.036
# [train] step=15000 q=18.218 critic=4.390 actor=-0.607 bc=0.049 lambda=0.036
# [train] step=16000 q=20.968 critic=8.016 actor=-0.644 bc=0.066 lambda=0.034
# [train] step=17000 q=12.873 critic=6.523 actor=-0.414 bc=0.046 lambda=0.036
# [train] step=18000 q=15.980 critic=9.960 actor=-0.466 bc=0.042 lambda=0.032
# [train] step=19000 q=13.178 critic=2.881 actor=-0.394 bc=0.052 lambda=0.034
# [train] step=20000 q=18.825 critic=4.604 actor=-0.555 bc=0.061 lambda=0.033
# [train] step=21000 q=16.767 critic=208.127 actor=-0.487 bc=0.046 lambda=0.032
# [train] step=22000 q=15.113 critic=4.385 actor=-0.485 bc=0.042 lambda=0.035
# [train] step=23000 q=19.388 critic=4.046 actor=-0.546 bc=0.052 lambda=0.031
# [train] step=24000 q=21.510 critic=3.192 actor=-0.567 bc=0.049 lambda=0.029
# [train] step=25000 q=21.584 critic=4.389 actor=-0.542 bc=0.052 lambda=0.028
# [train] step=26000 q=23.568 critic=3.845 actor=-0.562 bc=0.049 lambda=0.026
# [train] step=27000 q=24.625 critic=12.501 actor=-0.585 bc=0.053 lambda=0.026
# [train] step=28000 q=18.971 critic=6.349 actor=-0.468 bc=0.054 lambda=0.028
# [train] step=29000 q=20.218 critic=3.738 actor=-0.501 bc=0.047 lambda=0.027
# [train] step=30000 q=19.772 critic=6.532 actor=-0.477 bc=0.057 lambda=0.027
# [train] step=31000 q=26.223 critic=6.155 actor=-0.549 bc=0.052 lambda=0.023
# [train] step=32000 q=20.922 critic=5.825 actor=-0.483 bc=0.043 lambda=0.025
# [train] step=33000 q=21.052 critic=3.263 actor=-0.450 bc=0.045 lambda=0.024
# [train] step=34000 q=20.745 critic=4.777 actor=-0.464 bc=0.044 lambda=0.024
# [train] step=35000 q=22.185 critic=7.387 actor=-0.492 bc=0.049 lambda=0.024
# [train] step=36000 q=22.158 critic=4.738 actor=-0.481 bc=0.043 lambda=0.024
# [train] step=37000 q=24.391 critic=5.595 actor=-0.520 bc=0.053 lambda=0.023
# [train] step=38000 q=23.672 critic=5.805 actor=-0.468 bc=0.039 lambda=0.021
# [train] step=39000 q=21.338 critic=4.111 actor=-0.442 bc=0.048 lambda=0.023
# [train] step=40000 q=22.723 critic=7.741 actor=-0.448 bc=0.039 lambda=0.021
# [train] step=41000 q=19.024 critic=5.390 actor=-0.382 bc=0.047 lambda=0.023
# [train] step=42000 q=20.572 critic=4.294 actor=-0.425 bc=0.039 lambda=0.023
# [train] step=43000 q=27.441 critic=7.231 actor=-0.535 bc=0.040 lambda=0.021
# [train] step=44000 q=17.513 critic=9.825 actor=-0.347 bc=0.049 lambda=0.023
# [train] step=45000 q=18.987 critic=5.142 actor=-0.389 bc=0.040 lambda=0.023
# [train] step=46000 q=19.888 critic=3.786 actor=-0.419 bc=0.043 lambda=0.023
# [train] step=47000 q=16.628 critic=4.285 actor=-0.332 bc=0.047 lambda=0.023
# [train] step=48000 q=16.938 critic=5.431 actor=-0.337 bc=0.043 lambda=0.022
# [train] step=49000 q=17.137 critic=16.728 actor=-0.306 bc=0.049 lambda=0.021
# [train] step=50000 q=17.987 critic=4.983 actor=-0.328 bc=0.050 lambda=0.021
# [train] step=51000 q=12.802 critic=3.778 actor=-0.241 bc=0.057 lambda=0.023
# [train] step=52000 q=16.553 critic=7.773 actor=-0.334 bc=0.042 lambda=0.023
# [train] step=53000 q=12.341 critic=16.750 actor=-0.251 bc=0.046 lambda=0.024
# [train] step=54000 q=22.517 critic=5.818 actor=-0.450 bc=0.039 lambda=0.022
# [train] step=55000 q=10.164 critic=4.414 actor=-0.198 bc=0.043 lambda=0.024
# [train] step=56000 q=17.817 critic=3.512 actor=-0.334 bc=0.056 lambda=0.022
# [train] step=57000 q=17.115 critic=8.436 actor=-0.321 bc=0.055 lambda=0.022
# [train] step=58000 q=14.513 critic=5.569 actor=-0.267 bc=0.049 lambda=0.022
# [train] step=59000 q=18.854 critic=4.192 actor=-0.351 bc=0.044 lambda=0.021
# [train] step=60000 q=12.701 critic=4.649 actor=-0.237 bc=0.053 lambda=0.023
# [train] step=61000 q=14.910 critic=2.673 actor=-0.278 bc=0.041 lambda=0.021
# [train] step=62000 q=13.002 critic=3.489 actor=-0.223 bc=0.058 lambda=0.022
# [train] step=63000 q=14.540 critic=6.774 actor=-0.269 bc=0.037 lambda=0.021
# [train] step=64000 q=11.345 critic=7.995 actor=-0.196 bc=0.047 lambda=0.021
# [train] step=65000 q=18.315 critic=9.494 actor=-0.350 bc=0.034 lambda=0.021
# [train] step=66000 q=12.796 critic=4.404 actor=-0.238 bc=0.046 lambda=0.022
# [train] step=67000 q=15.998 critic=2.929 actor=-0.284 bc=0.044 lambda=0.021
# [train] step=68000 q=8.989 critic=11.896 actor=-0.157 bc=0.041 lambda=0.022
# [train] step=69000 q=6.433 critic=6.007 actor=-0.102 bc=0.048 lambda=0.023
# [train] step=70000 q=12.705 critic=236.243 actor=-0.215 bc=0.048 lambda=0.021
# [train] step=71000 q=12.648 critic=13.505 actor=-0.232 bc=0.046 lambda=0.022
# [train] step=72000 q=17.036 critic=7.324 actor=-0.327 bc=0.050 lambda=0.022
# [train] step=73000 q=10.268 critic=4.673 actor=-0.179 bc=0.043 lambda=0.022
# [train] step=74000 q=14.635 critic=10.037 actor=-0.271 bc=0.041 lambda=0.021
# [train] step=75000 q=9.818 critic=4.478 actor=-0.170 bc=0.040 lambda=0.021
# [train] step=76000 q=10.102 critic=34.418 actor=-0.158 bc=0.052 lambda=0.021
# [train] step=77000 q=10.786 critic=2.671 actor=-0.192 bc=0.041 lambda=0.022
# [train] step=78000 q=14.569 critic=6.488 actor=-0.270 bc=0.042 lambda=0.021
# [train] step=79000 q=9.032 critic=4.226 actor=-0.153 bc=0.045 lambda=0.022
# [train] step=80000 q=15.083 critic=5.332 actor=-0.265 bc=0.043 lambda=0.020
# [train] step=81000 q=14.465 critic=6.107 actor=-0.280 bc=0.037 lambda=0.022
# [train] step=82000 q=12.804 critic=4.318 actor=-0.213 bc=0.044 lambda=0.020
# [train] step=83000 q=14.473 critic=8.396 actor=-0.240 bc=0.042 lambda=0.019
# [train] step=84000 q=9.698 critic=4.649 actor=-0.163 bc=0.041 lambda=0.021
# [train] step=85000 q=10.379 critic=4.052 actor=-0.180 bc=0.043 lambda=0.022
# [train] step=86000 q=10.185 critic=7.044 actor=-0.163 bc=0.040 lambda=0.020
# [train] step=87000 q=8.385 critic=5.371 actor=-0.148 bc=0.039 lambda=0.022
# [train] step=88000 q=10.739 critic=3.777 actor=-0.187 bc=0.044 lambda=0.022
# [train] step=89000 q=14.362 critic=3.852 actor=-0.262 bc=0.042 lambda=0.021
# [train] step=90000 q=12.031 critic=7.557 actor=-0.198 bc=0.051 lambda=0.021
# [train] step=91000 q=14.944 critic=3.518 actor=-0.249 bc=0.047 lambda=0.020
# [train] step=92000 q=13.610 critic=4.474 actor=-0.235 bc=0.051 lambda=0.021
# [train] step=93000 q=13.073 critic=2.896 actor=-0.214 bc=0.045 lambda=0.020
# [train] step=94000 q=12.086 critic=4.512 actor=-0.225 bc=0.038 lambda=0.022
# [train] step=95000 q=9.389 critic=4.161 actor=-0.148 bc=0.044 lambda=0.021
# [train] step=96000 q=12.595 critic=8.010 actor=-0.206 bc=0.049 lambda=0.020
# [train] step=97000 q=3.623 critic=8.365 actor=-0.020 bc=0.051 lambda=0.020
# [train] step=98000 q=11.889 critic=3.658 actor=-0.201 bc=0.049 lambda=0.021
# [train] step=99000 q=9.337 critic=4.969 actor=-0.152 bc=0.042 lambda=0.021
# [train] step=100000 q=13.810 critic=4.626 actor=-0.226 bc=0.054 lambda=0.020
# [train] step=101000 q=10.679 critic=2.575 actor=-0.179 bc=0.033 lambda=0.020
# [train] step=102000 q=3.796 critic=8.090 actor=-0.042 bc=0.038 lambda=0.021
# [train] step=103000 q=7.922 critic=15.863 actor=-0.129 bc=0.044 lambda=0.022
# [train] step=104000 q=12.245 critic=3.920 actor=-0.201 bc=0.050 lambda=0.020
# [train] step=105000 q=10.870 critic=4.503 actor=-0.181 bc=0.044 lambda=0.021
# [train] step=106000 q=6.013 critic=8.185 actor=-0.083 bc=0.047 lambda=0.022
# [train] step=107000 q=3.990 critic=13.815 actor=-0.038 bc=0.047 lambda=0.021
# [train] step=108000 q=7.822 critic=5.394 actor=-0.132 bc=0.041 lambda=0.022
# [train] step=109000 q=6.392 critic=5.568 actor=-0.094 bc=0.038 lambda=0.021
# [train] step=110000 q=13.027 critic=8.500 actor=-0.224 bc=0.039 lambda=0.020
# [train] step=111000 q=6.213 critic=8.012 actor=-0.105 bc=0.034 lambda=0.022
# [train] step=112000 q=8.833 critic=12.669 actor=-0.148 bc=0.038 lambda=0.021
# [train] step=113000 q=11.684 critic=2.995 actor=-0.207 bc=0.044 lambda=0.021
# [train] step=114000 q=1.237 critic=6.513 actor=0.026 bc=0.051 lambda=0.020
# [train] step=115000 q=5.534 critic=3.720 actor=-0.081 bc=0.037 lambda=0.021
# [train] step=116000 q=7.973 critic=5.035 actor=-0.125 bc=0.042 lambda=0.021
# [train] step=117000 q=16.120 critic=11.002 actor=-0.291 bc=0.038 lambda=0.020
# [train] step=118000 q=6.889 critic=3.763 actor=-0.095 bc=0.043 lambda=0.020
# [train] step=119000 q=8.291 critic=2.917 actor=-0.138 bc=0.037 lambda=0.021
# [train] step=120000 q=8.543 critic=6.140 actor=-0.131 bc=0.043 lambda=0.020
# [train] step=121000 q=7.989 critic=4.970 actor=-0.133 bc=0.038 lambda=0.021
# [train] step=122000 q=5.641 critic=5.792 actor=-0.070 bc=0.047 lambda=0.021
# [train] step=123000 q=9.252 critic=8.448 actor=-0.145 bc=0.045 lambda=0.021
# [train] step=124000 q=8.654 critic=5.727 actor=-0.141 bc=0.040 lambda=0.021
# [train] step=125000 q=6.343 critic=5.954 actor=-0.094 bc=0.037 lambda=0.021
# [train] step=126000 q=3.670 critic=5.504 actor=-0.038 bc=0.039 lambda=0.021
# [train] step=127000 q=9.992 critic=4.641 actor=-0.169 bc=0.042 lambda=0.021
# [train] step=128000 q=3.818 critic=26.869 actor=-0.029 bc=0.044 lambda=0.019
# [train] step=129000 q=8.328 critic=3.791 actor=-0.118 bc=0.049 lambda=0.020
# [train] step=130000 q=9.475 critic=5.769 actor=-0.146 bc=0.040 lambda=0.020
# [train] step=131000 q=12.537 critic=6.933 actor=-0.217 bc=0.039 lambda=0.020
# [train] step=132000 q=11.402 critic=5.320 actor=-0.192 bc=0.042 lambda=0.021
# [train] step=133000 q=7.608 critic=4.618 actor=-0.116 bc=0.043 lambda=0.021
# [train] step=134000 q=10.207 critic=6.209 actor=-0.167 bc=0.046 lambda=0.021
# [train] step=135000 q=6.514 critic=6.604 actor=-0.098 bc=0.046 lambda=0.022
# [train] step=136000 q=10.712 critic=5.139 actor=-0.188 bc=0.037 lambda=0.021
# [train] step=137000 q=10.231 critic=29.779 actor=-0.169 bc=0.043 lambda=0.021
# [train] step=138000 q=8.845 critic=10.648 actor=-0.144 bc=0.044 lambda=0.021
# [train] step=139000 q=1.569 critic=7.068 actor=0.014 bc=0.048 lambda=0.022
# [train] step=140000 q=11.908 critic=6.298 actor=-0.202 bc=0.043 lambda=0.021
# [train] step=141000 q=11.001 critic=5.388 actor=-0.171 bc=0.043 lambda=0.019
# [train] step=142000 q=10.166 critic=4.569 actor=-0.166 bc=0.040 lambda=0.020
# [train] step=143000 q=10.668 critic=6.506 actor=-0.175 bc=0.039 lambda=0.020
# [train] step=144000 q=7.748 critic=7.470 actor=-0.117 bc=0.049 lambda=0.021
# [train] step=145000 q=6.627 critic=6.017 actor=-0.102 bc=0.038 lambda=0.021
# [train] step=146000 q=11.680 critic=5.042 actor=-0.195 bc=0.039 lambda=0.020
# [train] step=147000 q=8.818 critic=6.351 actor=-0.143 bc=0.040 lambda=0.021
# [train] step=148000 q=7.756 critic=6.936 actor=-0.120 bc=0.037 lambda=0.020
# [train] step=149000 q=5.172 critic=6.977 actor=-0.066 bc=0.045 lambda=0.021
# [train] step=150000 q=4.602 critic=11.681 actor=-0.054 bc=0.044 lambda=0.021
# [train] step=151000 q=8.657 critic=10.447 actor=-0.146 bc=0.043 lambda=0.022
# [train] step=152000 q=11.378 critic=9.025 actor=-0.192 bc=0.043 lambda=0.021
# [train] step=153000 q=-2.209 critic=2.975 actor=0.095 bc=0.049 lambda=0.021
# [train] step=154000 q=8.164 critic=4.317 actor=-0.127 bc=0.046 lambda=0.021
# [train] step=155000 q=7.079 critic=4.614 actor=-0.103 bc=0.038 lambda=0.020
# [train] step=156000 q=4.929 critic=6.283 actor=-0.063 bc=0.041 lambda=0.021
# [train] step=157000 q=7.395 critic=5.493 actor=-0.125 bc=0.044 lambda=0.023
# [train] step=158000 q=0.717 critic=8.576 actor=0.028 bc=0.042 lambda=0.020
# [train] step=159000 q=5.377 critic=3.604 actor=-0.085 bc=0.035 lambda=0.022
# [train] step=160000 q=9.766 critic=12.406 actor=-0.165 bc=0.044 lambda=0.021
# [train] step=161000 q=9.476 critic=21.241 actor=-0.141 bc=0.039 lambda=0.019
# [train] step=162000 q=7.663 critic=5.189 actor=-0.122 bc=0.040 lambda=0.021
# [train] step=163000 q=11.607 critic=4.816 actor=-0.209 bc=0.037 lambda=0.021
# [train] step=164000 q=9.348 critic=8.208 actor=-0.152 bc=0.037 lambda=0.020
# [train] step=165000 q=2.934 critic=7.135 actor=-0.019 bc=0.039 lambda=0.020
# [train] step=166000 q=5.188 critic=6.867 actor=-0.069 bc=0.041 lambda=0.021
# [train] step=167000 q=4.408 critic=9.354 actor=-0.039 bc=0.046 lambda=0.019
# [train] step=168000 q=4.341 critic=7.423 actor=-0.045 bc=0.041 lambda=0.020
# [train] step=169000 q=7.955 critic=9.240 actor=-0.116 bc=0.042 lambda=0.020
# [train] step=170000 q=3.436 critic=4.069 actor=-0.022 bc=0.048 lambda=0.020
# [train] step=171000 q=7.764 critic=4.918 actor=-0.113 bc=0.046 lambda=0.020
# [train] step=172000 q=9.225 critic=11.069 actor=-0.152 bc=0.041 lambda=0.021
# [train] step=173000 q=6.525 critic=5.531 actor=-0.083 bc=0.048 lambda=0.020
# [train] step=174000 q=6.833 critic=5.043 actor=-0.091 bc=0.046 lambda=0.020
# [train] step=175000 q=3.302 critic=5.340 actor=-0.021 bc=0.048 lambda=0.021
# [train] step=176000 q=2.170 critic=8.991 actor=0.000 bc=0.044 lambda=0.020
# [train] step=177000 q=5.283 critic=13.901 actor=-0.068 bc=0.039 lambda=0.020
# [train] step=178000 q=5.520 critic=12.139 actor=-0.072 bc=0.042 lambda=0.021
# [train] step=179000 q=10.581 critic=4.030 actor=-0.172 bc=0.048 lambda=0.021
# [train] step=180000 q=-5.023 critic=15.263 actor=0.146 bc=0.041 lambda=0.021
# [train] step=181000 q=4.474 critic=6.018 actor=-0.056 bc=0.039 lambda=0.021
# [train] step=182000 q=4.416 critic=8.492 actor=-0.042 bc=0.052 lambda=0.021
# [train] step=183000 q=9.337 critic=4.407 actor=-0.156 bc=0.034 lambda=0.020
# [train] step=184000 q=4.122 critic=29.879 actor=-0.039 bc=0.044 lambda=0.020
# [train] step=185000 q=9.337 critic=4.349 actor=-0.147 bc=0.039 lambda=0.020
# [train] step=186000 q=2.342 critic=6.054 actor=0.000 bc=0.047 lambda=0.020
# [train] step=187000 q=5.980 critic=4.048 actor=-0.079 bc=0.047 lambda=0.021
# [train] step=188000 q=2.284 critic=32.284 actor=-0.006 bc=0.041 lambda=0.020
# [train] step=189000 q=-5.961 critic=5.047 actor=0.156 bc=0.040 lambda=0.020
# [train] step=190000 q=6.343 critic=7.639 actor=-0.101 bc=0.038 lambda=0.022
# [train] step=191000 q=9.838 critic=27.163 actor=-0.158 bc=0.047 lambda=0.021
# [train] step=192000 q=7.776 critic=8.375 actor=-0.117 bc=0.036 lambda=0.020
# [train] step=193000 q=7.468 critic=11.698 actor=-0.094 bc=0.050 lambda=0.019
# [train] step=194000 q=13.660 critic=3.480 actor=-0.237 bc=0.041 lambda=0.020
# [train] step=195000 q=5.512 critic=2.907 actor=-0.067 bc=0.042 lambda=0.020
# [train] step=196000 q=10.711 critic=3.146 actor=-0.171 bc=0.042 lambda=0.020
# [train] step=197000 q=12.440 critic=6.277 actor=-0.207 bc=0.042 lambda=0.020
# [train] step=198000 q=7.197 critic=4.338 actor=-0.104 bc=0.044 lambda=0.020
# [train] step=199000 q=4.816 critic=8.006 actor=-0.061 bc=0.041 lambda=0.021
# [train] step=200000 q=4.707 critic=3.419 actor=-0.060 bc=0.035 lambda=0.020
# [train done] fql | mexp | seed=0 in 49.4 min
#
# ========================================================================
#   train fql | expert | seed=0  →  checkpoints/offline/sac_collector_h2h/fql/expert/seed_0
# ========================================================================
# [offline] algo=fql transitions=114832 obs_dim=48 action_dim=2 protocol=deployable tensor_replay=on eval_workers=1 sampling=uniform total_steps=200000
# [train] step=1 q=-0.295 critic=39.734 actor=1.901 bc=0.975 lambda=3.136
# [train] step=1000 q=3.048 critic=53.944 actor=-0.791 bc=0.073 lambda=0.284
# [train] step=2000 q=4.215 critic=28.789 actor=-0.704 bc=0.076 lambda=0.185
# [train] step=3000 q=4.104 critic=6.110 actor=-0.679 bc=0.055 lambda=0.179
# [train] step=4000 q=9.902 critic=2.949 actor=-0.806 bc=0.053 lambda=0.087
# [train] step=5000 q=12.354 critic=1.855 actor=-0.774 bc=0.047 lambda=0.066
# [train] step=6000 q=10.449 critic=2.794 actor=-0.729 bc=0.054 lambda=0.075
# [train] step=7000 q=16.493 critic=2.262 actor=-0.794 bc=0.065 lambda=0.052
# [train] step=8000 q=15.556 critic=2.398 actor=-0.732 bc=0.042 lambda=0.050
# [train] step=9000 q=20.314 critic=3.539 actor=-0.784 bc=0.045 lambda=0.041
# [train] step=10000 q=18.149 critic=5.272 actor=-0.778 bc=0.048 lambda=0.045
# [train] step=11000 q=17.658 critic=11.737 actor=-0.664 bc=0.059 lambda=0.041
# [train] step=12000 q=22.964 critic=6.505 actor=-0.715 bc=0.050 lambda=0.033
# [train] step=13000 q=21.926 critic=44.557 actor=-0.764 bc=0.045 lambda=0.037
# [train] step=14000 q=30.619 critic=5.039 actor=-0.814 bc=0.048 lambda=0.028
# [train] step=15000 q=27.936 critic=3.030 actor=-0.719 bc=0.037 lambda=0.027
# [train] step=16000 q=31.793 critic=3.414 actor=-0.811 bc=0.032 lambda=0.026
# [train] step=17000 q=33.056 critic=5.235 actor=-0.736 bc=0.046 lambda=0.024
# [train] step=18000 q=28.160 critic=2.111 actor=-0.711 bc=0.033 lambda=0.026
# [train] step=19000 q=34.754 critic=4.042 actor=-0.729 bc=0.045 lambda=0.022
# [train] step=20000 q=33.802 critic=4.989 actor=-0.756 bc=0.038 lambda=0.023
# [train] step=21000 q=38.974 critic=9.335 actor=-0.753 bc=0.038 lambda=0.020
# [train] step=22000 q=33.347 critic=2.911 actor=-0.721 bc=0.034 lambda=0.023
# [train] step=23000 q=40.576 critic=4.308 actor=-0.773 bc=0.044 lambda=0.020
# [train] step=24000 q=35.429 critic=8.533 actor=-0.694 bc=0.039 lambda=0.021
# [train] step=25000 q=42.006 critic=48.959 actor=-0.775 bc=0.044 lambda=0.019
# [train] step=26000 q=36.848 critic=5.612 actor=-0.725 bc=0.040 lambda=0.021
# [train] step=27000 q=42.433 critic=5.938 actor=-0.729 bc=0.035 lambda=0.018
# [train] step=28000 q=36.022 critic=8.422 actor=-0.641 bc=0.054 lambda=0.019
# [train] step=29000 q=41.696 critic=3.933 actor=-0.716 bc=0.034 lambda=0.018
# [train] step=30000 q=34.744 critic=63.753 actor=-0.615 bc=0.032 lambda=0.019
# [train] step=31000 q=39.213 critic=5.196 actor=-0.671 bc=0.033 lambda=0.018
# [train] step=32000 q=37.536 critic=4.818 actor=-0.624 bc=0.037 lambda=0.018
# [train] step=33000 q=41.573 critic=3.083 actor=-0.692 bc=0.035 lambda=0.017
# [train] step=34000 q=46.457 critic=4.724 actor=-0.790 bc=0.031 lambda=0.018
# [train] step=35000 q=40.044 critic=4.118 actor=-0.640 bc=0.033 lambda=0.017
# [train] step=36000 q=36.116 critic=14.990 actor=-0.621 bc=0.034 lambda=0.018
# [train] step=37000 q=40.400 critic=6.879 actor=-0.654 bc=0.041 lambda=0.017
# [train] step=38000 q=41.467 critic=2.734 actor=-0.663 bc=0.030 lambda=0.017
# [train] step=39000 q=37.916 critic=46.680 actor=-0.633 bc=0.041 lambda=0.018
# [train] step=40000 q=38.450 critic=66.231 actor=-0.618 bc=0.039 lambda=0.017
# [train] step=41000 q=37.097 critic=2.506 actor=-0.604 bc=0.045 lambda=0.018
# [train] step=42000 q=39.556 critic=2.644 actor=-0.619 bc=0.036 lambda=0.017
# [train] step=43000 q=33.534 critic=5.941 actor=-0.531 bc=0.046 lambda=0.017
# [train] step=44000 q=38.659 critic=5.462 actor=-0.605 bc=0.037 lambda=0.017
# [train] step=45000 q=37.382 critic=7.209 actor=-0.586 bc=0.030 lambda=0.016
# [train] step=46000 q=36.614 critic=7.620 actor=-0.647 bc=0.034 lambda=0.019
# [train] step=47000 q=34.242 critic=4.360 actor=-0.526 bc=0.047 lambda=0.017
# [train] step=48000 q=38.506 critic=5.379 actor=-0.607 bc=0.036 lambda=0.017
# [train] step=49000 q=38.010 critic=5.896 actor=-0.594 bc=0.030 lambda=0.016
# [train] step=50000 q=34.251 critic=13.584 actor=-0.540 bc=0.038 lambda=0.017
# [train] step=51000 q=38.903 critic=281.111 actor=-0.616 bc=0.044 lambda=0.017
# [train] step=52000 q=31.282 critic=5.180 actor=-0.532 bc=0.032 lambda=0.018
# [train] step=53000 q=34.828 critic=16.847 actor=-0.549 bc=0.032 lambda=0.017
# [train] step=54000 q=32.810 critic=5.157 actor=-0.526 bc=0.039 lambda=0.017
# [train] step=55000 q=34.100 critic=6.319 actor=-0.551 bc=0.040 lambda=0.017
# [train] step=56000 q=33.068 critic=19.932 actor=-0.512 bc=0.045 lambda=0.017
# [train] step=57000 q=22.029 critic=6.187 actor=-0.337 bc=0.033 lambda=0.017
# [train] step=58000 q=32.781 critic=18.276 actor=-0.508 bc=0.036 lambda=0.017
# [train] step=59000 q=27.136 critic=24.846 actor=-0.446 bc=0.038 lambda=0.018
# [train] step=60000 q=30.107 critic=8.564 actor=-0.511 bc=0.033 lambda=0.018
# [train] step=61000 q=32.490 critic=8.184 actor=-0.528 bc=0.036 lambda=0.017
# [train] step=62000 q=27.141 critic=9.920 actor=-0.416 bc=0.040 lambda=0.017
# [train] step=63000 q=38.161 critic=256.309 actor=-0.613 bc=0.030 lambda=0.017
# [train] step=64000 q=28.982 critic=39.198 actor=-0.439 bc=0.032 lambda=0.016
# [train] step=65000 q=35.310 critic=5.828 actor=-0.560 bc=0.036 lambda=0.017
# [train] step=66000 q=31.465 critic=6.933 actor=-0.477 bc=0.028 lambda=0.016
# [train] step=67000 q=25.717 critic=3.380 actor=-0.400 bc=0.038 lambda=0.017
# [train] step=68000 q=26.999 critic=90.092 actor=-0.436 bc=0.045 lambda=0.018
# [train] step=69000 q=31.254 critic=9.312 actor=-0.456 bc=0.036 lambda=0.016
# [train] step=70000 q=28.459 critic=10.656 actor=-0.433 bc=0.035 lambda=0.016
# [train] step=71000 q=32.846 critic=5.098 actor=-0.528 bc=0.030 lambda=0.017
# [train] step=72000 q=31.451 critic=7.764 actor=-0.500 bc=0.031 lambda=0.017
# [train] step=73000 q=21.618 critic=24.926 actor=-0.323 bc=0.037 lambda=0.017
# [train] step=74000 q=34.170 critic=9.318 actor=-0.526 bc=0.031 lambda=0.016
# [train] step=75000 q=27.598 critic=9.589 actor=-0.431 bc=0.033 lambda=0.017
# [train] step=76000 q=21.762 critic=12.404 actor=-0.331 bc=0.035 lambda=0.017
# [train] step=77000 q=34.610 critic=6.015 actor=-0.550 bc=0.030 lambda=0.017
# [train] step=78000 q=24.206 critic=6.975 actor=-0.372 bc=0.030 lambda=0.017
# [train] step=79000 q=25.973 critic=9.017 actor=-0.408 bc=0.032 lambda=0.017
# [train] step=80000 q=26.132 critic=10.912 actor=-0.397 bc=0.033 lambda=0.016
# [train] step=81000 q=28.712 critic=5.686 actor=-0.459 bc=0.032 lambda=0.017
# [train] step=82000 q=28.790 critic=27.049 actor=-0.453 bc=0.023 lambda=0.017
# [train] step=83000 q=28.296 critic=8.247 actor=-0.429 bc=0.032 lambda=0.016
# [train] step=84000 q=34.189 critic=6.385 actor=-0.513 bc=0.035 lambda=0.016
# [train] step=85000 q=31.175 critic=17.354 actor=-0.477 bc=0.029 lambda=0.016
# [train] step=86000 q=37.421 critic=13.923 actor=-0.593 bc=0.031 lambda=0.017
# [train] step=87000 q=30.660 critic=11.257 actor=-0.479 bc=0.032 lambda=0.017
# [train] step=88000 q=27.346 critic=429.989 actor=-0.390 bc=0.032 lambda=0.015
# [train] step=89000 q=21.952 critic=20.791 actor=-0.334 bc=0.033 lambda=0.017
# [train] step=90000 q=26.904 critic=7.778 actor=-0.405 bc=0.040 lambda=0.017
# [train] step=91000 q=25.405 critic=4.942 actor=-0.401 bc=0.029 lambda=0.017
# [train] step=92000 q=25.206 critic=12.010 actor=-0.407 bc=0.027 lambda=0.017
# [train] step=93000 q=28.952 critic=18.540 actor=-0.443 bc=0.030 lambda=0.016
# [train] step=94000 q=31.405 critic=4.580 actor=-0.498 bc=0.024 lambda=0.017
# [train] step=95000 q=18.905 critic=5.701 actor=-0.287 bc=0.030 lambda=0.017
# [train] step=96000 q=23.636 critic=11.881 actor=-0.333 bc=0.047 lambda=0.016
# [train] step=97000 q=19.798 critic=36.015 actor=-0.292 bc=0.027 lambda=0.016
# [train] step=98000 q=23.957 critic=10.074 actor=-0.327 bc=0.038 lambda=0.015
# [train] step=99000 q=21.908 critic=38.993 actor=-0.320 bc=0.031 lambda=0.016
# [train] step=100000 q=25.026 critic=30.625 actor=-0.380 bc=0.036 lambda=0.017
# [train] step=101000 q=20.561 critic=50.790 actor=-0.310 bc=0.029 lambda=0.016
# [train] step=102000 q=25.721 critic=6.880 actor=-0.382 bc=0.035 lambda=0.016
# [train] step=103000 q=29.530 critic=5.790 actor=-0.433 bc=0.032 lambda=0.016
# [train] step=104000 q=20.364 critic=19.238 actor=-0.289 bc=0.036 lambda=0.016
# [train] step=105000 q=28.733 critic=10.870 actor=-0.450 bc=0.033 lambda=0.017
# [train] step=106000 q=28.043 critic=13.544 actor=-0.429 bc=0.033 lambda=0.016
# [train] step=107000 q=28.622 critic=21.522 actor=-0.432 bc=0.025 lambda=0.016
# [train] step=108000 q=26.118 critic=4.108 actor=-0.414 bc=0.030 lambda=0.017
# [train] step=109000 q=18.106 critic=37.664 actor=-0.245 bc=0.037 lambda=0.016
# [train] step=110000 q=28.230 critic=5.976 actor=-0.430 bc=0.027 lambda=0.016
# [train] step=111000 q=16.072 critic=15.023 actor=-0.219 bc=0.030 lambda=0.015
# [train] step=112000 q=19.311 critic=8.088 actor=-0.276 bc=0.042 lambda=0.016
# [train] step=113000 q=27.559 critic=11.319 actor=-0.403 bc=0.033 lambda=0.016
# [train] step=114000 q=26.177 critic=6.175 actor=-0.402 bc=0.028 lambda=0.016
# [train] step=115000 q=23.127 critic=30.564 actor=-0.319 bc=0.035 lambda=0.015
# [train] step=116000 q=20.357 critic=14.036 actor=-0.303 bc=0.028 lambda=0.016
# [train] step=117000 q=19.882 critic=34.804 actor=-0.300 bc=0.028 lambda=0.016
# [train] step=118000 q=28.381 critic=16.234 actor=-0.435 bc=0.027 lambda=0.016
# [train] step=119000 q=22.151 critic=7.188 actor=-0.341 bc=0.032 lambda=0.017
# [train] step=120000 q=28.947 critic=74.160 actor=-0.420 bc=0.033 lambda=0.016
# [train] step=121000 q=26.899 critic=8.840 actor=-0.402 bc=0.031 lambda=0.016
# [train] step=122000 q=25.446 critic=22.642 actor=-0.374 bc=0.032 lambda=0.016
# [train] step=123000 q=24.416 critic=7.408 actor=-0.328 bc=0.031 lambda=0.015
# [train] step=124000 q=29.886 critic=13.961 actor=-0.459 bc=0.034 lambda=0.016
# [train] step=125000 q=23.519 critic=54.283 actor=-0.323 bc=0.028 lambda=0.015
# [train] step=126000 q=22.329 critic=28.956 actor=-0.336 bc=0.027 lambda=0.016
# [train] step=127000 q=22.701 critic=11.327 actor=-0.319 bc=0.035 lambda=0.016
# [train] step=128000 q=25.300 critic=8.119 actor=-0.380 bc=0.032 lambda=0.016
# [train] step=129000 q=22.359 critic=87.474 actor=-0.306 bc=0.038 lambda=0.015
# [train] step=130000 q=20.589 critic=23.830 actor=-0.282 bc=0.034 lambda=0.015
# [train] step=131000 q=22.513 critic=64.799 actor=-0.305 bc=0.029 lambda=0.015
# [train] step=132000 q=24.196 critic=9.034 actor=-0.333 bc=0.034 lambda=0.015
# [train] step=133000 q=19.662 critic=6.364 actor=-0.286 bc=0.036 lambda=0.016
# [train] step=134000 q=18.714 critic=4.738 actor=-0.277 bc=0.035 lambda=0.017
# [train] step=135000 q=27.701 critic=4.562 actor=-0.427 bc=0.031 lambda=0.017
# [train] step=136000 q=28.079 critic=15.539 actor=-0.416 bc=0.025 lambda=0.016
# [train] step=137000 q=27.263 critic=6.759 actor=-0.409 bc=0.027 lambda=0.016
# [train] step=138000 q=27.307 critic=385.552 actor=-0.393 bc=0.033 lambda=0.016
# [train] step=139000 q=24.787 critic=56.475 actor=-0.372 bc=0.027 lambda=0.016
# [train] step=140000 q=21.747 critic=3.761 actor=-0.317 bc=0.033 lambda=0.016
# [train] step=141000 q=22.737 critic=175.989 actor=-0.338 bc=0.033 lambda=0.016
# [train] step=142000 q=22.308 critic=3.335 actor=-0.291 bc=0.028 lambda=0.014
# [train] step=143000 q=29.082 critic=5.099 actor=-0.460 bc=0.030 lambda=0.017
# [train] step=144000 q=22.482 critic=12.705 actor=-0.327 bc=0.032 lambda=0.016
# [train] step=145000 q=27.220 critic=15.297 actor=-0.421 bc=0.031 lambda=0.017
# [train] step=146000 q=23.223 critic=15.636 actor=-0.324 bc=0.027 lambda=0.015
# [train] step=147000 q=31.637 critic=46.589 actor=-0.469 bc=0.030 lambda=0.016
# [train] step=148000 q=26.137 critic=4.607 actor=-0.397 bc=0.029 lambda=0.016
# [train] step=149000 q=26.131 critic=8.052 actor=-0.373 bc=0.032 lambda=0.015
# [train] step=150000 q=27.312 critic=7.524 actor=-0.424 bc=0.026 lambda=0.016
# [train] step=151000 q=27.312 critic=7.281 actor=-0.392 bc=0.036 lambda=0.016
# [train] step=152000 q=26.649 critic=3.468 actor=-0.376 bc=0.031 lambda=0.015
# [train] step=153000 q=20.637 critic=5.747 actor=-0.290 bc=0.031 lambda=0.016
# [train] step=154000 q=22.436 critic=7.277 actor=-0.312 bc=0.032 lambda=0.015
# [train] step=155000 q=23.941 critic=7.378 actor=-0.376 bc=0.032 lambda=0.017
# [train] step=156000 q=32.264 critic=5.831 actor=-0.494 bc=0.029 lambda=0.016
# [train] step=157000 q=27.832 critic=4.138 actor=-0.382 bc=0.039 lambda=0.015
# [train] step=158000 q=17.796 critic=5.017 actor=-0.260 bc=0.030 lambda=0.016
# [train] step=159000 q=22.509 critic=8.144 actor=-0.337 bc=0.026 lambda=0.016
# [train] step=160000 q=29.267 critic=12.210 actor=-0.442 bc=0.029 lambda=0.016
# [train] step=161000 q=27.168 critic=10.367 actor=-0.396 bc=0.026 lambda=0.016
# [train] step=162000 q=23.377 critic=6.489 actor=-0.340 bc=0.024 lambda=0.016
# [train] step=163000 q=27.105 critic=9.586 actor=-0.421 bc=0.021 lambda=0.016
# [train] step=164000 q=29.768 critic=21.824 actor=-0.455 bc=0.029 lambda=0.016
# [train] step=165000 q=32.165 critic=3.161 actor=-0.494 bc=0.021 lambda=0.016
# [train] step=166000 q=22.670 critic=89.648 actor=-0.335 bc=0.040 lambda=0.017
# [train] step=167000 q=23.622 critic=12.343 actor=-0.351 bc=0.024 lambda=0.016
# [train] step=168000 q=23.820 critic=3.245 actor=-0.368 bc=0.030 lambda=0.017
# [train] step=169000 q=24.527 critic=4.035 actor=-0.378 bc=0.031 lambda=0.017
# [train] step=170000 q=26.186 critic=3.880 actor=-0.383 bc=0.037 lambda=0.016
# [train] step=171000 q=25.825 critic=2.905 actor=-0.383 bc=0.027 lambda=0.016
# [train] step=172000 q=22.158 critic=9.095 actor=-0.310 bc=0.032 lambda=0.015
# [train] step=173000 q=25.264 critic=3.039 actor=-0.371 bc=0.032 lambda=0.016
# [train] step=174000 q=25.471 critic=3.898 actor=-0.367 bc=0.035 lambda=0.016
# [train] step=175000 q=29.350 critic=5.462 actor=-0.435 bc=0.032 lambda=0.016
# [train] step=176000 q=32.068 critic=4.256 actor=-0.452 bc=0.031 lambda=0.015
# [train] step=177000 q=23.388 critic=3.856 actor=-0.343 bc=0.034 lambda=0.016
# [train] step=178000 q=27.375 critic=17.230 actor=-0.398 bc=0.029 lambda=0.016
# [train] step=179000 q=30.973 critic=5.238 actor=-0.459 bc=0.031 lambda=0.016
# [train] step=180000 q=24.804 critic=3.094 actor=-0.362 bc=0.028 lambda=0.016
# [train] step=181000 q=14.033 critic=5.452 actor=-0.195 bc=0.023 lambda=0.016
# [train] step=182000 q=32.067 critic=3.720 actor=-0.452 bc=0.029 lambda=0.015
# [train] step=183000 q=26.850 critic=6.128 actor=-0.401 bc=0.022 lambda=0.016
# [train] step=184000 q=22.228 critic=4.637 actor=-0.328 bc=0.030 lambda=0.016
# [train] step=185000 q=28.447 critic=2.446 actor=-0.418 bc=0.033 lambda=0.016
# [train] step=186000 q=27.648 critic=7.712 actor=-0.405 bc=0.031 lambda=0.016
# [train] step=187000 q=28.939 critic=5.954 actor=-0.456 bc=0.022 lambda=0.017
# [train] step=188000 q=21.219 critic=3.838 actor=-0.317 bc=0.029 lambda=0.016
# [train] step=189000 q=24.188 critic=7.158 actor=-0.351 bc=0.033 lambda=0.016
# [train] step=190000 q=35.783 critic=3.171 actor=-0.535 bc=0.024 lambda=0.016
# [train] step=191000 q=27.283 critic=2.355 actor=-0.418 bc=0.026 lambda=0.016
# [train] step=192000 q=31.653 critic=4.179 actor=-0.465 bc=0.029 lambda=0.016
# [train] step=193000 q=26.877 critic=6.277 actor=-0.381 bc=0.027 lambda=0.015
# [train] step=194000 q=28.793 critic=5.822 actor=-0.440 bc=0.026 lambda=0.016
# [train] step=195000 q=17.573 critic=2.450 actor=-0.243 bc=0.034 lambda=0.016
# [train] step=196000 q=30.236 critic=7.511 actor=-0.447 bc=0.031 lambda=0.016
# [train] step=197000 q=34.383 critic=2.353 actor=-0.526 bc=0.031 lambda=0.016
# [train] step=198000 q=31.582 critic=1.684 actor=-0.478 bc=0.025 lambda=0.016
# [train] step=199000 q=32.312 critic=4.933 actor=-0.490 bc=0.027 lambda=0.016
# [train] step=200000 q=29.725 critic=7.276 actor=-0.442 bc=0.024 lambda=0.016
# [train done] fql | expert | seed=0 in 49.4 min
#
# === Sprint 2 FQL train complete, total = 193.4 min ===

# %% [markdown]
# ## 5. Evaluate — 12 run × 100 ep test on `single_u10_cross_tgt15`
#
# **Per-run skip-resume**：若 `<results-dir>/test_result.json` 已存在则跳过；若 `<save-dir>/agent_final.pt` 不存在则跳过并打 warn（train 未完）。
#
# **预算**：12 × 2 min ≈ 25 min L4。

# %%
import time

t_start_eval = time.time()

for tier, _ in TIERS:
    for seed in SEEDS:
        sd = save_dir(tier, seed)
        sd_str = str(sd)
        out_path = test_result_path(tier, seed)
        out_path_str = str(out_path)
        manifest_str = str(MANIFEST)
        if out_path.exists():
            print(f"[skip-eval] fql | {tier} | seed={seed} (test_result.json exists)")
            continue
        if not (sd / "agent_final.pt").exists():
            print(f"[warn] fql | {tier} | seed={seed}  missing agent_final.pt — train not done?")
            continue
        out_path.parent.mkdir(parents=True, exist_ok=True)
        print(f"\n{'=' * 72}")
        print(f"  eval  fql | {tier} | seed={seed}  →  {out_path}")
        print(f"{'=' * 72}")
        t0 = time.time()
        # !python -m scripts.evaluate_offline \
            --checkpoint '{sd_str}' \
            --manifest '{manifest_str}' \
            --episodes 100 \
            --seed 456 \
            --device cuda \
            --output-json '{out_path_str}'
        print(f"[eval done] fql | {tier} | seed={seed} in {(time.time() - t0) / 60:.1f} min")

print(f"\n=== Eval all complete, total = {(time.time() - t_start_eval) / 60:.1f} min ===")
# Out:
# ========================================================================
#   eval  fql | random | seed=0  →  results/offline/sac_collector_h2h/fql/random/seed_0/test_result.json
# ========================================================================
# reward_objective      : arrival_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.000000
# episodes              : 30
# success_rate          : 0.0%
# avg_return            : -341.00 +/- 58.89
# avg_safety_cost       : 20.437 +/- 15.042
# avg_time_s            : 87.06 +/- 39.42
# avg_time_s_success    : nan
# avg_energy            : 24228.31 +/- 13668.10
# avg_path_length_m     : 87.27 +/- 39.35
# avg_progress_ratio    : -1.013 +/- 0.822
# avg_path_efficiency   : -0.405 +/- 0.247
# termination           : {'out_of_bounds': 30}
# benchmark_manifest    : benchmarks/single_u10_cross_tgt15.json
# [eval done] fql | random | seed=0 in 1.2 min
#
# ========================================================================
#   eval  fql | medium | seed=0  →  results/offline/sac_collector_h2h/fql/medium/seed_0/test_result.json
# ========================================================================
# reward_objective      : arrival_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.000000
# episodes              : 30
# success_rate          : 83.3%
# avg_return            : 70.43 +/- 130.09
# avg_safety_cost       : 9.576 +/- 10.581
# avg_time_s            : 52.81 +/- 15.07
# avg_time_s_success    : 54.77
# avg_energy            : 39815.37 +/- 8122.65
# avg_path_length_m     : 55.00 +/- 8.36
# avg_progress_ratio    : 0.839 +/- 0.172
# avg_path_efficiency   : 0.667 +/- 0.158
# termination           : {'out_of_bounds': 5, 'goal': 25}
# benchmark_manifest    : benchmarks/single_u10_cross_tgt15.json
# [eval done] fql | medium | seed=0 in 0.7 min
#
# ========================================================================
#   eval  fql | mexp | seed=0  →  results/offline/sac_collector_h2h/fql/mexp/seed_0/test_result.json
# ========================================================================
# reward_objective      : arrival_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.000000
# episodes              : 30
# success_rate          : 90.0%
# avg_return            : 109.86 +/- 87.41
# avg_safety_cost       : 3.779 +/- 5.313
# avg_time_s            : 50.53 +/- 36.24
# avg_time_s_success    : 44.81
# avg_energy            : 37615.69 +/- 17110.60
# avg_path_length_m     : 50.43 +/- 12.60
# avg_progress_ratio    : 0.884 +/- 0.073
# avg_path_efficiency   : 0.784 +/- 0.134
# termination           : {'goal': 27, 'timeout': 1, 'out_of_bounds': 2}
# benchmark_manifest    : benchmarks/single_u10_cross_tgt15.json
# [eval done] fql | mexp | seed=0 in 0.6 min
#
# ========================================================================
#   eval  fql | expert | seed=0  →  results/offline/sac_collector_h2h/fql/expert/seed_0/test_result.json
# ========================================================================
# reward_objective      : arrival_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.000000
# episodes              : 30
# success_rate          : 93.3%
# avg_return            : 125.09 +/- 54.00
# avg_safety_cost       : 2.556 +/- 2.200
# avg_time_s            : 52.58 +/- 50.53
# avg_time_s_success    : 39.19
# avg_energy            : 38640.45 +/- 22612.50
# avg_path_length_m     : 50.83 +/- 18.79
# avg_progress_ratio    : 0.870 +/- 0.142
# avg_path_efficiency   : 0.808 +/- 0.199
# termination           : {'goal': 28, 'timeout': 2}
# benchmark_manifest    : benchmarks/single_u10_cross_tgt15.json
# [eval done] fql | expert | seed=0 in 0.7 min
#
# === Eval all complete, total = 3.2 min ===

# %% [markdown]
# ## 6. Verify summary — 12 test_result.json → table
#
# **输出**：
# - per-tier mean ± std across 3 seeds (success_rate)
# - (Optional) sprint 1 ReBRAC β1=1 / β1=4 per-tier paired comparison — 详细 paired bootstrap CI 留给本地 sprint 1+2 联合 analysis notebook

# %%
import json
import numpy as np

results: dict[str, list[float]] = {}
missing = []
for tier, _ in TIERS:
    seed_successes = []
    for seed in SEEDS:
        p = test_result_path(tier, seed)
        if not p.exists():
            missing.append((tier, seed))
            continue
        data = json.loads(p.read_text())
        sr = float(data.get("eval_success_rate", float("nan")))  # evaluate_offline.py outputs eval_success_rate in [0,1]
        seed_successes.append(sr)
    results[tier] = seed_successes

print("=== FQL head-to-head on SAC tier datasets (test 100 ep × 3 seed) ===\n")
print(f"{'tier':12s} {'FQL α_bc=1 (mean ± std)':25s} {'seeds':>20s}")
print("-" * 70)
for tier, _ in TIERS:
    s = results.get(tier, [])
    m = float(np.mean(s)) if s else float("nan")
    sd_ = float(np.std(s, ddof=0)) if len(s) > 1 else 0.0
    seed_repr = "  ".join(f"{v:.3f}" for v in s) if s else "(empty)"
    print(f"{tier:12s} {m:.3f} ± {sd_:.3f}{'':>13} {seed_repr:>20s}")

print()
if missing:
    print(f"⚠️ {len(missing)} runs missing test_result.json:")
    for m in missing:
        print(f"    {m}")
else:
    print("✅ All 12 runs have test_result.json — sprint 2 complete.")
# Out:
# === FQL head-to-head on SAC tier datasets (test 100 ep × 3 seed) ===
#
# tier         FQL α_bc=1 (mean ± std)                  seeds
# ----------------------------------------------------------------------
# random       0.000 ± 0.000                             0.000
# medium       0.833 ± 0.000                             0.833
# mexp         0.900 ± 0.000                             0.900
# expert       0.933 ± 0.000                             0.933
#
# ✅ All 12 runs have test_result.json — sprint 2 complete.

# %% [markdown]
# ## 7. Next steps（sprint 2 完成后）
#
# 1. **Paired bootstrap analysis（本地 + sprint 1）**：合并 sprint 1 (24 ReBRAC) + sprint 2 (12 FQL) = 36 run 的 test_result.json，对 (tier × algo) 矩阵跑 paired bootstrap 1000 resample CI。重点对位：
#    - expert ↔ FQL P2 E-uni（FQL vs ReBRAC β1=1 paired CI of Δ）
#    - mexp ↔ FQL P2 M-uni-noise
#    - medium ↔ FQL P2 M-multi-mix
# 2. **Finding 候选 2 判定**：在 expert tier, FQL distill_α_bc=1.0 vs ReBRAC β1=1 paired Δ 的 95% CI 若跨 0 → 复现 FQL P2 C-1 RESCUE-FAIL；CI 显著 < 0 → FQL 在 SAC clean expert 上更差（强化 paper 1 结论）。
# 3. **结果回收**：本 notebook 跑完结果落 `_completed.ipynb` 副本 commit 进 git 作实验记录（参考 audit / collection completed 模式）。
