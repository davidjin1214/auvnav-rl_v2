# %% [markdown]
# # FQL Succession P2 — **Cross-Benchmark Confirmation** (`single_u15_cross`, U=1.5/Re250)
#
# **Purpose**: minimally re-test P2's two load-bearing claims on a **harder** benchmark, to harden the mechanism finding's generalization before publication. Spec: `docs/fql_succession_p2_xbench_spec.md`.
#
# P2 closed as **B+A (mechanism finding + honest negative, NOT "FQL wins")** on `single_u10_cross`. This notebook checks the same conclusions reproduce at U=1.5/Re250:
#
# - **C1** — noise (not modality) is the discriminator → test clean vs noisy.
# - **C2** — fixed **ReBRAC β1=1.0 ≥ FQL on worst-case-over-noise** (the apparent "FQL wins" is a β1 mis-tuning artifact), AND the **β1 4→1 noise recovery** reproduces.
#
# ## Design — 12 runs (noise axis only)
#
# | cell | noise | configs | seeds | runs |
# |---|---|---|---|---|
# | `e_uni_clean` | privileged σ=0 | FQL / ReBRAC β1=4.0 / ReBRAC β1=1.0 | 42, 0 | 6 |
# | `m_uni_noise` | privileged σ=0.5 | FQL / ReBRAC β1=4.0 / ReBRAC β1=1.0 | 42, 0 | 6 |
#
# **modality axis dropped** (E-multi was NULL in P2 → modality already exonerated). β1=4.0 kept — it is needed to reproduce the headline mechanism (β1=4 collapses on noise, β1=1 recovers).
#
# ## Order of operations
#
# 1. **§3** prerequisites — generate ep100 manifest + collect 2 datasets (idempotent).
# 2. **§4 FLOOR GATE** — train+eval **1** run (ReBRAC β1=1.0 / clean / seed 42); only proceed if SR ∈ (0.50, 0.97) (learnable AND has headroom). **STOP otherwise.**
# 3. **§5/§6** — the remaining 11 runs + eval (skip-resume skips the gate run).
# 4. **§7/§8** — worst-case-over-noise table + auto verdict.
#
# ## Out of scope
#
# - C-1 FQL `distill_alpha_bc` rematch (only if §8 hits NEW POSITIVE).
# - seed-补 (>2), algo re-tune, edits to Gate-B-frozen `auv_nav/{fql,rebrac}.py`.
# - GMM audit re-run (advisory per D22).

# %% [markdown]
# ## 1. Environment sanity
#
# 确认 cwd 是 repo root + GPU 可用 + `auv_nav` import 通过。

# %%
# !nvidia-smi | head -15
# !lscpu | head -10
# Out:
# Sat May 23 14:34:54 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA L4                      Off |   00000000:00:03.0 Off |                    0 |
# | N/A   49C    P8             13W /   72W |       0MiB /  23034MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# Architecture:                            x86_64
# CPU op-mode(s):                          32-bit, 64-bit
# Address sizes:                           46 bits physical, 48 bits virtual
# Byte Order:                              Little Endian
# CPU(s):                                  12
# On-line CPU(s) list:                     0-11
# Vendor ID:                               GenuineIntel
# Model name:                              Intel(R) Xeon(R) CPU @ 2.20GHz
# CPU family:                              6
# Model:                                   85

# %%
import torch
print(f'torch={torch.__version__}  CUDA available={torch.cuda.is_available()}')
if torch.cuda.is_available():
    print(f'device={torch.cuda.get_device_name(0)}')
# Out:
# torch=2.10.0+cu128  CUDA available=True
# device=NVIDIA L4

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=False)
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5'
# Out:
# /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5

# %%
import os, sys, subprocess
from pathlib import Path

if Path.cwd().name != 'rl_v2':
    candidates = [
        Path('/content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5'),
        Path('/content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2'),
    ]
    for c in candidates:
        if c.exists():
            os.chdir(c); break
    else:
        raise RuntimeError('repo root not found')

print('cwd =', Path.cwd())
import torch
print('torch =', torch.__version__, '  cuda =', torch.cuda.is_available())
if torch.cuda.is_available():
    print('  device =', torch.cuda.get_device_name(0))
import auv_nav
print('auv_nav OK')
# Out:
# cwd = /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5
# torch = 2.10.0+cu128   cuda = True
#   device = NVIDIA L4
# auv_nav OK

# %% [markdown]
# ## 2. Config
#
# 共享参数与 P2 **完全一致**(probe s0 / h4 / target 1.5 / cross_stream / arrival_v2 / 200k steps / batch 256 / eval-every 10k / eval-episodes 100)。唯一变化是 **flow + manifest + dataset** 换到 `re250_u15cross`。
#
# 3 个 config:`fql`(冻结)、`rebrac_b1p4`(默认 β1=4.0)、`rebrac_b1p1`(β1=1.0)。

# %%
from pathlib import Path

FLOW          = 'wake_data/wake_v8_U1p50_Re250_D12p00_dx0p60_Ti5pct_1200f_roi.npy'
MANIFEST      = 'benchmarks/single_u15_cross_tgt15_ep100.json'
DATASET_CLEAN = 'offline_data/fql_succession/xbench_u15cross/e_uni_clean_1000'
DATASET_NOISY = 'offline_data/fql_succession/xbench_u15cross/m_uni_noise_eps0p5_1000'

PROBE_LAYOUT   = 's0'
HISTORY_LENGTH = 4
TARGET_SPEED   = 1.5
TASK_GEOMETRY  = 'cross_stream'
OBJECTIVE      = 'arrival_v2'

# Matches P2 EXACTLY (only flow/manifest/dataset differ).
TOTAL_STEPS    = 200_000
BATCH_SIZE     = 256
EVAL_EVERY     = 10_000
EVAL_EPISODES  = 100   # in-training monitoring; test eval (§6) is the comparison metric
TEST_EPISODES  = 100
EVAL_NUM_WORKERS = 6

# Algo flags. FQL Gate-B-frozen; ReBRAC β2 frozen at 2.0, only β1 ∈ {4.0, 1.0}.
FQL_FLAGS = '--flow-steps 10 --distill-alpha-bc 1.0 --teacher-lr 3e-4 --flow-time-embed-dim 32'

# config: (name, algo, algo-flags)
CONFIGS = [
    ('fql',         'fql',    FQL_FLAGS),
    ('rebrac_b1p4', 'rebrac', '--actor-penalty-coef 4.0 --critic-penalty-coef 2.0'),
    ('rebrac_b1p1', 'rebrac', '--actor-penalty-coef 1.0 --critic-penalty-coef 2.0'),
]

# cell: (cell_name, dataset)
CELLS = [
    ('e_uni_clean', DATASET_CLEAN),
    ('m_uni_noise', DATASET_NOISY),
]
SEEDS = [42, 0]

CKPT_ROOT = Path('checkpoints/fql_succession/p2_xbench')
RES_ROOT  = Path('results/fql_succession/p2_xbench')
MIRROR_FILES = ('train_log.jsonl', 'eval_log.csv', 'trainer_state.json', 'train_config.txt')

def make_job(cell, dataset, cfg_name, algo, flags, seed):
    name = f'{cfg_name}_seed{seed}'
    return {
        'cell': cell, 'dataset': dataset, 'cfg': cfg_name, 'algo': algo,
        'flags': flags, 'seed': seed, 'name': name,
        'ckpt': CKPT_ROOT / cell / name,
        'test_json': RES_ROOT / cell / 'test' / f'{name}.json',
        'mirror': RES_ROOT / cell / 'training_curves' / name,
    }

JOBS = []
for cell, dataset in CELLS:
    for cfg_name, algo, flags in CONFIGS:
        for seed in SEEDS:
            JOBS.append(make_job(cell, dataset, cfg_name, algo, flags, seed))

# FLOOR GATE job = ReBRAC β1=1.0 / clean / seed 42 (run FIRST, see §4).
GATE_JOB = next(j for j in JOBS if j['cell'] == 'e_uni_clean'
                and j['cfg'] == 'rebrac_b1p1' and j['seed'] == 42)

print(f'{len(JOBS)} jobs:')
for j in JOBS:
    gate = '  <-- FLOOR GATE' if j is GATE_JOB else ''
    print(f"  {j['cell']:<12} {j['cfg']:<12} seed={j['seed']:<3} → {j['ckpt']}{gate}")
# Out:
# 12 jobs:
#   e_uni_clean  fql          seed=42  → checkpoints/fql_succession/p2_xbench/e_uni_clean/fql_seed42
#   e_uni_clean  fql          seed=0   → checkpoints/fql_succession/p2_xbench/e_uni_clean/fql_seed0
#   e_uni_clean  rebrac_b1p4  seed=42  → checkpoints/fql_succession/p2_xbench/e_uni_clean/rebrac_b1p4_seed42
#   e_uni_clean  rebrac_b1p4  seed=0   → checkpoints/fql_succession/p2_xbench/e_uni_clean/rebrac_b1p4_seed0
#   e_uni_clean  rebrac_b1p1  seed=42  → checkpoints/fql_succession/p2_xbench/e_uni_clean/rebrac_b1p1_seed42  <-- FLOOR GATE
#   e_uni_clean  rebrac_b1p1  seed=0   → checkpoints/fql_succession/p2_xbench/e_uni_clean/rebrac_b1p1_seed0
#   m_uni_noise  fql          seed=42  → checkpoints/fql_succession/p2_xbench/m_uni_noise/fql_seed42
#   m_uni_noise  fql          seed=0   → checkpoints/fql_succession/p2_xbench/m_uni_noise/fql_seed0
#   m_uni_noise  rebrac_b1p4  seed=42  → checkpoints/fql_succession/p2_xbench/m_uni_noise/rebrac_b1p4_seed42
#   m_uni_noise  rebrac_b1p4  seed=0   → checkpoints/fql_succession/p2_xbench/m_uni_noise/rebrac_b1p4_seed0
#   m_uni_noise  rebrac_b1p1  seed=42  → checkpoints/fql_succession/p2_xbench/m_uni_noise/rebrac_b1p1_seed42
#   m_uni_noise  rebrac_b1p1  seed=0   → checkpoints/fql_succession/p2_xbench/m_uni_noise/rebrac_b1p1_seed0

# %% [markdown]
# ## 3. Prerequisites — ep100 manifest + 2 datasets (idempotent)
#
# 全部 skip-if-exists。manifest 用现有 key + `--output-name` 生成 100-ep 变体;两个 dataset 复用 P2 配方,仅换 flow(本机 6-worker CPU,各 ~3-4 min)。

# %%
from pathlib import Path

# 3.1 ep100 manifest
if not Path(MANIFEST).is_file():
    print('generating ep100 manifest ...')
    # !python -m scripts.generate_standard_benchmarks \
        --benchmarks single_u15_cross_tgt15 \
        --episodes 100 \
        --output-name single_u15_cross_tgt15_ep100
else:
    print(f'[skip] manifest exists: {MANIFEST}')
assert Path(MANIFEST).is_file(), f'manifest still missing: {MANIFEST}'

# 3.2 clean-uni dataset (privileged σ=0)
if not (Path(DATASET_CLEAN) / 'transitions.npz').is_file():
    print('collecting clean-uni dataset ...')
    # !python -m scripts.collect_offline_data --policy privileged \
        --flow '{FLOW}' \
        --probe-layout {PROBE_LAYOUT} --task-geometry {TASK_GEOMETRY} --target-speed {TARGET_SPEED} \
        --history-length {HISTORY_LENGTH} --objective {OBJECTIVE} \
        --episodes 1000 --seed 0 --num-workers 6 --action-noise-std 0.0 \
        --output-dir '{DATASET_CLEAN}'
else:
    print(f'[skip] clean dataset exists: {DATASET_CLEAN}')

# 3.3 noisy-uni dataset (privileged σ=0.5)
if not (Path(DATASET_NOISY) / 'transitions.npz').is_file():
    print('collecting noisy-uni dataset ...')
    # !python -m scripts.collect_offline_data --policy privileged \
        --flow '{FLOW}' \
        --probe-layout {PROBE_LAYOUT} --task-geometry {TASK_GEOMETRY} --target-speed {TARGET_SPEED} \
        --history-length {HISTORY_LENGTH} --objective {OBJECTIVE} \
        --episodes 1000 --seed 1 --num-workers 6 --action-noise-std 0.5 \
        --output-dir '{DATASET_NOISY}'
else:
    print(f'[skip] noisy dataset exists: {DATASET_NOISY}')
# Out:
# generating ep100 manifest ...
# [done] single_u15_cross_tgt15 -> benchmarks/single_u15_cross_tgt15_ep100.json
# collecting clean-uni dataset ...
# [collect] ep=167/1000 transitions=34885 success_rate=71.26% elapsed=1059.6s
# [collect] ep=334/1000 transitions=71495 success_rate=73.35% elapsed=1082.2s
# [collect] ep=501/1000 transitions=106595 success_rate=72.65% elapsed=1082.2s
# [collect] ep=668/1000 transitions=138993 success_rate=71.56% elapsed=1082.2s
# [collect] ep=835/1000 transitions=176733 success_rate=71.86% elapsed=1088.9s
# [collect] ep=1000/1000 transitions=212692 success_rate=71.90% elapsed=1088.9s
#
# [done] Saved 212692 transitions to offline_data/fql_succession/xbench_u15cross/e_uni_clean_1000/transitions.npz
#   policy=privileged  obs_dim=48  action_dim=2
#   episodes=1000  success_rate=71.90%
#   mean_return=28.25 +/- 166.04
# collecting noisy-uni dataset ...
# [collect] ep=167/1000 transitions=41465 success_rate=11.98% elapsed=1203.1s
# [collect] ep=334/1000 transitions=83140 success_rate=11.98% elapsed=1230.4s
# [collect] ep=501/1000 transitions=123462 success_rate=11.58% elapsed=1232.2s
# [collect] ep=668/1000 transitions=162089 success_rate=11.08% elapsed=1232.2s
# [collect] ep=835/1000 transitions=199238 success_rate=10.06% elapsed=1232.2s
# [collect] ep=1000/1000 transitions=234696 success_rate=9.80% elapsed=1232.2s
#
# [done] Saved 234696 transitions to offline_data/fql_succession/xbench_u15cross/m_uni_noise_eps0p5_1000/transitions.npz
#   policy=privileged  obs_dim=48  action_dim=2
#   episodes=1000  success_rate=9.80%
#   mean_return=-180.35 +/- 132.42

# %%
import json
from pathlib import Path

# Pre-flight: datasets + flow + manifest exist; print collection success rates.
for tag, ds, exp_noise in [('clean', DATASET_CLEAN, 0.0), ('noisy', DATASET_NOISY, 0.5)]:
    d = Path(ds)
    assert (d / 'transitions.npz').is_file(), f'transitions.npz missing under {d}'
    meta = json.loads((d / 'metadata.json').read_text())
    noise = float(meta.get('action_noise_std', float('nan')))
    assert abs(noise - exp_noise) < 1e-6, f'{tag}: expected σ={exp_noise} got {noise}'
    print(f'{tag:<6} σ={noise}  success_rate={meta.get("success_rate")}  '
          f'n_tx={meta.get("num_transitions")}  policy={meta.get("policy_mixture")}')

assert Path(FLOW).is_file(), f'flow missing: {FLOW}'
assert Path(MANIFEST).is_file(), f'manifest missing: {MANIFEST}'
print('\nPre-flight PASS.')
print('NOTE (spec §4): clean privileged SR should be >>0.5; noisy >~0.4. '
      'If noisy collection SR is very low, the benchmark may floor — watch §4.')
# Out:
# clean  σ=0.0  success_rate=0.719  n_tx=212692  policy=[{'policy': 'privileged', 'weight': 1.0}]
# noisy  σ=0.5  success_rate=0.098  n_tx=234696  policy=[{'policy': 'privileged', 'weight': 1.0}]
#
# Pre-flight PASS.
# NOTE (spec §4): clean privileged SR should be >>0.5; noisy >~0.4. If noisy collection SR is very low, the benchmark may floor — watch §4.

# %% [markdown]
# ## 4. FLOOR-EFFECT GATE (run FIRST — 1 run)
#
# u15_cross 更难。先只跑 **1 个** run(ReBRAC β1=1.0 / clean / seed 42),确认 benchmark **可学且有 headroom**,再解锁 §5 的剩余 11 runs。**判据**:
#
# - **PASS** — test SR ∈ **(0.50, 0.97)** → 跑 §5/§6。
# - **FLOOR** — SR ≤ 0.50 → benchmark 对 offline-from-privileged 太难 → **STOP**,回报后再议。
# - **CEILING** — SR ≥ 0.97 → 无区分 headroom → **STOP**,回报后再议。

# %%
import time
from pathlib import Path

t_start = time.time()
for job in [GATE_JOB]:
    sd = job['ckpt']; sd_str = str(sd)
    ALGO = job['algo']; FLAGS = job['flags']
    if (sd / 'agent_final.pt').exists():
        print(f"[skip-train] {job['cell']} {job['cfg']} seed={job['seed']} (exists)")
        continue
    sd.mkdir(parents=True, exist_ok=True)
    print(f"\n{'=' * 72}")
    print(f"  train {job['cell']} {job['cfg']} ({ALGO}) seed={job['seed']} → {sd}")
    print(f"{'=' * 72}")
    t0 = time.time()
    DATASET = job['dataset']
    seed = job['seed']
    # !python -m scripts.train_offline \
        --algo {ALGO} \
        --offline-data '{DATASET}/transitions.npz' \
        --flow '{FLOW}' \
        --manifest '{MANIFEST}' \
        --probe-layout {PROBE_LAYOUT} \
        --history-length {HISTORY_LENGTH} \
        --target-speed {TARGET_SPEED} \
        --task-geometry {TASK_GEOMETRY} \
        --objective {OBJECTIVE} \
        --total-steps {TOTAL_STEPS} \
        --batch-size {BATCH_SIZE} \
        --eval-every {EVAL_EVERY} \
        --eval-episodes {EVAL_EPISODES} \
        {FLAGS} \
        --skip-final-eval \
        --seed {seed} \
        --save-dir '{sd_str}' \
        --device cuda
    print(f"[train done] {job['cfg']} seed={job['seed']} in {(time.time() - t0) / 60:.1f} min")
print(f"\n[train total] {(time.time() - t_start) / 60:.1f} min")
# Out:
# ========================================================================
#   train e_uni_clean rebrac_b1p1 (rebrac) seed=42 → checkpoints/fql_succession/p2_xbench/e_uni_clean/rebrac_b1p1_seed42
# ========================================================================
# [offline] algo=rebrac transitions=212692 obs_dim=48 action_dim=2 protocol=deployable tensor_replay=on eval_workers=1 sampling=uniform total_steps=200000
# [train] step=1 q=-0.889 critic=10.715 actor=2.382 bc=1.382 lambda=1.125 critic_pen=1.477
# [train] step=1000 q=-4.085 critic=33.302 actor=1.054 bc=0.151 lambda=0.221 critic_pen=0.231
# [train] step=2000 q=-4.888 critic=25.907 actor=0.883 bc=0.146 lambda=0.151 critic_pen=0.278
# [train] step=3000 q=-4.554 critic=18.715 actor=0.650 bc=0.115 lambda=0.118 critic_pen=0.192
# [train] step=4000 q=-4.607 critic=27.204 actor=0.521 bc=0.131 lambda=0.085 critic_pen=0.190
# [train] step=5000 q=-4.756 critic=13.964 actor=0.524 bc=0.163 lambda=0.076 critic_pen=0.207
# [train] step=6000 q=-5.668 critic=130.939 actor=0.502 bc=0.109 lambda=0.069 critic_pen=0.165
# [train] step=7000 q=-0.815 critic=10.102 actor=0.160 bc=0.115 lambda=0.055 critic_pen=0.172
# [train] step=8000 q=0.752 critic=3.959 actor=0.081 bc=0.115 lambda=0.045 critic_pen=0.154
# [train] step=9000 q=-0.091 critic=7.317 actor=0.153 bc=0.149 lambda=0.040 critic_pen=0.159
# [train] step=10000 q=-0.965 critic=123.151 actor=0.139 bc=0.105 lambda=0.035 critic_pen=0.167
# [eval] step=10000 success=1.00% return=-253.59 time=78.67s energy=62480.76 path=87.95 prog=-0.047
# [train] step=11000 q=1.232 critic=5.167 actor=0.098 bc=0.141 lambda=0.035 critic_pen=0.151
# [train] step=12000 q=2.561 critic=4.187 actor=0.012 bc=0.094 lambda=0.032 critic_pen=0.159
# [train] step=13000 q=0.758 critic=240.641 actor=0.079 bc=0.101 lambda=0.029 critic_pen=0.160
# [train] step=14000 q=3.663 critic=14.383 actor=0.001 bc=0.102 lambda=0.027 critic_pen=0.129
# [train] step=15000 q=3.328 critic=6.811 actor=0.020 bc=0.108 lambda=0.026 critic_pen=0.162
# [train] step=16000 q=3.683 critic=110.563 actor=-0.015 bc=0.073 lambda=0.024 critic_pen=0.146
# [train] step=17000 q=2.326 critic=7.806 actor=0.073 bc=0.136 lambda=0.027 critic_pen=0.162
# [train] step=18000 q=7.089 critic=5.901 actor=-0.114 bc=0.060 lambda=0.024 critic_pen=0.148
# [train] step=19000 q=7.875 critic=4.908 actor=-0.115 bc=0.059 lambda=0.022 critic_pen=0.105
# [train] step=20000 q=2.937 critic=151.094 actor=0.078 bc=0.142 lambda=0.022 critic_pen=0.138
# [eval] step=20000 success=1.00% return=-236.62 time=75.15s energy=59535.78 path=80.92 prog=0.098
# [train] step=21000 q=1.407 critic=274.846 actor=0.038 bc=0.069 lambda=0.022 critic_pen=0.197
# [train] step=22000 q=2.276 critic=6.940 actor=0.020 bc=0.068 lambda=0.021 critic_pen=0.126
# [train] step=23000 q=1.223 critic=10.453 actor=0.060 bc=0.085 lambda=0.020 critic_pen=0.117
# [train] step=24000 q=-0.853 critic=11.131 actor=0.135 bc=0.117 lambda=0.021 critic_pen=0.195
# [train] step=25000 q=4.788 critic=102.560 actor=-0.015 bc=0.078 lambda=0.019 critic_pen=0.138
# [train] step=26000 q=3.856 critic=10.274 actor=-0.014 bc=0.062 lambda=0.020 critic_pen=0.109
# [train] step=27000 q=-1.315 critic=16.368 actor=0.097 bc=0.072 lambda=0.019 critic_pen=0.152
# [train] step=28000 q=8.525 critic=9.158 actor=-0.025 bc=0.133 lambda=0.019 critic_pen=0.143
# [train] step=80000 q=6.491 critic=12.852 actor=-0.053 bc=0.056 lambda=0.017 critic_pen=0.154
# [eval] step=80000 success=0.00% return=-243.87 time=80.95s energy=64781.71 path=89.83 prog=0.058
# [train] step=81000 q=2.422 critic=14.922 actor=0.022 bc=0.061 lambda=0.016 critic_pen=0.108
# [train] step=82000 q=7.734 critic=13.170 actor=-0.071 bc=0.057 lambda=0.017 critic_pen=0.101
# [train] step=83000 q=1.655 critic=15.383 actor=0.035 bc=0.062 lambda=0.016 critic_pen=0.108
# [train] step=84000 q=2.311 critic=16.863 actor=0.002 bc=0.041 lambda=0.017 critic_pen=0.125
# [train] step=85000 q=-1.297 critic=13.017 actor=0.092 bc=0.071 lambda=0.016 critic_pen=0.117
# [train] step=86000 q=4.750 critic=23.489 actor=-0.005 bc=0.072 lambda=0.016 critic_pen=0.114
# [train] step=87000 q=-4.543 critic=11.148 actor=0.133 bc=0.061 lambda=0.016 critic_pen=0.094
# [train] step=88000 q=14.349 critic=14.775 actor=-0.186 bc=0.049 lambda=0.016 critic_pen=0.145
# [train] step=89000 q=3.557 critic=29.351 actor=0.002 bc=0.061 lambda=0.016 critic_pen=0.128
# [train] step=90000 q=5.496 critic=14.665 actor=-0.050 bc=0.033 lambda=0.015 critic_pen=0.146
# [eval] step=90000 success=0.00% return=-249.43 time=85.17s energy=67926.23 path=92.47 prog=0.009
# [train] step=91000 q=5.437 critic=7.925 actor=-0.045 bc=0.044 lambda=0.016 critic_pen=0.100
# [train] step=92000 q=-5.826 critic=14.660 actor=0.145 bc=0.059 lambda=0.015 critic_pen=0.121
# [train] step=93000 q=2.670 critic=11.456 actor=0.042 bc=0.085 lambda=0.016 critic_pen=0.136
# [train] step=94000 q=7.983 critic=11.262 actor=-0.068 bc=0.075 lambda=0.018 critic_pen=0.105
# [train] step=95000 q=6.086 critic=11.449 actor=-0.053 bc=0.047 lambda=0.017 critic_pen=0.116
# [train] step=96000 q=13.710 critic=7.150 actor=-0.155 bc=0.071 lambda=0.016 critic_pen=0.101
# [train] step=97000 q=5.835 critic=69.500 actor=-0.043 bc=0.055 lambda=0.017 critic_pen=0.106
# [train] step=98000 q=-1.611 critic=18.861 actor=0.083 bc=0.057 lambda=0.016 critic_pen=0.135
# [train] step=99000 q=1.603 critic=17.688 actor=0.052 bc=0.081 lambda=0.018 critic_pen=0.104
# [train] step=100000 q=0.855 critic=12.654 actor=0.030 bc=0.044 lambda=0.016 critic_pen=0.132
# [eval] step=100000 success=0.00% return=-241.19 time=82.33s energy=66836.57 path=92.11 prog=0.099
# [train] step=101000 q=-3.500 critic=17.747 actor=0.134 bc=0.076 lambda=0.017 critic_pen=0.155
# [train] step=102000 q=11.640 critic=9.725 actor=-0.153 bc=0.073 lambda=0.019 critic_pen=0.111
# [train] step=103000 q=2.634 critic=12.795 actor=0.015 bc=0.058 lambda=0.016 critic_pen=0.108
# [train] step=104000 q=4.579 critic=11.358 actor=-0.018 bc=0.063 lambda=0.018 critic_pen=0.124
# [train] step=181000 q=13.417 critic=21.634 actor=-0.164 bc=0.061 lambda=0.017 critic_pen=0.133
# [train] step=182000 q=13.538 critic=22.573 actor=-0.215 bc=0.069 lambda=0.021 critic_pen=0.103
# [train] step=183000 q=9.016 critic=7.835 actor=-0.151 bc=0.031 lambda=0.020 critic_pen=0.126
# [train] step=184000 q=11.372 critic=12.154 actor=-0.137 bc=0.068 lambda=0.018 critic_pen=0.129
# [train] step=185000 q=10.093 critic=13.059 actor=-0.149 bc=0.038 lambda=0.019 critic_pen=0.107
# [train] step=186000 q=17.149 critic=17.491 actor=-0.278 bc=0.033 lambda=0.018 critic_pen=0.104
# [train] step=187000 q=20.794 critic=6.720 actor=-0.346 bc=0.057 lambda=0.019 critic_pen=0.124
# [train] step=188000 q=17.765 critic=8.579 actor=-0.316 bc=0.039 lambda=0.020 critic_pen=0.098
# [train] step=189000 q=17.724 critic=7.163 actor=-0.256 bc=0.068 lambda=0.018 critic_pen=0.099
# [train] step=190000 q=18.597 critic=10.352 actor=-0.269 bc=0.070 lambda=0.018 critic_pen=0.125
# [eval] step=190000 success=6.00% return=-219.97 time=100.50s energy=79782.87 path=104.59 prog=0.125
# [train] step=191000 q=11.502 critic=14.152 actor=-0.153 bc=0.059 lambda=0.018 critic_pen=0.103
# [train] step=192000 q=8.487 critic=11.950 actor=-0.079 bc=0.072 lambda=0.018 critic_pen=0.116
# [train] step=193000 q=9.868 critic=8.064 actor=-0.110 bc=0.057 lambda=0.017 critic_pen=0.103
# [train] step=194000 q=21.702 critic=8.460 actor=-0.359 bc=0.038 lambda=0.018 critic_pen=0.107
# [train] step=195000 q=14.034 critic=11.855 actor=-0.202 bc=0.052 lambda=0.018 critic_pen=0.068
# [train] step=196000 q=14.197 critic=11.155 actor=-0.238 bc=0.019 lambda=0.018 critic_pen=0.127
# [train] step=197000 q=25.213 critic=8.342 actor=-0.424 bc=0.045 lambda=0.019 critic_pen=0.089
# [train] step=198000 q=14.824 critic=11.240 actor=-0.215 bc=0.064 lambda=0.019 critic_pen=0.107
# [train] step=199000 q=12.712 critic=9.430 actor=-0.201 bc=0.038 lambda=0.019 critic_pen=0.087
# [train] step=200000 q=14.674 critic=11.337 actor=-0.225 bc=0.045 lambda=0.018 critic_pen=0.104
# [eval] step=200000 success=9.00% return=-198.27 time=106.79s energy=86371.97 path=104.45 prog=0.225
# [train done] rebrac_b1p1 seed=42 in 91.9 min
#
# [train total] 91.9 min

# %%
import time
from pathlib import Path

t_start = time.time()
for job in [GATE_JOB]:
    sd = job['ckpt']; sd_str = str(sd)
    out_path = job['test_json']; out_path_str = str(out_path)
    out_path.parent.mkdir(parents=True, exist_ok=True)
    if out_path.exists():
        print(f"[skip-eval] {job['cell']} {job['cfg']} seed={job['seed']}: {out_path}")
        continue
    if not (sd / 'agent_final.pt').exists():
        print(f"[warn] missing agent_final.pt at {sd} — train not done?")
        continue
    print(f"\n  eval {job['cell']} {job['cfg']} seed={job['seed']} → {out_path}")
    t0 = time.time()
    # !python -m scripts.evaluate_offline \
        --checkpoint '{sd_str}' \
        --manifest '{MANIFEST}' \
        --episodes {TEST_EPISODES} \
        --num-workers {EVAL_NUM_WORKERS} \
        --worker-device cpu \
        --device cuda \
        --output-json '{out_path_str}'
    print(f"[eval done] {job['cfg']} seed={job['seed']} in {(time.time() - t0) / 60:.1f} min")
print(f"\n[eval total] {(time.time() - t_start) / 60:.1f} min")
# Out:
#   eval e_uni_clean rebrac_b1p1 seed=42 → results/fql_succession/p2_xbench/e_uni_clean/test/rebrac_b1p1_seed42.json
# reward_objective      : arrival_v2
# energy_cost_gain      : 0.000000
# safety_cost_gain      : 0.000000
# episodes              : 100
# success_rate          : 14.0%
# avg_return            : -183.93 +/- 137.15
# avg_safety_cost       : 19.940 +/- 19.354
# avg_time_s            : 104.10 +/- 68.64
# avg_time_s_success    : 139.52
# avg_energy            : 83818.14 +/- 56688.64
# avg_path_length_m     : 101.45 +/- 52.71
# avg_progress_ratio    : 0.263 +/- 0.486
# avg_path_efficiency   : 0.140 +/- 0.218
# termination           : {'out_of_bounds': 78, 'goal': 14, 'timeout': 7, 'depth_hold_failure': 1}
# benchmark_manifest    : benchmarks/single_u15_cross_tgt15_ep100.json
# [eval done] rebrac_b1p1 seed=42 in 2.6 min
#
# [eval total] 2.6 min

# %%
import json
from pathlib import Path

p = GATE_JOB['test_json']
assert p.exists(), f'gate eval json missing: {p} — run the two cells above first'
sr = float(json.loads(p.read_text())['eval_success_rate'])
print(f'FLOOR GATE — ReBRAC β1=1.0 / clean / seed 42  SR = {sr:.3f}')
if sr <= 0.50:
    print('\nVERDICT: FLOOR — benchmark too hard for offline-from-privileged. STOP, report back.')
elif sr >= 0.97:
    print('\nVERDICT: CEILING — no discriminating headroom. STOP, report back.')
else:
    print('\nVERDICT: PASS — learnable AND has headroom. Proceed to §5/§6 (remaining 11 runs).')
# Out:
# FLOOR GATE — ReBRAC β1=1.0 / clean / seed 42  SR = 0.140
#
# VERDICT: FLOOR — benchmark too hard for offline-from-privileged. STOP, report back.

# %% [markdown]
# ## 5. Train full matrix (12 runs; gate run is skipped via skip-resume)
#
# 只在 §4 GATE = **PASS** 后运行。逐 job 跑,skip-resume on `agent_final.pt`。
# `--skip-final-eval`:在线 eval 100 ep 监控,test eval 走 §6。

# %%
import time
from pathlib import Path

t_start = time.time()
for job in JOBS:
    sd = job['ckpt']; sd_str = str(sd)
    ALGO = job['algo']; FLAGS = job['flags']
    if (sd / 'agent_final.pt').exists():
        print(f"[skip-train] {job['cell']} {job['cfg']} seed={job['seed']} (exists)")
        continue
    sd.mkdir(parents=True, exist_ok=True)
    print(f"\n{'=' * 72}")
    print(f"  train {job['cell']} {job['cfg']} ({ALGO}) seed={job['seed']} → {sd}")
    print(f"{'=' * 72}")
    t0 = time.time()
    DATASET = job['dataset']
    seed = job['seed']
    # !python -m scripts.train_offline \
        --algo {ALGO} \
        --offline-data '{DATASET}/transitions.npz' \
        --flow '{FLOW}' \
        --manifest '{MANIFEST}' \
        --probe-layout {PROBE_LAYOUT} \
        --history-length {HISTORY_LENGTH} \
        --target-speed {TARGET_SPEED} \
        --task-geometry {TASK_GEOMETRY} \
        --objective {OBJECTIVE} \
        --total-steps {TOTAL_STEPS} \
        --batch-size {BATCH_SIZE} \
        --eval-every {EVAL_EVERY} \
        --eval-episodes {EVAL_EPISODES} \
        {FLAGS} \
        --skip-final-eval \
        --seed {seed} \
        --save-dir '{sd_str}' \
        --device cuda
    print(f"[train done] {job['cfg']} seed={job['seed']} in {(time.time() - t0) / 60:.1f} min")
print(f"\n[train total] {(time.time() - t_start) / 60:.1f} min")

# %% [markdown]
# ## 6. Test eval (100 ep / run) + mirror small files
#
# 对每个 `agent_final.pt` 跑 `evaluate_offline` 100 ep(固定 manifest re-eval),写 `<test_json>`;再 mirror 4 个 small files。CLI 与 P2 §5 一致。

# %%
import time
from pathlib import Path

t_start = time.time()
for job in JOBS:
    sd = job['ckpt']; sd_str = str(sd)
    out_path = job['test_json']; out_path_str = str(out_path)
    out_path.parent.mkdir(parents=True, exist_ok=True)
    if out_path.exists():
        print(f"[skip-eval] {job['cell']} {job['cfg']} seed={job['seed']}: {out_path}")
        continue
    if not (sd / 'agent_final.pt').exists():
        print(f"[warn] missing agent_final.pt at {sd} — train not done?")
        continue
    print(f"\n  eval {job['cell']} {job['cfg']} seed={job['seed']} → {out_path}")
    t0 = time.time()
    # !python -m scripts.evaluate_offline \
        --checkpoint '{sd_str}' \
        --manifest '{MANIFEST}' \
        --episodes {TEST_EPISODES} \
        --num-workers {EVAL_NUM_WORKERS} \
        --worker-device cpu \
        --device cuda \
        --output-json '{out_path_str}'
    print(f"[eval done] {job['cfg']} seed={job['seed']} in {(time.time() - t0) / 60:.1f} min")
print(f"\n[eval total] {(time.time() - t_start) / 60:.1f} min")

# %%
import shutil
from pathlib import Path

for job in JOBS:
    sd = job['ckpt']; mdir = job['mirror']
    mdir.mkdir(parents=True, exist_ok=True)
    for fname in MIRROR_FILES:
        src = sd / fname
        if src.exists():
            shutil.copy2(src, mdir / fname)
    print(f"mirrored small files for {job['cell']} {job['cfg']} seed={job['seed']} → {mdir}")

# %% [markdown]
# ## 7. Worst-case-over-noise table
#
# 每个 config 取 **min(clean SR, noisy SR)** = worst-case-over-noise。三个 config 排成一列对照。

# %%
import json
from pathlib import Path
from statistics import mean

def sr(cell, cfg, seed):
    p = RES_ROOT / cell / 'test' / f'{cfg}_seed{seed}.json'
    return float(json.loads(p.read_text())['eval_success_rate']) if p.exists() else None

def cell_mean(cell, cfg):
    vals = [sr(cell, cfg, s) for s in SEEDS]
    vals = [v for v in vals if v is not None]
    return mean(vals) if vals else None

CFG_NAMES = [c[0] for c in CONFIGS]
rows = {}
print(f'{"config":<14} | {"clean":>6} | {"noisy":>6} | {"worst-case":>10}')
print('-' * 48)
for cfg in CFG_NAMES:
    cl = cell_mean('e_uni_clean', cfg)
    no = cell_mean('m_uni_noise', cfg)
    wc = min(cl, no) if (cl is not None and no is not None) else None
    rows[cfg] = {'clean': cl, 'noisy': no, 'worst': wc}
    f = lambda v: f'{v:.3f}' if v is not None else '  --  '
    print(f'{cfg:<14} | {f(cl):>6} | {f(no):>6} | {f(wc):>10}')

# %% [markdown]
# ## 8. Verdict (auto)
#
# 预注册判据(spec §5):
# - ✅ **CONFIRM** — ReBRAC β1=1.0 worst-case **≥** FQL worst-case(FQL 不赢)**AND** β1=4.0 noisy < β1=1.0 noisy(4→1 噪声恢复复现)→ P2 在更难 benchmark 上泛化。
# - ⚠ **NEW POSITIVE** — FQL worst-case > ReBRAC β1=1.0 worst-case **> 5pp** → FQL 意外赢,**重开**(非协议失败)。
# - **NULL/TIE** — 差距 < 5pp / 方向不一 → 与 P2 相容(FQL 无 edge),verdict 性质不变。

# %%
import json
from pathlib import Path
from statistics import mean

def sr(cell, cfg, seed):
    p = RES_ROOT / cell / 'test' / f'{cfg}_seed{seed}.json'
    return float(json.loads(p.read_text())['eval_success_rate']) if p.exists() else None
def cm(cell, cfg):
    vals = [v for v in (sr(cell, cfg, s) for s in SEEDS) if v is not None]
    return mean(vals) if vals else None
def wc(cfg):
    cl, no = cm('e_uni_clean', cfg), cm('m_uni_noise', cfg)
    return (min(cl, no), cl, no) if (cl is not None and no is not None) else (None, cl, no)

fql_wc, _, _ = wc('fql')
b1_wc,  _, b1_no = wc('rebrac_b1p1')
b4_wc,  _, b4_no = wc('rebrac_b1p4')
assert None not in (fql_wc, b1_wc, b4_no, b1_no), 'incomplete results — run §5/§6 first'

print(f'FQL          worst-case = {fql_wc:.3f}')
print(f'ReBRAC β1=1.0 worst-case = {b1_wc:.3f}')
print(f'ReBRAC β1=4.0 worst-case = {b4_wc:.3f}')
print(f'noise recovery: β1=4.0 noisy {b4_no:.3f}  vs  β1=1.0 noisy {b1_no:.3f}')

fql_wins_by = fql_wc - b1_wc
recovery_reproduces = b4_no < b1_no
if fql_wins_by > 0.05:
    print('\nVERDICT: NEW POSITIVE — FQL beats ReBRAC β1=1.0 on worst-case by '
          f'{fql_wins_by*100:.1f}pp (>5pp). Re-open: investigate before any claim.')
elif b1_wc >= fql_wc and recovery_reproduces:
    print('\nVERDICT: CONFIRM — ReBRAC β1=1.0 ≥ FQL on worst-case AND β1 4→1 noise '
          'recovery reproduces. P2 generalizes to U=1.5/Re250; mechanism claim hardened.')
elif b1_wc >= fql_wc and not recovery_reproduces:
    print('\nVERDICT: PARTIAL — FQL does not win (good), but the β1 4→1 noise recovery '
          'did NOT reproduce. Report both; C2 partially generalizes.')
else:
    print('\nVERDICT: NULL/TIE — FQL within 5pp of ReBRAC β1=1.0 on worst-case. '
          'Consistent with P2 (FQL no edge); verdict nature unchanged.')

# %% [markdown]
# ## 9. Report checklist
#
# 跑完后:
# - [ ] sync `results/fql_succession/p2_xbench/**/test/*.json`(12 个)回 local
# - [ ] 把 worst-case-over-noise 表 + verdict **追加**进 `docs/fql_succession_p2_results.md` 的 generalization 小节(**不新开**报告)
# - [ ] verdict notebook `notebooks/fql_succession_p2_verdict.ipynb` 增一个 xbench 行
# - [ ] 若 **NEW POSITIVE** → 才考虑建 C-1 u15 rematch;否则 B+A 闭环不变
