# %% [markdown]
# # SAC arrival_v2 — sac_asym s0_k4 SEED=0 replication of §7.7 (single_cross, 1M)
#
# **Pre-context（commits `01b78ad` / `3d20e86`）**：[`docs/arrival_v2_experiment_report.md`](../docs/arrival_v2_experiment_report.md) §7.7 给出 AsymCritic pure ablation 的 negative finding（mean 0.044 vs vanilla 0.221，5× 更差），但**仅 seed=42 单 seed**。该 claim 在严格意义上是 single-point estimate，不是 well-established negative finding。
#
# | 已闭环 single_cross cell | algo | sensor | k | seed | final | mean | OOB |
# |---|---|---|---|---|---:|---:|---:|
# | §7.1 single_cross_s1_k4 | vanilla | s1 | 4 | 42 | 0.900 | — | 0.100 |
# | §7.6.4 single_cross_s0_k4 | vanilla | s0 | 4 | **42** | 0.100 | 0.221 | 0.667 |
# | §7.7 single_cross_s0_k4 + asym | sac_asym | s0 | 4 | **42** | 0.167 | 0.044 | 0.633 |
#
# **本 notebook 任务（sac_asym k=4 SEED=0 paired-seed replication）**：把 §7.7 的 sac_asym 配置**唯一变量**换成 `--seed 0`，其它**全部不动**：
#
# | 维度 | §7.7 baseline (seed=42) | 本 notebook |
# |---|---|---|
# | `--seed` | 42 | **0** ← 唯一变量 |
# | `--use-asymmetric-critic` | True | True |
# | sensor layout | s0 (DVL-only) | s0 (DVL-only) |
# | history_length | 4 | 4 |
# | reward | arrival_v2 | arrival_v2 |
# | flow U / target | 1.5 / 1.5 | 1.5 / 1.5 |
# | total_steps | 1M | 1M |
# | num_envs | 6 | 6 |
# | benchmark | `single_u15_cross_tgt15` | 同 |
# | obs_dim (actor) | 10×4 + 8 = 48 | 同 (48) |
# | privileged_obs_dim (critic) | 2 | 同 (2) |
#
# **配对设计**：本 notebook 与 `sac_arrival_v2_s0_cross_vanilla_seed0.ipynb` 并行跑，构成 2 seed × 2 algo = 4-cell paired ablation：
#
# | | seed=42 (已有) | seed=0 (姊妹 + 本) |
# |---|---|---|
# | **vanilla** | §7.6.4 final=0.100 mean=0.221 | ← 姊妹 notebook |
# | **sac_asym** | §7.7 final=0.167 mean=0.044 | ← **本 notebook** |
#
# **判读规则**（驱动 §7.7 negative finding 升降级）：
# - **HARDEN-NEGATIVE**（seed=0 asym mean ≤ 0.15 AND 显著低于 vanilla seed=0 / seed=42 均值）→ 2 seed × 2 algo 都验证 asym worse than vanilla → §7.7 升格为 **2-seed hardened negative claim**，可直接写进论文；§8 P1 路线维持「actor-side info upgrade」（k=8 / temporal）方向。
# - **COLLAPSE-NEGATIVE**（seed=0 asym mean ∈ [0.15, 0.30]，与 vanilla baselines 同量级）→ §7.7 的「asym hurts」claim **collapse 为「asym does not improve」**，seed=42 的 mean 0.044 是 unlucky outlier；§8 P1 重写：asym 不再是"被推翻"，而是"被弱化为 no-effect"；下一步仍可走 k=8 但需补 3rd seed。
# - **REVERSE**（seed=0 asym mean ≥ 0.30，明显高于 vanilla baselines）→ §7.7 claim **反转**：seed=42 是 asym 的 unlucky outlier，asym 可能确实有助益 → §7.7 整段重写，§8 P1 需要重新考虑 asym 作为候选。
# - **AMBIGUOUS**（其他情况，例如 seed=0 asym mean 高于 §7.7 但仍低于 vanilla seeds）→ 部分确认；需要 3rd seed (=7 或 =1) 才能定论。
#
# **输出根（与 §7.7 seed=42 互不覆盖）**：
# - `experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_asym/s0_k4/seed_0/`
#
# **总预算**：~2.5h L4（1 Colab Pro+ session）。可与姊妹 vanilla seed=0 + 已在跑的 k=8 共 3 session 并行。
#
# **风格**：训练用 `!python -u -m scripts.train_sac` 直跑（实时 stdout），与 §7 / §7.6 / §7.7 一致。

# %% [markdown]
# ## 0. GPU sanity

# %%
# !nvidia-smi | head -10
# Out:
# Mon May 18 04:36:51 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA L4                      Off |   00000000:00:03.0 Off |                    0 |
# | N/A   40C    P8             12W /   72W |       0MiB /  23034MiB |      0%      Default |

# %% [markdown]
# ## 1. Mount Drive + cwd

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

REPO_DIR = '/content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5'
# %cd $REPO_DIR
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5

# %% [markdown]
# ## 2. Config — sac_asym + seed=0（与 §7.7 baseline 仅差一个 flag value）

# %%
import json
import os
from pathlib import Path

import pandas as pd

# ==== SAC / env config (与 §7.7 baseline 严格一致，除 seed 外) ====
OBJECTIVE = 'arrival_v2'
PROBE_LAYOUT = 's0'
HISTORY_LENGTH = 4
TARGET_SPEED = 1.5
SEED = 0                                # ← 唯一与 §7.7 不同 (was 42)

RANDOM_STEPS = 5_000
UPDATE_AFTER = 5_000
BATCH_SIZE = 256
HIDDEN_DIM = 256
NUM_ENVS = 6
EVAL_EVERY = 25_000
EVAL_EPISODES = 30
CHECKPOINT_EVERY = 100_000
DEVICE = 'cuda'

# AsymCritic 关键 flag — 与 §7.7 一致，pure ablation（不带 LN / UTD / Dropout）
USE_ASYMMETRIC_CRITIC = True           # ← 与 vanilla 路线唯一差别
USE_LAYERNORM = False
UPDATES_PER_STEP = 1
DROPOUT_RATE = 0.0

PASS_FINAL_SUCCESS = 0.85
PASS_LAST100_RATIO = 0.90
PASS_OOB_RATE = 0.10

# Flow file（与 §7.1 / §7.6.4 / §7.7 严格一致）
SINGLE_FLOW = 'wake_data/wake_v8_U1p50_Re250_D12p00_dx0p60_Ti5pct_1200f_roi.npy'

# ==== Single phase — sac_asym s0 k=4 seed=0 (X_*) ====
X_BENCHMARK_KEY = 'single_u15_cross_tgt15'
X_TASK_GEOMETRY = 'cross_stream'
X_FLOW_PATH = SINGLE_FLOW
X_TOTAL_STEPS = 1_000_000
X_RUN_ROOT = Path('experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_asym/s0_k4/seed_0')
X_CKPT_ROOT = Path('checkpoints/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_asym/s0_k4/seed_0')
X_MANIFEST_PATH = Path(f'benchmarks/{X_BENCHMARK_KEY}.json')

# Baselines（事后对比）
X_K4_ASYM_SEED42_ANCHOR = Path('experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_asym/s0_k4/seed_42')   # §7.7
X_K4_V_SEED42_BASELINE  = Path('experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s0_k4/seed_42') # §7.6.4
X_K4_V_SEED0_SISTER     = Path('experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s0_k4/seed_0')  # 姊妹 notebook
X_S1_BASELINE           = Path('experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s1_k4/seed_42') # §7.1 上界 ref

os.environ['PYTHONUNBUFFERED'] = '1'

print(f'PROBE_LAYOUT          = {PROBE_LAYOUT}')
print(f'OBJECTIVE             = {OBJECTIVE}')
print(f'HISTORY_LENGTH        = {HISTORY_LENGTH}')
print(f'SEED                  = {SEED}        ← 唯一与 §7.7 不同 (was 42)')
print(f'NUM_ENVS              = {NUM_ENVS}')
print(f'USE_ASYMMETRIC_CRITIC = {USE_ASYMMETRIC_CRITIC}   ← 与 §7.7 一致')
print(f'USE_LAYERNORM         = {USE_LAYERNORM}')
print(f'UPDATES_PER_STEP      = {UPDATES_PER_STEP}')
print(f'DROPOUT_RATE          = {DROPOUT_RATE}')
print()
print(f'benchmark             : {X_BENCHMARK_KEY}')
print(f'geometry              : {X_TASK_GEOMETRY}')
print(f'total_steps           : {X_TOTAL_STEPS:,}')
print(f'expected obs_dim      : 10 * {HISTORY_LENGTH} + 8 (arrival_v2 context) = {10 * HISTORY_LENGTH + 8}')
print(f'expected privileged   : dim=2 (body-frame [u_eq, v_eq])')
print(f'run_root              : {X_RUN_ROOT}')
print(f'§7.7 seed=42 anchor   : {X_K4_ASYM_SEED42_ANCHOR}')
print(f'§7.6.4 vanilla ref    : {X_K4_V_SEED42_BASELINE}')
print(f'sister vanilla seed=0 : {X_K4_V_SEED0_SISTER}')
print(f'§7.1 s1_k4 upper ref  : {X_S1_BASELINE}')
# Out:
# PROBE_LAYOUT          = s0
# OBJECTIVE             = arrival_v2
# HISTORY_LENGTH        = 4
# SEED                  = 0        ← 唯一与 §7.7 不同 (was 42)
# NUM_ENVS              = 6
# USE_ASYMMETRIC_CRITIC = True   ← 与 §7.7 一致
# USE_LAYERNORM         = False
# UPDATES_PER_STEP      = 1
# DROPOUT_RATE          = 0.0
#
# benchmark             : single_u15_cross_tgt15
# geometry              : cross_stream
# total_steps           : 1,000,000
# expected obs_dim      : 10 * 4 + 8 (arrival_v2 context) = 48
# expected privileged   : dim=2 (body-frame [u_eq, v_eq])
# run_root              : experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_asym/s0_k4/seed_0
# §7.7 seed=42 anchor   : experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_asym/s0_k4/seed_42
# §7.6.4 vanilla ref    : experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s0_k4/seed_42
# sister vanilla seed=0 : experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s0_k4/seed_0
# §7.1 s1_k4 upper ref  : experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s1_k4/seed_42

# %% [markdown]
# ## 3. Preflight — flow / arrival_v2 candidate gate / reward unit tests / manifest / baseline 就位

# %%
# Flow file
fp = Path(X_FLOW_PATH)
if not fp.exists():
    raise FileNotFoundError(f'missing flow file: {fp}')
print(f'[OK] flow file: {fp}  ({fp.stat().st_size / 1e6:.1f} MB)')
# Out:
# [OK] flow file: wake_data/wake_v8_U1p50_Re250_D12p00_dx0p60_Ti5pct_1200f_roi.npy  (230.4 MB)

# %%
# !python -u -m scripts.validate_arrival_v2_candidate
# Out:
# [undiscounted]
# fast_success       144.473
# slow_success       142.023
# unsafe_success      91.048
# timeout_near      -149.800
# timeout_far       -229.800
# late_oob          -274.500
# fast_oob          -280.325
# mid_oob           -319.450
#
# [discounted_gamma_0.995]
# fast_success        88.578
# slow_success        54.683
# unsafe_success      34.857
# timeout_near       -39.480
# timeout_far        -58.269
# late_oob          -103.800
# mid_oob           -190.006
# fast_oob          -212.555
#
# [discounted_shortcut] safe=69.330 risky=62.361
#
# PASS: arrival_v2 candidate pre-integration gates passed.

# %%
# !python -u -m pytest tests/test_reward_objective.py -q
# Out:
# ...............                                                          [100%]
# 15 passed in 20.40s

# %%
if not X_MANIFEST_PATH.exists():
    # !python -u -m scripts.generate_standard_benchmarks --benchmarks {X_BENCHMARK_KEY} --episodes {EVAL_EPISODES}
if not X_MANIFEST_PATH.exists():
    raise FileNotFoundError(f'manifest not generated: {X_MANIFEST_PATH}')
print(f'[OK] manifest ready: {X_MANIFEST_PATH}')
# Out:
# [OK] manifest ready: benchmarks/single_u15_cross_tgt15.json

# %%
# 检查对比 baseline 是否就位 — 不影响训练，仅 §6 verdict 用
for label, root, ref_final, ref_oob in [
    ('§7.7   sac_asym_s0_k4 seed=42 (paired) ', X_K4_ASYM_SEED42_ANCHOR, 0.167, 0.633),
    ('§7.6.4 vanilla_s0_k4 seed=42           ', X_K4_V_SEED42_BASELINE,  0.100, 0.667),
    ('§7.1   vanilla_s1_k4 seed=42 (upper)   ', X_S1_BASELINE,           0.900, 0.100),
    ('SISTER vanilla_s0_k4 seed=0            ', X_K4_V_SEED0_SISTER,     -1,    -1),
]:
    fp = root / 'results' / 'final_eval.json'
    if fp.exists():
        d = json.loads(fp.read_text(encoding='utf-8'))
        f = float(d['eval_success_rate'])
        c = d.get('eval_termination_counts', {})
        n = float(d.get('num_eval_episodes', EVAL_EPISODES))
        oob = float(c.get('out_of_bounds', 0)) / max(n, 1.0)
        if ref_final >= 0:
            match = '✓' if abs(f - ref_final) < 0.05 and abs(oob - ref_oob) < 0.05 else '✗ mismatch'
        else:
            match = '(sister, no ref)'
        print(f'[OK] {label}: final={f:.4f}  oob={oob:.4f}  counts={c}  {match}')
    else:
        if 'SISTER' in label:
            print(f'[INFO] {label}: 姊妹 notebook 尚未跑完，§6 verdict 会跳过 2x2 完整设计')
        else:
            print(f'[WARN] {label}: {fp} 不存在 (后续 §6 会回退到 report 转载值)')
# Out:
# [OK] §7.7   sac_asym_s0_k4 seed=42 (paired) : final=0.1667  oob=0.6333  counts={'out_of_bounds': 19, 'goal': 5, 'timeout': 6}  ✓
# [OK] §7.6.4 vanilla_s0_k4 seed=42           : final=0.1000  oob=0.6667  counts={'out_of_bounds': 20, 'timeout': 7, 'goal': 3}  ✓
# [OK] §7.1   vanilla_s1_k4 seed=42 (upper)   : final=0.9000  oob=0.1000  counts={'goal': 27, 'out_of_bounds': 3}  ✓
# [INFO] SISTER vanilla_s0_k4 seed=0            : 姊妹 notebook 尚未跑完，§6 verdict 会跳过 2x2 完整设计

# %% [markdown]
# ## 4. Train — sac_asym s0 k=4 SEED=0 (1.0M, skip/resume)

# %%
x_state_path = X_RUN_ROOT / 'trainer_state.json'
if x_state_path.exists():
    x_state = json.loads(x_state_path.read_text(encoding='utf-8'))
    x_current_step = int(x_state.get('env_step', 0))
else:
    x_current_step = 0
print(f'[state] X env_step = {x_current_step:,} / target {X_TOTAL_STEPS:,}')

if x_current_step >= X_TOTAL_STEPS:
    print(f'[skip] X already trained to {x_current_step:,} >= {X_TOTAL_STEPS:,}')
elif x_current_step > 0:
    print(f'[resume] X continuing from {x_current_step:,} -> {X_TOTAL_STEPS:,}')
    # !python -u -m scripts.train_sac \
        --resume {str(X_RUN_ROOT)} \
        --total-steps {X_TOTAL_STEPS} \
        --eval-every {EVAL_EVERY} \
        --eval-episodes {EVAL_EPISODES} \
        --checkpoint-every {CHECKPOINT_EVERY} \
        --eval-manifest {str(X_MANIFEST_PATH)} \
        --device {DEVICE}
else:
    print(f'[train] X fresh start -> {X_TOTAL_STEPS:,}')
    # !python -u -m scripts.train_sac \
        --flow {X_FLOW_PATH} \
        --task-geometry {X_TASK_GEOMETRY} \
        --target-speed {TARGET_SPEED} \
        --objective {OBJECTIVE} \
        --probe-layout {PROBE_LAYOUT} \
        --history-length {HISTORY_LENGTH} \
        --use-asymmetric-critic \
        --total-steps {X_TOTAL_STEPS} \
        --random-steps {RANDOM_STEPS} \
        --update-after {UPDATE_AFTER} \
        --batch-size {BATCH_SIZE} \
        --hidden-dim {HIDDEN_DIM} \
        --num-envs {NUM_ENVS} \
        --eval-every {EVAL_EVERY} \
        --eval-episodes {EVAL_EPISODES} \
        --checkpoint-every {CHECKPOINT_EVERY} \
        --eval-manifest {str(X_MANIFEST_PATH)} \
        --seed {SEED} \
        --device {DEVICE} \
        --save-dir {str(X_RUN_ROOT)} \
        --checkpoint-dir {str(X_CKPT_ROOT)}
# Out:
# [state] X env_step = 0 / target 1,000,000
# [train] X fresh start -> 1,000,000
# [train] episode=5 step=678 return=-310.07 success=False time=56.1s geometry=cross_stream history=4
# [train] episode=10 step=1842 return=-455.98 success=False time=106.2s geometry=cross_stream history=4
# [train] episode=15 step=2268 return=-404.30 success=False time=94.9s geometry=cross_stream history=4
# [train] episode=20 step=2670 return=-324.46 success=False time=31.6s geometry=cross_stream history=4
# [train] episode=25 step=3204 return=-285.89 success=False time=55.0s geometry=cross_stream history=4
# [train] episode=30 step=3702 return=-416.50 success=False time=38.5s geometry=cross_stream history=4
# [train] episode=35 step=4242 return=-432.68 success=False time=49.6s geometry=cross_stream history=4
# [train] episode=40 step=5112 return=-497.94 success=False time=109.5s geometry=cross_stream history=4 | q1=786.988 actor=0.482 alpha=0.199
# [train] episode=45 step=5550 return=-417.03 success=False time=90.4s geometry=cross_stream history=4 | q1=6.013 actor=2.936 alpha=0.195
# [train] episode=50 step=6096 return=-399.47 success=False time=81.4s geometry=cross_stream history=4 | q1=794.293 actor=3.041 alpha=0.190
# [train] episode=55 step=6858 return=-369.37 success=False time=88.8s geometry=cross_stream history=4 | q1=3.980 actor=4.171 alpha=0.184
# [train] episode=60 step=7428 return=-458.09 success=False time=115.4s geometry=cross_stream history=4 | q1=7.234 actor=5.486 alpha=0.180
# [train] episode=65 step=8250 return=-401.82 success=False time=84.2s geometry=cross_stream history=4 | q1=541.278 actor=6.441 alpha=0.174
# [train] episode=70 step=8802 return=-406.74 success=False time=99.8s geometry=cross_stream history=4 | q1=1356.791 actor=7.465 alpha=0.171
# [train] episode=75 step=9456 return=-274.11 success=False time=11.8s geometry=cross_stream history=4 | q1=745.287 actor=8.930 alpha=0.167
# [train] episode=80 step=10236 return=-454.80 success=False time=133.3s geometry=cross_stream history=4 | q1=1037.193 actor=9.233 alpha=0.163
# [train] episode=85 step=10902 return=-339.34 success=False time=62.8s geometry=cross_stream history=4 | q1=735.927 actor=10.520 alpha=0.158
# [train] episode=90 step=11232 return=-322.26 success=False time=26.8s geometry=cross_stream history=4 | q1=713.453 actor=12.164 alpha=0.156
# [train] episode=95 step=11970 return=-373.82 success=False time=84.2s geometry=cross_stream history=4 | q1=508.614 actor=12.081 alpha=0.151
# [train] episode=100 step=12564 return=-271.21 success=False time=11.1s geometry=cross_stream history=4 | q1=7.756 actor=13.651 alpha=0.147
# [train] episode=105 step=13404 return=-256.77 success=False time=9.2s geometry=cross_stream history=4 | q1=200.082 actor=15.917 alpha=0.140
# [train] episode=110 step=13776 return=-268.83 success=False time=10.9s geometry=cross_stream history=4 | q1=4.224 actor=14.079 alpha=0.138
# [train] episode=115 step=14394 return=-312.22 success=False time=41.0s geometry=cross_stream history=4 | q1=444.547 actor=17.440 alpha=0.134
# [train] episode=120 step=15012 return=-257.31 success=False time=17.1s geometry=cross_stream history=4 | q1=688.021 actor=17.246 alpha=0.129
# [train] episode=125 step=15258 return=-277.80 success=False time=19.0s geometry=cross_stream history=4 | q1=7.880 actor=18.373 alpha=0.127
# [train] episode=130 step=15876 return=-292.82 success=False time=24.5s geometry=cross_stream history=4 | q1=438.949 actor=19.269 alpha=0.124
# [train] episode=135 step=16404 return=-507.49 success=False time=81.3s geometry=cross_stream history=4 | q1=459.946 actor=19.977 alpha=0.121
# [train] episode=140 step=17328 return=-405.42 success=False time=76.2s geometry=cross_stream history=4 | q1=380.577 actor=21.927 alpha=0.117
# [train] episode=145 step=17670 return=-540.02 success=False time=94.6s geometry=cross_stream history=4 | q1=683.637 actor=21.962 alpha=0.115
# [train] episode=150 step=18462 return=-347.96 success=False time=81.5s geometry=cross_stream history=4 | q1=234.189 actor=24.491 alpha=0.111
# [train] episode=155 step=18906 return=-243.53 success=False time=17.1s geometry=cross_stream history=4 | q1=241.802 actor=25.567 alpha=0.109
# [train] episode=160 step=19464 return=-499.98 success=False time=55.7s geometry=cross_stream history=4 | q1=428.317 actor=27.467 alpha=0.106
# [train] episode=165 step=20244 return=-349.36 success=False time=29.2s geometry=cross_stream history=4 | q1=143.825 actor=26.205 alpha=0.103
# [train] episode=170 step=20478 return=-396.21 success=False time=109.4s geometry=cross_stream history=4 | q1=413.085 actor=29.486 alpha=0.102
# [train] episode=175 step=21300 return=-293.09 success=False time=36.3s geometry=cross_stream history=4 | q1=182.125 actor=30.577 alpha=0.098
# [train] episode=180 step=21840 return=-503.48 success=False time=112.8s geometry=cross_stream history=4 | q1=2.280 actor=30.937 alpha=0.096
# [train] episode=185 step=22908 return=-414.03 success=False time=88.1s geometry=cross_stream history=4 | q1=658.832 actor=33.174 alpha=0.092
# [train] episode=190 step=23544 return=-353.96 success=False time=59.3s geometry=cross_stream history=4 | q1=766.160 actor=32.567 alpha=0.089
# [train] episode=195 step=24360 return=-307.12 success=False time=51.2s geometry=cross_stream history=4 | q1=481.568 actor=34.628 alpha=0.087
# [train] episode=200 step=24984 return=-284.11 success=False time=19.9s geometry=cross_stream history=4 | q1=236.206 actor=33.612 alpha=0.085
# [eval] step=25002 objective=arrival_v2 return=-357.51 safety=18.134 success=0.00% time=57.1s energy=27178.1 path=92.2 prog=-1.18
# [train] episode=205 step=25986 return=-415.51 success=False time=108.5s geometry=cross_stream history=4 | q1=410.927 actor=37.162 alpha=0.082
# [train] episode=210 step=26544 return=-296.21 success=False time=45.6s geometry=cross_stream history=4 | q1=414.427 actor=33.621 alpha=0.080
# [train] episode=215 step=27108 return=-328.70 success=False time=46.4s geometry=cross_stream history=4 | q1=393.381 actor=35.980 alpha=0.078
# [train] episode=220 step=27768 return=-360.41 success=False time=77.5s geometry=cross_stream history=4 | q1=9.784 actor=40.390 alpha=0.076
# [train] episode=225 step=28242 return=-313.59 success=False time=25.8s geometry=cross_stream history=4 | q1=478.276 actor=38.725 alpha=0.075
# [train] episode=230 step=28878 return=-255.50 success=False time=39.8s geometry=cross_stream history=4 | q1=574.959 actor=41.948 alpha=0.073
# [train] episode=235 step=29832 return=-269.94 success=False time=39.7s geometry=cross_stream history=4 | q1=28.284 actor=42.768 alpha=0.071
# [train] episode=240 step=30180 return=-234.75 success=False time=24.7s geometry=cross_stream history=4 | q1=230.072 actor=43.516 alpha=0.070
# [train] episode=245 step=30696 return=-358.42 success=False time=60.5s geometry=cross_stream history=4 | q1=693.506 actor=45.127 alpha=0.069
# [train] episode=250 step=31176 return=-300.51 success=False time=56.7s geometry=cross_stream history=4 | q1=301.720 actor=43.781 alpha=0.067
# [train] episode=255 step=32172 return=-347.88 success=False time=44.1s geometry=cross_stream history=4 | q1=645.802 actor=42.779 alpha=0.065
# [train] episode=260 step=32598 return=-261.88 success=False time=14.9s geometry=cross_stream history=4 | q1=475.616 actor=46.816 alpha=0.065
# [train] episode=265 step=33060 return=-320.81 success=False time=61.9s geometry=cross_stream history=4 | q1=884.388 actor=46.403 alpha=0.064
# [train] episode=270 step=33816 return=-276.32 success=False time=24.6s geometry=cross_stream history=4 | q1=581.015 actor=48.402 alpha=0.063
# [train] episode=275 step=34524 return=-326.63 success=False time=40.9s geometry=cross_stream history=4 | q1=4.390 actor=46.962 alpha=0.062
# [train] episode=280 step=35298 return=-272.88 success=False time=45.1s geometry=cross_stream history=4 | q1=137.755 actor=47.957 alpha=0.061
# [train] episode=285 step=35898 return=-262.85 success=False time=12.0s geometry=cross_stream history=4 | q1=235.826 actor=47.131 alpha=0.061
# [train] episode=290 step=36522 return=-392.53 success=False time=127.4s geometry=cross_stream history=4 | q1=587.629 actor=48.562 alpha=0.060
# [train] episode=295 step=37020 return=-367.38 success=False time=80.3s geometry=cross_stream history=4 | q1=413.405 actor=52.728 alpha=0.060
# [train] episode=300 step=38016 return=-472.09 success=False time=139.3s geometry=cross_stream history=4 | q1=194.210 actor=52.324 alpha=0.059
# [train] episode=305 step=38376 return=-255.69 success=False time=29.3s geometry=cross_stream history=4 | q1=581.474 actor=51.680 alpha=0.058
# [train] episode=310 step=38838 return=-369.51 success=False time=64.1s geometry=cross_stream history=4 | q1=286.874 actor=51.868 alpha=0.058
# [train] episode=315 step=39324 return=-346.95 success=False time=58.1s geometry=cross_stream history=4 | q1=845.926 actor=52.886 alpha=0.058
# [train] episode=320 step=40200 return=-431.94 success=False time=106.1s geometry=cross_stream history=4 | q1=42.126 actor=53.626 alpha=0.057
# [train] episode=325 step=40776 return=-322.23 success=False time=55.8s geometry=cross_stream history=4 | q1=396.458 actor=55.073 alpha=0.056
# [train] episode=330 step=41430 return=-319.49 success=False time=47.0s geometry=cross_stream history=4 | q1=484.996 actor=54.552 alpha=0.055
# [train] episode=335 step=42102 return=-268.52 success=False time=13.7s geometry=cross_stream history=4 | q1=193.631 actor=53.892 alpha=0.055
# [train] episode=340 step=42708 return=-259.09 success=False time=44.7s geometry=cross_stream history=4 | q1=541.896 actor=54.897 alpha=0.054
# [train] episode=345 step=43320 return=-236.62 success=False time=15.7s geometry=cross_stream history=4 | q1=324.827 actor=58.764 alpha=0.054
# [train] episode=350 step=44064 return=-279.48 success=False time=34.4s geometry=cross_stream history=4 | q1=126.107 actor=58.542 alpha=0.053
# [train] episode=355 step=44898 return=-255.77 success=False time=20.6s geometry=cross_stream history=4 | q1=499.728 actor=59.020 alpha=0.053
# [train] episode=360 step=45906 return=-294.15 success=False time=54.2s geometry=cross_stream history=4 | q1=334.165 actor=55.022 alpha=0.052
# [train] episode=365 step=46482 return=-419.68 success=False time=46.9s geometry=cross_stream history=4 | q1=216.554 actor=61.079 alpha=0.051
# [train] episode=370 step=47220 return=-345.18 success=False time=83.3s geometry=cross_stream history=4 | q1=320.008 actor=62.161 alpha=0.052
# [train] episode=375 step=47814 return=-258.76 success=False time=12.1s geometry=cross_stream history=4 | q1=182.357 actor=59.880 alpha=0.051
# [train] episode=380 step=48456 return=-425.08 success=False time=116.4s geometry=cross_stream history=4 | q1=541.797 actor=59.286 alpha=0.050
# [train] episode=385 step=49104 return=-305.96 success=False time=53.3s geometry=cross_stream history=4 | q1=447.828 actor=64.322 alpha=0.050
# [train] episode=390 step=49584 return=-336.09 success=False time=74.3s geometry=cross_stream history=4 | q1=181.362 actor=64.606 alpha=0.050
# [eval] step=50004 objective=arrival_v2 return=-358.42 safety=18.194 success=0.00% time=75.3s energy=31832.0 path=103.0 prog=-1.35
# [train] episode=395 step=50184 return=-251.56 success=False time=23.2s geometry=cross_stream history=4 | q1=622.146 actor=68.869 alpha=0.049
# [train] episode=400 step=50880 return=-256.36 success=False time=20.8s geometry=cross_stream history=4 | q1=448.225 actor=67.768 alpha=0.049
# [train] episode=405 step=51516 return=-505.89 success=False time=110.5s geometry=cross_stream history=4 | q1=421.122 actor=69.110 alpha=0.049
# [train] episode=410 step=52074 return=-379.66 success=False time=77.7s geometry=cross_stream history=4 | q1=48.675 actor=68.216 alpha=0.048
# [train] episode=415 step=52512 return=-304.81 success=False time=53.5s geometry=cross_stream history=4 | q1=75.962 actor=68.776 alpha=0.048
# [train] episode=420 step=53208 return=-343.35 success=False time=57.4s geometry=cross_stream history=4 | q1=387.694 actor=64.699 alpha=0.049
# [train] episode=425 step=54054 return=-247.40 success=False time=20.9s geometry=cross_stream history=4 | q1=298.389 actor=64.780 alpha=0.049
# [train] episode=430 step=54390 return=-480.61 success=False time=113.8s geometry=cross_stream history=4 | q1=100.629 actor=66.296 alpha=0.049
# [train] episode=435 step=55068 return=-491.58 success=False time=114.8s geometry=cross_stream history=4 | q1=157.784 actor=65.704 alpha=0.050
# [train] episode=440 step=55596 return=-358.14 success=False time=60.8s geometry=cross_stream history=4 | q1=164.752 actor=65.333 alpha=0.050
# [train] episode=445 step=56382 return=-396.56 success=False time=82.2s geometry=cross_stream history=4 | q1=427.463 actor=71.267 alpha=0.050
# [train] episode=450 step=57270 return=-357.80 success=False time=73.7s geometry=cross_stream history=4 | q1=259.856 actor=68.692 alpha=0.050
# [train] episode=455 step=58206 return=-272.97 success=False time=240.1s geometry=cross_stream history=4 | q1=94.914 actor=70.982 alpha=0.051
# [train] episode=460 step=58710 return=-295.84 success=False time=55.6s geometry=cross_stream history=4 | q1=315.443 actor=71.441 alpha=0.051
# [train] episode=465 step=59958 return=-337.25 success=False time=67.3s geometry=cross_stream history=4 | q1=6.778 actor=70.999 alpha=0.050
# [train] episode=470 step=60954 return=-348.04 success=False time=112.5s geometry=cross_stream history=4 | q1=247.104 actor=76.007 alpha=0.049
# [train] episode=475 step=61794 return=-245.58 success=False time=34.8s geometry=cross_stream history=4 | q1=17.484 actor=72.099 alpha=0.049
# [train] episode=480 step=62514 return=-285.12 success=False time=27.2s geometry=cross_stream history=4 | q1=355.229 actor=72.606 alpha=0.048
# [train] episode=485 step=63738 return=-212.71 success=False time=102.3s geometry=cross_stream history=4 | q1=238.784 actor=70.765 alpha=0.047
# [train] episode=490 step=63948 return=-574.78 success=False time=111.6s geometry=cross_stream history=4 | q1=237.770 actor=75.969 alpha=0.047
# [train] episode=495 step=64998 return=-489.82 success=False time=95.9s geometry=cross_stream history=4 | q1=227.558 actor=74.345 alpha=0.048
# [train] episode=500 step=65478 return=-278.47 success=False time=45.2s geometry=cross_stream history=4 | q1=134.932 actor=73.610 alpha=0.049
# [train] episode=505 step=65994 return=-248.01 success=False time=12.9s geometry=cross_stream history=4 | q1=166.881 actor=77.370 alpha=0.048
# [train] episode=510 step=66624 return=-382.04 success=False time=67.0s geometry=cross_stream history=4 | q1=137.518 actor=73.022 alpha=0.048
# [train] episode=515 step=67092 return=-252.34 success=False time=7.5s geometry=cross_stream history=4 | q1=119.027 actor=75.533 alpha=0.048
# [train] episode=520 step=68124 return=-506.71 success=False time=91.9s geometry=cross_stream history=4 | q1=264.799 actor=73.076 alpha=0.047
# [train] episode=525 step=68598 return=-331.56 success=False time=62.8s geometry=cross_stream history=4 | q1=33.610 actor=72.605 alpha=0.046
# [train] episode=530 step=69534 return=-310.28 success=False time=53.5s geometry=cross_stream history=4 | q1=143.627 actor=76.628 alpha=0.047
# [train] episode=535 step=70098 return=-243.53 success=False time=22.6s geometry=cross_stream history=4 | q1=387.275 actor=73.459 alpha=0.047
# [train] episode=540 step=70530 return=-273.95 success=False time=99.9s geometry=cross_stream history=4 | q1=205.724 actor=73.008 alpha=0.048
# [train] episode=545 step=70968 return=-265.24 success=False time=30.3s geometry=cross_stream history=4 | q1=353.394 actor=79.306 alpha=0.047
# [train] episode=550 step=71238 return=-251.72 success=False time=12.2s geometry=cross_stream history=4 | q1=97.107 actor=77.255 alpha=0.047
# [train] episode=555 step=71676 return=-375.27 success=False time=83.1s geometry=cross_stream history=4 | q1=71.980 actor=75.368 alpha=0.048
# [train] episode=560 step=72384 return=-285.13 success=False time=95.6s geometry=cross_stream history=4 | q1=171.191 actor=71.902 alpha=0.048
# [train] episode=565 step=73344 return=-413.90 success=False time=77.3s geometry=cross_stream history=4 | q1=293.690 actor=76.932 alpha=0.048
# [train] episode=570 step=74094 return=-202.32 success=False time=53.9s geometry=cross_stream history=4 | q1=101.933 actor=77.754 alpha=0.049
# [eval] step=75000 objective=arrival_v2 return=-345.18 safety=26.674 success=0.00% time=97.9s energy=47820.3 path=101.6 prog=-1.12
# [train] episode=575 step=75480 return=-357.30 success=False time=78.0s geometry=cross_stream history=4 | q1=144.848 actor=79.237 alpha=0.050
# [train] episode=580 step=76176 return=-263.28 success=False time=29.3s geometry=cross_stream history=4 | q1=201.616 actor=78.942 alpha=0.049
# [train] episode=585 step=76776 return=-250.52 success=False time=15.8s geometry=cross_stream history=4 | q1=93.016 actor=77.371 alpha=0.049
# [train] episode=590 step=78306 return=-389.89 success=False time=114.1s geometry=cross_stream history=4 | q1=453.081 actor=79.389 alpha=0.048
# [train] episode=595 step=79260 return=-356.68 success=False time=73.2s geometry=cross_stream history=4 | q1=143.530 actor=80.885 alpha=0.049
# [train] episode=600 step=80022 return=-514.63 success=False time=91.0s geometry=cross_stream history=4 | q1=117.117 actor=80.011 alpha=0.050
# [train] episode=605 step=81150 return=-285.34 success=False time=142.9s geometry=cross_stream history=4 | q1=340.580 actor=83.871 alpha=0.052
# [train] episode=610 step=82392 return=-404.36 success=False time=102.9s geometry=cross_stream history=4 | q1=112.321 actor=81.180 alpha=0.053
# [train] episode=615 step=82920 return=-242.81 success=False time=38.8s geometry=cross_stream history=4 | q1=40.579 actor=84.747 alpha=0.053
# [train] episode=620 step=84276 return=-348.61 success=False time=63.7s geometry=cross_stream history=4 | q1=343.962 actor=81.474 alpha=0.055
# [train] episode=625 step=85026 return=-367.83 success=False time=61.7s geometry=cross_stream history=4 | q1=138.434 actor=86.473 alpha=0.055
# [train] episode=630 step=86106 return=-399.09 success=False time=84.9s geometry=cross_stream history=4 | q1=229.709 actor=86.630 alpha=0.056
# [train] episode=635 step=86730 return=-268.21 success=False time=13.0s geometry=cross_stream history=4 | q1=162.085 actor=86.452 alpha=0.055
# [train] episode=640 step=87342 return=-258.30 success=False time=26.6s geometry=cross_stream history=4 | q1=88.847 actor=83.707 alpha=0.056
# [train] episode=645 step=88488 return=-251.92 success=False time=35.5s geometry=cross_stream history=4 | q1=197.124 actor=86.121 alpha=0.055
# [train] episode=650 step=89064 return=-449.99 success=False time=95.8s geometry=cross_stream history=4 | q1=148.864 actor=83.109 alpha=0.055
# [train] episode=655 step=90444 return=-193.41 success=False time=240.1s geometry=cross_stream history=4 | q1=175.150 actor=86.642 alpha=0.055
# [train] episode=660 step=91116 return=-435.25 success=False time=55.3s geometry=cross_stream history=4 | q1=173.589 actor=89.220 alpha=0.056
# [train] episode=665 step=91578 return=-258.30 success=False time=4.8s geometry=cross_stream history=4 | q1=381.042 actor=90.918 alpha=0.055
# [train] episode=670 step=92304 return=-326.66 success=False time=59.9s geometry=cross_stream history=4 | q1=14.914 actor=84.624 alpha=0.056
# [train] episode=675 step=93054 return=-359.23 success=False time=62.0s geometry=cross_stream history=4 | q1=96.510 actor=86.198 alpha=0.056
# [train] episode=680 step=93366 return=-379.11 success=False time=73.2s geometry=cross_stream history=4 | q1=116.290 actor=85.760 alpha=0.057
# [train] episode=685 step=94182 return=-359.30 success=False time=69.8s geometry=cross_stream history=4 | q1=94.805 actor=89.927 alpha=0.057
# [train] episode=690 step=95082 return=-259.39 success=False time=82.8s geometry=cross_stream history=4 | q1=116.614 actor=84.326 alpha=0.058
# [train] episode=695 step=95904 return=-259.27 success=False time=58.7s geometry=cross_stream history=4 | q1=99.778 actor=88.211 alpha=0.058
# [train] episode=700 step=96594 return=-254.18 success=False time=34.0s geometry=cross_stream history=4 | q1=135.957 actor=83.182 alpha=0.059
# [train] episode=705 step=98208 return=-226.71 success=False time=133.9s geometry=cross_stream history=4 | q1=130.760 actor=87.143 alpha=0.059
# [train] episode=710 step=99198 return=-280.70 success=False time=60.9s geometry=cross_stream history=4 | q1=92.691 actor=92.460 alpha=0.057
# [eval] step=100002 objective=arrival_v2 return=-278.29 safety=17.740 success=0.00% time=84.2s energy=55112.5 path=87.0 prog=-0.40
# [train] episode=715 step=100638 return=-365.56 success=False time=72.2s geometry=cross_stream history=4 | q1=168.756 actor=91.466 alpha=0.058
# [train] episode=720 step=101796 return=-393.68 success=False time=169.8s geometry=cross_stream history=4 | q1=150.096 actor=92.879 alpha=0.059
# [train] episode=725 step=102330 return=-361.35 success=False time=62.4s geometry=cross_stream history=4 | q1=112.182 actor=87.198 alpha=0.060
# [train] episode=730 step=103110 return=-322.95 success=False time=59.4s geometry=cross_stream history=4 | q1=64.203 actor=90.361 alpha=0.061
# [train] episode=735 step=104334 return=-350.01 success=False time=70.0s geometry=cross_stream history=4 | q1=157.010 actor=92.667 alpha=0.060
# [train] episode=740 step=106308 return=-259.56 success=False time=49.1s geometry=cross_stream history=4 | q1=27.250 actor=91.152 alpha=0.061
# [train] episode=745 step=107724 return=-330.65 success=False time=55.8s geometry=cross_stream history=4 | q1=78.181 actor=92.395 alpha=0.062
# [train] episode=750 step=108894 return=-318.55 success=False time=240.1s geometry=cross_stream history=4 | q1=170.999 actor=100.816 alpha=0.063
# [train] episode=755 step=109542 return=-189.44 success=False time=240.1s geometry=cross_stream history=4 | q1=312.233 actor=90.538 alpha=0.065
# [train] episode=760 step=110262 return=-298.79 success=False time=59.3s geometry=cross_stream history=4 | q1=48.654 actor=90.777 alpha=0.068
# [train] episode=765 step=111444 return=-357.49 success=False time=69.4s geometry=cross_stream history=4 | q1=5.603 actor=87.693 alpha=0.068
# [train] episode=770 step=113154 return=-105.83 success=False time=240.1s geometry=cross_stream history=4 | q1=228.848 actor=90.649 alpha=0.067
# [train] episode=775 step=114252 return=-332.05 success=False time=63.9s geometry=cross_stream history=4 | q1=49.896 actor=90.914 alpha=0.068
# [train] episode=780 step=115728 return=-368.25 success=False time=66.9s geometry=cross_stream history=4 | q1=91.890 actor=90.938 alpha=0.070
# [train] episode=785 step=117522 return=-103.85 success=False time=240.1s geometry=cross_stream history=4 | q1=28.348 actor=89.132 alpha=0.073
# [train] episode=790 step=118470 return=-265.96 success=False time=78.4s geometry=cross_stream history=4 | q1=55.109 actor=92.012 alpha=0.075
# [train] episode=795 step=119616 return=-171.92 success=False time=166.7s geometry=cross_stream history=4 | q1=3.675 actor=90.522 alpha=0.079
# [train] episode=800 step=120126 return=138.42 success=True time=204.5s geometry=cross_stream history=4 | q1=118.475 actor=93.438 alpha=0.080
# [train] episode=805 step=121524 return=-24.24 success=True time=121.9s geometry=cross_stream history=4 | q1=148.653 actor=93.815 alpha=0.084
# [train] episode=810 step=122922 return=-96.60 success=False time=240.1s geometry=cross_stream history=4 | q1=77.024 actor=96.015 alpha=0.089
# [train] episode=815 step=124230 return=-278.12 success=False time=53.4s geometry=cross_stream history=4 | q1=91.671 actor=95.310 alpha=0.090
# [eval] step=125004 objective=arrival_v2 return=-283.82 safety=36.582 success=0.00% time=113.5s energy=76594.9 path=92.8 prog=-0.14
# [train] episode=820 step=125406 return=-148.24 success=False time=240.1s geometry=cross_stream history=4 | q1=113.613 actor=94.585 alpha=0.090
# [train] episode=825 step=126780 return=-178.20 success=False time=159.6s geometry=cross_stream history=4 | q1=70.128 actor=94.946 alpha=0.091
# [train] episode=830 step=127458 return=-295.56 success=False time=47.8s geometry=cross_stream history=4 | q1=107.553 actor=97.803 alpha=0.090
# [train] episode=835 step=128376 return=-287.63 success=False time=62.3s geometry=cross_stream history=4 | q1=94.780 actor=90.539 alpha=0.089
# [train] episode=840 step=129078 return=-225.18 success=False time=27.3s geometry=cross_stream history=4 | q1=154.327 actor=95.536 alpha=0.091
# [train] episode=845 step=129750 return=-272.07 success=False time=39.5s geometry=cross_stream history=4 | q1=116.726 actor=91.527 alpha=0.090
# [train] episode=850 step=130590 return=-316.02 success=False time=61.8s geometry=cross_stream history=4 | q1=106.820 actor=95.401 alpha=0.088
# [train] episode=855 step=131298 return=-290.84 success=False time=58.2s geometry=cross_stream history=4 | q1=127.309 actor=95.052 alpha=0.086
# [train] episode=860 step=132162 return=-245.13 success=False time=19.9s geometry=cross_stream history=4 | q1=113.586 actor=93.500 alpha=0.089
# [train] episode=865 step=134142 return=-187.24 success=False time=236.4s geometry=cross_stream history=4 | q1=39.830 actor=90.013 alpha=0.088
# [train] episode=870 step=134478 return=-247.96 success=False time=19.2s geometry=cross_stream history=4 | q1=238.867 actor=94.079 alpha=0.088
# [train] episode=875 step=135210 return=-400.27 success=False time=76.6s geometry=cross_stream history=4 | q1=86.636 actor=97.925 alpha=0.087
# [train] episode=880 step=137298 return=-208.26 success=False time=189.3s geometry=cross_stream history=4 | q1=33.460 actor=95.732 alpha=0.090
# [train] episode=885 step=138816 return=-376.89 success=False time=119.8s geometry=cross_stream history=4 | q1=104.620 actor=91.829 alpha=0.089
# [train] episode=890 step=139740 return=-184.91 success=False time=222.8s geometry=cross_stream history=4 | q1=173.507 actor=93.306 alpha=0.088
# [train] episode=895 step=141324 return=135.67 success=True time=104.4s geometry=cross_stream history=4 | q1=138.496 actor=99.023 alpha=0.088
# [train] episode=900 step=142704 return=-247.29 success=False time=6.3s geometry=cross_stream history=4 | q1=2.959 actor=93.097 alpha=0.090
# [train] episode=905 step=143526 return=-246.87 success=False time=8.1s geometry=cross_stream history=4 | q1=69.332 actor=92.877 alpha=0.091
# [train] episode=910 step=145122 return=-223.45 success=False time=132.4s geometry=cross_stream history=4 | q1=163.654 actor=93.790 alpha=0.090
# [train] episode=915 step=147270 return=101.99 success=True time=81.8s geometry=cross_stream history=4 | q1=83.083 actor=96.464 alpha=0.085
# [train] episode=920 step=147774 return=-287.09 success=False time=54.7s geometry=cross_stream history=4 | q1=5.762 actor=98.659 alpha=0.084
# [train] episode=925 step=149568 return=-269.40 success=False time=161.7s geometry=cross_stream history=4 | q1=134.204 actor=98.265 alpha=0.083
# [eval] step=150000 objective=arrival_v2 return=-210.20 safety=20.749 success=10.00% time=126.5s energy=94412.2 path=101.3 prog=-0.05
# [train] episode=930 step=151080 return=-345.09 success=False time=57.2s geometry=cross_stream history=4 | q1=93.773 actor=98.420 alpha=0.082
# [train] episode=935 step=152178 return=-243.82 success=False time=28.9s geometry=cross_stream history=4 | q1=113.762 actor=95.127 alpha=0.081
# [train] episode=940 step=153060 return=-162.29 success=False time=150.7s geometry=cross_stream history=4 | q1=35.999 actor=98.568 alpha=0.080
# [train] episode=945 step=154092 return=-246.21 success=False time=10.9s geometry=cross_stream history=4 | q1=113.347 actor=98.022 alpha=0.081
# [train] episode=950 step=155514 return=-219.51 success=False time=221.4s geometry=cross_stream history=4 | q1=94.633 actor=97.374 alpha=0.083
# [train] episode=955 step=157608 return=-191.14 success=False time=27.7s geometry=cross_stream history=4 | q1=66.174 actor=101.866 alpha=0.077
# [train] episode=960 step=158760 return=-401.84 success=False time=78.4s geometry=cross_stream history=4 | q1=237.706 actor=96.449 alpha=0.077
# [train] episode=965 step=159336 return=-415.16 success=False time=74.2s geometry=cross_stream history=4 | q1=6.949 actor=92.730 alpha=0.076
# [train] episode=970 step=160674 return=-314.13 success=False time=119.4s geometry=cross_stream history=4 | q1=48.976 actor=97.554 alpha=0.077
# [train] episode=975 step=162204 return=-253.00 success=False time=237.9s geometry=cross_stream history=4 | q1=189.581 actor=99.338 alpha=0.077
# [train] episode=980 step=163260 return=-215.61 success=False time=98.3s geometry=cross_stream history=4 | q1=28.433 actor=100.898 alpha=0.078
# [train] episode=985 step=164346 return=-255.20 success=False time=228.1s geometry=cross_stream history=4 | q1=92.473 actor=96.724 alpha=0.077
# [train] episode=990 step=165366 return=-269.20 success=False time=13.2s geometry=cross_stream history=4 | q1=37.040 actor=99.164 alpha=0.076
# [train] episode=995 step=167016 return=-172.60 success=False time=175.9s geometry=cross_stream history=4 | q1=27.637 actor=94.664 alpha=0.075
# [train] episode=1000 step=168150 return=-348.49 success=False time=93.6s geometry=cross_stream history=4 | q1=177.973 actor=101.632 alpha=0.075
# [train] episode=1005 step=168684 return=-195.34 success=False time=31.1s geometry=cross_stream history=4 | q1=49.393 actor=95.983 alpha=0.074
# [train] episode=1010 step=170220 return=-336.33 success=False time=225.1s geometry=cross_stream history=4 | q1=109.707 actor=97.745 alpha=0.075
# [train] episode=1015 step=171354 return=-302.25 success=False time=53.4s geometry=cross_stream history=4 | q1=3.233 actor=99.342 alpha=0.077
# [train] episode=1020 step=172572 return=-228.68 success=False time=127.3s geometry=cross_stream history=4 | q1=4.111 actor=104.672 alpha=0.076
# [train] episode=1025 step=174006 return=-266.51 success=False time=39.5s geometry=cross_stream history=4 | q1=64.348 actor=103.381 alpha=0.075
# [train] episode=1030 step=174888 return=-380.63 success=False time=62.7s geometry=cross_stream history=4 | q1=20.687 actor=96.361 alpha=0.072
# [eval] step=175002 objective=arrival_v2 return=-255.69 safety=16.332 success=0.00% time=88.5s energy=63960.8 path=79.8 prog=-0.15
# [train] episode=1035 step=175986 return=-360.90 success=False time=198.5s geometry=cross_stream history=4 | q1=66.949 actor=98.342 alpha=0.071
# [train] episode=1040 step=176838 return=-375.17 success=False time=70.5s geometry=cross_stream history=4 | q1=73.025 actor=100.143 alpha=0.071
# [train] episode=1045 step=178128 return=-239.57 success=False time=18.2s geometry=cross_stream history=4 | q1=44.358 actor=98.256 alpha=0.071
# [train] episode=1050 step=179004 return=-137.56 success=False time=240.1s geometry=cross_stream history=4 | q1=34.948 actor=99.180 alpha=0.069
# [train] episode=1055 step=179904 return=-264.77 success=False time=107.8s geometry=cross_stream history=4 | q1=117.183 actor=100.910 alpha=0.068
# [train] episode=1060 step=181314 return=-97.01 success=False time=240.1s geometry=cross_stream history=4 | q1=105.736 actor=101.549 alpha=0.065
# [train] episode=1065 step=182088 return=-158.33 success=False time=161.8s geometry=cross_stream history=4 | q1=110.481 actor=104.646 alpha=0.065
# [train] episode=1070 step=183282 return=-199.70 success=False time=100.9s geometry=cross_stream history=4 | q1=53.817 actor=99.934 alpha=0.066
# [train] episode=1075 step=184284 return=-239.30 success=False time=28.9s geometry=cross_stream history=4 | q1=139.248 actor=104.684 alpha=0.067
# [train] episode=1080 step=186240 return=-351.24 success=False time=57.1s geometry=cross_stream history=4 | q1=300.815 actor=102.217 alpha=0.066
# [train] episode=1085 step=186900 return=-335.38 success=False time=54.1s geometry=cross_stream history=4 | q1=32.193 actor=104.866 alpha=0.066
# [train] episode=1090 step=187368 return=-252.06 success=False time=14.7s geometry=cross_stream history=4 | q1=114.224 actor=105.227 alpha=0.065
# [train] episode=1095 step=188646 return=-313.88 success=False time=68.4s geometry=cross_stream history=4 | q1=128.870 actor=105.294 alpha=0.068
# [train] episode=1100 step=189414 return=-323.55 success=False time=48.5s geometry=cross_stream history=4 | q1=22.744 actor=104.655 alpha=0.067
# [train] episode=1105 step=190170 return=-237.24 success=False time=17.0s geometry=cross_stream history=4 | q1=14.745 actor=102.407 alpha=0.066
# [train] episode=1110 step=190632 return=-371.56 success=False time=75.3s geometry=cross_stream history=4 | q1=51.043 actor=98.652 alpha=0.065
# [train] episode=1115 step=191964 return=137.39 success=True time=136.3s geometry=cross_stream history=4 | q1=46.269 actor=105.355 alpha=0.065
# [train] episode=1120 step=193044 return=-285.01 success=False time=48.7s geometry=cross_stream history=4 | q1=4.163 actor=103.528 alpha=0.065
# [train] episode=1125 step=194148 return=-69.79 success=False time=240.1s geometry=cross_stream history=4 | q1=36.126 actor=105.870 alpha=0.065
# [train] episode=1130 step=195042 return=-343.80 success=False time=73.9s geometry=cross_stream history=4 | q1=110.893 actor=104.864 alpha=0.065
# [train] episode=1135 step=195942 return=-293.70 success=False time=39.5s geometry=cross_stream history=4 | q1=116.614 actor=108.047 alpha=0.066
# [train] episode=1140 step=197070 return=-423.96 success=False time=93.3s geometry=cross_stream history=4 | q1=56.932 actor=106.721 alpha=0.065
# [train] episode=1145 step=198144 return=54.32 success=True time=151.8s geometry=cross_stream history=4 | q1=53.056 actor=104.990 alpha=0.064
# [train] episode=1150 step=199260 return=-325.86 success=False time=240.1s geometry=cross_stream history=4 | q1=54.514 actor=111.103 alpha=0.064
# [eval] step=200004 objective=arrival_v2 return=-214.36 safety=21.150 success=6.67% time=99.7s energy=71032.7 path=81.0 prog=0.14
# [train] episode=1155 step=200946 return=-43.23 success=False time=240.1s geometry=cross_stream history=4 | q1=22.831 actor=106.295 alpha=0.063
# [train] episode=1160 step=202140 return=-365.85 success=False time=70.9s geometry=cross_stream history=4 | q1=58.770 actor=108.127 alpha=0.063
# [train] episode=1165 step=203136 return=-240.52 success=False time=23.2s geometry=cross_stream history=4 | q1=72.710 actor=105.092 alpha=0.063
# [train] episode=1170 step=204762 return=-248.16 success=False time=10.6s geometry=cross_stream history=4 | q1=48.030 actor=107.297 alpha=0.064
# [train] episode=1175 step=205926 return=-320.24 success=False time=94.4s geometry=cross_stream history=4 | q1=89.592 actor=108.502 alpha=0.062
# [train] episode=1180 step=207210 return=-306.34 success=False time=56.6s geometry=cross_stream history=4 | q1=93.671 actor=108.714 alpha=0.061
# [train] episode=1185 step=208290 return=-211.67 success=False time=240.1s geometry=cross_stream history=4 | q1=48.787 actor=106.276 alpha=0.061
# [train] episode=1190 step=209184 return=-261.79 success=False time=29.6s geometry=cross_stream history=4 | q1=125.330 actor=108.560 alpha=0.061
# [train] episode=1195 step=210216 return=-276.65 success=False time=62.7s geometry=cross_stream history=4 | q1=38.961 actor=107.705 alpha=0.061
# [train] episode=1200 step=210906 return=-310.07 success=False time=56.5s geometry=cross_stream history=4 | q1=2.414 actor=109.489 alpha=0.060
# [train] episode=1205 step=211524 return=-268.44 success=False time=24.9s geometry=cross_stream history=4 | q1=28.475 actor=106.157 alpha=0.059
# [train] episode=1210 step=211932 return=-262.85 success=False time=11.9s geometry=cross_stream history=4 | q1=67.735 actor=111.767 alpha=0.059
# [train] episode=1215 step=212592 return=-278.59 success=False time=54.5s geometry=cross_stream history=4 | q1=14.501 actor=109.820 alpha=0.058
# [train] episode=1220 step=212886 return=-249.96 success=False time=11.2s geometry=cross_stream history=4 | q1=60.585 actor=108.365 alpha=0.058
# [train] episode=1225 step=215496 return=-369.55 success=False time=69.5s geometry=cross_stream history=4 | q1=51.260 actor=107.116 alpha=0.057
# [train] episode=1230 step=216264 return=-96.78 success=False time=240.1s geometry=cross_stream history=4 | q1=80.823 actor=111.199 alpha=0.057
# [train] episode=1235 step=218202 return=-258.14 success=False time=201.1s geometry=cross_stream history=4 | q1=161.422 actor=109.640 alpha=0.057
# [train] episode=1240 step=218742 return=137.03 success=True time=130.6s geometry=cross_stream history=4 | q1=46.791 actor=105.734 alpha=0.057
# [train] episode=1245 step=219420 return=-266.18 success=False time=56.3s geometry=cross_stream history=4 | q1=13.899 actor=111.051 alpha=0.057
# [train] episode=1250 step=220122 return=-348.54 success=False time=43.3s geometry=cross_stream history=4 | q1=96.232 actor=109.609 alpha=0.057
# [train] episode=1255 step=221316 return=63.13 success=True time=116.7s geometry=cross_stream history=4 | q1=3.677 actor=111.489 alpha=0.057
# [train] episode=1260 step=223014 return=-94.57 success=False time=240.1s geometry=cross_stream history=4 | q1=22.624 actor=112.402 alpha=0.057
# [train] episode=1265 step=224394 return=115.91 success=True time=222.4s geometry=cross_stream history=4 | q1=16.939 actor=108.934 alpha=0.055
# [eval] step=225000 objective=arrival_v2 return=-218.89 safety=17.182 success=13.33% time=101.1s energy=64419.7 path=87.4 prog=-0.16
# [train] episode=1270 step=225492 return=-229.18 success=False time=31.5s geometry=cross_stream history=4 | q1=65.569 actor=111.300 alpha=0.055
# [train] episode=1275 step=226470 return=-283.34 success=False time=48.0s geometry=cross_stream history=4 | q1=75.338 actor=109.372 alpha=0.055
# [train] episode=1280 step=227802 return=-231.66 success=False time=240.1s geometry=cross_stream history=4 | q1=3.997 actor=109.912 alpha=0.056
# [train] episode=1285 step=228480 return=-245.47 success=False time=9.4s geometry=cross_stream history=4 | q1=17.735 actor=111.906 alpha=0.056
# [train] episode=1290 step=229182 return=-61.72 success=True time=140.8s geometry=cross_stream history=4 | q1=88.873 actor=112.938 alpha=0.056
# [train] episode=1295 step=230046 return=-343.00 success=False time=67.8s geometry=cross_stream history=4 | q1=141.186 actor=111.015 alpha=0.057
# [train] episode=1300 step=231582 return=-284.50 success=False time=54.1s geometry=cross_stream history=4 | q1=28.523 actor=111.928 alpha=0.057
# [train] episode=1305 step=233214 return=-320.02 success=False time=61.6s geometry=cross_stream history=4 | q1=38.762 actor=111.350 alpha=0.058
# [train] episode=1310 step=234150 return=-281.02 success=False time=238.2s geometry=cross_stream history=4 | q1=50.188 actor=111.525 alpha=0.060
# [train] episode=1315 step=234882 return=-260.66 success=False time=29.5s geometry=cross_stream history=4 | q1=45.929 actor=111.999 alpha=0.061
# [train] episode=1320 step=235956 return=-329.02 success=False time=49.5s geometry=cross_stream history=4 | q1=16.058 actor=113.134 alpha=0.062
# [train] episode=1325 step=236826 return=-342.39 success=False time=57.9s geometry=cross_stream history=4 | q1=120.236 actor=110.757 alpha=0.064
# [train] episode=1330 step=237588 return=-143.54 success=False time=240.1s geometry=cross_stream history=4 | q1=10.752 actor=114.778 alpha=0.064
# [train] episode=1335 step=239112 return=139.23 success=True time=202.8s geometry=cross_stream history=4 | q1=79.961 actor=110.773 alpha=0.067
# [train] episode=1340 step=240480 return=-162.60 success=False time=240.1s geometry=cross_stream history=4 | q1=59.846 actor=109.768 alpha=0.069
# [train] episode=1345 step=242388 return=-161.89 success=False time=240.1s geometry=cross_stream history=4 | q1=14.388 actor=116.392 alpha=0.070
# [train] episode=1350 step=244548 return=-177.13 success=False time=240.1s geometry=cross_stream history=4 | q1=97.599 actor=113.992 alpha=0.070
# [train] episode=1355 step=245286 return=-310.75 success=False time=53.9s geometry=cross_stream history=4 | q1=76.087 actor=111.521 alpha=0.070
# [train] episode=1360 step=246564 return=-298.68 success=False time=47.5s geometry=cross_stream history=4 | q1=98.087 actor=111.653 alpha=0.070
# [train] episode=1365 step=248292 return=-377.43 success=False time=240.1s geometry=cross_stream history=4 | q1=4.779 actor=112.126 alpha=0.069
# [train] episode=1370 step=249186 return=-282.74 success=False time=45.1s geometry=cross_stream history=4 | q1=7.098 actor=111.283 alpha=0.071
# [eval] step=250002 objective=arrival_v2 return=-172.93 safety=27.694 success=23.33% time=126.5s energy=84630.4 path=93.1 prog=0.12
# [train] episode=1375 step=250902 return=-241.57 success=False time=14.2s geometry=cross_stream history=4 | q1=42.023 actor=115.926 alpha=0.073
# [train] episode=1380 step=251658 return=-220.28 success=False time=39.0s geometry=cross_stream history=4 | q1=160.252 actor=110.322 alpha=0.072
# [train] episode=1385 step=252348 return=-218.83 success=False time=240.1s geometry=cross_stream history=4 | q1=3.169 actor=112.982 alpha=0.074
# [train] episode=1390 step=254550 return=-193.41 success=False time=240.1s geometry=cross_stream history=4 | q1=80.137 actor=113.937 alpha=0.076
# [train] episode=1395 step=255978 return=-349.67 success=False time=60.9s geometry=cross_stream history=4 | q1=62.863 actor=106.710 alpha=0.076
# [train] episode=1400 step=257946 return=-326.99 success=False time=172.8s geometry=cross_stream history=4 | q1=3.742 actor=109.459 alpha=0.078
# [train] episode=1405 step=259056 return=-216.22 success=False time=240.1s geometry=cross_stream history=4 | q1=16.491 actor=111.342 alpha=0.078
# [train] episode=1410 step=261054 return=-518.58 success=False time=240.1s geometry=cross_stream history=4 | q1=76.422 actor=111.092 alpha=0.078
# [train] episode=1415 step=261972 return=-265.41 success=False time=240.1s geometry=cross_stream history=4 | q1=55.972 actor=111.004 alpha=0.077
# [train] episode=1420 step=264072 return=-300.27 success=False time=181.7s geometry=cross_stream history=4 | q1=27.989 actor=110.223 alpha=0.076
# [train] episode=1425 step=266316 return=-266.96 success=False time=240.1s geometry=cross_stream history=4 | q1=72.991 actor=110.493 alpha=0.078
# [train] episode=1430 step=267732 return=-184.15 success=False time=240.1s geometry=cross_stream history=4 | q1=143.628 actor=109.649 alpha=0.077
# [train] episode=1435 step=269034 return=142.00 success=True time=107.7s geometry=cross_stream history=4 | q1=41.138 actor=112.869 alpha=0.077
# [train] episode=1440 step=270744 return=-256.94 success=False time=56.2s geometry=cross_stream history=4 | q1=10.378 actor=114.566 alpha=0.077
# [train] episode=1445 step=271212 return=-224.40 success=False time=34.8s geometry=cross_stream history=4 | q1=204.719 actor=109.975 alpha=0.077
# [train] episode=1450 step=272106 return=-242.03 success=False time=106.6s geometry=cross_stream history=4 | q1=33.956 actor=113.082 alpha=0.078
# [train] episode=1455 step=274092 return=-262.75 success=False time=137.7s geometry=cross_stream history=4 | q1=53.757 actor=112.553 alpha=0.082
# [eval] step=275004 objective=arrival_v2 return=-238.74 safety=27.702 success=0.00% time=106.2s energy=75109.4 path=80.1 prog=0.15
# [train] episode=1460 step=275070 return=-154.60 success=False time=240.1s geometry=cross_stream history=4 | q1=17.664 actor=114.703 alpha=0.082
# [train] episode=1465 step=276858 return=-284.19 success=False time=45.3s geometry=cross_stream history=4 | q1=46.308 actor=111.729 alpha=0.085
# [train] episode=1470 step=278226 return=-220.87 success=False time=35.3s geometry=cross_stream history=4 | q1=77.227 actor=110.097 alpha=0.085
# [train] episode=1475 step=280272 return=-407.85 success=False time=214.0s geometry=cross_stream history=4 | q1=47.735 actor=108.384 alpha=0.084
# [train] episode=1480 step=281952 return=-254.30 success=False time=240.1s geometry=cross_stream history=4 | q1=31.082 actor=109.258 alpha=0.084
# [train] episode=1485 step=282726 return=-230.45 success=False time=33.5s geometry=cross_stream history=4 | q1=26.802 actor=109.959 alpha=0.084
# [train] episode=1490 step=285402 return=-257.12 success=False time=240.1s geometry=cross_stream history=4 | q1=28.076 actor=107.436 alpha=0.086
# [train] episode=1495 step=287736 return=-144.46 success=False time=240.1s geometry=cross_stream history=4 | q1=85.578 actor=105.692 alpha=0.087
# [train] episode=1500 step=288402 return=-321.17 success=False time=68.5s geometry=cross_stream history=4 | q1=19.984 actor=106.220 alpha=0.088
# [train] episode=1505 step=290628 return=-161.14 success=False time=240.1s geometry=cross_stream history=4 | q1=15.305 actor=109.784 alpha=0.087
# [train] episode=1510 step=292170 return=-134.61 success=False time=240.1s geometry=cross_stream history=4 | q1=92.956 actor=111.607 alpha=0.087
# [train] episode=1515 step=294180 return=-123.99 success=False time=240.1s geometry=cross_stream history=4 | q1=197.360 actor=102.159 alpha=0.085
# [train] episode=1520 step=294714 return=-210.39 success=False time=48.1s geometry=cross_stream history=4 | q1=28.263 actor=105.711 alpha=0.086
# [train] episode=1525 step=295890 return=-247.86 success=False time=37.3s geometry=cross_stream history=4 | q1=70.227 actor=109.143 alpha=0.086
# [train] episode=1530 step=298434 return=-144.10 success=False time=240.1s geometry=cross_stream history=4 | q1=108.308 actor=105.899 alpha=0.089
# [train] episode=1535 step=299286 return=-38.91 success=False time=240.1s geometry=cross_stream history=4 | q1=82.076 actor=102.184 alpha=0.090
# [eval] step=300000 objective=arrival_v2 return=-133.30 safety=22.827 success=20.00% time=143.3s energy=98401.2 path=103.7 prog=0.39
# [train] episode=1540 step=300984 return=-240.75 success=False time=13.0s geometry=cross_stream history=4 | q1=157.318 actor=102.749 alpha=0.088
# [train] episode=1545 step=302634 return=-233.06 success=False time=79.1s geometry=cross_stream history=4 | q1=42.056 actor=107.384 alpha=0.088
# [train] episode=1550 step=304536 return=-250.95 success=False time=54.3s geometry=cross_stream history=4 | q1=11.736 actor=103.599 alpha=0.089
# [train] episode=1555 step=305526 return=-141.40 success=False time=240.1s geometry=cross_stream history=4 | q1=82.974 actor=103.110 alpha=0.089
# [train] episode=1560 step=306546 return=-291.85 success=False time=44.2s geometry=cross_stream history=4 | q1=92.261 actor=104.664 alpha=0.089
# [train] episode=1565 step=308400 return=-138.26 success=False time=240.1s geometry=cross_stream history=4 | q1=180.555 actor=104.881 alpha=0.089
# [train] episode=1570 step=309180 return=140.68 success=True time=52.7s geometry=cross_stream history=4 | q1=16.135 actor=102.773 alpha=0.089
# [train] episode=1575 step=310134 return=-121.62 success=False time=240.1s geometry=cross_stream history=4 | q1=41.358 actor=101.559 alpha=0.091
# [train] episode=1580 step=311280 return=-260.92 success=False time=39.7s geometry=cross_stream history=4 | q1=157.266 actor=104.603 alpha=0.090
# [train] episode=1585 step=312300 return=131.94 success=True time=84.3s geometry=cross_stream history=4 | q1=15.422 actor=102.704 alpha=0.091
# [train] episode=1590 step=314844 return=-112.20 success=False time=240.1s geometry=cross_stream history=4 | q1=34.381 actor=101.021 alpha=0.090
# [train] episode=1595 step=315654 return=-145.45 success=False time=240.1s geometry=cross_stream history=4 | q1=103.746 actor=102.509 alpha=0.090
# [train] episode=1600 step=317760 return=-181.45 success=False time=240.1s geometry=cross_stream history=4 | q1=16.896 actor=101.351 alpha=0.089
# [train] episode=1605 step=318834 return=-75.99 success=False time=240.1s geometry=cross_stream history=4 | q1=20.939 actor=99.177 alpha=0.089
# [train] episode=1610 step=321324 return=-150.89 success=False time=240.1s geometry=cross_stream history=4 | q1=34.118 actor=102.503 alpha=0.089
# [train] episode=1615 step=323238 return=-206.87 success=False time=240.1s geometry=cross_stream history=4 | q1=113.883 actor=97.330 alpha=0.090
# [train] episode=1620 step=324732 return=-191.92 success=False time=104.5s geometry=cross_stream history=4 | q1=19.935 actor=95.042 alpha=0.088
# [eval] step=325002 objective=arrival_v2 return=-193.41 safety=22.316 success=6.67% time=145.4s energy=96771.7 path=100.3 prog=0.06
# [train] episode=1625 step=326802 return=-291.87 success=False time=55.1s geometry=cross_stream history=4 | q1=20.029 actor=94.229 alpha=0.088
# [train] episode=1630 step=327900 return=-159.70 success=False time=240.1s geometry=cross_stream history=4 | q1=41.049 actor=95.805 alpha=0.089
# [train] episode=1635 step=328716 return=-168.86 success=False time=240.1s geometry=cross_stream history=4 | q1=24.462 actor=98.391 alpha=0.089
# ...
# [eval] step=850002 objective=arrival_v2 return=-137.64 safety=20.900 success=6.67% time=149.4s energy=108752.5 path=120.6 prog=0.58
# [train] episode=4100 step=851730 return=140.19 success=True time=102.3s geometry=cross_stream history=4 | q1=31.165 actor=105.018 alpha=0.064
# [train] episode=4105 step=852618 return=-239.61 success=False time=41.5s geometry=cross_stream history=4 | q1=3.604 actor=106.983 alpha=0.062
# [train] episode=4110 step=854922 return=-117.13 success=False time=240.1s geometry=cross_stream history=4 | q1=106.311 actor=106.974 alpha=0.064
# [train] episode=4115 step=855828 return=139.43 success=True time=122.7s geometry=cross_stream history=4 | q1=8.366 actor=107.941 alpha=0.063
# [train] episode=4120 step=857514 return=-59.07 success=False time=240.1s geometry=cross_stream history=4 | q1=8.339 actor=106.398 alpha=0.065
# [train] episode=4125 step=858882 return=-164.18 success=False time=240.1s geometry=cross_stream history=4 | q1=36.637 actor=108.951 alpha=0.065
# [train] episode=4130 step=860826 return=-86.00 success=False time=240.1s geometry=cross_stream history=4 | q1=13.342 actor=107.633 alpha=0.065
# [train] episode=4135 step=862176 return=-218.48 success=False time=240.1s geometry=cross_stream history=4 | q1=27.117 actor=108.271 alpha=0.065
# [train] episode=4140 step=863916 return=-226.51 success=False time=87.5s geometry=cross_stream history=4 | q1=19.890 actor=108.686 alpha=0.062
# [train] episode=4145 step=865704 return=-144.10 success=False time=240.1s geometry=cross_stream history=4 | q1=232.848 actor=106.905 alpha=0.061
# [train] episode=4150 step=866808 return=-80.83 success=False time=240.1s geometry=cross_stream history=4 | q1=38.142 actor=106.317 alpha=0.061
# [train] episode=4155 step=869538 return=-126.32 success=False time=240.1s geometry=cross_stream history=4 | q1=3.096 actor=108.908 alpha=0.061
# [train] episode=4160 step=871164 return=-159.47 success=False time=154.4s geometry=cross_stream history=4 | q1=16.451 actor=107.357 alpha=0.064
# [train] episode=4165 step=872172 return=137.30 success=True time=218.7s geometry=cross_stream history=4 | q1=47.001 actor=107.180 alpha=0.067
# [train] episode=4170 step=873840 return=-234.78 success=False time=11.9s geometry=cross_stream history=4 | q1=6.448 actor=109.003 alpha=0.066
# [train] episode=4175 step=874386 return=-117.42 success=False time=240.1s geometry=cross_stream history=4 | q1=36.440 actor=107.756 alpha=0.066
# [eval] step=875004 objective=arrival_v2 return=-121.46 safety=24.222 success=26.67% time=113.4s energy=85870.1 path=92.6 prog=0.54
# [train] episode=4180 step=875922 return=-209.09 success=False time=33.8s geometry=cross_stream history=4 | q1=5.871 actor=105.386 alpha=0.066
# [train] episode=4185 step=877212 return=-86.24 success=False time=240.1s geometry=cross_stream history=4 | q1=17.564 actor=105.882 alpha=0.067
# [train] episode=4190 step=879042 return=-135.61 success=False time=240.1s geometry=cross_stream history=4 | q1=174.674 actor=109.693 alpha=0.065
# [train] episode=4195 step=881706 return=-124.60 success=False time=240.1s geometry=cross_stream history=4 | q1=18.163 actor=105.805 alpha=0.064
# [train] episode=4200 step=882750 return=-98.57 success=False time=240.1s geometry=cross_stream history=4 | q1=44.278 actor=107.405 alpha=0.065
# [train] episode=4205 step=885282 return=-117.22 success=False time=240.1s geometry=cross_stream history=4 | q1=5.512 actor=106.201 alpha=0.064
# [train] episode=4210 step=886884 return=-118.15 success=False time=240.1s geometry=cross_stream history=4 | q1=9.607 actor=107.323 alpha=0.063
# [train] episode=4215 step=888048 return=-214.48 success=False time=229.7s geometry=cross_stream history=4 | q1=20.221 actor=107.632 alpha=0.063
# [train] episode=4220 step=888966 return=-108.02 success=False time=240.1s geometry=cross_stream history=4 | q1=69.171 actor=107.939 alpha=0.064
# [train] episode=4225 step=890244 return=-272.15 success=False time=46.8s geometry=cross_stream history=4 | q1=22.185 actor=107.950 alpha=0.062
# [train] episode=4230 step=891102 return=-227.97 success=False time=53.8s geometry=cross_stream history=4 | q1=30.076 actor=108.713 alpha=0.061
# [train] episode=4235 step=892542 return=-231.36 success=False time=12.3s geometry=cross_stream history=4 | q1=69.980 actor=107.699 alpha=0.061
# [train] episode=4240 step=893862 return=-221.87 success=False time=101.4s geometry=cross_stream history=4 | q1=8.660 actor=106.500 alpha=0.062
# [train] episode=4245 step=895236 return=-116.04 success=False time=240.1s geometry=cross_stream history=4 | q1=165.278 actor=107.862 alpha=0.062
# [train] episode=4250 step=896772 return=-213.11 success=False time=127.5s geometry=cross_stream history=4 | q1=15.225 actor=109.600 alpha=0.061
# [train] episode=4255 step=897894 return=-271.85 success=False time=37.9s geometry=cross_stream history=4 | q1=38.998 actor=108.541 alpha=0.061
# [train] episode=4260 step=899808 return=-202.62 success=False time=240.1s geometry=cross_stream history=4 | q1=28.466 actor=108.188 alpha=0.061
# [eval] step=900000 objective=arrival_v2 return=-214.05 safety=28.481 success=0.00% time=141.6s energy=93205.7 path=103.5 prog=0.25
# [train] episode=4265 step=900210 return=-222.15 success=False time=46.4s geometry=cross_stream history=4 | q1=19.965 actor=106.194 alpha=0.061
# [train] episode=4270 step=901080 return=-282.42 success=False time=87.4s geometry=cross_stream history=4 | q1=6.885 actor=106.521 alpha=0.061
# [train] episode=4275 step=902712 return=-253.00 success=False time=135.5s geometry=cross_stream history=4 | q1=8.085 actor=108.110 alpha=0.061
# [train] episode=4280 step=903744 return=-102.92 success=False time=240.1s geometry=cross_stream history=4 | q1=64.865 actor=107.526 alpha=0.063
# [train] episode=4285 step=905142 return=-204.02 success=False time=129.8s geometry=cross_stream history=4 | q1=39.912 actor=107.416 alpha=0.062
# [train] episode=4290 step=906342 return=-258.55 success=False time=6.4s geometry=cross_stream history=4 | q1=43.572 actor=106.651 alpha=0.062
# [train] episode=4295 step=907188 return=140.91 success=True time=35.9s geometry=cross_stream history=4 | q1=26.638 actor=107.230 alpha=0.062
# [train] episode=4300 step=909384 return=-199.40 success=False time=211.4s geometry=cross_stream history=4 | q1=260.345 actor=107.794 alpha=0.062
# [train] episode=4305 step=910110 return=141.77 success=True time=39.8s geometry=cross_stream history=4 | q1=44.798 actor=107.356 alpha=0.062
# [train] episode=4310 step=912348 return=-196.78 success=False time=240.1s geometry=cross_stream history=4 | q1=74.491 actor=108.444 alpha=0.062
# [train] episode=4315 step=913068 return=-219.69 success=False time=59.5s geometry=cross_stream history=4 | q1=3.910 actor=106.218 alpha=0.061
# [train] episode=4320 step=914754 return=-297.77 success=False time=50.0s geometry=cross_stream history=4 | q1=17.878 actor=105.472 alpha=0.062
# [train] episode=4325 step=915774 return=-289.47 success=False time=87.9s geometry=cross_stream history=4 | q1=5.135 actor=107.305 alpha=0.061
# [train] episode=4330 step=916314 return=-201.87 success=False time=44.2s geometry=cross_stream history=4 | q1=22.024 actor=105.594 alpha=0.061
# [train] episode=4335 step=917586 return=-259.32 success=False time=71.3s geometry=cross_stream history=4 | q1=7.050 actor=109.084 alpha=0.061
# [train] episode=4340 step=919044 return=-220.52 success=False time=48.9s geometry=cross_stream history=4 | q1=19.889 actor=106.443 alpha=0.061
# [train] episode=4345 step=920970 return=-109.97 success=False time=240.1s geometry=cross_stream history=4 | q1=12.945 actor=108.722 alpha=0.064
# [train] episode=4350 step=923448 return=-196.31 success=False time=240.1s geometry=cross_stream history=4 | q1=34.857 actor=107.472 alpha=0.062
# [train] episode=4355 step=924876 return=-215.23 success=False time=47.8s geometry=cross_stream history=4 | q1=9.409 actor=110.188 alpha=0.059
# [eval] step=925002 objective=arrival_v2 return=-202.85 safety=28.528 success=0.00% time=154.5s energy=105573.7 path=112.4 prog=0.26
# [train] episode=4360 step=926340 return=-89.66 success=False time=240.1s geometry=cross_stream history=4 | q1=36.679 actor=106.988 alpha=0.059
# [train] episode=4365 step=927354 return=-167.40 success=False time=190.4s geometry=cross_stream history=4 | q1=37.817 actor=107.037 alpha=0.059
# [train] episode=4370 step=928302 return=-230.37 success=False time=38.6s geometry=cross_stream history=4 | q1=20.351 actor=107.265 alpha=0.059
# [train] episode=4375 step=929670 return=-76.17 success=False time=240.1s geometry=cross_stream history=4 | q1=3.850 actor=106.719 alpha=0.059
# [train] episode=4380 step=931860 return=-344.51 success=False time=186.3s geometry=cross_stream history=4 | q1=272.234 actor=106.545 alpha=0.060
# [train] episode=4385 step=933252 return=-140.81 success=False time=240.1s geometry=cross_stream history=4 | q1=35.948 actor=105.764 alpha=0.060
# [train] episode=4390 step=934146 return=-250.84 success=False time=73.9s geometry=cross_stream history=4 | q1=4.990 actor=108.366 alpha=0.060
# [train] episode=4395 step=935130 return=-150.35 success=False time=202.5s geometry=cross_stream history=4 | q1=8.823 actor=107.527 alpha=0.059
# [train] episode=4400 step=936342 return=-225.85 success=False time=42.9s geometry=cross_stream history=4 | q1=26.135 actor=109.846 alpha=0.059
# [train] episode=4405 step=937644 return=-134.27 success=False time=240.1s geometry=cross_stream history=4 | q1=31.884 actor=104.754 alpha=0.059
# [train] episode=4410 step=938466 return=-256.28 success=False time=15.7s geometry=cross_stream history=4 | q1=6.352 actor=106.203 alpha=0.059
# [train] episode=4415 step=939492 return=122.67 success=True time=84.8s geometry=cross_stream history=4 | q1=4.592 actor=107.661 alpha=0.059
# [train] episode=4420 step=941268 return=-226.58 success=False time=46.5s geometry=cross_stream history=4 | q1=57.361 actor=107.188 alpha=0.059
# [train] episode=4425 step=941784 return=-249.85 success=False time=240.1s geometry=cross_stream history=4 | q1=74.740 actor=106.833 alpha=0.059
# [train] episode=4430 step=943338 return=-173.07 success=False time=152.7s geometry=cross_stream history=4 | q1=11.020 actor=109.037 alpha=0.058
# [train] episode=4435 step=945048 return=-133.88 success=False time=240.1s geometry=cross_stream history=4 | q1=215.174 actor=104.496 alpha=0.057
# [train] episode=4440 step=946674 return=-172.90 success=False time=95.9s geometry=cross_stream history=4 | q1=23.666 actor=107.168 alpha=0.060
# [train] episode=4445 step=947976 return=-218.13 success=False time=92.6s geometry=cross_stream history=4 | q1=15.099 actor=108.903 alpha=0.061
# [train] episode=4450 step=949344 return=-205.88 success=False time=110.0s geometry=cross_stream history=4 | q1=10.320 actor=107.430 alpha=0.062
# [train] episode=4455 step=949848 return=-231.62 success=False time=41.4s geometry=cross_stream history=4 | q1=18.993 actor=109.155 alpha=0.061
# [eval] step=950004 objective=arrival_v2 return=-94.84 safety=14.682 success=23.33% time=130.1s energy=97520.1 path=110.1 prog=0.52
# [train] episode=4460 step=950994 return=-212.20 success=False time=95.0s geometry=cross_stream history=4 | q1=9.570 actor=109.225 alpha=0.061
# [train] episode=4465 step=952134 return=-254.41 success=False time=54.3s geometry=cross_stream history=4 | q1=41.977 actor=106.799 alpha=0.060
# [train] episode=4470 step=954024 return=-262.13 success=False time=37.3s geometry=cross_stream history=4 | q1=3.569 actor=106.277 alpha=0.060
# [train] episode=4475 step=955026 return=-130.79 success=False time=240.1s geometry=cross_stream history=4 | q1=60.360 actor=106.585 alpha=0.058
# [train] episode=4480 step=956430 return=-179.83 success=False time=199.7s geometry=cross_stream history=4 | q1=210.620 actor=107.531 alpha=0.058
# [train] episode=4485 step=958236 return=-131.61 success=False time=240.1s geometry=cross_stream history=4 | q1=52.531 actor=107.701 alpha=0.058
# [train] episode=4490 step=958950 return=-201.06 success=False time=59.2s geometry=cross_stream history=4 | q1=23.098 actor=109.350 alpha=0.057
# [train] episode=4495 step=959760 return=-267.95 success=False time=75.1s geometry=cross_stream history=4 | q1=61.484 actor=106.004 alpha=0.056
# [train] episode=4500 step=961518 return=-209.09 success=False time=40.9s geometry=cross_stream history=4 | q1=30.816 actor=104.473 alpha=0.054
# [train] episode=4505 step=962712 return=-218.86 success=False time=240.1s geometry=cross_stream history=4 | q1=31.563 actor=109.035 alpha=0.055
# [train] episode=4510 step=964368 return=-192.39 success=False time=155.2s geometry=cross_stream history=4 | q1=104.101 actor=107.651 alpha=0.054
# [train] episode=4515 step=965238 return=-259.06 success=False time=65.7s geometry=cross_stream history=4 | q1=32.151 actor=110.415 alpha=0.055
# [train] episode=4520 step=967260 return=-203.83 success=False time=178.1s geometry=cross_stream history=4 | q1=14.579 actor=105.346 alpha=0.056
# [train] episode=4525 step=968664 return=-259.33 success=False time=213.9s geometry=cross_stream history=4 | q1=7.309 actor=106.888 alpha=0.057
# [train] episode=4530 step=970152 return=-104.16 success=False time=240.1s geometry=cross_stream history=4 | q1=7.531 actor=108.679 alpha=0.057
# [train] episode=4535 step=971850 return=-192.65 success=False time=36.7s geometry=cross_stream history=4 | q1=17.219 actor=104.696 alpha=0.056
# [train] episode=4540 step=973044 return=-71.07 success=False time=240.1s geometry=cross_stream history=4 | q1=39.797 actor=108.249 alpha=0.056
# [train] episode=4545 step=974514 return=-266.11 success=False time=57.4s geometry=cross_stream history=4 | q1=11.728 actor=106.803 alpha=0.056
# [eval] step=975000 objective=arrival_v2 return=-145.99 safety=23.253 success=13.33% time=140.3s energy=97882.7 path=108.0 prog=0.39
# [train] episode=4550 step=975438 return=-242.87 success=False time=38.4s geometry=cross_stream history=4 | q1=182.987 actor=110.358 alpha=0.055
# [train] episode=4555 step=977562 return=-205.52 success=False time=41.1s geometry=cross_stream history=4 | q1=35.395 actor=105.833 alpha=0.056
# [train] episode=4560 step=978330 return=-77.66 success=False time=240.1s geometry=cross_stream history=4 | q1=27.905 actor=108.225 alpha=0.058
# [train] episode=4565 step=979320 return=-259.60 success=False time=40.1s geometry=cross_stream history=4 | q1=41.178 actor=107.107 alpha=0.058
# [train] episode=4570 step=981516 return=-123.14 success=False time=240.1s geometry=cross_stream history=4 | q1=14.108 actor=109.456 alpha=0.059
# [train] episode=4575 step=982374 return=-251.94 success=False time=110.3s geometry=cross_stream history=4 | q1=33.926 actor=107.608 alpha=0.059
# [train] episode=4580 step=983106 return=-251.60 success=False time=60.5s geometry=cross_stream history=4 | q1=7.697 actor=112.085 alpha=0.058
# [train] episode=4585 step=985872 return=-117.19 success=False time=240.1s geometry=cross_stream history=4 | q1=3.608 actor=107.317 alpha=0.057
# [train] episode=4590 step=988470 return=-220.19 success=False time=215.6s geometry=cross_stream history=4 | q1=282.149 actor=108.495 alpha=0.055
# [train] episode=4595 step=989832 return=-151.91 success=False time=240.1s geometry=cross_stream history=4 | q1=13.256 actor=106.912 alpha=0.053
# [train] episode=4600 step=991566 return=-181.94 success=False time=240.1s geometry=cross_stream history=4 | q1=9.338 actor=108.367 alpha=0.055
# [train] episode=4605 step=992712 return=-236.09 success=False time=90.0s geometry=cross_stream history=4 | q1=5.040 actor=107.794 alpha=0.054
# [train] episode=4610 step=993786 return=118.31 success=True time=88.8s geometry=cross_stream history=4 | q1=41.340 actor=107.987 alpha=0.055
# [train] episode=4615 step=995022 return=-232.27 success=False time=17.3s geometry=cross_stream history=4 | q1=32.000 actor=109.828 alpha=0.055
# [train] episode=4620 step=996558 return=-103.51 success=False time=240.1s geometry=cross_stream history=4 | q1=17.872 actor=108.993 alpha=0.053
# [train] episode=4625 step=998208 return=-86.03 success=False time=240.1s geometry=cross_stream history=4 | q1=249.327 actor=105.796 alpha=0.055

# %% [markdown]
# ## 5. Summary + gate

# %%
def summarize_phase(run_root: Path, total_steps: int, label: str, gate_filename: str):
    eval_log_path = run_root / 'results' / 'eval_log.csv'
    final_eval_path = run_root / 'results' / 'final_eval.json'
    trainer_state_path = run_root / 'trainer_state.json'
    train_config_path = run_root / 'results' / 'train_config.txt'

    if not eval_log_path.exists():
        raise FileNotFoundError(f'missing eval log: {eval_log_path}')
    if not final_eval_path.exists():
        raise FileNotFoundError(f'missing final eval: {final_eval_path}')

    df = pd.read_csv(eval_log_path)
    final_eval = json.loads(final_eval_path.read_text(encoding='utf-8'))
    trainer_state = json.loads(trainer_state_path.read_text(encoding='utf-8')) if trainer_state_path.exists() else {}

    # Parse train_config.txt for seed / history_length / privileged_obs_dim confirmation
    # (trainer_state.json 不 dump use_asymmetric_critic key — 必须从 train_config.txt 读 privileged_obs_dim=2 来确认)
    seed_from_config = 'NA'
    history_from_config = 'NA'
    privileged_dim_from_config = 'NA'
    if train_config_path.exists():
        for ln in train_config_path.read_text(encoding='utf-8').splitlines():
            s = ln.strip()
            if s.startswith('seed='):
                seed_from_config = s.split('=', 1)[1]
            elif s.startswith('history_length='):
                history_from_config = s.split('=', 1)[1]
            elif s.startswith('privileged_obs_dim='):
                privileged_dim_from_config = s.split('=', 1)[1]

    peak_success = float(df['eval_success_rate'].max()) if len(df) else 0.0
    peak_step = int(df.loc[df['eval_success_rate'].idxmax(), 'env_step']) if len(df) else 0
    last100 = df[df['env_step'] >= total_steps - 100_000].copy()
    last100_mean = float(last100['eval_success_rate'].mean()) if len(last100) else 0.0
    mean_all = float(df['eval_success_rate'].mean()) if len(df) else 0.0
    n_evals_with_success = int((df['eval_success_rate'] > 0).sum()) if len(df) else 0
    final_success = float(final_eval['eval_success_rate'])
    counts = final_eval.get('eval_termination_counts', {})
    num_eps = float(final_eval.get('num_eval_episodes', EVAL_EPISODES))
    oob_rate = float(counts.get('out_of_bounds', 0)) / max(num_eps, 1.0)

    print('=' * 100)
    print(f'{label}  (arrival_v2 / s0 / k=4 / sac_asym / seed=0 / {total_steps:,} steps)')
    print('-' * 100)
    print(f"  final_success_rate    : {final_success:.4f}   gate >= {PASS_FINAL_SUCCESS:.2f}")
    print(f"  peak_success_rate     : {peak_success:.4f}   @ {peak_step:,}")
    print(f"  last100k_mean_success : {last100_mean:.4f}   gate >= {PASS_LAST100_RATIO * peak_success:.4f}")
    print(f"  full-traj mean        : {mean_all:.4f}   ({len(df)} evals)")
    print(f"  n_evals_with_success  : {n_evals_with_success} / {len(df)}")
    print(f"  final_oob_rate        : {oob_rate:.4f}   gate <= {PASS_OOB_RATE:.2f}")
    print(f"  obs_dim               : {trainer_state.get('observation_dim', 'NA')}   (expect 48)")
    print(f"  seed                  : {seed_from_config}   (expect 0)")
    print(f"  history_length        : {history_from_config}   (expect 4)")
    print(f"  privileged_obs_dim    : {privileged_dim_from_config}   (expect 2 — confirms asym critic wired)")
    print(f"  context_obs           : {trainer_state.get('include_episode_context_obs', 'NA')}")
    print(f"  timeout_bootstrap     : {trainer_state.get('timeout_bootstrap_semantics', 'NA')}")
    print(f"  termination           : {counts}")
    print('=' * 100)

    if str(privileged_dim_from_config) != '2':
        print('⚠️  privileged_obs_dim ≠ 2 — AsymCritic 没生效！请检查 CLI flag。')

    if len(df):
        print()
        print('[last 16 eval rows]')
        cols = ['env_step', 'eval_success_rate', 'eval_return', 'eval_safety_cost',
                'eval_time_s', 'eval_progress_ratio']
        available = [c for c in cols if c in df.columns]
        print(df[available].tail(16).to_string(index=False))

    checks = [
        ('final success >= 0.85', final_success >= PASS_FINAL_SUCCESS, f'{final_success:.4f}'),
        ('last100k mean >= 0.9 * peak', last100_mean >= PASS_LAST100_RATIO * peak_success,
         f'{last100_mean:.4f} / peak={peak_success:.4f}'),
        ('final OOB rate <= 0.10', oob_rate <= PASS_OOB_RATE, f'{oob_rate:.4f}'),
        ('arrival_v2 context obs enabled',
         trainer_state.get('include_episode_context_obs') is True,
         str(trainer_state.get('include_episode_context_obs'))),
        ('arrival_v2 timeout terminal semantics',
         trainer_state.get('timeout_bootstrap_semantics') == 'terminal',
         str(trainer_state.get('timeout_bootstrap_semantics'))),
        ('asym critic wired (privileged_obs_dim=2)',
         str(privileged_dim_from_config) == '2',
         f'privileged_obs_dim={privileged_dim_from_config}'),
    ]

    print()
    print('=' * 96)
    print(f"{'check':<48}{'pass':>8}{'detail':>40}")
    print('-' * 96)
    all_pass = True
    for name, ok, detail in checks:
        mark = 'PASS' if ok else 'FAIL'
        if not ok:
            all_pass = False
        print(f'{name:<48}{mark:>8}{detail:>40}')
    print('=' * 96)

    summary = {
        'phase': label,
        'objective': OBJECTIVE,
        'probe_layout': PROBE_LAYOUT,
        'history_length': int(history_from_config) if history_from_config != 'NA' else HISTORY_LENGTH,
        'seed': int(seed_from_config) if seed_from_config != 'NA' else SEED,
        'total_steps': total_steps,
        'algorithm': 'sac_asym',
        'privileged_obs_dim': int(privileged_dim_from_config) if str(privileged_dim_from_config).isdigit() else None,
        'final_success_rate': final_success,
        'peak_success_rate': peak_success,
        'peak_step': peak_step,
        'last100k_mean_success': last100_mean,
        'mean_success_full_trajectory': mean_all,
        'n_evals_with_success': n_evals_with_success,
        'n_evals_total': len(df),
        'final_oob_rate': oob_rate,
        'termination_counts': counts,
        'all_pass': bool(all_pass),
        'checks': [{'name': n, 'ok': bool(ok), 'detail': d} for n, ok, d in checks],
    }
    out_path = run_root / 'results' / gate_filename
    out_path.parent.mkdir(parents=True, exist_ok=True)
    out_path.write_text(json.dumps(summary, indent=2), encoding='utf-8')
    print(f'[saved] {out_path}')
    return summary

x_summary = summarize_phase(
    X_RUN_ROOT,
    X_TOTAL_STEPS,
    'SINGLE_CROSS_SAC_ASYM_S0_K4_SEED0',
    'sac_asym_s0_k4_seed0_gate_summary.json',
)
X_PASS = x_summary['all_pass']
print()
print(f'X_PASS = {X_PASS}')
# Out:
# ====================================================================================================
# SINGLE_CROSS_SAC_ASYM_S0_K4_SEED0  (arrival_v2 / s0 / k=4 / sac_asym / seed=0 / 1,000,000 steps)
# ----------------------------------------------------------------------------------------------------
#   final_success_rate    : 0.2000   gate >= 0.85
#   peak_success_rate     : 0.2667   @ 750,000
#   last100k_mean_success : 0.0917   gate >= 0.2400
#   full-traj mean        : 0.0880   (39 evals)
#   n_evals_with_success  : 25 / 39
#   final_oob_rate        : 0.5667   gate <= 0.10
#   obs_dim               : 48   (expect 48)
#   seed                  : 0   (expect 0)
#   history_length        : 4   (expect 4)
#   privileged_obs_dim    : 2   (expect 2 — confirms asym critic wired)
#   context_obs           : True
#   timeout_bootstrap     : terminal
#   termination           : {'goal': 6, 'out_of_bounds': 17, 'timeout': 7}
# ====================================================================================================
#
# [last 16 eval rows]
#  env_step  eval_success_rate  eval_return  eval_safety_cost  eval_time_s  eval_progress_ratio
#    600000           0.033333  -228.575717         21.768966    80.990000             0.185874
#    625002           0.100000  -156.059976         16.781294   114.853333             0.436204
#    650004           0.166667  -136.123722         11.750205    91.653333             0.460447
#    675000           0.033333  -186.738516         12.982698    94.033333             0.327301
#    700002           0.166667  -187.648928         22.794636    68.080000             0.342359
#    725004           0.133333  -173.980742         26.142304   116.576667             0.351816
#    750000           0.266667  -124.788696         19.750466   107.716667             0.504498
#    775002           0.266667   -98.680141         17.450167   120.123333             0.604199
#    800004           0.200000  -138.096087         22.245666   121.896667             0.517245
#    825000           0.000000  -235.543350         23.137731   111.863333             0.119522
#    850002           0.066667  -137.639207         20.900134   149.406667             0.577839
#    875004           0.266667  -121.458612         24.221861   113.370000             0.539484
#    900000           0.000000  -214.052975         28.481226   141.646667             0.251886
#    925002           0.000000  -202.851105         28.527999   154.503333             0.264007
#    950004           0.233333   -94.837336         14.682301   130.130000             0.518805
#    975000           0.133333  -145.993630         23.252654   140.293333             0.391361
#
# ================================================================================================
# check                                               pass                                  detail
# ------------------------------------------------------------------------------------------------
# final success >= 0.85                               FAIL                                  0.2000
# last100k mean >= 0.9 * peak                         FAIL                    0.0917 / peak=0.2667
# final OOB rate <= 0.10                              FAIL                                  0.5667
# arrival_v2 context obs enabled                      PASS                                    True
# arrival_v2 timeout terminal semantics               PASS                                terminal
# asym critic wired (privileged_obs_dim=2)            PASS                    privileged_obs_dim=2
# ================================================================================================
# [saved] experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_asym/s0_k4/seed_0/results/sac_asym_s0_k4_seed0_gate_summary.json
#
# X_PASS = False

# %% [markdown]
# ## 6. Seed-pair verdict — asym seed=0 vs seed=42（验证 §7.7 negative finding 是否 seed-stable）

# %%
def read_baseline(root: Path, ref_final: float, ref_oob: float, ref_mean: float = None):
    fp = root / 'results' / 'final_eval.json'
    log = root / 'results' / 'eval_log.csv'
    out = {'final': ref_final, 'oob': ref_oob, 'mean': ref_mean, 'peak': None, 'source': 'report-fallback'}
    if fp.exists():
        d = json.loads(fp.read_text(encoding='utf-8'))
        f = float(d['eval_success_rate'])
        c = d.get('eval_termination_counts', {})
        n = float(d.get('num_eval_episodes', EVAL_EPISODES))
        out['final'] = f
        out['oob'] = float(c.get('out_of_bounds', 0)) / max(n, 1.0)
        out['source'] = 'on-disk'
    if log.exists():
        dlog = pd.read_csv(log)
        out['mean'] = float(dlog['eval_success_rate'].mean())
        out['peak'] = float(dlog['eval_success_rate'].max())
    return out

print('=' * 100)
print('SAC_ASYM s0_k4 — paired seed verdict (seed=0 vs seed=42)')
print('-' * 100)

# 当前 seed=0 结果
a0_final = float(x_summary['final_success_rate'])
a0_oob = float(x_summary['final_oob_rate'])
a0_peak = float(x_summary['peak_success_rate'])
a0_mean = float(x_summary.get('mean_success_full_trajectory', 0.0))
a0_n_succ = int(x_summary.get('n_evals_with_success', 0))
a0_n_tot = int(x_summary.get('n_evals_total', 0))

# Baselines
b_a42 = read_baseline(X_K4_ASYM_SEED42_ANCHOR, 0.167, 0.633, 0.044)
b_v42 = read_baseline(X_K4_V_SEED42_BASELINE,  0.100, 0.667, 0.221)
b_v0  = read_baseline(X_K4_V_SEED0_SISTER,     -1,    -1,    None)  # 姊妹 notebook
b_s1  = read_baseline(X_S1_BASELINE,           0.900, 0.100, None)

# 计算 2-seed × 2-algo cell mean
asym_2seed_mean = (a0_mean + (b_a42['mean'] or 0.044)) / 2.0
if b_v0['source'] == 'on-disk':
    vanilla_2seed_mean = (b_v0['mean'] + (b_v42['mean'] or 0.221)) / 2.0
else:
    vanilla_2seed_mean = None

print()
print(f'{"config":<48}{"final":>10}{"mean":>10}{"oob":>10}{"source":>14}')
print('-' * 100)
print(f'{"vanilla SAC, s1_k4 seed=42 (§7.1 upper ref)":<48}{b_s1["final"]:>10.4f}{(b_s1["mean"] or float("nan")):>10.4f}{b_s1["oob"]:>10.4f}{b_s1["source"]:>14}')
print(f'{"vanilla SAC, s0_k4 seed=42 (§7.6.4)":<48}{b_v42["final"]:>10.4f}{(b_v42["mean"] or float("nan")):>10.4f}{b_v42["oob"]:>10.4f}{b_v42["source"]:>14}')
if b_v0['source'] == 'on-disk':
    print(f'{"vanilla SAC, s0_k4 SEED=0 (sister run)":<48}{b_v0["final"]:>10.4f}{(b_v0["mean"] or float("nan")):>10.4f}{b_v0["oob"]:>10.4f}{b_v0["source"]:>14}')
else:
    print(f'{"vanilla SAC, s0_k4 SEED=0 (sister run)":<48}{"PENDING":>10}{"PENDING":>10}{"PENDING":>10}{"not-yet":>14}')
print(f'{"sac_asym,   s0_k4 seed=42 (§7.7 anchor)":<48}{b_a42["final"]:>10.4f}{(b_a42["mean"] or float("nan")):>10.4f}{b_a42["oob"]:>10.4f}{b_a42["source"]:>14}')
print(f'{"sac_asym,   s0_k4 SEED=0 (this run)":<48}{a0_final:>10.4f}{a0_mean:>10.4f}{a0_oob:>10.4f}{"on-disk":>14}')
print('=' * 100)

# Δ 行
print()
print(f'{"contrast":<60}{"Δ final":>12}{"Δ mean":>12}{"Δ oob":>12}')
print('-' * 100)
d_final = a0_final - b_a42['final']
d_mean = a0_mean - (b_a42['mean'] or 0)
d_oob = a0_oob - b_a42['oob']
print(f'{"asym seed=0 vs seed=42 — paired test":<60}{d_final:>+12.4f}{d_mean:>+12.4f}{d_oob:>+12.4f}')
print(f'{"asym seed=0 vs vanilla seed=42 — cross-arm":<60}'
      f'{a0_final - b_v42["final"]:>+12.4f}'
      f'{a0_mean - (b_v42["mean"] or 0):>+12.4f}'
      f'{a0_oob - b_v42["oob"]:>+12.4f}')
if b_v0['source'] == 'on-disk':
    print(f'{"asym seed=0 vs vanilla seed=0 — same-seed cross-arm":<60}'
          f'{a0_final - b_v0["final"]:>+12.4f}'
          f'{a0_mean - (b_v0["mean"] or 0):>+12.4f}'
          f'{a0_oob - b_v0["oob"]:>+12.4f}')
    print(f'{"2-seed asym mean vs 2-seed vanilla mean":<60}'
          f'{"N/A":>12}'
          f'{asym_2seed_mean - vanilla_2seed_mean:>+12.4f}'
          f'{"N/A":>12}')
print('=' * 100)
print()
print(f'seed=0 evals_with_success: {a0_n_succ} / {a0_n_tot}  (seed=42 asym was 19/39, vanilla was 35/39)')
print(f'2-seed asym mean : {asym_2seed_mean:.4f}')
if vanilla_2seed_mean is not None:
    print(f'2-seed vanilla mean: {vanilla_2seed_mean:.4f}')
    print(f'asym - vanilla (2-seed mean delta): {asym_2seed_mean - vanilla_2seed_mean:+.4f}')

# 判读 — 4 档 paired-seed verdict for §7.7
vanilla_ref_mean = vanilla_2seed_mean if vanilla_2seed_mean is not None else (b_v42['mean'] or 0.221)

if a0_mean <= 0.15 and a0_mean < vanilla_ref_mean - 0.05:
    verdict = ('HARDEN-NEGATIVE — seed=0 asym mean={:.3f} 仍显著低于 vanilla 参照 ({:.3f})；'
               '配合 §7.7 的 seed=42 mean=0.044，2 seed × 2 algo 都证实 asym worse than vanilla；'
               '§7.7 升格为 2-seed hardened negative claim ✓；§8 P1 路线维持 actor-side info upgrade (k=8 / temporal)'
               .format(a0_mean, vanilla_ref_mean))
elif a0_mean >= 0.30 and a0_mean > vanilla_ref_mean + 0.05:
    verdict = ('REVERSE — seed=0 asym mean={:.3f} 明显高于 vanilla 参照 ({:.3f})；'
               '§7.7 claim 反转：seed=42 是 asym 的 unlucky outlier，asym 可能确实有助益；'
               '§7.7 整段重写，§8 P1 需重新考虑 asym 作为候选'.format(a0_mean, vanilla_ref_mean))
elif abs(a0_mean - vanilla_ref_mean) <= 0.10:
    verdict = ('COLLAPSE-NEGATIVE — seed=0 asym mean={:.3f} 与 vanilla 参照 ({:.3f}) 同量级；'
               '§7.7 的「asym hurts」claim collapse 为「asym does not improve」；'
               'seed=42 mean 0.044 是 unlucky outlier；§8 P1 重写 asym 段为 no-effect；下一步仍可走 k=8 但需补 3rd seed'
               .format(a0_mean, vanilla_ref_mean))
else:
    verdict = ('AMBIGUOUS — seed=0 asym mean={:.3f}，处于 §7.7 anchor (0.044) 与 vanilla ref ({:.3f}) 之间；'
               '部分确认 §7.7 trend；需要 3rd seed (=7 或 =1) 才能定论'
               .format(a0_mean, vanilla_ref_mean))

print()
print(f'>>> verdict: {verdict}')

# 落盘
ablation_out = {
    'experiment': 'arrival_v2_s0_cross_sac_asym_seed0_replication',
    'seed': SEED,
    'benchmark': X_BENCHMARK_KEY,
    'probe_layout': PROBE_LAYOUT,
    'history_length': HISTORY_LENGTH,
    'total_steps': X_TOTAL_STEPS,
    'algorithm': 'sac_asym',
    'cli_diff_vs_§7.7_baseline': '--seed 42 → --seed 0',
    'results': {
        'sac_asym_s0_k4_seed0_thisrun': {
            'final': a0_final, 'mean': a0_mean, 'oob': a0_oob, 'peak': a0_peak,
            'n_evals_with_success': a0_n_succ, 'n_evals_total': a0_n_tot,
        },
        'sac_asym_s0_k4_seed42_anchor_§7.7': b_a42,
        'vanilla_s0_k4_seed42_§7.6.4': b_v42,
        'vanilla_s0_k4_seed0_sister': b_v0,
        'vanilla_s1_k4_seed42_§7.1_upper': b_s1,
    },
    'delta_vs_§7.7_seed42_paired': {
        'final_pp': round(d_final * 100, 2),
        'mean_pp': round(d_mean * 100, 2),
        'oob_pp': round(d_oob * 100, 2),
    },
    'two_seed_summary': {
        'asym_2seed_mean': asym_2seed_mean,
        'vanilla_2seed_mean': vanilla_2seed_mean,
        'asym_minus_vanilla_2seed_mean': (
            asym_2seed_mean - vanilla_2seed_mean if vanilla_2seed_mean is not None else None
        ),
    },
    'all_pass': bool(x_summary['all_pass']),
    'verdict': verdict,
}
out_dir = Path('experiments/arrival_v2_prototype/s0_cross_sac_asym_seed0_summary')
out_dir.mkdir(parents=True, exist_ok=True)
out_path = out_dir / 'combined_gate_summary.json'
out_path.write_text(json.dumps(ablation_out, indent=2), encoding='utf-8')
print(f'\n[saved] {out_path}')
# Out:
# ====================================================================================================
# SAC_ASYM s0_k4 — paired seed verdict (seed=0 vs seed=42)
# ----------------------------------------------------------------------------------------------------
#
# config                                               final      mean       oob        source
# ----------------------------------------------------------------------------------------------------
# vanilla SAC, s1_k4 seed=42 (§7.1 upper ref)         0.9000    0.4966    0.1000       on-disk
# vanilla SAC, s0_k4 seed=42 (§7.6.4)                 0.1000    0.2205    0.6667       on-disk
# vanilla SAC, s0_k4 SEED=0 (sister run)             PENDING   PENDING   PENDING       not-yet
# sac_asym,   s0_k4 seed=42 (§7.7 anchor)             0.1667    0.0436    0.6333       on-disk
# sac_asym,   s0_k4 SEED=0 (this run)                 0.2000    0.0880    0.5667       on-disk
# ====================================================================================================
#
# contrast                                                         Δ final      Δ mean       Δ oob
# ----------------------------------------------------------------------------------------------------
# asym seed=0 vs seed=42 — paired test                             +0.0333     +0.0444     -0.0667
# asym seed=0 vs vanilla seed=42 — cross-arm                       +0.1000     -0.1325     -0.1000
# ====================================================================================================
#
# seed=0 evals_with_success: 25 / 39  (seed=42 asym was 19/39, vanilla was 35/39)
# 2-seed asym mean : 0.0658
#
# >>> verdict: HARDEN-NEGATIVE — seed=0 asym mean=0.088 仍显著低于 vanilla 参照 (0.221)；配合 §7.7 的 seed=42 mean=0.044，2 seed × 2 algo 都证实 asym worse than vanilla；§7.7 升格为 2-seed hardened negative claim ✓；§8 P1 路线维持 actor-side info upgrade (k=8 / temporal)
#
# [saved] experiments/arrival_v2_prototype/s0_cross_sac_asym_seed0_summary/combined_gate_summary.json
