# %% [markdown]
# # SAC arrival_v2 — history k=8 multi-seed (seed=7, TIE-BREAKER) on single_cross_s0 (1M, vanilla)
#
# **Pre-context（commit `e00f9af` + seed=0 results 回流 2026-05-19）**：[`docs/arrival_v2_experiment_report.md`](../docs/arrival_v2_experiment_report.md) §7.8 「k=4→8 闭合 80pp gap」claim 目前是 **1 PASS + 1 PARTIAL** 的混合状态：
#
# | §7.8 multi-seed state (2/3 anchors)      | seed | final  | peak@step    | mean39 | OOB   | Gate |
# |---                                       |---:  |---:    |---           |---:    |---:   |---   |
# | **s0 k=8 vanilla (§7.8 anchor)**         | 42   | **0.900** | 0.900 @ 475k | **0.636** | **0.100** | **PASS（5/5）** |
# | **s0 k=8 vanilla (§7.8' 本套 seed=0)**   | 0    | 0.500  | 0.500 @ 925k | 0.260  | 0.133 | **FAIL（2/5）** |
# | s0 k=4 vanilla (§7.6.4 floor)            | 42   | 0.100  | 0.367 @ 975k | 0.221  | 0.667 | FAIL |
# | s0 k=4 vanilla (§7.7.1 sister)           | 0    | 0.400  | 0.533 @ 625k | 0.218  | 0.200 | FAIL |
# | s1 k=4 vanilla (§7.1 upper ref)          | 42   | 0.900  | 0.900 @ 725k | 0.497  | 0.100 | PASS |
#
# **关键 tension**：seed=42 上 k=4→8 buy 到 +80pp final + −56pp OOB；但 seed=0 上同样的切换只 buy 到 +10pp final + −7pp OOB，且最终高原在 50%。两 seed 跨 history 增益差异 **8 倍**。
#
# **单 seed 解释不了的两种竞争 hypothesis**：
#
# | Hypothesis | 含义 |
# |---|---|
# | **H1: "k=8 真的解决 information bottleneck，只是 seed=0 不幸卡 local minimum"** | seed=7 应 PASS（与 seed=42 类似），2/3 PASS 支持 H1 |
# | **H2: "§7.8 anchor 本质是 seed=42 lucky strike，k=4→8 真实增益接近 seed=0 的 +10pp"** | seed=7 应 PARTIAL/REGRESS（与 seed=0 类似），2/3 FAIL 支持 H2 |
#
# **本 notebook 任务（pure vanilla + history k=8，seed=7 第三 anchor，tie-breaker）**：
#
# | 维度                  | §7.8 anchor (seed=42) | §7.8' (seed=0) | 本 notebook (seed=7) |
# |---                    |---                    |---             |---                  |
# | `--seed`              | 42                    | 0              | **7** ← 唯一变量    |
# | `--history-length`    | 8                     | 8              | 8                   |
# | algorithm             | vanilla SAC           | vanilla SAC    | vanilla SAC         |
# | sensor layout         | s0 (DVL-only)         | s0 (DVL-only)  | s0 (DVL-only)       |
# | reward                | arrival_v2            | arrival_v2     | arrival_v2          |
# | flow U / target       | 1.5 / 1.5             | 1.5 / 1.5      | 1.5 / 1.5           |
# | total_steps           | 1M                    | 1M             | 1M                  |
# | num_envs              | 6                     | 6              | 6                   |
# | benchmark             | `single_u15_cross_tgt15` | 同           | 同                   |
# | obs_dim               | 96 (12×8)             | 96             | 96                  |
#
# **Seed 选择 = 7 的理由**：与 §7 章节其它 multi-seed 套保持 prime-seed 习惯（42 / 0 / 7 是常用三元组）；避免与 §7.6 / §7.7 已用 seed 重合。
#
# **Gate**（与 §7 / §7.6 / §7.7 / §7.8 同口径）：
# - `final_success_rate ≥ 0.85`
# - `last100k_mean ≥ 0.9 × peak`
# - `final_oob_rate ≤ 0.10`
# - `include_episode_context_obs == True`
# - `timeout_bootstrap_semantics == 'terminal'`
#
# **TIE-BREAK verdict 规则**（驱动 §7.8 主张存亡 + 决定后续 §8 P1 走向）：
#
# | Verdict | 触发条件 | 解释 + §7.8 主张状态 |
# |---|---|---|
# | **TIE-BREAK-ROBUST** | seed=7 PASS（5/5）| 2/3 PASS → 支持 H1。§7.8 写「k=4→8 在 2/3 seeds 上 close gap；seed=0 fails to converge from this init」+ 加 seed=0 audit 段；可以推进 §8 P1#2 k=12 cross-seed |
# | **TIE-BREAK-HIGH-VAR** | seed=7 PASS 但 \|Δfinal\| vs anchor > 0.15 | 2/3 PASS 但 noisy；§7.8 写「k=8 PASS robust but seed-noisy; recommend ≥3 seeds for thesis claim」 |
# | **TIE-BREAK-WEAK** | seed=7 STRONG-PARTIAL（final ∈ [0.5, 0.85)）| 1 PASS + 2 PARTIAL → effect 部分存在；§7.8 reframe「k=8 partial mitigation, seed-sensitive 50-90% final range」；放弃 §8 P1#2 k=12 / k=16 单 seed 路径 |
# | **TIE-BREAK-DEAD** | seed=7 final < 0.5 | 1/3 PASS → 强证据 H2（§7.8 anchor = seed=42 偶然命中）；§7.8 主张回退「k=4→8 effect highly seed-dependent, not a method-level gap closer」；可能转向 §8 P0 SAC variance reduction（DroQ / SimBa / N-Step）路线 |
#
# **输出根（与 §7.8 anchor / §7.8' 互不覆盖）**：
# - `experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s0_k8/seed_7/`
#
# **总预算**：~2.5h L4（1 Colab Pro+ session）。
#
# **风格**：训练用 `!python -u -m scripts.train_sac` 直跑（实时 stdout），与 §7.8 / §7.8' 一致。

# %% [markdown]
# ## 0. GPU sanity

# %%
# !nvidia-smi | head -10
# Out:
# Mon May 18 17:18:13 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA L4                      Off |   00000000:00:03.0 Off |                    0 |
# | N/A   38C    P8             12W /   72W |       0MiB /  23034MiB |      0%      Default |

# %% [markdown]
# ## 1. Mount Drive + cwd

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

REPO_DIR = '/content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5'
# %cd $REPO_DIR
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Colab Notebooks/new_offRL/rl_v2_5

# %% [markdown]
# ## 2. Config — single phase（vanilla SAC + history k=8 + seed=7，与 §7.8 anchor 仅差一个 flag value）

# %%
import json
import os
from pathlib import Path

import pandas as pd

# ==== SAC / env config (与 §7.8 anchor 严格一致，除 seed 外) ====
OBJECTIVE = 'arrival_v2'
PROBE_LAYOUT = 's0'
HISTORY_LENGTH = 8
TARGET_SPEED = 1.5
SEED = 7                                # ← 唯一与 §7.8 anchor (seed=42) 不同的值；TIE-BREAK 3rd anchor

RANDOM_STEPS = 5_000
UPDATE_AFTER = 5_000
BATCH_SIZE = 256
HIDDEN_DIM = 256
NUM_ENVS = 6
EVAL_EVERY = 25_000
EVAL_EPISODES = 30
CHECKPOINT_EVERY = 100_000
DEVICE = 'cuda'

# 显式拒绝所有 SAC 改进项 — 与 §7.8 anchor 一致
USE_ASYMMETRIC_CRITIC = False
USE_LAYERNORM = False
UPDATES_PER_STEP = 1
DROPOUT_RATE = 0.0

PASS_FINAL_SUCCESS = 0.85
PASS_LAST100_RATIO = 0.90
PASS_OOB_RATE = 0.10

# Flow file（与 §7.1 / §7.6.4 / §7.7 / §7.8 / §7.8' 严格一致）
SINGLE_FLOW = 'wake_data/wake_v8_U1p50_Re250_D12p00_dx0p60_Ti5pct_1200f_roi.npy'

# ==== Single phase — single_cross s0 k=8 seed=7 (X_*) ====
X_BENCHMARK_KEY = 'single_u15_cross_tgt15'
X_TASK_GEOMETRY = 'cross_stream'
X_FLOW_PATH = SINGLE_FLOW
X_TOTAL_STEPS = 1_000_000
X_RUN_ROOT = Path('experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s0_k8/seed_7')
X_CKPT_ROOT = Path('checkpoints/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s0_k8/seed_7')
X_MANIFEST_PATH = Path(f'benchmarks/{X_BENCHMARK_KEY}.json')

# Baselines（事后对比）
X_K8_S42_ROOT  = Path('experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s0_k8/seed_42')   # §7.8 anchor PASS
X_K8_S0_ROOT   = Path('experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s0_k8/seed_0')    # §7.8' PARTIAL (本套上一轮)
X_K4_S42_ROOT  = Path('experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s0_k4/seed_42')   # §7.6.4 floor
X_K4_S0_ROOT   = Path('experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s0_k4/seed_0')    # §7.7.1 sister
X_S1_UPPER_ROOT = Path('experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s1_k4/seed_42')  # §7.1 upper

os.environ['PYTHONUNBUFFERED'] = '1'

print(f'PROBE_LAYOUT          = {PROBE_LAYOUT}')
print(f'OBJECTIVE             = {OBJECTIVE}')
print(f'HISTORY_LENGTH        = {HISTORY_LENGTH}')
print(f'SEED                  = {SEED}        ← TIE-BREAK 3rd anchor，与 §7.8 anchor (seed=42) / §7.8\' (seed=0) 不同')
print(f'NUM_ENVS              = {NUM_ENVS}')
print(f'USE_ASYMMETRIC_CRITIC = {USE_ASYMMETRIC_CRITIC}')
print(f'USE_LAYERNORM         = {USE_LAYERNORM}')
print(f'UPDATES_PER_STEP      = {UPDATES_PER_STEP}')
print(f'DROPOUT_RATE          = {DROPOUT_RATE}')
print()
print(f'benchmark             : {X_BENCHMARK_KEY}')
print(f'geometry              : {X_TASK_GEOMETRY}')
print(f'total_steps           : {X_TOTAL_STEPS:,}')
print(f'expected obs_dim      : 12 * {HISTORY_LENGTH} = {12 * HISTORY_LENGTH} (per train_config.txt across all baselines)')
print(f'run_root              : {X_RUN_ROOT}')
print(f'§7.8  k=8 seed=42 PASS    : {X_K8_S42_ROOT}')
print(f"§7.8' k=8 seed=0  PARTIAL : {X_K8_S0_ROOT}")
print(f'§7.6.4 k=4 seed=42 floor  : {X_K4_S42_ROOT}')
print(f'§7.7.1 k=4 seed=0  sister : {X_K4_S0_ROOT}')
print(f'§7.1  s1 k=4 upper ref    : {X_S1_UPPER_ROOT}')
# Out:
# PROBE_LAYOUT          = s0
# OBJECTIVE             = arrival_v2
# HISTORY_LENGTH        = 8
# SEED                  = 7        ← TIE-BREAK 3rd anchor，与 §7.8 anchor (seed=42) / §7.8' (seed=0) 不同
# NUM_ENVS              = 6
# USE_ASYMMETRIC_CRITIC = False
# USE_LAYERNORM         = False
# UPDATES_PER_STEP      = 1
# DROPOUT_RATE          = 0.0
#
# benchmark             : single_u15_cross_tgt15
# geometry              : cross_stream
# total_steps           : 1,000,000
# expected obs_dim      : 12 * 8 = 96 (per train_config.txt across all baselines)
# run_root              : experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s0_k8/seed_7
# §7.8  k=8 seed=42 PASS    : experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s0_k8/seed_42
# §7.8' k=8 seed=0  PARTIAL : experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s0_k8/seed_0
# §7.6.4 k=4 seed=42 floor  : experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s0_k4/seed_42
# §7.7.1 k=4 seed=0  sister : experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s0_k4/seed_0
# §7.1  s1 k=4 upper ref    : experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s1_k4/seed_42

# %% [markdown]
# ## 3. Preflight — flow / arrival_v2 candidate gate / reward unit tests / manifest / baseline 就位

# %%
# Flow file
fp = Path(X_FLOW_PATH)
if not fp.exists():
    raise FileNotFoundError(f'missing flow file: {fp}')
print(f'[OK] flow file: {fp}  ({fp.stat().st_size / 1e6:.1f} MB)')
# Out:
# [OK] flow file: wake_data/wake_v8_U1p50_Re250_D12p00_dx0p60_Ti5pct_1200f_roi.npy  (230.4 MB)

# %%
# !python -u -m scripts.validate_arrival_v2_candidate
# Out:
# [undiscounted]
# fast_success       144.473
# slow_success       142.023
# unsafe_success      91.048
# timeout_near      -149.800
# timeout_far       -229.800
# late_oob          -274.500
# fast_oob          -280.325
# mid_oob           -319.450
#
# [discounted_gamma_0.995]
# fast_success        88.578
# slow_success        54.683
# unsafe_success      34.857
# timeout_near       -39.480
# timeout_far        -58.269
# late_oob          -103.800
# mid_oob           -190.006
# fast_oob          -212.555
#
# [discounted_shortcut] safe=69.330 risky=62.361
#
# PASS: arrival_v2 candidate pre-integration gates passed.

# %%
# !python -u -m pytest tests/test_reward_objective.py -q
# Out:
# ...............                                                          [100%]
# 15 passed in 23.04s

# %%
if not X_MANIFEST_PATH.exists():
    # !python -u -m scripts.generate_standard_benchmarks --benchmarks {X_BENCHMARK_KEY} --episodes {EVAL_EPISODES}
if not X_MANIFEST_PATH.exists():
    raise FileNotFoundError(f'manifest not generated: {X_MANIFEST_PATH}')
print(f'[OK] manifest ready: {X_MANIFEST_PATH}')
# Out:
# [OK] manifest ready: benchmarks/single_u15_cross_tgt15.json

# %%
# 检查 5 个对比 baseline 是否就位
for label, root, ref_final, ref_oob in [
    ('§7.8  k8 seed=42 PASS    ', X_K8_S42_ROOT, 0.900, 0.100),
    ("§7.8' k8 seed=0  PARTIAL ", X_K8_S0_ROOT,  0.500, 0.133),
    ('§7.6.4 k4 seed=42 floor   ', X_K4_S42_ROOT, 0.100, 0.667),
    ('§7.7.1 k4 seed=0  sister  ', X_K4_S0_ROOT,  0.400, 0.200),
    ('§7.1  s1 k=4 upper ref    ', X_S1_UPPER_ROOT, 0.900, 0.100),
]:
    fp = root / 'results' / 'final_eval.json'
    if fp.exists():
        d = json.loads(fp.read_text(encoding='utf-8'))
        f = float(d['eval_success_rate'])
        c = d.get('eval_termination_counts', {})
        n = float(d.get('num_eval_episodes', EVAL_EPISODES))
        oob = float(c.get('out_of_bounds', 0)) / max(n, 1.0)
        match = '✓' if abs(f - ref_final) < 0.05 and abs(oob - ref_oob) < 0.05 else '✗ mismatch'
        print(f'[OK] {label}: final={f:.4f}  oob={oob:.4f}  counts={c}  {match}')
    else:
        print(f'[WARN] {label}: {fp} 不存在 (后续 §5 diff 会回退到 report 转载值)')
# Out:
# [OK] §7.8  k8 seed=42 PASS    : final=0.9000  oob=0.1000  counts={'goal': 27, 'out_of_bounds': 3}  ✓
# [OK] §7.8' k8 seed=0  PARTIAL : final=0.5000  oob=0.1333  counts={'timeout': 11, 'goal': 15, 'out_of_bounds': 4}  ✓
# [OK] §7.6.4 k4 seed=42 floor   : final=0.1000  oob=0.6667  counts={'out_of_bounds': 20, 'timeout': 7, 'goal': 3}  ✓
# [OK] §7.7.1 k4 seed=0  sister  : final=0.4000  oob=0.2000  counts={'timeout': 12, 'out_of_bounds': 6, 'goal': 12}  ✓
# [OK] §7.1  s1 k=4 upper ref    : final=0.9000  oob=0.1000  counts={'goal': 27, 'out_of_bounds': 3}  ✓

# %% [markdown]
# ## 4. Train — single_cross_s0 + history k=8 + seed=7 (1.0M, skip/resume)

# %%
x_state_path = X_RUN_ROOT / 'trainer_state.json'
if x_state_path.exists():
    x_state = json.loads(x_state_path.read_text(encoding='utf-8'))
    x_current_step = int(x_state.get('env_step', 0))
else:
    x_current_step = 0
print(f'[state] X env_step = {x_current_step:,} / target {X_TOTAL_STEPS:,}')

if x_current_step >= X_TOTAL_STEPS:
    print(f'[skip] X already trained to {x_current_step:,} >= {X_TOTAL_STEPS:,}')
elif x_current_step > 0:
    print(f'[resume] X continuing from {x_current_step:,} -> {X_TOTAL_STEPS:,}')
    # !python -u -m scripts.train_sac \
        --resume {str(X_RUN_ROOT)} \
        --total-steps {X_TOTAL_STEPS} \
        --eval-every {EVAL_EVERY} \
        --eval-episodes {EVAL_EPISODES} \
        --checkpoint-every {CHECKPOINT_EVERY} \
        --eval-manifest {str(X_MANIFEST_PATH)} \
        --device {DEVICE}
else:
    print(f'[train] X fresh start -> {X_TOTAL_STEPS:,}')
    # !python -u -m scripts.train_sac \
        --flow {X_FLOW_PATH} \
        --task-geometry {X_TASK_GEOMETRY} \
        --target-speed {TARGET_SPEED} \
        --objective {OBJECTIVE} \
        --probe-layout {PROBE_LAYOUT} \
        --history-length {HISTORY_LENGTH} \
        --total-steps {X_TOTAL_STEPS} \
        --random-steps {RANDOM_STEPS} \
        --update-after {UPDATE_AFTER} \
        --batch-size {BATCH_SIZE} \
        --hidden-dim {HIDDEN_DIM} \
        --num-envs {NUM_ENVS} \
        --eval-every {EVAL_EVERY} \
        --eval-episodes {EVAL_EPISODES} \
        --checkpoint-every {CHECKPOINT_EVERY} \
        --eval-manifest {str(X_MANIFEST_PATH)} \
        --seed {SEED} \
        --device {DEVICE} \
        --save-dir {str(X_RUN_ROOT)} \
        --checkpoint-dir {str(X_CKPT_ROOT)}
# Out:
# [state] X env_step = 0 / target 1,000,000
# [train] X fresh start -> 1,000,000
# [train] episode=5 step=1134 return=-392.07 success=False time=94.2s geometry=cross_stream history=8
# [train] episode=10 step=1854 return=-386.00 success=False time=80.0s geometry=cross_stream history=8
# [train] episode=15 step=2736 return=-408.78 success=False time=83.1s geometry=cross_stream history=8
# [train] episode=20 step=3060 return=-416.75 success=False time=99.8s geometry=cross_stream history=8
# [train] episode=25 step=3936 return=-429.27 success=False time=72.1s geometry=cross_stream history=8
# [train] episode=30 step=4590 return=-453.34 success=False time=109.3s geometry=cross_stream history=8
# [train] episode=35 step=5130 return=-265.36 success=False time=26.0s geometry=cross_stream history=8 | q1=0.344 actor=0.693 alpha=0.199
# [train] episode=40 step=5478 return=-317.16 success=False time=22.6s geometry=cross_stream history=8 | q1=2.063 actor=2.124 alpha=0.195
# [train] episode=45 step=6498 return=-381.34 success=False time=89.4s geometry=cross_stream history=8 | q1=268.259 actor=2.981 alpha=0.186
# [train] episode=50 step=6930 return=-353.25 success=False time=28.8s geometry=cross_stream history=8 | q1=481.868 actor=4.180 alpha=0.183
# [train] episode=55 step=7500 return=-357.64 success=False time=46.3s geometry=cross_stream history=8 | q1=268.660 actor=5.238 alpha=0.178
# [train] episode=60 step=8346 return=-394.49 success=False time=85.8s geometry=cross_stream history=8 | q1=475.961 actor=6.910 alpha=0.171
# [train] episode=65 step=9192 return=-344.84 success=False time=38.5s geometry=cross_stream history=8 | q1=237.551 actor=7.074 alpha=0.165
# [train] episode=70 step=9666 return=-459.35 success=False time=51.0s geometry=cross_stream history=8 | q1=531.123 actor=9.175 alpha=0.161
# [train] episode=75 step=10410 return=-423.09 success=False time=94.1s geometry=cross_stream history=8 | q1=757.860 actor=8.866 alpha=0.156
# [train] episode=80 step=10944 return=-396.31 success=False time=72.0s geometry=cross_stream history=8 | q1=3.316 actor=10.479 alpha=0.152
# [train] episode=85 step=11502 return=-362.75 success=False time=77.4s geometry=cross_stream history=8 | q1=5.736 actor=12.438 alpha=0.148
# [train] episode=90 step=12192 return=-449.40 success=False time=99.0s geometry=cross_stream history=8 | q1=1052.950 actor=12.881 alpha=0.143
# [train] episode=95 step=12804 return=-391.22 success=False time=78.2s geometry=cross_stream history=8 | q1=211.779 actor=14.155 alpha=0.139
# [train] episode=100 step=13512 return=-406.88 success=False time=103.4s geometry=cross_stream history=8 | q1=263.266 actor=14.601 alpha=0.135
# [train] episode=105 step=13992 return=-373.83 success=False time=79.7s geometry=cross_stream history=8 | q1=232.329 actor=14.619 alpha=0.132
# [train] episode=110 step=14526 return=-403.97 success=False time=58.4s geometry=cross_stream history=8 | q1=8.179 actor=17.734 alpha=0.129
# [train] episode=115 step=14904 return=-454.54 success=False time=51.6s geometry=cross_stream history=8 | q1=616.052 actor=18.380 alpha=0.127
# [train] episode=120 step=15684 return=-380.46 success=False time=34.0s geometry=cross_stream history=8 | q1=803.139 actor=18.858 alpha=0.122
# [train] episode=125 step=16242 return=-533.88 success=False time=88.9s geometry=cross_stream history=8 | q1=8.910 actor=19.765 alpha=0.120
# [train] episode=130 step=16980 return=-257.23 success=False time=46.9s geometry=cross_stream history=8 | q1=25.599 actor=20.682 alpha=0.116
# [train] episode=135 step=17532 return=-380.17 success=False time=35.9s geometry=cross_stream history=8 | q1=251.863 actor=23.878 alpha=0.113
# [train] episode=140 step=18240 return=-358.97 success=False time=58.1s geometry=cross_stream history=8 | q1=369.560 actor=24.377 alpha=0.109
# [train] episode=145 step=18852 return=-413.17 success=False time=71.4s geometry=cross_stream history=8 | q1=195.726 actor=23.581 alpha=0.106
# [train] episode=150 step=19602 return=-417.44 success=False time=102.4s geometry=cross_stream history=8 | q1=12.099 actor=26.491 alpha=0.103
# [train] episode=155 step=20448 return=-422.86 success=False time=118.8s geometry=cross_stream history=8 | q1=18.291 actor=27.768 alpha=0.099
# [train] episode=160 step=21144 return=-386.05 success=False time=109.7s geometry=cross_stream history=8 | q1=227.200 actor=27.253 alpha=0.097
# [train] episode=165 step=21534 return=-340.32 success=False time=31.9s geometry=cross_stream history=8 | q1=437.095 actor=30.597 alpha=0.095
# [train] episode=170 step=22014 return=-358.96 success=False time=48.7s geometry=cross_stream history=8 | q1=368.527 actor=29.231 alpha=0.093
# [train] episode=175 step=22398 return=-267.66 success=False time=9.0s geometry=cross_stream history=8 | q1=802.197 actor=31.415 alpha=0.091
# [train] episode=180 step=22980 return=-270.41 success=False time=22.8s geometry=cross_stream history=8 | q1=340.900 actor=31.713 alpha=0.089
# [train] episode=185 step=23454 return=-324.12 success=False time=23.4s geometry=cross_stream history=8 | q1=41.358 actor=31.669 alpha=0.087
# [train] episode=190 step=24294 return=-305.80 success=False time=20.6s geometry=cross_stream history=8 | q1=532.299 actor=35.474 alpha=0.084
# [train] episode=195 step=24846 return=-446.33 success=False time=94.3s geometry=cross_stream history=8 | q1=848.506 actor=36.963 alpha=0.083
# [eval] step=25002 objective=arrival_v2 return=-376.92 safety=25.507 success=0.00% time=58.4s energy=9675.8 path=89.5 prog=-1.27
# [train] episode=200 step=25800 return=-372.53 success=False time=30.8s geometry=cross_stream history=8 | q1=37.154 actor=35.796 alpha=0.079
# [train] episode=205 step=26232 return=-429.12 success=False time=109.8s geometry=cross_stream history=8 | q1=821.740 actor=37.787 alpha=0.078
# [train] episode=210 step=26712 return=-428.74 success=False time=74.1s geometry=cross_stream history=8 | q1=571.139 actor=40.330 alpha=0.076
# [train] episode=215 step=27570 return=-268.95 success=False time=35.0s geometry=cross_stream history=8 | q1=299.561 actor=41.329 alpha=0.073
# [train] episode=220 step=28092 return=-370.26 success=False time=30.2s geometry=cross_stream history=8 | q1=901.212 actor=40.428 alpha=0.072
# [train] episode=225 step=28854 return=-380.89 success=False time=83.1s geometry=cross_stream history=8 | q1=697.257 actor=41.685 alpha=0.070
# [train] episode=230 step=29400 return=-473.22 success=False time=46.3s geometry=cross_stream history=8 | q1=204.671 actor=45.384 alpha=0.068
# [train] episode=235 step=30072 return=-307.99 success=False time=55.4s geometry=cross_stream history=8 | q1=50.028 actor=41.122 alpha=0.067
# [train] episode=240 step=30522 return=-269.14 success=False time=8.2s geometry=cross_stream history=8 | q1=593.553 actor=47.375 alpha=0.066
# [train] episode=245 step=31674 return=-446.68 success=False time=84.5s geometry=cross_stream history=8 | q1=428.698 actor=48.495 alpha=0.063
# [train] episode=250 step=32352 return=-339.24 success=False time=56.0s geometry=cross_stream history=8 | q1=224.088 actor=48.293 alpha=0.061
# [train] episode=255 step=32592 return=-254.60 success=False time=25.1s geometry=cross_stream history=8 | q1=465.942 actor=50.730 alpha=0.061
# [train] episode=260 step=33108 return=-284.71 success=False time=19.2s geometry=cross_stream history=8 | q1=465.872 actor=49.957 alpha=0.060
# [train] episode=265 step=33666 return=-350.35 success=False time=56.8s geometry=cross_stream history=8 | q1=365.324 actor=50.240 alpha=0.059
# [train] episode=270 step=34710 return=-314.73 success=False time=41.6s geometry=cross_stream history=8 | q1=186.149 actor=55.875 alpha=0.056
# [train] episode=275 step=35112 return=-532.43 success=False time=119.7s geometry=cross_stream history=8 | q1=252.646 actor=49.797 alpha=0.055
# [train] episode=280 step=35946 return=-398.59 success=False time=80.1s geometry=cross_stream history=8 | q1=291.325 actor=53.735 alpha=0.053
# [train] episode=285 step=36696 return=-428.35 success=False time=124.2s geometry=cross_stream history=8 | q1=632.177 actor=57.121 alpha=0.052
# [train] episode=290 step=37236 return=-384.48 success=False time=89.2s geometry=cross_stream history=8 | q1=82.320 actor=57.807 alpha=0.051
# [train] episode=295 step=38070 return=-384.48 success=False time=69.0s geometry=cross_stream history=8 | q1=74.245 actor=57.792 alpha=0.049
# [train] episode=300 step=38838 return=-421.31 success=False time=100.9s geometry=cross_stream history=8 | q1=410.633 actor=59.589 alpha=0.048
# [train] episode=305 step=39204 return=-268.90 success=False time=16.3s geometry=cross_stream history=8 | q1=286.497 actor=56.029 alpha=0.047
# [train] episode=310 step=39960 return=-261.21 success=False time=20.5s geometry=cross_stream history=8 | q1=175.034 actor=62.366 alpha=0.045
# [train] episode=315 step=40494 return=-241.53 success=False time=44.8s geometry=cross_stream history=8 | q1=200.157 actor=62.409 alpha=0.045
# [train] episode=320 step=40926 return=-306.90 success=False time=38.5s geometry=cross_stream history=8 | q1=373.388 actor=61.916 alpha=0.044
# [train] episode=325 step=41886 return=-340.42 success=False time=54.8s geometry=cross_stream history=8 | q1=302.762 actor=64.052 alpha=0.043
# [train] episode=330 step=42138 return=-342.61 success=False time=77.6s geometry=cross_stream history=8 | q1=292.963 actor=66.445 alpha=0.043
# [train] episode=335 step=42786 return=-297.80 success=False time=48.2s geometry=cross_stream history=8 | q1=92.362 actor=62.392 alpha=0.043
# [train] episode=340 step=43500 return=-359.56 success=False time=54.3s geometry=cross_stream history=8 | q1=573.588 actor=66.561 alpha=0.042
# [train] episode=345 step=44052 return=-347.32 success=False time=71.4s geometry=cross_stream history=8 | q1=232.539 actor=64.801 alpha=0.041
# [train] episode=350 step=44850 return=-358.10 success=False time=31.1s geometry=cross_stream history=8 | q1=265.023 actor=67.638 alpha=0.040
# [train] episode=355 step=45618 return=-395.32 success=False time=63.2s geometry=cross_stream history=8 | q1=393.264 actor=70.726 alpha=0.039
# [train] episode=360 step=46128 return=-275.72 success=False time=52.5s geometry=cross_stream history=8 | q1=682.455 actor=70.794 alpha=0.039
# [train] episode=365 step=47016 return=-341.67 success=False time=81.4s geometry=cross_stream history=8 | q1=377.455 actor=70.765 alpha=0.038
# [train] episode=370 step=47934 return=-584.73 success=False time=75.9s geometry=cross_stream history=8 | q1=40.580 actor=69.965 alpha=0.039
# [train] episode=375 step=48456 return=-418.23 success=False time=48.8s geometry=cross_stream history=8 | q1=929.658 actor=70.432 alpha=0.038
# [train] episode=380 step=49308 return=-300.65 success=False time=23.5s geometry=cross_stream history=8 | q1=256.306 actor=73.144 alpha=0.038
# [train] episode=385 step=49830 return=-426.88 success=False time=137.7s geometry=cross_stream history=8 | q1=599.446 actor=74.432 alpha=0.037
# [eval] step=50004 objective=arrival_v2 return=-357.97 safety=17.104 success=0.00% time=78.3s energy=26835.8 path=112.1 prog=-1.39
# [train] episode=390 step=50574 return=-342.53 success=False time=61.5s geometry=cross_stream history=8 | q1=458.262 actor=70.999 alpha=0.037
# [train] episode=395 step=51492 return=-336.25 success=False time=111.7s geometry=cross_stream history=8 | q1=529.155 actor=72.976 alpha=0.036
# [train] episode=400 step=52272 return=-407.12 success=False time=40.1s geometry=cross_stream history=8 | q1=2.252 actor=73.513 alpha=0.036
# [train] episode=405 step=53328 return=-473.45 success=False time=98.9s geometry=cross_stream history=8 | q1=405.076 actor=75.045 alpha=0.035
# [train] episode=410 step=54336 return=-297.56 success=False time=56.9s geometry=cross_stream history=8 | q1=593.707 actor=75.501 alpha=0.035
# [train] episode=415 step=54894 return=-300.22 success=False time=48.0s geometry=cross_stream history=8 | q1=163.511 actor=74.597 alpha=0.034
# [train] episode=420 step=55692 return=-341.54 success=False time=93.9s geometry=cross_stream history=8 | q1=247.633 actor=80.388 alpha=0.035
# [train] episode=425 step=56622 return=-215.48 success=False time=45.9s geometry=cross_stream history=8 | q1=411.996 actor=77.454 alpha=0.035
# [train] episode=430 step=57156 return=-284.73 success=False time=115.8s geometry=cross_stream history=8 | q1=361.611 actor=77.877 alpha=0.036
# [train] episode=435 step=57960 return=-282.90 success=False time=66.1s geometry=cross_stream history=8 | q1=265.608 actor=81.970 alpha=0.035
# [train] episode=440 step=58284 return=-403.00 success=False time=67.3s geometry=cross_stream history=8 | q1=181.083 actor=84.226 alpha=0.035
# [train] episode=445 step=59538 return=-319.41 success=False time=114.5s geometry=cross_stream history=8 | q1=408.241 actor=84.181 alpha=0.035
# [train] episode=450 step=60168 return=-324.51 success=False time=63.4s geometry=cross_stream history=8 | q1=195.878 actor=82.888 alpha=0.035
# [train] episode=455 step=60762 return=-468.98 success=False time=101.1s geometry=cross_stream history=8 | q1=138.979 actor=83.681 alpha=0.035
# [train] episode=460 step=61296 return=-283.66 success=False time=93.1s geometry=cross_stream history=8 | q1=234.980 actor=84.066 alpha=0.036
# [train] episode=465 step=62100 return=-370.93 success=False time=71.5s geometry=cross_stream history=8 | q1=117.761 actor=82.611 alpha=0.036
# [train] episode=470 step=62946 return=-356.11 success=False time=73.2s geometry=cross_stream history=8 | q1=315.395 actor=82.717 alpha=0.036
# [train] episode=475 step=63702 return=-364.66 success=False time=155.3s geometry=cross_stream history=8 | q1=141.513 actor=85.599 alpha=0.036
# [train] episode=480 step=64236 return=-400.19 success=False time=44.0s geometry=cross_stream history=8 | q1=260.579 actor=85.051 alpha=0.036
# [train] episode=485 step=64770 return=-245.33 success=False time=21.7s geometry=cross_stream history=8 | q1=205.059 actor=88.707 alpha=0.036
# [train] episode=490 step=65760 return=-361.11 success=False time=94.7s geometry=cross_stream history=8 | q1=67.640 actor=85.869 alpha=0.036
# [train] episode=495 step=66426 return=-399.58 success=False time=102.7s geometry=cross_stream history=8 | q1=298.056 actor=87.601 alpha=0.035
# [train] episode=500 step=67626 return=-424.46 success=False time=106.0s geometry=cross_stream history=8 | q1=148.237 actor=89.153 alpha=0.035
# [train] episode=505 step=68232 return=-200.75 success=False time=46.6s geometry=cross_stream history=8 | q1=262.136 actor=90.211 alpha=0.035
# [train] episode=510 step=68748 return=-257.53 success=False time=42.4s geometry=cross_stream history=8 | q1=125.952 actor=94.647 alpha=0.035
# [train] episode=515 step=69654 return=-333.12 success=False time=43.1s geometry=cross_stream history=8 | q1=161.066 actor=92.536 alpha=0.034
# [train] episode=520 step=70374 return=-328.71 success=False time=87.8s geometry=cross_stream history=8 | q1=39.987 actor=93.784 alpha=0.035
# [train] episode=525 step=71316 return=-366.48 success=False time=77.9s geometry=cross_stream history=8 | q1=34.404 actor=91.724 alpha=0.034
# [train] episode=530 step=71820 return=-377.05 success=False time=84.4s geometry=cross_stream history=8 | q1=361.117 actor=95.393 alpha=0.034
# [train] episode=535 step=72516 return=-307.49 success=False time=82.7s geometry=cross_stream history=8 | q1=39.947 actor=92.580 alpha=0.033
# [train] episode=540 step=73248 return=-408.09 success=False time=106.4s geometry=cross_stream history=8 | q1=292.227 actor=95.768 alpha=0.033
# [train] episode=545 step=73968 return=-361.31 success=False time=74.0s geometry=cross_stream history=8 | q1=167.384 actor=99.380 alpha=0.032
# [train] episode=550 step=74808 return=-243.25 success=False time=15.3s geometry=cross_stream history=8 | q1=3.522 actor=97.953 alpha=0.032
# [eval] step=75000 objective=arrival_v2 return=-331.53 safety=21.555 success=0.00% time=80.1s energy=41963.7 path=106.3 prog=-0.93
# [train] episode=555 step=75678 return=-320.29 success=False time=52.7s geometry=cross_stream history=8 | q1=324.333 actor=98.925 alpha=0.033
# [train] episode=560 step=76326 return=-204.26 success=False time=38.2s geometry=cross_stream history=8 | q1=4.062 actor=90.274 alpha=0.033
# [train] episode=565 step=77532 return=-384.54 success=False time=114.5s geometry=cross_stream history=8 | q1=230.554 actor=99.661 alpha=0.033
# [train] episode=570 step=78228 return=-314.77 success=False time=211.6s geometry=cross_stream history=8 | q1=213.103 actor=99.993 alpha=0.033
# [train] episode=575 step=80124 return=-473.90 success=False time=201.2s geometry=cross_stream history=8 | q1=268.264 actor=98.415 alpha=0.035
# [train] episode=580 step=80886 return=-328.72 success=False time=226.8s geometry=cross_stream history=8 | q1=258.315 actor=99.188 alpha=0.034
# [train] episode=585 step=81780 return=-441.10 success=False time=94.4s geometry=cross_stream history=8 | q1=82.865 actor=101.167 alpha=0.033
# [train] episode=590 step=83184 return=-404.55 success=False time=109.0s geometry=cross_stream history=8 | q1=44.877 actor=95.339 alpha=0.033
# [train] episode=595 step=83862 return=-353.75 success=False time=208.6s geometry=cross_stream history=8 | q1=9.889 actor=100.880 alpha=0.033
# [train] episode=600 step=84960 return=-342.05 success=False time=57.2s geometry=cross_stream history=8 | q1=125.794 actor=102.079 alpha=0.033
# [train] episode=605 step=85398 return=-340.23 success=False time=50.3s geometry=cross_stream history=8 | q1=66.558 actor=103.383 alpha=0.033
# [train] episode=610 step=86220 return=-195.00 success=False time=73.8s geometry=cross_stream history=8 | q1=127.778 actor=105.513 alpha=0.034
# [train] episode=615 step=87174 return=-415.77 success=False time=99.1s geometry=cross_stream history=8 | q1=366.603 actor=106.745 alpha=0.033
# [train] episode=620 step=87684 return=-223.39 success=False time=84.1s geometry=cross_stream history=8 | q1=461.341 actor=106.792 alpha=0.033
# [train] episode=625 step=88620 return=-261.00 success=False time=16.0s geometry=cross_stream history=8 | q1=72.769 actor=103.577 alpha=0.032
# [train] episode=630 step=88986 return=-245.89 success=False time=18.0s geometry=cross_stream history=8 | q1=95.536 actor=103.134 alpha=0.032
# [train] episode=635 step=89784 return=-431.95 success=False time=94.9s geometry=cross_stream history=8 | q1=20.745 actor=101.370 alpha=0.032
# [train] episode=640 step=90336 return=-388.08 success=False time=77.0s geometry=cross_stream history=8 | q1=207.927 actor=106.674 alpha=0.032
# [train] episode=645 step=91116 return=-214.37 success=False time=107.3s geometry=cross_stream history=8 | q1=28.753 actor=103.587 alpha=0.032
# [train] episode=650 step=91956 return=-444.52 success=False time=100.0s geometry=cross_stream history=8 | q1=7.938 actor=105.876 alpha=0.032
# [train] episode=655 step=92778 return=-360.14 success=False time=84.3s geometry=cross_stream history=8 | q1=7.910 actor=108.769 alpha=0.032
# [train] episode=660 step=93594 return=-261.05 success=False time=37.3s geometry=cross_stream history=8 | q1=69.374 actor=109.140 alpha=0.031
# [train] episode=665 step=95118 return=-274.01 success=False time=40.0s geometry=cross_stream history=8 | q1=150.309 actor=110.415 alpha=0.032
# [train] episode=670 step=95658 return=-363.53 success=False time=71.1s geometry=cross_stream history=8 | q1=104.447 actor=107.145 alpha=0.032
# [train] episode=675 step=96714 return=-355.14 success=False time=68.0s geometry=cross_stream history=8 | q1=62.964 actor=112.620 alpha=0.034
# [train] episode=680 step=98442 return=-376.28 success=False time=102.3s geometry=cross_stream history=8 | q1=62.308 actor=107.452 alpha=0.035
# [train] episode=685 step=99216 return=-144.63 success=False time=240.1s geometry=cross_stream history=8 | q1=172.999 actor=110.387 alpha=0.036
# [train] episode=690 step=99936 return=-278.22 success=False time=43.7s geometry=cross_stream history=8 | q1=398.094 actor=116.532 alpha=0.036
# [eval] step=100002 objective=arrival_v2 return=-269.14 safety=17.274 success=0.00% time=128.2s energy=71829.3 path=110.1 prog=-0.61
# [train] episode=695 step=101064 return=-412.67 success=False time=93.5s geometry=cross_stream history=8 | q1=160.370 actor=106.588 alpha=0.036
# [train] episode=700 step=102750 return=-456.05 success=False time=200.6s geometry=cross_stream history=8 | q1=208.517 actor=114.601 alpha=0.038
# [train] episode=705 step=104436 return=-349.77 success=False time=52.1s geometry=cross_stream history=8 | q1=94.842 actor=117.090 alpha=0.039
# [train] episode=710 step=105108 return=-282.70 success=False time=30.4s geometry=cross_stream history=8 | q1=124.837 actor=115.418 alpha=0.040
# [train] episode=715 step=106572 return=-335.57 success=False time=155.9s geometry=cross_stream history=8 | q1=56.465 actor=112.813 alpha=0.039
# [train] episode=720 step=107436 return=-275.05 success=False time=193.5s geometry=cross_stream history=8 | q1=12.056 actor=118.393 alpha=0.039
# [train] episode=725 step=109422 return=-275.36 success=False time=57.0s geometry=cross_stream history=8 | q1=91.193 actor=119.549 alpha=0.038
# [train] episode=730 step=110004 return=-245.85 success=False time=47.7s geometry=cross_stream history=8 | q1=112.336 actor=118.549 alpha=0.039
# [train] episode=735 step=111618 return=-187.03 success=False time=133.9s geometry=cross_stream history=8 | q1=128.388 actor=114.405 alpha=0.038
# [train] episode=740 step=112494 return=-147.72 success=False time=240.1s geometry=cross_stream history=8 | q1=179.879 actor=122.617 alpha=0.038
# [train] episode=745 step=114510 return=-342.83 success=False time=240.1s geometry=cross_stream history=8 | q1=157.456 actor=113.679 alpha=0.039
# [train] episode=750 step=115512 return=-121.18 success=False time=240.1s geometry=cross_stream history=8 | q1=157.158 actor=114.787 alpha=0.039
# [train] episode=755 step=116694 return=-188.54 success=False time=240.1s geometry=cross_stream history=8 | q1=120.370 actor=119.101 alpha=0.038
# [train] episode=760 step=118464 return=-219.03 success=False time=161.8s geometry=cross_stream history=8 | q1=72.442 actor=117.666 alpha=0.039
# [train] episode=765 step=119784 return=-466.16 success=False time=109.1s geometry=cross_stream history=8 | q1=15.314 actor=116.372 alpha=0.041
# [train] episode=770 step=121074 return=-260.39 success=False time=33.0s geometry=cross_stream history=8 | q1=3.460 actor=114.402 alpha=0.042
# [train] episode=775 step=122460 return=-360.42 success=False time=82.7s geometry=cross_stream history=8 | q1=202.811 actor=119.754 alpha=0.043
# [train] episode=780 step=123780 return=-250.85 success=False time=18.7s geometry=cross_stream history=8 | q1=230.535 actor=121.371 alpha=0.043
# [eval] step=125004 objective=arrival_v2 return=-247.41 safety=29.885 success=0.00% time=154.4s energy=94132.9 path=109.4 prog=-0.16
# [train] episode=785 step=126024 return=-260.11 success=False time=186.3s geometry=cross_stream history=8 | q1=136.545 actor=120.331 alpha=0.044
# [train] episode=790 step=126762 return=-214.17 success=False time=183.8s geometry=cross_stream history=8 | q1=157.286 actor=123.895 alpha=0.043
# [train] episode=795 step=128220 return=-239.90 success=False time=12.6s geometry=cross_stream history=8 | q1=167.370 actor=122.923 alpha=0.043
# [train] episode=800 step=129822 return=-183.46 success=False time=150.8s geometry=cross_stream history=8 | q1=23.494 actor=123.035 alpha=0.042
# [train] episode=805 step=131142 return=-332.31 success=False time=109.1s geometry=cross_stream history=8 | q1=46.730 actor=122.527 alpha=0.042
# [train] episode=810 step=132192 return=-158.00 success=False time=240.1s geometry=cross_stream history=8 | q1=86.199 actor=128.766 alpha=0.040
# [train] episode=815 step=133806 return=-274.07 success=False time=43.1s geometry=cross_stream history=8 | q1=97.984 actor=129.763 alpha=0.040
# [train] episode=820 step=134718 return=-254.95 success=False time=236.6s geometry=cross_stream history=8 | q1=178.127 actor=129.205 alpha=0.040
# [train] episode=825 step=136800 return=-126.53 success=False time=240.1s geometry=cross_stream history=8 | q1=144.188 actor=120.303 alpha=0.039
# [train] episode=830 step=137706 return=142.27 success=True time=74.9s geometry=cross_stream history=8 | q1=92.806 actor=119.030 alpha=0.038
# [train] episode=835 step=138690 return=-196.01 success=False time=209.6s geometry=cross_stream history=8 | q1=382.238 actor=120.867 alpha=0.039
# [train] episode=840 step=139848 return=-82.96 success=False time=240.1s geometry=cross_stream history=8 | q1=2.828 actor=123.990 alpha=0.040
# [train] episode=845 step=140646 return=-199.50 success=False time=145.5s geometry=cross_stream history=8 | q1=281.745 actor=127.178 alpha=0.039
# [train] episode=850 step=142212 return=-71.95 success=False time=240.1s geometry=cross_stream history=8 | q1=241.101 actor=125.619 alpha=0.041
# [train] episode=855 step=143478 return=-73.55 success=False time=240.1s geometry=cross_stream history=8 | q1=101.625 actor=119.396 alpha=0.040
# [train] episode=860 step=144270 return=-206.15 success=False time=91.8s geometry=cross_stream history=8 | q1=175.151 actor=127.298 alpha=0.039
# [train] episode=865 step=146634 return=-354.01 success=False time=57.6s geometry=cross_stream history=8 | q1=109.471 actor=126.286 alpha=0.039
# [train] episode=870 step=147474 return=-299.74 success=False time=61.5s geometry=cross_stream history=8 | q1=112.567 actor=121.855 alpha=0.039
# [train] episode=875 step=148542 return=-441.96 success=False time=95.1s geometry=cross_stream history=8 | q1=140.812 actor=121.525 alpha=0.040
# [eval] step=150000 objective=arrival_v2 return=-357.18 safety=29.789 success=0.00% time=88.4s energy=40268.1 path=102.1 prog=-1.13
# [train] episode=880 step=151230 return=-58.16 success=False time=240.1s geometry=cross_stream history=8 | q1=104.166 actor=120.605 alpha=0.039
# [train] episode=885 step=153024 return=-251.54 success=False time=24.6s geometry=cross_stream history=8 | q1=32.190 actor=127.931 alpha=0.040
# [train] episode=890 step=154122 return=-80.47 success=False time=240.1s geometry=cross_stream history=8 | q1=33.371 actor=128.845 alpha=0.041
# [train] episode=895 step=155424 return=-282.09 success=False time=48.9s geometry=cross_stream history=8 | q1=30.242 actor=128.590 alpha=0.040
# [train] episode=900 step=157194 return=-34.13 success=False time=240.1s geometry=cross_stream history=8 | q1=166.302 actor=129.255 alpha=0.043
# [train] episode=905 step=159390 return=-58.48 success=False time=240.1s geometry=cross_stream history=8 | q1=92.718 actor=127.396 alpha=0.043
# [train] episode=910 step=160074 return=140.53 success=True time=84.9s geometry=cross_stream history=8 | q1=168.079 actor=129.269 alpha=0.044
# [train] episode=915 step=162648 return=-34.48 success=False time=240.1s geometry=cross_stream history=8 | q1=87.688 actor=125.198 alpha=0.042
# [train] episode=920 step=163830 return=138.25 success=True time=82.4s geometry=cross_stream history=8 | q1=189.585 actor=125.663 alpha=0.043
# [train] episode=925 step=164904 return=134.29 success=True time=187.5s geometry=cross_stream history=8 | q1=114.932 actor=129.188 alpha=0.045
# [train] episode=930 step=165840 return=-309.89 success=False time=52.5s geometry=cross_stream history=8 | q1=71.724 actor=125.169 alpha=0.046
# [train] episode=935 step=167502 return=-325.21 success=False time=59.0s geometry=cross_stream history=8 | q1=132.503 actor=120.987 alpha=0.047
# [train] episode=940 step=169302 return=-75.98 success=False time=240.1s geometry=cross_stream history=8 | q1=157.056 actor=125.234 alpha=0.047
# [train] episode=945 step=170958 return=-243.06 success=False time=237.2s geometry=cross_stream history=8 | q1=61.707 actor=126.637 alpha=0.050
# [train] episode=950 step=171876 return=-280.27 success=False time=46.3s geometry=cross_stream history=8 | q1=20.609 actor=123.806 alpha=0.051
# [train] episode=955 step=174138 return=-45.78 success=False time=240.1s geometry=cross_stream history=8 | q1=117.609 actor=125.739 alpha=0.050
# [eval] step=175002 objective=arrival_v2 return=-171.35 safety=16.976 success=3.33% time=135.1s energy=94291.9 path=99.1 prog=0.30
# [train] episode=960 step=175716 return=-343.52 success=False time=64.7s geometry=cross_stream history=8 | q1=214.765 actor=126.169 alpha=0.049
# [train] episode=965 step=177420 return=-143.54 success=False time=240.1s geometry=cross_stream history=8 | q1=51.841 actor=125.345 alpha=0.051
# [train] episode=970 step=178692 return=139.29 success=True time=85.3s geometry=cross_stream history=8 | q1=174.694 actor=120.344 alpha=0.052
# [train] episode=975 step=180060 return=-54.44 success=False time=240.1s geometry=cross_stream history=8 | q1=64.792 actor=125.461 alpha=0.051
# [train] episode=980 step=181950 return=-88.31 success=False time=240.1s geometry=cross_stream history=8 | q1=4.336 actor=124.751 alpha=0.049
# [train] episode=985 step=183810 return=-71.76 success=False time=240.1s geometry=cross_stream history=8 | q1=57.662 actor=126.431 alpha=0.047
# [train] episode=990 step=184488 return=-214.96 success=False time=43.0s geometry=cross_stream history=8 | q1=39.838 actor=124.027 alpha=0.046
# [train] episode=995 step=185460 return=-245.77 success=False time=37.1s geometry=cross_stream history=8 | q1=120.273 actor=123.753 alpha=0.045
# [train] episode=1000 step=187734 return=-57.26 success=False time=240.1s geometry=cross_stream history=8 | q1=4.040 actor=123.128 alpha=0.046
# [train] episode=1005 step=189162 return=-431.41 success=False time=118.4s geometry=cross_stream history=8 | q1=106.248 actor=123.842 alpha=0.046
# [train] episode=1010 step=190176 return=-178.38 success=False time=68.3s geometry=cross_stream history=8 | q1=3.250 actor=128.743 alpha=0.047
# [train] episode=1015 step=191802 return=-197.94 success=False time=219.2s geometry=cross_stream history=8 | q1=182.365 actor=125.137 alpha=0.047
# [train] episode=1020 step=193134 return=139.44 success=True time=200.2s geometry=cross_stream history=8 | q1=3.753 actor=128.032 alpha=0.046
# [train] episode=1025 step=194598 return=-224.72 success=False time=76.4s geometry=cross_stream history=8 | q1=56.941 actor=129.686 alpha=0.046
# [train] episode=1030 step=195696 return=-170.39 success=False time=90.6s geometry=cross_stream history=8 | q1=36.439 actor=124.711 alpha=0.046
# [train] episode=1035 step=196290 return=-245.06 success=False time=23.9s geometry=cross_stream history=8 | q1=123.757 actor=121.763 alpha=0.046
# [train] episode=1040 step=197370 return=-266.44 success=False time=46.3s geometry=cross_stream history=8 | q1=58.762 actor=118.629 alpha=0.045
# [train] episode=1045 step=198336 return=-241.00 success=False time=15.3s geometry=cross_stream history=8 | q1=20.706 actor=121.838 alpha=0.046
# [train] episode=1050 step=199932 return=-184.08 success=False time=199.2s geometry=cross_stream history=8 | q1=93.275 actor=123.105 alpha=0.045
# [eval] step=200004 objective=arrival_v2 return=-213.90 safety=27.230 success=0.00% time=124.9s energy=91085.8 path=83.2 prog=0.30
# [train] episode=1055 step=200592 return=-175.42 success=False time=181.6s geometry=cross_stream history=8 | q1=42.400 actor=121.695 alpha=0.045
# [train] episode=1060 step=201558 return=-96.87 success=False time=240.1s geometry=cross_stream history=8 | q1=35.452 actor=123.952 alpha=0.046
# [train] episode=1065 step=202518 return=138.27 success=True time=143.2s geometry=cross_stream history=8 | q1=30.625 actor=127.099 alpha=0.046
# [train] episode=1070 step=203484 return=-261.89 success=False time=46.6s geometry=cross_stream history=8 | q1=55.437 actor=117.818 alpha=0.045
# [train] episode=1075 step=205392 return=-309.66 success=False time=238.9s geometry=cross_stream history=8 | q1=5.167 actor=117.107 alpha=0.047
# [train] episode=1080 step=206280 return=-376.90 success=False time=73.4s geometry=cross_stream history=8 | q1=9.366 actor=126.358 alpha=0.046
# [train] episode=1085 step=206874 return=-250.74 success=False time=16.2s geometry=cross_stream history=8 | q1=34.305 actor=129.054 alpha=0.046
# [train] episode=1090 step=208014 return=-314.74 success=False time=188.7s geometry=cross_stream history=8 | q1=121.644 actor=126.633 alpha=0.046
# [train] episode=1095 step=209736 return=71.42 success=True time=67.8s geometry=cross_stream history=8 | q1=3.999 actor=126.334 alpha=0.046
# [train] episode=1100 step=210444 return=-244.60 success=False time=37.2s geometry=cross_stream history=8 | q1=64.482 actor=127.798 alpha=0.047
# [train] episode=1105 step=212076 return=136.39 success=True time=92.9s geometry=cross_stream history=8 | q1=21.100 actor=122.961 alpha=0.049
# [train] episode=1110 step=213174 return=-201.97 success=False time=176.8s geometry=cross_stream history=8 | q1=57.112 actor=128.926 alpha=0.051
# [train] episode=1115 step=214710 return=-347.89 success=False time=67.0s geometry=cross_stream history=8 | q1=75.104 actor=120.094 alpha=0.050
# [train] episode=1120 step=215718 return=-151.66 success=False time=240.1s geometry=cross_stream history=8 | q1=25.746 actor=121.935 alpha=0.050
# [train] episode=1125 step=217530 return=-136.51 success=False time=234.1s geometry=cross_stream history=8 | q1=82.877 actor=122.278 alpha=0.048
# [train] episode=1130 step=218946 return=-405.94 success=False time=91.5s geometry=cross_stream history=8 | q1=67.823 actor=123.852 alpha=0.046
# [train] episode=1135 step=221502 return=-48.37 success=False time=240.1s geometry=cross_stream history=8 | q1=64.156 actor=124.288 alpha=0.048
# [train] episode=1140 step=222762 return=-214.75 success=False time=240.1s geometry=cross_stream history=8 | q1=5.151 actor=119.830 alpha=0.048
# [train] episode=1145 step=224100 return=1.70 success=True time=110.6s geometry=cross_stream history=8 | q1=24.420 actor=118.284 alpha=0.048
# [eval] step=225000 objective=arrival_v2 return=-52.84 safety=27.136 success=46.67% time=134.3s energy=99311.1 path=74.5 prog=0.62
# [train] episode=1150 step=226128 return=-330.30 success=False time=198.6s geometry=cross_stream history=8 | q1=23.598 actor=129.558 alpha=0.048
# [train] episode=1155 step=227622 return=-71.85 success=False time=240.1s geometry=cross_stream history=8 | q1=87.399 actor=121.291 alpha=0.048
# [train] episode=1160 step=229128 return=-92.55 success=False time=240.1s geometry=cross_stream history=8 | q1=5.065 actor=124.118 alpha=0.050
# [train] episode=1165 step=230196 return=-367.43 success=False time=76.8s geometry=cross_stream history=8 | q1=44.289 actor=123.309 alpha=0.051
# [train] episode=1170 step=231744 return=-297.38 success=False time=228.0s geometry=cross_stream history=8 | q1=121.414 actor=121.785 alpha=0.051
# [train] episode=1175 step=233406 return=-50.85 success=False time=240.1s geometry=cross_stream history=8 | q1=51.931 actor=122.875 alpha=0.050
# [train] episode=1180 step=234522 return=141.24 success=True time=92.4s geometry=cross_stream history=8 | q1=11.770 actor=119.457 alpha=0.050
# [train] episode=1185 step=236028 return=-46.43 success=False time=240.1s geometry=cross_stream history=8 | q1=14.676 actor=121.903 alpha=0.050
# [train] episode=1190 step=238092 return=-48.87 success=False time=240.1s geometry=cross_stream history=8 | q1=99.532 actor=118.362 alpha=0.051
# [train] episode=1195 step=240936 return=-91.72 success=False time=240.1s geometry=cross_stream history=8 | q1=122.844 actor=117.824 alpha=0.050
# [train] episode=1200 step=243018 return=-92.66 success=False time=240.1s geometry=cross_stream history=8 | q1=3.997 actor=125.567 alpha=0.048
# [train] episode=1205 step=244404 return=-95.22 success=False time=240.1s geometry=cross_stream history=8 | q1=133.290 actor=120.907 alpha=0.049
# [train] episode=1210 step=246066 return=129.32 success=True time=137.9s geometry=cross_stream history=8 | q1=86.371 actor=120.142 alpha=0.049
# [train] episode=1215 step=248058 return=-39.18 success=False time=240.1s geometry=cross_stream history=8 | q1=109.703 actor=120.289 alpha=0.049
# [train] episode=1220 step=249408 return=-338.46 success=False time=61.2s geometry=cross_stream history=8 | q1=74.094 actor=118.520 alpha=0.049
# [eval] step=250002 objective=arrival_v2 return=-65.31 safety=28.270 success=36.67% time=157.1s energy=113678.0 path=78.5 prog=0.66
# [train] episode=1225 step=250632 return=101.05 success=True time=138.8s geometry=cross_stream history=8 | q1=3.971 actor=121.190 alpha=0.049
# [train] episode=1230 step=252612 return=-77.14 success=False time=240.1s geometry=cross_stream history=8 | q1=19.551 actor=112.643 alpha=0.051
# [train] episode=1235 step=254358 return=-355.50 success=False time=224.4s geometry=cross_stream history=8 | q1=74.359 actor=122.782 alpha=0.052
# [train] episode=1240 step=255978 return=-276.14 success=False time=50.8s geometry=cross_stream history=8 | q1=10.655 actor=119.092 alpha=0.053
# [train] episode=1245 step=256728 return=84.37 success=True time=101.3s geometry=cross_stream history=8 | q1=10.796 actor=120.486 alpha=0.053
# [train] episode=1250 step=258330 return=-387.98 success=False time=185.6s geometry=cross_stream history=8 | q1=2.750 actor=121.858 alpha=0.052
# [train] episode=1255 step=259542 return=-103.04 success=False time=240.1s geometry=cross_stream history=8 | q1=55.548 actor=116.209 alpha=0.053
# [train] episode=1260 step=260676 return=140.07 success=True time=59.5s geometry=cross_stream history=8 | q1=27.937 actor=113.610 alpha=0.052
# [train] episode=1265 step=262782 return=-236.95 success=False time=16.0s geometry=cross_stream history=8 | q1=26.713 actor=117.534 alpha=0.051
# [train] episode=1270 step=264102 return=-52.13 success=False time=240.1s geometry=cross_stream history=8 | q1=37.910 actor=117.160 alpha=0.054
# [train] episode=1275 step=265632 return=-47.64 success=False time=240.1s geometry=cross_stream history=8 | q1=69.630 actor=115.541 alpha=0.054
# [train] episode=1280 step=268164 return=-237.80 success=False time=35.6s geometry=cross_stream history=8 | q1=5.058 actor=117.725 alpha=0.052
# [train] episode=1285 step=270750 return=-102.16 success=False time=240.1s geometry=cross_stream history=8 | q1=101.608 actor=115.362 alpha=0.053
# [train] episode=1290 step=271812 return=-247.99 success=False time=38.7s geometry=cross_stream history=8 | q1=65.550 actor=121.789 alpha=0.052
# [train] episode=1295 step=273948 return=-34.81 success=False time=240.1s geometry=cross_stream history=8 | q1=62.076 actor=115.319 alpha=0.051
# [eval] step=275004 objective=arrival_v2 return=15.26 safety=14.877 success=63.33% time=120.3s energy=91021.9 path=70.0 prog=0.71
# [train] episode=1300 step=275496 return=-244.60 success=False time=34.7s geometry=cross_stream history=8 | q1=17.470 actor=111.040 alpha=0.050
# [train] episode=1305 step=276594 return=-29.12 success=False time=240.1s geometry=cross_stream history=8 | q1=3.239 actor=109.891 alpha=0.051
# [train] episode=1310 step=278856 return=139.21 success=True time=85.3s geometry=cross_stream history=8 | q1=2.524 actor=113.792 alpha=0.054
# [train] episode=1315 step=280974 return=-280.14 success=False time=203.7s geometry=cross_stream history=8 | q1=3.716 actor=113.848 alpha=0.051
# [train] episode=1320 step=282360 return=130.03 success=True time=230.9s geometry=cross_stream history=8 | q1=156.188 actor=118.974 alpha=0.051
# [train] episode=1325 step=284172 return=-26.09 success=False time=240.1s geometry=cross_stream history=8 | q1=2.533 actor=111.944 alpha=0.052
# [train] episode=1330 step=286590 return=-279.09 success=False time=233.0s geometry=cross_stream history=8 | q1=85.963 actor=111.497 alpha=0.052
# [train] episode=1335 step=287190 return=138.24 success=True time=49.5s geometry=cross_stream history=8 | q1=2.478 actor=116.528 alpha=0.053
# [train] episode=1340 step=289122 return=-84.14 success=False time=240.1s geometry=cross_stream history=8 | q1=122.487 actor=111.636 alpha=0.053
# [train] episode=1345 step=290286 return=-241.71 success=False time=130.2s geometry=cross_stream history=8 | q1=35.568 actor=109.344 alpha=0.052
# [train] episode=1350 step=292014 return=-100.06 success=False time=240.1s geometry=cross_stream history=8 | q1=4.139 actor=108.213 alpha=0.054
# [train] episode=1355 step=294150 return=-281.85 success=False time=80.3s geometry=cross_stream history=8 | q1=67.200 actor=111.940 alpha=0.049
# [train] episode=1360 step=295410 return=-59.44 success=False time=240.1s geometry=cross_stream history=8 | q1=143.685 actor=110.397 alpha=0.049
# [train] episode=1365 step=296664 return=30.72 success=True time=142.5s geometry=cross_stream history=8 | q1=2.896 actor=110.330 alpha=0.050
# [train] episode=1370 step=297858 return=-326.34 success=False time=213.9s geometry=cross_stream history=8 | q1=24.696 actor=112.892 alpha=0.051
# [train] episode=1375 step=298716 return=140.59 success=True time=57.0s geometry=cross_stream history=8 | q1=16.723 actor=110.602 alpha=0.051
# [train] episode=1380 step=299928 return=-312.49 success=False time=171.6s geometry=cross_stream history=8 | q1=43.136 actor=107.295 alpha=0.051
# [eval] step=300000 objective=arrival_v2 return=-159.63 safety=77.224 success=33.33% time=182.2s energy=124116.9 path=83.1 prog=0.72
# [train] episode=1385 step=301956 return=51.18 success=True time=181.4s geometry=cross_stream history=8 | q1=3.459 actor=116.830 alpha=0.050
# [train] episode=1390 step=303912 return=139.75 success=True time=162.5s geometry=cross_stream history=8 | q1=203.824 actor=112.885 alpha=0.049
# [train] episode=1395 step=306480 return=-125.62 success=False time=240.1s geometry=cross_stream history=8 | q1=2.422 actor=106.681 alpha=0.047
# [train] episode=1400 step=308952 return=-94.05 success=False time=240.1s geometry=cross_stream history=8 | q1=39.627 actor=113.266 alpha=0.047
# [train] episode=1405 step=310230 return=114.59 success=True time=155.9s geometry=cross_stream history=8 | q1=178.868 actor=109.034 alpha=0.048
# [train] episode=1410 step=312618 return=-81.60 success=False time=240.1s geometry=cross_stream history=8 | q1=151.122 actor=108.423 alpha=0.049
# [train] episode=1415 step=315060 return=-128.92 success=False time=240.1s geometry=cross_stream history=8 | q1=71.402 actor=109.870 alpha=0.050
# [train] episode=1420 step=316686 return=-73.79 success=False time=240.1s geometry=cross_stream history=8 | q1=224.419 actor=105.398 alpha=0.050
# [train] episode=1425 step=318438 return=-255.97 success=False time=7.2s geometry=cross_stream history=8 | q1=57.180 actor=108.309 alpha=0.048
# [train] episode=1430 step=321294 return=-53.60 success=False time=240.1s geometry=cross_stream history=8 | q1=17.009 actor=113.124 alpha=0.046
# [train] episode=1435 step=323010 return=-121.72 success=False time=231.7s geometry=cross_stream history=8 | q1=150.624 actor=109.819 alpha=0.048
# [eval] step=325002 objective=arrival_v2 return=-182.60 safety=58.346 success=6.67% time=192.6s energy=128870.3 path=95.1 prog=0.61
# [train] episode=1440 step=325350 return=-106.94 success=False time=240.1s geometry=cross_stream history=8 | q1=9.996 actor=112.755 alpha=0.049
# [train] episode=1445 step=326358 return=-453.91 success=False time=107.5s geometry=cross_stream history=8 | q1=430.055 actor=100.268 alpha=0.050
# [train] episode=1450 step=328794 return=-71.87 success=False time=240.1s geometry=cross_stream history=8 | q1=14.116 actor=106.685 alpha=0.050
# [train] episode=1455 step=330912 return=-50.87 success=False time=240.1s geometry=cross_stream history=8 | q1=13.740 actor=110.114 alpha=0.050
# [train] episode=1460 step=332370 return=-245.68 success=False time=59.3s geometry=cross_stream history=8 | q1=2.481 actor=107.906 alpha=0.051
# [train] episode=1465 step=334512 return=-299.71 success=False time=177.8s geometry=cross_stream history=8 | q1=171.809 actor=109.652 alpha=0.052
# [train] episode=1470 step=336444 return=-375.29 success=False time=228.4s geometry=cross_stream history=8 | q1=74.680 actor=107.604 alpha=0.051
# [train] episode=1475 step=337632 return=-253.63 success=False time=9.0s geometry=cross_stream history=8 | q1=15.990 actor=108.438 alpha=0.050
# [train] episode=1480 step=339804 return=-36.90 success=False time=240.1s geometry=cross_stream history=8 | q1=52.766 actor=102.904 alpha=0.049
# [train] episode=1485 step=341166 return=-274.32 success=False time=112.6s geometry=cross_stream history=8 | q1=4.544 actor=103.973 alpha=0.050
# [train] episode=1490 step=343470 return=-231.32 success=False time=35.2s geometry=cross_stream history=8 | q1=141.635 actor=105.301 alpha=0.050
# [train] episode=1495 step=344058 return=-57.44 success=False time=240.1s geometry=cross_stream history=8 | q1=4.531 actor=108.355 alpha=0.050
# [train] episode=1500 step=346944 return=-27.07 success=False time=240.1s geometry=cross_stream history=8 | q1=31.492 actor=106.596 alpha=0.051
# [train] episode=1505 step=349254 return=-24.99 success=False time=240.1s geometry=cross_stream history=8 | q1=3.183 actor=102.566 alpha=0.049
# [eval] step=350004 objective=arrival_v2 return=-158.17 safety=50.421 success=0.00% time=200.9s energy=136416.0 path=90.6 prog=0.73
# [train] episode=1510 step=351360 return=53.72 success=True time=191.0s geometry=cross_stream history=8 | q1=1.730 actor=103.178 alpha=0.049
# [train] episode=1515 step=352596 return=-273.89 success=False time=240.1s geometry=cross_stream history=8 | q1=23.778 actor=99.215 alpha=0.050
# [train] episode=1520 step=355374 return=-44.90 success=False time=240.1s geometry=cross_stream history=8 | q1=2.053 actor=99.224 alpha=0.051
# [train] episode=1525 step=357156 return=-33.87 success=False time=240.1s geometry=cross_stream history=8 | q1=81.580 actor=101.673 alpha=0.052
# [train] episode=1530 step=358362 return=-3.48 success=True time=238.8s geometry=cross_stream history=8 | q1=16.315 actor=107.103 alpha=0.052
# [train] episode=1535 step=360036 return=136.12 success=True time=202.7s geometry=cross_stream history=8 | q1=27.343 actor=99.450 alpha=0.052
# [train] episode=1540 step=361806 return=-88.82 success=False time=240.1s geometry=cross_stream history=8 | q1=22.760 actor=102.926 alpha=0.051
# [train] episode=1545 step=363126 return=125.89 success=True time=149.7s geometry=cross_stream history=8 | q1=4.404 actor=99.186 alpha=0.052
# [train] episode=1550 step=364794 return=-100.96 success=True time=168.2s geometry=cross_stream history=8 | q1=20.035 actor=103.804 alpha=0.051
# [train] episode=1555 step=366198 return=118.72 success=True time=153.3s geometry=cross_stream history=8 | q1=115.232 actor=97.839 alpha=0.051
# [train] episode=1560 step=367524 return=139.83 success=True time=124.8s geometry=cross_stream history=8 | q1=33.782 actor=99.293 alpha=0.052
# [train] episode=1565 step=368604 return=-67.28 success=True time=161.4s geometry=cross_stream history=8 | q1=19.714 actor=100.063 alpha=0.052
# [train] episode=1570 step=370140 return=135.60 success=True time=145.1s geometry=cross_stream history=8 | q1=42.444 actor=105.060 alpha=0.055
# [train] episode=1575 step=372168 return=129.38 success=True time=183.6s geometry=cross_stream history=8 | q1=5.243 actor=100.632 alpha=0.054
# [train] episode=1580 step=373326 return=131.89 success=True time=95.7s geometry=cross_stream history=8 | q1=4.274 actor=94.551 alpha=0.054
# [train] episode=1585 step=374904 return=-241.35 success=False time=39.7s geometry=cross_stream history=8 | q1=20.942 actor=95.423 alpha=0.053
# [eval] step=375000 objective=arrival_v2 return=-18.69 safety=34.181 success=70.00% time=128.4s energy=93516.3 path=79.5 prog=0.80
# [train] episode=1590 step=376032 return=110.88 success=True time=144.2s geometry=cross_stream history=8 | q1=4.040 actor=102.779 alpha=0.052
# [train] episode=1595 step=377796 return=-53.90 success=False time=240.1s geometry=cross_stream history=8 | q1=5.340 actor=97.111 alpha=0.051
# [train] episode=1600 step=378612 return=133.61 success=True time=149.7s geometry=cross_stream history=8 | q1=136.064 actor=99.090 alpha=0.053
# [train] episode=1605 step=379848 return=139.94 success=True time=81.8s geometry=cross_stream history=8 | q1=77.402 actor=103.652 alpha=0.054
# [train] episode=1610 step=381180 return=141.99 success=True time=101.8s geometry=cross_stream history=8 | q1=75.499 actor=101.550 alpha=0.054
# [train] episode=1615 step=382308 return=122.81 success=True time=182.6s geometry=cross_stream history=8 | q1=154.712 actor=106.362 alpha=0.053
# [train] episode=1620 step=383100 return=-232.47 success=False time=14.4s geometry=cross_stream history=8 | q1=5.263 actor=101.448 alpha=0.053
# [train] episode=1625 step=383922 return=139.65 success=True time=67.9s geometry=cross_stream history=8 | q1=2.977 actor=96.829 alpha=0.055
# ...
# [train] episode=4370 step=916092 return=142.84 success=True time=83.5s geometry=cross_stream history=8 | q1=317.537 actor=28.390 alpha=0.100
# [train] episode=4375 step=916620 return=141.59 success=True time=43.4s geometry=cross_stream history=8 | q1=6.966 actor=36.744 alpha=0.100
# [train] episode=4380 step=917496 return=140.52 success=True time=94.4s geometry=cross_stream history=8 | q1=152.080 actor=33.748 alpha=0.101
# [train] episode=4385 step=918078 return=141.10 success=True time=47.9s geometry=cross_stream history=8 | q1=93.256 actor=29.869 alpha=0.102
# [train] episode=4390 step=918714 return=139.90 success=True time=67.6s geometry=cross_stream history=8 | q1=150.987 actor=43.414 alpha=0.103
# [train] episode=4395 step=919452 return=141.46 success=True time=72.7s geometry=cross_stream history=8 | q1=20.066 actor=31.332 alpha=0.103
# [train] episode=4400 step=920172 return=93.94 success=True time=99.6s geometry=cross_stream history=8 | q1=84.403 actor=37.477 alpha=0.101
# [train] episode=4405 step=920826 return=-243.59 success=False time=12.0s geometry=cross_stream history=8 | q1=32.325 actor=38.392 alpha=0.101
# [train] episode=4410 step=921708 return=135.51 success=True time=127.5s geometry=cross_stream history=8 | q1=4.176 actor=31.720 alpha=0.100
# [train] episode=4415 step=922530 return=142.34 success=True time=56.6s geometry=cross_stream history=8 | q1=49.103 actor=42.997 alpha=0.100
# [train] episode=4420 step=923220 return=69.40 success=True time=59.9s geometry=cross_stream history=8 | q1=47.419 actor=37.856 alpha=0.100
# [train] episode=4425 step=923910 return=137.20 success=True time=40.6s geometry=cross_stream history=8 | q1=31.442 actor=34.889 alpha=0.103
# [train] episode=4430 step=924828 return=-234.32 success=False time=40.2s geometry=cross_stream history=8 | q1=309.964 actor=32.645 alpha=0.105
# [eval] step=925002 objective=arrival_v2 return=12.87 safety=22.684 success=60.00% time=121.1s energy=89299.4 path=73.2 prog=0.82
# [train] episode=4435 step=925680 return=117.57 success=True time=49.4s geometry=cross_stream history=8 | q1=163.090 actor=34.353 alpha=0.105
# [train] episode=4440 step=926418 return=118.27 success=True time=60.6s geometry=cross_stream history=8 | q1=86.936 actor=33.877 alpha=0.105
# [train] episode=4445 step=927030 return=120.19 success=True time=82.6s geometry=cross_stream history=8 | q1=6.500 actor=35.221 alpha=0.106
# [train] episode=4450 step=927750 return=141.33 success=True time=72.5s geometry=cross_stream history=8 | q1=60.161 actor=34.626 alpha=0.106
# [train] episode=4455 step=928548 return=123.01 success=True time=63.0s geometry=cross_stream history=8 | q1=11.774 actor=36.565 alpha=0.105
# [train] episode=4460 step=929418 return=140.97 success=True time=51.2s geometry=cross_stream history=8 | q1=6.411 actor=33.583 alpha=0.104
# [train] episode=4465 step=930066 return=97.11 success=True time=102.5s geometry=cross_stream history=8 | q1=226.857 actor=30.409 alpha=0.105
# [train] episode=4470 step=930798 return=139.81 success=True time=83.9s geometry=cross_stream history=8 | q1=77.738 actor=35.309 alpha=0.104
# [train] episode=4475 step=931728 return=136.04 success=True time=84.5s geometry=cross_stream history=8 | q1=108.077 actor=24.846 alpha=0.103
# [train] episode=4480 step=932520 return=-259.14 success=False time=7.3s geometry=cross_stream history=8 | q1=26.398 actor=32.685 alpha=0.103
# [train] episode=4485 step=933228 return=140.52 success=True time=106.2s geometry=cross_stream history=8 | q1=90.797 actor=29.714 alpha=0.103
# [train] episode=4490 step=933846 return=140.23 success=True time=90.1s geometry=cross_stream history=8 | q1=5.234 actor=35.504 alpha=0.104
# [train] episode=4495 step=934908 return=140.86 success=True time=87.9s geometry=cross_stream history=8 | q1=4.103 actor=34.530 alpha=0.101
# [train] episode=4500 step=935598 return=120.40 success=True time=67.7s geometry=cross_stream history=8 | q1=4.837 actor=33.780 alpha=0.102
# [train] episode=4505 step=936648 return=-397.06 success=False time=98.1s geometry=cross_stream history=8 | q1=69.791 actor=38.492 alpha=0.102
# [train] episode=4510 step=937644 return=8.86 success=True time=82.2s geometry=cross_stream history=8 | q1=6.769 actor=34.572 alpha=0.101
# [train] episode=4515 step=938100 return=139.32 success=True time=58.4s geometry=cross_stream history=8 | q1=66.359 actor=31.926 alpha=0.100
# [train] episode=4520 step=938904 return=132.21 success=True time=89.0s geometry=cross_stream history=8 | q1=31.950 actor=37.466 alpha=0.102
# [train] episode=4525 step=939420 return=138.44 success=True time=107.8s geometry=cross_stream history=8 | q1=48.225 actor=33.306 alpha=0.102
# [train] episode=4530 step=940326 return=137.28 success=True time=143.2s geometry=cross_stream history=8 | q1=35.362 actor=35.340 alpha=0.102
# [train] episode=4535 step=941172 return=138.21 success=True time=71.8s geometry=cross_stream history=8 | q1=32.378 actor=37.961 alpha=0.102
# [train] episode=4540 step=941748 return=-261.74 success=False time=5.1s geometry=cross_stream history=8 | q1=91.869 actor=27.229 alpha=0.101
# [train] episode=4545 step=942774 return=137.48 success=True time=84.8s geometry=cross_stream history=8 | q1=127.664 actor=38.495 alpha=0.100
# [train] episode=4550 step=943332 return=142.36 success=True time=40.5s geometry=cross_stream history=8 | q1=40.045 actor=34.526 alpha=0.101
# [train] episode=4555 step=944040 return=-291.33 success=False time=53.4s geometry=cross_stream history=8 | q1=124.266 actor=38.340 alpha=0.100
# [train] episode=4560 step=944844 return=139.55 success=True time=91.1s geometry=cross_stream history=8 | q1=34.145 actor=35.538 alpha=0.099
# [train] episode=4565 step=945342 return=-217.34 success=False time=21.7s geometry=cross_stream history=8 | q1=39.269 actor=31.860 alpha=0.099
# [train] episode=4570 step=946266 return=136.89 success=True time=93.9s geometry=cross_stream history=8 | q1=55.533 actor=28.147 alpha=0.101
# [train] episode=4575 step=946932 return=-254.41 success=False time=18.0s geometry=cross_stream history=8 | q1=27.739 actor=26.910 alpha=0.099
# [train] episode=4580 step=947784 return=126.94 success=True time=100.1s geometry=cross_stream history=8 | q1=101.050 actor=39.514 alpha=0.097
# [train] episode=4585 step=948588 return=140.83 success=True time=55.5s geometry=cross_stream history=8 | q1=268.850 actor=33.671 alpha=0.097
# [train] episode=4590 step=949404 return=138.22 success=True time=55.2s geometry=cross_stream history=8 | q1=118.333 actor=35.914 alpha=0.095
# [train] episode=4595 step=949974 return=-251.84 success=False time=32.9s geometry=cross_stream history=8 | q1=143.815 actor=31.226 alpha=0.095
# [eval] step=950004 objective=arrival_v2 return=79.08 safety=7.602 success=86.67% time=71.7s energy=57618.2 path=60.8 prog=0.80
# [train] episode=4600 step=950850 return=137.71 success=True time=73.1s geometry=cross_stream history=8 | q1=24.058 actor=37.982 alpha=0.095
# [train] episode=4605 step=951564 return=85.38 success=True time=73.6s geometry=cross_stream history=8 | q1=42.490 actor=31.341 alpha=0.097
# [train] episode=4610 step=952296 return=135.65 success=True time=100.3s geometry=cross_stream history=8 | q1=22.200 actor=26.786 alpha=0.098
# [train] episode=4615 step=952590 return=131.99 success=True time=87.0s geometry=cross_stream history=8 | q1=77.573 actor=26.713 alpha=0.098
# [train] episode=4620 step=953424 return=140.10 success=True time=69.6s geometry=cross_stream history=8 | q1=134.823 actor=32.968 alpha=0.099
# [train] episode=4625 step=953910 return=131.94 success=True time=72.2s geometry=cross_stream history=8 | q1=135.360 actor=27.524 alpha=0.098
# [train] episode=4630 step=954936 return=137.52 success=True time=85.0s geometry=cross_stream history=8 | q1=72.628 actor=32.170 alpha=0.098
# [train] episode=4635 step=955704 return=138.60 success=True time=63.3s geometry=cross_stream history=8 | q1=5.809 actor=31.314 alpha=0.100
# [train] episode=4640 step=956550 return=137.69 success=True time=100.6s geometry=cross_stream history=8 | q1=42.668 actor=29.684 alpha=0.101
# [train] episode=4645 step=957006 return=141.03 success=True time=69.5s geometry=cross_stream history=8 | q1=138.402 actor=27.742 alpha=0.101
# [train] episode=4650 step=957906 return=141.84 success=True time=74.4s geometry=cross_stream history=8 | q1=204.567 actor=28.651 alpha=0.102
# [train] episode=4655 step=958764 return=141.81 success=True time=71.0s geometry=cross_stream history=8 | q1=40.753 actor=39.292 alpha=0.102
# [train] episode=4660 step=959232 return=143.52 success=True time=53.2s geometry=cross_stream history=8 | q1=141.523 actor=30.426 alpha=0.101
# [train] episode=4665 step=960270 return=132.58 success=True time=78.9s geometry=cross_stream history=8 | q1=58.578 actor=29.005 alpha=0.099
# [train] episode=4670 step=961068 return=-211.95 success=True time=220.5s geometry=cross_stream history=8 | q1=67.482 actor=32.770 alpha=0.102
# [train] episode=4675 step=961638 return=139.09 success=True time=109.1s geometry=cross_stream history=8 | q1=157.886 actor=27.709 alpha=0.103
# [train] episode=4680 step=962490 return=122.68 success=True time=91.3s geometry=cross_stream history=8 | q1=51.762 actor=31.636 alpha=0.102
# [train] episode=4685 step=963474 return=139.85 success=True time=87.4s geometry=cross_stream history=8 | q1=66.090 actor=40.608 alpha=0.099
# [train] episode=4690 step=964116 return=103.87 success=True time=107.2s geometry=cross_stream history=8 | q1=10.251 actor=32.118 alpha=0.099
# [train] episode=4695 step=964938 return=-249.57 success=False time=33.8s geometry=cross_stream history=8 | q1=89.825 actor=27.171 alpha=0.099
# [train] episode=4700 step=965742 return=139.87 success=True time=100.5s geometry=cross_stream history=8 | q1=170.095 actor=31.808 alpha=0.097
# [train] episode=4705 step=966654 return=140.49 success=True time=85.5s geometry=cross_stream history=8 | q1=133.884 actor=38.156 alpha=0.100
# [train] episode=4710 step=967386 return=139.25 success=True time=110.3s geometry=cross_stream history=8 | q1=4.255 actor=26.249 alpha=0.099
# [train] episode=4715 step=968004 return=136.32 success=True time=85.5s geometry=cross_stream history=8 | q1=161.667 actor=27.482 alpha=0.099
# [train] episode=4720 step=969420 return=-229.09 success=False time=22.5s geometry=cross_stream history=8 | q1=230.676 actor=25.095 alpha=0.098
# [train] episode=4725 step=969900 return=139.65 success=True time=83.5s geometry=cross_stream history=8 | q1=99.762 actor=31.823 alpha=0.098
# [train] episode=4730 step=970776 return=137.60 success=True time=90.0s geometry=cross_stream history=8 | q1=10.704 actor=36.929 alpha=0.097
# [train] episode=4735 step=971874 return=91.72 success=True time=81.3s geometry=cross_stream history=8 | q1=39.847 actor=31.472 alpha=0.098
# [train] episode=4740 step=972612 return=127.47 success=True time=109.3s geometry=cross_stream history=8 | q1=56.987 actor=28.342 alpha=0.098
# [train] episode=4745 step=973446 return=136.89 success=True time=102.4s geometry=cross_stream history=8 | q1=8.361 actor=31.929 alpha=0.098
# [train] episode=4750 step=974220 return=-386.10 success=False time=84.2s geometry=cross_stream history=8 | q1=54.514 actor=31.669 alpha=0.100
# [train] episode=4755 step=974982 return=136.21 success=True time=93.8s geometry=cross_stream history=8 | q1=3.481 actor=26.455 alpha=0.100
# [eval] step=975000 objective=arrival_v2 return=90.52 safety=8.277 success=90.00% time=74.2s energy=60128.9 path=61.4 prog=0.84
# [train] episode=4760 step=975528 return=137.51 success=True time=74.8s geometry=cross_stream history=8 | q1=63.721 actor=32.874 alpha=0.101
# [train] episode=4765 step=976308 return=84.30 success=True time=127.5s geometry=cross_stream history=8 | q1=16.377 actor=36.149 alpha=0.103
# [train] episode=4770 step=977058 return=137.71 success=True time=81.4s geometry=cross_stream history=8 | q1=59.293 actor=35.225 alpha=0.103
# [train] episode=4775 step=977676 return=-242.60 success=False time=15.0s geometry=cross_stream history=8 | q1=31.959 actor=30.596 alpha=0.102
# [train] episode=4780 step=978798 return=138.03 success=True time=102.4s geometry=cross_stream history=8 | q1=125.019 actor=37.327 alpha=0.102
# [train] episode=4785 step=979548 return=140.78 success=True time=76.5s geometry=cross_stream history=8 | q1=41.865 actor=28.759 alpha=0.102
# [train] episode=4790 step=980214 return=89.38 success=True time=104.9s geometry=cross_stream history=8 | q1=21.250 actor=35.967 alpha=0.101
# [train] episode=4795 step=980772 return=40.57 success=True time=71.4s geometry=cross_stream history=8 | q1=70.170 actor=24.485 alpha=0.100
# [train] episode=4800 step=981576 return=117.74 success=True time=100.3s geometry=cross_stream history=8 | q1=9.125 actor=27.479 alpha=0.101
# [train] episode=4805 step=982230 return=129.63 success=True time=70.7s geometry=cross_stream history=8 | q1=8.527 actor=26.010 alpha=0.101
# [train] episode=4810 step=982716 return=-284.93 success=False time=41.5s geometry=cross_stream history=8 | q1=21.837 actor=25.111 alpha=0.103
# [train] episode=4815 step=983226 return=-246.81 success=False time=13.0s geometry=cross_stream history=8 | q1=83.734 actor=30.153 alpha=0.101
# [train] episode=4820 step=983880 return=-271.52 success=False time=45.6s geometry=cross_stream history=8 | q1=53.540 actor=32.057 alpha=0.101
# [train] episode=4825 step=984798 return=134.21 success=True time=75.7s geometry=cross_stream history=8 | q1=65.881 actor=31.149 alpha=0.099
# [train] episode=4830 step=985326 return=-259.96 success=False time=13.5s geometry=cross_stream history=8 | q1=37.324 actor=32.981 alpha=0.101
# [train] episode=4835 step=986274 return=138.34 success=True time=78.1s geometry=cross_stream history=8 | q1=25.866 actor=31.682 alpha=0.103
# [train] episode=4840 step=986754 return=139.31 success=True time=75.2s geometry=cross_stream history=8 | q1=84.562 actor=30.463 alpha=0.103
# [train] episode=4845 step=987762 return=64.56 success=True time=98.8s geometry=cross_stream history=8 | q1=267.627 actor=19.733 alpha=0.102
# [train] episode=4850 step=988608 return=119.83 success=True time=88.8s geometry=cross_stream history=8 | q1=4.754 actor=31.972 alpha=0.101
# [train] episode=4855 step=989358 return=124.44 success=True time=64.2s geometry=cross_stream history=8 | q1=34.246 actor=28.563 alpha=0.101
# [train] episode=4860 step=990084 return=141.51 success=True time=59.7s geometry=cross_stream history=8 | q1=34.948 actor=21.542 alpha=0.101
# [train] episode=4865 step=991008 return=142.00 success=True time=76.3s geometry=cross_stream history=8 | q1=60.468 actor=29.526 alpha=0.101
# [train] episode=4870 step=991842 return=140.41 success=True time=75.9s geometry=cross_stream history=8 | q1=230.889 actor=18.987 alpha=0.101
# [train] episode=4875 step=992664 return=141.93 success=True time=89.1s geometry=cross_stream history=8 | q1=108.737 actor=26.523 alpha=0.102
# [train] episode=4880 step=993474 return=140.43 success=True time=73.8s geometry=cross_stream history=8 | q1=140.601 actor=27.486 alpha=0.102
# [train] episode=4885 step=993996 return=18.78 success=True time=110.5s geometry=cross_stream history=8 | q1=55.459 actor=22.687 alpha=0.103
# [train] episode=4890 step=994692 return=-331.00 success=False time=61.1s geometry=cross_stream history=8 | q1=4.383 actor=26.734 alpha=0.104
# [train] episode=4895 step=995688 return=83.71 success=True time=87.7s geometry=cross_stream history=8 | q1=7.325 actor=38.268 alpha=0.102
# [train] episode=4900 step=996498 return=98.73 success=True time=82.7s geometry=cross_stream history=8 | q1=167.463 actor=34.902 alpha=0.101
# [train] episode=4905 step=997278 return=-253.57 success=False time=10.4s geometry=cross_stream history=8 | q1=103.345 actor=34.064 alpha=0.101
# [train] episode=4910 step=998100 return=-406.60 success=False time=132.6s geometry=cross_stream history=8 | q1=23.150 actor=26.835 alpha=0.102
# [train] episode=4915 step=998700 return=135.21 success=True time=117.8s geometry=cross_stream history=8 | q1=32.165 actor=34.309 alpha=0.102
# [train] episode=4920 step=999288 return=142.55 success=True time=40.9s geometry=cross_stream history=8 | q1=58.299 actor=27.096 alpha=0.102

# %% [markdown]
# ## 5. Summary + gate

# %%
def summarize_phase(run_root: Path, total_steps: int, label: str, gate_filename: str):
    eval_log_path = run_root / 'results' / 'eval_log.csv'
    final_eval_path = run_root / 'results' / 'final_eval.json'
    trainer_state_path = run_root / 'trainer_state.json'
    train_config_path = run_root / 'results' / 'train_config.txt'

    if not eval_log_path.exists():
        raise FileNotFoundError(f'missing eval log: {eval_log_path}')
    if not final_eval_path.exists():
        raise FileNotFoundError(f'missing final eval: {final_eval_path}')

    df = pd.read_csv(eval_log_path)
    final_eval = json.loads(final_eval_path.read_text(encoding='utf-8'))
    trainer_state = json.loads(trainer_state_path.read_text(encoding='utf-8')) if trainer_state_path.exists() else {}

    history_from_config = 'NA'
    obs_dim_from_config = 'NA'
    if train_config_path.exists():
        for ln in train_config_path.read_text(encoding='utf-8').splitlines():
            s = ln.strip()
            if s.startswith('history_length='):
                history_from_config = s.split('=', 1)[1]
            elif s.startswith('obs_dim='):
                obs_dim_from_config = s.split('=', 1)[1]

    peak_success = float(df['eval_success_rate'].max()) if len(df) else 0.0
    peak_step = int(df.loc[df['eval_success_rate'].idxmax(), 'env_step']) if len(df) else 0
    last100 = df[df['env_step'] >= total_steps - 100_000].copy()
    last100_mean = float(last100['eval_success_rate'].mean()) if len(last100) else 0.0
    mean_all = float(df['eval_success_rate'].mean()) if len(df) else 0.0
    n_evals_with_success = int((df['eval_success_rate'] > 0).sum()) if len(df) else 0
    final_success = float(final_eval['eval_success_rate'])
    counts = final_eval.get('eval_termination_counts', {})
    num_eps = float(final_eval.get('num_eval_episodes', EVAL_EPISODES))
    oob_rate = float(counts.get('out_of_bounds', 0)) / max(num_eps, 1.0)

    print('=' * 100)
    print(f'{label}  (arrival_v2 / s0 / k=8 / seed={SEED} / vanilla / {total_steps:,} steps)')
    print('-' * 100)
    print(f"  final_success_rate    : {final_success:.4f}   gate >= {PASS_FINAL_SUCCESS:.2f}")
    print(f"  peak_success_rate     : {peak_success:.4f}   @ {peak_step:,}")
    print(f"  last100k_mean_success : {last100_mean:.4f}   gate >= {PASS_LAST100_RATIO * peak_success:.4f}")
    print(f"  full-traj mean        : {mean_all:.4f}   (39 evals)")
    print(f"  n_evals_with_success  : {n_evals_with_success} / {len(df)}")
    print(f"  final_oob_rate        : {oob_rate:.4f}   gate <= {PASS_OOB_RATE:.2f}")
    print(f"  obs_dim               : {obs_dim_from_config}   (expect 12*8=96)")
    print(f"  history_length        : {history_from_config}   (from train_config.txt)")
    print(f"  context_obs           : {trainer_state.get('include_episode_context_obs', 'NA')}")
    print(f"  timeout_bootstrap     : {trainer_state.get('timeout_bootstrap_semantics', 'NA')}")
    print(f"  termination           : {counts}")
    print('=' * 100)

    if len(df):
        print()
        print('[last 16 eval rows]')
        cols = ['env_step', 'eval_success_rate', 'eval_return', 'eval_safety_cost',
                'eval_time_s', 'eval_progress_ratio']
        available = [c for c in cols if c in df.columns]
        print(df[available].tail(16).to_string(index=False))

    checks = [
        ('final success >= 0.85', final_success >= PASS_FINAL_SUCCESS, f'{final_success:.4f}'),
        ('last100k mean >= 0.9 * peak', last100_mean >= PASS_LAST100_RATIO * peak_success,
         f'{last100_mean:.4f} / peak={peak_success:.4f}'),
        ('final OOB rate <= 0.10', oob_rate <= PASS_OOB_RATE, f'{oob_rate:.4f}'),
        ('arrival_v2 context obs enabled',
         trainer_state.get('include_episode_context_obs') is True,
         str(trainer_state.get('include_episode_context_obs'))),
        ('arrival_v2 timeout terminal semantics',
         trainer_state.get('timeout_bootstrap_semantics') == 'terminal',
         str(trainer_state.get('timeout_bootstrap_semantics'))),
    ]

    print()
    print('=' * 96)
    print(f"{'check':<48}{'pass':>8}{'detail':>40}")
    print('-' * 96)
    all_pass = True
    for name, ok, detail in checks:
        mark = 'PASS' if ok else 'FAIL'
        if not ok:
            all_pass = False
        print(f'{name:<48}{mark:>8}{detail:>40}')
    print('=' * 96)

    summary = {
        'phase': label,
        'objective': OBJECTIVE,
        'probe_layout': PROBE_LAYOUT,
        'history_length': int(history_from_config) if history_from_config != 'NA' else HISTORY_LENGTH,
        'seed': SEED,
        'total_steps': total_steps,
        'algorithm': 'sac_vanilla',
        'final_success_rate': final_success,
        'peak_success_rate': peak_success,
        'peak_step': peak_step,
        'last100k_mean_success': last100_mean,
        'mean_success_full_trajectory': mean_all,
        'n_evals_with_success': n_evals_with_success,
        'n_evals_total': len(df),
        'final_oob_rate': oob_rate,
        'termination_counts': counts,
        'all_pass': bool(all_pass),
        'checks': [{'name': n, 'ok': bool(ok), 'detail': d} for n, ok, d in checks],
    }
    out_path = run_root / 'results' / gate_filename
    out_path.parent.mkdir(parents=True, exist_ok=True)
    out_path.write_text(json.dumps(summary, indent=2), encoding='utf-8')
    print(f'[saved] {out_path}')
    return summary

x_summary = summarize_phase(
    X_RUN_ROOT,
    X_TOTAL_STEPS,
    'SINGLE_CROSS_S0_K8_SEED7',
    'single_cross_s0_k8_seed7_gate_summary.json',
)
X_PASS = x_summary['all_pass']
print()
print(f'X_PASS = {X_PASS}')
# Out:
# ====================================================================================================
# SINGLE_CROSS_S0_K8_SEED7  (arrival_v2 / s0 / k=8 / seed=7 / vanilla / 1,000,000 steps)
# ----------------------------------------------------------------------------------------------------
#   final_success_rate    : 0.8667   gate >= 0.85
#   peak_success_rate     : 0.9000   @ 550,002
#   last100k_mean_success : 0.8167   gate >= 0.8100
#   full-traj mean        : 0.5179   (39 evals)
#   n_evals_with_success  : 31 / 39
#   final_oob_rate        : 0.1333   gate <= 0.10
#   obs_dim               : 96   (expect 12*8=96)
#   history_length        : 8   (from train_config.txt)
#   context_obs           : True
#   timeout_bootstrap     : terminal
#   termination           : {'goal': 26, 'out_of_bounds': 4}
# ====================================================================================================
#
# [last 16 eval rows]
#  env_step  eval_success_rate  eval_return  eval_safety_cost  eval_time_s  eval_progress_ratio
#    600000           0.766667    62.883956          7.236163   124.206667             0.798208
#    625002           0.433333   -61.795611         29.614900   137.580000             0.703920
#    650004           0.833333    55.427339         13.376826   102.400000             0.769950
#    675000           0.666667    -4.916195         24.615149   146.330000             0.759398
#    700002           0.866667    68.244777         16.549089   100.400000             0.834999
#    725004           0.900000    86.029260         10.362118    83.236667             0.833933
#    750000           0.866667    79.162547          7.572606    81.996667             0.804537
#    775002           0.866667    78.240926          8.692288    75.006667             0.813605
#    800004           0.900000    87.658458          9.803808    73.540000             0.836884
#    825000           0.900000    92.007450          7.583837    73.503333             0.836008
#    850002           0.700000    27.231568         23.502966   103.780000             0.822209
#    875004           0.900000    84.532243         11.309961    69.666667             0.835046
#    900000           0.900000    89.089997          9.095185    68.673333             0.836132
#    925002           0.600000    12.872138         22.684132   121.063333             0.820432
#    950004           0.866667    79.084534          7.602197    71.663333             0.802359
#    975000           0.900000    90.518877          8.277212    74.160000             0.835178
#
# ================================================================================================
# check                                               pass                                  detail
# ------------------------------------------------------------------------------------------------
# final success >= 0.85                               PASS                                  0.8667
# last100k mean >= 0.9 * peak                         PASS                    0.8167 / peak=0.9000
# final OOB rate <= 0.10                              FAIL                                  0.1333
# arrival_v2 context obs enabled                      PASS                                    True
# arrival_v2 timeout terminal semantics               PASS                                terminal
# ================================================================================================
# [saved] experiments/arrival_v2_prototype/single_u15_cross_tgt15/arrival_v2/sac_vanilla/s0_k8/seed_7/results/single_cross_s0_k8_seed7_gate_summary.json
#
# X_PASS = False

# %% [markdown]
# ## 6. TIE-BREAK verdict — k=8 seed=7 vs §7.8 anchor (seed=42 PASS) + §7.8' (seed=0 PARTIAL) + 全表 7-run 对照

# %%
def read_baseline(root: Path, ref_final: float, ref_oob: float, ref_mean: float = None):
    fp = root / 'results' / 'final_eval.json'
    log = root / 'results' / 'eval_log.csv'
    out = {'final': ref_final, 'oob': ref_oob, 'mean': ref_mean, 'peak': None, 'peak_step': None, 'source': 'report'}
    if fp.exists():
        d = json.loads(fp.read_text(encoding='utf-8'))
        f = float(d['eval_success_rate'])
        c = d.get('eval_termination_counts', {})
        n = float(d.get('num_eval_episodes', EVAL_EPISODES))
        out['final'] = f
        out['oob'] = float(c.get('out_of_bounds', 0)) / max(n, 1.0)
        out['source'] = 'on-disk'
    if log.exists():
        dlog = pd.read_csv(log)
        out['mean'] = float(dlog['eval_success_rate'].mean())
        out['peak'] = float(dlog['eval_success_rate'].max())
        out['peak_step'] = int(dlog.loc[dlog['eval_success_rate'].idxmax(), 'env_step'])
    return out

print('=' * 100)
print('SINGLE_CROSS — k=8 multi-seed TIE-BREAK verdict (seed=7 vs seed=42 PASS + seed=0 PARTIAL)')
print('-' * 100)

# 本 run (k=8 seed=7)
k8s7_final = float(x_summary['final_success_rate'])
k8s7_oob   = float(x_summary['final_oob_rate'])
k8s7_peak  = float(x_summary['peak_success_rate'])
k8s7_mean  = float(x_summary.get('mean_success_full_trajectory', 0.0))
k8s7_nsucc = int(x_summary.get('n_evals_with_success', 0))
k8s7_ntot  = int(x_summary.get('n_evals_total', 0))

# 5 个 baseline（report-fallback 用 §7.8 / §7.8' / §7.6.4 / §7.7.1 / §7.1 转载值）
b_k8_s42 = read_baseline(X_K8_S42_ROOT,   0.900, 0.100, 0.636)   # §7.8 anchor PASS
b_k8_s0  = read_baseline(X_K8_S0_ROOT,    0.500, 0.133, 0.260)   # §7.8' PARTIAL
b_k4_s42 = read_baseline(X_K4_S42_ROOT,   0.100, 0.667, 0.221)   # §7.6.4 floor
b_k4_s0  = read_baseline(X_K4_S0_ROOT,    0.400, 0.200, 0.218)   # §7.7.1 sister
b_s1     = read_baseline(X_S1_UPPER_ROOT, 0.900, 0.100, 0.497)   # §7.1 upper

print()
print(f'{"config":<48}{"final":>10}{"mean":>10}{"oob":>10}{"peak":>10}{"source":>12}')
print('-' * 100)
print(f'{"vanilla s1_k4 s42 (§7.1 upper ref)":<48}{b_s1["final"]:>10.4f}{(b_s1["mean"] or float("nan")):>10.4f}{b_s1["oob"]:>10.4f}{(b_s1["peak"] or float("nan")):>10.4f}{b_s1["source"]:>12}')
print(f'{"vanilla s0_k4 s42 (§7.6.4 FAIL floor)":<48}{b_k4_s42["final"]:>10.4f}{(b_k4_s42["mean"] or float("nan")):>10.4f}{b_k4_s42["oob"]:>10.4f}{(b_k4_s42["peak"] or float("nan")):>10.4f}{b_k4_s42["source"]:>12}')
# Pre-format apostrophe-containing label (avoid backslash inside f-string {...} expression)
label_k8_s0 = "vanilla s0_k8 s0  (§7.8' PARTIAL)"
print(f'{"vanilla s0_k4 s0  (§7.7.1 sister)":<48}{b_k4_s0["final"]:>10.4f}{(b_k4_s0["mean"] or float("nan")):>10.4f}{b_k4_s0["oob"]:>10.4f}{(b_k4_s0["peak"] or float("nan")):>10.4f}{b_k4_s0["source"]:>12}')
print(f'{"vanilla s0_k8 s42 (§7.8 anchor PASS)":<48}{b_k8_s42["final"]:>10.4f}{(b_k8_s42["mean"] or float("nan")):>10.4f}{b_k8_s42["oob"]:>10.4f}{(b_k8_s42["peak"] or float("nan")):>10.4f}{b_k8_s42["source"]:>12}')
print(f'{label_k8_s0:<48}{b_k8_s0["final"]:>10.4f}{(b_k8_s0["mean"] or float("nan")):>10.4f}{b_k8_s0["oob"]:>10.4f}{(b_k8_s0["peak"] or float("nan")):>10.4f}{b_k8_s0["source"]:>12}')
print(f'{"vanilla s0_k8 s7  (THIS RUN, TIE-BREAK)":<48}{k8s7_final:>10.4f}{k8s7_mean:>10.4f}{k8s7_oob:>10.4f}{k8s7_peak:>10.4f}{"on-disk":>12}')
print('=' * 100)

# Δ 行
delta_final_vs_s42 = k8s7_final - b_k8_s42['final']
delta_mean_vs_s42  = k8s7_mean  - (b_k8_s42['mean'] or 0.0)
delta_oob_vs_s42   = k8s7_oob   - b_k8_s42['oob']
delta_final_vs_s0  = k8s7_final - b_k8_s0['final']
delta_mean_vs_s0   = k8s7_mean  - (b_k8_s0['mean'] or 0.0)

print()
print(f'{"contrast":<60}{"Δ final":>12}{"Δ mean":>12}{"Δ oob":>12}')
print('-' * 100)
print(f'{"k=8 seed=7 vs k=8 seed=42 (vs PASS anchor)":<60}'
      f'{delta_final_vs_s42:>+12.4f}{delta_mean_vs_s42:>+12.4f}{delta_oob_vs_s42:>+12.4f}')
print(f'{"k=8 seed=7 vs k=8 seed=0 (vs PARTIAL sister)":<60}'
      f'{delta_final_vs_s0:>+12.4f}{delta_mean_vs_s0:>+12.4f}{(k8s7_oob - b_k8_s0["oob"]):>+12.4f}')
print(f'{"k=8 seed=7 vs s1_k4 seed=42 (gap-to-upper)":<60}'
      f'{k8s7_final - b_s1["final"]:>+12.4f}'
      f'{(k8s7_mean - (b_s1["mean"] or 0)):>+12.4f}'
      f'{k8s7_oob - b_s1["oob"]:>+12.4f}')
print('=' * 100)
print()
print(f'k=8 seed=7 evals_with_success: {k8s7_nsucc} / {k8s7_ntot}  '
      f'(seed=42 was 37/39 PASS, seed=0 was 32/39 PARTIAL, k=4 seed=42 was 35/39 FAIL, k=4 seed=0 was 34/39 FAIL)')

# TIE-BREAK verdict — 4 档
THRESH_FINAL = 0.15   # paired |Δfinal| 容忍度 (vs anchor)
abs_delta_vs_s42 = abs(delta_final_vs_s42)
seed7_pass = (k8s7_final >= PASS_FINAL_SUCCESS) and (k8s7_oob <= PASS_OOB_RATE)
seed7_strong_partial = (k8s7_final >= 0.50) and (k8s7_final < PASS_FINAL_SUCCESS)
seed7_regress = (k8s7_final < 0.50)

# 3-seed aggregate state
seed42_pass = True   # §7.8 anchor
seed0_pass  = False  # §7.8' PARTIAL
n_pass_total = int(seed42_pass) + int(seed0_pass) + int(seed7_pass)

if seed7_pass and abs_delta_vs_s42 <= THRESH_FINAL:
    verdict = (
        f'TIE-BREAK-ROBUST — seed=7 PASS 且 |Δfinal vs anchor|={abs_delta_vs_s42:.3f}≤0.15；'
        f'3-seed state: {n_pass_total}/3 PASS (seed=42 PASS + seed=7 PASS + seed=0 PARTIAL)；'
        '支持 H1。§7.8 主张升格为 "k=4→8 closes 80pp gap in 2/3 seeds; seed=0 hits local minimum, '
        'requires init audit"。下一步：§8 P1#2 k=12 seed=0 sister 验 monotonicity 跨 seed 鲁棒性'
    )
elif seed7_pass and abs_delta_vs_s42 > THRESH_FINAL:
    verdict = (
        f'TIE-BREAK-HIGH-VAR — seed=7 PASS 但 |Δfinal vs anchor|={abs_delta_vs_s42:.3f}>0.15；'
        f'3-seed state: {n_pass_total}/3 PASS but high variance；'
        '§7.8 写 "k=8 PASS robust modulo high seed variance; thesis claim requires ≥4 seeds"；'
        '下一步：考虑 §8 P0 SAC variance reduction (DroQ / SimBa / N-Step) 改善 stability'
    )
elif seed7_strong_partial:
    verdict = (
        f'TIE-BREAK-WEAK — seed=7 STRONG-PARTIAL (final={k8s7_final:.3f}∈[0.5,0.85))；'
        '3-seed state: 1 PASS + 2 PARTIAL；'
        'effect 部分存在但 seed-sensitive；§7.8 reframe "k=8 buys partial mitigation: '
        'final 50-90% range with strong seed dependence"；'
        '放弃 §8 P1#2 k=12 / k=16 单 seed 路径；考虑直接转向 §8 P0 SAC variance reduction'
    )
else:  # seed7_regress
    verdict = (
        f'TIE-BREAK-DEAD — seed=7 REGRESS (final={k8s7_final:.3f}<0.50)；'
        '3-seed state: 1/3 PASS only；'
        '强证据 H2：§7.8 anchor 本质 seed=42 lucky strike，k=4→8 真实增益接近 +10pp 而非 +80pp；'
        '§7.8 主张回退「k=4→8 effect highly seed-dependent, not a method-level gap closer」；'
        '必须转向 §8 P0 SAC variance reduction (DroQ / SimBa / N-Step) 路线，'
        '或重新审视 actor temporal info hypothesis（可能是 critic estimation noise 同样大）'
    )

print()
print(f'>>> verdict: {verdict}')

# 落盘 tie-break summary
tiebreak_out = {
    'experiment': 'arrival_v2_s0_cross_k8_seed7_tiebreak',
    'seed': SEED,
    'benchmark': X_BENCHMARK_KEY,
    'probe_layout': PROBE_LAYOUT,
    'history_length': HISTORY_LENGTH,
    'total_steps': X_TOTAL_STEPS,
    'algorithm': 'sac_vanilla',
    'cli_diff_vs_§7.8_anchor': '--seed 42 → --seed 7',
    'results': {
        'k8_s7_thisrun': {
            'final': k8s7_final, 'mean': k8s7_mean, 'oob': k8s7_oob, 'peak': k8s7_peak,
            'n_evals_with_success': k8s7_nsucc, 'n_evals_total': k8s7_ntot,
        },
        'k8_s42_anchor_§7.8_PASS': b_k8_s42,
        "k8_s0_§7.8'_PARTIAL": b_k8_s0,
        '§7.6.4_k4_s42_floor': b_k4_s42,
        '§7.7.1_k4_s0_sister': b_k4_s0,
        '§7.1_s1_k4_s42_upper': b_s1,
    },
    'delta_vs_§7.8_anchor_seed42': {
        'final_pp': round(delta_final_vs_s42 * 100, 2),
        'mean_pp':  round(delta_mean_vs_s42  * 100, 2),
        'oob_pp':   round(delta_oob_vs_s42   * 100, 2),
    },
    "delta_vs_§7.8'_seed0": {
        'final_pp': round(delta_final_vs_s0 * 100, 2),
        'mean_pp':  round(delta_mean_vs_s0  * 100, 2),
        'oob_pp':   round((k8s7_oob - b_k8_s0['oob']) * 100, 2),
    },
    'multi_seed_state': {
        'seed42': 'PASS',
        'seed0': 'PARTIAL',
        'seed7': 'PASS' if seed7_pass else ('STRONG-PARTIAL' if seed7_strong_partial else 'REGRESS'),
        'n_pass_total': n_pass_total,
    },
    'all_pass': bool(x_summary['all_pass']),
    'verdict': verdict,
}
out_dir = Path('experiments/arrival_v2_prototype/s0_cross_k8_seed7_summary')
out_dir.mkdir(parents=True, exist_ok=True)
out_path = out_dir / 'combined_gate_summary.json'
out_path.write_text(json.dumps(tiebreak_out, indent=2), encoding='utf-8')
print(f'\n[saved] {out_path}')
# Out:
# ====================================================================================================
# SINGLE_CROSS — k=8 multi-seed TIE-BREAK verdict (seed=7 vs seed=42 PASS + seed=0 PARTIAL)
# ----------------------------------------------------------------------------------------------------
#
# config                                               final      mean       oob      peak      source
# ----------------------------------------------------------------------------------------------------
# vanilla s1_k4 s42 (§7.1 upper ref)                  0.9000    0.4966    0.1000    0.9000     on-disk
# vanilla s0_k4 s42 (§7.6.4 FAIL floor)               0.1000    0.2205    0.6667    0.3667     on-disk
# vanilla s0_k4 s0  (§7.7.1 sister)                   0.4000    0.2179    0.2000    0.5333     on-disk
# vanilla s0_k8 s42 (§7.8 anchor PASS)                0.9000    0.6359    0.1000    0.9000     on-disk
# vanilla s0_k8 s0  (§7.8' PARTIAL)                   0.5000    0.2598    0.1333    0.5000     on-disk
# vanilla s0_k8 s7  (THIS RUN, TIE-BREAK)             0.8667    0.5179    0.1333    0.9000     on-disk
# ====================================================================================================
#
# contrast                                                         Δ final      Δ mean       Δ oob
# ----------------------------------------------------------------------------------------------------
# k=8 seed=7 vs k=8 seed=42 (vs PASS anchor)                       -0.0333     -0.1179     +0.0333
# k=8 seed=7 vs k=8 seed=0 (vs PARTIAL sister)                     +0.3667     +0.2581     +0.0000
# k=8 seed=7 vs s1_k4 seed=42 (gap-to-upper)                       -0.0333     +0.0214     +0.0333
# ====================================================================================================
#
# k=8 seed=7 evals_with_success: 31 / 39  (seed=42 was 37/39 PASS, seed=0 was 32/39 PARTIAL, k=4 seed=42 was 35/39 FAIL, k=4 seed=0 was 34/39 FAIL)
#
# >>> verdict: TIE-BREAK-DEAD — seed=7 REGRESS (final=0.867<0.50)；3-seed state: 1/3 PASS only；强证据 H2：§7.8 anchor 本质 seed=42 lucky strike，k=4→8 真实增益接近 +10pp 而非 +80pp；§7.8 主张回退「k=4→8 effect highly seed-dependent, not a method-level gap closer」；必须转向 §8 P0 SAC variance reduction (DroQ / SimBa / N-Step) 路线，或重新审视 actor temporal info hypothesis（可能是 critic estimation noise 同样大）
#
# [saved] experiments/arrival_v2_prototype/s0_cross_k8_seed7_summary/combined_gate_summary.json
